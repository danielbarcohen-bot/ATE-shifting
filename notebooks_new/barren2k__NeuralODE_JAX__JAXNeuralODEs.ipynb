# %% [markdown]
# # Task: Neural Ordinary Differential Equations
# #### Non-linear Euler-Bernoulli beam
#
# ---
#
# Lecture: "Physics-augmented machine learning" @ Cyber-Physical Simulation, TU Darmstadt
#
# Lecturer: Prof. Oliver Weeger
#
# Content creators: Dr.-Ing. Maximilian Kannapin
#
# Summer term 2024
#
# ---
#
# #### In this notebook, you learn...
#
# *

# %% [markdown]
# *Run the following cells to install and import the required dependencies.*

# %%
# %% Imports
import time

import numpy
import numpy as np
import diffrax
from diffrax import backward_hermite_coefficients, CubicInterpolation
import equinox as eqx  # https://github.com/patrick-kidger/equinox
import jax
import jax.nn as jnn
import jax.numpy as jnp
import jax.random as jr
import matplotlib.pyplot as plt
import optax  # https://github.com/deepmind/optax
import os
from tqdm import tqdm
import numpy as np

# %% [markdown]
# ## Introduction to Neural Ordinary Differential Equations (Neural ODEs)
#
# ### Ordinary Differential Equations (ODEs)
#
# Ordinary Differential Equations (ODEs) are equations that describe the relationship between a function and its derivatives and are typically written in the form:
# $$
# \[\frac{dy(t)}{dt} = f(t, y(t)) \]
# $$
# where $\( y(t) \)$ is the state of the system at time $\( t \)$, and $\( f(t, y(t)) \)$ is a function that describes the dynamics of the system.

# %% [markdown]
# ### Neural Ordinary Differential Equations (NODEs)
#
# Owing to the fact that Ordinary Differential Equations are a continuous functions, Neural ODEs leverage this behaviour to model complex dynamical systems. Instead of using discrete layers like traditional Neural Networks or Residual Networks, Neural ODEs use a Neural Network to parameterize the function $f$ as an Ordinary Differential Equation.
#
# >insert image of ResNet (intermittent) vs NODE (continuous) from Chen et. al.<
#
# Given an initial state $\( y(t_0) = y_0 \)$, the evolution of the state over time can be described by solving the ODE:
#
# $$\[ y(t) = y_0 + \int_{t_0}^{t} f(y(t), t, \theta) dt \]$$
#
# where $\( \theta \)$ represents the parameters of the neural network, and $y_0 \in \mathbb{R}^n$.
#
# Simply put, we need the dynamics function to accept the current state $y(t)$ of the ODE at current time $t$ and parameters $\theta$, to give an output $\frac{\partial(y(t))}{\partial(t)}$ that has the same shape as $y(t)$
#
# Let's take a look at how to define such a class of machine learning models using Google JAX

# %%
class NeuralODE(eqx.Module):
    mlp: eqx.nn.MLP
    time_dependent: bool
    state_size: int
    augmentation_size: int
    input_size: int

    def __init__(self, state_size, augmentation_size=0, input_size=0, time_dependent=False, nn_width=16, nn_depth=2, *,
                 key, **kwargs):
        super().__init__(**kwargs)

        nn_in_size = state_size + augmentation_size + input_size + time_dependent
        nn_out_size = state_size + augmentation_size

        self.state_size = state_size
        self.time_dependent = time_dependent
        self.augmentation_size = augmentation_size
        self.input_size = input_size

        self.mlp = eqx.nn.MLP(
            in_size=nn_in_size,
            out_size=nn_out_size,
            width_size=nn_width,
            depth=nn_depth,
            activation=jnn.softplus,
            key=key,
        )

    def __call__(self, ts, y0, us):

        y0 = jnp.pad(y0, (0, self.augmentation_size))

        if self.input_size:
            coeffs = backward_hermite_coefficients(ts, us)
            interp = CubicInterpolation(ts, coeffs)
        else:
            interp = None

        def func(t, y, interp):
            if self.input_size:
                u = interp.evaluate(t)
            else:
                u = jnp.empty(shape=(0,))

            if self.time_dependent:
                t = jnp.expand_dims(t, axis=0)
            else:
                t = jnp.empty(shape=(0,))

            nn_input = jnp.concat([y, u, t], axis=0)
            return self.mlp(nn_input)

        solution = diffrax.diffeqsolve(
            diffrax.ODETerm(func),
            diffrax.Dopri5(),
            t0=ts[0], t1=ts[-1],
            dt0=ts[1] - ts[0], y0=y0,
            stepsize_controller=diffrax.PIDController(rtol=1e-3, atol=1e-6),
            saveat=diffrax.SaveAt(ts=ts),
            args=interp,
        )
        return solution.ys[:, :self.state_size]

# %% [markdown]
# In the above, we have defined, a Neural ODE model that adapts to the size of the data that is being provided.  We are using a Dormand-Prince Solver, which is an adaptive step-size solver. The adaptive step size control is achieved using a PID Controller where the relative tolerance (`rtol`) and absolute tolerance (`atol`). The PID controller can further be tweaked using the PID coefficients (`pcoeff`, `icoeff` and `dcoeff`) or even by adding minnimum and maximum step size (`dtmin` and `dtmax`)
#
# For now, we ignore the statements relating to augmentations. It defaults to 0, which means no augmentations will take place.

# %% [markdown]
# ## Data Preparation
#
# A parameter-sweep is performed on the Non-linear Euler-Bernoulli beam model on MATLAB to generate data for training.
#
# The following function imports the necessary data and prepares it to be used with the model, for training and inference.

# %%
def dataprep(datafile, node):
    def create_path(i):
        filename = [filename for filename in os.listdir('nlebb-training-data/') if filename.startswith(str(i))][0]
        path1 = "nlebb-training-data/"
        path2 = filename

        return path1 + path2 + "/" + path2 + "_exc.csv", path1 + path2 + "/" + path2 + "_out.csv"

    def load_data(data_list, nodes):
        inp = np.empty((len(data_list), 2502, 2))
        out = np.empty((len(data_list), 2502, len(nodes)))

        for i in range(len(data_list)):
            exc, outt = create_path(data_list[i])
            inp[i] = np.loadtxt(open(exc), delimiter=',', skiprows=1)
            out[i] = np.loadtxt(open(outt), delimiter=',', skiprows=1, usecols=(nodes))

        return inp, out

    inp_tr, out_tr = load_data(datafile, node)
    us = np.expand_dims(inp_tr[:, :, 1],-1)
    ys = out_tr
    ts = inp_tr[:, :, 0]
    ts = np.squeeze(ts[0])
    return us, ys, ts

# %% [markdown]
# We can now define the parameters for the model and its training

# %%
datafile = [2100, 2105, 2130, 2135]
#datafile = np.arange(2100, 2136, 1)
node = [34, 36]    # The z-axis displacement of the final node and its derivative w.r.t time
aug_dim = 0
hidden_layers = 2
hidden_dims = 32
learning_rate = 0.001
Epochs = 20000
print_every = 100
validation_dataset = np.arange(2100, 2136, 1)
optim = optax.adabelief(learning_rate)
seed = 42         # Seed for a pseudo-random function which initializes parameters of the Neural Network

# %%
us_train, ys_train, ts_train = dataprep(datafile, node)       # Training data
us, ys, ts = dataprep(datafile, node)
us_val, ys_val, ts_val = dataprep(validation_dataset, node)  # Validation data
num_ts = ts_train.size
key = jr.PRNGKey(seed)
model_key, key = jr.split(key, 2)

# %% [markdown]
# Further, let's also define functions that obtain loss, gradient and update the weights accordingly.

# %%
def _dataloader(arrays, batch_size, *, key):
    dataset_size = arrays[0].shape[0]
    assert all(array.shape[0] == dataset_size for array in arrays)
    indices = jnp.arange(dataset_size)
    while True:
        perm = jr.permutation(key, indices)
        (key,) = jr.split(key, 1)
        start = 0
        end = min(batch_size, dataset_size)
        while end <= dataset_size:
            batch_perm = perm[start:end]
            yield tuple(array[batch_perm] for array in arrays)
            start = end
            end = start + batch_size

@eqx.filter_jit
def get_loss(model, ti, yi, ui):
    y_pred = jax.vmap(model, in_axes=(None, 0, 0))(ti, yi[:, 0], ui)
    return jnp.mean((yi - y_pred) ** 2)

grad_loss = eqx.filter_value_and_grad(get_loss)

@eqx.filter_jit
def make_step(ti, yi, ui, model, optim, opt_state):
    loss, grads = grad_loss(model, ti, yi, ui)
    updates, opt_state = optim.update(grads, opt_state)
    model = eqx.apply_updates(model, updates)
    return loss, model, opt_state

def train(
    model,
    training_data,
    key,
    validation_data,
    batch_size=32,
    lr_strategy=(3e-3, 1e-3),
    steps_strategy=(500, 1000),
    length_strategy=(0.1, 1),
    print_every=100,):

    ts, ys, us = training_data
    vts, vys, vus = validation_data

    num_ts = ts.shape[0]
    losses = []
    val_losses = []

    start_time = time.time()
    for lr, steps, length in zip(lr_strategy, steps_strategy, length_strategy):
        optim = optax.adabelief(lr)
        opt_state = optim.init(eqx.filter(model, eqx.is_inexact_array))
        _ts = ts[:   int(num_ts * length)]
        _ys = ys[:, :int(num_ts * length)]
        _us = us[:, :int(num_ts * length)]
        _vts = vts[:   int(num_ts * length)]
        _vys = vys[:, :int(num_ts * length)]
        _vus = vus[:, :int(num_ts * length)]
        for step, (yi, ui) in zip(
            range(steps), _dataloader((_ys, _us), batch_size, key=key)
        ):
            loss, model, opt_state = make_step(_ts, yi, ui, model, optim, opt_state)
            val_loss = get_loss(model, _vts, _vys, _vus)
            losses.append(loss)
            val_losses.append(val_loss)
            if (step % print_every) == 0 or step == steps - 1:
                print(f"Step: {step}, Loss: {loss:.3e}, Val Loss: {val_loss:.3e}")
    training_time = time.time() - start_time
    print(f'Training took: {training_time:-2f}s')

    return model, losses, val_losses

# %% [markdown]
# The model can now be trained

# %%
model = NeuralODE(state_size=ys.shape[-1],
                      input_size=us.shape[-1], 
                      time_dependent=False, 
                      nn_width=hidden_dims, nn_depth=hidden_layers, 
                      key=model_key)
model, losses, val_losses = train(
        model, (ts_train, ys_train, us_train), key, validation_data=(ts_val, ys_val, us_val), batch_size=len(ys), 
        steps_strategy=(Epochs,), length_strategy=(0.5, ), lr_strategy=(learning_rate, )
    )
# Out:
# Step: 0, Loss: 1.240e-01, Val Loss: 2.483e-02
# Step: 100, Loss: 5.705e-03, Val Loss: 4.913e-03
# Step: 200, Loss: 5.708e-03, Val Loss: 5.079e-03
# Step: 300, Loss: 5.687e-03, Val Loss: 5.030e-03
# Step: 400, Loss: 5.684e-03, Val Loss: 5.077e-03
# Step: 500, Loss: 5.705e-03, Val Loss: 5.040e-03
# Step: 600, Loss: 5.687e-03, Val Loss: 5.264e-03
# Step: 700, Loss: 5.657e-03, Val Loss: 5.301e-03
# Step: 800, Loss: 5.658e-03, Val Loss: 5.151e-03
# Step: 900, Loss: 5.687e-03, Val Loss: 5.138e-03
# Step: 1000, Loss: 5.673e-03, Val Loss: 4.774e-03
# Step: 1100, Loss: 5.663e-03, Val Loss: 4.743e-03
# Step: 1200, Loss: 5.679e-03, Val Loss: 4.594e-03
# Step: 1300, Loss: 5.665e-03, Val Loss: 4.685e-03
# Step: 1400, Loss: 5.659e-03, Val Loss: 4.508e-03
# Step: 1500, Loss: 5.626e-03, Val Loss: 4.628e-03
# Step: 1600, Loss: 5.667e-03, Val Loss: 4.470e-03
# Step: 1700, Loss: 5.640e-03, Val Loss: 4.512e-03
# Step: 1800, Loss: 5.642e-03, Val Loss: 4.602e-03
# Step: 1900, Loss: 5.641e-03, Val Loss: 4.561e-03
# Step: 2000, Loss: 5.721e-03, Val Loss: 4.526e-03
# Step: 2100, Loss: 5.663e-03, Val Loss: 4.531e-03
# Step: 2200, Loss: 5.660e-03, Val Loss: 4.701e-03
# Step: 2300, Loss: 5.678e-03, Val Loss: 4.625e-03
# Step: 2400, Loss: 5.663e-03, Val Loss: 4.589e-03
# Step: 2500, Loss: 5.649e-03, Val Loss: 4.913e-03
# Step: 2600, Loss: 5.650e-03, Val Loss: 4.812e-03
# Step: 2700, Loss: 5.640e-03, Val Loss: 5.084e-03
# Step: 2800, Loss: 5.659e-03, Val Loss: 4.828e-03
# Step: 2900, Loss: 5.641e-03, Val Loss: 4.952e-03
# Step: 3000, Loss: 5.726e-03, Val Loss: 5.168e-03
# Step: 3100, Loss: 5.651e-03, Val Loss: 5.284e-03
# Step: 3200, Loss: 5.637e-03, Val Loss: 5.215e-03
# Step: 3300, Loss: 5.623e-03, Val Loss: 5.164e-03
# Step: 3400, Loss: 5.653e-03, Val Loss: 5.294e-03
# Step: 3500, Loss: 5.626e-03, Val Loss: 5.217e-03
# Step: 3600, Loss: 5.631e-03, Val Loss: 5.156e-03
# Step: 3700, Loss: 5.641e-03, Val Loss: 5.360e-03
# Step: 3800, Loss: 5.624e-03, Val Loss: 5.367e-03
# Step: 3900, Loss: 5.665e-03, Val Loss: 5.076e-03
# Step: 4000, Loss: 6.190e-03, Val Loss: 5.813e-03
# Step: 4100, Loss: 5.607e-03, Val Loss: 4.937e-03
# Step: 4200, Loss: 5.582e-03, Val Loss: 4.908e-03
# Step: 4300, Loss: 6.000e-03, Val Loss: 5.007e-03
# Step: 4400, Loss: 5.556e-03, Val Loss: 5.018e-03
# Step: 4500, Loss: 5.530e-03, Val Loss: 5.176e-03
# Step: 4600, Loss: 5.441e-03, Val Loss: 5.175e-03
# Step: 4700, Loss: 7.619e-03, Val Loss: 6.004e-03
# Step: 4800, Loss: 4.864e-03, Val Loss: 5.125e-03
# Step: 4900, Loss: 4.463e-03, Val Loss: 4.867e-03
# Step: 5000, Loss: 3.899e-03, Val Loss: 4.351e-03
# Step: 5100, Loss: 3.558e-03, Val Loss: 3.544e-03
# Step: 5200, Loss: 3.337e-03, Val Loss: 3.244e-03
# Step: 5300, Loss: 3.198e-03, Val Loss: 3.332e-03
# Step: 5400, Loss: 2.955e-03, Val Loss: 2.446e-03
# Step: 5500, Loss: 2.682e-03, Val Loss: 2.136e-03
# Step: 5600, Loss: 2.404e-03, Val Loss: 2.009e-03
# Step: 5700, Loss: 2.106e-03, Val Loss: 1.696e-03
# Step: 5800, Loss: 1.836e-03, Val Loss: 1.374e-03
# Step: 5900, Loss: 1.574e-03, Val Loss: 1.259e-03
# Step: 6000, Loss: 1.423e-03, Val Loss: 1.039e-03
# Step: 6100, Loss: 1.191e-03, Val Loss: 1.058e-03
# Step: 6200, Loss: 1.069e-03, Val Loss: 1.013e-03
# Step: 6300, Loss: 9.367e-04, Val Loss: 7.931e-04
# Step: 6400, Loss: 8.443e-04, Val Loss: 7.340e-04
# Step: 6500, Loss: 9.142e-04, Val Loss: 9.681e-04
# Step: 6600, Loss: 7.008e-04, Val Loss: 6.282e-04
# Step: 6700, Loss: 6.460e-04, Val Loss: 5.619e-04
# Step: 6800, Loss: 9.407e-04, Val Loss: 1.036e-03
# Step: 6900, Loss: 5.526e-04, Val Loss: 4.825e-04
# Step: 7000, Loss: 5.157e-04, Val Loss: 4.504e-04
# Step: 7100, Loss: 4.827e-04, Val Loss: 3.978e-04
# Step: 7200, Loss: 4.522e-04, Val Loss: 3.805e-04
# Step: 7300, Loss: 4.260e-04, Val Loss: 3.479e-04
# Step: 7400, Loss: 4.027e-04, Val Loss: 3.093e-04
# Step: 7500, Loss: 3.778e-04, Val Loss: 2.616e-04
# Step: 7600, Loss: 3.584e-04, Val Loss: 2.331e-04
# Step: 7700, Loss: 3.897e-04, Val Loss: 1.905e-04
# Step: 7800, Loss: 3.233e-04, Val Loss: 1.863e-04
# Step: 7900, Loss: 3.082e-04, Val Loss: 1.778e-04
# Step: 8000, Loss: 2.948e-04, Val Loss: 1.671e-04
# Step: 8100, Loss: 2.827e-04, Val Loss: 1.557e-04
# Step: 8200, Loss: 2.708e-04, Val Loss: 1.560e-04
# Step: 8300, Loss: 5.812e-04, Val Loss: 5.476e-04
# Step: 8400, Loss: 2.500e-04, Val Loss: 1.420e-04
# Step: 8500, Loss: 2.530e-04, Val Loss: 1.752e-04
# Step: 8600, Loss: 2.324e-04, Val Loss: 1.321e-04
# Step: 8700, Loss: 2.244e-04, Val Loss: 1.280e-04
# Step: 8800, Loss: 3.918e-04, Val Loss: 1.495e-04
# Step: 8900, Loss: 2.101e-04, Val Loss: 1.195e-04
# Step: 9000, Loss: 2.034e-04, Val Loss: 1.158e-04
# Step: 9100, Loss: 1.975e-04, Val Loss: 1.109e-04
# Step: 9200, Loss: 1.916e-04, Val Loss: 1.083e-04
# Step: 9300, Loss: 1.910e-04, Val Loss: 9.925e-05
# Step: 9400, Loss: 1.810e-04, Val Loss: 1.015e-04
# Step: 9500, Loss: 1.764e-04, Val Loss: 1.004e-04
# Step: 9600, Loss: 1.717e-04, Val Loss: 9.574e-05
# Step: 9700, Loss: 1.673e-04, Val Loss: 9.187e-05
# Step: 9800, Loss: 1.645e-04, Val Loss: 8.934e-05
# Step: 9900, Loss: 1.596e-04, Val Loss: 8.685e-05
# Step: 10000, Loss: 1.561e-04, Val Loss: 8.395e-05
# Step: 10100, Loss: 2.979e-04, Val Loss: 2.926e-04
# Step: 10200, Loss: 1.493e-04, Val Loss: 7.956e-05
# Step: 10300, Loss: 1.461e-04, Val Loss: 7.726e-05
# Step: 10400, Loss: 2.246e-04, Val Loss: 7.570e-05
# Step: 10500, Loss: 1.404e-04, Val Loss: 7.360e-05
# Step: 10600, Loss: 1.376e-04, Val Loss: 7.149e-05
# Step: 10700, Loss: 1.371e-04, Val Loss: 9.042e-05
# Step: 10800, Loss: 1.325e-04, Val Loss: 6.813e-05
# Step: 10900, Loss: 1.303e-04, Val Loss: 6.546e-05
# Step: 11000, Loss: 1.279e-04, Val Loss: 6.474e-05
# Step: 11100, Loss: 1.257e-04, Val Loss: 6.375e-05
# Step: 11200, Loss: 1.401e-04, Val Loss: 9.658e-05
# Step: 11300, Loss: 1.215e-04, Val Loss: 6.113e-05
# Step: 11400, Loss: 1.196e-04, Val Loss: 6.004e-05
# Step: 11500, Loss: 1.178e-04, Val Loss: 5.883e-05
# Step: 11600, Loss: 1.165e-04, Val Loss: 5.818e-05
# Step: 11700, Loss: 1.144e-04, Val Loss: 5.686e-05
# Step: 11800, Loss: 1.128e-04, Val Loss: 5.582e-05
# Step: 11900, Loss: 1.085e-04, Val Loss: 5.282e-05
# Step: 12000, Loss: 1.066e-04, Val Loss: 5.309e-05
# Step: 12100, Loss: 1.071e-04, Val Loss: 5.498e-05
# Step: 12200, Loss: 1.063e-04, Val Loss: 5.270e-05
# Step: 12300, Loss: 1.083e-04, Val Loss: 6.005e-05
# Step: 12400, Loss: 2.157e-04, Val Loss: 1.383e-04
# Step: 12500, Loss: 1.168e-04, Val Loss: 6.932e-05
# Step: 12600, Loss: 1.148e-04, Val Loss: 6.756e-05
# Step: 12700, Loss: 1.457e-04, Val Loss: 8.129e-05
# Step: 12800, Loss: 1.304e-04, Val Loss: 6.641e-05
# Step: 12900, Loss: 1.285e-04, Val Loss: 6.429e-05
# Step: 13000, Loss: 1.270e-04, Val Loss: 6.268e-05
# Step: 13100, Loss: 1.256e-04, Val Loss: 6.136e-05
# Step: 13200, Loss: 1.244e-04, Val Loss: 6.030e-05
# Step: 13300, Loss: 1.236e-04, Val Loss: 5.933e-05
# Step: 13400, Loss: 1.224e-04, Val Loss: 5.892e-05
# Step: 13500, Loss: 1.215e-04, Val Loss: 5.878e-05
# Step: 13600, Loss: 1.209e-04, Val Loss: 5.803e-05
# Step: 13700, Loss: 1.200e-04, Val Loss: 5.815e-05
# Step: 13800, Loss: 1.192e-04, Val Loss: 5.677e-05
# Step: 13900, Loss: 1.186e-04, Val Loss: 5.652e-05
# Step: 14000, Loss: 1.256e-04, Val Loss: 5.957e-05
# Step: 14100, Loss: 1.174e-04, Val Loss: 5.572e-05
# Step: 14200, Loss: 1.165e-04, Val Loss: 5.514e-05
# Step: 14300, Loss: 1.158e-04, Val Loss: 5.463e-05
# Step: 14400, Loss: 1.153e-04, Val Loss: 5.333e-05
# Step: 14500, Loss: 1.143e-04, Val Loss: 5.402e-05
# Step: 14600, Loss: 1.139e-04, Val Loss: 5.168e-05
# Step: 14700, Loss: 1.167e-04, Val Loss: 5.960e-05
# Step: 14800, Loss: 1.119e-04, Val Loss: 5.193e-05
# Step: 14900, Loss: 1.111e-04, Val Loss: 5.148e-05
# Step: 15000, Loss: 1.103e-04, Val Loss: 5.106e-05
# Step: 15100, Loss: 1.095e-04, Val Loss: 5.073e-05
# Step: 15200, Loss: 1.088e-04, Val Loss: 5.097e-05
# Step: 15300, Loss: 1.080e-04, Val Loss: 5.004e-05
# Step: 15400, Loss: 1.072e-04, Val Loss: 4.969e-05
# Step: 15500, Loss: 1.066e-04, Val Loss: 5.030e-05
# Step: 15600, Loss: 1.058e-04, Val Loss: 4.901e-05
# Step: 15700, Loss: 1.048e-04, Val Loss: 4.858e-05
# Step: 15800, Loss: 1.052e-04, Val Loss: 4.786e-05
# Step: 15900, Loss: 1.049e-04, Val Loss: 4.790e-05
# Step: 16000, Loss: 1.047e-04, Val Loss: 5.281e-05
# Step: 16100, Loss: 9.767e-05, Val Loss: 4.870e-05
# Step: 16200, Loss: 1.469e-04, Val Loss: 8.199e-05
# Step: 16300, Loss: 1.415e-04, Val Loss: 7.882e-05
# Step: 16400, Loss: 1.363e-04, Val Loss: 7.441e-05
# Step: 16500, Loss: 1.317e-04, Val Loss: 7.057e-05
# Step: 16600, Loss: 1.277e-04, Val Loss: 6.707e-05
# Step: 16700, Loss: 1.247e-04, Val Loss: 6.428e-05
# Step: 16800, Loss: 1.214e-04, Val Loss: 6.167e-05
# Step: 16900, Loss: 1.186e-04, Val Loss: 5.937e-05
# Step: 17000, Loss: 1.161e-04, Val Loss: 5.735e-05
# Step: 17100, Loss: 1.141e-04, Val Loss: 5.591e-05
# Step: 17200, Loss: 1.974e-04, Val Loss: 1.083e-04
# Step: 17300, Loss: 1.824e-04, Val Loss: 9.493e-05
# Step: 17400, Loss: 1.703e-04, Val Loss: 8.727e-05
# Step: 17500, Loss: 1.601e-04, Val Loss: 8.112e-05
# Step: 17600, Loss: 1.541e-04, Val Loss: 7.711e-05
# Step: 17700, Loss: 1.473e-04, Val Loss: 7.299e-05
# Step: 17800, Loss: 1.541e-04, Val Loss: 7.322e-05
# Step: 17900, Loss: 1.463e-04, Val Loss: 7.130e-05
# Step: 18000, Loss: 1.397e-04, Val Loss: 6.745e-05
# Step: 18100, Loss: 1.349e-04, Val Loss: 6.470e-05
# Step: 18200, Loss: 1.309e-04, Val Loss: 6.244e-05
# Step: 18300, Loss: 1.270e-04, Val Loss: 6.048e-05
# Step: 18400, Loss: 1.309e-04, Val Loss: 6.242e-05
# Step: 18500, Loss: 1.248e-04, Val Loss: 5.903e-05
# Step: 18600, Loss: 1.220e-04, Val Loss: 5.757e-05
# Step: 18700, Loss: 1.196e-04, Val Loss: 5.643e-05
# Step: 18800, Loss: 1.175e-04, Val Loss: 5.545e-05
# Step: 18900, Loss: 1.158e-04, Val Loss: 5.463e-05
# Step: 19000, Loss: 1.143e-04, Val Loss: 5.390e-05
# Step: 19100, Loss: 1.129e-04, Val Loss: 5.325e-05
# Step: 19200, Loss: 1.117e-04, Val Loss: 5.263e-05
# Step: 19300, Loss: 1.105e-04, Val Loss: 5.204e-05
# Step: 19400, Loss: 1.094e-04, Val Loss: 5.147e-05
# Step: 19500, Loss: 1.083e-04, Val Loss: 5.091e-05
# Step: 19600, Loss: 1.073e-04, Val Loss: 5.035e-05
# Step: 19700, Loss: 1.062e-04, Val Loss: 4.981e-05
# Step: 19800, Loss: 1.050e-04, Val Loss: 4.925e-05
# Step: 19900, Loss: 1.040e-04, Val Loss: 4.877e-05
# Step: 19999, Loss: 1.030e-04, Val Loss: 4.831e-05
# Training took: 1732.982620s

# %%
testset = [2102]
tus, tys, tts = dataprep(testset, node)
y_pred = jax.vmap(model, in_axes=(None, 0, 0))(tts, tys[:, 0], tus)

plt.figure()
plt.plot(tts, tys[0, :, 0], color='black', label='true', alpha = 1)
plt.plot(tts , y_pred[0, :, 0], color='blue', label='predicted', linestyle = '--')
plt.legend()
plt.title('Predictions from Neural ODE')
plt.show()

plt.figure()
plt.semilogy(losses, label="Training Loss")
plt.semilogy(val_losses, label = "Validation Loss")
plt.legend()
plt.grid(which = 'both')
plt.title("Loss vs Epochs")
plt.show()

# %%
te = np.arange(2100, 2136, 1)
for i in range (len(te)):
    plt.figure()
    ttus, ttys, ttts = dataprep([te[i]], node)
    ty_pred = jax.vmap(model, in_axes=(None, 0, 0))(ttts, ttys[:, 0], ttus)
    plt.plot(ttts, ttys[0, :, 0], color='black', label='true', alpha = 1)
    plt.plot(ttts , ty_pred[0, :, 0], color='blue', label='predicted', linestyle = '--')
    plt.legend()
    plt.title('Predictions from Neural ODE')
    plt.savefig(f"ResultsJAX/neuralODE_Zlast/trAllte{te[i]}.png")
    plt.close()

# %% [markdown]
# ### Advantages of Neural ODEs
#
# * Continuous-Time Modeling: They provide a natural way to model systems that evolve continuously over time.  Unlike ResNets, the data does not have to be modelled in fixed time steps.
#
# * Adaptive computation: They allow for adaptive time-stepping during training and inference, potentially leading to more efficient computation.
#
# * Memory efficiency: They can be more memory efficient than traditional neural networks as they do not store intermediate activations, but rather a continuous function
#
# ### Limitations
#
# * Limited Expressive Power: Neural ODEs can struggle with representing complex, high-dimensional dynamics, especially when the underlying system exhibits intricate behaviors that a standard ODE might find hard to capture.
#
# * Gradient Flow: During training, Neural ODEs can suffer from vanishing or exploding gradients, which hampers their ability to learn effectively, especially for long sequences or deep networks.
#
# * Representation of Discontinuous Dynamics: Neural ODEs are inherently continuous and may struggle with systems that have discontinuities or sharp transitions.
#
# * Intersecting Trajectories: For a given an initial condition, the solution to the ODE is unique, and this trait is inherited by Neural ODEs. Therefore systems that have intersecting trajectory evolution cannot be represented accurately by Neural ODE models.
#
# >insert image of ResNet vs NODE intersecting trajectory problem from Dupont et.al.<

# %% [markdown]
# ## Augmented Neural Ordinary Differential Equations (ANODE)
#
# Augmented Neural ODEs address this limitation by introducing additional dimensions to the state space. This augmentation allows the model to learn more complex dynamics and capture finer details. This is achieved by allowing the trajectories to "flow" into the augmented dimensions, to avoid intersecting.
#
# If the original state is $\( y(t) \in \mathbb{R}^n \)$, the augmented state is $\( (y(t), z(t)) \in \mathbb{R}^{n+m} \)$, where $\( z(t) \)$ represents the additional dimensions.  Hence, the general form of an Augmented Neural ODE can be written as:
#
# $$\[ \frac{d}{dt} \begin{pmatrix} y(t) \\ z(t) \end{pmatrix} = f\left( t, \begin{pmatrix} y(t) \\ z(t) \end{pmatrix}, \theta \right) \]$$
#
# The initial augmented state $\( (y(t_0), z(t_0)) \)$ is typically initialized with $\( z(t_0) = 0 \)$ or some other values that reflect prior knowledge about the system.

# %% [markdown]
# ### Definition of an Augmented Neural ODE
#
# Similar to NODEs, we now define the parameters for the model and training, with an additional parameter for augmented dimensions

# %%
datafile = [2100, 2105, 2130, 2135]
#datafile = np.arange(2100, 2136, 1)
node = [34, 36]    # The z-axis displacement of the final node and its derivative w.r.t time
aug_dim = 1
hidden_layers = 2
hidden_dims = 32
learning_rate = 0.001
Epochs = 30000
print_every = 100
validation_dataset = np.arange(2100, 2136, 1)
optim = optax.adabelief(learning_rate)
seed = 42         # Seed for a pseudo-random function which initializes parameters of the Neural Network

# %%
us_train, ys_train, ts_train = dataprep(datafile, node)       # Training data
us, ys, ts = dataprep(datafile, node)
us_val, ys_val, ts_val = dataprep(validation_dataset, node)  # Validation data
num_ts = ts_train.size
key = jr.PRNGKey(seed)
model_key, key = jr.split(key, 2)

# %%
model = NeuralODE(state_size=ys.shape[-1],
                      input_size=us.shape[-1], 
                      time_dependent=False, 
                      nn_width=hidden_dims, nn_depth=hidden_layers, 
                      key=model_key, augmentation_size=aug_dim)
model, losses, val_losses = train(
        model, (ts_train, ys_train, us_train), key, validation_data=(ts_val, ys_val, us_val), batch_size=len(ys[0]), 
        steps_strategy=(Epochs,), length_strategy=(0.5, ), lr_strategy=(learning_rate, )
    )
# Out:
# Step: 0, Loss: 4.658e-01, Val Loss: 2.197e-01
# Step: 100, Loss: 5.654e-03, Val Loss: 4.160e-03
# Step: 200, Loss: 5.618e-03, Val Loss: 4.141e-03
# Step: 300, Loss: 5.607e-03, Val Loss: 4.112e-03
# Step: 400, Loss: 5.549e-03, Val Loss: 4.101e-03
# Step: 500, Loss: 5.475e-03, Val Loss: 4.087e-03
# Step: 600, Loss: 5.376e-03, Val Loss: 4.090e-03
# Step: 700, Loss: 5.224e-03, Val Loss: 4.059e-03
# Step: 800, Loss: 5.152e-03, Val Loss: 4.085e-03
# Step: 900, Loss: 5.095e-03, Val Loss: 4.103e-03
# Step: 1000, Loss: 5.070e-03, Val Loss: 4.173e-03
# Step: 1100, Loss: 5.048e-03, Val Loss: 4.283e-03
# Step: 1200, Loss: 5.012e-03, Val Loss: 4.455e-03
# Step: 1300, Loss: 4.962e-03, Val Loss: 4.581e-03
# Step: 1400, Loss: 4.928e-03, Val Loss: 4.620e-03
# Step: 1500, Loss: 4.803e-03, Val Loss: 4.642e-03
# Step: 1600, Loss: 4.505e-03, Val Loss: 4.481e-03
# Step: 1700, Loss: 3.717e-03, Val Loss: 3.689e-03
# Step: 1800, Loss: 3.425e-03, Val Loss: 3.295e-03
# Step: 1900, Loss: 3.323e-03, Val Loss: 3.119e-03
# Step: 2000, Loss: 3.291e-03, Val Loss: 3.069e-03
# Step: 2100, Loss: 3.295e-03, Val Loss: 2.976e-03
# Step: 2200, Loss: 3.272e-03, Val Loss: 3.024e-03
# Step: 2300, Loss: 3.245e-03, Val Loss: 3.047e-03
# Step: 2400, Loss: 3.248e-03, Val Loss: 3.046e-03
# Step: 2500, Loss: 3.305e-03, Val Loss: 3.150e-03
# Step: 2600, Loss: 3.323e-03, Val Loss: 3.218e-03
# Step: 2700, Loss: 3.211e-03, Val Loss: 3.287e-03
# Step: 2800, Loss: 3.229e-03, Val Loss: 3.106e-03
# Step: 2900, Loss: 3.248e-03, Val Loss: 3.279e-03
# Step: 3000, Loss: 3.278e-03, Val Loss: 3.386e-03
# Step: 3100, Loss: 3.173e-03, Val Loss: 3.733e-03
# Step: 3200, Loss: 3.187e-03, Val Loss: 3.471e-03
# Step: 3300, Loss: 3.177e-03, Val Loss: 3.480e-03
# Step: 3400, Loss: 3.216e-03, Val Loss: 3.916e-03
# Step: 3500, Loss: 3.138e-03, Val Loss: 3.968e-03
# Step: 3600, Loss: 3.152e-03, Val Loss: 3.965e-03
# Step: 3700, Loss: 3.123e-03, Val Loss: 4.274e-03
# Step: 3800, Loss: 3.121e-03, Val Loss: 4.022e-03
# Step: 3900, Loss: 3.103e-03, Val Loss: 4.143e-03
# Step: 4000, Loss: 3.094e-03, Val Loss: 4.250e-03
# Step: 4100, Loss: 3.082e-03, Val Loss: 5.101e-03
# Step: 4200, Loss: 3.067e-03, Val Loss: 5.183e-03
# Step: 4300, Loss: 3.068e-03, Val Loss: 4.860e-03
# Step: 4400, Loss: 3.073e-03, Val Loss: 5.199e-03
# Step: 4500, Loss: 3.355e-03, Val Loss: 5.751e-03
# Step: 4600, Loss: 3.037e-03, Val Loss: 5.742e-03
# Step: 4700, Loss: 3.099e-03, Val Loss: 6.241e-03
# Step: 4800, Loss: 3.030e-03, Val Loss: 7.222e-03
# Step: 4900, Loss: 3.001e-03, Val Loss: 6.977e-03
# Step: 5000, Loss: 3.000e-03, Val Loss: 7.454e-03
# Step: 5100, Loss: 2.992e-03, Val Loss: 7.409e-03
# Step: 5200, Loss: 2.956e-03, Val Loss: 8.176e-03
# Step: 5300, Loss: 3.012e-03, Val Loss: 8.437e-03
# Step: 5400, Loss: 2.971e-03, Val Loss: 7.899e-03
# Step: 5500, Loss: 2.935e-03, Val Loss: 8.215e-03
# Step: 5600, Loss: 2.925e-03, Val Loss: 8.322e-03
# Step: 5700, Loss: 2.882e-03, Val Loss: 9.685e-03
# Step: 5800, Loss: 2.892e-03, Val Loss: 8.407e-03
# Step: 5900, Loss: 3.084e-03, Val Loss: 9.260e-03
# Step: 6000, Loss: 2.870e-03, Val Loss: 9.196e-03
# Step: 6100, Loss: 2.792e-03, Val Loss: 9.184e-03
# Step: 6200, Loss: 2.854e-03, Val Loss: 9.399e-03
# Step: 6300, Loss: 2.739e-03, Val Loss: 8.332e-03
# Step: 6400, Loss: 2.710e-03, Val Loss: 8.469e-03
# Step: 6500, Loss: 2.640e-03, Val Loss: 7.033e-03
# Step: 6600, Loss: 2.577e-03, Val Loss: 7.236e-03
# Step: 6700, Loss: 2.783e-03, Val Loss: 6.897e-03
# Step: 6800, Loss: 2.356e-03, Val Loss: 6.065e-03
# Step: 6900, Loss: 2.318e-03, Val Loss: 5.743e-03
# Step: 7000, Loss: 2.108e-03, Val Loss: 5.614e-03
# Step: 7100, Loss: 2.008e-03, Val Loss: 6.162e-03
# Step: 7200, Loss: 1.882e-03, Val Loss: 5.594e-03
# Step: 7300, Loss: 1.673e-03, Val Loss: 5.167e-03
# Step: 7400, Loss: 1.646e-03, Val Loss: 4.754e-03
# Step: 7500, Loss: 1.526e-03, Val Loss: 5.907e-03
# Step: 7600, Loss: 1.393e-03, Val Loss: 6.796e-03
# Step: 7700, Loss: 1.291e-03, Val Loss: 6.520e-03
# Step: 7800, Loss: 1.249e-03, Val Loss: 6.193e-03
# Step: 7900, Loss: 1.144e-03, Val Loss: 6.150e-03
# Step: 8000, Loss: 1.080e-03, Val Loss: 6.382e-03
# Step: 8100, Loss: 1.320e-03, Val Loss: 7.446e-03
# Step: 8200, Loss: 1.371e-03, Val Loss: 5.898e-03
# Step: 8300, Loss: 9.612e-04, Val Loss: 5.877e-03
# Step: 8400, Loss: 9.413e-04, Val Loss: 5.654e-03
# Step: 8500, Loss: 9.234e-04, Val Loss: 5.580e-03
# Step: 8600, Loss: 9.000e-04, Val Loss: 5.422e-03
# Step: 8700, Loss: 9.885e-04, Val Loss: 5.591e-03
# Step: 8800, Loss: 8.541e-04, Val Loss: 5.153e-03
# Step: 8900, Loss: 7.938e-04, Val Loss: 4.578e-03
# Step: 9000, Loss: 7.682e-04, Val Loss: 4.672e-03
# Step: 9100, Loss: 7.260e-04, Val Loss: 4.265e-03
# Step: 9200, Loss: 8.570e-04, Val Loss: 4.288e-03
# Step: 9300, Loss: 7.043e-04, Val Loss: 4.383e-03
# Step: 9400, Loss: 8.357e-04, Val Loss: 3.551e-03
# Step: 9500, Loss: 7.996e-04, Val Loss: 3.364e-03
# Step: 9600, Loss: 7.217e-04, Val Loss: 3.944e-03
# Step: 9700, Loss: 1.735e-03, Val Loss: 2.773e-03
# Step: 9800, Loss: 8.889e-04, Val Loss: 2.458e-03
# Step: 9900, Loss: 6.934e-04, Val Loss: 3.103e-03
# Step: 10000, Loss: 8.305e-04, Val Loss: 2.261e-03
# Step: 10100, Loss: 6.609e-04, Val Loss: 2.493e-03
# Step: 10200, Loss: 7.763e-04, Val Loss: 2.759e-03
# Step: 10300, Loss: 9.607e-04, Val Loss: 2.387e-03
# Step: 10400, Loss: 6.366e-04, Val Loss: 3.008e-03
# Step: 10500, Loss: 5.948e-04, Val Loss: 2.445e-03
# Step: 10600, Loss: 6.519e-04, Val Loss: 2.002e-03
# Step: 10700, Loss: 6.120e-04, Val Loss: 1.903e-03
# Step: 10800, Loss: 6.036e-04, Val Loss: 2.186e-03
# Step: 10900, Loss: 5.584e-04, Val Loss: 2.162e-03
# Step: 11000, Loss: 5.408e-04, Val Loss: 1.906e-03
# Step: 11100, Loss: 5.381e-04, Val Loss: 1.833e-03
# Step: 11200, Loss: 5.176e-04, Val Loss: 1.800e-03
# Step: 11300, Loss: 5.131e-04, Val Loss: 1.759e-03
# Step: 11400, Loss: 5.031e-04, Val Loss: 1.829e-03
# Step: 11500, Loss: 5.004e-04, Val Loss: 1.596e-03
# Step: 11600, Loss: 4.828e-04, Val Loss: 1.649e-03
# Step: 11700, Loss: 4.718e-04, Val Loss: 1.598e-03
# Step: 11800, Loss: 4.782e-04, Val Loss: 1.426e-03
# Step: 11900, Loss: 4.689e-04, Val Loss: 1.503e-03
# Step: 12000, Loss: 4.620e-04, Val Loss: 1.318e-03
# Step: 12100, Loss: 4.489e-04, Val Loss: 1.338e-03
# Step: 12200, Loss: 4.707e-04, Val Loss: 1.267e-03
# Step: 12300, Loss: 4.582e-04, Val Loss: 1.044e-03
# Step: 12400, Loss: 4.465e-04, Val Loss: 1.189e-03
# Step: 12500, Loss: 4.414e-04, Val Loss: 1.067e-03
# Step: 12600, Loss: 4.073e-04, Val Loss: 1.074e-03
# Step: 12700, Loss: 3.943e-04, Val Loss: 9.924e-04
# Step: 12800, Loss: 3.997e-04, Val Loss: 9.866e-04
# Step: 12900, Loss: 3.953e-04, Val Loss: 9.117e-04
# Step: 13000, Loss: 3.941e-04, Val Loss: 9.339e-04
# Step: 13100, Loss: 3.608e-04, Val Loss: 9.657e-04
# Step: 13200, Loss: 3.551e-04, Val Loss: 8.351e-04
# Step: 13300, Loss: 3.501e-04, Val Loss: 8.129e-04
# Step: 13400, Loss: 3.376e-04, Val Loss: 8.589e-04
# Step: 13500, Loss: 3.596e-04, Val Loss: 9.788e-04
# Step: 13600, Loss: 3.350e-04, Val Loss: 8.447e-04
# Step: 13700, Loss: 3.246e-04, Val Loss: 8.058e-04
# Step: 13800, Loss: 3.225e-04, Val Loss: 7.976e-04
# Step: 13900, Loss: 3.636e-04, Val Loss: 8.685e-04
# Step: 14000, Loss: 3.059e-04, Val Loss: 7.075e-04
# Step: 14100, Loss: 3.135e-04, Val Loss: 6.731e-04
# Step: 14200, Loss: 3.120e-04, Val Loss: 5.949e-04
# Step: 14300, Loss: 2.990e-04, Val Loss: 7.385e-04
# Step: 14400, Loss: 2.871e-04, Val Loss: 6.467e-04
# Step: 14500, Loss: 2.975e-04, Val Loss: 6.779e-04
# Step: 14600, Loss: 2.829e-04, Val Loss: 5.653e-04
# Step: 14700, Loss: 2.738e-04, Val Loss: 7.094e-04
# Step: 14800, Loss: 2.661e-04, Val Loss: 6.219e-04
# Step: 14900, Loss: 2.637e-04, Val Loss: 6.092e-04
# Step: 15000, Loss: 2.571e-04, Val Loss: 6.023e-04
# Step: 15100, Loss: 2.506e-04, Val Loss: 5.995e-04
# Step: 15200, Loss: 2.472e-04, Val Loss: 5.633e-04
# Step: 15300, Loss: 2.425e-04, Val Loss: 5.718e-04
# Step: 15400, Loss: 2.389e-04, Val Loss: 6.039e-04
# Step: 15500, Loss: 2.320e-04, Val Loss: 6.113e-04
# Step: 15600, Loss: 2.267e-04, Val Loss: 5.833e-04
# Step: 15700, Loss: 2.295e-04, Val Loss: 6.550e-04
# Step: 15800, Loss: 2.208e-04, Val Loss: 6.715e-04
# Step: 15900, Loss: 2.173e-04, Val Loss: 5.890e-04
# Step: 16000, Loss: 2.338e-04, Val Loss: 5.675e-04
# Step: 16100, Loss: 2.093e-04, Val Loss: 6.590e-04
# Step: 16200, Loss: 2.011e-04, Val Loss: 6.271e-04
# Step: 16300, Loss: 1.981e-04, Val Loss: 5.929e-04
# Step: 16400, Loss: 1.923e-04, Val Loss: 6.162e-04
# Step: 16500, Loss: 1.982e-04, Val Loss: 6.037e-04
# Step: 16600, Loss: 2.014e-04, Val Loss: 6.017e-04
# Step: 16700, Loss: 1.814e-04, Val Loss: 6.140e-04
# Step: 16800, Loss: 1.761e-04, Val Loss: 6.558e-04
# Step: 16900, Loss: 1.746e-04, Val Loss: 6.281e-04
# Step: 17000, Loss: 1.754e-04, Val Loss: 6.278e-04
# Step: 17100, Loss: 1.660e-04, Val Loss: 6.562e-04
# Step: 17200, Loss: 1.641e-04, Val Loss: 5.935e-04
# Step: 17300, Loss: 1.584e-04, Val Loss: 6.188e-04
# Step: 17400, Loss: 1.584e-04, Val Loss: 6.306e-04
# Step: 17500, Loss: 1.523e-04, Val Loss: 5.999e-04
# Step: 17600, Loss: 1.551e-04, Val Loss: 6.275e-04
# Step: 17700, Loss: 1.451e-04, Val Loss: 6.000e-04
# Step: 17800, Loss: 1.478e-04, Val Loss: 5.964e-04
# Step: 17900, Loss: 1.479e-04, Val Loss: 5.546e-04
# Step: 18000, Loss: 1.413e-04, Val Loss: 5.768e-04
# Step: 18100, Loss: 1.389e-04, Val Loss: 5.453e-04
# Step: 18200, Loss: 1.313e-04, Val Loss: 5.457e-04
# Step: 18300, Loss: 1.286e-04, Val Loss: 5.544e-04
# Step: 18400, Loss: 1.311e-04, Val Loss: 5.544e-04
# Step: 18500, Loss: 1.251e-04, Val Loss: 5.368e-04
# Step: 18600, Loss: 1.285e-04, Val Loss: 5.493e-04
# Step: 18700, Loss: 1.170e-04, Val Loss: 5.041e-04
# Step: 18800, Loss: 1.147e-04, Val Loss: 4.952e-04
# Step: 18900, Loss: 1.110e-04, Val Loss: 5.147e-04
# Step: 19000, Loss: 1.094e-04, Val Loss: 4.908e-04
# Step: 19100, Loss: 1.212e-04, Val Loss: 4.720e-04
# Step: 19200, Loss: 1.038e-04, Val Loss: 4.591e-04
# Step: 19300, Loss: 1.009e-04, Val Loss: 4.512e-04
# Step: 19400, Loss: 9.861e-05, Val Loss: 4.320e-04
# Step: 19500, Loss: 9.889e-05, Val Loss: 4.149e-04
# Step: 19600, Loss: 9.346e-05, Val Loss: 3.995e-04
# Step: 19700, Loss: 9.055e-05, Val Loss: 3.910e-04
# Step: 19800, Loss: 9.223e-05, Val Loss: 3.860e-04
# Step: 19900, Loss: 8.778e-05, Val Loss: 3.550e-04
# Step: 20000, Loss: 9.246e-05, Val Loss: 3.555e-04
# Step: 20100, Loss: 8.529e-05, Val Loss: 3.349e-04
# Step: 20200, Loss: 8.305e-05, Val Loss: 3.130e-04
# Step: 20300, Loss: 8.465e-05, Val Loss: 3.060e-04
# Step: 20400, Loss: 8.249e-05, Val Loss: 2.923e-04
# Step: 20500, Loss: 8.588e-05, Val Loss: 2.938e-04
# Step: 20600, Loss: 7.891e-05, Val Loss: 2.657e-04
# Step: 20700, Loss: 9.305e-05, Val Loss: 2.733e-04
# Step: 20800, Loss: 7.620e-05, Val Loss: 2.510e-04
# Step: 20900, Loss: 8.388e-05, Val Loss: 2.446e-04
# Step: 21000, Loss: 7.316e-05, Val Loss: 2.384e-04
# Step: 21100, Loss: 7.337e-05, Val Loss: 2.289e-04
# Step: 21200, Loss: 7.908e-05, Val Loss: 2.310e-04
# Step: 21300, Loss: 7.199e-05, Val Loss: 2.281e-04
# Step: 21400, Loss: 7.222e-05, Val Loss: 2.265e-04
# Step: 21500, Loss: 7.374e-05, Val Loss: 2.156e-04
# Step: 21600, Loss: 7.034e-05, Val Loss: 2.149e-04
# Step: 21700, Loss: 7.205e-05, Val Loss: 2.136e-04
# Step: 21800, Loss: 6.872e-05, Val Loss: 2.085e-04
# Step: 21900, Loss: 6.762e-05, Val Loss: 2.014e-04
# Step: 22000, Loss: 6.765e-05, Val Loss: 2.010e-04
# Step: 22100, Loss: 6.664e-05, Val Loss: 2.016e-04
# Step: 22200, Loss: 6.587e-05, Val Loss: 2.016e-04
# Step: 22300, Loss: 6.590e-05, Val Loss: 1.969e-04
# Step: 22400, Loss: 6.867e-05, Val Loss: 1.993e-04
# Step: 22500, Loss: 1.014e-04, Val Loss: 2.201e-04
# Step: 22600, Loss: 6.499e-05, Val Loss: 1.865e-04
# Step: 22700, Loss: 6.706e-05, Val Loss: 1.847e-04
# Step: 22800, Loss: 6.299e-05, Val Loss: 1.828e-04
# Step: 22900, Loss: 6.303e-05, Val Loss: 1.846e-04
# Step: 23000, Loss: 7.893e-05, Val Loss: 1.919e-04
# Step: 23100, Loss: 6.333e-05, Val Loss: 1.714e-04
# Step: 23200, Loss: 6.157e-05, Val Loss: 1.716e-04
# Step: 23300, Loss: 6.772e-05, Val Loss: 1.750e-04
# Step: 23400, Loss: 6.089e-05, Val Loss: 1.637e-04
# Step: 23500, Loss: 6.381e-05, Val Loss: 1.641e-04
# Step: 23600, Loss: 5.938e-05, Val Loss: 1.523e-04
# Step: 23700, Loss: 6.335e-05, Val Loss: 1.540e-04
# Step: 23800, Loss: 6.141e-05, Val Loss: 1.479e-04
# Step: 23900, Loss: 5.809e-05, Val Loss: 1.455e-04
# Step: 24000, Loss: 5.760e-05, Val Loss: 1.434e-04
# Step: 24100, Loss: 5.866e-05, Val Loss: 1.380e-04
# Step: 24200, Loss: 5.722e-05, Val Loss: 1.319e-04
# Step: 24300, Loss: 5.682e-05, Val Loss: 1.261e-04
# Step: 24400, Loss: 5.633e-05, Val Loss: 1.246e-04
# Step: 24500, Loss: 5.796e-05, Val Loss: 1.230e-04
# Step: 24600, Loss: 5.514e-05, Val Loss: 1.160e-04
# Step: 24700, Loss: 5.790e-05, Val Loss: 1.173e-04
# Step: 24800, Loss: 5.608e-05, Val Loss: 1.134e-04
# Step: 24900, Loss: 5.454e-05, Val Loss: 1.107e-04
# Step: 25000, Loss: 5.435e-05, Val Loss: 1.079e-04
# Step: 25100, Loss: 5.473e-05, Val Loss: 1.075e-04
# Step: 25200, Loss: 5.326e-05, Val Loss: 1.039e-04
# Step: 25300, Loss: 5.394e-05, Val Loss: 1.007e-04
# Step: 25400, Loss: 5.432e-05, Val Loss: 1.006e-04
# Step: 25500, Loss: 5.356e-05, Val Loss: 9.793e-05
# Step: 25600, Loss: 5.213e-05, Val Loss: 9.570e-05
# Step: 25700, Loss: 5.310e-05, Val Loss: 9.403e-05
# Step: 25800, Loss: 5.207e-05, Val Loss: 9.196e-05
# Step: 25900, Loss: 5.147e-05, Val Loss: 8.974e-05
# Step: 26000, Loss: 5.085e-05, Val Loss: 8.769e-05
# Step: 26100, Loss: 5.067e-05, Val Loss: 8.601e-05
# Step: 26200, Loss: 5.128e-05, Val Loss: 8.475e-05
# Step: 26300, Loss: 5.053e-05, Val Loss: 8.457e-05
# Step: 26400, Loss: 5.051e-05, Val Loss: 8.213e-05
# Step: 26500, Loss: 5.402e-05, Val Loss: 8.408e-05
# Step: 26600, Loss: 4.935e-05, Val Loss: 7.909e-05
# Step: 26700, Loss: 5.089e-05, Val Loss: 7.992e-05
# Step: 26800, Loss: 4.955e-05, Val Loss: 7.803e-05
# Step: 26900, Loss: 4.953e-05, Val Loss: 7.570e-05
# Step: 27000, Loss: 4.947e-05, Val Loss: 7.379e-05
# Step: 27100, Loss: 4.855e-05, Val Loss: 7.287e-05
# Step: 27200, Loss: 4.824e-05, Val Loss: 7.217e-05
# Step: 27300, Loss: 4.874e-05, Val Loss: 7.274e-05
# Step: 27400, Loss: 5.486e-05, Val Loss: 7.720e-05
# Step: 27500, Loss: 4.895e-05, Val Loss: 6.991e-05
# Step: 27600, Loss: 4.791e-05, Val Loss: 6.837e-05
# Step: 27700, Loss: 4.806e-05, Val Loss: 6.784e-05
# Step: 27800, Loss: 4.764e-05, Val Loss: 6.690e-05
# Step: 27900, Loss: 4.737e-05, Val Loss: 6.536e-05
# Step: 28000, Loss: 4.753e-05, Val Loss: 6.483e-05
# Step: 28100, Loss: 6.050e-05, Val Loss: 6.525e-05
# Step: 28200, Loss: 4.701e-05, Val Loss: 6.258e-05
# Step: 28300, Loss: 4.674e-05, Val Loss: 6.202e-05
# Step: 28400, Loss: 4.778e-05, Val Loss: 6.251e-05
# Step: 28500, Loss: 4.632e-05, Val Loss: 6.002e-05
# Step: 28600, Loss: 4.729e-05, Val Loss: 5.980e-05
# Step: 28700, Loss: 4.726e-05, Val Loss: 5.924e-05
# Step: 28800, Loss: 4.671e-05, Val Loss: 5.897e-05
# Step: 28900, Loss: 4.743e-05, Val Loss: 5.829e-05
# Step: 29000, Loss: 4.785e-05, Val Loss: 5.770e-05
# Step: 29100, Loss: 4.965e-05, Val Loss: 6.004e-05
# Step: 29200, Loss: 4.943e-05, Val Loss: 5.929e-05
# Step: 29300, Loss: 4.595e-05, Val Loss: 5.495e-05
# Step: 29400, Loss: 4.630e-05, Val Loss: 5.456e-05
# Step: 29500, Loss: 4.627e-05, Val Loss: 5.348e-05
# Step: 29600, Loss: 4.584e-05, Val Loss: 5.270e-05
# Step: 29700, Loss: 4.673e-05, Val Loss: 5.328e-05
# Step: 29800, Loss: 4.627e-05, Val Loss: 5.211e-05
# Step: 29900, Loss: 4.571e-05, Val Loss: 5.085e-05
# Step: 29999, Loss: 4.582e-05, Val Loss: 5.071e-05
# Training took: 1856.270575s

# %%
testset = [2132]
tus, tys, tts = dataprep(testset, node)
y_pred = jax.vmap(model, in_axes=(None, 0, 0))(tts, tys[:, 0], tus)

plt.figure()
plt.plot(tts, tys[0, :, 0], color='black', label='true', alpha = 1)
plt.plot(tts , y_pred[0, :, 0], color='blue', label='predicted', linestyle = '--')
plt.legend()
plt.title('Predictions from Augmented Neural ODE')
plt.show()

plt.figure()
plt.semilogy(losses, label="Training Loss")
plt.semilogy(val_losses, label = "Validation Loss")
plt.legend()
plt.grid(which = 'both')
plt.title("Loss vs Epochs")
plt.show()

# %%
te = np.arange(2100, 2136, 1)
for i in range (len(te)):
    plt.figure()
    ttus, ttys, ttts = dataprep([te[i]], node)
    ty_pred = jax.vmap(model, in_axes=(None, 0, 0))(ttts, ttys[:, 0], ttus)
    plt.plot(ttts, ttys[0, :, 0], color='black', label='true', alpha = 1)
    plt.plot(ttts , ty_pred[0, :, 0], color='blue', label='predicted', linestyle = '--')
    plt.legend()
    plt.title('Predictions from Neural ODE')
    plt.savefig(f"ResultsJAX/Aug1neuralODE_Zlast/trAllte{te[i]}.png")
    plt.close()

# %% [markdown]
# ### Advantages of Augmented Neural ODEs
#
# * Better expressiveness: By expanding the state space, the model can capture more complex dynamics with higher accuracy.
# * Wider applicability: Augmented Neural ODEs can achieve better results across a range of tasks and even represent cases where Neural ODEs fall short (for example: Intersecting trajectories)
#
# >Add more as necessary<
