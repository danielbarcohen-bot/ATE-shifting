# %%
#!pip install konlpy
#!pip install wordcloud

# %% [markdown]
# - KoNLPy를 위한 자바 설치
# https://www.codeit.kr/tutorials/43/KoNLPy-%EC%84%A4%EC%B9%98%ED%95%98%EA%B8%B0-Windows

# %%
import requests
from bs4 import BeautifulSoup
import re
from konlpy.tag import Okt
from collections import Counter
import pandas as pd
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# %% [markdown]
# - 검색어 및 검색페이지 수 입력

# %%
# 검색어 입력
keyword = input("검색어를 입력하세요.")
# Out:
# 검색어를 입력하세요.공룡

# %%
# 검색페이지 입력
lastpage = int(input("마지막 페이지 번호를 입력하세요."))
# Out:
# 마지막 페이지 번호를 입력하세요.2

# %% [markdown]
# - 다음 뉴스 검색 : 상기 검색어 및 페이지수 활용

# %%
titleList = []

for i in range(1, lastpage+1, 1) :
    url = f"https://search.naver.com/search.naver?where=news&sm=tab_jum&query={keyword}&start=[{i}]"
    #url = f"https://search.daum.net/search?w=news&nil_search=btn&DA=PGD&enc=utf8&cluster=y&cluster_page=1&q={keyword}&p={i}"
    print(url)
    response = requests.get(url)
    html = response.text
    soup = BeautifulSoup(html, 'html.parser')
    
    titles = soup.select("ul.c-list-basic")
    #subtitles = soup.select("a.elss.sub_tit")
    
    for title in titles : # titles에서 title
        titleText = title.text # title.text만 추출
        print(titleText)
        titleList.append(titleText) # titleList에 추가
# Out:
# https://search.naver.com/search.naver?where=news&sm=tab_jum&query=공룡&start=[1]
# https://search.naver.com/search.naver?where=news&sm=tab_jum&query=공룡&start=[2]

# %%
titleList[0]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Input In [7], in <cell line: 1>()
# ----> 1 titleList[0]
#
# IndexError: list index out of range

# %%
# 한글만 추출
def text_cleaning(text) : # 한글 추출
    hangul = re.compile('[^ ㄱ-ㅣ가-힣]+')
    result = hangul.sub('', text)
    return result

# %%
# 전처리 : 한글만 추출
titleList = list(map(lambda x:text_cleaning(x), titleList))

# %%
titleList[0]
# Out:
# '            동아   언론사 픽     개별문서메뉴  톡으로 바로 공유 공유하기                    애정남 갤럭시 핏와 갤럭시 워치  어떻게 다른가요       동아 남시현 기자 지난 월 일 삼성전자의 새로운 스마트 밴드 갤럭시 핏가 정식 출시됐습니다 삼성전자가 스마트 밴드를 출시한 건 년 갤럭시 핏  이후 년 만이며 국내는 물론 해외에서도 반응이 뜨겁습니다 그도 그럴게 스마트 밴드는 샤오미                     스포츠동아       개별문서메뉴  톡으로 바로 공유 공유하기                 휘브      콘셉트 트레일러 공개       닷컴 휘브제이더 하승 진범 유건 이정 재하 인홍 원준가 공식 유튜브 채널을 통해 싱글 집 앨범     이터널 유스 킥 잇의 개인 단체 콘셉트 트레일러 영상을 공개했다 공개된 개인 트레일러 영상에서는 도심 옥상에서 각자    시간전                 비즈워치   언론사 픽     개별문서메뉴  톡으로 바로 공유 공유하기                    거버넌스워치 노루페인트 세 업체  전문가 영입 왜       지렛대로 활용하고 있는 시스템통합업체의 존재감을 점점 끌어올리고 있다 연쇄적으로 지주사 지분을 넘겨준 데 이어 이번에는  전문가를 영입해 공격적으로 볼륨 확장을 꾀할 것으로 점쳐지고 있다 지주 지분 매각 이어 전문경영인 영입 일 노루페인트    시간전                 국민일보   언론사 픽     개별문서메뉴  톡으로 바로 공유 공유하기                     경술국치 부글부글 네이버 침묵 놓고도 반감 확산       본사 모습 연합뉴스 일본의 국민 메신저 라인을 운영하는 라인야후가 대주주인 네이버 지우기를 시도하자 국내 정보기술 업계의 반발이 커지고 있다 특히 업계에서는 라인을 글로벌 서비스로 공들여 키워놓고는 일본에 빼앗길 위기인데도 별다른 입장을                     코리아중앙데일리   언론사 픽     개별문서메뉴  톡으로 바로 공유 공유하기                                                                                               동아   언론사 픽     개별문서메뉴  톡으로 바로 공유 공유하기                    농업이 잇다 에스와이에스 플라즈마로 농축산 폐수 정화합니다         동아 한국농업기술진흥원과 동아는 우리나라 농업의 발전과 디지털 전환을 이끌 유망한 스타트업을 소개합니다 기발한 아이디어와 상품 그리고 독창적인 기술로 우리의 삶을 윤택하게 할 전국 각지의 농업 스타트업을 만나보세요 동아 한만혁                     이데일리   언론사 픽     개별문서메뉴  톡으로 바로 공유 공유하기                    데이터 국적주의 시대에  수출 선봉장 네이버 김현아의 세상읽기       정부가 네이버에 지분 매각까지 요구하는 것은 과도한 조치로 여겨집니다 이런 기준에 따르면 한국 기업들이 일본 국민을 대상으로  서비스를 제공하는 것이 거의 불가능해질 수 있습니다 한 예로 인공지능 스타트업인 올거나이즈는 일본의 대 메가뱅크 중                     뉴스       개별문서메뉴  톡으로 바로 공유 공유하기                    라인야후 탐내는 소프트뱅크는 어떤 회사인가손엄지의 살롱       뉴스   권진영 기자 서울뉴스 손엄지 기자  소프트뱅크는 일본 도쿄 증권거래소 시가총액 위의 최대 정보기술기업이자 투자 회사다 시가총액은 조 억 엔약 조 억 원으로 네이버조 억 원의 배다 소프트뱅크의    시간전                 아이뉴스   언론사 픽     개별문서메뉴  톡으로 바로 공유 공유하기                 하반기 턴어라운드 노리는 디스플레이용  대세 올라탄다       독보적인 지배력으로 점유율 위를 달리고 있다 지난해 기준  시장 점유율은 한국이  중국이 다 특히 와 용 패널이 주력인 대형  시장에서는 한국이 로 높은 점유율을 보였다 모바일 등 중소형  시장은 한국  중국 로                     문화일보       개별문서메뉴  톡으로 바로 공유 공유하기                 휘브 케이콘 재팬에서 신보 타이틀곡   선공개       있는 그룹 휘브 보이그룹 휘브가 케이콘 재팬  현장을 달궜다 오는 일 싱글 집 앨범     이터널 유스 킥 잇으로 컴백하는 휘브제이더 하승 진범 유건 이정 재하 인홍 원준는 이에 앞선 일 일본 도쿄          '

# %% [markdown]
# - 텍스트 전처리 : 명사의 빈도수 계산

# %%
# 텍스트 전처리
title_corpus = " ".join(titleList) # 말뭉치
nouns_tagger = Okt() # 명사 추출
nouns = nouns_tagger.nouns(title_corpus)
count = Counter(nouns) # 각 명사의 빈도수 계산

# %%
# 각 명사의 빈도수 계산
count
# Out:
# Counter({'동아': 10,
#          '언론사': 12,
#          '픽': 12,
#          '개별': 40,
#          '문서': 40,
#          '메뉴': 40,
#          '톡': 40,
#          '바로': 40,
#          '공유': 83,
#          '애정': 2,
#          '남': 2,
#          '갤럭시': 5,
#          '핏': 3,
#          '워치': 3,
#          '가요': 1,
#          '현': 3,
#          '기자': 13,
#          '지난': 1,
#          '월': 4,
#          '일': 22,
#          '전자': 3,
#          '스마트': 3,
#          '밴드': 3,
#          '정식': 1,
#          '출시': 2,
#          '건': 1,
#          '년': 5,
#          '이후': 1,
#          '만이': 1,
#          '국내': 3,
#          '해외': 6,
#          '반응': 1,
#          '그': 1,
#          '샤오미': 1,
#          '스포츠동아': 1,
#          '휘브': 6,
#          '콘셉트': 2,
#          '트레일러': 3,
#          '공개': 3,
#          '제이': 2,
#          '더': 12,
#          '승': 2,
#          '진범': 2,
#          '유건': 2,
#          '이정': 2,
#          '인홍': 2,
#          '준가': 1,
#          '공식': 2,
#          '유튜브': 1,
#          '채널': 1,
#          '통해': 5,
#          '싱글': 3,
#          '집': 2,
#          '앨범': 2,
#          '터널': 2,
#          '유스': 2,
#          '킥': 2,
#          '개인': 2,
#          '단체': 1,
#          '영상': 2,
#          '도심': 1,
#          '옥상': 1,
#          '각자': 1,
#          '간전': 5,
#          '비즈': 2,
#          '거': 1,
#          '버넌스': 1,
#          '노루': 2,
#          '페인트': 2,
#          '세': 2,
#          '업체': 2,
#          '전문가': 5,
#          '입': 2,
#          '왜': 1,
#          '지렛대': 1,
#          '활용': 5,
#          '시스템': 10,
#          '통합': 1,
#          '존재': 1,
#          '감': 1,
#          '점점': 1,
#          '연쇄': 1,
#          '지주사': 1,
#          '분': 8,
#          '데': 4,
#          '이번': 2,
#          '영': 1,
#          '공격': 1,
#          '볼륨': 1,
#          '확장': 2,
#          '꾀': 2,
#          '것': 7,
#          '점': 1,
#          '지주': 1,
#          '매각': 3,
#          '전문': 5,
#          '경영인': 1,
#          '국민일보': 1,
#          '경술국치': 1,
#          '네이버': 20,
#          '침묵': 1,
#          '반감': 1,
#          '확산': 1,
#          '본사': 4,
#          '모습': 2,
#          '연합뉴스': 3,
#          '일본': 17,
#          '국민': 2,
#          '메신저': 1,
#          '라인': 21,
#          '운영': 1,
#          '야후': 8,
#          '대주': 1,
#          '주인': 1,
#          '시도': 1,
#          '정보기술': 5,
#          '업계': 3,
#          '반발': 1,
#          '글로벌': 4,
#          '서비스': 5,
#          '공': 1,
#          '위기': 1,
#          '도': 1,
#          '입장': 3,
#          '코리아': 5,
#          '중앙': 2,
#          '일리': 2,
#          '농업': 4,
#          '에스': 2,
#          '플라즈마': 1,
#          '농축': 1,
#          '산': 1,
#          '폐수': 1,
#          '정화': 1,
#          '한국': 11,
#          '기술': 7,
#          '진흥': 1,
#          '우리나라': 1,
#          '발전': 1,
#          '디지털': 8,
#          '전환': 3,
#          '유망': 1,
#          '스타트업': 3,
#          '소개': 3,
#          '아이디어': 1,
#          '상품': 1,
#          '독창': 1,
#          '우리': 3,
#          '삶': 1,
#          '윤택': 1,
#          '전국': 1,
#          '각지': 1,
#          '혁': 1,
#          '이데일리': 6,
#          '데이터': 1,
#          '국적': 1,
#          '주의': 2,
#          '시대': 2,
#          '수출': 1,
#          '선봉': 1,
#          '김현아': 1,
#          '세상': 1,
#          '정부': 16,
#          '요구': 5,
#          '과도': 1,
#          '조치': 3,
#          '기준': 2,
#          '기업': 17,
#          '대상': 2,
#          '제공': 4,
#          '거의': 1,
#          '수': 3,
#          '예': 1,
#          '인공': 4,
#          '지능': 4,
#          '이즈': 1,
#          '메': 1,
#          '뱅크': 1,
#          '중': 1,
#          '뉴스': 15,
#          '소프트뱅크': 3,
#          '회사': 5,
#          '손': 4,
#          '엄지': 3,
#          '살롱': 1,
#          '권진영': 1,
#          '서울': 8,
#          '도쿄': 2,
#          '증권': 1,
#          '거래소': 1,
#          '시가총액': 2,
#          '위': 11,
#          '최대': 1,
#          '이자': 1,
#          '투자': 1,
#          '조': 2,
#          '억': 4,
#          '약': 1,
#          '원': 3,
#          '아이': 1,
#          '하반기': 2,
#          '턴': 1,
#          '라운드': 2,
#          '디스플레이': 1,
#          '용': 3,
#          '대세': 1,
#          '독보': 1,
#          '지배': 1,
#          '점유': 3,
#          '율': 3,
#          '달리': 1,
#          '지난해': 3,
#          '시장': 5,
#          '중국': 2,
#          '패널': 1,
#          '주력': 3,
#          '대형': 1,
#          '로': 5,
#          '모바일': 1,
#          '등': 6,
#          '중소': 1,
#          '문화': 2,
#          '일보': 2,
#          '케이': 4,
#          '콘': 2,
#          '재팬': 2,
#          '보': 1,
#          '타이틀곡': 1,
#          '선공': 1,
#          '그룹': 12,
#          '보이': 1,
#          '현장': 1,
#          '컴백': 1,
#          '이': 4,
#          '경제': 6,
#          '이수영': 3,
#          '대표': 2,
#          '후': 1,
#          '웅진': 8,
#          '인식': 1,
#          '강경': 1,
#          '카페': 1,
#          '신문': 2,
#          '인터뷰': 1,
#          '사진': 3,
#          '렌털': 2,
#          '교육': 5,
#          '서적': 1,
#          '유통': 2,
#          '식품': 1,
#          '사업': 3,
#          '체질': 1,
#          '개선': 1,
#          '박차': 1,
#          '정체': 2,
#          '윤석금': 2,
#          '회장': 2,
#          '특명': 2,
#          '뉴시스': 1,
#          '현대': 13,
#          '퓨처': 5,
#          '넷': 8,
#          '인수': 4,
#          '미디어': 2,
#          '콘텐츠': 2,
#          '도약': 4,
#          '백화점': 2,
#          '지주회사': 2,
#          '에프': 1,
#          '홀딩스': 1,
#          '쇼핑': 1,
#          '보유': 1,
#          '를': 4,
#          '억원': 2,
#          '매입': 1,
#          '주식': 1,
#          '매매': 1,
#          '계약': 1,
#          '체결': 3,
#          '공시': 1,
#          '내': 2,
#          '매일경제': 1,
#          '보기': 12,
#          '이전': 4,
#          '컨텐츠': 8,
#          '다음': 4,
#          '생': 4,
#          '길라잡이': 1,
#          '사례': 1,
#          '및': 4,
#          '커뮤니티': 1,
#          '피터': 1,
#          '스': 4,
#          '그림': 1,
#          '글': 1,
#          '설치': 1,
#          '방법': 1,
#          '최신': 1,
#          '소식': 1,
#          '전': 1,
#          '비롯': 1,
#          '성형': 1,
#          '일상': 2,
#          '속': 1,
#          '헤럴드경제': 4,
#          '소작인': 2,
#          '비용': 1,
#          '닛': 2,
#          '지수': 1,
#          '전광판': 1,
#          '보고': 1,
#          '정목': 1,
#          '엔화': 1,
#          '가치': 3,
#          '역대': 1,
#          '하락': 1,
#          '미국': 2,
#          '전락': 1,
#          '전망': 1,
#          '혼': 1,
#          '게이': 1,
#          '은': 2,
#          '영향': 1,
#          '머니투데이': 3,
#          '국제': 2,
#          '자격증': 2,
#          '취득': 1,
#          '직원': 3,
#          '연봉': 1,
#          '상승': 1,
#          '핵심': 1,
#          '요소': 1,
#          '부상': 1,
#          '비즈니스': 2,
#          '직무': 1,
#          '스킬': 1,
#          '소프트': 1,
#          '최근': 2,
#          '발표': 2,
#          '급여': 1,
#          '수준': 1,
#          '관': 1,
#          '연례': 1,
#          '리서치': 1,
#          '전세계': 1,
#          '리더': 4,
#          '관련': 3,
#          '인증': 1,
#          '자격': 1,
#          '획득': 1,
#          '조직': 1,
#          '매년': 1,
#          '최소': 1,
#          '달러': 1,
#          '이상': 2,
#          '건설': 5,
#          '공제조합': 2,
#          '고객': 7,
#          '중심': 1,
#          '보증': 2,
#          '개방': 1,
#          '기관': 1,
#          '간': 1,
#          '경쟁': 1,
#          '더욱': 2,
#          '심화': 1,
#          '상황': 1,
#          '조합원': 1,
#          '이용': 5,
#          '구축': 5,
#          '필수': 1,
#          '판단': 1,
#          '차세대': 2,
#          '정보': 3,
#          '진행': 2,
#          '전경': 1,
#          '사진전': 1,
#          '아시아': 2,
#          '취업': 3,
#          '등용문': 1,
#          '스쿨': 2,
#          '지원': 2,
#          '모집': 2,
#          '현지': 5,
#          '생활': 1,
#          '알선': 1,
#          '맞춤': 1,
#          '인재': 4,
#          '양성': 5,
#          '프로그램': 4,
#          '특화된': 1,
#          '클라우드': 2,
#          '기반': 1,
#          '풀': 2,
#          '스택': 1,
#          '웹': 1,
#          '개발자': 1,
#          '과정': 2,
#          '어학': 1,
#          '시민': 10,
#          '연대': 8,
#          '지분매각': 4,
#          '행정지도': 5,
#          '철회': 3,
#          '최': 2,
#          '다래': 1,
#          '공정': 5,
#          '정의': 4,
#          '대가': 2,
#          '촉구': 4,
#          '정리': 1,
#          '온라인': 1,
#          '기자회견': 1,
#          '정현': 1,
#          '준비': 6,
#          '위원장': 1,
#          '학습': 1,
#          '젠': 1,
#          '탈바꿈': 1,
#          '변신': 1,
#          '사진가': 1,
#          '프로젝트': 1,
#          '진두': 1,
#          '지휘': 1,
#          '전자신문': 3,
#          '다인': 3,
#          '우즈베키스탄': 3,
#          '파크': 4,
#          '역량': 4,
#          '강화': 4,
#          '연수': 4,
#          '료': 2,
#          '우즈': 1,
#          '베': 1,
#          '키스': 1,
#          '칸': 1,
#          '수료식': 1,
#          '개최': 4,
#          '지난달': 1,
#          '달': 1,
#          '주간': 2,
#          '팩트': 3,
#          '판': 1,
#          '강력': 2,
#          '항의': 2,
#          '적극': 4,
#          '표명': 1,
#          '대응': 7,
#          '필요': 2,
#          '대한': 3,
#          '영향력': 1,
#          '축소': 1,
#          '가운데': 1,
#          '위원회': 4,
#          '측': 1,
#          '문정': 1,
#          '스타': 1,
#          '걸스': 1,
#          '플래닛쇼미': 1,
#          '유다연': 3,
#          '신곡': 2,
#          '발매': 2,
#          '디오': 1,
#          '티': 1,
#          '가수': 1,
#          '에너지': 1,
#          '증명': 1,
#          '정오': 1,
#          '각종': 1,
#          '음원': 1,
#          '사이트': 1,
#          '킵': 1,
#          '로우': 1,
#          '사랑': 1,
#          '주제': 1,
#          '댄스': 1,
#          '곡': 1,
#          '로맨틱': 1,
#          '감정': 1,
#          '교차': 1,
#          '지점': 1,
#          '섬세': 1,
#          '강탈': 1,
#          '야욕': 1,
#          '잇쥬': 1,
#          '분야': 1,
#          '민영': 1,
#          '통신사': 1,
#          '핫이슈': 1,
#          '한눈': 1,
#          '주요': 1,
#          '뉴스잇쥬': 1,
#          '강도현': 1,
#          '과학기술': 1,
#          '정보통신부': 1,
#          '차관': 1,
#          '종로구': 1,
#          '청사': 1,
#          '현안': 1,
#          '브리핑': 1,
#          '디지털타임스': 2,
#          '공공': 2,
#          '아마추어': 1,
#          '공무원': 1,
#          '오류': 1,
#          '장애': 1,
#          '거듭': 1,
#          '유지관리': 1,
#          '근본': 1,
#          '변화': 1,
#          '목소리': 1,
#          '민간': 1,
#          '혁신': 4,
#          '예산': 1,
#          '투자가': 1,
#          '지적': 1,
#          '국세청': 1,
#          '운영체제': 2,
#          '프리도스': 1,
#          '노트북': 2,
#          '구매': 1,
#          '권택경': 1,
#          '윈도우': 4,
#          '꼭': 1,
#          '조립': 1,
#          '완제': 1,
#          '품': 1,
#          '라면': 1,
#          '보통': 1,
#          '제품': 3,
#          '포함': 3,
#          '때문': 1,
#          '알': 1,
#          '가격': 2,
#          '기본': 1,
#          '구성': 2,
#          '코리아헤럴드': 1,
#          '가스': 6,
#          '유': 8,
#          '자산': 6,
#          '기부': 5,
#          '경영': 5,
#          '실천': 4,
#          '앞장': 2,
#          '김은경': 1,
#          '재활용': 1,
#          '통한': 1,
#          '환경': 1,
#          '사회': 3,
#          '지배구조': 1,
#          '경기도': 2,
#          '성남': 1,
#          '판교': 1,
#          '소재': 1,
#          '기증': 1,
#          '서버': 1,
#          '스토리': 1,
#          '행복': 1,
#          '헤럴드': 1,
#          '산업': 1,
#          '허브': 3,
#          '인도': 1,
#          '첸나이': 3,
#          '공장': 2,
#          '아이폰': 1,
#          '생산': 1,
#          '확대': 1,
#          '계획': 1,
#          '기숙사': 1,
#          '또한': 1,
#          '테크': 1,
#          '자동차': 1,
#          '소프트웨어': 1,
#          '개발': 1,
#          '포드': 1,
#          '르노': 1,
#          '닛산': 1,
#          '솔루션': 1,
#          '양주시': 6,
#          '광운대': 4,
#          '양주': 2,
#          '광운': 4,
#          '첨단': 9,
#          '융합': 5,
#          '연구소': 5,
#          '설립': 5,
#          '합심': 1,
#          '학교': 3,
#          '경기': 2,
#          '주택': 2,
#          '시공사': 2,
#          '테크노': 2,
#          '밸리': 2,
#          '휼': 1,
#          '강수현': 1,
#          '총장': 1,
#          '장호': 1,
#          '사장': 2,
#          '김': 1,
#          '세용': 1,
#          '활성화': 1,
#          '파이낸셜뉴스': 1,
#          '업무': 1,
#          '협약': 1,
#          '데일리안': 2,
#          '삼성': 3,
#          '전기': 6,
#          '전장': 2,
#          '초청': 4,
#          '행사': 3,
#          '장기': 1,
#          '장덕': 1,
#          '인사말': 1,
#          '일간': 2,
#          '부산': 1,
#          '소자': 1,
#          '시민단체': 6,
#          '강요': 1,
#          '분노': 1,
#          '대해': 2,
#          '이하': 1,
#          '동시': 1,
#          '국민은행': 4,
#          '청년': 3,
#          '기': 3,
#          '발족': 1,
#          '잇츠': 2,
#          '라이프': 2,
#          '발대식': 2,
#          '참석자': 1,
#          '기념': 1,
#          '촬영': 1,
#          '세계': 1,
#          '사태': 8,
#          '자본주의': 1,
#          '상상': 1,
#          '자본': 1,
#          '관계': 1,
#          '재': 1,
#          '설정': 1,
#          '촉발': 2,
#          '개입': 1,
#          '시간': 1,
#          '주장': 1,
#          '월일': 1,
#          '대책': 1,
#          '프레': 1,
#          '시안': 1,
#          '의원': 1,
#          '연구': 1,
#          '모임': 1,
#          '건강': 3,
#          '도시': 5,
#          '조성': 3,
#          '의회': 5,
#          '회': 2,
#          '방안': 2,
#          '모색': 2,
#          '국가': 4,
#          '성남시': 1,
#          '분당구': 1,
#          '김진환': 1,
#          '태스크포스': 1,
#          '노컷뉴스': 1,
#          '제': 1,
#          '독도': 1,
#          '비화': 1,
#          '수도': 1,
#          '웨딩': 1,
#          '토니모리': 3,
#          '첫': 1,
#          '팝업': 2,
#          '스토어': 2,
#          '오픈': 1,
#          '토': 2,
#          '일일': 2,
#          '겟잇': 1,
#          '틴트': 1,
#          '워터': 1,
#          '버터': 1,
#          '빵': 1,
#          '순례': 1,
#          '시리즈': 1,
#          '뉴': 1,
#          '컬러': 1,
#          '종': 1,
#          '이미지': 1,
#          '뷰티': 1,
#          '브랜드': 1,
#          '성수동': 1,
#          '위치': 1,
#          '회복': 1,
#          '장로': 1,
#          '영토': 1,
#          '반등': 1,
#          '시동': 1,
#          '김응열': 1,
#          '불경기': 1,
#          '실적': 2,
#          '부진': 1,
#          '피하': 1,
#          '못': 1,
#          '불황': 1,
#          '그림자': 1,
#          '시작': 1,
#          '올해': 1,
#          '분기': 1,
#          '정기': 1,
#          '여': 1,
#          '사': 1,
#          '참석': 1,
#          '잠재': 1,
#          '협회': 2,
#          '미래': 1,
#          '해답': 1,
#          '서울시': 2,
#          '인사이트': 1,
#          '자리': 1,
#          '강요식': 1,
#          '재단': 1,
#          '이사장': 1,
#          '전략': 1,
#          '강남구': 1,
#          '삼정': 1,
#          '호텔': 1,
#          '갤폴드': 1,
#          '배터리': 5,
#          '탑재': 1,
#          '수명': 2,
#          '듯': 1,
#          '폴드': 1,
#          '내장': 1,
#          '예상': 1,
#          '구체': 1,
#          '내용': 1,
#          '유명': 1,
#          '팁스터': 1,
#          '유출': 1,
#          '판다': 1,
#          '플래시': 1,
#          '향상': 1,
#          '위해': 1,
#          '리소스': 1,
#          '사용': 1,
#          '작업': 1,
#          '제거': 1})

# %% [markdown]
# - 텍스트 전처리 : 불용어 처리

# %%
# 불용어처리명
remove_char_counter = Counter({x:count[x] for x in count if len(x) > 1})

# 불용어 텍스트 파일 경로
korean_stopwords_path = "data/stopwords-ko.txt"

# 불용어 로드
with open(korean_stopwords_path, encoding='UTF-8') as f:
    stopwords = f.readlines()
stopwords = [x.strip() for x in stopwords]

# 나무위키에서 추가한 불용어
namu_wiki_stopwords = ['상위', '문서', '내용', '누설', '아래', '해당', '설명',
                       '표기', '추가', '모든', '사용', '매우', '가장', '줄거리',
                       '요소', '상황', '편집', '틀', '경우', '때문', '모습',
                       '정도', '이후', '사실', '생각', '인물', '이름', '년월', '공유', 
                       '인공', '지능'] ##### 개별적 불용어 추가

# 불용어 추가
stopwords.extend(namu_wiki_stopwords)

# 불용어 처리
remove_char_counter = Counter({x:remove_char_counter[x] for x in remove_char_counter if x not in stopwords})
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [18], in <cell line: 8>()
#       5 korean_stopwords_path = "data/stopwords-ko.txt"
#       7 # 불용어 로드
# ----> 8 with open(korean_stopwords_path, encoding='UTF-8') as f:
#       9     stopwords = f.readlines()
#      10 stopwords = [x.strip() for x in stopwords]
#
# FileNotFoundError: [Errno 2] No such file or directory: 'data/stopwords-ko.txt'

# %%
remove_char_counter
# Out:
# Counter({'동아': 10,
#          '언론사': 12,
#          '개별': 40,
#          '문서': 40,
#          '메뉴': 40,
#          '바로': 40,
#          '공유': 83,
#          '애정': 2,
#          '갤럭시': 5,
#          '워치': 3,
#          '가요': 1,
#          '기자': 13,
#          '지난': 1,
#          '전자': 3,
#          '스마트': 3,
#          '밴드': 3,
#          '정식': 1,
#          '출시': 2,
#          '이후': 1,
#          '만이': 1,
#          '국내': 3,
#          '해외': 6,
#          '반응': 1,
#          '샤오미': 1,
#          '스포츠동아': 1,
#          '휘브': 6,
#          '콘셉트': 2,
#          '트레일러': 3,
#          '공개': 3,
#          '제이': 2,
#          '진범': 2,
#          '유건': 2,
#          '이정': 2,
#          '인홍': 2,
#          '준가': 1,
#          '공식': 2,
#          '유튜브': 1,
#          '채널': 1,
#          '통해': 5,
#          '싱글': 3,
#          '앨범': 2,
#          '터널': 2,
#          '유스': 2,
#          '개인': 2,
#          '단체': 1,
#          '영상': 2,
#          '도심': 1,
#          '옥상': 1,
#          '각자': 1,
#          '간전': 5,
#          '비즈': 2,
#          '버넌스': 1,
#          '노루': 2,
#          '페인트': 2,
#          '업체': 2,
#          '전문가': 5,
#          '지렛대': 1,
#          '활용': 5,
#          '시스템': 10,
#          '통합': 1,
#          '존재': 1,
#          '점점': 1,
#          '연쇄': 1,
#          '지주사': 1,
#          '이번': 2,
#          '공격': 1,
#          '볼륨': 1,
#          '확장': 2,
#          '지주': 1,
#          '매각': 3,
#          '전문': 5,
#          '경영인': 1,
#          '국민일보': 1,
#          '경술국치': 1,
#          '네이버': 20,
#          '침묵': 1,
#          '반감': 1,
#          '확산': 1,
#          '본사': 4,
#          '모습': 2,
#          '연합뉴스': 3,
#          '일본': 17,
#          '국민': 2,
#          '메신저': 1,
#          '라인': 21,
#          '운영': 1,
#          '야후': 8,
#          '대주': 1,
#          '주인': 1,
#          '시도': 1,
#          '정보기술': 5,
#          '업계': 3,
#          '반발': 1,
#          '글로벌': 4,
#          '서비스': 5,
#          '위기': 1,
#          '입장': 3,
#          '코리아': 5,
#          '중앙': 2,
#          '일리': 2,
#          '농업': 4,
#          '에스': 2,
#          '플라즈마': 1,
#          '농축': 1,
#          '폐수': 1,
#          '정화': 1,
#          '한국': 11,
#          '기술': 7,
#          '진흥': 1,
#          '우리나라': 1,
#          '발전': 1,
#          '디지털': 8,
#          '전환': 3,
#          '유망': 1,
#          '스타트업': 3,
#          '소개': 3,
#          '아이디어': 1,
#          '상품': 1,
#          '독창': 1,
#          '우리': 3,
#          '윤택': 1,
#          '전국': 1,
#          '각지': 1,
#          '이데일리': 6,
#          '데이터': 1,
#          '국적': 1,
#          '주의': 2,
#          '시대': 2,
#          '수출': 1,
#          '선봉': 1,
#          '김현아': 1,
#          '세상': 1,
#          '정부': 16,
#          '요구': 5,
#          '과도': 1,
#          '조치': 3,
#          '기준': 2,
#          '기업': 17,
#          '대상': 2,
#          '제공': 4,
#          '거의': 1,
#          '인공': 4,
#          '지능': 4,
#          '이즈': 1,
#          '뱅크': 1,
#          '뉴스': 15,
#          '소프트뱅크': 3,
#          '회사': 5,
#          '엄지': 3,
#          '살롱': 1,
#          '권진영': 1,
#          '서울': 8,
#          '도쿄': 2,
#          '증권': 1,
#          '거래소': 1,
#          '시가총액': 2,
#          '최대': 1,
#          '이자': 1,
#          '투자': 1,
#          '아이': 1,
#          '하반기': 2,
#          '라운드': 2,
#          '디스플레이': 1,
#          '대세': 1,
#          '독보': 1,
#          '지배': 1,
#          '점유': 3,
#          '달리': 1,
#          '지난해': 3,
#          '시장': 5,
#          '중국': 2,
#          '패널': 1,
#          '주력': 3,
#          '대형': 1,
#          '모바일': 1,
#          '중소': 1,
#          '문화': 2,
#          '일보': 2,
#          '케이': 4,
#          '재팬': 2,
#          '타이틀곡': 1,
#          '선공': 1,
#          '그룹': 12,
#          '보이': 1,
#          '현장': 1,
#          '컴백': 1,
#          '경제': 6,
#          '이수영': 3,
#          '대표': 2,
#          '웅진': 8,
#          '인식': 1,
#          '강경': 1,
#          '카페': 1,
#          '신문': 2,
#          '인터뷰': 1,
#          '사진': 3,
#          '렌털': 2,
#          '교육': 5,
#          '서적': 1,
#          '유통': 2,
#          '식품': 1,
#          '사업': 3,
#          '체질': 1,
#          '개선': 1,
#          '박차': 1,
#          '정체': 2,
#          '윤석금': 2,
#          '회장': 2,
#          '특명': 2,
#          '뉴시스': 1,
#          '현대': 13,
#          '퓨처': 5,
#          '인수': 4,
#          '미디어': 2,
#          '콘텐츠': 2,
#          '도약': 4,
#          '백화점': 2,
#          '지주회사': 2,
#          '에프': 1,
#          '홀딩스': 1,
#          '쇼핑': 1,
#          '보유': 1,
#          '억원': 2,
#          '매입': 1,
#          '주식': 1,
#          '매매': 1,
#          '계약': 1,
#          '체결': 3,
#          '공시': 1,
#          '매일경제': 1,
#          '보기': 12,
#          '이전': 4,
#          '컨텐츠': 8,
#          '다음': 4,
#          '길라잡이': 1,
#          '사례': 1,
#          '커뮤니티': 1,
#          '피터': 1,
#          '그림': 1,
#          '설치': 1,
#          '방법': 1,
#          '최신': 1,
#          '소식': 1,
#          '비롯': 1,
#          '성형': 1,
#          '일상': 2,
#          '헤럴드경제': 4,
#          '소작인': 2,
#          '비용': 1,
#          '지수': 1,
#          '전광판': 1,
#          '보고': 1,
#          '정목': 1,
#          '엔화': 1,
#          '가치': 3,
#          '역대': 1,
#          '하락': 1,
#          '미국': 2,
#          '전락': 1,
#          '전망': 1,
#          '게이': 1,
#          '영향': 1,
#          '머니투데이': 3,
#          '국제': 2,
#          '자격증': 2,
#          '취득': 1,
#          '직원': 3,
#          '연봉': 1,
#          '상승': 1,
#          '핵심': 1,
#          '요소': 1,
#          '부상': 1,
#          '비즈니스': 2,
#          '직무': 1,
#          '스킬': 1,
#          '소프트': 1,
#          '최근': 2,
#          '발표': 2,
#          '급여': 1,
#          '수준': 1,
#          '연례': 1,
#          '리서치': 1,
#          '전세계': 1,
#          '리더': 4,
#          '관련': 3,
#          '인증': 1,
#          '자격': 1,
#          '획득': 1,
#          '조직': 1,
#          '매년': 1,
#          '최소': 1,
#          '달러': 1,
#          '이상': 2,
#          '건설': 5,
#          '공제조합': 2,
#          '고객': 7,
#          '중심': 1,
#          '보증': 2,
#          '개방': 1,
#          '기관': 1,
#          '경쟁': 1,
#          '더욱': 2,
#          '심화': 1,
#          '상황': 1,
#          '조합원': 1,
#          '이용': 5,
#          '구축': 5,
#          '필수': 1,
#          '판단': 1,
#          '차세대': 2,
#          '정보': 3,
#          '진행': 2,
#          '전경': 1,
#          '사진전': 1,
#          '아시아': 2,
#          '취업': 3,
#          '등용문': 1,
#          '스쿨': 2,
#          '지원': 2,
#          '모집': 2,
#          '현지': 5,
#          '생활': 1,
#          '알선': 1,
#          '맞춤': 1,
#          '인재': 4,
#          '양성': 5,
#          '프로그램': 4,
#          '특화된': 1,
#          '클라우드': 2,
#          '기반': 1,
#          '스택': 1,
#          '개발자': 1,
#          '과정': 2,
#          '어학': 1,
#          '시민': 10,
#          '연대': 8,
#          '지분매각': 4,
#          '행정지도': 5,
#          '철회': 3,
#          '다래': 1,
#          '공정': 5,
#          '정의': 4,
#          '대가': 2,
#          '촉구': 4,
#          '정리': 1,
#          '온라인': 1,
#          '기자회견': 1,
#          '정현': 1,
#          '준비': 6,
#          '위원장': 1,
#          '학습': 1,
#          '탈바꿈': 1,
#          '변신': 1,
#          '사진가': 1,
#          '프로젝트': 1,
#          '진두': 1,
#          '지휘': 1,
#          '전자신문': 3,
#          '다인': 3,
#          '우즈베키스탄': 3,
#          '파크': 4,
#          '역량': 4,
#          '강화': 4,
#          '연수': 4,
#          '우즈': 1,
#          '키스': 1,
#          '수료식': 1,
#          '개최': 4,
#          '지난달': 1,
#          '주간': 2,
#          '팩트': 3,
#          '강력': 2,
#          '항의': 2,
#          '적극': 4,
#          '표명': 1,
#          '대응': 7,
#          '필요': 2,
#          '대한': 3,
#          '영향력': 1,
#          '축소': 1,
#          '가운데': 1,
#          '위원회': 4,
#          '문정': 1,
#          '스타': 1,
#          '걸스': 1,
#          '플래닛쇼미': 1,
#          '유다연': 3,
#          '신곡': 2,
#          '발매': 2,
#          '디오': 1,
#          '가수': 1,
#          '에너지': 1,
#          '증명': 1,
#          '정오': 1,
#          '각종': 1,
#          '음원': 1,
#          '사이트': 1,
#          '로우': 1,
#          '사랑': 1,
#          '주제': 1,
#          '댄스': 1,
#          '로맨틱': 1,
#          '감정': 1,
#          '교차': 1,
#          '지점': 1,
#          '섬세': 1,
#          '강탈': 1,
#          '야욕': 1,
#          '잇쥬': 1,
#          '분야': 1,
#          '민영': 1,
#          '통신사': 1,
#          '핫이슈': 1,
#          '한눈': 1,
#          '주요': 1,
#          '뉴스잇쥬': 1,
#          '강도현': 1,
#          '과학기술': 1,
#          '정보통신부': 1,
#          '차관': 1,
#          '종로구': 1,
#          '청사': 1,
#          '현안': 1,
#          '브리핑': 1,
#          '디지털타임스': 2,
#          '공공': 2,
#          '아마추어': 1,
#          '공무원': 1,
#          '오류': 1,
#          '장애': 1,
#          '거듭': 1,
#          '유지관리': 1,
#          '근본': 1,
#          '변화': 1,
#          '목소리': 1,
#          '민간': 1,
#          '혁신': 4,
#          '예산': 1,
#          '투자가': 1,
#          '지적': 1,
#          '국세청': 1,
#          '운영체제': 2,
#          '프리도스': 1,
#          '노트북': 2,
#          '구매': 1,
#          '권택경': 1,
#          '윈도우': 4,
#          '조립': 1,
#          '완제': 1,
#          '라면': 1,
#          '보통': 1,
#          '제품': 3,
#          '포함': 3,
#          '때문': 1,
#          '가격': 2,
#          '기본': 1,
#          '구성': 2,
#          '코리아헤럴드': 1,
#          '가스': 6,
#          '자산': 6,
#          '기부': 5,
#          '경영': 5,
#          '실천': 4,
#          '앞장': 2,
#          '김은경': 1,
#          '재활용': 1,
#          '통한': 1,
#          '환경': 1,
#          '사회': 3,
#          '지배구조': 1,
#          '경기도': 2,
#          '성남': 1,
#          '판교': 1,
#          '소재': 1,
#          '기증': 1,
#          '서버': 1,
#          '스토리': 1,
#          '행복': 1,
#          '헤럴드': 1,
#          '산업': 1,
#          '허브': 3,
#          '인도': 1,
#          '첸나이': 3,
#          '공장': 2,
#          '아이폰': 1,
#          '생산': 1,
#          '확대': 1,
#          '계획': 1,
#          '기숙사': 1,
#          '또한': 1,
#          '테크': 1,
#          '자동차': 1,
#          '소프트웨어': 1,
#          '개발': 1,
#          '포드': 1,
#          '르노': 1,
#          '닛산': 1,
#          '솔루션': 1,
#          '양주시': 6,
#          '광운대': 4,
#          '양주': 2,
#          '광운': 4,
#          '첨단': 9,
#          '융합': 5,
#          '연구소': 5,
#          '설립': 5,
#          '합심': 1,
#          '학교': 3,
#          '경기': 2,
#          '주택': 2,
#          '시공사': 2,
#          '테크노': 2,
#          '밸리': 2,
#          '강수현': 1,
#          '총장': 1,
#          '장호': 1,
#          '사장': 2,
#          '세용': 1,
#          '활성화': 1,
#          '파이낸셜뉴스': 1,
#          '업무': 1,
#          '협약': 1,
#          '데일리안': 2,
#          '삼성': 3,
#          '전기': 6,
#          '전장': 2,
#          '초청': 4,
#          '행사': 3,
#          '장기': 1,
#          '장덕': 1,
#          '인사말': 1,
#          '일간': 2,
#          '부산': 1,
#          '소자': 1,
#          '시민단체': 6,
#          '강요': 1,
#          '분노': 1,
#          '대해': 2,
#          '이하': 1,
#          '동시': 1,
#          '국민은행': 4,
#          '청년': 3,
#          '발족': 1,
#          '잇츠': 2,
#          '라이프': 2,
#          '발대식': 2,
#          '참석자': 1,
#          '기념': 1,
#          '촬영': 1,
#          '세계': 1,
#          '사태': 8,
#          '자본주의': 1,
#          '상상': 1,
#          '자본': 1,
#          '관계': 1,
#          '설정': 1,
#          '촉발': 2,
#          '개입': 1,
#          '시간': 1,
#          '주장': 1,
#          '월일': 1,
#          '대책': 1,
#          '프레': 1,
#          '시안': 1,
#          '의원': 1,
#          '연구': 1,
#          '모임': 1,
#          '건강': 3,
#          '도시': 5,
#          '조성': 3,
#          '의회': 5,
#          '방안': 2,
#          '모색': 2,
#          '국가': 4,
#          '성남시': 1,
#          '분당구': 1,
#          '김진환': 1,
#          '태스크포스': 1,
#          '노컷뉴스': 1,
#          '독도': 1,
#          '비화': 1,
#          '수도': 1,
#          '웨딩': 1,
#          '토니모리': 3,
#          '팝업': 2,
#          '스토어': 2,
#          '오픈': 1,
#          '일일': 2,
#          '겟잇': 1,
#          '틴트': 1,
#          '워터': 1,
#          '버터': 1,
#          '순례': 1,
#          '시리즈': 1,
#          '컬러': 1,
#          '이미지': 1,
#          '뷰티': 1,
#          '브랜드': 1,
#          '성수동': 1,
#          '위치': 1,
#          '회복': 1,
#          '장로': 1,
#          '영토': 1,
#          '반등': 1,
#          '시동': 1,
#          '김응열': 1,
#          '불경기': 1,
#          '실적': 2,
#          '부진': 1,
#          '피하': 1,
#          '불황': 1,
#          '그림자': 1,
#          '시작': 1,
#          '올해': 1,
#          '분기': 1,
#          '정기': 1,
#          '참석': 1,
#          '잠재': 1,
#          '협회': 2,
#          '미래': 1,
#          '해답': 1,
#          '서울시': 2,
#          '인사이트': 1,
#          '자리': 1,
#          '강요식': 1,
#          '재단': 1,
#          '이사장': 1,
#          '전략': 1,
#          '강남구': 1,
#          '삼정': 1,
#          '호텔': 1,
#          '갤폴드': 1,
#          '배터리': 5,
#          '탑재': 1,
#          '수명': 2,
#          '폴드': 1,
#          '내장': 1,
#          '예상': 1,
#          '구체': 1,
#          '내용': 1,
#          '유명': 1,
#          '팁스터': 1,
#          '유출': 1,
#          '판다': 1,
#          '플래시': 1,
#          '향상': 1,
#          '위해': 1,
#          '리소스': 1,
#          '사용': 1,
#          '작업': 1,
#          '제거': 1})

# %% [markdown]
# - 텍스트 전처리 : 명사의 분석 대상 갯수 지정

# %%
# 빈도수 특정 명사의 갯수 지정
ranked_tags = remove_char_counter.most_common(50) # 빈도순 n개 단어

# %%
pd.DataFrame(ranked_tags)

# %% [markdown]
# - 워드클라우드

# %%
####### [WordCloud 오류 해결]
#!pip install --upgrade pip
#!pip install --upgrade Pillow

# %%
### 워드클라우드
wc = WordCloud(font_path='data/malgun.ttf', width=1200, height=500,
               scale=4.0, max_font_size=600, background_color='white')
gen = wc.generate_from_frequencies(remove_char_counter)

# %%
# 워드클라우드 그리기 및 파일로 저장
plt.figure(figsize=(15, 7))
plt.imshow(gen)
plt.axis('off')
plt.savefig(f'data/daumNews_wc_{keyword}.png')
