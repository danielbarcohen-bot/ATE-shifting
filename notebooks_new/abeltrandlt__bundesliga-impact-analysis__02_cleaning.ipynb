# %%
{
 "cells": [
  {"cell_type":"markdown","metadata":{},"source":["# 02 — Cleaning & Feature Engineering\nBuild per-season analytic datasets (per-90 features + joins)."]},
  {"cell_type":"code","metadata":{},"source":[
"from src.cleaning import build_season, build_both\n",
"live = build_season('live')\n",
"bench = build_season('benchmark')\n",
"combo = build_both()\n",
"live.head()\n"
  ]},
  {"cell_type":"code","metadata":{},"source":[
"import pandas as pd\n",
"pd.read_csv('data/processed/players_analytic_2025-2026.csv').head()"
  ]}
 ],
 "metadata": {"kernelspec":{"display_name":"Python 3","language":"python","name":"python3"}},
 "nbformat":4,"nbformat_minor":5
}
