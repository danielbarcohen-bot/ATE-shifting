# %%
import os
import pandas
df = pandas.read_json("supermarkets.json")
df.set_index("ID")
# Out:
#             Address           City             State Country         Name  \
# ID
# 1      3666 21st St  San Francisco          CA 94114     USA      Madeira
# 2    735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 3       332 Hill St  San Francisco  California 94114     USA  Super River
# 4      3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 5   1056 Sanchez St  San Francisco        California     USA      Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#     Employees
# ID
# 1           8
# 2          15
# 3          25
# 4          10
# 5          12
# 6          20

# %%
df2 = pandas.read_excel("supermarkets.xlsx", sheet_name=0)
df2.set_index("ID")
# Out:
#             Address           City             State Country Supermarket Name  \
# ID
# 1      3666 21st St  San Francisco          CA 94114     USA          Madeira
# 2    735 Dolores St  San Francisco          CA 94119     USA      Bready Shop
# 3       332 Hill St  San Francisco  California 94114     USA      Super River
# 4      3995 23rd St  San Francisco          CA 94114     USA       Ben's Shop
# 5   1056 Sanchez St  San Francisco        California     USA          Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114     USA       Richvalley
#
#     Number of Employees
# ID
# 1                     8
# 2                    15
# 3                    25
# 4                    10
# 5                    12
# 6                    20

# %%
df4 = pandas.read_csv("supermarkets-commas.txt")
df4.set_index("ID")
# Out:
#             Address           City             State Country         Name  \
# ID
# 1      3666 21st St  San Francisco          CA 94114     USA      Madeira
# 2    735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 3       332 Hill St  San Francisco  California 94114     USA  Super River
# 4      3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 5   1056 Sanchez St  San Francisco        California     USA      Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#     Employees
# ID
# 1           8
# 2          15
# 3          25
# 4          10
# 5          12
# 6          20

# %%
df5 = pandas.read_csv("supermarkets-semi-colons.txt", sep=";")
df5.set_index("ID")
# Out:
#             Address           City             State Country          Name  \
# ID
# 1      3666 21st St  San Francisco          CA 94114     USA       Madeira
# 2    735 Dolores St  San Francisco          CA 94119     USA   Bready Shop
# 3       332 Hill St  San Francisco  California 94114     USA   Super River
# 4      3995 23rd St  San Francisco          CA 94114     USA    Ben's Shop
# 5   1056 Sanchez St  San Francisco        California     USA       Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114     USA    Richvalley
#
#     Employees
# ID
# 1           8
# 2          15
# 3          25
# 4          10
# 5          12
# 6          20

# %%
dfl = pandas.read_csv("supermarkets-commas.txt")
dfl.set_index("ID", inplace=True)

# %%
dfl.set_index("Name", inplace=True, drop=False)

# %%
dfl
# Out:
#                      Address           City             State Country  \
# Name
#  Madeira        3666 21st St  San Francisco          CA 94114     USA
# Bready Shop   735 Dolores St  San Francisco          CA 94119     USA
# Super River      332 Hill St  San Francisco  California 94114     USA
# Ben's Shop      3995 23rd St  San Francisco          CA 94114     USA
# Sanchez      1056 Sanchez St  San Francisco        California     USA
# Richvalley   551 Alvarado St  San Francisco          CA 94114     USA
#
#                     Name  Employees
# Name
#  Madeira         Madeira          8
# Bready Shop  Bready Shop         15
# Super River  Super River         25
# Ben's Shop    Ben's Shop         10
# Sanchez          Sanchez         12
# Richvalley    Richvalley         20

# %%
dfl.loc["Super River":"Sanchez","City":"Country"]
# Out:
#                       City             State Country
# Name
# Super River  San Francisco  California 94114     USA
# Ben's Shop   San Francisco          CA 94114     USA
# Sanchez      San Francisco        California     USA

# %%
dfl
# Out:
#                      Address           City             State Country  \
# Name
#  Madeira        3666 21st St  San Francisco          CA 94114     USA
# Bready Shop   735 Dolores St  San Francisco          CA 94119     USA
# Super River      332 Hill St  San Francisco  California 94114     USA
# Ben's Shop      3995 23rd St  San Francisco          CA 94114     USA
# Sanchez      1056 Sanchez St  San Francisco        California     USA
# Richvalley   551 Alvarado St  San Francisco          CA 94114     USA
#
#                     Name  Employees
# Name
#  Madeira         Madeira          8
# Bready Shop  Bready Shop         15
# Super River  Super River         25
# Ben's Shop    Ben's Shop         10
# Sanchez          Sanchez         12
# Richvalley    Richvalley         20

# %%
dfl.iloc[1:4,1:4]
# Out:
#                       City             State Country
# Name
# Bready Shop  San Francisco          CA 94119     USA
# Super River  San Francisco  California 94114     USA
# Ben's Shop   San Francisco          CA 94114     USA

# %%
dfl.drop("Sanchez", 0)
# Out:
#                      Address           City             State Country  \
# Name
#  Madeira        3666 21st St  San Francisco          CA 94114     USA
# Bready Shop   735 Dolores St  San Francisco          CA 94119     USA
# Super River      332 Hill St  San Francisco  California 94114     USA
# Ben's Shop      3995 23rd St  San Francisco          CA 94114     USA
# Richvalley   551 Alvarado St  San Francisco          CA 94114     USA
#
#                     Name  Employees
# Name
#  Madeira         Madeira          8
# Bready Shop  Bready Shop         15
# Super River  Super River         25
# Ben's Shop    Ben's Shop         10
# Richvalley    Richvalley         20

# %%
dfl.drop("Name", 1)
# Out:
#                      Address           City             State Country  \
# Name
#  Madeira        3666 21st St  San Francisco          CA 94114     USA
# Bready Shop   735 Dolores St  San Francisco          CA 94119     USA
# Super River      332 Hill St  San Francisco  California 94114     USA
# Ben's Shop      3995 23rd St  San Francisco          CA 94114     USA
# Sanchez      1056 Sanchez St  San Francisco        California     USA
# Richvalley   551 Alvarado St  San Francisco          CA 94114     USA
#
#              Employees
# Name
#  Madeira             8
# Bready Shop         15
# Super River         25
# Ben's Shop          10
# Sanchez             12
# Richvalley          20

# %%
dfl.drop(dfl.index[0:3], 0)
# Out:
#                     Address           City       State Country        Name  \
# Name
# Ben's Shop     3995 23rd St  San Francisco    CA 94114     USA  Ben's Shop
# Sanchez     1056 Sanchez St  San Francisco  California     USA     Sanchez
# Richvalley  551 Alvarado St  San Francisco    CA 94114     USA  Richvalley
#
#             Employees
# Name
# Ben's Shop         10
# Sanchez            12
# Richvalley         20

# %%
dfl.drop(dfl.columns[0:3], 1)
# Out:
#             Country         Name  Employees
# Name
#  Madeira        USA      Madeira          8
# Bready Shop     USA  Bready Shop         15
# Super River     USA  Super River         25
# Ben's Shop      USA   Ben's Shop         10
# Sanchez         USA      Sanchez         12
# Richvalley      USA   Richvalley         20

# %%
dfl = dfl.drop(dfl.index[0:3], 0)
dfl = dfl.drop(dfl.columns[0:3], 1)
dfl
# Out:
# Empty DataFrame
# Columns: [Country, Name, Employees]
# Index: []

# %%
dfl["bullshit"]=["one", "two", "three"]

# %%
dfl
# Out:
#   Country Name  Employees bullshit
# 0     NaN  NaN        NaN      one
# 1     NaN  NaN        NaN      two
# 2     NaN  NaN        NaN    three

# %%
dfl["Country"] = ["1","2","3"]
dfl
# Out:
#   Country Name  Employees bullshit
# 0       1  NaN        NaN      one
# 1       2  NaN        NaN      two
# 2       3  NaN        NaN    three

# %%
dfl.set_index("Country")
# Out:
#         Name  Employees bullshit
# Country
# 1        NaN        NaN      one
# 2        NaN        NaN      two
# 3        NaN        NaN    three

# %%
dfl
# Out:
#   Country Name  Employees bullshit
# 0       1  NaN        NaN      one
# 1       2  NaN        NaN      two
# 2       3  NaN        NaN    three

# %%
dfl.shape[0]*["North America"]
# Out:
# ['North America', 'North America', 'North America']

# %%
dfl
# Out:
#   Country Name  Employees bullshit
# 0       1  NaN        NaN      one
# 1       2  NaN        NaN      two
# 2       3  NaN        NaN    three

# %%
dfl["Name"]=dfl["Country"]+ " - " + "Something"

# %%
dfl
# Out:
#   Country           Name  Employees bullshit
# 0       1  1 - Something        NaN      one
# 1       2  2 - Something        NaN      two
# 2       3  3 - Something        NaN    three

# %%
dflt=dfl.T

# %%
dflt
# Out:
#                        0              1              2
# Country                1              2              3
# Name       1 - Something  2 - Something  3 - Something
# Employees            NaN            NaN            NaN
# bullshit             one            two          three

# %%
dflt[4]=[4,"4 - Something","","four"]

# %%
dflt
# Out:
#                        0              1              2              4
# Country                1              2              3              4
# Name       1 - Something  2 - Something  3 - Something  4 - Something
# Employees            NaN            NaN            NaN
# bullshit             one            two          three           four

# %%
dflt = dflt.T

# %%
dflt
# Out:
#   Country           Name Employees bullshit
# 0       1  1 - Something       NaN      one
# 1       2  2 - Something       NaN      two
# 2       3  3 - Something       NaN    three
# 4       4  4 - Something               four
