# %%
# Video Games Sales Data Analysis

"""
This notebook demonstrates how to analyze a video games sales dataset using Python. You will learn how to load, clean, and explore the data, as well as perform basic visualizations and answer key analytical questions.

Libraries Used
- pandas: Data manipulation and analysis
- numpy: Numerical operations
- matplotlib & seaborn: Data visualization
"""

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## 1. Import Required Libraries
#
# First, we import the necessary libraries for data analysis and visualization.

# %%
video = pd.read_csv("video_games_dataset.csv")

# %% [markdown]
# ## 2. Load the Dataset
#
# Load the video games sales dataset into a pandas DataFrame for analysis.

# %%
video.head()

# %% [markdown]
# ## 3. Explore the Data
#
# Let's take a first look at the dataset to understand its structure and contents.

# %%
video.tail()

# %%
video.info()

# %%
video.shape

# %%
video.dtypes

# %%
video.describe(include='all')

# %%
video.info()

# %% [markdown]
# __After looking at the data for the first time, you should ask yourself a few questions:__
# 1. Do I need all of the variables?
# 2. Should I transform any variables?
# 3. Are there NA (missing) values, outliers or other strange values?
# 4. Should I create new variables?
#
# For the rest of this lesson, we will address each of the questions in the context of this dataset.

# %% [markdown]
# ## 4. Data Cleaning and Preparation
#
# Before analysis, we need to clean the data: handle missing values, remove unnecessary columns, and transform variables as needed.

# %% [markdown]
# __Do I Need All of the Variables?__
#
# Getting rid of unnecessary variables is a good first step when dealing with any data set, since dropping variables reduces complexity and can make computation on the data faster. Whether you should get rid of a variable or not will depend on size of the data set and the goal of your analysis. With a data set as small as the Video data, there's no real need to drop variables from a computing perspective (we have plenty of memory and processing power to deal with such a small data set) but it can still be helpful to drop variables that will only distract from your goal.

# %% [markdown]
# __To delete "Rank" column:__

# %%
del video["Rank"]

# %%
video.describe(include='all')

# %% [markdown]
# #### Are there any missing values, outliers or other strange values?

# %%
video.isna().sum()

# %%
video["Publisher"] = video["Publisher"].fillna("Unknown")

# %%
video.isna().sum()

# %%
video["Year"] = video["Year"].fillna(video["Year"].mean())

# %%
video.isna().sum()

# %%
video.shape

# %% [markdown]
# __Should I Transform Any Variables?__
#
# When you first load a data set, some of the variables may be encoded as data types that don't fit well with what the data really is or what it means.
#
# For instance, Year is a float that is supposed to be either an integer or datetime

# %%
video["Year"] = pd.to_datetime(video["Year"].astype("int32"), format="%Y").dt.year

# %%
video.info()

# %%
video.head()

# %%
video["Platform"].unique()

# %%
video["Platform"].value_counts()

# %%
video["Genre"].unique()

# %%
video["Genre"].value_counts()

# %%
video["Year"].describe()

# %%
video.hist(column="Year", bins=30, figsize=(10, 5))

# %%
video.hist(column="Global_Sales", bins=30, figsize=(10, 5))

# %%
video["Global_Sales"].min()

# %%
video["Global_Sales"].max()

# %% [markdown]
# #### Data Analysis

# %% [markdown]
# ## 5. Data Analysis
#
# Now that the data is clean, let's analyze it to answer some key questions about video game sales.

# %%
video.head()

# %% [markdown]
# 1. Which genre has the highest global sales?

# %%
genre_sales = video.groupby('Genre')['Global_Sales'].sum().sort_values(ascending=False)
genre_sales

# %%
plt.figure(figsize=(10, 6))
genre_sales.plot(kind='bar', color='skyblue')
plt.title('Total Global Sales by Genre')
plt.xlabel('Genre')
plt.ylabel('Global Sales (in millions)')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# The bar chart above shows the total global sales for each genre. The "Action" genre has the highest total global sales, followed by "Sports" and "Shooter." The "Platform" genre has the lowest total global sales.

# %% [markdown]
# 2. Which platform has the highest number of top-selling games?

# %%
platform_count = video['Platform'].value_counts()
platform_count

# %%
plt.figure(figsize=(10, 6))
platform_count.plot(kind='bar', color='slateblue')
plt.title('Number of Games by Platform')
plt.xlabel('Platform')
plt.ylabel('Number of Games')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# The plot above shows the number of top-selling games for each platform. The "DS" platform has the highest number of top-selling games.

# %% [markdown]
# 3. Which region (NA, EU, JP, Other) has the highest global sales?

# %%
region_sales = {
    "NA": video['NA_Sales'].sum(),
    "EU": video['EU_Sales'].sum(),
    "JP": video['JP_Sales'].sum(),
    "Other": video['Other_Sales'].sum()
}
region_sales_sorted = dict(sorted(region_sales.items(), key=lambda item: item[1], reverse=True))
region_sales_sorted

# %%
plt.figure(figsize=(5, 5))
plt.pie(region_sales_sorted.values(), labels=region_sales_sorted.keys(), autopct='%1.1f%%', startangle=140, colors=sns.color_palette("pastel"))
plt.title('Global Sales Distribution by Region')
plt.axis('equal')  # Equal aspect ratio ensures that pie chart is a circle.
plt.show()

# %% [markdown]
# The pie chart above shows the distribution of global sales across different regions. The "NA" region has the highest global sales, followed by "EU" and "JP." The "Other" region has the lowest global sales.

# %% [markdown]
# 4. What are the top 5 games with the highest global sales?

# %%
top_5_games = video.nlargest(5, 'Global_Sales')[['Name', 'Genre', 'Global_Sales']]
print("Top 5 Games by Global Sales:")
print(top_5_games)

# %%
plt.figure(figsize=(10, 6))
sns.barplot(x='Name', y='Global_Sales', data=top_5_games, palette='Blues_d')
plt.title('Top 5 Games by Global Sales')
plt.xlabel('Game Name')
plt.ylabel('Global Sales (in millions)')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Assignments
# 1. Year-wise Release Trend with Global Sales
# 2. Platform vs. Regional Sales Heatmap
# 3. Publisher-wise Global Sales Distribution
# 4. Top Genre per Region
# 5. NA vs JP Market Comparison per Genre

# %% [markdown]
# ## 6. Summary and Next Steps
#
# - We explored and cleaned a video games sales dataset.
# - Performed basic analysis and visualizations to answer key questions.
#
# **Next Steps:**
# - Try the assignments below to deepen your understanding.
# - Explore more advanced visualizations or machine learning techniques on this dataset.

# %%
yearly_sales = video.groupby('Year')['Global_Sales'].sum().sort_index()
plt.figure(figsize=(12, 6))
plt.plot(yearly_sales.index, yearly_sales.values, marker='o', linestyle='-', color='green')
plt.title('Total Global Sales by Year')
plt.xlabel('Year')
plt.ylabel('Global Sales (in millions)')
plt.xticks(rotation=45)
plt.grid()
plt.tight_layout()
plt.show()
