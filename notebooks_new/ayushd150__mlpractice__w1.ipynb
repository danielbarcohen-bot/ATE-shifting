# %%
import pandas

# %% [markdown]
# filtering data

# %%
df.head()
df.tail()

df[df['Category']=='electronics']

df[(df['category']=='clothing')&(df['Poductname']=='shoes')]

# %% [markdown]
# 29/10

# %%
iris = load_iris()
type(iris) #bunch object - multiple things acted together
# as_frame = true, datafrmae object or with the foll:-
iris.data
iris.feature_names #names of columns

# %%
onehotEncoder

pd.get_dummies
