# %%
setwd("/nfs/team297/bs16/current_projects/kidney_glomTI_response")
suppressPackageStartupMessages(source("https://raw.githubusercontent.com/bjstewart1/helpful_singlecell/main/functions.R"))
ad <- import("anndata")
sc <- import("scanpy")
library(GenotypeMixtures)
# Out:
# Warning message:
# “The `size` argument of `element_rect()` is deprecated as of ggplot2 3.4.0.
# ℹ Please use the `linewidth` argument instead.”

# %%
setwd("~/lustre/scratch126/cellgen/clatworthy/bs16/kidney_glomTI_response/seq_data")
#10X3p
seq_inventory = read.csv("~/nfs/team297/bs16/sample_donor_data/sequencing_inventory.csv")
seq_inventory = seq_inventory[seq_inventory$experiment %in% "10X_3'_V3", ]
tissue_idx = seq_inventory$tissue %in% c('spleen_lymphoid_single_cell_suspension', 'spleen_myeloid_single_cell_suspension',
                                 'TI_compartment_single_cell_suspension', 'TI_compartment_single_cell_suspension_AND_Glomerulus_single_cell_suspension',
                                 'kidney_single_cell_suspension', 'Glomerulus_single_cell_suspension')
seq_inventory = seq_inventory[tissue_idx, ]
#remove perfusion
exclude_idx = seq_inventory$sequencing_sample_name %in% grep('10X_LPS_perfusion_sc', seq_inventory$sequencing_sample_name, value = TRUE)
seq_inventory = seq_inventory[!exclude_idx, ]
seq_inventory$irods_ID <- gsub(" ", "", seq_inventory$irods_ID)
#keep the depth samples - we will do these later because they are tricky and require supervised rerun of souporcell
#remove poorQC samples
seq_inventory = seq_inventory[!seq_inventory$poor_QC, ]
#copy
multiplex_design = seq_inventory

# %%
perfusion_kidneys = c("K288", "K287", "K281", "K290", "K289", "K282", "K283")
multiplex_design = multiplex_design[grep(paste(perfusion_kidneys, collapse = "|"), multiplex_design$donor), ]

# %%
#get channels
channels <- multiplex_design$sanger_ID
#get the correct directory 
seq_dir = multiplex_design$`10xDIR`
#reset some of the directory names names
seq_dir[seq_dir == '10x3p'] = '10X_3p'
seq_dir[seq_dir == '10xATAC'] = '10X_snATACseq'
seq_dir[seq_dir == '10x_multiome'] = '10X_multiome'
#then build a multiplexing matrix
channel_donors <- strsplit(multiplex_design$donor, "_")
names(channel_donors) <- multiplex_design$sanger_ID
donors <- unique(unlist(channel_donors))
multiplexing_mat <- do.call(rbind, lapply(names(channel_donors), function(i){
  donors %in% channel_donors[[i]]*1
}))
colnames(multiplexing_mat) <- donors
rownames(multiplexing_mat) <- names(channel_donors)

# %%
options(repr.plot.width = 8, repr.plot.height = 8)
plot_experimental_design(multiplexing_mat)
# Out:
# Using channel as id variables
# plot without title

# %%
#get the locations of the files ####
dirs <- multiplex_design[match(multiplex_design$sanger_ID, rownames(multiplexing_mat)), "10xDIR"]
locations <- data.frame("channel" = rownames(multiplexing_mat), 
                        "SOC_location" = file.path("/lustre/scratch126/cellgen/clatworthy/bs16/kidney_glomTI_response/seq_data/10X_3p/SOC", multiplex_design$irods_ID, "SOC_common_variants"))

# %%
#make multiplexing mat into a donor mat
multiplexing_mat = data.frame(multiplexing_mat)
multiplexing_mat$donor1 = multiplexing_mat[, 'K281']
multiplexing_mat$donor2 = rowSums(multiplexing_mat[, c('K282', 'K283')])
multiplexing_mat$donor3 = rowSums(multiplexing_mat[, c('K287', 'K288')])
multiplexing_mat$donor4 = rowSums(multiplexing_mat[, c('K289', 'K290')])
multiplexing_mat = multiplexing_mat[, -c(1:7)]

# %%
multiplexing_mat
# Out:
#                    donor1 donor2 donor3 donor4
# WSSS_A_KID11165952 1      0      0      0
# WSSS_A_KID11165953 1      0      0      0
# WSSS_A_KID11165954 0      1      0      0
# WSSS_A_KID11165955 0      1      0      0
# WSSS_A_KID11165956 0      1      0      0
# WSSS_A_KID11165957 0      1      0      0
# KID_CZI11986216    0      0      1      1
# KID_CZI11986217    0      0      1      1
# KID_CZI11986218    1      0      0      1
# KID_CZI11986219    0      0      1      1
# KID_CZI11986220    1      0      1      0
# KID_CZI12929931    0      1      1      1
# KID_CZI12929932    0      1      1      1
# KID_CZI12929933    0      1      1      1
# KID_CZI12929934    0      1      1      1

# %%
options(repr.plot.width = 8, repr.plot.height = 8)
plot_experimental_design(multiplexing_mat)
# Out:
# Using channel as id variables
# plot without title

# %%
genotype_clustering_output <- construct_genotype_cluster_graph(experimental_design = multiplexing_mat, 
                                                               file_locations = locations, ncounts  = 10)
# Out:
# checking files
#   |                                                                      |   0%
# reading in VCF files
#
#
#    *****       ***   vcfR   ***       *****
#    This is vcfR 1.15.0
#      browseVignettes('vcfR') # Documentation
#      citation('vcfR') # Citation
#    *****       *****      *****       *****
#   |======================================================================| 100%
# the membership graph is a collection of complete subgraphs as expected

# %%
genotype_clustering_output$graph_plot
# Out:
# plot without title

# %%
cluster_mapping <- membership_map(experimental_design = multiplexing_mat,
                                  graph_output =  genotype_clustering_output)

# %%
cell_assignments <- cells_to_genotypes(SOC_locations = locations, 
                                       membership_mat =cluster_mapping)

# %%
head(cell_assignments)
# Out:
#   barcode            status  assignment channel            genotype
# 1 AAACCCAAGCTCGTGC-1 singlet 0          WSSS_A_KID11165952 donor1
# 2 AAACCCAAGGCAGGGA-1 singlet 0          WSSS_A_KID11165952 donor1
# 3 AAACCCACACGGGTAA-1 singlet 0          WSSS_A_KID11165952 donor1
# 4 AAACCCACACTAGGCC-1 singlet 0          WSSS_A_KID11165952 donor1
# 5 AAACCCACAGAACTAA-1 singlet 0          WSSS_A_KID11165952 donor1
# 6 AAACCCACAGCCCACA-1 singlet 0          WSSS_A_KID11165952 donor1
#   SOC_cluster
# 1 WSSS_A_KID11165952_0
# 2 WSSS_A_KID11165952_0
# 3 WSSS_A_KID11165952_0
# 4 WSSS_A_KID11165952_0
# 5 WSSS_A_KID11165952_0
# 6 WSSS_A_KID11165952_0

# %%
table(cell_assignments$genotype, cell_assignments$channel)
# Out:
#
#                 KID_CZI11986216 KID_CZI11986217 KID_CZI11986218 KID_CZI11986219
#   donor1                      0               0            1777               0
#   donor1/donor3               0               0               0               0
#   donor1/donor4               0               0              30               0
#   donor2                      0               0               0               0
#   donor2/donor3               0               0               0               0
#   donor2/donor4               0               0               0               0
#   donor3                   5432            4438               0             534
#   donor3/donor1               0               0               0               0
#   donor3/donor2               0               0               0               0
#   donor3/donor4            1543              97               0              18
#   donor4                   8981            2684            1192            2889
#   donor4/donor1               0               0              20               0
#   donor4/donor2               0               0               0               0
#   donor4/donor3            2127             112               0              45
#
#                 KID_CZI11986220 KID_CZI12929931 KID_CZI12929932 KID_CZI12929933
#   donor1                    387               0               0               0
#   donor1/donor3               4               0               0               0
#   donor1/donor4               0               0               0               0
#   donor2                      0             568            1435             651
#   donor2/donor3               0               6              87              12
#   donor2/donor4               0              15              91              13
#   donor3                   1647             150            1368            1297
#   donor3/donor1              10               0               0               0
#   donor3/donor2               0              12              37              16
#   donor3/donor4               0               2              20              24
#   donor4                      0            1265            2428            4060
#   donor4/donor1               0               0               0               0
#   donor4/donor2               0              19              70              80
#   donor4/donor3               0              13              56             121
#
#                 KID_CZI12929934 WSSS_A_KID11165952 WSSS_A_KID11165953
#   donor1                      0               4750               4101
#   donor1/donor3               0                  0                  0
#   donor1/donor4               0                  0                  0
#   donor2                   1679                  0                  0
#   donor2/donor3              60                  0                  0
#   donor2/donor4              61                  0                  0
#   donor3                   2663                  0                  0
#   donor3/donor1               0                  0                  0
#   donor3/donor2              66                  0                  0
#   donor3/donor4             111                  0                  0
#   donor4                   3035                  0                  0
#   donor4/donor1               0                  0                  0
#   donor4/donor2              99                  0                  0
#   donor4/donor3             107                  0                  0
#
#                 WSSS_A_KID11165954 WSSS_A_KID11165955 WSSS_A_KID11165956
#   donor1                         0                  0                  0
#   donor1/donor3                  0                  0                  0
#   donor1/donor4                  0                  0                  0
#   donor2                      3345               2139               1184
#   donor2/donor3                  0                  0                  0
#   donor2/donor4                  0                  0                  0
#   donor3                         0                  0                  0
#   donor3/donor1                  0                  0                  0
#   donor3/donor2                  0                  0                  0
#   donor3/donor4                  0                  0                  0
#   donor4                         0                  0                  0
#   donor4/donor1                  0                  0                  0
#   donor4/donor2                  0                  0                  0
#   donor4/donor3                  0                  0                  0
#
#                 WSSS_A_KID11165957
#   donor1                         0
#   donor1/donor3                  0
#   donor1/donor4                  0
#   donor2                      2565
#   donor2/donor3                  0
#   donor2/donor4                  0
#   donor3                         0
#   donor3/donor1                  0
#   donor3/donor2                  0
#   donor3/donor4                  0
#   donor4                         0
#   donor4/donor1                  0
#   donor4/donor2                  0
#   donor4/donor3                  0

# %%
#then make a dataframe of stimulation kidney anatomy and channel
table(cell_assignments$channel)
# Out:
#    KID_CZI11986216    KID_CZI11986217    KID_CZI11986218    KID_CZI11986219
#              18083               7331               3019               3486
#    KID_CZI11986220    KID_CZI12929931    KID_CZI12929932    KID_CZI12929933
#               2048               2050               5592               6274
#    KID_CZI12929934 WSSS_A_KID11165952 WSSS_A_KID11165953 WSSS_A_KID11165954
#               7881               4750               4101               3345
# WSSS_A_KID11165955 WSSS_A_KID11165956 WSSS_A_KID11165957
#               2139               1184               2565

# %%
#now we read these back to the tissue
idx_df =  data.frame(do.call(rbind, list(
c("WSSS_A_KID11165952", "K281", "GLOM", "donor1"),
c("WSSS_A_KID11165953", "K281", "TI", "donor1"),
c("WSSS_A_KID11165954", "K283", "GLOM", "donor2"),
c("WSSS_A_KID11165955", "K283", "TI", "donor2"),
c("WSSS_A_KID11165956", "K282", "GLOM", "donor2"),
c("WSSS_A_KID11165957", "K282", "TI", "donor2"),
c("KID_CZI11986216", "K287", "GLOM", "donor3"),
c("KID_CZI11986216", "K289", "GLOM", "donor4"),
c("KID_CZI11986217", "K287", "TI", "donor3"),
c("KID_CZI11986217", "K289", "TI", "donor4"),
c("KID_CZI11986218", "K281", "TI", "donor1"),
c("KID_CZI11986218", "K290", "GLOM", "donor4"),
c("KID_CZI11986219", "K288", "TI", "donor3"),
c("KID_CZI11986219", "K290", "TI", "donor4"),
c("KID_CZI11986220", "K281", "GLOM", "donor1"),
c("KID_CZI11986220", "K288", "GLOM", "donor3"),
    
c("KID_CZI12929931", "K283", "GLOM", "donor2"),
c("KID_CZI12929931", "K288", "GLOM", "donor3"),
c("KID_CZI12929931", "K290", "GLOM", "donor4"),

c("KID_CZI12929932", "K283", "TI", "donor2"),
c("KID_CZI12929932", "K288", "TI", "donor3"),
c("KID_CZI12929932", "K290", "TI", "donor4"),

c("KID_CZI12929933", "K282", "GLOM", "donor2"),
c("KID_CZI12929933", "K287", "GLOM", "donor3"),
c("KID_CZI12929933", "K289", "GLOM", "donor4"),

c("KID_CZI12929934", "K282", "TI", "donor2"),
c("KID_CZI12929934", "K287", "TI", "donor3"),
c("KID_CZI12929934", "K289", "TI", "donor4")
)))

# %%
cell_assignments$tissue = NA
for(i in rownames(idx_df)){
    ch = idx_df[i, 1]
    don = idx_df[i, 4]
    cell_assignments[cell_assignments$channel %in% ch & cell_assignments$genotype %in% don, "tissue"] = idx_df[i, 3]
    cell_assignments[cell_assignments$channel %in% ch & cell_assignments$genotype %in% don, "kidney"] = idx_df[i, 2]

    }

# %%
table(cell_assignments$tissue, cell_assignments$kidney)
table(cell_assignments$tissue, cell_assignments$genotype)
table(cell_assignments$kidney, cell_assignments$genotype)
# Out:
#
#         K281  K282  K283  K287  K288  K289  K290
#   GLOM  5137  1835  3913  6729  1797 13041  2457
#   TI    5878  4244  3574  7101  1902  5719  5317
#
#        donor1 donor1/donor3 donor1/donor4 donor2 donor2/donor3 donor2/donor4
#   GLOM   5137             0             0   5748             0             0
#   TI     5878             0             0   7818             0             0
#
#        donor3 donor3/donor1 donor3/donor2 donor3/donor4 donor4 donor4/donor1
#   GLOM   8526             0             0             0  15498             0
#   TI     9003             0             0             0  11036             0
#
#        donor4/donor2 donor4/donor3
#   GLOM             0             0
#   TI               0             0
#
#        donor1 donor1/donor3 donor1/donor4 donor2 donor2/donor3 donor2/donor4
#   K281  11015             0             0      0             0             0
#   K282      0             0             0   6079             0             0
#   K283      0             0             0   7487             0             0
#   K287      0             0             0      0             0             0
#   K288      0             0             0      0             0             0
#   K289      0             0             0      0             0             0
#   K290      0             0             0      0             0             0
#
#        donor3 donor3/donor1 donor3/donor2 donor3/donor4 donor4 donor4/donor1
#   K281      0             0             0             0      0             0
#   K282      0             0             0             0      0             0
#   K283      0             0             0             0      0             0
#   K287  13830             0             0             0      0             0
#   K288   3699             0             0             0      0             0
#   K289      0             0             0             0  18760             0
#   K290      0             0             0             0   7774             0
#
#        donor4/donor2 donor4/donor3
#   K281             0             0
#   K282             0             0
#   K283             0             0
#   K287             0             0
#   K288             0             0
#   K289             0             0
#   K290             0             0

# %%
table(cell_assignments$tissue)
# Out:
#  GLOM    TI
# 34909 33735

# %%
setwd("~/lustre/scratch126/cellgen/clatworthy/bs16/kidney_glomTI_response/genotypes")

saveRDS(cluster_mapping, "perfusion_cluster_mapping.RDS")
saveRDS(cell_assignments, "perfusion_cell_assignments.RDS")
saveRDS(genotype_clustering_output, "perfusion_genotype_clustering_output.RDS")

# %%
#get ambients
ambient <- unlist(lapply(locations$SOC_location, function(x){
  amb <- read.table(file.path(x, 'ambient_rna.txt'), check.names = FALSE)
  amb <- amb[, 5]
  amb <- as.numeric(gsub("%", "", amb))/100
  return(amb)}))
names(ambient) <- locations$channel
saveRDS(ambient, "perfusion_ambient_proportions.RDS")
# Out:
# Warning message in read.table(file.path(x, "ambient_rna.txt"), check.names = FALSE):
# “incomplete final line found by readTableHeader on '/lustre/scratch126/cellgen/clatworthy/bs16/kidney_glomTI_response/seq_data/10X_3p/SOC/cellranger700_count_41742_WSSS_A_KID11165952_GRCh38-2020-A/SOC_common_variants/ambient_rna.txt'”
# Warning message in read.table(file.path(x, "ambient_rna.txt"), check.names = FALSE):
# “incomplete final line found by readTableHeader on '/lustre/scratch126/cellgen/clatworthy/bs16/kidney_glomTI_response/seq_data/10X_3p/SOC/cellranger700_count_41742_WSSS_A_KID11165953_GRCh38-2020-A/SOC_common_variants/ambient_rna.txt'”
# Warning message in read.table(file.path(x, "ambient_rna.txt"), check.names = FALSE):
# “incomplete final line found by readTableHeader on '/lustre/scratch126/cellgen/clatworthy/bs16/kidney_glomTI_response/seq_data/10X_3p/SOC/cellranger700_count_41742_WSSS_A_KID11165954_GRCh38-2020-A/SOC_common_variants/ambient_rna.txt'”
# Warning message in read.table(file.path(x, "ambient_rna.txt"), check.names = FALSE):
# “incomplete final line found by readTableHeader on '/lustre/scratch126/cellgen/clatworthy/bs16/kidney_glomTI_response/seq_data/10X_3p/SOC/cellranger700_count_41742_WSSS_A_KID11165955_GRCh38-2020-A/SOC_common_variants/ambient_rna.txt'”
# Warning message in read.table(file.path(x, "ambient_rna.txt"), check.names = FALSE):
# “incomplete final line found by readTableHeader on '/lustre/scratch126/cellgen/clatworthy/bs16/kidney_glomTI_response/seq_data/10X_3p/SOC/cellranger700_count_41742_WSSS_A_KID11165956_GRCh38-2020-A/SOC_common_variants/ambient_rna.txt'”
# Warning message in read.table(file.path(x, "ambient_rna.txt"), check.names = FALSE):
# “incomplete final line found by readTableHeader on '/lustre/scratch126/cellgen/clatworthy/bs16/kidney_glomTI_response/seq_data/10X_3p/SOC/cellranger700_count_41742_WSSS_A_KID11165957_GRCh38-2020-A/SOC_common_variants/ambient_rna.txt'”
# Warning message in read.table(file.path(x, "ambient_rna.txt"), check.names = FALSE):
# “incomplete final line found by readTableHeader on '/lustre/scratch126/cellgen/clatworthy/bs16/kidney_glomTI_response/seq_data/10X_3p/SOC/cellranger700_count_43617_KID_CZI11986216_GRCh38-2020-A/SOC_common_variants/ambient_rna.txt'”
# Warning message in read.table(file.path(x, "ambient_rna.txt"), check.names = FALSE):
# “incomplete final line found by readTableHeader on '/lustre/scratch126/cellgen/clatworthy/bs16/kidney_glomTI_response/seq_data/10X_3p/SOC/cellranger700_count_43617_KID_CZI11986217_GRCh38-2020-A/SOC_common_variants/ambient_rna.txt'”
# Warning message in read.table(file.path(x, "ambient_rna.txt"), check.names = FALSE):
# “incomplete final line found by readTableHeader on '/lustre/scratch126/cellgen/clatworthy/bs16/kidney_glomTI_response/seq_data/10X_3p/SOC/cellranger700_count_43617_KID_CZI11986218_GRCh38-2020-A/SOC_common_variants/ambient_rna.txt'”
# Warning message in read.table(file.path(x, "ambient_rna.txt"), check.names = FALSE):
# “incomplete final line found by readTableHeader on '/lustre/scratch126/cellgen/clatworthy/bs16/kidney_glomTI_response/seq_data/10X_3p/SOC/cellranger700_count_43617_KID_CZI11986219_GRCh38-2020-A/SOC_common_variants/ambient_rna.txt'”
# Warning message in read.table(file.path(x, "ambient_rna.txt"), check.names = FALSE):
# “incomplete final line found by readTableHeader on '/lustre/scratch126/cellgen/clatworthy/bs16/kidney_glomTI_response/seq_data/10X_3p/SOC/cellranger700_count_43617_KID_CZI11986220_GRCh38-2020-A/SOC_common_variants/ambient_rna.txt'”
# Warning message in read.table(file.path(x, "ambient_rna.txt"), check.names = FALSE):
# “incomplete final line found by readTableHeader on '/lustre/scratch126/cellgen/clatworthy/bs16/kidney_glomTI_response/seq_data/10X_3p/SOC/cellranger700_count_45058_KID_CZI12929931_GRCh38-2020-A/SOC_common_variants/ambient_rna.txt'”
# Warning message in read.table(file.path(x, "ambient_rna.txt"), check.names = FALSE):
# “incomplete final line found by readTableHeader on '/lustre/scratch126/cellgen/clatworthy/bs16/kidney_glomTI_response/seq_data/10X_3p/SOC/cellranger700_count_45058_KID_CZI12929932_GRCh38-2020-A/SOC_common_variants/ambient_rna.txt'”
# Warning message in read.table(file.path(x, "ambient_rna.txt"), check.names = FALSE):
# “incomplete final line found by readTableHeader on '/lustre/scratch126/cellgen/clatworthy/bs16/kidney_glomTI_response/seq_data/10X_3p/SOC/cellranger700_count_45058_KID_CZI12929933_GRCh38-2020-A/SOC_common_variants/ambient_rna.txt'”
# Warning message in read.table(file.path(x, "ambient_rna.txt"), check.names = FALSE):
# “incomplete final line found by readTableHeader on '/lustre/scratch126/cellgen/clatworthy/bs16/kidney_glomTI_response/seq_data/10X_3p/SOC/cellranger700_count_45058_KID_CZI12929934_GRCh38-2020-A/SOC_common_variants/ambient_rna.txt'”

# %%
hist(ambient, breaks = 20)
# Out:
# Plot with title “Histogram of ambient”
