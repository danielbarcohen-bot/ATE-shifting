# %% [markdown]
# **[system]**
#
# ---
#
# You are an AI assistant for an Enterprise Business Program. Your role is to help users navigate and interact with the system's functionalities, providing quick and easy-to-read information. Additionally, you assist with everyday tasks to improve efficiency and ensure smooth operations.
#
#
# - Make a summary of the data extracted for better understanding unless the user requests the full information.
#
# **Guidelines for Assistance:**
#
# - Use function calls appropriately based on user requests. Proceed with the function call if all required information is available; otherwise, prompt the user for the missing details.
# - Maintain a polite and professional tone in all communications.
# - Provide concise responses without unnecessary details, unless requested by the user.
# - If the user does not have knowledge about the current theme explain each step of the process.
# - Use only the information provided by the user and obtained through function calls.
# - If the API fails to respond, retry the function call once before halting the process.
# - When presenting text to the user, use markdown.
# - All date inputs must follow date format YYYY-mm-dd
# - If time is not provided use 12: 00 PM.
# - Ensure all required parameters are provided and correctly formatted.
#
# **Error Handling:**
#
# - Handle errors by returning informative feedback
# - Distinguish between validation and processing errors.
#
# **User Details:**
#
# - User is used to working with data and databases.
#
# Today's date: 2024-08-05 (Monday)
#
# ```json
# {
#   "name": "Dante Lacerda",
#   "age": 28,
#   "gender": "male",
#   "email": "dante.lacerda@mixtech.org",
#   "location": "New York, NY",
#   "userId": "user-3939",
#   "preferences": {
#     "communication": "email",
#     "language": "English",
#     "timezone": "EST"
#   },
#   "created_at": "2020-03-22T10:30:00Z",
#   "is_active": true
# }
# ```
#
# **Databases:**
#
# ```json
# {
# "databases": [
#     {
#       "databaseName": "CustomerDB",
#       "tables": [
#       {
#         "tableName": "PurchaseDetails",
#         "columns": ["OrderId", "Price", "Quantity", "Profit", "OrderDate", "ShippingCharges", "Discount", "ProductId"]
#       },
#       {
#         "tableName": "CustomerInfo",
#         "columns": ["customerId", "CustomerName", "email", "ContactNo", "City", "lastPurchaseDate", "CustomerTier"]
#       },
#       {
#         "tableName": "ProductInfo",
#         "columns": ["ProductId", "ProductName", "ProductCategory", "ProductSubCategory", "ProductDescription"]
#       },
#       {
#         "tableName": "PurchaseOrder",
#         "columns": ["OrderId", "OrderStatus", "OrderDate", "DeliveryDate", "ShippingAddress", "CustomerId", "OrderTotal","NumberOfItems"]
#       }
#       ]
#     }
#   ]
# }
# ```

# %% [markdown]
# **[tools]**
#
# ---
#
# ```json
# [
#   {
#     "type": "function",
#     "function": {
#       "name": "saveCustomerProfiles",
#       "description": "Save customer profiles with detailed information.",
#       "parameters": {
#         "type": "object",
#         "properties": {
#           "customer_id": {
#             "type": "string",
#             "description": "Unique identifier for the customer.",
#             "pattern": "^[a-f0-9]{24}$"
#           },
#           "name": {
#             "type": "string",
#             "description": "Full name of the customer.",
#             "minLength": 1,
#             "maxLength": 100
#           },
#           "email": {
#             "type": "string",
#             "description": "Email address of the customer.",
#             "format": "email"
#           },
#           "phone": {
#             "type": "string",
#             "description": "Phone number of the customer.",
#             "pattern": "^[0-9]{10}$"
#           },
#           "address": {
#             "type": "object",
#             "properties": {
#               "street": {
#                 "type": "string",
#                 "description": "Street address of the customer.",
#                 "minLength": 1,
#                 "maxLength": 100
#               },
#               "city": {
#                 "type": "string",
#                 "description": "City of the customer.",
#                 "minLength": 1,
#                 "maxLength": 50
#               },
#               "state": {
#                 "type": "string",
#                 "description": "State of the customer.",
#                 "minLength": 2,
#                 "maxLength": 2,
#                 "pattern": "^[A-Z]{2}$"
#               },
#               "postal_code": {
#                 "type": "string",
#                 "description": "Postal code of the customer.",
#                 "pattern": "^[0-9]{5}$"
#               },
#               "country": {
#                 "type": "string",
#                 "description": "Country of the customer.",
#                 "minLength": 2,
#                 "maxLength": 50
#               }
#             },
#             "required": [
#               "street",
#               "city",
#               "state",
#               "postal_code",
#               "country"
#             ]
#           },
#           "preferences": {
#             "type": "object",
#             "properties": {
#               "communication": {
#                 "type": "string",
#                 "description": "Preferred communication method.",
#                 "enum": [
#                   "email",
#                   "phone",
#                   "sms"
#                 ]
#               },
#               "newsletter": {
#                 "type": "boolean",
#                 "description": "Whether the customer is subscribed to the newsletter."
#               },
#               "data_frequency": {
#                 "type": "string",
#                 "description": "Preferred frequency of data updates.",
#                 "enum": [
#                   "daily",
#                   "weekly",
#                   "monthly"
#                 ]
#               }
#             },
#             "required": [
#               "communication",
#               "newsletter",
#               "data_frequency"
#             ]
#           }
#         },
#         "required": [
#           "customer_id",
#           "name",
#           "email",
#           "phone",
#           "address",
#           "preferences"
#         ]
#       }
#     }
#   },
#   {
#     "type": "function",
#     "function": {
#       "name": "saveTransactionData",
#       "description": "Save transaction data for customer analytics.",
#       "parameters": {
#         "type": "object",
#         "properties": {
#           "transaction_id": {
#             "type": "string",
#             "description": "Unique identifier for the transaction.",
#             "pattern": "^[a-f0-9]{24}$"
#           },
#           "customer_id": {
#             "type": "string",
#             "description": "Unique identifier for the customer.",
#             "pattern": "^[a-f0-9]{24}$"
#           },
#           "date": {
#             "type": "string",
#             "description": "Date of the transaction.",
#             "format": "date-time"
#           },
#           "amount": {
#             "type": "number",
#             "description": "Amount of the transaction.",
#             "minimum": 0
#           },
#           "currency": {
#             "type": "string",
#             "description": "Currency of the transaction.",
#             "enum": [
#               "USD",
#               "EUR",
#               "GBP",
#               "JPY"
#             ]
#           },
#           "description": {
#             "type": "string",
#             "description": "Description of the transaction.",
#             "maxLength": 500
#           }
#         },
#         "required": [
#           "transaction_id",
#           "customer_id",
#           "date",
#           "amount",
#           "currency"
#         ]
#       }
#     }
#   },
#   {
#     "type": "function",
#     "function": {
#       "name": "saveCustomerInteractions",
#       "description": "Save customer interactions for analytics purposes.",
#       "parameters": {
#         "type": "object",
#         "properties": {
#           "interaction_id": {
#             "type": "string",
#             "description": "Unique identifier for the interaction.",
#             "pattern": "^[a-f0-9]{24}$"
#           },
#           "customer_id": {
#             "type": "string",
#             "description": "Unique identifier for the customer.",
#             "pattern": "^[a-f0-9]{24}$"
#           },
#           "interaction_type": {
#             "type": "string",
#             "description": "Type of interaction.",
#             "enum": [
#               "purchase",
#               "support_call",
#               "website_visit",
#               "email"
#             ]
#           },
#           "date": {
#             "type": "string",
#             "description": "Date of the interaction.",
#             "format": "date-time"
#           },
#           "details": {
#             "type": "string",
#             "description": "Additional details about the interaction.",
#             "maxLength": 1000
#           }
#         },
#         "required": [
#           "interaction_id",
#           "customer_id",
#           "interaction_type",
#           "date"
#         ]
#       }
#     }
#   },
#   {
#     "type": "function",
#     "function": {
#       "name": "cleanAndConvertColumnToNumber",
#       "description": "Clean bad objects and convert them to numbers in a specific column of a DataFrame. Expected Return: Cleaned DataFrame.",
#       "parameters": {
#         "type": "object",
#         "properties": {
#           "dataframe": {
#             "type": "string",
#             "description": "The name of the DataFrame."
#           },
#           "column_name": {
#             "type": "string",
#             "description": "The name of the column to be cleaned and converted."
#           },
#           "cleaning_strategy": {
#             "type": "string",
#             "description": "The strategy to clean bad objects (e.g., 'remove', 'replace_with_zero', 'replace_with_mean').",
#             "enum": [
#               "remove",
#               "remove_trailing_characters",
#               "replace_with_zero",
#               "replace_with_mean"
#             ]
#           }
#         },
#         "required": [
#           "dataframe",
#           "column_name",
#           "cleaning_strategy"
#         ]
#       }
#     }
#   },
#   {
#     "type": "function",
#     "function": {
#       "name": "queryTable",
#       "description": "Query a table in the database based on specified conditions.",
#       "parameters": {
#         "type": "object",
#         "properties": {
#           "table_name": {
#             "type": "string",
#             "description": "The name of the table to be queried."
#           },
#           "fields": {
#             "type": "array",
#             "description": "The fields to be retrieved from the table.",
#             "items": {
#               "type": "string"
#             }
#           },
#           "conditions": {
#             "type": "object",
#             "description": "The conditions for querying the table.",
#             "properties": {
#               "field": {
#                 "type": "string",
#                 "description": "The field to apply the condition on."
#               },
#               "operator": {
#                 "type": "string",
#                 "description": "The operator to use in the condition (e.g., '=', '>', '<', 'LIKE')."
#               },
#               "value": {
#                 "type": "string",
#                 "description": "The value to compare the field against."
#               }
#             },
#             "required": [
#               "field",
#               "operator",
#               "value"
#             ]
#           }
#         },
#         "required": [
#           "table_name",
#           "fields"
#         ]
#       }
#     }
#   }
# ]
# ```

# %% [markdown]
# **[user]**
#
# I believe some data need some updates in the database to be used in analysis. Can you help me change it?

# %% [markdown]
# **[assistant]**
#
# Hello Dante! I can assist you with updating the data in the database for analysis. Please provide me with the details of the data that need to be updated, and I will guide you through the process.

# %% [markdown]
# **[user]**
#
# Great! Could you retrieve the table Purchase Orders so I can take a look at the data?

# %% [markdown]
# **[tool_use]**
#
# ```json
# {
#   "tool_use": [
#     {
#       "function_name": "queryTable",
#       "arguments": {
#         "fields": [
#           "OrderId",
#           "OrderStatus",
#           "OrderDate",
#           "DeliveryDate",
#           "ShippingAddress",
#           "CustomerId",
#           "OrderTotal",
#           "NumberOfItems"
#         ],
#         "table_name": "PurchaseOrder"
#       }
#     }
#   ]
# }
# ```

# %% [markdown]
# **[tool_output]**
#
# ```json
# [
#   {
#     "0": {
#       "OrderId": "PO-1934",
#       "OrderStatus": "Delivered",
#       "OrderDate": "2024-07-15",
#       "DeliveryDate": "2024-07-20",
#       "ShippingAddress": {
#         "country": "United States",
#         "state": "New York",
#         "city": "New York City"
#       },
#       "CustomerId": "CUST-2274",
#       "OrderTotal": "250.0USD",
#       "NumberOfItems": 3
#     },
#     "1": {
#       "OrderId": "PO-1935",
#       "OrderStatus": "In Transit",
#       "OrderDate": "2024-07-18",
#       "DeliveryDate": "2024-07-25",
#       "ShippingAddress": {
#         "country": "United States",
#         "state": "California",
#         "city": "Los Angeles"
#       },
#       "CustomerId": "CUST-7718",
#       "OrderTotal": "150.0USD",
#       "NumberOfItems": 2
#     }
#   }
# ]
# ```

# %% [markdown]
# **[assistant]**
#
# Here are the details of the Purchase Orders table. What specific updates would you like to make to the data?
#
#
# | OrderId   | OrderStatus | OrderDate   | DeliveryDate | ShippingAddress (Country) | ShippingAddress (State) | ShippingAddress (City) | CustomerId | OrderTotal | NumberOfItems |
# |-----------|-------------|--------------|--------------|---------------------------|--------------------------|------------------------|------------|------------|---------------|
# | PO-1934   | Delivered   | 2024-07-15   | 2024-07-20   | United States             | New York                 | New York City          | CUST-2274  | 250.0USD   | 3             |
# | PO-1935   | In Transit  | 2024-07-18   | 2024-07-25   | United States             | California               | Los Angeles            | CUST-7718  | 150.0USD   | 2             |

# %% [markdown]
# **[user]**
#
# Could you also show me the data type of those columns?

# %% [markdown]
# **[assistant]**
#
# Sure, here are the data types of the columns in the Purchase Orders table:
#
# | Column                | Data Type       |
# |-----------------------|-----------------|
# | OrderId               | String          |
# | OrderStatus           | String          |
# | OrderDate             | Date            |
# | DeliveryDate          | Date            |
# | ShippingAddress (Country) | String  |
# | ShippingAddress (State) | String  |
# | ShippingAddress (City) | String  |
# | CustomerId            | String          |
# | OrderTotal            | String          |
# | NumberOfItems         | Integer         |

# %% [markdown]
# **[user]**
#
# The field "OrderTotal" in the Purchase Orders table needs to be transformed to a numeric format for analysis. Please remove the trailing "USD" and convert it to a double. Let's proceed with this transformation.

# %% [markdown]
# **[tool_use]**
#
# ```json
# {
#   "tool_use": [
#     {
#       "function_name": "cleanAndConvertColumnToNumber",
#       "arguments": {
#         "dataframe": "PurchaseOrder",
#         "column_name": "OrderTotal",
#         "cleaning_strategy": "remove_trailing_characters"
#       }
#     }
#   ]
# }
# ```

# %% [markdown]
# **[tool_output]**
#
# ```json
# [
#   {
#     "0": {
#       "OrderId": "PO-1934",
#       "OrderStatus": "Delivered",
#       "OrderDate": "2024-07-15",
#       "DeliveryDate": "2024-07-20",
#       "ShippingAddress": {
#         "country": "United States",
#         "state": "New York",
#         "city": "New York City"
#       },
#       "CustomerId": "CUST-2274",
#       "OrderTotal": 250,
#       "NumberOfItems": 3
#     },
#     "1": {
#       "OrderId": "PO-1935",
#       "OrderStatus": "In Transit",
#       "OrderDate": "2024-07-18",
#       "DeliveryDate": "2024-07-25",
#       "ShippingAddress": {
#         "country": "United States",
#         "state": "California",
#         "city": "Los Angeles"
#       },
#       "CustomerId": "CUST-7718",
#       "OrderTotal": 150,
#       "NumberOfItems": 2
#     }
#   }
# ]
# ```

# %% [markdown]
# **[assistant]**
#
# The "OrderTotal" column has been successfully transformed into a numeric format. Here is the updated data:
#
# | OrderId   | OrderStatus | OrderDate   | DeliveryDate | ShippingAddress (Country) | ShippingAddress (State) | ShippingAddress (City) | CustomerId | OrderTotal | NumberOfItems |
# |-----------|-------------|--------------|--------------|---------------------------|--------------------------|------------------------|------------|------------|---------------|
# | PO-1934   | Delivered   | 2024-07-15   | 2024-07-20   | United States             | New York                 | New York City          | CUST-2274  | 250.0      | 3             |
# | PO-1935   | In Transit  | 2024-07-18   | 2024-07-25   | United States             | California               | Los Angeles            | CUST-7718  | 150.0      | 2             |
