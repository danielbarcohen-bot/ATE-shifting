# %%
import pandas
df = pandas.read_csv("Data.csv")
df.drop(df.columns[0], axis=1, inplace=True)
df
# Out:
#        company       car           tream  kilometer  year       price
# 0        volvo      xc60        r-design      27000  2013          -1
# 1      renault  talisman              e3      40000  2017          -1
# 2        saina        ex              mt          0  1400          -1
# 3      peugeot       206        ir-type2          0  1399          -1
# 4      hyundai    sonata  4cyl-automatic      83000  2015  1270000000
# ...        ...       ...             ...        ...   ...         ...
# 15001   samand        lx           basic      32000  1398   209000000
# 15002  renault     megan         ir-2000     160000  1390   330000000
# 15003  renault  tondar90              at      73000  1396   280000000
# 15004    quick    manual               r          0  1400          -1
# 15005   samand        lx           basic      40000  1397   175000000
#
# [15006 rows x 6 columns]

# %% [markdown]
# ### Q1

# %%
filt = df[(df.company == "peugeot") | (df.company == "hyundai")]
filt.drop_duplicates(subset ="car", inplace = True)
filt
# Out:
# /tmp/ipykernel_3711/739216490.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filt.drop_duplicates(subset ="car", inplace = True)
#       company         car           tream  kilometer  year       price
# 3     peugeot         206        ir-type2          0  1399          -1
# 4     hyundai      sonata  4cyl-automatic      83000  2015  1270000000
# 11    hyundai     santafe     ix45-2400cc     120000  2014          -1
# 14    peugeot         405             glx     199700  1387    85000000
# 17    peugeot         207              mt          0  1399          -1
# 33    peugeot       206sd              v8      25000  1398          -1
# 57    peugeot        2008             NaN      31000  1398   844000000
# 74    hyundai     genesis           coupe      60000  2013  1450000000
# ...

# %% [markdown]
# ### Q2

# %%
filt = df[((df.year <= 2022) & (df.year > 2017)) | ((df.year <= 1400) & (df.year > 1395))]
filt
# Out:
#        company       car       tream  kilometer  year       price
# 2        saina        ex          mt          0  1400          -1
# 3      peugeot       206    ir-type2          0  1399          -1
# 6       shahin         g         NaN          0  1400          -1
# 7       nissan    zamyad  pickup-gas          0  1400          -1
# 8          mvm       x55   excellent          0  1400          -1
# ...        ...       ...         ...        ...   ...         ...
# 15000  hyundai   elantra          ir      24000  1397  1235000000
# 15001   samand        lx       basic      32000  1398   209000000
# 15003  renault  tondar90          at      73000  1396   280000000
# 15004    quick    manual           r          0  1400          -1
# 15005   samand        lx       basic      40000  1397   175000000
#
# [7208 rows x 6 columns]

# %% [markdown]
# ### Q3

# %%
filt = df[(df.company == "peugeot") & (df.car == "206sd")]
filt.tream.describe()

filt.drop_duplicates(filt.drop_duplicates(subset="tream", inplace=True))
filt
# Out:
# /tmp/ipykernel_3711/416910933.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filt.drop_duplicates(filt.drop_duplicates(subset="tream", inplace=True))
#       company    car tream  kilometer  year      price
# 33    peugeot  206sd    v8      25000  1398         -1
# 82    peugeot  206sd    v9     180000  1389         -1
# 1386  peugeot  206sd    v1     196000  1386  115000000
# 1590  peugeot  206sd    v6     180000  1387  114000000
# 6048  peugeot  206sd   v20     270000  1388  100000000
# 6798  peugeot  206sd    v2     225000  1388  134000000

# %% [markdown]
# ### Q4

# %%
tmpDF = df
tmpDF["year"].where(tmpDF["year"] > 1400, tmpDF["year"]+622, inplace = True)
mosaferat = tmpDF.kilometer/(2023-tmpDF.year)
tmpDF["mosaferat"] = mosaferat
tmpDF.loc[tmpDF.mosaferat.idxmax()]
# Out:
# company        samand
# car                lx
# tream           basic
# kilometer      260000
# year             2022
# price              -1
# mosaferat    260000.0
# Name: 13532, dtype: object

# %% [markdown]
# ### Q5

# %%
filt = df[["company", "price"]]
ans = ((filt[(filt.price != -1)]).groupby("company").mean())["price"].idxmax() 
ans
# Out:
# 'maserati'

# %% [markdown]
# ### Q6

# %%
filt = df.car
filt.describe()
# Out:
# count     14885
# unique      303
# top         206
# freq        793
# Name: car, dtype: object

# %% [markdown]
# ### Q7

# %%
filt1 = tmpDF[(tmpDF.car == "206") & (tmpDF.price != -1) & (tmpDF.year >= 2007) & (tmpDF.year <= 2014)]
filt2 = tmpDF[(tmpDF.car == "206") & (tmpDF.price != -1) & (tmpDF.year <= 2022) & (tmpDF.year >= 2015)]
print(abs(filt1.price.mean() - filt2.price.mean()))
# Out:
# 72206503.24743348
