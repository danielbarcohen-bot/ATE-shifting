# %%
{
 "cells": [
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "# Exploratory Data Analysis (EDA)\n",
    "This notebook explores the integrated master dataset for the Smart Loan Recovery System."
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "outputs": [],
   "source": [
    "import pandas as pd\n",
    "import matplotlib.pyplot as plt\n",
    "import seaborn as sns\n",
    "\n",
    "# Load the master dataset\n",
    "df = pd.read_csv('master_dataset.csv')\n",
    "df.head()"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "outputs": [],
   "source": [
    "# Basic info\n",
    "print(df.info())\n",
    "df.describe()"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "outputs": [],
   "source": [
    "# Check for missing values\n",
    "df.isnull().sum()"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "outputs": [],
   "source": [
    "# Distribution of key numeric features\n",
    "numeric_cols = df.select_dtypes(include='number').columns\n",
    "df[numeric_cols].hist(figsize=(15, 10))\n",
    "plt.tight_layout()\n",
    "plt.show()"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "outputs": [],
   "source": [
    "# Correlation heatmap\n",
    "plt.figure(figsize=(12, 8))\n",
    "sns.heatmap(df[numeric_cols].corr(), annot=True, fmt='.2f', cmap='coolwarm')\n",
    "plt.title('Correlation Heatmap')\n",
    "plt.show()"
   ]
  },
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "## Next Steps\n",
    "- Explore relationships between categorical features and outcomes (e.g., default rate by loan type)\n",
    "- Segment analysis (by location, customer segment, etc.)\n",
    "- Feature engineering and model building after EDA\n"
   ]
  }
 ],
 "metadata": {
  "kernelspec": {
   "display_name": "Python 3",
   "language": "python",
   "name": "python3"
  },
  "language_info": {
   "name": "python",
   "version": "3.8"
  }
 },
 "nbformat": 4,
 "nbformat_minor": 2
}
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 13
#       1 {
#       2  "cells": [
#       3   {
#       4    "cell_type": "markdown",
#       5    "metadata": {},
#       6    "source": [
#       7     "# Exploratory Data Analysis (EDA)\n",
#       8     "This notebook explores the integrated master dataset for the Smart Loan Recovery System."
#       9    ]
#      10   },
#      11   {
#      12    "cell_type": "code",
# ---> 13    "execution_count": null,
#      14    "metadata": {},
#      15    "outputs": [],
#      16    "source": [
#      17     "import pandas as pd\n",
#      18     "import matplotlib.pyplot as plt\n",
#      19     "import seaborn as sns\n",
#      20     "\n",
#      21     "# Load the master dataset\n",
#      22     "df = pd.read_csv('master_dataset.csv')\n",
#      23     "df.head()"
#      24    ]
#      25   },
#      26   {
# ...
