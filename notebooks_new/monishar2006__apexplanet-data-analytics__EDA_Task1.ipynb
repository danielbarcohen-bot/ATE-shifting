# %%
print("Hello ApexPlanet")
# Out:
# Hello ApexPlanet

# %%
import pandas as pd
import numpy as np

print("Setup Successful")
# Out:
# Setup Successful

# %%
import os

print(os.getcwd())
# Out:
# c:\apexplanet-data-analytics

# %%
import os

print(os.listdir())
# Out:
# ['analytics_env', 'dashboards', 'data', 'EDA_Task1.ipynb', 'notebooks', 'reports', 'scripts']

# %%
import os

print(os.listdir("data"))
# Out:
# ['processed', 'raw']

# %%
import os

print(os.listdir("data/raw"))
# Out:
# []

# %%
import os

print(os.listdir("data"))
print(os.listdir("data/raw"))
# Out:
# ['processed', 'raw']
# ['raw']

# %%
print(os.listdir("data/raw/raw"))
# Out:
# ['supermarket_sales.csv']

# %%
import pandas as pd

df = pd.read_csv("data/raw/supermarket_sales.csv")
df.head()
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity   Tax 5%     Total       Date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715   1/5/2019
# 1  Electronic accessories       15.28         5   3.8200   80.2200   3/8/2019
# 2      Home and lifestyle       46.33         7  16.2155  340.5255   3/3/2019
# 3       Health and beauty       58.22         8  23.2880  489.0480  1/27/2019
# 4       Sports and travel       86.31         7  30.2085  634.3785   2/8/2019
#
#     Time      Payment    cogs  gross margin percentage  gross income  Rating
# 0  13:08      Ewallet  522.83                 4.761905       26.1415     9.1
# ...

# %%
import os
print(os.listdir("data/raw"))
# Out:
# ['supermarket_sales.csv']

# %%
df.head()
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity   Tax 5%     Total       Date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715   1/5/2019
# 1  Electronic accessories       15.28         5   3.8200   80.2200   3/8/2019
# 2      Home and lifestyle       46.33         7  16.2155  340.5255   3/3/2019
# 3       Health and beauty       58.22         8  23.2880  489.0480  1/27/2019
# 4       Sports and travel       86.31         7  30.2085  634.3785   2/8/2019
#
#     Time      Payment    cogs  gross margin percentage  gross income  Rating
# 0  13:08      Ewallet  522.83                 4.761905       26.1415     9.1
# ...

# %%
df.shape
# Out:
# (1000, 17)

# %%
df.columns
# Out:
# Index(['Invoice ID', 'Branch', 'City', 'Customer type', 'Gender',
#        'Product line', 'Unit price', 'Quantity', 'Tax 5%', 'Total', 'Date',
#        'Time', 'Payment', 'cogs', 'gross margin percentage', 'gross income',
#        'Rating'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Invoice ID               1000 non-null   object
#  1   Branch                   1000 non-null   object
#  2   City                     1000 non-null   object
#  3   Customer type            1000 non-null   object
#  4   Gender                   1000 non-null   object
#  5   Product line             1000 non-null   object
#  6   Unit price               1000 non-null   float64
#  7   Quantity                 1000 non-null   int64
#  8   Tax 5%                   1000 non-null   float64
#  9   Total                    1000 non-null   float64
#  10  Date                     1000 non-null   object
#  11  Time                     1000 non-null   object
#  12  Payment                  1000 non-null   object
#  13  cogs                     1000 non-null   float64
# ...

# %%
df.describe()
# Out:
#         Unit price     Quantity       Tax 5%        Total        cogs  \
# count  1000.000000  1000.000000  1000.000000  1000.000000  1000.00000
# mean     55.672130     5.510000    15.379369   322.966749   307.58738
# std      26.494628     2.923431    11.708825   245.885335   234.17651
# min      10.080000     1.000000     0.508500    10.678500    10.17000
# 25%      32.875000     3.000000     5.924875   124.422375   118.49750
# 50%      55.230000     5.000000    12.088000   253.848000   241.76000
# 75%      77.935000     8.000000    22.445250   471.350250   448.90500
# max      99.960000    10.000000    49.650000  1042.650000   993.00000
#
#        gross margin percentage  gross income      Rating
# count              1000.000000   1000.000000  1000.00000
# mean                  4.761905     15.379369     6.97270
# std                   0.000000     11.708825     1.71858
# min                   4.761905      0.508500     4.00000
# ...

# %% [markdown]
# ## Statistical Summary
#
# The statistical summary provides information about the numerical columns in the dataset.
#
# ### Observations
# - The dataset contains **1000 records**.
# - The average unit price is **55.67**.
# - The average quantity purchased is **5.51** items.
# - The average total sale amount is **322.97**.
# - The maximum total sale recorded is **1042.65**.
# - The minimum total sale is **10.68**.

# %%
df.isnull().sum()
# Out:
# Invoice ID                 0
# Branch                     0
# City                       0
# Customer type              0
# Gender                     0
# Product line               0
# Unit price                 0
# Quantity                   0
# Tax 5%                     0
# Total                      0
# Date                       0
# Time                       0
# Payment                    0
# cogs                       0
# gross margin percentage    0
# gross income               0
# Rating                     0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.drop_duplicates(inplace=True)

# %%
df.columns = df.columns.str.lower()
df.columns = df.columns.str.replace(" ", "_")

df.columns
# Out:
# Index(['invoice_id', 'branch', 'city', 'customer_type', 'gender',
#        'product_line', 'unit_price', 'quantity', 'tax_5%', 'total', 'date',
#        'time', 'payment', 'cogs', 'gross_margin_percentage', 'gross_income',
#        'rating'],
#       dtype='object')

# %%
df["date"] = pd.to_datetime(df["date"])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   invoice_id               1000 non-null   object
#  1   branch                   1000 non-null   object
#  2   city                     1000 non-null   object
#  3   customer_type            1000 non-null   object
#  4   gender                   1000 non-null   object
#  5   product_line             1000 non-null   object
#  6   unit_price               1000 non-null   float64
#  7   quantity                 1000 non-null   int64
#  8   tax_5%                   1000 non-null   float64
#  9   total                    1000 non-null   float64
#  10  date                     1000 non-null   datetime64[ns]
#  11  time                     1000 non-null   object
#  12  payment                  1000 non-null   object
# ...

# %%
Q1 = df["total"].quantile(0.25)
Q3 = df["total"].quantile(0.75)

IQR = Q3 - Q1

lower = Q1 - 1.5 * IQR
upper = Q3 + 1.5 * IQR

outliers = df[(df["total"] < lower) | (df["total"] > upper)]

print(outliers.shape)
# Out:
# (9, 17)

# %%
df = df[(df["total"] >= lower) & (df["total"] <= upper)]

# %%
df["date"] = pd.to_datetime(df["date"])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 991 entries, 0 to 999
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   invoice_id               991 non-null    object
#  1   branch                   991 non-null    object
#  2   city                     991 non-null    object
#  3   customer_type            991 non-null    object
#  4   gender                   991 non-null    object
#  5   product_line             991 non-null    object
#  6   unit_price               991 non-null    float64
#  7   quantity                 991 non-null    int64
#  8   tax_5%                   991 non-null    float64
#  9   total                    991 non-null    float64
#  10  date                     991 non-null    datetime64[ns]
#  11  time                     991 non-null    object
#  12  payment                  991 non-null    object
#  13  cogs                     991 non-null    float64
# ...

# %% [markdown]
# ## Date Conversion
#
# The `date` column was converted from object type to datetime format.

# %%
Q1 = df["total"].quantile(0.25)
Q3 = df["total"].quantile(0.75)

IQR = Q3 - Q1

lower = Q1 - 1.5 * IQR
upper = Q3 + 1.5 * IQR

outliers = df[(df["total"] < lower) | (df["total"] > upper)]

print("Number of outliers:", outliers.shape[0])
# Out:
# Number of outliers: 0

# %%
df = df[(df["total"] >= lower) & (df["total"] <= upper)]

# %% [markdown]
# ## Outlier Detection
#
# The IQR method was used to detect outliers in the `total` column.
#
# ### Observation
#
# Outliers were identified and handled appropriately.

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8,5))
plt.hist(df["total"], bins=20)
plt.title("Distribution of Total Sales")
plt.xlabel("Total Sales")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# ## Observation
#
# Most sales are concentrated between lower and medium values, with fewer high-value transactions.

# %%
import seaborn as sns

plt.figure(figsize=(8,5))
sns.boxplot(x=df["total"])
plt.title("Boxplot of Total Sales")
plt.show()

# %% [markdown]
# ## Observation
#
# The boxplot highlights the spread of total sales and indicates the presence of a few outliers.

# %%
df["gender"].value_counts().plot(kind="bar")

plt.title("Gender Distribution")
plt.xlabel("Gender")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# ## Observation
#
# The number of male and female customers is nearly balanced.

# %%
plt.figure(figsize=(8,5))

sns.scatterplot(data=df, x="gross_income", y="total")

plt.title("Gross Income vs Total Sales")
plt.show()

# %% [markdown]
# ## Observation
#
# Gross income increases as the total sales amount increases, showing a positive relationship.

# %%
plt.figure(figsize=(10,8))

sns.heatmap(
    df.select_dtypes(include="number").corr(),
    annot=True,
    cmap="coolwarm"
)

plt.title("Correlation Heatmap")
plt.show()

# %% [markdown]
# ## Observation
#
# The heatmap shows strong positive correlations between Total, COGS, Tax, and Gross Income.

# %%
df.to_csv("data/processed/cleaned_supermarket_sales.csv", index=False)

# %%
import os
print(os.listdir("data/processed"))
# Out:
# ['cleaned_supermarket_sales.csv']
