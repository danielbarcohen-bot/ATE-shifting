# %%
def clean_script(text):
    """
    Cleans up the script text by removing unnecessary whitespace and
    formatting issues. It replaces the "NEWLINE_TOKEN" with actual newlines
    and removes extra spaces before punctuation marks.
    It also removes leading and trailing whitespace from the entire text.
    Args:
        text (str): The script text to be cleaned.
    Returns:
        str: The cleaned script text.
    """
    import re

    text = text.replace(" NEWLINE_TOKEN ", "\n")
    text = text.replace(" NEWLINE_TOKEN", "\n")
    text = text.replace("NEWLINE_TOKEN ", "\n")

    text = re.sub(r"\s+([.,!?;:])", r"\1", text)

    return text.strip()

# %%
import csv

file = "transformers-aventIQ-50-50.csv"

csv_reader = csv.reader(open(file, "r"), delimiter=";")



for row in csv_reader:
    print(len(row))
    if len(row) == 9:
        seed, generate, reference, bleu, rouge, perplexity, f1, precision, recall = row
        print("=" * 20)
        print(f"Seed:\n{clean_script(seed)}")
        print("-" * 20)
        print(f"Generate:\n{clean_script(generate)}")
        print("-" * 20)
        print(f"Reference:\n{clean_script(reference)}")
        print("-" * 20)
        print(f"BLEU: {bleu}")
        print(f"ROUGE: {rouge}")
        print(f"Perplexity: {perplexity}")
        print(f"F1: {f1}")
        print(f"Precision: {precision}")
        print(f"Recall: {recall}")
    elif len(row) == 8:
        seed, generate, reference, bleu, rouge, f1, precision, recall = row
        print("=" * 20)
        print(f"Seed:\n{clean_script(seed)}")
        print("-" * 20)
        print(f"Generate:\n{clean_script(generate)}")
        print("-" * 20)
        print(f"Reference:\n{clean_script(reference)}")
        print("-" * 20)
        print(f"BLEU: {bleu}")
        print(f"ROUGE: {rouge}")
        print(f"F1: {f1}")
        print(f"Precision: {precision}")
        print(f"Recall: {recall}")
# Out:
# 8
# ====================
# Seed:
# 1
# Delhi flight!
# Sorry, Ma'am.
# Boarding is closed.
# Listen, I know!
# I am so sorry, I got delayed.
# Just do something.
# Please help me.
# Sorry, Ma'am
# --------------------
# Generate:
# .
# Okay.
# What happened?
# My son was playing with his friends.
# My son was playing with his friends.
# The bus came
# --------------------
# Reference:
# .
# You should have been on time.
# I know, I am so sorry!
# I got stuck in traffic.
# You know how it is.
# Just, please! Can you do this?
# Okay, hold on.
# Thank
# --------------------
# BLEU: 0.018169880606443114
# ROUGE: 0.048780483307555446
# F1: 0.5353618264198303
# Precision: 0.5789827704429626
# Recall: 0.49149641394615173
# 8
# ====================
# Seed:
# He 's going to end corruption.
# Gannu is here to rule.
# He 's going to end corruption.
# Gannu is here to rule.
# He 's going to end corruption.
# Gannu is here to rule.
# --------------------
# Generate:
# He 's going to end corruption.
# He 's going to end corruption.
# He 's going to end corruption.
# He 's going to end
# --------------------
# Reference:
# He 's going to end corruption.
# Calm down.
# Please calm down!
# Please calm down!
# This is not just you speaking up.
# It is the entire nation revolting...
# against its pathetic plight.
# But the time
# --------------------
# BLEU: 0.13755725144565087
# ROUGE: 0.39999999680000003
# F1: 0.5211456418037415
# Precision: 0.6328017115592957
# Recall: 0.41333839297294617
# 8
# ====================
# Seed:
# Come on, I 'm open!
# Naty, over here!
# Give me that.
# We were just...
# Pass!
# Here! Over here!
# Is someone else
# gon na turn Priscilla?
# Me, too! I
# --------------------
# Generate:
# 'm over here!
# That 's why we have to go back!
# I ca n't, I don 't want to.
# Is that 'bout the hospital? NEW
# --------------------
# Reference:
# 'm open!
# Come on, I 'm open!
# Pass it!
# Amanda, here!
# How about Wes?
# How 's he doing?
# He 's still Wes.
# He has no friends, really.
# Just kind of on
# --------------------
# BLEU: 0.020132993701444946
# ROUGE: 0.17021276095971044
# F1: 0.46113717555999756
# Precision: 0.38582801818847656
# Recall: 0.5376253724098206
# 8
# ====================
# Seed:
# 1
# Delhi flight!
# Sorry, Ma'am.
# Boarding is closed.
# Listen, I know!
# I am so sorry, I got delayed.
# Just do something.
# Please help me.
# Sorry, Ma'am
# --------------------
# Generate:
# .
# Are you okay?
# No, I am fine.
# Are you alright?
# I am so sorry, I have to go.
# --------------------
# Reference:
# .
# You should have been on time.
# I know, I am so sorry!
# I got stuck in traffic.
# You know how it is.
# Just, please! Can you do this?
# Okay, hold on.
# Thank
# --------------------
# BLEU: 0.0768824933327388
# ROUGE: 0.2926829223319453
# F1: 0.6058740019798279
# Precision: 0.6683292388916016
# Recall: 0.5440975427627563
# 8
# ====================
# Seed:
# He 's going to end corruption.
# Gannu is here to rule.
# He 's going to end corruption.
# Gannu is here to rule.
# He 's going to end corruption.
# Gannu is here to rule.
# --------------------
# Generate:
# He 's going to end corruption.
# Gannu is here to rule.
# He 's going to end corruption.
# Gannu is here to
# --------------------
# Reference:
# He 's going to end corruption.
# Calm down.
# Please calm down!
# Please calm down!
# This is not just you speaking up.
# It is the entire nation revolting...
# against its pathetic plight.
# But the time
# --------------------
# BLEU: 0.1383778927554525
# ROUGE: 0.4102564062064431
# F1: 0.4700651466846466
# Precision: 0.518263578414917
# Recall: 0.4216614067554474
# 8
# ====================
# Seed:
# Come on, I 'm open!
# Naty, over here!
# Give me that.
# We were just...
# Pass!
# Here! Over here!
# Is someone else
# gon na turn Priscilla?
# Me, too! I
# --------------------
# Generate:
# 'm over here!
# We need to talk.
# We need to talk.
# I 'm over here!
# You hear me?
# I 'm
# --------------------
# Reference:
# 'm open!
# Come on, I 'm open!
# Pass it!
# Amanda, here!
# How about Wes?
# How 's he doing?
# He 's still Wes.
# He has no friends, really.
# Just kind of on
# --------------------
# BLEU: 0.023912907684589254
# ROUGE: 0.16666666222222234
# F1: 0.5481718182563782
# Precision: 0.5832499861717224
# Recall: 0.5126055479049683
# 8
# ====================
# Seed:
# 1
# [ ambient music ]
# [ audience applauding ]
# Here in New York,
# there 's a big election tomorrow.
# The city will be choosing
# a new mayor that many...
# [ audience cheering ]... that
# --------------------
# Generate:
# really have a chance
# to change the course of history.
# [ George Washington ]
# I think that 's what we 're gon na get
# from this race. NEWLINE
# --------------------
# Reference:
# many are calling
# `` Not Bill de Blasio. ''
# [ audience laughs ]
# New York will also be electing
# a new city council,
# and there 's some shocking news
# out of that race.
# Manhattan candidate
# Zack Weiner --
# --------------------
# BLEU: 0.011162473364638319
# ROUGE: 0.09999999505000023
# F1: 0.41453659534454346
# Precision: 0.408354789018631
# Recall: 0.4194401204586029
# 8
# ====================
# Seed:
# Moving onto the Hollywood Freeway,
# we have a multiple vehicle...
# multiple injury accident.
# An absolute mess
# from VineStreet to the valley.
# If you 're in it,
# expect a long commute.
# If you 're not,
# --------------------
# Generate:
# expect to be hit by a truck.
# Cruise onto the freeway
# and onto the vineyards.
# Here we go.
# Here. NEW
# --------------------
# Reference:
# seek alternate routes.
# If Dan doesn 't want to do a daily rate,
# we can talk about a weekly rate.
# But I 'm tellin ' you right now,
# I 'm not goin ' below a million.
# --------------------
# BLEU: 0.010468190280679513
# ROUGE: 0.12499999531250018
# F1: 0.34461772441864014
# Precision: 0.4676106572151184
# Recall: 0.22632665932178497
# 8
# ====================
# Seed:
# And I 'll start it up...... and we 'll start generating.
# John has a very special mission in life.
# He is trying to contact aliens.
# It was started by myself.
# My grandfather helped me.
# I lived with
# --------------------
# Generate:
# my grandmother and my great-aunt in a small town
# called Glen Ellyn.
# I joined the military as a 16-year old.
# Then I was raised by my grandfather to
# --------------------
# Reference:
# my grandparents
# in a small cottage in Northern Michigan.
# I started building
# the electronic equipment to make contact
# with whatever might be out there
# beyond the Earth.
# It grew to encompass an entire bedroom.
# That equipment continued to grow.
# --------------------
# BLEU: 0.03746086023756219
# ROUGE: 0.23333332847222235
# F1: 0.3948012590408325
# Precision: 0.38451099395751953
# Recall: 0.40379589796066284
# 8
# ====================
# Seed:
# 1
# 'It is said that Heer and Ranjha
# made TakhtHazaare popular. '
# 'Sohni-Mehiwal made
# river Chenab popular. '
# 'Romeo and Juliet made Italy popular. '
# --------------------
# Generate:
# 'Alfred Hitchcock made
# Hitchcock 's Psycho popular.
# 'Dhavan-Chandniya made
# Tamil cinema popular. '
# 'Somn
# --------------------
# Reference:
# 'But this is not Italy.
# This is Patiala, my city. '
# 'Now even this will become
# popular in the entire world. '
# 'Because of my love story. '
# Laali, what are you doing dear?
# --------------------
# BLEU: 0.007304566769563103
# ROUGE: 0.10256409851413557
# F1: 0.309874027967453
# Precision: 0.3208528459072113
# Recall: 0.2974332869052887
# 8
# ====================
# Seed:
# Pay attention to the sights,
# and not the words.
# Because sounds can
# often be deceptive.
# But sight...
# Sights never lie.
# So the question is not
# what is in front of your eyes.
# The question is
# --------------------
# Generate:
# what
# is hidden within.
# So we must be careful not to
# overload our
# imaginations with silly antics.
# If anything, NEWLINE
# --------------------
# Reference:
# what
# are you looking at?
# David, my brother.
# How are you?
# All good, man.
# Hand it over.
# Next time you got to be here earlier.
# You ca n't keep me waiting like this.
# --------------------
# BLEU: 0.01875922871730228
# ROUGE: 0.07843136770472925
# F1: 0.31494438648223877
# Precision: 0.3341517448425293
# Recall: 0.29439643025398254
# 8
# ====================
# Seed:
# This is my recurring dream
# That I am fIying.... Iike a bird.. in the sky
# Cutting through the cIouds
# And when I am fIying.. I feeI happy
# A happiness that is
# --------------------
# Generate:
# But what is it that keeps me from
# Finishing my day?
# Good morning, Mr. Peterson.
# My name is Saleh.
# And I 'm from
# --------------------
# Reference:
# impossibIe to describe
# A feeIing Iike nothing
# eIse - Unique... wondrous
# But this is not a dream- this is reaI
# The wind that caresses my face
# The sound of g
# --------------------
# BLEU: 0.01356892539961709
# ROUGE: 0.2127659525033953
# F1: 0.19064415991306305
# Precision: 0.23873959481716156
# Recall: 0.14179356396198273
# 8
# ====================
# Seed:
# [ EERIE MUSIC PLAYING ]
# [ KNOCKING ON DOOR ]
# [ LANDLORD ] Father!
# [ KNOCKING ON DOOR ]
# [ LANDLORD ]
# Open the door, Father!
# [
# --------------------
# Generate:
# LANDLORD ]
# Open the door,
# Mom!
# [ LANDLORD ]
# Open the door,
# Mom! NEWLINE
# --------------------
# Reference:
# BANGING ON DOOR ]
# [ LANDLORD ] Father!
# Father!
# [ DOOR RATTLING ]
# [ LANDLORD ] My god!
# [ BANGING ON DOOR ]
# [ LANDLORD
# --------------------
# BLEU: 0.05107854119372
# ROUGE: 0.37499999507812504
# F1: 0.5872476696968079
# Precision: 0.6465878486633301
# Recall: 0.5284031629562378
# 8
# ====================
# Seed:
# Germany broadcasting,
# Germany broadcasting.
# People of Britain,
# greetings from
# the Third Reich.
# This is the voice you
# have learned to fear.
# This is the
# Voice of Terror.
# Again, we bring
# you disaster
# --------------------
# Generate:
# .
# This is the voice of peace.
# This is the voice of hope.
# This is the voice of justice.
# This is the
# --------------------
# Reference:
# ,
# crushing humiliating
# disaster.
# It is folly to
# stand against
# the mighty wraith
# of the Fuhrer.
# Do you need more testimony
# of his invincible might
# to bring you
# to your knees?
# Very well
# --------------------
# BLEU: 0.009688924669592262
# ROUGE: 0.21621621253469692
# F1: 0.4049384593963623
# Precision: 0.4699382185935974
# Recall: 0.3403796851634979
# 9
# ====================
# Seed:
# Thanks for coming early Tommy
# So, what happened this time?
# I splitted up with my girl
# man
# --------------------
# Generate:
# Forget that bitch
# She is n't right
# man she wants me
# to be somebody I 'm not
# All her friends date a
# --------------------
# Reference:
# guy like her
# All the time
# He says he did n't pay me for a ride
# She isnt sure if he paid me
# for a ride NEWLINE_
# --------------------
# BLEU: bunch NEWLINE_TOKEN of college boys and shit NEWLINE_TOKEN That is n't me . NEWLINE_TOKEN I got you . NEWLINE_TOKEN You NEWLINE_TOKEN know what I love about Miami ? NEWLINE_TOKEN Everybody is dirty NEWLINE_TOKEN And if you want NEWLINE_TOKEN to make some money you NEWLINE_TOKEN got to get dirty too .
# ROUGE: 0.01675961784966279
# Perplexity: 0.1568627401922339
# F1: 0.3274058699607849
# Precision: 0.34223851561546326
# Recall: 0.31119421124458313
# 8
# ====================
# Seed:
# Mathematicians
# won the war.
# Mathematicians broke
# the Japanese codes-
# and built the A-bomb.
# Mathematicians...
# like you.
# The stated goal of the Soviets
# is global Communism.
# In medicine
# --------------------
# Generate:
# and in science,
# the goal is to revolutionize
# science and eliminate
# the control of science and technology.
# The goal of this revolution
# --------------------
# Reference:
# or economics,
# in technology or space,
# battle lines are being drawn.
# To triumph,
# we need results-
# publishable,
# applicable results.
# Now who among you
# will be the next Morse?
# The next Einstein?
# --------------------
# BLEU: 0.020820852789200633
# ROUGE: 0.18604650708491086
# F1: 0.41142362356185913
# Precision: 0.4297269582748413
# Recall: 0.39197292923927307
# 8
# ====================
# Seed:
# 1
# [ theme music comes up
# with sound of gushing water ]
# [ sounds of waterfall ]
# Have you been up to the job site?
# I honestly do n't think
# Tuesday is an option.
# I think if we
# --------------------
# Generate:
# go back to the past,
# we should focus on the present day.
# We have four days until Christmas Eve
# before Christmas Eve.
# If we go back to
# --------------------
# Reference:
# do n't get
# it out there Monday...
# So do you want to say
# Monday at noon?
# I love it.
# Okay, have a great weekend.
# Thank you.
# [ whistling ]
# [ sounds of
# --------------------
# BLEU: 0.0116693745445365
# ROUGE: 0.13043477769376202
# F1: 0.3907936215400696
# Precision: 0.3688279390335083
# Recall: 0.4116065800189972
# 8
# ====================
# Seed:
# [ laughing ]
# Your usual.
# With ghost peppers and extra sriracha.
# Hooray! My hot, hot dog.
# [ head whistles ]
# [ burps, panting ]
# Milk will put out that fire
# --------------------
# Generate:
# .
# You always get to keep your hands off me.
# Oh, my God!
# How many times have you just thrown a stone at me?
# - Every
# --------------------
# Reference:
# .
# [ slurps ]
# [ sighs ]
# See you again tomorrow.
# [ laughs ]
# [ pants ] Give it!
# Let go!
# Oh, great! Thanks a lot.
# Look what you did!
# --------------------
# BLEU: 0.029751681526569502
# ROUGE: 0.13636363137396712
# F1: 0.43089842796325684
# Precision: 0.389780730009079
# Recall: 0.4714498519897461
# 8
# ====================
# Seed:
# 1
# [ instrumental music ]
# [ upbeat music ]
# ( Kat ) Once up on a time there
# was a girl who loved Christmas.
# I mean what 's not to love?
# Opening presents
# with her amazing family.
# --------------------
# Generate:
# And when she came home
# to find her bed soaked in snow.
# And her little sister
# was gone before she couldAPBE
# to
# --------------------
# Reference:
# Kissing her totally hot
# boyfriend under the mistletoe.
# But the tinsel on the tree..... she was an insanely-talented
# songwriter.
# Her music videos
# had over a billion views
# and her newest
# --------------------
# BLEU: 0.043428719766126674
# ROUGE: 0.17391303862948973
# F1: 0.34971025586128235
# Precision: 0.3667995035648346
# Recall: 0.3313218355178833
# 8
# ====================
# Seed:
# Brandon. You 're not here
# to play games. Reset time! Sir. Horse stance. Sir. Sir. Sir. -Class dismissed.
# Sir. Good job. All right now, baby.
# Let 's roll. Show us what you
# --------------------
# Generate:
# got.
# Here. Sir. Can you turn around?
# Let 'em roll.
# Here. Ready.
# Come on. Sir. You 've got to keep
# --------------------
# Reference:
# got
# Show us what you got. Whoo! What a way to start
# this thing off. Go, go. Oh, I see y'all. Hey. Lunge toss.
# Y'all gots to top that, baby
# --------------------
# BLEU: 0.023582613949279855
# ROUGE: 0.18604650684694443
# F1: 0.4114567041397095
# Precision: 0.49577057361602783
# Recall: 0.32875290513038635
# 8
# ====================
# Seed:
# - Mr. Vale.
# - Yes.
# I 'm Barbara Watson.
# Yes. Come in.
# Thank you.
# Hmm.
# Ah. May I take your coat?
# No, thank you.
# Uh...
# would you like
# --------------------
# Generate:
# a light switch?
# Would you like that?
# Oh.
# You 'll never forget
# my name.
# Miss Watson, you ' ll
# --------------------
# Reference:
# something to drink?
# No.
# Shall we get started?
# Uh, okay.
# Let 's try it again.
# The same thing?
# Yes.
# And remember...
# fingers curved like a tunnel.
# Okay.
# Do n't
# --------------------
# BLEU: 0.009413771748742252
# ROUGE: 0.04444443986172887
# F1: 0.48153555393218994
# Precision: 0.4863375127315521
# Recall: 0.4756036102771759
# 8
# ====================
# Seed:
# I should have told her everything.
# Mom loved stories like that.
# MY LIFE AS A DOG
# It 's not so bad if you think about it.
# It could have been worse.
# Just think how that poor guy ended up
# --------------------
# Generate:
# with a snake like that in his stomach.
# He didn 't deserve it.
# I 'd tell her everything.
# I didn 't care what she thought. NEWLINE_
# --------------------
# Reference:
# who got a new kidney in Boston.
# He got his name in all the papers,
# but he died just the same.
# And what about Laika, the space dog?
# They put her in a Sputnik
# and sent her
# --------------------
# BLEU: 0.01964657027796928
# ROUGE: 0.22641508938412258
# F1: 0.3769182860851288
# Precision: 0.39428338408470154
# Recall: 0.3583175539970398
# 8
# ====================
# Seed:
# these fields
# were the bloody arena
# for the most terrible
# conflict in human history
# In 1913, an alien
# invasion shook the world
# and hurled it into an
# unimaginable future.
# The next four years
# of ferocious combat
# has forever
# --------------------
# Generate:
# changed
# our history books.
# A band of genetically enhanced
# soldiers have taken over
# the world 's cities,
# taking human form and power NEW
# --------------------
# Reference:
# marked this ground
# as the land of the vanished.
# We were fighting monsters.
# There was life
# beyond our planet.
# It went completely
# against everything
# I 'd been raised to believe.
# I 'm standing feet away
# from this
# --------------------
# BLEU: 0.008709648695908854
# ROUGE: 0.0677966053432925
# F1: 0.42007213830947876
# Precision: 0.4348641633987427
# Recall: 0.40410110354423523
# 8
# ====================
# Seed:
# Have a good day, Mr Quentin.
# Right...
# Shut up, asshole!
# You suck your ice.
# Sun on the beach.
# I do n't give
# a fig.
# You 're talking to me?
# Are you talking to
# --------------------
# Generate:
# me?
# You know what I 'm talking about?
# You know what I 'm talking about?
# I 'm talking about
# the bullshit
# that
# --------------------
# Reference:
# me?
# - Bye, Tony.
# - Bye, Jos.
# See you later.
# Bye.
# Bye, buddy.
# See you later.
# See you later, kids.
# - Your laces, Zo.
# - Never
# --------------------
# BLEU: 0.027481209162944248
# ROUGE: 0.23076922579881665
# F1: 0.2263088971376419
# Precision: 0.1890299916267395
# Recall: 0.2624635100364685
# 8
# ====================
# Seed:
# 1
# Ouch!
# It is every parents wish
# for their daughter
# to arrive to this day
# a day when they come of age.
# You 're now an adult, baby sister
# My fathers last born
# It 's time
# --------------------
# Generate:
# for some rest.
# We all need some rest.
# All your life you have dreamed of becoming a doctor.
# You are responsible for your own health.
# You
# --------------------
# Reference:
# to get married
# Great ancestors.
# Its time to get married now
# Here 's your daughter, Nosipho.
# Today is a big day,
# it 's her coming of age ceremony.
# Please be with her as she
# --------------------
# BLEU: 0.010838041283888367
# ROUGE: 0.1199999952000002
# F1: 0.41306909918785095
# Precision: 0.44875678420066833
# Recall: 0.3766310214996338
# 8
# ====================
# Seed:
# 1
# I made mashed eggplants today.
# No french fries for you.
# Why, mom?
# Yes, no french fries.
# That 's all you want to eat.
# Your teacher 's been complaining
# that you never finish your
# --------------------
# Generate:
# sentence.
# Well, maybe he could.
# And you 're going to get
# to see his grandson 's masterpiece.
# Oh, my God. NEWLINE_
# --------------------
# Reference:
# lunch.
# Either you want french
# fries or those fried smilies.
# I 've told you many times
# not to look at that place.
# But why, mom?
# Are n't you asking too many questions?
# Keep walking.
# --------------------
# BLEU: 0.008933457445570302
# ROUGE: 0.11320754238519067
# F1: 0.43239739537239075
# Precision: 0.47646480798721313
# Recall: 0.38789474964141846
# 8
# ====================
# Seed:
# # My bills are all due
# and my baby needs shoes #
# # And I 'm busted #
# # Cotton is down
# to a quarter a pound #
# # But I 'm busted #
# # Got ta a cow that went dry
# and
# --------------------
# Generate:
# a teddy bear that 's dry
# #
# # I 'm busted #
# # I 'm busted #
# # I 'm busted # NEWLINE_
# --------------------
# Reference:
# a hen that wo n't lay #
# # A big stack ofbills
# that gets bigger each day #
# # The county 's gon na haul
# all my things away #
# # 'Cause I 'm busted #
# # They got the change
# --------------------
# BLEU: 0.05828835501016341
# ROUGE: 0.3333333294671202
# F1: 0.5156679153442383
# Precision: 0.6472275257110596
# Recall: 0.3897925019264221
# 8
# ====================
# Seed:
# Hey, dude. How much coal you have?
# Hey.
# Do you remember me? Yes?
# What is missing your friend? - He is dead.
# What did I tell you?
# It is cold. - Yes, it 's
# --------------------
# Generate:
# warm.
# What do you think you know?
# You are a scientist?
# You have studied physics?
# Yes, but only after you finished school? NEWLINE
# --------------------
# Reference:
# cold.
# And your friend is dead because you did nothing about it.
# What did I tell you?
# What did I tell you?
# When you finally get up off your lazy ass, huh?
# If not, you 're next.
# --------------------
# BLEU: 0.019334304403225835
# ROUGE: 0.12499999513888908
# F1: 0.5077461004257202
# Precision: 0.5687225461006165
# Recall: 0.447195440530777
# 8
# ====================
# Seed:
# Wait a minute.
# Whiskey.
# What is this?
# Oh!
# All right.
# Come on, Spot.
# It 's all right, boy.
# Marshal.
# Come out of there.
# What 's this town?
# --------------------
# Generate:
# The Confederate lines.
# A place that no one wants to live in.
# Stop!
# Stop!
# How old is she?
# She 's
# --------------------
# Reference:
# What?
# Its name.
# Paradise.
# Well, there ai n't
# no more law in Paradise.
# Get out of the light.
# It 's Marshal Webb.
# - How bad is he?
# Oh, Lord.
# He 's
# --------------------
# BLEU: 0.021142796624761533
# ROUGE: 0.2553191441195111
# F1: 0.517198383808136
# Precision: 0.5504423975944519
# Recall: 0.4833509624004364
# 8
# ====================
# Seed:
# 1
# `` Sponsored by the Ministry of the Navy ''
# `` Produced by Shochiku Co., Ltd. ''
# `` MOMOTARO - SACRED SAILORS ''
# `` Completed December 1944 ''
# `` Constructed by Ki
# --------------------
# Generate:
# chiro Hoshino,
# Commander of the 27th Armored Div.... and is now under construction
# at Shichiro 's yard in Ogasawara. NEWLINE_
# --------------------
# Reference:
# ichiro Kumaki ''
# `` Written & Directed by Mitsuyo Seo ''
# `` Shadowgraph by Kenzo Masaoka ''
# `` Music by Yuji Koseki ''
# `` Lyrics by Hachiro Sato ''
# --------------------
# BLEU: 0.015271699436865032
# ROUGE: 0.05263157400277054
# F1: 0.2652626633644104
# Precision: 0.27055564522743225
# Recall: 0.25836697220802307
# 8
# ====================
# Seed:
# # # [ Angelic Choir ]
# [ Male Voices ]
# # In the silence of our souls #
# # O Lord,
# we contemplate Thy peace #
# [ Women ]
# # Free from all the world 's desires #
# # Free of
# --------------------
# Generate:
# all the world 's curses #
# # For Thou art the image of the Father
# # [ Son ]
# [ Guitars ]
# # [ Choir ] NEWLINE
# --------------------
# Reference:
# fear and all anxiety #
# # Ooooh. Ooooh #
# # Ooooh. Ooooh #
# # Ooooh. Ooooh #
# # Ooooh. Ooooh #
# # Ooooh
# --------------------
# BLEU: 0.018719340304984573
# ROUGE: 0.18181817785123974
# F1: 0.1894674003124237
# Precision: 0.25935208797454834
# Recall: 0.1199222207069397
# 8
# ====================
# Seed:
# 1
# [ CHEERS AND APPLAUSE ]
# HOO! HOO! HOO!
# -HOO! HOO! HOO!
# -HOO!
# [ CHEERS AND APPLAUSE
# INTENSIF
# --------------------
# Generate:
# ES ]
# [ LIGHTS WHOOSH ]
# [ LIGHTS WHOOSH ]
# [ LIGHTS WHOOSH ]
# [ OPENING AND CLASHING ] NEWLINE
# --------------------
# Reference:
# Y ]
# HOO! HOO!
# HOO! HOO!
# HOO! HOO! HOO! HOO! HOO!
# [ BEATBOXING ]
# [ MUSIC PLAYS ]
# IF YOU
# --------------------
# BLEU: 0.015728281312164867
# ROUGE: 0.1249999950000002
# F1: 0.46559938788414
# Precision: 0.5322365760803223
# Recall: 0.39959806203842163
# 8
# ====================
# Seed:
# 1
# [ sighs ]
# [ crew member ] 101. Take four.
# [ producer ] Thank you.
# [ man 1 ] Recruiting is everything.
# My name is Jose Sanchez.
# Sorry, I 'm stopping you
# --------------------
# Generate:
# .
# [ siren blaring ]
# [ gasps ]
# [ siren wailing ]
# [ siren wailing ]
# [ s
# --------------------
# Reference:
# because I work forAbercrombie & Fitch.
# I 'm a recruiter. I 'm looking for people
# to work part-time in a store.
# Nothing crazy. Five, ten, 15 hours a week.
# --------------------
# BLEU: 0.006171017401195168
# ROUGE: 0.0689655139595721
# F1: 0.14729949831962585
# Precision: 0.31060031056404114
# Recall: -0.0067918612621724606
# 8
# ====================
# Seed:
# 1
# ( )
# NICOLE: Let go. Let go, let go.
# Let, go, let go.! Let go, let go, let go, let go.! Let go, let go, let go,
# --------------------
# Generate:
# let go.
# It 's all we have.
# It 's all we have.
# It 's all we have.
# What?
# - All
# --------------------
# Reference:
# let go.
# Are you ready to wake up?
# ( )
# NARRATOR: Kurt Gdel once
# wrote in any universe described
# by the theory of relativity,
# time can not exist.
# Its conclusion is that
# if relativity theory is
# --------------------
# BLEU: 0.030528551344733926
# ROUGE: 0.1463414599881024
# F1: 0.4085606038570404
# Precision: 0.47028490900993347
# Recall: 0.34711623191833496
# 8
# ====================
# Seed:
# She 's going to win the race today.
# - You 'll collapse in the fresh air.
# - Tell me how much it costs.
# My little conk.
# I do n't think so, fatty. Get lost.
# Not even the
# --------------------
# Generate:
# wind will cut it.
# No! Not even the sun.
# It won 't do.
# That 's not my sport.
# The wind will chop you down
# --------------------
# Reference:
# Bank of England could afford
# what you 're asking of me, you bastard.
# What is he thinking? Who knows what kind
# of a person he is? So much is happening.
# Half the night wasted with that beer barrel,
# and
# --------------------
# BLEU: 0.009047397795017086
# ROUGE: 0.0769230721893494
# F1: 0.33936426043510437
# Precision: 0.41460350155830383
# Recall: 0.26503631472587585
# 8
# ====================
# Seed:
# [ `` How Lucky '' playing ]
# One, two A one, two, three
# Today I walked down
# The street I used to wander
# Yeah, shook my hand
# And made myself a bet
# There was all these things
# That I don
# --------------------
# Generate:
# 't know
# If I could just get one
# I could bet
# I 'm gon na get one
# I ca n't stop thinking
# 'Cause there 's
# --------------------
# Reference:
# 't think I remember
# Hey, how lucky
# Can one man get?
# I bronzed my shoes and I hun
# 'Em from a rearview mirror
# Bronzed admiration
# In a blind spot of regret
# There was all these things
# --------------------
# BLEU: 0.020780174639624248
# ROUGE: 0.1886792405838378
# F1: 0.25372254848480225
# Precision: 0.28343260288238525
# Recall: 0.22276590764522552
# 8
# ====================
# Seed:
# Modd!
# She went modd!
# Relax, relax, relax...
# He called me out, he got something to show me,
# so I 'll let him have it.
# You 're in my house, baby.
# Laura:
# --------------------
# Generate:
# Hi, Dad.
# - I 'm going to make you some tea.
# - Thank you.
# - It 's good for you.
# You do n't need to
# --------------------
# Reference:
# ... to have to set things and
# remember a sequence.
# Vanessa: Been trying to tell him,
# you know, you ca n't...... you know, your world is fine,
# but you also have to learn
# about other people
# --------------------
# BLEU: 0.020058803741540086
# ROUGE: 0.12765956965142616
# F1: 0.3949146568775177
# Precision: 0.41232195496559143
# Recall: 0.3763110339641571
# 8
# ====================
# Seed:
# Long ago in the Reign of the
# King 's Richard the LionHeart.
# There was a legend known to all.
# That 's a man who stole from the
# rich to feed the poor
# He was known throught out the Reign.
# --------------------
# Generate:
# His victims were...
# his own people.
# A beggar called the Irishman
# the `` Lionheart of Dublin. ''
# And the legend goes that his victims
# --------------------
# Reference:
# As Robin Hood.
# lt is known that he and
# his band of merry men
# Played the evil share of Nottingham.
# And he romanced one heart of maid,
# Marion.
# There was more to their story.
# A tale
# --------------------
# BLEU: 0.023868762531952917
# ROUGE: 0.1568627405305653
# F1: 0.4535815715789795
# Precision: 0.46340808272361755
# Recall: 0.4425962567329407
# 8
# ====================
# Seed:
# 2
# Ew, Mom, I 'm trying
# to eat breakfast.
# Almost done.
# Aw, your mustache
# is really coming in.
# Mom!
# - Phoebe!
# - Ow!
# I 'm bleeding!
# You
# --------------------
# Generate:
# okay?
# - Yes.
# - I don ' t know if it 's a condition
# or not.
# - How long has it been? NEWLINE_
# --------------------
# Reference:
# made me bleed!
# You 'll live. Phoebe!
# Oh! What are you doing?
# Neighbor 's electricity
# is running out of phase.
# - I tied in, bumped us up to 220.
# - Take that off.
# --------------------
# BLEU: 0.018673692412298
# ROUGE: 0.07999999528800027
# F1: 0.3924114406108856
# Precision: 0.4297301769256592
# Recall: 0.3543493151664734
# 8
# ====================
# Seed:
# If you spare my life,
# I 'll live it to the fullest.
# If not, let me see my family.
# Dad, where do people go after they die?
# I do n't know, Melody.
# Dad, what 's a
# --------------------
# Generate:
# proper funeral?
# There are lots of places for you to live.
# So it is with sadness.
# I have no place to go, my sister-in-law. NEWLINE
# --------------------
# Reference:
# ghost?
# Well, some say they 're the dead people
# who ca n't leave those
# who are still alive,
# and they stay behind in this world.
# Some say, ghosts are the imagination
# of those who are alive,
# refusing
# --------------------
# BLEU: 0.008317478306635049
# ROUGE: 0.11320754218583146
# F1: 0.3295527994632721
# Precision: 0.3314726650714874
# Recall: 0.3261585533618927
# 8
# ====================
# Seed:
# Table 4.
# Did Horatiu leave anything? It 's Alice.
# Thanks.
# Horatiu!
# - 400?
# - They 're 350 online.
# - Thanks for checking!
# - What the fuck did you think?
# --------------------
# Generate:
# I checked the auctions, I didn 't think so.
# - What do you know?
# - Nothing at all.
# And what is that?
# - The
# --------------------
# Reference:
# Forget it.
# Hey, Alice!
# - No funny games!
# - Relax!
# - Let me know when youve done it.
# - Done what?
# You little bitch!
# Bye.
# Its my phone, give it back
# --------------------
# BLEU: 0.01180285158319997
# ROUGE: 0.13636363145661173
# F1: 0.46382156014442444
# Precision: 0.43478086590766907
# Recall: 0.4920158088207245
# 8
# ====================
# Seed:
# Come on, boys.
# Hey, Captain, why the haste?
# The city will not vanish.
# It is not the city of Charak he wishes
# to see, but someone who dwells within.
# After a long voyage
# it
# --------------------
# Generate:
# is necessary to return to the original place.
# What purpose in this journey?
# To wander the desert and
# find his victims.
# The original purpose of this voyage
# --------------------
# Reference:
# 's good to stretch one 's legs.
# The only good thing about this port
# is the inn of Abu Jamil.
# I have been dreaming of
# his roasted sheep 's eyes.
# - And I of the eyes of his daughter.
# --------------------
# BLEU: 0.02155281186712992
# ROUGE: 0.24489795428571431
# F1: 0.4104434847831726
# Precision: 0.46313855051994324
# Recall: 0.3576112985610962
# 8
# ====================
# Seed:
# Wait.
# What?
# This.
# Later.
# I wan na smoke.
# I wan na smoke.
# Fine. Smoke.
# Smoke all night.
# Be still.
# Do not turn around.
# Do not turn around.
# You will
# --------------------
# Generate:
# burn my house.
# I will burn you.
# You will burn my house.
# I will burn you.
# You will burn my house. NEWLINE_TO
# --------------------
# Reference:
# not be hurt.
# - Bonjour, Nick.
# - Bonjour, madame.
# Albert.
# Boss, hi.
# - Jean-Claude.
# - So, the trip was good?
# - So, how
# --------------------
# BLEU: 0.014816729550514562
# ROUGE: 0.07999999564800023
# F1: 0.3348008394241333
# Precision: 0.3652406334877014
# Recall: 0.3033031225204468
# 8
# ====================
# Seed:
# AUTUMN SONATA
# Sometimes I watch my wife,
# without her being aware of
# my presence.
# The first time she entered that room,
# she said,
# `` It 's good. I want to be here. ''
# We
# --------------------
# Generate:
# t and prayed together.
# My heartache was permanent.
# The second time,
# she said,
# `` My son will be safe. `` NEWLINE_TO
# --------------------
# Reference:
# 'd met only a few days before,
# at a bishops ' council in Trondheim.
# She was the correspondent
# of a church magazine.
# We met at lunch, and I told her about
# the vicarage here.
# I
# --------------------
# BLEU: 0.020944754666988977
# ROUGE: 0.12499999521701408
# F1: 0.34017863869667053
# Precision: 0.41507211327552795
# Recall: 0.266176700592041
# 8
# ====================
# Seed:
# ( CICADAS CHIRPING )
# ( FLY BUZZING )
# EVANGELIST: ( OVER TV )
# We come together today...
# ( EVANGELIST CONTINUES
# SPEAKING INDISTINCT
# --------------------
# Generate:
# CONVERSATION )
# ( INTENSIFIES )
# ( INTENSIFIES CONTINUE )
# ( INTENSIFIES CONTINUE )
# ( INTELL
# --------------------
# Reference:
# LY OVER TV )
# In dark times such as these,
# we must all remember
# to look
# to the Lord for guidance.
# Submit yourselves,
# then, to God.
# CONGREGATION: Amen.
# Resist the Devil...
# --------------------
# BLEU: 0.0026238458562306303
# ROUGE: 0.06060605803489451
# F1: 0.2397768646478653
# Precision: 0.2605716586112976
# Recall: 0.21750807762145996
# 8
# ====================
# Seed:
# [ music playing ]
# [ music playing ]
# To celebrate his sixth
# wedding anniversary,
# our illustrious
# emperor has decided,
# in his immeasurable mercy, togrant amnesty to all traitors
# to the empire, on one
# --------------------
# Generate:
# condition:
# that all conscientious applicants
# shall be summarily
# expelled from the empire,
# and on the condition that they
# shall await execution by
# --------------------
# Reference:
# condition.
# Return to your family, demand all the rebel leaders
# give up this futile rebellion.
# [ music playing ]
# His Imperial Highness, andher majesty, the Empress.
# Honored friends, onthis, the sixth anniversary
# --------------------
# BLEU: 0.02440529406678539
# ROUGE: 0.1666666618836807
# F1: 0.24255315959453583
# Precision: 0.2825471758842468
# Recall: 0.20159950852394104
# 8
# ====================
# Seed:
# 1
# [ boat engine idles ]
# All right.
# Well, the water looks good.
# I think we 're all set.
# It has n't rained in a while,
# so there should
# be maximum visibility.
# Just follow
# --------------------
# Generate:
# the signs.
# [ sign above water ]
# [ sign below water ]
# [ sign ]
# [ sign ]
# [ sign ] NEWLINE_
# --------------------
# Reference:
# my lead.
# Yeah, right.
# I 'm not the one who wanted
# to quit early last time.
# You follow my lead.
# Oh, I see how it is.
# First person out of the water
# buys drinks tonight.
# --------------------
# BLEU: 0.01082159421754468
# ROUGE: 0.0999999968000001
# F1: 0.24331901967525482
# Precision: 0.32409346103668213
# Recall: 0.16365718841552734
# 8
# ====================
# Seed:
# - Oh, I got it!
# - No way! No way! No way!
# Jeez, Susie,
# you sure pack a load.
# No, you asshole, you made me...
# Duncan,
# you 're in the
# --------------------
# Generate:
# right place.
# You gon na hide your guns.
# You gon na bury your head in the sand.
# And if I see you selling guns to people in
# New Jersey
# --------------------
# Reference:
# way, Duncan.
# - Hey, Duncan.
# - What?
# 'Guys let s fne I `` Go! p ay!
# Come on, guys, let him play.
# - He 'll help, anyway.
# - Think
# --------------------
# BLEU: 0.012842782910783277
# ROUGE: 0.08888888389135831
# F1: 0.26771703362464905
# Precision: 0.2527836859226227
# Recall: 0.2811214327812195
# 8
# ====================
# Seed:
# 1
# ( heart beating )
# ( house creaking )
# ( crying and whimpering )
# ( heels clicking )
# ( door opens )
# ( sniffing )
# ( paper crinkling )
# ( heavy breathing )
# --------------------
# Generate:
# ( sips )
# ( sips )
# ( heavy breathing )
# ( rattling )
# ( sips )
# ( rattling ) NEW
# --------------------
# Reference:
# ( urinating )
# ( softly ): Come on.
# Come on, come on, come on.
# ( whimpering )
# ( shaky breathing )
# ( heels clicking )
# ( sniffing )
# ( toilet
# --------------------
# BLEU: 0.024986788685598407
# ROUGE: 0.22222221777777784
# F1: 0.6165974736213684
# Precision: 0.6708912253379822
# Recall: 0.5626316666603088
# 8
# ====================
# Seed:
# [ ]
# LIVIN ' OUT OF SUITCASES
# MOST OF MY LIFE
# IT DO N'T MATTER MUCH TO ME
# MOVIN ' WITH MY MAMA
# ACROSS THIS FAIR LAND
# WITH OUR
# --------------------
# Generate:
# LIFETIME FAMILY
# THEATER WOULD NOMINUE
# WITH THE DINGS
# AND EASTER THINGS,
# --------------------
# Reference:
# LIVES...
# SHE SAID `` GIRL, YOU 'VE GOT TA
# CHANGE YOUR MIND ''
# IT AI N'T UP TO THEM
# TO SAY
# WHAT YOU 'RE GON NA MAKE
# YOU '
# --------------------
# BLEU: 0.008645078761399716
# ROUGE: 0.05555555111111147
# F1: 0.32075074315071106
# Precision: 0.36687058210372925
# Recall: 0.2740507423877716
# 8
# ====================
# Seed:
# The days
# Of wine and roses
# Laugh and run away
# Like a child at play
# Through the meadowland
# Toward a closing door
# A door marked `` nevermore ''
# That was n't there before
# The lonely night discloses
# --------------------
# Generate:
# A secret
# Of love and victory
# And death and peace
# That whispered in the hearts
# Of the lost
# My sister
# --------------------
# Reference:
# Just a passing breeze
# Filled with memories
# Of the golden smile
# That introduced me to
# The days of wine and roses
# And you
# Wait a minute.
# I got another idea.
# Here. This one.
# She 's
# --------------------
# BLEU: 0.04225805214763228
# ROUGE: 0.12244897506039165
# F1: 0.5036516785621643
# Precision: 0.582277774810791
# Recall: 0.4264162480831146
# 8
# ====================
# Seed:
# Are you scared, Hannes?
# - He 's brave. He 'll make it.
# That 's not true.
# - All of us went up.
# Even Peter, who 's known to shit himself.
# - I do not!
# --------------------
# Generate:
# - You do not believe that.
# We have to go up.
# We have to hide.
# I have to go and fetch the body.
# If the police
# --------------------
# Reference:
# But what will we do
# if he falls off?
# Duck!
# The pendants are at the top.
# If you get it, you 're in.
# Yes, keep going Hannes!
# Shit!
# Great.
# Ah!
# --------------------
# BLEU: 0.023154148050242993
# ROUGE: 0.17021276114078782
# F1: 0.4337267279624939
# Precision: 0.43475449085235596
# Recall: 0.4314521849155426
# 8
# ====================
# Seed:
# `` Celtic '' is in the water,
# Thanks, I needed that,
# This is not a true story,
# except for all the facts,
# America at a crossroads,
# a presidential election
# looms as Black Lives Matter
# --------------------
# Generate:
# marches on Washington,
# the death penalty is no longer just
# a convenient death sentence,
# it 's a moral certainty.
# America is in a crossroads NEWLINE
# --------------------
# Reference:
# protests around the country,
# cry out for justice,
# You 're watching the nightly news
# and tonight we have a special report
# from the ground at one of those protests,
# Terence, over to you,
# I 'm Terence Williams
# --------------------
# BLEU: 0.00923833230435263
# ROUGE: 0.1090909042909093
# F1: 0.3585595488548279
# Precision: 0.38356706500053406
# Recall: 0.33241623640060425
# 8
# ====================
# Seed:
# Stay still, you dirty whore!
# - No!
# Grab her legs!
# - No!
# Will you stay still!
# Now you 're going to enjoy this!
# Watch, watch! Because it 's the
# last thing you 're going
# --------------------
# Generate:
# to see.
# Come on, you filthy whore!
# I 'll take you to the water tower!
# And you 'll see!
# That girl is beautiful! NEW
# --------------------
# Reference:
# to see!
# It 's my turn!
# - No!
# Do n't cry!
# Do n't let them hear you.
# Vanina, do n't let them hear you!
# Let 's get out of here!
# Move it!
# --------------------
# BLEU: 0.0401558614845382
# ROUGE: 0.19512194622248677
# F1: 0.5002184510231018
# Precision: 0.5359136462211609
# Recall: 0.4639523923397064
# 8
# ====================
# Seed:
# 1
# 'In the next one minute my
# dream will be fulfilled. '
# 'This dream came into existence
# along with me. '
# I have done some good, some bad.. '
# '.. and some very bad deeds
# to achieve this
# --------------------
# Generate:
# dream. '
# 'But now, the nightmare begins. '
# 'In the next one minute my
# dream will be fulfilled. '
# 'This dream was a
# --------------------
# Reference:
# dream. '
# 'But I do n't regret any of it. '
# 'Tell me one person in the world.. '
# '.. who has n't done something
# good, something bad.. '
# '.. or something very bad,
# to achieve
# --------------------
# BLEU: 0.04619433814005505
# ROUGE: 0.22222221742222234
# F1: 0.43655088543891907
# Precision: 0.5123300552368164
# Recall: 0.36187732219696045
# 8
# ====================
# Seed:
# Have him call me when he wakes up.
# I love you too.
# None of this
# should 've happened.
# Chief ' shall I clean it?
# It 'll shine. It 's on me.
# I should n't be feeling
# the
# --------------------
# Generate:
# pings of love.
# I need a bath.
# I need to get dressed.
# My coat is lint.
# I need a change of pace. NEW
# --------------------
# Reference:
# way I do.
# Nor thinking what I 'm thinking.
# Everything is...
# Everything is a mess.
# That 's why I 'm trying to do
# the right thing now.
# If anything right can be done.
# Now, go,
# --------------------
# BLEU: 0.010358693448957837
# ROUGE: 0.1777777729777779
# F1: 0.39198803901672363
# Precision: 0.4427357614040375
# Recall: 0.3409852683544159
# 8
# ====================
# Seed:
# 1
# [ panting ]
# ( Ryan ) Holy Fuck.
# So like a car must have crashed
# into that semi or something,
# a bunch of cars.
# ( Kyle ) I wonder if maybe
# something hit that first.
# (
# --------------------
# Generate:
# Ryan ) Yeah.
# ( Drew ) No.
# [ panting ]
# [ sipping heavily ]
# [ gasping ]
# [ sipping
# --------------------
# Reference:
# Jesse ) Is there two semis?
# ( Kyle ) I Do n't know.
# ( Jesse ) You see the one on
# fire there to the left there
# is a big something...
# ( Kyle ) I ca n't even
# --------------------
# BLEU: 0.005463016796703557
# ROUGE: 0.06060605663911872
# F1: 0.3317987024784088
# Precision: 0.44259747862815857
# Recall: 0.22456172108650208
# 8
# ====================
# Seed:
# -- == McEphie == --
# For latest releases visit moviesnipipay website
# It was an ordinary day when Jason
# first laid eyes on Bettina
# the girl who would be his `` Muse ''
# the quote, un
# --------------------
# Generate:
# oading her
# collection of stolen goods and driving her to
# Los Angeles.
# She was nothing but trouble,
# a punk who 'd been
# robbed
# --------------------
# Reference:
# quote - `` girl of his dreams ''.
# Bettina...
# who took his breath away when she moaned
# `` I love you so much, Jason ''
# at the peak of her orgasm
# but not once did Jason ever dream
# that Bett
# --------------------
# BLEU: 0.011009832894747672
# ROUGE: 0.1428571380165818
# F1: 0.29672056436538696
# Precision: 0.3307657539844513
# Recall: 0.26163700222969055
# 8
# ====================
# Seed:
# 1
# You do n't know me...
# unless you know
# about me and Tom Sawyer,
# where we 've been,
# what we 've done together.
# Huckleberry!
# You 'll respect your father, boy.
# - Meow!
# --------------------
# Generate:
# - I 'm a wee bit picky about...
# - I 'm your uncle, don ' t you?
# - I 'm not really picky about NEWLINE_TO
# --------------------
# Reference:
# - Where do you think you 're going?
# Huck, get your ass back in here!
# Meow!
# Tom was the
# closest thing to real family I had.
# He saw a world where we were
# just one adventure away
# --------------------
# BLEU: 0.00860511790550385
# ROUGE: 0.11764705451749341
# F1: 0.24730515480041504
# Precision: 0.26379653811454773
# Recall: 0.22928473353385925
# 8
# ====================
# Seed:
# 1
# I
# you
# how do you do I know that y'all so we 're
# the new tenants
# I miss you sweetness meet back in please
# one before you leave
# thank you so much know some heavy I
# did n't know
# --------------------
# Generate:
# if you were n't there
# to see us
# you know you know
# how do you do I know
# that you NEWLINE_TO
# --------------------
# Reference:
# if I could open by myself
# she was only holding the door I was only
# thank you important you never get out of
# the front row the core front row I ca n't
# even get out the back yes you do n't know
# me because
# --------------------
# BLEU: 0.01759411756448827
# ROUGE: 0.21276595310095073
# F1: 0.33961963653564453
# Precision: 0.4567579925060272
# Recall: 0.22662381827831268
# 8
# ====================
# Seed:
# ( Mac )
# `` April 1865.
# `` Dear Ma and Pa,
# I hope this letter
# finds you well.
# `` I have some good news.
# `` Word is
# the war may be over soon.
# `` I tell you
# --------------------
# Generate:
# , dear
# Pa,
# that your countrymen
# will not be long gone from
# your country.
# Your soldiers will be gone. NEWLINE
# --------------------
# Reference:
# ,
# if there 's one thing
# I 've learnt,
# `` it 's the Travens
# ai n't the only family
# split by this war,
# `` brother against brother.
# `` I just keep fearin ',
# one day I
# --------------------
# BLEU: 0.008964201839745299
# ROUGE: 0.04878048316478331
# F1: 0.3090866208076477
# Precision: 0.3911292552947998
# Recall: 0.22834308445453644
# 8
# ====================
# Seed:
# No luck.
# I 've checked everywhere.
# Something must have come up, Pamela.
# There is nothing to worry about.
# Maybe he is with the D.A.
# Well, it 's about time.
# Your wife is on the
# --------------------
# Generate:
# run.
# Her parents say she is ill.
# They have to find a job.
# They are out of food and shelter.
# I 'm out of money
# --------------------
# Reference:
# phone.
# - Tell her to forget it.
# What 's the matter with you?
# Where have you been?
# Yes, Pam. I 'm listening.
# Why does he do this to me every
# time mother and father are here?
# --------------------
# BLEU: 0.02138208057639821
# ROUGE: 0.17543859167743936
# F1: 0.47560134530067444
# Precision: 0.5036386251449585
# Recall: 0.44674262404441833
# 8
# ====================
# Seed:
# I always knew we
# were a fairly odd family.
# First there was me.
# Too tall. Too skinny.
# Too orange.
# My mum was lovely,
# but not like other mums.
# There was
# something solid about her
# --------------------
# Generate:
# .
# Her eyes
# were like a ruby.
# Her voice was like a ruby on a crystal ball.
# My brother, Liam, used to take her NEWLINE
# --------------------
# Reference:
# .
# Something rectangular,
# busy and unsentimental.
# Her fashion icon was the Queen.
# Dad, well, he was more normal. He always
# seemed to have time on his hands.
# After giving up teaching university
# students on
# --------------------
# BLEU: 0.020086109558733842
# ROUGE: 0.15999999528800013
# F1: 0.42151618003845215
# Precision: 0.4693721532821655
# Recall: 0.37334588170051575
# 8
# ====================
# Seed:
# 1
# Drummer-Crab.
# My name 's Pierre.
# I 'm 50.
# I 'd chosen my own life
# and then...
# I let go
# I 'm afraid of myself.
# I got back in line.
# Cast
# --------------------
# Generate:
# your vote.
# You ca n't have more than one man.
# You ca n't have more than one woman.
# You ca n't have more than one toilet.
# --------------------
# Reference:
# off aft!
# Bearing 215!
# Steady on 215!
# Helm port 5!
# Ahead 2!
# Ahead 2 carried out!
# Bearing 217!
# Helm port 10!
# Capt. Taking over!
# Helm port 25!
# Helm
# --------------------
# BLEU: 0.010072661845381145
# ROUGE: 0.060606055831038036
# F1: 0.1662178784608841
# Precision: 0.0766129419207573
# Recall: 0.2575661838054657
# 8
# ====================
# Seed:
# Hey, you guys, you ca n't
# play in there, Jack.
# It 's dangerous, there 's nails and stuff.
# Should 've dumped them all
# of at Chuck E. Cheese
# Well, that place is a nightmare.
# I
# --------------------
# Generate:
# 'm gon na kill you.
# No more waiting around.
# Let 'em get some
# cheese and hash browns.
# We ai n't done yet. NEWLINE_
# --------------------
# Reference:
# hate clowns.
# Yeah, well, it 's what he wanted.
# He 's seven.
# Well, when I was seven,
# I thought clowns were creepy.
# Oh, you can tell that to the
# clown when he gets
# --------------------
# BLEU: 0.009734248399981466
# ROUGE: 0.039999995008000624
# F1: 0.3647305369377136
# Precision: 0.36383578181266785
# Recall: 0.3642253279685974
# 8
# ====================
# Seed:
# 1
# ( alarm clock ringing )
# ( man sighing )
# ( soft music )
# Love ca n't go wrong
# ( water splashing )
# With a girl like this
# Like Cupid 's arrow
# This love just ca n't miss
# --------------------
# Generate:
# .
# ( siren blaring )
# ( thudding )
# ( thudding )
# ( footsteps thudding )
# ( footsteps thudding )
# --------------------
# Reference:
# Your love it makes me
# Feel like a million dollars
# You make feel like
# A full bright scholar
# Love ca n't go wrong
# With a girl like this
# My ship 's come in
# Love is on the list
# Red flags they
# --------------------
# BLEU: 0.0017558529328741835
# ROUGE: 0.04999999781250009
# F1: 0.11846110224723816
# Precision: 0.14018040895462036
# Recall: 0.0950268805027008
# 8
# ====================
# Seed:
# Cab fare, Richard?
# No, I 've got to pay some biIIs.
# You couId at Ieast Ieave me
# enough for breakfast.
# Toddy, one wouId suspect
# you think I 'm mercenary
# --------------------
# Generate:
# ?
# A man of few words?
# I ai n't much of a man,
# but I ' ve been through a fair bit.
# I got a degree in
# --------------------
# Reference:
# .
# Try `` unscrupuIous. ''
# You get your money 's worth.
# I 'd say we both get my money 's worth.
# Look, Toddy, if you 're not happy
# with the arrangement --
# As a
# --------------------
# BLEU: 0.021833228604410414
# ROUGE: 0.13333332845432116
# F1: 0.35421907901763916
# Precision: 0.3380008637905121
# Recall: 0.3691149353981018
# 8
# ====================
# Seed:
# Painting the mat, eh?
# You were told to wash it.
# - It 's nice this way, sir.
# - It 'll crack.
# So we 'll paint it again.
# Pardon me, the iron,
# but that
# --------------------
# Generate:
# wasn 't always the case.
# You 're a little dry these days.
# - You don ' t like wetting the bedside table?
# - No. NEWLINE_TO
# --------------------
# Reference:
# 's it.
# Captain!
# Saturday we go to sea.
# They 've called from the HQ.
# Sorry, dear Katyusha.
# Where 's my cap?
# In the water, Captain.
# Catch my cap, everybody!
# -
# --------------------
# BLEU: 0.010016393519912185
# ROUGE: 0.08888888395061757
# F1: 0.35341787338256836
# Precision: 0.3180065155029297
# Recall: 0.38791659474372864
# 8
# ====================
# Seed:
# `` Bus now arriving from San Francisco,
# Fresno and Bakersfield. ''
# Well, what brings you here, Lieutenant?
# Maybe my fine memories.
# I did n't think you had any.
# One of your parolees was in while
# --------------------
# Generate:
# on parole.
# You should have known better.
# I 've been away longer.
# You must have missed him.
# I have, indeed. NEWLINE_TO
# --------------------
# Reference:
# you were out for supper, Miss Turner.
# Oh? Who?
# Jane Wanamaker.
# Is something wrong?
# I thought it was okay to check.
# - You should have had her wait.
# I thought it was alright to
# --------------------
# BLEU: 0.07695195332885259
# ROUGE: 0.1739130387145559
# F1: 0.4364371597766876
# Precision: 0.5200273394584656
# Recall: 0.35444775223731995
# 8
# ====================
# Seed:
# Young people from all over the globe...
# are joining up
# to fight for the future.
# - I 'm doing my part.
# - I 'm doing my part.
# - I 'm doing my part.
# - I 'm doing my part
# --------------------
# Generate:
# .
# - And if you 're
# supporting the cause,
# you 're supporting the cause.
# - I 'm supporting the cause.
# -
# --------------------
# Reference:
# too.
# They 're doing their part,
# are you?
# Join the Mobile Infantry
# and save the world.
# Service guarantees citizenship.
# The bugs send
# another meteor our way...
# but this time we 're ready.
# Planetary defences
# --------------------
# ...
# See you tomorrow.
# She never told me.
# Ihab Abdulla.
# - I love you.
# - I love you.
# Citizenship?
# We do n't have.
# You do n't have citizenship?
# As
# --------------------
# Generate:
# long as you live
# in the United States, you have no right to be
# a citizen of the United States.
# You can not be a citizen of the United States. NEWLINE_
# --------------------
# Reference:
# in, you do n't
# have a country.
# That 's right.
# Where are you from?
# - Israel?
# - No, no.
# It 's the Palestinian territory.
# Your occupation?
# Yes.
# It is occupied
# --------------------
# BLEU: 0.013967686353916754
# ROUGE: 0.17777777283950633
# F1: 0.3239273130893707
# Precision: 0.2971212863922119
# Recall: 0.3495330512523651
# 8
# ====================
# Seed:
# See!
# You look ten years younger!
# Ms. Elda...
# Dont worry, it 's a simple reinforcement
# Damn it!
# How much have I degraded!
# But c'mon...
# When someone is desperate,
# at
# --------------------
# Generate:
# least try to
# make themselves heard
# Mr. Aguirre, you ca n't
# complain.
# You 're not qualified to be
# president of
# --------------------
# Reference:
# the end of the rope...
# Yes, I mean suicidal...
# He has to try everything
# before giving up, right?
# At the end of the rope...... imagine! If anyone had told me
# two years ago that I
# --------------------
# BLEU: 0.009599624758234988
# ROUGE: 0.0833333285503475
# F1: 0.2558373510837555
# Precision: 0.2963378429412842
# Recall: 0.21442103385925293
# 8
# ====================
# Seed:
# Hi, everybody.
# This is your cousin Brucie. Whoa!
# Our summer romances are in full bloom,
# and everybody 's in love!
# So cousins, here 's a great song
# from the Four Seasons.
# That
# --------------------
# Generate:
# 'll be all for once, you know.
# What a beautiful sunny day
# you 're gon na get!
# Yup! The groom is coming!
# Do n't forget
# --------------------
# Reference:
# was the summer of 1963...
# when everybody called me `` '' Baby '' ''
# and it did n't occur to me to mind.
# That was before
# President Kennedy was shot...
# before the Beatles came...
# when I could n't wait
# to join
# --------------------
# BLEU: 0.008925198998798903
# ROUGE: 0.11111110613854619
# F1: 0.3370431959629059
# Precision: 0.3306390345096588
# Recall: 0.34199991822242737
# 8
# ====================
# Seed:
# Do n't take my mother away from me!
# You 've protected our village
# for thousands of years.
# We tried our best to save you
# for two years, but we 've lost...
# Brother, we are n't leaving her.
# We
# --------------------
# Generate:
# need to find our daughter.
# I don ' t know what to do now.
# I ' ll stay with you till I find you.
# We ' ll fight till we die.
# --------------------
# Reference:
# 're taking Mother with us.
# CBI Special Director Mr Dhananjay Rawat
# is waiting for you, sir.
# - Send him in.
# - Sir.
# - Good morning, Sir.
# - Morning.
# It 's been
# --------------------
# BLEU: 0.012282330121868492
# ROUGE: 0.0869565167769379
# F1: 0.3235929012298584
# Precision: 0.31404033303260803
# Recall: 0.3316878080368042
# 8
# ====================
# Seed:
# 1
# `` L '' is for the way
# you look at me
# `` O '' is for the only one
# I see
# `` V '' is
# very, very extraordinary
# `` E '' is even more
# than anyone that you adore can
# --------------------
# Generate:
# offer.
# I ca n't believe
# you sent me this.
# I do n't know
# what else to do.
# I just need one more
# --------------------
# Reference:
# love is all
# that I can give to you
# love is more than
# just a game for two
# two in love can make it
# take my heart
# and please do n't break it
# love was made for me and you
# ``
# --------------------
# BLEU: 0.016531204757437364
# ROUGE: 0.15999999528800013
# F1: 0.34265968203544617
# Precision: 0.37512877583503723
# Recall: 0.30920350551605225
# 8
# ====================
# Seed:
# I should n't be doing this,
# but it 's dangerous out here.
# You said it, mister.
# I do n't know what worries me more...
# running out of water
# or running into the Drifter.
# The, uh
# --------------------
# Generate:
# ... well, the Drifter is
# dangerous when you 're wet.
# And if you do n't have water
# to dry yourself in,
# it 'll get pretty wind
# --------------------
# Reference:
# , Drifter?
# You never heard
# of the Death Valley Drifter?
# No.
# Killed dozens
# out here in the desert.
# Kinda funny, huh?
# Death Valley.
# You get it?
# Death Valley.
# --------------------
# BLEU: 0.013684648321460163
# ROUGE: 0.21739129938563337
# F1: 0.3516445457935333
# Precision: 0.29360923171043396
# Recall: 0.4096657335758209
# 8
# ====================
# Seed:
# 1
# We 've been running surveillance
# on your wife
# for months, Mr. Montano.
# That 's what 's left of the car
# she rented in Los Mochis
# Airport two days ago.
# I 'm telling you,
# --------------------
# Generate:
# you can trust him.
# He doesn ' t care what
# he looks like, Mr. Montano.
# I 'm telling you,
# he won 't care
# --------------------
# Reference:
# brother, he stole a knife?
# Where 's Sara?
# -I do n't speak English.
# No English.
# -Answer the question.
# Wait, wait, wait.
# He does n't speak English.
# He 's my brother,
# --------------------
# BLEU: 0.02843309944563904
# ROUGE: 0.1538461488757398
# F1: 0.4039779007434845
# Precision: 0.3869614005088806
# Recall: 0.4197925925254822
# 8
# ====================
# Seed:
# ( Tyres screech )
# ( Siren )
# You want it?
# Is it yours?
# No, not mine.
# Yours.
# How much do you want for it?
# Whatever you think it 's worth.
# Exactly
# --------------------
# Generate:
# .
# What do you think it 's worth?
# It 's mine.
# No, not mine.
# How much do you want for it? NEWLINE_
# --------------------
# Reference:
# the figure I had in mind.
# Take pleasure in it.
# ( Woman ) 'Most nights,
# this inner city emergency room
# 'would be a chaos of blood, panic
# and grace under pressure,
# 'but, tonight, as
# --------------------
# BLEU: 0.009623645112325394
# ROUGE: 0.08333332888888913
# F1: 0.2875143587589264
# Precision: 0.35792768001556396
# Recall: 0.21763703227043152
# 8
# ====================
# Seed:
# America on the March...... brings you a special event.
# When war ended last year,
# numberless plans were proposed...... for the advancement
# of peace and prosperity.
# But from among them has emerged one......
# --------------------
# Generate:
# the Republic of Poland.
# Poland is the last frontier in NATO.
# Poland is the gateway between the United States and
# the Soviet Union.
# Poland is the gateway
# --------------------
# Reference:
# which has captured
# the imagination of the world.
# It 's popularity enhanced by the fact...... that it 's presented
# in the form of a novel.
# Here is Tomorrow
# by Christopher Madden...... is a blueprint of the future
# --------------------
# BLEU: 0.02086865400157506
# ROUGE: 0.22727272253099182
# F1: 0.29198238253593445
# Precision: 0.3144751489162445
# Recall: 0.26816031336784363
# 8
# ====================
# Seed:
# 1
# The film is based on true events.
# Certain characters, names and
# events have been dramatized.
# I have been forced to leave a house in the
# middle of the night because of a man earlier.
# But this is
# --------------------
# Generate:
# not my story.
# My story is based on real events.
# In order to understand the significance
# of these events
# one must understand
# the
# --------------------
# Reference:
# the first time I have
# been forced to leave a country.
# 7221, you 're ready to fly in.
# Okay, good people, now
# we enter US airspace.
# You are safe now.
# OWN PLACE 1993
# I
# --------------------
# BLEU: 0.01041245707673475
# ROUGE: 0.07999999528800027
# F1: 0.3716156482696533
# Precision: 0.3981074094772339
# Recall: 0.34404751658439636
# 8
# ====================
# Seed:
# 00:00:19,052 -- 00:00:20,326
# My mom said
# 2
# 00:00:20,754 -- 00:00:23,963
# color and smell have a huge effect
# on people 's
# --------------------
# Generate:
# personalities
# NEWLINE_TOKEN
# NEWLINE_TOKEN
# NEWLINE_TOKEN
# NEWLINE_TOKEN
# NEWLINE_TO
# --------------------
# Reference:
# moods.
# 3
# 00:00:24,858 -- 00:00:25,734
# So I wonder,
# 4
# 00:00:26,326 -- 00:00:28,328
# if that theory
# --------------------
# BLEU: 0.01633451134233008
# ROUGE: 0.11764705591695508
# F1: 0.08920153230428696
# Precision: 0.40618064999580383
# Recall: -0.1902657002210617
# 8
# ====================
# Seed:
# [ winds howling ]
# [ alarm blaring ]
# [ tense instrumental music plays ]
# [ man 1 ] Mayday, mayday!
# We are under attack.
# Under attack from our own people.
# They just started
# --------------------
# Generate:
# walking
# around the village.
# They are coming from all sides.
# [ thudding ]
# [ man 1 ] Under attack by our own people. NEWLINE_
# --------------------
# Reference:
# shooting.
# They took out everyone.
# - [ man 2 ] Why are they doing this?
# - [ man 1 ] They 're ours. What 's happening?
# [ music builds ]
# [ beeping ]
# [ man 1 ] How
# --------------------
# BLEU: 0.052988671596804086
# ROUGE: 0.18604650663061129
# F1: 0.5327847003936768
# Precision: 0.5464228391647339
# Recall: 0.5181988477706909
# 8
# ====================
# Seed:
# 1
# ( suspenseful music )
# ( birds chirping )
# ( gas clicking )
# ( egg bubbling )
# ( bacon sizzling )
#
# ( juice gurgling )
#
# Breakfast is ready
# --------------------
# Generate:
# and you are all set.
# ( peace and quiet )
# ( children chattering )
# ( children cheering )
# ( dogs barking ) NEW
# --------------------
# Reference:
# .
# - Good morning, beautiful.
# - Good morning.
# Everything okay?
# Yeah, I just wished my dad
# a happy birthday.
# - Oh! Did he get our gift?
# - I do n't know.
# He couldn
# --------------------
# BLEU: 0.00876063147494084
# ROUGE: 0.051282046679816326
# F1: 0.32304129004478455
# Precision: 0.35840946435928345
# Recall: 0.2867282032966614
# 8
# ====================
# Seed:
# 1
# MAVERICK CARTER: What an
# incredible room we have here.
# Let 's give it up
# for the Superbowl MVP.
# Yeah!
# PATRICK MAHOMES II: You ca n't
# overcomplicate
# --------------------
# Generate:
# things.
# Okay, there you go.
# And the kitchen.
# Made of
# steel and aluminum.
# Oh, that was awesome! NEW
# --------------------
# Reference:
# everything.
# Sometimes,
# players just got ta make plays.
# CHADWICK BOSEMAN: There are
# moments when you improv
# or even if it 's something
# serious.
# What did you improv
# in Black Panther?
# --------------------
# BLEU: 0.009832094243643544
# ROUGE: 0.12765956974196485
# F1: 0.41388893127441406
# Precision: 0.4858004152774811
# Recall: 0.3428158164024353
# 8
# ====================
# Seed:
# My name is Xiong Dun.
# Xiong, like a bear.
# Dun, like Newton.
# Tomorrow,
# I 'll be turning 29.
# Alexander Bell
# invented the telephone when he was 29.
# Murakami
# --------------------
# Generate:
# was the inventor of the modern telephone.
# Bell was a famous artist,
# and his work was loved
# by everyone.
# People called him Picasso. NEWLINE
# --------------------
# Reference:
# started writing novels when he was 29.
# Spielberg
# directed `` Jaws '' when he was 29.
# and at 29, Steve Jobs introduced the Macintosh.
# I believe,
# the next 29-year-old to influence the world,
# --------------------
# BLEU: 0.02386305414518096
# ROUGE: 0.1276595694884565
# F1: 0.3885727822780609
# Precision: 0.43302997946739197
# Recall: 0.34360694885253906
# 8
# ====================
# Seed:
# The majority of events related
# in this film are true.
# However, the authors are not trying
# to do the work of historians.
# They have allowed
# their imaginations some liberty.
# They apologise to those
# who may share the same
# --------------------
# Generate:
# view.
# This film is about
# the conflict in Yemen between the
# Saudi Arabia and the United Arab Emirates.
# The conflict escalated into
# civil
# --------------------
# Reference:
# names...
# as those used for
# certain characters in this film.
# There is, naturally,
# no relationship involved.
# There they are!
# There they are!
# JULY 1933...
# CASSIS, FRANCE
# Im Chief
# --------------------
# BLEU: 0.023025841426106287
# ROUGE: 0.17777777283950633
# F1: 0.41188398003578186
# Precision: 0.4361467659473419
# Recall: 0.386582612991333
# 8
# ====================
# Seed:
# 1
# She will not die now because she is 85 years old,
# I give her another 20 years of life.
# Her, she gave me the maternal initiation,
# otherwise I can not go back to the Mamiwata convents.
# --------------------
# Generate:
# She will be remembered as one of the bravest
# young women in history.
# My own daughter, Zainab, will be remembered
# as one of the
# --------------------
# Reference:
# Where 's we going to see her?
# - At her home in Cotonou.
# - Oh yes, and when will we go?
# I 'll see with her now...
# She 's here now?
# Yes, she gave me
# --------------------
# BLEU: 0.020865023341012836
# ROUGE: 0.09090908607438043
# F1: 0.2930585741996765
# Precision: 0.3007607161998749
# Recall: 0.283829927444458
# 8
# ====================
# Seed:
# 1
# Curses! Get 'em, boys!
# Who are you?
# I am the Robot Ninja...
# and remember, kids,
# drugs are not cool!
# Oh Robot Ninja, you 're my hero!
# Courageous citizens like
# --------------------
# Generate:
# you
# will make a huge contribution
# to our planet.
# Thank you robot Ninja.
# Hello robot,
# thank you! NEWLINE_TO
# --------------------
# Reference:
# you
# are the real heroes...
# - I did not thee, little sprite.
# Dost thou know the form
# that thee just took?
# Boy, this was the
# best deal I ever made
# letting NBC pick up
# the domestic
# --------------------
# BLEU: 0.01438586525879198
# ROUGE: 0.0869565173440456
# F1: 0.4304264783859253
# Precision: 0.5260756611824036
# Recall: 0.3372228741645813
# 8
# ====================
# Seed:
# 1
# Twenty one years.
# What have I learnt
# in twenty one years?
# All I have to do is stay
# on this bike,
# and keep my eyes and ears open.
# And keep my mind
# as free as I can
# --------------------
# Generate:
# be.
# Come on, let 's go!
# I 've got to go now.
# - Let 's go!
# - Great!
# -
# --------------------
# Reference:
# .
# I want to know
# what the wall was like
# from the other side.
# They are building another wall,
# somewhere else now.
# The foster child grows
# bigger and bigger,
# and the redbreast
# begins looking thin
# --------------------
# BLEU: 0.016720069012351367
# ROUGE: 0.19047618620181417
# F1: 0.3506958782672882
# Precision: 0.38117551803588867
# Recall: 0.31919237971305847
# 8
# ====================
# Seed:
# Write slip twice. Put money in the bag.
# Joe?
# Gina.
# Lucas, what are you doing in here?
# My life has reached its pinnacle.
# Joe 's letting me close the store tonight.
# - You 're kidding.
# --------------------
# Generate:
# - It 's not.
# - It 's not.
# - Do n't do that.
# - You 'd meet a lot of people tonight. NEW
# --------------------
# Reference:
# - I am not.
# Big responsibility, Lucas.
# Yes.
# But Joe 's rules are extremely simple:
# Count money twice...
# keep my hands off of his beer...
# cigars...
# and drumsticks.
# My, my
# --------------------
# BLEU: 0.019407379501991763
# ROUGE: 0.13636363173553734
# F1: 0.322030633687973
# Precision: 0.3539823889732361
# Recall: 0.28903406858444214
# 8
# ====================
# Seed:
# Define `` violence ''.
# - What?
# - Okay, everyone,
# I need you to step back.
# Step back. Violence. Define it.
# I do n't know.
# Violence?
# You 're making a movie about it
# --------------------
# Generate:
# .
# No, I 'm not making a movie about it.
# I 'm making a movie about
# what happened last night.
# I killed my ex-boyfriend
# --------------------
# Reference:
# .
# Should n't you know what it is?
# Maybe we should
# just get ready.
# I 'm ready.
# All right, silence.
# We 're going in 20,
# here we go.
# Try and define it.
# --------------------
# BLEU: 0.038139901062587106
# ROUGE: 0.1818181770764464
# F1: 0.4482477903366089
# Precision: 0.4432831406593323
# Recall: 0.45200368762016296
# 8
# ====================
# Seed:
# -Congressman.
# -General.
# Herzlich Willkommen in Berlin.
# Who is that guy?
# It 's Breimer. He 's a congressman.
# -You 're here for the peace conference?
# -To write about
# --------------------
# Generate:
# .
# -We 've been talking about it.
# -And if you don ' t
# know what 's happening in Europe,
# then write about it.
# --------------------
# Reference:
# it.
# -You ever hear of The New Republic?
# -No.
# The uniform
# is the Army 's idea of a joke.
# You see any action?
# I was in London when Franz Bettmann
# aimed his Roman candles...
# --------------------
# BLEU: 0.018023668838227015
# ROUGE: 0.19607842660515198
# F1: 0.3769908845424652
# Precision: 0.4081093966960907
# Recall: 0.3449203372001648
# 8
# ====================
# Seed:
# I 'm pregnant
# Oh yeah, it 's pretty pleasant... Fancy.
# can I get you anything else?
# No. We 're good. Thank you.
# She 's cute. I wonder what her deal is.
# what?
# I 'm
# --------------------
# Generate:
# not sure.
# She 's cute.
# I ca n't wait to get her a burberry
# I know she likes cake
# I 'm going to get a
# --------------------
# Reference:
# pregnant
# Hey! Wow! Congratulations!
# Who 's the lucky dad?
# You are.
# No... seriously
# Pregnant?
# Yes. Pregnant.
# What do you mean pregnant?
# How are you pregnant?
# You
# --------------------
# BLEU: 0.011630640784812192
# ROUGE: 0.10256409756739011
# F1: 0.3782714307308197
# Precision: 0.3219511806964874
# Recall: 0.43454501032829285
