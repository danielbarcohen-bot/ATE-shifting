# %%
import pandas as pd
df = pd.read_csv(r'D:\Capstone project\modular_price_prediction\data\cleaned_data.csv')

# %%
df['Locality'].unique()
# Out:
# array(['Chharodi', 'Vastral', 'Thaltej', 'Science City', 'Ambli',
#        'Sarkhej Gandhinagar Highway', 'Shela', 'Ognaj', 'Jagatpur',
#        'Shilaj', 'Khodiyar', 'Tragad', 'Bopal', 'Vaishnodevi Circle',
#        'Gota', 'Shantigram', 'Motera', 'Chandkheda', 'Naranpura',
#        'Ghatlodiya', 'Ambawadi', 'Bodakdev', 'Shyamal',
#        'Shantipura Circle', 'Bhadaj', 'Gurukul',
#        'Friends Colony Bodakdev', 'Thaltej Shilaj Road',
#        'Ambli Bopal Road', 'Sola', 'Gandhinagar Rd', 'Drive In Road',
#        'Gulbai Tekra', 'Satellite', 'Navrangpura', 'Ghuma', 'Usmanpura',
#        'Prahlad Nagar', 'Vastrapur', 'Vandematram Arcade',
#        'Sentossa Greenland', 'Sanand Sarkhej Road', 'Yashkamal Society',
#        'Vasna', 'New Ranip', 'Judges Bunglow Road', 'New Maninagar',
#        'Hinglajnagar', 'Sanand', 'Nava Naroda', 'Narolgam',
#        'Janata Nagar Umedpark Society', 'Nikol', 'Makarba', 'Paldi',
#        'New Naroda', 'Keshav Nagar', 'Ranip', 'Daskroi',
# ...

# %%
shela = df[df['Locality'] == 'Shela']

# %%
print(shela['Price_Clean'].median())
# Out:
# 7340000.0
