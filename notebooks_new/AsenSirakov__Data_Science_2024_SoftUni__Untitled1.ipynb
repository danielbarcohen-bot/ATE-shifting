# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
import requests
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Fetch data from the API
url = "https://www.cheapshark.com/api/1.0/deals?storeID=1&upperPrice=15"
response = requests.get(url)
data = response.json()

# Convert the data to a DataFrame
df = pd.DataFrame(data)

# Display the first few rows of the DataFrame
print(df.head())

# Basic exploration
print(f"Number of deals: {len(df)}")
print(f"Columns: {df.columns}")

# Analyze discounts
df['discountPercent'] = df['savings'].astype(float)
print(f"Average discount: {df['discountPercent'].mean():.2f}%")

# Visualize the data
plt.figure(figsize=(10, 6))
sns.histplot(df['discountPercent'], kde=True, bins=20)
plt.title('Distribution of Discounts')
plt.xlabel('Discount Percent')
plt.ylabel('Number of Deals')
plt.show()

# Top 10 deals with the highest discount
top_deals = df.sort_values(by='discountPercent', ascending=False).head(10)
print("Top 10 deals with the highest discount:")
print(top_deals[['title', 'normalPrice', 'salePrice', 'discountPercent']])

# Visualize top 10 deals
plt.figure(figsize=(12, 8))
sns.barplot(x='discountPercent', y='title', data=top_deals, palette='viridis')
plt.title('Top 10 Deals by Discount Percent')
plt.xlabel('Discount Percent')
plt.ylabel('Deal Title')
plt.show()
# Out:
#               internalName                          title  \
# 0  DISCOELYSIUMTHEFINALCUT  Disco Elysium - The Final Cut
# 1                HALFLIFE2                    Half-Life 2
# 2                 HALFLIFE                      Half-Life
# 3                  PORTAL2                       Portal 2
# 4      THEWITCHER3WILDHUNT       The Witcher 3: Wild Hunt
#
#                        metacriticLink  \
# 0  /game/disco-elysium-the-final-cut/
# 1                  /game/half-life-2/
# 2                    /game/half-life/
# 3                     /game/portal-2/
# 4      /game/the-witcher-3-wild-hunt/
#
#                                               dealID storeID  gameID  \
# 0  Uk9pH81%2BgPUwbkh9YzwMnYLT%2B%2FEaktqN8AgwMr6Y...       1  227942
# 1   Vz5eZMF1sKvs02I4cuEgrGnmM1r%2BkWHig0YMa0lJ0vM%3D       1      59
# 2  G%2BXAA0GGjaN4wXzRSpEpKtspbGp%2Bz3TJoNnhJI72Bu...       1      75
# 3   rwQ2JCEr5NOySyBsAj6fyPuZg4qMlh9w67U%2BmM6b2VE%3D       1      36
# 4     zm2ORJ1RIWrq7UFFCs9J4ps4rgsNUV7FTSnWxzxxj8Q%3D       1  112330
#
#   salePrice normalPrice isOnSale    savings metacriticScore  \
# 0      3.99       39.99        1  90.022506              97
# 1      0.99        9.99        1  90.090090              96
# 2      0.99        9.99        1  90.090090              96
# 3      0.99        9.99        1  90.090090              95
# 4      3.99       39.99        1  90.022506              93
#
#            steamRatingText steamRatingPercent steamRatingCount steamAppID  \
# 0            Very Positive                 93            86152     632470
# 1  Overwhelmingly Positive                 97           153905        220
# 2  Overwhelmingly Positive                 96            92803         70
# 3  Overwhelmingly Positive                 98           327175        620
# 4  Overwhelmingly Positive                 96           711659     292030
#
#    releaseDate  lastChange dealRating  \
# 0   1617062400  1719510042       10.0
# 1   1100563200  1719510166       10.0
# 2    911433600  1719510173       10.0
# 3   1303084800  1719510062       10.0
# 4   1431907200  1719510030       10.0
#
#                                                thumb
# 0  https://shared.akamai.steamstatic.com/store_it...
# 1  https://shared.akamai.steamstatic.com/store_it...
# 2  https://shared.akamai.steamstatic.com/store_it...
# 3  https://shared.akamai.steamstatic.com/store_it...
# 4  https://shared.akamai.steamstatic.com/store_it...
# Number of deals: 60
# Columns: Index(['internalName', 'title', 'metacriticLink', 'dealID', 'storeID',
#        'gameID', 'salePrice', 'normalPrice', 'isOnSale', 'savings',
#        'metacriticScore', 'steamRatingText', 'steamRatingPercent',
#        'steamRatingCount', 'steamAppID', 'releaseDate', 'lastChange',
#        'dealRating', 'thumb'],
#       dtype='object')
# Average discount: 88.72%
# C:\Users\ACER\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# Top 10 deals with the highest discount:
#                                 title normalPrice salePrice  discountPercent
# 49                     Helheim Hassle       51.96      1.20        97.690531
# 25  Warhammer: End Times - Vermintide       44.99      2.24        95.021116
# 5          Sid Meiers Civilization VI       59.99      2.99        95.015836
# 46                Time on Frog Island       36.98      1.96        94.699838
# 57                        Dreamscaper       76.95      5.03        93.463288
# 10                      Battlefield 1       39.99      2.79        93.023256
# 34                      Battlefield 4       39.99      2.79        93.023256
# 39                      Battlefield V       49.99      3.49        93.018604
# 42              Atomik: RunGunJumpGun        7.99      0.79        90.112641
# 20           Half-Life 2: Episode One        7.99      0.79        90.112641

# %%
import requests
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Fetch data from the API
url = "https://www.cheapshark.com/api/1.0/deals?storeID=1&upperPrice=15"
response = requests.get(url)
data = response.json()

# Convert the data to a DataFrame
df = pd.DataFrame(data)

# Display the DataFrame in a tabular format
pd.set_option('display.max_columns', None)  # Show all columns
print(df.head())

# Basic exploration
print(f"Number of deals: {len(df)}")
print(f"Columns: {df.columns}")

# Analyze discounts
df['discountPercent'] = df['savings'].astype(float)
print(f"Average discount: {df['discountPercent'].mean():.2f}%")

# Visualize the data
plt.figure(figsize=(10, 6))
sns.histplot(df['discountPercent'], kde=True, bins=20)
plt.title('Distribution of Discounts')
plt.xlabel('Discount Percent')
plt.ylabel('Number of Deals')
plt.show()

# Top 10 deals with the highest discount
top_deals = df.sort_values(by='discountPercent', ascending=False).head(10)
print("Top 10 deals with the highest discount:")
print(top_deals[['title', 'normalPrice', 'salePrice', 'discountPercent']])

# Visualize top 10 deals
plt.figure(figsize=(12, 8))
sns.barplot(x='discountPercent', y='title', data=top_deals, palette='viridis')
plt.title('Top 10 Deals by Discount Percent')
plt.xlabel('Discount Percent')
plt.ylabel('Deal Title')
plt.show()

# Display the DataFrame with key columns
results = df[['title', 'normalPrice', 'salePrice', 'discountPercent', 'dealID', 'storeID']]
print(results.head(10))
# Out:
#               internalName                          title  \
# 0  DISCOELYSIUMTHEFINALCUT  Disco Elysium - The Final Cut
# 1                HALFLIFE2                    Half-Life 2
# 2                 HALFLIFE                      Half-Life
# 3                  PORTAL2                       Portal 2
# 4      THEWITCHER3WILDHUNT       The Witcher 3: Wild Hunt
#
#                        metacriticLink  \
# 0  /game/disco-elysium-the-final-cut/
# 1                  /game/half-life-2/
# 2                    /game/half-life/
# 3                     /game/portal-2/
# 4      /game/the-witcher-3-wild-hunt/
#
#                                               dealID storeID  gameID  \
# 0  Uk9pH81%2BgPUwbkh9YzwMnYLT%2B%2FEaktqN8AgwMr6Y...       1  227942
# 1   Vz5eZMF1sKvs02I4cuEgrGnmM1r%2BkWHig0YMa0lJ0vM%3D       1      59
# 2  G%2BXAA0GGjaN4wXzRSpEpKtspbGp%2Bz3TJoNnhJI72Bu...       1      75
# 3   rwQ2JCEr5NOySyBsAj6fyPuZg4qMlh9w67U%2BmM6b2VE%3D       1      36
# 4     zm2ORJ1RIWrq7UFFCs9J4ps4rgsNUV7FTSnWxzxxj8Q%3D       1  112330
#
#   salePrice normalPrice isOnSale    savings metacriticScore  \
# 0      3.99       39.99        1  90.022506              97
# 1      0.99        9.99        1  90.090090              96
# 2      0.99        9.99        1  90.090090              96
# 3      0.99        9.99        1  90.090090              95
# 4      3.99       39.99        1  90.022506              93
#
#            steamRatingText steamRatingPercent steamRatingCount steamAppID  \
# 0            Very Positive                 93            86152     632470
# 1  Overwhelmingly Positive                 97           153905        220
# 2  Overwhelmingly Positive                 96            92803         70
# 3  Overwhelmingly Positive                 98           327175        620
# 4  Overwhelmingly Positive                 96           711659     292030
#
#    releaseDate  lastChange dealRating  \
# 0   1617062400  1719510042       10.0
# 1   1100563200  1719510166       10.0
# 2    911433600  1719510173       10.0
# 3   1303084800  1719510062       10.0
# 4   1431907200  1719510030       10.0
#
#                                                thumb
# 0  https://shared.akamai.steamstatic.com/store_it...
# 1  https://shared.akamai.steamstatic.com/store_it...
# 2  https://shared.akamai.steamstatic.com/store_it...
# 3  https://shared.akamai.steamstatic.com/store_it...
# 4  https://shared.akamai.steamstatic.com/store_it...
# Number of deals: 60
# Columns: Index(['internalName', 'title', 'metacriticLink', 'dealID', 'storeID',
#        'gameID', 'salePrice', 'normalPrice', 'isOnSale', 'savings',
#        'metacriticScore', 'steamRatingText', 'steamRatingPercent',
#        'steamRatingCount', 'steamAppID', 'releaseDate', 'lastChange',
#        'dealRating', 'thumb'],
#       dtype='object')
# Average discount: 88.72%
# C:\Users\ACER\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# Top 10 deals with the highest discount:
#                                 title normalPrice salePrice  discountPercent
# 49                     Helheim Hassle       51.96      1.20        97.690531
# 25  Warhammer: End Times - Vermintide       44.99      2.24        95.021116
# 5          Sid Meiers Civilization VI       59.99      2.99        95.015836
# 46                Time on Frog Island       36.98      1.96        94.699838
# 57                        Dreamscaper       76.95      5.03        93.463288
# 10                      Battlefield 1       39.99      2.79        93.023256
# 34                      Battlefield 4       39.99      2.79        93.023256
# 39                      Battlefield V       49.99      3.49        93.018604
# 42              Atomik: RunGunJumpGun        7.99      0.79        90.112641
# 20           Half-Life 2: Episode One        7.99      0.79        90.112641
#                            title normalPrice salePrice  discountPercent  \
# 0  Disco Elysium - The Final Cut       39.99      3.99        90.022506
# 1                    Half-Life 2        9.99      0.99        90.090090
# 2                      Half-Life        9.99      0.99        90.090090
# 3                       Portal 2        9.99      0.99        90.090090
# 4       The Witcher 3: Wild Hunt       39.99      3.99        90.022506
# 5     Sid Meiers Civilization VI       59.99      2.99        95.015836
# 6    Sid Meier's Civilization IV       19.99      2.99        85.042521
# 7       Half-Life 2: Episode Two        7.99      0.79        90.112641
# 8                         Portal        9.99      0.99        90.090090
# 9               Metro 2033 Redux       19.99      1.99        90.045023
#
#                                               dealID storeID
# 0  Uk9pH81%2BgPUwbkh9YzwMnYLT%2B%2FEaktqN8AgwMr6Y...       1
# 1   Vz5eZMF1sKvs02I4cuEgrGnmM1r%2BkWHig0YMa0lJ0vM%3D       1
# 2  G%2BXAA0GGjaN4wXzRSpEpKtspbGp%2Bz3TJoNnhJI72Bu...       1
# 3   rwQ2JCEr5NOySyBsAj6fyPuZg4qMlh9w67U%2BmM6b2VE%3D       1
# 4     zm2ORJ1RIWrq7UFFCs9J4ps4rgsNUV7FTSnWxzxxj8Q%3D       1
# 5     5xRuVIgFiH0TW2PTPJPlTN4NYMjAt4bg3p1CvKMMJv8%3D       1
# 6   khSrhkgpaxgOWWEYV9MdKid%2FcDzIGa0zHzvh5j73lLo%3D       1
# 7     S0Ig5YiyefrWVD4DC7ZKSQLcr9sBbVuLAvP17Tq4Vfw%3D       1
# 8  rPSCN3%2FJpoZ0SjQ%2FgDXvmCifMHiePHA9JjbUPcGPS3...       1
# 9   o35o2DS12hd%2BlYrHgmxPiMry13keOtIO83Cziy6I2l8%3D       1

# %%
import requests
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Fetch data from the API
url = "https://www.cheapshark.com/api/1.0/deals?storeID=1&upperPrice=15"
response = requests.get(url)
data = response.json()

# Convert the data to a DataFrame
df = pd.DataFrame(data)

# Select relevant columns and rename them for better readability
results = pd.DataFrame({
    'Title': df['title'],
    'Normal Price': df['normalPrice'],
    'Sale Price': df['salePrice'],
    'Discount Percent': df['savings'].astype(float),
    'Deal Rating': df['dealRating'],
    'Metacritic Score': df['metacriticScore'],
    'Steam Rating': df['steamRatingText']
})

# Display the DataFrame in a tabular format
print(results.head(10))

# Basic exploration
print(f"Number of deals: {len(df)}")
print(f"Columns: {df.columns}")

# Analyze discounts
average_discount = results['Discount Percent'].mean()
print(f"Average discount: {average_discount:.2f}%")

# Visualize the data
plt.figure(figsize=(10, 6))
sns.histplot(results['Discount Percent'], kde=True, bins=20)
plt.title('Distribution of Discounts')
plt.xlabel('Discount Percent')
plt.ylabel('Number of Deals')
plt.show()

# Top 10 deals with the highest discount
top_deals = results.sort_values(by='Discount Percent', ascending=False).head(10)
print("Top 10 deals with the highest discount:")
print(top_deals)

# Visualize top 10 deals
plt.figure(figsize=(12, 8))
sns.barplot(x='Discount Percent', y='Title', data=top_deals, palette='viridis')
plt.title('Top 10 Deals by Discount Percent')
plt.xlabel('Discount Percent')
plt.ylabel('Deal Title')
plt.show()
# Out:
#                            Title Normal Price Sale Price  Discount Percent  \
# 0  Disco Elysium - The Final Cut        39.99       3.99         90.022506
# 1                    Half-Life 2         9.99       0.99         90.090090
# 2                      Half-Life         9.99       0.99         90.090090
# 3                       Portal 2         9.99       0.99         90.090090
# 4       The Witcher 3: Wild Hunt        39.99       3.99         90.022506
# 5     Sid Meiers Civilization VI        59.99       2.99         95.015836
# 6    Sid Meier's Civilization IV        19.99       2.99         85.042521
# 7       Half-Life 2: Episode Two         7.99       0.79         90.112641
# 8                         Portal         9.99       0.99         90.090090
# 9               Metro 2033 Redux        19.99       1.99         90.045023
#
#   Deal Rating Metacritic Score             Steam Rating
# 0        10.0               97            Very Positive
# 1        10.0               96  Overwhelmingly Positive
# 2        10.0               96  Overwhelmingly Positive
# 3        10.0               95  Overwhelmingly Positive
# 4        10.0               93  Overwhelmingly Positive
# 5         9.9               88            Very Positive
# 6         9.9               94            Very Positive
# 7         9.8               90  Overwhelmingly Positive
# 8         9.8               90  Overwhelmingly Positive
# 9         9.8               90            Very Positive
# Number of deals: 60
# Columns: Index(['internalName', 'title', 'metacriticLink', 'dealID', 'storeID',
#        'gameID', 'salePrice', 'normalPrice', 'isOnSale', 'savings',
#        'metacriticScore', 'steamRatingText', 'steamRatingPercent',
#        'steamRatingCount', 'steamAppID', 'releaseDate', 'lastChange',
#        'dealRating', 'thumb'],
#       dtype='object')
# Average discount: 88.72%
# C:\Users\ACER\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# Top 10 deals with the highest discount:
#                                 Title Normal Price Sale Price  \
# 49                     Helheim Hassle        51.96       1.20
# 25  Warhammer: End Times - Vermintide        44.99       2.24
# 5          Sid Meiers Civilization VI        59.99       2.99
# 46                Time on Frog Island        36.98       1.96
# 57                        Dreamscaper        76.95       5.03
# 10                      Battlefield 1        39.99       2.79
# 34                      Battlefield 4        39.99       2.79
# 39                      Battlefield V        49.99       3.49
# 42              Atomik: RunGunJumpGun         7.99       0.79
# 20           Half-Life 2: Episode One         7.99       0.79
#
#     Discount Percent Deal Rating Metacritic Score             Steam Rating
# 49         97.690531         9.1               71            Very Positive
# 25         95.021116         9.3               79            Very Positive
# 5          95.015836         9.9               88            Very Positive
# 46         94.699838         9.2               77          Mostly Positive
# 57         93.463288         9.1               80            Very Positive
# 10         93.023256         9.8               88            Very Positive
# 34         93.023256         9.2               81            Very Positive
# 39         93.018604         9.2               81          Mostly Positive
# 42         90.112641         9.2               82            Very Positive
# 20         90.112641         9.5               87  Overwhelmingly Positive
