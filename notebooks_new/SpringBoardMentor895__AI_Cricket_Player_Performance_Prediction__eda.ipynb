# %% [markdown]
# # Exploratory Data Analysis (EDA)
# Initial exploration of IPL data

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('ipl_data.csv')

# %%
# summary statistics
df.describe()

# %%
# value counts for runs
if 'runs' in df.columns:
    df['runs'].value_counts().head()

# %%
# histogram of runs
if 'runs' in df.columns:
    df['runs'].plot(kind='hist')
    plt.title('Runs Distribution')
    plt.show()
