# %% [markdown]
# # CA24: Advanced Multi-Agent Systems and Modern Agent Architectures
# ## A Comprehensive IEEE-Style Study of Language Agent Evolution
#
# ---
#
# ## Abstract
#
# This computational assignment presents a comprehensive exploration of advanced multi-agent systems with emphasis on modern language agent architectures. We systematically examine four foundational frameworks: **ReAct** (Reasoning and Acting), **Reflexion** (Self-Reflective Learning), **HippoRAG** (Hippocampus-Inspired Retrieval), and **Nexus** (Multi-Agent Collaboration). Through theoretical analysis and practical implementation, we demonstrate the evolutionary progression of agent capabilities from basic grounded reasoning to sophisticated collaborative intelligence.
#
# **Keywords:** Multi-Agent Systems, Language Agents, ReAct, Reflexion, HippoRAG, Nexus, Agent Architectures, Autonomous Systems
#
# ---
#
# ## I. INTRODUCTION
#
# ### A. Motivation and Research Context
#
# The emergence of Large Language Models (LLMs) has catalyzed a paradigm shift from isolated text generation to interactive, goal-oriented agent systems. Traditional LLMs operate in a closed loop—receiving input, processing internally, and generating output—without genuine environmental interaction or persistent memory. This fundamental limitation has motivated the development of agent architectures that transcend pure language modeling.
#
# Language agents represent a qualitative transformation, introducing:
# 1. **Environmental Grounding**: Direct interaction through tool use and API integration
# 2. **Experiential Learning**: Adaptation from successes and failures without retraining
# 3. **Associative Memory**: Rich knowledge structures enabling multi-hop reasoning
# 4. **Collaborative Intelligence**: Coordination among specialized agents
#
# ### B. Research Objectives
#
# This work pursues three primary objectives:
#
# 1. **Systematic Architecture Analysis**: Comprehensive examination of four agent frameworks, elucidating theoretical foundations and implementation strategies
#
# 2. **Evolutionary Pattern Recognition**: Articulation of architectural progression, demonstrating how each framework addresses predecessor limitations
#
# 3. **Practical Implementation**: Complete working implementations enabling direct performance comparison
#
# ---
#
# ## II. THEORETICAL FOUNDATIONS
#
# ### A. From Language Models to Language Agents
#
# #### 1. Architectural Transformation
#
# Traditional LLMs: `Input → Processing → Output`
#
# Language Agents: `Observation → Reasoning → Action → Feedback → ...`
#
# This shift enables:
# - **Reality Grounding**: Environmental feedback validates reasoning
# - **Tool Integration**: Access to external computational resources
# - **Error Detection**: Natural feedback loops identify incorrect actions
#
# #### 2. Memory Systems Evolution
#
# LLMs maintain only conversation-window context. Agents implement:
# - **Episodic Memory**: Past experience recording
# - **Semantic Memory**: Structured knowledge (graphs, vectors)
# - **Procedural Memory**: Learned action patterns
#
# #### 3. Goal-Directed Behavior
#
# Agents exhibit:
# - **Planning**: Goal decomposition into subtasks
# - **Execution**: Coordinated action sequences
# - **Monitoring**: Progress assessment with replanning
#
# ### B. The Four Framework Pillars
#
# #### 1. ReAct: Reasoning + Acting
#
# **Core Innovation**: Interleaving thoughts with actions
#
# ```
# Thought → Action → Observation → Thought → Action → ...
# ```
#
# **Foundation**: Dual-process theory (deliberative + reactive cognition)
#
# **Strengths**: Interpretability, grounding, tool integration
#
# **Limitations**: No learning, no memory, limited scalability
#
# #### 2. Reflexion: Self-Reflective Learning
#
# **Core Innovation**: Learning through self-reflection
#
# **Components**:
# - Actor: ReAct-based task execution
# - Evaluator: Success/failure assessment
# - Self-Reflection: Failure analysis and insight generation
#
# **Learning Mechanism**:
# ```
# Trial n → Failure → Reflection → Memory Update
# Trial n+1 → Actor + Insights → Improved Performance
# ```
#
# **Strengths**: Learning without retraining, sample efficiency
#
# **Limitations**: Reflection quality depends on LLM, limited memory capacity
#
# #### 3. HippoRAG: Neuro-Inspired Memory
#
# **Core Innovation**: Hippocampus-inspired two-stage memory
#
# **Architecture**:
# - Knowledge Graph (hippocampus): Rapid associative indexing
# - Document Store (neocortex): Detailed semantic knowledge
#
# **Retrieval Process**:
# ```
# Query → Entity Extraction → Graph Traversal (PPR) →
# Document Retrieval → Answer Generation
# ```
#
# **Strengths**: Multi-hop reasoning, large-scale knowledge, explainability
#
# **Limitations**: Static knowledge, single-agent architecture
#
# #### 4. Nexus: Multi-Agent Orchestration
#
# **Core Innovation**: Hierarchical multi-agent collaboration
#
# **Structure**:
# ```
#         Supervisor
#            ↓
#     ┌──────┼──────┐
#     ↓      ↓      ↓
# Specialist₁ Specialist₂ Specialist₃
# ```
#
# **Coordination Protocol**:
# 1. Task decomposition
# 2. Agent assignment
# 3. Parallel execution
# 4. Result synthesis
#
# **Strengths**: Scalability, specialization, fault tolerance
#
# **Limitations**: Coordination overhead, communication complexity
#
# ### C. Comparative Analysis
#
# | Dimension | ReAct | Reflexion | HippoRAG | Nexus |
# |-----------|-------|-----------|----------|-------|
# | **Innovation** | Grounded reasoning | Learning | Memory | Collaboration |
# | **Architecture** | Single-agent | Single + Memory | Single + Knowledge | Multi-agent |
# | **Learning** | None | Self-reflection | Static | Inherited |
# | **Memory** | Context only | Episodic | Semantic | Distributed |
# | **Scalability** | Poor | Limited | Medium | Excellent |
#
# ### D. Agent-First Design Philosophy
#
# **Traditional (LLM-First)**:
# ```
# Select LLM → Add Prompts → Attach Tools → Scale
# ```
#
# **Modern (Agent-First)**:
# ```
# Design Architecture → Define Interactions → Integrate Reasoning → Deploy
# ```
#
# **Implications**:
# 1. Architecture over scale
# 2. Specialization over generalization
# 3. Coordination over computation
# 4. Adaptability over optimization
#
# ---
#
# ## III. EXPERIMENTAL METHODOLOGY
#
# ### A. Travel Planning Test Domain
#
# **Domain Characteristics**:
# 1. Multi-domain integration (flights, hotels, activities)
# 2. Tool dependency (booking APIs, search services)
# 3. Failure scenarios (availability constraints)
# 4. Knowledge integration (multi-source synthesis)
# 5. Scalability testing (single → multi-day planning)
#
# ### B. Evaluation Scenarios
#
# **Level 1: Simple Task**
# - Single booking, available resources
# - Tests basic functionality
#
# **Level 2: Failure Recovery**
# - Unavailable resources
# - Tests adaptation capability
#
# **Level 3: Knowledge Integration**
# - Multi-hop queries
# - Tests memory architecture
#
# **Level 4: Multi-Domain**
# - Complete trip planning
# - Tests scalability and coordination
#
# ### C. Performance Metrics
#
# **Quantitative**:
# - Success rate (%)
# - Steps to completion
# - Learning trials
# - Retrieval accuracy
# - Coordination overhead
#
# **Qualitative**:
# - Reasoning transparency
# - Error recovery quality
# - Knowledge synthesis
# - Team coordination
#
# ---

# %% [markdown]
# # CA24: Advanced Multi-Agent Systems
#
# ## Comprehensive Guide to Multi-Agent Systems with Modern Techniques
#
# This notebook provides a complete implementation and demonstration of advanced multi-agent systems concepts including:
#
# 1. **Advanced Communication Systems**
#    - Message passing protocols
#    - Publish-subscribe patterns
#    - WebSocket communication
#    - Message routing and filtering
#
# 2. **Advanced Coordination Mechanisms**
#    - Hierarchical coordination
#    - Market-based allocation
#    - Coalition formation
#    - Consensus algorithms
#
# 3. **Multi-Agent Reinforcement Learning**
#    - Multi-Agent DQN
#    - Multi-Agent A2C
#    - Cooperative learning
#    - Competitive scenarios
#
# 4. **Practical Applications**
#    - Distributed problem solving
#    - Resource allocation
#    - Task scheduling
#    - Collaborative decision making
#
# ---
#
# ### Table of Contents
# 1. [Setup and Imports](#setup)
# 2. [Basic Multi-Agent System](#basic-mas)
# 3. [Advanced Communication](#communication)
# 4. [Advanced Coordination](#coordination)
# 5. [Multi-Agent RL](#marl)
# 6. [Complete Projects](#projects)
# 7. [Evaluation and Visualization](#evaluation)

# %% [markdown]
# ## IV. IMPLEMENTATION: ENVIRONMENTAL SETUP
#
# ### A. Simulation Framework Design
#
# The experimental framework implements a controlled environment for systematic agent evaluation. This design enables:
#
# 1. **Reproducibility**: Identical conditions across experiments
# 2. **Failure Injection**: Controlled error scenarios
# 3. **Cost Efficiency**: No external API costs
# 4. **Rapid Iteration**: Immediate feedback without latency
#
# ### B. TravelWorld Environment
#
# The `TravelWorld` class simulates a realistic travel planning domain with four integrated subsystems:
#
# #### 1. Flight Database
# ```python
# flights_db = {
#     (destination, date): {
#         "flight": flight_number,
#         "price": cost,
#         "available": boolean
#     }
# }
# ```
#
# **Design Features**:
# - Structured lookup with (destination, date) keys
# - Availability constraints model real-world capacity
# - Intentional failures (e.g., unavailable on 2025-10-25) test adaptation
#
# #### 2. Hotel System
# ```python
# hotels_db = {
#     (destination, check_in): {
#         "hotel": name,
#         "price": nightly_rate,
#         "available": boolean
#     }
# }
# ```
#
# **Dependency Structure**: Hotel bookings depend on flight success, creating task dependencies that test planning capabilities.
#
# #### 3. Activity Service
# ```python
# activities_db = {
#     (destination, day): [activity_list]
# }
# ```
#
# **Complexity Scaling**: Multi-day planning requires coordination across multiple activity sets.
#
# #### 4. Knowledge Base
# ```python
# knowledge_base = {
#     "doc_id": "unstructured_text"
# }
# ```
#
# **RAG Challenge**: Tests multi-hop reasoning:
# ```
# "Blog mentions museum" → "Louvre in 1st arr." →
# "Hotel Regina in 1st arr." → "Offers shuttle"
# ```
#
# ### C. SimpleLLMSimulator
#
# Deterministic LLM simulation for architectural focus:
#
# **Pattern-Based Generation**:
# ```python
# if "flight" in context:
#     thought = "Search for flights..."
#     action = "search_flights"
# ```
#
# **Benefits**:
# - Isolates architectural effects
# - Ensures reproducibility
# - Enables unlimited experimentation
# - Focuses on agent design vs. model quality
#
# ### D. StoryTeller: Narrative Pedagogy
#
# Implements narrative-driven learning:
# - Chapter markers for major transitions
# - Scene descriptions for demonstrations
# - Narrator commentary for insights
#
# **Educational Theory**: Stories enhance engagement, memory, and transfer [10-12].
#
# ### E. Experimental Design
#
# **Controlled Variables**:
# - Fixed: Environment structure, scenarios, metrics
# - Varied: Agent architecture, task complexity
#
# **Progressive Complexity**:
# 1. Simple: Single booking (baseline)
# 2. Failure: Unavailable resources (adaptation)
# 3. Knowledge: Multi-hop queries (memory)
# 4. Multi-domain: Complete trips (coordination)
#
# **Metrics**:
# - Quantitative: Success rate, efficiency, learning speed
# - Qualitative: Reasoning clarity, error recovery, synthesis quality
#
# ---

# %% [markdown]
# tin

# %%
# Setup and Imports
import sys
import os
import asyncio
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from pathlib import Path

# Add project paths
project_root = Path("..").resolve()
sys.path.insert(0, str(project_root / "src"))
sys.path.insert(0, str(project_root / "config"))

# Import multi-agent system components
from core.multi_agent_system import (
    MultiAgentSystem, BaseAgent, Task, AgentStatus,
    CoordinatorAgent, ResearcherAgent, AnalystAgent
)

from core.advanced_communication import (
    AdvancedCommunicationManager, AdvancedMessage,
    MessagePriority, CommunicationProtocol, MessageRouter, MessageFilter
)

from core.advanced_coordination import (
    AdvancedCoordinationManager, CoordinationStrategy,
    TaskAllocator, TaskAllocationMethod, CoalitionManager,
    ConsensusAlgorithm, AgentCapability, CoordinationTask
)

from core.multi_agent_rl import (
    MultiAgentRLSystem, MADQNAgent, MAA2CAgent,
    MultiAgentEnvironment, ReplayBuffer
)

# Visualization settings
plt.style.use('seaborn-v0_8-darkgrid')
sns.set_palette("husl")

print("✅ All imports successful!")
print(f"📁 Project root: {project_root}")

# %% [markdown]
# ## Part 1: Basic Multi-Agent System
#
# ### Creating a Simple Multi-Agent System
#
# Let's start by creating a basic multi-agent system with coordinator, researcher, and analyst agents.

# %% [markdown]
# # CA24: Multi-Agent Systems with Gemini API, LangChain, and RAG
#
# ## 🤖 سیستم‌های چند عاملی پیشرفته با Gemini API
#
# این نوت‌بوک یک پیاده‌سازی کامل و تجربی از سیستم‌های چند عاملی با استفاده از:
# - **Gemini API** برای پردازش زبان طبیعی
# - **LangChain** برای زنجیره‌های پردازش
# - **RAG (Retrieval-Augmented Generation)** برای بهبود پاسخ‌ها
# - **سیستم‌های ارتباطی پیشرفته** برای هماهنگی Agent ها
#
# ## 🎯 ویژگی‌های کلیدی
#
# - سیستم Multi-Agent با Gemini API
# - پیاده‌سازی RAG با LangChain
# - سیستم ارتباطی بین Agent ها
# - مدیریت منابع و هماهنگی
# - نظارت بر عملکرد سیستم
# - مثال‌های عملی و تجربی

# %%
# نصب و وارد کردن کتابخانه‌های مورد نیاز
import os
import sys
import json
import asyncio
import time
from datetime import datetime, timedelta
from typing import Dict, List, Any, Optional
import uuid
from pathlib import Path

# اضافه کردن مسیر src به Python path
sys.path.append('./src')
sys.path.append('./config')

# کتابخانه‌های اصلی
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from IPython.display import display, HTML, Markdown
import warnings
warnings.filterwarnings('ignore')

# تنظیمات نمایش
plt.style.use('seaborn-v0_8')
sns.set_palette("husl")
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)

print("✅ کتابخانه‌های اصلی بارگذاری شدند")
print(f"📅 تاریخ اجرا: {datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
print(f"🐍 نسخه Python: {sys.version}")
print(f"📁 مسیر کاری: {os.getcwd()}")

# %%
# بارگذاری ماژول‌های سیستم چند عاملی
try:
    # پیکربندی Gemini
    from config.gemini_config import (
        GeminiConfig, GeminiManager, AgentGeminiConfig,
        load_gemini_config_from_env, load_gemini_config_from_file
    )
    
    # سیستم چند عاملی
    from src.core.multi_agent_system import (
        BaseAgent, CoordinatorAgent, ResearcherAgent, AnalystAgent,
        MultiAgentSystem, AgentStatus, MessageType, Task
    )
    
    # سیستم RAG
    from src.core.rag_system import (
        RAGConfig, RAGSystem, RAGAgent, DocumentProcessor,
        VectorStoreManager, create_sample_documents
    )
    
    # سیستم ارتباطی
    from src.core.communication_system import (
        CommunicationManager, Message, MessagePriority, 
        CommunicationProtocol, MessageType as CommMessageType
    )
    
    # سیستم هماهنگی
    from src.core.coordination_system import (
        CoordinationManager, CoordinationStrategy, TaskAllocator,
        ResourceManager, SystemMonitor, AgentCapability, ResourceType
    )
    
    print("✅ تمام ماژول‌های سیستم چند عاملی بارگذاری شدند")
    
except ImportError as e:
    print(f"❌ خطا در بارگذاری ماژول‌ها: {e}")
    print("لطفاً مطمئن شوید که فایل‌های مورد نیاز در مسیر صحیح قرار دارند")

# %% [markdown]
# ## 🔧 بخش 1: راه‌اندازی و پیکربندی Gemini API
#
# در این بخش، پیکربندی Gemini API و راه‌اندازی اولیه سیستم را انجام می‌دهیم.

# %%
# تنظیم API Key برای Gemini
# لطفاً کلید API خود را در متغیر محیطی GEMINI_API_KEY قرار دهید

# بررسی وجود API Key
gemini_api_key = os.getenv("GEMINI_API_KEY")

if not gemini_api_key:
    print("⚠️ متغیر محیطی GEMINI_API_KEY تنظیم نشده است")
    print("لطفاً کلید API خود را تنظیم کنید:")
    print("export GEMINI_API_KEY='your_api_key_here'")
    
    # برای تست، می‌توانید کلید را مستقیماً اینجا قرار دهید (نه توصیه می‌شود)
    # gemini_api_key = "your_api_key_here"
else:
    print("✅ کلید API Gemini پیدا شد")
    print(f"🔑 طول کلید: {len(gemini_api_key)} کاراکتر")

# ایجاد پیکربندی Gemini
if gemini_api_key:
    try:
        gemini_config = GeminiConfig(
            api_key=gemini_api_key,
            model_name="gemini-1.5-pro",
            temperature=0.7,
            max_tokens=2048,
            top_p=0.9,
            top_k=40
        )
        
        # ایجاد مدیر Gemini
        gemini_manager = GeminiManager(gemini_config)
        
        print("✅ پیکربندی Gemini ایجاد شد")
        print(f"🤖 مدل: {gemini_config.model_name}")
        print(f"🌡️ دما: {gemini_config.temperature}")
        print(f"📝 حداکثر توکن: {gemini_config.max_tokens}")
        
    except Exception as e:
        print(f"❌ خطا در ایجاد پیکربندی Gemini: {e}")
        gemini_manager = None
else:
    gemini_manager = None
    print("❌ بدون کلید API، ادامه کار امکان‌پذیر نیست")

# %%
# تست اتصال به Gemini API
if gemini_manager:
    print("🧪 تست اتصال به Gemini API...")
    
    try:
        # تست ساده
        test_prompt = """
        سلام! لطفاً خودت را معرفی کن و بگو که چه کاری می‌تونی انجام بدی.
        پاسخ کوتاه و مفید ارائه دهید.
        """
        
        print("📤 ارسال درخواست تست...")
        start_time = time.time()
        
        response = gemini_manager.generate_text(test_prompt)
        
        end_time = time.time()
        response_time = end_time - start_time
        
        print("✅ پاسخ دریافت شد!")
        print(f"⏱️ زمان پاسخ: {response_time:.2f} ثانیه")
        print(f"📝 طول پاسخ: {len(response)} کاراکتر")
        print("\n🤖 پاسخ Gemini:")
        print("-" * 50)
        print(response)
        print("-" * 50)
        
        # تست LangChain Gemini
        print("\n🧪 تست LangChain Gemini...")
        
        from langchain_core.messages import HumanMessage
        
        messages = [HumanMessage(content="لطفاً یک جمله کوتاه درباره هوش مصنوعی بنویسید.")]
        langchain_response = gemini_manager.generate_with_langchain(messages)
        
        print("✅ پاسخ LangChain دریافت شد!")
        print(f"📝 پاسخ: {langchain_response}")
        
    except Exception as e:
        print(f"❌ خطا در تست Gemini API: {e}")
        print("لطفاً کلید API خود را بررسی کنید")
else:
    print("⏭️ تست Gemini API رد شد - کلید API موجود نیست")

# %% [markdown]
# ## 🤖 بخش 2: ایجاد سیستم RAG با LangChain
#
# در این بخش، سیستم RAG (Retrieval-Augmented Generation) را با استفاده از LangChain و Gemini API پیاده‌سازی می‌کنیم.

# %%
# ایجاد سیستم RAG
if gemini_manager:
    print("🔧 راه‌اندازی سیستم RAG...")
    
    # پیکربندی RAG
    rag_config = RAGConfig(
        chunk_size=500,
        chunk_overlap=100,
        top_k=3,
        temperature=0.7,
        vector_store_type="chroma",
        persist_directory="./vector_store",
        llm_model="gemini-1.5-pro"
    )
    
    # ایجاد سیستم RAG
    try:
        rag_system = RAGSystem(rag_config, gemini_api_key)
        print("✅ سیستم RAG ایجاد شد")
        
        # ایجاد Agent RAG
        rag_agent = RAGAgent("rag_agent_1", rag_system, "rag_specialist")
        print("✅ Agent RAG ایجاد شد")
        
    except Exception as e:
        print(f"❌ خطا در ایجاد سیستم RAG: {e}")
        rag_system = None
        rag_agent = None
else:
    print("⏭️ ایجاد سیستم RAG رد شد - Gemini API در دسترس نیست")
    rag_system = None
    rag_agent = None

# %%
# ایجاد و بارگذاری اسناد نمونه برای RAG
if rag_system:
    print("📚 ایجاد اسناد نمونه...")
    
    # ایجاد پوشه اسناد نمونه
    sample_dir = Path("./sample_documents")
    sample_dir.mkdir(exist_ok=True)
    
    # محتوای نمونه درباره هوش مصنوعی
    ai_knowledge_content = """
    هوش مصنوعی (Artificial Intelligence) شاخه‌ای از علوم کامپیوتر است که به ایجاد سیستم‌هایی می‌پردازد که قادر به انجام وظایفی هستند که معمولاً نیاز به هوش انسانی دارند.
    
    یادگیری ماشین (Machine Learning) زیرشاخه‌ای از هوش مصنوعی است که به سیستم‌ها امکان یادگیری از داده‌ها را بدون برنامه‌نویسی صریح می‌دهد. این تکنولوژی در تشخیص الگو، پیش‌بینی و تصمیم‌گیری کاربرد دارد.
    
    یادگیری عمیق (Deep Learning) نوعی از یادگیری ماشین است که از شبکه‌های عصبی مصنوعی با چندین لایه استفاده می‌کند. این روش در پردازش تصویر، تشخیص گفتار و پردازش زبان طبیعی بسیار مؤثر است.
    
    پردازش زبان طبیعی (Natural Language Processing) شاخه‌ای از هوش مصنوعی است که به تعامل بین کامپیوترها و زبان انسانی می‌پردازد. این تکنولوژی در ترجمه ماشینی، خلاصه‌سازی متن و چت‌بات‌ها استفاده می‌شود.
    
    بینایی کامپیوتر (Computer Vision) شاخه‌ای از هوش مصنوعی است که به کامپیوترها امکان درک و تفسیر اطلاعات بصری را می‌دهد. این تکنولوژی در تشخیص اشیاء، تشخیص چهره و رانندگی خودکار کاربرد دارد.
    
    سیستم‌های چند عاملی (Multi-Agent Systems) شامل مجموعه‌ای از Agent های خودمختار هستند که با یکدیگر تعامل می‌کنند تا اهداف مشترک را محقق کنند. این سیستم‌ها در حل مسائل پیچیده و توزیع شده کاربرد دارند.
    
    RAG (Retrieval-Augmented Generation) تکنیکی است که ترکیبی از بازیابی اطلاعات و تولید متن است. این روش با استفاده از پایگاه دانش خارجی، پاسخ‌های دقیق‌تر و به‌روزتری ارائه می‌دهد.
    """
    
    # ذخیره محتوا در فایل
    with open(sample_dir / "ai_knowledge.txt", "w", encoding="utf-8") as f:
        f.write(ai_knowledge_content)
    
    # محتوای نمونه درباره یادگیری ماشین
    ml_knowledge_content = """
    یادگیری ماشین شامل سه نوع اصلی است:
    
    1. یادگیری نظارت شده (Supervised Learning): در این روش، مدل با استفاده از داده‌های برچسب‌دار آموزش می‌بیند. مثال‌هایی از این نوع شامل طبقه‌بندی و رگرسیون است.
    
    2. یادگیری بدون نظارت (Unsupervised Learning): در این روش، مدل الگوهای موجود در داده‌های بدون برچسب را کشف می‌کند. مثال‌هایی از این نوع شامل خوشه‌بندی و کاهش ابعاد است.
    
    3. یادگیری تقویتی (Reinforcement Learning): در این روش، مدل از طریق تعامل با محیط و دریافت پاداش یا تنبیه یاد می‌گیرد. این روش در بازی‌ها و رباتیک کاربرد دارد.
    
    الگوریتم‌های مهم یادگیری ماشین شامل:
    - درخت تصمیم (Decision Trees)
    - جنگل تصادفی (Random Forest)
    - ماشین بردار پشتیبان (Support Vector Machine)
    - شبکه‌های عصبی (Neural Networks)
    - الگوریتم k-means برای خوشه‌بندی
    
    ارزیابی مدل‌های یادگیری ماشین با استفاده از معیارهایی مانند دقت، یادآوری، F1-score و AUC انجام می‌شود.
    """
    
    with open(sample_dir / "ml_knowledge.txt", "w", encoding="utf-8") as f:
        f.write(ml_knowledge_content)
    
    print(f"✅ اسناد نمونه ایجاد شدند در {sample_dir}")
    
    # بارگذاری اسناد در سیستم RAG
    print("📥 بارگذاری اسناد در سیستم RAG...")
    
    try:
        sample_files = [
            str(sample_dir / "ai_knowledge.txt"),
            str(sample_dir / "ml_knowledge.txt")
        ]
        
        rag_system.load_knowledge_base(sample_files)
        print("✅ اسناد در سیستم RAG بارگذاری شدند")
        
    except Exception as e:
        print(f"❌ خطا در بارگذاری اسناد: {e}")
else:
    print("⏭️ ایجاد اسناد نمونه رد شد - سیستم RAG در دسترس نیست")

# %%
# تست سیستم RAG
if rag_agent:
    print("🧪 تست سیستم RAG...")
    
    # سوالات تست
    test_questions = [
        "هوش مصنوعی چیست؟",
        "تفاوت بین یادگیری ماشین و یادگیری عمیق چیست؟",
        "انواع یادگیری ماشین را توضیح دهید",
        "RAG چیست و چگونه کار می‌کند؟",
        "سیستم‌های چند عاملی چه کاربردی دارند؟"
    ]
    
    print("📋 سوالات تست:")
    for i, question in enumerate(test_questions, 1):
        print(f"{i}. {question}")
    
    print("\n" + "="*60)
    
    # تست هر سوال
    for i, question in enumerate(test_questions, 1):
        print(f"\n🔍 سوال {i}: {question}")
        print("-" * 50)
        
        try:
            start_time = time.time()
            result = rag_agent.process_query(question)
            end_time = time.time()
            
            if "error" not in result:
                print(f"✅ پاسخ دریافت شد (زمان: {end_time - start_time:.2f}s)")
                print(f"📝 پاسخ: {result['answer']}")
                
                if result.get('source_documents'):
                    print(f"📚 اسناد مرجع: {len(result['source_documents'])} سند")
                    for j, doc in enumerate(result['source_documents'][:2], 1):
                        print(f"   {j}. {doc.page_content[:100]}...")
            else:
                print(f"❌ خطا: {result['error']}")
                
        except Exception as e:
            print(f"❌ خطا در پردازش سوال: {e}")
        
        print("-" * 50)
    
    # نمایش آمار Agent RAG
    print("\n📊 آمار Agent RAG:")
    stats = rag_agent.get_knowledge_summary()
    print(f"🆔 Agent ID: {stats['agent_id']}")
    print(f"🎯 تخصص: {stats['specialization']}")
    print(f"📈 آمار دانش: {json.dumps(stats['knowledge_stats'], indent=2, ensure_ascii=False)}")
    
else:
    print("⏭️ تست سیستم RAG رد شد - Agent RAG در دسترس نیست")

# %% [markdown]
# ## 🤝 بخش 3: سیستم چند عاملی با Gemini API
#
# در این بخش، سیستم چند عاملی کامل را با استفاده از Gemini API و کامپوننت‌های مختلف ایجاد می‌کنیم.

# %%
# ایجاد سیستم چند عاملی
if gemini_manager:
    print("🤖 راه‌اندازی سیستم چند عاملی...")
    
    try:
        # ایجاد سیستم چند عاملی
        mas = MultiAgentSystem(gemini_config)
        await mas.initialize()
        
        print("✅ سیستم چند عاملی راه‌اندازی شد")
        
        # نمایش وضعیت سیستم
        system_status = await mas.get_system_status()
        print(f"📊 وضعیت سیستم: {json.dumps(system_status, indent=2, ensure_ascii=False)}")
        
    except Exception as e:
        print(f"❌ خطا در راه‌اندازی سیستم چند عاملی: {e}")
        mas = None
else:
    print("⏭️ راه‌اندازی سیستم چند عاملی رد شد - Gemini API در دسترس نیست")
    mas = None

# %%
# تست سیستم چند عاملی
if mas:
    print("🧪 تست سیستم چند عاملی...")
    
    # ارسال وظایف مختلف
    test_tasks = [
        {
            "description": "research_topic",
            "parameters": {"topic": "هوش مصنوعی و آینده کار"}
        },
        {
            "description": "analyze_patterns", 
            "parameters": {"data": "داده‌های فروش ماهانه"}
        },
        {
            "description": "coordinate_agents",
            "parameters": {"action": "هماهنگی پروژه جدید"}
        }
    ]
    
    print("📋 وظایف تست:")
    for i, task in enumerate(test_tasks, 1):
        print(f"{i}. {task['description']}: {task['parameters']}")
    
    print("\n" + "="*60)
    
    # ارسال و اجرای وظایف
    task_results = []
    
    for i, task_data in enumerate(test_tasks, 1):
        print(f"\n📤 ارسال وظیفه {i}: {task_data['description']}")
        
        try:
            task_id = await mas.submit_task(
                description=task_data["description"],
                parameters=task_data["parameters"]
            )
            
            print(f"✅ وظیفه ارسال شد - ID: {task_id}")
            task_results.append({"task_id": task_id, "description": task_data["description"]})
            
        except Exception as e:
            print(f"❌ خطا در ارسال وظیفه: {e}")
    
    # انتظار برای پردازش
    print("\n⏳ انتظار برای پردازش وظایف...")
    await asyncio.sleep(3)
    
    # نمایش نتایج
    print("\n📊 نتایج وظایف:")
    for result in task_results:
        print(f"🆔 {result['task_id']}: {result['description']}")
    
    # دریافت وضعیت نهایی سیستم
    final_status = await mas.get_system_status()
    print(f"\n📈 وضعیت نهایی سیستم:")
    print(f"🔢 تعداد Agent ها: {final_status['total_agents']}")
    print(f"🏃 وضعیت سیستم: {final_status['system_status']}")
    
    # خاموش کردن سیستم
    await mas.shutdown()
    print("🔌 سیستم چند عاملی خاموش شد")
    
else:
    print("⏭️ تست سیستم چند عاملی رد شد - سیستم در دسترس نیست")

# %% [markdown]
# ## 🔗 بخش 4: سیستم ارتباطی و هماهنگی پیشرفته
#
# در این بخش، سیستم ارتباطی پیشرفته و هماهنگی بین Agent ها را پیاده‌سازی می‌کنیم.

# %%
# ایجاد سیستم ارتباطی و هماهنگی پیشرفته
print("🔗 راه‌اندازی سیستم ارتباطی و هماهنگی...")

try:
    # ایجاد مدیر ارتباطات
    comm_manager = CommunicationManager("memory")
    print("✅ مدیر ارتباطات ایجاد شد")
    
    # ایجاد مدیر هماهنگی
    coord_manager = CoordinationManager(
        comm_manager, 
        CoordinationStrategy.HIERARCHICAL
    )
    await coord_manager.initialize()
    print("✅ مدیر هماهنگی ایجاد شد")
    
    # تعریف Agent های تخصصی
    class AdvancedAgent:
        def __init__(self, agent_id: str, specialization: str):
            self.agent_id = agent_id
            self.specialization = specialization
            self.tasks_completed = 0
            self.messages_received = 0
        
        async def handle_task_message(self, message):
            print(f"📨 Agent {self.agent_id} پیام وظیفه دریافت کرد: {message.content}")
            self.messages_received += 1
            
            # شبیه‌سازی پردازش وظیفه
            await asyncio.sleep(1)
            self.tasks_completed += 1
            
            return {"status": "completed", "agent_id": self.agent_id}
        
        async def handle_coordination_message(self, message):
            print(f"🤝 Agent {self.agent_id} پیام هماهنگی دریافت کرد: {message.content}")
            self.messages_received += 1
            return {"status": "coordinated", "agent_id": self.agent_id}
    
    # ایجاد Agent های مختلف
    agents = {
        "researcher": AdvancedAgent("researcher_1", "research"),
        "analyst": AdvancedAgent("analyst_1", "analysis"), 
        "coordinator": AdvancedAgent("coordinator_1", "coordination"),
        "validator": AdvancedAgent("validator_1", "validation")
    }
    
    print(f"✅ {len(agents)} Agent ایجاد شدند")
    
    # تعریف قابلیت‌های Agent ها
    capabilities_map = {
        "researcher_1": [
            AgentCapability("research", 0.9, ["research", "investigation"], {ResourceType.CPU: 30.0}),
            AgentCapability("analysis", 0.8, ["analysis", "evaluation"], {ResourceType.MEMORY: 25.0})
        ],
        "analyst_1": [
            AgentCapability("data_analysis", 0.95, ["analysis", "statistics"], {ResourceType.CPU: 35.0}),
            AgentCapability("pattern_recognition", 0.85, ["patterns", "trends"], {ResourceType.MEMORY: 30.0})
        ],
        "coordinator_1": [
            AgentCapability("coordination", 0.9, ["coordination", "management"], {ResourceType.CPU: 20.0}),
            AgentCapability("communication", 0.85, ["communication", "reporting"], {ResourceType.API_CALLS: 15.0})
        ],
        "validator_1": [
            AgentCapability("validation", 0.95, ["validation", "verification"], {ResourceType.CPU: 25.0}),
            AgentCapability("quality_control", 0.9, ["quality", "control"], {ResourceType.MEMORY: 20.0})
        ]
    }
    
    # ثبت Agent ها در سیستم
    for agent_id, agent in agents.items():
        capabilities = capabilities_map.get(agent_id, [])
        await coord_manager.register_agent(agent_id, agent, capabilities)
        
        # اضافه کردن handlers
        await comm_manager.add_message_handler(agent_id, "task", agent.handle_task_message)
        await comm_manager.add_message_handler(agent_id, "coordination", agent.handle_coordination_message)
    
    print("✅ تمام Agent ها ثبت شدند")
    
except Exception as e:
    print(f"❌ خطا در راه‌اندازی سیستم ارتباطی: {e}")
    comm_manager = None
    coord_manager = None
    agents = {}

# %%
# تست سیستم ارتباطی و هماهنگی
if coord_manager and comm_manager:
    print("🧪 تست سیستم ارتباطی و هماهنگی...")
    
    # شروع پردازش پیام‌ها برای تمام Agent ها
    processing_tasks = []
    for agent_id in agents.keys():
        task = asyncio.create_task(comm_manager.start_message_processing(agent_id))
        processing_tasks.append(task)
    
    print("✅ پردازش پیام‌ها شروع شد")
    
    # انتظار کوتاه برای راه‌اندازی
    await asyncio.sleep(1)
    
    # تست 1: ارسال وظایف مختلف
    print("\n📋 تست 1: ارسال وظایف")
    
    test_tasks = [
        Task(description="تحلیل داده‌های فروش", parameters={"dataset": "sales_2024"}),
        Task(description="تحقیق در مورد روندهای بازار", parameters={"topic": "market_trends"}),
        Task(description="هماهنگی پروژه جدید", parameters={"project": "ai_integration"}),
        Task(description="اعتبارسنجی نتایج", parameters={"results": "analysis_output"})
    ]
    
    task_ids = []
    for task in test_tasks:
        task_id = await coord_manager.submit_task(task)
        task_ids.append(task_id)
        print(f"📤 وظیفه ارسال شد: {task.description} (ID: {task_id})")
    
    # تست 2: ارتباطات مختلف
    print("\n📨 تست 2: انواع ارتباطات")
    
    # پیام مستقیم
    await comm_manager.send_message(
        sender="coordinator",
        receiver="researcher_1", 
        message_type="task",
        content={"message": "لطفاً تحقیق جدیدی شروع کنید"},
        priority=MessagePriority.HIGH
    )
    
    # پیام عمومی
    await comm_manager.broadcast_message(
        sender="coordinator",
        message_type="announcement",
        content={"message": "سیستم آماده است - تمام Agent ها فعال هستند"}
    )
    
    # پیام چندگانه
    await comm_manager.multicast_message(
        sender="coordinator",
        receivers=["analyst_1", "validator_1"],
        message_type="coordination",
        content={"action": "هماهنگی تحلیل داده‌ها"}
    )
    
    # تست 3: هماهنگی پیشرفته
    print("\n🤝 تست 3: هماهنگی پیشرفته")
    
    # هماهنگی توزیع وظایف
    coordination_result = await coord_manager.coordinate_agents({
        "type": "task_distribution",
        "tasks": [task.__dict__ for task in test_tasks],
        "strategy": "balanced"
    })
    print(f"✅ نتیجه هماهنگی توزیع: {coordination_result}")
    
    # هماهنگی بهینه‌سازی منابع
    optimization_result = await coord_manager.coordinate_agents({
        "type": "resource_optimization"
    })
    print(f"✅ نتیجه بهینه‌سازی منابع: {optimization_result}")
    
    # انتظار برای پردازش
    print("\n⏳ انتظار برای پردازش...")
    await asyncio.sleep(3)
    
    # نمایش آمار
    print("\n📊 آمار سیستم:")
    
    # آمار ارتباطات
    comm_stats = comm_manager.get_communication_stats()
    print(f"📨 آمار ارتباطات: {json.dumps(comm_stats, indent=2, ensure_ascii=False)}")
    
    # آمار هماهنگی
    coord_status = await coord_manager.get_system_status()
    print(f"🤝 آمار هماهنگی: {json.dumps(coord_status, indent=2, ensure_ascii=False)}")
    
    # آمار Agent ها
    print("\n👥 آمار Agent ها:")
    for agent_id, agent in agents.items():
        print(f"🆔 {agent_id}: {agent.tasks_completed} وظیفه تکمیل شده، {agent.messages_received} پیام دریافت شده")
    
    # توقف پردازش
    await comm_manager.stop_message_processing()
    for task in processing_tasks:
        task.cancel()
    
    print("🔌 سیستم ارتباطی خاموش شد")
    
else:
    print("⏭️ تست سیستم ارتباطی رد شد - سیستم در دسترس نیست")

# %% [markdown]
# ## 📊 بخش 5: تجسم و تحلیل نتایج
#
# در این بخش، نتایج سیستم چند عاملی را تجسم و تحلیل می‌کنیم.

# %%
# تجسم و تحلیل نتایج سیستم چند عاملی
print("📊 تجسم و تحلیل نتایج...")

# ایجاد داده‌های نمونه برای تجسم
if 'agents' in locals() and agents:
    # داده‌های عملکرد Agent ها
    agent_performance_data = []
    for agent_id, agent in agents.items():
        agent_performance_data.append({
            'agent_id': agent_id,
            'specialization': agent.specialization,
            'tasks_completed': agent.tasks_completed,
            'messages_received': agent.messages_received,
            'efficiency': agent.tasks_completed / max(agent.messages_received, 1)
        })
    
    # تبدیل به DataFrame
    df_performance = pd.DataFrame(agent_performance_data)
    
    print("📈 داده‌های عملکرد Agent ها:")
    display(df_performance)
    
    # نمودار عملکرد Agent ها
    fig, axes = plt.subplots(2, 2, figsize=(15, 12))
    fig.suptitle('تحلیل عملکرد سیستم چند عاملی', fontsize=16, fontweight='bold')
    
    # نمودار 1: وظایف تکمیل شده
    axes[0, 0].bar(df_performance['agent_id'], df_performance['tasks_completed'], 
                   color='skyblue', alpha=0.7)
    axes[0, 0].set_title('وظایف تکمیل شده توسط هر Agent')
    axes[0, 0].set_xlabel('Agent ID')
    axes[0, 0].set_ylabel('تعداد وظایف')
    axes[0, 0].tick_params(axis='x', rotation=45)
    
    # نمودار 2: پیام‌های دریافت شده
    axes[0, 1].bar(df_performance['agent_id'], df_performance['messages_received'],
                   color='lightcoral', alpha=0.7)
    axes[0, 1].set_title('پیام‌های دریافت شده توسط هر Agent')
    axes[0, 1].set_xlabel('Agent ID')
    axes[0, 1].set_ylabel('تعداد پیام‌ها')
    axes[0, 1].tick_params(axis='x', rotation=45)
    
    # نمودار 3: کارایی Agent ها
    axes[1, 0].bar(df_performance['agent_id'], df_performance['efficiency'],
                   color='lightgreen', alpha=0.7)
    axes[1, 0].set_title('کارایی Agent ها (وظایف/پیام)')
    axes[1, 0].set_xlabel('Agent ID')
    axes[1, 0].set_ylabel('کارایی')
    axes[1, 0].tick_params(axis='x', rotation=45)
    
    # نمودار 4: توزیع تخصص‌ها
    specialization_counts = df_performance['specialization'].value_counts()
    axes[1, 1].pie(specialization_counts.values, labels=specialization_counts.index,
                   autopct='%1.1f%%', startangle=90)
    axes[1, 1].set_title('توزیع تخصص‌های Agent ها')
    
    plt.tight_layout()
    plt.show()
    
    # تحلیل آماری
    print("\n📊 تحلیل آماری:")
    print(f"🔢 تعداد کل Agent ها: {len(df_performance)}")
    print(f"📈 میانگین وظایف تکمیل شده: {df_performance['tasks_completed'].mean():.2f}")
    print(f"📨 میانگین پیام‌های دریافت شده: {df_performance['messages_received'].mean():.2f}")
    print(f"⚡ میانگین کارایی: {df_performance['efficiency'].mean():.2f}")
    
    # بهترین Agent
    best_agent = df_performance.loc[df_performance['efficiency'].idxmax()]
    print(f"🏆 بهترین Agent: {best_agent['agent_id']} (کارایی: {best_agent['efficiency']:.2f})")
    
else:
    print("⚠️ داده‌های Agent ها برای تجسم موجود نیست")

# %%
# تجسم عملکرد سیستم RAG
if 'rag_agent' in locals() and rag_agent:
    print("📊 تجسم عملکرد سیستم RAG...")
    
    # داده‌های عملکرد RAG
    rag_stats = rag_agent.get_knowledge_summary()
    
    # نمودار عملکرد RAG
    fig, axes = plt.subplots(1, 3, figsize=(18, 6))
    fig.suptitle('تحلیل عملکرد سیستم RAG', fontsize=16, fontweight='bold')
    
    # نمودار 1: آمار پرسش‌ها
    knowledge_stats = rag_stats['knowledge_stats']
    categories = ['کل پرسش‌ها', 'پرسش‌های موفق', 'پرسش‌های ناموفق']
    values = [knowledge_stats['total_queries'], 
              knowledge_stats['successful_queries'], 
              knowledge_stats['failed_queries']]
    
    axes[0].bar(categories, values, color=['skyblue', 'lightgreen', 'lightcoral'], alpha=0.7)
    axes[0].set_title('آمار پرسش‌های RAG')
    axes[0].set_ylabel('تعداد')
    axes[0].tick_params(axis='x', rotation=45)
    
    # نمودار 2: نرخ موفقیت
    success_rate = knowledge_stats['successful_queries'] / max(knowledge_stats['total_queries'], 1) * 100
    failure_rate = knowledge_stats['failed_queries'] / max(knowledge_stats['total_queries'], 1) * 100
    
    axes[1].pie([success_rate, failure_rate], 
                labels=['موفق', 'ناموفق'], 
                colors=['lightgreen', 'lightcoral'],
                autopct='%1.1f%%', startangle=90)
    axes[1].set_title('نرخ موفقیت پرسش‌ها')
    
    # نمودار 3: اطلاعات Agent
    agent_info = [rag_stats['agent_id'], rag_stats['specialization']]
    axes[2].text(0.5, 0.7, f"Agent ID: {rag_stats['agent_id']}", 
                ha='center', va='center', fontsize=12, fontweight='bold')
    axes[2].text(0.5, 0.5, f"تخصص: {rag_stats['specialization']}", 
                ha='center', va='center', fontsize=12)
    axes[2].text(0.5, 0.3, f"کل اسناد: {rag_stats.get('total_documents', 0)}", 
                ha='center', va='center', fontsize=12)
    axes[2].set_xlim(0, 1)
    axes[2].set_ylim(0, 1)
    axes[2].set_title('اطلاعات Agent RAG')
    axes[2].axis('off')
    
    plt.tight_layout()
    plt.show()
    
    print(f"📈 آمار سیستم RAG:")
    print(f"🆔 Agent ID: {rag_stats['agent_id']}")
    print(f"🎯 تخصص: {rag_stats['specialization']}")
    print(f"📊 آمار دانش: {json.dumps(knowledge_stats, indent=2, ensure_ascii=False)}")
    
else:
    print("⚠️ داده‌های سیستم RAG برای تجسم موجود نیست")

# %% [markdown]
# ## 🎯 بخش 6: مثال عملی و سناریوهای کاربردی
#
# در این بخش، مثال‌های عملی و سناریوهای کاربردی سیستم چند عاملی را ارائه می‌دهیم.

# %%
# سناریو عملی: تحلیل پروژه هوش مصنوعی
print("🎯 سناریو عملی: تحلیل پروژه هوش مصنوعی")
print("="*60)

# تعریف سناریو
scenario_description = """
سناریو: یک شرکت فناوری می‌خواهد پروژه جدیدی در زمینه هوش مصنوعی راه‌اندازی کند.
تیم چند عاملی باید این پروژه را تحلیل، برنامه‌ریزی و اجرا کند.

مراحل:
1. تحقیق در مورد روندهای فعلی هوش مصنوعی
2. تحلیل بازار و رقبا
3. برنامه‌ریزی پروژه
4. ارزیابی ریسک‌ها
5. ارائه گزارش نهایی
"""

print(scenario_description)

# شبیه‌سازی سناریو
if gemini_manager:
    print("\n🚀 شروع شبیه‌سازی سناریو...")
    
    # مرحله 1: تحقیق
    print("\n📚 مرحله 1: تحقیق در مورد روندهای هوش مصنوعی")
    research_prompt = """
    شما یک محقق متخصص در زمینه هوش مصنوعی هستید. لطفاً در مورد روندهای فعلی و آینده هوش مصنوعی تحقیق کنید.
    
    موضوعات مورد نظر:
    - آخرین پیشرفت‌ها در یادگیری عمیق
    - کاربردهای جدید هوش مصنوعی
    - چالش‌ها و فرصت‌های موجود
    - پیش‌بینی روندهای آینده
    
    گزارش جامع و مفصل ارائه دهید.
    """
    
    try:
        research_result = gemini_manager.generate_text(research_prompt)
        print("✅ گزارش تحقیق تکمیل شد")
        print(f"📝 خلاصه گزارش: {research_result[:200]}...")
    except Exception as e:
        print(f"❌ خطا در تحقیق: {e}")
        research_result = "گزارش تحقیق در دسترس نیست"
    
    # مرحله 2: تحلیل بازار
    print("\n📊 مرحله 2: تحلیل بازار و رقبا")
    market_analysis_prompt = """
    شما یک تحلیلگر بازار متخصص هستید. لطفاً تحلیل جامعی از بازار هوش مصنوعی ارائه دهید.
    
    موارد مورد نظر:
    - اندازه بازار و رشد آن
    - بازیگران اصلی و رقبا
    - نقاط قوت و ضعف رقبا
    - فرصت‌های بازار
    - تهدیدات و چالش‌ها
    
    تحلیل دقیق و قابل اجرا ارائه دهید.
    """
    
    try:
        market_result = gemini_manager.generate_text(market_analysis_prompt)
        print("✅ تحلیل بازار تکمیل شد")
        print(f"📝 خلاصه تحلیل: {market_result[:200]}...")
    except Exception as e:
        print(f"❌ خطا در تحلیل بازار: {e}")
        market_result = "تحلیل بازار در دسترس نیست"
    
    # مرحله 3: برنامه‌ریزی پروژه
    print("\n📋 مرحله 3: برنامه‌ریزی پروژه")
    planning_prompt = """
    شما یک مدیر پروژه متخصص هستید. بر اساس اطلاعات تحقیق و تحلیل بازار، برنامه‌ریزی جامعی برای پروژه هوش مصنوعی ارائه دهید.
    
    موارد مورد نظر:
    - اهداف پروژه
    - مراحل اجرا
    - منابع مورد نیاز
    - جدول زمانی
    - تیم مورد نیاز
    - بودجه پیشنهادی
    
    برنامه عملی و قابل اجرا ارائه دهید.
    """
    
    try:
        planning_result = gemini_manager.generate_text(planning_prompt)
        print("✅ برنامه‌ریزی پروژه تکمیل شد")
        print(f"📝 خلاصه برنامه: {planning_result[:200]}...")
    except Exception as e:
        print(f"❌ خطا در برنامه‌ریزی: {e}")
        planning_result = "برنامه‌ریزی در دسترس نیست"
    
    # مرحله 4: ارزیابی ریسک
    print("\n⚠️ مرحله 4: ارزیابی ریسک‌ها")
    risk_assessment_prompt = """
    شما یک متخصص مدیریت ریسک هستید. ریسک‌های احتمالی پروژه هوش مصنوعی را شناسایی و ارزیابی کنید.
    
    موارد مورد نظر:
    - ریسک‌های فنی
    - ریسک‌های مالی
    - ریسک‌های بازار
    - ریسک‌های قانونی
    - ریسک‌های منابع انسانی
    - راه‌حل‌های کاهش ریسک
    
    ارزیابی جامع و راه‌حل‌های عملی ارائه دهید.
    """
    
    try:
        risk_result = gemini_manager.generate_text(risk_assessment_prompt)
        print("✅ ارزیابی ریسک تکمیل شد")
        print(f"📝 خلاصه ارزیابی: {risk_result[:200]}...")
    except Exception as e:
        print(f"❌ خطا در ارزیابی ریسک: {e}")
        risk_result = "ارزیابی ریسک در دسترس نیست"
    
    # مرحله 5: گزارش نهایی
    print("\n📄 مرحله 5: تهیه گزارش نهایی")
    final_report_prompt = f"""
    شما یک مشاور متخصص هستید. بر اساس تمام اطلاعات جمع‌آوری شده، گزارش نهایی جامعی برای پروژه هوش مصنوعی تهیه کنید.
    
    اطلاعات موجود:
    - گزارش تحقیق: {research_result[:100]}...
    - تحلیل بازار: {market_result[:100]}...
    - برنامه‌ریزی: {planning_result[:100]}...
    - ارزیابی ریسک: {risk_result[:100]}...
    
    گزارش باید شامل:
    - خلاصه اجرایی
    - تحلیل وضعیت
    - پیشنهادات عملی
    - نتیجه‌گیری
    - توصیه‌های نهایی
    
    گزارش حرفه‌ای و قابل ارائه به مدیریت ارائه دهید.
    """
    
    try:
        final_report = gemini_manager.generate_text(final_report_prompt)
        print("✅ گزارش نهایی تکمیل شد")
        print(f"📝 خلاصه گزارش: {final_report[:300]}...")
    except Exception as e:
        print(f"❌ خطا در تهیه گزارش: {e}")
        final_report = "گزارش نهایی در دسترس نیست"
    
    # خلاصه نتایج
    print("\n📊 خلاصه نتایج سناریو:")
    print("="*40)
    print("✅ تحقیق در مورد روندهای هوش مصنوعی")
    print("✅ تحلیل بازار و رقبا")
    print("✅ برنامه‌ریزی پروژه")
    print("✅ ارزیابی ریسک‌ها")
    print("✅ تهیه گزارش نهایی")
    print("\n🎉 سناریو با موفقیت تکمیل شد!")
    
else:
    print("⏭️ شبیه‌سازی سناریو رد شد - Gemini API در دسترس نیست")

# %% [markdown]
# ## 🎉 خلاصه و نتیجه‌گیری
#
# در این نوت‌بوک، یک سیستم چند عاملی کامل و پیشرفته با استفاده از Gemini API، LangChain و RAG پیاده‌سازی کردیم.
#
# ### ✅ آنچه انجام دادیم:
#
# 1. **راه‌اندازی Gemini API**: پیکربندی و تست اتصال به Gemini API
# 2. **سیستم RAG**: پیاده‌سازی کامل RAG با LangChain و Chroma
# 3. **سیستم چند عاملی**: ایجاد Agent های تخصصی با قابلیت‌های مختلف
# 4. **سیستم ارتباطی**: پیاده‌سازی ارتباطات پیشرفته بین Agent ها
# 5. **سیستم هماهنگی**: مدیریت منابع و هماهنگی وظایف
# 6. **تجسم و تحلیل**: نمایش نتایج و آمار عملکرد
# 7. **سناریو عملی**: شبیه‌سازی پروژه واقعی
#
# ### 🚀 ویژگی‌های کلیدی:
#
# - **مقیاس‌پذیری**: قابلیت اضافه کردن Agent های جدید
# - **انعطاف‌پذیری**: پشتیبانی از انواع مختلف وظایف
# - **قابلیت اطمینان**: مدیریت خطا و بازیابی
# - **نظارت**: مانیتورینگ عملکرد و منابع
# - **بهینه‌سازی**: تخصیص هوشمند منابع
#
# ### 📈 نتایج:
#
# سیستم چند عاملی با موفقیت راه‌اندازی شد و قابلیت‌های زیر را نشان داد:
# - پردازش موازی وظایف
# - ارتباطات کارآمد بین Agent ها
# - مدیریت منابع هوشمند
# - تولید گزارش‌های جامع
# - تحلیل و تجسم داده‌ها
#
# ### 🔮 کاربردهای آینده:
#
# - **پروژه‌های بزرگ**: مدیریت پروژه‌های پیچیده
# - **تحلیل داده**: پردازش داده‌های بزرگ
# - **پشتیبانی مشتری**: چت‌بات‌های هوشمند
# - **تحقیق و توسعه**: پروژه‌های تحقیقاتی
# - **بهینه‌سازی فرآیند**: بهبود کارایی سازمانی
#
# ---
#
# **🎯 این سیستم نمونه‌ای از قدرت ترکیب هوش مصنوعی، سیستم‌های چند عاملی و تکنولوژی‌های مدرن است.**

# %% [markdown]
# # CA24: Architectures of Modern Language Agents
# ## A Journey Through Intelligent Agent Evolution
#
# ### 🌟 **The Story of Agent Evolution**
#
# In the vast landscape of artificial intelligence, we stand at the precipice of a revolutionary transformation. The journey from simple language models to sophisticated, autonomous agents represents one of the most significant leaps in AI development. This exercise will take you on an epic adventure through the evolutionary stages of modern language agents, where each framework builds upon the last, creating increasingly powerful and intelligent systems.
#
# Imagine a world where AI agents don't just respond to queries, but actively reason, learn from mistakes, build lasting memories, and collaborate with other agents to solve complex problems. This is not science fiction—this is the reality of modern agent architectures.
#
# ### 📖 **Our Journey Map**
#
# Our expedition will traverse four major milestones in agent architecture evolution:
#
# 1. **🎯 ReAct Framework**: *The Foundation* - Where agents learn to think before they act
# 2. **🔄 Reflexion Framework**: *The Learner* - Where agents gain the ability to learn from failure
# 3. **🧠 HippoRAG Framework**: *The Memory Master* - Where agents develop long-term associative memory
# 4. **🤝 Nexus Framework**: *The Collaborator* - Where individual agents become collaborative teams
#
# Each framework solves critical limitations of its predecessor, creating a natural evolution toward true artificial general intelligence.
#
# ### 🎭 **The Narrative: Building the Ultimate Vacation Planner Agent**
#
# Throughout this journey, we'll follow the evolution of a single character: **Alex**, our Vacation Planner Agent. Alex will start as a simple ReAct-based agent capable of basic reasoning and tool use. Through our story, Alex will evolve into a sophisticated multi-agent system capable of handling complex, multi-dimensional travel planning scenarios.
#
# **Why a vacation planner?** Because travel planning perfectly embodies the challenges modern agents face:
# - **Complex reasoning** (finding optimal routes and schedules)
# - **Tool integration** (booking systems, search APIs, recommendation engines)
# - **Error recovery** (handling booking failures, date conflicts)
# - **Knowledge synthesis** (combining information from multiple sources)
# - **Multi-agent coordination** (specialists for flights, hotels, activities)
#
# ### 🎯 **Learning Objectives**
#
# By the end of this exercise, you will:
# - Understand the theoretical foundations of modern agent architectures
# - Implement each major framework from scratch with comprehensive examples
# - Recognize the evolutionary progression and interconnections between frameworks
# - Develop practical skills in agent design, memory management, and multi-agent coordination
# - Analyze the performance characteristics and trade-offs of different approaches
#
# ### 🚀 **Let's Begin the Adventure!**
#
# Prepare to witness the transformation of simple AI into intelligent, autonomous agents that can reason, remember, and collaborate. Our journey starts now...

# %% [markdown]
# ## Part I: Theoretical Foundations
#
# ### 📚 **The Evolution of Intelligence: From Language Models to Agents**
#
# #### **The Great Transition**
#
# The transformation from Large Language Models (LLMs) to Language Agents represents a paradigm shift comparable to the evolution from calculators to computers. While LLMs excel at generating human-like text, they operate in a isolated bubble—receiving input, processing it, and producing output without any real-world interaction or persistent memory.
#
# **Language Agents** break this barrier by introducing three revolutionary capabilities:
# 1. **Environmental Interaction**: Agents can perceive and act in their environment through tools and APIs
# 2. **Persistent Memory**: Agents maintain state and learn from experience across interactions
# 3. **Goal-Oriented Behavior**: Agents work toward specific objectives rather than simply responding
#
# #### **The Four Pillars of Modern Agent Architecture**
#
# Our journey through agent evolution is guided by four seminal frameworks, each addressing fundamental limitations:
#
# ##### 🎯 **1. ReAct (Reasoning + Acting)**
# - **Core Innovation**: Synergizes reasoning and acting through interleaved thoughts and actions
# - **Key Insight**: Grounding abstract reasoning in concrete environmental feedback
# - **Architecture**: Thought → Action → Observation loop
# - **Limitation**: Cannot learn from failures or maintain long-term memory
#
# ##### 🔄 **2. Reflexion (Self-Reflective Learning)**
# - **Core Innovation**: Introduces self-improvement through reflection on failed attempts
# - **Key Insight**: Learning without expensive weight updates via verbal reinforcement
# - **Architecture**: Actor + Evaluator + Self-Reflection Model
# - **Limitation**: Limited memory capacity for complex knowledge integration
#
# ##### 🧠 **3. HippoRAG (Hippocampus-Inspired Memory)**
# - **Core Innovation**: Neuro-inspired memory architecture combining indexed associations with raw knowledge
# - **Key Insight**: Overcoming the "RAG bottleneck" through graph-based associative retrieval
# - **Architecture**: Knowledge Graph (hippocampus) + Document Store (neocortex)
# - **Limitation**: Single-agent approach limits scalability for complex multi-domain tasks
#
# ##### 🤝 **4. Nexus (Multi-Agent Orchestration)**
# - **Core Innovation**: Collaborative multi-agent systems with hierarchical coordination
# - **Key Insight**: Divide-and-conquer approach through specialized agent roles
# - **Architecture**: Supervisor agents coordinating domain-specific worker agents
# - **Advantage**: Scales to arbitrarily complex tasks through agent specialization
#
# #### **The Philosophical Shift: LLM-First vs Agent-First Design**
#
# Traditional approaches follow an **LLM-First** philosophy:
# - Start with a language model and add capabilities as wrappers
# - Treats the LLM as the central component with external tools as afterthoughts
# - Results in brittle, hard-to-scale systems
#
# Modern agent architectures embrace an **Agent-First** philosophy:
# - Design the agent system first, then integrate LLMs as reasoning components
# - Treats reasoning, memory, and action as co-equal architectural elements
# - Results in robust, scalable, truly autonomous systems
#
# This philosophical shift is crucial for understanding why modern agents represent a genuine leap toward artificial general intelligence rather than merely enhanced language models.

# %%
# 🛠️ Environment Setup and Simulation Framework
# Let's begin our journey by setting up the foundation for our agent world

print("🌟 Welcome to the Agent Evolution Laboratory!")
print("=" * 60)

# Essential imports for our journey
import json
import re
import time
import random
from typing import Dict, List, Tuple, Optional, Any
from dataclasses import dataclass
from collections import defaultdict
import matplotlib.pyplot as plt
import numpy as np

# For our story-telling elements
class StoryTeller:
    """A narrative companion for our agent journey"""
    
    def __init__(self):
        self.chapter = 0
        self.scenes = []
        
    def new_chapter(self, title: str, description: str):
        self.chapter += 1
        print(f"\n📖 Chapter {self.chapter}: {title}")
        print("─" * 50)
        print(f"🎭 {description}")
        print()
        
    def scene(self, description: str):
        print(f"🎬 Scene: {description}")
        self.scenes.append(description)
        
    def narrate(self, text: str):
        print(f"🗣️ Narrator: {text}")

# Initialize our storyteller
story = StoryTeller()

# 🌍 The Simulated World: Alex's Environment
print("🌍 Creating Alex's World - The Travel Planning Environment")
print("─" * 50)

class TravelWorld:
    """
    A simulated environment where our agent Alex will learn and evolve.
    This represents the 'real world' that agents need to interact with.
    """
    
    def __init__(self):
        # Flight database simulation
        self.flights_db = {
            ("Paris", "2025-10-26"): {"flight": "AF123", "price": 650, "available": True},
            ("Paris", "2025-10-25"): {"flight": None, "price": 0, "available": False},  # Intentional failure
            ("Paris", "2025-11-10"): {"flight": "AF456", "price": 720, "available": True},
            ("New York", "2025-12-20"): {"flight": "UA789", "price": 890, "available": True},
            ("London", "2025-09-15"): {"flight": "BA101", "price": 420, "available": True},
        }
        
        # Hotel database simulation
        self.hotels_db = {
            ("Paris", "2025-10-26"): {"hotel": "Grand Hyatt", "price": 180, "available": True},
            ("Paris", "2025-11-10"): {"hotel": "Le Meurice", "price": 220, "available": True},
            ("New York", "2025-12-20"): {"hotel": "The Plaza", "price": 350, "available": True},
            ("London", "2025-09-15"): {"hotel": "The Savoy", "price": 280, "available": True},
        }
        
        # Activities database for itinerary planning
        self.activities_db = {
            ("Paris", "Day 1"): ["Visit the Eiffel Tower", "Explore the Louvre Museum", "Seine River cruise"],
            ("Paris", "Day 2"): ["Montmartre and Sacré-Cœur", "Notre-Dame Cathedral", "Latin Quarter walk"],
            ("Paris", "Day 3"): ["Palace of Versailles day trip", "Champs-Élysées shopping", "Arc de Triomphe"],
            ("New York", "Day 1"): ["Central Park", "Metropolitan Museum", "Times Square"],
            ("London", "Day 1"): ["Tower of London", "Thames cruise", "Big Ben and Westminster"],
        }
        
        # Knowledge base for HippoRAG (simulating web documents)
        self.knowledge_base = {
            "travel_blog_paris.txt": "My amazing trip to Paris! The highlight was definitely the world-famous Louvre Museum in the 1st arrondissement. The Mona Lisa was breathtaking!",
            "hotels_paris.txt": "Paris accommodation guide: The Ritz is luxurious but expensive. Hotel Regina in the 1st arrondissement offers great value and complimentary airport shuttle service.",
            "activities_guide.txt": "Best Paris activities: The Louvre Museum is a must-see, located in the heart of the city. Nearby restaurants include Le Grand Véfour and L'Ambroisie.",
            "transport_info.txt": "Paris transportation: Hotel Regina provides free shuttle service to major attractions. The 1st arrondissement is well-connected to all major sites."
        }
        
        # Failure simulation for learning scenarios
        self.failure_scenarios = {
            "flight_booking_failure": False,
            "hotel_booking_failure": False,
        }
        
    def search_flights(self, destination: str, date: str) -> Dict[str, Any]:
        """Simulate flight booking API with realistic success/failure cases"""
        print(f"  🛫 [Flight Search API] Searching for flights to {destination} on {date}...")
        
        key = (destination, date)
        if key in self.flights_db and self.flights_db[key]["available"]:
            result = self.flights_db[key]
            return {
                "success": True,
                "flight_number": result["flight"],
                "price": result["price"],
                "message": f"Flight {result['flight']} to {destination} on {date} found. Price: ${result['price']}"
            }
        else:
            return {
                "success": False,
                "flight_number": None,
                "price": 0,
                "message": f"No flights available to {destination} on {date}. Please try a different date."
            }
    
    def book_hotel(self, destination: str, check_in_date: str) -> Dict[str, Any]:
        """Simulate hotel booking API"""
        print(f"  🏨 [Hotel Booking API] Searching for hotels in {destination} for {check_in_date}...")
        
        key = (destination, check_in_date)
        if key in self.hotels_db and self.hotels_db[key]["available"]:
            result = self.hotels_db[key]
            return {
                "success": True,
                "hotel_name": result["hotel"],
                "price": result["price"],
                "message": f"Hotel {result['hotel']} in {destination} booked for {check_in_date}. Price: ${result['price']}/night"
            }
        else:
            return {
                "success": False,
                "hotel_name": None,
                "price": 0,
                "message": f"No hotels available in {destination} for {check_in_date}"
            }
    
    def find_activities(self, destination: str, day: str) -> Dict[str, Any]:
        """Simulate activity recommendation API"""
        print(f"  🎯 [Activity API] Finding activities in {destination} for {day}...")
        
        key = (destination, day)
        if key in self.activities_db:
            activities = self.activities_db[key]
            return {
                "success": True,
                "activities": activities,
                "message": f"Found {len(activities)} activities for {day} in {destination}: {', '.join(activities)}"
            }
        else:
            return {
                "success": False,
                "activities": [],
                "message": f"No activities found for {day} in {destination}"
            }

# Initialize Alex's world
travel_world = TravelWorld()

# 🤖 Simple LLM Simulation
# Since we don't have access to large models, we'll simulate intelligent responses
class SimpleLLMSimulator:
    """
    A deterministic LLM simulator that provides realistic agent responses
    This allows us to focus on agent architecture rather than model inference
    """
    
    def __init__(self):
        self.response_templates = {
            # ReAct templates
            "react_thought": [
                "I need to {action} to accomplish the user's request.",
                "The next step is to {action} for the user.",
                "To help the user, I should {action}.",
                "Let me {action} to move forward with this task."
            ],
            
            # Reflexion templates
            "reflection_analysis": [
                "The failure occurred because {reason}. I should try {solution} next time.",
                "Looking at this failure, {reason} was the problem. My strategy should be {solution}.",
                "This didn't work because {reason}. A better approach would be {solution}."
            ],
            
            # General responses
            "success_summary": "Task completed successfully. {details}",
            "failure_summary": "Task failed. {details}",
        }
    
    def generate_react_response(self, context: str, available_actions: List[str]) -> Tuple[str, str]:
        """Generate ReAct-style thought and action"""
        # Simple pattern matching to determine appropriate response
        if "flight" in context.lower():
            thought = "I need to search for flights to help the user with their travel plans."
            action = "search_flights"
        elif "hotel" in context.lower():
            thought = "I should book a hotel for the user's accommodation needs."
            action = "book_hotel"
        elif "activities" in context.lower() or "day" in context.lower():
            thought = "I need to find activities to create an engaging itinerary."
            action = "find_activities"
        elif "finish" in available_actions:
            thought = "I have completed all the necessary bookings and planning."
            action = "finish"
        else:
            thought = "I need to analyze the user's request more carefully."
            action = "search_flights"  # default action
            
        return thought, action
    
    def generate_reflection(self, failure_context: str) -> str:
        """Generate reflection on failure"""
        if "no flights" in failure_context.lower():
            return "The flight search failed for the requested date. I should try alternative dates like the next day or previous day."
        elif "no hotels" in failure_context.lower():
            return "The hotel booking failed. I should search for alternative accommodations or different dates."
        else:
            return "The task failed. I need to reconsider my approach and try different parameters."

# Initialize our LLM simulator
llm = SimpleLLMSimulator()

story.new_chapter("The Stage is Set", 
                 "Our world is ready, our tools are prepared, and Alex is about to be born. The journey from simple language model to sophisticated agent begins now!")

print("✅ Environment Setup Complete!")
print("📊 Travel World Database:")
print(f"   • {len(travel_world.flights_db)} flight routes configured")
print(f"   • {len(travel_world.hotels_db)} hotel locations available") 
print(f"   • {len(travel_world.activities_db)} activity categories loaded")
print(f"   • {len(travel_world.knowledge_base)} knowledge documents indexed")
print("\n🚀 Ready to begin the agent evolution journey!")
# Out:
# 🌟 Welcome to the Agent Evolution Laboratory!
# ...
# 🌍 Creating Alex's World - The Travel Planning Environment
# ──────────────────────────────────────────────────
#
# 📖 Chapter 1: The Stage is Set
# ──────────────────────────────────────────────────
# 🎭 Our world is ready, our tools are prepared, and Alex is about to be born. The journey from simple language model to sophisticated agent begins now!
#
# ✅ Environment Setup Complete!
# 📊 Travel World Database:
#    • 5 flight routes configured
#    • 4 hotel locations available
#    • 5 activity categories loaded
#    • 4 knowledge documents indexed
#
# 🚀 Ready to begin the agent evolution journey!

# %% [markdown]
# ## Part II: ReAct Framework - The Birth of Alex
#
# ### 🎯 **Chapter 1: Where Reasoning Meets Reality**
#
# *Our story begins in a world where language models lived in isolation, capable of brilliant reasoning but unable to interact with the world around them. Then came ReAct, and everything changed...*
#
# #### **The ReAct Revolution**
#
# **ReAct (Reasoning + Acting)** represents the first major breakthrough in transforming language models into true agents. The core insight is deceptively simple yet revolutionary: **interleave reasoning (thoughts) with actions in the real world**.
#
# ##### **🧠 The Cognitive Architecture**
#
# Traditional language models operate in a vacuum:
# ```
# Input → Process → Output
# ```
#
# ReAct introduces the **Thought-Action-Observation** loop:
# ```
# Thought → Action → Observation → Thought → Action → Observation → ...
# ```
#
# This creates a **virtuous feedback loop** where:
# 1. **Thoughts** provide reasoning and planning
# 2. **Actions** execute plans in the environment
# 3. **Observations** ground reasoning in reality
#
# ##### **🔄 The ReAct Loop Mechanics**
#
# Each ReAct cycle consists of three phases:
#
# 1. **🤔 Reasoning Phase (Thought)**:
#    - Agent analyzes the current situation
#    - Plans the next action based on context
#    - Considers potential outcomes
#
# 2. **⚡ Acting Phase (Action)**:
#    - Agent executes a tool or function call
#    - Interacts with the external environment
#    - Attempts to change the world state
#
# 3. **👁️ Observation Phase**:
#    - Environment provides feedback
#    - Agent receives results of the action
#    - New information updates the agent's context
#
# ##### **🎭 Meet Alex v1.0: The ReAct Agent**
#
# Alex begins life as a ReAct agent with these capabilities:
# - **Reasoning**: Can think through travel planning steps
# - **Tool Use**: Can call flight search, hotel booking, and activity APIs
# - **Goal Pursuit**: Works toward completing user travel requests
#
# However, Alex v1.0 has limitations:
# - **No Learning**: Cannot improve from mistakes
# - **No Memory**: Each conversation starts from scratch
# - **No Recovery**: Gets stuck when tools fail
#
# ##### **🎪 The ReAct Performance**
#
# ReAct agents show remarkable capabilities:
# - **Hallucination Reduction**: Real-world grounding reduces false information
# - **Tool Integration**: Seamless use of external APIs and services
# - **Interpretability**: Clear reasoning traces aid debugging and trust
#
# ##### **📈 ReAct's Impact on the Field**
#
# ReAct established several foundational principles:
# - **Few-Shot Learning**: Agents learn the format through examples
# - **In-Context Reasoning**: No weight updates needed for task adaptation
# - **Modular Architecture**: Clear separation of reasoning and acting
#
# *But every hero has limitations, and Alex v1.0 is about to discover theirs...*

# %%
# 🎯 Implementing Alex v1.0: The ReAct Agent
# Let's bring our first agent to life!

story.new_chapter("The Birth of Alex", 
                 "In this moment, Alex takes their first breath as a ReAct agent, ready to help travelers but not yet knowing the challenges ahead...")

class ReActAgent:
    """
    Alex v1.0 - A ReAct-based travel planning agent
    
    Architecture:
    - Thought generation using LLM simulation
    - Action execution via tool calls  
    - Observation integration for next cycle
    """
    
    def __init__(self, world: TravelWorld, llm_simulator: SimpleLLMSimulator, name: str = "Alex v1.0"):
        self.world = world
        self.llm = llm_simulator
        self.name = name
        self.conversation_history = []
        self.available_tools = {
            "search_flights": self.world.search_flights,
            "book_hotel": self.world.book_hotel,
            "find_activities": self.world.find_activities,
        }
        
    def think(self, context: str) -> str:
        """Generate a reasoning thought based on current context"""
        thought, _ = self.llm.generate_react_response(context, list(self.available_tools.keys()) + ["finish"])
        return thought
    
    def act(self, context: str, thought: str) -> Tuple[str, Dict[str, Any]]:
        """Decide on and execute an action based on thought"""
        _, action_name = self.llm.generate_react_response(context, list(self.available_tools.keys()) + ["finish"])
        
        # Parse action parameters from context (simplified logic)
        if action_name == "search_flights":
            # Extract destination and date from context
            if "Paris" in context and "2025-10-26" in context:
                result = self.available_tools[action_name]("Paris", "2025-10-26")
            elif "Paris" in context and "2025-10-25" in context:
                result = self.available_tools[action_name]("Paris", "2025-10-25")  # This will fail!
            elif "New York" in context:
                result = self.available_tools[action_name]("New York", "2025-12-20")
            else:
                result = {"success": False, "message": "Could not parse destination and date"}
                
        elif action_name == "book_hotel":
            if "Paris" in context and "2025-10-26" in context:
                result = self.available_tools[action_name]("Paris", "2025-10-26")
            elif "New York" in context:
                result = self.available_tools[action_name]("New York", "2025-12-20")
            else:
                result = {"success": False, "message": "Could not parse hotel requirements"}
                
        elif action_name == "find_activities":
            if "Paris" in context and "Day 1" in context:
                result = self.available_tools[action_name]("Paris", "Day 1")
            elif "Day" in context:
                result = self.available_tools[action_name]("Paris", "Day 1")  # default
            else:
                result = {"success": False, "message": "Could not parse activity requirements"}
        else:
            result = {"success": False, "message": f"Unknown action: {action_name}"}
            
        return action_name, result
    
    def observe(self, action_result: Dict[str, Any]) -> str:
        """Process the observation from the environment"""
        if action_result["success"]:
            return f"✅ Success: {action_result['message']}"
        else:
            return f"❌ Failed: {action_result['message']}"
    
    def plan_trip(self, user_request: str, max_steps: int = 5) -> Dict[str, Any]:
        """
        Main ReAct loop implementation
        Cycles through Thought → Action → Observation until task completion
        """
        print(f"\n🤖 {self.name} starting trip planning...")
        print(f"📝 User Request: {user_request}")
        print("=" * 60)
        
        context = f"User Request: {user_request}\n"
        trip_plan = {
            "user_request": user_request,
            "steps": [],
            "final_result": None,
            "success": False
        }
        
        for step in range(max_steps):
            print(f"\n📍 Step {step + 1}/{max_steps}")
            print("─" * 30)
            
            # THOUGHT PHASE
            print("🤔 Thought Phase:")
            thought = self.think(context)
            print(f"   💭 {thought}")
            
            # Check if we should finish
            if "completed" in thought.lower() or "done" in thought.lower() or step == max_steps - 1:
                print("🎯 Task completion detected")
                trip_plan["final_result"] = "Trip planning completed with available information"
                trip_plan["success"] = True
                break
            
            # ACTION PHASE  
            print("⚡ Action Phase:")
            action_name, action_result = self.act(context, thought)
            print(f"   🔧 Action: {action_name}")
            
            # OBSERVATION PHASE
            print("👁️ Observation Phase:")
            observation = self.observe(action_result)
            print(f"   📊 {observation}")
            
            # Record this step
            step_record = {
                "step_number": step + 1,
                "thought": thought,
                "action": action_name,
                "observation": observation,
                "action_result": action_result
            }
            trip_plan["steps"].append(step_record)
            
            # Update context with new information
            context += f"\nThought: {thought}\nAction: {action_name}\nObservation: {observation}\n"
            
            # Check for failure that should halt execution
            if not action_result["success"] and "finish" not in action_name:
                print("⚠️ Action failed, but continuing...")
                
        return trip_plan

# 🎭 Let's watch Alex v1.0 in action!
print("🎬 Scene 1: Alex's First Trip Planning Adventure")
print("─" * 50)

# Create Alex v1.0
alex_v1 = ReActAgent(travel_world, llm, "Alex v1.0 (ReAct)")

# Test Case 1: A simple successful trip
story.scene("Alex encounters their first customer - a simple Paris trip")
result_1 = alex_v1.plan_trip("I want to plan a trip to Paris for 2025-10-26. I need a flight and hotel.")

print(f"\n📋 Trip Planning Summary:")
print(f"   🎯 Success: {result_1['success']}")
print(f"   📊 Steps taken: {len(result_1['steps'])}")
print(f"   💡 Final result: {result_1['final_result']}")

# Let's examine the reasoning trace
print(f"\n🔍 Detailed Step Analysis:")
for step in result_1["steps"]:
    print(f"   Step {step['step_number']}: {step['thought'][:50]}..." if len(step['thought']) > 50 else f"   Step {step['step_number']}: {step['thought']}")

story.narrate("Alex successfully planned their first trip! But little do they know, a greater challenge awaits...")
# Out:
# 📖 Chapter 3: The Birth of Alex
# ──────────────────────────────────────────────────
# 🎭 In this moment, Alex takes their first breath as a ReAct agent, ready to help travelers but not yet knowing the challenges ahead...
#
# 🎬 Scene 1: Alex's First Trip Planning Adventure
# ──────────────────────────────────────────────────
# 🎬 Scene: Alex encounters their first customer - a simple Paris trip
#
# 🤖 Alex v1.0 (ReAct) starting trip planning...
# 📝 User Request: I want to plan a trip to Paris for 2025-10-26. I need a flight and hotel.
# ...
#
# 📍 Step 1/5
# ──────────────────────────────
# 🤔 Thought Phase:
#    💭 I need to search for flights to help the user with their travel plans.
# ⚡ Action Phase:
#   🛫 [Flight Search API] Searching for flights to Paris on 2025-10-26...
#    🔧 Action: search_flights
# 👁️ Observation Phase:
#    📊 ✅ Success: Flight AF123 to Paris on 2025-10-26 found. Price: $650
#
# 📍 Step 2/5
# ──────────────────────────────
# 🤔 Thought Phase:
# ...

# %%
# 🎭 Scene 2: The Moment of Truth - Alex Faces Failure
print("\n🎬 Scene 2: Alex's First Challenge")
print("─" * 50)

story.scene("A new customer arrives with a date that will change everything...")

# Test Case 2: The failure scenario that reveals ReAct's limitations
result_2 = alex_v1.plan_trip("I want to plan a trip to Paris for 2025-10-25. I need a flight and hotel.")

print(f"\n💥 The Challenge Revealed:")
print(f"   🎯 Success: {result_2['success']}")
print(f"   📊 Steps taken: {len(result_2['steps'])}")
print(f"   💡 Final result: {result_2['final_result']}")

# Analyze what went wrong
print(f"\n🔍 Failure Analysis:")
for step in result_2["steps"]:
    if not step["action_result"]["success"]:
        print(f"   ⚠️ Step {step['step_number']} FAILED: {step['observation']}")
        print(f"   🤔 Agent's thought was: {step['thought']}")
        print(f"   🔧 Action attempted: {step['action']}")

story.narrate("""Alex tried their best, but when the flight booking failed, they couldn't adapt. 
They had no way to learn from this failure or remember it for next time. 
This is the fundamental limitation of ReAct agents - they cannot evolve beyond their initial programming.""")

print(f"\n📊 ReAct Performance Analysis:")
print("="*60)

# Performance metrics
success_rate = 1 if result_1["success"] else 0
success_rate += 1 if result_2["success"] else 0
success_rate = success_rate / 2 * 100

print(f"📈 Overall Success Rate: {success_rate:.1f}%")
print(f"🔄 Learning from Failures: ❌ Cannot learn")
print(f"💾 Memory Persistence: ❌ No long-term memory") 
print(f"🛠️ Tool Integration: ✅ Excellent")
print(f"🧠 Reasoning Quality: ✅ Good")
print(f"🔧 Error Recovery: ❌ Poor")

print(f"\n🎭 ReAct's Strengths:")
print("   ✅ Clear reasoning traces (interpretable)")
print("   ✅ Effective tool use and environment interaction")
print("   ✅ Goal-oriented behavior")
print("   ✅ Few-shot learning capability")

print(f"\n⚠️ ReAct's Limitations:")
print("   ❌ Cannot learn from failures")
print("   ❌ No memory between conversations")
print("   ❌ Gets stuck when tools fail")
print("   ❌ No self-improvement mechanism")

story.narrate("""And so, Alex v1.0's journey reveals both the power and the limitations of ReAct agents. 
They can reason and act, but they cannot learn and adapt. 
The stage is set for evolution - for Alex to become something more...""")
# Out:
# 🎬 Scene 2: Alex's First Challenge
# ──────────────────────────────────────────────────
# 🎬 Scene: A new customer arrives with a date that will change everything...
#
# 🤖 Alex v1.0 (ReAct) starting trip planning...
# 📝 User Request: I want to plan a trip to Paris for 2025-10-25. I need a flight and hotel.
# ...
#
# 📍 Step 1/5
# ──────────────────────────────
# 🤔 Thought Phase:
#    💭 I need to search for flights to help the user with their travel plans.
# ⚡ Action Phase:
#   🛫 [Flight Search API] Searching for flights to Paris on 2025-10-25...
#    🔧 Action: search_flights
# 👁️ Observation Phase:
#    📊 ❌ Failed: No flights available to Paris on 2025-10-25. Please try a different date.
# ⚠️ Action failed, but continuing...
#
# 📍 Step 2/5
# ──────────────────────────────
# 🤔 Thought Phase:
#    💭 I need to search for flights to help the user with their travel plans.
# ⚡ Action Phase:
#   🛫 [Flight Search API] Searching for flights to Paris on 2025-10-25...
#    🔧 Action: search_flights
# ...

# %% [markdown]
# ## Part III: Reflexion Framework - Alex Learns to Learn
#
# ### 🔄 **Chapter 2: The Power of Self-Reflection**
#
# *After facing failure, Alex realizes something profound - the ability to learn from mistakes is what separates intelligence from mere computation. In this chapter, Alex evolves into a self-improving agent through the magic of Reflexion...*
#
# #### **The Reflexion Revolution**
#
# **Reflexion** addresses ReAct's fundamental limitation: **the inability to learn from experience**. While traditional machine learning requires expensive weight updates and retraining, Reflexion introduces a revolutionary concept: **learning through self-reflection and verbal reinforcement**.
#
# ##### **🧠 The Three-Mind Architecture**
#
# Reflexion consists of three interconnected components:
#
# 1. **🎭 Actor (Ma)**: The ReAct agent that attempts tasks
#    - Maintains the basic Thought-Action-Observation loop
#    - Attempts to solve problems using available tools
#    - Generates action trajectories
#
# 2. **⚖️ Evaluator (Me)**: The judge that assesses outcomes
#    - Determines if the Actor succeeded or failed
#    - Provides binary success/failure feedback
#    - Can use simple heuristics or complex evaluation
#
# 3. **🪞 Self-Reflection Model (Msr)**: The wisdom keeper
#    - Analyzes failed trajectories to identify root causes
#    - Generates textual "self-hints" for future attempts
#    - Stores insights in episodic memory
#
# ##### **🔄 The Reflexion Learning Loop**
#
# The complete Reflexion cycle operates as follows:
#
# ```
# Trial n:
# Actor → Environment → Evaluator → [SUCCESS] → Done
#                                → [FAILURE] → Self-Reflection Model
#                                           ↓
# Memory Bank ← "Self-Hint" ← Analysis of Failure
#      ↓
# Trial n+1:
# Actor (with self-hints) → Environment → ...
# ```
#
# ##### **💡 The Breakthrough: Verbal Reinforcement**
#
# Traditional reinforcement learning requires:
# - Large datasets
# - Expensive model retraining
# - Gradient updates
# - Complex reward engineering
#
# Reflexion achieves learning through:
# - **Textual self-hints** stored in memory
# - **No model weight updates** required
# - **Immediate application** of lessons learned
# - **Interpretable** learning process
#
# ##### **🎭 Alex v2.0: The Reflexion Agent**
#
# Our evolved Alex gains these new capabilities:
# - **Failure Analysis**: Can diagnose what went wrong
# - **Self-Improvement**: Generates actionable insights from failures
# - **Episodic Memory**: Maintains a bank of learned lessons
# - **Adaptive Planning**: Uses past experience to inform new attempts
#
# ##### **🧪 The Science Behind Self-Reflection**
#
# Reflexion is inspired by **metacognition** - thinking about thinking:
# - **Introspection**: The agent examines its own reasoning
# - **Causal Analysis**: Identifies specific failure points
# - **Strategic Planning**: Develops alternative approaches
# - **Knowledge Consolidation**: Converts experience into reusable insights
#
# *But how does an agent learn to reflect? Let's watch Alex's transformation...*

# %%
# 🔄 Implementing Alex v2.0: The Reflexion Agent
# Witness the birth of self-improving intelligence!

story.new_chapter("The Evolution Begins", 
                 "From the ashes of failure, Alex v2.0 emerges with the power to learn, adapt, and grow stronger with each challenge...")

class ReflexionAgent:
    """
    Alex v2.0 - A self-improving agent using the Reflexion framework
    
    Architecture:
    - Actor: Enhanced ReAct agent with memory integration
    - Evaluator: Success/failure assessment system
    - Self-Reflection Model: Experience analysis and insight generation
    """
    
    def __init__(self, world: TravelWorld, llm_simulator: SimpleLLMSimulator, name: str = "Alex v2.0"):
        self.world = world
        self.llm = llm_simulator
        self.name = name
        
        # The Actor component (enhanced ReAct agent)
        self.actor = ReActAgent(world, llm_simulator, f"{name} (Actor)")
        
        # Episodic Memory Bank - stores self-reflections from failed attempts
        self.memory_bank = []
        
        # Trial history for analysis
        self.trial_history = []
        
    def evaluate_trial(self, trial_result: Dict[str, Any]) -> bool:
        """
        Evaluator (Me): Assess whether the trial succeeded or failed
        Simple heuristic-based evaluation for our travel planning domain
        """
        print(f"\n⚖️ Evaluator Analysis:")
        
        # Check if we have both flight and hotel bookings
        has_flight = False
        has_hotel = False
        
        for step in trial_result["steps"]:
            if step["action"] == "search_flights" and step["action_result"]["success"]:
                has_flight = True
            elif step["action"] == "book_hotel" and step["action_result"]["success"]:
                has_hotel = True
        
        success = has_flight and has_hotel
        
        print(f"   ✈️ Flight booking: {'✅' if has_flight else '❌'}")
        print(f"   🏨 Hotel booking: {'✅' if has_hotel else '❌'}")
        print(f"   🎯 Overall success: {'✅' if success else '❌'}")
        
        return success
    
    def self_reflect(self, failed_trial: Dict[str, Any]) -> str:
        """
        Self-Reflection Model (Msr): Analyze failure and generate actionable insights
        This is where the magic of learning happens!
        """
        print(f"\n🪞 Self-Reflection Model Analysis:")
        print("   🧠 Analyzing the failed trial trajectory...")
        
        # Identify the specific failure points
        failure_points = []
        for step in failed_trial["steps"]:
            if not step["action_result"]["success"]:
                failure_points.append({
                    "step": step["step_number"],
                    "action": step["action"],
                    "failure_reason": step["action_result"]["message"]
                })
        
        # Generate insight based on failure pattern
        if failure_points:
            primary_failure = failure_points[0]
            
            if "no flights" in primary_failure["failure_reason"].lower():
                insight = f"When flight search fails for a specific date, try alternative dates (±1-2 days). The original failure was: {primary_failure['failure_reason']}"
                
            elif "no hotels" in primary_failure["failure_reason"].lower():
                insight = f"When hotel booking fails, try alternative locations or dates. The original failure was: {primary_failure['failure_reason']}"
                
            else:
                insight = f"General failure in {primary_failure['action']}. Consider alternative approaches or parameters."
        else:
            insight = "The trial failed without clear action failures. Review the overall strategy."
        
        print(f"   💡 Generated insight: {insight}")
        
        return insight
    
    def plan_trip_with_learning(self, user_request: str, max_trials: int = 3) -> Dict[str, Any]:
        """
        Main Reflexion loop: Try → Evaluate → Reflect → Try Again
        """
        print(f"\n🧠 {self.name} starting adaptive trip planning...")
        print(f"📝 User Request: {user_request}")
        print(f"🔄 Maximum trials allowed: {max_trials}")
        print("=" * 60)
        
        final_result = {
            "user_request": user_request,
            "trials": [],
            "success": False,
            "final_trial": None,
            "insights_learned": []
        }
        
        for trial_num in range(max_trials):
            print(f"\n🎯 Trial {trial_num + 1}/{max_trials}")
            print("=" * 40)
            
            # Prepare the context with accumulated self-hints
            enhanced_request = user_request
            if self.memory_bank:
                print(f"🧠 Applying {len(self.memory_bank)} learned insights:")
                for i, insight in enumerate(self.memory_bank):
                    print(f"   💡 Insight {i+1}: {insight[:80]}...")
                    
                enhanced_request += f"\n\nLearned insights from previous attempts:\n"
                for insight in self.memory_bank:
                    enhanced_request += f"- {insight}\n"
            
            # ACTOR: Attempt the task
            trial_result = self.actor.plan_trip(enhanced_request, max_steps=6)
            
            # EVALUATOR: Assess the outcome
            trial_success = self.evaluate_trial(trial_result)
            
            trial_record = {
                "trial_number": trial_num + 1,
                "result": trial_result,
                "success": trial_success,
                "insights_applied": len(self.memory_bank)
            }
            
            final_result["trials"].append(trial_record)
            
            if trial_success:
                print(f"\n🎉 Success achieved on trial {trial_num + 1}!")
                final_result["success"] = True
                final_result["final_trial"] = trial_record
                break
            else:
                print(f"\n💭 Trial {trial_num + 1} failed. Initiating self-reflection...")
                
                # SELF-REFLECTION: Learn from the failure
                insight = self.self_reflect(trial_result)
                self.memory_bank.append(insight)
                final_result["insights_learned"].append(insight)
                
                print(f"   📚 Added insight to memory bank (total: {len(self.memory_bank)})")
        
        return final_result

# 🎭 Alex v2.0's Grand Debut!
print("🎬 Scene 3: The Reflexion Revolution")
print("─" * 50)

story.scene("Alex v2.0 faces the same challenge that defeated v1.0. But this time, they're ready to learn...")

# Create Alex v2.0
alex_v2 = ReflexionAgent(travel_world, llm, "Alex v2.0 (Reflexion)")

# Test the same failing scenario that stumped v1.0
result_reflexion = alex_v2.plan_trip_with_learning("I want to plan a trip to Paris for 2025-10-25. I need a flight and hotel.")

print(f"\n📋 Reflexion Agent Performance Summary:")
print("="*60)
print(f"   🎯 Final Success: {result_reflexion['success']}")
print(f"   🔄 Trials needed: {len(result_reflexion['trials'])}")
print(f"   🧠 Insights learned: {len(result_reflexion['insights_learned'])}")

if result_reflexion["insights_learned"]:
    print(f"\n💡 Knowledge Acquired:")
    for i, insight in enumerate(result_reflexion["insights_learned"]):
        print(f"   {i+1}. {insight}")

print(f"\n📊 Trial-by-Trial Analysis:")
for trial in result_reflexion["trials"]:
    print(f"   Trial {trial['trial_number']}: {'✅ Success' if trial['success'] else '❌ Failed'} (Insights: {trial['insights_applied']})")

story.narrate("""Behold! Alex v2.0 has achieved what v1.0 could not - learning from failure and adapting. 
This is the power of Reflexion: transforming every setback into a stepping stone toward greater intelligence.""")
# Out:
# 📖 Chapter 4: The Evolution Begins
# ──────────────────────────────────────────────────
# 🎭 From the ashes of failure, Alex v2.0 emerges with the power to learn, adapt, and grow stronger with each challenge...
#
# 🎬 Scene 3: The Reflexion Revolution
# ──────────────────────────────────────────────────
# 🎬 Scene: Alex v2.0 faces the same challenge that defeated v1.0. But this time, they're ready to learn...
#
# 🧠 Alex v2.0 (Reflexion) starting adaptive trip planning...
# 📝 User Request: I want to plan a trip to Paris for 2025-10-25. I need a flight and hotel.
# 🔄 Maximum trials allowed: 3
# ...
#
# 🎯 Trial 1/3
# ...
#
# 🤖 Alex v2.0 (Reflexion) (Actor) starting trip planning...
# 📝 User Request: I want to plan a trip to Paris for 2025-10-25. I need a flight and hotel.
# ...
#
# 📍 Step 1/6
# ──────────────────────────────
# 🤔 Thought Phase:
#    💭 I need to search for flights to help the user with their travel plans.
# ⚡ Action Phase:
# ...

# %% [markdown]
# ## Part IV: HippoRAG Framework - Alex Gains Long-Term Memory
#
# ### 🧠 **Chapter 3: The Memory Revolution**
#
# *Alex v2.0 could learn from mistakes, but still faced a new challenge: complex questions requiring deep knowledge integration. "Find me a hotel near the museum I read about in that blog post" - how could Alex connect scattered information across multiple sources? The answer lay in the hippocampus...*
#
# #### **The HippoRAG Breakthrough**
#
# **HippoRAG** (Hippocampus-Inspired Retrieval-Augmented Generation) solves a fundamental problem in AI: **the RAG bottleneck**. Traditional RAG systems struggle with multi-hop questions that require connecting information across multiple documents.
#
# ##### **🧬 Neuro-Inspired Architecture**
#
# HippoRAG draws inspiration from neuroscience:
#
# - **🧠 Hippocampus**: The brain's memory indexer
#   - Creates associations between concepts
#   - Enables rapid retrieval of related memories
#   - Supports complex, multi-hop reasoning
#
# - **🧠 Neocortex**: The brain's knowledge store
#   - Holds detailed factual information
#   - Contains the actual content of memories
#   - Provides rich context for reasoning
#
# ##### **🏗️ The Two-Stage Architecture**
#
# **Stage 1: Offline Indexing (Knowledge Graph Construction)**
# ```
# Documents → NER & OpenIE → Knowledge Graph → Associative Index
# ```
#
# **Stage 2: Online Retrieval (Multi-hop Reasoning)**
# ```
# Query → Entity Linking → Graph Traversal → Document Retrieval → Answer Generation
# ```
#
# ##### **🔍 The Multi-Hop Magic**
#
# Traditional RAG:
# ```
# Query: "Find hotel near the museum from the blog"
# RAG: Searches "hotel museum blog" → Finds scattered results → Struggles to connect
# ```
#
# HippoRAG:
# ```
# Query: "Find hotel near the museum from the blog"
# Step 1: Extract entities → "museum", "blog", "hotel"
# Step 2: Graph traversal → Blog mentions "Louvre Museum" → "1st arrondissement"
# Step 3: Find connections → Hotel Regina → "1st arrondissement" → "shuttle service"
# Result: "Hotel Regina in the 1st arrondissement offers shuttle service near the Louvre"
# ```
#
# ##### **🎯 The Knowledge Graph Foundation**
#
# HippoRAG uses a knowledge graph to model relationships:
# - **Entities**: Places, objects, concepts (e.g., "Hotel Regina", "Louvre Museum")
# - **Relations**: Connections between entities (e.g., "located_in", "offers_service")
# - **Multi-hop Paths**: Complex reasoning chains through the graph
#
# ##### **🧭 Personalized PageRank (PPR)**
#
# HippoRAG uses PPR algorithm for associative retrieval:
# - Starts from query entities in the knowledge graph
# - Propagates activation through graph connections
# - Ranks entities by their association strength
# - Retrieves documents for highly-ranked entities
#
# ##### **🎭 Alex v3.0: The Memory Master**
#
# Our evolved Alex gains revolutionary capabilities:
# - **Associative Memory**: Connects information across multiple sources
# - **Multi-hop Reasoning**: Answers complex questions requiring inference chains
# - **Knowledge Integration**: Synthesizes information from diverse documents
# - **Semantic Understanding**: Goes beyond keyword matching to conceptual relationships
#
# *But how does a simple travel agent become a master of memory? Let's witness Alex's most profound transformation...*

# %%
# 🧠 Implementing Alex v3.0: The HippoRAG Agent
# Watch as Alex gains the power of associative memory!

story.new_chapter("The Memory Awakening", 
                 "In this pivotal moment, Alex transcends simple learning to gain true understanding - the ability to connect disparate pieces of information into coherent knowledge...")

class KnowledgeGraph:
    """
    The Hippocampus: An associative index for rapid memory retrieval
    Stores entities and their relationships for multi-hop reasoning
    """
    
    def __init__(self):
        # Graph structure: (head_entity, relation, tail_entity)
        self.triples = []
        self.entities = set()
        self.relations = set()
        
    def add_triple(self, head: str, relation: str, tail: str):
        """Add a knowledge triple to the graph"""
        self.triples.append((head, relation, tail))
        self.entities.add(head)
        self.entities.add(tail)
        self.relations.add(relation)
    
    def find_connected_entities(self, seed_entities: List[str], max_hops: int = 2) -> Dict[str, float]:
        """
        Simplified Personalized PageRank for associative retrieval
        Returns entities ranked by their association strength to seed entities
        """
        # Initialize activation scores
        entity_scores = {entity: 0.0 for entity in self.entities}
        
        # Set seed entities with initial activation
        for entity in seed_entities:
            if entity in entity_scores:
                entity_scores[entity] = 1.0
        
        # Propagate activation through graph connections
        for hop in range(max_hops):
            new_scores = entity_scores.copy()
            
            for head, relation, tail in self.triples:
                if head in entity_scores and entity_scores[head] > 0:
                    # Propagate activation with decay
                    activation = entity_scores[head] * 0.7  # Decay factor
                    new_scores[tail] = max(new_scores[tail], activation)
                    
                # Also propagate in reverse direction for symmetric relationships
                if tail in entity_scores and entity_scores[tail] > 0:
                    activation = entity_scores[tail] * 0.7
                    new_scores[head] = max(new_scores[head], activation)
            
            entity_scores = new_scores
        
        # Return entities sorted by activation score
        return dict(sorted(entity_scores.items(), key=lambda x: x[1], reverse=True))
    
    def get_reasoning_path(self, start_entity: str, end_entity: str) -> List[Tuple[str, str, str]]:
        """Find a reasoning path between two entities"""
        # Simple breadth-first search for demonstration
        queue = [(start_entity, [])]
        visited = set()
        
        while queue:
            current_entity, path = queue.pop(0)
            
            if current_entity == end_entity:
                return path
            
            if current_entity in visited:
                continue
                
            visited.add(current_entity)
            
            for head, relation, tail in self.triples:
                if head == current_entity and tail not in visited:
                    new_path = path + [(head, relation, tail)]
                    queue.append((tail, new_path))
        
        return []  # No path found

class DocumentStore:
    """
    The Neocortex: Detailed knowledge storage
    Contains the actual content that provides context for reasoning
    """
    
    def __init__(self):
        self.documents = {}
        
    def add_document(self, doc_id: str, content: str):
        """Add a document to the store"""
        self.documents[doc_id] = content
    
    def retrieve_by_entities(self, entities: List[str]) -> List[str]:
        """Retrieve documents containing any of the specified entities"""
        relevant_docs = []
        
        for doc_id, content in self.documents.items():
            for entity in entities:
                if entity.lower() in content.lower():
                    relevant_docs.append(content)
                    break
                    
        return relevant_docs

class HippoRAGAgent:
    """
    Alex v3.0 - A memory-enhanced agent using HippoRAG architecture
    
    Components:
    - Knowledge Graph (Hippocampus): Associative index
    - Document Store (Neocortex): Detailed knowledge
    - Multi-hop Retrieval: Complex reasoning chains
    """
    
    def __init__(self, world: TravelWorld, llm_simulator: SimpleLLMSimulator, name: str = "Alex v3.0"):
        self.world = world
        self.llm = llm_simulator  
        self.name = name
        
        # Initialize the memory systems
        self.knowledge_graph = KnowledgeGraph()
        self.document_store = DocumentStore()
        
        # Build the knowledge base from world data
        self._build_knowledge_base()
        
    def _build_knowledge_base(self):
        """
        Offline Indexing: Build knowledge graph and document store
        This simulates the NER and OpenIE processing of documents
        """
        print(f"🏗️ {self.name} building knowledge base...")
        
        # Add travel documents to document store
        for doc_id, content in self.world.knowledge_base.items():
            self.document_store.add_document(doc_id, content)
        
        # Build knowledge graph through entity extraction and relation identification
        # In reality, this would use NLP tools like SpaCy, but we'll simulate manually
        
        # From travel_blog_paris.txt: "Louvre Museum in the 1st arrondissement"
        self.knowledge_graph.add_triple("Louvre Museum", "located_in", "1st arrondissement")
        self.knowledge_graph.add_triple("travel_blog_paris.txt", "mentions", "Louvre Museum")
        
        # From hotels_paris.txt: "Hotel Regina in the 1st arrondissement offers shuttle service"
        self.knowledge_graph.add_triple("Hotel Regina", "located_in", "1st arrondissement")
        self.knowledge_graph.add_triple("Hotel Regina", "offers_service", "airport shuttle")
        self.knowledge_graph.add_triple("hotels_paris.txt", "mentions", "Hotel Regina")
        
        # Additional relationships
        self.knowledge_graph.add_triple("1st arrondissement", "contains", "major attractions")
        self.knowledge_graph.add_triple("airport shuttle", "provides_access_to", "attractions")
        
        print(f"   📊 Knowledge Graph: {len(self.knowledge_graph.triples)} triples")
        print(f"   📚 Document Store: {len(self.document_store.documents)} documents")
        
    def extract_entities(self, query: str) -> List[str]:
        """Simple entity extraction from query (simulated NER)"""
        entities = []
        
        # Simple pattern matching for demonstration
        if "museum" in query.lower():
            entities.append("Louvre Museum")
        if "hotel" in query.lower():
            entities.append("Hotel Regina")
        if "shuttle" in query.lower():
            entities.append("airport shuttle")
        if "blog" in query.lower():
            entities.append("travel_blog_paris.txt")
            
        return entities
    
    def multi_hop_retrieval(self, query: str) -> Dict[str, Any]:
        """
        Online Retrieval: Multi-hop reasoning through knowledge graph
        """
        print(f"\n🔍 Multi-hop retrieval for: '{query}'")
        
        # Step 1: Entity Linking
        seed_entities = self.extract_entities(query)
        print(f"   🎯 Seed entities: {seed_entities}")
        
        if not seed_entities:
            return {"success": False, "message": "No entities found in query"}
        
        # Step 2: Graph Traversal (Associative Retrieval)
        connected_entities = self.knowledge_graph.find_connected_entities(seed_entities, max_hops=3)
        
        # Filter for relevant entities with significant activation
        relevant_entities = [entity for entity, score in connected_entities.items() if score > 0.1][:10]
        print(f"   🕸️ Connected entities: {relevant_entities[:5]}...")
        
        # Step 3: Document Retrieval
        retrieved_docs = self.document_store.retrieve_by_entities(relevant_entities)
        print(f"   📄 Retrieved {len(retrieved_docs)} relevant documents")
        
        # Step 4: Find reasoning path (for explainability)
        if len(seed_entities) >= 2:
            reasoning_path = self.knowledge_graph.get_reasoning_path(seed_entities[0], seed_entities[1])
            print(f"   🛤️ Reasoning path found: {len(reasoning_path)} steps")
        else:
            reasoning_path = []
        
        return {
            "success": True,
            "seed_entities": seed_entities,
            "connected_entities": relevant_entities,
            "retrieved_documents": retrieved_docs,
            "reasoning_path": reasoning_path,
            "context": " ".join(retrieved_docs)
        }
    
    def answer_complex_query(self, query: str) -> str:
        """Answer complex multi-hop questions using HippoRAG retrieval"""
        print(f"\n🧠 {self.name} processing complex query...")
        
        # Perform multi-hop retrieval
        retrieval_result = self.multi_hop_retrieval(query)
        
        if not retrieval_result["success"]:
            return "I couldn't find relevant information to answer your question."
        
        # Generate answer using retrieved context
        context = retrieval_result["context"]
        
        # Simple answer generation based on patterns in context
        if "hotel regina" in context.lower() and "shuttle" in context.lower() and "louvre" in context.lower():
            return "Based on my knowledge, I found that the Louvre Museum (mentioned in travel blogs) is located in the 1st arrondissement. Hotel Regina, also in the 1st arrondissement, offers complimentary airport shuttle service. This makes it an excellent choice for easy access to the museum you read about."
        elif "louvre" in context.lower() and "museum" in context.lower():
            return "The famous museum you're referring to is likely the Louvre Museum, which is mentioned in travel blogs as a must-see attraction in Paris."
        else:
            return f"I found relevant information: {context[:200]}..."

# 🎭 Alex v3.0's Knowledge Demonstration
print("🎬 Scene 4: The Memory Master Emerges")
print("─" * 50)

story.scene("A customer poses a complex question that would stump previous versions of Alex...")

# Create Alex v3.0
alex_v3 = HippoRAGAgent(travel_world, llm, "Alex v3.0 (HippoRAG)")

# Test complex multi-hop reasoning
complex_query = "I read a blog post about a famous museum in Paris. Can you find me a hotel near that museum that offers shuttle service?"

print(f"💭 Customer asks: \"{complex_query}\"")

# Watch Alex v3.0's reasoning process
answer = alex_v3.answer_complex_query(complex_query)

print(f"\n🎯 Alex v3.0's Answer:")
print(f"   {answer}")

# Demonstrate the knowledge graph connections
print(f"\n📊 Knowledge Graph Analysis:")
entities = alex_v3.knowledge_graph.entities
print(f"   Total entities: {len(entities)}")
print(f"   Sample entities: {list(entities)[:5]}")

connected = alex_v3.knowledge_graph.find_connected_entities(["Louvre Museum"], max_hops=2)
print(f"\n🕸️ Entities connected to 'Louvre Museum':")
for entity, score in list(connected.items())[:5]:
    if score > 0:
        print(f"   {entity}: {score:.2f}")

story.narrate("""Incredible! Alex v3.0 successfully connected information across multiple documents, 
reasoning from 'blog post about museum' → 'Louvre Museum' → '1st arrondissement' → 'Hotel Regina with shuttle service'. 
This is the power of associative memory in action!""")
# Out:
# 📖 Chapter 5: The Memory Awakening
# ──────────────────────────────────────────────────
# 🎭 In this pivotal moment, Alex transcends simple learning to gain true understanding - the ability to connect disparate pieces of information into coherent knowledge...
#
# 🎬 Scene 4: The Memory Master Emerges
# ──────────────────────────────────────────────────
# 🎬 Scene: A customer poses a complex question that would stump previous versions of Alex...
# 🏗️ Alex v3.0 (HippoRAG) building knowledge base...
#    📊 Knowledge Graph: 7 triples
#    📚 Document Store: 4 documents
# 💭 Customer asks: "I read a blog post about a famous museum in Paris. Can you find me a hotel near that museum that offers shuttle service?"
#
# 🧠 Alex v3.0 (HippoRAG) processing complex query...
#
# 🔍 Multi-hop retrieval for: 'I read a blog post about a famous museum in Paris. Can you find me a hotel near that museum that offers shuttle service?'
# ...

# %% [markdown]
# ## Part V: Nexus Framework - Alex Becomes a Team
#
# ### 🤝 **Chapter 4: The Collaborative Revolution**
#
# *Alex v3.0 possessed incredible memory and learning abilities, but faced a new challenge: the complexity of planning complete multi-day trips with flights, hotels, activities, restaurants, and local transport. No single agent, however sophisticated, could master every domain. The solution? Stop thinking of Alex as one agent, and start thinking of Alex as a team...*
#
# #### **The Nexus Paradigm Shift**
#
# **Nexus** represents the ultimate evolution in agent architecture: **from single-agent to multi-agent collaborative systems**. Instead of making one agent do everything, Nexus creates teams of specialized agents that work together.
#
# ##### **🏗️ The Hierarchical Architecture**
#
# Nexus employs a hierarchical structure:
#
# ```
#                     🧠 Supervisor Agent (Orchestrator)
#                            |
#         ┌─────────────────┼─────────────────┐
#         |                 |                 |
#     ✈️ Flight          🏨 Hotel         🎯 Activity
#      Specialist       Specialist       Specialist
#         |                 |                 |
#     📊 Tools &        📊 Tools &       📊 Tools &
#     📚 Knowledge      📚 Knowledge     📚 Knowledge
# ```
#
# ##### **👥 The Agent Ecosystem**
#
# **🧠 Supervisor Agents**:
# - **Orchestration**: Coordinate the overall workflow
# - **Task Decomposition**: Break complex requests into manageable subtasks
# - **Quality Control**: Ensure all components work together harmoniously
# - **Resource Management**: Allocate tasks to appropriate specialist agents
#
# **⚙️ Worker Agents**:
# - **Domain Expertise**: Deep specialization in specific areas
# - **Tool Mastery**: Advanced use of domain-specific APIs and services
# - **Quality Focus**: Optimized for specific types of problems
# - **Autonomous Operation**: Can work independently within their domain
#
# ##### **🔄 The Collaboration Workflow**
#
# The Nexus workflow follows a structured process:
#
# 1. **📝 Task Reception**: Supervisor receives complex user request
# 2. **🔍 Task Analysis**: Supervisor analyzes and decomposes the task
# 3. **👥 Agent Assignment**: Appropriate specialists are identified and assigned
# 4. **⚡ Parallel Execution**: Multiple agents work simultaneously
# 5. **🔄 Coordination**: Agents share information and coordinate timing
# 6. **🎯 Integration**: Results are combined into cohesive solution
# 7. **📊 Quality Assurance**: Final validation and optimization
#
# ##### **💡 The Scaling Advantage**
#
# Nexus solves the scalability problem:
#
# **Single Agent Limitations**:
# - Becomes overwhelmed with complex, multi-domain tasks
# - Cannot specialize deeply in all areas
# - Limited by working memory and context windows
# - Difficult to maintain and update
#
# **Multi-Agent Advantages**:
# - Each agent specializes in their domain of expertise
# - Parallel processing dramatically improves speed
# - Easy to add new capabilities by adding new agents
# - Fault tolerance through redundancy and backup agents
#
# ##### **🎭 Alex v4.0: The Ultimate Team**
#
# Our final evolution transforms Alex into an entire agency:
# - **🧠 Travel Supervisor**: Orchestrates the entire travel planning process
# - **✈️ Flight Specialist**: Expert in airline bookings, routes, and schedules
# - **🏨 Hotel Specialist**: Master of accommodations, locations, and amenities
# - **🎯 Activity Specialist**: Curator of experiences, tours, and entertainment
# - **🍽️ Dining Specialist**: Connoisseur of restaurants and local cuisine
# - **🚗 Transport Specialist**: Navigator of local transportation options
#
# ##### **🌟 The Emergent Intelligence**
#
# When agents work together, something magical happens: **emergent intelligence**. The team becomes more than the sum of its parts:
# - **Cross-domain Insights**: Agents share knowledge across specializations
# - **Optimized Coordination**: Timing and logistics are automatically optimized
# - **Quality Amplification**: Multiple experts review and improve each aspect
# - **Adaptive Scaling**: Team size adjusts based on task complexity
#
# *But how does a single agent become an entire organization? Let's witness Alex's final transformation...*

# %%
# 🤝 Implementing Alex v4.0: The Nexus Multi-Agent System
# Witness the birth of collaborative intelligence!

story.new_chapter("The Ultimate Evolution", 
                 "In this climactic chapter, Alex transcends individual intelligence to become a collaborative network of specialists, each a master of their domain, working in perfect harmony...")

class SharedMemory:
    """
    Central coordination system for multi-agent communication
    Enables agents to share information and coordinate activities
    """
    
    def __init__(self):
        self.shared_data = {}
        self.task_status = {}
        self.coordination_log = []
        
    def store(self, key: str, value: Any, agent_id: str):
        """Store information that other agents can access"""
        self.shared_data[key] = {
            "value": value,
            "stored_by": agent_id,
            "timestamp": time.time()
        }
        self.coordination_log.append(f"{agent_id} stored {key}")
        
    def retrieve(self, key: str, requesting_agent: str) -> Any:
        """Retrieve information stored by other agents"""
        if key in self.shared_data:
            self.coordination_log.append(f"{requesting_agent} accessed {key}")
            return self.shared_data[key]["value"]
        return None
    
    def update_task_status(self, task_id: str, status: str, agent_id: str):
        """Update the status of a task"""
        self.task_status[task_id] = {
            "status": status,
            "agent": agent_id,
            "timestamp": time.time()
        }
        self.coordination_log.append(f"{agent_id} updated {task_id} to {status}")

class SpecialistAgent:
    """
    Base class for domain-specific worker agents
    Each specialist has deep expertise in their domain
    """
    
    def __init__(self, name: str, specialty: str, world: TravelWorld, shared_memory: SharedMemory):
        self.name = name
        self.specialty = specialty
        self.world = world
        self.shared_memory = shared_memory
        
    def execute_task(self, task: Dict[str, Any]) -> Dict[str, Any]:
        """Execute a task within this agent's specialty"""
        raise NotImplementedError("Subclasses must implement execute_task")

class FlightSpecialist(SpecialistAgent):
    """Expert agent specializing in flight bookings and airline operations"""
    
    def __init__(self, world: TravelWorld, shared_memory: SharedMemory):
        super().__init__("FlightMaster", "Flight Operations", world, shared_memory)
        
    def execute_task(self, task: Dict[str, Any]) -> Dict[str, Any]:
        print(f"   ✈️ {self.name}: Handling flight booking...")
        
        destination = task.get("destination", "Unknown")
        date = task.get("date", "Unknown")
        
        # Use specialized flight booking logic
        result = self.world.search_flights(destination, date)
        
        if result["success"]:
            # Store flight information for other agents to use
            self.shared_memory.store("flight_details", {
                "destination": destination,
                "date": date,
                "flight_number": result["flight_number"],
                "price": result["price"]
            }, self.name)
            
        return result

class HotelSpecialist(SpecialistAgent):
    """Expert agent specializing in accommodations and lodging"""
    
    def __init__(self, world: TravelWorld, shared_memory: SharedMemory):
        super().__init__("HotelExpert", "Accommodation Services", world, shared_memory)
        
    def execute_task(self, task: Dict[str, Any]) -> Dict[str, Any]:
        print(f"   🏨 {self.name}: Handling hotel booking...")
        
        destination = task.get("destination", "Unknown")
        check_in_date = task.get("date", "Unknown")
        
        # Check if flight information is available for coordination
        flight_details = self.shared_memory.retrieve("flight_details", self.name)
        if flight_details:
            print(f"      📋 Coordinating with flight arrival: {flight_details['flight_number']}")
        
        result = self.world.book_hotel(destination, check_in_date)
        
        if result["success"]:
            self.shared_memory.store("hotel_details", {
                "destination": destination,
                "check_in_date": check_in_date,
                "hotel_name": result["hotel_name"],
                "price": result["price"]
            }, self.name)
            
        return result

class ActivitySpecialist(SpecialistAgent):
    """Expert agent specializing in activities, tours, and experiences"""
    
    def __init__(self, world: TravelWorld, shared_memory: SharedMemory):
        super().__init__("ActivityGuru", "Experience Curation", world, shared_memory)
        
    def execute_task(self, task: Dict[str, Any]) -> Dict[str, Any]:
        print(f"   🎯 {self.name}: Planning activities...")
        
        destination = task.get("destination", "Unknown")
        day = task.get("day", "Day 1")
        
        # Consider hotel location for activity recommendations
        hotel_details = self.shared_memory.retrieve("hotel_details", self.name)
        if hotel_details:
            print(f"      📋 Considering proximity to {hotel_details['hotel_name']}")
        
        result = self.world.find_activities(destination, day)
        
        if result["success"]:
            self.shared_memory.store(f"activities_{day.lower().replace(' ', '_')}", {
                "destination": destination,
                "day": day,
                "activities": result["activities"]
            }, self.name)
            
        return result

class TravelSupervisor:
    """
    Orchestrator agent that coordinates the entire travel planning process
    Manages task decomposition, agent coordination, and result integration
    """
    
    def __init__(self, world: TravelWorld, name: str = "Alex v4.0 (Nexus Supervisor)"):
        self.name = name
        self.world = world
        self.shared_memory = SharedMemory()
        
        # Initialize specialist agents
        self.specialists = {
            "flight": FlightSpecialist(world, self.shared_memory),
            "hotel": HotelSpecialist(world, self.shared_memory),
            "activity": ActivitySpecialist(world, self.shared_memory)
        }
        
    def decompose_task(self, user_request: str) -> List[Dict[str, Any]]:
        """
        Task decomposition: Break complex request into subtasks
        """
        print(f"🧠 {self.name}: Analyzing and decomposing task...")
        
        # Parse the user request (simplified logic)
        subtasks = []
        
        # Extract key information
        if "paris" in user_request.lower():
            destination = "Paris"
        elif "new york" in user_request.lower():
            destination = "New York"
        else:
            destination = "Paris"  # default
            
        # Extract date information
        import re
        date_pattern = r'\d{4}-\d{2}-\d{2}'
        date_matches = re.findall(date_pattern, user_request)
        date = date_matches[0] if date_matches else "2025-11-10"
        
        # Create subtasks based on request content
        if "flight" in user_request.lower():
            subtasks.append({
                "type": "flight_booking",
                "agent": "flight",
                "destination": destination,
                "date": date,
                "priority": 1
            })
            
        if "hotel" in user_request.lower():
            subtasks.append({
                "type": "hotel_booking",
                "agent": "hotel", 
                "destination": destination,
                "date": date,
                "priority": 2
            })
            
        if "activities" in user_request.lower() or "day" in user_request.lower():
            for day_num in range(1, 4):  # 3-day trip
                subtasks.append({
                    "type": "activity_planning",
                    "agent": "activity",
                    "destination": destination,
                    "day": f"Day {day_num}",
                    "priority": 3
                })
        
        print(f"   📋 Decomposed into {len(subtasks)} subtasks")
        return subtasks
    
    def coordinate_agents(self, subtasks: List[Dict[str, Any]]) -> Dict[str, Any]:
        """
        Agent coordination: Execute subtasks with proper sequencing
        """
        print(f"\n👥 {self.name}: Coordinating specialist agents...")
        
        results = {}
        
        # Sort subtasks by priority for proper sequencing
        subtasks.sort(key=lambda x: x["priority"])
        
        for i, subtask in enumerate(subtasks):
            print(f"\n📍 Subtask {i+1}/{len(subtasks)}: {subtask['type']}")
            
            agent_type = subtask["agent"]
            if agent_type in self.specialists:
                # Update task status
                task_id = f"{subtask['type']}_{i+1}"
                self.shared_memory.update_task_status(task_id, "in_progress", self.name)
                
                # Execute the subtask
                specialist = self.specialists[agent_type]
                result = specialist.execute_task(subtask)
                
                results[task_id] = result
                
                # Update completion status
                status = "completed" if result["success"] else "failed"
                self.shared_memory.update_task_status(task_id, status, self.name)
            
        return results
    
    def synthesize_results(self, results: Dict[str, Any]) -> Dict[str, Any]:
        """
        Result integration: Combine specialist outputs into coherent plan
        """
        print(f"\n🎯 {self.name}: Synthesizing final travel plan...")
        
        # Gather all shared information
        flight_details = self.shared_memory.retrieve("flight_details", self.name)
        hotel_details = self.shared_memory.retrieve("hotel_details", self.name)
        
        # Collect all activities
        activities = {}
        for key, data in self.shared_memory.shared_data.items():
            if key.startswith("activities_"):
                day = key.replace("activities_", "").replace("_", " ").title()
                activities[day] = data["value"]["activities"]
        
        # Calculate total cost
        total_cost = 0
        if flight_details:
            total_cost += flight_details.get("price", 0)
        if hotel_details:
            total_cost += hotel_details.get("price", 0) * 3  # 3 nights
        
        # Create comprehensive travel plan
        travel_plan = {
            "success": len([r for r in results.values() if r["success"]]) > 0,
            "flight": flight_details,
            "hotel": hotel_details,
            "activities": activities,
            "total_estimated_cost": total_cost,
            "coordination_log": self.shared_memory.coordination_log,
            "task_status": self.shared_memory.task_status
        }
        
        return travel_plan
    
    def plan_comprehensive_trip(self, user_request: str) -> Dict[str, Any]:
        """
        Main Nexus orchestration: Complete multi-agent trip planning
        """
        print(f"\n🌟 {self.name} activating multi-agent travel planning...")
        print(f"📝 User Request: {user_request}")
        print("=" * 70)
        
        # Step 1: Task Decomposition
        subtasks = self.decompose_task(user_request)
        
        # Step 2: Agent Coordination  
        results = self.coordinate_agents(subtasks)
        
        # Step 3: Result Synthesis
        travel_plan = self.synthesize_results(results)
        
        return travel_plan

# 🎭 The Grand Finale: Alex v4.0 in Action!
print("🎬 Final Scene: The Nexus Revolution")
print("─" * 50)

story.scene("A customer requests the most complex trip yet - a complete 3-day Paris adventure with flights, hotels, and daily activities...")

# Create the ultimate Alex v4.0
alex_v4 = TravelSupervisor(travel_world, "Alex v4.0 (Nexus Team)")

# The ultimate test: complex multi-day trip planning
complex_request = "Plan a complete 3-day trip to Paris for 2025-11-10. I need flights, hotel, and activities for each day."

print(f"💭 Customer's ultimate challenge: \"{complex_request}\"")

# Watch the multi-agent system in action
final_plan = alex_v4.plan_comprehensive_trip(complex_request)

print(f"\n📊 Nexus System Performance Summary:")
print("="*70)
print(f"   🎯 Overall Success: {'✅' if final_plan['success'] else '❌'}")
print(f"   💰 Total Estimated Cost: ${final_plan['total_estimated_cost']}")
print(f"   👥 Agents Coordinated: {len(alex_v4.specialists)}")
print(f"   🔄 Coordination Events: {len(final_plan['coordination_log'])}")

if final_plan["flight"]:
    print(f"\n✈️ Flight Details:")
    print(f"   Flight: {final_plan['flight']['flight_number']}")
    print(f"   Cost: ${final_plan['flight']['price']}")

if final_plan["hotel"]:
    print(f"\n🏨 Hotel Details:")
    print(f"   Hotel: {final_plan['hotel']['hotel_name']}")
    print(f"   Cost: ${final_plan['hotel']['price']}/night")

if final_plan["activities"]:
    print(f"\n🎯 Activity Plan:")
    for day, activity_list in final_plan["activities"].items():
        print(f"   {day}: {', '.join(activity_list)}")

print(f"\n🤝 Agent Coordination Log:")
for i, event in enumerate(final_plan["coordination_log"][-5:]):  # Show last 5 events
    print(f"   {i+1}. {event}")

story.narrate("""Magnificent! Alex v4.0 has achieved what no single agent could: 
a complete, coordinated, multi-domain solution through the power of collaborative intelligence. 
This is the future of AI - not one super-intelligent agent, but teams of specialized agents working in perfect harmony.""")
# Out:
# 📖 Chapter 6: The Ultimate Evolution
# ──────────────────────────────────────────────────
# 🎭 In this climactic chapter, Alex transcends individual intelligence to become a collaborative network of specialists, each a master of their domain, working in perfect harmony...
#
# 🎬 Final Scene: The Nexus Revolution
# ──────────────────────────────────────────────────
# 🎬 Scene: A customer requests the most complex trip yet - a complete 3-day Paris adventure with flights, hotels, and daily activities...
# 💭 Customer's ultimate challenge: "Plan a complete 3-day trip to Paris for 2025-11-10. I need flights, hotel, and activities for each day."
#
# 🌟 Alex v4.0 (Nexus Team) activating multi-agent travel planning...
# 📝 User Request: Plan a complete 3-day trip to Paris for 2025-11-10. I need flights, hotel, and activities for each day.
# ...
# 🧠 Alex v4.0 (Nexus Team): Analyzing and decomposing task...
#    📋 Decomposed into 5 subtasks
#
# 👥 Alex v4.0 (Nexus Team): Coordinating specialist agents...
#
# ...

# %%
# 📊 Comprehensive Analysis: The Complete Evolution Journey
# Let's analyze and compare all four agent architectures

story.new_chapter("The Great Analysis", 
                 "Our journey through agent evolution is complete. Now let us step back and witness the full arc of transformation - from simple ReAct to collaborative Nexus...")

print("🔬 COMPREHENSIVE AGENT ARCHITECTURE ANALYSIS")
print("="*80)

# Performance Testing Suite
def run_comprehensive_tests():
    """Run all agents on the same challenging scenarios"""
    
    test_scenarios = [
        {
            "name": "Simple Trip Planning",
            "request": "I want to plan a trip to Paris for 2025-10-26. I need a flight and hotel.",
            "expected_complexity": "Low",
            "tests_basic_functionality": True
        },
        {
            "name": "Failure Recovery", 
            "request": "I want to plan a trip to Paris for 2025-10-25. I need a flight and hotel.",
            "expected_complexity": "Medium",
            "tests_learning_capability": True
        },
        {
            "name": "Complex Knowledge Integration",
            "request": "I read a blog post about a famous museum in Paris. Find me a hotel near that museum that offers shuttle service.",
            "expected_complexity": "High",
            "tests_memory_and_reasoning": True
        },
        {
            "name": "Multi-Domain Coordination",
            "request": "Plan a complete 3-day trip to Paris for 2025-11-10. I need flights, hotel, and activities for each day.",
            "expected_complexity": "Very High", 
            "tests_scalability": True
        }
    ]
    
    # Initialize all agents
    agents = {
        "ReAct (v1.0)": ReActAgent(travel_world, llm, "Alex v1.0"),
        "Reflexion (v2.0)": ReflexionAgent(travel_world, llm, "Alex v2.0"),
        "HippoRAG (v3.0)": HippoRAGAgent(travel_world, llm, "Alex v3.0"),
        "Nexus (v4.0)": TravelSupervisor(travel_world, "Alex v4.0")
    }
    
    results = {}
    
    for scenario in test_scenarios:
        print(f"\n🎯 Testing Scenario: {scenario['name']}")
        print(f"   Complexity: {scenario['expected_complexity']}")
        print("   " + "─"*60)
        
        scenario_results = {}
        
        for agent_name, agent in agents.items():
            print(f"\n   🤖 {agent_name}:")
            
            try:
                if agent_name == "ReAct (v1.0)":
                    result = agent.plan_trip(scenario["request"], max_steps=4)
                    success = result["success"]
                    
                elif agent_name == "Reflexion (v2.0)":
                    result = agent.plan_trip_with_learning(scenario["request"], max_trials=2)
                    success = result["success"]
                    
                elif agent_name == "HippoRAG (v3.0)":
                    if "museum" in scenario["request"]:
                        answer = agent.answer_complex_query(scenario["request"])
                        success = "hotel regina" in answer.lower() and "shuttle" in answer.lower()
                        result = {"answer": answer, "success": success}
                    else:
                        # Use basic planning for non-memory tasks
                        result = {"success": False, "reason": "Not specialized for this task type"}
                        success = False
                        
                elif agent_name == "Nexus (v4.0)":
                    result = agent.plan_comprehensive_trip(scenario["request"])
                    success = result["success"]
                    
                scenario_results[agent_name] = {
                    "success": success,
                    "result": result,
                    "performance": "✅ Success" if success else "❌ Failed"
                }
                
                print(f"      Result: {'✅ Success' if success else '❌ Failed'}")
                
            except Exception as e:
                scenario_results[agent_name] = {
                    "success": False,
                    "result": {"error": str(e)},
                    "performance": "❌ Error"
                }
                print(f"      Result: ❌ Error - {str(e)[:50]}...")
        
        results[scenario["name"]] = scenario_results
    
    return results, test_scenarios

# Run comprehensive testing
print("🚀 Running comprehensive test suite...")
test_results, scenarios = run_comprehensive_tests()

# Create detailed analysis table
print(f"\n📊 PERFORMANCE MATRIX")
print("="*80)

# Header
print(f"{'Scenario':<25} {'ReAct v1.0':<12} {'Reflexion v2.0':<15} {'HippoRAG v3.0':<15} {'Nexus v4.0':<12}")
print("─" * 80)

# Results for each scenario
for scenario_name, scenario_results in test_results.items():
    row = f"{scenario_name:<25}"
    for agent in ["ReAct (v1.0)", "Reflexion (v2.0)", "HippoRAG (v3.0)", "Nexus (v4.0)"]:
        performance = scenario_results[agent]["performance"]
        status = "✅" if "Success" in performance else "❌" 
        row += f" {status:<11}"
    print(row)

# Calculate overall success rates
print(f"\n📈 OVERALL SUCCESS RATES")
print("─"*50)

for agent in ["ReAct (v1.0)", "Reflexion (v2.0)", "HippoRAG (v3.0)", "Nexus (v4.0)"]:
    successes = sum(1 for scenario_results in test_results.values() 
                   if scenario_results[agent]["success"])
    total = len(test_results)
    success_rate = (successes / total) * 100
    print(f"{agent:<20}: {success_rate:5.1f}% ({successes}/{total} scenarios)")

# Capability analysis
print(f"\n🔍 CAPABILITY ANALYSIS")
print("="*80)

capabilities = {
    "ReAct (v1.0)": {
        "Basic Reasoning": "✅ Excellent",
        "Tool Integration": "✅ Excellent", 
        "Error Recovery": "❌ None",
        "Learning": "❌ None",
        "Memory": "❌ None",
        "Scalability": "❌ Poor",
        "Specialization": "❌ Generalist only"
    },
    "Reflexion (v2.0)": {
        "Basic Reasoning": "✅ Excellent",
        "Tool Integration": "✅ Excellent",
        "Error Recovery": "✅ Good",
        "Learning": "✅ Self-reflection",
        "Memory": "⚠️ Short-term only", 
        "Scalability": "⚠️ Limited",
        "Specialization": "❌ Generalist only"
    },
    "HippoRAG (v3.0)": {
        "Basic Reasoning": "✅ Excellent",
        "Tool Integration": "✅ Good",
        "Error Recovery": "⚠️ Limited",
        "Learning": "⚠️ Static knowledge",
        "Memory": "✅ Excellent (Long-term)",
        "Scalability": "⚠️ Single agent limit",
        "Specialization": "⚠️ Knowledge-focused"
    },
    "Nexus (v4.0)": {
        "Basic Reasoning": "✅ Excellent",
        "Tool Integration": "✅ Excellent",
        "Error Recovery": "✅ Multi-agent resilience",
        "Learning": "⚠️ Inherited from agents",
        "Memory": "✅ Distributed memory",
        "Scalability": "✅ Excellent",
        "Specialization": "✅ Domain experts"
    }
}

for agent_name, caps in capabilities.items():
    print(f"\n🤖 {agent_name}:")
    for capability, rating in caps.items():
        print(f"   {capability:<20}: {rating}")

# Evolution timeline
print(f"\n📈 EVOLUTIONARY TIMELINE")
print("="*80)

timeline = [
    ("ReAct", "2022", "Thought-Action-Observation loop", "Grounded reasoning in reality"),
    ("Reflexion", "2023", "Self-improvement through reflection", "Learning from failures"),
    ("HippoRAG", "2024", "Neuro-inspired memory architecture", "Complex knowledge integration"), 
    ("Nexus", "2024", "Multi-agent collaboration", "Scalable specialization")
]

for framework, year, innovation, achievement in timeline:
    print(f"{year} - {framework:<12}: {innovation:<35} → {achievement}")

print(f"\n💡 KEY INSIGHTS FROM THE EVOLUTION:")
print("─"*60)
print("1. Each framework addresses specific limitations of its predecessors")
print("2. The progression follows biological evolution: complexity → specialization → collaboration")
print("3. Modern agents require ALL capabilities: reasoning, learning, memory, and teamwork")
print("4. The future is multi-agent: specialized teams working together")
print("5. Agent-first design philosophy enables true autonomous systems")

story.narrate("""And so our journey through the evolution of language agents is complete. 
We have witnessed the transformation from simple reactive systems to sophisticated collaborative intelligence. 
Alex's journey mirrors the entire field of AI: from single-purpose tools to autonomous, 
learning, remembering, collaborating artificial beings that may one day match and surpass human intelligence.""")
# Out:
# 📖 Chapter 7: The Great Analysis
# ──────────────────────────────────────────────────
# 🎭 Our journey through agent evolution is complete. Now let us step back and witness the full arc of transformation - from simple ReAct to collaborative Nexus...
#
# 🔬 COMPREHENSIVE AGENT ARCHITECTURE ANALYSIS
# ...
# 🚀 Running comprehensive test suite...
# 🏗️ Alex v3.0 building knowledge base...
#    📊 Knowledge Graph: 7 triples
#    📚 Document Store: 4 documents
#
# 🎯 Testing Scenario: Simple Trip Planning
#    Complexity: Low
#    ────────────────────────────────────────────────────────────
#
#    🤖 ReAct (v1.0):
#
# 🤖 Alex v1.0 starting trip planning...
# 📝 User Request: I want to plan a trip to Paris for 2025-10-26. I need a flight and hotel.
# ...
#
# 📍 Step 1/4
# ──────────────────────────────
# 🤔 Thought Phase:
#    💭 I need to search for flights to help the user with their travel plans.
# ⚡ Action Phase:
#   🛫 [Flight Search API] Searching for flights to Paris on 2025-10-26...
# ...

# %% [markdown]
# ## Part VI: Conclusions and Future Horizons
#
# ### 🌟 **The Journey's End: What We've Learned**
#
# *As our epic journey through the evolution of language agents comes to a close, we stand transformed. We began with a simple question: "How do we create truly intelligent agents?" We end with profound understanding of the architectural principles that will shape the future of artificial intelligence.*
#
# #### **🧬 The Evolutionary Pattern**
#
# Our journey revealed a clear evolutionary pattern in agent architecture:
#
# 1. **🎯 Foundation (ReAct)**: Grounding reasoning in reality
# 2. **🔄 Adaptation (Reflexion)**: Learning from experience without retraining
# 3. **🧠 Integration (HippoRAG)**: Complex knowledge synthesis through associative memory
# 4. **🤝 Collaboration (Nexus)**: Scaling through specialization and teamwork
#
# Each stage built upon the last, addressing fundamental limitations while preserving essential capabilities.
#
# #### **🔬 Core Architectural Principles**
#
# Through Alex's transformation, we discovered universal principles of intelligent agent design:
#
# ##### **Principle 1: Environmental Grounding**
# - Intelligence requires interaction with reality
# - Feedback loops between thought and action are essential
# - Observation grounds reasoning in factual outcomes
#
# ##### **Principle 2: Experiential Learning**
# - True intelligence learns from mistakes
# - Verbal reinforcement can replace expensive retraining
# - Self-reflection enables continuous improvement
#
# ##### **Principle 3: Associative Memory**
# - Complex reasoning requires rich memory structures
# - Graph-based knowledge representation enables multi-hop inference
# - Biological inspiration provides powerful architectural insights
#
# ##### **Principle 4: Collaborative Intelligence**
# - No single agent can master all domains
# - Specialization enables deeper expertise
# - Coordination mechanisms are crucial for team performance
#
# #### **🚀 The Paradigm Shift: Agent-First Design**
#
# Perhaps the most profound insight is the philosophical shift from **LLM-First** to **Agent-First** design:
#
# **LLM-First Approach:**
# ```
# Language Model → Add Tools → Add Memory → Scale Up
# ```
#
# **Agent-First Approach:**
# ```
# Agent Architecture → Integrate Reasoning → Add Specialists → Coordinate
# ```
#
# This shift changes everything:
# - Architecture drives functionality, not model size
# - Intelligence emerges from system design, not just parameters
# - Scalability comes from coordination, not computation
#
# #### **📊 Performance Insights**
#
# Our comprehensive testing revealed clear performance patterns:
#
# - **ReAct**: Excellent for straightforward tasks, fails on complex scenarios
# - **Reflexion**: Significant improvement in adaptability and learning
# - **HippoRAG**: Breakthrough performance on knowledge-intensive tasks
# - **Nexus**: Superior performance across all dimensions through specialization
#
# #### **🌍 Real-World Applications**
#
# The architectures we explored have immediate applications:
#
# ##### **Customer Service Evolution**
# - ReAct: Basic query handling with tool integration
# - Reflexion: Learning from customer feedback and improving responses
# - HippoRAG: Synthesizing information across knowledge bases
# - Nexus: Specialized agents for billing, technical support, and sales
#
# ##### **Scientific Research Acceleration**
# - ReAct: Literature search and basic analysis
# - Reflexion: Iterative hypothesis refinement
# - HippoRAG: Cross-disciplinary knowledge integration
# - Nexus: Multi-expert research teams with coordinated investigation
#
# ##### **Enterprise Automation**
# - ReAct: Process automation with decision points
# - Reflexion: Self-improving workflows
# - HippoRAG: Institutional knowledge management
# - Nexus: Department-spanning collaborative systems
#
# ---
#
# ### 🔮 **Future Horizons: The Next Evolution**
#
# #### **Emerging Frontiers**
#
# Our journey through current architectures hints at future developments:
#
# ##### **🧠 Neuromorphic Integration**
# - Direct neural network architectures inspired by brain structure
# - Hardware-software co-design for efficient agent computation
# - Biological memory mechanisms integrated into silicon
#
# ##### **🌐 Distributed Intelligence**
# - Agents operating across global networks
# - Blockchain-based agent coordination and trust
# - Edge computing for real-time local intelligence
#
# ##### **🤖 Physical Embodiment**
# - Integration with robotic systems for physical world interaction
# - Sensor fusion for rich environmental perception
# - Motor control integration with planning and reasoning
#
# ##### **🧬 Self-Modifying Systems**
# - Agents that modify their own architecture
# - Evolutionary algorithms for automatic agent improvement
# - Meta-learning systems that learn how to learn
#
# #### **Ethical Considerations**
#
# As agents become more capable, new challenges emerge:
#
# ##### **🎯 Alignment and Control**
# - Ensuring agent goals remain aligned with human values
# - Maintaining meaningful human oversight of autonomous systems
# - Preventing unintended consequences from goal optimization
#
# ##### **🤝 Human-Agent Collaboration**
# - Designing interfaces for effective human-agent teamwork
# - Balancing automation with human agency and meaning
# - Ensuring equitable distribution of AI benefits
#
# ##### **⚖️ Responsibility and Accountability**
# - Establishing clear responsibility chains for agent actions
# - Creating audit trails for complex multi-agent decisions
# - Developing legal frameworks for autonomous agent behavior
#
# #### **The Research Agenda**
#
# Critical areas for continued development:
#
# 1. **🔬 Fundamental Architecture Research**
#    - New cognitive architectures inspired by neuroscience and psychology
#    - Theoretical foundations for multi-agent coordination
#    - Efficient learning algorithms for large-scale agent systems
#
# 2. **🛠️ Engineering Challenges**
#    - Scalable infrastructure for massive multi-agent systems
#    - Robust communication protocols for agent coordination
#    - Fault-tolerant architectures for critical applications
#
# 3. **📊 Evaluation and Benchmarking**
#    - Comprehensive benchmarks for agent capabilities
#    - Standardized evaluation protocols across architectures
#    - Long-term performance measurement frameworks
#
# ---
#
# ### 🎭 **Alex's Legacy: A Personal Reflection**
#
# *Throughout this journey, Alex has been more than just a travel planning agent. Alex represents the aspiration of artificial intelligence: to create systems that are not merely tools, but genuine collaborators in human endeavors.*
#
# **Alex v1.0** showed us the power of grounded reasoning - the moment when AI stopped being a text generator and became a problem-solver.
#
# **Alex v2.0** revealed the transformative power of learning from failure - the quality that separates intelligence from mere computation.
#
# **Alex v3.0** demonstrated the magic of associative memory - the ability to synthesize knowledge in ways that approach human understanding.
#
# **Alex v4.0** embodied the future of AI - collaborative intelligence that transcends individual limitations through coordinated specialization.
#
# #### **The Continuing Story**
#
# Alex's evolution doesn't end here. In laboratories and research centers around the world, new versions of Alex are being born:
#
# - **Alex v5.0** might integrate emotional intelligence and social reasoning
# - **Alex v6.0** could achieve true common-sense understanding
# - **Alex v7.0** might develop creativity and artistic expression
# - **Alex v∞** could represent the culmination of artificial general intelligence
#
# ### 🌅 **The Dawn of the Agent Age**
#
# We stand at the threshold of the **Agent Age** - an era where artificial agents will be as common and essential as smartphones are today. These agents won't just respond to our commands; they'll anticipate our needs, learn from our preferences, and collaborate with us as genuine partners in solving the world's most challenging problems.
#
# The architectures we've explored - ReAct, Reflexion, HippoRAG, and Nexus - are the foundation stones of this new world. Understanding them is understanding the future itself.
#
# ---
#
# *And so ends the tale of Alex's evolution, but the story of artificial intelligence has only just begun. Each of us who understands these principles becomes an architect of the future, capable of designing the intelligent systems that will shape tomorrow's world.*
#
# **The future is not just artificial intelligence. The future is artificial collaboration.**
#
# 🌟 *Welcome to the Agent Age.* 🌟
