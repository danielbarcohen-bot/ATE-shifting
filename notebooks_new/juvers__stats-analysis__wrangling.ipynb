# %%
import pandas as pd
import numpy as np
import zipfile
import os
import subprocess

with zipfile.ZipFile('armenian-online-job-postings.zip', 'r') as myzip:
    myzip.extractall()
    
os.listdir('./')
df = pd.read_csv('online-job-postings.csv')
df.query('IT == True' and 'Month == 1' and 'Title == "Chief Financial Officer"').count()
df.head()
# Out:
#                                              jobpost          date  \
# 0  AMERIA Investment Consulting Company\r\nJOB TI...   Jan 5, 2004
# 1  International Research & Exchanges Board (IREX...   Jan 7, 2004
# 2  Caucasus Environmental NGO Network (CENN)\r\nJ...   Jan 7, 2004
# 3  Manoff Group\r\nJOB TITLE:  BCC Specialist\r\n...   Jan 7, 2004
# 4  Yerevan Brandy Company\r\nJOB TITLE:  Software...  Jan 10, 2004
#
#                                                Title  \
# 0                            Chief Financial Officer
# 1  Full-time Community Connections Intern (paid i...
# 2                                Country Coordinator
# 3                                     BCC Specialist
# 4                                 Software Developer
#
#                                            Company AnnouncementCode Term  \
# 0             AMERIA Investment Consulting Company              NaN  NaN
# 1  International Research & Exchanges Board (IREX)              NaN  NaN
# 2        Caucasus Environmental NGO Network (CENN)              NaN  NaN
# 3                                     Manoff Group              NaN  NaN
# 4                           Yerevan Brandy Company              NaN  NaN
#
#   Eligibility Audience StartDate                               Duration  \
# 0         NaN      NaN       NaN                                    NaN
# 1         NaN      NaN       NaN                               3 months
# 2         NaN      NaN       NaN  Renewable annual contract\r\nPOSITION
# 3         NaN      NaN       NaN                                    NaN
# 4         NaN      NaN       NaN                                    NaN
#
#    ...   Salary                                       ApplicationP  \
# 0  ...      NaN  To apply for this position, please submit a\r\...
# 1  ...      NaN  Please submit a cover letter and resume to:\r\...
# 2  ...      NaN  Please send resume or CV toursula.kazarian@......
# 3  ...      NaN  Please send cover letter and resume to Amy\r\n...
# 4  ...      NaN  Successful candidates should submit\r\n- CV; \...
#
#   OpeningDate                                       Deadline Notes  \
# 0         NaN                                26 January 2004   NaN
# 1         NaN                                12 January 2004   NaN
# 2         NaN  20 January 2004\r\nSTART DATE:  February 2004   NaN
# 3         NaN      23 January 2004\r\nSTART DATE:  Immediate   NaN
# 4         NaN                         20 January 2004, 18:00   NaN
#
#                                               AboutC Attach  Year Month     IT
# 0                                                NaN    NaN  2004     1  False
# 1  The International Research & Exchanges Board (...    NaN  2004     1  False
# 2  The Caucasus Environmental NGO Network is a\r\...    NaN  2004     1  False
# 3                                                NaN    NaN  2004     1  False
# 4                                                NaN    NaN  2004     1   True
#
# [5 rows x 24 columns]

# %%
nn = os.getcwd()
nn.split('/')[len(nn.split('/'))-2]
# Out:
# 'jkuti'

# %% [markdown]
# ### Tidy Data
# - Each variable is a column each observation is a row.
# - Each type of observational unit is a table.
# - Untidy vs Messy Data
#
# Tidy datasets provide a standardized way to link the structure of a dataset (its physical layout) with its semantics (its meaning).
#
# ### Messy data
# - Column headers are values, not variable names.
# - Multiple variables are stored in one column.
# - Variables are stored in both rows and columns.
# - Multiple types of observational units are stored in the same table.
# - A single observational unit is stored in multiple tables.
#
# ##### Dot vs Bracket Notation
# > Only bracket notation work in the following instances:
# - if variables start with a number e.g. 4days
# - if variables have a space in them e.g four days
# - if variables have a dash in them e.g four-days

# %%
# Get a copy of the df
df_clean = df.copy()

# Change the column names by inplacing True
df_clean.rename(columns={'ApplicationP':'ApplicationProcedure','AboutC': 'AboutCompany','RequiredQual':'RequiredQualification','JobRequirment':'JobRequirements'}, inplace=True)
df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19001 entries, 0 to 19000
# Data columns (total 24 columns):
# jobpost                  19001 non-null object
# date                     19001 non-null object
# Title                    18973 non-null object
# Company                  18994 non-null object
# AnnouncementCode         1208 non-null object
# Term                     7676 non-null object
# Eligibility              4930 non-null object
# Audience                 640 non-null object
# StartDate                9675 non-null object
# Duration                 10798 non-null object
# Location                 18969 non-null object
# JobDescription           15109 non-null object
# JobRequirements          16479 non-null object
# RequiredQualification    18517 non-null object
# Salary                   9622 non-null object
# ApplicationProcedure     18941 non-null object
# OpeningDate              18295 non-null object
# Deadline                 18936 non-null object
# Notes                    2211 non-null object
# AboutCompany             12470 non-null object
# Attach                   1559 non-null object
# Year                     19001 non-null int64
# Month                    19001 non-null int64
# IT                       19001 non-null bool
# dtypes: bool(1), int64(2), object(21)
# memory usage: 3.4+ MB

# %%
df_clean['StartDate'].value_counts()
# Create a deep copy of df_clean as df_clean2 not to lose original content
df_clean2 = df_clean.copy()
clean_val = df_clean2['StartDate'].value_counts()
# convert value_count keys to array using object.keys()
asap_list = list(clean_val.keys())
asap_list
for phrase in asap_list:
    # loop through asap_list and replace every value with the word 'ASAP' using replace(...)
    df_clean.StartDate.replace(phrase, 'ASAP', inplace=True)
# Check if all values have been replaced with 'ASAP'
df_clean['StartDate'].value_counts()
# Out:
# ASAP    9675
# Name: StartDate, dtype: int64

# %%
df_clean.head()
# Out:
#                                              jobpost          date  \
# 0  AMERIA Investment Consulting Company\r\nJOB TI...   Jan 5, 2004
# 1  International Research & Exchanges Board (IREX...   Jan 7, 2004
# 2  Caucasus Environmental NGO Network (CENN)\r\nJ...   Jan 7, 2004
# 3  Manoff Group\r\nJOB TITLE:  BCC Specialist\r\n...   Jan 7, 2004
# 4  Yerevan Brandy Company\r\nJOB TITLE:  Software...  Jan 10, 2004
#
#                                                Title  \
# 0                            Chief Financial Officer
# 1  Full-time Community Connections Intern (paid i...
# 2                                Country Coordinator
# 3                                     BCC Specialist
# 4                                 Software Developer
#
#                                            Company AnnouncementCode Term  \
# 0             AMERIA Investment Consulting Company              NaN  NaN
# 1  International Research & Exchanges Board (IREX)              NaN  NaN
# 2        Caucasus Environmental NGO Network (CENN)              NaN  NaN
# 3                                     Manoff Group              NaN  NaN
# 4                           Yerevan Brandy Company              NaN  NaN
#
#   Eligibility Audience StartDate                               Duration  \
# 0         NaN      NaN       NaN                                    NaN
# 1         NaN      NaN       NaN                               3 months
# 2         NaN      NaN       NaN  Renewable annual contract\r\nPOSITION
# 3         NaN      NaN       NaN                                    NaN
# 4         NaN      NaN       NaN                                    NaN
#
#    ...   Salary                               ApplicationProcedure  \
# 0  ...      NaN  To apply for this position, please submit a\r\...
# 1  ...      NaN  Please submit a cover letter and resume to:\r\...
# 2  ...      NaN  Please send resume or CV toursula.kazarian@......
# 3  ...      NaN  Please send cover letter and resume to Amy\r\n...
# 4  ...      NaN  Successful candidates should submit\r\n- CV; \...
#
#   OpeningDate                                       Deadline Notes  \
# 0         NaN                                26 January 2004   NaN
# 1         NaN                                12 January 2004   NaN
# 2         NaN  20 January 2004\r\nSTART DATE:  February 2004   NaN
# 3         NaN      23 January 2004\r\nSTART DATE:  Immediate   NaN
# 4         NaN                         20 January 2004, 18:00   NaN
#
#                                         AboutCompany Attach  Year Month     IT
# 0                                                NaN    NaN  2004     1  False
# 1  The International Research & Exchanges Board (...    NaN  2004     1  False
# 2  The Caucasus Environmental NGO Network is a\r\...    NaN  2004     1  False
# 3                                                NaN    NaN  2004     1  False
# 4                                                NaN    NaN  2004     1   True
#
# [5 rows x 24 columns]

# %%
df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19001 entries, 0 to 19000
# Data columns (total 24 columns):
# jobpost                  19001 non-null object
# date                     19001 non-null object
# Title                    18973 non-null object
# Company                  18994 non-null object
# AnnouncementCode         1208 non-null object
# Term                     7676 non-null object
# Eligibility              4930 non-null object
# Audience                 640 non-null object
# StartDate                9675 non-null object
# Duration                 10798 non-null object
# Location                 18969 non-null object
# JobDescription           15109 non-null object
# JobRequirements          16479 non-null object
# RequiredQualification    18517 non-null object
# Salary                   9622 non-null object
# ApplicationProcedure     18941 non-null object
# OpeningDate              18295 non-null object
# Deadline                 18936 non-null object
# Notes                    2211 non-null object
# AboutCompany             12470 non-null object
# Attach                   1559 non-null object
# Year                     19001 non-null int64
# Month                    19001 non-null int64
# IT                       19001 non-null bool
# dtypes: bool(1), int64(2), object(21)
# memory usage: 3.4+ MB

# %%
# Using assert statements to test
# asser condition, message 
# same as below
# if not condition:
#     raise AssertionError(message)
assert 2 + 2 == 4
assert 2 + 2 == 5, "2 plus 2 is 4"
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-5-d6b8e86a7786> in <module>
#       5 #     raise AssertionError(message)
#       6 assert 2 + 2 == 4
# ----> 7 assert 2 + 2 == 5, "2 plus 2 is 4"
#
# AssertionError: 2 plus 2 is 4

# %%
# test to see if 'ASAP' is not in 'StartDate', python should yell an assertion error at us, so the below is correct
for phrase in asap_list:
    assert phrase not in df_clean.StartDate.values
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-6-1b0bc3332c5a> in <module>
#       1 # test to see if 'ASAP' is not in 'StartDate', python should yell an assertion error at us, so the below is correct
#       2 for phrase in asap_list:
# ----> 3     assert phrase not in df_clean.StartDate.values
#
# AssertionError:

# %% [markdown]
# #### Wrangling vs EDA vs ETL
# - EDA: Exploratory Data Analysis, an analysis approach that focuses on identifying general patterns in the data, and identifying outliers and features of the data that might not have been anticipated.
# - Data wrangling: is about gathering the right pieces of data, assessing your data's quality and structure, then modifying your data to make it clean. But the assessments you make and convert to cleaning operations won't make your analysis, viz, or model better, though.
# - ETL: Extract-Transform-Load process is similar to Data Wrangling except that i.The users are different ii.The data is different iii.The use cases are different

# %%
# Get value count for year and plot a pie chart
df_clean.Year.value_counts().plot(kind="pie");

# %% [markdown]
# ## Gathering Data

# %%
# Read tsv files
# csv
# pandas.read_csv(filepath_or_buffer, sep=',', delimiter=None, header='infer',
# names=None, index_col=None, usecols=None)


# tsv
# pandas.read_csv(filepath_or_buffer, sep='\t', delimiter=None, header='infer',
# names=None, index_col=None, usecols=None)
# or
# pd.read_csv(fpath, sep='\t') or pd.read_table(fpath).


# Web Scrapping with beautiful soup

# %%
import requests
page = requests.get("http://letusgetpersonal.com")
page
# Out:
# <Response [200]>

# %%
page.status_code
# Out:
# 200

# %%
page.content
# Out:
# b'<!DOCTYPE html PUBLIC "-//W3C//DTD XHTML 1.0 Transitional//EN" "https://www.w3.org/TR/xhtml1/DTD/xhtml1-transitional.dtd">\n<html xmlns="https://www.w3.org/1999/xhtml">\n<head><meta http-equiv="Content-Type" content="text/html; charset=windows-1252">\n\n<title>Lets Get Personal</title>\n<link rel="stylesheet" href="https://www.hostgatorsupport.com/style.css" type="text/css" />\n</head>\n\n<body>\n<h1>Website content coming soon</h1>\n<p>This site is owned by Jude</p>\n</body>\n</html>\n'

# %%
from bs4 import BeautifulSoup
soup = BeautifulSoup(page.content, 'html.parser')
print(soup.prettify())
# Out:
# <!DOCTYPE html PUBLIC "-//W3C//DTD XHTML 1.0 Transitional//EN" "https://www.w3.org/TR/xhtml1/DTD/xhtml1-transitional.dtd">
# <html xmlns="https://www.w3.org/1999/xhtml">
#  <head>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#   <title>
#    Lets Get Personal
#   </title>
#   <link href="https://www.hostgatorsupport.com/style.css" rel="stylesheet" type="text/css"/>
#  </head>
#  <body>
#   <h1>
#    Website content coming soon
#   </h1>
#   <p>
#    This site is owned by Jude
#   </p>
#  </body>
# </html>

# %%
list(soup.children)
# Out:
# ['html PUBLIC "-//W3C//DTD XHTML 1.0 Transitional//EN" "https://www.w3.org/TR/xhtml1/DTD/xhtml1-transitional.dtd"',
#  '\n',
#  <html xmlns="https://www.w3.org/1999/xhtml">
#  <head><meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#  <title>Lets Get Personal</title>
#  <link href="https://www.hostgatorsupport.com/style.css" rel="stylesheet" type="text/css"/>
#  </head>
#  <body>
#  <h1>Website content coming soon</h1>
#  <p>This site is owned by Jude</p>
#  </body>
#  </html>,
#  '\n']

# %%
# list manipulation to check items
[type(item) for item in list(soup.children)]
# Out:
# [bs4.element.Doctype,
#  bs4.element.NavigableString,
#  bs4.element.Tag,
#  bs4.element.NavigableString]

# %%
# get only the html content
html = list(soup.children)[2]
html
# Out:
# <html xmlns="https://www.w3.org/1999/xhtml">
# <head><meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <title>Lets Get Personal</title>
# <link href="https://www.hostgatorsupport.com/style.css" rel="stylesheet" type="text/css"/>
# </head>
# <body>
# <h1>Website content coming soon</h1>
# <p>This site is owned by Jude</p>
# </body>
# </html>

# %%
# put the children of html in a list
list(html.children)
# Out:
# ['\n',
#  <head><meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#  <title>Lets Get Personal</title>
#  <link href="https://www.hostgatorsupport.com/style.css" rel="stylesheet" type="text/css"/>
#  </head>,
#  '\n',
#  <body>
#  <h1>Website content coming soon</h1>
#  <p>This site is owned by Jude</p>
#  </body>,
#  '\n']

# %%
# get body content
body = list(html.children)[3]
body
# Out:
# <body>
# <h1>Website content coming soon</h1>
# <p>This site is owned by Jude</p>
# </body>

# %%
h1 = list(body.children)[1]
h1
# Out:
# <h1>Website content coming soon</h1>

# %%
h1.get_text() # gives content without tags as string
h1.contents # gives content without tags but all content in a single array
h1.contents[0] # does what get_text() does
# Out:
# 'Website content coming soon'

# %% [markdown]
# ##### Change git repo with set-url
# > git remote -v # to check remote name
# > git remote set-url origin https://github.com/USERNAME/REPOSITORY.git
# > git remote -v # verify that remote has been set right

# %%
#### Search all instances at once
sei = requests.get('https://www.sei-mi.com')
sei
# Out:
# <Response [200]>

# %%
seiSoup = BeautifulSoup(sei.content, 'html.parser')
seiSoup
# Out:
# <!DOCTYPE html>
# <html>
# <head>
# <!-- Global site tag (gtag.js) - Google Analytics -->
# <script async="" src="https://www.googletagmanager.com/gtag/js?id=UA-135478469-1"></script>
# <script>
#     window.dataLayer = window.dataLayer || [];
#     function gtag(){dataLayer.push(arguments);}
#     gtag('js', new Date());
#
#     gtag('config', 'UA-135478469-1');
#     </script>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# <meta content="summary" name="twitter:card"/>
# <meta content="@SEI_Meetings" name="twitter:site"/>
# <meta content="@SEI_Meetings" name="twitter:creator"/>
# <meta content="SEI Meetings &amp; Incentives" name="twitter:title"/>
# <meta content="For over 40 years, SEI Meetings and Incentives has partnered with companies of all sizes to orchestrate motivational incentive programs, meetings, and exciting destination events all over the world. In this ever-changing global environment, SEI continues to evolve and elevate its commitment to the meeting and incentive industry." name="twitter:description"/>
# <meta content="https://res.cloudinary.com/mobileimages/image/upload/v1551472242/cdn/sei/logos/seilogofb3.png" name="twitter:image"/>
# <meta content="https://www.sei-mi.com/index.html" property="og:url"/>
# <meta content="article" property="og:type"/>
# <meta content="SEI Meetings &amp; Incentives" property="og:title"/>
# <meta content="For over 40 years, SEI Meetings and Incentives has partnered with companies of all sizes to orchestrate motivational incentive programs, meetings, and exciting destination events all over the world. In this ever-changing global environment, SEI continues to evolve and elevate its commitment to the meeting and incentive industry." property="og:description"/>
# <meta content="https://res.cloudinary.com/mobileimages/image/upload/v1551472242/cdn/sei/logos/seilogofb3.png" property="og:image"/>
# <meta content="1200" property="og:image:width"/>
# <meta content="1200" property="og:image:height"/>
# <title>SEI Meetings &amp; Incentives</title>
# <link href="https://cdnjs.cloudflare.com/ajax/libs/twitter-bootstrap/4.1.2/css/bootstrap.min.css" rel="stylesheet"/>
# <link crossorigin="anonymous" href="https://use.fontawesome.com/releases/v5.6.3/css/all.css" integrity="sha384-UHRtZLI+pbxtHCWp1t77Bi1L4ZtiqrqD80Kn4Z8NTSRyMA2Fd33n5dQ8lWUE00s/" rel="stylesheet"/>
# <link href="https://cdnjs.cloudflare.com/ajax/libs/ionicons/2.0.1/css/ionicons.min.css" rel="stylesheet"/>
# <link href="https://maxcdn.icons8.com/fonts/line-awesome/1.1/css/line-awesome-font-awesome.min.css" rel="stylesheet"/>
# <link href="https://cdnjs.cloudflare.com/ajax/libs/simple-line-icons/2.4.1/css/simple-line-icons.min.css" rel="stylesheet"/>
# <link href="https://fonts.googleapis.com/css?family=Raleway:300,400,500" rel="stylesheet" type="text/css"/>
# <link href="https://fonts.googleapis.com/css?family=Raleway+Dots" rel="stylesheet" type="text/css"/>
# <link href="https://fonts.googleapis.com/css?family=Spectral:300,300i,400,400i" rel="stylesheet"/>
# <link href="assets/css/Slider.css" rel="stylesheet"/>
# <link href="assets/css/Fixed-Navbar.css" rel="stylesheet"/>
# <link href="assets/css/Identity-Page.css" rel="stylesheet"/>
# <link href="assets/css/Brands.css" rel="stylesheet"/>
# <link href="assets/css/Corporate-Footer.css" rel="stylesheet"/>
# <link href="assets/css/Grid-Overlay-Hero.css" rel="stylesheet"/>
# <link href="https://cdnjs.cloudflare.com/ajax/libs/animate.css/3.5.2/animate.min.css" rel="stylesheet"/>
# <link href="https://cdnjs.cloudflare.com/ajax/libs/aos/2.1.1/aos.css" rel="stylesheet"/>
# <link href="assets/css/News-article.css" rel="stylesheet"/>
# <link href="assets/css/Scroll-To-Top-Button.css" rel="stylesheet"/>
# <link href="assets/css/styles.css" rel="stylesheet"/>
# <link href="assets/css/Text-Slider.css" rel="stylesheet"/>
# <link href="assets/css/Video-Parallax-Background-v2.css" rel="stylesheet"/>
# <link href="assets/css/Video-Parallax-Background.css" rel="stylesheet"/>
# <link href="https://res.cloudinary.com/mobileimages/image/upload/v1552066533/clients/sei/2019/sei-home-129/sei-favicon.png" rel="shortcut icon" type="image/x-icon"/>
# </head>
# <body>
# <div>
# <nav class="navbar navbar-light navbar-expand-lg fixed-top bg-white transparency border-bottom border-light" id="transmenu">
# <div class="container">
# <a class="navbar-brand" href="index.html" style="cursor:pointer;">
# <img class="img-fluid" src="assets/img/seilogo.png" style="width: 50px;"/> <span class="lead sei-brand">SEI Meetings &amp; Incentives<span></span></span></a>
# <button class="navbar-toggler collapsed" data-target="#navcol-1" data-toggle="collapse"><span></span><span></span><span></span>
# </button>
# <div class="collapse navbar-collapse" id="navcol-1">
# <ul class="nav navbar-nav ml-auto nav-snip">
# <li class="nav-item" role="presentation">
# <a class="nav-link" href="index.html">Who We Are</a>
# </li>
# <li class="nav-item" role="presentation">
# <a class="nav-link" href="meetings.html">Meetings &amp; Incentives</a>
# </li>
# <li class="nav-item" role="presentation">
# <a class="nav-link" href="resources.html">Resources</a>
# </li>
# <li class="nav-item" role="presentation">
# <a class="nav-link" href="technology.html">Technology</a>
# </li>
# <li class="nav-item" role="presentation"><a class="nav-link" href="letsconnect.html">Let's Connect</a></li>
# </ul>
# </div>
# </div>
# </nav>
# </div>
# <section id="home">
# <div class="row" id="textSlider">
# <div class="col-md-12 text-center slideCol">
# <div class="scroller">
# <div class="inner" style="word-wrap: break-word;">
# <p>Meetings Worth Having</p>
# <p>Incentives Worth Pursuing</p>
# <p>Rewards Worth Treasuring</p>
# <p>SEI Meetings &amp; Incentives</p>
# </div>
# </div>
# </div>
# <div class="hero-btn">
# <a class="btn btn-outline-info btn-block btn-lg mt-4 py-2" href="#about" role="button">Discover More</a>
# </div>
# </div>
# </section>
# <div class="container-fluid d-flex justify-content-center align-items-center align-content-center video-parallax-container" style="height:100vh">
# <video autoplay="" loop="" muted=""><source src="https://res.cloudinary.com/mobileimages/video/upload/v1548883859/clients/sei/2019/sei-home-129/videos/timelapsecloud.mp4" type="video/mp4"/></video>
# </div>
# <section class="testimonials text-center bg-light py-5" id="about">
# <div class="container py-5">
# <div class="row" id="n-index">
# <div class="col">
# <h2>COMPANYWIDE TO <span style="color: #037aa5; text-shadow: 0.5px 0.5px 0.5px #000;">WORLDWIDE</span></h2>
# <hr/>
# <p class="text-justify">For over 40 years, SEI Meetings and Incentives has partnered with companies of all sizes to orchestrate motivational incentive programs, meetings, and exciting destination events all over the world. In this ever-changing global environment, SEI continues to evolve and elevate its commitment to the meeting and incentive industry.<br/><br/> Whether it's a business meeting tailored to your corporate vision, an incentive trip rewarding your employees with outstanding experiences, or a company-wide merchandise award program, SEI is your team. Rely on us to help you launch meetings that educate and inspire, provide incentive travel that will thrill top producers, and fuel peak performance with rewards and recognition.</p>
# <hr/></div>
# </div>
# <div class="row">
# <div class="col-12 py-3">
# <h4 class="raleway-cursive">Why SEI?</h4>
# <hr style="width: 30%; margin: 5px auto;"/>
# </div>
# <div class="col-lg-3 mt-3 col-md-6">
# <div class="card shadow fullheight">
# <div class="card-body">
# <h4 class="card-title">Flexibility</h4>
# <hr/>
# <img class="img-fluid mb-3" src="https://res.cloudinary.com/mobileimages/image/upload/v1548893225/clients/sei/2019/sei-home-129/flexibility.png" style="width: 50%;"/>
# <p class="card-text">
#                                 Nothing is impossible; our team will customize programs that exceed your expectations.
#                             </p>
# </div>
# </div>
# </div>
# <div class="col-lg-3 mt-3 col-md-6">
# <div class="card shadow fullheight">
# <div class="card-body">
# <h4 class="card-title">Synergy</h4>
# <hr/>
# <img class="img-fluid mb-3" src="https://res.cloudinary.com/mobileimages/image/upload/v1548893225/clients/sei/2019/sei-home-129/synergy.png" style="width: 50%;"/>
# <p class="card-text">
#                                 As your partner, your goals and objectives will soar to the next level.
#                             </p>
# </div>
# </div>
# </div>
# <div class="col-lg-3 mt-3 col-md-6">
# <div class="card shadow fullheight">
# <div class="card-body">
# <h4 class="card-title">Turnkey</h4>
# <hr/>
# <img class="img-fluid" src="https://res.cloudinary.com/mobileimages/image/upload/v1548893195/clients/sei/2019/sei-home-129/turnkey.png" style="width: 50%;"/>
# <p class="card-text">
#                                 Do what you do best, and leave the rest to us!
#                             </p>
# </div>
# </div>
# </div>
# <div class="col-lg-3 mt-3 col-md-6">
# <div class="card shadow fullheight">
# <div class="card-body">
# <h4 class="card-title">Results</h4>
# <hr/>
# <img class="img-fluid mb-3" src="https://res.cloudinary.com/mobileimages/image/upload/v1548893225/clients/sei/2019/sei-home-129/results.png" style="width: 50%;"/>
# <p class="card-text">
#                                 Your success is our mission.
#                             </p>
# </div>
# </div>
# </div>
# </div>
# </div>
# </section>
# <section>
# <div class="parallax">
# <div class="container parallax-content" style="height:100vh;">
# <div class="row d-flex justify-content-center pt-5">
# <div class="col-12 flex-column pt-5">
# <h1 data-aos="fade-up" data-aos-delay="200" data-aos-duration="1500" style="text-shadow: 1px 1px 1px #000;">SEI Meetings &amp; Incentives</h1>
# <p data-aos="fade-up" data-aos-delay="400" data-aos-duration="2000" style="text-shadow: 1px 1px 1px #000;">In step with your goals...</p>
# <div class="hero-btn pt-4">
# <div class="col text-center d-flex flex-column">
# <a class="btn btn-lg btn-outline-primary m-2" data-aos="fade-up" data-aos-delay="400" data-aos-duration="3000" href="meetings.html" role="button">Meetings &amp; Incentives</a>
# <a class="btn btn-lg btn-outline-warning m-2" data-aos="fade-up" data-aos-delay="600" data-aos-duration="2500" href="resources.html" role="button">Resources</a>
# <a class="btn btn-lg btn-outline-danger m-2" data-aos="fade-up" data-aos-delay="500" data-aos-duration="2000" href="technology.html" role="button">Technology</a>
# <a class="btn btn-lg btn-outline-dark m-2" data-aos="fade-up" data-aos-delay="700" data-aos-duration="1500" href="letsconnect.html" role="button">Let's Connect</a>
# </div>
# </div>
# </div>
# </div>
# </div><video autoplay="" class="parallax-background" loop="" muted=""><source src="https://res.cloudinary.com/mobileimages/video/upload/v1549495842/clients/sei/2019/sei-home-129/videos/explorer4.mp4" type="video/mp4"/></video>
# </div>
# </section>
# <div class="container-fluid">
# <div class="row">
# <div class="col testim" id="testim">
# <div class="wrap"><span class="arrow right fa fa-chevron-right" id="right-arrow"></span><span class="arrow left fa fa-chevron-left" id="left-arrow"></span>
# <ul class="dots" id="testim-dots">
# <li class="dot active"></li>
# <li class="dot"></li>
# <li class="dot"></li>
# <li class="dot"></li>
# <li class="dot"></li>
# </ul>
# <div class="cont" id="testim-content">
# <div class="active">
# <h2>Vice President, Meetings &amp; Incentives, Financial Services Company</h2>
# <p>"Based on my 24 years of experience in the event planning profession I believe that SEI is simply the best... They always find a way for us to accomplish our objectives in the most cost effective manner while maintaining an outstanding level of service."</p>
# </div>
# <div>
# <h2>Sr. Manager, Rewards &amp; Recognition, Telecommunications Company</h2>
# <p>"One of the big benefits I have working with SEI is that our Account Director absolutely functions as an extension of my internal team. She "gets" our brand, our culture, and the goals we're trying to accomplish -- even as those goals change over time."</p>
# </div>
# <div>
# <h2>Regional Vice President &amp; General Manager, Fairmont Hotels</h2>
# <p>"I have been in this business for over 30 years and without a doubt SEI was clearly at the top of my list for professionalism, execution on every detail and an innate ability to blend with the client as well as the operational team."</p>
# </div>
# <div>
# <h2>Regional Director, Banff &amp; Calgary, Cantrav</h2>
# <p>"SEI is a company with a foundation built on relationships and loyalty, and your long term clients and repeat business provide an excellent testimony to this. You always put client needs first and deliver on your promises."</p>
# </div>
# <div>
# <h2>Global Events Manager, Technology Company</h2>
# <p>"With SEI, we truly feel we have a partnership and we are excited for the years to come."</p>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="row">
# <div class="col p-0">
# <div class="brands">
# <a href="#">
# <img data-aos="fade-up" data-aos-delay="600" data-aos-duration="2200" src="https://res.cloudinary.com/mobileimages/image/upload/v1507749090/cdn/home/img/logo5_mpi.jpg"/>
# <img data-aos="fade-up" data-aos-delay="700" data-aos-duration="2400" src="https://res.cloudinary.com/mobileimages/image/upload/v1507749032/cdn/home/img/logo1_asi.jpg"/>
# <img data-aos="fade-up" data-aos-delay="800" data-aos-duration="2600" src="https://res.cloudinary.com/mobileimages/image/upload/v1507748962/cdn/home/img/logo2_sage.jpg"/>
# <img data-aos="fade-up" data-aos-delay="900" data-aos-duration="2800" src="https://res.cloudinary.com/mobileimages/image/upload/v1507748930/cdn/home/img/logo3_ppai.jpg"/>
# <hr class="mx-auto" style="width: 25%; "/>
# <h3 class="raleway-cursive">Be our partner</h3>
# </a>
# </div>
# </div>
# </div>
# </div>
# <section>
# <div class="container-fluid p-0">
# <div data-aos="fade-up " data-aos-delay="300 " data-aos-duration="2000 " style="background-color:rgba(255,255,255,0.9); padding:25px 50px; ">
# <div class="row" id="company">
# <div class="col-md-6 col-lg-3 py-2">
# <h1 class="newsblock-title">Our Office</h1>
# <p class="newsblock-link"><a href="https://goo.gl/maps/tmJQp13jMwC2"><i class="fa fa-building-o"></i>  122 West John Carpenter Freeway, Suite 400 Irving, TX 75039</a></p>
# <p class="newsblock-link"><a href="tel:9727171400"><i class="fa fa-phone"></i> 972-717-1400</a></p>
# <p class="newsblock-link"><a href="tel:9727171624"><i class="fa fa-fax"></i> FAX: 972-717-1624</a></p>
# <p class="newsblock-link"><a href="mailto:info@sei-mi.com"><i class="fa fa-envelope-o"></i> info@sei-mi.com</a></p>
# </div>
# <div class="col-md-6 col-lg-3 py-2">
# <h1 class="newsblock-title">Sales/Support</h1>
# <p class="newsblock-link"><a><i class="fa fa-question-circle-o"></i>  Want to see the latest features or need help with other services we offer?</a></p>
# <p class="newsblock-link"><a><i class="fa fa-shopping-cart"></i>  Our Sales team is available: </a></p>
# <p class="newsblock-link"><a><i class="fa fa-clock-o"></i>   8:45AM - 5:15PM Central</a></p>
# <p class="newsblock-link"><a href="tel:9727171400"><i class="fa fa-phone"></i>   972-717-1400 </a></p>
# <p class="newsblock-link"><a href="mailto:sales@sei-mi.com"><i class="fa fa-envelope-o"></i>  sales@sei-mi.com</a>
# </p>
# </div>
# <div class="col-md-6 col-lg-3 py-2">
# <h1 class="newsblock-title">Billing</h1>
# <p class="newsblock-link"><a><i class="fa fa-question-circle-o"></i>  Need to speak with our billing department?</a></p>
# <p class="newsblock-link"><a><i class="fa fa-money"></i>  Our Billing department is available: </a></p>
# <p class="newsblock-link"><a><i class="fa fa-clock-o"></i>   8:45AM - 5:15PM Central</a></p>
# <p class="newsblock-link"><a href="tel:9727171400"><i class="fa fa-phone"></i>   972-717-1400 </a></p>
# <p class="newsblock-link"><a href="mailto:accounting@sei-mi.com"><i class="fa fa-envelope-o"></i>  accounting@sei-mi.com </a></p>
# </div>
# <div class="col-md-6 col-lg-3 py-2">
# <h1 class="newsblock-title">Contact Us</h1>
# <button class="btn btn-outline-info btn-block btn-lg mb-3 py-2" data-target="#contact-form" data-toggle="modal" type="button">Send us a message</button>
# <div class="social-icons text-center">
# <a class="d-inline-block" data-aos="fade-up" data-aos-delay="500" data-aos-duration="2000" data-original-title="Instagram" data-toggle="tooltip" href="https://www.instagram.com/sei_meetings_incentives/"><i class="icon ion-social-instagram-outline"></i></a>
# <a class="d-inline-block" data-aos="fade-up" data-aos-delay="600" data-aos-duration="2200" data-original-title="Facebook" data-toggle="tooltip" href="https://www.facebook.com/SEImeetings/"><i class="icon ion-social-facebook"></i></a>
# <a class="d-inline-block" data-aos="fade-up" data-aos-delay="700" data-aos-duration="2400" data-original-title="Twitter" data-toggle="tooltip" href="https://mobile.twitter.com/SEI_Meetings"><i class="icon ion-social-twitter"></i></a>
# <a class="d-inline-block" data-aos="fade-up" data-aos-delay="800" data-aos-duration="2600" data-original-title="LinkedIn" data-toggle="tooltip" href="http://www.linkedin.com/company/sei-meetings-&amp;-incentives"><i class="icon ion-social-linkedin"></i></a>
# </div>
# </div>
# </div>
# </div>
# <footer class="page-footer">
# <div class="container">
# <div class="row">
# <div class="col-md-3 col-sm-6">
# <h4>Navigation</h4>
# <ul class="footer-links">
# <li><a href="index.html">Who We Are</a></li>
# <li><a href="meetings.html">Meetings &amp; Incentives</a></li>
# <li><a href="resources.html">Resources</a></li>
# <li><a href="technology.html">Technology</a></li>
# <li><a href="letsconnect.html">Let's Connect</a></li>
# </ul>
# </div>
# <div class="col-md-3 col-sm-6">
# <h4>Support</h4>
# <ul class="footer-links">
# <li><a href="index.html">Get Started</a></li>
# <li><a href="mailto:info@sei-mi.com">Email Support</a></li>
# <li><a href="tel: 9727171400">Call Support</a></li>
# </ul>
# </div>
# <div class="col-md-6 col-sm-12 text-justify">
# <h4>About SEI</h4>
# <p>For over 40 years, SEI Meetings and Incentives has partnered with companies of all sizes to orchestrate motivational incentive programs, meetings, and exciting destination events all over the world. In this ever-changing global
#                                 environment, SEI continues to evolve and elevate its commitment to the meeting and incentive industry. </p>
# </div>
# </div>
# <h4>In step with your goals...</h4>
# <hr/>
# <div class="footer-legal">
# <div class="float-md-right region">
# <a style="cursor: none"><img src="assets/img/united-states-flag.png"/>United States</a>
# </div>
# <div class="d-inline-block copyright">
# <p class="d-inline-block">Copyright © 2019. All rights reserved.<br/></p>
# </div>
# <div class="d-inline-block legal-links">
# <div class="d-inline-block item">
# <h5><a href="policy.html">Privacy Policy</a></h5>
# </div>
# </div>
# </div>
# </div>
# <a class="btn btn-primary btn-lg box-shadow" href="#" id="top" role="button"><i class="fa fa-arrow-up"></i></a>
# <!--Message Modal-->
# <div class="modal fade" id="contact-form" role="dialog" tabindex="-1">
# <div class="modal-dialog modal-dialog-centered" role="document">
# <div class="modal-content">
# <!--Modal Header-->
# <div class="modal-header">
# <div class="errorBlock">
# <p id="regisErr"></p>
# </div>
# <button aria-label="" class="close" data-dismiss="modal" id="close_form" type="button">×</button>
# </div>
# <!--Modal body-->
# <div class="modal-body">
# <div class="" id="contact-form">
# <form action="" id="form-fields">
# <div class="form-row"><input id="name" name="name" required="required" type="text"/><label class="m-0" for="name" id="contact-name">Name</label></div>
# <div class="form-row"><input id="email" name="_replyto" required="required" type="email"/><label class="m-0" for="email" id="contact-email">Email</label></div>
# <div class="form-row"><textarea data-gramm_editor="false" id="message" name="message" required="required" type="text"></textarea><label class="m-0" for="message" id="contact-message">Message</label></div>
# <div class="form-row"><button class="cta-animated" id="contact-button" type="submit">Send</button></div>
# </form>
# </div>
# </div>
# <!--Modal footer-->
# <div class="modal-footer">
# </div>
# </div>
# </div>
# </div>
# <div id="modal-container">
# <div class="modal-background">
# <div class="modal">
# <h2 style="color: #5cb85c"> <i class="fas fa-envelope-open-text mr-2"></i>Message Sent
#                     </h2><p class="text-center p-2">
# <a aria-label="" class="btn btn-outline-success" data-dismiss="modal">Okay</a>
# </p>
# </div>
# </div>
# </div>
# <div id="modal-failed">
# <div class="modal-background">
# <div class="modal">
# <h2 style="color: red"> <i class="fas fa-exclamation-triangle mr-2"></i>Message Not Sent
#                     </h2><p class="text-center p-2">
# <a aria-label="" class="btn btn-outline-danger" data-dismiss="modal">Okay</a>
# </p>
# </div>
# </div>
# </div>
# <script src="https://cdnjs.cloudflare.com/ajax/libs/jquery/3.2.1/jquery.min.js"></script>
# <script src="https://cdnjs.cloudflare.com/ajax/libs/twitter-bootstrap/4.1.2/js/bootstrap.bundle.min.js"></script>
# <script src="https://cdnjs.cloudflare.com/ajax/libs/aos/2.1.1/aos.js"></script>
# <script src="assets/js/aos.js"></script>
# <script src="assets/js/app.js"></script>
# <script src="assets/js/Scroll-To-Top-Button.js"></script>
# <script src="assets/js/Slider.js"></script>
# <script src="assets/js/Fixed-Navbar-start-with-transparency-background.js"></script>
# <script src="https://use.fontawesome.com/1744f3f671.js"></script>
# <script src="assets/js/Video-Parallax-Background-v2.js"></script>
# <script src="assets/js/Video-Parallax-Background.js"></script>
# <script src="assets/js/cookie.js"></script>
# </footer></div></section></body>
# </html>

# %%
print(seiSoup.prettify())
# Out:
# <!DOCTYPE html>
# <html>
#  <head>
#   <!-- Global site tag (gtag.js) - Google Analytics -->
#   <script async="" src="https://www.googletagmanager.com/gtag/js?id=UA-135478469-1">
#   </script>
#   <script>
#    window.dataLayer = window.dataLayer || [];
#     function gtag(){dataLayer.push(arguments);}
#     gtag('js', new Date());
#
#     gtag('config', 'UA-135478469-1');
#   </script>
#   <meta charset="utf-8"/>
#   <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
#   <meta content="summary" name="twitter:card"/>
#   <meta content="@SEI_Meetings" name="twitter:site"/>
#   <meta content="@SEI_Meetings" name="twitter:creator"/>
#   <meta content="SEI Meetings &amp; Incentives" name="twitter:title"/>
#   <meta content="For over 40 years, SEI Meetings and Incentives has partnered with companies of all sizes to orchestrate motivational incentive programs, meetings, and exciting destination events all over the world. In this ever-changing global environment, SEI continues to evolve and elevate its commitment to the meeting and incentive industry." name="twitter:description"/>
#   <meta content="https://res.cloudinary.com/mobileimages/image/upload/v1551472242/cdn/sei/logos/seilogofb3.png" name="twitter:image"/>
#   <meta content="https://www.sei-mi.com/index.html" property="og:url">
#    <meta content="article" property="og:type">
#     <meta content="SEI Meetings &amp; Incentives" property="og:title">
#      <meta content="For over 40 years, SEI Meetings and Incentives has partnered with companies of all sizes to orchestrate motivational incentive programs, meetings, and exciting destination events all over the world. In this ever-changing global environment, SEI continues to evolve and elevate its commitment to the meeting and incentive industry." property="og:description">
#       <meta content="https://res.cloudinary.com/mobileimages/image/upload/v1551472242/cdn/sei/logos/seilogofb3.png" property="og:image">
#        <meta content="1200" property="og:image:width">
#         <meta content="1200" property="og:image:height">
#          <title>
#           SEI Meetings &amp; Incentives
#          </title>
#          <link href="https://cdnjs.cloudflare.com/ajax/libs/twitter-bootstrap/4.1.2/css/bootstrap.min.css" rel="stylesheet"/>
#          <link crossorigin="anonymous" href="https://use.fontawesome.com/releases/v5.6.3/css/all.css" integrity="sha384-UHRtZLI+pbxtHCWp1t77Bi1L4ZtiqrqD80Kn4Z8NTSRyMA2Fd33n5dQ8lWUE00s/" rel="stylesheet"/>
#          <link href="https://cdnjs.cloudflare.com/ajax/libs/ionicons/2.0.1/css/ionicons.min.css" rel="stylesheet"/>
#          <link href="https://maxcdn.icons8.com/fonts/line-awesome/1.1/css/line-awesome-font-awesome.min.css" rel="stylesheet"/>
#          <link href="https://cdnjs.cloudflare.com/ajax/libs/simple-line-icons/2.4.1/css/simple-line-icons.min.css" rel="stylesheet"/>
#          <link href="https://fonts.googleapis.com/css?family=Raleway:300,400,500" rel="stylesheet" type="text/css"/>
#          <link href="https://fonts.googleapis.com/css?family=Raleway+Dots" rel="stylesheet" type="text/css"/>
#          <link href="https://fonts.googleapis.com/css?family=Spectral:300,300i,400,400i" rel="stylesheet"/>
#          <link href="assets/css/Slider.css" rel="stylesheet"/>
#          <link href="assets/css/Fixed-Navbar.css" rel="stylesheet"/>
#          <link href="assets/css/Identity-Page.css" rel="stylesheet"/>
#          <link href="assets/css/Brands.css" rel="stylesheet"/>
#          <link href="assets/css/Corporate-Footer.css" rel="stylesheet"/>
#          <link href="assets/css/Grid-Overlay-Hero.css" rel="stylesheet"/>
#          <link href="https://cdnjs.cloudflare.com/ajax/libs/animate.css/3.5.2/animate.min.css" rel="stylesheet"/>
#          <link href="https://cdnjs.cloudflare.com/ajax/libs/aos/2.1.1/aos.css" rel="stylesheet"/>
#          <link href="assets/css/News-article.css" rel="stylesheet"/>
#          <link href="assets/css/Scroll-To-Top-Button.css" rel="stylesheet"/>
#          <link href="assets/css/styles.css" rel="stylesheet"/>
#          <link href="assets/css/Text-Slider.css" rel="stylesheet"/>
#          <link href="assets/css/Video-Parallax-Background-v2.css" rel="stylesheet"/>
#          <link href="assets/css/Video-Parallax-Background.css" rel="stylesheet"/>
#          <link href="https://res.cloudinary.com/mobileimages/image/upload/v1552066533/clients/sei/2019/sei-home-129/sei-favicon.png" rel="shortcut icon" type="image/x-icon"/>
#         </meta>
#        </meta>
#       </meta>
#      </meta>
#     </meta>
#    </meta>
#   </meta>
#  </head>
#  <body>
#   <div>
#    <nav class="navbar navbar-light navbar-expand-lg fixed-top bg-white transparency border-bottom border-light" id="transmenu">
#     <div class="container">
#      <a class="navbar-brand" href="index.html" style="cursor:pointer;">
#       <img class="img-fluid" src="assets/img/seilogo.png" style="width: 50px;"/>
#       <span class="lead sei-brand">
#        SEI Meetings &amp; Incentives
#        <span>
#        </span>
#       </span>
#      </a>
#      <button class="navbar-toggler collapsed" data-target="#navcol-1" data-toggle="collapse">
#       <span>
#       </span>
#       <span>
#       </span>
#       <span>
#       </span>
#      </button>
#      <div class="collapse navbar-collapse" id="navcol-1">
#       <ul class="nav navbar-nav ml-auto nav-snip">
#        <li class="nav-item" role="presentation">
#         <a class="nav-link" href="index.html">
#          Who We Are
#         </a>
#        </li>
#        <li class="nav-item" role="presentation">
#         <a class="nav-link" href="meetings.html">
#          Meetings &amp; Incentives
#         </a>
#        </li>
#        <li class="nav-item" role="presentation">
#         <a class="nav-link" href="resources.html">
#          Resources
#         </a>
#        </li>
#        <li class="nav-item" role="presentation">
#         <a class="nav-link" href="technology.html">
#          Technology
#         </a>
#        </li>
#        <li class="nav-item" role="presentation">
#         <a class="nav-link" href="letsconnect.html">
#          Let's Connect
#         </a>
#        </li>
#       </ul>
#      </div>
#     </div>
#    </nav>
#   </div>
#   <section id="home">
#    <div class="row" id="textSlider">
#     <div class="col-md-12 text-center slideCol">
#      <div class="scroller">
#       <div class="inner" style="word-wrap: break-word;">
#        <p>
#         Meetings Worth Having
#        </p>
#        <p>
#         Incentives Worth Pursuing
#        </p>
#        <p>
#         Rewards Worth Treasuring
#        </p>
#        <p>
#         SEI Meetings &amp; Incentives
#        </p>
#       </div>
#      </div>
#     </div>
#     <div class="hero-btn">
#      <a class="btn btn-outline-info btn-block btn-lg mt-4 py-2" href="#about" role="button">
#       Discover More
#      </a>
#     </div>
#    </div>
#   </section>
#   <div class="container-fluid d-flex justify-content-center align-items-center align-content-center video-parallax-container" style="height:100vh">
#    <video autoplay="" loop="" muted="">
#     <source src="https://res.cloudinary.com/mobileimages/video/upload/v1548883859/clients/sei/2019/sei-home-129/videos/timelapsecloud.mp4" type="video/mp4"/>
#    </video>
#   </div>
#   <section class="testimonials text-center bg-light py-5" id="about">
#    <div class="container py-5">
#     <div class="row" id="n-index">
#      <div class="col">
#       <h2>
#        COMPANYWIDE TO
#        <span style="color: #037aa5; text-shadow: 0.5px 0.5px 0.5px #000;">
#         WORLDWIDE
#        </span>
#       </h2>
#       <hr/>
#       <p class="text-justify">
#        For over 40 years, SEI Meetings and Incentives has partnered with companies of all sizes to orchestrate motivational incentive programs, meetings, and exciting destination events all over the world. In this ever-changing global environment, SEI continues to evolve and elevate its commitment to the meeting and incentive industry.
#        <br/>
#        <br/>
#        Whether it's a business meeting tailored to your corporate vision, an incentive trip rewarding your employees with outstanding experiences, or a company-wide merchandise award program, SEI is your team. Rely on us to help you launch meetings that educate and inspire, provide incentive travel that will thrill top producers, and fuel peak performance with rewards and recognition.
#       </p>
#       <hr/>
#      </div>
#     </div>
#     <div class="row">
#      <div class="col-12 py-3">
#       <h4 class="raleway-cursive">
#        Why SEI?
#       </h4>
#       <hr style="width: 30%; margin: 5px auto;"/>
#      </div>
#      <div class="col-lg-3 mt-3 col-md-6">
#       <div class="card shadow fullheight">
#        <div class="card-body">
#         <h4 class="card-title">
#          Flexibility
#         </h4>
#         <hr/>
#         <img class="img-fluid mb-3" src="https://res.cloudinary.com/mobileimages/image/upload/v1548893225/clients/sei/2019/sei-home-129/flexibility.png" style="width: 50%;"/>
#         <p class="card-text">
#          Nothing is impossible; our team will customize programs that exceed your expectations.
#         </p>
#        </div>
#       </div>
#      </div>
#      <div class="col-lg-3 mt-3 col-md-6">
#       <div class="card shadow fullheight">
#        <div class="card-body">
#         <h4 class="card-title">
#          Synergy
#         </h4>
#         <hr/>
#         <img class="img-fluid mb-3" src="https://res.cloudinary.com/mobileimages/image/upload/v1548893225/clients/sei/2019/sei-home-129/synergy.png" style="width: 50%;"/>
#         <p class="card-text">
#          As your partner, your goals and objectives will soar to the next level.
#         </p>
#        </div>
#       </div>
#      </div>
#      <div class="col-lg-3 mt-3 col-md-6">
#       <div class="card shadow fullheight">
#        <div class="card-body">
#         <h4 class="card-title">
#          Turnkey
#         </h4>
#         <hr/>
#         <img class="img-fluid" src="https://res.cloudinary.com/mobileimages/image/upload/v1548893195/clients/sei/2019/sei-home-129/turnkey.png" style="width: 50%;"/>
#         <p class="card-text">
#          Do what you do best, and leave the rest to us!
#         </p>
#        </div>
#       </div>
#      </div>
#      <div class="col-lg-3 mt-3 col-md-6">
#       <div class="card shadow fullheight">
#        <div class="card-body">
#         <h4 class="card-title">
#          Results
#         </h4>
#         <hr/>
#         <img class="img-fluid mb-3" src="https://res.cloudinary.com/mobileimages/image/upload/v1548893225/clients/sei/2019/sei-home-129/results.png" style="width: 50%;"/>
#         <p class="card-text">
#          Your success is our mission.
#         </p>
#        </div>
#       </div>
#      </div>
#     </div>
#    </div>
#   </section>
#   <section>
#    <div class="parallax">
#     <div class="container parallax-content" style="height:100vh;">
#      <div class="row d-flex justify-content-center pt-5">
#       <div class="col-12 flex-column pt-5">
#        <h1 data-aos="fade-up" data-aos-delay="200" data-aos-duration="1500" style="text-shadow: 1px 1px 1px #000;">
#         SEI Meetings &amp; Incentives
#        </h1>
#        <p data-aos="fade-up" data-aos-delay="400" data-aos-duration="2000" style="text-shadow: 1px 1px 1px #000;">
#         In step with your goals...
#        </p>
#        <div class="hero-btn pt-4">
#         <div class="col text-center d-flex flex-column">
#          <a class="btn btn-lg btn-outline-primary m-2" data-aos="fade-up" data-aos-delay="400" data-aos-duration="3000" href="meetings.html" role="button">
#           Meetings &amp; Incentives
#          </a>
#          <a class="btn btn-lg btn-outline-warning m-2" data-aos="fade-up" data-aos-delay="600" data-aos-duration="2500" href="resources.html" role="button">
#           Resources
#          </a>
#          <a class="btn btn-lg btn-outline-danger m-2" data-aos="fade-up" data-aos-delay="500" data-aos-duration="2000" href="technology.html" role="button">
#           Technology
#          </a>
#          <a class="btn btn-lg btn-outline-dark m-2" data-aos="fade-up" data-aos-delay="700" data-aos-duration="1500" href="letsconnect.html" role="button">
#           Let's Connect
#          </a>
#         </div>
#        </div>
#       </div>
#      </div>
#     </div>
#     <video autoplay="" class="parallax-background" loop="" muted="">
#      <source src="https://res.cloudinary.com/mobileimages/video/upload/v1549495842/clients/sei/2019/sei-home-129/videos/explorer4.mp4" type="video/mp4"/>
#     </video>
#    </div>
#   </section>
#   <div class="container-fluid">
#    <div class="row">
#     <div class="col testim" id="testim">
#      <div class="wrap">
#       <span class="arrow right fa fa-chevron-right" id="right-arrow">
#       </span>
#       <span class="arrow left fa fa-chevron-left" id="left-arrow">
#       </span>
#       <ul class="dots" id="testim-dots">
#        <li class="dot active">
#        </li>
#        <li class="dot">
#        </li>
#        <li class="dot">
#        </li>
#        <li class="dot">
#        </li>
#        <li class="dot">
#        </li>
#       </ul>
#       <div class="cont" id="testim-content">
#        <div class="active">
#         <h2>
#          Vice President, Meetings &amp; Incentives, Financial Services Company
#         </h2>
#         <p>
#          "Based on my 24 years of experience in the event planning profession I believe that SEI is simply the best... They always find a way for us to accomplish our objectives in the most cost effective manner while maintaining an outstanding level of service."
#         </p>
#        </div>
#        <div>
#         <h2>
#          Sr. Manager, Rewards &amp; Recognition, Telecommunications Company
#         </h2>
#         <p>
#          "One of the big benefits I have working with SEI is that our Account Director absolutely functions as an extension of my internal team. She "gets" our brand, our culture, and the goals we're trying to accomplish -- even as those goals change over time."
#         </p>
#        </div>
#        <div>
#         <h2>
#          Regional Vice President &amp; General Manager, Fairmont Hotels
#         </h2>
#         <p>
#          "I have been in this business for over 30 years and without a doubt SEI was clearly at the top of my list for professionalism, execution on every detail and an innate ability to blend with the client as well as the operational team."
#         </p>
#        </div>
#        <div>
#         <h2>
#          Regional Director, Banff &amp; Calgary, Cantrav
#         </h2>
#         <p>
#          "SEI is a company with a foundation built on relationships and loyalty, and your long term clients and repeat business provide an excellent testimony to this. You always put client needs first and deliver on your promises."
#         </p>
#        </div>
#        <div>
#         <h2>
#          Global Events Manager, Technology Company
#         </h2>
#         <p>
#          "With SEI, we truly feel we have a partnership and we are excited for the years to come."
#         </p>
#        </div>
#       </div>
#      </div>
#     </div>
#    </div>
#    <div class="row">
#     <div class="col p-0">
#      <div class="brands">
#       <a href="#">
#        <img data-aos="fade-up" data-aos-delay="600" data-aos-duration="2200" src="https://res.cloudinary.com/mobileimages/image/upload/v1507749090/cdn/home/img/logo5_mpi.jpg"/>
#        <img data-aos="fade-up" data-aos-delay="700" data-aos-duration="2400" src="https://res.cloudinary.com/mobileimages/image/upload/v1507749032/cdn/home/img/logo1_asi.jpg"/>
#        <img data-aos="fade-up" data-aos-delay="800" data-aos-duration="2600" src="https://res.cloudinary.com/mobileimages/image/upload/v1507748962/cdn/home/img/logo2_sage.jpg"/>
#        <img data-aos="fade-up" data-aos-delay="900" data-aos-duration="2800" src="https://res.cloudinary.com/mobileimages/image/upload/v1507748930/cdn/home/img/logo3_ppai.jpg"/>
#        <hr class="mx-auto" style="width: 25%; "/>
#        <h3 class="raleway-cursive">
#         Be our partner
#        </h3>
#       </a>
#      </div>
#     </div>
#    </div>
#   </div>
#   <section>
#    <div class="container-fluid p-0">
#     <div data-aos="fade-up " data-aos-delay="300 " data-aos-duration="2000 " style="background-color:rgba(255,255,255,0.9); padding:25px 50px; ">
#      <div class="row" id="company">
#       <div class="col-md-6 col-lg-3 py-2">
#        <h1 class="newsblock-title">
#         Our Office
#        </h1>
#        <p class="newsblock-link">
#         <a href="https://goo.gl/maps/tmJQp13jMwC2">
#          <i class="fa fa-building-o">
#          </i>
#          122 West John Carpenter Freeway, Suite 400 Irving, TX 75039
#         </a>
#        </p>
#        <p class="newsblock-link">
#         <a href="tel:9727171400">
#          <i class="fa fa-phone">
#          </i>
#          972-717-1400
#         </a>
#        </p>
#        <p class="newsblock-link">
#         <a href="tel:9727171624">
#          <i class="fa fa-fax">
#          </i>
#          FAX: 972-717-1624
#         </a>
#        </p>
#        <p class="newsblock-link">
#         <a href="mailto:info@sei-mi.com">
#          <i class="fa fa-envelope-o">
#          </i>
#          info@sei-mi.com
#         </a>
#        </p>
#       </div>
#       <div class="col-md-6 col-lg-3 py-2">
#        <h1 class="newsblock-title">
#         Sales/Support
#        </h1>
#        <p class="newsblock-link">
#         <a>
#          <i class="fa fa-question-circle-o">
#          </i>
#          Want to see the latest features or need help with other services we offer?
#         </a>
#        </p>
#        <p class="newsblock-link">
#         <a>
#          <i class="fa fa-shopping-cart">
#          </i>
#          Our Sales team is available:
#         </a>
#        </p>
#        <p class="newsblock-link">
#         <a>
#          <i class="fa fa-clock-o">
#          </i>
#          8:45AM - 5:15PM Central
#         </a>
#        </p>
#        <p class="newsblock-link">
#         <a href="tel:9727171400">
#          <i class="fa fa-phone">
#          </i>
#          972-717-1400
#         </a>
#        </p>
#        <p class="newsblock-link">
#         <a href="mailto:sales@sei-mi.com">
#          <i class="fa fa-envelope-o">
#          </i>
#          sales@sei-mi.com
#         </a>
#        </p>
#       </div>
#       <div class="col-md-6 col-lg-3 py-2">
#        <h1 class="newsblock-title">
#         Billing
#        </h1>
#        <p class="newsblock-link">
#         <a>
#          <i class="fa fa-question-circle-o">
#          </i>
#          Need to speak with our billing department?
#         </a>
#        </p>
#        <p class="newsblock-link">
#         <a>
#          <i class="fa fa-money">
#          </i>
#          Our Billing department is available:
#         </a>
#        </p>
#        <p class="newsblock-link">
#         <a>
#          <i class="fa fa-clock-o">
#          </i>
#          8:45AM - 5:15PM Central
#         </a>
#        </p>
#        <p class="newsblock-link">
#         <a href="tel:9727171400">
#          <i class="fa fa-phone">
#          </i>
#          972-717-1400
#         </a>
#        </p>
#        <p class="newsblock-link">
#         <a href="mailto:accounting@sei-mi.com">
#          <i class="fa fa-envelope-o">
#          </i>
#          accounting@sei-mi.com
#         </a>
#        </p>
#       </div>
#       <div class="col-md-6 col-lg-3 py-2">
#        <h1 class="newsblock-title">
#         Contact Us
#        </h1>
#        <button class="btn btn-outline-info btn-block btn-lg mb-3 py-2" data-target="#contact-form" data-toggle="modal" type="button">
#         Send us a message
#        </button>
#        <div class="social-icons text-center">
#         <a class="d-inline-block" data-aos="fade-up" data-aos-delay="500" data-aos-duration="2000" data-original-title="Instagram" data-toggle="tooltip" href="https://www.instagram.com/sei_meetings_incentives/">
#          <i class="icon ion-social-instagram-outline">
#          </i>
#         </a>
#         <a class="d-inline-block" data-aos="fade-up" data-aos-delay="600" data-aos-duration="2200" data-original-title="Facebook" data-toggle="tooltip" href="https://www.facebook.com/SEImeetings/">
#          <i class="icon ion-social-facebook">
#          </i>
#         </a>
#         <a class="d-inline-block" data-aos="fade-up" data-aos-delay="700" data-aos-duration="2400" data-original-title="Twitter" data-toggle="tooltip" href="https://mobile.twitter.com/SEI_Meetings">
#          <i class="icon ion-social-twitter">
#          </i>
#         </a>
#         <a class="d-inline-block" data-aos="fade-up" data-aos-delay="800" data-aos-duration="2600" data-original-title="LinkedIn" data-toggle="tooltip" href="http://www.linkedin.com/company/sei-meetings-&amp;-incentives">
#          <i class="icon ion-social-linkedin">
#          </i>
#         </a>
#        </div>
#       </div>
#      </div>
#     </div>
#     <footer class="page-footer">
#      <div class="container">
#       <div class="row">
#        <div class="col-md-3 col-sm-6">
#         <h4>
#          Navigation
#         </h4>
#         <ul class="footer-links">
#          <li>
#           <a href="index.html">
#            Who We Are
#           </a>
#          </li>
#          <li>
#           <a href="meetings.html">
#            Meetings &amp; Incentives
#           </a>
#          </li>
#          <li>
#           <a href="resources.html">
#            Resources
#           </a>
#          </li>
#          <li>
#           <a href="technology.html">
#            Technology
#           </a>
#          </li>
#          <li>
#           <a href="letsconnect.html">
#            Let's Connect
#           </a>
#          </li>
#         </ul>
#        </div>
#        <div class="col-md-3 col-sm-6">
#         <h4>
#          Support
#         </h4>
#         <ul class="footer-links">
#          <li>
#           <a href="index.html">
#            Get Started
#           </a>
#          </li>
#          <li>
#           <a href="mailto:info@sei-mi.com">
#            Email Support
#           </a>
#          </li>
#          <li>
#           <a href="tel: 9727171400">
#            Call Support
#           </a>
#          </li>
#         </ul>
#        </div>
#        <div class="col-md-6 col-sm-12 text-justify">
#         <h4>
#          About SEI
#         </h4>
#         <p>
#          For over 40 years, SEI Meetings and Incentives has partnered with companies of all sizes to orchestrate motivational incentive programs, meetings, and exciting destination events all over the world. In this ever-changing global
#                                 environment, SEI continues to evolve and elevate its commitment to the meeting and incentive industry.
#         </p>
#        </div>
#       </div>
#       <h4>
#        In step with your goals...
#       </h4>
#       <hr/>
#       <div class="footer-legal">
#        <div class="float-md-right region">
#         <a style="cursor: none">
#          <img src="assets/img/united-states-flag.png"/>
#          United States
#         </a>
#        </div>
#        <div class="d-inline-block copyright">
#         <p class="d-inline-block">
#          Copyright © 2019. All rights reserved.
#          <br/>
#         </p>
#        </div>
#        <div class="d-inline-block legal-links">
#         <div class="d-inline-block item">
#          <h5>
#           <a href="policy.html">
#            Privacy Policy
#           </a>
#          </h5>
#         </div>
#        </div>
#       </div>
#      </div>
#     </footer>
#    </div>
#   </section>
#   <a class="btn btn-primary btn-lg box-shadow" href="#" id="top" role="button">
#    <i class="fa fa-arrow-up">
#    </i>
#   </a>
#   <!--Message Modal-->
#   <div class="modal fade" id="contact-form" role="dialog" tabindex="-1">
#    <div class="modal-dialog modal-dialog-centered" role="document">
#     <div class="modal-content">
#      <!--Modal Header-->
#      <div class="modal-header">
#       <div class="errorBlock">
#        <p id="regisErr">
#        </p>
#       </div>
#       <button aria-label="" class="close" data-dismiss="modal" id="close_form" type="button">
#        ×
#       </button>
#      </div>
#      <!--Modal body-->
#      <div class="modal-body">
#       <div class="" id="contact-form">
#        <form action="" id="form-fields">
#         <div class="form-row">
#          <input id="name" name="name" required="required" type="text"/>
#          <label class="m-0" for="name" id="contact-name">
#           Name
#          </label>
#         </div>
#         <div class="form-row">
#          <input id="email" name="_replyto" required="required" type="email"/>
#          <label class="m-0" for="email" id="contact-email">
#           Email
#          </label>
#         </div>
#         <div class="form-row">
#          <textarea data-gramm_editor="false" id="message" name="message" required="required" type="text"></textarea>
#          <label class="m-0" for="message" id="contact-message">
#           Message
#          </label>
#         </div>
#         <div class="form-row">
#          <button class="cta-animated" id="contact-button" type="submit">
#           Send
#          </button>
#         </div>
#        </form>
#       </div>
#      </div>
#      <!--Modal footer-->
#      <div class="modal-footer">
#      </div>
#     </div>
#    </div>
#   </div>
#   <div id="modal-container">
#    <div class="modal-background">
#     <div class="modal">
#      <h2 style="color: #5cb85c">
#       <i class="fas fa-envelope-open-text mr-2">
#       </i>
#       Message Sent
#      </h2>
#     </div>
#    </div>
#   </div>
#  </body>
# </html>
# <p class="text-center p-2">
#  <a aria-label="" class="btn btn-outline-success" data-dismiss="modal">
#   Okay
#  </a>
# </p>
# <div id="modal-failed">
#  <div class="modal-background">
#   <div class="modal">
#    <h2 style="color: red">
#     <i class="fas fa-exclamation-triangle mr-2">
#     </i>
#     Message Not Sent
#    </h2>
#   </div>
#  </div>
# </div>
# <p class="text-center p-2">
#  <a aria-label="" class="btn btn-outline-danger" data-dismiss="modal">
#   Okay
#  </a>
# </p>
# <script src="https://cdnjs.cloudflare.com/ajax/libs/jquery/3.2.1/jquery.min.js">
# </script>
# <script src="https://cdnjs.cloudflare.com/ajax/libs/twitter-bootstrap/4.1.2/js/bootstrap.bundle.min.js">
# </script>
# <script src="https://cdnjs.cloudflare.com/ajax/libs/aos/2.1.1/aos.js">
# </script>
# <script src="assets/js/aos.js">
# </script>
# <script src="assets/js/app.js">
# </script>
# <script src="assets/js/Scroll-To-Top-Button.js">
# </script>
# <script src="assets/js/Slider.js">
# </script>
# <script src="assets/js/Fixed-Navbar-start-with-transparency-background.js">
# </script>
# <script src="https://use.fontawesome.com/1744f3f671.js">
# </script>
# <script src="assets/js/Video-Parallax-Background-v2.js">
# </script>
# <script src="assets/js/Video-Parallax-Background.js">
# </script>
# <script src="assets/js/cookie.js">
# </script>

# %%
seiSoup.find_all('p')
# Out:
# [<p>Meetings Worth Having</p>,
#  <p>Incentives Worth Pursuing</p>,
#  <p>Rewards Worth Treasuring</p>,
#  <p>SEI Meetings &amp; Incentives</p>,
#  <p class="text-justify">For over 40 years, SEI Meetings and Incentives has partnered with companies of all sizes to orchestrate motivational incentive programs, meetings, and exciting destination events all over the world. In this ever-changing global environment, SEI continues to evolve and elevate its commitment to the meeting and incentive industry.<br/><br/> Whether it's a business meeting tailored to your corporate vision, an incentive trip rewarding your employees with outstanding experiences, or a company-wide merchandise award program, SEI is your team. Rely on us to help you launch meetings that educate and inspire, provide incentive travel that will thrill top producers, and fuel peak performance with rewards and recognition.</p>,
#  <p class="card-text">
#                                  Nothing is impossible; our team will customize programs that exceed your expectations.
#                              </p>,
#  <p class="card-text">
#                                  As your partner, your goals and objectives will soar to the next level.
#                              </p>,
#  <p class="card-text">
#                                  Do what you do best, and leave the rest to us!
#                              </p>,
#  <p class="card-text">
#                                  Your success is our mission.
#                              </p>,
#  <p data-aos="fade-up" data-aos-delay="400" data-aos-duration="2000" style="text-shadow: 1px 1px 1px #000;">In step with your goals...</p>,
#  <p>"Based on my 24 years of experience in the event planning profession I believe that SEI is simply the best... They always find a way for us to accomplish our objectives in the most cost effective manner while maintaining an outstanding level of service."</p>,
#  <p>"One of the big benefits I have working with SEI is that our Account Director absolutely functions as an extension of my internal team. She "gets" our brand, our culture, and the goals we're trying to accomplish -- even as those goals change over time."</p>,
#  <p>"I have been in this business for over 30 years and without a doubt SEI was clearly at the top of my list for professionalism, execution on every detail and an innate ability to blend with the client as well as the operational team."</p>,
#  <p>"SEI is a company with a foundation built on relationships and loyalty, and your long term clients and repeat business provide an excellent testimony to this. You always put client needs first and deliver on your promises."</p>,
#  <p>"With SEI, we truly feel we have a partnership and we are excited for the years to come."</p>,
#  <p class="newsblock-link"><a href="https://goo.gl/maps/tmJQp13jMwC2"><i class="fa fa-building-o"></i>  122 West John Carpenter Freeway, Suite 400 Irving, TX 75039</a></p>,
#  <p class="newsblock-link"><a href="tel:9727171400"><i class="fa fa-phone"></i> 972-717-1400</a></p>,
#  <p class="newsblock-link"><a href="tel:9727171624"><i class="fa fa-fax"></i> FAX: 972-717-1624</a></p>,
#  <p class="newsblock-link"><a href="mailto:info@sei-mi.com"><i class="fa fa-envelope-o"></i> info@sei-mi.com</a></p>,
#  <p class="newsblock-link"><a><i class="fa fa-question-circle-o"></i>  Want to see the latest features or need help with other services we offer?</a></p>,
#  <p class="newsblock-link"><a><i class="fa fa-shopping-cart"></i>  Our Sales team is available: </a></p>,
#  <p class="newsblock-link"><a><i class="fa fa-clock-o"></i>   8:45AM - 5:15PM Central</a></p>,
#  <p class="newsblock-link"><a href="tel:9727171400"><i class="fa fa-phone"></i>   972-717-1400 </a></p>,
#  <p class="newsblock-link"><a href="mailto:sales@sei-mi.com"><i class="fa fa-envelope-o"></i>  sales@sei-mi.com</a>
#  </p>,
#  <p class="newsblock-link"><a><i class="fa fa-question-circle-o"></i>  Need to speak with our billing department?</a></p>,
#  <p class="newsblock-link"><a><i class="fa fa-money"></i>  Our Billing department is available: </a></p>,
#  <p class="newsblock-link"><a><i class="fa fa-clock-o"></i>   8:45AM - 5:15PM Central</a></p>,
#  <p class="newsblock-link"><a href="tel:9727171400"><i class="fa fa-phone"></i>   972-717-1400 </a></p>,
#  <p class="newsblock-link"><a href="mailto:accounting@sei-mi.com"><i class="fa fa-envelope-o"></i>  accounting@sei-mi.com </a></p>,
#  <p>For over 40 years, SEI Meetings and Incentives has partnered with companies of all sizes to orchestrate motivational incentive programs, meetings, and exciting destination events all over the world. In this ever-changing global
#                                  environment, SEI continues to evolve and elevate its commitment to the meeting and incentive industry. </p>,
#  <p class="d-inline-block">Copyright © 2019. All rights reserved.<br/></p>,
#  <p id="regisErr"></p>,
#  <p class="text-center p-2">
#  <a aria-label="" class="btn btn-outline-success" data-dismiss="modal">Okay</a>
#  </p>,
#  <p class="text-center p-2">
#  <a aria-label="" class="btn btn-outline-danger" data-dismiss="modal">Okay</a>
#  </p>]

# %%
seiSoup.find_all('p')[2].get_text()
# Out:
# 'Rewards Worth Treasuring'

# %%
# find gets you only the first p
seiSoup.find('p').get_text()
# Out:
# 'Meetings Worth Having'

# %%
# N.B. BS4 uses class_ because class is already a keyword in python
seiSoup.find_all('p', class_='newsblock-link')[2].get_text()
# Out:
# '\xa0FAX:\xa0972-717-1624'

# %%
seiSoup.find_all('p', id="regisErr")
# Out:
# [<p id="regisErr"></p>]

# %% [markdown]
# > p a - finds all 'a' tags inside of a 'p' tag
# > body p a - finds all 'a' tags of a 'p' tag inside of a 'body' tag
# > html body - finds all 'body' tags inside of an 'html'tag
# > p.outer-text - finds all 'p' tags with a class of 'outer-text'
# > body p.outer-text - finds any 'p' tags with a class of 'outer-text' inside of a 'body' tag

# %%
# with select you can use css selectors and combinations
seiSoup.select('p > a')
# Out:
# [<a href="https://goo.gl/maps/tmJQp13jMwC2"><i class="fa fa-building-o"></i>  122 West John Carpenter Freeway, Suite 400 Irving, TX 75039</a>,
#  <a href="tel:9727171400"><i class="fa fa-phone"></i> 972-717-1400</a>,
#  <a href="tel:9727171624"><i class="fa fa-fax"></i> FAX: 972-717-1624</a>,
#  <a href="mailto:info@sei-mi.com"><i class="fa fa-envelope-o"></i> info@sei-mi.com</a>,
#  <a><i class="fa fa-question-circle-o"></i>  Want to see the latest features or need help with other services we offer?</a>,
#  <a><i class="fa fa-shopping-cart"></i>  Our Sales team is available: </a>,
#  <a><i class="fa fa-clock-o"></i>   8:45AM - 5:15PM Central</a>,
#  <a href="tel:9727171400"><i class="fa fa-phone"></i>   972-717-1400 </a>,
#  <a href="mailto:sales@sei-mi.com"><i class="fa fa-envelope-o"></i>  sales@sei-mi.com</a>,
#  <a><i class="fa fa-question-circle-o"></i>  Need to speak with our billing department?</a>,
#  <a><i class="fa fa-money"></i>  Our Billing department is available: </a>,
#  <a><i class="fa fa-clock-o"></i>   8:45AM - 5:15PM Central</a>,
#  <a href="tel:9727171400"><i class="fa fa-phone"></i>   972-717-1400 </a>,
#  <a href="mailto:accounting@sei-mi.com"><i class="fa fa-envelope-o"></i>  accounting@sei-mi.com </a>,
#  <a aria-label="" class="btn btn-outline-success" data-dismiss="modal">Okay</a>,
#  <a aria-label="" class="btn btn-outline-danger" data-dismiss="modal">Okay</a>]

# %% [markdown]
# ## Sample Scraping of Weather data

# %%
weather = requests.get("http://forecast.weather.gov/MapClick.php?lat=37.7772&lon=-122.4168")
soup = BeautifulSoup(weather.content, 'html.parser')
seven_day = soup.find(id="seven-day-forecast")
forecast_items = seven_day.find_all(class_="tombstone-container")
tonight = forecast_items[0]
print(tonight.prettify())
# Out:
# <div class="tombstone-container">
#  <p class="period-name">
#   Tonight
#   <br/>
#   <br/>
#  </p>
#  <p>
#   <img alt="Tonight: Mostly cloudy, with a low around 53. West southwest wind 6 to 13 mph. " class="forecast-icon" src="newimages/medium/nbkn.png" title="Tonight: Mostly cloudy, with a low around 53. West southwest wind 6 to 13 mph. "/>
#  </p>
#  <p class="short-desc">
#   Mostly Cloudy
#  </p>
#  <p class="temp temp-low">
#   Low: 53 °F
#  </p>
# </div>

# %%
period = tonight.find(class_="period-name").get_text()
short_desc = tonight.find(class_="short-desc").get_text()
temp = tonight.find(class_="temp").get_text()

print(period)
print(short_desc)
print(temp)
# Out:
# Tonight
# Mostly Cloudy
# Low: 53 °F

# %%
img = tonight.find("img")
desc = img['title']

print(desc)
# Out:
# Tonight: Mostly cloudy, with a low around 53. West southwest wind 6 to 13 mph.

# %%
period_tags = seven_day.select(".tombstone-container .period-name")
periods = [pt.get_text() for pt in period_tags]
periods
# Out:
# ['Tonight',
#  'Tuesday',
#  'TuesdayNight',
#  'Wednesday',
#  'WednesdayNight',
#  'Thursday',
#  'ThursdayNight',
#  'Friday',
#  'FridayNight']

# %%
short_descs = [sd.get_text() for sd in seven_day.select(".tombstone-container .short-desc")]
temps = [t.get_text() for t in seven_day.select(".tombstone-container .temp")]
descs = [d["title"] for d in seven_day.select(".tombstone-container img")]
print(short_descs)
print(temps)
print(descs)
# Out:
# ['Mostly Cloudy', 'GradualClearing', 'Partly Cloudy', 'Partly Sunny', 'Partly Cloudy', 'Sunny', 'Mostly Cloudy', 'Mostly Sunny', 'Partly Cloudy']
# ['Low: 53 °F', 'High: 64 °F', 'Low: 53 °F', 'High: 66 °F', 'Low: 54 °F', 'High: 66 °F', 'Low: 55 °F', 'High: 67 °F', 'Low: 54 °F']
# ['Tonight: Mostly cloudy, with a low around 53. West southwest wind 6 to 13 mph. ', 'Tuesday: Cloudy through mid morning, then gradual clearing, with a high near 64. Light west wind becoming west southwest 8 to 13 mph in the afternoon. ', 'Tuesday Night: Partly cloudy, with a low around 53. West southwest wind 9 to 13 mph. ', 'Wednesday: Partly sunny, with a high near 66. West southwest wind 5 to 14 mph, with gusts as high as 18 mph. ', 'Wednesday Night: Partly cloudy, with a low around 54. West southwest wind 8 to 15 mph, with gusts as high as 18 mph. ', 'Thursday: Sunny, with a high near 66.', 'Thursday Night: Mostly cloudy, with a low around 55.', 'Friday: Mostly sunny, with a high near 67.', 'Friday Night: Partly cloudy, with a low around 54.']

# %%
import pandas as pd
weather = pd.DataFrame({
        "period": periods,
         "short_desc": short_descs,
         "temp": temps,
         "desc":descs
    })
weather
# Out:
#            period       short_desc         temp  \
# 0         Tonight    Mostly Cloudy   Low: 53 °F
# 1         Tuesday  GradualClearing  High: 64 °F
# 2    TuesdayNight    Partly Cloudy   Low: 53 °F
# 3       Wednesday     Partly Sunny  High: 66 °F
# 4  WednesdayNight    Partly Cloudy   Low: 54 °F
# 5        Thursday            Sunny  High: 66 °F
# 6   ThursdayNight    Mostly Cloudy   Low: 55 °F
# 7          Friday     Mostly Sunny  High: 67 °F
# 8     FridayNight    Partly Cloudy   Low: 54 °F
#
#                                                 desc
# 0  Tonight: Mostly cloudy, with a low around 53. ...
# 1  Tuesday: Cloudy through mid morning, then grad...
# 2  Tuesday Night: Partly cloudy, with a low aroun...
# 3  Wednesday: Partly sunny, with a high near 66. ...
# 4  Wednesday Night: Partly cloudy, with a low aro...
# 5              Thursday: Sunny, with a high near 66.
# 6  Thursday Night: Mostly cloudy, with a low arou...
# 7         Friday: Mostly sunny, with a high near 67.
# 8  Friday Night: Partly cloudy, with a low around...

# %%
# use a regular expression and the Series.str.extract method to pull out the numeric temperature values:
temp_nums = weather["temp"].str.extract("(?P<temp_num>\d+)", expand=False)
weather["temp_num"] = temp_nums.astype('int')
temp_nums
# Out:
# 0    53
# 1    64
# 2    53
# 3    66
# 4    54
# 5    66
# 6    55
# 7    67
# 8    54
# Name: temp_num, dtype: object

# %%
# find the mean of all the high and low temperatures:
weather["temp_num"].mean()
# Out:
# 59.111111111111114

# %%
is_night = weather["temp"].str.contains("Low")
weather["is_night"] = is_night
is_night
# Out:
# 0     True
# 1    False
# 2     True
# 3    False
# 4     True
# 5    False
# 6     True
# 7    False
# 8     True
# Name: temp, dtype: bool

# %%
# only select the rows that happen at night:
weather[is_night]
# Out:
#            period     short_desc        temp  \
# 0         Tonight  Mostly Cloudy  Low: 53 °F
# 2    TuesdayNight  Partly Cloudy  Low: 53 °F
# 4  WednesdayNight  Partly Cloudy  Low: 54 °F
# 6   ThursdayNight  Mostly Cloudy  Low: 55 °F
# 8     FridayNight  Partly Cloudy  Low: 54 °F
#
#                                                 desc  temp_num  is_night
# 0  Tonight: Mostly cloudy, with a low around 53. ...        53      True
# 2  Tuesday Night: Partly cloudy, with a low aroun...        53      True
# 4  Wednesday Night: Partly cloudy, with a low aro...        54      True
# 6  Thursday Night: Mostly cloudy, with a low arou...        55      True
# 8  Friday Night: Partly cloudy, with a low around...        54      True

# %% [markdown]
# #### UDACITY Beautiful soup

# %%
from bs4 import BeautifulSoup

# %%
with open('http://www.sei-mi.com') as file:
    soup = BeautifulSoup(file, 'lmxl')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-16-671c842abc14> in <module>
# ----> 1 with open('http://www.sei-mi.com') as file:
#       2     soup = BeautifulSoup(file, 'lmxl')
#
# FileNotFoundError: [Errno 2] No such file or directory: 'http://www.sei-mi.com'
