# %%
#Установка всех необходимых модулей
"""
# %pip install pandas
# %pip install numpy
# %pip install matplotlib
# %pip install tensorflow
# %pip install scikit-learn
# %pip install tensorflow
# %pip install keras
"""
# Out:
# '\n%pip install pandas\n%pip install numpy\n%pip install matplotlib\n%pip install tensorflow\n%pip install scikit-learn\n%pip install tensorflow\n%pip install keras\n'

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

from sklearn.preprocessing import MinMaxScaler

# %%
df = pd.read_csv("LOGI copy.csv", parse_dates=["Date"])
df
# Out:
#            Date       Open       High        Low      Close     Adj Close  \
# 0    1997-03-27   2.093750   2.000000   2.023438   1.525964  1.065920e+07
# 1    1997-03-31   2.046875   2.046875   2.000000   2.031250  1.531856e+00
# 2    1997-04-01   2.078125   2.093750   2.031250   2.093750  1.578990e+00
# 3    1997-04-02   2.132813   2.140625   2.062500   2.062500  1.555423e+00
# 4    1997-04-03   2.093750   2.109375   2.046875   2.093750  1.578990e+00
# ...         ...        ...        ...        ...        ...           ...
# 6768 2024-02-20  87.620003  87.980003  86.739998  87.790001  8.779000e+01
# 6769 2024-02-21  86.750000  87.230003  86.290001  86.739998  8.674000e+01
# 6770 2024-02-22  87.839996  89.290001  87.800003  89.000000  8.900000e+01
# 6771 2024-02-23  90.000000  90.000000  89.120003  89.639999  8.964000e+01
# 6772 2024-02-26  90.080002  90.199997  89.599998  89.849998  8.985000e+01
#
#          Volume
# 0           NaN
# 1     1594400.0
# 2     2324000.0
# 3      745600.0
# 4      651200.0
# ...         ...
# 6768   466700.0
# 6769   512400.0
# 6770   364000.0
# 6771   288400.0
# 6772   397000.0
#
# [6773 rows x 7 columns]

# %%
def preproc(df):
    df = df.drop("Date", axis = 1)
    df.info()
    if df.isnull().sum().any():
        df = df.dropna(how = "any")
        print("Удалил все строки с пропуски")
        return df
    else:
        return df
        
preproc(df)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6773 entries, 0 to 6772
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Open       6773 non-null   float64
#  1   High       6773 non-null   float64
#  2   Low        6773 non-null   float64
#  3   Close      6773 non-null   float64
#  4   Adj Close  6773 non-null   float64
#  5   Volume     6772 non-null   float64
# dtypes: float64(6)
# memory usage: 317.6 KB
# Удалил все пропуски
#            Open       High        Low      Close  Adj Close     Volume
# 1      2.046875   2.046875   2.000000   2.031250   1.531856  1594400.0
# 2      2.078125   2.093750   2.031250   2.093750   1.578990  2324000.0
# 3      2.132813   2.140625   2.062500   2.062500   1.555423   745600.0
# 4      2.093750   2.109375   2.046875   2.093750   1.578990   651200.0
# 5      2.093750   2.140625   2.093750   2.132813   1.608449  1029600.0
# ...         ...        ...        ...        ...        ...        ...
# 6768  87.620003  87.980003  86.739998  87.790001  87.790001   466700.0
# 6769  86.750000  87.230003  86.290001  86.739998  86.739998   512400.0
# 6770  87.839996  89.290001  87.800003  89.000000  89.000000   364000.0
# 6771  90.000000  90.000000  89.120003  89.639999  89.639999   288400.0
# 6772  90.080002  90.199997  89.599998  89.849998  89.849998   397000.0
#
# [6772 rows x 6 columns]

# %%
df[["Open", "Close", "Low", "High"]].corr()
# Out:
#            Open     Close       Low      High
# Open   1.000000  0.999792  0.999882  0.999900
# Close  0.999792  1.000000  0.999909  0.999901
# Low    0.999882  0.999909  1.000000  0.999853
# High   0.999900  0.999901  0.999853  1.000000

# %%
plt.plot(df[["Open", "Close", "Low", "High"]], label = ["Open", "Close", "Low", "High"], linewidth = 0.5)
plt.legend()

# %%
print(df["Close"])

# %%
#   Разделение данных на тестовые и тренеровочные
def stab_data(name_col):
    "Нормализация данных"
    column = df[name_col].astype('float')
    #train = column[:int(len(column))] #не обязательно. ничего не делает, в случае чего, позже можно будет удалить
    scale_col = MinMaxScaler()
    scale_col.fit(column.values.reshape(-1, 1))
    column = scale_col.transform(column.values.reshape(-1, 1))
    return column


def xyarray(data):
    "Разбиение массива на x y "
    x, y = [], []
    for i in range(len(data) - lb - 1):
        x.append(data[i:(i + lb), 0])
        y.append(data[(i + lb), 0])
    return np.array(x), np.array(y)


"""Разбиение на тестовые и тренеровочные данные"""
lb = 10 
val = 0.9
x,y = xyarray(stab_data("Close"))

x_train, x_test = x[:int(x.shape[0] * val)], x[int(x.shape[0] * val):]
y_train, y_test = y[:int(x.shape[0] * val)], y[int(x.shape[0] * val):]
print(f"x train -> {x_train.shape}  \ny train -> {y_train.shape}  \nx test  -> {x_test.shape} \ny test  -> {y_test.shape}")
# Out:
# x train -> (6085, 10)
# y train -> (6085,)
# x test  -> (677, 10)
# y test  -> (677,)

# %% [markdown]
# Раздел с обучением

# %%
from tensorflow.keras.models import Sequential # type: ignore
from tensorflow.keras.layers import Dense, LSTM, Dropout, Activation # type: ignore

# %%
x_train = x_train.reshape((x_train.shape[0], x_train.shape[1], 1))

# %%
model = Sequential([
            LSTM(256, input_shape = (lb, 1), return_sequences = True),
            LSTM(10),
            Dense(1)
        ])
model.compile(optimizer = 'adam', loss = 'mse')

history = model.fit(x_train, y_train, epochs = 50, shuffle=False)
model.evaluate(x_test, y_test)
# Out:
# Epoch 1/50
# 191/191 [==============================] - 3s 12ms/step - loss: 8.5140e-04
# Epoch 2/50
# 191/191 [==============================] - 2s 11ms/step - loss: 0.0024
# Epoch 3/50
# 191/191 [==============================] - 2s 12ms/step - loss: 0.0024
# Epoch 4/50
# 191/191 [==============================] - 2s 11ms/step - loss: 0.0025
# Epoch 5/50
# 191/191 [==============================] - 2s 11ms/step - loss: 8.3094e-04
# Epoch 6/50
# 191/191 [==============================] - 2s 11ms/step - loss: 2.9321e-04
# Epoch 7/50
# 191/191 [==============================] - 2s 12ms/step - loss: 4.9310e-04
# Epoch 8/50
# 191/191 [==============================] - 2s 12ms/step - loss: 3.3754e-04
# Epoch 9/50
# 191/191 [==============================] - 2s 12ms/step - loss: 9.6347e-05
# Epoch 10/50
# 191/191 [==============================] - 2s 11ms/step - loss: 6.8728e-05
# Epoch 11/50
# 191/191 [==============================] - 2s 11ms/step - loss: 5.2551e-05
# Epoch 12/50
# 191/191 [==============================] - 2s 12ms/step - loss: 5.0042e-05
# Epoch 13/50
# 191/191 [==============================] - 2s 12ms/step - loss: 5.0555e-05
# Epoch 14/50
# 191/191 [==============================] - 2s 11ms/step - loss: 4.9359e-05
# Epoch 15/50
# 191/191 [==============================] - 2s 12ms/step - loss: 4.9900e-05
# Epoch 16/50
# 191/191 [==============================] - 2s 12ms/step - loss: 4.8643e-05
# Epoch 17/50
# 191/191 [==============================] - 2s 12ms/step - loss: 4.9277e-05
# Epoch 18/50
# 191/191 [==============================] - 2s 12ms/step - loss: 4.7335e-05
# Epoch 19/50
# 191/191 [==============================] - 2s 12ms/step - loss: 4.9177e-05
# Epoch 20/50
# 191/191 [==============================] - 2s 12ms/step - loss: 4.5102e-05
# Epoch 21/50
# 191/191 [==============================] - 2s 12ms/step - loss: 4.7210e-05
# Epoch 22/50
# 191/191 [==============================] - 2s 12ms/step - loss: 4.4962e-05
# Epoch 23/50
# 191/191 [==============================] - 2s 12ms/step - loss: 7.1711e-05
# Epoch 24/50
# 191/191 [==============================] - 2s 12ms/step - loss: 4.5426e-04
# Epoch 25/50
# 191/191 [==============================] - 2s 12ms/step - loss: 7.3535e-04
# Epoch 26/50
# 191/191 [==============================] - 2s 12ms/step - loss: 2.4783e-04
# Epoch 27/50
# 191/191 [==============================] - 2s 12ms/step - loss: 1.1055e-04
# Epoch 28/50
# 191/191 [==============================] - 2s 12ms/step - loss: 4.2888e-05
# Epoch 29/50
# 191/191 [==============================] - 2s 12ms/step - loss: 4.7892e-05
# Epoch 30/50
# 191/191 [==============================] - 2s 12ms/step - loss: 3.5852e-05
# Epoch 31/50
# 191/191 [==============================] - 2s 12ms/step - loss: 5.1427e-05
# Epoch 32/50
# 191/191 [==============================] - 2s 12ms/step - loss: 4.1253e-05
# Epoch 33/50
# 191/191 [==============================] - 2s 12ms/step - loss: 6.3160e-05
# Epoch 34/50
# 191/191 [==============================] - 2s 12ms/step - loss: 6.1727e-05
# Epoch 35/50
# 191/191 [==============================] - 2s 12ms/step - loss: 9.5495e-05
# Epoch 36/50
# 191/191 [==============================] - 2s 12ms/step - loss: 6.6550e-05
# Epoch 37/50
# 191/191 [==============================] - 2s 12ms/step - loss: 9.2416e-05
# Epoch 38/50
# 191/191 [==============================] - 2s 12ms/step - loss: 4.8675e-05
# Epoch 39/50
# 191/191 [==============================] - 2s 12ms/step - loss: 7.4406e-05
# Epoch 40/50
# 191/191 [==============================] - 2s 12ms/step - loss: 6.4365e-05
# Epoch 41/50
# 191/191 [==============================] - 2s 12ms/step - loss: 7.8349e-05
# Epoch 42/50
# 191/191 [==============================] - 2s 12ms/step - loss: 4.6107e-05
# Epoch 43/50
# 191/191 [==============================] - 2s 12ms/step - loss: 6.4312e-05
# Epoch 44/50
# 191/191 [==============================] - 2s 12ms/step - loss: 7.6229e-05
# Epoch 45/50
# 191/191 [==============================] - 2s 12ms/step - loss: 1.0213e-04
# Epoch 46/50
# 191/191 [==============================] - 2s 12ms/step - loss: 3.6548e-04
# Epoch 47/50
# 191/191 [==============================] - 2s 12ms/step - loss: 3.8399e-04
# Epoch 48/50
# 191/191 [==============================] - 2s 12ms/step - loss: 1.5911e-04
# Epoch 49/50
# 191/191 [==============================] - 2s 12ms/step - loss: 1.5249e-04
# Epoch 50/50
# 191/191 [==============================] - 2s 12ms/step - loss: 8.0736e-05
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0011
# 0.0010766892228275537

# %%
def get_result():
    result_predict = model.predict(x_test)

    plt.plot(result_predict, label = 'x')
    plt.plot(y_test, label = 'y')
    plt.legend()
    return result_predict

# %%
plt.plot(get_result())
# Out:
# 22/22 [==============================] - 0s 5ms/step

# %%
mse = np.mean(((get_result() - y_test) ** 2))
print("MSE", mse)
print("RMSE", np.sqrt(mse))
# Out:
# 22/22 [==============================] - 0s 5ms/step
# MSE 0.036028488508219575
# RMSE 0.1898117185745379

# %%
#хороший результат 
#Создание модели
"""model = Sequential([
            LSTM(128, input_shape = (lb, 1), return_sequences = True),
            Dropout(0.1),
            LSTM(10),
            Dense(1)
        ])
model.compile(optimizer = 'adam', loss = 'mse')

history = model.fit(x_train, y_train, epochs = 50, shuffle=False)
get_result()
model.evaluate(x_test, y_test)"""
# Out:
# "model = Sequential([\n            LSTM(128, input_shape = (lb, 1), return_sequences = True),\n            Dropout(0.1),\n            LSTM(10),\n            Dense(1)\n        ])\nmodel.compile(optimizer = 'adam', loss = 'mse')\n\nhistory = model.fit(x_train, y_train, epochs = 50, shuffle=False)\nget_result()\nmodel.evaluate(x_test, y_test)"
