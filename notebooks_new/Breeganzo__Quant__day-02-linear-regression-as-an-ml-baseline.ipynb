# %% [markdown]
# # Week 5 Tue: Linear regression as an ML baseline
#
#         Estimated time: 10 hours
#
#         ## Why this matters
#         Linear regression as an ML baseline is part of real quant work inside ml foundations i: supervised learning, regression, features, and train-test discipline research, trading, or risk workflows.
#
#         ## Core explanation
#         Build linear regression as an ml baseline from intuition to implementation: define the core mechanism, map it to measurable outputs, and state one assumption that can break in live deployment.
#
#         ## Worked example
#         Run one compact, reproducible example for linear regression as an ml baseline and explain both the signal and the main failure mode a quant team should watch.
#
#         ## Continuity
#         Previous day: Prediction problems in finance: what are we forecasting?
#
# Next day: Feature engineering from price and volume data

# %% [markdown]
# ## Code Lab 1: Topic-specific implementation

# %%
from pathlib import Path
import pandas as pd
from sklearn.linear_model import LinearRegression

market = pd.read_csv(Path("curriculum/datasets/real_market_prices.csv"), parse_dates=["date"])
prices = market.pivot(index="date", columns="symbol", values="close").dropna()
returns = prices.pct_change().dropna()
X = returns[["SPY"]].shift(1).dropna()
y = returns.loc[X.index, "QQQ"]
model = LinearRegression().fit(X, y)
print({"beta_spy": round(float(model.coef_[0]), 6), "intercept": round(float(model.intercept_), 6), "r2": round(float(model.score(X, y)), 4)})
# Out:
# {'beta_spy': -0.049526, 'intercept': 0.000706, 'r2': 0.0014}

# %% [markdown]
# ## Code Lab 2: Assumption register

# %%
import pandas as pd

assumptions = pd.DataFrame(
    [
        {"topic": 'Linear regression as an ML baseline', "assumption": "Data is representative", "status": "needs verification"},
        {"topic": 'Linear regression as an ML baseline', "assumption": "No leakage in pipeline", "status": "needs test"},
        {"topic": 'Linear regression as an ML baseline', "assumption": "Costs are realistic", "status": "needs calibration"},
    ]
)
print(assumptions)
# Out:
#                                  topic              assumption  \
# 0  Linear regression as an ML baseline  Data is representative
# 1  Linear regression as an ML baseline  No leakage in pipeline
# 2  Linear regression as an ML baseline     Costs are realistic
#
#                status
# 0  needs verification
# 1          needs test
# 2   needs calibration

# %% [markdown]
# ## Code Lab 3: Sensitivity or stress note

# %%
import pandas as pd

stress = pd.DataFrame(
    [
        {"scenario": "base", "impact": "baseline output"},
        {"scenario": "adverse", "impact": "degradation expected"},
        {"scenario": "extreme", "impact": "failure boundary"},
    ]
)
print("Topic:", 'linear regression as an ml baseline')
print(stress)
# Out:
# Topic: linear regression as an ml baseline
#   scenario                impact
# 0     base       baseline output
# 1  adverse  degradation expected
# 2  extreme      failure boundary

# %% [markdown]
# ## Code Lab 4: Study-note structure for revision

# %%
study_note = {
    "topic": 'Linear regression as an ML baseline',
    "main_formula_or_workflow": "",
    "what_worked": "",
    "failure_mode": "",
    "next_review_date": "",
}
print(study_note)
# Out:
# {'topic': 'Linear regression as an ML baseline', 'main_formula_or_workflow': '', 'what_worked': '', 'failure_mode': '', 'next_review_date': ''}

# %% [markdown]
# ## Practice recap
# - Explain linear regression as an ml baseline in one paragraph without jargon.
# - Write down one topic-specific formula or workflow for linear regression as an ml baseline from memory.
# - Connect linear regression as an ml baseline to one realistic trading, portfolio, risk, or research decision.
# - Reflection prompt: What from linear regression as an ml baseline is now evidence-backed in your notes, and what still needs a focused retry?
# - Deliverable: write a 100-word note connecting today's topic to a real trading or risk decision.

# %% [markdown]
# ## Interview drill
# - Q: Explain linear regression as an ml baseline and one real quant use case.
# - A: Start with intuition, provide one technical detail, and connect it to a trading, portfolio, or risk decision.
# - Q: What would go wrong if this concept is applied carelessly?
# - A: Discuss one realistic failure mode and how you would detect it.

# %% [markdown]
# ## 10-Hour Completion Roadmap
#
# Use this minimum structure to turn today's notebook into a serious study session:
#
# - Phase 1 (60 min): Read concept notes and rewrite the core idea from memory.
# - Phase 2 (60 min): Rewrite formulas/workflows and define each term.
# - Phase 3 (60 min): Complete baseline code labs with comments.
# - Phase 4 (60 min): Build one real-data extension and compare outputs.
# - Phase 5 (60 min): Add stress/sensitivity checks and interpret shifts.
# - Phase 6 (60 min): Run scenario analysis and identify fragile assumptions.
# - Phase 7 (60 min): Complete interview-style Python drill with explanation.
# - Phase 8 (60 min): Do closed-book retrieval and update error log.
# - Phase 9 (60 min): Write one desk memo with recommendation and caveat.
# - Phase 10 (60 min): Define next-session experiment plan and confidence score.

# %% [markdown]
# ## Formula Rewrite Drill

# %%
import pandas as pd

formula_drill = pd.DataFrame(
    [{'formula': '\\hat\\beta=(X^TX)^{-1}X^Ty', 'from_memory': '', 'term_explanations': ''}, {'formula': 'e_i=y_i-\\hat y_i', 'from_memory': '', 'term_explanations': ''}, {'formula': 'R^2=1-\\frac{\\sum e_i^2}{\\sum (y_i-\\bar y)^2}', 'from_memory': '', 'term_explanations': ''}]
)
print(formula_drill)
# Out:
#                                         formula from_memory term_explanations
# 0                     \hat\beta=(X^TX)^{-1}X^Ty
# 1                              e_i=y_i-\hat y_i
# 2  R^2=1-\frac{\sum e_i^2}{\sum (y_i-\bar y)^2}

# %% [markdown]
# ## Real Market Data Lab (Topic-Aligned)
#
#         Use today's topic (Linear regression as an ML baseline) with one concrete dataset and one measurable output.
#
#         - Use yfinance first for SPY, QQQ, TLT, and GLD when internet is available.
# - If available, validate against a Robinhood-style export CSV for consistency checks.
# - Fall back to curriculum/datasets/real_market_prices.csv for reproducible runs.
# - Design one topic-specific analysis for linear regression as an ml baseline instead of reusing generic volatility-only metrics.
# - Document one implementation risk and one robustness check before finalizing conclusions.

# %%
TASK = 'Fit a linear regression of QQQ returns on lagged SPY returns and report coefficient and R^2.'
print('Lab task:', TASK)

from pathlib import Path
import pandas as pd
from sklearn.linear_model import LinearRegression

market = pd.read_csv(Path("curriculum/datasets/real_market_prices.csv"), parse_dates=["date"])
prices = market.pivot(index="date", columns="symbol", values="close").dropna()
returns = prices.pct_change().dropna()
X = returns[["SPY"]].shift(1).dropna()
y = returns.loc[X.index, "QQQ"]
model = LinearRegression().fit(X, y)
print({"beta_spy": round(float(model.coef_[0]), 6), "intercept": round(float(model.intercept_), 6), "r2": round(float(model.score(X, y)), 4)})
# Out:
# Lab task: Fit a linear regression of QQQ returns on lagged SPY returns and report coefficient and R^2.
# {'beta_spy': -0.049526, 'intercept': 0.000706, 'r2': 0.0014}

# %% [markdown]
# ## Real-World Takeaway Prompt
#
# Write 5-8 lines for today's topic (Linear regression as an ML baseline):
#
# 1. Which symbol looked most volatile and why that matters.
# 2. Which pair looked most diversifying.
# 3. One realistic portfolio/risk decision you could make from this table.

# %% [markdown]
# ## Interview Question + Python Solution Drill
#
# Use this format for interview preparation:
#
# 1. State the question clearly.
# 2. Explain your approach in plain language.
# 3. Write Python code on relevant data.
# 4. Interpret one risk caveat in words.
#
# **Drill prompt**
# - Fit a linear regression of QQQ returns on lagged SPY returns and report coefficient and R^2.

# %%
TASK = 'Fit a linear regression of QQQ returns on lagged SPY returns and report coefficient and R^2.'
print('Interview drill task:', TASK)

from pathlib import Path
import pandas as pd
from sklearn.linear_model import LinearRegression

market = pd.read_csv(Path("curriculum/datasets/real_market_prices.csv"), parse_dates=["date"])
prices = market.pivot(index="date", columns="symbol", values="close").dropna()
returns = prices.pct_change().dropna()
X = returns[["SPY"]].shift(1).dropna()
y = returns.loc[X.index, "QQQ"]
model = LinearRegression().fit(X, y)
print({"beta_spy": round(float(model.coef_[0]), 6), "intercept": round(float(model.intercept_), 6), "r2": round(float(model.score(X, y)), 4)})
# Out:
# Interview drill task: Fit a linear regression of QQQ returns on lagged SPY returns and report coefficient and R^2.
# {'beta_spy': -0.049526, 'intercept': 0.000706, 'r2': 0.0014}

# %% [markdown]
# ## Extended 10-Hour Coding Challenge
#
# Build one additional variant for today's topic (Linear regression as an ML baseline):
#
# 1. Change one key assumption or parameter.
# 2. Re-run the pipeline and compare baseline vs variant.
# 3. Comment each major step in code so another analyst can audit your logic.
# 4. State whether the recommendation changed and why.

# %%
import pandas as pd

baseline_vs_variant = pd.DataFrame(
    [
        {"run": "baseline", "key_assumption": "", "headline_metric": None, "decision": ""},
        {"run": "variant", "key_assumption": "", "headline_metric": None, "decision": ""},
    ]
)

# Fill this table after running your variant so the comparison is explicit.
print(baseline_vs_variant)
# Out:
#         run key_assumption headline_metric decision
# 0  baseline                           None
# 1   variant                           None

# %% [markdown]
# ## Scenario Analysis Drill

# %%
import pandas as pd

scenarios = pd.DataFrame(
    [
        {"scenario": "base_case", "assumption": "", "expected_effect": ""},
        {"scenario": "bull_case", "assumption": "", "expected_effect": ""},
        {"scenario": "stress_case", "assumption": "", "expected_effect": ""},
    ]
)
print("Topic:", 'Linear regression as an ML baseline')
print(scenarios)
# Out:
# Topic: Linear regression as an ML baseline
#       scenario assumption expected_effect
# 0    base_case
# 1    bull_case
# 2  stress_case

# %% [markdown]
# ## Closed-Book Retrieval and Error Log

# %%
import pandas as pd

retrieval_scorecard = pd.DataFrame(
    [
        {"prompt": "Explain today's concept in 3 lines", "score_0_to_5": None, "notes": ""},
        {"prompt": "Write one key formula without notes", "score_0_to_5": None, "notes": ""},
        {"prompt": "Give one realistic failure mode", "score_0_to_5": None, "notes": ""},
        {"prompt": "Connect to one trading/risk decision", "score_0_to_5": None, "notes": ""},
    ]
)

error_log = pd.DataFrame(
    [
        {
            "concept": "",
            "mistake": "",
            "correction": "",
            "next_review_date": "",
        }
    ]
)
print("Retrieval scorecard template:")
print(retrieval_scorecard)
print("\nError log template:")
print(error_log)
# Out:
# Retrieval scorecard template:
#                                  prompt score_0_to_5 notes
# 0    Explain today's concept in 3 lines         None
# 1   Write one key formula without notes         None
# 2       Give one realistic failure mode         None
# 3  Connect to one trading/risk decision         None
#
# Error log template:
#   concept mistake correction next_review_date
# 0

# %% [markdown]
# ## Final 30-Minute Deliverable
#
# Write a short memo (150-250 words) with this structure:
#
# 1. Core idea of Linear regression as an ML baseline in plain language.
# 2. One technical detail or formula and why it matters.
# 3. One practical quant use case.
# 4. One limitation or failure mode and how you would detect it.
