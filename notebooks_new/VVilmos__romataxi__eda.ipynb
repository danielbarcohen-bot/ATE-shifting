# %%
import pandas

df = pandas.read_csv("data/taxi2.csv", names=["driver_id", "timestamp", "latitude", "longitude"], nrows=1000)
df.sort_values(["driver_id", "timestamp"], inplace=True)
df.head()
# Out:
#      driver_id                      timestamp   latitude  longitude
# 33           2  2014-02-01 00:00:10.168741+01  41.908130  12.504367
# 89           2  2014-02-01 00:00:25.774039+01  41.908663  12.506601
# 138          2   2014-02-01 00:00:40.26196+01  41.909040  12.507911
# 191          2  2014-02-01 00:00:56.451894+01  41.909040  12.507911
# 240          2  2014-02-01 00:01:09.895936+01  41.909040  12.507911
