# %% [markdown]
# <a href="https://colab.research.google.com/github/PetrovES570/PDA_SOL/blob/main/%D0%9F%D1%80%D0%B0%D0%BA%D1%82%D0%B8%D1%87%D0%B5%D1%81%D0%BA%D0%B0%D1%8F_%D1%80%D0%B0%D0%B1%D0%BE%D1%82%D0%B0_2_%D0%90%D0%BB%D1%8C%D1%82%D0%B5%D1%80%D0%B0%D0%BD%D0%B0%D1%82%D0%B8%D0%B2%D0%BD%D0%B0%D1%8F_%D1%80%D0%B0%D0%B1%D0%BE%D1%82%D0%B0_%D0%98%D0%B7%D0%B2%D0%BB%D0%B5%D1%87%D0%B5%D0%BD%D0%B8%D0%B5_%D0%B4%D0%B0%D0%BD%D0%BD%D1%8B%D1%85_%D0%9F%D0%B5%D1%82%D1%80%D0%BE%D0%B2_%D0%95%D0%B2%D0%B3%D0%B5%D0%BD%D0%B8%D0%B9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Практическая работа 2. Альтернативная работа. Извлечение данных**

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-387fb948-2eea-4d14-90fd-8a8803c141a3" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-387fb948-2eea-4d14-90fd-8a8803c141a3">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# Установите `Kaggle API`, используя

# %%
# !pip install -q kaggle

# %% [markdown]
# Переместите файл `kaggle.json` в **~/.kaggle**, где клиент `API` ожидает расположения вашего токена:

# %%
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/

# %% [markdown]
# Предоставьте разрешения на изменение, чтобы избежать предупреждения при запуске инструмента `Kaggle`.

# %%
# !chmod 600 ~/.kaggle/kaggle.json

# %% [markdown]
# Теперь вы можете получить доступ к наборам данных с помощью клиента

# %%
# !kaggle datasets list
# Out:
# ...
# ref                                                           title                                            size  lastUpdated          downloadCount  voteCount  usabilityRating
# ------------------------------------------------------------  ----------------------------------------------  -----  -------------------  -------------  ---------  ---------------
# sudarshan24byte/online-food-dataset                           Online Food Dataset                               3KB  2024-03-02 18:50:30          24649        489  0.9411765
# sukhmandeepsinghbrar/most-subscribed-youtube-channel          Most Subscribed YouTube Channel                   1KB  2024-04-10 20:33:05            743         30  1.0
# sanyamgoyal401/customer-purchases-behaviour-dataset           Customer Purchases Behaviour Dataset              1MB  2024-04-06 18:42:01           1266         34  1.0
# ...

# %%
import kaggle

# List of all datasets available on Kaggle
kaggle.api.dataset_list()
# Out:
# ...
# [sudarshan24byte/online-food-dataset,
#  sukhmandeepsinghbrar/most-subscribed-youtube-channel,
#  sanyamgoyal401/customer-purchases-behaviour-dataset,
#  mohdshahnawazaadil/credit-card-dataset,
#  sahirmaharajj/employee-salaries-analysis,
#  nbroad/gemma-rewrite-nbroad,
#  soumyajitjalua/crop-datasets-for-all-indian-states-2010-2017,
#  bhavikjikadara/student-study-performance,
#  fatemehmehrparvar/obesity-levels,
#  joshuanaude/effects-of-alcohol-on-student-performance,
#  sahirmaharajj/air-pollution-dataset,
#  sahilnbajaj/loans-data,
#  sukhmandeepsinghbrar/housing-price-dataset,
#  startalks/pii-models,
#  sahirmaharajj/electric-vehicle-population-size-2024,
#  jatinthakur706/most-watched-netflix-original-shows-tv-time,
#  sahirmaharajj/retail-sales-analysis,
#  shriyashjagtap/fraudulent-e-commerce-transactions,
#  willianoliveiragibin/time-the-internet,
#  muhammadkashif724/netflix-tv-shows-2021]

# %%
# поиск наборов данных на Kaggle о ""ключевое слово"""
datasets = kaggle.api.datasets_list(search="HeadHunter vacancies")

print(datasets)
# Out:
# [{'subtitleNullable': 'HeadHunter vacancies for "data" search that were scraped directly from the site.', 'creatorNameNullable': 'Anton Belyaev', 'creatorUrlNullable': 'antonbelyaevd', 'totalBytesNullable': 40725, 'urlNullable': 'https://www.kaggle.com/datasets/antonbelyaevd/headhunter-vacancies-for-data-search', 'licenseNameNullable': 'Apache 2.0', 'descriptionNullable': None, 'ownerNameNullable': 'Anton Belyaev', 'ownerRefNullable': 'antonbelyaevd', 'titleNullable': 'HeadHunter vacancies', 'currentVersionNumberNullable': 1, 'usabilityRatingNullable': 1.0, 'id': 3676296, 'ref': 'antonbelyaevd/headhunter-vacancies-for-data-search', 'subtitle': 'HeadHunter vacancies for "data" search that were scraped directly from the site.', 'hasSubtitle': True, 'creatorName': 'Anton Belyaev', 'hasCreatorName': True, 'creatorUrl': 'antonbelyaevd', 'hasCreatorUrl': True, 'totalBytes': 40725, 'hasTotalBytes': True, 'url': 'https://www.kaggle.com/datasets/antonbelyaevd/headhunter-vacancies-for-data-sea
# ...

# %%
# !pip install pandas
import pandas as pd

# %%
datasets = kaggle.api.datasets_list(search="HeadHunter vacancies")
df1=pd.DataFrame(datasets)
pd.DataFrame(datasets)
# Out:
#                                     subtitleNullable creatorNameNullable  \
# 0  HeadHunter vacancies for "data" search that we...       Anton Belyaev
# 1  IT Vacancies from HeadHunter obtained through ...       Ilya Zawilsiv
# 2  Scraped Jobs. No any augmentation or clearing ...    Gennadii Manzhos
#
#   creatorUrlNullable  totalBytesNullable  \
# 0      antonbelyaevd               40725
# 1       ilyazawilsiv            78146938
# 2    gennadiimanzhos              348542
#
#                                          urlNullable licenseNameNullable  \
# 0  https://www.kaggle.com/datasets/antonbelyaevd/...          Apache 2.0
# 1  https://www.kaggle.com/datasets/ilyazawilsiv/i...          Apache 2.0
# 2  https://www.kaggle.com/datasets/gennadiimanzho...          Apache 2.0
#
#   descriptionNullable ownerNameNullable ownerRefNullable  \
# 0                None     Anton Belyaev    antonbelyaevd
# 1                None     Ilya Zawilsiv     ilyazawilsiv
# ...

# %%
df1.to_excel("HeadHunter vacancies.xlsx", sheet_name='HeadHunter vacancies')

# %%
from google.colab import files
files.download('HeadHunter vacancies.xlsx')

# %% [markdown]
# # Изучим датасет **HeadHunter Vacancies**

# %% [markdown]
# Download Dataset.

# %%
# !kaggle datasets download -d antonbelyaevd/headhunter-vacancies-for-data-search
# Out:
# ...
#   0% 0.00/39.8k [00:00<?, ?B/s]
# 100% 39.8k/39.8k [00:00<00:00, 2.09MB/s]

# %%
import zipfile

with zipfile.ZipFile("headhunter-vacancies-for-data-search.zip","r") as zip_ref:

    # extracting content in the zipfile
    zip_ref.extractall()

# %%
# !ls
# Out:
# headhunter-vacancies-for-data-search.zip  kaggle.json  sample_data  vacancies.csv

# %%
df = pd.read_csv('/content/vacancies.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 800 entries, 0 to 799
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   name          797 non-null    object
#  1   tags          800 non-null    object
#  2   link          800 non-null    object
#  3   experience    797 non-null    object
#  4   lower_salary  187 non-null    float64
#  5   upper_salary  187 non-null    float64
#  6   currency      160 non-null    object
# dtypes: float64(2), object(5)
# memory usage: 43.9+ KB

# %%
# reading the contents of the "NetFlix.csv"
df = pd.read_csv("vacancies.csv")

# printing first 6 raws of the dataframe
df.head(100)
# Out:
#                                                  name  \
# 0                        Ведущий менеджер по продажам
# 1                     Data Scientist (команда Поиска)
# 2                    Data Scientist в b2c направление
# 3   Портфельный риск-аналитик / Middle Data Scient...
# 4                                     Трафик-менеджер
# ..                                                ...
# 95       Data Scientist / Developer (Middle / Senior)
# 96               Data Scientist/ML Architect (junior)
# 97  Middle Системный Аналитик в продукт B2B (Big D...
# 98  Специалист по машинному обучению (Data Scientist)
# 99               Data engineer, Фреш, Ценообразование
#
#                                                  tags  \
# 0   ['Активные продажи', 'Ведение переговоров', 'Т...
# 1   ['Python', 'PyTorch', 'SQL', 'Machine Learning...
# 2   ['Python', 'Machine Learning', 'SQL', 'PyTorch...
# 3                                                  []
# ...

# %%
my_df =df[['name','tags','link','experience','lower_salary','upper_salary']].copy()

# %%
my_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 800 entries, 0 to 799
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   name          797 non-null    object
#  1   tags          800 non-null    object
#  2   link          800 non-null    object
#  3   experience    797 non-null    object
#  4   lower_salary  187 non-null    float64
#  5   upper_salary  187 non-null    float64
# dtypes: float64(2), object(4)
# memory usage: 37.6+ KB

# %%
my_df
# Out:
#                                                   name  \
# 0                         Ведущий менеджер по продажам
# 1                      Data Scientist (команда Поиска)
# 2                     Data Scientist в b2c направление
# 3    Портфельный риск-аналитик / Middle Data Scient...
# 4                                      Трафик-менеджер
# ..                                                 ...
# 795                             BI Developer (Tableau)
# 796                             Performance-маркетолог
# 797                             Ведущий специалист RPA
# 798                      IT Специалист/ Engineer (RPA)
# 799                         Архитектор направления CVM
#
#                                                   tags  \
# 0    ['Активные продажи', 'Ведение переговоров', 'Т...
# 1    ['Python', 'PyTorch', 'SQL', 'Machine Learning...
# 2    ['Python', 'Machine Learning', 'SQL', 'PyTorch...
# 3                                                   []
# ...

# %%
my_df.isnull().values.any()
# Out:
# True

# %%
my_df.isnull().sum()
# Out:
# name              3
# tags              0
# link              0
# experience        3
# lower_salary    613
# upper_salary    613
# dtype: int64

# %%
df.isnull().sum().sum()
# Out:
# 1872

# %%
my_df.isna().sum()/(len(df))*100
# Out:
# name             0.375
# tags             0.000
# link             0.000
# experience       0.375
# lower_salary    76.625
# upper_salary    76.625
# dtype: float64

# %%
my_df.isnull().sum()/(len(df))*100
# Out:
# name             0.375
# tags             0.000
# link             0.000
# experience       0.375
# lower_salary    76.625
# upper_salary    76.625
# dtype: float64

# %%
df2 = my_df.dropna()

# %%
df2
# Out:
#                                                   name  \
# 0                         Ведущий менеджер по продажам
# 1                      Data Scientist (команда Поиска)
# 4                                      Трафик-менеджер
# 6                                        Data Engineer
# 15                                      Data scientist
# ..                                                 ...
# 772  Java-разработчик (Middle Back), удаленно (финтех)
# 778  Менеджер по развитию розничной сети / Менеджер...
# 791                          Middle Python-разработчик
# 793        Специалист по управлению данными (удалённо)
# 794                      Legal & Compliance Specialist
#
#                                                   tags  \
# 0    ['Активные продажи', 'Ведение переговоров', 'Т...
# 1    ['Python', 'PyTorch', 'SQL', 'Machine Learning...
# 4    ['Анализ трафика', 'Аналитика', 'Маркетинг', '...
# 6                                                   []
# ...

# %%
df2.isnull().values.any()
# Out:
# False

# %% [markdown]
#     Только рф

# %%
rslt_df = rslt_df[(rslt_df['experience'] == 'Требуемый опыт работы: не требуется') & (rslt_df['lower_salary'] >= 60000)]

# %%
rslt_df
# Out:
#                                                  name  \
# 0                        Ведущий менеджер по продажам
# 1   Разработчик нейросетевых алгоритмов / Data Sci...
# 2                Data Scientist/ML Architect (junior)
# 3                            Инженер / Data Scientist
# 4                                        Data Analyst
# 5                                     Аналитик данных
# 11  Маркетолог/менеджер маркетплейсов (Junior/Juni...
# 12                                 Operations manager
# 14  Management Trainee - Legal & External Affairs ...
# 15                               Менеджер по продажам
# 16           Инженер-программист компьютерного зрения
# 18         Специалист по перемещению товара/кладовщик
# 21                                    Аналитик данных
# 22                         Investor Relations Analyst
#
#                                                  tags  \
# 0   ['Активные продажи', 'Ведение переговоров', 'Т...
# ...

# %%
rslt_df.reset_index(drop=True, inplace=True)

# %%
rslt_df
# Out:
#                                                  name  \
# 0                        Ведущий менеджер по продажам
# 1   Разработчик нейросетевых алгоритмов / Data Sci...
# 2                Data Scientist/ML Architect (junior)
# 3                            Инженер / Data Scientist
# 4                                        Data Analyst
# 5                                     Аналитик данных
# 6   Маркетолог/менеджер маркетплейсов (Junior/Juni...
# 7                                  Operations manager
# 8   Management Trainee - Legal & External Affairs ...
# 9                                Менеджер по продажам
# 10           Инженер-программист компьютерного зрения
# 11         Специалист по перемещению товара/кладовщик
# 12                                    Аналитик данных
# 13                         Investor Relations Analyst
#
#                                                  tags  \
# 0   ['Активные продажи', 'Ведение переговоров', 'Т...
# ...

# %%
rslt_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14 entries, 0 to 13
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   name          14 non-null     object
#  1   tags          14 non-null     object
#  2   link          14 non-null     object
#  3   experience    14 non-null     object
#  4   lower_salary  14 non-null     float64
#  5   upper_salary  14 non-null     float64
# dtypes: float64(2), object(4)
# memory usage: 800.0+ bytes
