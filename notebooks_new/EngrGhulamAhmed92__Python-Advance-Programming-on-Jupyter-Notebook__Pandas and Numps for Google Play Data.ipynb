# %% [markdown]
# import numpy as numps

# %% [markdown]
# Extract Data from Google Play .Initially the the data type is dictionary

# %%
import pandas as pd
import numpy as np

# Generating sample Google Play Store data
data = {
    'App': [f'App_{i}' for i in range(1, 31)],
    'Category': np.random.choice(['Game', 'Productivity', 'Health', 'Education'], 30),
    'Rating': np.random.uniform(1.0, 5.0, 30).round(1),
    'Reviews': np.random.randint(1, 10000, 30),
    'Size': np.random.choice(['Varies with device', '10M', '20M', '30M'], 30),
    'Installs': np.random.choice(['1,000+', '10,000+', '50,000+', '100,000+'], 30),
    'Type': np.random.choice(['Free', 'Paid'], 30),
    'Price': np.random.choice(['0', '0.99', '1.99', '2.99', '4.99', '5.99', '9.99'], 30),
    'Content Rating': np.random.choice(['Everyone', 'Teen', 'Everyone 10+', 'Mature 17+'], 30)
}

# %% [markdown]
# Check Data Type

# %%
type(data)
# Out:
# dict

# %% [markdown]
# Call Pandas Data Frame

# %%
df=pd.DataFrame(data)

# %% [markdown]
# Call DataFrame with df

# %%
df
# Out:
#        App      Category  Rating  Reviews                Size  Installs  Type  \
# 0    App_1          Game     2.7     7370                 10M    1,000+  Paid
# 1    App_2     Education     2.0     6922                 30M   10,000+  Free
# 2    App_3     Education     4.8     5857                 30M   50,000+  Paid
# 3    App_4          Game     4.8     9659                 20M   10,000+  Paid
# 4    App_5          Game     2.2     3293  Varies with device    1,000+  Paid
# 5    App_6     Education     3.5     8836  Varies with device  100,000+  Free
# 6    App_7          Game     2.6      717  Varies with device   50,000+  Paid
# 7    App_8     Education     1.5     9860  Varies with device  100,000+  Free
# 8    App_9     Education     4.1     6219                 30M   50,000+  Paid
# 9   App_10        Health     3.0     3054                 10M  100,000+  Paid
# 10  App_11        Health     2.3     1370                 30M   50,000+  Free
# ...

# %% [markdown]
# Check the starting 5 entries

# %%
df.head()
# Out:
#      App      Category  Rating  Reviews Size  Installs  Type Price  \
# 0  App_1        Health     1.1     4114  20M   50,000+  Free  9.99
# 1  App_2          Game     1.7     6605  10M   10,000+  Paid  5.99
# 2  App_3  Productivity     2.2     2327  20M   10,000+  Paid  4.99
# 3  App_4          Game     1.8     2961  10M   50,000+  Paid  1.99
# 4  App_5     Education     4.8     1803  30M  100,000+  Free  0.99
#
#   Content Rating
# 0   Everyone 10+
# 1   Everyone 10+
# 2     Mature 17+
# 3   Everyone 10+
# 4           Teen

# %% [markdown]
# Check the last 5 Entries

# %%
df.tail()
# Out:
#        App   Category  Rating  Reviews                Size  Installs  Type  \
# 25  App_26  Education     3.3     5224  Varies with device   50,000+  Free
# 26  App_27  Education     1.4     5843                 10M  100,000+  Free
# 27  App_28       Game     2.0     9234                 10M    1,000+  Paid
# 28  App_29  Education     1.1     6387                 30M   10,000+  Free
# 29  App_30     Health     2.0     1354                 20M   10,000+  Free
#
#    Price Content Rating
# 25  1.99       Everyone
# 26  1.99       Everyone
# 27  0.99   Everyone 10+
# 28  1.99   Everyone 10+
# 29  5.99   Everyone 10+

# %% [markdown]
# Check the dimensions of data frame

# %%
df.shape
# Out:
# (30, 9)

# %% [markdown]
# Check the information data

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             30 non-null     object
#  1   Category        30 non-null     object
#  2   Rating          30 non-null     float64
#  3   Reviews         30 non-null     int32
#  4   Size            30 non-null     object
#  5   Installs        30 non-null     object
#  6   Type            30 non-null     object
#  7   Price           30 non-null     object
#  8   Content Rating  30 non-null     object
# dtypes: float64(1), int32(1), object(7)
# memory usage: 2.1+ KB

# %%
df.head()
# Out:
#      App      Category  Rating  Reviews Size  Installs  Type Price  \
# 0  App_1        Health     1.1     4114  20M   50,000+  Free  9.99
# 1  App_2          Game     1.7     6605  10M   10,000+  Paid  5.99
# 2  App_3  Productivity     2.2     2327  20M   10,000+  Paid  4.99
# 3  App_4          Game     1.8     2961  10M   50,000+  Paid  1.99
# 4  App_5     Education     4.8     1803  30M  100,000+  Free  0.99
#
#   Content Rating
# 0   Everyone 10+
# 1   Everyone 10+
# 2     Mature 17+
# 3   Everyone 10+
# 4           Teen

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             30 non-null     object
#  1   Category        30 non-null     object
#  2   Rating          30 non-null     float64
#  3   Reviews         30 non-null     int32
#  4   Size            30 non-null     object
#  5   Installs        30 non-null     object
#  6   Type            30 non-null     object
#  7   Price           30 non-null     object
#  8   Content Rating  30 non-null     object
# dtypes: float64(1), int32(1), object(7)
# memory usage: 2.1+ KB

# %% [markdown]
# Check any three rows

# %%
df[["App","Price","Reviews"]]
# Out:
#        App Price  Reviews
# 0    App_1  9.99     4114
# 1    App_2  5.99     6605
# 2    App_3  4.99     2327
# 3    App_4  1.99     2961
# 4    App_5  0.99     1803
# 5    App_6  1.99     6571
# 6    App_7  1.99     7409
# 7    App_8     0     3020
# 8    App_9  2.99     5479
# 9   App_10     0      465
# 10  App_11  1.99      533
# 11  App_12  0.99     4101
# 12  App_13  0.99      962
# 13  App_14  1.99     1576
# 14  App_15     0     3078
# 15  App_16  4.99     7284
# 16  App_17  0.99     7285
# 17  App_18  2.99     2535
# 18  App_19  0.99     4566
# 19  App_20  1.99        4
# 20  App_21  2.99     5161
# 21  App_22     0     9591
# 22  App_23  2.99     4366
# 23  App_24  9.99     9282
# 24  App_25  5.99     4224
# 25  App_26  4.99     2222
# 26  App_27  1.99     2712
# 27  App_28  0.99     9774
# 28  App_29  9.99     2731
# 29  App_30     0     9101

# %% [markdown]
# Describe is used to show the Numeric values .Note it will not display string

# %%
df.describe()
# Out:
#           Rating      Reviews
# count  30.000000    30.000000
# mean    2.770000  4394.733333
# std     1.282817  2871.873303
# min     1.100000     4.000000
# 25%     1.700000  2379.000000
# 50%     2.500000  4107.500000
# 75%     3.975000  6596.500000
# max     4.900000  9774.000000

# %% [markdown]
# It is used to check the dimensions

# %%
df.shape
# Out:
# (30, 9)

# %% [markdown]
# Check the unique values( Unique values function is used for see the undesired values like M,+,varies with device).We remove this type of values .This is called cleansing

# %%
df["Size"].unique()
# Out:
# array(['20M', '10M', '30M', 'Varies with device'], dtype=object)

# %% [markdown]
# This is used to display null values (the reply in Boolean)

# %%
df.isnull()
# Out:
#       App  Category  Rating  Reviews   Size  Installs   Type  Price  \
# 0   False     False   False    False  False     False  False  False
# 1   False     False   False    False  False     False  False  False
# 2   False     False   False    False  False     False  False  False
# 3   False     False   False    False  False     False  False  False
# 4   False     False   False    False  False     False  False  False
# 5   False     False   False    False  False     False  False  False
# 6   False     False   False    False  False     False  False  False
# 7   False     False   False    False  False     False  False  False
# 8   False     False   False    False  False     False  False  False
# 9   False     False   False    False  False     False  False  False
# 10  False     False   False    False  False     False  False  False
# 11  False     False   False    False  False     False  False  False
# 12  False     False   False    False  False     False  False  False
# ...

# %% [markdown]
# The see the null values sum

# %%
df.isnull().sum()
# Out:
# App               0
# Category          0
# Rating            0
# Reviews           0
# Size              0
# Installs          0
# Type              0
# Price             0
# Content Rating    0
# dtype: int64

# %% [markdown]
# To see unique values in Price

# %%
df["Price"].unique()
# Out:
# array(['9.99', '5.99', '4.99', '1.99', '0.99', '0', '2.99'], dtype=object)

# %% [markdown]
# In the column of Price replace Free with 0.However it is temporary do this.df["Price"].replace("Free","0")
# For permanent you have to write this code    df["Price"].df["Price"].replace("Free","0")

# %%
df["Price"].replace("Free","0")
# Out:
# 0     2.99
# 1     5.99
# 2        0
# 3     9.99
# 4     5.99
# 5     1.99
# 6     1.99
# 7     5.99
# 8     0.99
# 9     9.99
# 10       0
# 11    2.99
# 12    0.99
# 13    1.99
# 14    9.99
# 15    2.99
# 16    0.99
# 17    2.99
# 18    1.99
# 19    1.99
# 20    9.99
# 21    5.99
# 22       0
# 23    0.99
# 24    4.99
# 25    1.99
# 26    1.99
# 27    0.99
# 28    1.99
# 29    5.99
# Name: Price, dtype: object

# %% [markdown]
# Code for Permanent replacement

# %%
df["Price"]=df["Price"].replace("Free","0")

# %%
df
# Out:
#        App      Category  Rating  Reviews                Size  Installs  Type  \
# 0    App_1        Health     1.1     4114                 20M   50,000+  Free
# 1    App_2          Game     1.7     6605                 10M   10,000+  Paid
# 2    App_3  Productivity     2.2     2327                 20M   10,000+  Paid
# 3    App_4          Game     1.8     2961                 10M   50,000+  Paid
# 4    App_5     Education     4.8     1803                 30M  100,000+  Free
# 5    App_6     Education     1.7     6571                 30M   50,000+  Paid
# 6    App_7        Health     4.2     7409                 10M  100,000+  Free
# 7    App_8     Education     4.7     3020                 30M    1,000+  Paid
# 8    App_9     Education     2.5     5479                 10M   10,000+  Free
# 9   App_10  Productivity     4.4      465                 20M    1,000+  Paid
# 10  App_11     Education     1.2      533                 20M   10,000+  Paid
# ...
