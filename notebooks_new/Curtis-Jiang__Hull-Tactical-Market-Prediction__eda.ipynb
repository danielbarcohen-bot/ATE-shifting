# %% [markdown]
# # Exploratory Data Analysis
#
# This notebook demonstrates the data loading and feature engineering pipeline.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from utils import load_data, create_synthetic_data
from features import preprocess_data

# %matplotlib inline

# %%
# Try to load real data, else use synthetic
data_path = 'train.csv'
df = load_data(data_path)

if df is None:
    print("Real data not found. Generating synthetic data for demonstration.")
    df = create_synthetic_data(1000)
    
df.head()

# %%
# Preprocess and generate features
df_processed = preprocess_data(df)
df_processed.head()

# %%
plt.figure(figsize=(12, 6))
plt.plot(df['date'], df['close'], label='Close Price')
plt.title('Price Series')
plt.legend()
plt.show()

# %%
pd.plotting.scatter_matrix(df_processed[['close', 'lag_1', 'rolling_mean_5']], figsize=(10,10))
plt.show()
