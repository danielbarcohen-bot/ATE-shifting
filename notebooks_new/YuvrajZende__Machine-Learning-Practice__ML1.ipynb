# %% [markdown]
# <a href="https://colab.research.google.com/github/YuvrajZende/Machine-Learning-Practice/blob/main/ML1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report

# %%
df = pd.read_csv('/content/titanic - titanic.csv')

feactures = ['Pclass','Sex','Age','SibSp','Parch','Fare','Embarked']

df = df[feactures + ['Survived']].dropna()

print(df.head(10))
print("\n")
print("\n")
print("\n")
df.info()
# Out:
#     Pclass     Sex   Age  SibSp  Parch     Fare Embarked  Survived
# 0        3    male  22.0      1      0   7.2500        S         0
# 1        1  female  38.0      1      0  71.2833        C         1
# 2        3  female  26.0      0      0   7.9250        S         1
# 3        1  female  35.0      1      0  53.1000        S         1
# 4        3    male  35.0      0      0   8.0500        S         0
# 6        1    male  54.0      0      0  51.8625        S         0
# 7        3    male   2.0      3      1  21.0750        S         0
# 8        3  female  27.0      0      2  11.1333        S         1
# 9        2  female  14.0      1      0  30.0708        C         1
# 10       3  female   4.0      1      1  16.7000        S         1
#
#
#
#
#
#
# <class 'pandas.core.frame.DataFrame'>
# Index: 712 entries, 0 to 890
# Data columns (total 8 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Pclass    712 non-null    int64
# ...

# %%
num_feactures = ['Age','SibSp','Parch','Fare']
cat_feactures = ['Pclass','Sex','Embarked']

#transformer
num_transformer = StandardScaler()
cat_transformer = OneHotEncoder(handle_unknown='ignore')

#combine transformer into a preprocessor things
preprocessor = ColumnTransformer([
     ('num',num_transformer,num_feactures),
     ('cat',cat_transformer,cat_feactures)
 ])
# Out:
# StandardScaler()
# OneHotEncoder(handle_unknown='ignore')
# ColumnTransformer(transformers=[('num', StandardScaler(),
#                                  ['Age', 'SibSp', 'Parch', 'Fare']),
#                                 ('cat', OneHotEncoder(handle_unknown='ignore'),
#                                  ['Pclass', 'Sex', 'Embarked'])])

# %%
# now we will split our data into X and Y
X = df[feactures]
Y = df['Survived']

X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size=0.2,random_state=42)

pipeline = Pipeline([
    ('preprocessor',preprocessor),
    ('classifier',RandomForestClassifier(n_estimators=100, random_state=42))
])

pipeline = pipeline.fit(X_train,Y_train)
print("Model training Completed")
print("\n")
y_prediction = pipeline.predict(X_test)
accuracy = accuracy_score(Y_test,y_prediction)
print("Accuracy = ",accuracy)
# Out:
# Model training Completed
#
#
# Accuracy =  0.7552447552447552

# %%
sample_data = pd.DataFrame([{
    'Pclass': 3,
    'Sex':'male',
    'Age': 25,
    'SibSp':1,
    'Parch':0,
    'Fare': 7.25,
    'Embarked':'S'
}])

prediction = pipeline.predict(sample_data)
print(prediction)
if(prediction[0]==1):
  print("Survived")
else:
  print("Not Survived")
# Out:
# [0]
# Not Survived
