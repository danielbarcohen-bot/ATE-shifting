# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns

# %%
from sklearn.model_selection  import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.dummy import DummyClassifier
from sklearn.metrics import accuracy_score, balanced_accuracy_score, roc_auc_score, classification_report,confusion_matrix, ConfusionMatrixDisplay
from sklearn.preprocessing import StandardScaler, LabelEncoder, OneHotEncoder, LabelBinarizer
from sklearn.pipeline import Pipeline
import pickle

# %% [markdown]
# # Step 1: Reading files as dataframe

# %%
df = pd.read_csv('train.csv')

# %% [markdown]
# # Step 2: Getting knowledge from the dataframe

# %%
df
# Out:
#        age           job   marital            education  default housing loan
# 0       49   blue-collar   married             basic.9y  unknown      no   no  \
# 1       37  entrepreneur   married    university.degree       no      no   no
# 2       78       retired   married             basic.4y       no      no   no
# 3       36        admin.   married    university.degree       no     yes   no
# 4       59       retired  divorced    university.degree       no      no   no
# ...    ...           ...       ...                  ...      ...     ...  ...
# 32945   28      services    single          high.school       no     yes   no
# 32946   52    technician   married  professional.course       no     yes   no
# 32947   54        admin.   married             basic.9y       no      no  yes
# 32948   29        admin.   married    university.degree       no      no   no
# 32949   35        admin.   married    university.degree       no      no  yes
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32950 entries, 0 to 32949
# Data columns (total 16 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   age          32950 non-null  int64
#  1   job          32950 non-null  object
#  2   marital      32950 non-null  object
#  3   education    32950 non-null  object
#  4   default      32950 non-null  object
#  5   housing      32950 non-null  object
#  6   loan         32950 non-null  object
#  7   contact      32950 non-null  object
#  8   month        32950 non-null  object
#  9   day_of_week  32950 non-null  object
#  10  duration     32950 non-null  int64
#  11  campaign     32950 non-null  int64
#  12  pdays        32950 non-null  int64
#  13  previous     32950 non-null  int64
#  14  poutcome     32950 non-null  object
#  15  y            32950 non-null  object
# dtypes: int64(5), object(11)
# memory usage: 4.0+ MB

# %%
df.describe()
# Out:
#                 age      duration      campaign         pdays      previous
# count  32950.000000  32950.000000  32950.000000  32950.000000  32950.000000
# mean      40.014112    258.127466      2.560607    962.052413      0.174719
# std       10.403636    258.975917      2.752326    187.951096      0.499025
# min       17.000000      0.000000      1.000000      0.000000      0.000000
# 25%       32.000000    103.000000      1.000000    999.000000      0.000000
# 50%       38.000000    180.000000      2.000000    999.000000      0.000000
# 75%       47.000000    319.000000      3.000000    999.000000      0.000000
# max       98.000000   4918.000000     56.000000    999.000000      7.000000

# %%
df.describe(include='O')
# Out:
#            job  marital          education default housing   loan   contact
# count    32950    32950              32950   32950   32950  32950     32950  \
# unique      12        4                  8       3       3      3         2
# top     admin.  married  university.degree      no     yes     no  cellular
# freq      8314    19953               9736   26007   17254  27131     20908
#
#         month day_of_week     poutcome      y
# count   32950       32950        32950  32950
# unique     10           5            3      2
# top       may         thu  nonexistent     no
# freq    11011        6857        28416  29238

# %%
df.head(3)
# Out:
#    age           job  marital          education  default housing loan
# 0   49   blue-collar  married           basic.9y  unknown      no   no  \
# 1   37  entrepreneur  married  university.degree       no      no   no
# 2   78       retired  married           basic.4y       no      no   no
#
#      contact month day_of_week  duration  campaign  pdays  previous
# 0   cellular   nov         wed       227         4    999         0  \
# 1  telephone   nov         wed       202         2    999         1
# 2   cellular   jul         mon      1148         1    999         0
#
#       poutcome    y
# 0  nonexistent   no
# 1      failure   no
# 2  nonexistent  yes

# %%
df.tail(3)
# Out:
#        age     job  marital          education default housing loan
# 32947   54  admin.  married           basic.9y      no      no  yes  \
# 32948   29  admin.  married  university.degree      no      no   no
# 32949   35  admin.  married  university.degree      no      no  yes
#
#          contact month day_of_week  duration  campaign  pdays  previous
# 32947   cellular   jul         mon       131         4    999         0  \
# 32948  telephone   may         fri       165         1    999         0
# 32949  telephone   jun         tue       544         3    999         0
#
#           poutcome   y
# 32947  nonexistent  no
# 32948  nonexistent  no
# 32949  nonexistent  no

# %%
df.isnull().sum()
# Out:
# age            0
# job            0
# marital        0
# education      0
# default        0
# housing        0
# loan           0
# contact        0
# month          0
# day_of_week    0
# duration       0
# campaign       0
# pdays          0
# previous       0
# poutcome       0
# y              0
# dtype: int64

# %%
print(df.apply(lambda col: col.nunique()))
# Out:
# age              75
# job              12
# marital           4
# education         8
# default           3
# housing           3
# loan              3
# contact           2
# month            10
# day_of_week       5
# duration       1467
# campaign         40
# pdays            27
# previous          8
# poutcome          3
# y                 2
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 8

# %%
df.drop_duplicates(inplace=True)

# %%
df.duplicated().sum()
# Out:
# 0

# %%
len(df)
# Out:
# 32942

# %% [markdown]
# # Step 3: Plotting the Graph for the thorough analysis

# %%
correlation = df.select_dtypes(include=np.number).corr()

fig, ax = plt.subplots(figsize=(11, 11))
cmap = sns.diverging_palette(20, 220, n=256, as_cmap=True)
sns.heatmap(correlation, 
            cmap=cmap, 
            vmax=.3, 
            center=0,
            square=True, 
            linewidths=.5,
            annot = True,
            fmt='.2f',)

plt.title('Corrleation plot for the numerical columns.')
plt.tight_layout()

# %%
sns.countplot(x='y',data=df)
# Out:
# <AxesSubplot:xlabel='y', ylabel='count'>

# %% [markdown]
# # Step 4: Baseline Evaluation

# %%
baseline_data = df.copy(deep=True)
X_baseline = baseline_data.drop('y',axis=1)
y_baseline = baseline_data.y

# %%
X_train_baseline,X_test_baseline, y_train_baseline, y_test_baseline = train_test_split(X_baseline, y_baseline, test_size=0.25)

# %%
dummyClassifier = DummyClassifier(strategy="most_frequent", random_state=42)
dummyClassifier.fit(X_train_baseline, y_train_baseline)
# Out:
# DummyClassifier(random_state=42, strategy='most_frequent')

# %%
y_pred_baseline = dummyClassifier.predict(X_test_baseline)
baseline_balanced_score = balanced_accuracy_score(y_test_baseline, y_pred_baseline)
baseline_accuracy_score = accuracy_score(y_test_baseline, y_pred_baseline)
# baseline_roc = roc_auc_score(y_test_baseline, y_pred_baseline)
baseline_cm = confusion_matrix(y_test_baseline, y_pred_baseline)
baseline_plot = ConfusionMatrixDisplay(baseline_cm, display_labels=dummyClassifier.classes_)
baseline_plot.plot()
baseline_report = classification_report(y_test_baseline, y_pred_baseline)
print(baseline_report)
print(baseline_balanced_score, baseline_accuracy_score)
# Out:
#               precision    recall  f1-score   support
#
#           no       0.88      1.00      0.94      7281
#          yes       0.00      0.00      0.00       955
#
#     accuracy                           0.88      8236
#    macro avg       0.44      0.50      0.47      8236
# weighted avg       0.78      0.88      0.83      8236
#
# 0.5 0.8840456532297232
# /Users/aegon/opt/miniconda3/envs/machine_learning/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ...

# %% [markdown]
# # Step 5: Preprocessing and Feature Engineering

# %%
numerical_columns = df.select_dtypes(include="int64").columns
categorical_columns = df.select_dtypes(exclude="int64").columns

# %%
data = df.copy(deep=True)

# %%
labelEncoder = LabelEncoder()
data['y'] = labelEncoder.fit_transform(data['y'])

# %%
data
# Out:
#        age           job   marital            education  default housing loan
# 0       49   blue-collar   married             basic.9y  unknown      no   no  \
# 1       37  entrepreneur   married    university.degree       no      no   no
# 2       78       retired   married             basic.4y       no      no   no
# 3       36        admin.   married    university.degree       no     yes   no
# 4       59       retired  divorced    university.degree       no      no   no
# ...    ...           ...       ...                  ...      ...     ...  ...
# 32945   28      services    single          high.school       no     yes   no
# 32946   52    technician   married  professional.course       no     yes   no
# 32947   54        admin.   married             basic.9y       no      no  yes
# 32948   29        admin.   married    university.degree       no      no   no
# 32949   35        admin.   married    university.degree       no      no  yes
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 32942 entries, 0 to 32949
# Data columns (total 16 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   age          32942 non-null  int64
#  1   job          32942 non-null  object
#  2   marital      32942 non-null  object
#  3   education    32942 non-null  object
#  4   default      32942 non-null  object
#  5   housing      32942 non-null  object
#  6   loan         32942 non-null  object
#  7   contact      32942 non-null  object
#  8   month        32942 non-null  object
#  9   day_of_week  32942 non-null  object
#  10  duration     32942 non-null  int64
#  11  campaign     32942 non-null  int64
#  12  pdays        32942 non-null  int64
#  13  previous     32942 non-null  int64
#  14  poutcome     32942 non-null  object
#  15  y            32942 non-null  int64
# dtypes: int64(6), object(10)
# memory usage: 4.3+ MB

# %%
X = data.drop('y', axis=1)
y = data['y']

# %%
numerical_columns = X.select_dtypes(include="int64").columns
categorical_columns = X.select_dtypes(exclude="int64").columns

# %%
print(numerical_columns)
# Out:
# Index(['age', 'duration', 'campaign', 'pdays', 'previous'], dtype='object')

# %%
print(categorical_columns)
# Out:
# Index(['job', 'marital', 'education', 'default', 'housing', 'loan', 'contact',
#        'month', 'day_of_week', 'poutcome'],
#       dtype='object')

# %%
week_days = ['mon', 'tue', 'wed', 'thu', 'fri', 'sat', 'sun']
months = list(map(str.lower, ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']))

# %%
def numerize(df, col,tuple):
    if type(df[col].iloc[0]) == str:
        df[col] = df[col].apply(lambda x: tuple.index(x))

# %%
numerize(X, 'day_of_week', week_days)
numerize(X, 'month', months)

# %%
X
# Out:
#        age           job   marital            education  default housing loan
# 0       49   blue-collar   married             basic.9y  unknown      no   no  \
# 1       37  entrepreneur   married    university.degree       no      no   no
# 2       78       retired   married             basic.4y       no      no   no
# 3       36        admin.   married    university.degree       no     yes   no
# 4       59       retired  divorced    university.degree       no      no   no
# ...    ...           ...       ...                  ...      ...     ...  ...
# 32945   28      services    single          high.school       no     yes   no
# 32946   52    technician   married  professional.course       no     yes   no
# 32947   54        admin.   married             basic.9y       no      no  yes
# 32948   29        admin.   married    university.degree       no      no   no
# 32949   35        admin.   married    university.degree       no      no  yes
#
# ...

# %%
poutcome = ('failure','nonexistent','success')
contact = ('cellular','telephone')
loan = ('no','yes','unknown')
numerize(X, 'poutcome', poutcome)
numerize(X, 'contact', contact)
numerize(X, 'loan', loan)

# %%
X
# Out:
#        age           job   marital            education  default housing
# 0       49   blue-collar   married             basic.9y  unknown      no  \
# 1       37  entrepreneur   married    university.degree       no      no
# 2       78       retired   married             basic.4y       no      no
# 3       36        admin.   married    university.degree       no     yes
# 4       59       retired  divorced    university.degree       no      no
# ...    ...           ...       ...                  ...      ...     ...
# 32945   28      services    single          high.school       no     yes
# 32946   52    technician   married  professional.course       no     yes
# 32947   54        admin.   married             basic.9y       no      no
# 32948   29        admin.   married    university.degree       no      no
# 32949   35        admin.   married    university.degree       no      no
#
#        loan  contact  month  day_of_week  duration  campaign  pdays  previous
# ...

# %%
job=('admin.','blue-collar','entrepreneur','housemaid','management','retired','self-employed','services','student','technician','unemployed','unknown')
marital=('divorced','married','single','unknown')   # note: 'divorced' means divorced or widowed)
education=('basic.4y','basic.6y','basic.9y','high.school','illiterate','professional.course','university.degree','unknown')
default=('no','yes','unknown')
housing=('no','yes','unknown')
numerize(X, 'job', job)
numerize(X, 'marital', marital)
numerize(X, 'education', education)
numerize(X, 'default', default)
numerize(X, 'housing', housing)

# %%
X
# Out:
#        age  job  marital  education  default  housing  loan  contact  month
# 0       49    1        1          2        2        0     0        0     10  \
# 1       37    2        1          6        0        0     0        1     10
# 2       78    5        1          0        0        0     0        0      6
# 3       36    0        1          6        0        1     0        1      4
# 4       59    5        0          6        0        0     0        0      5
# ...    ...  ...      ...        ...      ...      ...   ...      ...    ...
# 32945   28    7        2          3        0        1     0        0      6
# 32946   52    9        1          5        0        1     0        0     10
# 32947   54    0        1          2        0        0     1        0      6
# 32948   29    0        1          6        0        0     0        1      4
# 32949   35    0        1          6        0        0     1        1      5
#
# ...

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 32942 entries, 0 to 32949
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   age          32942 non-null  int64
#  1   job          32942 non-null  int64
#  2   marital      32942 non-null  int64
#  3   education    32942 non-null  int64
#  4   default      32942 non-null  int64
#  5   housing      32942 non-null  int64
#  6   loan         32942 non-null  int64
#  7   contact      32942 non-null  int64
#  8   month        32942 non-null  int64
#  9   day_of_week  32942 non-null  int64
#  10  duration     32942 non-null  int64
#  11  campaign     32942 non-null  int64
#  12  pdays        32942 non-null  int64
#  13  previous     32942 non-null  int64
#  14  poutcome     32942 non-null  int64
# dtypes: int64(15)
# memory usage: 4.0 MB

# %%
standardScaler = StandardScaler()
decisionTree = DecisionTreeClassifier(random_state=42)

# %%
pipeline = Pipeline(steps=[
    ('standardScaler', standardScaler),
    ('decisionTree', decisionTree)
])

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y,test_size=0.25, random_state=42)

# %%
pipeline.fit(X_train,y_train)
# Out:
# Pipeline(steps=[('standardScaler', StandardScaler()),
#                 ('decisionTree', DecisionTreeClassifier(random_state=42))])

# %%
y_pred = pipeline.predict(X_test)

# %%
balanced_score = balanced_accuracy_score(y_test, y_pred)
accuracy_score = accuracy_score(y_test, y_pred)
# baseline_roc = roc_auc_score(y_test_baseline, y_pred_baseline)
cm = confusion_matrix(y_test, y_pred)
cm_plot = ConfusionMatrixDisplay(baseline_cm, display_labels=dummyClassifier.classes_)
cm_plot.plot()
report = classification_report(y_test, y_pred)
print(report)
print(balanced_score, accuracy_score)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.93      0.92      0.93      7288
#            1       0.45      0.48      0.46       948
#
#     accuracy                           0.87      8236
#    macro avg       0.69      0.70      0.70      8236
# weighted avg       0.88      0.87      0.87      8236
#
# 0.7013537657417314 0.87178241864983

# %%
def dump_file(obj, file_name):
    with open(file_name,"wb") as file:
        pickle.dump(obj, file)

# %%
dump_file(obj=pipeline,file_name='pipeline.pkl')
