# %%
from dask.distributed import Client

client = Client("tcp://10.0.23.131:8790")
def square(x): return x * x
print(client.gather(client.map(square, range(5))))
# Out:
# [0, 1, 4, 9, 16]

# %%
from dask.distributed import Client

client = Client("tcp://10.0.23.131:8790")

def square(x):
    return x * x

futures = client.map(square, range(10))
results = client.gather(futures)
print(results)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from dask.distributed import Client
#       3 client = Client("tcp://10.0.23.131:8790")
#       5 def square(x):
#
# ModuleNotFoundError: No module named 'dask'

# %%
import pandas as pd

# Define file paths
file_path_in = r'c:\Users\Akshit\OneDrive\Documents\code\New folder (5)\68e8d1d70b66d_student_resource\student_resource\dataset\sample_test.csv'
file_path_out = r'c:\Users\Akshit\OneDrive\Documents\code\New folder (5)\68e8d1d70b66d_student_resource\student_resource\dataset\sample_test_out.csv'

# Read the datasets
df_in = pd.read_csv(file_path_in)
df_out = pd.read_csv(file_path_out)

# %%
print("--- Structure and details for sample_test.csv ---")
print("\nHead of the DataFrame:")
print(df_in.head())
print("\nDataFrame Shape:")
print(df_in.shape)
print("\nDataFrame Columns:")
print(df_in.columns)
print("\nInfo about the DataFrame:")
print(df_in.info())
print("\nDescription of numerical columns:")
print(df_in.describe())
print("\nMissing values per column:")
print(df_in.isnull().sum())
print("\n")

print("--- Structure and details for sample_test_out.csv ---")
print("\nHead of the DataFrame:")
print(df_out.head())
print("\nDataFrame Shape:")
print(df_out.shape)
print("\nDataFrame Columns:")
print(df_out.columns)
print("\nInfo about the DataFrame:")
print(df_out.info())
print("\nDescription of numerical columns:")
print(df_out.describe())
print("\nMissing values per column:")
print(df_out.isnull().sum())
# Out:
# --- Structure and details for sample_test.csv ---
#
# Head of the DataFrame:
#    sample_id                                    catalog_content  \
# 0     217392  Item Name: Gift Basket Village Gourmet Meat an...
# 1     209156  Item Name: NPG Dried Lotus Seeds 16 Oz, Uncook...
# 2     262333  Item Name: Annies Homegrown Macaroni and Chees...
# 3     295979  Item Name: Bear Creek Country Kitchens Creamy ...
# 4      50604  Item Name: Japanese Kelp Kombu Umami Soup Stoc...
#
#                                           image_link
# 0  https://m.media-amazon.com/images/I/91GB1wC6Ob...
# 1  https://m.media-amazon.com/images/I/81VnzF1vkv...
# 2  https://m.media-amazon.com/images/I/51aCDMHMnI...
# 3  https://m.media-amazon.com/images/I/71dzRyLGPi...
# 4  https://m.media-amazon.com/images/I/71Yu21cGwr...
#
# DataFrame Shape:
# (100, 3)
#
# DataFrame Columns:
# Index(['sample_id', 'catalog_content', 'image_link'], dtype='object')
#
# Info about the DataFrame:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 3 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   sample_id        100 non-null    int64
#  1   catalog_content  100 non-null    object
#  2   image_link       100 non-null    object
# dtypes: int64(1), object(2)
# memory usage: 2.5+ KB
# None
#
# Description of numerical columns:
#          sample_id
# count     100.0000
# mean   140796.1800
# std     89582.3789
# min     11241.0000
# 25%     65455.2500
# 50%    138960.5000
# 75%    221359.0000
# max    297033.0000
#
# Missing values per column:
# sample_id          0
# catalog_content    0
# image_link         0
# dtype: int64
#
#
# --- Structure and details for sample_test_out.csv ---
#
# Head of the DataFrame:
#    sample_id      price
# 0     217392  62.080008
# 1     209156  17.189763
# 2     262333  96.501410
# 3     295979   5.652474
# 4      50604  23.794780
#
# DataFrame Shape:
# (100, 2)
#
# DataFrame Columns:
# Index(['sample_id', 'price'], dtype='object')
#
# Info about the DataFrame:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   sample_id  100 non-null    int64
#  1   price      100 non-null    float64
# dtypes: float64(1), int64(1)
# memory usage: 1.7 KB
# None
#
# Description of numerical columns:
#          sample_id       price
# count     100.0000  100.000000
# mean   140796.1800   51.208660
# std     89582.3789   29.855508
# min     11241.0000    0.536396
# 25%     65455.2500   26.012233
# 50%    138960.5000   53.216238
# 75%    221359.0000   75.996010
# max    297033.0000   99.726515
#
# Missing values per column:
# sample_id    0
# price        0
# dtype: int64

# %% [markdown]
# Data cleaning part
