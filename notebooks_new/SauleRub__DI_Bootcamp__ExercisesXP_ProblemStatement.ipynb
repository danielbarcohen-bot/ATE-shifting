# %% [markdown]
# <a href="https://colab.research.google.com/github/SauleRub/DI_Bootcamp/blob/main/Week11/Day2/ExercisesXP_ProblemStatement.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# ============================================
# Loan Default Prediction Project
# Dataset: Dataset_Train.csv
# ============================================

import pandas as pd

# Step 1: Load dataset
from google.colab import files
uploaded = files.upload()   # Upload Dataset_Train.csv from your computer

df = pd.read_csv("Dataset_Train.csv")
print("Dataset shape:", df.shape)
print(df.head())
# Out:
#      <input type="file" id="files-00d15b65-1f5f-434a-8c17-a2dbe7a6f9d6" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-00d15b65-1f5f-434a-8c17-a2dbe7a6f9d6">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# ==================================================
# 🌟 Exercise 1 : Problem Statement & Data Collection
# ==================================================

problem_statement = """
### Problem Statement
The goal is to predict whether a loan applicant will default on their loan.
This prediction helps financial institutions reduce risk and make better lending decisions.

### Data Types Needed
- Personal details: Gender, Dependents, Education, Employment status
- Financial info: ApplicantIncome, CoapplicantIncome, LoanAmount, Loan_Amount_Term
- Credit history: Credit_History
- Loan details: Loan_ID, Property_Area, Loan_Status (target)

### Data Sources
- Internal bank records
- Credit bureau data (Experian, Equifax, etc.)
- Government / regulatory financial datasets
"""
print(problem_statement)

# ==================================================
# 🌟 Exercise 2 : Feature Selection
# ==================================================

features_text = """
### Selected Features
- ApplicantIncome & CoapplicantIncome: repayment capacity
- LoanAmount & Loan_Amount_Term: burden of loan
- Credit_History: strongest indicator of repayment behavior
- Education & Employment status: economic stability
- Property_Area: proxy for regional economic differences
- Dependents: financial responsibility load

These features directly relate to ability and likelihood of repaying loans.
"""
print(features_text)

# ==================================================
# 🌟 Exercise 3 : Model Choice & Evaluation
# ==================================================

model_choice = """
### Model Choice
1. Logistic Regression → interpretable baseline
2. Random Forest → handles non-linear patterns
3. XGBoost → optimized for tabular classification

### Evaluation Metrics
- Accuracy → overall correctness
- Precision → how many predicted defaulters are real defaulters
- Recall → how many actual defaulters were caught
- F1-score → balance between precision and recall
- ROC-AUC → separation between good/bad borrowers
"""
print(model_choice)

# ==================================================
# 🌟 Exercise 4 : ML Scenarios
# ==================================================

scenarios_text = """
### ML Scenarios
- Stock Price Prediction → Regression (Supervised Learning, Time-series models like LSTM)
- Organizing Library Books → Clustering (Unsupervised Learning, KMeans)
- Robot Maze Navigation → Reinforcement Learning (Q-learning, DQN)
"""
print(scenarios_text)

# ==================================================
# 🌟 Exercise 5 : Evaluation Strategies
# ==================================================

eval_strategies = """
### Evaluation Strategies

1. Supervised (Loan Default Classification)
   - Metrics: Accuracy, Precision, Recall, F1-score, ROC-AUC
   - Methods: Train/test split, Cross-validation, ROC curve

2. Unsupervised (Library Clustering)
   - Metrics: Silhouette Score, Davies-Bouldin Index
   - Methods: Elbow Method, cluster validation

3. Reinforcement Learning (Robot Maze)
   - Metrics: Cumulative reward, success rate
   - Challenge: Exploration vs Exploitation balance
"""
print(eval_strategies)
# Out:
# ### Problem Statement
# The goal is to predict whether a loan applicant will default on their loan.
# This prediction helps financial institutions reduce risk and make better lending decisions.
#
# ### Data Types Needed
# - Personal details: Gender, Dependents, Education, Employment status
# - Financial info: ApplicantIncome, CoapplicantIncome, LoanAmount, Loan_Amount_Term
# - Credit history: Credit_History
# - Loan details: Loan_ID, Property_Area, Loan_Status (target)
#
# ### Data Sources
# - Internal bank records
# - Credit bureau data (Experian, Equifax, etc.)
# - Government / regulatory financial datasets
#
#
# ### Selected Features
# - ApplicantIncome & CoapplicantIncome: repayment capacity
# - LoanAmount & Loan_Amount_Term: burden of loan
# - Credit_History: strongest indicator of repayment behavior
# - Education & Employment status: economic stability
# - Property_Area: proxy for regional economic differences
# - Dependents: financial responsibility load
#
# ...
