# %%
# !pip install opencv-python mediapipe
# Out:
# Requirement already satisfied: opencv-python in c:\users\asus\anaconda3\envs\ds_prep\lib\site-packages (4.11.0.86)
# Collecting mediapipe
#   Using cached mediapipe-0.10.21-cp311-cp311-win_amd64.whl.metadata (10 kB)
# Requirement already satisfied: numpy>=1.21.2 in c:\users\asus\anaconda3\envs\ds_prep\lib\site-packages (from opencv-python) (1.26.0)
# Requirement already satisfied: absl-py in c:\users\asus\anaconda3\envs\ds_prep\lib\site-packages (from mediapipe) (2.1.0)
# Requirement already satisfied: attrs>=19.1.0 in c:\users\asus\anaconda3\envs\ds_prep\lib\site-packages (from mediapipe) (24.2.0)
# Requirement already satisfied: flatbuffers>=2.0 in c:\users\asus\anaconda3\envs\ds_prep\lib\site-packages (from mediapipe) (25.1.24)
# Collecting jax (from mediapipe)
#   Using cached jax-0.5.2-py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: jaxlib in c:\users\asus\anaconda3\envs\ds_prep\lib\site-packages (from mediapipe) (0.5.1)
# Requirement already satisfied: matplotlib in c:\users\asus\anaconda3\envs\ds_prep\lib\site-packages (from mediapipe) (3.10.0)
# Requirement already satisfied: opencv-contrib-python in c:\users\asus\anaconda3\envs\ds_prep\lib\site-packages (from mediapipe) (4.11.0.86)
# Requirement already satisfied: protobuf<5,>=4.25.3 in c:\users\asus\anaconda3\envs\ds_prep\lib\site-packages (from mediapipe) (4.25.6)
# Requirement already satisfied: sounddevice>=0.4.4 in c:\users\asus\anaconda3\envs\ds_prep\lib\site-packages (from mediapipe) (0.5.1)
# Requirement already satisfied: sentencepiece in c:\users\asus\anaconda3\envs\ds_prep\lib\site-packages (from mediapipe) (0.2.0)
# Requirement already satisfied: CFFI>=1.0 in c:\users\asus\anaconda3\envs\ds_prep\lib\site-packages (from sounddevice>=0.4.4->mediapipe) (1.17.1)
# Requirement already satisfied: ml_dtypes>=0.4.0 in c:\users\asus\anaconda3\envs\ds_prep\lib\site-packages (from jax->mediapipe) (0.4.1)
# Requirement already satisfied: opt_einsum in c:\users\asus\anaconda3\envs\ds_prep\lib\site-packages (from jax->mediapipe) (3.4.0)
# Requirement already satisfied: scipy>=1.11.1 in c:\users\asus\anaconda3\envs\ds_prep\lib\site-packages (from jax->mediapipe) (1.15.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\asus\anaconda3\envs\ds_prep\lib\site-packages (from matplotlib->mediapipe) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\asus\anaconda3\envs\ds_prep\lib\site-packages (from matplotlib->mediapipe) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\asus\anaconda3\envs\ds_prep\lib\site-packages (from matplotlib->mediapipe) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\asus\anaconda3\envs\ds_prep\lib\site-packages (from matplotlib->mediapipe) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in c:\users\asus\anaconda3\envs\ds_prep\lib\site-packages (from matplotlib->mediapipe) (24.1)
# Requirement already satisfied: pillow>=8 in c:\users\asus\anaconda3\envs\ds_prep\lib\site-packages (from matplotlib->mediapipe) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\asus\anaconda3\envs\ds_prep\lib\site-packages (from matplotlib->mediapipe) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\asus\anaconda3\envs\ds_prep\lib\site-packages (from matplotlib->mediapipe) (2.9.0.post0)
# Requirement already satisfied: pycparser in c:\users\asus\anaconda3\envs\ds_prep\lib\site-packages (from CFFI>=1.0->sounddevice>=0.4.4->mediapipe) (2.21)
# Requirement already satisfied: six>=1.5 in c:\users\asus\anaconda3\envs\ds_prep\lib\site-packages (from python-dateutil>=2.7->matplotlib->mediapipe) (1.16.0)
# Using cached mediapipe-0.10.21-cp311-cp311-win_amd64.whl (51.0 MB)
# Using cached jax-0.5.2-py3-none-any.whl (2.4 MB)
# Installing collected packages: jax, mediapipe
# Successfully installed jax-0.5.2 mediapipe-0.10.21
# [notice] A new release of pip is available: 24.2 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import cv2
import mediapipe as mp
import matplotlib.pyplot as plt
import numpy as np

# %%
def annotate_pose(image_path, output_path="annotated_image.jpg"):
    
    mp_drawing = mp.solutions.drawing_utils
    mp_pose = mp.solutions.pose

    # Read the image
    image = cv2.imread(image_path)
    if image is None:
        print(f"Error: Could not read image at {image_path}")
        return

    with mp_pose.Pose(
        static_image_mode=True,
        model_complexity=2,
        enable_segmentation=False,
        min_detection_confidence=0.5
    ) as pose:
        # Convert the image to RGB
        image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
        # Process the image to detect the pose
        results = pose.process(image_rgb)

    # Check if pose landmarks were detected
    if results.pose_landmarks:
        # Draw the pose landmarks on the image
        mp_drawing.draw_landmarks(
            image,
            results.pose_landmarks,
            mp_pose.POSE_CONNECTIONS,
            mp_drawing.DrawingSpec(color=(0, 255, 0), thickness=2, circle_radius=2),
            mp_drawing.DrawingSpec(color=(255, 0, 0), thickness=2)
        )
    else:
        print("No pose detected in the image.")
        return

    # Save the annotated image
    cv2.imwrite(output_path, image)
    print(f"Annotated image saved to {output_path}")

# %%
# Specify the path to your image file
image_path = "J01 - 28.08.2024.jpg"  # e.g., "C:/Users/YourName/Pictures/photo.jpg"
print(f"Using image: {image_path}")
# Out:
# Using image: J01 - 28.08.2024.jpg

# %%
# Annotate the image
annotate_pose(image_path)

# Read and display the annotated image
annotated_image = cv2.imread("annotated_image.jpg")
if annotated_image is not None:
    # Convert BGR (default in OpenCV) to RGB for proper display in matplotlib
    annotated_image = cv2.cvtColor(annotated_image, cv2.COLOR_BGR2RGB)
    
    plt.figure(figsize=(8, 6))
    plt.imshow(annotated_image)
    plt.axis("off")
    plt.title("Annotated Pose")
    plt.show()
else:
    print("Failed to load the annotated image. Please check the image path and pose detection.")
# Out:
# No pose detected in the image.
