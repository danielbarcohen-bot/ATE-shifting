# %% [markdown]
# # Comparing channels
#
# - R: sequential
# - G: reverse complementary
# - B: inverse

# %%
import ppscore
import pandas
import os
import numpy
from scipy.stats import spearmanr
from IPython.core.display import display, HTML
from ete3 import Tree
# Out:
# /tmp/ipykernel_457606/499083497.py:6: DeprecationWarning: Importing display from IPython.core.display is deprecated since IPython 7.14, please import from IPython display
#   from IPython.core.display import display, HTML

# %%
tree_path = "../../../data/trees"

# %%
def read_and_compare(dataset, channel="full"):
    result_dict = {}
    path = f"{tree_path}/{channel}/{dataset}"
    control_df = pandas.read_csv(f"{path}/Control with Clustal Omega.csv", index_col=0)
    for file in os.listdir(path):
        if file.endswith(".csv"):
            basename = ".".join(file.split(".")[0:-1])
            df = pandas.read_csv(f"{path}/{file}", index_col=0)
            result_dict[basename] = round(numpy.sqrt(numpy.sum((control_df.values - df.values)**2)), 4)
    result_df = pandas.DataFrame(result_dict, index=[dataset])
    result_df.rename(columns={"MultiScale Structural Similarity Index Measure": channel}, inplace=True)
    result_df.index.name = "dataset"
    return result_df

# %% [markdown]
# ## Euclidean Distance from distance matrices

# %%
channels = ("full", "red", "green", "blue", "red_green", "red_blue", "green_blue", "gray_r", "gray_g", "gray_b", "gray_max", "gray_mean")
datasets = ["indelible", "orthologs_hemoglobin_beta", "orthologs_myoglobin", "orthologs_neuroglobin", "orthologs_cytoglobin", "orthologs_androglobin"]
sum_dfs = []
for channel in channels:
    dfs = []
    for dataset in datasets:
        dfs.append(read_and_compare(dataset, channel))
    sum_dfs.append(pandas.concat(dfs))
pandas.concat(sum_dfs, axis=1).T.reset_index().drop_duplicates().set_index("index").T
# Out:
# index                         full  Universal Quality Index  \
# dataset
# indelible                  19.4880                   4.9357
# orthologs_hemoglobin_beta   0.1542                   1.7944
# orthologs_myoglobin         0.0954                   1.9198
# orthologs_neuroglobin       1.2176                   4.3852
# orthologs_cytoglobin        2.7743                   8.2561
# orthologs_androglobin       4.0221                  10.0408
#
# index                      Global with Needleman-Wunsch  \
# dataset
# indelible                                       10.4094
# orthologs_hemoglobin_beta                        0.9085
# orthologs_myoglobin                              0.9196
# orthologs_neuroglobin                            1.8043
# orthologs_cytoglobin                             6.3417
# orthologs_androglobin                            8.2855
#
# index                      Deep Search with Annoy  \
# dataset
# indelible                                  6.3518
# orthologs_hemoglobin_beta                  3.4018
# orthologs_myoglobin                        3.4647
# orthologs_neuroglobin                      4.9502
# orthologs_cytoglobin                       8.3726
# orthologs_androglobin                      8.6007
#
# index                      Structural Similarity Index Measure  \
# dataset
# indelible                                               4.8671
# orthologs_hemoglobin_beta                               1.6405
# orthologs_myoglobin                                     1.7845
# orthologs_neuroglobin                                   4.3484
# orthologs_cytoglobin                                    8.0178
# orthologs_androglobin                                   9.7640
#
# index                      Control with Clustal Omega  \
# dataset
# indelible                                         0.0
# orthologs_hemoglobin_beta                         0.0
# orthologs_myoglobin                               0.0
# orthologs_neuroglobin                             0.0
# orthologs_cytoglobin                              0.0
# orthologs_androglobin                             0.0
#
# index                      Local with Smith–Waterman      red  \
# dataset
# indelible                                     8.7200  30.0765
# orthologs_hemoglobin_beta                     0.8937   0.9769
# orthologs_myoglobin                           0.9044   0.9702
# orthologs_neuroglobin                         1.1514   1.3372
# orthologs_cytoglobin                          3.1095   2.4480
# orthologs_androglobin                         2.9601   0.9328
#
# index                      Universal Quality Index  Deep Search with Annoy  \
# dataset
# indelible                                  21.2013                 13.5759
# orthologs_hemoglobin_beta                   0.2275                  2.2404
# orthologs_myoglobin                         0.1829                  2.4713
# orthologs_neuroglobin                       0.7065                  3.3366
# orthologs_cytoglobin                        1.5906                  6.1292
# orthologs_androglobin                       2.6475                  6.7286
#
# index                      ...  Deep Search with Annoy  \
# dataset                    ...
# indelible                  ...                  5.1742
# orthologs_hemoglobin_beta  ...                  5.8557
# orthologs_myoglobin        ...                  5.1548
# orthologs_neuroglobin      ...                  5.7259
# orthologs_cytoglobin       ...                  9.6924
# orthologs_androglobin      ...                 11.0382
#
# index                      Structural Similarity Index Measure  gray_max  \
# dataset
# indelible                                               5.9398   14.5535
# orthologs_hemoglobin_beta                               2.4685    0.3889
# orthologs_myoglobin                                     2.7135    0.5494
# orthologs_neuroglobin                                   5.5042    1.8501
# orthologs_cytoglobin                                    9.8530    4.0279
# orthologs_androglobin                                      NaN    5.6724
#
# index                      Universal Quality Index  Deep Search with Annoy  \
# dataset
# indelible                                  11.0862                  5.7711
# orthologs_hemoglobin_beta                   0.9606                  4.0439
# orthologs_myoglobin                         1.0809                  4.7645
# orthologs_neuroglobin                       2.1755                  5.6379
# orthologs_cytoglobin                        4.1343                  8.7963
# orthologs_androglobin                       5.8893                  9.5528
#
# index                      Structural Similarity Index Measure  gray_mean  \
# dataset
# indelible                                               5.4829    19.3268
# orthologs_hemoglobin_beta                               2.2516     0.0754
# orthologs_myoglobin                                     2.4729     0.1965
# orthologs_neuroglobin                                   4.9408     1.1943
# orthologs_cytoglobin                                    9.0304     2.7103
# orthologs_androglobin                                      NaN     3.7766
#
# index                      Universal Quality Index  Deep Search with Annoy  \
# dataset
# indelible                                   9.9296                  6.5418
# orthologs_hemoglobin_beta                   0.9427                  4.0765
# orthologs_myoglobin                         1.1184                  4.5982
# orthologs_neuroglobin                       2.4028                  5.6275
# orthologs_cytoglobin                        4.5513                  8.8261
# orthologs_androglobin                       6.3139                  9.3038
#
# index                      Structural Similarity Index Measure
# dataset
# indelible                                               4.9414
# orthologs_hemoglobin_beta                               1.8407
# orthologs_myoglobin                                     2.1081
# orthologs_neuroglobin                                   4.4653
# orthologs_cytoglobin                                    8.0407
# orthologs_androglobin                                      NaN
#
# [6 rows x 51 columns]

# %%
channels = ("full", "red", "green", "blue")
datasets = ["indelible", "orthologs_hemoglobin_beta", "orthologs_myoglobin", "orthologs_neuroglobin", "orthologs_cytoglobin", "orthologs_androglobin"]
sum_dfs = []
for channel in channels:
    dfs = []
    for dataset in datasets:
        dfs.append(read_and_compare(dataset, channel))
    sum_dfs.append(pandas.concat(dfs))
pandas.concat(sum_dfs, axis=1).T.reset_index().drop_duplicates().set_index("index").T
# Out:
# index                         full  Universal Quality Index  \
# dataset
# indelible                  19.4880                   4.9357
# orthologs_hemoglobin_beta   0.1542                   1.7944
# orthologs_myoglobin         0.0954                   1.9198
# orthologs_neuroglobin       1.2176                   4.3852
# orthologs_cytoglobin        2.7743                   8.2561
# orthologs_androglobin       4.0221                  10.0408
#
# index                      Global with Needleman-Wunsch  \
# dataset
# indelible                                       10.4094
# orthologs_hemoglobin_beta                        0.9085
# orthologs_myoglobin                              0.9196
# orthologs_neuroglobin                            1.8043
# orthologs_cytoglobin                             6.3417
# orthologs_androglobin                            8.2855
#
# index                      Deep Search with Annoy  \
# dataset
# indelible                                  6.3518
# orthologs_hemoglobin_beta                  3.4018
# orthologs_myoglobin                        3.4647
# orthologs_neuroglobin                      4.9502
# orthologs_cytoglobin                       8.3726
# orthologs_androglobin                      8.6007
#
# index                      Structural Similarity Index Measure  \
# dataset
# indelible                                               4.8671
# orthologs_hemoglobin_beta                               1.6405
# orthologs_myoglobin                                     1.7845
# orthologs_neuroglobin                                   4.3484
# orthologs_cytoglobin                                    8.0178
# orthologs_androglobin                                   9.7640
#
# index                      Control with Clustal Omega  \
# dataset
# indelible                                         0.0
# orthologs_hemoglobin_beta                         0.0
# orthologs_myoglobin                               0.0
# orthologs_neuroglobin                             0.0
# orthologs_cytoglobin                              0.0
# orthologs_androglobin                             0.0
#
# index                      Local with Smith–Waterman      red  \
# dataset
# indelible                                     8.7200  30.0765
# orthologs_hemoglobin_beta                     0.8937   0.9769
# orthologs_myoglobin                           0.9044   0.9702
# orthologs_neuroglobin                         1.1514   1.3372
# orthologs_cytoglobin                          3.1095   2.4480
# orthologs_androglobin                         2.9601   0.9328
#
# index                      Universal Quality Index  Deep Search with Annoy  \
# dataset
# indelible                                  21.2013                 13.5759
# orthologs_hemoglobin_beta                   0.2275                  2.2404
# orthologs_myoglobin                         0.1829                  2.4713
# orthologs_neuroglobin                       0.7065                  3.3366
# orthologs_cytoglobin                        1.5906                  6.1292
# orthologs_androglobin                       2.6475                  6.7286
#
# index                      Structural Similarity Index Measure    green  \
# dataset
# indelible                                              21.2583  27.7266
# orthologs_hemoglobin_beta                               0.1363   0.7896
# orthologs_myoglobin                                     0.1045   0.7975
# orthologs_neuroglobin                                   0.8911   0.9323
# orthologs_cytoglobin                                    1.8680   1.7804
# orthologs_androglobin                                      NaN   1.0347
#
# index                      Universal Quality Index  Deep Search with Annoy  \
# dataset
# indelible                                  21.1520                  5.3203
# orthologs_hemoglobin_beta                   0.1463                  3.0701
# orthologs_myoglobin                         0.1380                  2.5298
# orthologs_neuroglobin                       0.7349                  3.5526
# orthologs_cytoglobin                        1.6181                  6.5167
# orthologs_androglobin                       2.6778                 11.8461
#
# index                      Structural Similarity Index Measure     blue  \
# dataset
# indelible                                              21.8397  27.7222
# orthologs_hemoglobin_beta                               0.1990   0.8000
# orthologs_myoglobin                                     0.1797   0.7811
# orthologs_neuroglobin                                   0.7320   0.9554
# orthologs_cytoglobin                                    1.5885   1.7816
# orthologs_androglobin                                   5.6120   1.0623
#
# index                      Universal Quality Index  Deep Search with Annoy  \
# dataset
# indelible                                  21.1548                  6.2651
# orthologs_hemoglobin_beta                   0.1691                  3.8291
# orthologs_myoglobin                         0.1259                  3.0248
# orthologs_neuroglobin                       0.7217                  3.7993
# orthologs_cytoglobin                        1.6206                  7.5317
# orthologs_androglobin                       2.6542                 11.0361
#
# index                      Structural Similarity Index Measure
# dataset
# indelible                                              21.8372
# orthologs_hemoglobin_beta                               0.2245
# orthologs_myoglobin                                     0.1721
# orthologs_neuroglobin                                   0.7021
# orthologs_cytoglobin                                    1.5757
# orthologs_androglobin                                   5.6163

# %%
channels = ("full", "gray_r", "gray_g", "gray_b", "gray_max", "gray_mean")
datasets = ["indelible", "orthologs_hemoglobin_beta", "orthologs_myoglobin", "orthologs_neuroglobin", "orthologs_cytoglobin", "orthologs_androglobin"]
sum_dfs = []
for channel in channels:
    dfs = []
    for dataset in datasets:
        dfs.append(read_and_compare(dataset, channel))
    sum_dfs.append(pandas.concat(dfs))
pandas.concat(sum_dfs, axis=1).T.reset_index().drop_duplicates().set_index("index").T
# Out:
# index                         full  Universal Quality Index  \
# dataset
# indelible                  19.4880                   4.9357
# orthologs_hemoglobin_beta   0.1542                   1.7944
# orthologs_myoglobin         0.0954                   1.9198
# orthologs_neuroglobin       1.2176                   4.3852
# orthologs_cytoglobin        2.7743                   8.2561
# orthologs_androglobin       4.0221                  10.0408
#
# index                      Global with Needleman-Wunsch  \
# dataset
# indelible                                       10.4094
# orthologs_hemoglobin_beta                        0.9085
# orthologs_myoglobin                              0.9196
# orthologs_neuroglobin                            1.8043
# orthologs_cytoglobin                             6.3417
# orthologs_androglobin                            8.2855
#
# index                      Deep Search with Annoy  \
# dataset
# indelible                                  6.3518
# orthologs_hemoglobin_beta                  3.4018
# orthologs_myoglobin                        3.4647
# orthologs_neuroglobin                      4.9502
# orthologs_cytoglobin                       8.3726
# orthologs_androglobin                      8.6007
#
# index                      Structural Similarity Index Measure  \
# dataset
# indelible                                               4.8671
# orthologs_hemoglobin_beta                               1.6405
# orthologs_myoglobin                                     1.7845
# orthologs_neuroglobin                                   4.3484
# orthologs_cytoglobin                                    8.0178
# orthologs_androglobin                                   9.7640
#
# index                      Control with Clustal Omega  \
# dataset
# indelible                                         0.0
# orthologs_hemoglobin_beta                         0.0
# orthologs_myoglobin                               0.0
# orthologs_neuroglobin                             0.0
# orthologs_cytoglobin                              0.0
# orthologs_androglobin                             0.0
#
# index                      Local with Smith–Waterman   gray_r  \
# dataset
# indelible                                     8.7200  19.5789
# orthologs_hemoglobin_beta                     0.8937   0.2307
# orthologs_myoglobin                           0.9044   0.1200
# orthologs_neuroglobin                         1.1514   1.1599
# orthologs_cytoglobin                          3.1095   2.7064
# orthologs_androglobin                         2.9601   4.0998
#
# index                      Universal Quality Index  Deep Search with Annoy  \
# dataset
# indelible                                   4.9113                  8.1126
# orthologs_hemoglobin_beta                   1.6217                  4.1546
# orthologs_myoglobin                         1.7881                  3.6828
# orthologs_neuroglobin                       4.2828                  4.6459
# orthologs_cytoglobin                        8.1209                  8.3101
# orthologs_androglobin                      10.0046                  9.7836
#
# index                      ...  Deep Search with Annoy  \
# dataset                    ...
# indelible                  ...                  5.1742
# orthologs_hemoglobin_beta  ...                  5.8557
# orthologs_myoglobin        ...                  5.1548
# orthologs_neuroglobin      ...                  5.7259
# orthologs_cytoglobin       ...                  9.6924
# orthologs_androglobin      ...                 11.0382
#
# index                      Structural Similarity Index Measure  gray_max  \
# dataset
# indelible                                               5.9398   14.5535
# orthologs_hemoglobin_beta                               2.4685    0.3889
# orthologs_myoglobin                                     2.7135    0.5494
# orthologs_neuroglobin                                   5.5042    1.8501
# orthologs_cytoglobin                                    9.8530    4.0279
# orthologs_androglobin                                      NaN    5.6724
#
# index                      Universal Quality Index  Deep Search with Annoy  \
# dataset
# indelible                                  11.0862                  5.7711
# orthologs_hemoglobin_beta                   0.9606                  4.0439
# orthologs_myoglobin                         1.0809                  4.7645
# orthologs_neuroglobin                       2.1755                  5.6379
# orthologs_cytoglobin                        4.1343                  8.7963
# orthologs_androglobin                       5.8893                  9.5528
#
# index                      Structural Similarity Index Measure  gray_mean  \
# dataset
# indelible                                               5.4829    19.3268
# orthologs_hemoglobin_beta                               2.2516     0.0754
# orthologs_myoglobin                                     2.4729     0.1965
# orthologs_neuroglobin                                   4.9408     1.1943
# orthologs_cytoglobin                                    9.0304     2.7103
# orthologs_androglobin                                      NaN     3.7766
#
# index                      Universal Quality Index  Deep Search with Annoy  \
# dataset
# indelible                                   9.9296                  6.5418
# orthologs_hemoglobin_beta                   0.9427                  4.0765
# orthologs_myoglobin                         1.1184                  4.5982
# orthologs_neuroglobin                       2.4028                  5.6275
# orthologs_cytoglobin                        4.5513                  8.8261
# orthologs_androglobin                       6.3139                  9.3038
#
# index                      Structural Similarity Index Measure
# dataset
# indelible                                               4.9414
# orthologs_hemoglobin_beta                               1.8407
# orthologs_myoglobin                                     2.1081
# orthologs_neuroglobin                                   4.4653
# orthologs_cytoglobin                                    8.0407
# orthologs_androglobin                                      NaN
#
# [6 rows x 27 columns]

# %%
channels = ("full", "red_green", "red_blue", "green_blue")
datasets = ["indelible", "orthologs_hemoglobin_beta", "orthologs_myoglobin", "orthologs_neuroglobin", "orthologs_cytoglobin", "orthologs_androglobin"]
sum_dfs = []
for channel in channels:
    dfs = []
    for dataset in datasets:
        dfs.append(read_and_compare(dataset, channel))
    sum_dfs.append(pandas.concat(dfs))
pandas.concat(sum_dfs, axis=1).T.reset_index().drop_duplicates().set_index("index").T
# Out:
# index                         full  Universal Quality Index  \
# dataset
# indelible                  19.4880                   4.9357
# orthologs_hemoglobin_beta   0.1542                   1.7944
# orthologs_myoglobin         0.0954                   1.9198
# orthologs_neuroglobin       1.2176                   4.3852
# orthologs_cytoglobin        2.7743                   8.2561
# orthologs_androglobin       4.0221                  10.0408
#
# index                      Global with Needleman-Wunsch  \
# dataset
# indelible                                       10.4094
# orthologs_hemoglobin_beta                        0.9085
# orthologs_myoglobin                              0.9196
# orthologs_neuroglobin                            1.8043
# orthologs_cytoglobin                             6.3417
# orthologs_androglobin                            8.2855
#
# index                      Deep Search with Annoy  \
# dataset
# indelible                                  6.3518
# orthologs_hemoglobin_beta                  3.4018
# orthologs_myoglobin                        3.4647
# orthologs_neuroglobin                      4.9502
# orthologs_cytoglobin                       8.3726
# orthologs_androglobin                      8.6007
#
# index                      Structural Similarity Index Measure  \
# dataset
# indelible                                               4.8671
# orthologs_hemoglobin_beta                               1.6405
# orthologs_myoglobin                                     1.7845
# orthologs_neuroglobin                                   4.3484
# orthologs_cytoglobin                                    8.0178
# orthologs_androglobin                                   9.7640
#
# index                      Control with Clustal Omega  \
# dataset
# indelible                                         0.0
# orthologs_hemoglobin_beta                         0.0
# orthologs_myoglobin                               0.0
# orthologs_neuroglobin                             0.0
# orthologs_cytoglobin                              0.0
# orthologs_androglobin                             0.0
#
# index                      Local with Smith–Waterman  red_green  \
# dataset
# indelible                                     8.7200    23.6159
# orthologs_hemoglobin_beta                     0.8937     0.4849
# orthologs_myoglobin                           0.9044     0.4510
# orthologs_neuroglobin                         1.1514     0.6618
# orthologs_cytoglobin                          3.1095     1.5191
# orthologs_androglobin                         2.9601     2.4228
#
# index                      Universal Quality Index  Deep Search with Annoy  \
# dataset
# indelible                                  10.8325                  6.4986
# orthologs_hemoglobin_beta                   0.8008                  3.3919
# orthologs_myoglobin                         0.8755                  3.3211
# orthologs_neuroglobin                       2.4277                  4.3246
# orthologs_cytoglobin                        4.6484                  7.6154
# orthologs_androglobin                       6.3221                  9.5862
#
# index                      Structural Similarity Index Measure  red_blue  \
# dataset
# indelible                                              12.1031   23.6115
# orthologs_hemoglobin_beta                               0.7123    0.4957
# orthologs_myoglobin                                     0.7957    0.4347
# orthologs_neuroglobin                                   2.4301    0.6385
# orthologs_cytoglobin                                    4.5236    1.5174
# orthologs_androglobin                                   7.6809    2.4578
#
# index                      Universal Quality Index  Deep Search with Annoy  \
# dataset
# indelible                                  10.8349                  8.0268
# orthologs_hemoglobin_beta                   0.7808                  3.6864
# orthologs_myoglobin                         0.8781                  3.6256
# orthologs_neuroglobin                       2.4158                  4.5724
# orthologs_cytoglobin                        4.6571                  8.1302
# orthologs_androglobin                       6.2980                  8.8234
#
# index                      Structural Similarity Index Measure  green_blue  \
# dataset
# indelible                                              12.1008     23.5676
# orthologs_hemoglobin_beta                               0.6902      0.4511
# orthologs_myoglobin                                     0.7965      0.4279
# orthologs_neuroglobin                                   2.3888      0.6520
# orthologs_cytoglobin                                    4.4990      1.5304
# orthologs_androglobin                                   7.6852      2.4023
#
# index                      Universal Quality Index  Deep Search with Annoy  \
# dataset
# indelible                                  10.7897                  5.2276
# orthologs_hemoglobin_beta                   0.8787                  3.2673
# orthologs_myoglobin                         0.9431                  2.8999
# orthologs_neuroglobin                       2.4714                  4.4973
# orthologs_cytoglobin                        4.7180                  7.9015
# orthologs_androglobin                       6.3283                 10.3151
#
# index                      Structural Similarity Index Measure
# dataset
# indelible                                              12.0657
# orthologs_hemoglobin_beta                               0.7499
# orthologs_myoglobin                                     0.8332
# orthologs_neuroglobin                                   2.4261
# orthologs_cytoglobin                                    4.5461
# orthologs_androglobin                                   7.6536

# %%
def read_and_linear_correlate(dataset, channel="full"):
    result_dict = {}
    path = f"{tree_path}/{channel}/{dataset}"
    control_df = pandas.read_csv(f"{path}/Control with Clustal Omega.csv", index_col=0)
    for file in os.listdir(path):
        if file.endswith(".csv"):
            basename = ".".join(file.split(".")[0:-1])
            df = pandas.read_csv(f"{path}/{file}", index_col=0)
            result_dict[basename] = round(spearmanr(control_df.values.flatten(), df.values.flatten())[0], 4)
    result_df = pandas.DataFrame(result_dict, index=[dataset])
    result_df.rename(columns={"MultiScale Structural Similarity Index Measure": channel}, inplace=True)
    result_df.index.name = "dataset"
    return result_df

# %% [markdown]
# ## Linear Correlation from distance matrices

# %%
channels = ("full", "red", "green", "blue", "red_green", "red_blue", "green_blue", "gray_r", "gray_g", "gray_b", "gray_max", "gray_mean")
datasets = ["indelible", "orthologs_hemoglobin_beta", "orthologs_myoglobin", "orthologs_neuroglobin", "orthologs_cytoglobin", "orthologs_androglobin"]
sum_dfs = []
for channel in channels:
    dfs = []
    for dataset in datasets:
        dfs.append(read_and_linear_correlate(dataset, channel))
    sum_dfs.append(pandas.concat(dfs))
pandas.concat(sum_dfs, axis=1).T.reset_index().drop_duplicates().set_index("index").T
# Out:
# index                        full  Universal Quality Index  \
# dataset
# indelible                  0.1616                   0.2561
# orthologs_hemoglobin_beta  0.9965                   0.9982
# orthologs_myoglobin        0.9918                   0.9973
# orthologs_neuroglobin      0.9861                   0.9904
# orthologs_cytoglobin       0.3888                   0.5210
# orthologs_androglobin      0.5718                   0.6514
#
# index                      Global with Needleman-Wunsch  \
# dataset
# indelible                                        0.2541
# orthologs_hemoglobin_beta                        0.9999
# orthologs_myoglobin                              0.9999
# orthologs_neuroglobin                            0.9999
# orthologs_cytoglobin                             0.7775
# orthologs_androglobin                            0.9054
#
# index                      Deep Search with Annoy  \
# dataset
# indelible                                  0.1143
# orthologs_hemoglobin_beta                  0.2451
# orthologs_myoglobin                        0.2297
# orthologs_neuroglobin                      0.1462
# orthologs_cytoglobin                       0.2531
# orthologs_androglobin                      0.2036
#
# index                      Structural Similarity Index Measure  \
# dataset
# indelible                                               0.1957
# orthologs_hemoglobin_beta                               0.9975
# orthologs_myoglobin                                     0.9969
# orthologs_neuroglobin                                   0.9888
# orthologs_cytoglobin                                    0.4716
# orthologs_androglobin                                   0.4814
#
# index                      Control with Clustal Omega  \
# dataset
# indelible                                         1.0
# orthologs_hemoglobin_beta                         1.0
# orthologs_myoglobin                               1.0
# orthologs_neuroglobin                             1.0
# orthologs_cytoglobin                              1.0
# orthologs_androglobin                             1.0
#
# index                      Local with Smith–Waterman     red  \
# dataset
# indelible                                     0.3428  0.1623
# orthologs_hemoglobin_beta                     0.9998  0.9904
# orthologs_myoglobin                           0.9998  0.9915
# orthologs_neuroglobin                         0.9992  0.9827
# orthologs_cytoglobin                          0.8623  0.2930
# orthologs_androglobin                         0.9769  0.5633
#
# index                      Universal Quality Index  Deep Search with Annoy  \
# dataset
# indelible                                   0.2746                  0.0336
# orthologs_hemoglobin_beta                   0.9965                  0.1950
# orthologs_myoglobin                         0.9959                  0.2522
# orthologs_neuroglobin                       0.9883                  0.1475
# orthologs_cytoglobin                        0.4978                  0.2731
# orthologs_androglobin                       0.6551                  0.2166
#
# index                      ...  Deep Search with Annoy  \
# dataset                    ...
# indelible                  ...                  0.1790
# orthologs_hemoglobin_beta  ...                  0.2488
# orthologs_myoglobin        ...                  0.3220
# orthologs_neuroglobin      ...                  0.1171
# orthologs_cytoglobin       ...                  0.2597
# orthologs_androglobin      ...                  0.1715
#
# index                      Structural Similarity Index Measure  gray_max  \
# dataset
# indelible                                               0.2174    0.2284
# orthologs_hemoglobin_beta                               0.9821    0.9948
# orthologs_myoglobin                                     0.9688    0.9952
# orthologs_neuroglobin                                   0.9927    0.9852
# orthologs_cytoglobin                                    0.4625    0.4360
# orthologs_androglobin                                      NaN    0.6329
#
# index                      Universal Quality Index  Deep Search with Annoy  \
# dataset
# indelible                                   0.3654                  0.1092
# orthologs_hemoglobin_beta                   0.9970                  0.2774
# orthologs_myoglobin                         0.9977                  0.2875
# orthologs_neuroglobin                       0.9804                  0.1388
# orthologs_cytoglobin                        0.6277                  0.2534
# orthologs_androglobin                       0.7081                  0.2196
#
# index                      Structural Similarity Index Measure  gray_mean  \
# dataset
# indelible                                               0.2483     0.2238
# orthologs_hemoglobin_beta                               0.9968     0.9962
# orthologs_myoglobin                                     0.9981     0.9930
# orthologs_neuroglobin                                   0.9796     0.9917
# orthologs_cytoglobin                                    0.3650     0.4386
# orthologs_androglobin                                      NaN     0.3940
#
# index                      Universal Quality Index  Deep Search with Annoy  \
# dataset
# indelible                                   0.2992                  0.1210
# orthologs_hemoglobin_beta                   0.9966                  0.2594
# orthologs_myoglobin                         0.9891                  0.2833
# orthologs_neuroglobin                       0.9777                  0.1488
# orthologs_cytoglobin                        0.6606                  0.2703
# orthologs_androglobin                       0.7357                  0.1967
#
# index                      Structural Similarity Index Measure
# dataset
# indelible                                               0.2817
# orthologs_hemoglobin_beta                               0.9976
# orthologs_myoglobin                                     0.9967
# orthologs_neuroglobin                                   0.9943
# orthologs_cytoglobin                                    0.3971
# orthologs_androglobin                                      NaN
#
# [6 rows x 51 columns]

# %%
def read_and_correlate(dataset, channel="full"):
    result_dict = {}
    path = f"{tree_path}/{channel}/{dataset}"
    control_df = pandas.read_csv(f"{path}/Control with Clustal Omega.csv", index_col=0)
    for file in os.listdir(path):
        if file.endswith(".csv"):
            basename = ".".join(file.split(".")[0:-1])
            df = pandas.read_csv(f"{path}/{file}", index_col=0)
            result_dict[basename] = round(ppscore.score(
                pandas.DataFrame({"x": control_df.values.flatten(), "y": df.values.flatten()}), "x", "y")["ppscore"], 4)
    result_df = pandas.DataFrame(result_dict, index=[dataset])
    result_df.rename(columns={"MultiScale Structural Similarity Index Measure": channel}, inplace=True)
    result_df.index.name = "dataset"
    return result_df

# %% [markdown]
# ## Predictive Power Score from distance matrices

# %%
channels = ("full", "red", "green", "blue", "red_green", "red_blue", "green_blue", "gray_r", "gray_g", "gray_b", "gray_max", "gray_mean")
datasets = ["indelible", "orthologs_hemoglobin_beta", "orthologs_myoglobin", "orthologs_neuroglobin", "orthologs_cytoglobin", "orthologs_androglobin"]
sum_dfs = []
for channel in channels:
    dfs = []
    for dataset in datasets:
        dfs.append(read_and_correlate(dataset, channel))
    sum_dfs.append(pandas.concat(dfs))
pandas.concat(sum_dfs, axis=1).T.reset_index().drop_duplicates().set_index("index").T
# Out:
# index                        full  Universal Quality Index  \
# dataset
# indelible                  0.8666                   0.9809
# orthologs_hemoglobin_beta  0.9658                   0.9798
# orthologs_myoglobin        0.9471                   0.9697
# orthologs_neuroglobin      0.9584                   0.9673
# orthologs_cytoglobin       0.7789                   0.7964
# orthologs_androglobin      0.8638                   0.8654
#
# index                      Global with Needleman-Wunsch  \
# dataset
# indelible                                        0.9039
# orthologs_hemoglobin_beta                        0.9953
# orthologs_myoglobin                              0.9954
# orthologs_neuroglobin                            0.9876
# orthologs_cytoglobin                             0.8524
# orthologs_androglobin                            0.9773
#
# index                      Deep Search with Annoy  \
# dataset
# indelible                                  0.5474
# orthologs_hemoglobin_beta                  0.4035
# orthologs_myoglobin                        0.2873
# orthologs_neuroglobin                      0.3161
# orthologs_cytoglobin                       0.6691
# orthologs_androglobin                      0.5908
#
# index                      Structural Similarity Index Measure  \
# dataset
# indelible                                               0.9868
# orthologs_hemoglobin_beta                               0.9776
# orthologs_myoglobin                                     0.9689
# orthologs_neuroglobin                                   0.9659
# orthologs_cytoglobin                                    0.7943
# orthologs_androglobin                                   0.7885
#
# index                      Control with Clustal Omega  \
# dataset
# indelible                                      0.9998
# orthologs_hemoglobin_beta                      0.9968
# orthologs_myoglobin                            0.9968
# orthologs_neuroglobin                          0.9964
# orthologs_cytoglobin                           0.9913
# orthologs_androglobin                          0.9977
#
# index                      Local with Smith–Waterman     red  \
# dataset
# indelible                                     0.9779  0.8203
# orthologs_hemoglobin_beta                     0.9944  0.9491
# orthologs_myoglobin                           0.9925  0.9457
# orthologs_neuroglobin                         0.9897  0.9562
# orthologs_cytoglobin                          0.8584  0.7765
# orthologs_androglobin                         0.9799  0.8775
#
# index                      Universal Quality Index  Deep Search with Annoy  \
# dataset
# indelible                                   0.9783                  0.5491
# orthologs_hemoglobin_beta                   0.9693                  0.3950
# orthologs_myoglobin                         0.9651                  0.2766
# orthologs_neuroglobin                       0.9636                  0.2980
# orthologs_cytoglobin                        0.7940                  0.6707
# orthologs_androglobin                       0.8650                  0.5741
#
# index                      ...  Deep Search with Annoy  \
# dataset                    ...
# indelible                  ...                  0.5670
# orthologs_hemoglobin_beta  ...                  0.2939
# orthologs_myoglobin        ...                  0.3381
# orthologs_neuroglobin      ...                  0.3245
# orthologs_cytoglobin       ...                  0.7007
# orthologs_androglobin      ...                  0.6273
#
# index                      Structural Similarity Index Measure  gray_max  \
# dataset
# indelible                                               0.6654    0.8543
# orthologs_hemoglobin_beta                               0.9150    0.9586
# orthologs_myoglobin                                     0.8541    0.9548
# orthologs_neuroglobin                                   0.9616    0.9555
# orthologs_cytoglobin                                    0.8000    0.7697
# orthologs_androglobin                                      NaN    0.8729
#
# index                      Universal Quality Index  Deep Search with Annoy  \
# dataset
# indelible                                   0.9692                  0.5288
# orthologs_hemoglobin_beta                   0.9713                  0.4367
# orthologs_myoglobin                         0.9742                  0.2751
# orthologs_neuroglobin                       0.9661                  0.3295
# orthologs_cytoglobin                        0.8007                  0.6833
# orthologs_androglobin                       0.8700                  0.5983
#
# index                      Structural Similarity Index Measure  gray_mean  \
# dataset
# indelible                                               0.9852     0.5002
# orthologs_hemoglobin_beta                               0.9706     0.9672
# orthologs_myoglobin                                     0.9722     0.9363
# orthologs_neuroglobin                                   0.9668     0.9599
# orthologs_cytoglobin                                    0.7992     0.7621
# orthologs_androglobin                                      NaN     0.8746
#
# index                      Universal Quality Index  Deep Search with Annoy  \
# dataset
# indelible                                   0.8278                  0.5134
# orthologs_hemoglobin_beta                   0.9646                  0.4078
# orthologs_myoglobin                         0.9312                  0.2911
# orthologs_neuroglobin                       0.9654                  0.3321
# orthologs_cytoglobin                        0.7992                  0.6882
# orthologs_androglobin                       0.8663                  0.6001
#
# index                      Structural Similarity Index Measure
# dataset
# indelible                                               0.7179
# orthologs_hemoglobin_beta                               0.9741
# orthologs_myoglobin                                     0.9563
# orthologs_neuroglobin                                   0.9681
# orthologs_cytoglobin                                    0.7945
# orthologs_androglobin                                      NaN
#
# [6 rows x 50 columns]

# %%
def read_and_tree_compare(dataset, channel="full"):
    result_dict = {}
    path = f"{tree_path}/{channel}/{dataset}"
    control_tree = Tree(f"{path}/Control with Clustal Omega.nw", format=1)
    for file in os.listdir(path):
        if file.endswith(".nw"):
            basename = ".".join(file.split(".")[0:-1])
            tree = Tree(f"{path}/{file}", format=1)
            result = control_tree.compare(tree, unrooted=True)
            result_dict[basename] = round(result["norm_rf"], 4)
    result_df = pandas.DataFrame(result_dict, index=[dataset])
    result_df.rename(columns={"MultiScale Structural Similarity Index Measure": channel}, inplace=True)
    result_df.index.name = "dataset"
    return result_df

# %% [markdown]
# ## Robinson-foulds distance from generated Trees

# %%
channels = ("full", "red", "green", "blue", "red_green", "red_blue", "green_blue", "gray_r", "gray_g", "gray_b", "gray_max", "gray_mean")
datasets = ["indelible", "orthologs_hemoglobin_beta", "orthologs_myoglobin", "orthologs_neuroglobin", "orthologs_cytoglobin", "orthologs_androglobin"]
sum_dfs = []
for channel in channels:
    dfs = []
    for dataset in datasets:
        dfs.append(read_and_tree_compare(dataset, channel))
    sum_dfs.append(pandas.concat(dfs))
pandas.concat(sum_dfs, axis=1).T.reset_index().drop_duplicates().set_index("index").T
# Out:
# index                      Global with Needleman-Wunsch  \
# dataset
# indelible                                        0.1622
# orthologs_hemoglobin_beta                        0.0000
# orthologs_myoglobin                              0.0000
# orthologs_neuroglobin                            0.0000
# orthologs_cytoglobin                             0.6667
# orthologs_androglobin                            0.8333
#
# index                      Local with Smith–Waterman  Deep Search with Annoy  \
# dataset
# indelible                                     0.1622                  1.0000
# orthologs_hemoglobin_beta                     0.0000                  1.0000
# orthologs_myoglobin                           0.0000                  0.9167
# orthologs_neuroglobin                         0.0000                  1.0000
# orthologs_cytoglobin                          0.5000                  1.0000
# orthologs_androglobin                         0.5000                  1.0000
#
# index                      Structural Similarity Index Measure    full  \
# dataset
# indelible                                               0.1892  0.1892
# orthologs_hemoglobin_beta                               0.0000  0.0000
# orthologs_myoglobin                                     0.0833  0.0000
# orthologs_neuroglobin                                   0.0833  0.1667
# orthologs_cytoglobin                                    0.9167  0.9167
# orthologs_androglobin                                   1.0000  0.9167
#
# index                      Control with Clustal Omega  \
# dataset
# indelible                                         0.0
# orthologs_hemoglobin_beta                         0.0
# orthologs_myoglobin                               0.0
# orthologs_neuroglobin                             0.0
# orthologs_cytoglobin                              0.0
# orthologs_androglobin                             0.0
#
# index                      Universal Quality Index  Deep Search with Annoy  \
# dataset
# indelible                                   0.1892                     1.0
# orthologs_hemoglobin_beta                   0.0000                     1.0
# orthologs_myoglobin                         0.0833                     1.0
# orthologs_neuroglobin                       0.0833                     1.0
# orthologs_cytoglobin                        0.9167                     1.0
# orthologs_androglobin                       0.9167                     1.0
#
# index                      Structural Similarity Index Measure     red  ...  \
# dataset                                                                 ...
# indelible                                               0.1892  0.1892  ...
# orthologs_hemoglobin_beta                               0.0833  0.0833  ...
# orthologs_myoglobin                                     0.0833  0.0833  ...
# orthologs_neuroglobin                                   0.1667  0.1667  ...
# orthologs_cytoglobin                                    0.9167  0.9167  ...
# orthologs_androglobin                                      NaN  0.9167  ...
#
# index                      gray_g  Universal Quality Index  \
# dataset
# indelible                  0.1892                   0.1892
# orthologs_hemoglobin_beta  0.0000                   0.0000
# orthologs_myoglobin        0.2500                   0.2500
# orthologs_neuroglobin      0.2500                   0.0833
# orthologs_cytoglobin       0.9167                   0.9167
# orthologs_androglobin      0.9167                   0.9167
#
# index                      Deep Search with Annoy  \
# dataset
# indelible                                  0.9730
# orthologs_hemoglobin_beta                  1.0000
# orthologs_myoglobin                        0.8333
# orthologs_neuroglobin                      1.0000
# orthologs_cytoglobin                       1.0000
# orthologs_androglobin                      1.0000
#
# index                      Structural Similarity Index Measure  gray_b  \
# dataset
# indelible                                               0.1892  0.1892
# orthologs_hemoglobin_beta                               0.1667  0.0833
# orthologs_myoglobin                                     0.1667  0.0833
# orthologs_neuroglobin                                   0.0833  0.1667
# orthologs_cytoglobin                                    0.9167  0.9167
# orthologs_androglobin                                      NaN  0.9167
#
# index                      Universal Quality Index  \
# dataset
# indelible                                   0.1892
# orthologs_hemoglobin_beta                   0.1667
# orthologs_myoglobin                         0.1667
# orthologs_neuroglobin                       0.0833
# orthologs_cytoglobin                        0.9167
# orthologs_androglobin                       0.9167
#
# index                      Structural Similarity Index Measure  gray_max  \
# dataset
# indelible                                               0.1622    0.1892
# orthologs_hemoglobin_beta                               0.0000    0.0000
# orthologs_myoglobin                                     0.0833    0.0833
# orthologs_neuroglobin                                   0.0833    0.1667
# orthologs_cytoglobin                                    0.9167    0.9167
# orthologs_androglobin                                      NaN    0.9167
#
# index                      Structural Similarity Index Measure  gray_mean
# dataset
# indelible                                               0.1892     0.1892
# orthologs_hemoglobin_beta                               0.0000     0.0833
# orthologs_myoglobin                                     0.0833     0.0833
# orthologs_neuroglobin                                   0.0833     0.1667
# orthologs_cytoglobin                                    0.9167     0.9167
# orthologs_androglobin                                      NaN     0.9167
#
# [6 rows x 37 columns]

# %%
def read_and_tree_compare_branches(dataset, channel="full"):
    result_dict = {}
    path = f"{tree_path}/{channel}/{dataset}"
    control_tree = Tree(f"{path}/Control with Clustal Omega.nw", format=1)
    for file in os.listdir(path):
        if file.endswith(".nw"):
            basename = ".".join(file.split(".")[0:-1])
            tree = Tree(f"{path}/{file}", format=1)
            result = control_tree.compare(tree, unrooted=True)
            result_dict[basename] = 1.0 - round(result["source_edges_in_ref"], 4)
    result_df = pandas.DataFrame(result_dict, index=[dataset])
    result_df.rename(columns={"MultiScale Structural Similarity Index Measure": channel}, inplace=True)
    result_df.index.name = "dataset"
    return result_df

# %% [markdown]
# ## Compatibility branch score from generated Trees

# %%
channels = ("full",)#, "red", "green", "blue", "red_green", "red_blue", "green_blue", "gray_r", "gray_g", "gray_b", "gray_max", "gray_mean")
datasets = ["indelible", "orthologs_hemoglobin_beta", "orthologs_myoglobin", "orthologs_neuroglobin", "orthologs_cytoglobin", "orthologs_androglobin"]
sum_dfs = []
for channel in channels:
    dfs = []
    for dataset in datasets:
        dfs.append(read_and_tree_compare_branches(dataset, channel))
    sum_dfs.append(pandas.concat(dfs))
pandas.concat(sum_dfs, axis=1).T.reset_index().drop_duplicates().set_index("index").T
# Out:
# index                      Global with Needleman-Wunsch  \
# dataset
# indelible                                        0.0789
# orthologs_hemoglobin_beta                        0.0000
# orthologs_myoglobin                              0.0000
# orthologs_neuroglobin                            0.0000
# orthologs_cytoglobin                             0.3077
# orthologs_androglobin                            0.3846
#
# index                      Local with Smith–Waterman  Deep Search with Annoy  \
# dataset
# indelible                                     0.0789                  0.4868
# orthologs_hemoglobin_beta                     0.0000                  0.4615
# orthologs_myoglobin                           0.0000                  0.4231
# orthologs_neuroglobin                         0.0000                  0.4615
# orthologs_cytoglobin                          0.2308                  0.4615
# orthologs_androglobin                         0.2308                  0.4615
#
# index                      Structural Similarity Index Measure    full  \
# dataset
# indelible                                               0.0921  0.0921
# orthologs_hemoglobin_beta                               0.0000  0.0000
# orthologs_myoglobin                                     0.0385  0.0000
# orthologs_neuroglobin                                   0.0385  0.0769
# orthologs_cytoglobin                                    0.4231  0.4231
# orthologs_androglobin                                   0.4615  0.4231
#
# index                      Control with Clustal Omega  Universal Quality Index
# dataset
# indelible                                         0.0                   0.0921
# orthologs_hemoglobin_beta                         0.0                   0.0000
# orthologs_myoglobin                               0.0                   0.0385
# orthologs_neuroglobin                             0.0                   0.0385
# orthologs_cytoglobin                              0.0                   0.4231
# orthologs_androglobin                             0.0                   0.4231

# %%
def read_and_compare_channels(dataset):
    result_dict = {}
    dfs = {}
    channels = ("full", "red", "green", "blue", "red_green", "red_blue", "green_blue", "gray_r", "gray_g", "gray_b", "gray_max", "gray_mean")
    for channel in channels:
        result_dict[channel] = {}
        path = f"{tree_path}/{channel}/{dataset}"
        dfs[channel] = pandas.read_csv(f"{path}/MultiScale Structural Similarity Index Measure.csv", index_col=0)
    for channel in channels:
        control_df = dfs[channel]
        for c, df in dfs.items():
            result_dict[channel][c] = round(numpy.sqrt(numpy.sum((control_df.values - df.values)**2)), 4)
    result_df = pandas.DataFrame.from_dict(result_dict, orient='index')
    result_df.index.name = "dataset"
    return result_df.style.background_gradient(axis=None, vmin=result_df.min().min(), vmax=result_df.max().max(), cmap="YlGnBu")

# %% [markdown]
# ## Features Euclidean distance from distance matrices

# %%
for dataset in datasets:
    display(HTML(f"<center><h3>{dataset}</h3></center>"))
    display(read_and_compare_channels(dataset))
# Out:
# <center><h3>indelible</h3></center>
# <style type="text/css">
# #T_eeb66_row0_col0, #T_eeb66_row1_col1, #T_eeb66_row2_col2, #T_eeb66_row2_col3, #T_eeb66_row3_col2, #T_eeb66_row3_col3, #T_eeb66_row4_col4, #T_eeb66_row4_col5, #T_eeb66_row4_col6, #T_eeb66_row5_col4, #T_eeb66_row5_col5, #T_eeb66_row5_col6, #T_eeb66_row6_col4, #T_eeb66_row6_col5, #T_eeb66_row6_col6, #T_eeb66_row7_col7, #T_eeb66_row8_col8, #T_eeb66_row9_col9, #T_eeb66_row10_col10, #T_eeb66_row11_col11 {
#   background-color: #ffffd9;
#   color: #000000;
# }
# #T_eeb66_row0_col1, #T_eeb66_row1_col0 {
#   background-color: #33a7c2;
#   color: #f1f1f1;
# }
# #T_eeb66_row0_col2, #T_eeb66_row0_col3, #T_eeb66_row2_col0, #T_eeb66_row3_col0 {
#   background-color: #65c3bf;
#   color: #000000;
# }
# #T_eeb66_row0_col4, #T_eeb66_row0_col5, #T_eeb66_row2_col6, #T_eeb66_row3_col6, #T_eeb66_row4_col0, #T_eeb66_row5_col0, #T_eeb66_row6_col2, #T_eeb66_row6_col3 {
#   background-color: #d1edb3;
#   color: #000000;
# }
# #T_eeb66_row0_col6, #T_eeb66_row2_col4, #T_eeb66_row2_col5, #T_eeb66_row3_col4, #T_eeb66_row3_col5, #T_eeb66_row4_col2, #T_eeb66_row4_col3, #T_eeb66_row5_col2, #T_eeb66_row5_col3, #T_eeb66_row6_col0 {
#   background-color: #d3eeb3;
#   color: #000000;
# }
# #T_eeb66_row0_col7, #T_eeb66_row7_col0 {
#   background-color: #feffd8;
#   color: #000000;
# }
# #T_eeb66_row0_col8, #T_eeb66_row8_col0 {
#   background-color: #57bec1;
#   color: #000000;
# }
# #T_eeb66_row0_col9, #T_eeb66_row9_col0 {
#   background-color: #7ecdbb;
#   color: #000000;
# }
# #T_eeb66_row0_col10, #T_eeb66_row10_col0 {
#   background-color: #c0e6b5;
#   color: #000000;
# }
# #T_eeb66_row0_col11, #T_eeb66_row7_col11, #T_eeb66_row11_col0, #T_eeb66_row11_col7 {
#   background-color: #fafdcf;
#   color: #000000;
# }
# #T_eeb66_row1_col2, #T_eeb66_row1_col3, #T_eeb66_row2_col1, #T_eeb66_row3_col1 {
#   background-color: #edf8b2;
#   color: #000000;
# }
# #T_eeb66_row1_col4, #T_eeb66_row1_col5, #T_eeb66_row4_col1, #T_eeb66_row5_col1 {
#   background-color: #97d6b9;
#   color: #000000;
# }
# #T_eeb66_row1_col6, #T_eeb66_row6_col1 {
#   background-color: #95d5b9;
#   color: #000000;
# }
# #T_eeb66_row1_col7, #T_eeb66_row7_col1 {
#   background-color: #34a9c3;
#   color: #f1f1f1;
# }
# #T_eeb66_row1_col8, #T_eeb66_row8_col1 {
#   background-color: #081d58;
#   color: #f1f1f1;
# }
# #T_eeb66_row1_col9, #T_eeb66_row9_col1 {
#   background-color: #1a2b7e;
#   color: #f1f1f1;
# }
# #T_eeb66_row1_col10, #T_eeb66_row10_col1 {
#   background-color: #24489d;
#   color: #f1f1f1;
# }
# #T_eeb66_row1_col11, #T_eeb66_row11_col1 {
#   background-color: #2fa4c2;
#   color: #f1f1f1;
# }
# #T_eeb66_row2_col7, #T_eeb66_row3_col7, #T_eeb66_row7_col2, #T_eeb66_row7_col3 {
#   background-color: #67c4be;
#   color: #000000;
# }
# #T_eeb66_row2_col8, #T_eeb66_row8_col2 {
#   background-color: #233390;
#   color: #f1f1f1;
# }
# #T_eeb66_row2_col9, #T_eeb66_row3_col9, #T_eeb66_row9_col2, #T_eeb66_row9_col3 {
#   background-color: #234da0;
#   color: #f1f1f1;
# }
# #T_eeb66_row2_col10, #T_eeb66_row10_col2 {
#   background-color: #2075b3;
#   color: #f1f1f1;
# }
# #T_eeb66_row2_col11, #T_eeb66_row3_col11, #T_eeb66_row11_col2, #T_eeb66_row11_col3 {
#   background-color: #5fc1c0;
#   color: #000000;
# }
# #T_eeb66_row3_col8, #T_eeb66_row8_col3 {
#   background-color: #243392;
#   color: #f1f1f1;
# }
# #T_eeb66_row3_col10, #T_eeb66_row10_col3 {
#   background-color: #2076b3;
#   color: #f1f1f1;
# }
# #T_eeb66_row4_col7, #T_eeb66_row5_col7, #T_eeb66_row6_col7, #T_eeb66_row7_col4, #T_eeb66_row7_col5, #T_eeb66_row7_col6 {
#   background-color: #d4eeb3;
#   color: #000000;
# }
# #T_eeb66_row4_col8, #T_eeb66_row5_col8, #T_eeb66_row6_col8, #T_eeb66_row8_col4, #T_eeb66_row8_col5, #T_eeb66_row8_col6 {
#   background-color: #1f80b8;
#   color: #f1f1f1;
# }
# #T_eeb66_row4_col9, #T_eeb66_row5_col9, #T_eeb66_row9_col4, #T_eeb66_row9_col5 {
#   background-color: #289cc1;
#   color: #f1f1f1;
# }
# #T_eeb66_row4_col10, #T_eeb66_row5_col10, #T_eeb66_row10_col4, #T_eeb66_row10_col5 {
#   background-color: #4cbac2;
#   color: #f1f1f1;
# }
# #T_eeb66_row4_col11, #T_eeb66_row5_col11, #T_eeb66_row6_col11, #T_eeb66_row11_col4, #T_eeb66_row11_col5, #T_eeb66_row11_col6 {
#   background-color: #cfecb3;
#   color: #000000;
# }
# #T_eeb66_row6_col9, #T_eeb66_row9_col6 {
#   background-color: #299dc1;
#   color: #f1f1f1;
# }
# #T_eeb66_row6_col10, #T_eeb66_row10_col6 {
#   background-color: #4ebbc2;
#   color: #000000;
# }
# #T_eeb66_row7_col8, #T_eeb66_row8_col7 {
#   background-color: #55bec1;
#   color: #000000;
# }
# #T_eeb66_row7_col9, #T_eeb66_row9_col7 {
#   background-color: #7cccbb;
#   color: #000000;
# }
# #T_eeb66_row7_col10, #T_eeb66_row10_col7 {
#   background-color: #bde5b5;
#   color: #000000;
# }
# #T_eeb66_row8_col9, #T_eeb66_row9_col8 {
#   background-color: #ecf7b1;
#   color: #000000;
# }
# #T_eeb66_row8_col10, #T_eeb66_row10_col8 {
#   background-color: #d7efb3;
#   color: #000000;
# }
# #T_eeb66_row8_col11, #T_eeb66_row11_col8 {
#   background-color: #5bc0c0;
#   color: #000000;
# }
# #T_eeb66_row9_col10, #T_eeb66_row10_col9 {
#   background-color: #eaf7b1;
#   color: #000000;
# }
# #T_eeb66_row9_col11, #T_eeb66_row11_col9 {
#   background-color: #85cfba;
#   color: #000000;
# }
# #T_eeb66_row10_col11, #T_eeb66_row11_col10 {
#   background-color: #c4e8b4;
#   color: #000000;
# }
# </style>
# <table id="T_eeb66">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_eeb66_level0_col0" class="col_heading level0 col0" >full</th>
#       <th id="T_eeb66_level0_col1" class="col_heading level0 col1" >red</th>
#       <th id="T_eeb66_level0_col2" class="col_heading level0 col2" >green</th>
#       <th id="T_eeb66_level0_col3" class="col_heading level0 col3" >blue</th>
#       <th id="T_eeb66_level0_col4" class="col_heading level0 col4" >red_green</th>
#       <th id="T_eeb66_level0_col5" class="col_heading level0 col5" >red_blue</th>
#       <th id="T_eeb66_level0_col6" class="col_heading level0 col6" >green_blue</th>
#       <th id="T_eeb66_level0_col7" class="col_heading level0 col7" >gray_r</th>
#       <th id="T_eeb66_level0_col8" class="col_heading level0 col8" >gray_g</th>
#       <th id="T_eeb66_level0_col9" class="col_heading level0 col9" >gray_b</th>
#       <th id="T_eeb66_level0_col10" class="col_heading level0 col10" >gray_max</th>
#       <th id="T_eeb66_level0_col11" class="col_heading level0 col11" >gray_mean</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >dataset</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#       <th class="blank col11" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_eeb66_level0_row0" class="row_heading level0 row0" >full</th>
#       <td id="T_eeb66_row0_col0" class="data row0 col0" >0.000000</td>
#       <td id="T_eeb66_row0_col1" class="data row0 col1" >10.796300</td>
#       <td id="T_eeb66_row0_col2" class="data row0 col2" >8.414700</td>
#       <td id="T_eeb66_row0_col3" class="data row0 col3" >8.410400</td>
#       <td id="T_eeb66_row0_col4" class="data row0 col4" >4.232100</td>
#       <td id="T_eeb66_row0_col5" class="data row0 col5" >4.227700</td>
#       <td id="T_eeb66_row0_col6" class="data row0 col6" >4.182700</td>
#       <td id="T_eeb66_row0_col7" class="data row0 col7" >0.095500</td>
#       <td id="T_eeb66_row0_col8" class="data row0 col8" >8.908400</td>
#       <td id="T_eeb66_row0_col9" class="data row0 col9" >7.382900</td>
#       <td id="T_eeb66_row0_col10" class="data row0 col10" >5.170800</td>
#       <td id="T_eeb66_row0_col11" class="data row0 col11" >0.643200</td>
#     </tr>
#     <tr>
#       <th id="T_eeb66_level0_row1" class="row_heading level0 row1" >red</th>
#       <td id="T_eeb66_row1_col0" class="data row1 col0" >10.796300</td>
#       <td id="T_eeb66_row1_col1" class="data row1 col1" >0.000000</td>
#       <td id="T_eeb66_row1_col2" class="data row1 col2" >2.381600</td>
#       <td id="T_eeb66_row1_col3" class="data row1 col3" >2.385900</td>
# <center><h3>orthologs_hemoglobin_beta</h3></center>
# <style type="text/css">
# #T_6ac77_row0_col0, #T_6ac77_row1_col1, #T_6ac77_row2_col2, #T_6ac77_row3_col3, #T_6ac77_row4_col4, #T_6ac77_row5_col5, #T_6ac77_row6_col6, #T_6ac77_row7_col7, #T_6ac77_row8_col8, #T_6ac77_row9_col9, #T_6ac77_row10_col10, #T_6ac77_row11_col11 {
#   background-color: #ffffd9;
#   color: #000000;
# }
# #T_6ac77_row0_col1, #T_6ac77_row1_col0, #T_6ac77_row9_col11, #T_6ac77_row11_col9 {
#   background-color: #6dc6be;
#   color: #000000;
# }
# #T_6ac77_row0_col2, #T_6ac77_row2_col0 {
#   background-color: #a0dab8;
#   color: #000000;
# }
# #T_6ac77_row0_col3, #T_6ac77_row3_col0 {
#   background-color: #9cd8b8;
#   color: #000000;
# }
# #T_6ac77_row0_col4, #T_6ac77_row2_col6, #T_6ac77_row4_col0, #T_6ac77_row6_col2 {
#   background-color: #e0f3b2;
#   color: #000000;
# }
# #T_6ac77_row0_col5, #T_6ac77_row3_col6, #T_6ac77_row5_col0, #T_6ac77_row6_col3 {
#   background-color: #dff2b2;
#   color: #000000;
# }
# #T_6ac77_row0_col6, #T_6ac77_row2_col4, #T_6ac77_row3_col5, #T_6ac77_row4_col2, #T_6ac77_row5_col3, #T_6ac77_row6_col0 {
#   background-color: #e6f5b2;
#   color: #000000;
# }
# #T_6ac77_row0_col7, #T_6ac77_row7_col0 {
#   background-color: #f9fdcc;
#   color: #000000;
# }
# #T_6ac77_row0_col8, #T_6ac77_row8_col0 {
#   background-color: #289cc1;
#   color: #f1f1f1;
# }
# #T_6ac77_row0_col9, #T_6ac77_row1_col11, #T_6ac77_row9_col0, #T_6ac77_row11_col1 {
#   background-color: #50bbc2;
#   color: #000000;
# }
# #T_6ac77_row0_col10, #T_6ac77_row10_col0 {
#   background-color: #c4e8b4;
#   color: #000000;
# }
# #T_6ac77_row0_col11, #T_6ac77_row11_col0 {
#   background-color: #f7fcc6;
#   color: #000000;
# }
# #T_6ac77_row1_col2, #T_6ac77_row2_col1 {
#   background-color: #f2fabc;
#   color: #000000;
# }
# #T_6ac77_row1_col3, #T_6ac77_row3_col1 {
#   background-color: #f3fabd;
#   color: #000000;
# }
# #T_6ac77_row1_col4, #T_6ac77_row4_col1 {
#   background-color: #c9eab4;
#   color: #000000;
# }
# #T_6ac77_row1_col5, #T_6ac77_row5_col1 {
#   background-color: #caeab4;
#   color: #000000;
# }
# #T_6ac77_row1_col6, #T_6ac77_row6_col1 {
#   background-color: #c2e7b4;
#   color: #000000;
# }
# #T_6ac77_row1_col7, #T_6ac77_row7_col1 {
#   background-color: #80cebb;
#   color: #000000;
# }
# #T_6ac77_row1_col8, #T_6ac77_row8_col1 {
#   background-color: #081d58;
#   color: #f1f1f1;
# }
# #T_6ac77_row1_col9, #T_6ac77_row9_col1 {
#   background-color: #243392;
#   color: #f1f1f1;
# }
# #T_6ac77_row1_col10, #T_6ac77_row10_col1 {
#   background-color: #1f7eb7;
#   color: #f1f1f1;
# }
# #T_6ac77_row2_col3, #T_6ac77_row3_col2, #T_6ac77_row4_col5, #T_6ac77_row5_col4 {
#   background-color: #feffd6;
#   color: #000000;
# }
# #T_6ac77_row2_col5, #T_6ac77_row5_col2 {
#   background-color: #e7f6b1;
#   color: #000000;
# }
# #T_6ac77_row2_col7, #T_6ac77_row7_col2 {
#   background-color: #b7e3b6;
#   color: #000000;
# }
# #T_6ac77_row2_col8, #T_6ac77_row8_col2 {
#   background-color: #1d2e83;
#   color: #f1f1f1;
# }
# #T_6ac77_row2_col9, #T_6ac77_row9_col2 {
#   background-color: #2351a2;
#   color: #f1f1f1;
# }
# #T_6ac77_row2_col10, #T_6ac77_row10_col2 {
#   background-color: #2b9fc2;
#   color: #f1f1f1;
# }
# #T_6ac77_row2_col11, #T_6ac77_row11_col2 {
#   background-color: #7ecdbb;
#   color: #000000;
# }
# #T_6ac77_row3_col4, #T_6ac77_row4_col3 {
#   background-color: #e3f4b2;
#   color: #000000;
# }
# #T_6ac77_row3_col7, #T_6ac77_row7_col3 {
#   background-color: #b2e1b6;
#   color: #000000;
# }
# #T_6ac77_row3_col8, #T_6ac77_row8_col3 {
#   background-color: #1c2d81;
#   color: #f1f1f1;
# }
# #T_6ac77_row3_col9, #T_6ac77_row9_col3 {
#   background-color: #2350a1;
#   color: #f1f1f1;
# }
# #T_6ac77_row3_col10, #T_6ac77_row10_col3 {
#   background-color: #2a9ec1;
#   color: #f1f1f1;
# }
# #T_6ac77_row3_col11, #T_6ac77_row11_col3 {
#   background-color: #7acbbc;
#   color: #000000;
# }
# #T_6ac77_row4_col6, #T_6ac77_row6_col4 {
#   background-color: #fdfed4;
#   color: #000000;
# }
# #T_6ac77_row4_col7, #T_6ac77_row7_col4 {
#   background-color: #ecf7b1;
#   color: #000000;
# }
# #T_6ac77_row4_col8, #T_6ac77_row8_col4 {
#   background-color: #225ca7;
#   color: #f1f1f1;
# }
# #T_6ac77_row4_col9, #T_6ac77_row9_col4 {
#   background-color: #1e8bbd;
#   color: #f1f1f1;
# }
# #T_6ac77_row4_col10, #T_6ac77_row10_col4 {
#   background-color: #67c4be;
#   color: #000000;
# }
# #T_6ac77_row4_col11, #T_6ac77_row9_col10, #T_6ac77_row10_col9, #T_6ac77_row11_col4 {
#   background-color: #ceecb3;
#   color: #000000;
# }
# #T_6ac77_row5_col6, #T_6ac77_row6_col5 {
#   background-color: #fcfed1;
#   color: #000000;
# }
# #T_6ac77_row5_col7, #T_6ac77_row7_col5 {
#   background-color: #eaf7b1;
#   color: #000000;
# }
# #T_6ac77_row5_col8, #T_6ac77_row8_col5 {
#   background-color: #225aa6;
#   color: #f1f1f1;
# }
# #T_6ac77_row5_col9, #T_6ac77_row9_col5 {
#   background-color: #1e8abd;
#   color: #f1f1f1;
# }
# #T_6ac77_row5_col10, #T_6ac77_row10_col5 {
#   background-color: #65c3bf;
#   color: #000000;
# }
# #T_6ac77_row5_col11, #T_6ac77_row11_col5 {
#   background-color: #cdebb4;
#   color: #000000;
# }
# #T_6ac77_row6_col7, #T_6ac77_row7_col6 {
#   background-color: #eff9b5;
#   color: #000000;
# }
# #T_6ac77_row6_col8, #T_6ac77_row8_col6 {
#   background-color: #2262aa;
#   color: #f1f1f1;
# }
# #T_6ac77_row6_col9, #T_6ac77_row9_col6 {
#   background-color: #1f93c0;
#   color: #f1f1f1;
# }
# #T_6ac77_row6_col10, #T_6ac77_row10_col6 {
#   background-color: #6fc7bd;
#   color: #000000;
# }
# #T_6ac77_row6_col11, #T_6ac77_row11_col6 {
#   background-color: #d4eeb3;
#   color: #000000;
# }
# #T_6ac77_row7_col8, #T_6ac77_row8_col7 {
#   background-color: #1d90c0;
#   color: #f1f1f1;
# }
# #T_6ac77_row7_col9, #T_6ac77_row9_col7 {
#   background-color: #3eb3c4;
#   color: #f1f1f1;
# }
# #T_6ac77_row7_col10, #T_6ac77_row10_col7 {
#   background-color: #aedfb6;
#   color: #000000;
# }
# #T_6ac77_row7_col11, #T_6ac77_row11_col7 {
#   background-color: #f1faba;
#   color: #000000;
# }
# #T_6ac77_row8_col9, #T_6ac77_row9_col8 {
#   background-color: #e1f3b2;
#   color: #000000;
# }
# #T_6ac77_row8_col10, #T_6ac77_row10_col8 {
#   background-color: #97d6b9;
#   color: #000000;
# }
# #T_6ac77_row8_col11, #T_6ac77_row11_col8 {
#   background-color: #39adc3;
#   color: #f1f1f1;
# }
# #T_6ac77_row10_col11, #T_6ac77_row11_col10 {
#   background-color: #d7efb3;
#   color: #000000;
# }
# </style>
# <table id="T_6ac77">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6ac77_level0_col0" class="col_heading level0 col0" >full</th>
#       <th id="T_6ac77_level0_col1" class="col_heading level0 col1" >red</th>
#       <th id="T_6ac77_level0_col2" class="col_heading level0 col2" >green</th>
#       <th id="T_6ac77_level0_col3" class="col_heading level0 col3" >blue</th>
#       <th id="T_6ac77_level0_col4" class="col_heading level0 col4" >red_green</th>
#       <th id="T_6ac77_level0_col5" class="col_heading level0 col5" >red_blue</th>
#       <th id="T_6ac77_level0_col6" class="col_heading level0 col6" >green_blue</th>
#       <th id="T_6ac77_level0_col7" class="col_heading level0 col7" >gray_r</th>
#       <th id="T_6ac77_level0_col8" class="col_heading level0 col8" >gray_g</th>
#       <th id="T_6ac77_level0_col9" class="col_heading level0 col9" >gray_b</th>
#       <th id="T_6ac77_level0_col10" class="col_heading level0 col10" >gray_max</th>
#       <th id="T_6ac77_level0_col11" class="col_heading level0 col11" >gray_mean</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >dataset</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#       <th class="blank col11" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6ac77_level0_row0" class="row_heading level0 row0" >full</th>
#       <td id="T_6ac77_row0_col0" class="data row0 col0" >0.000000</td>
#       <td id="T_6ac77_row0_col1" class="data row0 col1" >0.834500</td>
#       <td id="T_6ac77_row0_col2" class="data row0 col2" >0.646900</td>
#       <td id="T_6ac77_row0_col3" class="data row0 col3" >0.656900</td>
#       <td id="T_6ac77_row0_col4" class="data row0 col4" >0
# <center><h3>orthologs_myoglobin</h3></center>
# <style type="text/css">
# #T_4ebd1_row0_col0, #T_4ebd1_row1_col1, #T_4ebd1_row2_col2, #T_4ebd1_row3_col3, #T_4ebd1_row4_col4, #T_4ebd1_row5_col5, #T_4ebd1_row6_col6, #T_4ebd1_row7_col7, #T_4ebd1_row8_col8, #T_4ebd1_row9_col9, #T_4ebd1_row10_col10, #T_4ebd1_row11_col11 {
#   background-color: #ffffd9;
#   color: #000000;
# }
# #T_4ebd1_row0_col1, #T_4ebd1_row1_col0 {
#   background-color: #63c3bf;
#   color: #000000;
# }
# #T_4ebd1_row0_col2, #T_4ebd1_row2_col0 {
#   background-color: #8ed3ba;
#   color: #000000;
# }
# #T_4ebd1_row0_col3, #T_4ebd1_row3_col0 {
#   background-color: #92d5b9;
#   color: #000000;
# }
# #T_4ebd1_row0_col4, #T_4ebd1_row2_col6, #T_4ebd1_row4_col0, #T_4ebd1_row6_col2, #T_4ebd1_row10_col11, #T_4ebd1_row11_col10 {
#   background-color: #dcf1b2;
#   color: #000000;
# }
# #T_4ebd1_row0_col5, #T_4ebd1_row3_col6, #T_4ebd1_row5_col0, #T_4ebd1_row6_col3 {
#   background-color: #dff2b2;
#   color: #000000;
# }
# #T_4ebd1_row0_col6, #T_4ebd1_row2_col4, #T_4ebd1_row3_col5, #T_4ebd1_row4_col2, #T_4ebd1_row5_col3, #T_4ebd1_row6_col0 {
#   background-color: #e0f3b2;
#   color: #000000;
# }
# #T_4ebd1_row0_col7, #T_4ebd1_row7_col0 {
#   background-color: #fcfed3;
#   color: #000000;
# }
# #T_4ebd1_row0_col8, #T_4ebd1_row8_col0 {
#   background-color: #3aaec3;
#   color: #f1f1f1;
# }
# #T_4ebd1_row0_col9, #T_4ebd1_row9_col0 {
#   background-color: #2da2c2;
#   color: #f1f1f1;
# }
# #T_4ebd1_row0_col10, #T_4ebd1_row4_col11, #T_4ebd1_row10_col0, #T_4ebd1_row11_col4 {
#   background-color: #a9ddb7;
#   color: #000000;
# }
# #T_4ebd1_row0_col11, #T_4ebd1_row11_col0 {
#   background-color: #edf8b1;
#   color: #000000;
# }
# #T_4ebd1_row1_col2, #T_4ebd1_row2_col1 {
#   background-color: #f3fabf;
#   color: #000000;
# }
# #T_4ebd1_row1_col3, #T_4ebd1_row3_col1 {
#   background-color: #f2fabc;
#   color: #000000;
# }
# #T_4ebd1_row1_col4, #T_4ebd1_row4_col1 {
#   background-color: #c6e9b4;
#   color: #000000;
# }
# #T_4ebd1_row1_col5, #T_4ebd1_row5_col1 {
#   background-color: #c2e7b4;
#   color: #000000;
# }
# #T_4ebd1_row1_col6, #T_4ebd1_row6_col1 {
#   background-color: #c0e6b5;
#   color: #000000;
# }
# #T_4ebd1_row1_col7, #T_4ebd1_row7_col1 {
#   background-color: #6bc6be;
#   color: #000000;
# }
# #T_4ebd1_row1_col8, #T_4ebd1_row8_col1 {
#   background-color: #12256d;
#   color: #f1f1f1;
# }
# #T_4ebd1_row1_col9, #T_4ebd1_row9_col1 {
#   background-color: #081d58;
#   color: #f1f1f1;
# }
# #T_4ebd1_row1_col10, #T_4ebd1_row10_col1 {
#   background-color: #2165ab;
#   color: #f1f1f1;
# }
# #T_4ebd1_row1_col11, #T_4ebd1_row11_col1 {
#   background-color: #31a5c2;
#   color: #f1f1f1;
# }
# #T_4ebd1_row2_col3, #T_4ebd1_row3_col2, #T_4ebd1_row4_col5, #T_4ebd1_row4_col6, #T_4ebd1_row5_col4, #T_4ebd1_row6_col4 {
#   background-color: #fdfed5;
#   color: #000000;
# }
# #T_4ebd1_row2_col5, #T_4ebd1_row5_col2 {
#   background-color: #ddf2b2;
#   color: #000000;
# }
# #T_4ebd1_row2_col7, #T_4ebd1_row7_col2 {
#   background-color: #97d6b9;
#   color: #000000;
# }
# #T_4ebd1_row2_col8, #T_4ebd1_row8_col2 {
#   background-color: #253494;
#   color: #f1f1f1;
# }
# #T_4ebd1_row2_col9, #T_4ebd1_row9_col2 {
#   background-color: #1b2c80;
#   color: #f1f1f1;
# }
# #T_4ebd1_row2_col10, #T_4ebd1_row10_col2 {
#   background-color: #1e86bb;
#   color: #f1f1f1;
# }
# #T_4ebd1_row2_col11, #T_4ebd1_row6_col10, #T_4ebd1_row10_col6, #T_4ebd1_row11_col2 {
#   background-color: #50bbc2;
#   color: #000000;
# }
# #T_4ebd1_row3_col4, #T_4ebd1_row4_col3 {
#   background-color: #e2f4b2;
#   color: #000000;
# }
# #T_4ebd1_row3_col7, #T_4ebd1_row7_col3 {
#   background-color: #9cd8b8;
#   color: #000000;
# }
# #T_4ebd1_row3_col8, #T_4ebd1_row8_col3 {
#   background-color: #253795;
#   color: #f1f1f1;
# }
# #T_4ebd1_row3_col9, #T_4ebd1_row9_col3 {
#   background-color: #1d2e83;
#   color: #f1f1f1;
# }
# #T_4ebd1_row3_col10, #T_4ebd1_row10_col3 {
#   background-color: #1e8abd;
#   color: #f1f1f1;
# }
# #T_4ebd1_row3_col11, #T_4ebd1_row11_col3 {
#   background-color: #53bdc1;
#   color: #000000;
# }
# #T_4ebd1_row4_col7, #T_4ebd1_row7_col4 {
#   background-color: #e1f3b2;
#   color: #000000;
# }
# #T_4ebd1_row4_col8, #T_4ebd1_row8_col4 {
#   background-color: #2070b0;
#   color: #f1f1f1;
# }
# #T_4ebd1_row4_col9, #T_4ebd1_row9_col4 {
#   background-color: #225ea8;
#   color: #f1f1f1;
# }
# #T_4ebd1_row4_col10, #T_4ebd1_row10_col4 {
#   background-color: #4ab9c3;
#   color: #f1f1f1;
# }
# #T_4ebd1_row5_col6, #T_4ebd1_row6_col5 {
#   background-color: #feffd6;
#   color: #000000;
# }
# #T_4ebd1_row5_col7, #T_4ebd1_row7_col5 {
#   background-color: #e3f4b2;
#   color: #000000;
# }
# #T_4ebd1_row5_col8, #T_4ebd1_row8_col5 {
#   background-color: #2073b2;
#   color: #f1f1f1;
# }
# #T_4ebd1_row5_col9, #T_4ebd1_row9_col5 {
#   background-color: #2262aa;
#   color: #f1f1f1;
# }
# #T_4ebd1_row5_col10, #T_4ebd1_row10_col5 {
#   background-color: #4ebbc2;
#   color: #000000;
# }
# #T_4ebd1_row5_col11, #T_4ebd1_row11_col5 {
#   background-color: #aedfb6;
#   color: #000000;
# }
# #T_4ebd1_row6_col7, #T_4ebd1_row7_col6 {
#   background-color: #e5f5b2;
#   color: #000000;
# }
# #T_4ebd1_row6_col8, #T_4ebd1_row8_col6 {
#   background-color: #2075b3;
#   color: #f1f1f1;
# }
# #T_4ebd1_row6_col9, #T_4ebd1_row9_col6 {
#   background-color: #2163aa;
#   color: #f1f1f1;
# }
# #T_4ebd1_row6_col11, #T_4ebd1_row11_col6 {
#   background-color: #b0e0b6;
#   color: #000000;
# }
# #T_4ebd1_row7_col8, #T_4ebd1_row8_col7 {
#   background-color: #34a9c3;
#   color: #f1f1f1;
# }
# #T_4ebd1_row7_col9, #T_4ebd1_row9_col7 {
#   background-color: #289cc1;
#   color: #f1f1f1;
# }
# #T_4ebd1_row7_col10, #T_4ebd1_row10_col7 {
#   background-color: #a0dab8;
#   color: #000000;
# }
# #T_4ebd1_row7_col11, #T_4ebd1_row11_col7 {
#   background-color: #e8f6b1;
#   color: #000000;
# }
# #T_4ebd1_row8_col9, #T_4ebd1_row9_col8 {
#   background-color: #ecf7b1;
#   color: #000000;
# }
# #T_4ebd1_row8_col10, #T_4ebd1_row10_col8 {
#   background-color: #caeab4;
#   color: #000000;
# }
# #T_4ebd1_row8_col11, #T_4ebd1_row11_col8 {
#   background-color: #6dc6be;
#   color: #000000;
# }
# #T_4ebd1_row9_col10, #T_4ebd1_row10_col9 {
#   background-color: #b7e3b6;
#   color: #000000;
# }
# #T_4ebd1_row9_col11, #T_4ebd1_row11_col9 {
#   background-color: #59bfc0;
#   color: #000000;
# }
# </style>
# <table id="T_4ebd1">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4ebd1_level0_col0" class="col_heading level0 col0" >full</th>
#       <th id="T_4ebd1_level0_col1" class="col_heading level0 col1" >red</th>
#       <th id="T_4ebd1_level0_col2" class="col_heading level0 col2" >green</th>
#       <th id="T_4ebd1_level0_col3" class="col_heading level0 col3" >blue</th>
#       <th id="T_4ebd1_level0_col4" class="col_heading level0 col4" >red_green</th>
#       <th id="T_4ebd1_level0_col5" class="col_heading level0 col5" >red_blue</th>
#       <th id="T_4ebd1_level0_col6" class="col_heading level0 col6" >green_blue</th>
#       <th id="T_4ebd1_level0_col7" class="col_heading level0 col7" >gray_r</th>
#       <th id="T_4ebd1_level0_col8" class="col_heading level0 col8" >gray_g</th>
#       <th id="T_4ebd1_level0_col9" class="col_heading level0 col9" >gray_b</th>
#       <th id="T_4ebd1_level0_col10" class="col_heading level0 col10" >gray_max</th>
#       <th id="T_4ebd1_level0_col11" class="col_heading level0 col11" >gray_mean</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >dataset</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#       <th class="blank col11" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4ebd1_level0_row0" class="row_heading level0 row0" >full</th>
#       <td id="T_4ebd1_row0_col0" class="data row0 col0" >0.000000</td>
#       <td id="T_4ebd1_row0_col1" class="data row0 col1" >0.893200</td>
#       <td id="T_4ebd1_row0_col2" class="data row0 col2" >0.719700</td>
#       <td id="T_4ebd1_row0_col3" class="data row0 col3" >0.703500</td>
#       <td id="T_4ebd1_row0_col4" class="data row0 col4" >0.371800</td>
#       <td id="T_4ebd1_row0_col5" clas
# <center><h3>orthologs_neuroglobin</h3></center>
# <style type="text/css">
# #T_edce6_row0_col0, #T_edce6_row1_col1, #T_edce6_row2_col2, #T_edce6_row3_col3, #T_edce6_row4_col4, #T_edce6_row5_col5, #T_edce6_row6_col6, #T_edce6_row7_col7, #T_edce6_row8_col8, #T_edce6_row9_col9, #T_edce6_row10_col10, #T_edce6_row11_col11 {
#   background-color: #ffffd9;
#   color: #000000;
# }
# #T_edce6_row0_col1, #T_edce6_row1_col0 {
#   background-color: #50bbc2;
#   color: #000000;
# }
# #T_edce6_row0_col2, #T_edce6_row2_col0 {
#   background-color: #85cfba;
#   color: #000000;
# }
# #T_edce6_row0_col3, #T_edce6_row3_col0 {
#   background-color: #80cebb;
#   color: #000000;
# }
# #T_edce6_row0_col4, #T_edce6_row2_col6, #T_edce6_row4_col0, #T_edce6_row6_col2 {
#   background-color: #dbf1b2;
#   color: #000000;
# }
# #T_edce6_row0_col5, #T_edce6_row3_col6, #T_edce6_row5_col0, #T_edce6_row6_col3 {
#   background-color: #d9f0b3;
#   color: #000000;
# }
# #T_edce6_row0_col6, #T_edce6_row2_col4, #T_edce6_row3_col5, #T_edce6_row4_col2, #T_edce6_row5_col3, #T_edce6_row6_col0 {
#   background-color: #dcf1b2;
#   color: #000000;
# }
# #T_edce6_row0_col7, #T_edce6_row7_col0 {
#   background-color: #fdfed4;
#   color: #000000;
# }
# #T_edce6_row0_col8, #T_edce6_row3_col10, #T_edce6_row8_col0, #T_edce6_row10_col3 {
#   background-color: #39adc3;
#   color: #f1f1f1;
# }
# #T_edce6_row0_col9, #T_edce6_row9_col0 {
#   background-color: #4ebbc2;
#   color: #000000;
# }
# #T_edce6_row0_col10, #T_edce6_row10_col0 {
#   background-color: #e3f4b2;
#   color: #000000;
# }
# #T_edce6_row0_col11, #T_edce6_row11_col0 {
#   background-color: #f9fdcc;
#   color: #000000;
# }
# #T_edce6_row1_col2, #T_edce6_row2_col1 {
#   background-color: #f0f9b8;
#   color: #000000;
# }
# #T_edce6_row1_col3, #T_edce6_row3_col1 {
#   background-color: #f1fabb;
#   color: #000000;
# }
# #T_edce6_row1_col4, #T_edce6_row4_col1 {
#   background-color: #b2e1b6;
#   color: #000000;
# }
# #T_edce6_row1_col5, #T_edce6_row5_col1 {
#   background-color: #b9e4b5;
#   color: #000000;
# }
# #T_edce6_row1_col6, #T_edce6_row6_col1 {
#   background-color: #b0e0b6;
#   color: #000000;
# }
# #T_edce6_row1_col7, #T_edce6_row7_col1 {
#   background-color: #57bec1;
#   color: #000000;
# }
# #T_edce6_row1_col8, #T_edce6_row8_col1 {
#   background-color: #081d58;
#   color: #f1f1f1;
# }
# #T_edce6_row1_col9, #T_edce6_row9_col1 {
#   background-color: #152772;
#   color: #f1f1f1;
# }
# #T_edce6_row1_col10, #T_edce6_row10_col1 {
#   background-color: #1d91c0;
#   color: #f1f1f1;
# }
# #T_edce6_row1_col11, #T_edce6_row11_col1 {
#   background-color: #48b9c3;
#   color: #f1f1f1;
# }
# #T_edce6_row2_col3, #T_edce6_row3_col2, #T_edce6_row4_col5, #T_edce6_row5_col4 {
#   background-color: #feffd6;
#   color: #000000;
# }
# #T_edce6_row2_col5, #T_edce6_row5_col2 {
#   background-color: #e0f3b2;
#   color: #000000;
# }
# #T_edce6_row2_col7, #T_edce6_row5_col10, #T_edce6_row7_col2, #T_edce6_row10_col5 {
#   background-color: #8ed3ba;
#   color: #000000;
# }
# #T_edce6_row2_col8, #T_edce6_row8_col2 {
#   background-color: #203089;
#   color: #f1f1f1;
# }
# #T_edce6_row2_col9, #T_edce6_row9_col2 {
#   background-color: #24409a;
#   color: #f1f1f1;
# }
# #T_edce6_row2_col10, #T_edce6_row10_col2 {
#   background-color: #3cb1c3;
#   color: #f1f1f1;
# }
# #T_edce6_row2_col11, #T_edce6_row8_col10, #T_edce6_row10_col8, #T_edce6_row11_col2 {
#   background-color: #7cccbb;
#   color: #000000;
# }
# #T_edce6_row3_col4, #T_edce6_row4_col3 {
#   background-color: #daf0b3;
#   color: #000000;
# }
# #T_edce6_row3_col7, #T_edce6_row7_col3 {
#   background-color: #89d1ba;
#   color: #000000;
# }
# #T_edce6_row3_col8, #T_edce6_row8_col3 {
#   background-color: #1e2e85;
#   color: #f1f1f1;
# }
# #T_edce6_row3_col9, #T_edce6_row9_col3 {
#   background-color: #243d98;
#   color: #f1f1f1;
# }
# #T_edce6_row3_col11, #T_edce6_row11_col3 {
#   background-color: #78cbbc;
#   color: #000000;
# }
# #T_edce6_row4_col6, #T_edce6_row6_col4 {
#   background-color: #feffd8;
#   color: #000000;
# }
# #T_edce6_row4_col7, #T_edce6_row6_col7, #T_edce6_row7_col4, #T_edce6_row7_col6 {
#   background-color: #e1f3b2;
#   color: #000000;
# }
# #T_edce6_row4_col8, #T_edce6_row8_col4 {
#   background-color: #216daf;
#   color: #f1f1f1;
# }
# #T_edce6_row4_col9, #T_edce6_row9_col4 {
#   background-color: #1e83ba;
#   color: #f1f1f1;
# }
# #T_edce6_row4_col10, #T_edce6_row10_col4 {
#   background-color: #95d5b9;
#   color: #000000;
# }
# #T_edce6_row4_col11, #T_edce6_row11_col4 {
#   background-color: #d6efb3;
#   color: #000000;
# }
# #T_edce6_row5_col6, #T_edce6_row6_col5 {
#   background-color: #fdfed5;
#   color: #000000;
# }
# #T_edce6_row5_col7, #T_edce6_row7_col5 {
#   background-color: #ddf2b2;
#   color: #000000;
# }
# #T_edce6_row5_col8, #T_edce6_row8_col5 {
#   background-color: #2168ad;
#   color: #f1f1f1;
# }
# #T_edce6_row5_col9, #T_edce6_row9_col5 {
#   background-color: #1f80b8;
#   color: #f1f1f1;
# }
# #T_edce6_row5_col11, #T_edce6_row11_col5 {
#   background-color: #d4eeb3;
#   color: #000000;
# }
# #T_edce6_row6_col8, #T_edce6_row8_col6 {
#   background-color: #206eb0;
#   color: #f1f1f1;
# }
# #T_edce6_row6_col9, #T_edce6_row9_col6 {
#   background-color: #1e85ba;
#   color: #f1f1f1;
# }
# #T_edce6_row6_col10, #T_edce6_row10_col6 {
#   background-color: #97d6b9;
#   color: #000000;
# }
# #T_edce6_row6_col11, #T_edce6_row11_col6 {
#   background-color: #d7efb3;
#   color: #000000;
# }
# #T_edce6_row7_col8, #T_edce6_row8_col7 {
#   background-color: #34a9c3;
#   color: #f1f1f1;
# }
# #T_edce6_row7_col9, #T_edce6_row9_col7 {
#   background-color: #46b8c3;
#   color: #f1f1f1;
# }
# #T_edce6_row7_col10, #T_edce6_row10_col7 {
#   background-color: #dff2b2;
#   color: #000000;
# }
# #T_edce6_row7_col11, #T_edce6_row11_col7 {
#   background-color: #f8fcc9;
#   color: #000000;
# }
# #T_edce6_row8_col9, #T_edce6_row9_col8 {
#   background-color: #edf8b2;
#   color: #000000;
# }
# #T_edce6_row8_col11, #T_edce6_row11_col8 {
#   background-color: #3bb0c3;
#   color: #f1f1f1;
# }
# #T_edce6_row9_col10, #T_edce6_row10_col9 {
#   background-color: #9cd8b8;
#   color: #000000;
# }
# #T_edce6_row9_col11, #T_edce6_row11_col9 {
#   background-color: #55bec1;
#   color: #000000;
# }
# #T_edce6_row10_col11, #T_edce6_row11_col10 {
#   background-color: #e8f6b1;
#   color: #000000;
# }
# </style>
# <table id="T_edce6">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_edce6_level0_col0" class="col_heading level0 col0" >full</th>
#       <th id="T_edce6_level0_col1" class="col_heading level0 col1" >red</th>
#       <th id="T_edce6_level0_col2" class="col_heading level0 col2" >green</th>
#       <th id="T_edce6_level0_col3" class="col_heading level0 col3" >blue</th>
#       <th id="T_edce6_level0_col4" class="col_heading level0 col4" >red_green</th>
#       <th id="T_edce6_level0_col5" class="col_heading level0 col5" >red_blue</th>
#       <th id="T_edce6_level0_col6" class="col_heading level0 col6" >green_blue</th>
#       <th id="T_edce6_level0_col7" class="col_heading level0 col7" >gray_r</th>
#       <th id="T_edce6_level0_col8" class="col_heading level0 col8" >gray_g</th>
#       <th id="T_edce6_level0_col9" class="col_heading level0 col9" >gray_b</th>
#       <th id="T_edce6_level0_col10" class="col_heading level0 col10" >gray_max</th>
#       <th id="T_edce6_level0_col11" class="col_heading level0 col11" >gray_mean</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >dataset</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#       <th class="blank col11" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_edce6_level0_row0" class="row_heading level0 row0" >full</th>
#       <td id="T_edce6_row0_col0" class="data row0 col0" >0.000000</td>
#       <td id="T_edce6_row0_col1" class="data row0 col1" >2.223000</td>
#       <td id="T_edce6_row0_col2" class="data row0 col2" >1.725800</td>
#       <td id="T_edce6_row0_col3" class="data row0 col3" >1.769000</td>
#       <td id="T_edce6_row0_col4" class="data row0 col4" >0.871900</td>
#       <td id="T_edce6_row0_col5" clas
# <center><h3>orthologs_cytoglobin</h3></center>
# <style type="text/css">
# #T_0005c_row0_col0, #T_0005c_row1_col1, #T_0005c_row2_col2, #T_0005c_row2_col3, #T_0005c_row3_col2, #T_0005c_row3_col3, #T_0005c_row4_col4, #T_0005c_row4_col5, #T_0005c_row5_col4, #T_0005c_row5_col5, #T_0005c_row6_col6, #T_0005c_row7_col7, #T_0005c_row8_col8, #T_0005c_row9_col9, #T_0005c_row10_col10, #T_0005c_row11_col11 {
#   background-color: #ffffd9;
#   color: #000000;
# }
# #T_0005c_row0_col1, #T_0005c_row1_col0 {
#   background-color: #4ebbc2;
#   color: #000000;
# }
# #T_0005c_row0_col2, #T_0005c_row0_col3, #T_0005c_row2_col0, #T_0005c_row3_col0, #T_0005c_row7_col9, #T_0005c_row9_col7 {
#   background-color: #7ecdbb;
#   color: #000000;
# }
# #T_0005c_row0_col4, #T_0005c_row0_col5, #T_0005c_row2_col6, #T_0005c_row3_col6, #T_0005c_row4_col0, #T_0005c_row5_col0, #T_0005c_row6_col2, #T_0005c_row6_col3 {
#   background-color: #daf0b3;
#   color: #000000;
# }
# #T_0005c_row0_col6, #T_0005c_row2_col4, #T_0005c_row2_col5, #T_0005c_row3_col4, #T_0005c_row3_col5, #T_0005c_row4_col2, #T_0005c_row4_col3, #T_0005c_row4_col11, #T_0005c_row5_col2, #T_0005c_row5_col3, #T_0005c_row5_col11, #T_0005c_row6_col0, #T_0005c_row11_col4, #T_0005c_row11_col5 {
#   background-color: #dbf1b2;
#   color: #000000;
# }
# #T_0005c_row0_col7, #T_0005c_row7_col0 {
#   background-color: #fdfed5;
#   color: #000000;
# }
# #T_0005c_row0_col8, #T_0005c_row2_col10, #T_0005c_row3_col10, #T_0005c_row8_col0, #T_0005c_row10_col2, #T_0005c_row10_col3 {
#   background-color: #3aaec3;
#   color: #f1f1f1;
# }
# #T_0005c_row0_col9, #T_0005c_row9_col0 {
#   background-color: #85cfba;
#   color: #000000;
# }
# #T_0005c_row0_col10, #T_0005c_row10_col0 {
#   background-color: #e7f6b1;
#   color: #000000;
# }
# #T_0005c_row0_col11, #T_0005c_row7_col11, #T_0005c_row11_col0, #T_0005c_row11_col7 {
#   background-color: #fcfed3;
#   color: #000000;
# }
# #T_0005c_row1_col2, #T_0005c_row1_col3, #T_0005c_row2_col1, #T_0005c_row3_col1 {
#   background-color: #f1fabb;
#   color: #000000;
# }
# #T_0005c_row1_col4, #T_0005c_row1_col5, #T_0005c_row4_col1, #T_0005c_row5_col1 {
#   background-color: #b4e2b6;
#   color: #000000;
# }
# #T_0005c_row1_col6, #T_0005c_row6_col1 {
#   background-color: #b2e1b6;
#   color: #000000;
# }
# #T_0005c_row1_col7, #T_0005c_row7_col1 {
#   background-color: #53bdc1;
#   color: #000000;
# }
# #T_0005c_row1_col8, #T_0005c_row8_col1 {
#   background-color: #081d58;
#   color: #f1f1f1;
# }
# #T_0005c_row1_col9, #T_0005c_row9_col1 {
#   background-color: #24409a;
#   color: #f1f1f1;
# }
# #T_0005c_row1_col10, #T_0005c_row10_col1 {
#   background-color: #1d91c0;
#   color: #f1f1f1;
# }
# #T_0005c_row1_col11, #T_0005c_row11_col1 {
#   background-color: #52bcc2;
#   color: #000000;
# }
# #T_0005c_row2_col7, #T_0005c_row2_col11, #T_0005c_row3_col7, #T_0005c_row3_col11, #T_0005c_row7_col2, #T_0005c_row7_col3, #T_0005c_row11_col2, #T_0005c_row11_col3 {
#   background-color: #83cebb;
#   color: #000000;
# }
# #T_0005c_row2_col8, #T_0005c_row3_col8, #T_0005c_row8_col2, #T_0005c_row8_col3 {
#   background-color: #1e2e85;
#   color: #f1f1f1;
# }
# #T_0005c_row2_col9, #T_0005c_row3_col9, #T_0005c_row9_col2, #T_0005c_row9_col3 {
#   background-color: #2262aa;
#   color: #f1f1f1;
# }
# #T_0005c_row4_col6, #T_0005c_row5_col6, #T_0005c_row6_col4, #T_0005c_row6_col5 {
#   background-color: #feffd8;
#   color: #000000;
# }
# #T_0005c_row4_col7, #T_0005c_row5_col7, #T_0005c_row6_col11, #T_0005c_row7_col4, #T_0005c_row7_col5, #T_0005c_row11_col6 {
#   background-color: #dcf1b2;
#   color: #000000;
# }
# #T_0005c_row4_col8, #T_0005c_row5_col8, #T_0005c_row8_col4, #T_0005c_row8_col5 {
#   background-color: #216bae;
#   color: #f1f1f1;
# }
# #T_0005c_row4_col9, #T_0005c_row5_col9, #T_0005c_row9_col4, #T_0005c_row9_col5 {
#   background-color: #31a5c2;
#   color: #f1f1f1;
# }
# #T_0005c_row4_col10, #T_0005c_row5_col10, #T_0005c_row10_col4, #T_0005c_row10_col5 {
#   background-color: #95d5b9;
#   color: #000000;
# }
# #T_0005c_row6_col7, #T_0005c_row7_col6 {
#   background-color: #ddf2b2;
#   color: #000000;
# }
# #T_0005c_row6_col8, #T_0005c_row8_col6 {
#   background-color: #216daf;
#   color: #f1f1f1;
# }
# #T_0005c_row6_col9, #T_0005c_row9_col6 {
#   background-color: #32a6c2;
#   color: #f1f1f1;
# }
# #T_0005c_row6_col10, #T_0005c_row10_col6 {
#   background-color: #97d6b9;
#   color: #000000;
# }
# #T_0005c_row7_col8, #T_0005c_row8_col7 {
#   background-color: #36abc3;
#   color: #f1f1f1;
# }
# #T_0005c_row7_col10, #T_0005c_row10_col7 {
#   background-color: #e3f4b2;
#   color: #000000;
# }
# #T_0005c_row8_col9, #T_0005c_row9_col8 {
#   background-color: #e0f3b2;
#   color: #000000;
# }
# #T_0005c_row8_col10, #T_0005c_row10_col8 {
#   background-color: #7cccbb;
#   color: #000000;
# }
# #T_0005c_row8_col11, #T_0005c_row11_col8 {
#   background-color: #37acc3;
#   color: #f1f1f1;
# }
# #T_0005c_row9_col10, #T_0005c_row10_col9 {
#   background-color: #d0edb3;
#   color: #000000;
# }
# #T_0005c_row9_col11, #T_0005c_row11_col9 {
#   background-color: #80cebb;
#   color: #000000;
# }
# #T_0005c_row10_col11, #T_0005c_row11_col10 {
#   background-color: #e5f5b2;
#   color: #000000;
# }
# </style>
# <table id="T_0005c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0005c_level0_col0" class="col_heading level0 col0" >full</th>
#       <th id="T_0005c_level0_col1" class="col_heading level0 col1" >red</th>
#       <th id="T_0005c_level0_col2" class="col_heading level0 col2" >green</th>
#       <th id="T_0005c_level0_col3" class="col_heading level0 col3" >blue</th>
#       <th id="T_0005c_level0_col4" class="col_heading level0 col4" >red_green</th>
#       <th id="T_0005c_level0_col5" class="col_heading level0 col5" >red_blue</th>
#       <th id="T_0005c_level0_col6" class="col_heading level0 col6" >green_blue</th>
#       <th id="T_0005c_level0_col7" class="col_heading level0 col7" >gray_r</th>
#       <th id="T_0005c_level0_col8" class="col_heading level0 col8" >gray_g</th>
#       <th id="T_0005c_level0_col9" class="col_heading level0 col9" >gray_b</th>
#       <th id="T_0005c_level0_col10" class="col_heading level0 col10" >gray_max</th>
#       <th id="T_0005c_level0_col11" class="col_heading level0 col11" >gray_mean</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >dataset</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#       <th class="blank col11" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0005c_level0_row0" class="row_heading level0 row0" >full</th>
#       <td id="T_0005c_row0_col0" class="data row0 col0" >0.000000</td>
#       <td id="T_0005c_row0_col1" class="data row0 col1" >4.426300</td>
#       <td id="T_0005c_row0_col2" class="data row0 col2" >3.526700</td>
#       <td id="T_0005c_row0_col3" class="data row0 col3" >3.529400</td>
#       <td id="T_0005c_row0_col4" class="data row0 col4" >1.784900</td>
#       <td id="T_0005c_row0_col5" class="data row0 col5" >1.787500</td>
#       <td id="T_0005c_row0_col6" class="data row0 col6" >1.742100</td>
#       <td id="T_0005c_row0_col7" class="data row0 col7" >0.120400</td>
#       <td id="T_0005c_row0_col8" class="data row0 col8" >4.917800</td>
#       <td id="T_0005c_row0_col9" class="data row0 col9" >3.411000</td>
#       <td id="T_0005c_row0_col10" class="data row0 col10" >1.378100</td>
#       <td id="T_0005c_row0_col11" class="data row0 col11" >0.184500</td>
#     </tr>
#     <tr>
#       <th id="T_0005c_level0_row1" class="row_heading level0 row1" >red</th>
#       <td id="T_0005c_row1_col0" class="data row1 col0" >4.426300</td>
#       <td id="T_0005c_row1_col1" class="data row1 col1" >0.000000</td>
#       <td id="T_0005c_row1_col2" class="data row1 col2" >0.900400</td>
#       <td id="T_0005c_row1_col3" class="data row1 col3" >0.898100</td>
#       <td id="T_0005c_row1_col4" class="data row1 col4" >2.641500</td>
#       <td id="T_0005c_row1_col5" class="data row1 col5" >2.639000</td>
#       <td id="
# <center><h3>orthologs_androglobin</h3></center>
# <style type="text/css">
# #T_93edb_row0_col0, #T_93edb_row1_col1, #T_93edb_row2_col2, #T_93edb_row3_col3, #T_93edb_row4_col4, #T_93edb_row5_col5, #T_93edb_row6_col6, #T_93edb_row7_col7, #T_93edb_row8_col8, #T_93edb_row9_col9, #T_93edb_row10_col10, #T_93edb_row11_col11 {
#   background-color: #ffffd9;
#   color: #000000;
# }
# #T_93edb_row0_col1, #T_93edb_row1_col0 {
#   background-color: #216aad;
#   color: #f1f1f1;
# }
# #T_93edb_row0_col2, #T_93edb_row2_col0, #T_93edb_row4_col10, #T_93edb_row10_col4 {
#   background-color: #32a6c2;
#   color: #f1f1f1;
# }
# #T_93edb_row0_col3, #T_93edb_row3_col0, #T_93edb_row5_col10, #T_93edb_row10_col5 {
#   background-color: #33a7c2;
#   color: #f1f1f1;
# }
# #T_93edb_row0_col4, #T_93edb_row2_col6, #T_93edb_row3_col4, #T_93edb_row4_col0, #T_93edb_row4_col3, #T_93edb_row6_col2 {
#   background-color: #b9e4b5;
#   color: #000000;
# }
# #T_93edb_row0_col5, #T_93edb_row3_col6, #T_93edb_row5_col0, #T_93edb_row6_col3 {
#   background-color: #bbe4b5;
#   color: #000000;
# }
# #T_93edb_row0_col6, #T_93edb_row0_col10, #T_93edb_row2_col4, #T_93edb_row3_col5, #T_93edb_row4_col2, #T_93edb_row5_col3, #T_93edb_row6_col0, #T_93edb_row10_col0 {
#   background-color: #b7e3b6;
#   color: #000000;
# }
# #T_93edb_row0_col7, #T_93edb_row7_col0 {
#   background-color: #fdfed4;
#   color: #000000;
# }
# #T_93edb_row0_col8, #T_93edb_row8_col0 {
#   background-color: #bde5b5;
#   color: #000000;
# }
# #T_93edb_row0_col9, #T_93edb_row9_col0 {
#   background-color: #eaf7b1;
#   color: #000000;
# }
# #T_93edb_row0_col11, #T_93edb_row11_col0 {
#   background-color: #f8fcc9;
#   color: #000000;
# }
# #T_93edb_row1_col2, #T_93edb_row2_col1 {
#   background-color: #e0f3b2;
#   color: #000000;
# }
# #T_93edb_row1_col3, #T_93edb_row3_col1 {
#   background-color: #dff2b2;
#   color: #000000;
# }
# #T_93edb_row1_col4, #T_93edb_row4_col1 {
#   background-color: #5bc0c0;
#   color: #000000;
# }
# #T_93edb_row1_col5, #T_93edb_row5_col1 {
#   background-color: #59bfc0;
#   color: #000000;
# }
# #T_93edb_row1_col6, #T_93edb_row6_col1 {
#   background-color: #5dc0c0;
#   color: #000000;
# }
# #T_93edb_row1_col7, #T_93edb_row7_col1 {
#   background-color: #2163aa;
#   color: #f1f1f1;
# }
# #T_93edb_row1_col8, #T_93edb_row8_col1 {
#   background-color: #0d2161;
#   color: #f1f1f1;
# }
# #T_93edb_row1_col9, #T_93edb_row3_col8, #T_93edb_row8_col3, #T_93edb_row9_col1 {
#   background-color: #234b9f;
#   color: #f1f1f1;
# }
# #T_93edb_row1_col10, #T_93edb_row10_col1 {
#   background-color: #081d58;
#   color: #f1f1f1;
# }
# #T_93edb_row1_col11, #T_93edb_row11_col1 {
#   background-color: #1f7bb6;
#   color: #f1f1f1;
# }
# #T_93edb_row2_col3, #T_93edb_row3_col2, #T_93edb_row4_col5, #T_93edb_row4_col6, #T_93edb_row5_col4, #T_93edb_row6_col4 {
#   background-color: #feffd8;
#   color: #000000;
# }
# #T_93edb_row2_col5, #T_93edb_row5_col2, #T_93edb_row5_col7, #T_93edb_row7_col5 {
#   background-color: #b4e2b6;
#   color: #000000;
# }
# #T_93edb_row2_col7, #T_93edb_row7_col2 {
#   background-color: #2da2c2;
#   color: #f1f1f1;
# }
# #T_93edb_row2_col8, #T_93edb_row8_col2 {
#   background-color: #23499e;
#   color: #f1f1f1;
# }
# #T_93edb_row2_col9, #T_93edb_row9_col2 {
#   background-color: #1e8abd;
#   color: #f1f1f1;
# }
# #T_93edb_row2_col10, #T_93edb_row10_col2 {
#   background-color: #24419a;
#   color: #f1f1f1;
# }
# #T_93edb_row2_col11, #T_93edb_row11_col2 {
#   background-color: #3db2c4;
#   color: #f1f1f1;
# }
# #T_93edb_row3_col7, #T_93edb_row7_col3 {
#   background-color: #2fa4c2;
#   color: #f1f1f1;
# }
# #T_93edb_row3_col9, #T_93edb_row9_col3 {
#   background-color: #1e8bbd;
#   color: #f1f1f1;
# }
# #T_93edb_row3_col10, #T_93edb_row10_col3 {
#   background-color: #24449c;
#   color: #f1f1f1;
# }
# #T_93edb_row3_col11, #T_93edb_row11_col3 {
#   background-color: #3fb4c4;
#   color: #f1f1f1;
# }
# #T_93edb_row4_col7, #T_93edb_row7_col4 {
#   background-color: #b2e1b6;
#   color: #000000;
# }
# #T_93edb_row4_col8, #T_93edb_row8_col4 {
#   background-color: #37acc3;
#   color: #f1f1f1;
# }
# #T_93edb_row4_col9, #T_93edb_row9_col4 {
#   background-color: #83cebb;
#   color: #000000;
# }
# #T_93edb_row4_col11, #T_93edb_row6_col11, #T_93edb_row11_col4, #T_93edb_row11_col6 {
#   background-color: #cbebb4;
#   color: #000000;
# }
# #T_93edb_row5_col6, #T_93edb_row6_col5 {
#   background-color: #feffd6;
#   color: #000000;
# }
# #T_93edb_row5_col8, #T_93edb_row8_col5 {
#   background-color: #39adc3;
#   color: #f1f1f1;
# }
# #T_93edb_row5_col9, #T_93edb_row9_col5 {
#   background-color: #85cfba;
#   color: #000000;
# }
# #T_93edb_row5_col11, #T_93edb_row9_col10, #T_93edb_row10_col9, #T_93edb_row11_col5 {
#   background-color: #ceecb3;
#   color: #000000;
# }
# #T_93edb_row6_col7, #T_93edb_row7_col6 {
#   background-color: #b0e0b6;
#   color: #000000;
# }
# #T_93edb_row6_col8, #T_93edb_row8_col6 {
#   background-color: #36abc3;
#   color: #f1f1f1;
# }
# #T_93edb_row6_col9, #T_93edb_row9_col6 {
#   background-color: #80cebb;
#   color: #000000;
# }
# #T_93edb_row6_col10, #T_93edb_row10_col6 {
#   background-color: #31a5c2;
#   color: #f1f1f1;
# }
# #T_93edb_row7_col8, #T_93edb_row8_col7 {
#   background-color: #c6e9b4;
#   color: #000000;
# }
# #T_93edb_row7_col9, #T_93edb_row9_col7 {
#   background-color: #ecf7b1;
#   color: #000000;
# }
# #T_93edb_row7_col10, #T_93edb_row10_col7 {
#   background-color: #c0e6b5;
#   color: #000000;
# }
# #T_93edb_row7_col11, #T_93edb_row11_col7 {
#   background-color: #f6fbc5;
#   color: #000000;
# }
# #T_93edb_row8_col9, #T_93edb_row9_col8 {
#   background-color: #d3eeb3;
#   color: #000000;
# }
# #T_93edb_row8_col10, #T_93edb_row10_col8 {
#   background-color: #f3fabf;
#   color: #000000;
# }
# #T_93edb_row8_col11, #T_93edb_row11_col8 {
#   background-color: #a7dcb7;
#   color: #000000;
# }
# #T_93edb_row9_col11, #T_93edb_row11_col9 {
#   background-color: #e2f4b2;
#   color: #000000;
# }
# #T_93edb_row10_col11, #T_93edb_row11_col10 {
#   background-color: #9ed9b8;
#   color: #000000;
# }
# </style>
# <table id="T_93edb">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_93edb_level0_col0" class="col_heading level0 col0" >full</th>
#       <th id="T_93edb_level0_col1" class="col_heading level0 col1" >red</th>
#       <th id="T_93edb_level0_col2" class="col_heading level0 col2" >green</th>
#       <th id="T_93edb_level0_col3" class="col_heading level0 col3" >blue</th>
#       <th id="T_93edb_level0_col4" class="col_heading level0 col4" >red_green</th>
#       <th id="T_93edb_level0_col5" class="col_heading level0 col5" >red_blue</th>
#       <th id="T_93edb_level0_col6" class="col_heading level0 col6" >green_blue</th>
#       <th id="T_93edb_level0_col7" class="col_heading level0 col7" >gray_r</th>
#       <th id="T_93edb_level0_col8" class="col_heading level0 col8" >gray_g</th>
#       <th id="T_93edb_level0_col9" class="col_heading level0 col9" >gray_b</th>
#       <th id="T_93edb_level0_col10" class="col_heading level0 col10" >gray_max</th>
#       <th id="T_93edb_level0_col11" class="col_heading level0 col11" >gray_mean</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >dataset</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#       <th class="blank col11" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_93edb_level0_row0" class="row_heading level0 row0" >full</th>
#       <td id="T_93edb_row0_col0" class="data row0 col0" >0.000000</td>
#       <td id="T_93edb_row0_col1" class="data row0 col1" >4.362000</td>
#       <td id="T_93edb_row0_col2" class="data row0 col2" >3.348900</td>
#       <td id="T_93edb_row0_col3" class="data row0 col3" >3.315300</td>
#       <td id="T_93edb_row0_col4" class="data row0 col4" >1.663000</td>
#       <td id="T_93edb_row0_col5" class="data row0 col5" >1.629500</td>
#       <td id="T_93edb_row0_col6" class="data row0 col6" >1.685900</td>
#       <td id="T_93edb_row0_col7" class="data row0 col7" >0.109900</td>
#       <td id="T_93edb_row0_col8" class="data row0 col8" >1.606500</td>
