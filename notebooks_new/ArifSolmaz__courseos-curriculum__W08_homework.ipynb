# %% [markdown]
# # CP2 Week 8 Homework -- Timing & Performance
#
# **Due:** Before next week
# **Estimated time:** 2-4 hours
#
# ## Instructions
# - Complete exercises in order (they build on each other)
# - **Review** exercises check understanding
# - **Practice** exercises apply concepts
# - **Challenge** exercises go deeper
# - **Mini-Project** combines everything
# - Show your work: include print statements for all outputs
# - Expected outputs are provided where applicable

# %%
# === SETUP (run this first) ===
# If running in Google Colab, uncomment and run the lines below:
# !git clone https://github.com/ArifSolmaz/courseos-curriculum.git
# %cd courseos-curriculum/course-content

import sys, os
# Add src to path so we can import project modules
if os.path.exists('src'):
    sys.path.insert(0, 'src')
elif os.path.exists('../src'):
    sys.path.insert(0, '../src')
elif os.path.exists('../../src'):
    sys.path.insert(0, '../../src')

print("Setup complete! Ready to work.")

# %% [markdown]
# ---
# ## Review (1-4)
#
# These exercises check that you understood the core concepts.

# %%
# HW1: In your own words (as comments), explain:
# a) What is timing & performance?
# b) Why does it matter for a v2 pipeline?
# c) How did you apply it in studio today?

# %%
# HW2: Write a working example of the main concept from Week 8.
# It should be different from the examples in the core notebook.
# Use your own data, not the examples.

# %%
# HW3: What error would you get if you skip timing & performance?
# Write code that demonstrates the problem.
# Then write code that fixes it.

# %%
# HW4: Draw (in comments or print statements) a diagram
# showing how timing & performance fits into the v2 pipeline.

# %% [markdown]
# ---
# ## Practice (5-8)
#
# These exercises require applying concepts to new scenarios.

# %%
# HW5: Apply timing & performance to a new dataset.
# Create at least 15 rows of sample data.
# Show the output and verify it is correct.

# %%
# HW6: Write a function that combines timing & performance
# with one concept from a previous week.
# Example: combine with schema validation, or cleaning, etc.

# %%
# HW7: Handle at least 3 edge cases:
# a) Empty input
# b) Single row
# c) All identical values
# Show that your code handles each one gracefully.

# %%
# HW8: Write clear documentation (docstrings + comments)
# for the main function you wrote this week.
# Include: description, args, returns, example usage.

# %% [markdown]
# ---
# ## Challenge (9-11)
#
# These exercises push you beyond what was covered in class.

# %%
# HW9: Extend timing & performance with a feature not covered in class.
# Be creative! Think about what would be useful for your project.

# %%
# HW10: Write 3 tests for your implementation:
# a) Happy path test
# b) Edge case test
# c) Error handling test

# %%
# HW11: Compare two different approaches to timing & performance.
# Which is better and why? Show timing if applicable.

# %% [markdown]
# ---
# ## Mini-Project
#
# Combine everything from this week into one cohesive piece.

# %%
# HW12 (Mini-Project): Build a standalone tool that demonstrates
# mastery of timing & performance.
#
# Requirements:
# - At least 3 functions
# - Handles edge cases
# - Clear output with print statements
# - Demonstrates 3+ concepts from this week
# - Works with your project data

# %% [markdown]
# ---
# ## Reflection (Required - Complete before submitting)
#
# In the cell below, write 3-5 bullet points:
# 1. **What I learned today:**
# 2. **What was hardest:**
# 3. **What I still don't understand:**
# 4. **What I will review before next week:**
# 5. **If I used AI tools, what for:**

# %%
# YOUR REFLECTION (write as comments or as a multi-line string)
reflection = """
- What I learned:
- What was hardest:
- What I still don't understand:
- What I will review:
- AI tools used (if any):
"""
print(reflection)
