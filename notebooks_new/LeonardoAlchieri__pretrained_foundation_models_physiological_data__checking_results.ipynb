# %%
import pandas as pd
import os
from yaml import safe_load
from IPython.display import display


def present_results(path: str, val_method: str = "lopo") -> None:
    experiments = [f for f in os.listdir(path) if os.path.isdir(os.path.join(path, f))]
    results = []
    for exp in experiments:
        exp_path = os.path.join(path, exp)
        reports_path = os.path.join(exp_path, "reports.csv")
        if not os.path.exists(reports_path):
            print(f"Skipping {exp_path} as reports.csv does not exist.")
            continue
        report = pd.read_csv(reports_path, index_col=0)
        conf = safe_load(open(os.path.join(exp_path, ".hydra/config.yaml")))
        if conf['validation_method']['_target_'].split(".")[-1].lower() != val_method:
            continue
        model_name: str = conf["model"]["model"]["_target_"].split(".")[-1]
        features_name = (
            conf["feature_extractor"]["_target_"].split(".")[-1]
            if "model_name" not in conf["feature_extractor"]
            else conf["feature_extractor"]["model_name"]
        )
        validation_method = conf["validation_method"]["_target_"].split(".")[-1]
        if "aggregator" not in conf:
            aggregator = "MeanTimeAggregator"
        else:
            aggregator = conf["aggregator"]["_target_"].split(".")[-1] if "_target_" in conf["aggregator"] else None
        acc = report["accuracy"].mean()
        sem_acc = report["accuracy"].sem()
        # Collect results in a list of dicts
        results.append(
            {
                "Model": model_name,
                "Features": features_name,
                "Aggregator": aggregator,
                "Validation": validation_method,
                "Accuracy (%)": f"{acc*100:.0f}",
                "SEM (%)": f"{sem_acc*100:.0f}",
            }
        )

    # After the loop, display as a table
    display(pd.DataFrame(results).sort_values(by=["Model", "Features", "Aggregator"]))

# %% [markdown]
# # USILaughs

# %% [markdown]
# ## Left-side data

# %% [markdown]
# ### LOPO

# %%
import pandas as pd

present_results("../outputs/multirun_2025-06-17_17-42-08")
# Out:
#                  Model                 Features          Aggregator  \
# 6      DummyClassifier  AutonLab/MOMENT-1-large       CatAggregator
# 11     DummyClassifier  AutonLab/MOMENT-1-large  MeanChanAggregator
# 23     DummyClassifier  AutonLab/MOMENT-1-large  MeanTimeAggregator
# 20     DummyClassifier  AutonLab/MOMENT-1-large                None
# 16     DummyClassifier  amazon/chronos-t5-large       CatAggregator
# 1      DummyClassifier  amazon/chronos-t5-large  MeanChanAggregator
# 13     DummyClassifier  amazon/chronos-t5-large  MeanTimeAggregator
# 18     DummyClassifier  amazon/chronos-t5-large                None
# 8      DummyClassifier  amazon/chronos-t5-small       CatAggregator
# 0      DummyClassifier  amazon/chronos-t5-small  MeanChanAggregator
# 14     DummyClassifier  amazon/chronos-t5-small  MeanTimeAggregator
# 22     DummyClassifier  amazon/chronos-t5-small                None
# 15  LogisticRegression  AutonLab/MOMENT-1-large       CatAggregator
# 5   LogisticRegression  AutonLab/MOMENT-1-large  MeanChanAggregator
# 10  LogisticRegression  AutonLab/MOMENT-1-large  MeanTimeAggregator
# 9   LogisticRegression  AutonLab/MOMENT-1-large                None
# 17  LogisticRegression  amazon/chronos-t5-large       CatAggregator
# 7   LogisticRegression  amazon/chronos-t5-large  MeanChanAggregator
# 2   LogisticRegression  amazon/chronos-t5-large  MeanTimeAggregator
# 3   LogisticRegression  amazon/chronos-t5-large                None
# 21  LogisticRegression  amazon/chronos-t5-small       CatAggregator
# 12  LogisticRegression  amazon/chronos-t5-small  MeanChanAggregator
# 4   LogisticRegression  amazon/chronos-t5-small  MeanTimeAggregator
# 19  LogisticRegression  amazon/chronos-t5-small                None
#
#    Validation Accuracy (%) SEM (%)
# 6        LOPO           56       0
# 11       LOPO           56       0
# 23       LOPO           56       0
# 20       LOPO           56       0
# 16       LOPO           56       0
# 1        LOPO           56       0
# 13       LOPO           56       0
# 18       LOPO           56       0
# 8        LOPO           56       0
# 0        LOPO           56       0
# 14       LOPO           56       0
# 22       LOPO           56       0
# 15       LOPO           53       1
# 5        LOPO           54       1
# 10       LOPO           53       1
# 9        LOPO           52       1
# 17       LOPO           70       3
# 7        LOPO           72       3
# 2        LOPO           69       3
# 3        LOPO           56       0
# 21       LOPO           67       4
# 12       LOPO           69       3
# 4        LOPO           68       4
# 19       LOPO           56       0

# %%
# Out:
#                 Model                     Features Validation Accuracy (%)  \
# 0  LogisticRegression  HandcraftedFeatureExtractor       LOPO           64
# 1       XGBClassifier      amazon/chronos-t5-small       LOPO           69
# 2       XGBClassifier  HandcraftedFeatureExtractor       LOPO           64
# 3  LogisticRegression      amazon/chronos-t5-small       LOPO           68
# 4       XGBClassifier      amazon/chronos-t5-large       LOPO           69
# 5     DummyClassifier      amazon/chronos-t5-small       LOPO           56
# 6     DummyClassifier  HandcraftedFeatureExtractor       LOPO           56
# 7  LogisticRegression      amazon/chronos-t5-large       LOPO           69
# 8     DummyClassifier      amazon/chronos-t5-large       LOPO           56
#
#   SEM (%)
# 0       4
# 1       4
# 2       4
# 3       4
# 4       4
# 5       0
# 6       0
# 7       3
# 8       0

# %% [markdown]
# ### TACV

# %% [markdown]
# ## Right-side data

# %% [markdown]
# #### LOPO

# %%
present_results("../outputs/multirun_2025-06-18_08-58-59")
# Out:
#                  Model                     Features          Aggregator  \
# 30     DummyClassifier      AutonLab/MOMENT-1-large       CatAggregator
# 15     DummyClassifier      AutonLab/MOMENT-1-large  MeanChanAggregator
# 19     DummyClassifier      AutonLab/MOMENT-1-large  MeanTimeAggregator
# 1      DummyClassifier      AutonLab/MOMENT-1-large                None
# 0      DummyClassifier  HandcraftedFeatureExtractor       CatAggregator
# 20     DummyClassifier  HandcraftedFeatureExtractor  MeanChanAggregator
# 10     DummyClassifier  HandcraftedFeatureExtractor  MeanTimeAggregator
# 8      DummyClassifier  HandcraftedFeatureExtractor                None
# 17     DummyClassifier      amazon/chronos-t5-large       CatAggregator
# 31     DummyClassifier      amazon/chronos-t5-large  MeanChanAggregator
# 7      DummyClassifier      amazon/chronos-t5-large  MeanTimeAggregator
# 11     DummyClassifier      amazon/chronos-t5-large                None
# 21     DummyClassifier      amazon/chronos-t5-small       CatAggregator
# 2      DummyClassifier      amazon/chronos-t5-small  MeanChanAggregator
# 18     DummyClassifier      amazon/chronos-t5-small  MeanTimeAggregator
# 14     DummyClassifier      amazon/chronos-t5-small                None
# 9   LogisticRegression      AutonLab/MOMENT-1-large       CatAggregator
# 13  LogisticRegression      AutonLab/MOMENT-1-large  MeanChanAggregator
# 29  LogisticRegression      AutonLab/MOMENT-1-large  MeanTimeAggregator
# 26  LogisticRegression      AutonLab/MOMENT-1-large                None
# 22  LogisticRegression  HandcraftedFeatureExtractor       CatAggregator
# 16  LogisticRegression  HandcraftedFeatureExtractor  MeanChanAggregator
# 25  LogisticRegression  HandcraftedFeatureExtractor  MeanTimeAggregator
# 4   LogisticRegression  HandcraftedFeatureExtractor                None
# 28  LogisticRegression      amazon/chronos-t5-large       CatAggregator
# 3   LogisticRegression      amazon/chronos-t5-large  MeanChanAggregator
# 27  LogisticRegression      amazon/chronos-t5-large  MeanTimeAggregator
# 12  LogisticRegression      amazon/chronos-t5-large                None
# 6   LogisticRegression      amazon/chronos-t5-small       CatAggregator
# 5   LogisticRegression      amazon/chronos-t5-small  MeanChanAggregator
# 23  LogisticRegression      amazon/chronos-t5-small  MeanTimeAggregator
# 24  LogisticRegression      amazon/chronos-t5-small                None
#
#    Validation Accuracy (%) SEM (%)
# 30       LOPO           56       0
# 15       LOPO           56       0
# 19       LOPO           56       0
# 1        LOPO           56       0
# 0        LOPO           56       0
# 20       LOPO           56       0
# 10       LOPO           56       0
# 8        LOPO           56       0
# 17       LOPO           56       0
# 31       LOPO           56       0
# 7        LOPO           56       0
# 11       LOPO           56       0
# 21       LOPO           56       0
# 2        LOPO           56       0
# 18       LOPO           56       0
# 14       LOPO           56       0
# 9        LOPO           56       2
# 13       LOPO           55       2
# 29       LOPO           56       2
# 26       LOPO           53       2
# 22       LOPO           72       5
# 16       LOPO           72       5
# 25       LOPO           72       5
# 4        LOPO           72       5
# 28       LOPO           73       4
# 3        LOPO           73       4
# 27       LOPO           76       4
# 12       LOPO           56       0
# 6        LOPO           75       4
# 5        LOPO           74       4
# 23       LOPO           73       5
# 24       LOPO           56       0

# %%
present_results("../outputs/multirun_2025-06-23_11-03-31", val_method="lopo")
# Out:
#             Model                     Features          Aggregator Validation  \
# 4   XGBClassifier      AutonLab/MOMENT-1-large       CatAggregator       LOPO
# 6   XGBClassifier      AutonLab/MOMENT-1-large  MeanChanAggregator       LOPO
# 15  XGBClassifier      AutonLab/MOMENT-1-large  MeanTimeAggregator       LOPO
# 12  XGBClassifier      AutonLab/MOMENT-1-large                None       LOPO
# 8   XGBClassifier  HandcraftedFeatureExtractor       CatAggregator       LOPO
# 7   XGBClassifier  HandcraftedFeatureExtractor  MeanChanAggregator       LOPO
# 11  XGBClassifier  HandcraftedFeatureExtractor  MeanTimeAggregator       LOPO
# 1   XGBClassifier  HandcraftedFeatureExtractor                None       LOPO
# 14  XGBClassifier      amazon/chronos-t5-large       CatAggregator       LOPO
# 0   XGBClassifier      amazon/chronos-t5-large  MeanChanAggregator       LOPO
# 13  XGBClassifier      amazon/chronos-t5-large  MeanTimeAggregator       LOPO
# 5   XGBClassifier      amazon/chronos-t5-large                None       LOPO
# 3   XGBClassifier      amazon/chronos-t5-small       CatAggregator       LOPO
# 2   XGBClassifier      amazon/chronos-t5-small  MeanChanAggregator       LOPO
# 9   XGBClassifier      amazon/chronos-t5-small  MeanTimeAggregator       LOPO
# 10  XGBClassifier      amazon/chronos-t5-small                None       LOPO
#
#    Accuracy (%) SEM (%)
# 4            55       2
# 6            41       8
# 15           42       6
# 12           54       2
# 8            75       4
# 7            42       5
# 11           63       7
# 1            75       4
# 14           73       4
# 0            51       7
# 13           35       6
# 5            56       0
# 3            73       4
# 2            31       5
# 9            46      11
# 10           56       0

# %% [markdown]
# ### TACV

# %%
present_results("../outputs/multirun_2025-06-18_13-56-30")
# Out:
#                  Model                     Features          Aggregator  \
# 30     DummyClassifier      AutonLab/MOMENT-1-large       CatAggregator
# 15     DummyClassifier      AutonLab/MOMENT-1-large  MeanChanAggregator
# 19     DummyClassifier      AutonLab/MOMENT-1-large  MeanTimeAggregator
# 1      DummyClassifier      AutonLab/MOMENT-1-large                None
# 0      DummyClassifier  HandcraftedFeatureExtractor       CatAggregator
# 20     DummyClassifier  HandcraftedFeatureExtractor  MeanChanAggregator
# 10     DummyClassifier  HandcraftedFeatureExtractor  MeanTimeAggregator
# 8      DummyClassifier  HandcraftedFeatureExtractor                None
# 17     DummyClassifier      amazon/chronos-t5-large       CatAggregator
# 31     DummyClassifier      amazon/chronos-t5-large  MeanChanAggregator
# 7      DummyClassifier      amazon/chronos-t5-large  MeanTimeAggregator
# 11     DummyClassifier      amazon/chronos-t5-large                None
# 21     DummyClassifier      amazon/chronos-t5-small       CatAggregator
# 2      DummyClassifier      amazon/chronos-t5-small  MeanChanAggregator
# 18     DummyClassifier      amazon/chronos-t5-small  MeanTimeAggregator
# 14     DummyClassifier      amazon/chronos-t5-small                None
# 9   LogisticRegression      AutonLab/MOMENT-1-large       CatAggregator
# 13  LogisticRegression      AutonLab/MOMENT-1-large  MeanChanAggregator
# 29  LogisticRegression      AutonLab/MOMENT-1-large  MeanTimeAggregator
# 26  LogisticRegression      AutonLab/MOMENT-1-large                None
# 22  LogisticRegression  HandcraftedFeatureExtractor       CatAggregator
# 16  LogisticRegression  HandcraftedFeatureExtractor  MeanChanAggregator
# 25  LogisticRegression  HandcraftedFeatureExtractor  MeanTimeAggregator
# 4   LogisticRegression  HandcraftedFeatureExtractor                None
# 28  LogisticRegression      amazon/chronos-t5-large       CatAggregator
# 3   LogisticRegression      amazon/chronos-t5-large  MeanChanAggregator
# 27  LogisticRegression      amazon/chronos-t5-large  MeanTimeAggregator
# 12  LogisticRegression      amazon/chronos-t5-large                None
# 6   LogisticRegression      amazon/chronos-t5-small       CatAggregator
# 5   LogisticRegression      amazon/chronos-t5-small  MeanChanAggregator
# 23  LogisticRegression      amazon/chronos-t5-small  MeanTimeAggregator
# 24  LogisticRegression      amazon/chronos-t5-small                None
#
#    Validation Accuracy (%) SEM (%)
# 30       TACV           56       0
# 15       TACV           56       0
# 19       TACV           56       0
# 1        TACV           56       0
# 0        TACV           56       0
# 20       TACV           56       0
# 10       TACV           56       0
# 8        TACV           56       0
# 17       TACV           56       0
# 31       TACV           56       0
# 7        TACV           56       0
# 11       TACV           56       0
# 21       TACV           56       0
# 2        TACV           56       0
# 18       TACV           56       0
# 14       TACV           56       0
# 9        TACV           57       3
# 13       TACV           58       3
# 29       TACV           57       3
# 26       TACV           54       4
# 22       TACV           74       4
# 16       TACV           74       4
# 25       TACV           74       4
# 4        TACV           74       4
# 28       TACV           76       4
# 3        TACV           78       5
# 27       TACV           81       4
# 12       TACV           56       0
# 6        TACV           80       2
# 5        TACV           77       3
# 23       TACV           77       4
# 24       TACV           56       0

# %%
present_results("../outputs/multirun_2025-06-20_10-46-02")
# Out:
#             Model                     Features          Aggregator Validation  \
# 4   XGBClassifier      AutonLab/MOMENT-1-large       CatAggregator       TACV
# 6   XGBClassifier      AutonLab/MOMENT-1-large  MeanChanAggregator       TACV
# 15  XGBClassifier      AutonLab/MOMENT-1-large  MeanTimeAggregator       TACV
# 12  XGBClassifier      AutonLab/MOMENT-1-large                None       TACV
# 8   XGBClassifier  HandcraftedFeatureExtractor       CatAggregator       TACV
# 7   XGBClassifier  HandcraftedFeatureExtractor  MeanChanAggregator       TACV
# 11  XGBClassifier  HandcraftedFeatureExtractor  MeanTimeAggregator       TACV
# 1   XGBClassifier  HandcraftedFeatureExtractor                None       TACV
# 14  XGBClassifier      amazon/chronos-t5-large       CatAggregator       TACV
# 0   XGBClassifier      amazon/chronos-t5-large  MeanChanAggregator       TACV
# 13  XGBClassifier      amazon/chronos-t5-large  MeanTimeAggregator       TACV
# 5   XGBClassifier      amazon/chronos-t5-large                None       TACV
# 3   XGBClassifier      amazon/chronos-t5-small       CatAggregator       TACV
# 2   XGBClassifier      amazon/chronos-t5-small  MeanChanAggregator       TACV
# 9   XGBClassifier      amazon/chronos-t5-small  MeanTimeAggregator       TACV
# 10  XGBClassifier      amazon/chronos-t5-small                None       TACV
#
#    Accuracy (%) SEM (%)
# 4            56       2
# 6            57       4
# 15           56       2
# 12           56       3
# 8            81       3
# 7            81       3
# 11           81       3
# 1            81       3
# 14           74       3
# 0            79       3
# 13           74       3
# 5            56       0
# 3            76       2
# 2            79       3
# 9            76       3
# 10           56       0

# %% [markdown]
# # APSYNC (4sec) - engagement (> 4 high, <= 4 low)

# %% [markdown]
# ## LOPO

# %%
present_results("../outputs/multirun_2025-06-24_13-08-52", val_method="lopo")
# Out:
# Skipping ../outputs/multirun_2025-06-24_13-08-52/45 as reports.csv does not exist.
# Skipping ../outputs/multirun_2025-06-24_13-08-52/28 as reports.csv does not exist.
# Skipping ../outputs/multirun_2025-06-24_13-08-52/21 as reports.csv does not exist.
# Skipping ../outputs/multirun_2025-06-24_13-08-52/44 as reports.csv does not exist.
# Skipping ../outputs/multirun_2025-06-24_13-08-52/36 as reports.csv does not exist.
# Skipping ../outputs/multirun_2025-06-24_13-08-52/53 as reports.csv does not exist.
# Skipping ../outputs/multirun_2025-06-24_13-08-52/37 as reports.csv does not exist.
# Skipping ../outputs/multirun_2025-06-24_13-08-52/52 as reports.csv does not exist.
# Skipping ../outputs/multirun_2025-06-24_13-08-52/4 as reports.csv does not exist.
# Skipping ../outputs/multirun_2025-06-24_13-08-52/12 as reports.csv does not exist.
# Skipping ../outputs/multirun_2025-06-24_13-08-52/13 as reports.csv does not exist.
# Skipping ../outputs/multirun_2025-06-24_13-08-52/5 as reports.csv does not exist.
#                  Model                     Features          Aggregator  \
# 20     DummyClassifier  HandcraftedFeatureExtractor       CatAggregator
# 18     DummyClassifier  HandcraftedFeatureExtractor  MeanChanAggregator
# 2      DummyClassifier  HandcraftedFeatureExtractor  MeanTimeAggregator
# 1      DummyClassifier  HandcraftedFeatureExtractor                None
# 8      DummyClassifier      amazon/chronos-t5-large       CatAggregator
# 0      DummyClassifier      amazon/chronos-t5-large  MeanChanAggregator
# 3      DummyClassifier      amazon/chronos-t5-large  MeanTimeAggregator
# 4      DummyClassifier      amazon/chronos-t5-large                None
# 17     DummyClassifier      amazon/chronos-t5-small       CatAggregator
# 15     DummyClassifier      amazon/chronos-t5-small  MeanChanAggregator
# 14     DummyClassifier      amazon/chronos-t5-small  MeanTimeAggregator
# 13     DummyClassifier      amazon/chronos-t5-small                None
# 12  LogisticRegression  HandcraftedFeatureExtractor       CatAggregator
# 7   LogisticRegression  HandcraftedFeatureExtractor  MeanChanAggregator
# 19  LogisticRegression  HandcraftedFeatureExtractor  MeanTimeAggregator
# 6   LogisticRegression  HandcraftedFeatureExtractor                None
# 10  LogisticRegression      amazon/chronos-t5-large       CatAggregator
# 5   LogisticRegression      amazon/chronos-t5-large  MeanChanAggregator
# 11  LogisticRegression      amazon/chronos-t5-large  MeanTimeAggregator
# 21  LogisticRegression      amazon/chronos-t5-large                None
# 22  LogisticRegression      amazon/chronos-t5-small       CatAggregator
# 23  LogisticRegression      amazon/chronos-t5-small  MeanChanAggregator
# 16  LogisticRegression      amazon/chronos-t5-small  MeanTimeAggregator
# 9   LogisticRegression      amazon/chronos-t5-small                None
#
#    Validation Accuracy (%) SEM (%)
# 20       LOPO           47       5
# 18       LOPO           47       5
# 2        LOPO           47       5
# 1        LOPO           47       5
# 8        LOPO           47       5
# 0        LOPO           47       5
# 3        LOPO           47       5
# 4        LOPO           47       5
# 17       LOPO           47       5
# 15       LOPO           47       5
# 14       LOPO           47       5
# 13       LOPO           47       5
# 12       LOPO           61       6
# 7        LOPO           61       6
# 19       LOPO           61       6
# 6        LOPO           61       6
# 10       LOPO           48       5
# 5        LOPO           49       8
# 11       LOPO           49       8
# 21       LOPO           49       8
# 22       LOPO           46       4
# 23       LOPO           52       7
# 16       LOPO           49       8
# 9        LOPO           49       8

# %%
present_results("../outputs/multirun_2025-06-24_13-40-40", val_method="lopo")
# Out:
#                  Model                 Features          Aggregator  \
# 0      DummyClassifier  AutonLab/MOMENT-1-large       CatAggregator
# 10     DummyClassifier  AutonLab/MOMENT-1-large  MeanChanAggregator
# 5      DummyClassifier  AutonLab/MOMENT-1-large  MeanTimeAggregator
# 3      DummyClassifier  AutonLab/MOMENT-1-large                None
# 15     DummyClassifier  amazon/chronos-t5-small       CatAggregator
# 7      DummyClassifier  amazon/chronos-t5-small  MeanChanAggregator
# 9      DummyClassifier  amazon/chronos-t5-small  MeanTimeAggregator
# 1      DummyClassifier  amazon/chronos-t5-small                None
# 11  LogisticRegression  AutonLab/MOMENT-1-large       CatAggregator
# 8   LogisticRegression  AutonLab/MOMENT-1-large  MeanChanAggregator
# 12  LogisticRegression  AutonLab/MOMENT-1-large  MeanTimeAggregator
# 2   LogisticRegression  AutonLab/MOMENT-1-large                None
# 4   LogisticRegression  amazon/chronos-t5-small       CatAggregator
# 6   LogisticRegression  amazon/chronos-t5-small  MeanChanAggregator
# 14  LogisticRegression  amazon/chronos-t5-small  MeanTimeAggregator
# 13  LogisticRegression  amazon/chronos-t5-small                None
#
#    Validation Accuracy (%) SEM (%)
# 0        LOPO           47       5
# 10       LOPO           47       5
# 5        LOPO           47       5
# 3        LOPO           47       5
# 15       LOPO           47       5
# 7        LOPO           47       5
# 9        LOPO           47       5
# 1        LOPO           47       5
# 11       LOPO           45       4
# 8        LOPO           49       7
# 12       LOPO           45       4
# 2        LOPO           48       6
# 4        LOPO           46       4
# 6        LOPO           52       7
# 14       LOPO           49       8
# 13       LOPO           49       8

# %% [markdown]
# ## TACV

# %%
present_results("../outputs/multirun_2025-06-24_13-08-52", val_method="tacv")
present_results("../outputs/multirun_2025-06-24_13-40-40", val_method="tacv")
# Out:
# Skipping ../outputs/multirun_2025-06-24_13-08-52/45 as reports.csv does not exist.
# Skipping ../outputs/multirun_2025-06-24_13-08-52/28 as reports.csv does not exist.
# Skipping ../outputs/multirun_2025-06-24_13-08-52/21 as reports.csv does not exist.
# Skipping ../outputs/multirun_2025-06-24_13-08-52/44 as reports.csv does not exist.
# Skipping ../outputs/multirun_2025-06-24_13-08-52/36 as reports.csv does not exist.
# Skipping ../outputs/multirun_2025-06-24_13-08-52/53 as reports.csv does not exist.
# Skipping ../outputs/multirun_2025-06-24_13-08-52/37 as reports.csv does not exist.
# Skipping ../outputs/multirun_2025-06-24_13-08-52/52 as reports.csv does not exist.
# Skipping ../outputs/multirun_2025-06-24_13-08-52/4 as reports.csv does not exist.
# Skipping ../outputs/multirun_2025-06-24_13-08-52/12 as reports.csv does not exist.
# Skipping ../outputs/multirun_2025-06-24_13-08-52/13 as reports.csv does not exist.
# Skipping ../outputs/multirun_2025-06-24_13-08-52/5 as reports.csv does not exist.
#                  Model                     Features          Aggregator  \
# 17     DummyClassifier  HandcraftedFeatureExtractor       CatAggregator
# 21     DummyClassifier  HandcraftedFeatureExtractor  MeanChanAggregator
# 1      DummyClassifier  HandcraftedFeatureExtractor  MeanTimeAggregator
# 4      DummyClassifier  HandcraftedFeatureExtractor                None
# 12     DummyClassifier      amazon/chronos-t5-large       CatAggregator
# 3      DummyClassifier      amazon/chronos-t5-large  MeanChanAggregator
# 0      DummyClassifier      amazon/chronos-t5-large  MeanTimeAggregator
# 2      DummyClassifier      amazon/chronos-t5-large                None
# 22     DummyClassifier      amazon/chronos-t5-small       CatAggregator
# 15     DummyClassifier      amazon/chronos-t5-small  MeanChanAggregator
# 16     DummyClassifier      amazon/chronos-t5-small  MeanTimeAggregator
# 14     DummyClassifier      amazon/chronos-t5-small                None
# 6   LogisticRegression  HandcraftedFeatureExtractor       CatAggregator
# 9   LogisticRegression  HandcraftedFeatureExtractor  MeanChanAggregator
# 23  LogisticRegression  HandcraftedFeatureExtractor  MeanTimeAggregator
# 10  LogisticRegression  HandcraftedFeatureExtractor                None
# 7   LogisticRegression      amazon/chronos-t5-large       CatAggregator
# 11  LogisticRegression      amazon/chronos-t5-large  MeanChanAggregator
# 5   LogisticRegression      amazon/chronos-t5-large  MeanTimeAggregator
# 20  LogisticRegression      amazon/chronos-t5-large                None
# 19  LogisticRegression      amazon/chronos-t5-small       CatAggregator
# 18  LogisticRegression      amazon/chronos-t5-small  MeanChanAggregator
# 13  LogisticRegression      amazon/chronos-t5-small  MeanTimeAggregator
# 8   LogisticRegression      amazon/chronos-t5-small                None
#
#    Validation Accuracy (%) SEM (%)
# 17       TACV           53       5
# 21       TACV           53       5
# 1        TACV           53       5
# 4        TACV           53       5
# 12       TACV           53       5
# 3        TACV           53       5
# 0        TACV           53       5
# 2        TACV           53       5
# 22       TACV           53       5
# 15       TACV           53       5
# 16       TACV           53       5
# 14       TACV           53       5
# 6        TACV           59       6
# 9        TACV           59       6
# 23       TACV           59       6
# 10       TACV           59       6
# 7        TACV           53       3
# 11       TACV           53       5
# 5        TACV           53       5
# 20       TACV           53       5
# 19       TACV           51       2
# 18       TACV           54       4
# 13       TACV           53       5
# 8        TACV           53       5
#                  Model                 Features          Aggregator  \
# 8      DummyClassifier  AutonLab/MOMENT-1-large       CatAggregator
# 15     DummyClassifier  AutonLab/MOMENT-1-large  MeanChanAggregator
# 4      DummyClassifier  AutonLab/MOMENT-1-large  MeanTimeAggregator
# 5      DummyClassifier  AutonLab/MOMENT-1-large                None
# 10     DummyClassifier  amazon/chronos-t5-small       CatAggregator
# 0      DummyClassifier  amazon/chronos-t5-small  MeanChanAggregator
# 9      DummyClassifier  amazon/chronos-t5-small  MeanTimeAggregator
# 7      DummyClassifier  amazon/chronos-t5-small                None
# 14  LogisticRegression  AutonLab/MOMENT-1-large       CatAggregator
# 1   LogisticRegression  AutonLab/MOMENT-1-large  MeanChanAggregator
# 13  LogisticRegression  AutonLab/MOMENT-1-large  MeanTimeAggregator
# 6   LogisticRegression  AutonLab/MOMENT-1-large                None
# 3   LogisticRegression  amazon/chronos-t5-small       CatAggregator
# 2   LogisticRegression  amazon/chronos-t5-small  MeanChanAggregator
# 11  LogisticRegression  amazon/chronos-t5-small  MeanTimeAggregator
# 12  LogisticRegression  amazon/chronos-t5-small                None
#
#    Validation Accuracy (%) SEM (%)
# 8        TACV           53       5
# 15       TACV           53       5
# 4        TACV           53       5
# 5        TACV           53       5
# 10       TACV           53       5
# 0        TACV           53       5
# 9        TACV           53       5
# 7        TACV           53       5
# 14       TACV           50       2
# 1        TACV           54       5
# 13       TACV           50       2
# 6        TACV           54       5
# 3        TACV           51       2
# 2        TACV           54       4
# 11       TACV           53       5
# 12       TACV           53       5

# %% [markdown]
# # APSYNC (4sec) - enjoyment (> 4 high, <= 4 low)

# %% [markdown]
# ## LOPO

# %%
present_results("../outputs/multirun_2025-06-24_14-40-15", val_method="lopo")
# Out:
#                  Model                     Features          Aggregator  \
# 16     DummyClassifier      AutonLab/MOMENT-1-large       CatAggregator
# 22     DummyClassifier      AutonLab/MOMENT-1-large  MeanChanAggregator
# 4      DummyClassifier      AutonLab/MOMENT-1-large  MeanTimeAggregator
# 18     DummyClassifier      AutonLab/MOMENT-1-large                None
# 28     DummyClassifier  HandcraftedFeatureExtractor       CatAggregator
# 24     DummyClassifier  HandcraftedFeatureExtractor  MeanChanAggregator
# 2      DummyClassifier  HandcraftedFeatureExtractor  MeanTimeAggregator
# 1      DummyClassifier  HandcraftedFeatureExtractor                None
# 10     DummyClassifier      amazon/chronos-t5-large       CatAggregator
# 0      DummyClassifier      amazon/chronos-t5-large  MeanChanAggregator
# 3      DummyClassifier      amazon/chronos-t5-large  MeanTimeAggregator
# 5      DummyClassifier      amazon/chronos-t5-large                None
# 23     DummyClassifier      amazon/chronos-t5-small       CatAggregator
# 20     DummyClassifier      amazon/chronos-t5-small  MeanChanAggregator
# 19     DummyClassifier      amazon/chronos-t5-small  MeanTimeAggregator
# 17     DummyClassifier      amazon/chronos-t5-small                None
# 27  LogisticRegression      AutonLab/MOMENT-1-large       CatAggregator
# 6   LogisticRegression      AutonLab/MOMENT-1-large  MeanChanAggregator
# 12  LogisticRegression      AutonLab/MOMENT-1-large  MeanTimeAggregator
# 26  LogisticRegression      AutonLab/MOMENT-1-large                None
# 15  LogisticRegression  HandcraftedFeatureExtractor       CatAggregator
# 9   LogisticRegression  HandcraftedFeatureExtractor  MeanChanAggregator
# 25  LogisticRegression  HandcraftedFeatureExtractor  MeanTimeAggregator
# 8   LogisticRegression  HandcraftedFeatureExtractor                None
# 13  LogisticRegression      amazon/chronos-t5-large       CatAggregator
# 7   LogisticRegression      amazon/chronos-t5-large  MeanChanAggregator
# 14  LogisticRegression      amazon/chronos-t5-large  MeanTimeAggregator
# 29  LogisticRegression      amazon/chronos-t5-large                None
# 30  LogisticRegression      amazon/chronos-t5-small       CatAggregator
# 31  LogisticRegression      amazon/chronos-t5-small  MeanChanAggregator
# 21  LogisticRegression      amazon/chronos-t5-small  MeanTimeAggregator
# 11  LogisticRegression      amazon/chronos-t5-small                None
#
#    Validation Accuracy (%) SEM (%)
# 16       LOPO           58      10
# 22       LOPO           58      10
# 4        LOPO           58      10
# 18       LOPO           58      10
# 28       LOPO           58      10
# 24       LOPO           58      10
# 2        LOPO           58      10
# 1        LOPO           58      10
# 10       LOPO           58      10
# 0        LOPO           58      10
# 3        LOPO           58      10
# 5        LOPO           58      10
# 23       LOPO           58      10
# 20       LOPO           58      10
# 19       LOPO           58      10
# 17       LOPO           58      10
# 27       LOPO           55      10
# 6        LOPO           57      10
# 12       LOPO           55      10
# 26       LOPO           57      10
# 15       LOPO           47       7
# 9        LOPO           47       7
# 25       LOPO           47       7
# 8        LOPO           47       7
# 13       LOPO           54      10
# 7        LOPO           58      10
# 14       LOPO           57      10
# 29       LOPO           58      10
# 30       LOPO           56      10
# 31       LOPO           58      10
# 21       LOPO           58      10
# 11       LOPO           58      10

# %% [markdown]
# ## TACV

# %%
present_results("../outputs/multirun_2025-06-24_14-40-15", val_method="tacv")
# Out:
#                  Model                     Features          Aggregator  \
# 11     DummyClassifier      AutonLab/MOMENT-1-large       CatAggregator
# 18     DummyClassifier      AutonLab/MOMENT-1-large  MeanChanAggregator
# 0      DummyClassifier      AutonLab/MOMENT-1-large  MeanTimeAggregator
# 19     DummyClassifier      AutonLab/MOMENT-1-large                None
# 23     DummyClassifier  HandcraftedFeatureExtractor       CatAggregator
# 27     DummyClassifier  HandcraftedFeatureExtractor  MeanChanAggregator
# 2      DummyClassifier  HandcraftedFeatureExtractor  MeanTimeAggregator
# 5      DummyClassifier  HandcraftedFeatureExtractor                None
# 16     DummyClassifier      amazon/chronos-t5-large       CatAggregator
# 4      DummyClassifier      amazon/chronos-t5-large  MeanChanAggregator
# 1      DummyClassifier      amazon/chronos-t5-large  MeanTimeAggregator
# 3      DummyClassifier      amazon/chronos-t5-large                None
# 28     DummyClassifier      amazon/chronos-t5-small       CatAggregator
# 21     DummyClassifier      amazon/chronos-t5-small  MeanChanAggregator
# 22     DummyClassifier      amazon/chronos-t5-small  MeanTimeAggregator
# 20     DummyClassifier      amazon/chronos-t5-small                None
# 29  LogisticRegression      AutonLab/MOMENT-1-large       CatAggregator
# 15  LogisticRegression      AutonLab/MOMENT-1-large  MeanChanAggregator
# 10  LogisticRegression      AutonLab/MOMENT-1-large  MeanTimeAggregator
# 30  LogisticRegression      AutonLab/MOMENT-1-large                None
# 7   LogisticRegression  HandcraftedFeatureExtractor       CatAggregator
# 12  LogisticRegression  HandcraftedFeatureExtractor  MeanChanAggregator
# 31  LogisticRegression  HandcraftedFeatureExtractor  MeanTimeAggregator
# 13  LogisticRegression  HandcraftedFeatureExtractor                None
# 8   LogisticRegression      amazon/chronos-t5-large       CatAggregator
# 14  LogisticRegression      amazon/chronos-t5-large  MeanChanAggregator
# 6   LogisticRegression      amazon/chronos-t5-large  MeanTimeAggregator
# 26  LogisticRegression      amazon/chronos-t5-large                None
# 25  LogisticRegression      amazon/chronos-t5-small       CatAggregator
# 24  LogisticRegression      amazon/chronos-t5-small  MeanChanAggregator
# 17  LogisticRegression      amazon/chronos-t5-small  MeanTimeAggregator
# 9   LogisticRegression      amazon/chronos-t5-small                None
#
#    Validation Accuracy (%) SEM (%)
# 11       TACV           60       7
# 18       TACV           60       7
# 0        TACV           60       7
# 19       TACV           60       7
# 23       TACV           60       7
# 27       TACV           60       7
# 2        TACV           60       7
# 5        TACV           60       7
# 16       TACV           60       7
# 4        TACV           60       7
# 1        TACV           60       7
# 3        TACV           60       7
# 28       TACV           60       7
# 21       TACV           60       7
# 22       TACV           60       7
# 20       TACV           60       7
# 29       TACV           57       7
# 15       TACV           60       7
# 10       TACV           57       7
# 30       TACV           60       7
# 7        TACV           47       7
# 12       TACV           47       7
# 31       TACV           47       7
# 13       TACV           47       7
# 8        TACV           60       7
# 14       TACV           60       7
# 6        TACV           60       6
# 26       TACV           60       7
# 25       TACV           60       7
# 24       TACV           60       7
# 17       TACV           60       7
# 9        TACV           60       7

# %% [markdown]
# # APSYNC (10 seconds) - engagement (> 4 high, <= 4 low)

# %% [markdown]
# ## LOPO

# %%
present_results("../outputs/multirun_2025-06-27_18-11-06", val_method="lopo")
# Out:
# Skipping ../outputs/multirun_2025-06-27_18-11-06/20 as reports.csv does not exist.
# Skipping ../outputs/multirun_2025-06-27_18-11-06/18 as reports.csv does not exist.
# Skipping ../outputs/multirun_2025-06-27_18-11-06/27 as reports.csv does not exist.
# Skipping ../outputs/multirun_2025-06-27_18-11-06/9 as reports.csv does not exist.
# Skipping ../outputs/multirun_2025-06-27_18-11-06/0 as reports.csv does not exist.
# Skipping ../outputs/multirun_2025-06-27_18-11-06/11 as reports.csv does not exist.
# Skipping ../outputs/multirun_2025-06-27_18-11-06/7 as reports.csv does not exist.
# Skipping ../outputs/multirun_2025-06-27_18-11-06/16 as reports.csv does not exist.
# Skipping ../outputs/multirun_2025-06-27_18-11-06/6 as reports.csv does not exist.
# Skipping ../outputs/multirun_2025-06-27_18-11-06/17 as reports.csv does not exist.
# Skipping ../outputs/multirun_2025-06-27_18-11-06/1 as reports.csv does not exist.
# Skipping ../outputs/multirun_2025-06-27_18-11-06/10 as reports.csv does not exist.
# Skipping ../outputs/multirun_2025-06-27_18-11-06/19 as reports.csv does not exist.
# Skipping ../outputs/multirun_2025-06-27_18-11-06/26 as reports.csv does not exist.
# Skipping ../outputs/multirun_2025-06-27_18-11-06/8 as reports.csv does not exist.
# Skipping ../outputs/multirun_2025-06-27_18-11-06/21 as reports.csv does not exist.
# Skipping ../outputs/multirun_2025-06-27_18-11-06/24 as reports.csv does not exist.
# Skipping ../outputs/multirun_2025-06-27_18-11-06/23 as reports.csv does not exist.
# Skipping ../outputs/multirun_2025-06-27_18-11-06/4 as reports.csv does not exist.
# Skipping ../outputs/multirun_2025-06-27_18-11-06/15 as reports.csv does not exist.
# Skipping ../outputs/multirun_2025-06-27_18-11-06/3 as reports.csv does not exist.
# Skipping ../outputs/multirun_2025-06-27_18-11-06/12 as reports.csv does not exist.
# Skipping ../outputs/multirun_2025-06-27_18-11-06/2 as reports.csv does not exist.
# Skipping ../outputs/multirun_2025-06-27_18-11-06/13 as reports.csv does not exist.
# Skipping ../outputs/multirun_2025-06-27_18-11-06/5 as reports.csv does not exist.
# Skipping ../outputs/multirun_2025-06-27_18-11-06/14 as reports.csv does not exist.
# Skipping ../outputs/multirun_2025-06-27_18-11-06/22 as reports.csv does not exist.
# Skipping ../outputs/multirun_2025-06-27_18-11-06/25 as reports.csv does not exist.
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /var/folders/rc/t3h_b88s3vbg5dcd4pnlgskr0000gp/T/ipykernel_26971/298283373.py in ?()
# ----> 1 present_results("../outputs/multirun_2025-06-27_18-11-06", val_method="lopo")
#
# /var/folders/rc/t3h_b88s3vbg5dcd4pnlgskr0000gp/T/ipykernel_26971/1631156344.py in ?(path, val_method)
#      42             }
#      43         )
#      44
#      45     # After the loop, display as a table
# ---> 46     display(pd.DataFrame(results).sort_values(by=["Model", "Features", "Aggregator"]))
#
# ~/mambaforge/envs/pff/lib/python3.11/site-packages/pandas/core/frame.py in ?(self, by, axis, ascending, inplace, kind, na_position, ignore_index, key)
#    6923                 f"Length of ascending ({len(ascending)})"  # type: ignore[arg-type]
#    6924                 f" != length of by ({len(by)})"
#    6925             )
#    6926         if len(by) > 1:
# -> 6927             keys = [self._get_label_or_level_values(x, axis=axis) for x in by]
#    6928
#    6929             # need to rewrap columns in Series to apply key function
#    6930             if key is not None:
#
# ~/mambaforge/envs/pff/lib/python3.11/site-packages/pandas/core/frame.py in ?(.0)
# -> 6927         ...     key=lambda x: np.argsort(index_natsorted(df["time"]))
#
# ~/mambaforge/envs/pff/lib/python3.11/site-packages/pandas/core/generic.py in ?(self, key, axis)
#    1840             values = self.xs(key, axis=other_axes[0])._values
#    1841         elif self._is_level_reference(key, axis=axis):
#    1842             values = self.axes[axis].get_level_values(key)._values
#    1843         else:
# -> 1844             raise KeyError(key)
#    1845
#    1846         # Check for duplicates
#    1847         if values.ndim > 1:
#
# KeyError: 'Model'

# %% [markdown]
# ## TACV

# %%
present_results("../outputs/multirun_2025-06-27_16-23-32", val_method="tacv")
# Out:
# Skipping ../outputs/multirun_2025-06-27_16-23-32/20 as reports.csv does not exist.
# Skipping ../outputs/multirun_2025-06-27_16-23-32/18 as reports.csv does not exist.
# Skipping ../outputs/multirun_2025-06-27_16-23-32/27 as reports.csv does not exist.
# Skipping ../outputs/multirun_2025-06-27_16-23-32/19 as reports.csv does not exist.
# Skipping ../outputs/multirun_2025-06-27_16-23-32/26 as reports.csv does not exist.
# Skipping ../outputs/multirun_2025-06-27_16-23-32/21 as reports.csv does not exist.
# Skipping ../outputs/multirun_2025-06-27_16-23-32/24 as reports.csv does not exist.
# Skipping ../outputs/multirun_2025-06-27_16-23-32/23 as reports.csv does not exist.
# Skipping ../outputs/multirun_2025-06-27_16-23-32/22 as reports.csv does not exist.
# Skipping ../outputs/multirun_2025-06-27_16-23-32/25 as reports.csv does not exist.
#                 Model                     Features     Aggregator Validation  \
# 3     DummyClassifier  HandcraftedFeatureExtractor           None       TACV
# 2  LogisticRegression  HandcraftedFeatureExtractor           None       TACV
# 1  LogisticRegression      amazon/chronos-t5-large  CatAggregator       TACV
# 0  LogisticRegression      amazon/chronos-t5-large           None       TACV
#
#   Accuracy (%) SEM (%)
# 3           55       4
# 2           64       7
# 1           49       3
# 0           53       5

# %% [markdown]
# # APSYNC (60 seconds) - engagement (> 4 high, <= 4 low)

# %% [markdown]
# ## LOPO

# %%
present_results("../outputs/multirun_2025-06-24_17-02-26", val_method="lopo")
# Out:
# Skipping ../outputs/multirun_2025-06-24_17-02-26/44 as reports.csv does not exist.
#                  Model                     Features          Aggregator  \
# 13     DummyClassifier      AutonLab/MOMENT-1-large                None
# 18     DummyClassifier  HandcraftedFeatureExtractor       CatAggregator
# 0      DummyClassifier  HandcraftedFeatureExtractor                None
# 6      DummyClassifier      amazon/chronos-t5-large       CatAggregator
# 1      DummyClassifier      amazon/chronos-t5-large                None
# 12     DummyClassifier      amazon/chronos-t5-small                None
# 17  LogisticRegression      AutonLab/MOMENT-1-large       CatAggregator
# 2   LogisticRegression      AutonLab/MOMENT-1-large  MeanChanAggregator
# 8   LogisticRegression      AutonLab/MOMENT-1-large  MeanTimeAggregator
# 16  LogisticRegression      AutonLab/MOMENT-1-large                None
# 11  LogisticRegression  HandcraftedFeatureExtractor       CatAggregator
# 5   LogisticRegression  HandcraftedFeatureExtractor  MeanChanAggregator
# 15  LogisticRegression  HandcraftedFeatureExtractor  MeanTimeAggregator
# 4   LogisticRegression  HandcraftedFeatureExtractor                None
# 9   LogisticRegression      amazon/chronos-t5-large       CatAggregator
# 3   LogisticRegression      amazon/chronos-t5-large  MeanChanAggregator
# 10  LogisticRegression      amazon/chronos-t5-large  MeanTimeAggregator
# 19  LogisticRegression      amazon/chronos-t5-large                None
# 20  LogisticRegression      amazon/chronos-t5-small       CatAggregator
# 21  LogisticRegression      amazon/chronos-t5-small  MeanChanAggregator
# 14  LogisticRegression      amazon/chronos-t5-small  MeanTimeAggregator
# 7   LogisticRegression      amazon/chronos-t5-small                None
#
#    Validation Accuracy (%) SEM (%)
# 13       LOPO           33       5
# 18       LOPO           33       5
# 0        LOPO           33       5
# 6        LOPO           33       5
# 1        LOPO           33       5
# 12       LOPO           33       5
# 17       LOPO           56      10
# 2        LOPO           37       7
# 8        LOPO           56      10
# 16       LOPO           39       6
# 11       LOPO           59       9
# 5        LOPO           59       9
# 15       LOPO           59       9
# 4        LOPO           59       9
# 9        LOPO           35       6
# 3        LOPO           37       4
# 10       LOPO           35       4
# 19       LOPO           35       4
# 20       LOPO           54       9
# 21       LOPO           39       3
# 14       LOPO           39       6
# 7        LOPO           35       4

# %% [markdown]
# ## TACV

# %%
present_results("../outputs/multirun_2025-06-24_17-02-26", val_method="tacv")
# Out:
# Skipping ../outputs/multirun_2025-06-24_17-02-26/44 as reports.csv does not exist.
#                  Model                     Features          Aggregator  \
# 13     DummyClassifier      AutonLab/MOMENT-1-large                None
# 15     DummyClassifier  HandcraftedFeatureExtractor       CatAggregator
# 1      DummyClassifier  HandcraftedFeatureExtractor                None
# 11     DummyClassifier      amazon/chronos-t5-large       CatAggregator
# 0      DummyClassifier      amazon/chronos-t5-large                None
# 14     DummyClassifier      amazon/chronos-t5-small                None
# 19  LogisticRegression      AutonLab/MOMENT-1-large       CatAggregator
# 10  LogisticRegression      AutonLab/MOMENT-1-large  MeanChanAggregator
# 6   LogisticRegression      AutonLab/MOMENT-1-large  MeanTimeAggregator
# 20  LogisticRegression      AutonLab/MOMENT-1-large                None
# 3   LogisticRegression  HandcraftedFeatureExtractor       CatAggregator
# 7   LogisticRegression  HandcraftedFeatureExtractor  MeanChanAggregator
# 21  LogisticRegression  HandcraftedFeatureExtractor  MeanTimeAggregator
# 8   LogisticRegression  HandcraftedFeatureExtractor                None
# 4   LogisticRegression      amazon/chronos-t5-large       CatAggregator
# 9   LogisticRegression      amazon/chronos-t5-large  MeanChanAggregator
# 2   LogisticRegression      amazon/chronos-t5-large  MeanTimeAggregator
# 18  LogisticRegression      amazon/chronos-t5-large                None
# 17  LogisticRegression      amazon/chronos-t5-small       CatAggregator
# 16  LogisticRegression      amazon/chronos-t5-small  MeanChanAggregator
# 12  LogisticRegression      amazon/chronos-t5-small  MeanTimeAggregator
# 5   LogisticRegression      amazon/chronos-t5-small                None
#
#    Validation Accuracy (%) SEM (%)
# 13       TACV           43       7
# 15       TACV           43       7
# 1        TACV           43       7
# 11       TACV           43       7
# 0        TACV           43       7
# 14       TACV           43       7
# 19       TACV           50      17
# 10       TACV           40      17
# 6        TACV           50      17
# 20       TACV           40      17
# 3        TACV           60      12
# 7        TACV           60      12
# 21       TACV           60      12
# 8        TACV           60      12
# 4        TACV           72      13
# 9        TACV           46      14
# 2        TACV           36       4
# 18       TACV           36       4
# 17       TACV           65      18
# 16       TACV           72      20
# 12       TACV           49      18
# 5        TACV           36       4

# %% [markdown]
# # APSYNC (10sec) - enjoyment (> 4 high, <= 4 low)

# %% [markdown]
# ## LOPO

# %%
present_results("../outputs/multirun_2025-06-25_09-57-48", val_method="lopo")
# Out:
#                  Model                     Features          Aggregator  \
# 0      DummyClassifier      AutonLab/MOMENT-1-large       CatAggregator
# 3      DummyClassifier      AutonLab/MOMENT-1-large  MeanChanAggregator
# 2      DummyClassifier      AutonLab/MOMENT-1-large  MeanTimeAggregator
# 18     DummyClassifier      AutonLab/MOMENT-1-large                None
# 14     DummyClassifier  HandcraftedFeatureExtractor                None
# 11     DummyClassifier      amazon/chronos-t5-large       CatAggregator
# 9      DummyClassifier      amazon/chronos-t5-large  MeanChanAggregator
# 19     DummyClassifier      amazon/chronos-t5-large  MeanTimeAggregator
# 4      DummyClassifier      amazon/chronos-t5-large                None
# 17     DummyClassifier      amazon/chronos-t5-small       CatAggregator
# 20     DummyClassifier      amazon/chronos-t5-small  MeanChanAggregator
# 16     DummyClassifier      amazon/chronos-t5-small  MeanTimeAggregator
# 1      DummyClassifier      amazon/chronos-t5-small                None
# 10  LogisticRegression      AutonLab/MOMENT-1-large       CatAggregator
# 8   LogisticRegression      AutonLab/MOMENT-1-large  MeanChanAggregator
# 15  LogisticRegression      AutonLab/MOMENT-1-large  MeanTimeAggregator
# 25  LogisticRegression      AutonLab/MOMENT-1-large                None
# 6   LogisticRegression  HandcraftedFeatureExtractor                None
# 24  LogisticRegression      amazon/chronos-t5-large       CatAggregator
# 22  LogisticRegression      amazon/chronos-t5-large  MeanChanAggregator
# 21  LogisticRegression      amazon/chronos-t5-large  MeanTimeAggregator
# 12  LogisticRegression      amazon/chronos-t5-large                None
# 13  LogisticRegression      amazon/chronos-t5-small       CatAggregator
# 7   LogisticRegression      amazon/chronos-t5-small  MeanChanAggregator
# 23  LogisticRegression      amazon/chronos-t5-small  MeanTimeAggregator
# 5   LogisticRegression      amazon/chronos-t5-small                None
#
#    Validation Accuracy (%) SEM (%)
# 0        LOPO           58      10
# 3        LOPO           58      10
# 2        LOPO           58      10
# 18       LOPO           58      10
# 14       LOPO           58      10
# 11       LOPO           58      10
# 9        LOPO           58      10
# 19       LOPO           58      10
# 4        LOPO           58      10
# 17       LOPO           58      10
# 20       LOPO           58      10
# 16       LOPO           58      10
# 1        LOPO           58      10
# 10       LOPO           55      10
# 8        LOPO           58      10
# 15       LOPO           55      10
# 25       LOPO           58      10
# 6        LOPO           43       6
# 24       LOPO           54      10
# 22       LOPO           58      10
# 21       LOPO           54      10
# 12       LOPO           58      10
# 13       LOPO           53       9
# 7        LOPO           58      10
# 23       LOPO           58      10
# 5        LOPO           58      10

# %% [markdown]
# ## TACV

# %%
present_results("../outputs/multirun_2025-06-25_09-57-48", val_method="tacv")
# Out:
#                  Model                     Features          Aggregator  \
# 6      DummyClassifier      AutonLab/MOMENT-1-large       CatAggregator
# 13     DummyClassifier      AutonLab/MOMENT-1-large  MeanChanAggregator
# 21     DummyClassifier      AutonLab/MOMENT-1-large  MeanTimeAggregator
# 10     DummyClassifier      AutonLab/MOMENT-1-large                None
# 12     DummyClassifier  HandcraftedFeatureExtractor                None
# 14     DummyClassifier      amazon/chronos-t5-large       CatAggregator
# 5      DummyClassifier      amazon/chronos-t5-large  MeanChanAggregator
# 11     DummyClassifier      amazon/chronos-t5-large  MeanTimeAggregator
# 20     DummyClassifier      amazon/chronos-t5-large                None
# 19     DummyClassifier      amazon/chronos-t5-small       CatAggregator
# 0      DummyClassifier      amazon/chronos-t5-small  MeanChanAggregator
# 1      DummyClassifier      amazon/chronos-t5-small  MeanTimeAggregator
# 15     DummyClassifier      amazon/chronos-t5-small                None
# 8   LogisticRegression      AutonLab/MOMENT-1-large       CatAggregator
# 2   LogisticRegression      AutonLab/MOMENT-1-large  MeanChanAggregator
# 9   LogisticRegression      AutonLab/MOMENT-1-large  MeanTimeAggregator
# 3   LogisticRegression      AutonLab/MOMENT-1-large                None
# 22  LogisticRegression  HandcraftedFeatureExtractor                None
# 18  LogisticRegression      amazon/chronos-t5-large       CatAggregator
# 4   LogisticRegression      amazon/chronos-t5-large  MeanChanAggregator
# 7   LogisticRegression      amazon/chronos-t5-large  MeanTimeAggregator
# 23  LogisticRegression      amazon/chronos-t5-large                None
# 17  LogisticRegression      amazon/chronos-t5-small       CatAggregator
# 16  LogisticRegression      amazon/chronos-t5-small  MeanChanAggregator
# 25  LogisticRegression      amazon/chronos-t5-small  MeanTimeAggregator
# 24  LogisticRegression      amazon/chronos-t5-small                None
#
#    Validation Accuracy (%) SEM (%)
# 6        TACV           60       7
# 13       TACV           60       7
# 21       TACV           60       7
# 10       TACV           60       7
# 12       TACV           60       7
# 14       TACV           60       7
# 5        TACV           60       7
# 11       TACV           60       7
# 20       TACV           60       7
# 19       TACV           60       7
# 0        TACV           60       7
# 1        TACV           60       7
# 15       TACV           60       7
# 8        TACV           63       5
# 2        TACV           60       7
# 9        TACV           63       5
# 3        TACV           60       7
# 22       TACV           45       9
# 18       TACV           57       7
# 4        TACV           60       7
# 7        TACV           56       8
# 23       TACV           60       7
# 17       TACV           56       7
# 16       TACV           60       7
# 25       TACV           60       7
# 24       TACV           60       7

# %% [markdown]
# # APSYNC (10 seconds) - immersion (> 4 high, <= 4 low)

# %% [markdown]
# ## LOPO

# %%
present_results("../outputs/multirun_2025-06-26_10-15-52", val_method="lopo")
# Out:
#                  Model                     Features          Aggregator  \
# 1      DummyClassifier  HandcraftedFeatureExtractor                None
# 3   LogisticRegression      AutonLab/MOMENT-1-large       CatAggregator
# 7   LogisticRegression      AutonLab/MOMENT-1-large  MeanChanAggregator
# 0   LogisticRegression      AutonLab/MOMENT-1-large  MeanTimeAggregator
# 4   LogisticRegression      AutonLab/MOMENT-1-large                None
# 5   LogisticRegression  HandcraftedFeatureExtractor                None
# 9   LogisticRegression      amazon/chronos-t5-large       CatAggregator
# 8   LogisticRegression      amazon/chronos-t5-large  MeanChanAggregator
# 13  LogisticRegression      amazon/chronos-t5-large  MeanTimeAggregator
# 11  LogisticRegression      amazon/chronos-t5-large                None
# 2   LogisticRegression      amazon/chronos-t5-small       CatAggregator
# 10  LogisticRegression      amazon/chronos-t5-small  MeanChanAggregator
# 12  LogisticRegression      amazon/chronos-t5-small  MeanTimeAggregator
# 6   LogisticRegression      amazon/chronos-t5-small                None
#
#    Validation Accuracy (%) SEM (%)
# 1        LOPO           22       8
# 3        LOPO           24       8
# 7        LOPO           22       7
# 0        LOPO           24       8
# 4        LOPO           23       8
# 5        LOPO           27       7
# 9        LOPO           27       9
# 8        LOPO           25       9
# 13       LOPO           24       7
# 11       LOPO           20       7
# 2        LOPO           33       6
# 10       LOPO           25       8
# 12       LOPO           20       7
# 6        LOPO           20       7

# %% [markdown]
# ## TACV

# %%
present_results("../outputs/multirun_2025-06-26_10-15-52", val_method="tacv")
# Out:
#                  Model                     Features          Aggregator  \
# 11     DummyClassifier  HandcraftedFeatureExtractor                None
# 7   LogisticRegression      AutonLab/MOMENT-1-large       CatAggregator
# 12  LogisticRegression      AutonLab/MOMENT-1-large  MeanChanAggregator
# 9   LogisticRegression      AutonLab/MOMENT-1-large  MeanTimeAggregator
# 0   LogisticRegression      AutonLab/MOMENT-1-large                None
# 10  LogisticRegression  HandcraftedFeatureExtractor                None
# 4   LogisticRegression      amazon/chronos-t5-large       CatAggregator
# 1   LogisticRegression      amazon/chronos-t5-large  MeanChanAggregator
# 5   LogisticRegression      amazon/chronos-t5-large  MeanTimeAggregator
# 3   LogisticRegression      amazon/chronos-t5-large                None
# 13  LogisticRegression      amazon/chronos-t5-small       CatAggregator
# 6   LogisticRegression      amazon/chronos-t5-small  MeanChanAggregator
# 2   LogisticRegression      amazon/chronos-t5-small  MeanTimeAggregator
# 8   LogisticRegression      amazon/chronos-t5-small                None
#
#    Validation Accuracy (%) SEM (%)
# 11       TACV           51       4
# 7        TACV           41       9
# 12       TACV           52      10
# 9        TACV           41       9
# 0        TACV           48      10
# 10       TACV           30       7
# 4        TACV           47       9
# 1        TACV           50      10
# 5        TACV           50      10
# 3        TACV           54      10
# 13       TACV           43       5
# 6        TACV           45       9
# 2        TACV           54      10
# 8        TACV           54      10

# %% [markdown]
# # SEED (10 seconds, median)

# %% [markdown]
# ## LOPO

# %%
present_results("../outputs/multirun_2025-06-27_16-33-37", val_method="lopo")
# Out:
# Skipping ../outputs/multirun_2025-06-27_16-33-37/3 as reports.csv does not exist.
#                 Model                     Features Aggregator Validation  \
# 0     DummyClassifier  HandcraftedFeatureExtractor       None       LOPO
# 1  LogisticRegression  HandcraftedFeatureExtractor       None       LOPO
# 2  LogisticRegression      amazon/chronos-t5-large       None       LOPO
#
#   Accuracy (%) SEM (%)
# 0           84       6
# 1           84       6
# 2           84       6

# %% [markdown]
# ## TACV

# %%
present_results("../outputs/multirun_2025-06-26_10-15-52", val_method="tacv")
# Out:
#                  Model                     Features          Aggregator  \
# 11     DummyClassifier  HandcraftedFeatureExtractor                None
# 7   LogisticRegression      AutonLab/MOMENT-1-large       CatAggregator
# 12  LogisticRegression      AutonLab/MOMENT-1-large  MeanChanAggregator
# 9   LogisticRegression      AutonLab/MOMENT-1-large  MeanTimeAggregator
# 0   LogisticRegression      AutonLab/MOMENT-1-large                None
# 10  LogisticRegression  HandcraftedFeatureExtractor                None
# 4   LogisticRegression      amazon/chronos-t5-large       CatAggregator
# 1   LogisticRegression      amazon/chronos-t5-large  MeanChanAggregator
# 5   LogisticRegression      amazon/chronos-t5-large  MeanTimeAggregator
# 3   LogisticRegression      amazon/chronos-t5-large                None
# 13  LogisticRegression      amazon/chronos-t5-small       CatAggregator
# 6   LogisticRegression      amazon/chronos-t5-small  MeanChanAggregator
# 2   LogisticRegression      amazon/chronos-t5-small  MeanTimeAggregator
# 8   LogisticRegression      amazon/chronos-t5-small                None
#
#    Validation Accuracy (%) SEM (%)
# 11       TACV           51       4
# 7        TACV           41       9
# 12       TACV           52      10
# 9        TACV           41       9
# 0        TACV           48      10
# 10       TACV           30       7
# 4        TACV           47       9
# 1        TACV           50      10
# 5        TACV           50      10
# 3        TACV           54      10
# 13       TACV           43       5
# 6        TACV           45       9
# 2        TACV           54      10
# 8        TACV           54      10

# %% [markdown]
# # BiHearts (10min)

# %%
present_results("../outputs_usilaughs_right/multirun_2025-06-30_11-53-58", val_method="lopo")
# Out:
# Skipping ../outputs_usilaughs_right/multirun_2025-06-30_11-53-58/3 as reports.csv does not exist.
#                 Model                     Features Aggregator Validation  \
# 0     DummyClassifier  HandcraftedFeatureExtractor       None       LOPO
# 1  LogisticRegression  HandcraftedFeatureExtractor       None       LOPO
# 2  LogisticRegression      amazon/chronos-t5-large       None       LOPO
#
#   Accuracy (%) SEM (%)
# 0           56       0
# 1           73       5
# 2           56       0
