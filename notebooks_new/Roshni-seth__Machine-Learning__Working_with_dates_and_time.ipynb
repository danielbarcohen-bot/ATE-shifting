# %% [markdown]
# <a href="https://colab.research.google.com/github/Roshni-seth/Machine-Learning/blob/main/Working_with_dates_and_time.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q kaggle
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-6a7a7147-4ff4-4061-ab77-a8a8475c691b" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-6a7a7147-4ff4-4061-ab77-a8a8475c691b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
! mkdir ~/.kaggle
! cp kaggle.json ~/.kaggle/

# %%
! kaggle datasets download onidzelskyi/chat-messages
# Out:
# ...
# Dataset URL: https://www.kaggle.com/datasets/onidzelskyi/chat-messages
# License(s): CC0-1.0
# ...
#  47% 12.0M/25.6M [00:00<00:00, 41.6MB/s]
# 100% 25.6M/25.6M [00:00<00:00, 71.1MB/s]

# %%
import pandas as pd
import numpy as np

# %%
time=pd.read_csv('/content/chat-messages.zip')
time.head()
# Out:
#                   date                                                msg
# 0  2012-01-02 00:21:00                            нужен парень 0965188229
# 1  2012-01-02 00:24:00                       Всем привет! Как настроение?
# 2  2012-01-02 00:27:00  ИЩЮ ВТОРУЮ ПОЛОВИНКУ МНЕ 23 ЗОВУТ ВАНЯ ПИШИТЕ ...
# 3  2012-01-02 00:27:00     Эля  встречала в шумной компании! Все отлично!
# 4  2012-01-02 00:27:00  Парень катается по городу. Нужна девушка. 0992...

# %%
! kaggle datasets download jyesawtellrickson/ecommerce-bookings-data
# Out:
# ...
# Dataset URL: https://www.kaggle.com/datasets/jyesawtellrickson/ecommerce-bookings-data
# License(s): unknown
# ...
#   0% 0.00/1.78M [00:00<?, ?B/s]
# 100% 1.78M/1.78M [00:00<00:00, 132MB/s]

# %%
date=pd.read_csv('/content/ecommerce-bookings-data.zip')
date.head()
# Out:
#          date  product_id  city_id  orders
# 0  2019-12-16        1897       26       2
# 1  2019-12-16        4850       26       4
# 2  2019-12-16        2466       26       1
# 3  2019-12-16         637       26       1
# 4  2019-12-16        3497       26     184

# %%
date.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 523684 entries, 0 to 523683
# Data columns (total 4 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   date        523684 non-null  object
#  1   product_id  523684 non-null  int64
#  2   city_id     523684 non-null  int64
#  3   orders      523684 non-null  int64
# dtypes: int64(3), object(1)
# memory usage: 16.0+ MB

# %%
time.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1147100 entries, 0 to 1147099
# Data columns (total 2 columns):
#  #   Column  Non-Null Count    Dtype
# ---  ------  --------------    -----
#  0   date    1147100 non-null  object
#  1   msg     1147100 non-null  object
# dtypes: object(2)
# memory usage: 17.5+ MB

# %% [markdown]
# **Working with Dates**

# %%
# converting to datetime datatype
date['date']=pd.to_datetime(date['date'])

# %%
date.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 523684 entries, 0 to 523683
# Data columns (total 4 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   date        523684 non-null  datetime64[ns]
#  1   product_id  523684 non-null  int64
#  2   city_id     523684 non-null  int64
#  3   orders      523684 non-null  int64
# dtypes: datetime64[ns](1), int64(3)
# memory usage: 16.0 MB

# %% [markdown]
# **1. Extract year**

# %%
date['date_year']=date['date'].dt.year
date.head()
# Out:
#         date  product_id  city_id  orders  date_year
# 0 2019-12-16        1897       26       2       2019
# 1 2019-12-16        4850       26       4       2019
# 2 2019-12-16        2466       26       1       2019
# 3 2019-12-16         637       26       1       2019
# 4 2019-12-16        3497       26     184       2019

# %% [markdown]
# **2. Extract Month**

# %%
date['date_month_no']=date['date'].dt.month
date.head()
# Out:
#         date  product_id  city_id  orders  date_year  date_month_no
# 0 2019-12-16        1897       26       2       2019             12
# 1 2019-12-16        4850       26       4       2019             12
# 2 2019-12-16        2466       26       1       2019             12
# 3 2019-12-16         637       26       1       2019             12
# 4 2019-12-16        3497       26     184       2019             12

# %%
date['date_month_name']=date['date'].dt.month_name()
date.head()
# Out:
#         date  product_id  city_id  orders  date_year  date_month_no  \
# 0 2019-12-16        1897       26       2       2019             12
# 1 2019-12-16        4850       26       4       2019             12
# 2 2019-12-16        2466       26       1       2019             12
# 3 2019-12-16         637       26       1       2019             12
# 4 2019-12-16        3497       26     184       2019             12
#
#   date_month_name
# 0        December
# 1        December
# 2        December
# 3        December
# 4        December

# %% [markdown]
# **Extract Days**

# %%
date['date_day']=date['date'].dt.day
date.head()
# Out:
#         date  product_id  city_id  orders  date_year  date_month_no  \
# 0 2019-12-16        1897       26       2       2019             12
# 1 2019-12-16        4850       26       4       2019             12
# 2 2019-12-16        2466       26       1       2019             12
# 3 2019-12-16         637       26       1       2019             12
# 4 2019-12-16        3497       26     184       2019             12
#
#   date_month_name  date_day
# 0        December        16
# 1        December        16
# 2        December        16
# 3        December        16
# 4        December        16

# %%
# day of week
date['date_dow']=date['date'].dt.dayofweek
date.sample()
# Out:
#             date  product_id  city_id  orders  date_year  date_month_no  \
# 65245 2019-05-17        4846        1       7       2019              5
#
#       date_month_name  date_day  date_dow
# 65245             May        17         4

# %%
# day of week name
date['date_dow_name']=date['date'].dt.day_name()
date.drop(columns=['product_id','city_id','orders']).head()
# Out:
#         date  date_year  date_month_no date_month_name  date_day  date_dow  \
# 0 2019-12-16       2019             12        December        16         0
# 1 2019-12-16       2019             12        December        16         0
# 2 2019-12-16       2019             12        December        16         0
# 3 2019-12-16       2019             12        December        16         0
# 4 2019-12-16       2019             12        December        16         0
#
#   date_dow_name
# 0        Monday
# 1        Monday
# 2        Monday
# 3        Monday
# 4        Monday

# %%
# is weekend?

date['date_is_weekend']=np.where(date['date_dow_name'].isin(['Sunday','Saturday']),1,0)
date.drop(columns=['product_id','city_id','orders']).head()
# Out:
#         date  date_year  date_month_no date_month_name  date_day  date_dow  \
# 0 2019-12-16       2019             12        December        16         0
# 1 2019-12-16       2019             12        December        16         0
# 2 2019-12-16       2019             12        December        16         0
# 3 2019-12-16       2019             12        December        16         0
# 4 2019-12-16       2019             12        December        16         0
#
#   date_dow_name  date_is_weekend
# 0        Monday                0
# 1        Monday                0
# 2        Monday                0
# 3        Monday                0
# 4        Monday                0

# %% [markdown]
# **Extract week of the year**

# %%
date['date_week']=date['date'].dt.isocalendar().week
date.drop(columns=['product_id','city_id','orders']).head()
# Out:
#         date  date_year  date_month_no date_month_name  date_day  date_dow  \
# 0 2019-12-16       2019             12        December        16         0
# 1 2019-12-16       2019             12        December        16         0
# 2 2019-12-16       2019             12        December        16         0
# 3 2019-12-16       2019             12        December        16         0
# 4 2019-12-16       2019             12        December        16         0
#
#   date_dow_name  date_is_weekend  date_week
# 0        Monday                0         51
# 1        Monday                0         51
# 2        Monday                0         51
# 3        Monday                0         51
# 4        Monday                0         51

# %% [markdown]
# **Extract Quarter**

# %%
date['quarter']=date['date'].dt.quarter

date.drop(columns=['product_id','city_id','orders']).head()
# Out:
#         date  date_year  date_month_no date_month_name  date_day  date_dow  \
# 0 2019-12-16       2019             12        December        16         0
# 1 2019-12-16       2019             12        December        16         0
# 2 2019-12-16       2019             12        December        16         0
# 3 2019-12-16       2019             12        December        16         0
# 4 2019-12-16       2019             12        December        16         0
#
#   date_dow_name  date_is_weekend  date_week  quarter
# 0        Monday                0         51        4
# 1        Monday                0         51        4
# 2        Monday                0         51        4
# 3        Monday                0         51        4
# 4        Monday                0         51        4

# %% [markdown]
# **Extract Semester**

# %%
date['semester']=np.where(date['quarter'].isin([1,2]),1,2)
date.drop(columns=['product_id','city_id','orders']).head()
# Out:
#         date  date_year  date_month_no date_month_name  date_day  date_dow  \
# 0 2019-12-16       2019             12        December        16         0
# 1 2019-12-16       2019             12        December        16         0
# 2 2019-12-16       2019             12        December        16         0
# 3 2019-12-16       2019             12        December        16         0
# 4 2019-12-16       2019             12        December        16         0
#
#   date_dow_name  date_is_weekend  date_week  quarter  semester
# 0        Monday                0         51        4         2
# 1        Monday                0         51        4         2
# 2        Monday                0         51        4         2
# 3        Monday                0         51        4         2
# 4        Monday                0         51        4         2

# %% [markdown]
# **Extract Time elapsed between date**

# %%
import datetime
today=datetime.datetime.today()
today
# Out:
# datetime.datetime(2024, 11, 16, 17, 38, 53, 502400)

# %%
today-date['date']
# Out:
# 0        1797 days 17:38:53.502400
# 1        1797 days 17:38:53.502400
# 2        1797 days 17:38:53.502400
# 3        1797 days 17:38:53.502400
# 4        1797 days 17:38:53.502400
#                     ...
# 523679   2145 days 17:38:53.502400
# 523680   2143 days 17:38:53.502400
# 523681   2139 days 17:38:53.502400
# 523682   2138 days 17:38:53.502400
# 523683   2137 days 17:38:53.502400
# Name: date, Length: 523684, dtype: timedelta64[ns]

# %%
(today-date['date']).dt.days
# Out:
# 0         1797
# 1         1797
# 2         1797
# 3         1797
# 4         1797
#           ...
# 523679    2145
# 523680    2143
# 523681    2139
# 523682    2138
# 523683    2137
# Name: date, Length: 523684, dtype: int64

# %%
# Month Passes

# Month Passes

# Calculate the difference in days
day_diff = (today - date['date']).dt.days

# Divide by the average number of days in a month (30.4375)
month_diff = np.round(day_diff / 30.4375, 0)

month_diff
# Out:
# 0         59.0
# 1         59.0
# 2         59.0
# 3         59.0
# 4         59.0
#           ...
# 523679    70.0
# 523680    70.0
# 523681    70.0
# 523682    70.0
# 523683    70.0
# Name: date, Length: 523684, dtype: float64

# %% [markdown]
# **time**

# %%
# converting to datetime datatype
time['date']=pd.to_datetime(time['date'])

# %%
time.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1147100 entries, 0 to 1147099
# Data columns (total 2 columns):
#  #   Column  Non-Null Count    Dtype
# ---  ------  --------------    -----
#  0   date    1147100 non-null  datetime64[ns]
#  1   msg     1147100 non-null  object
# dtypes: datetime64[ns](1), object(1)
# memory usage: 17.5+ MB

# %%
time['hour']=time['date'].dt.hour
time['min']=time['date'].dt.minute
time['sec']=time['date'].dt.second

time.head()
# Out:
#                  date                                                msg  \
# 0 2012-01-02 00:21:00                            нужен парень 0965188229
# 1 2012-01-02 00:24:00                       Всем привет! Как настроение?
# 2 2012-01-02 00:27:00  ИЩЮ ВТОРУЮ ПОЛОВИНКУ МНЕ 23 ЗОВУТ ВАНЯ ПИШИТЕ ...
# 3 2012-01-02 00:27:00     Эля  встречала в шумной компании! Все отлично!
# 4 2012-01-02 00:27:00  Парень катается по городу. Нужна девушка. 0992...
#
#    hour  min  sec
# 0     0   21    0
# 1     0   24    0
# 2     0   27    0
# 3     0   27    0
# 4     0   27    0

# %% [markdown]
# **Extract Time part**

# %%
time['time']=time['date'].dt.time
time.head()
# Out:
#                  date                                                msg  \
# 0 2012-01-02 00:21:00                            нужен парень 0965188229
# 1 2012-01-02 00:24:00                       Всем привет! Как настроение?
# 2 2012-01-02 00:27:00  ИЩЮ ВТОРУЮ ПОЛОВИНКУ МНЕ 23 ЗОВУТ ВАНЯ ПИШИТЕ ...
# 3 2012-01-02 00:27:00     Эля  встречала в шумной компании! Все отлично!
# 4 2012-01-02 00:27:00  Парень катается по городу. Нужна девушка. 0992...
#
#    hour  min  sec      time
# 0     0   21    0  00:21:00
# 1     0   24    0  00:24:00
# 2     0   27    0  00:27:00
# 3     0   27    0  00:27:00
# 4     0   27    0  00:27:00

# %% [markdown]
# **Time differetnce**

# %%
today-time['date']
# Out:
# 0         4702 days 17:17:53.502400
# 1         4702 days 17:14:53.502400
# 2         4702 days 17:11:53.502400
# 3         4702 days 17:11:53.502400
# 4         4702 days 17:11:53.502400
#                      ...
# 1147095   2845 days 17:16:53.502400
# 1147096   2845 days 17:16:53.502400
# 1147097   2845 days 17:16:53.502400
# 1147098   2845 days 17:14:53.502400
# 1147099   2845 days 17:12:53.502400
# Name: date, Length: 1147100, dtype: timedelta64[ns]

# %% [markdown]
# **in seconds**

# %%
(today-time['date'])/np.timedelta64(1,'s')
# Out:
# 0          4.063151e+08
# 1          4.063149e+08
# 2          4.063147e+08
# 3          4.063147e+08
# 4          4.063147e+08
#                ...
# 1147095    2.458702e+08
# 1147096    2.458702e+08
# 1147097    2.458702e+08
# 1147098    2.458701e+08
# 1147099    2.458700e+08
# Name: date, Length: 1147100, dtype: float64

# %%
#in minutes
(today-time['date'])/np.timedelta64(1,'m')
# Out:
# 0          6.771918e+06
# 1          6.771915e+06
# 2          6.771912e+06
# 3          6.771912e+06
# 4          6.771912e+06
#                ...
# 1147095    4.097837e+06
# 1147096    4.097837e+06
# 1147097    4.097837e+06
# 1147098    4.097835e+06
# 1147099    4.097833e+06
# Name: date, Length: 1147100, dtype: float64
