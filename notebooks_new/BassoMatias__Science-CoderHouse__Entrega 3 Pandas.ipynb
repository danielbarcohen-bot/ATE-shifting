# %%
import numpy as np
import pandas as pd

# %%
# Consigna 1 Indice igual a año

# %%
JJOO= pd.read_csv('C:\\Users\\Usuario\Documents\Coder\Data Science\JJOO.csv',encoding='latin-1')
indice= list(JJOO.Year)
indice
columnas= JJOO.columns[1:]
columnas
valores= JJOO.values[:,1:]
JJOOdf= pd.DataFrame(valores, index=indice,columns=columnas)
JJOOdf
# Out:
#           Year      Sport       Discipline           Event  \
# 1976.0  1976.0   Aquatics           Diving  3m springboard
# 1976.0  1976.0   Aquatics           Diving  3m springboard
# 1976.0  1976.0   Aquatics           Diving  3m springboard
# 1976.0  1976.0   Aquatics           Diving  3m springboard
# 1976.0  1976.0   Aquatics           Diving    10m platform
# ...        ...        ...              ...             ...
# 2008.0  2008.0  Wrestling  Wrestling Gre-R       66 - 74kg
# 2008.0  2008.0  Wrestling  Wrestling Gre-R       66 - 74kg
# 2008.0  2008.0  Wrestling  Wrestling Gre-R       55 - 60kg
# 2008.0  2008.0  Wrestling  Wrestling Gre-R       60 - 66kg
# 2008.0  2008.0  Wrestling  Wrestling Gre-R      96 - 120kg
#
#                          Athlete Gender Country_Code        Country  \
# 1976.0           KÖHLER, Christa  Women          GDR   East Germany
# 1976.0       KOSENKOV, Aleksandr    Men          URS   Soviet Union
# ...

# %%
# Consigna 2 Nombre y Apellido en 2 columnas

# %%
Atleta= pd.Series(JJOOdf['Athlete'])
Atleta_sep=Atleta.str.split(',',n=1,expand=True)
Atleta_sep.columns=['Apellido','Nombre']
Atleta_sep
JJOOcompleto= pd.concat([JJOOdf,Atleta_sep],axis=1)
JJOOcompleto
# Out:
#           Year      Sport       Discipline           Event  \
# 1976.0  1976.0   Aquatics           Diving  3m springboard
# 1976.0  1976.0   Aquatics           Diving  3m springboard
# 1976.0  1976.0   Aquatics           Diving  3m springboard
# 1976.0  1976.0   Aquatics           Diving  3m springboard
# 1976.0  1976.0   Aquatics           Diving    10m platform
# ...        ...        ...              ...             ...
# 2008.0  2008.0  Wrestling  Wrestling Gre-R       66 - 74kg
# 2008.0  2008.0  Wrestling  Wrestling Gre-R       66 - 74kg
# 2008.0  2008.0  Wrestling  Wrestling Gre-R       55 - 60kg
# 2008.0  2008.0  Wrestling  Wrestling Gre-R       60 - 66kg
# 2008.0  2008.0  Wrestling  Wrestling Gre-R      96 - 120kg
#
#                          Athlete Gender Country_Code        Country  \
# 1976.0           KÖHLER, Christa  Women          GDR   East Germany
# 1976.0       KOSENKOV, Aleksandr    Men          URS   Soviet Union
# ...

# %%
# Consigna 3 Resumen

# %%
JJOOcompleto.describe()
# Out:
#            Year     Sport Discipline   Event          Athlete Gender  \
# count   15316.0     15316      15316   15316            15316  15316
# unique      9.0        28         41     293            11337      2
# top      2008.0  Aquatics  Athletics  hockey  PHELPS, Michael    Men
# freq     2042.0      2210       1523     817               16   9388
#
#        Country_Code        Country Event_gender   Medal Apellido     Nombre
# count         15316          15316        15316   15316    15316      15223
# unique          128            127            3       3     8930       5587
# top             USA  United States            M  Bronze      KIM   Vladimir
# freq           1992           1992         8817    5258      103        113

# %%
# Consinga 3 Pais con mas medallas

# %%
Country=JJOOcompleto['Country']
Country.mode()
# Out:
# 0    United States
# Name: Country, dtype: object

# %%
# Consigna 4 Medallas por año de los hombres

# %%
JJOOcompleto
Masculinos=JJOOcompleto[JJOOcompleto['Event_gender']=='M']
Medals= Masculinos.groupby(['Year']).count() 
Medals[['Medal']]
# Out:
#         Medal
# Year
# 1976.0    843
# 1980.0    854
# 1984.0    911
# 1988.0    950
# 1992.0   1041
# 1996.0   1029
# 2000.0   1065
# 2004.0   1052
# 2008.0   1072
