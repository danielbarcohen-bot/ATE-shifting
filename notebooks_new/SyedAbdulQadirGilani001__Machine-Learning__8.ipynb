# %%
from itertools import combinations # itertools for combinations

def main(): # main function
  word = 'bath' # word for combinations
  for string in combinations(word, 3): # combinations of word
    print(''.join(string)) # print combinations

if __name__ == '__main__': # if main
  main() # run main
# Out:
# bat
# bah
# bth
# ath

# %%
import requests # requests for get
from io import StringIO # StringIO for file
# csv github url
url='https://raw.githubusercontent.com/plotly/datasets/master/2014_usa_states.csv' # url
headers= {'User-Agent': 'Mozilla/5.0'} # headers
req=requests.get(url, headers=headers) # get url
data=req.content.decode('utf-8') # decode data
pd.read_csv(url) # read csv
# Out:
#     Rank                 State Postal  Population
# 0      1               Alabama     AL   4849377.0
# 1      2                Alaska     AK    736732.0
# 2      3               Arizona     AZ   6731484.0
# 3      4              Arkansas     AR   2966369.0
# 4      5            California     CA  38802500.0
# 5      6              Colorado     CO   5355866.0
# 6      7           Connecticut     CT   3596677.0
# 7      8              Delaware     DE    935614.0
# 8      9  District of Columbia     DC    658893.0
# 9     10               Florida     FL  19893297.0
# 10    11               Georgia     GA  10097343.0
# 11    12                Hawaii     HI   1419561.0
# 12    13                 Idaho     ID   1634464.0
# 13    14              Illinois     IL  12880580.0
# 14    15               Indiana     IN   6596855.0
# 15    16                  Iowa     IA   3107126.0
# 16    17                Kansas     KS   2904021.0
# 17    18              Kentucky     KY   4413457.0
# ...

# %%
# tsv github url
df=pd.read_csv('https://raw.githubusercontent.com/plotly/datasets/master/2014_usa_states.csv', sep='\t',names=['a','b','c','d','e']) # read tsv
df.head() # head of tsv
# Out:
#                               a   b   c   d   e
# 0  Rank,State,Postal,Population NaN NaN NaN NaN
# 1        1,Alabama,AL,4849377.0 NaN NaN NaN NaN
# 2          2,Alaska,AK,736732.0 NaN NaN NaN NaN
# 3        3,Arizona,AZ,6731484.0 NaN NaN NaN NaN
# 4       4,Arkansas,AR,2966369.0 NaN NaN NaN NaN

# %%
# index_col
df=pd.read_csv('https://raw.githubusercontent.com/plotly/datasets/master/2014_usa_states.csv', index_col=0) # read csv
df.head() # head of csv
# Out:
#            State Postal  Population
# Rank
# 1        Alabama     AL   4849377.0
# 2         Alaska     AK    736732.0
# 3        Arizona     AZ   6731484.0
# 4       Arkansas     AR   2966369.0
# 5     California     CA  38802500.0

# %%
# header
df=pd.read_csv('https://raw.githubusercontent.com/plotly/datasets/master/2014_usa_states.csv', header=0) # read csv
df.head() # head of csv
# Out:
#    Rank       State Postal  Population
# 0     1     Alabama     AL   4849377.0
# 1     2      Alaska     AK    736732.0
# 2     3     Arizona     AZ   6731484.0
# 3     4    Arkansas     AR   2966369.0
# 4     5  California     CA  38802500.0

# %%
# use_cols parameter
df=pd.read_csv('https://raw.githubusercontent.com/plotly/datasets/master/2014_usa_states.csv', usecols=['State','Postal']) # read csv
df.head() # head of csv
# Out:
#         State Postal
# 0     Alabama     AL
# 1      Alaska     AK
# 2     Arizona     AZ
# 3    Arkansas     AR
# 4  California     CA

# %%
# squeeze parameter is used to convert 1 column dataframe to series
# other github url with 1 column
pd.read_csv('https://raw.githubusercontent.com/plotly/datasets/master/2014_usa_states.csv', usecols=['State'], squeeze=True) # read csv
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[17], line 3
#       1 # squeeze parameter is used to convert 1 column dataframe to series
#       2 # other github url with 1 column
# ----> 3 pd.read_csv('https://raw.githubusercontent.com/plotly/datasets/master/2014_usa_states.csv', usecols=['State'], squeeze=True) # read csv
#
# TypeError: read_csv() got an unexpected keyword argument 'squeeze'

# %%
# nrows
df=pd.read_csv('https://raw.githubusercontent.com/plotly/datasets/master/2014_usa_states.csv', nrows=5) # read csv
df.head() # head of csv
# Out:
#    Rank       State Postal  Population
# 0     1     Alabama     AL   4849377.0
# 1     2      Alaska     AK    736732.0
# 2     3     Arizona     AZ   6731484.0
# 3     4    Arkansas     AR   2966369.0
# 4     5  California     CA  38802500.0

# %%
# encoding parameter
df=pd.read_csv('https://raw.githubusercontent.com/plotly/datasets/master/2014_usa_states.csv', encoding='utf-8') # read csv
df.head() # head of csv
# Out:
#    Rank       State Postal  Population
# 0     1     Alabama     AL   4849377.0
# 1     2      Alaska     AK    736732.0
# 2     3     Arizona     AZ   6731484.0
# 3     4    Arkansas     AR   2966369.0
# 4     5  California     CA  38802500.0

# %%
# skip bad lines
df=pd.read_csv('https://raw.githubusercontent.com/plotly/datasets/master/2014_usa_states.csv', error_bad_lines=False) # read csv
df.head() # head of csv
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[20], line 2
#       1 # skip bad lines
# ----> 2 df=pd.read_csv('https://raw.githubusercontent.com/plotly/datasets/master/2014_usa_states.csv', error_bad_lines=False) # read csv
#       3 df.head() # head of csv
#
# TypeError: read_csv() got an unexpected keyword argument 'error_bad_lines'

# %%
# dtpyes parameter
df=pd.read_csv('https://raw.githubusercontent.com/plotly/datasets/master/2014_usa_states.csv', dtype={'Postal':str}).info() # read csv
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Rank        52 non-null     int64
#  1   State       52 non-null     object
#  2   Postal      52 non-null     object
#  3   Population  52 non-null     float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 1.8+ KB

# %%
# parse_dates parameter
df=pd.read_csv('https://raw.githubusercontent.com/plotly/datasets/master/2014_usa_states.csv', parse_dates=['Date']).info() # read csv
df.head() # head of csv
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[23], line 2
#       1 # parse_dates parameter
# ----> 2 df=pd.read_csv('https://raw.githubusercontent.com/plotly/datasets/master/2014_usa_states.csv', parse_dates=['Date']).info() # read csv
#       3 df.head() # head of csv
#
# ...

# %%
# chunksizes parameter
df=pd.read_csv('https://raw.githubusercontent.com/plotly/datasets/master/2014_usa_states.csv', chunksize=1000) # read csv
df.head() # head of csv
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[24], line 3
#       1 # chunksizes parameter
#       2 df=pd.read_csv('https://raw.githubusercontent.com/plotly/datasets/master/2014_usa_states.csv', chunksize=1000) # read csv
# ----> 3 df.head() # head of csv
#
# AttributeError: 'TextFileReader' object has no attribute 'head'

# %%
# converter parameter
df=pd.read_csv('https://raw.githubusercontent.com/plotly/datasets/master/2014_usa_states.csv', converters={'Postal':lambda x: x.upper()}) # read csv
df.head() # head of csv
# Out:
#    Rank       State Postal  Population
# 0     1     Alabama     AL   4849377.0
# 1     2      Alaska     AK    736732.0
# 2     3     Arizona     AZ   6731484.0
# 3     4    Arkansas     AR   2966369.0
# 4     5  California     CA  38802500.0

# %%
# na_values parameter
df=pd.read_csv('https://raw.githubusercontent.com/plotly/datasets/master/2014_usa_states.csv', na_values=['']) # read csv
df.head() # head of csv
# Out:
#    Rank       State Postal  Population
# 0     1     Alabama     AL   4849377.0
# 1     2      Alaska     AK    736732.0
# 2     3     Arizona     AZ   6731484.0
# 3     4    Arkansas     AR   2966369.0
# 4     5  California     CA  38802500.0

# %%
# loading a huge dataset with chunksize
df=pd.read_csv('https://raw.githubusercontent.com/plotly/datasets/master/2014_usa_states.csv', chunksize=1000) # read csv
for chunk in df: # for chunk in df
    print(chunk.head()) # print chunk head
# Out:
#    Rank       State Postal  Population
# 0     1     Alabama     AL   4849377.0
# 1     2      Alaska     AK    736732.0
# 2     3     Arizona     AZ   6731484.0
# 3     4    Arkansas     AR   2966369.0
# 4     5  California     CA  38802500.0

# %%
import pandas as pd # pandas for dataframe

# %%
pd.read_json('https://raw.githubusercontent.com/chrisalbon/simulated_datasets/master/data.json') # read json
# Out:
#     integer            datetime  category
# 0         5 2015-01-01 00:00:00         0
# 1         5 2015-01-01 00:00:01         0
# 2         9 2015-01-01 00:00:02         0
# 3         6 2015-01-01 00:00:03         0
# 4         6 2015-01-01 00:00:04         0
# ..      ...                 ...       ...
# 95        9 2015-01-01 00:01:35         0
# 96        8 2015-01-01 00:01:36         0
# 97        6 2015-01-01 00:01:37         0
# 98        8 2015-01-01 00:01:38         0
# 99        1 2015-01-01 00:01:39         0
#
# [100 rows x 3 columns]

# %%
# !pip install mysql.connector
# Out:
# ...
#      ---------------------------------------- 0.0/11.9 MB ? eta -:--:--
#      ---------------------------------------- 0.0/11.9 MB ? eta -:--:--
#      ---------------------------------------- 0.0/11.9 MB ? eta -:--:--
#      ---------------------------------------- 0.0/11.9 MB ? eta -:--:--
#      ---------------------------------------- 0.0/11.9 MB ? eta -:--:--
#      ---------------------------------------- 0.0/11.9 MB ? eta -:--:--
#      ---------------------------------------- 0.0/11.9 MB ? eta -:--:--
#      ---------------------------------------- 0.0/11.9 MB ? eta -:--:--
#      ---------------------------------------- 0.0/11.9 MB ? eta -:--:--
#      ---------------------------------------- 0.0/11.9 MB ? eta -:--:--
#      --------------------------------------- 0.1/11.9 MB 140.6 kB/s eta 0:01:24
#      --------------------------------------- 0.1/11.9 MB 140.6 kB/s eta 0:01:24
#      --------------------------------------- 0.1/11.9 MB 140.6 kB/s eta 0:01:24
# ...

# %%
pd.read_json('https://api.exchangerate-api.com/v4/latest/INR')
# Out:
#                              provider  ...    rates
# AED  https://www.exchangerate-api.com  ...   0.0448
# AFN  https://www.exchangerate-api.com  ...   1.0500
# ALL  https://www.exchangerate-api.com  ...   1.1100
# AMD  https://www.exchangerate-api.com  ...   4.7200
# ANG  https://www.exchangerate-api.com  ...   0.0219
# ..                                ...  ...      ...
# XPF  https://www.exchangerate-api.com  ...   1.3200
# YER  https://www.exchangerate-api.com  ...   3.0500
# ZAR  https://www.exchangerate-api.com  ...   0.2180
# ZMW  https://www.exchangerate-api.com  ...   0.2380
# ZWL  https://www.exchangerate-api.com  ...  55.4300
#
# [162 rows x 7 columns]

# %%
import mysql.connector

# %%
conn = mysql.connector.connect(host='localhost',user='root',password='',database='world')
# Out:
# c:\Users\SyedA\mambaforge\lib\site-packages\mysql\connector\abstracts.py:130: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if group is 'connector_python':
# c:\Users\SyedA\mambaforge\lib\site-packages\mysql\connector\abstracts.py:130: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if group is 'connector_python':
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 conn = mysql.connector.connect(host='localhost',user='root',password='',database='world')
#
# File c:\Users\SyedA\mambaforge\lib\site-packages\mysql\connector\__init__.py:179, in connect(*args, **kwargs)
#     177     return CMySQLConnection(*args, **kwargs)
#     178 else:
# --> 179     return MySQLConnection(*args, **kwargs)
#
# File c:\Users\SyedA\mambaforge\lib\site-packages\mysql\connector\connection.py:95, in MySQLConnection.__init__(self, *args, **kwargs)
# ...

# %%
conn=sqlite3.connect('world.db')


df = pd.read_sql_query('select * from country',conn)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[40], line 1
# ----> 1 conn=sqlite3.connect('world.db')
#       4 df = pd.read_sql_query('select * from country',conn)
#
# NameError: name 'sqlite3' is not defined

# %%
import pandas as pd # pandas for dataframe
import requests # requests for get

# %%
response = requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=8265bd1679663a7ea12ac168da84d2e8&language=en-US&page=1')

# %%
temp_df = pd.DataFrame(response.json()['results'])[['id','title','overview','release_date','popularity','vote_average','vote_count']]

# %%
for i in range(1,429):
    response = requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=8265bd1679663a7ea12ac168da84d2e8&language=en-US&page={}'.format(i))
    temp_df = pd.DataFrame(response.json()['results'])[['id','title','overview','release_date','popularity','vote_average','vote_count']]
    df = df.append(temp_df,ignore_index=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[45], line 4
#       2 response = requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=8265bd1679663a7ea12ac168da84d2e8&language=en-US&page={}'.format(i))
#       3 temp_df = pd.DataFrame(response.json()['results'])[['id','title','overview','release_date','popularity','vote_average','vote_count']]
# ----> 4 df = df.append(temp_df,ignore_index=True)
#
# AttributeError: 'TextFileReader' object has no attribute 'append'

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup
import numpy as np

# %%
webpage=requests.get('https://www.ambitionbox.com/list-of-companies?page=1').text
soup=BeautifulSoup(webpage,'lxml')
     

#print(soup.prettify())
     

soup.find_all('h1')[0].text
# Out:
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# File c:\Users\SyedA\mambaforge\lib\site-packages\urllib3\connection.py:203, in HTTPConnection._new_conn(self)
#     202 try:
# --> 203     sock = connection.create_connection(
#     204         (self._dns_host, self.port),
#     205         self.timeout,
#     206         source_address=self.source_address,
#     207         socket_options=self.socket_options,
#     208     )
#     209 except socket.gaierror as e:
#
# File c:\Users\SyedA\mambaforge\lib\site-packages\urllib3\util\connection.py:60, in create_connection(address, timeout, source_address, socket_options)
#      58     raise LocationParseError(f"'{host}', label empty or too long") from None
# ---> 60 for res in socket.getaddrinfo(host, port, family, socket.SOCK_STREAM):
#      61     af, socktype, proto, canonname, sa = res
#
# ...

# %%
import seaborn as sns # seaborn for dataset
df=sns.load_dataset('titanic') # load iris dataset
df.head() # head of dataset
# Out:
#    survived  pclass     sex   age  ...  deck  embark_town  alive  alone
# 0         0       3    male  22.0  ...   NaN  Southampton     no  False
# 1         1       1  female  38.0  ...     C    Cherbourg    yes  False
# 2         1       3  female  26.0  ...   NaN  Southampton    yes   True
# 3         1       1  female  35.0  ...     C  Southampton    yes  False
# 4         0       3    male  35.0  ...   NaN  Southampton     no   True
#
# [5 rows x 15 columns]

# %%
df.shape # shape of dataset
# Out:
# (891, 15)

# %%
df.sample(5) # sample of dataset
# Out:
#      survived  pclass     sex   age  ...  deck  embark_town  alive  alone
# 223         0       3    male   NaN  ...   NaN  Southampton     no   True
# 1           1       1  female  38.0  ...     C    Cherbourg    yes  False
# 450         0       2    male  36.0  ...   NaN  Southampton     no  False
# 477         0       3    male  29.0  ...   NaN  Southampton     no  False
# 368         1       3  female   NaN  ...   NaN   Queenstown    yes   True
#
# [5 rows x 15 columns]

# %%
df.info() # info of dataset
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %%
df.isnull().sum() # null values in dataset
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
df.describe() # describe dataset
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
df.duplicated().sum() # duplicated values in dataset
# Out:
# 107

# %%
df.corr()['survived'].sort_values() # correlation of dataset
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[72], line 1
# ----> 1 df.corr()['survived'].sort_values() # correlation of dataset
#
# File c:\Users\SyedA\mambaforge\lib\site-packages\pandas\core\frame.py:10054, in DataFrame.corr(self, method, min_periods, numeric_only)
#   10052 cols = data.columns
#   10053 idx = cols.copy()
# > 10054 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   10056 if method == "pearson":
#   10057     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File c:\Users\SyedA\mambaforge\lib\site-packages\pandas\core\frame.py:1838, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1836 if dtype is not None:
#    1837     dtype = np.dtype(dtype)
# -> 1838 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1839 if result.dtype is not dtype:
# ...
