# %%
# visualization
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
fe = fm.FontEntry(
    fname=r'/usr/share/fonts/truetype/nanum/NanumGothic.ttf', # ttf 파일이 저장되어 있는 경로
    name='NanumBarunGothic')                        # 이 폰트의 원하는 이름 설정
fm.fontManager.ttflist.insert(0, fe)              # Matplotlib에 폰트 추가
plt.rcParams.update({'font.size': 10, 'font.family': 'NanumBarunGothic'}) # 폰트 설정
plt.rc('font', family='NanumBarunGothic')
import seaborn as sns

# utils
import pandas as pd
import numpy as np
from tqdm import tqdm
import pickle
import warnings;warnings.filterwarnings('ignore')

# Model
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.ensemble import RandomForestRegressor
from sklearn import metrics

import eli5
from eli5.sklearn import PermutationImportance

# %% [markdown]
# # 데이터로드

# %%
train_path = "../modified_data/v03_train.csv"
test_path = "../modified_data/v03_test.csv"

# %%
train = pd.read_csv(train_path, index_col=0)
test = pd.read_csv(test_path,index_col=0)

# %%
train["is_test"] = 0
test["is_test"] = 1
concat = pd.concat([train, test])

# %%
column_date = ["k-사용검사일-사용승인일","k-등록일자", "k-수정일자", "단지승인일", "단지신청일"]

for column in column_date:
    print(column, concat[column].dtypes)
    concat[column] = pd.to_datetime(concat[column])
    print(concat[column].dtypes)
# Out:
# k-사용검사일-사용승인일 object
# datetime64[ns]
# k-등록일자 object
# datetime64[ns]
# k-수정일자 object
# datetime64[ns]
# 단지승인일 object
# datetime64[ns]
# 단지신청일 object
# datetime64[ns]

# %%
continuous_columns = []
categorical_columns = []
for column in concat.columns:
    if pd.api.types.is_numeric_dtype(concat[column]) or pd.api.types.is_datetime64_ns_dtype(concat[column]):
        continuous_columns.append(column)
    else:
        categorical_columns.append(column)

print("연속형 변수:", continuous_columns)
print("범주형 변수:", categorical_columns)
# Out:
# 연속형 변수: ['본번', '부번', '전용면적(㎡)', '계약년월', '계약일', '층', '건축년도', '등기신청일자', 'k-전체동수', 'k-전체세대수', 'k-사용검사일-사용승인일', 'k-연면적', 'k-주거전용면적', 'k-관리비부과면적', 'k-전용면적별세대현황(60㎡이하)', 'k-전용면적별세대현황(60㎡~85㎡이하)', 'k-85㎡~135㎡이하', 'k-135㎡초과', 'k-등록일자', 'k-수정일자', '건축면적', '주차대수', '단지승인일', '사용허가여부', '관리비 업로드', '좌표X', '좌표Y', '단지신청일', 'target', 'is_test']
# 범주형 변수: ['시군구', '번지', '아파트명', '거래유형', 'k-단지분류(아파트,주상복합등등)', 'k-세대타입(분양형태)', 'k-복도유형', 'k-난방방식', 'k-건설사(시공사)', '기타/의무/임대/임의=1/2/3/4']

# %% [markdown]
# # 인코딩 전에 어떤 범주형 변수에 어떤 값이 들어있는지 확인

# %%
for column in categorical_columns:
    print(column)
    display(concat[column].unique())
# Out:
# 시군구
# array(['서울특별시 강남구 개포동', '서울특별시 강남구 논현동', '서울특별시 강남구 대치동', '서울특별시 강남구 도곡동',
#        '서울특별시 강남구 삼성동', '서울특별시 강남구 세곡동', '서울특별시 강남구 수서동', '서울특별시 강남구 신사동',
#        '서울특별시 강남구 역삼동', '서울특별시 강남구 압구정동', '서울특별시 강남구 일원동',
#        '서울특별시 강남구 자곡동', '서울특별시 강남구 청담동', '서울특별시 강동구 강일동', '서울특별시 강남구 율현동',
#        '서울특별시 강동구 고덕동', '서울특별시 강동구 길동', '서울특별시 강동구 둔촌동', '서울특별시 강동구 명일동',
#        '서울특별시 강동구 상일동', '서울특별시 강동구 성내동', '서울특별시 강동구 암사동', '서울특별시 강동구 천호동',
#        '서울특별시 강북구 미아동', '서울특별시 강북구 번동', '서울특별시 강서구 가양동', '서울특별시 강북구 수유동',
#        '서울특별시 강북구 우이동', '서울특별시 강서구 내발산동', '서울특별시 강서구 등촌동',
#        '서울특별시 강서구 공항동', '서울특별시 강서구 마곡동', '서울특별시 강서구 방화동', '서울특별시 강서구 염창동',
#        '서울특별시 강서구 화곡동', '서울특별시 관악구 남현동', '서울특별시 관악구 봉천동', '서울특별시 관악구 신림동',
#        '서울특별시 광진구 광장동', '서울특별시 광진구 구의동', '서울특별시 광진구 자양동', '서울특별시 광진구 군자동',
#        '서울특별시 광진구 화양동', '서울특별시 구로구 개봉동', '서울특별시 구로구 고척동', '서울특별시 광진구 중곡동',
#        '서울특별시 구로구 가리봉동', '서울특별시 구로구 구로동', '서울특별시 구로구 오류동',
#        '서울특별시 구로구 천왕동', '서울특별시 금천구 독산동', '서울특별시 구로구 온수동', '서울특별시 구로구 궁동',
#        '서울특별시 구로구 신도림동', '서울특별시 구로구 항동', '서울특별시 금천구 가산동', '서울특별시 금천구 시흥동',
#        '서울특별시 노원구 공릉동', '서울특별시 노원구 상계동', '서울특별시 노원구 월계동', '서울특별시 노원구 중계동',
#        '서울특별시 노원구 하계동', '서울특별시 도봉구 도봉동', '서울특별시 도봉구 방학동', '서울특별시 도봉구 쌍문동',
#        '서울특별시 도봉구 창동', '서울특별시 동대문구 답십리동', '서울특별시 동대문구 용두동',
#        '서울특별시 동대문구 이문동', '서울특별시 동대문구 신설동', '서울특별시 동대문구 장안동',
#        '서울특별시 동대문구 전농동', '서울특별시 동대문구 회기동', '서울특별시 동대문구 제기동',
#        '서울특별시 동대문구 청량리동', '서울특별시 동대문구 휘경동', '서울특별시 동작구 노량진동',
#        '서울특별시 동작구 대방동', '서울특별시 동작구 동작동', '서울특별시 동작구 본동', '서울특별시 동작구 사당동',
#        '서울특별시 동작구 상도동', '서울특별시 동작구 상도1동', '서울특별시 동작구 신대방동',
#        '서울특별시 동작구 흑석동', '서울특별시 마포구 공덕동', '서울특별시 마포구 노고산동',
#        '서울특별시 마포구 대흥동', '서울특별시 마포구 도화동', '서울특별시 마포구 마포동', '서울특별시 마포구 상수동',
#        '서울특별시 마포구 상암동', '서울특별시 마포구 서교동', '서울특별시 마포구 성산동',
#        '서울특별시 마포구 신공덕동', '서울특별시 마포구 신수동', '서울특별시 마포구 신정동',
#        '서울특별시 마포구 아현동', '서울특별시 마포구 동교동', '서울특별시 마포구 망원동', '서울특별시 마포구 염리동',
#        '서울특별시 마포구 용강동', '서울특별시 마포구 중동', '서울특별시 마포구 창전동', '서울특별시 마포구 하중동',
#        '서울특별시 마포구 합정동', '서울특별시 서대문구 남가좌동', '서울특별시 서대문구 냉천동',
#        '서울특별시 서대문구 북가좌동', '서울특별시 마포구 연남동', '서울특별시 마포구 토정동',
#        '서울특별시 마포구 현석동', '서울특별시 서대문구 대현동', '서울특별시 서대문구 연희동',
#        '서울특별시 서대문구 영천동', '서울특별시 서대문구 충정로3가', '서울특별시 서대문구 현저동',
#        '서울특별시 서대문구 홍은동', '서울특별시 서대문구 홍제동', '서울특별시 서대문구 북아현동',
#        '서울특별시 서대문구 창천동', '서울특별시 서대문구 천연동', '서울특별시 서대문구 충정로2가',
#        '서울특별시 서대문구 합동', '서울특별시 서초구 내곡동', '서울특별시 서초구 반포동', '서울특별시 서초구 방배동',
#        '서울특별시 서초구 서초동', '서울특별시 서초구 신원동', '서울특별시 서초구 우면동', '서울특별시 서초구 잠원동',
#        '서울특별시 서초구 양재동', '서울특별시 성동구 금호동1가', '서울특별시 성동구 금호동2가',
#        '서울특별시 성동구 금호동3가', '서울특별시 성동구 성수동1가', '서울특별시 성동구 성수동2가',
#        '서울특별시 성동구 금호동4가', '서울특별시 성동구 송정동', '서울특별시 성동구 도선동',
#        '서울특별시 성동구 마장동', '서울특별시 성동구 사근동', '서울특별시 성동구 상왕십리동',
#        '서울특별시 성동구 옥수동', '서울특별시 성동구 하왕십리동', '서울특별시 성동구 행당동',
#        '서울특별시 성동구 응봉동', '서울특별시 성동구 용답동', '서울특별시 성동구 홍익동', '서울특별시 성북구 길음동',
#        '서울특별시 성북구 돈암동', '서울특별시 성북구 동소문동5가', '서울특별시 성북구 동소문동7가',
#        '서울특별시 성북구 보문동3가', '서울특별시 성북구 동선동1가', '서울특별시 성북구 동선동3가',
#        '서울특별시 성북구 동선동4가', '서울특별시 성북구 동선동5가', '서울특별시 성북구 동소문동4가',
#        '서울특별시 성북구 동소문동6가', '서울특별시 성북구 보문동6가', '서울특별시 성북구 삼선동2가',
#        '서울특별시 성북구 상월곡동', '서울특별시 성북구 석관동', '서울특별시 성북구 장위동',
#        '서울특별시 성북구 정릉동', '서울특별시 성북구 보문동4가', '서울특별시 성북구 삼선동3가',
#        '서울특별시 성북구 삼선동4가', '서울특별시 성북구 삼선동5가', '서울특별시 성북구 성북동',
#        '서울특별시 성북구 성북동1가', '서울특별시 성북구 안암동1가', '서울특별시 성북구 안암동3가',
#        '서울특별시 성북구 안암동4가', '서울특별시 성북구 종암동', '서울특별시 성북구 하월곡동',
#        '서울특별시 송파구 가락동', '서울특별시 송파구 거여동', '서울특별시 송파구 마천동', '서울특별시 송파구 문정동',
#        '서울특별시 송파구 석촌동', '서울특별시 송파구 송파동', '서울특별시 송파구 방이동', '서울특별시 송파구 삼전동',
#        '서울특별시 송파구 신천동', '서울특별시 송파구 오금동', '서울특별시 송파구 잠실동', '서울특별시 송파구 장지동',
#        '서울특별시 송파구 풍납동', '서울특별시 양천구 목동', '서울특별시 양천구 신월동', '서울특별시 양천구 신정동',
#        '서울특별시 영등포구 당산동', '서울특별시 영등포구 당산동3가', '서울특별시 영등포구 당산동4가',
#        '서울특별시 영등포구 대림동', '서울특별시 영등포구 도림동', '서울특별시 영등포구 문래동3가',
#        '서울특별시 영등포구 당산동5가', '서울특별시 영등포구 당산동1가', '서울특별시 영등포구 당산동2가',
#        '서울특별시 영등포구 당산동6가', '서울특별시 영등포구 문래동2가', '서울특별시 영등포구 문래동5가',
#        '서울특별시 영등포구 문래동6가', '서울특별시 영등포구 신길동', '서울특별시 영등포구 양평동2가',
#        '서울특별시 영등포구 양평동5가', '서울특별시 영등포구 여의도동', '서울특별시 영등포구 문래동4가',
#        '서울특별시 영등포구 양평동1가', '서울특별시 영등포구 양평동3가', '서울특별시 영등포구 양평동4가',
#        '서울특별시 영등포구 양평동6가', '서울특별시 영등포구 영등포동', '서울특별시 영등포구 영등포동8가',
#        '서울특별시 용산구 문배동', '서울특별시 용산구 산천동', '서울특별시 용산구 신계동',
#        '서울특별시 용산구 원효로1가', '서울특별시 용산구 이촌동', '서울특별시 용산구 한강로1가',
#        '서울특별시 영등포구 영등포동1가', '서울특별시 영등포구 영등포동2가', '서울특별시 영등포구 영등포동3가',
#        '서울특별시 영등포구 영등포동4가', '서울특별시 영등포구 영등포동5가', '서울특별시 영등포구 영등포동7가',
#        '서울특별시 용산구 갈월동', '서울특별시 용산구 도원동', '서울특별시 용산구 동빙고동',
#        '서울특별시 용산구 동자동', '서울특별시 용산구 보광동', '서울특별시 용산구 서빙고동',
#        '서울특별시 용산구 신창동', '서울특별시 용산구 용문동', '서울특별시 용산구 용산동2가',
#        '서울특별시 용산구 용산동5가', '서울특별시 용산구 원효로2가', '서울특별시 용산구 원효로3가',
#        '서울특별시 용산구 원효로4가', '서울특별시 용산구 이태원동', '서울특별시 용산구 주성동',
#        '서울특별시 용산구 청암동', '서울특별시 용산구 청파동1가', '서울특별시 용산구 청파동3가',
#        '서울특별시 용산구 한강로2가', '서울특별시 용산구 한남동', '서울특별시 용산구 효창동',
#        '서울특별시 용산구 후암동', '서울특별시 은평구 구산동', '서울특별시 은평구 녹번동', '서울특별시 은평구 불광동',
#        '서울특별시 은평구 수색동', '서울특별시 용산구 한강로3가', '서울특별시 은평구 갈현동',
#        '서울특별시 은평구 대조동', '서울특별시 은평구 신사동', '서울특별시 은평구 역촌동', '서울특별시 은평구 응암동',
#        '서울특별시 은평구 증산동', '서울특별시 은평구 진관동', '서울특별시 종로구 내수동', '서울특별시 종로구 무악동',
#        '서울특별시 종로구 숭인동', '서울특별시 종로구 익선동', '서울특별시 종로구 효제동',
#        '서울특별시 중구 만리동1가', '서울특별시 중구 만리동2가', '서울특별시 중구 신당동',
#        '서울특별시 중구 충무로4가', '서울특별시 종로구 견지동', '서울특별시 종로구 교남동',
#        '서울특별시 종로구 교북동', '서울특별시 종로구 누상동', '서울특별시 종로구 당주동', '서울특별시 종로구 동숭동',
#        '서울특별시 종로구 명륜1가', '서울특별시 종로구 명륜2가', '서울특별시 종로구 명륜3가',
#        '서울특별시 종로구 사직동', '서울특별시 종로구 신문로1가', '서울특별시 종로구 신영동',
#        '서울특별시 종로구 연건동', '서울특별시 종로구 옥인동', '서울특별시 종로구 인의동', '서울특별시 종로구 창신동',
#        '서울특별시 종로구 청운동', '서울특별시 종로구 충신동', '서울특별시 종로구 평창동', '서울특별시 종로구 필운동',
#        '서울특별시 종로구 행촌동', '서울특별시 종로구 혜화동', '서울특별시 종로구 홍파동',
#        '서울특별시 중구 남대문로5가', '서울특별시 중구 남창동', '서울특별시 중구 묵정동', '서울특별시 중구 산림동',
#        '서울특별시 중구 순화동', '서울특별시 중구 예장동', '서울특별시 중구 을지로5가', '서울특별시 중구 인현동2가',
#        '서울특별시 중구 장충동1가', '서울특별시 중구 장충동2가', '서울특별시 중구 중림동',
#        '서울특별시 중구 충무로5가', '서울특별시 중구 필동1가', '서울특별시 중구 황학동',
#        '서울특별시 중구 회현동1가', '서울특별시 중구 회현동2가', '서울특별시 중구 흥인동',
#        '서울특별시 중랑구 망우동', '서울특별시 중랑구 면목동', '서울특별시 중랑구 묵동', '서울특별시 중랑구 상봉동',
#        '서울특별시 중랑구 신내동', '서울특별시 중랑구 중화동', '서울특별시 광진구 능동', '서울특별시 서대문구 미근동',
#        '서울특별시 성북구 보문동2가', '서울특별시 종로구 구기동', '서울특별시 종로구 부암동',
#        '서울특별시 종로구 수송동', '서울특별시 종로구 통인동', '서울특별시 중구 남산동2가',
#        '서울특별시 종로구 신교동', '서울특별시 중구 정동', '서울특별시 중구 필동3가', '서울특별시 성북구 안암동5가',
#        '서울특별시 종로구 신문로2가', '서울특별시 종로구 연지동', '서울특별시 종로구 평동', '서울특별시 중구 오장동',
#        '서울특별시 중구 입정동', '서울특별시 종로구 이화동', '서울특별시 마포구 구수동', '서울특별시 종로구 원남동',
#        '서울특별시 종로구 낙원동'], dtype=object)
# 번지
# array(['658-1', '652', '12-2', ..., '253-89', '67-5', '240'], dtype=object)
# 아파트명
# array(['개포6차우성', '개포우성3차', '개포자이', ..., '히페리온리버팰리스', '세운푸르지오헤리시티',
#        '힐스테이트세운센트럴1단지'], dtype=object)
# 거래유형
# array([nan, '중개거래', '직거래'], dtype=object)
# k-단지분류(아파트,주상복합등등)
# array(['아파트', '주상복합', nan, '연립주택', '도시형 생활주택(아파트)', '도시형 생활주택(주상복합)'],
#       dtype=object)
# k-세대타입(분양형태)
# array(['분양', '기타', nan, '임대'], dtype=object)
# k-복도유형
# array(['계단식', '혼합식', '복도식', '타워형', '기타', nan], dtype=object)
# k-난방방식
# array(['개별난방', '지역난방', '기타', nan, '중앙난방'], dtype=object)
# k-건설사(시공사)
# array(['우성건설', '박연정', '대한주택공사', '현대건설(주)', '동양고속건설주식회사', '대우건설',
#        '대림산업(주)', '삼성물산', nan, '삼성물산주식회사', '현대,쌍용,GS', '쌍용건설(주)',
#        '현대산업개발', '한보', '삼성중공업', '대성산업', '중앙건설', '세방기업', '태영건설', '신동아',
#        '신동아건설', '고려개발(주)', '대우건설,대림산업,태영건설', '한라, 두진', '고려산업개발(주)',
#        '삼성건설', '롯데건설', 'GS건설', '(주)한화건설', '한신공영', '(주)건영,삼익주택,라이프주택',
#        '계룡건설산업(주)', '한양수자인', '건영종합건설(주)', '청담삼익아파트', '계룡건설(주)', '삼환기업',
#        '한신공영(주)', 'KR산업', '동부건설', '고속도로관리공단', '동부건설(주)외1', 'SH공사',
#        '남광, 대우', 'sh공사', '청광종합건설(주)', '중앙건설(주)', 'LG건설', '신동아건설(주)',
#        '현대산업개발(주)', '(주)청구주택', '삼호건설', '(주)삼호', '한솔건설', '현대,대림',
#        '신동아 건설(주)', '임광토건(주)', '롯데건설(주)', '벽산건설', '동부건설(주)', '현대 성우건설',
#        '홍익종합건업(주)', '한양주택 (주)', '한진중공업(주)', '성지건설', '남광토건(주)', 'gs건설',
#        '신명건설,신원건설,미주건설', 'KCC', '두산, 이수건설', '두산건설', 'TEC건설',
#        '현대건설,현대산업개발,한진중공업', '성원건설(주)', '라인건설', '코오롱글로벌(주)', '금호건설',
#        '(주)대보건설', '(주)한양', '경남기업', '에스에이치공사', '금호', '(주)서광건설산업',
#        '우림건설(주)', '중앙하이츠', '청구', '우림건설', '삼환, 삼익건설', '(주)현대건설', '(주)쌍용건설',
#        '삼성건설(주)', '보람건설(주)', '한화건설', '현대건설', '한일건설', '주식회사 서희건설',
#        '대호아이피종합건설', '라이프건설', '갑을건설', '대우건설(주)', '현대건설주식회사', 'SK건설',
#        '우성건설(주)', '고려산업개발', '인정건설(주)', '인정건설', '(주)우성건설', '재건축조합',
#        '(주)월드건설', '대우푸르지오', '삼익건설', 'GS건설(주)', '(주)롯데건설', '(주)태영',
#        '(주)우리건설', '대한전척(주)', '경남기업(주)', '포스코건설', '(주)금호건설', '풍림건설',
#        '한진중공업', '(주)중앙건설', '한양', '풍림산업(주)', '현대종합건설', '신도건설', '건영건설',
#        '풍림산업,현대건설', '서울도시개발공사', '우성', '(주)효성', '현대엔지니어링', '이수건설,대우엔지니어링',
#        '한일개발', '(주)효성건설', '효성중공업', '대림산업', '두산건설주식회사', '(주)신도종합건설',
#        '(주)성원건설', '세양건설', '인덕주택재건축정비사업조합/(주)신도종합건설', '롯데건설,우성건설', '럭키외',
#        '도시개발공사', '대백건설', 'sh 공사', '삼성물산,두산건설', '세양건설산업(주)', '대우경남',
#        '극동건설', '현대bs&c', '금호산업', '삼성물산 건설부문', '주택공사', '삼성물산(주) 건설부문',
#        'BYC', '현대BS&C', '삼성물산(주)', '신성건설(주)', '(주)동일토건', '코오롱건설',
#        '(주) 신한건설', '경동건설', '극동건설(주)', '남해건설', '엘지건설(주)', '(주)서희건설',
#        'LIG건설', '경향건설(주)', '삼성물산(주) 주택부문', '라성건설', '해태건설(주)', '동양메이저건설',
#        '흑석5구역재개발조합', '(주)포스코건설', '서희건설', '동원산업건설', '쌍용', '양우건설', '양우건설사',
#        '서광산업', '대동건설', '진흥기업', '신창건설(주)->우방건설', '유원, 선경, 대우건설', '이수건설(주)',
#        '(주)우리창우', 'GS자이 건설', '삼성중공업(주)', '(주)삼성물산', '청구건설', ' (주) 건영',
#        '계룡건설', '지에스건설주식회사', '(주)대우건설', '두산중공업', '삼성물산, 대림산업', '대림',
#        '우정건설', '라이프주택', '고려개발 ', '?양건설', '포스코', '고려개발', '삼성물산, 현대산업개발',
#        '한보건설', '(주)대우', '(주)대림산업', '흥화공업(주)', '삼호주택', '쌍용건설', '대림산업주식회사',
#        '삼성래미안', '(주)대림/ (주)삼성', '한보철강', '대림건설', '대림산업 (주)', '아남건설주식회사',
#        '유원건설', '풍림산업', '진흥건설', 'SH', '(주)태영건설', '울트라건설', '(주)건영', '우방건설',
#        '금호자이', '이수건설', '포스코,SK,현대', '삼부토건', '동아건설', '벽산건설(주)',
#        '돈암정릉구역주택재개발정비사업조합', '동일하이빌', '동선구역주택재개발조합', '동아건설산업(주)', '대명종합건설',
#        '대주건설', '성원건설', '(주)동아건설산업', '정릉제4구역재개발조합 ', '현대힐스테이트', '선경건설',
#        '동일토건', '아키데코', '미주실업주식회사', '삼익주택(주)', '(주)신일건업', '태영건설, 현대산업개발',
#        '대우,럭키개발,롯데건설,선경건설,태평양건설', '주식회사 삼익주택', '(주)한양건설', '주)대우건설',
#        '동성개발', '(주)호반건설', '삼성물산,한화건설', '대림,삼성,현대,현산', '(주)한라', '(주)일성건설',
#        '양우건설(주)', '삼중종합건설(주)', '울트라건설(주)', '(주)진흥기업', '(주)신창건설',
#        '현대산업개발 주', '(주)한진중공업', '금호건설(주)', '나산건설', '금하건설', '한성강서재건축조합',
#        '유원건설(주)', '한양건설', '서초건설', '(주)gs공사', '미원건설(주)', '상부종합건설(주)',
#        '우정건설 주식회사', '한화건설(주)', '롯데건설주식회사', '(주)순영종합건설', '(주)대우자동차판매',
#        '한진건설(주)', '(주) 건영', '(주)금호산업', 'JR건설', '해주개발주식회사', '대창건설',
#        '지에스 건설', '신성건설', '토왕건설', '(주)신성건설', '주시회사 현대건설', '문영건설', '(주)우방',
#        '한라', '(주)삼전건설', '신홍선건설', 'LIG건설(주)', 'GS건설주식회사', '(주)한라건설',
#        '예성종합건설', '삼익주택', '공영토건', '코오롱글로벌', '포스코, 포스코A&C', '(주)건설알포메',
#        '흥화공업', '동양메이저(주)', '동일', '한솔', ' 일신건영', '호반건설', '미주실업,동방티앤씨',
#        '진흥기업(주)', '(주)도시공감', '(주)에스에이치건설', '두산건설(주)', '지에스건설(주)', '(주)금호',
#        '삼정건설', '월드건설(주)', '한승', '유원울트라', '(주)현진종합건설', '우리건설', '(주)현대산업개발',
#        '일성건설', '신일산업', '진흥연립재건축조합', '코오롱건설주식회사', '두산', '신영건설',
#        '현대건설,삼성물산,현대산업개발', '자이에스앤디(주)', '대림건설(주)', 'HDC현대산업개발',
#        '대림산업, 롯데건설', 'GS 건설', 'kcc건설', '삼정기업', '혜림건설',
#        '한신공영(주), 한양산업개발(주', '(주)에스케이건설', '삼익건설(주)'], dtype=object)
# 기타/의무/임대/임의=1/2/3/4
# array(['임의', '의무', '기타', nan, '임대'], dtype=object)

# %%
for column in categorical_columns:
     concat[column]  = concat[column].fillna('NULL')

# %%
for column in categorical_columns:
    print(column)
    display(concat[column].unique())
# Out:
# 시군구
# array(['서울특별시 강남구 개포동', '서울특별시 강남구 논현동', '서울특별시 강남구 대치동', '서울특별시 강남구 도곡동',
#        '서울특별시 강남구 삼성동', '서울특별시 강남구 세곡동', '서울특별시 강남구 수서동', '서울특별시 강남구 신사동',
#        '서울특별시 강남구 역삼동', '서울특별시 강남구 압구정동', '서울특별시 강남구 일원동',
#        '서울특별시 강남구 자곡동', '서울특별시 강남구 청담동', '서울특별시 강동구 강일동', '서울특별시 강남구 율현동',
#        '서울특별시 강동구 고덕동', '서울특별시 강동구 길동', '서울특별시 강동구 둔촌동', '서울특별시 강동구 명일동',
#        '서울특별시 강동구 상일동', '서울특별시 강동구 성내동', '서울특별시 강동구 암사동', '서울특별시 강동구 천호동',
#        '서울특별시 강북구 미아동', '서울특별시 강북구 번동', '서울특별시 강서구 가양동', '서울특별시 강북구 수유동',
#        '서울특별시 강북구 우이동', '서울특별시 강서구 내발산동', '서울특별시 강서구 등촌동',
#        '서울특별시 강서구 공항동', '서울특별시 강서구 마곡동', '서울특별시 강서구 방화동', '서울특별시 강서구 염창동',
#        '서울특별시 강서구 화곡동', '서울특별시 관악구 남현동', '서울특별시 관악구 봉천동', '서울특별시 관악구 신림동',
#        '서울특별시 광진구 광장동', '서울특별시 광진구 구의동', '서울특별시 광진구 자양동', '서울특별시 광진구 군자동',
#        '서울특별시 광진구 화양동', '서울특별시 구로구 개봉동', '서울특별시 구로구 고척동', '서울특별시 광진구 중곡동',
#        '서울특별시 구로구 가리봉동', '서울특별시 구로구 구로동', '서울특별시 구로구 오류동',
#        '서울특별시 구로구 천왕동', '서울특별시 금천구 독산동', '서울특별시 구로구 온수동', '서울특별시 구로구 궁동',
#        '서울특별시 구로구 신도림동', '서울특별시 구로구 항동', '서울특별시 금천구 가산동', '서울특별시 금천구 시흥동',
#        '서울특별시 노원구 공릉동', '서울특별시 노원구 상계동', '서울특별시 노원구 월계동', '서울특별시 노원구 중계동',
#        '서울특별시 노원구 하계동', '서울특별시 도봉구 도봉동', '서울특별시 도봉구 방학동', '서울특별시 도봉구 쌍문동',
#        '서울특별시 도봉구 창동', '서울특별시 동대문구 답십리동', '서울특별시 동대문구 용두동',
#        '서울특별시 동대문구 이문동', '서울특별시 동대문구 신설동', '서울특별시 동대문구 장안동',
#        '서울특별시 동대문구 전농동', '서울특별시 동대문구 회기동', '서울특별시 동대문구 제기동',
#        '서울특별시 동대문구 청량리동', '서울특별시 동대문구 휘경동', '서울특별시 동작구 노량진동',
#        '서울특별시 동작구 대방동', '서울특별시 동작구 동작동', '서울특별시 동작구 본동', '서울특별시 동작구 사당동',
#        '서울특별시 동작구 상도동', '서울특별시 동작구 상도1동', '서울특별시 동작구 신대방동',
#        '서울특별시 동작구 흑석동', '서울특별시 마포구 공덕동', '서울특별시 마포구 노고산동',
#        '서울특별시 마포구 대흥동', '서울특별시 마포구 도화동', '서울특별시 마포구 마포동', '서울특별시 마포구 상수동',
#        '서울특별시 마포구 상암동', '서울특별시 마포구 서교동', '서울특별시 마포구 성산동',
#        '서울특별시 마포구 신공덕동', '서울특별시 마포구 신수동', '서울특별시 마포구 신정동',
#        '서울특별시 마포구 아현동', '서울특별시 마포구 동교동', '서울특별시 마포구 망원동', '서울특별시 마포구 염리동',
#        '서울특별시 마포구 용강동', '서울특별시 마포구 중동', '서울특별시 마포구 창전동', '서울특별시 마포구 하중동',
#        '서울특별시 마포구 합정동', '서울특별시 서대문구 남가좌동', '서울특별시 서대문구 냉천동',
#        '서울특별시 서대문구 북가좌동', '서울특별시 마포구 연남동', '서울특별시 마포구 토정동',
#        '서울특별시 마포구 현석동', '서울특별시 서대문구 대현동', '서울특별시 서대문구 연희동',
#        '서울특별시 서대문구 영천동', '서울특별시 서대문구 충정로3가', '서울특별시 서대문구 현저동',
#        '서울특별시 서대문구 홍은동', '서울특별시 서대문구 홍제동', '서울특별시 서대문구 북아현동',
#        '서울특별시 서대문구 창천동', '서울특별시 서대문구 천연동', '서울특별시 서대문구 충정로2가',
#        '서울특별시 서대문구 합동', '서울특별시 서초구 내곡동', '서울특별시 서초구 반포동', '서울특별시 서초구 방배동',
#        '서울특별시 서초구 서초동', '서울특별시 서초구 신원동', '서울특별시 서초구 우면동', '서울특별시 서초구 잠원동',
#        '서울특별시 서초구 양재동', '서울특별시 성동구 금호동1가', '서울특별시 성동구 금호동2가',
#        '서울특별시 성동구 금호동3가', '서울특별시 성동구 성수동1가', '서울특별시 성동구 성수동2가',
#        '서울특별시 성동구 금호동4가', '서울특별시 성동구 송정동', '서울특별시 성동구 도선동',
#        '서울특별시 성동구 마장동', '서울특별시 성동구 사근동', '서울특별시 성동구 상왕십리동',
#        '서울특별시 성동구 옥수동', '서울특별시 성동구 하왕십리동', '서울특별시 성동구 행당동',
#        '서울특별시 성동구 응봉동', '서울특별시 성동구 용답동', '서울특별시 성동구 홍익동', '서울특별시 성북구 길음동',
#        '서울특별시 성북구 돈암동', '서울특별시 성북구 동소문동5가', '서울특별시 성북구 동소문동7가',
#        '서울특별시 성북구 보문동3가', '서울특별시 성북구 동선동1가', '서울특별시 성북구 동선동3가',
#        '서울특별시 성북구 동선동4가', '서울특별시 성북구 동선동5가', '서울특별시 성북구 동소문동4가',
#        '서울특별시 성북구 동소문동6가', '서울특별시 성북구 보문동6가', '서울특별시 성북구 삼선동2가',
#        '서울특별시 성북구 상월곡동', '서울특별시 성북구 석관동', '서울특별시 성북구 장위동',
#        '서울특별시 성북구 정릉동', '서울특별시 성북구 보문동4가', '서울특별시 성북구 삼선동3가',
#        '서울특별시 성북구 삼선동4가', '서울특별시 성북구 삼선동5가', '서울특별시 성북구 성북동',
#        '서울특별시 성북구 성북동1가', '서울특별시 성북구 안암동1가', '서울특별시 성북구 안암동3가',
#        '서울특별시 성북구 안암동4가', '서울특별시 성북구 종암동', '서울특별시 성북구 하월곡동',
#        '서울특별시 송파구 가락동', '서울특별시 송파구 거여동', '서울특별시 송파구 마천동', '서울특별시 송파구 문정동',
#        '서울특별시 송파구 석촌동', '서울특별시 송파구 송파동', '서울특별시 송파구 방이동', '서울특별시 송파구 삼전동',
#        '서울특별시 송파구 신천동', '서울특별시 송파구 오금동', '서울특별시 송파구 잠실동', '서울특별시 송파구 장지동',
#        '서울특별시 송파구 풍납동', '서울특별시 양천구 목동', '서울특별시 양천구 신월동', '서울특별시 양천구 신정동',
#        '서울특별시 영등포구 당산동', '서울특별시 영등포구 당산동3가', '서울특별시 영등포구 당산동4가',
#        '서울특별시 영등포구 대림동', '서울특별시 영등포구 도림동', '서울특별시 영등포구 문래동3가',
#        '서울특별시 영등포구 당산동5가', '서울특별시 영등포구 당산동1가', '서울특별시 영등포구 당산동2가',
#        '서울특별시 영등포구 당산동6가', '서울특별시 영등포구 문래동2가', '서울특별시 영등포구 문래동5가',
#        '서울특별시 영등포구 문래동6가', '서울특별시 영등포구 신길동', '서울특별시 영등포구 양평동2가',
#        '서울특별시 영등포구 양평동5가', '서울특별시 영등포구 여의도동', '서울특별시 영등포구 문래동4가',
#        '서울특별시 영등포구 양평동1가', '서울특별시 영등포구 양평동3가', '서울특별시 영등포구 양평동4가',
#        '서울특별시 영등포구 양평동6가', '서울특별시 영등포구 영등포동', '서울특별시 영등포구 영등포동8가',
#        '서울특별시 용산구 문배동', '서울특별시 용산구 산천동', '서울특별시 용산구 신계동',
#        '서울특별시 용산구 원효로1가', '서울특별시 용산구 이촌동', '서울특별시 용산구 한강로1가',
#        '서울특별시 영등포구 영등포동1가', '서울특별시 영등포구 영등포동2가', '서울특별시 영등포구 영등포동3가',
#        '서울특별시 영등포구 영등포동4가', '서울특별시 영등포구 영등포동5가', '서울특별시 영등포구 영등포동7가',
#        '서울특별시 용산구 갈월동', '서울특별시 용산구 도원동', '서울특별시 용산구 동빙고동',
#        '서울특별시 용산구 동자동', '서울특별시 용산구 보광동', '서울특별시 용산구 서빙고동',
#        '서울특별시 용산구 신창동', '서울특별시 용산구 용문동', '서울특별시 용산구 용산동2가',
#        '서울특별시 용산구 용산동5가', '서울특별시 용산구 원효로2가', '서울특별시 용산구 원효로3가',
#        '서울특별시 용산구 원효로4가', '서울특별시 용산구 이태원동', '서울특별시 용산구 주성동',
#        '서울특별시 용산구 청암동', '서울특별시 용산구 청파동1가', '서울특별시 용산구 청파동3가',
#        '서울특별시 용산구 한강로2가', '서울특별시 용산구 한남동', '서울특별시 용산구 효창동',
#        '서울특별시 용산구 후암동', '서울특별시 은평구 구산동', '서울특별시 은평구 녹번동', '서울특별시 은평구 불광동',
#        '서울특별시 은평구 수색동', '서울특별시 용산구 한강로3가', '서울특별시 은평구 갈현동',
#        '서울특별시 은평구 대조동', '서울특별시 은평구 신사동', '서울특별시 은평구 역촌동', '서울특별시 은평구 응암동',
#        '서울특별시 은평구 증산동', '서울특별시 은평구 진관동', '서울특별시 종로구 내수동', '서울특별시 종로구 무악동',
#        '서울특별시 종로구 숭인동', '서울특별시 종로구 익선동', '서울특별시 종로구 효제동',
#        '서울특별시 중구 만리동1가', '서울특별시 중구 만리동2가', '서울특별시 중구 신당동',
#        '서울특별시 중구 충무로4가', '서울특별시 종로구 견지동', '서울특별시 종로구 교남동',
#        '서울특별시 종로구 교북동', '서울특별시 종로구 누상동', '서울특별시 종로구 당주동', '서울특별시 종로구 동숭동',
#        '서울특별시 종로구 명륜1가', '서울특별시 종로구 명륜2가', '서울특별시 종로구 명륜3가',
#        '서울특별시 종로구 사직동', '서울특별시 종로구 신문로1가', '서울특별시 종로구 신영동',
#        '서울특별시 종로구 연건동', '서울특별시 종로구 옥인동', '서울특별시 종로구 인의동', '서울특별시 종로구 창신동',
#        '서울특별시 종로구 청운동', '서울특별시 종로구 충신동', '서울특별시 종로구 평창동', '서울특별시 종로구 필운동',
#        '서울특별시 종로구 행촌동', '서울특별시 종로구 혜화동', '서울특별시 종로구 홍파동',
#        '서울특별시 중구 남대문로5가', '서울특별시 중구 남창동', '서울특별시 중구 묵정동', '서울특별시 중구 산림동',
#        '서울특별시 중구 순화동', '서울특별시 중구 예장동', '서울특별시 중구 을지로5가', '서울특별시 중구 인현동2가',
#        '서울특별시 중구 장충동1가', '서울특별시 중구 장충동2가', '서울특별시 중구 중림동',
#        '서울특별시 중구 충무로5가', '서울특별시 중구 필동1가', '서울특별시 중구 황학동',
#        '서울특별시 중구 회현동1가', '서울특별시 중구 회현동2가', '서울특별시 중구 흥인동',
#        '서울특별시 중랑구 망우동', '서울특별시 중랑구 면목동', '서울특별시 중랑구 묵동', '서울특별시 중랑구 상봉동',
#        '서울특별시 중랑구 신내동', '서울특별시 중랑구 중화동', '서울특별시 광진구 능동', '서울특별시 서대문구 미근동',
#        '서울특별시 성북구 보문동2가', '서울특별시 종로구 구기동', '서울특별시 종로구 부암동',
#        '서울특별시 종로구 수송동', '서울특별시 종로구 통인동', '서울특별시 중구 남산동2가',
#        '서울특별시 종로구 신교동', '서울특별시 중구 정동', '서울특별시 중구 필동3가', '서울특별시 성북구 안암동5가',
#        '서울특별시 종로구 신문로2가', '서울특별시 종로구 연지동', '서울특별시 종로구 평동', '서울특별시 중구 오장동',
#        '서울특별시 중구 입정동', '서울특별시 종로구 이화동', '서울특별시 마포구 구수동', '서울특별시 종로구 원남동',
#        '서울특별시 종로구 낙원동'], dtype=object)
# 번지
# array(['658-1', '652', '12-2', ..., '253-89', '67-5', '240'], dtype=object)
# 아파트명
# array(['개포6차우성', '개포우성3차', '개포자이', ..., '히페리온리버팰리스', '세운푸르지오헤리시티',
#        '힐스테이트세운센트럴1단지'], dtype=object)
# 거래유형
# array(['NULL', '중개거래', '직거래'], dtype=object)
# k-단지분류(아파트,주상복합등등)
# array(['아파트', '주상복합', 'NULL', '연립주택', '도시형 생활주택(아파트)', '도시형 생활주택(주상복합)'],
#       dtype=object)
# k-세대타입(분양형태)
# array(['분양', '기타', 'NULL', '임대'], dtype=object)
# k-복도유형
# array(['계단식', '혼합식', '복도식', '타워형', '기타', 'NULL'], dtype=object)
# k-난방방식
# array(['개별난방', '지역난방', '기타', 'NULL', '중앙난방'], dtype=object)
# k-건설사(시공사)
# array(['우성건설', '박연정', '대한주택공사', '현대건설(주)', '동양고속건설주식회사', '대우건설',
#        '대림산업(주)', '삼성물산', 'NULL', '삼성물산주식회사', '현대,쌍용,GS', '쌍용건설(주)',
#        '현대산업개발', '한보', '삼성중공업', '대성산업', '중앙건설', '세방기업', '태영건설', '신동아',
#        '신동아건설', '고려개발(주)', '대우건설,대림산업,태영건설', '한라, 두진', '고려산업개발(주)',
#        '삼성건설', '롯데건설', 'GS건설', '(주)한화건설', '한신공영', '(주)건영,삼익주택,라이프주택',
#        '계룡건설산업(주)', '한양수자인', '건영종합건설(주)', '청담삼익아파트', '계룡건설(주)', '삼환기업',
#        '한신공영(주)', 'KR산업', '동부건설', '고속도로관리공단', '동부건설(주)외1', 'SH공사',
#        '남광, 대우', 'sh공사', '청광종합건설(주)', '중앙건설(주)', 'LG건설', '신동아건설(주)',
#        '현대산업개발(주)', '(주)청구주택', '삼호건설', '(주)삼호', '한솔건설', '현대,대림',
#        '신동아 건설(주)', '임광토건(주)', '롯데건설(주)', '벽산건설', '동부건설(주)', '현대 성우건설',
#        '홍익종합건업(주)', '한양주택 (주)', '한진중공업(주)', '성지건설', '남광토건(주)', 'gs건설',
#        '신명건설,신원건설,미주건설', 'KCC', '두산, 이수건설', '두산건설', 'TEC건설',
#        '현대건설,현대산업개발,한진중공업', '성원건설(주)', '라인건설', '코오롱글로벌(주)', '금호건설',
#        '(주)대보건설', '(주)한양', '경남기업', '에스에이치공사', '금호', '(주)서광건설산업',
#        '우림건설(주)', '중앙하이츠', '청구', '우림건설', '삼환, 삼익건설', '(주)현대건설', '(주)쌍용건설',
#        '삼성건설(주)', '보람건설(주)', '한화건설', '현대건설', '한일건설', '주식회사 서희건설',
#        '대호아이피종합건설', '라이프건설', '갑을건설', '대우건설(주)', '현대건설주식회사', 'SK건설',
#        '우성건설(주)', '고려산업개발', '인정건설(주)', '인정건설', '(주)우성건설', '재건축조합',
#        '(주)월드건설', '대우푸르지오', '삼익건설', 'GS건설(주)', '(주)롯데건설', '(주)태영',
#        '(주)우리건설', '대한전척(주)', '경남기업(주)', '포스코건설', '(주)금호건설', '풍림건설',
#        '한진중공업', '(주)중앙건설', '한양', '풍림산업(주)', '현대종합건설', '신도건설', '건영건설',
#        '풍림산업,현대건설', '서울도시개발공사', '우성', '(주)효성', '현대엔지니어링', '이수건설,대우엔지니어링',
#        '한일개발', '(주)효성건설', '효성중공업', '대림산업', '두산건설주식회사', '(주)신도종합건설',
#        '(주)성원건설', '세양건설', '인덕주택재건축정비사업조합/(주)신도종합건설', '롯데건설,우성건설', '럭키외',
#        '도시개발공사', '대백건설', 'sh 공사', '삼성물산,두산건설', '세양건설산업(주)', '대우경남',
#        '극동건설', '현대bs&c', '금호산업', '삼성물산 건설부문', '주택공사', '삼성물산(주) 건설부문',
#        'BYC', '현대BS&C', '삼성물산(주)', '신성건설(주)', '(주)동일토건', '코오롱건설',
#        '(주) 신한건설', '경동건설', '극동건설(주)', '남해건설', '엘지건설(주)', '(주)서희건설',
#        'LIG건설', '경향건설(주)', '삼성물산(주) 주택부문', '라성건설', '해태건설(주)', '동양메이저건설',
#        '흑석5구역재개발조합', '(주)포스코건설', '서희건설', '동원산업건설', '쌍용', '양우건설', '양우건설사',
#        '서광산업', '대동건설', '진흥기업', '신창건설(주)->우방건설', '유원, 선경, 대우건설', '이수건설(주)',
#        '(주)우리창우', 'GS자이 건설', '삼성중공업(주)', '(주)삼성물산', '청구건설', ' (주) 건영',
#        '계룡건설', '지에스건설주식회사', '(주)대우건설', '두산중공업', '삼성물산, 대림산업', '대림',
#        '우정건설', '라이프주택', '고려개발 ', '?양건설', '포스코', '고려개발', '삼성물산, 현대산업개발',
#        '한보건설', '(주)대우', '(주)대림산업', '흥화공업(주)', '삼호주택', '쌍용건설', '대림산업주식회사',
#        '삼성래미안', '(주)대림/ (주)삼성', '한보철강', '대림건설', '대림산업 (주)', '아남건설주식회사',
#        '유원건설', '풍림산업', '진흥건설', 'SH', '(주)태영건설', '울트라건설', '(주)건영', '우방건설',
#        '금호자이', '이수건설', '포스코,SK,현대', '삼부토건', '동아건설', '벽산건설(주)',
#        '돈암정릉구역주택재개발정비사업조합', '동일하이빌', '동선구역주택재개발조합', '동아건설산업(주)', '대명종합건설',
#        '대주건설', '성원건설', '(주)동아건설산업', '정릉제4구역재개발조합 ', '현대힐스테이트', '선경건설',
#        '동일토건', '아키데코', '미주실업주식회사', '삼익주택(주)', '(주)신일건업', '태영건설, 현대산업개발',
#        '대우,럭키개발,롯데건설,선경건설,태평양건설', '주식회사 삼익주택', '(주)한양건설', '주)대우건설',
#        '동성개발', '(주)호반건설', '삼성물산,한화건설', '대림,삼성,현대,현산', '(주)한라', '(주)일성건설',
#        '양우건설(주)', '삼중종합건설(주)', '울트라건설(주)', '(주)진흥기업', '(주)신창건설',
#        '현대산업개발 주', '(주)한진중공업', '금호건설(주)', '나산건설', '금하건설', '한성강서재건축조합',
#        '유원건설(주)', '한양건설', '서초건설', '(주)gs공사', '미원건설(주)', '상부종합건설(주)',
#        '우정건설 주식회사', '한화건설(주)', '롯데건설주식회사', '(주)순영종합건설', '(주)대우자동차판매',
#        '한진건설(주)', '(주) 건영', '(주)금호산업', 'JR건설', '해주개발주식회사', '대창건설',
#        '지에스 건설', '신성건설', '토왕건설', '(주)신성건설', '주시회사 현대건설', '문영건설', '(주)우방',
#        '한라', '(주)삼전건설', '신홍선건설', 'LIG건설(주)', 'GS건설주식회사', '(주)한라건설',
#        '예성종합건설', '삼익주택', '공영토건', '코오롱글로벌', '포스코, 포스코A&C', '(주)건설알포메',
#        '흥화공업', '동양메이저(주)', '동일', '한솔', ' 일신건영', '호반건설', '미주실업,동방티앤씨',
#        '진흥기업(주)', '(주)도시공감', '(주)에스에이치건설', '두산건설(주)', '지에스건설(주)', '(주)금호',
#        '삼정건설', '월드건설(주)', '한승', '유원울트라', '(주)현진종합건설', '우리건설', '(주)현대산업개발',
#        '일성건설', '신일산업', '진흥연립재건축조합', '코오롱건설주식회사', '두산', '신영건설',
#        '현대건설,삼성물산,현대산업개발', '자이에스앤디(주)', '대림건설(주)', 'HDC현대산업개발',
#        '대림산업, 롯데건설', 'GS 건설', 'kcc건설', '삼정기업', '혜림건설',
#        '한신공영(주), 한양산업개발(주', '(주)에스케이건설', '삼익건설(주)'], dtype=object)
# 기타/의무/임대/임의=1/2/3/4
# array(['임의', '의무', '기타', 'NULL', '임대'], dtype=object)

# %% [markdown]
# # 시군구 string 시, 구 , 동으로 분리

# %%
concat[['시', '구', '동']] = concat['시군구'].str.split(' ', expand=True)

concat.head(1)
# Out:
#              시군구     번지     본번   부번    아파트명  전용면적(㎡)    계약년월  계약일  층  건축년도  \
# 0  서울특별시 강남구 개포동  658-1  658.0  1.0  개포6차우성    79.97  201712    8  3  1987
#
#    ...  사용허가여부 관리비 업로드        좌표X        좌표Y               단지신청일    target  \
# 0  ...     1.0     0.0  127.05721  37.476763 2022-11-17 10:19:06  124000.0
#
#    is_test      시    구    동
# 0        0  서울특별시  강남구  개포동
#
# [1 rows x 43 columns]

# %%
concat.drop(["시군구"],axis=1, inplace=True)

# %%
concat.head(1)
# Out:
#       번지     본번   부번    아파트명  전용면적(㎡)    계약년월  계약일  층  건축년도  등기신청일자  ...  \
# 0  658-1  658.0  1.0  개포6차우성    79.97  201712    8  3  1987     NaN  ...
#
#   사용허가여부 관리비 업로드        좌표X        좌표Y               단지신청일    target  is_test  \
# 0    1.0     0.0  127.05721  37.476763 2022-11-17 10:19:06  124000.0        0
#
#        시    구    동
# 0  서울특별시  강남구  개포동
#
# [1 rows x 42 columns]

# %%
modified_train = concat[concat["is_test"]==0]
modified_test = concat[concat["is_test"]==1]
modified_train.head()
modified_train.drop(["is_test"], axis=1, inplace=True)
modified_test.head()
modified_test.drop(["is_test"], axis=1, inplace=True)

modified_test.to_csv("../modified_data/v04_test.csv")
modified_train.to_csv("../modified_data/v04_train.csv")
