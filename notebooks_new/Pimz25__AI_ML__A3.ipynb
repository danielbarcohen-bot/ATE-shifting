# %% [markdown]
# ![RMIT logo](https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTlAppozhCGl50pjgEZu_tTmalWJi3TjpNwCg&s)
# |Course|Foundations of Artificial Intelligence for STEM|
# |-----|-------|
# |Course Code|COSC2968/COSC3053|
# |Lecturer(s)|Mr.Nhat-Quang Tran and Mrs.Anh Le Van|
# |Full name - Student ID| Le Kim Quyen - s3983370<br>Ton Dat Toan - s4070286<br>Nguyen Hong Ha - s3979100<br>Huynh Bao Khoa Dang - s4045607<br>Nguyen Viet Ngan Anh - s4103086|

# %% [markdown]
# # Predicting The Age of Abalone

# %% [markdown]
# ## Table of Contents
# [1. Introduction](#intro) \
# [2. Exploration Data Analysis (EDA)](#eda) \
# &emsp;[2.1. Import Libraries and Modules](#eda_1) \
# &emsp;[2.2. Load the dataset](#eda_2) \
# &emsp;[2.3. Descriptive statistics, visualizations and correlation analysis](#eda_3) \
# &emsp;&emsp;[2.3.1. Overall data analysis](#eda_3_1) \
# &emsp;&emsp;[2.3.2. Group-specific data analysis](#eda_3_2) \
# [3. Data Preprocessing](#data_preprocessing) \
# &emsp;[3.1. Remove unused features](#data_preprocessing_1) \
# &emsp;[3.2. Identify and handle outliers](#data_preprocessing_2) \
# &emsp;[3.3. Split the data](#data_preprocessing_3) \
# &emsp;[3.4. Separate labels from data](#data_preprocessing_4) \
# &emsp;[3.5. Handle missing values](#data_preprocessing_5) \
# &emsp;[3.6. Encode categorical features](#data_preprocessing_6) \
# &emsp;[3.7. Scale numerical features](#data_preprocessing_7) \
# [4. Model Training and Evaluation](#train_evaluate) \
# &emsp;[4.1. Define support Functions](#train_evaluate_1) \
# &emsp;&emsp;[4.1.1. R-squared (R2) and root mean squared error (RMSE) Function](#train_evaluate_1_1) \
# &emsp;&emsp;[4.1.2. Function to store and load models](#train_evaluate_1_2) \
# &emsp;[4.2. Training Models](#train_evaluate_2) \
# &emsp;&emsp;[4.2.1. LinearRegression model](#train_evaluate_2_1) \
# &emsp;&emsp;[4.2.2. DecisionTreeRegressor model](#train_evaluate_2_2) \
# &emsp;&emsp;[4.2.3. RandomForestRegressor model](#train_evaluate_2_3) \
# &emsp;&emsp;[4.2.4. ElasticNet model](#train_evaluate_2_4) \
# &emsp;&emsp;[4.2.5. Gradient Boosting Regressor model](#train_evaluate_2_5) \
# &emsp;&emsp;[4.2.6. Lasso model](#train_evaluate_2_6) \
# &emsp;[4.3. Evaluate with K-fold cross validation](#train_evaluate_3) \
# [5. Hyperparameter Fine-tuning](#hyperparameter) \
# &emsp;[5.1. Define support Functions](#hyperparameter_1) \
# &emsp;[5.2. Choose the method for searching](#hyperparameter_2) \
# &emsp;[5.3. Grid search](#hyperparameter_3) \
# &emsp;[5.4. Randomized search](#hyperparameter_4) \
# [6. Model Testing and Analysis](#test_anal) \
# &emsp;[6.1. Model testing and evaluation](#test_anal_1) \
# &emsp;[6.2. Limitations and Implication](#test_anal_2) \
# [7. References](#ref) \
# [8. Contribution](#contribution)

# %% [markdown]
# ## 1. Introduction <a class="anchor" id="intro"></a>
# &emsp;Abalones are not only a rich source of nutrition but also provide therapeutic benefits to various diseases such as asthma, atherosclerosis, and heart disease (Suleria et al., 2017). Therefore, it has become one of the most sought-after luxury dishes in some global markets, such as Chile, France, China, Japan, Korea and Vietnam. The high demand for this item has led to an upsurge in the number of abalone farms and fisheries over the past few decades. Because of a potentially abundant supply, reducing costs is essential to keep the products competitive in the market (Cook, 2023). Although the value of abalone and its age have a positive correlation, the old method to determine its age is still slow, expensive and inefficient. Traditionally, an abalone shell must be sliced through the cone, stained, and examined under a microscope to count the rings, each of which represents one year of the abalone. Some rings can be difficult to distinguish, so the estimated age is often multiplied by 1.5 (Akanda et al., 2023). Therefore, it is necessary to implement a new technology to streamline the age-determination process.
#
# &emsp;The goal of this research is to construct a regression model that estimates the age of abalone just from its physical characteristics, namely, Sex, Longest shell, Diameter, Height, Whole weight, Shucked weight, Viscera weight, and Shell weight. This can help reduce the processing time and cost in abalone production. This report will consider six machine learning models, namely, linear regression model, decision tree regressor model, random forest regressor model, elastic net model, gradient boosting regressor, and lasso model, to find the optimal method. R-squared (R²) and Root Mean Squared Error (RMSE) are used to evaluate the models.

# %% [markdown]
# ## 2. Exploration Data Analysis (EDA) <a class="anchor" id="eda"></a>

# %% [markdown]
# ### 2.1. Import libraries and modules <a id="eda_1"></a>
# Installing and getting started with Terminal (if necessary):
# + pip install matplotlib
# + pip install seaborn
# + pip install ydata-profiling
# + pip install ipywidgets
# + pip install scikit-learn
# + pip install setuptools
#
# To install the necessary libraries / modules such as `pandas` (pandas, 2024) for read dataset; `matplotlib` (Matplotlib, n.d.), `seaborn` (Waskom, n.d.) and `ydata` (YData Profiling, n.d.) for visualization.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from ydata_profiling import ProfileReport

# run plots inline
# %matplotlib inline

# %% [markdown]
# ### 2.2. Load the dataset <a id="eda_2"></a>

# %%
abalone_df = pd.read_csv('Documents/Datasets/abalone.csv')
abalone_df.head() # Shows the first five samples

# %% [markdown]
# **Dataset description**
#
# &emsp;The dataset on abalone by Nash et al. (1995) is chosen due to several reasons. Firstly, in machine learning, particularly data analysis where datasets can range up to millions of samples, our chosen dataset is considered relatively moderate with a sample size of 4177, making it applicable in real-world scenarios. Secondly, there are eight different features, including one categorical feature, Type, and seven numeric features: Longest shell, Diameter, Height, Whole weight, Shucked weight, Viscera weight, and Shell weight. It also has 'rings' variable as the target data. The diversity in the number and dimensions makes the dataset satisfactory to the proposed regression model.
#
# &emsp;Based on the original study of this dataset (Nash et al., 1994), and the statistics of Candy Abalone (2021), there are some inconsistencies between the unit in the dataset (using decimeter and hectogram) and the description (millimetre and gram) on the latter version of Nash et al. (1995). Therefore, while the program runs the data in decimeter and hectogram, the report will interpret data using millimetre and gram for consistency with other reports, research, and accessibility to general readers.
#
# *Catagorical Variable:*
# + `Type`: Type of abalones (M = male, F = female and I = infant)
#
# *Numerical Variables:*
# + `Longest shell`: The longest shell measurement in dm
# + `Diameter`: The perpendicular to the length in dm
# + `Height`: The height with meat in shell in dm
# + `Whole weight`: The total weight of the abalone in hg
# + `Shucked weight`: The weight of the edible meat portion of the abalone in hg
# + `Viscera weight`: The weight of the abalone's internal organs, specifically the gut, after bleeding in hg
# + `Shell weight`: The weight of the shell after being dried in hg
# + `Rings`: +1.5 gives the age of the abalone in years

# %%
abalone_df.info() # Shows overview of each feature

# %% [markdown]
# &emsp;There are 4177 samples with no missing values. There are totally 9 variables, including 1 label (rings), and 8 features. While 'type' variable is categorical, and 'rings' variable is discrete, the rest are continuous data.

# %% [markdown]
# ### 2.3. Descriptive statistics, visualizations and correlation analysis <a id="eda_3"></a>

# %% [markdown]
# #### 2.3.1. Overall data analysis  <a id="eda_3_1"></a>
#
# **An overview using ydata** **:**

# %%
# An overview using ydata
ydata = ProfileReport(abalone_df, title = 'Abalone overview')
ydata.to_notebook_iframe()
ydata.to_file('Documents/Figures/abalone.html')

# %% [markdown]
# **Compute correlations between features**

# %%
# The variable contains correlations between features
abalone_corr = abalone_df.corr(numeric_only = True)

# uncomment to see data as table
abalone_corr

# %% [markdown]
# **Visualize using heatmap from seaborn** **:**

# %%
ones_corr = np.ones_like(abalone_corr, dtype = bool) # create a matrix contains boolean values with the same shape as abalone_corr
mask = np.triu(ones_corr) # a mask contains half triangle matrix of True and False

# Remove redundant the first row and the last column
adjusted_abalone_corr = abalone_corr.iloc[1:, :-1]
adjusted_mask_corr = mask[1:, :-1]

# Create plot
fig, ax = plt.subplots(figsize = (10, 8))

# Show heatmap
sns.heatmap(data = adjusted_abalone_corr, mask = adjusted_mask_corr, cmap = 'Blues',
            annot = True, fmt = '.2f', vmin = -1, vmax = 1,
            linecolor = 'white', linewidths = .5, annot_kws = {'fontsize': 14});

plt.savefig('Documents/Figures/heatmap.png') # Save as a picture in Figures folder
plt.show() # show plot

# %% [markdown]
# **Descriptive table**

# %%
abalone_df.describe()

# %% [markdown]
# &emsp;Abalones are categorized into 3 groups: female, male, and infant. The male group is comprised of 36.6% of the total samples (n = 1528), slightly larger than 2 other groups. Meanwhile, the infant and female groups have approximately the same sample size, at 32.1% (n = 1342) and 31.3% (1307).
#
# &emsp;Generally, descriptive statistics indicate the average size of all abalone samples with the longest shell of 52.4 mm (*SD* = 12), the diameter of 40 mm (*SD* = 9.92), and the height of 13.9 mm (*SD* = 4.18). The average whole weight is at 82.8 g (*SD* = 49), including the shucked weight of 35.9 g (*SD* = 22.19), the viscera weight of 18 g (*SD* = 10.96), and the shell weight of 23.9 g (*SD* = 13.92). The abalone are reported to be aged at nearly 10 years (*SD* = 3.22) on average. The size and weight of abalones can vary significantly: the longest shell ranges from 7.5 mm to 81.5 mm, the diameter ranges from 5.5 mm to 65 mm, and the height ranges from 1 mm to 11.3 mm. The whole weight can range from 0.2 g from 282.5 g. Specifically, the shucked weight spans from 0.1 g to 148.8 g; the viscera weight ranges from 0.05 g to 76 g; and the shell weight varies from 0.15 g to 100.5 g. In terms of age, the youngest abalone is 1 year, while the oldest is 29 years.
#
# &emsp;Regarding distribution, the histograms show that no variance of any variables follows normal distribution. This abnormal distribution can be affected by the data combination from one infant group, and two adult groups: males and females because infants are much smaller or younger than the grown-up. Besides, the histogram of height might be influenced by two error values (= 0) on the left. According the scale of Pearson correlation coefficients (Selvanathan et al., 2020), the number of rings has a strong positive relationship with only the shell weight (*r* = 0.63), while it has a moderate positive correlation with other features, with *r* values ranging from 0.42 to 0.57.

# %% [markdown]
# #### 2.3.2. Group-specific data analysis <a id="eda_3_2"></a>

# %% [markdown]
# **Descriptive statistics**

# %%
# Create an empty dataframe to contain min_max value for each type
df = pd.DataFrame(data = {})

# remove 3 columns that the total of them is the WholeWeight
remove_df = abalone_df.drop(['ShuckedWeight', 'VisceraWeight', 'ShellWeight'], axis = 1, inplace = False)

# Create columns for new dataframe
for col in remove_df.columns:
    if col != 'Type':
        df[f'{col}_min'] = [0]
        df[f'{col}_max'] = [0]
        df[f'{col}_mean'] = [0]
        df[f'{col}_std'] = [0]
        
# Loop each type (M, F, I)
for i, type in enumerate(list(remove_df['Type'].unique())):
    type_df = remove_df.loc[remove_df['Type'] == type] # get dataframe for each type
    array = np.array([]) # create an empty array to contain each min_max values
    for col in type_df.columns: # loop through each column in each type
        if col != 'Type':
            # Add to the array
            array = np.concatenate((array, np.array([np.min(type_df[col])])))
            array = np.concatenate((array, np.array([np.max(type_df[col])])))
            array = np.concatenate((array, np.array([np.mean(type_df[col])])))
            array = np.concatenate((array, np.array([np.std(type_df[col])])))
    df.loc[i] = None # fix FutureWarning
    df.loc[i] = array # set value for each type
    
df.index = list(abalone_df['Type'].unique()) # rename index from [0, 1, 2] to ['M', 'F', 'I']
df.T

# %% [markdown]
# &emsp;On average, female abalones are larger and have less variation in size compared to the other groups, with the shell length at 57.9 mm (*SD* = 8.6), the diameter at 45.5 mm (*SD* = 7.1), the height at 15.8 mm (*SD* = 3.9), and the weight at 104.6 g (*SD* = 43). Females' size can range from 27.5 mm to 81.5 mm in length, 19.5 mm to 65 mm in diameter, 1.5 mm to 113 mm in height, and 8 g to 265.7 g in weight. Followed closely by the figure for male, its average size is recoded at 56.1 mm in length (*SD* = 10.3), 43.9 mm (*SD* = 8.4) in diameter, 15.1 mm in height (*SD* = 3.5), and 99.1 g in weight (*SD* = 47). Infants was the smallest with a statistically significant difference compared to two other groups: 42.8 mm in mean length (*SD* = 10.9), 32.6 mm in mean diameter (*SD* = 8.8), 10.8 mm in height (*SD* = 3.2), and 43.1 g (*SD* = 28.6). It only can grow up from 7.2 mm to 42.8 mm in length, 5.5 mm to 55 mm in diameter, 1 mm to 22 mm in height, and 0.2 g to 204.9 g in weight. Finally, the ring count, which indicates age, shows that females (*M* = 11.13, *SD* = 3.103) and males (*M* = 10.7, *SD* = 3.02) are older on average than infants (*M* = 7.89, *SD* = 2.51). The range of ring counts is wider in adults, with females having a maximum of 29 rings, while infants have a maximum of 21 rings.

# %% [markdown]
# **Plot each pair of feature using seaborn:**

# %%
# An overview of the relationship between each pair feature
sns.set_theme() # set default theme for plot

# Plot features with each color for each type of abalone, including male (M), female (F) and infant (I)
sns.pairplot(data = abalone_df, hue = 'Type', corner = True, palette = 'Set2');

plt.savefig('Documents/Figures/pairplot.png') # save as a picture in Figures folder
plt.show() # show plot

# %% [markdown]
# &emsp;Histograms show that all variables follow nearly normal distributions across types, which could be attributed to some outliers on the left side. Meanwhile, scatter plots show a weak to moderate positive correlation between the ring number and each variable across types.

# %% [markdown]
# **The relationship between LongestShell and Rings using jointplot from seaborn** **:**

# %%
sns.jointplot(data = abalone_df, x = 'LongestShell', y = 'Rings', hue = 'Type');

plt.savefig('Documents/Figures/longestshell_rings.png') # Save as a picture in Figures folder
plt.show() # show plot

# %% [markdown]
# &emsp;The male and infant groups show a more consistent relationship between the longest shell length and the number of rings, compared to the female group.

# %% [markdown]
# **The relationship between Diameter and Rings using FacetGrid from seaborn:**

# %%
abalone_fg = sns.FacetGrid(data = abalone_df, col = 'Type')
abalone_fg.map(sns.scatterplot, 'Diameter', 'Rings', alpha = .4);

plt.savefig('Documents/Figures/diameter_rings.png') # Save as a picture in Figures folder
plt.show() # show plot

# %% [markdown]
# &emsp;The male and infant groups also indicate a stronger linear relationship between the diameter length and the ring number, compared to the female group.

# %% [markdown]
# **The relationship between Height and Rings using FaceGrid from seaborn:**

# %%
abalone_fg = sns.FacetGrid(data = abalone_df, col = 'Type')
abalone_fg.map(sns.scatterplot, 'Height', 'Rings', alpha = .4);

plt.savefig('Documents/Figures/height_rings.png') # Save as a picture in Figures folder
plt.show() # show plot

# %% [markdown]
# &emsp;All groups has a strong correlation between the height and the ring number, but some outliers in male and female groups need to be handled latter.

# %% [markdown]
# **The relationship between WholeWeight and Rings using jointplot from seaborn:**

# %%
sns.jointplot(data = abalone_df, x = 'WholeWeight', y = 'Rings', hue = 'Type');

plt.savefig('Documents/Figures/wholeweight_rings.png') # Save as a picture in Figures folder
plt.show() # show plot

# %% [markdown]
# &emsp; The correlation between the whole weight and the ring number is more stronger among both male and infant groups than female group.

# %% [markdown]
# ## 3. Data Preprocessing <a id="data_preprocessing"></a>

# %% [markdown]
# ### 3.1. Remove unused features <a id="data_preprocessing_1"></a>

# %%
abalone_df.drop(columns = ['ShuckedWeight', 'VisceraWeight', 'ShellWeight'], inplace = True)
# Uncomment to see the outcome
abalone_df

# %% [markdown]
# &emsp; As mentioned above, the distribution, and the correlation with the ring number are almost similar for the whole weight, the shucked weight, viscera weight, and shell weight, which might lead to unnecessary duplication when analysing data. The whole weight is measured when the intact abalone has not dried, so it consists of the shucked weight, the viscera weight, the shell weight, and the weight of retained water in the abalone. Therefore, to make it more concise, the whole weight will be retained while the others are removed.

# %% [markdown]
# ### 3.2. Identify and handle outliers <a id="data_preprocessing_2"></a>

# %% [markdown]
# &emsp;The Interquartile Range (IQR) is used to detect outliers in this research because of it is less likely to be affected by extreme outliers and a non-normal distribution (Faster Capital, 2024), both of which are present in this data. Because of the large sample size, these data errors and ouliers will be handled using listwise deletion.

# %%
total_rows = abalone_df.shape[0] # number of rows
new_total_rows = 0 # number of rows after filter

# Use Z-Score Threshold
while (new_total_rows != total_rows): # when equal => no more outlier values
    total_rows = abalone_df.shape[0] # get number of rows again
    for col in abalone_df.columns: # loop through each column
        if col != 'Type':
            q1, q3 = np.percentile(abalone_df[col], [25, 75]) # get Q1 adn Q3
            iqr = q3 - q1 # get IQR
            # Finding the lower and upper bound
            lower_bound = q1 - 1.5 * iqr
            upper_bound = q3 + 1.5 * iqr

            # Finding index that is outlier
            index_outliers = abalone_df.loc[(abalone_df[col] > upper_bound) | (abalone_df[col] < lower_bound) | (abalone_df[col] == 0)].index

            # Drop that row
            abalone_df.drop(index_outliers, inplace = True) # inplace = True => renew data
            
    new_total_rows = abalone_df.shape[0] # get new number of rows after dropping
    # print(total_rows, new_total_rows, '\n')

# %% [markdown]
# ### 3.3. Split the data <a id="data_preprocessing_3"></a>

# %% [markdown]
# &emsp;The dataset is divided into a training set (80% of the data) and a testing set (20% of the data). The training data is used to build and select the model, while the testing set is used for the evaluation of the chosen model's effectiveness.

# %%
from sklearn.model_selection import train_test_split

# Split the raw data: abalone_train (80%) for training and abalone_test (20%) for testing with the percentage
abalone_train, abalone_test = train_test_split(abalone_df, test_size = 0.2, random_state = 25)

# Uncomment to se the outcome
abalone_train.shape, abalone_test.shape

# %% [markdown]
# ### 3.4. Separate labels from data <a id="data_preprocessing_4"></a>
# &emsp;"Rings" variable is chosen as the label.

# %%
# Train set
train_set_labels = abalone_train['Rings'].copy()
train_set = abalone_train.drop(columns = 'Rings', inplace = False)

# Test set
test_set_labels = abalone_test['Rings'].copy()
test_set = abalone_test.drop(columns = 'Rings', inplace = False)

# %% [markdown]
# ### 3.5. Handle missing values <a id="data_preprocessing_5"></a>

# %% [markdown]
# &emsp;All missing values will be handled using median imputation to remain the sample size. However, there is no missing value in this dataset.

# %%
from sklearn.impute import SimpleImputer

# Handle missing values in train_set and test_set
for i, set in enumerate([train_set, test_set]):
    # if i == 0:
    #     print('____________ Training set ____________')
    # else:
    #     print('____________ Testing set ____________')

    # Loop through each column
    for col in set.columns:
        missing_values = set[col].isna().sum() # count number of missing values existed in a column
        if missing_values > 0:
            if col != 'Type': # find the nan values and replace by median number for numerical features
                imp_median = SimpleImputer(missing_values = np.nan, strategy = 'median')
                set[col] = imp_median.fit_transform(set[col].values.reshape(-1, 1))[:, 0]
            else: # find the nan values and replace by 'Unknown' string for categorical feature
                imp_type = SimpleImputer(missing_values = np.nan, strategy = 'constant', fill_value = 'Unknown')
                set[col] = imp_type.fit_transform(set[col].values.reshape(-1, 1))[:, 0]
            
    #     print(f'Feature {col} has {missing_values / len(set) * 100}% missing values')
    # print('')

# Handle missing value in labels
for i, label in enumerate([train_set_labels, test_set_labels]):
    # This is for printing
    # if i == 0:
    #     set = 'training set'
    # else:
    #     set = 'testing set'

    missing_values = label.isna().sum()
    if missing_values > 0:
        imp_median = SimpleImputer(missing_values = np.nan, strategy = 'median')
        label = imp_median.fit_transform(label.values.reshape(-1, 1))[:, 0]
    # print(f'Label Rings in {set} has {missing_values / len(label) * 100}% missing values')

# %% [markdown]
# ### 3.6. Encode categorical features <a id="data_preprocessing_6"></a>
# &emsp;There is one categorical feature in the dataset need to be encoded: Type, using one hot coding technique. As it helps avoid giving certain categories more importance just because they have higher numbers.

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder

# Create a class for encode columns
colTrans = ColumnTransformer(transformers = [('encode', OneHotEncoder(), [0])], remainder = 'passthrough')

# Encode
train_set = colTrans.fit_transform(train_set)
test_set = colTrans.transform(test_set)

# Uncomment to see the result
# train_set[0]
# test_set[0]

# %%
# Transform label column sets into the same format (array) with the above sets
train_set_labels = train_set_labels.values
test_set_labels = test_set_labels.values

# %% [markdown]
# ### 3.7. Scale numerical features <a id="data_preprocessing_7"></a>
# Scale features to zero mean and unit variance.

# %%
from sklearn.preprocessing import StandardScaler

# Create a class for scaling features
std_scaler = StandardScaler()

# Just only scale numerical features in training and testing set, not category feature
train_set[:, 3:] = std_scaler.fit_transform(train_set[:, 3:])
test_set[:, 3:] = std_scaler.transform(test_set[:, 3:])

# %% [markdown]
# ## 4. Model Training and Evaluation <a id="train_evaluate"></a>
# &emsp;Model training and evaluation is an essential process required to construct the best mathematical model to capture the relationship (supervised or unsupervised) between the data and a target. In other words, a high level of performance allows the model to be able to provide a more accurate estimation of the abalones’ age. There are a total of 6 models utilised within this report. Each model has its pros and cons, therefore, an evaluation metric, called K-fold cross-validation will later be used to compare the models and determine the one with the best performance.
#
# **Note:**
# + `train_set` contains set data for training
# + `train_set_labels` contains labels for training
# + `test_set` contains set data for testing
# + `test_set_labels` contains labels for testing
#
# **Used Models in lecture End-to-end Machine Learning:**
# + LinearRegression
# + DecisionTreeRegressor
# + RandomForestRegressor
# + PolynomialFeatures

# %% [markdown]
# ### 4.1. Define support functions <a id="train_evaluate_1"></a>

# %% [markdown]
# #### 4.1.1. R-squared (R2) and root mean squared error (RMSE) function <a id="train_evaluate_1_1"></a>
# &emsp;To further determine the extent to which a model can use the number of rings that abalone has to predict its age, two metrics are used in this report to understand how well the models fit the dataset, namely R-squared (R2) and root mean squared error (RMSE). The first mentioned metric, R2 provides an understanding of the proportion of variance in the response variable by using predictor variables (ranges between 0 and 1). Thus, a higher R2 value indicates that the model is a good fit for the dataset. On the other hand, the second metric, RMSE depicts how far the predicted values are from the observed values in the dataset on average. Therefore, a lower RMSE score indicates that the model fits the dataset better. However, R2 cannot indicate how large the errors are, while RMSE cannot show the variation that the model accounts for. Therefore, to gain a more accurate evaluation of the models, we’ll be using both metrics since each compromises the other’s weakness.

# %%
from sklearn.metrics import mean_squared_error

# The function based on lecture
def r2score_and_rmse(model, train_data, labels): 
    r2score = model.score(train_data, labels)
    prediction = model.predict(train_data)
    mse = mean_squared_error(labels, prediction)
    rmse = np.sqrt(mse)
    return r2score, rmse

# %% [markdown]
# #### 4.1.2. Functions to store and load models <a id="train_evaluate_1_2"></a>
# Parameters:
# + `action`: to distinguish between models training and models evaluation
# + `model`: model
# + `model_name`: name of model

# %%
import joblib

# These functions based on lecture
def store_model(action, model, model_name = ''):
    # NOTE: sklearn.joblib faster than pickle of Python
    # INFO: can store only ONE object in a file
    if model_name == '': 
        model_name = model.__class__.__name__
    joblib.dump(model,f'Documents/Models/{model_name}_model_{action}.pkl')

def load_model(action, model_name):
    # Load objects into memory
    #del model
    model = joblib.load(f'Documents/Models/{model_name}_model_{action}.pkl')
    #print(model)
    return model

# %% [markdown]
# ### 4.2. Training models <a id="train_evaluate_2"></a>

# %% [markdown]
# #### 4.2.1. LinearRegression model <a id="train_evaluate_2_1"></a>

# %%
from sklearn.linear_model import LinearRegression

# Create an empty model
model = LinearRegression()
model_name = model.__class__.__name__

# Call function to training model
model.fit(train_set, train_set_labels)
print(f'\n____________ {model_name} ____________')

# Compute R2 score and root mean squared error
r2score, rmse = r2score_and_rmse(model, train_set, train_set_labels)
print(f'\nR2 score (on training data, best = 1): {r2score}')
print(f'Root Mean Square Error: {rmse.round(decimals = 1)}')
        
# Predict labels for some training instances (9 first samples)
print('\nPredictions: ', model.predict(train_set[0:9]).round(decimals = 1))
print('Labels:      ', list(train_set_labels[0:9]))

# Store model
store_model('training', model)

# %% [markdown]
# #### 4.2.2. DecisionTreeRegressor model <a id="train_evaluate_2_2"></a>

# %%
from sklearn.tree import DecisionTreeRegressor

# Create an empty model
model = DecisionTreeRegressor()
model_name = model.__class__.__name__

# Training model
model.fit(train_set, train_set_labels)

# Compute R2 score and root mean squared error
r2score, rmse = r2score_and_rmse(model, train_set, train_set_labels)

print('\n____________ DecisionTreeRegressor ____________')
print(f'\nR2 score (on training data, best = 1): {r2score}')
print(f'Root Mean Square Error: {rmse.round(decimals = 1)}')

# Predict labels for some training instances (the first 9 samples)
print('\nPredictions: ', model.predict(train_set[0:9]).round(decimals = 1))
print('Labels:      ', list(train_set_labels[0:9]))

# Store model
store_model('training', model)

# %% [markdown]
# #### 4.2.3. RandomForestRegressor model <a id="train_evaluate_2_3"></a>

# %%
from sklearn.ensemble import RandomForestRegressor

# Create an empty model
model = RandomForestRegressor()
model_name = model.__class__.__name__

# Training model
model.fit(train_set, train_set_labels)

# Compute R2 and RMSE
r2score, rmse = r2score_and_rmse(model, train_set, train_set_labels)

print('\n____________ RandomForestRegressor ____________')
print(f'\nR2 score (on training data, best = 1): {r2score}')
print(f'Root Mean Square Error: {rmse.round(decimals = 1)}')

# Predict the first 9 samples
print('\nPredictions: ', model.predict(train_set[0:9]).round(decimals = 1))
print('Labels:      ', list(train_set_labels[0:9]))

# Store model
store_model('training', model)

# %% [markdown]
# #### 4.2.4. ElasticNet model <a id="train_evaluate_2_4"></a>

# %%
from sklearn.linear_model import ElasticNet

# Create Elastic net model
model = ElasticNet()
model_name = model.__class__.__name__

# Train the model 
model.fit(train_set, train_set_labels)

# Compute R2 and RMSE
r2score, rmse = r2score_and_rmse(model, train_set, train_set_labels)

print('\n____________ ElasticNet ____________')
print(f'\nR2 score (on training data, best = 1): {r2score}')
print(f'Root Mean Square Error: {rmse.round(decimals = 1)}')

# Predict the first 9 samples
print('\nPredictions: ', model.predict(train_set[0:9]).round(decimals = 1))
print('Labels:      ', list(train_set_labels[0:9]))

# Store model
store_model('training', model)

# %% [markdown]
# #### 4.2.5. Gradient Boosting Regressor <a id="train_evaluate_2_5"></a>
# `n_estimators` : the number of boosting stages that will be performed. Later, we will plot deviance against boosting iterations.
#
# `max_depth` : limits the number of nodes in the tree. The best value depends on the interaction of the input variables.
#
# `min_samples_split` : the minimum number of samples required to split an internal node.
#
# `learning_rate` : how much the contribution of each tree will shrink.
#
# `loss` : loss function to optimize. The least squares function is used in this case however, there are many other options

# %%
from sklearn.ensemble import GradientBoostingRegressor

# Create the model
params = {
    "n_estimators": 500,
    "max_depth": 4,
    "min_samples_split": 5,
    "learning_rate": 0.01,
    "loss": "squared_error",
}
model = GradientBoostingRegressor(**params)
model_name = model.__class__.__name__

# Train the model
model.fit(train_set, train_set_labels)

# Compute R2 and RMSE
r2score, rmse = r2score_and_rmse(model, train_set, train_set_labels)

print('\n____________ GradientBoostingRegressor ____________')
print(f'\nR2 score (on training data, best = 1): {r2score}')
print(f'Root Mean Square Error: {rmse.round(decimals = 1)}')

# Predict the first 9 samples
print('\nPredictions: ', model.predict(train_set[0:9]).round(decimals = 1))
print('Labels:      ', list(train_set_labels[0:9]))

# Store model
store_model('training', model)

# %% [markdown]
# #### 4.2.6. Lasso model <a id="train_evaluate_2_6"></a>

# %%
from sklearn.linear_model import Lasso

# Create the model
model = Lasso(alpha=0.1)
model_name = model.__class__.__name__

# Train the model
model.fit(train_set, train_set_labels)

# Compute R2 and RMSE
r2score, rmse = r2score_and_rmse(model, train_set, train_set_labels)

print(f'\n____________ {model_name} ____________')
print(f'\nR2 score (on training data, best = 1): {r2score}')
print(f'Root Mean Square Error: {rmse.round(decimals = 1)}')

# Predict the first 9 samples
print('\nPredictions: ', model.predict(train_set[0:9]).round(decimals = 1))
print('Labels:      ', list(train_set_labels[0:9]))

# Store model
store_model('training', model)

# %% [markdown]
# ### 4.3. Evaluate with K-fold cross validation <a id="train_evaluate_3"></a>
# &emsp;Two evaluation methods, namely Stratified, and K-fold cross-validation, were considered during the process of selecting a suitable model evaluator. The main difference between these two methods is the way that the data is divided into training and validation sets. For instance, K-fold cross-validation divides the data into k parts whereas, in Stratified cross-validation, each fold of the dataset has the same proportion of observations with a given label. At the final stage, our group decided on the K-fold cross-validation method since it can carry out more tests and therefore reduce the number of biased results significantly (due to the dataset).

# %%
from statistics import mean
from sklearn.model_selection import cross_val_score, KFold

cv = KFold(n_splits = 5, shuffle = True, random_state = 25)

# Evaluate LinearRegression
model = LinearRegression()
model_name = model.__class__.__name__

nmse_scores = cross_val_score(model, train_set, train_set_labels, cv = cv, scoring = 'neg_mean_squared_error')
rmse_scores = np.sqrt(-nmse_scores)
store_model('evaluation', rmse_scores, model_name)
print(f'{model_name} rmse: {rmse_scores.round(decimals = 1)}')
print(f'Avg. rmse: {mean(rmse_scores.round(decimals = 5))}\n')


# Evaluate DecisionTreeRegressor
model = DecisionTreeRegressor()
model_name = model.__class__.__name__

nmse_scores = cross_val_score(model, train_set, train_set_labels, cv = cv, scoring = 'neg_mean_squared_error')
rmse_scores = np.sqrt(-nmse_scores)
store_model('evaluation', rmse_scores, model_name)
print(f'{model_name} rmse: {rmse_scores.round(decimals = 1)}')
print(f'Avg. rmse: {mean(rmse_scores.round(decimals = 5))}\n')


# Evaluate RandomForestRegressor
model = RandomForestRegressor()
model_name = model.__class__.__name__

nmse_scores = cross_val_score(model, train_set, train_set_labels, cv = cv, scoring = 'neg_mean_squared_error')
rmse_scores = np.sqrt(-nmse_scores)
store_model('evaluation', rmse_scores, model_name)
print(f'{model_name} rmse: {rmse_scores.round(decimals = 1)}')
print(f'Avg. rmse: {mean(rmse_scores.round(decimals = 5))}\n')


# Evaluate ElasticNet model
model = ElasticNet()
model_name = model.__class__.__name__

nmse_scores = cross_val_score(model, train_set, train_set_labels, cv = cv, scoring = 'neg_mean_squared_error')
rmse_scores = np.sqrt(-nmse_scores)
store_model('evaluation', rmse_scores, model_name)
print(f'{model_name} rmse: {rmse_scores.round(decimals = 1)}')
print(f'Avg. rmse: {mean(rmse_scores.round(decimals = 5))}\n')


# Evaluate GradientBoostingRegressor
params = {
    "n_estimators": 500,
    "max_depth": 4,
    "min_samples_split": 5,
    "learning_rate": 0.01,
    "loss": "squared_error",
}
model = GradientBoostingRegressor(**params)
model_name = model.__class__.__name__

nmse_scores = cross_val_score(model, train_set, train_set_labels, cv = cv, scoring = 'neg_mean_squared_error')
rmse_scores = np.sqrt(-nmse_scores)
store_model('evaluation', rmse_scores, model_name)
print(f'{model_name} rmse: {rmse_scores.round(decimals = 1)}')
print(f'Avg. rmse: {mean(rmse_scores.round(decimals = 5))}\n')


# Evaluate Lasso model
model = Lasso(alpha = .1)
model_name = model.__class__.__name__

nmse_scores = cross_val_score(model, train_set, train_set_labels, cv = cv, scoring = 'neg_mean_squared_error')
rmse_scores = np.sqrt(-nmse_scores)
store_model('evaluation', rmse_scores, model_name)
print(f'{model_name} rmse: {rmse_scores.round(decimals = 1)}')
print(f'Avg. rmse: {mean(rmse_scores.round(decimals = 5))}\n')

# %% [markdown]
# &emsp;After performing the cross-validation evaluation for all 6 models, we have obtained the RMSE scores of each model, which will be further used to compare and find the most effective model. As mentioned earlier, a lower RMSE score indicates a better performance for models since they depict smaller prediction errors.  From the data collected, we have observed that Gradient Boosting Regressor has the lowest average RMSE score, at around 1.760, making it the most effective model in this case. Meanwhile, Linear Regression is also a good option considering as its RMSE score is relatively close to the previously mentioned, at about 1.774; the model is worth considering since it has a higher level of simplicity compared to Gradient Boosting Regressor. On the other hand, there was a negative trend recorded in Decision Tree Regressor, since it reaches the highest RMSE score, at 2.475. This indicates that the model has a poor performance on the dataset, which can be explained due to overfitting issue. To be more specific, it was recorded that Decision Tree Regressor has a perfect R2 score of 1.0, which indicates a condition called overfitting. This is when the model starts to explain the random error in the data rather than the correlations between variables. Therefore, Gradient Boosting Regressor is considered an overall best-performing model based on its RMSE score whilst Decision Tree Regressor is considered the least suitable option due to its higher prediction errors.

# %% [markdown]
# ## 5. Hyperparameter Fine-tuning <a id="hyperparameter"></a>
#
# &emsp;The `GradientBoostingRegresorr` is chosen because its Avg. rmse is the lowest. We will try to make the model more accurate by reducing the RMSE score by tuning the parameters. In this research, the hyperparameter space is large and the optimal hyperparameters are not highly correlated. This is reasonable to use randomized search (Kumar, 2023).

# %% [markdown]
# ### 5.1. Define support Functions <a id="hyperparameter_1"></a>
# Function to print the output for fine-tune.

# %%
# The function based on lecture
def print_search_result(search, model_name = ""): 
    print("\n====== Fine-tune " + model_name +" ======")
    print('Best hyperparameter combination: ',search.best_params_)
    print('Best rmse: ', np.sqrt(-search.best_score_))  
    #print('Best estimator: ', grid_search.best_estimator_) # NOTE: require refit=True in  SearchCV
    # print('Performance of hyperparameter combinations:')
    # cv_results = search.cv_results_
    # for (mean_score, params) in zip(cv_results["mean_test_score"], cv_results["params"]):
    #     print('rmse =', np.sqrt(-mean_score), params)

# %% [markdown]
# ### 5.2. Choose the method for searching  <a id="hyperparameter_2"></a>

# %%
# 1 for grid search, 2 for randomized search
method = 2

# %% [markdown]
# ### 5.3. Grid search <a id="hyperparameter_3"></a>

# %%
if method == 1:
    from sklearn.model_selection import GridSearchCV
    cv = KFold(n_splits=3,shuffle=True,random_state=25) # cv data generator
        
    run_new_search = 0  # Set to 1 to run new search
    if run_new_search:        
        
        # 5.1.1 Fine-tune GradientBoostingRegressor, since it is the best model
        model = GradientBoostingRegressor()
        model_name = model.__class__.__name__
        param_grid = {
            # try combinations of parameters

            'n_estimators': [50, 100, 150],  # numbers of trees built
            # higher the more trees builts, improve performace but may lead to overfitting

            'learning_rate': [0.01, 0.05, 0.1],  # Shrinkage of the contribution of trees
            # how much a tree can contribute, lower mean each tree contribute less, but make the model more accurate, for the cost of learning time

            'max_depth': [1, 3, 5],  # max depth of each tree
            # max depth for each tree, can capture more complex pattern, but can lead to overfitting
            
            'min_samples_split': [2, 5, 10],   # min numbers of samples required to split an internal node
            # Higher value prevent spliting nodes, prevent overfitting

            'min_samples_leaf': [1, 2, 4], # min numbers of samples to be at a leaf node
            # Ensure each leaf has enough sample, preventing leaves with too few samples

            'subsample': [0.6, 0.7, 1.0], # split sample for fitting into tree
            # less mean more trees, improbing generalization, but requires more trees.
            'max_features': [0.2, 0.5, 0.7]  # numbers of features to consider when looking for the best split
            # Add randomness in the tree building process. Ex: 0.2 of total features, 1 is all features
            }
            # Train cross 5 folds, hence a total of (37500)*5=187500 rounds of training 
        grid_search = GridSearchCV(model, param_grid, cv=cv, scoring='neg_mean_squared_error', n_jobs=8, verbose=10, 
                                   refit=True) # refit=True: after finding best hyperparam, it fit() the model with whole data (hope to get better result)
        
        # Start fitting to find best model
        grid_search.fit(train_set, train_set_labels)
        store_model('grid_search', grid_search, model_name)
        print_search_result(grid_search, model_name)
    else: # If don't run new search
        fitted_models = load_model('grid_search', 'GradientBoostingRegressor')
        print(fitted_models.best_estimator_)

# %% [markdown]
# ### 5.4. Randomized search  <a id="hyperparameter_4"></a>

# %%
if method == 2:
    from sklearn.model_selection import RandomizedSearchCV
    from scipy.stats import randint, uniform  # To make continuous range of numbers for randomized search
    cv = KFold(n_splits=5,shuffle=True,random_state=25) # cv data generator
        
    run_new_search = 1 # Set to 1 to run new search
    if run_new_search:        
        
        # 5.1.1 Fine-tune GradientBoostingRegressor, since it is the best model
        model = GradientBoostingRegressor()
        model_name = model.__class__.__name__
        param_distributions = {
            # try random combinations of range of parameters

            'n_estimators': randint(50, 500),  # numbers of trees built
            # higher the more trees builts, improve performace but may lead to overfitting

            'learning_rate': uniform(0.01, 0.19),  # Shrinkage of the contribution of trees
            # how much a tree can contribute, lower mean each tree contribute less, but make the model more accurate, for the cost of learning time

            'max_depth': randint(1, 10),  # max depth of each tree
            # max depth for each tree, can capture more complex pattern, but can lead to overfitting
            
            'min_samples_split': randint(2, 20),   # min numbers of samples required to split an internal node
            # Higher value prevent spliting nodes, prevent overfitting

            'min_samples_leaf': randint(1, 10), # min numbers of samples to be at a leaf node
            # Ensure each leaf has enough sample, preventing leaves with too few samples

            'subsample': uniform(0.3, 0.7), # split sample for fitting into tree
            # less mean more trees, improbing generalization, but requires more trees.
            'max_features': ['sqrt', 'log2']  # numbers of features to consider when looking for the best split
            # Add randomness in the tree building process. Ex: 0.2 of total features, 1 is all features
            }
            # Train cross 5 folds, hence a total of (37500)*5=187500 rounds of training 
        grid_search = RandomizedSearchCV(model, param_distributions, n_iter=500, cv=cv, scoring='neg_mean_squared_error', random_state=25,
                                    n_jobs=8, verbose=10, return_train_score=True, refit=True) 
        # refit=True: after finding best hyperparam, it fit() the model with whole data (hope to get better result)
        
        # Start fitting to find best model
        grid_search.fit(train_set, train_set_labels)
        store_model('randomized_search', grid_search, model_name)
        print_search_result(grid_search, model_name)
    else: 
        fitted_models = load_model('randomized_search', 'GradientBoostingRegressor')
        print(fitted_models.best_estimator_)

# %% [markdown]
# &emsp;This is a combination of hyperparameters that yields the best performance with the RMSE score of 1.75, which remains almost the same compared to the previous outcome on K-fold cross-validation (RMSE = 1.76). This consistency indicates that the model is robus and unlikely to be overfitting, determining it can generalize well in real environment.

# %% [markdown]
# ## 6. Model Testing and Analysis <a id="test_anal"></a>

# %% [markdown]
# ### 6.1. Model testing and evaluation <a id="test_anal_1"></a>

# %%
# Get the best model from the previous step
fitted_models = load_model('randomized_search', 'GradientBoostingRegressor')
best_model = fitted_models.best_estimator_

# Store that model
store_model('best_model', best_model, 'GradientBoostingRegressor')

# Run model with test set
r2score, rmse = r2score_and_rmse(best_model, test_set, test_set_labels)
print('\nPerformance on test data:')
print(f'R2 score (on test data, best = 1): {r2score}')
print(f'Root Mean Square Error: {rmse.round(decimals = 1)}')

# Predict labels for some test instances
print("\nTest data: \n", abalone_test.iloc[0:9])
print("\nPredictions: ", best_model.predict(test_set[0:9]).round(decimals = 1))
print("Labels:      ", list(test_set_labels[0:9]),'\n')

# %% [markdown]
# &emsp;The final result of the Gradient Boosting Regressor model shows the RMSE score at 1.7, which is slightly lower than the training outcome (RMSE = 1.75). This indicates that the model can work well and consistently in the real scenarios.

# %% [markdown]
# ### 6.2. Limitations and Implication <a id="test_anal_2"></a>
#
# &emsp;The dataset has some limitations that may affect the research outcome. First, the data was collected 30 years ago, and the environment has changed significantly. Using outdated data might not accurately reflect the current characteristics of abalone. Secondly, there are over 100 species of abalone, and different kinds have different physical characteristics (Candy Abalone, 2021). This data only includes 4177 instances without distinguishing between different abalone species, which may lead to inaccuracies when applied to other species. Besides, although the Gradient Boosting Regressor model is chosen to be the optimal model in this research, it takes quite a long time to run completely. This leads to reduction in productivity in real-world scenarios. This research proposes a new model to predict the age of abalone based on its physical characteristics. Further research can collect more up-to-date data and classify abalone species to reach a better conclusion. The running speed of the Gradient Boosting Regressor model can be improved when using only the most relevant features to reduce the complexity of the model in more research in the future.

# %% [markdown]
# ## 7. References <a id="ref"></a>

# %% [markdown]
# Akanda, A. B. R., Hassan, R., & Billah, M. M. (2023). Exploratory data analysis (EDA) on abalone’s age data and prediction of its age using machine learning with Python. In Research Gate. https://doi.org/10.13140/RG.2.2.25876.48006 \
# Candy Abalone. (2021). Australian abalone. https://www.candyabalone.com/australian-abalone/#:~:text=Retailed%20live%20abalone%20is%20usually \
# Cook, P. A. (2023). Worldwide abalone production: an update. New Zealand Journal of Marine and Freshwater Research, 1–7. https://doi.org/10.1080/00288330.2023.2261869
# Faster Capital. (2024). Z score: Z scores and IQR: Standardizing the outliers. https://fastercapital.com/content/Z-score--Z-scores-and-IQR--Standardizing-the-Outliers.html#Introduction-to-Z-scores-and-IQR \
# Kumar, B. (2023). Comparison GridSearchCV and RandomSearchCV. 360 Digi TMG. https://360digitmg.com/blog/comparison-gridsearchcv-and-randomsearchcv#:~:text=Random%20search%20is%20generally%20more \
# Matplotlib. (n.d.). Matplotlib: Visualization with Python. Matplotlib. https://matplotlib.org \
# Nash, W. J., Sellers, T. L., Talbot, S. R., Cawthorn, A. J., & Ford , W. B. (1994). The population biology of abalone (Haliotis species) in Tasmania. I. blacklip abalone (H. rubra) from the North Coast and the islands of Bass Strait (Technical Report No. 48). Sea Fisheries Division. https://www.researchgate.net/profile/Warwick-Nash/publication/ 287546509_7he_Population_Biology_of_Abalone_Haliotis_species_in_Tasmania_I_Blacklip_Abalone_H_rubra_from_the_North_Coast_and_Islands_of_Bass_Strait/links/5d949460458515202b7bf592/7he-Population-Biology-of-Abalone-Haliotis-species-in-Tasmania-I-Blacklip-Abalone-H-rubra-from-the-North-Coast-and-Islands-of-Bass-Strait.pdf  \
# Nash, W., Sellers, T., Talbot, S., Cawthorn, A., & Ford, W. (1995). Abalone. UCI Machine Learning. https://doi.org/10.24432/C55C7W \
# pandas. (2024). Python Data Analysis Library — pandas: Python Data Analysis Library. Pydata. https://pandas.pydata.org \
# Selvanathan, M., Jayabalan, N., Saini, G. K., Supramaniam, M., & Hussin, N. (2020). Employee productivity in Malaysian private higher educational institutions. PalArch’s Journal of Archaeology of Egypt / Egyptology, 17(3), 66–79. https://doi.org/10.48080/jae.v17i3.50 \
# Suleria, H. A. R., Masci, P. P., Gobe, G. C., & Osborne, S. A. (2017). Therapeutic potential of abalone and status of bioactive molecules: A comprehensive review. Critical Reviews in Food Science and Nutrition, 57(8), 1742–1748. https://doi.org/10.1080/10408398.2015.1031726 \
# Waskom, M. (n.d.). seaborn: statistical data visualization. Seaborn; Pydata. https://seaborn.pydata.org \
# YData Profiling. (n.d.). YData Profiling. https://docs.profiling.ydata.ai/latest/ \

# %% [markdown]
# ## 8. Contribution <a id="contribution"></a>
# |Student ID|Student Name|Contribution Rate <br> (1-100%)|Responsible for <br> (Parts, Cells...)|Note|
# |------|------|------|------|------|
# |s3983370|Le Kim Quyen|20%|Finding dataset<br>Loading and Visualization dataset<br>Preprocessing data<br>Training models<br>Testing models|Focusing on code and Discussing|
# |s4070286|Ton Dat Toan|20%|Finding dataset<br>Visualize and analysis dataset<br>Preprocessing data<br>Training and Evaluation models<br>Testing models|Focusing on analysis and Discussing|
# |s3979100|Nguyen Hong Ha|20%|Finding dataset<br>Data overview<br>Visualize and analysis dataset<br>Preprocessing data<br>Testing models|Focusing on analysis and Discussing|
# |s4045607|Huynh Bao Khoa Dang|20%|Finding dataset<br>Preprocessing data<br>Training and Evaluation models<br>Fine-tuning<br>Testing models|Focusing on code and Discussing|
# |s4103086|Nguyen Viet Ngan Anh|20%|Finding dataset<br>Visualize and analysis dataset<br>Preprocessing data<br>Evaluation models<br>Testing models|Focusing on analysis and Discussing|
