# %%
# !python run_pipeline.py

# %%
# !streamlit run app.py

# %%
import pandas as pd
import os
import sys

# Force UTF-8 to avoid emoji issues
try:
    sys.stdout.reconfigure(encoding='utf-8')
except:
    pass

# Import pipeline
sys.path.append(os.path.abspath("./"))
from pipeline.runner import run_pipeline

# -----------------------------
# STEP 1 — Ask user for file path
# -----------------------------
print("Enter the FULL PATH to your CSV file:")
print("Example: C:/Users/keshu/Desktop/mydata.csv\n")

csv_path = input("CSV Path: ").strip()

while not os.path.exists(csv_path):
    print("❌ File not found. Try again.")
    csv_path = input("CSV Path: ").strip()

print(f"\n📁 File selected: {csv_path}")

# Load preview
df = pd.read_csv(csv_path, on_bad_lines='skip', low_memory=False)
print("\n===== PREVIEW =====")
display(df.head())

columns = list(df.columns)
print("\nDetected columns:", columns)

# -----------------------------
# STEP 2 — Ask targets
# -----------------------------
primary_target = input("\nEnter PRIMARY target column: ").strip()
while primary_target not in columns:
    primary_target = input("Invalid. Enter PRIMARY column again: ").strip()

secondary_raw = input("\nEnter up to 2 SECONDARY columns (comma separated): ").strip()
secondary_targets = [s.strip() for s in secondary_raw.split(",") if s.strip()][:2]

for s in secondary_targets:
    if s not in columns:
        raise ValueError(f"Invalid secondary target: {s}")

if primary_target in secondary_targets:
    raise ValueError("Primary cannot also be secondary.")

task_type = input("\nEnter task type (classification / regression): ").strip().lower()
while task_type not in ["classification", "regression"]:
    task_type = input("Invalid. Enter classification or regression: ").strip().lower()

# -----------------------------
# STEP 3 — Run pipeline
# -----------------------------
print("\n\n==============================")
print("🚀 Running Full Pipeline")
print("==============================\n")

run_pipeline(
    csv_path,
    primary_target=primary_target,
    secondary_targets=secondary_targets,
    task_type=task_type
)

print("\n🎉 DONE — Check your results/ folder!")
# Out:
# Enter the FULL PATH to your CSV file:
# Example: C:/Users/keshu/Desktop/mydata.csv
# CSV Path:  C:\Users\keshu\CSET 346\Project\NLP\Implement\data\csv\student_depression_dataset.csv
# 📁 File selected: C:\Users\keshu\CSET 346\Project\NLP\Implement\data\csv\student_depression_dataset.csv
#
# ===== PREVIEW =====
#    id  Gender   Age           City Profession  Academic Pressure  \
# 0   2    Male  33.0  Visakhapatnam    Student                5.0
# 1   8  Female  24.0      Bangalore    Student                2.0
# 2  26    Male  31.0       Srinagar    Student                3.0
# 3  30  Female  28.0       Varanasi    Student                3.0
# 4  32  Female  25.0         Jaipur    Student                4.0
#
#    Work Pressure  CGPA  Study Satisfaction  Job Satisfaction  \
# 0            0.0  8.97                 2.0               0.0
# 1            0.0  5.90                 5.0               0.0
# 2            0.0  7.03                 5.0               0.0
# 3            0.0  5.59                 2.0               0.0
# 4            0.0  8.13                 3.0               0.0
#
#         Sleep Duration Dietary Habits   Degree  \
# 0          '5-6 hours'        Healthy  B.Pharm
# 1          '5-6 hours'       Moderate      BSc
# 2  'Less than 5 hours'        Healthy       BA
# 3          '7-8 hours'       Moderate      BCA
# 4          '5-6 hours'       Moderate   M.Tech
#
#   Have you ever had suicidal thoughts ?  Work/Study Hours Financial Stress  \
# 0                                   Yes               3.0              1.0
# 1                                    No               3.0              2.0
# 2                                    No               9.0              1.0
# 3                                   Yes               4.0              5.0
# 4                                   Yes               1.0              1.0
#
#   Family History of Mental Illness  Depression
# 0                               No           1
# 1                              Yes           0
# 2                              Yes           0
# 3                              Yes           1
# 4                               No           0
# Detected columns: ['id', 'Gender', 'Age', 'City', 'Profession', 'Academic Pressure', 'Work Pressure', 'CGPA', 'Study Satisfaction', 'Job Satisfaction', 'Sleep Duration', 'Dietary Habits', 'Degree', 'Have you ever had suicidal thoughts ?', 'Work/Study Hours', 'Financial Stress', 'Family History of Mental Illness', 'Depression']
# Enter PRIMARY target column:  Depression
#
# Enter up to 2 SECONDARY columns (comma separated):  CGPA
#
# Enter task type (classification / regression):  classification
# ==============================
# 🚀 Running Full Pipeline
# ==============================
#
#
# ===== STEP 1: Ingest & Profile =====
# 📄 Loaded 27901 rows, 18 columns
#   0%|                                                                                           | 0/18 [00:00<?, ?it/s]C:\Users\keshu\CSET 346\Project\NLP\Implement\pipeline\ingest_and_profile.py:40: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   dt_parsed = pd.to_datetime(non_null.sample(min(sample_size,len(non_null))), errors="coerce")
#  17%|█████████████▊                                                                     | 3/18 [00:00<00:00, 26.50it/s]C:\Users\keshu\CSET 346\Project\NLP\Implement\pipeline\ingest_and_profile.py:40: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   dt_parsed = pd.to_datetime(non_null.sample(min(sample_size,len(non_null))), errors="coerce")
#  44%|████████████████████████████████████▉                                              | 8/18 [00:00<00:00, 35.09it/s]C:\Users\keshu\CSET 346\Project\NLP\Implement\pipeline\ingest_and_profile.py:40: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   dt_parsed = pd.to_datetime(non_null.sample(min(sample_size,len(non_null))), errors="coerce")
# C:\Users\keshu\CSET 346\Project\NLP\Implement\pipeline\ingest_and_profile.py:40: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   dt_parsed = pd.to_datetime(non_null.sample(min(sample_size,len(non_null))), errors="coerce")
# C:\Users\keshu\CSET 346\Project\NLP\Implement\pipeline\ingest_and_profile.py:40: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   dt_parsed = pd.to_datetime(non_null.sample(min(sample_size,len(non_null))), errors="coerce")
#  72%|███████████████████████████████████████████████████████████▏                      | 13/18 [00:00<00:00, 36.66it/s]C:\Users\keshu\CSET 346\Project\NLP\Implement\pipeline\ingest_and_profile.py:40: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   dt_parsed = pd.to_datetime(non_null.sample(min(sample_size,len(non_null))), errors="coerce")
# C:\Users\keshu\CSET 346\Project\NLP\Implement\pipeline\ingest_and_profile.py:40: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   dt_parsed = pd.to_datetime(non_null.sample(min(sample_size,len(non_null))), errors="coerce")
# C:\Users\keshu\CSET 346\Project\NLP\Implement\pipeline\ingest_and_profile.py:40: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   dt_parsed = pd.to_datetime(non_null.sample(min(sample_size,len(non_null))), errors="coerce")
# 100%|██████████████████████████████████████████████████████████████████████████████████| 18/18 [00:00<00:00, 36.48it/s]
# ✅ Profile saved → ./results/student_depression_dataset/profiles\student_depression_dataset_profile.json
#
# ===== STEP 1.5: Generate Dataset Title =====
# 🧠 Loading Title Model from ./title_model to cuda...
# 🔍 Creating Summary for Prompt...
# ⚡ Generating Title...
# The attention mask is not set and cannot be inferred from input because pad token is same as eos token. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# ✅ Title Generated: 'Hospital Patient Record Analysis and Healthcare Performance Review'
# 💾 Saved to: ./results/student_depression_dataset/title\student_depression_dataset_title.json
#
# ===== STEP 2: Clean & Validate =====
# 📂 Using input CSV → C:\Users\keshu\CSET 346\Project\NLP\Implement\data\csv\student_depression_dataset.csv
# 📄 Loaded 27901 rows, 18 cols
# 🔧 Fixed 'id' → numeric (was datetime)
# 🔧 Fixed 'Age' → numeric (was datetime)
# 🔧 Fixed 'Academic Pressure' → numeric (was datetime)
# 🔧 Fixed 'Work Pressure' → numeric (was datetime)
# 🔧 Fixed 'CGPA' → numeric (was datetime)
# 🔧 Fixed 'Study Satisfaction' → numeric (was datetime)
# 🔧 Fixed 'Job Satisfaction' → numeric (was datetime)
# 🔧 Fixed 'Work/Study Hours' → numeric (was datetime)
# 🔧 Fixed 'Depression' → numeric (was datetime)
# ✅ Profile updated → ./results/student_depression_dataset/profiles/student_depression_dataset_profile.json
# 🗑️ Dropped columns → ['id', 'Dietary Habits']
# ✅ Cleaned CSV → ./results/student_depression_dataset/cleaned/student_depression_dataset_cleaned.csv
# ✅ Targets Meta Saved → ./results/student_depression_dataset/cleaned/student_depression_dataset_cleaned_targets_meta.json
#
# ===== STEP 3: Detect & Annotate Sentiment =====
# 📌 Loaded dtype_map from profile: {'id': 'numeric', 'Gender': 'categorical', 'Age': 'numeric', 'City': 'categorical', 'Profession': 'categorical', 'Academic Pressure': 'numeric', 'Work Pressure': 'numeric', 'CGPA': 'numeric', 'Study Satisfaction': 'numeric', 'Job Satisfaction': 'numeric', 'Sleep Duration': 'categorical', 'Dietary Habits': 'categorical', 'Degree': 'categorical', 'Have you ever had suicidal thoughts ?': 'categorical', 'Work/Study Hours': 'numeric', 'Financial Stress': 'categorical', 'Family History of Mental Illness': 'categorical', 'Depression': 'numeric'}
# 📄 Loaded 'student_depression_dataset_cleaned' — 27901 rows, 16 cols
# 🧩 Text candidates found: ['Sleep Duration']
# 🔹 Loading models on GPU (batch_size=64)...
# WARNING:tensorflow:From C:\Users\keshu\anaconda3\Lib\site-packages\tf_keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
# C:\Users\keshu\anaconda3\Lib\site-packages\transformers\pipelines\text_classification.py:104: UserWarning: `return_all_scores` is now deprecated,  if want a similar functionality use `top_k=None` instead of `return_all_scores=True` or `top_k=1` instead of `return_all_scores=False`.
#   warnings.warn(
# ✅ Models loaded.
#
# 🧠 Checking opinion in 'Sleep Duration' ...
# → Opinion fraction=0.56, mean_conf=0.87
# 🟢 Running sentiment model on 'Sleep Duration' ...
# Inferencing 'Sleep Duration': 100%|██████████████████████████████████████████████████████| 1/1 [00:00<00:00,  6.54it/s]
# ✅ Done! 1 columns labeled.
# 📁 Saved enriched CSV → ./results/student_depression_dataset/enriched\student_depression_dataset_cleaned_with_sentiment.csv
# 📄 Saved metadata → ./results/student_depression_dataset/enriched\student_depression_dataset_cleaned_sentiment_meta.json
# ⚡ Runtime: 32.03s
#
# ===== STEP 4: Feature Engineering =====
# ✅ Feature config saved → ./configs/student_depression_dataset_feature_config.json
# 🚀 Running feature engineering on: ./results\student_depression_dataset\enriched\student_depression_dataset_cleaned_with_sentiment.csv
# Primary: Depression, Secondary: ['CGPA']
# 🔢 Numeric: ['Age', 'Academic Pressure', 'Work Pressure', 'CGPA', 'Study Satisfaction', 'Job Satisfaction', 'Work/Study Hours', 'Depression', 'Sleep Duration_sentiment_num', 'Sleep Duration_sentiment_confidence']
# 🔣 Categorical: ['Gender', 'City', 'Profession', 'Sleep Duration', 'Degree', 'Have you ever had suicidal thoughts ?', 'Financial Stress', 'Family History of Mental Illness', 'Sleep Duration_sentiment']
# 💬 Text: []
# 🕒 Datetime: []
# ✅ Processed 6 numeric columns (excluding sentiment).
# ✅ Encoded 8 categorical columns (excluding sentiment).
# ✅ Generated text metrics for 0 columns.
# 🧠 Aggregated sentiment features from 1 columns.
# 🕒 Extracted datetime parts for 0 columns.
# 🧹 Dropped 6 redundant/constant columns.
# ✅ Saved enriched features → ./results\student_depression_dataset\features\student_depression_dataset_features.csv
# 🧾 Metadata saved → ./results\student_depression_dataset\meta\student_depression_dataset_encoders.json
# Total columns after feature engineering: 31
#
# ===== STEP 5: Relation Analysis =====
#
# ================ DEBUG: Relation Analyzer Input Check ================
# ➡ features_path argument: ./results/student_depression_dataset/features/student_depression_dataset_features.csv
# ✔ File exists ✔
#
# 📂 Directory containing file: ./results/student_depression_dataset/features
# 📁 Files in this directory:
# ['student_depression_dataset_features.csv']
#
# 🔍 CSV Columns Loaded:
# ['Gender', 'Age', 'City', 'Profession', 'Academic Pressure', 'Work Pressure', 'CGPA', 'Study Satisfaction', 'Job Satisfaction', 'Sleep Duration', 'Degree', 'Have you ever had suicidal thoughts ?', 'Work/Study Hours', 'Financial Stress', 'Family History of Mental Illness', 'Depression', 'Sleep Duration_sentiment_confidence', 'Age_z', 'Academic Pressure_z', 'Work Pressure_z', 'Study Satisfaction_z', 'Job Satisfaction_z', 'Work/Study Hours_z', 'Gender_encoded', 'City_freq', 'Profession_encoded', 'Sleep Duration_encoded', 'Degree_encoded', 'Have you ever had suicidal thoughts ?_encoded', 'Financial Stress_encoded', 'Family History of Mental Illness_encoded']
#
# 🔍 Checking key sentiment columns:
# ❌ MISSING: content_sentiment
# ❌ MISSING: content_sentiment_num
# ❌ MISSING: content_sentiment_confidence
#
# 🔍 Checking text parent 'content' derived columns (column_relations):
# From feature_meta: []
# ================ END DEBUG ========================================
#
# 🔢 Candidate parent pairs (with reps): 39
# ✅ Relations saved → ./results/student_depression_dataset/relations\student_depression_dataset_relations.json
# ✅ Sentences saved → ./results/student_depression_dataset/relations\student_depression_dataset_relations_sentences.json
# ✅ Plots saved → ./results/student_depression_dataset\plots
# ✅ Summary saved → ./results/student_depression_dataset/relations\summary.txt
#
# ===== STEP 6: Gemini Summary Generation =====
#
# ===== STEP 7: Final Report =====
# 📄 Final Report Generated: {'md': './results/student_depression_dataset/report/student_depression_dataset_report.md', 'pdf': './results/student_depression_dataset/report/student_depression_dataset_report.pdf', 'docx': './results/student_depression_dataset/report/student_depression_dataset_report.docx'}
#
# 🎉 Pipeline complete: student_depression_dataset
#
# 🎉 DONE — Check your results/ folder!
