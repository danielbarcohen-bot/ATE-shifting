# %%
pip install pandas
# Out:
# ...
#    ---------------------------------------- 0.0/11.5 MB ? eta -:--:--
#    --------- ------------------------------ 2.6/11.5 MB 13.8 MB/s eta 0:00:01
#    ------------------- -------------------- 5.5/11.5 MB 13.7 MB/s eta 0:00:01
#    ----------------------------- ---------- 8.4/11.5 MB 13.6 MB/s eta 0:00:01
#    ---------------------------------------  11.3/11.5 MB 13.6 MB/s eta 0:00:01
#    ---------------------------------------- 11.5/11.5 MB 13.3 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/12.6 MB ? eta -:--:--
#    --------- ------------------------------ 2.9/12.6 MB 13.5 MB/s eta 0:00:01
#    ------------------ --------------------- 5.8/12.6 MB 13.5 MB/s eta 0:00:01
#    --------------------------- ------------ 8.7/12.6 MB 13.5 MB/s eta 0:00:01
#    ----------------------------------- ---- 11.3/12.6 MB 13.5 MB/s eta 0:00:01
#    ---------------------------------------- 12.6/12.6 MB 13.2 MB/s eta 0:00:00
# ...

# %%
import pandas as pd

# %%
pip install pyyaml
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.0.1 -> 25.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import yaml
import pandas as pd

# Step 1: Load the YAML file
while True:
    for i in 
    with open('C:/Users/gthir/Desktop/Data_Driven_stock_project/data/2024-04/2024-04-01_05-30-00.yaml', 'r') as yaml_file:
    data1 = yaml.safe_load(yaml_file) # created in dict format

# %%
data1
# Out:
# [{'Ticker': 'SBIN',
#   'close': 758.3,
#   'date': '2024-04-01 05:30:00',
#   'high': 761.5,
#   'low': 752.1,
#   'month': '2024-04',
#   'open': 759.05,
#   'volume': 9949971},
#  {'Ticker': 'BAJFINANCE',
#   'close': 7250.95,
#   'date': '2024-04-01 05:30:00',
#   'high': 7343.45,
#   'low': 7220.05,
#   'month': '2024-04',
#   'open': 7261.25,
#   'volume': 1125238},
#  {'Ticker': 'TITAN',
#   'close': 3738.4,
#   'date': '2024-04-01 05:30:00',
#   'high': 3832.55,
#   'low': 3730.5,
#   'month': '2024-04',
#   'open': 3822.95,
#   'volume': 964052},
#  {'Ticker': 'ITC',
#   'close': 426.7,
#   'date': '2024-04-01 05:30:00',
#   'high': 431.35,
#   'low': 425.75,
#   'month': '2024-04',
#   'open': 429.1,
#   'volume': 9382308},
#  {'Ticker': 'TCS',
#   'close': 3916.75,
#   'date': '2024-04-01 05:30:00',
#   'high': 3933.3,
#   'low': 3888.05,
#   'month': '2024-04',
#   'open': 3897.7,
#   'volume': 1569676},
#  {'Ticker': 'LT',
#   'close': 3838.0,
# ...

# %%
df1 = pd.DataFrame(data1)

# %%
df1
# Out:
#         Ticker     close                 date      high       low    month  \
# 0         SBIN    758.30  2024-04-01 05:30:00    761.50    752.10  2024-04
# 1   BAJFINANCE   7250.95  2024-04-01 05:30:00   7343.45   7220.05  2024-04
# 2        TITAN   3738.40  2024-04-01 05:30:00   3832.55   3730.50  2024-04
# 3          ITC    426.70  2024-04-01 05:30:00    431.35    425.75  2024-04
# 4          TCS   3916.75  2024-04-01 05:30:00   3933.30   3888.05  2024-04
# 5           LT   3838.00  2024-04-01 05:30:00   3851.85   3780.85  2024-04
# 6   TATACONSUM   1073.56  2024-04-01 05:30:00   1090.84   1069.80  2024-04
# 7     RELIANCE   1484.78  2024-04-01 05:30:00   1493.98   1482.50  2024-04
# 8      HCLTECH   1556.70  2024-04-01 05:30:00   1569.00   1548.00  2024-04
# 9     JSWSTEEL    871.95  2024-04-01 05:30:00    876.45    838.00  2024-04
# 10  ULTRACEMCO   9954.40  2024-04-01 05:30:00   9997.05   9749.15  2024-04
# ...

# %%
import os
import yaml

folder_path = 'C:/Users/gthir/Desktop/Data_Driven_stock_project/data/2023-11'  # change this to your folder

comb_yamil = []

for filename in os.listdir(folder_path):
    if filename.endswith('.yaml') or filename.endswith('.yml'):
        file_path = os.path.join(folder_path, filename)
        with open(file_path, 'r') as file:
            data = yaml.safe_load(file)
            if data:
                comb_yamil.extend(data)  # for list-type YAML files

# %%
df = pd.DataFrame(comb_yamil)

# %%
df
# Out:
#           Ticker    close                 date     high      low    month  \
# 0           SBIN   566.40  2023-11-01 05:30:00   569.65   563.85  2023-11
# 1     BAJFINANCE  7471.90  2023-11-01 05:30:00  7549.00  7457.65  2023-11
# 2          TITAN  3173.40  2023-11-01 05:30:00  3212.90  3168.35  2023-11
# 3            ITC   428.10  2023-11-01 05:30:00   431.10   425.50  2023-11
# 4            TCS  3330.65  2023-11-01 05:30:00  3371.60  3311.00  2023-11
# ...          ...      ...                  ...      ...      ...      ...
# 1045    HINDALCO   515.65  2023-11-30 05:30:00   519.75   511.35  2023-11
# 1046  HEROMOTOCO  3819.05  2023-11-30 05:30:00  3884.50  3782.20  2023-11
# 1047    AXISBANK  1074.25  2023-11-30 05:30:00  1080.90  1055.45  2023-11
# 1048    HDFCBANK  1558.80  2023-11-30 05:30:00  1572.45  1542.15  2023-11
# 1049  BAJAJ-AUTO  6090.55  2023-11-30 05:30:00  6128.90  6031.00  2023-11
#
#          open    volume
# 0      566.25  13575575
# 1     7520.00    462778
# ...

# %%
df.columns
# Out:
# Index(['Ticker', 'close', 'date', 'high', 'low', 'month', 'open', 'volume'], dtype='object')

# %%
df['Ticker'].unique()
# Out:
# array(['SBIN', 'BAJFINANCE', 'TITAN', 'ITC', 'TCS', 'LT', 'TATACONSUM',
#        'RELIANCE', 'HCLTECH', 'JSWSTEEL', 'ULTRACEMCO', 'POWERGRID',
#        'INFY', 'TRENT', 'BHARTIARTL', 'TATAMOTORS', 'WIPRO', 'TECHM',
#        'NTPC', 'HINDUNILVR', 'APOLLOHOSP', 'M&M', 'GRASIM', 'ICICIBANK',
#        'ADANIENT', 'ADANIPORTS', 'BEL', 'BAJAJFINSV', 'EICHERMOT',
#        'COALINDIA', 'MARUTI', 'INDUSINDBK', 'ASIANPAINT', 'TATASTEEL',
#        'HDFCLIFE', 'DRREDDY', 'SUNPHARMA', 'KOTAKBANK', 'SHRIRAMFIN',
#        'NESTLEIND', 'ONGC', 'CIPLA', 'BPCL', 'BRITANNIA', 'SBILIFE',
#        'HINDALCO', 'HEROMOTOCO', 'AXISBANK', 'HDFCBANK', 'BAJAJ-AUTO'],
#       dtype=object)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1050 entries, 0 to 1049
# Data columns (total 8 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Ticker  1050 non-null   object
#  1   close   1050 non-null   float64
#  2   date    1050 non-null   object
#  3   high    1050 non-null   float64
#  4   low     1050 non-null   float64
#  5   month   1050 non-null   object
#  6   open    1050 non-null   float64
#  7   volume  1050 non-null   int64
# dtypes: float64(4), int64(1), object(3)
# memory usage: 65.8+ KB

# %%
from pathlib import Path

folder_yamil = Path(r'D:/Data_Driven_stock_project/data')  # Main folder path
# Use rglob to recursively search for all YAML files in subfolders
yaml_files = [f for f in folder_yamil.rglob('*.yaml')] # uses list comprehension to collect all ...
print(f"Total YAML files: {len(yaml_files)}")
# Out:
# Total YAML files: 264

# %%
folder_yamil = Path(r'D:/Data_Driven_stock_project/data')  # Main folder path
# Use rglob to recursively search for all YAML files in subfolders
yaml_files = [f for f in folder_yamil.rglob('*.yaml')] # uses list comprehension to collect all ...
#.yamil files from folder directory and alll its subfolders
comb_yamil=[] # create a list to store all the dictionary
# Loop through each YAML file
for file_links in yaml_files: 
    with open(file_links, 'r') as f:
        data = yaml.safe_load(f) 
        if data: #data is a list of dicts, so you want to flatten them all into one big list.
            comb_yamil.extend(data)  # extend() adds each dict inside the list, 
                                     # while append() would add the whole list as a single 
                                     # item (which you don’t want).

# %%
df=pd.DataFrame(comb_yamil)
df.to_csv("comb_stock.csv",index=False)
print("Merged YAML data saved to comb_stock.csv")

# %%
import pandas as pd

# %%
df=pd.read_csv("D:\Data_Driven_stock_project\comb_stock.csv")

# %%
df.columns
# Out:
# Index(['Ticker', 'close', 'date', 'high', 'low', 'month', 'open', 'volume'], dtype='object')

# %%
print(len(df))
# Out:
# 13200

# %%
df['Ticker'].nunique()
# Out:
# 50

# %%
df['date'].value_counts()
# Out:
# date
# 2024-11-22 05:30:00    50
# 2023-11-01 05:30:00    50
# 2023-11-02 05:30:00    50
# 2023-11-03 05:30:00    50
# 2023-11-06 05:30:00    50
#                        ..
# 2023-11-17 05:30:00    50
# 2023-11-16 05:30:00    50
# 2023-11-15 05:30:00    50
# 2023-11-13 05:30:00    50
# 2023-11-12 05:30:00    50
# Name: count, Length: 264, dtype: int64

# %%
df # combined all yaml files to df
# Out:
#            Ticker    close                 date     high      low    month  \
# 0            SBIN   566.40  2023-11-01 05:30:00   569.65   563.85  2023-11
# 1      BAJFINANCE  7471.90  2023-11-01 05:30:00  7549.00  7457.65  2023-11
# 2           TITAN  3173.40  2023-11-01 05:30:00  3212.90  3168.35  2023-11
# 3             ITC   428.10  2023-11-01 05:30:00   431.10   425.50  2023-11
# 4             TCS  3330.65  2023-11-01 05:30:00  3371.60  3311.00  2023-11
# ...           ...      ...                  ...      ...      ...      ...
# 13195    HINDALCO   652.10  2024-11-22 05:30:00   657.30   647.40  2024-11
# 13196  HEROMOTOCO  4794.10  2024-11-22 05:30:00  4808.40  4742.00  2024-11
# 13197    AXISBANK  1142.40  2024-11-22 05:30:00  1147.90  1127.55  2024-11
# 13198    HDFCBANK  1745.60  2024-11-22 05:30:00  1754.30  1729.55  2024-11
# 13199  BAJAJ-AUTO  9481.65  2024-11-22 05:30:00  9602.90  9444.10  2024-11
#
#           open    volume
# 0       566.25  13575575
# ...

# %%
df[df['Ticker'] == 'SBIN']
# Out:
#       Ticker   close                 date    high     low    month    open  \
# 0       SBIN  566.40  2023-11-01 05:30:00  569.65  563.85  2023-11  566.25
# 50      SBIN  572.10  2023-11-02 05:30:00  575.45  567.60  2023-11  571.10
# 100     SBIN  578.15  2023-11-03 05:30:00  579.50  573.45  2023-11  576.00
# 150     SBIN  574.35  2023-11-06 05:30:00  582.50  573.25  2023-11  582.00
# 200     SBIN  579.75  2023-11-07 05:30:00  581.20  572.60  2023-11  574.80
# ...      ...     ...                  ...     ...     ...      ...     ...
# 12950   SBIN  804.25  2024-11-14 05:30:00  818.00  801.05  2024-11  808.65
# 13000   SBIN  814.30  2024-11-18 05:30:00  816.70  799.25  2024-11  811.00
# 13050   SBIN  803.00  2024-11-19 05:30:00  820.30  800.10  2024-11  819.00
# 13100   SBIN  780.75  2024-11-21 05:30:00  798.50  761.55  2024-11  798.50
# 13150   SBIN  816.05  2024-11-22 05:30:00  819.95  784.05  2024-11  786.00
#
#          volume
# 0      13575575
# 50     11148516
# ...

# %%
df['Ticker'].unique()
# Out:
# array(['SBIN', 'BAJFINANCE', 'TITAN', 'ITC', 'TCS', 'LT', 'TATACONSUM',
#        'RELIANCE', 'HCLTECH', 'JSWSTEEL', 'ULTRACEMCO', 'POWERGRID',
#        'INFY', 'TRENT', 'BHARTIARTL', 'TATAMOTORS', 'WIPRO', 'TECHM',
#        'NTPC', 'HINDUNILVR', 'APOLLOHOSP', 'M&M', 'GRASIM', 'ICICIBANK',
#        'ADANIENT', 'ADANIPORTS', 'BEL', 'BAJAJFINSV', 'EICHERMOT',
#        'COALINDIA', 'MARUTI', 'INDUSINDBK', 'ASIANPAINT', 'TATASTEEL',
#        'HDFCLIFE', 'DRREDDY', 'SUNPHARMA', 'KOTAKBANK', 'SHRIRAMFIN',
#        'NESTLEIND', 'ONGC', 'CIPLA', 'BPCL', 'BRITANNIA', 'SBILIFE',
#        'HINDALCO', 'HEROMOTOCO', 'AXISBANK', 'HDFCBANK', 'BAJAJ-AUTO'],
#       dtype=object)

# %%
df[['date']]
# Out:
#                       date
# 0      2023-11-01 05:30:00
# 1      2023-11-01 05:30:00
# 2      2023-11-01 05:30:00
# 3      2023-11-01 05:30:00
# 4      2023-11-01 05:30:00
# ...                    ...
# 13195  2024-11-22 05:30:00
# 13196  2024-11-22 05:30:00
# 13197  2024-11-22 05:30:00
# 13198  2024-11-22 05:30:00
# 13199  2024-11-22 05:30:00
#
# [13200 rows x 1 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13200 entries, 0 to 13199
# Data columns (total 8 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Ticker  13200 non-null  object
#  1   close   13200 non-null  float64
#  2   date    13200 non-null  object
#  3   high    13200 non-null  float64
#  4   low     13200 non-null  float64
#  5   month   13200 non-null  object
#  6   open    13200 non-null  float64
#  7   volume  13200 non-null  int64
# dtypes: float64(4), int64(1), object(3)
# memory usage: 825.1+ KB

# %%
df['date'] = pd.to_datetime(df['date']).dt.date # converting to datetime

# %%
df[['date']]
# Out:
#              date
# 0      2023-11-01
# 1      2023-11-01
# 2      2023-11-01
# 3      2023-11-01
# 4      2023-11-01
# ...           ...
# 13195  2024-11-22
# 13196  2024-11-22
# 13197  2024-11-22
# 13198  2024-11-22
# 13199  2024-11-22
#
# [13200 rows x 1 columns]

# %%
df['date'] = pd.to_datetime(df['date'])

# %%
df[['date']]
# Out:
#             date
# 0     2023-11-01
# 1     2023-11-01
# 2     2023-11-01
# 3     2023-11-01
# 4     2023-11-01
# ...          ...
# 13195 2024-11-22
# 13196 2024-11-22
# 13197 2024-11-22
# 13198 2024-11-22
# 13199 2024-11-22
#
# [13200 rows x 1 columns]

# %%
df['date'] = pd.to_datetime(df['date']).dt.date

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13200 entries, 0 to 13199
# Data columns (total 8 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Ticker  13200 non-null  object
#  1   close   13200 non-null  float64
#  2   date    13200 non-null  object
#  3   high    13200 non-null  float64
#  4   low     13200 non-null  float64
#  5   month   13200 non-null  object
#  6   open    13200 non-null  float64
#  7   volume  13200 non-null  int64
# dtypes: float64(4), int64(1), object(3)
# memory usage: 825.1+ KB

# %%
df
# Out:
#            Ticker    close        date     high      low    month     open  \
# 0            SBIN   566.40  2023-11-01   569.65   563.85  2023-11   566.25
# 1      BAJFINANCE  7471.90  2023-11-01  7549.00  7457.65  2023-11  7520.00
# 2           TITAN  3173.40  2023-11-01  3212.90  3168.35  2023-11  3193.85
# 3             ITC   428.10  2023-11-01   431.10   425.50  2023-11   430.00
# 4             TCS  3330.65  2023-11-01  3371.60  3311.00  2023-11  3355.00
# ...           ...      ...         ...      ...      ...      ...      ...
# 13195    HINDALCO   652.10  2024-11-22   657.30   647.40  2024-11   652.95
# 13196  HEROMOTOCO  4794.10  2024-11-22  4808.40  4742.00  2024-11  4778.40
# 13197    AXISBANK  1142.40  2024-11-22  1147.90  1127.55  2024-11  1136.65
# 13198    HDFCBANK  1745.60  2024-11-22  1754.30  1729.55  2024-11  1743.55
# 13199  BAJAJ-AUTO  9481.65  2024-11-22  9602.90  9444.10  2024-11  9545.00
#
#          volume
# 0      13575575
# 1        462778
# ...

# %%
#save the Ticker data in separate csv files under one folder

import os

# Create a folder to store output files
output_folder = 'nifty50'
os.makedirs(output_folder, exist_ok=True)

# Loop through each unique ticker
for ticker in df['Ticker'].unique(): # here picks each unique ticker name is SBIN', 'BAJFINANCE', 'TITAN', 'ITC ...
    ticker_df = df[df['Ticker'] == ticker]  # filter dat
    file_name = f"{ticker}.csv"             # create filename like SBIN.csv...so on...
    file_path = os.path.join(output_folder, file_name)  # full path
    ticker_df.to_csv(file_path, index=False)  # save CSV
    print(f"Saved: {file_name}")
# Out:
# Saved: SBIN.csv
# Saved: BAJFINANCE.csv
# Saved: TITAN.csv
# Saved: ITC.csv
# Saved: TCS.csv
# Saved: LT.csv
# Saved: TATACONSUM.csv
# Saved: RELIANCE.csv
# Saved: HCLTECH.csv
# Saved: JSWSTEEL.csv
# Saved: ULTRACEMCO.csv
# Saved: POWERGRID.csv
# Saved: INFY.csv
# Saved: TRENT.csv
# Saved: BHARTIARTL.csv
# Saved: TATAMOTORS.csv
# Saved: WIPRO.csv
# Saved: TECHM.csv
# Saved: NTPC.csv
# Saved: HINDUNILVR.csv
# Saved: APOLLOHOSP.csv
# Saved: M&M.csv
# Saved: GRASIM.csv
# Saved: ICICIBANK.csv
# Saved: ADANIENT.csv
# Saved: ADANIPORTS.csv
# Saved: BEL.csv
# Saved: BAJAJFINSV.csv
# Saved: EICHERMOT.csv
# Saved: COALINDIA.csv
# Saved: MARUTI.csv
# Saved: INDUSINDBK.csv
# Saved: ASIANPAINT.csv
# Saved: TATASTEEL.csv
# Saved: HDFCLIFE.csv
# Saved: DRREDDY.csv
# Saved: SUNPHARMA.csv
# Saved: KOTAKBANK.csv
# Saved: SHRIRAMFIN.csv
# Saved: NESTLEIND.csv
# Saved: ONGC.csv
# Saved: CIPLA.csv
# Saved: BPCL.csv
# Saved: BRITANNIA.csv
# Saved: SBILIFE.csv
# Saved: HINDALCO.csv
# ...

# %%
df=pd.read_csv("D:/Data_Driven_stock_project/nifty50/ADANIENT.csv")

# %%
df
# Out:
#        Ticker    close                 date     high      low    month  \
# 0    ADANIENT  2217.30  2023-11-01 05:30:00  2312.25  2207.00  2023-11
# 1    ADANIENT  2215.30  2023-11-02 05:30:00  2297.95  2204.20  2023-11
# 2    ADANIENT  2229.85  2023-11-03 05:30:00  2279.00  2215.00  2023-11
# 3    ADANIENT  2246.00  2023-11-06 05:30:00  2260.00  2233.00  2023-11
# 4    ADANIENT  2233.35  2023-11-07 05:30:00  2260.00  2226.65  2023-11
# ..        ...      ...                  ...      ...      ...      ...
# 259  ADANIENT  2826.80  2024-11-14 05:30:00  2844.80  2801.00  2024-11
# 260  ADANIENT  2818.70  2024-11-18 05:30:00  2858.65  2793.30  2024-11
# 261  ADANIENT  2821.50  2024-11-19 05:30:00  2894.80  2809.80  2024-11
# 262  ADANIENT  2183.65  2024-11-21 05:30:00  2539.35  2155.05  2024-11
# 263  ADANIENT  2228.00  2024-11-22 05:30:00  2289.70  2025.00  2024-11
#
#         open    volume
# 0    2299.00   1666579
# 1    2247.00   2340997
# 2    2215.30   1853300
# ...

# %%
#Data cleaning

# %%
df['close'].nunique()
# Out:
# 260

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 264 entries, 0 to 263
# Data columns (total 8 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Ticker  264 non-null    object
#  1   close   264 non-null    float64
#  2   date    264 non-null    object
#  3   high    264 non-null    float64
#  4   low     264 non-null    float64
#  5   month   264 non-null    object
#  6   open    264 non-null    float64
#  7   volume  264 non-null    int64
# dtypes: float64(4), int64(1), object(3)
# memory usage: 16.6+ KB
