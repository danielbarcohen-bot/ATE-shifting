# %% [markdown]
# # Regression Engine to predict Arrival Delay

# %% [markdown]
# In this notebook we are going to buils a model to predict the delay time of flights.

# %% [markdown]
# Table of contents:
#
# 1. [Import relevant libraries](#Libraries)
# 2. [Load files](#Load)
# 3. [Preview files](#Preview)
# 5. [Data exploration and transformation](#Exploration)
# 6. [Target distribution](#Target)
# 7. [Outliers](#Outliers)
# 8. [Correlations](#Correlations)
# 9. [Model training](#Model)
# 10. [Test set predictions](#Predictions)
# 11. [Creating a submission file](#Submission)
# 12. [Tips to improve model performance](#Tips)

# %% [markdown]
# <a name = "Libraries"></a>
# ## 1. Import relevant libraries

# %%
# Pre-requisites
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
import missingno as msno

# Store the regression models to save time
import joblib

# Preprocessing
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split

# Classifiers from scikit-learn
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import ExtraTreesRegressor
from sklearn.ensemble import GradientBoostingRegressor

# Performance metrics
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import r2_score

pd.set_option('display.max_columns', None)

# %% [markdown]
# <a name = "Load"></a>
# ## 2. Load files

# %%
file_path = 'processed.parquet'

# Read the file using pandas
df = pd.read_parquet(file_path)

# %% [markdown]
# <a name = "Preview"></a>
# ## 3. Preview files

# %%
df.head()
# Out:
#    aircraft airport        rounded_hour        date  from  to  flight  \
# 0    ei-dwe     crl 2023-08-18 22:00:00  2023-08-18   157   7     329
# 1  a9c-dhab     bah 2023-08-21 22:00:00  2023-08-21    80   3     257
# 2    hb-jba     vie 2023-10-08 21:00:00  2023-10-08   107  22     635
# 3    9v-sfi     bru 2024-01-25 12:00:00  2024-01-25    71   5     789
# 4  ra-73249     msq 2024-03-28 19:00:00  2024-03-28   138  17     206
#
#    flight_time scheduled_time_departure actual_time_departure  \
# 0     1.016667      2023-08-18 19:30:00   2023-08-18 19:59:00
# 1     0.900000      2023-08-20 23:04:00   2023-08-21 22:10:00
# 2     1.316667      2023-10-08 19:00:00   2023-10-08 19:07:00
# 3     8.233333      2024-01-25 19:50:00   2024-01-25 20:28:00
# 4     1.066667      2024-03-28 17:10:00   2024-03-28 17:22:00
#
#   scheduled_time_arrival  status actual_time_arrival  from_city  to_city  \
# 0    2023-08-18 21:50:00       0 2023-08-18 22:00:00        142        6
# 1    2023-08-21 22:04:00       0 2023-08-21 22:04:00         72        3
# 2    2023-10-08 20:35:00       0 2023-10-08 20:26:00         88       20
# 3    2024-01-25 11:55:00       0 2024-01-25 11:42:00         69        6
# 4    2024-03-28 18:45:00       0 2024-03-28 18:25:00        221       15
#
#    delay_time  temperature  dew_point  humidity  wind_speed  wind_gust  \
# 0        10.0           73         68        83           6          0
# 1         0.0           95         84        71           9          0
# 2        -9.0           54         45        72           7          0
# 3       -13.0           45         45       100           7          0
# 4       -20.0           50         37        62          13         20
#
#     pressure  precip  my_flightradar24_rating  arrival_delay_index  \
# 0  29.260000     0.0                       63                  0.4
# 1  29.580000     0.0                       78                  0.4
# 2  29.700001     0.0                       85                  0.4
# 3  30.280001     0.0                       81                  0.4
# 4  28.820000     0.0                       71                  2.5
#
#    departure_delay_index    msn  type                              airline  \
# 0                    1.2  36074  B738                              Ryanair
# 1                    0.8  29606  B763  DHL (No. 1 Best Workplace Stickers)
# 2                    0.7  50010  BCS1                                Swiss
# 3                    0.8  28027  B744                   Singapore Airlines
# 4                    2.5  41241  B738                               Pobeda
#
#     age  departure_delay  departure_delay_15  year  month  day  hour  \
# 0  16.0             29.0                   1  2023      8   18    21
# 1  24.0           1386.0                   1  2023      8   21    22
# 2   7.0              7.0                   0  2023     10    8    20
# 3  23.0             38.0                   1  2024      1   25    11
# 4   5.0             12.0                   0  2024      3   28    18
#
#    dayofweek  quarter  is_year_start  is_year_end
# 0          4        3              0            0
# 1          0        3              0            0
# 2          6        4              0            0
# 3          3        1              0            0
# 4          3        1              0            0

# %% [markdown]
# <a name = "Exploration"></a>
# ## 5. Data exploration and transformation

# %%
print(msno.matrix(df))
# Out:
# Axes(0.125,0.125;0.698618x0.755)

# %%
df.dropna(inplace=True)

# %%
# Check for any missing values
df.isnull().sum().any()
# Out:
# False

# %%
df = df[df['status']==1]

df["arrival_delay"] = df["actual_time_arrival"] - df["scheduled_time_arrival"]
# Convert the arrival delay to minutes
df['arrival_delay'] = df['arrival_delay'].dt.total_seconds() / 60

# %%
cols = ['flight', 'from', 'to','from_city', 'to_city', 'flight_time', 'departure_delay',
        'temperature', 'humidity', 'wind_speed',
        'my_flightradar24_rating', 'arrival_delay_index', 'departure_delay_index',
         'year', 'month', 'day', 'hour', 'dayofweek', 'quarter', 'status']

df = df[cols]

# %%
# Show the first few rows of the DataFrame
df.head()
# Out:
#     flight  from  to  from_city  to_city  flight_time  departure_delay  \
# 6      447    54   7         51        6     1.316667             37.0
# 12     398   137   7        226        6     1.283333            221.0
# 13     327    94   5        201        6     1.733333            128.0
# 17      45   123  17        107       15     3.633333             22.0
# 27     282   147   7        127        6     2.433333             54.0
#
#     temperature  humidity  wind_speed  my_flightradar24_rating  \
# 6            77        57           7                       63
# 12           70        60           5                       63
# 13           68        68           5                       81
# 17           32        93           7                       71
# 27           59        63           6                       63
#
#     arrival_delay_index  departure_delay_index  year  month  day  hour  \
# 6                   0.4                    1.2  2023      9   11    15
# 12                  0.4                    1.2  2023      9    4    10
# 13                  0.4                    0.8  2023      9   26    17
# 17                  2.5                    2.5  2024      1   26    21
# 27                  0.4                    1.2  2023      8   30    17
#
#     dayofweek  quarter  status
# 6           0        3       1
# 12          0        3       1
# 13          1        3       1
# 17          4        1       1
# 27          2        3       1

# %%
# Check statistical summaries of the dataset
df.describe()
# Out:
#             flight         from           to    from_city      to_city  \
# count  1235.000000  1235.000000  1235.000000  1235.000000  1235.000000
# mean    473.756275   132.422672     9.821862   127.400000     9.048583
# std     254.102966    76.904556     6.493159    70.743301     5.770537
# min       3.000000     0.000000     0.000000     0.000000     0.000000
# 25%     274.000000    76.500000     5.000000    76.500000     6.000000
# 50%     479.000000   123.000000     7.000000   127.000000     6.000000
# 75%     693.000000   188.000000    16.000000   180.000000    14.000000
# max     936.000000   277.000000    22.000000   260.000000    21.000000
#
#        flight_time  departure_delay  temperature     humidity   wind_speed  \
# count  1235.000000      1235.000000  1235.000000  1235.000000  1235.000000
# mean      3.301646         9.998381    57.166802    72.429960     9.774899
# std       2.774133       289.347038    16.361685    19.791594     5.740006
# min       0.350000     -1417.000000     7.000000     0.000000     0.000000
# 25%       1.283333        37.000000    46.000000    60.000000     6.000000
# 50%       2.250000        52.000000    57.000000    76.000000     9.000000
# 75%       4.841667        78.000000    66.000000    88.000000    13.000000
# max      14.016667       710.000000   111.000000   100.000000    36.000000
#
#        my_flightradar24_rating  arrival_delay_index  departure_delay_index  \
# count              1235.000000          1235.000000            1235.000000
# mean                 74.207287             0.988988               1.414656
# std                   9.564205             0.921299               0.837940
# min                  45.000000             0.400000               0.100000
# 25%                  63.000000             0.400000               0.800000
# 50%                  79.000000             0.400000               1.200000
# 75%                  81.000000             2.500000               2.500000
# max                  85.000000             2.500000               3.500000
#
#               year        month          day         hour    dayofweek  \
# count  1235.000000  1235.000000  1235.000000  1235.000000  1235.000000
# mean   2023.269636     6.842915    15.317409    13.056680     3.021862
# std       0.443950     3.642617     8.831191     5.888623     1.996027
# min    2023.000000     1.000000     1.000000     0.000000     0.000000
# 25%    2023.000000     4.000000     8.000000     9.000000     1.000000
# 50%    2023.000000     7.000000    15.000000    13.000000     3.000000
# 75%    2024.000000    10.000000    23.000000    18.000000     5.000000
# max    2024.000000    12.000000    31.000000    23.000000     6.000000
#
#            quarter  status
# count  1235.000000  1235.0
# mean      2.623482     1.0
# std       1.131514     0.0
# min       1.000000     1.0
# 25%       2.000000     1.0
# 50%       3.000000     1.0
# 75%       4.000000     1.0
# max       4.000000     1.0

# %%
df.dtypes
# Out:
# flight                       int32
# from                         int32
# to                           int32
# from_city                    int32
# to_city                      int32
# flight_time                float64
# departure_delay            float64
# temperature                  int32
# humidity                     int32
# wind_speed                   int32
# my_flightradar24_rating      int32
# arrival_delay_index        float32
# departure_delay_index      float32
# year                         int64
# month                        int64
# day                          int64
# hour                         int64
# dayofweek                    int64
# quarter                      int64
# status                       int32
# dtype: object

# %% [markdown]
# <a name = "Target"></a>
# ## 6. Target variable distribution

# %%
sns.displot(df, x="arrival_delay", kind="kde")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [12], in <cell line: 1>()
# ----> 1 sns.displot(df, x="arrival_delay", kind="kde")
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\distributions.py:2194, in displot(data, x, y, hue, row, col, weights, kind, rug, rug_kws, log_scale, legend, palette, hue_order, hue_norm, color, col_wrap, row_order, col_order, height, aspect, facet_kws, **kwargs)
#    2180 def displot(
#    2181     data=None, *,
#    2182     # Vector variables
#    (...)
#    2191     **kwargs,
#    2192 ):
# -> 2194     p = _DistributionFacetPlotter(
#    2195         data=data,
#    2196         variables=_DistributionFacetPlotter.get_semantics(locals())
#    2197     )
#    2199     p.map_hue(palette=palette, order=hue_order, norm=hue_norm)
#    2201     _check_argument("kind", ["hist", "kde", "ecdf"], kind)
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\distributions.py:111, in _DistributionPlotter.__init__(self, data, variables)
#     105 def __init__(
#     106     self,
#     107     data=None,
#     108     variables={},
#     109 ):
# --> 111     super().__init__(data=data, variables=variables)
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\_core.py:605, in VectorPlotter.__init__(self, data, variables)
#     603 def __init__(self, data=None, variables={}):
# --> 605     self.assign_variables(data, variables)
#     607     for var, cls in self._semantic_mappings.items():
#     608
#     609         # Create the mapping function
#     610         map_func = partial(cls.map, plotter=self)
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\_core.py:668, in VectorPlotter.assign_variables(self, data, variables)
#     666 else:
#     667     self.input_format = "long"
# --> 668     plot_data, variables = self._assign_variables_longform(
#     669         data, **variables,
#     670     )
#     672 self.plot_data = plot_data
#     673 self.variables = variables
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\_core.py:903, in VectorPlotter._assign_variables_longform(self, data, **kwargs)
#     898 elif isinstance(val, (str, bytes)):
#     899
#     900     # This looks like a column name but we don't know what it means!
#     902     err = f"Could not interpret value `{val}` for parameter `{key}`"
# --> 903     raise ValueError(err)
#     905 else:
#     906
#     907     # Otherwise, assume the value is itself data
#     908
#     909     # Raise when data object is present and a vector can't matched
#     910     if isinstance(data, pd.DataFrame) and not isinstance(val, pd.Series):
#
# ValueError: Could not interpret value `arrival_delay` for parameter `x`

# %% [markdown]
# <a name = "Model"></a>
# ## 9. Model training

# %%
X = df.loc[:, df.columns != "arrival_delay"]
y = np.array(df.loc[:, df.columns == "arrival_delay"]["arrival_delay"])

# %%
print(f"\nDataset shape: {df.shape}")
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=42)
print(f"features_train shape: {X_train.shape} | features_test shape: {X_test.shape}")
print(f"labels_train shape: {y_train.shape} | labels_test shape: {y_test.shape}")
# Out:
# Dataset shape: (1235, 30)
# features_train shape: (988, 29) | features_test shape: (247, 29)
# labels_train shape: (988,) | labels_test shape: (247,)

# %%
def print_metrics(labels_test, model_pred, regressor_name):

    mse = mean_squared_error(labels_test, model_pred)
    rmse = np.sqrt(mse)
    mae = mean_absolute_error(labels_test, model_pred)
    r2 = r2_score(labels_test, model_pred)

    print(f"MSE      : {mse}", end="\n\n")
    print(f"RMSE     : {rmse}", end="\n\n")
    print(f"MAE      : {mae}", end="\n\n")
    print(f"R2 Score : {r2}", end="\n\n")

# %% [markdown]
# ## Linear Regression

# %%
model = LinearRegression(n_jobs=-1)
model.fit(X_train, y_train)
# Out:
# LinearRegression(n_jobs=-1)

# %%
model_pred = model.predict(X_test)
print_metrics(y_test, model_pred, "LinearRegression")
# Out:
# MSE      : 10299.194298639864
#
# RMSE     : 101.48494616759604
#
# MAE      : 45.21611190937011
#
# R2 Score : 0.024752867780290067

# %%
# Save the model
joblib.dump(model, 'regressors/linear_regression_regressor.joblib')
# Out:
# ['regressors/linear_regression_regressor.joblib']

# %% [markdown]
# ## Decision Tree Regressor

# %%
model = DecisionTreeRegressor()
model.fit(X_train, y_train)
# Out:
# DecisionTreeRegressor()

# %%
model_pred = model.predict(X_test)
print_metrics(y_test, model_pred, "DecisionTreeRegressor")
# Out:
# MSE      : 26505.433198380568
#
# RMSE     : 162.80489304188794
#
# MAE      : 55.587044534412954
#
# R2 Score : -1.5098417376566498

# %%
# Save the model
joblib.dump(model, 'regressors/decision_tree_regressor.joblib')
# Out:
# ['regressors/decision_tree_regressor.joblib']

# %% [markdown]
# ## XGBoost

# %%
model = GradientBoostingRegressor()
model.fit(X_train, y_train)
# Out:
# GradientBoostingRegressor()

# %%
model_pred = model.predict(X_test)
print_metrics(y_test, model_pred, "GradientBoostingRegressor")
# Out:
# MSE      : 23114.047160391405
#
# RMSE     : 152.0330462774176
#
# MAE      : 49.36732075262896
#
# R2 Score : -1.1887059854905138

# %%
# Save the model
joblib.dump(model, 'regressors/xgboost_regressor.joblib')
# Out:
# ['regressors/xgboost_regressor.joblib']

# %% [markdown]
# ## Random Forest

# %%
model = RandomForestRegressor()
model.fit(X_train, y_train)
# Out:
# RandomForestRegressor()

# %%
model_pred = model.predict(X_test)
print_metrics(y_test, model_pred, "RandomForestRegressor")
# Out:
# MSE      : 18268.440607692304
#
# RMSE     : 135.16079537977092
#
# MAE      : 48.8814979757085
#
# R2 Score : -0.7298677737472015

# %%
# Save the model
joblib.dump(model, 'regressors/random_forest_regressor.joblib')
# Out:
# ['regressors/random_forest_regressor.joblib']

# %%
importances = pd.DataFrame({
    "Feature": list(X.columns),
    "Importance": model.feature_importances_
})
importances = importances.sort_values(by="Importance", ascending=False)
importances = importances.set_index("Feature")
importances
plt.figure(figsize=(8, 6), dpi=80)
plt.barh(importances.index, importances.Importance)
plt.title("Feature Importance Ranking obtained from Random Forest Classifier", fontsize=12)
plt.xlabel("Importances")
plt.ylabel("Features")
# Out:
# Text(0, 0.5, 'Features')

# %% [markdown]
# ## To Do
# - Fine tuning
# - Model validation
