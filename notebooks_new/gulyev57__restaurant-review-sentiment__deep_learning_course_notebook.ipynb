# %% [markdown]
# # Portfolio Note
# Text preprocessing, sentiment analysis, spam classification, named-entity recognition, and text exploration.
#
# This notebook was completed as part of an artificial intelligence course and has been cleaned for portfolio use. Execution outputs, machine-specific paths, and installation cells were removed. Install dependencies from the repository requirements files before running it.

# %% [markdown]
# # NLP with Deep Learning

# %%
import nltk
nltk.download('punkt')
nltk.download('wordnet')
nltk.download('averaged_perceptron_tagger')
nltk.download('brown')

# %%
import pandas as pd
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Input, Dropout

from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer

from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from textblob import TextBlob

# %%
import sys
print(sys.version)

# %%
df = pd.read_csv('../data/yelp.csv')
sns.countplot(x=df['stars'])

# %%
df['text']=df['text'].str.lower() # kucuk harfe cevir
df['text']=df['text'].str.replace('[^\w\s]','', regex=True) # noktolama isaretlerini kaldirir
df['text']=df['text'].str.replace('\d+','', regex=True) # rakamlari kaldirir
df['text']=df['text'].str.replace('\n','', regex=True) # satir sonlarini kaldirir
df['text']=df['text'].str.replace('\r','', regex=True) # enter lari kaldirir

# %%
ybw=df[(df.stars==1)| (df.stars==5)]

# %%
ybw=ybw.reset_index(drop=True)

# %%
x=ybw['text']
y=ybw[['stars']]

# %%
d = {1:0, 5:1}

# %%
y['stars'] = y['stars'].map(d)

# %%
sns.countplot(x=y['stars'])

# %%
def ekkok(text):
    words=TextBlob(text).words
    return [word.lemmatize() for word in words]

# %%
vect=CountVectorizer(stop_words='english', analyzer=ekkok,ngram_range=(1,2))

# %%
x_vect=vect.fit_transform(x).toarray()

# %%
tf=pd.DataFrame(vect.fit_transform(x).toarray(), columns=vect.get_feature_names_out())

# %%
tf

# %%
x_train, x_test, y_train, y_test = train_test_split(x_vect, y, test_size=0.20, random_state=42)

# %%
model=Sequential([
    Dense(256, activation='relu'), # hayal urunu Black box nature of DL
    Dense(128, activation='relu'),
    Dense(64, activation='relu'),
    Dense(32, activation='relu'),
    Dense(1, activation='sigmoid') # classification son layer sigmoid eger 1-0 ise softmax 2 den fazla secenek icin
])
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
model.fit(x_train, y_train, batch_size = 32, validation_data = (x_test, y_test), verbose = 2, epochs = 15)

# %%
model.evaluate(x_test, y_test)

# %%
neg = df[df['stars']==1]['text'].iloc[0]

# %%
pos = df[df['stars']==5]['text'].iloc[0]

# %%
text1 = vect.transform([pos]).toarray()

# %%
text2 = vect.transform([neg]).toarray()

# %%
p1 = model.predict(text1)[0][0].astype('int8')

# %%
int(p1)

# %%
p2 = model.predict(text2)[0][0].astype('int8')

# %%
int(p2)

# %%
label = ['Negative', 'Positive']

# %%
label[p1]

# %%
label[p2]

# %%
model.save('../models/sentiment.keras')

# %%
from keras.models import load_model

# %%
model2 = load_model('../models/sentiment.keras')

# %%
p3 = model2.predict(text1)[0][0].astype('int8')

# %%
int(p3)

# %%
label[p3]

# %% [markdown]
# ## NLP with Neat Text

# %%
import pandas as pd

# %%
df = pd.read_csv('../data/yelp.csv')

# %%
df['text']

# %%
s = ' '.join(df['text'])

# %%
from collections import Counter

# %%
Counter(s.split())

# %%
import neattext.functions as nfx

# %%
s2 = nfx.remove_stopwords(s)

# %%
Counter(s2.split())

# %%
data = Counter(s2.split()).most_common(20) # en çok tekrar eden 20 kelime

# %%
data = dict(data)

# %%
plt.figure(figsize = (12,8))
sns.barplot(x = data.keys(), y = data.values(), hue = data.keys())

# %%
iyi = df[df['stars'] == 5]

# %%
iyic = ' '.join(iyi['text'])

# %%
iyic = nfx.remove_stopwords(iyic)

# %%
data = Counter(iyic.split()).most_common(20)

# %%
data = dict(data)

# %%
plt.figure(figsize = (12,8))
sns.barplot(x = data.keys(), y = data.values(), hue = data.keys())
