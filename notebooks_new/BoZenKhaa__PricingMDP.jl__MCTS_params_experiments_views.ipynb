# %% [markdown]
# PlotlyJS did not run in my main environment. Hence this.

# %%
display("text/html", "<style>.container { width:100% !important; }</style>")
# Out:
# <style>.container { width:100% !important; }</style>

# %%
using Pkg
Pkg.activate(".")
# Out:
#   Activating project at `~/projects/MDPPricing/notebooks/PlotlyJS`

# %%
using DataFrames
using CSV
using PlotlyJS
# Out:
# WebIO._IJuliaInit()

# %%
dataset(DataFrame, "iris");

# %%
res = CSV.File("mcts_params_results.csv") |> DataFrame;
# res = res[1:5, :]

# %%
df = res
x = :exploration_constant
y= :n_iterations 
z= :depth
marker_color = :mean_r
# Out:
# :mean_r

# %%
plot(df, Layout(title = "MCTS parameters",
                margin=attr(l=0, r=0, b=0, t=0), 
                scene = attr(
                    xaxis_title="$(x)",
                    yaxis_title="$(y)",
                    zaxis_title="$(z)"),
                coloraxis=attr(colorscale="Viridis",),
        ),
    x=x, y=y, z=z, marker_color = marker_color, text = marker_color, # text -> adds hover info about value
    type="scatter3d", mode="markers",
    marker = attr(
                size=10,
                colorscale="Viridis",   # choose a colorscale
                opacity=0.8, 
                showscale=true
            )
)
# Out:
# data: [
#   "scatter3d with fields marker, mode, text, type, x, xaxis, y, yaxis, and z"
# ]
#
# layout: "layout with fields coloraxis, legend, margin, scene, template, title, xaxis, and yaxis"
