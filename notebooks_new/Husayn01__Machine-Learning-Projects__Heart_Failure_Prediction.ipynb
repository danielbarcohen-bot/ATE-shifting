# %% [markdown]
# <a href="https://colab.research.google.com/github/Husayn01/Machine-Learning-Projects/blob/main/Heart_Failure_Prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install xgboost
# Out:
# Requirement already satisfied: xgboost in /usr/local/lib/python3.11/dist-packages (3.0.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from xgboost) (2.0.2)
# Requirement already satisfied: nvidia-nccl-cu12 in /usr/local/lib/python3.11/dist-packages (from xgboost) (2.21.5)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from xgboost) (1.15.3)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from xgboost import XGBClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier

# %%
import kagglehub
from kagglehub import KaggleDatasetAdapter

# Set the exact file path inside the dataset
file_path = "heart.csv"  # This is the main CSV file in the dataset

# Load the latest version of the dataset into a pandas DataFrame
df = kagglehub.load_dataset(
    KaggleDatasetAdapter.PANDAS,
    "fedesoriano/heart-failure-prediction",
    file_path,
)
# Out:
# <ipython-input-71-382224603>:8: DeprecationWarning: load_dataset is deprecated and will be removed in a future version.
#   df = kagglehub.load_dataset(

# %%
df.head(3)
# Out:
#    Age Sex ChestPainType  ...  Oldpeak  ST_Slope  HeartDisease
# 0   40   M           ATA  ...      0.0        Up             0
# 1   49   F           NAP  ...      1.0      Flat             1
# 2   37   M           ATA  ...      0.0        Up             0
#
# [3 rows x 12 columns]

# %%
cat_variables = ['Sex', 'ChestPainType', 'RestingECG', 'ExerciseAngina', 'ST_Slope']
num_variables = ['Age', 'RestingBP', 'Cholesterol', 'FastingBS', 'MaxHR', 'Oldpeak']

# %%
# This will replace the columns with the one-hot encoded ones and keep the columns outside 'columns' argument as it is.
df = pd.get_dummies(data = df,
                         prefix = cat_variables,
                         columns = cat_variables,
                    dtype=int
                    )

# %%
df.head(2)
# Out:
#    Age  RestingBP  Cholesterol  ...  ST_Slope_Down  ST_Slope_Flat  ST_Slope_Up
# 0   40        140          289  ...              0              0            1
# 1   49        160          180  ...              0              1            0
#
# [2 rows x 21 columns]

# %%
features = [feature for feature in df.columns if feature != 'HeartDisease']
target = 'HeartDisease'
print(f"Features: {features}\nTarget: {target}")
# Out:
# Features: ['Age', 'RestingBP', 'Cholesterol', 'FastingBS', 'MaxHR', 'Oldpeak', 'Sex_F', 'Sex_M', 'ChestPainType_ASY', 'ChestPainType_ATA', 'ChestPainType_NAP', 'ChestPainType_TA', 'RestingECG_LVH', 'RestingECG_Normal', 'RestingECG_ST', 'ExerciseAngina_N', 'ExerciseAngina_Y', 'ST_Slope_Down', 'ST_Slope_Flat', 'ST_Slope_Up']
# Target: HeartDisease

# %%
x_train, x_test, y_train, y_test = train_test_split(df[features], df[target], train_size=0.8, random_state=42)

# %%
print(f'train samples: {len(x_train)}')
print(f'validation samples: {len(x_test)}')
print(f'target proportion: {sum(y_train)/len(y_train):.4f}')
# Out:
# train samples: 734
# validation samples: 184
# target proportion: 0.5463

# %%
min_samples_split_list = [2,10, 30, 50, 100, 200, 300, 700] ## If the number is an integer, then it is the actual quantity of samples,
max_depth_list = [1,2, 3, 4, 8, 16, 32, 64, None] # None means that there is no depth limit.

# %%
accuracy_list_train = []
accuracy_list_test = []
for min_sample_split in min_samples_split_list:
  model = DecisionTreeClassifier(min_samples_split=min_sample_split)
  model.fit(x_train, y_train)
  pred_train = model.predict(x_train)
  pred_test = model.predict(x_test)
  accuracy_train = accuracy_score(y_train, pred_train)
  accuracy_test = accuracy_score(y_test, pred_test)
  accuracy_list_train.append(accuracy_train)
  accuracy_list_test.append(accuracy_test)

plt.title('Train x Validation metrics')
plt.xlabel('min_samples_split')
plt.ylabel('accuracy')
plt.xticks(ticks = range(len(min_samples_split_list )),labels=min_samples_split_list)
plt.plot(accuracy_list_train)
plt.plot(accuracy_list_test)
plt.legend(['Train','Validation'])

# %%
accuracy_list_train = []
accuracy_list_val = []
for max_depth in max_depth_list:
    # You can fit the model at the same time you define it, because the fit function returns the fitted estimator.
    model = DecisionTreeClassifier(max_depth = max_depth).fit(x_train,y_train)
    predictions_train = model.predict(x_train) ## The predicted values for the train dataset
    predictions_val = model.predict(x_test) ## The predicted values for the test dataset
    accuracy_train = accuracy_score(predictions_train,y_train)
    accuracy_val = accuracy_score(predictions_val,y_test)
    accuracy_list_train.append(accuracy_train)
    accuracy_list_val.append(accuracy_val)

plt.title('Train x Validation metrics')
plt.xlabel('max_depth')
plt.ylabel('accuracy')
plt.xticks(ticks = range(len(max_depth_list )),labels=max_depth_list)
plt.plot(accuracy_list_train)
plt.plot(accuracy_list_val)
plt.legend(['Train','Validation'])

# %%
decision_tree_model = DecisionTreeClassifier(min_samples_split = 50,
                                             max_depth = 3).fit(x_train,y_train)

# %%
print(f"Metrics train:\n\tAccuracy score: {accuracy_score(decision_tree_model.predict(x_train),y_train):.4f}")
print(f"Metrics validation:\n\tAccuracy score: {accuracy_score(decision_tree_model.predict(x_test),y_test):.4f}")
# Out:
# Metrics train:
# 	Accuracy score: 0.8542
# Metrics validation:
# 	Accuracy score: 0.8424

# %%
min_samples_split_list = [2,10, 30, 50, 100, 200, 300, 700]  ## If the number is an integer, then it is the actual quantity of samples,
                                             ## If it is a float, then it is the percentage of the dataset
max_depth_list = [2, 4, 8, 16, 32, 64, None]
n_estimators_list = [10,50,100,500]

# %%
accuracy_list_train = []
accuracy_list_val = []
for min_samples_split in min_samples_split_list:
    # You can fit the model at the same time you define it, because the fit function returns the fitted estimator.
    model = RandomForestClassifier(min_samples_split = min_samples_split).fit(x_train,y_train)
    predictions_train = model.predict(x_train) ## The predicted values for the train dataset
    predictions_val = model.predict(x_test) ## The predicted values for the test dataset
    accuracy_train = accuracy_score(predictions_train,y_train)
    accuracy_val = accuracy_score(predictions_val,y_test)
    accuracy_list_train.append(accuracy_train)
    accuracy_list_val.append(accuracy_val)

plt.title('Train x Validation metrics')
plt.xlabel('min_samples_split')
plt.ylabel('accuracy')
plt.xticks(ticks = range(len(min_samples_split_list )),labels=min_samples_split_list)
plt.plot(accuracy_list_train)
plt.plot(accuracy_list_val)
plt.legend(['Train','Validation'])

# %%
accuracy_list_train = []
accuracy_list_val = []
for max_depth in max_depth_list:
    # You can fit the model at the same time you define it, because the fit function returns the fitted estimator.
    model = RandomForestClassifier(max_depth = max_depth).fit(x_train,y_train)
    predictions_train = model.predict(x_train) ## The predicted values for the train dataset
    predictions_val = model.predict(x_test) ## The predicted values for the test dataset
    accuracy_train = accuracy_score(predictions_train,y_train)
    accuracy_val = accuracy_score(predictions_val,y_test)
    accuracy_list_train.append(accuracy_train)
    accuracy_list_val.append(accuracy_val)

plt.title('Train x Validation metrics')
plt.xlabel('max_depth')
plt.ylabel('accuracy')
plt.xticks(ticks = range(len(max_depth_list )),labels=max_depth_list)
plt.plot(accuracy_list_train)
plt.plot(accuracy_list_val)
plt.legend(['Train','Validation'])

# %%
accuracy_list_train = []
accuracy_list_val = []
for n_estimators in n_estimators_list:
    # You can fit the model at the same time you define it, because the fit function returns the fitted estimator.
    model = RandomForestClassifier(n_estimators = n_estimators).fit(x_train,y_train)
    predictions_train = model.predict(x_train) ## The predicted values for the train dataset
    predictions_val = model.predict(x_test) ## The predicted values for the test dataset
    accuracy_train = accuracy_score(predictions_train,y_train)
    accuracy_val = accuracy_score(predictions_val,y_test)
    accuracy_list_train.append(accuracy_train)
    accuracy_list_val.append(accuracy_val)

plt.title('Train x Validation metrics')
plt.xlabel('n_estimators')
plt.ylabel('accuracy')
plt.xticks(ticks = range(len(n_estimators_list )),labels=n_estimators_list)
plt.plot(accuracy_list_train)
plt.plot(accuracy_list_val)
plt.legend(['Train','Validation'])

# %%
random_forest_model = RandomForestClassifier(n_estimators = 100,
                                             max_depth = 16,
                                             min_samples_split = 10).fit(x_train,y_train)

# %%
print(f"Metrics train:\n\tAccuracy score: {accuracy_score(random_forest_model.predict(x_train),y_train):.4f}\nMetrics test:\n\tAccuracy score: {accuracy_score(random_forest_model.predict(x_test),y_test):.4f}")
# Out:
# Metrics train:
# 	Accuracy score: 0.9264
# Metrics test:
# 	Accuracy score: 0.8696

# %%
n = int(len(x_train)*0.8) ## Let's use 80% to train and 20% to eval

# %%
X_train_fit, X_train_eval, y_train_fit, y_train_eval = x_train[:n], x_train[n:], y_train[:n], y_train[n:]

# %%
xgb_model = XGBClassifier(n_estimators = 500, learning_rate = 0.1,verbosity = 1,)
xgb_model.fit(X_train_fit,y_train_fit, eval_set = [(X_train_eval,y_train_eval)])
# Out:
# [0]	validation_0-logloss:0.65141
# [1]	validation_0-logloss:0.61289
# [2]	validation_0-logloss:0.57971
# [3]	validation_0-logloss:0.55172
# [4]	validation_0-logloss:0.53175
# [5]	validation_0-logloss:0.51401
# [6]	validation_0-logloss:0.49884
# [7]	validation_0-logloss:0.48808
# [8]	validation_0-logloss:0.47906
# [9]	validation_0-logloss:0.47016
# [10]	validation_0-logloss:0.46099
# [11]	validation_0-logloss:0.45347
# [12]	validation_0-logloss:0.44867
# [13]	validation_0-logloss:0.44370
# [14]	validation_0-logloss:0.44137
# [15]	validation_0-logloss:0.43769
# [16]	validation_0-logloss:0.43645
# [17]	validation_0-logloss:0.43211
# [18]	validation_0-logloss:0.43149
# [19]	validation_0-logloss:0.42899
# [20]	validation_0-logloss:0.42878
# [21]	validation_0-logloss:0.42753
# [22]	validation_0-logloss:0.42596
# [23]	validation_0-logloss:0.42669
# [24]	validation_0-logloss:0.42381
# [25]	validation_0-logloss:0.42547
# [26]	validation_0-logloss:0.42418
# [27]	validation_0-logloss:0.42022
# [28]	validation_0-logloss:0.41854
# [29]	validation_0-logloss:0.41675
# [30]	validation_0-logloss:0.41670
# [31]	validation_0-logloss:0.41677
# [32]	validation_0-logloss:0.41277
# [33]	validation_0-logloss:0.40988
# [34]	validation_0-logloss:0.41156
# [35]	validation_0-logloss:0.41340
# [36]	validation_0-logloss:0.41410
# [37]	validation_0-logloss:0.41552
# [38]	validation_0-logloss:0.41682
# [39]	validation_0-logloss:0.41785
# [40]	validation_0-logloss:0.41901
# [41]	validation_0-logloss:0.41970
# [42]	validation_0-logloss:0.41873
# [43]	validation_0-logloss:0.42194
# [44]	validation_0-logloss:0.42288
# [45]	validation_0-logloss:0.42421
# [46]	validation_0-logloss:0.42330
# [47]	validation_0-logloss:0.42464
# [48]	validation_0-logloss:0.42822
# [49]	validation_0-logloss:0.42608
# [50]	validation_0-logloss:0.42758
# [51]	validation_0-logloss:0.42673
# [52]	validation_0-logloss:0.42384
# [53]	validation_0-logloss:0.42437
# [54]	validation_0-logloss:0.42709
# [55]	validation_0-logloss:0.42934
# [56]	validation_0-logloss:0.42927
# [57]	validation_0-logloss:0.42989
# [58]	validation_0-logloss:0.43053
# [59]	validation_0-logloss:0.43157
# [60]	validation_0-logloss:0.43091
# [61]	validation_0-logloss:0.43255
# [62]	validation_0-logloss:0.43555
# [63]	validation_0-logloss:0.43652
# [64]	validation_0-logloss:0.43734
# [65]	validation_0-logloss:0.43945
# [66]	validation_0-logloss:0.44028
# [67]	validation_0-logloss:0.43955
# [68]	validation_0-logloss:0.43831
# [69]	validation_0-logloss:0.43907
# [70]	validation_0-logloss:0.44123
# [71]	validation_0-logloss:0.44247
# [72]	validation_0-logloss:0.44215
# [73]	validation_0-logloss:0.44429
# [74]	validation_0-logloss:0.44493
# [75]	validation_0-logloss:0.44361
# [76]	validation_0-logloss:0.44365
# [77]	validation_0-logloss:0.44449
# [78]	validation_0-logloss:0.44632
# [79]	validation_0-logloss:0.44498
# [80]	validation_0-logloss:0.44371
# [81]	validation_0-logloss:0.44337
# [82]	validation_0-logloss:0.44506
# [83]	validation_0-logloss:0.44367
# [84]	validation_0-logloss:0.44569
# [85]	validation_0-logloss:0.44447
# [86]	validation_0-logloss:0.44341
# [87]	validation_0-logloss:0.44389
# [88]	validation_0-logloss:0.44558
# [89]	validation_0-logloss:0.44729
# [90]	validation_0-logloss:0.44755
# [91]	validation_0-logloss:0.44881
# [92]	validation_0-logloss:0.45091
# [93]	validation_0-logloss:0.44963
# [94]	validation_0-logloss:0.45149
# [95]	validation_0-logloss:0.45290
# [96]	validation_0-logloss:0.45418
# [97]	validation_0-logloss:0.45553
# [98]	validation_0-logloss:0.45734
# [99]	validation_0-logloss:0.45887
# [100]	validation_0-logloss:0.45939
# [101]	validation_0-logloss:0.45875
# [102]	validation_0-logloss:0.45961
# [103]	validation_0-logloss:0.46057
# [104]	validation_0-logloss:0.46087
# [105]	validation_0-logloss:0.46203
# [106]	validation_0-logloss:0.46228
# [107]	validation_0-logloss:0.46297
# [108]	validation_0-logloss:0.46165
# [109]	validation_0-logloss:0.46329
# [110]	validation_0-logloss:0.46436
# [111]	validation_0-logloss:0.46530
# [112]	validation_0-logloss:0.46696
# [113]	validation_0-logloss:0.46602
# [114]	validation_0-logloss:0.46523
# [115]	validation_0-logloss:0.46459
# [116]	validation_0-logloss:0.46459
# [117]	validation_0-logloss:0.46491
# [118]	validation_0-logloss:0.46505
# [119]	validation_0-logloss:0.46675
# [120]	validation_0-logloss:0.46787
# [121]	validation_0-logloss:0.46810
# [122]	validation_0-logloss:0.46690
# [123]	validation_0-logloss:0.46746
# [124]	validation_0-logloss:0.46697
# [125]	validation_0-logloss:0.46773
# [126]	validation_0-logloss:0.46873
# [127]	validation_0-logloss:0.46992
# [128]	validation_0-logloss:0.47086
# [129]	validation_0-logloss:0.47114
# [130]	validation_0-logloss:0.47215
# [131]	validation_0-logloss:0.47305
# [132]	validation_0-logloss:0.47339
# [133]	validation_0-logloss:0.47326
# [134]	validation_0-logloss:0.47418
# [135]	validation_0-logloss:0.47475
# [136]	validation_0-logloss:0.47573
# [137]	validation_0-logloss:0.47651
# [138]	validation_0-logloss:0.47777
# [139]	validation_0-logloss:0.47815
# [140]	validation_0-logloss:0.47900
# [141]	validation_0-logloss:0.47880
# [142]	validation_0-logloss:0.47976
# [143]	validation_0-logloss:0.48164
# [144]	validation_0-logloss:0.48048
# [145]	validation_0-logloss:0.48291
# [146]	validation_0-logloss:0.48287
# [147]	validation_0-logloss:0.48133
# [148]	validation_0-logloss:0.48202
# [149]	validation_0-logloss:0.48077
# [150]	validation_0-logloss:0.48112
# [151]	validation_0-logloss:0.48186
# [152]	validation_0-logloss:0.48289
# [153]	validation_0-logloss:0.48370
# [154]	validation_0-logloss:0.48399
# [155]	validation_0-logloss:0.48538
# [156]	validation_0-logloss:0.48509
# [157]	validation_0-logloss:0.48459
# [158]	validation_0-logloss:0.48586
# [159]	validation_0-logloss:0.48814
# [160]	validation_0-logloss:0.48796
# [161]	validation_0-logloss:0.48941
# [162]	validation_0-logloss:0.49112
# [163]	validation_0-logloss:0.49206
# [164]	validation_0-logloss:0.49187
# [165]	validation_0-logloss:0.49192
# [166]	validation_0-logloss:0.49293
# [167]	validation_0-logloss:0.49381
# [168]	validation_0-logloss:0.49412
# [169]	validation_0-logloss:0.49553
# [170]	validation_0-logloss:0.49551
# [171]	validation_0-logloss:0.49506
# [172]	validation_0-logloss:0.49527
# [173]	validation_0-logloss:0.49638
# [174]	validation_0-logloss:0.49757
# [175]	validation_0-logloss:0.49720
# [176]	validation_0-logloss:0.49817
# [177]	validation_0-logloss:0.49839
# [178]	validation_0-logloss:0.49674
# [179]	validation_0-logloss:0.49652
# [180]	validation_0-logloss:0.49781
# [181]	validation_0-logloss:0.49738
# [182]	validation_0-logloss:0.49779
# [183]	validation_0-logloss:0.49773
# [184]	validation_0-logloss:0.49859
# [185]	validation_0-logloss:0.49935
# [186]	validation_0-logloss:0.50064
# [187]	validation_0-logloss:0.50044
# [188]	validation_0-logloss:0.49939
# [189]	validation_0-logloss:0.50058
# [190]	validation_0-logloss:0.50192
# [191]	validation_0-logloss:0.50141
# [192]	validation_0-logloss:0.50182
# [193]	validation_0-logloss:0.50234
# [194]	validation_0-logloss:0.50330
# [195]	validation_0-logloss:0.50418
# [196]	validation_0-logloss:0.50374
# [197]	validation_0-logloss:0.50457
# [198]	validation_0-logloss:0.50428
# [199]	validation_0-logloss:0.50471
# [200]	validation_0-logloss:0.50491
# [201]	validation_0-logloss:0.50421
# [202]	validation_0-logloss:0.50388
# [203]	validation_0-logloss:0.50363
# [204]	validation_0-logloss:0.50409
# [205]	validation_0-logloss:0.50499
# [206]	validation_0-logloss:0.50551
# [207]	validation_0-logloss:0.50549
# [208]	validation_0-logloss:0.50595
# [209]	validation_0-logloss:0.50583
# [210]	validation_0-logloss:0.50594
# [211]	validation_0-logloss:0.50577
# [212]	validation_0-logloss:0.50553
# [213]	validation_0-logloss:0.50539
# [214]	validation_0-logloss:0.50581
# [215]	validation_0-logloss:0.50547
# [216]	validation_0-logloss:0.50539
# [217]	validation_0-logloss:0.50489
# [218]	validation_0-logloss:0.50651
# [219]	validation_0-logloss:0.50745
# [220]	validation_0-logloss:0.50842
# [221]	validation_0-logloss:0.50786
# [222]	validation_0-logloss:0.50873
# [223]	validation_0-logloss:0.50892
# [224]	validation_0-logloss:0.50975
# [225]	validation_0-logloss:0.51064
# [226]	validation_0-logloss:0.51118
# [227]	validation_0-logloss:0.51112
# [228]	validation_0-logloss:0.51244
# [229]	validation_0-logloss:0.51294
# [230]	validation_0-logloss:0.51251
# [231]	validation_0-logloss:0.51214
# [232]	validation_0-logloss:0.51337
# [233]	validation_0-logloss:0.51348
# [234]	validation_0-logloss:0.51323
# [235]	validation_0-logloss:0.51307
# [236]	validation_0-logloss:0.51312
# [237]	validation_0-logloss:0.51432
# [238]	validation_0-logloss:0.51483
# [239]	validation_0-logloss:0.51481
# [240]	validation_0-logloss:0.51485
# [241]	validation_0-logloss:0.51503
# [242]	validation_0-logloss:0.51563
# [243]	validation_0-logloss:0.51527
# [244]	validation_0-logloss:0.51496
# [245]	validation_0-logloss:0.51615
# [246]	validation_0-logloss:0.51626
# [247]	validation_0-logloss:0.51618
# [248]	validation_0-logloss:0.51731
# [249]	validation_0-logloss:0.51814
# [250]	validation_0-logloss:0.51764
# [251]	validation_0-logloss:0.51731
# [252]	validation_0-logloss:0.51723
# [253]	validation_0-logloss:0.51738
# [254]	validation_0-logloss:0.51758
# [255]	validation_0-logloss:0.51773
# [256]	validation_0-logloss:0.51824
# [257]	validation_0-logloss:0.51784
# [258]	validation_0-logloss:0.51840
# [259]	validation_0-logloss:0.51812
# [260]	validation_0-logloss:0.52017
# [261]	validation_0-logloss:0.52046
# [262]	validation_0-logloss:0.52243
# [263]	validation_0-logloss:0.52286
# [264]	validation_0-logloss:0.52249
# [265]	validation_0-logloss:0.52272
# [266]	validation_0-logloss:0.52155
# [267]	validation_0-logloss:0.52142
# [268]	validation_0-logloss:0.52160
# [269]	validation_0-logloss:0.52204
# [270]	validation_0-logloss:0.52153
# [271]	validation_0-logloss:0.52282
# [272]	validation_0-logloss:0.52305
# [273]	validation_0-logloss:0.52347
# [274]	validation_0-logloss:0.52310
# [275]	validation_0-logloss:0.52359
# [276]	validation_0-logloss:0.52369
# [277]	validation_0-logloss:0.52540
# [278]	validation_0-logloss:0.52618
# [279]	validation_0-logloss:0.52627
# [280]	validation_0-logloss:0.52633
# [281]	validation_0-logloss:0.52710
# [282]	validation_0-logloss:0.52684
# [283]	validation_0-logloss:0.52727
# [284]	validation_0-logloss:0.52704
# [285]	validation_0-logloss:0.52688
# [286]	validation_0-logloss:0.52744
# [287]	validation_0-logloss:0.52772
# [288]	validation_0-logloss:0.52844
# [289]	validation_0-logloss:0.52846
# [290]	validation_0-logloss:0.52949
# [291]	validation_0-logloss:0.53011
# [292]	validation_0-logloss:0.52969
# [293]	validation_0-logloss:0.52976
# [294]	validation_0-logloss:0.52929
# [295]	validation_0-logloss:0.52947
# [296]	validation_0-logloss:0.52957
# [297]	validation_0-logloss:0.52990
# [298]	validation_0-logloss:0.52972
# [299]	validation_0-logloss:0.53025
# [300]	validation_0-logloss:0.52931
# [301]	validation_0-logloss:0.52918
# [302]	validation_0-logloss:0.52956
# [303]	validation_0-logloss:0.52921
# [304]	validation_0-logloss:0.52914
# [305]	validation_0-logloss:0.52915
# [306]	validation_0-logloss:0.52941
# [307]	validation_0-logloss:0.53013
# [308]	validation_0-logloss:0.53036
# [309]	validation_0-logloss:0.53103
# [310]	validation_0-logloss:0.53116
# [311]	validation_0-logloss:0.53149
# [312]	validation_0-logloss:0.53234
# [313]	validation_0-logloss:0.53340
# [314]	validation_0-logloss:0.53352
# [315]	validation_0-logloss:0.53383
# [316]	validation_0-logloss:0.53341
# [317]	validation_0-logloss:0.53349
# [318]	validation_0-logloss:0.53362
# [319]	validation_0-logloss:0.53415
# [320]	validation_0-logloss:0.53454
# [321]	validation_0-logloss:0.53381
# [322]	validation_0-logloss:0.53382
# [323]	validation_0-logloss:0.53441
# [324]	validation_0-logloss:0.53519
# [325]	validation_0-logloss:0.53576
# [326]	validation_0-logloss:0.53612
# [327]	validation_0-logloss:0.53623
# [328]	validation_0-logloss:0.53669
# [329]	validation_0-logloss:0.53694
# [330]	validation_0-logloss:0.53681
# [331]	validation_0-logloss:0.53654
# [332]	validation_0-logloss:0.53636
# [333]	validation_0-logloss:0.53702
# [334]	validation_0-logloss:0.53722
# [335]	validation_0-logloss:0.53644
# [336]	validation_0-logloss:0.53574
# [337]	validation_0-logloss:0.53592
# [338]	validation_0-logloss:0.53616
# [339]	validation_0-logloss:0.53678
# [340]	validation_0-logloss:0.53678
# [341]	validation_0-logloss:0.53670
# [342]	validation_0-logloss:0.53672
# [343]	validation_0-logloss:0.53729
# [344]	validation_0-logloss:0.53699
# [345]	validation_0-logloss:0.53737
# [346]	validation_0-logloss:0.53794
# [347]	validation_0-logloss:0.53872
# [348]	validation_0-logloss:0.53870
# [349]	validation_0-logloss:0.53950
# [350]	validation_0-logloss:0.53954
# [351]	validation_0-logloss:0.54000
# [352]	validation_0-logloss:0.54040
# [353]	validation_0-logloss:0.54069
# [354]	validation_0-logloss:0.54128
# [355]	validation_0-logloss:0.54205
# [356]	validation_0-logloss:0.54244
# [357]	validation_0-logloss:0.54251
# [358]	validation_0-logloss:0.54296
# [359]	validation_0-logloss:0.54324
# [360]	validation_0-logloss:0.54401
# [361]	validation_0-logloss:0.54351
# [362]	validation_0-logloss:0.54383
# [363]	validation_0-logloss:0.54399
# [364]	validation_0-logloss:0.54448
# [365]	validation_0-logloss:0.54473
# [366]	validation_0-logloss:0.54488
# [367]	validation_0-logloss:0.54551
# [368]	validation_0-logloss:0.54581
# [369]	validation_0-logloss:0.54570
# [370]	validation_0-logloss:0.54626
# [371]	validation_0-logloss:0.54590
# [372]	validation_0-logloss:0.54542
# [373]	validation_0-logloss:0.54558
# [374]	validation_0-logloss:0.54621
# [375]	validation_0-logloss:0.54661
# [376]	validation_0-logloss:0.54704
# [377]	validation_0-logloss:0.54719
# [378]	validation_0-logloss:0.54770
# [379]	validation_0-logloss:0.54745
# [380]	validation_0-logloss:0.54794
# [381]	validation_0-logloss:0.54895
# [382]	validation_0-logloss:0.54919
# [383]	validation_0-logloss:0.54882
# [384]	validation_0-logloss:0.54921
# [385]	validation_0-logloss:0.54959
# [386]	validation_0-logloss:0.54923
# [387]	validation_0-logloss:0.55001
# [388]	validation_0-logloss:0.55031
# [389]	validation_0-logloss:0.55019
# [390]	validation_0-logloss:0.55071
# [391]	validation_0-logloss:0.55105
# [392]	validation_0-logloss:0.55114
# [393]	validation_0-logloss:0.55124
# [394]	validation_0-logloss:0.55119
# [395]	validation_0-logloss:0.55172
# [396]	validation_0-logloss:0.55171
# [397]	validation_0-logloss:0.55206
# [398]	validation_0-logloss:0.55235
# [399]	validation_0-logloss:0.55264
# [400]	validation_0-logloss:0.55305
# [401]	validation_0-logloss:0.55269
# [402]	validation_0-logloss:0.55297
# [403]	validation_0-logloss:0.55303
# [404]	validation_0-logloss:0.55330
# [405]	validation_0-logloss:0.55423
# [406]	validation_0-logloss:0.55431
# [407]	validation_0-logloss:0.55486
# [408]	validation_0-logloss:0.55475
# [409]	validation_0-logloss:0.55445
# [410]	validation_0-logloss:0.55416
# [411]	validation_0-logloss:0.55437
# [412]	validation_0-logloss:0.55453
# [413]	validation_0-logloss:0.55462
# [414]	validation_0-logloss:0.55452
# [415]	validation_0-logloss:0.55431
# [416]	validation_0-logloss:0.55402
# [417]	validation_0-logloss:0.55439
# [418]	validation_0-logloss:0.55454
# [419]	validation_0-logloss:0.55494
# [420]	validation_0-logloss:0.55513
# [421]	validation_0-logloss:0.55509
# [422]	validation_0-logloss:0.55499
# [423]	validation_0-logloss:0.55478
# [424]	validation_0-logloss:0.55496
# [425]	validation_0-logloss:0.55508
# [426]	validation_0-logloss:0.55516
# [427]	validation_0-logloss:0.55567
# [428]	validation_0-logloss:0.55582
# [429]	validation_0-logloss:0.55595
# [430]	validation_0-logloss:0.55617
# [431]	validation_0-logloss:0.55619
# [432]	validation_0-logloss:0.55658
# [433]	validation_0-logloss:0.55681
# [434]	validation_0-logloss:0.55765
# [435]	validation_0-logloss:0.55817
# [436]	validation_0-logloss:0.55851
# [437]	validation_0-logloss:0.55824
# [438]	validation_0-logloss:0.55850
# [439]	validation_0-logloss:0.55853
# [440]	validation_0-logloss:0.55921
# [441]	validation_0-logloss:0.55927
# [442]	validation_0-logloss:0.55942
# [443]	validation_0-logloss:0.55917
# [444]	validation_0-logloss:0.55958
# [445]	validation_0-logloss:0.55994
# [446]	validation_0-logloss:0.56000
# [447]	validation_0-logloss:0.56003
# [448]	validation_0-logloss:0.56069
# [449]	validation_0-logloss:0.56067
# [450]	validation_0-logloss:0.56039
# [451]	validation_0-logloss:0.56000
# [452]	validation_0-logloss:0.56075
# [453]	validation_0-logloss:0.56106
# [454]	validation_0-logloss:0.56078
# [455]	validation_0-logloss:0.56104
# [456]	validation_0-logloss:0.56130
# [457]	validation_0-logloss:0.56126
# [458]	validation_0-logloss:0.56112
# [459]	validation_0-logloss:0.56148
# [460]	validation_0-logloss:0.56161
# [461]	validation_0-logloss:0.56227
# [462]	validation_0-logloss:0.56271
# [463]	validation_0-logloss:0.56352
# [464]	validation_0-logloss:0.56387
# [465]	validation_0-logloss:0.56411
# [466]	validation_0-logloss:0.56424
# [467]	validation_0-logloss:0.56420
# [468]	validation_0-logloss:0.56395
# [469]	validation_0-logloss:0.56410
# [470]	validation_0-logloss:0.56375
# [471]	validation_0-logloss:0.56401
# [472]	validation_0-logloss:0.56431
# [473]	validation_0-logloss:0.56453
# [474]	validation_0-logloss:0.56467
# [475]	validation_0-logloss:0.56464
# [476]	validation_0-logloss:0.56446
# [477]	validation_0-logloss:0.56461
# [478]	validation_0-logloss:0.56473
# [479]	validation_0-logloss:0.56488
# [480]	validation_0-logloss:0.56487
# [481]	validation_0-logloss:0.56477
# [482]	validation_0-logloss:0.56466
# [483]	validation_0-logloss:0.56462
# [484]	validation_0-logloss:0.56452
# [485]	validation_0-logloss:0.56464
# [486]	validation_0-logloss:0.56474
# [487]	validation_0-logloss:0.56466
# [488]	validation_0-logloss:0.56488
# [489]	validation_0-logloss:0.56498
# [490]	validation_0-logloss:0.56484
# [491]	validation_0-logloss:0.56499
# [492]	validation_0-logloss:0.56510
# [493]	validation_0-logloss:0.56476
# [494]	validation_0-logloss:0.56468
# [495]	validation_0-logloss:0.56395
# [496]	validation_0-logloss:0.56359
# [497]	validation_0-logloss:0.56385
# [498]	validation_0-logloss:0.56360
# [499]	validation_0-logloss:0.56381
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.1, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=500, n_jobs=None,
#               num_parallel_tree=None, random_state=None, ...)

# %%
pred = xgb_model.predict(x_test)
test_accuracy = accuracy_score(pred,y_test)
test_accuracy
# Out:
# 0.8695652173913043
