# %% [markdown]
# <a href="https://colab.research.google.com/github/Intina47/ALGORITHMS_ARCHIVE/blob/main/who.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import tensorflow as tf
import io
from sklearn.preprocessing import OneHotEncoder

# %% [markdown]
# DATA PREPARATION

# %%
# Load the dataset from a file
file_path = 'Common_Surnames_Census_2000.csv'
df = pd.read_csv(file_path, delimiter=',')

# Extract the names column
names = df['name'].tolist()

# Example: Print the extracted names
print(names[:6])
# Out:
# ['SMITH', 'JOHNSON', 'WILLIAMS', 'BROWN', 'JONES', 'MILLER']

# %% [markdown]
# DATA ENCODING

# %%
#one-hot encoding on the names
encoder = OneHotEncoder(sparse_output=False)
names_encoded = encoder.fit_transform(pd.DataFrame(names))
print(names_encoded.shape)
# Out:
# (151671, 151671)
