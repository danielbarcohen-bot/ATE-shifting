# %% [markdown]
# <a href="https://colab.research.google.com/github/Raffikusuma/Data-Mining/blob/main/Data_Messy_tip.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **1. Import Libraries**

# %%
import pandas as pd

# %%
# Langkah 1: Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # **2. Baca Dataset tip yang kotor**

# %%
# Baca file .xlsx
file_path = '/content/drive/My Drive/Data Mining/tip.csv'
df = pd.read_csv(file_path)

# %%
# Tampilkan data
print(df)
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %% [markdown]
# # 3. Menampilkan Struktur Data

# %%
# Menampilkan struktur data
print("Struktur Data tip.csv:")
df.info()
# Out:
# Struktur Data tip.csv:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    object
#  3   smoker      244 non-null    object
#  4   day         244 non-null    object
#  5   time        244 non-null    object
#  6   size        244 non-null    int64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 13.5+ KB

# %% [markdown]
# # 4.Cleansing colom Hari

# %% [markdown]
# mengubah nama hari dari singkatan menjadi full nama

# %%
# Mapping singkatan hari ke nama lengkap
day_mapping = {
    "Sun": "Sunday",
    "Sat": "Saturday",
    "Thur": "Thursday",
    "Fri": "Friday"
}

# %%
# 4. Ubah kolom 'day'
df['day'] = df['day'].replace(day_mapping)

# %% [markdown]
# Hasil Data colom Hari setelah Di cleansing

# %%
print(df.head(10))
# Out:
#    total_bill   tip     sex smoker     day    time  size
# 0       16.99  1.01  Female     No  Sunday  Dinner     2
# 1       10.34  1.66    Male     No  Sunday  Dinner     3
# 2       21.01  3.50    Male     No  Sunday  Dinner     3
# 3       23.68  3.31    Male     No  Sunday  Dinner     2
# 4       24.59  3.61  Female     No  Sunday  Dinner     4
# 5       25.29  4.71    Male     No  Sunday  Dinner     4
# 6        8.77  2.00    Male     No  Sunday  Dinner     2
# 7       26.88  3.12    Male     No  Sunday  Dinner     4
# 8       15.04  1.96    Male     No  Sunday  Dinner     2
# 9       14.78  3.23    Male     No  Sunday  Dinner     2

# %% [markdown]
# # 5. Cleansing Data Colom Total Bill

# %%
# Urutkan berdasarkan total_bill dari yang termurah
df_sorted = df.sort_values(by='total_bill', ascending=True)

# %%
# Tampilkan hasil urutan
print(df_sorted.head(20))
# Out:
#      total_bill   tip     sex smoker       day    time  size
# 67         3.07  1.00  Female    Yes  Saturday  Dinner     1
# 92         5.75  1.00  Female    Yes    Friday  Dinner     2
# 111        7.25  1.00  Female     No  Saturday  Dinner     1
# 172        7.25  5.15    Male    Yes    Sunday  Dinner     2
# 149        7.51  2.00    Male     No  Thursday   Lunch     2
# 195        7.56  1.44    Male     No  Thursday   Lunch     2
# 218        7.74  1.44    Male    Yes  Saturday  Dinner     2
# 145        8.35  1.50  Female     No  Thursday   Lunch     2
# 135        8.51  1.25  Female     No  Thursday   Lunch     2
# 126        8.52  1.48    Male     No  Thursday   Lunch     2
# 222        8.58  1.92    Male    Yes    Friday   Lunch     1
# 6          8.77  2.00    Male     No    Sunday  Dinner     2
# 30         9.55  1.45    Male     No  Saturday  Dinner     2
# 178        9.60  4.00  Female    Yes    Sunday  Dinner     2
# ...

# %% [markdown]
# # Kesimpulan

# %% [markdown]
# 1.   Cleansing Data Hari
#
#
# *   Kolom day yang sebelumnya masih menggunakan singkatan (Sun, Sat, Fri, Thur) berhasil diubah menjadi nama lengkap (Sunday, Saturday, Friday, Thursday).
# *   Hal ini membuat data lebih jelas, mudah dipahami, dan konsisten untuk analisis lebih lanjut.
#
#
# 2.   Pengurutan Data
#
# *   Dataset berhasil diurutkan berdasarkan kolom total_bill dari yang termurah ke termahal.
# *   Dengan pengurutan ini, kita bisa mengetahui pelanggan dengan tagihan terkecil hingga terbesar, sehingga memudahkan analisis pola pengeluaran.
