# %%
import os

# %%
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  'data.txt',
#  'jupyter_notebook.py',
#  'main.py',
#  'pandas_playground.py',
#  'practice.ipynb',
#  'section_notes.py',
#  'supermarkets-commas.txt',
#  'supermarkets-semi-colons.txt',
#  'supermarkets.json',
#  'supermarkets_csv.csv',
#  'supermarkets_xlsx.xlsx',
#  'Testing Jupyter.ipynb']

# %%
import pandas

# %%
# load file supermarkets.csv
df_csv = pandas.read_csv("supermarkets_csv.csv")

# display the file
df_csv
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
read_json = pandas.read_json("supermarkets.json")
read_json
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
# read excel files
read_excel = pandas.read_excel("supermarkets_xlsx.xlsx")
read_excel
# Out:
#    ID          Address           City             State Country  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA
# 1   2   735 Dolores St  San Francisco          CA 94119     USA
# 2   3      332 Hill St  San Francisco  California 94114     USA
# 3   4     3995 23rd St  San Francisco          CA 94114     USA
# 4   5  1056 Sanchez St  San Francisco        California     USA
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA
#
#   Supermarket Name  Number of Employees
# 0          Madeira                    8
# 1      Bready Shop                   15
# 2      Super River                   25
# 3       Ben's Shop                   10
# 4          Sanchez                   12
# 5       Richvalley                   20

# %%
read_excel2 = pandas.read_excel('supermarkets_xlsx.xlsx', sheet_name=0)
read_excel2
# Out:
#    ID          Address           City             State Country  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA
# 1   2   735 Dolores St  San Francisco          CA 94119     USA
# 2   3      332 Hill St  San Francisco  California 94114     USA
# 3   4     3995 23rd St  San Francisco          CA 94114     USA
# 4   5  1056 Sanchez St  San Francisco        California     USA
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA
#
#   Supermarket Name  Number of Employees
# 0          Madeira                    8
# 1      Bready Shop                   15
# 2      Super River                   25
# 3       Ben's Shop                   10
# 4          Sanchez                   12
# 5       Richvalley                   20

# %%
# txt files uses .read_csv() method
read_txt = pandas.read_csv("supermarkets-commas.txt") 
read_txt
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
# in semi-colons seperated files, we should use the keyword
read_semi_colon = pandas.read_csv("supermarkets-semi-colons.txt", sep=';')
read_semi_colon
# Out:
#    ID          Address           City             State Country          Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA       Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA   Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA   Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA    Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA       Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA    Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
# we use keyword header=None in case the file has no header, or
# else the first record will be treated as the file header.
no_header = pandas.read_csv('data.txt', header=None)


# or, we could manually assigning header to columns without headers
data = pandas.read_csv('data.txt')
data.columns = ['ID', 'Address', 'City', 'Zip', 'Country', 'Cust', 'Emp']

data
# Out:
#    ID          Address           City               Zip Country         Cust  \
# 0   1   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 1   2      332 Hill St  San Francisco  California 94114     USA  Super River
# 2   3     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 3   4  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 4   5  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Emp
# 0   15
# 1   25
# 2   10
# 3   12
# 4   20

# %%
data.set_index('ID')
data
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_13656/1563296504.py in <module>
# ----> 1 data.set_index('ID')
#       2 data
#
# E:\Users\USER10\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# E:\Users\USER10\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\frame.py in set_index(self, keys, drop, append, inplace, verify_integrity)
#    5444
#    5445         if missing:
# -> 5446             raise KeyError(f"None of {missing} are in the columns")
#    5447
#    5448         if inplace:
#
# KeyError: "None of ['ID'] are in the columns"

# %%
data
# Out:
#    ID          Address           City               Zip Country         Cust  \
# 0   1   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 1   2      332 Hill St  San Francisco  California 94114     USA  Super River
# 2   3     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 3   4  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 4   5  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Emp
# 0   15
# 1   25
# 2   10
# 3   12
# 4   20

# %%
# filtering data using labeling

# accessing a range of rows:
data.loc[1: 2, "ID": "City"]
# Out:
#    ID       Address           City
# 1   2   332 Hill St  San Francisco
# 2   3  3995 23rd St  San Francisco

# %%
# accessing a single row 
data.loc[0, "ID": "Emp"]
# Out:
# ID                      1
# Address    735 Dolores St
# City        San Francisco
# Zip              CA 94119
# Country               USA
# Cust          Bready Shop
# Emp                    15
# Name: 0, dtype: object

# %%
# give me a list of all our customers in the data.txt
customers = data.loc[:,"Cust"]
customers_list = list(customers)
customers_list
# Out:
# ['Bready Shop', 'Super River', "Ben's Shop", 'Sanchez', 'Richvalley']

# %%
data
# Out:
#    ID          Address           City               Zip Country         Cust  \
# 0   1   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 1   2      332 Hill St  San Francisco  California 94114     USA  Super River
# 2   3     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 3   4  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 4   5  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Emp
# 0   15
# 1   25
# 2   10
# 3   12
# 4   20

# %%
# filter data using indexing:

# get me the first three row, but exclude the Emp column from data.txt

data.iloc[0:3 , 0:-1]
# Out:
#    ID         Address           City               Zip Country         Cust
# 0   1  735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 1   2     332 Hill St  San Francisco  California 94114     USA  Super River
# 2   3    3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
