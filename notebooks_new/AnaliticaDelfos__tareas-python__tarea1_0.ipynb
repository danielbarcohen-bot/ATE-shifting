# %%
#
#
# EJECUTAR ESTA CELDA CADA VEZ QUE ENTRES A HACER LA TAREA
#
#

#####################################
#  Operaciones aritméticas parte 1
#####################################


import calificador
from controlador import Controlador

# %%
@Controlador("1", "ejercicio_1")
def ejercicio_1(numero):
    """
    Instrucciones:
        La función "ejercicio_1" toma el parámetro 
        "numero", y  debe regresar el resultado de
        la resta de este parámetro menos 30.
    
    Ejemplo:
        Para un caso en el que numero = 100 la función 
        regresa un 70:
        100 - 30 = 70

    Recuerda:
        Lo que la función "regresa" es justo lo que
        va después de la palabra reservada "return".
        
        Cuida la indentación.
    
    """

    # Escribe aquí tu código ↓
    

    # Escribe aquí tu código ↑
    
    return # ← Escribe aquí tu código

# %%
ejercicio_1(60)
# Out:
# 30

# %%
calificador.califica_ejercicio_1(ejercicio_1)
# Out:
# ===============================================================================
#
# ============> Calificando: tarea 1 - ejercicio ejercicio_1 <============
#
# ===============================================================================
#
#
# ======================================================
#             ||          Calificación: 100.0
#             ||          Aciertos: 3
#             ||          Errores: 0
# ======================================================
#
# ======> Casos existosos: <======
#
#  Valores de entrada: 1.              Valor esperado: -29.              Valor obtenido: -29
#
#  Valores de entrada: -1.              Valor esperado: -31.              Valor obtenido: -31
#
#  Valores de entrada: 0.              Valor esperado: -30.              Valor obtenido: -30
#
# ======> No hubo errores :D <======
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# File c:\Users\Paola Soria\miniconda3\lib\site-packages\urllib3\connection.py:174, in HTTPConnection._new_conn(self)
#     173 try:
# --> 174     conn = connection.create_connection(
#     175         (self._dns_host, self.port), self.timeout, **extra_kw
#     176     )
#     178 except SocketTimeout:
#
# File c:\Users\Paola Soria\miniconda3\lib\site-packages\urllib3\util\connection.py:95, in create_connection(address, timeout, source_address, socket_options)
#      94 if err is not None:
# ---> 95     raise err
#      97 raise socket.error("getaddrinfo returns an empty list")
#
# File c:\Users\Paola Soria\miniconda3\lib\site-packages\urllib3\util\connection.py:85, in create_connection(address, timeout, source_address, socket_options)
#      84     sock.bind(source_address)
# ---> 85 sock.connect(sa)
#      86 return sock
#
# ConnectionRefusedError: [WinError 10061] No se puede establecer una conexión ya que el equipo de destino denegó expresamente dicha conexión
#
# During handling of the above exception, another exception occurred:
#
# NewConnectionError                        Traceback (most recent call last)
# File c:\Users\Paola Soria\miniconda3\lib\site-packages\urllib3\connectionpool.py:703, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     702 # Make the request on the httplib connection object.
# --> 703 httplib_response = self._make_request(
#     704     conn,
#     705     method,
#     706     url,
#     707     timeout=timeout_obj,
#     708     body=body,
#     709     headers=headers,
#     710     chunked=chunked,
#     711 )
#     713 # If we're going to release the connection in ``finally:``, then
#     714 # the response doesn't need to know about the connection. Otherwise
#     715 # it will also try to release it and we'll have a double-release
#     716 # mess.
#
# File c:\Users\Paola Soria\miniconda3\lib\site-packages\urllib3\connectionpool.py:398, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     397     else:
# --> 398         conn.request(method, url, **httplib_request_kw)
#     400 # We are swallowing BrokenPipeError (errno.EPIPE) since the server is
#     401 # legitimately able to close the connection after sending a valid response.
#     402 # With this behaviour, the received response is still readable.
#
# File c:\Users\Paola Soria\miniconda3\lib\site-packages\urllib3\connection.py:244, in HTTPConnection.request(self, method, url, body, headers)
#     243     headers["User-Agent"] = _get_default_user_agent()
# --> 244 super(HTTPConnection, self).request(method, url, body=body, headers=headers)
#
# File c:\Users\Paola Soria\miniconda3\lib\http\client.py:1282, in HTTPConnection.request(self, method, url, body, headers, encode_chunked)
#    1281 """Send a complete request to the server."""
# -> 1282 self._send_request(method, url, body, headers, encode_chunked)
#
# File c:\Users\Paola Soria\miniconda3\lib\http\client.py:1328, in HTTPConnection._send_request(self, method, url, body, headers, encode_chunked)
#    1327     body = _encode(body, 'body')
# -> 1328 self.endheaders(body, encode_chunked=encode_chunked)
#
# File c:\Users\Paola Soria\miniconda3\lib\http\client.py:1277, in HTTPConnection.endheaders(self, message_body, encode_chunked)
#    1276     raise CannotSendHeader()
# -> 1277 self._send_output(message_body, encode_chunked=encode_chunked)
#
# File c:\Users\Paola Soria\miniconda3\lib\http\client.py:1037, in HTTPConnection._send_output(self, message_body, encode_chunked)
#    1036 del self._buffer[:]
# -> 1037 self.send(msg)
#    1039 if message_body is not None:
#    1040
#    1041     # create a consistent interface to message_body
#
# File c:\Users\Paola Soria\miniconda3\lib\http\client.py:975, in HTTPConnection.send(self, data)
#     974 if self.auto_open:
# --> 975     self.connect()
#     976 else:
#
# File c:\Users\Paola Soria\miniconda3\lib\site-packages\urllib3\connection.py:205, in HTTPConnection.connect(self)
#     204 def connect(self):
# --> 205     conn = self._new_conn()
#     206     self._prepare_conn(conn)
#
# File c:\Users\Paola Soria\miniconda3\lib\site-packages\urllib3\connection.py:186, in HTTPConnection._new_conn(self)
#     185 except SocketError as e:
# --> 186     raise NewConnectionError(
#     187         self, "Failed to establish a new connection: %s" % e
#     188     )
#     190 return conn
#
# NewConnectionError: <urllib3.connection.HTTPConnection object at 0x0000014E0E363520>: Failed to establish a new connection: [WinError 10061] No se puede establecer una conexión ya que el equipo de destino denegó expresamente dicha conexión
#
# During handling of the above exception, another exception occurred:
#
# MaxRetryError                             Traceback (most recent call last)
# File c:\Users\Paola Soria\miniconda3\lib\site-packages\requests\adapters.py:486, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     485 try:
# --> 486     resp = conn.urlopen(
#     487         method=request.method,
#     488         url=url,
#     489         body=request.body,
#     490         headers=request.headers,
#     491         redirect=False,
#     492         assert_same_host=False,
#     493         preload_content=False,
#     494         decode_content=False,
#     495         retries=self.max_retries,
#     496         timeout=timeout,
#     497         chunked=chunked,
#     498     )
#     500 except (ProtocolError, OSError) as err:
#
# File c:\Users\Paola Soria\miniconda3\lib\site-packages\urllib3\connectionpool.py:787, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     785     e = ProtocolError("Connection aborted.", e)
# --> 787 retries = retries.increment(
#     788     method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#     789 )
#     790 retries.sleep()
#
# File c:\Users\Paola Soria\miniconda3\lib\site-packages\urllib3\util\retry.py:592, in Retry.increment(self, method, url, response, error, _pool, _stacktrace)
#     591 if new_retry.is_exhausted():
# --> 592     raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     594 log.debug("Incremented Retry for (url='%s'): %r", url, new_retry)
#
# MaxRetryError: HTTPConnectionPool(host='127.0.0.1', port=8086): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x0000014E0E363520>: Failed to establish a new connection: [WinError 10061] No se puede establecer una conexión ya que el equipo de destino denegó expresamente dicha conexión'))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 calificador.califica_ejercicio_1(ejercicio_1)
#
# File c:\Users\Paola Soria\Documents\delfos\tareas\tareas-python\Comodin04\templates.py:83, in template_iterable.<locals>.decoradora.<locals>.contenedora(f)
#      80     Controlador.ignorar_traceback()
#      81 Controlador.calificando()
# ---> 83 helper(resultados, tarea, nombre, error=error, excepcion=excepcion, exception_type=excepcion_type)
#
# File c:\Users\Paola Soria\Documents\delfos\tareas\tareas-python\Comodin04\utilidades.py:98, in helper(resultados, tarea, nombre, **kwargs)
#      96                 print(mensajes.mensaje_de_resultados(resultado['esperado'], resultado['obtenido'], resultado.get('argumentos')))
#      97         resultados = list(map(convertir_a_tupla, resultados))
# ---> 98         mandar_a_firestore(nombre, calificacion, resultados, tarea)
#     100 else:
#     101     # errores.append(str(kwargs['exception_type']))
#     102     mandar_a_firestore(nombre, None, None, tarea)
#
# File c:\Users\Paola Soria\Documents\delfos\tareas\tareas-python\Comodin04\utilidades.py:18, in mandar_a_firestore(ejercicio, calificacion, resultados, tarea)
#      16     correo = 'estudiante@analiticadelfos.com'
#      17     ruta = "http://127.0.0.1:8086"
# ---> 18 resp = requests \
#      19     .post(ruta, \
#      20     json={"uuid": correo, \
#      21     "id_curso": ID_CURSO, \
#      22     "ejercicio": ejercicio, \
#      23     "id_tarea": f'{tarea}', \
#      24     "calificacion": calificacion, \
#      25     "resultados": resultados, \
#      26     "edicion": "1", \
#      27     "tipo": "jupyter",
#      28     "errores": errores
#      29     })
#      30 if resp.status_code != 200:
#      31     print(mensajes.mensaje_de_error_en_servidor(resp))
#
# File c:\Users\Paola Soria\miniconda3\lib\site-packages\requests\api.py:115, in post(url, data, json, **kwargs)
#     103 def post(url, data=None, json=None, **kwargs):
#     104     r"""Sends a POST request.
#     105
#     106     :param url: URL for the new :class:`Request` object.
#    (...)
#     112     :rtype: requests.Response
#     113     """
# --> 115     return request("post", url, data=data, json=json, **kwargs)
#
# File c:\Users\Paola Soria\miniconda3\lib\site-packages\requests\api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File c:\Users\Paola Soria\miniconda3\lib\site-packages\requests\sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File c:\Users\Paola Soria\miniconda3\lib\site-packages\requests\sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File c:\Users\Paola Soria\miniconda3\lib\site-packages\requests\adapters.py:519, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     515     if isinstance(e.reason, _SSLError):
#     516         # This branch is for urllib3 v1.22 and later.
#     517         raise SSLError(e, request=request)
# --> 519     raise ConnectionError(e, request=request)
#     521 except ClosedPoolError as e:
#     522     raise ConnectionError(e, request=request)
#
# ConnectionError: HTTPConnectionPool(host='127.0.0.1', port=8086): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x0000014E0E363520>: Failed to establish a new connection: [WinError 10061] No se puede establecer una conexión ya que el equipo de destino denegó expresamente dicha conexión'))

# %%
@Controlador("1", "ejercicio_2")
def ejercicio_2(numero1, numero2):
    """
    Instrucciones:
        La función "ejercicio_2" toma los parámetros
        "numero1" y "numero2", y debe regresar el 
        resultado de la suma de "numero1" más "numero2".

    Ejemplo:
        Si numero1 = 3 y numero2 = 7 la función regresa un 10:
        3 + 7 = 5

    Recuerda:
        Cuida la indentación.
    """

    # Escribe aquí tu código ↓
    

    # Escribe aquí tu código ↑
    
    return # ← Escribe aquí tu código

# %%
ejercicio_2(2, 3)

# %%
calificador.califica_ejercicio_2(ejercicio_2)
# Out:
# ===============================================================================
#
# ============> Calificando: tarea 1 - ejercicio ejercicio_2 <============
#
# ===============================================================================
#
#
# ======================================================
#             ||          Calificación: 100.0
#             ||          Aciertos: 3
#             ||          Errores: 0
# ======================================================
#
# ======> Casos existosos: <======
#
# Valores de entrada: [1, 2].             Valor esperado: 3.             Valor obtenido: 3
#
# Valores de entrada: [-1, 2].             Valor esperado: 1.             Valor obtenido: 1
#
# Valores de entrada: [1, -2].             Valor esperado: -1.             Valor obtenido: -1
#
# ======> No hubo errores :D <======
#
# ============> Calificación recibida <============

# %%
@Controlador("1", "ejercicio_3")
def ejercicio_3(numero1, numero2):
    """
    Instrucciones:
        La función "ejercicio_3" toma los parámetros
        "numero1" y "numero2", y debe regresar el 
        resultado de dividir "numero1" entre "numero2"
        más 20.

    Ejemplo:
        Si numero1 = 10 y numero2 = 5 la función regresa un 22:
        10 / 5 = 2
        2 + 20 = 22

    Recuerda:
        Cuida la indentación.
    """

    # Escribe aquí tu código ↓
    

    # Escribe aquí tu código ↑
    
    return # ← Escribe aquí tu código

# %%
ejercicio_3(20, 2)

# %%
calificador.califica_ejercicio_3(ejercicio_3)
# Out:
# ===============================================================================
#
# ============> Calificando: tarea 1 - ejercicio ejercicio_3 <============
#
# ===============================================================================
#
#
# ======================================================
#             ||          Calificación: 100.0
#             ||          Aciertos: 4
#             ||          Errores: 0
# ======================================================
#
# ======> Casos existosos: <======
#
# Valores de entrada: [1, 2].             Valor esperado: 20.5.             Valor obtenido: 20.5
#
# Valores de entrada: [2, 1].             Valor esperado: 22.             Valor obtenido: 22.0
#
# Valores de entrada: [-1, 2].             Valor esperado: 19.5.             Valor obtenido: 19.5
#
# Valores de entrada: [-2, 1].             Valor esperado: 18.             Valor obtenido: 18.0
#
# ======> No hubo errores :D <======
#
# ============> Calificación recibida <============

# %%
@Controlador("1", "ejercicio_4")
def ejercicio_4(numero1, numero2):
    """
    Instrucciones:
        La función "ejercicio_4" toma los parámetros 
        "numero1" y "numero2", y debe regresar el resultado
        de multiplicar "numero1" por "numero2".

    Ejemplo:
        Si numero1 = 5 y numero2 = 3 la función regresa 15:
        5 * 3 = 15

    Recuerda:
        Cuida la indentación.
    """

    # Escribe aquí tu código ↓
    

    # Escribe aquí tu código ↑
    
    return # ← Escribe aquí tu código

# %%
ejercicio_4(6, 3)

# %%
calificador.califica_ejercicio_4(ejercicio_4)
# Out:
# ===============================================================================
#
# ============> Calificando: tarea 1 - ejercicio ejercicio_4 <============
#
# ===============================================================================
#
#
# ======================================================
#             ||          Calificación: 100.0
#             ||          Aciertos: 4
#             ||          Errores: 0
# ======================================================
#
# ======> Casos existosos: <======
#
# Valores de entrada: [1, 2].             Valor esperado: 2.             Valor obtenido: 2
#
# Valores de entrada: [2, 1].             Valor esperado: 2.             Valor obtenido: 2
#
# Valores de entrada: [-1, 2].             Valor esperado: -2.             Valor obtenido: -2
#
# Valores de entrada: [-2, 1].             Valor esperado: -2.             Valor obtenido: -2
#
# ======> No hubo errores :D <======
#
# ============> Calificación recibida <============

# %%
@Controlador("1", "ejercicio_5")
def ejercicio_5(numero1, numero2, numero3):
    """
    Instrucciones:
        La función "ejercicio_5" toma los parámetros
        "numero1", "numero2" y "numero3", y debe regresar
        el resultado de multiplicar "numero2" por "numero3"
        más "número1".

    Ejemplo:
        Si numero1 = 2, numero2 = 10 y numero3 = 3
        la función regresa un 32:
        10 * 3 = 30
        30 + 2 = 32

    Recuerda:
        Cuida la indentación.
    """

    # Escribe aquí tu código ↓
    

    # Escribe aquí tu código ↑
    
    return # ← Escribe aquí tu código

# %%
ejercicio_5(1, 5, 4)

# %%
calificador.califica_ejercicio_5(ejercicio_5)
# Out:
# ===============================================================================
#
# ============> Calificando: tarea 1 - ejercicio ejercicio_5 <============
#
# ===============================================================================
#
#
# ======================================================
#             ||          Calificación: 100.0
#             ||          Aciertos: 5
#             ||          Errores: 0
# ======================================================
#
# ======> Casos existosos: <======
#
# Valores de entrada: [1, 2, 3].             Valor esperado: 7.             Valor obtenido: 7
#
# Valores de entrada: [3, 2, 1].             Valor esperado: 5.             Valor obtenido: 5
#
# Valores de entrada: [-1, 2, 3].             Valor esperado: 5.             Valor obtenido: 5
#
# Valores de entrada: [1, -2, 3].             Valor esperado: -5.             Valor obtenido: -5
#
# Valores de entrada: [1, 2, -3].             Valor esperado: -5.             Valor obtenido: -5
#
# ======> No hubo errores :D <======
#
# ============> Calificación recibida <============

# %%
@Controlador("1", "ejercicio_6")
def ejercicio_6(numero1, numero2):
    """
    Instrucciones:
        La función "ejercicio_6" toma los parámetros
        "numero1" y "numero2", y debe regresar el resultado
        de elevar "numero1" a la potencia de "numero2".
        
    Ejemplo:
        Si numero1 = 3 y numero2 = 2 la función regresa 9:
        3 ** 2 = 9

    Recuerda:
        Cuida la indentación.
    """

    # Escribe aquí tu código ↓
    

    # Escribe aquí tu código ↑
    
    return # ← Escribe aquí tu código

# %%
ejercicio_6(2, 3)

# %%
calificador.califica_ejercicio_6(ejercicio_6)
# Out:
# ===============================================================================
#
# ============> Calificando: tarea 1 - ejercicio ejercicio_6 <============
#
# ===============================================================================
#
#
# ======================================================
#             ||          Calificación: 75.0
#             ||          Aciertos: 3
#             ||          Errores: 1
# ======================================================
#
# ======> Casos existosos: <======
#
# Valores de entrada: [1, 2].             Valor esperado: 1.             Valor obtenido: 1
#
# Valores de entrada: [-2, 2].             Valor esperado: 4.             Valor obtenido: 4
#
# Valores de entrada: [2, -2].             Valor esperado: 0.25.             Valor obtenido: 0.25
#
# ======> Casos con error <======
#
# Valores de entrada: [2, 1].             Valor esperado: 1.             Valor obtenido: 2
#
# ============> Calificación recibida <============

# %%
@Controlador("1", "ejercicio_7")
def ejercicio_7(numero1, numero2):
    """
    Instrucciones:
        La función "ejercicio_7" toma los parámetros "numero1"
        y "numero2", y debe regresar el resultado de elevar 
        "numero1" al cubo menos "numero2".

    Ejemplo:
        Si numero1 = 2 y numero2 = 3 la función regresa 5:
        2 ** 3 = 8
        8 - 3 = 5

    Recuerda:
        Cuida la indentación.
    """
    
    # Escribe aquí tu código ↓
    

    # Escribe aquí tu código ↑

    return # ← Escribe aquí tu código

# %%
ejercicio_7(3, 7)

# %%
calificador.califica_ejercicio_7(ejercicio_7)
# Out:
# ===============================================================================
#
# ============> Calificando: tarea 1 - ejercicio ejercicio_7 <============
#
# ===============================================================================
#
#
# ======================================================
#             ||          Calificación: 100.0
#             ||          Aciertos: 3
#             ||          Errores: 0
# ======================================================
#
# ======> Casos existosos: <======
#
# Valores de entrada: [1, 2].             Valor esperado: -1.             Valor obtenido: -1
#
# Valores de entrada: [-1, 2].             Valor esperado: -3.             Valor obtenido: -3
#
# Valores de entrada: [1, -2].             Valor esperado: 3.             Valor obtenido: 3
#
# ======> No hubo errores :D <======
#
# ============> Calificación recibida <============

# %%
@Controlador("1", "ejercicio_8")
def ejercicio_8(numero1, numero2):
    """
    Instrucciones:
        La función "ejercicio_8" toma los parámetros
        "numero1" y "numero2" y debe regresar el resultado
        de multiplicar "numero1" por 4 y despues restarle "numero2".

    Ejemplo:
        Si numero1 = 2 y numero2 = 1 la función regresa 7:
        2 * 4 = 8
        8 - 1 = 7

    Recuerda:
        Cuida la indentación.
    """
    
    # Escribe aquí tu código ↓
    

    # Escribe aquí tu código ↑
    
    return # ← Escribe aquí tu código

# %%
ejercicio_8(5, 10)

# %%
calificador.califica_ejercicio_8(ejercicio_8)
# Out:
# ===============================================================================
#
# ============> Calificando: tarea 1 - ejercicio ejercicio_8 <============
#
# ===============================================================================
#
#
# ======================================================
#             ||          Calificación: 100.0
#             ||          Aciertos: 3
#             ||          Errores: 0
# ======================================================
#
# ======> Casos existosos: <======
#
# Valores de entrada: [1, 2].             Valor esperado: 2.             Valor obtenido: 2
#
# Valores de entrada: [-1, 2].             Valor esperado: -6.             Valor obtenido: -6
#
# Valores de entrada: [1, -2].             Valor esperado: 6.             Valor obtenido: 6
#
# ======> No hubo errores :D <======
#
# ============> Calificación recibida <============

# %%
@Controlador("1", "ejercicio_9")
def ejercicio_9(numero):
    """
     Instrucciones:
        La función "ejercicio_9" toma el parámetro
        "numero" y debe regresar el resultado de
        obtener el valor absoluto de "numero".

    Ejemplo:
        Si numero = -4 la función regresa 4.

    Recuerda:
        La función abs() sirve para calcular el valor
        absoluto de un número.
        
        Cuida la indentación.
    """
    
    # Escribe aquí tu código ↓ 
    

    # Escribe aquí tu código ↑
    
    return # ← Escribe aquí tu código

# %%
ejercicio_9(-15)

# %%
calificador.califica_ejercicio_9(ejercicio_9)
# Out:
# ===============================================================================
#
# ============> Calificando: tarea 1 - ejercicio ejercicio_9 <============
#
# ===============================================================================
#
#
# ======================================================
#             ||          Calificación: 100.0
#             ||          Aciertos: 5
#             ||          Errores: 0
# ======================================================
#
# ======> Casos existosos: <======
#
#  Valores de entrada: 1.              Valor esperado: 1.              Valor obtenido: 1
#
#  Valores de entrada: 2.              Valor esperado: 2.              Valor obtenido: 2
#
#  Valores de entrada: -3.              Valor esperado: 3.              Valor obtenido: 3
#
#  Valores de entrada: -3.6.              Valor esperado: 3.6.              Valor obtenido: 3.6
#
#  Valores de entrada: -100000.              Valor esperado: 100000.              Valor obtenido: 100000
#
# ======> No hubo errores :D <======
#
# ============> Calificación recibida <============

# %%
@Controlador("1", "ejercicio_10")
def ejercicio_10(numero):
    """
    Instrucciones:
        La función "ejercicio_10" toma el parámetro "numero" 
        y debe regresar su raíz cúbica.

    Ejemplo:
        Si numero = 27 la función regresa 3.

    Restricciones:
        No importar ninguna librería adicional.

    Recuerda:
        Matemáticamente hablando, la raíz cuadrada de un 
        número se puede obtener al elevar dicho numero a 
        la potencia de 1/2, igual que la raíz cúbica de 
        un número se puede obtener al elevar dicho numero
        a la potencia de 1/3, y así sucesivamente. 
        
        Cuida la indentación.
    """
    
    # Escribe aquí tu código ↓
    

    # Escribe aquí tu código ↑
    
    return # ← Escribe aquí tu código

# %%
ejercicio_10(8)

# %%
calificador.califica_ejercicio_10(ejercicio_10)
# Out:
# ===============================================================================
#
# ============> Calificando: tarea 1 - ejercicio ejercicio_10 <============
#
# ===============================================================================
#
#
# ======================================================
#             ||          Calificación: 100.0
#             ||          Aciertos: 3
#             ||          Errores: 0
# ======================================================
#
# ======> Casos existosos: <======
#
#  Valores de entrada: 8.              Valor esperado: 2.0.              Valor obtenido: 2.0
#
#  Valores de entrada: 27.              Valor esperado: 3.0.              Valor obtenido: 3.0
#
#  Valores de entrada: 125.              Valor esperado: 5.0.              Valor obtenido: 5.0
#
# ======> No hubo errores :D <======
#
# ============> Calificación recibida <============
