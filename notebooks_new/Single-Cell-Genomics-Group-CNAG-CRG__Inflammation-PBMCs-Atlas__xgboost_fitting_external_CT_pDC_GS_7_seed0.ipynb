# %%
CELL_TYPE = 'pDC'
N_GENES: int = 20
SEED = 'shap_studyID' #'disease_NOstudy' 'study_NOdisease' or 'int' or 'shap_studyID'
TEST_SPLIT_IDX: int = 1 #[0,4]

# %%
# Parameters
CELL_TYPE = "pDC"
SEED = 7
TEST_SPLIT_IDX = 0

# %%
N_SPLITS: int = 5
N_TRIALS: int = 50

# %%
import os
import sys
from pyprojroot.here import here
import pandas as pd
import anndata as ad
import numpy as np
import math
from sklearn.model_selection import StratifiedGroupKFold
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import f1_score
import matplotlib.pyplot as plt
import seaborn as sns
from itertools import product
from sklearn.metrics import balanced_accuracy_score, f1_score
import optuna

import joblib
import pickle
import datetime

import collections

import xgboost
from sklearn.preprocessing import LabelEncoder

import scipy.sparse as ssp
import joblib

from dotenv import load_dotenv

# %%
load_dotenv()
# Out:
# True

# %% [markdown]
# # LOAD DATASET

# %%
train_adata = ad.read_h5ad(
    here(f'03_downstream_analysis/08_gene_importance/xgboost_external_validation/xgboost_TopN_genes/data_cellTypes/EXTERNAL_{CELL_TYPE}.filtered.log1p.h5ad')
)

# %%
if SEED != 'all':
    gene_subset = np.load(here(f'03_downstream_analysis/08_gene_importance/xgboost_external_validation/shap_gene_selection/gene_subsets_{N_GENES}/{CELL_TYPE}_{SEED}.npy'), allow_pickle=True)
    train_adata = train_adata[:,gene_subset]
    print(gene_subset)
elif SEED == 'all':
    print('Using all genes')
else:
    raise ValueError()
# Out:
# ['ENSG00000141367' 'ENSG00000205542' 'ENSG00000127022' 'ENSG00000184007'
#  'ENSG00000169442' 'ENSG00000145912' 'ENSG00000160213' 'ENSG00000089327'
#  'ENSG00000140105' 'ENSG00000144802' 'ENSG00000138378' 'ENSG00000171150'
#  'ENSG00000164543' 'ENSG00000106066' 'ENSG00000185591' 'ENSG00000156411'
#  'ENSG00000150782' 'ENSG00000100906' 'ENSG00000160932' 'ENSG00000134285'
#  'ENSG00000002549' 'ENSG00000143119' 'ENSG00000123358' 'ENSG00000122862'
#  'ENSG00000027697' 'ENSG00000108622' 'ENSG00000132965' 'ENSG00000101347'
#  'ENSG00000118260' 'ENSG00000198369' 'ENSG00000175567' 'ENSG00000153234'
#  'ENSG00000138623' 'ENSG00000157483' 'ENSG00000168461' 'ENSG00000153898'
#  'ENSG00000157873' 'ENSG00000172183' 'ENSG00000179218' 'ENSG00000134352'
#  'ENSG00000204267' 'ENSG00000197471' 'ENSG00000136738' 'ENSG00000133872'
#  'ENSG00000109861' 'ENSG00000231389' 'ENSG00000125148' 'ENSG00000033800'
#  'ENSG00000172009' 'ENSG00000160710' 'ENSG00000130429' 'ENSG00000135968'
#  'ENSG00000104964' 'ENSG00000177556' 'ENSG00000126267' 'ENSG00000110077'
#  'ENSG00000108518' 'ENSG00000139192' 'ENSG00000130755' 'ENSG00000164307'
#  'ENSG00000165272' 'ENSG00000089127' 'ENSG00000163563' 'ENSG00000271503'
#  'ENSG00000152700' 'ENSG00000204264' 'ENSG00000114423' 'ENSG00000005339'
#  'ENSG00000119922' 'ENSG00000101608' 'ENSG00000104856' 'ENSG00000160223'
#  'ENSG00000241837' 'ENSG00000235162' 'ENSG00000109321' 'ENSG00000127184'
#  'ENSG00000100393' 'ENSG00000104660' 'ENSG00000196154' 'ENSG00000175482'
#  'ENSG00000145220' 'ENSG00000135046' 'ENSG00000171700' 'ENSG00000163513'
#  'ENSG00000085265' 'ENSG00000111321' 'ENSG00000104870' 'ENSG00000158869'
#  'ENSG00000042753' 'ENSG00000197102' 'ENSG00000145675' 'ENSG00000132002'
#  'ENSG00000113441' 'ENSG00000173812' 'ENSG00000069399' 'ENSG00000130066'
#  'ENSG00000126759' 'ENSG00000205220' 'ENSG00000082074' 'ENSG00000163660'
#  'ENSG00000185436' 'ENSG00000149311' 'ENSG00000254087' 'ENSG00000140264'
#  'ENSG00000132510' 'ENSG00000264364' 'ENSG00000090382' 'ENSG00000119655'
#  'ENSG00000104904' 'ENSG00000165527' 'ENSG00000038427' 'ENSG00000164308']

# %%
train_adata.shape
# Out:
# (2320, 112)

# %%
train_adata.obs.disease.unique()
# Out:
# ['RA', 'healthy', 'COVID', 'HIV', 'cirrhosis', 'CD', 'SLE', 'sepsis']
# Categories (8, object): ['CD', 'COVID', 'HIV', 'RA', 'SLE', 'cirrhosis', 'healthy', 'sepsis']

# %%
train_adata.obs.sampleID.unique()
# Out:
# ['SCGT00val_I036023_T0', 'SCGT00val_I036024_T0', 'SCGT00val_I0364_T0', 'SCGT00val_I036015_T0', 'SCGT00val_I036019_T0', ..., '10XGenomics_10XHC2_T0', '10XGenomics_10XHC3_T0', '10XGenomics_10XHC5_T0', '10XGenomics_10XHC7_T0', '10XGenomics_10XHC8_T0']
# Length: 77
# Categories (77, object): ['10XGenomics_10XHC1_T0', '10XGenomics_10XHC2_T0', '10XGenomics_10XHC3_T0', '10XGenomics_10XHC4_T0', ..., 'Savage2021_BRISL6_T0', 'Savage2021_BRISL7_T0', 'Savage2021_PIDA_T0', 'Savage2021_PIDB_T0']

# %%
all_idxs = np.arange(train_adata.obs.shape[0])
left_out_splits = [s[1] for s in StratifiedGroupKFold(n_splits=N_SPLITS).split(all_idxs, train_adata.obs.disease, train_adata.obs.sampleID)]
# Out:
# /scratch_isilon/groups/singlecell/shared/conda_env/xgboost-cpu/lib/python3.12/site-packages/sklearn/model_selection/_split.py:994: UserWarning: The least populated class in y has only 4 members, which is less than n_splits=5.
#   warnings.warn(

# %%
TRAIN_SPLIT_IDXS = [0,1,2,3,4]
VAL_SPLIT_IDX = (TEST_SPLIT_IDX + 1) % 5
TRAIN_SPLIT_IDXS.remove(TEST_SPLIT_IDX)
TRAIN_SPLIT_IDXS.remove(VAL_SPLIT_IDX)
TRAIN_SPLIT_IDXS, VAL_SPLIT_IDX, TEST_SPLIT_IDX
# Out:
# ([2, 3, 4], 1, 0)

# %%
train_idxs = np.concatenate([left_out_splits[idx] for idx in TRAIN_SPLIT_IDXS])
val_idxs = left_out_splits[VAL_SPLIT_IDX]
test_idxs = left_out_splits[TEST_SPLIT_IDX]

# %% [markdown]
# ### SUBSET DATASET INTO TRAIN/TEST/VAL SPLITS

# %%
X_train = train_adata.X[train_idxs]
X_test = train_adata.X[test_idxs]
X_val = train_adata.X[val_idxs]
X_train.shape, X_test.shape, X_val.shape
# Out:
# ((1405, 112), (435, 112), (480, 112))

# %%
y_train = train_adata.obs.iloc[train_idxs].disease.values.astype(str)
y_test = train_adata.obs.iloc[test_idxs].disease.values.astype(str)
y_val = train_adata.obs.iloc[val_idxs].disease.values.astype(str)
y_train.shape, y_test.shape, y_val.shape
# Out:
# ((1405,), (435,), (480,))

# %%
lenc = LabelEncoder()
y_train_enc = lenc.fit_transform(y_train)
y_val_enc = lenc.transform(y_val)
y_test_enc = lenc.transform(y_test)

# %% [markdown]
# ### GENERATE F1

# %%
def custom_f1_score(y_true, y_pred):
    return -f1_score(y_true, y_pred.argmax(1), average='weighted')

# %%
eval_metric=custom_f1_score
eval_metric_name='custom_f1_score'

def objective(trial):
    params = {
        'n_estimators': 1500,
        'max_depth': trial.suggest_int('max_depth', 3, 20),
        'min_child_weight': trial.suggest_int('min_child_weight', 1, 250),
        'subsample': trial.suggest_float('subsample', 0.1, 1.0),
        'colsample_bynode': trial.suggest_float('colsample_bynode', 0.1, 1.0),
        'learning_rate': trial.suggest_float('learning_rate', 1e-3, 5e-1, log=True),
    }
    pruning_callback = optuna.integration.XGBoostPruningCallback(trial, f'validation_0-{eval_metric_name}')
    es_callback = xgboost.callback.EarlyStopping(20, min_delta=0.001)
    xgb = xgboost.XGBClassifier(
        eval_metric=eval_metric,
        callbacks=[pruning_callback, es_callback],
        n_jobs=5,
        **params
    )
    xgb.fit(
        X_train, 
        y_train_enc, 
        verbose=0,
        eval_set=[(X_val, y_val_enc)],
    )
    trial.set_user_attr('best_iteration', xgb.best_iteration)

    return xgb.best_score

# %%
sampler = optuna.samplers.TPESampler(seed=42)
study = optuna.create_study(direction='minimize', sampler=sampler)
study.optimize(objective, n_trials=N_TRIALS, gc_after_trial=True)
# Out:
# [I 2025-05-15 18:15:57,467] A new study created in memory with name: no-name-2a6bd831-1e81-4490-ba52-348721e0b1d4
# [I 2025-05-15 18:15:57,633] Trial 0 finished with value: -0.226534 and parameters: {'max_depth': 9, 'min_child_weight': 238, 'subsample': 0.7587945476302645, 'colsample_bynode': 0.6387926357773329, 'learning_rate': 0.0026368755339723046}. Best is trial 0 with value: -0.226534.
# [I 2025-05-15 18:15:59,006] Trial 1 finished with value: -0.570044 and parameters: {'max_depth': 5, 'min_child_weight': 15, 'subsample': 0.8795585311974417, 'colsample_bynode': 0.6410035105688879, 'learning_rate': 0.08148293210105287}. Best is trial 1 with value: -0.570044.
# [I 2025-05-15 18:15:59,224] Trial 2 finished with value: -0.226534 and parameters: {'max_depth': 3, 'min_child_weight': 243, 'subsample': 0.8491983767203796, 'colsample_bynode': 0.29110519961044856, 'learning_rate': 0.003095566460242371}. Best is trial 1 with value: -0.570044.
# [I 2025-05-15 18:15:59,844] Trial 3 finished with value: -0.472018 and parameters: {'max_depth': 6, 'min_child_weight': 77, 'subsample': 0.5722807884690141, 'colsample_bynode': 0.48875051677790415, 'learning_rate': 0.006109683510122491}. Best is trial 1 with value: -0.570044.
# [I 2025-05-15 18:16:00,125] Trial 4 finished with value: -0.483251 and parameters: {'max_depth': 14, 'min_child_weight': 35, 'subsample': 0.3629301836816964, 'colsample_bynode': 0.4297256589643226, 'learning_rate': 0.01701841881702917}. Best is trial 1 with value: -0.570044.
# [I 2025-05-15 18:16:00,542] Trial 5 pruned. Trial was pruned at iteration 33.
# [I 2025-05-15 18:16:00,671] Trial 6 pruned. Trial was pruned at iteration 0.
# [I 2025-05-15 18:16:00,814] Trial 7 pruned. Trial was pruned at iteration 0.
# [I 2025-05-15 18:16:00,949] Trial 8 pruned. Trial was pruned at iteration 0.
# [I 2025-05-15 18:16:01,109] Trial 9 pruned. Trial was pruned at iteration 4.
# [I 2025-05-15 18:16:02,823] Trial 10 finished with value: -0.602349 and parameters: {'max_depth': 9, 'min_child_weight': 2, 'subsample': 0.9725833997090791, 'colsample_bynode': 0.11616568805333755, 'learning_rate': 0.17780618353487967}. Best is trial 10 with value: -0.602349.
# [I 2025-05-15 18:16:04,368] Trial 11 finished with value: -0.570583 and parameters: {'max_depth': 9, 'min_child_weight': 4, 'subsample': 0.9818290990185045, 'colsample_bynode': 0.17702656156719, 'learning_rate': 0.11568531411766632}. Best is trial 10 with value: -0.602349.
# [I 2025-05-15 18:16:05,708] Trial 12 pruned. Trial was pruned at iteration 55.
# [I 2025-05-15 18:16:05,879] Trial 13 pruned. Trial was pruned at iteration 0.
# [I 2025-05-15 18:16:06,016] Trial 14 pruned. Trial was pruned at iteration 0.
# [I 2025-05-15 18:16:07,020] Trial 15 finished with value: -0.523127 and parameters: {'max_depth': 20, 'min_child_weight': 2, 'subsample': 0.719264024177087, 'colsample_bynode': 0.2540835086298475, 'learning_rate': 0.03987682305667138}. Best is trial 10 with value: -0.602349.
# [I 2025-05-15 18:16:07,190] Trial 16 pruned. Trial was pruned at iteration 0.
# [I 2025-05-15 18:16:07,338] Trial 17 pruned. Trial was pruned at iteration 0.
# [I 2025-05-15 18:16:07,960] Trial 18 pruned. Trial was pruned at iteration 50.
# [I 2025-05-15 18:16:08,119] Trial 19 pruned. Trial was pruned at iteration 0.
# [I 2025-05-15 18:16:08,284] Trial 20 pruned. Trial was pruned at iteration 0.
# [I 2025-05-15 18:16:08,963] Trial 21 pruned. Trial was pruned at iteration 33.
# [I 2025-05-15 18:16:09,566] Trial 22 pruned. Trial was pruned at iteration 36.
# [I 2025-05-15 18:16:09,849] Trial 23 pruned. Trial was pruned at iteration 20.
# [I 2025-05-15 18:16:10,589] Trial 24 finished with value: -0.530053 and parameters: {'max_depth': 8, 'min_child_weight': 4, 'subsample': 0.9363676414616533, 'colsample_bynode': 0.3570727728603251, 'learning_rate': 0.030617548856419777}. Best is trial 10 with value: -0.602349.
# [I 2025-05-15 18:16:10,745] Trial 25 pruned. Trial was pruned at iteration 0.
# [I 2025-05-15 18:16:10,880] Trial 26 pruned. Trial was pruned at iteration 0.
# [I 2025-05-15 18:16:11,024] Trial 27 pruned. Trial was pruned at iteration 0.
# [I 2025-05-15 18:16:11,162] Trial 28 pruned. Trial was pruned at iteration 0.
# [I 2025-05-15 18:16:11,311] Trial 29 pruned. Trial was pruned at iteration 0.
# [I 2025-05-15 18:16:11,460] Trial 30 pruned. Trial was pruned at iteration 0.
# [I 2025-05-15 18:16:12,602] Trial 31 pruned. Trial was pruned at iteration 33.
# [I 2025-05-15 18:16:13,039] Trial 32 pruned. Trial was pruned at iteration 18.
# [I 2025-05-15 18:16:13,180] Trial 33 pruned. Trial was pruned at iteration 0.
# [I 2025-05-15 18:16:14,580] Trial 34 finished with value: -0.561695 and parameters: {'max_depth': 12, 'min_child_weight': 1, 'subsample': 0.9484048686960357, 'colsample_bynode': 0.42966693340611073, 'learning_rate': 0.018404253578162902}. Best is trial 10 with value: -0.602349.
# [I 2025-05-15 18:16:14,740] Trial 35 pruned. Trial was pruned at iteration 0.
# [I 2025-05-15 18:16:14,884] Trial 36 pruned. Trial was pruned at iteration 0.
# [I 2025-05-15 18:16:15,831] Trial 37 finished with value: -0.617308 and parameters: {'max_depth': 10, 'min_child_weight': 13, 'subsample': 0.7432175746919831, 'colsample_bynode': 0.6172093761412798, 'learning_rate': 0.3139703135133186}. Best is trial 37 with value: -0.617308.
# [I 2025-05-15 18:16:15,993] Trial 38 pruned. Trial was pruned at iteration 0.
# [I 2025-05-15 18:16:16,169] Trial 39 pruned. Trial was pruned at iteration 0.
# [I 2025-05-15 18:16:16,318] Trial 40 pruned. Trial was pruned at iteration 0.
# [I 2025-05-15 18:16:16,506] Trial 41 pruned. Trial was pruned at iteration 0.
# [I 2025-05-15 18:16:16,693] Trial 42 pruned. Trial was pruned at iteration 0.
# [I 2025-05-15 18:16:16,847] Trial 43 pruned. Trial was pruned at iteration 0.
# [I 2025-05-15 18:16:17,931] Trial 44 finished with value: -0.569178 and parameters: {'max_depth': 10, 'min_child_weight': 1, 'subsample': 0.9930703920158097, 'colsample_bynode': 0.4177287822871783, 'learning_rate': 0.45744058583021374}. Best is trial 37 with value: -0.617308.
# [I 2025-05-15 18:16:18,170] Trial 45 pruned. Trial was pruned at iteration 5.
# [I 2025-05-15 18:16:18,347] Trial 46 pruned. Trial was pruned at iteration 0.
# [I 2025-05-15 18:16:18,495] Trial 47 pruned. Trial was pruned at iteration 0.
# [I 2025-05-15 18:16:18,631] Trial 48 pruned. Trial was pruned at iteration 0.
# [I 2025-05-15 18:16:18,777] Trial 49 pruned. Trial was pruned at iteration 0.

# %%
out_dir = here(f'03_downstream_analysis/08_gene_importance/xgboost_external_validation/xgboost_TopN_genes/results_{N_GENES}/study')

if not os.path.exists(out_dir):
    os.makedirs(out_dir)
    
joblib.dump(study,os.path.join(out_dir, f'{CELL_TYPE}_{SEED}_{TEST_SPLIT_IDX}_xgboost.pkl'))
# Out:
# ['/scratch_isilon/groups/singlecell/shared/projects/Inflammation-PBMCs-Atlas/03_downstream_analysis/08_gene_importance/xgboost_external_validation/xgboost_TopN_genes/results_20/study/pDC_7_0_xgboost.pkl']

# %%
n_estimators = int(study.best_trial.user_attrs['best_iteration']*1.2)
xgb = xgboost.XGBClassifier(
        eval_metric=eval_metric,
        n_estimators=n_estimators,
        **study.best_trial.params
    )
xgb.fit(
    ssp.vstack((X_train, X_val)), 
    np.concatenate((y_train_enc, y_val_enc)),
    verbose=1,
)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=0.6172093761412798,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False,
#               eval_metric=<function custom_f1_score at 0x7f3bc30dbec0>,
#               feature_types=None, gamma=None, grow_policy=None,
#               importance_type=None, interaction_constraints=None,
#               learning_rate=0.3139703135133186, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=10, max_leaves=None,
#               min_child_weight=13, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=60, n_jobs=None,
#               num_parallel_tree=None, objective='multi:softprob', ...)

# %%
out_dir = here(f'03_downstream_analysis/08_gene_importance/xgboost_external_validation/xgboost_TopN_genes/results_{N_GENES}/best_model')

if not os.path.exists(out_dir):
    os.makedirs(out_dir)
    
joblib.dump(xgb, os.path.join(out_dir, f'{CELL_TYPE}_{SEED}_{TEST_SPLIT_IDX}_xgb.json'))
# Out:
# ['/scratch_isilon/groups/singlecell/shared/projects/Inflammation-PBMCs-Atlas/03_downstream_analysis/08_gene_importance/xgboost_external_validation/xgboost_TopN_genes/results_20/best_model/pDC_7_0_xgb.json']

# %%
df_pred_test = pd.DataFrame(dict(
    cell_id=train_adata.obs.iloc[test_idxs].index.values,
    y_true=y_test, 
    y_true_code=y_test_enc, 
    y_pred=xgb.predict(X_test))).set_index('cell_id')

# %%
out_dir = here(f'03_downstream_analysis/08_gene_importance/xgboost_external_validation/xgboost_TopN_genes/results_{N_GENES}/predictions')

if not os.path.exists(out_dir):
    os.makedirs(out_dir)
    
df_pred_test.to_csv(os.path.join(out_dir, f'{CELL_TYPE}_{SEED}_{TEST_SPLIT_IDX}_pred_test.zip'))

# %%
metrics_dict = dict(
    BAS=balanced_accuracy_score(y_true=df_pred_test.y_true_code, y_pred=df_pred_test.y_pred), WF1=f1_score(y_true=df_pred_test.y_true_code, y_pred=df_pred_test.y_pred,average='weighted'))

# %%
metrics_dict
# Out:
# {'BAS': 0.4289266717325228, 'WF1': 0.7374400379847238}

# %%
metrics_df = pd.DataFrame.from_dict([metrics_dict]).assign(split_idx=TEST_SPLIT_IDX, gene_set_seed=SEED, cell_type=CELL_TYPE)
metrics_df
# Out:
#         BAS      WF1  split_idx  gene_set_seed cell_type
# 0  0.428927  0.73744          0              7       pDC

# %%
out_dir = here(f'03_downstream_analysis/08_gene_importance/xgboost_external_validation/xgboost_TopN_genes/results_{N_GENES}/metrics')

if not os.path.exists(out_dir):
    os.makedirs(out_dir)
    
metrics_df.to_csv(os.path.join(out_dir, f'{CELL_TYPE}_{SEED}_{TEST_SPLIT_IDX}_metrics.zip'))
