# %%
import pandas as pd
from utils.io import get_data
from data_prep import get_surveydata_expanded
all_atom = r'C:\Users\aftab.jalal\dev\atom-analysis\data\in\20170101_20230630.parquet'

# %%
# atoms= pd.read_parquet(all_atom)

# %%
extract_start_date = 20170101
extract_end_date = 20230630
raw_df = get_data(extract_start_date, extract_end_date, f"./data/in/20170101_20230630.parquet", cache=True)
# Out:
# 2023-08-13 14:03:19,412 - utils.io - INFO - Using cached data from ./data/in/20170101_20230630.parquet

# %%
df2 = get_surveydata_expanded(raw_df.copy())
# Out:
# 2023-08-13 14:05:09,977 - data_prep - DEBUG - 	 get_surveydata_expanded

# %%
# C:\Users\aftab.jalal\dev\atom-analysis\data\out\matched_df.xlsx
list(df2.columns)
# 'PartitionKey',
#  'RowKey',
#  'Program',
#  'SurveyName',
#  'AssessmentDate',
# 'PDC'
# Out:
# ['PartitionKey',
#  'RowKey',
#  'Program',
#  'SurveyName',
#  'AssessmentDate',
#  'PDC',
#  'Anyodc',
#  'NotesODC',
#  'Past4WkNumInjectingDays',
#  'HaveYouEverSharedEquipment',
#  'Past4WkDailyLivingImpacted',
#  'Past4WkHowOftenPhysicalHealthCausedProblems',
#  'Past4WkHowOftenMentalHealthCausedProblems',
#  'Past4WkUseLedToProblemsWithFamilyFriend',
#  'Past4WkHowOftenIllegalActivities',
#  'HowCloseToManagingSubstanceUse',
#  'HowSatisfiedWithProgress',
#  'Past4WkDifficultyFindingHousing',
#  'Staff',
#  'ClientType',
#  'IndigenousStatus',
#  'SDSIsAODUseOutOfControl',
#  'SDSHowMuchDoYouWorryAboutAODUse',
#  'SDSDoesMissingFixMakeAnxious',
#  'SDSDoYouWishToStop',
#  'SDSHowDifficultToStopOrGoWithout',
#  'SDS_Score',
#  'doK10',
#  'K10Q01',
#  'K10Q02',
#  'K10Q03',
#  'K10Q04',
#  'K10Q05',
#  'K10Q06',
#  'K10Q07',
#  'K10Q08',
#  'K10Q09',
#  'K10Q10',
#  'LivingArrangements',
#  'UsualAccommodation',
#  'AreYouCurrentlyTakingMeds',
#  'MedicationsNotes',
# ...
