# %% [markdown]
# # Tokenization - Start Here
#
# ---
#
# Tokenization is the bridge between raw text and everything that follows in modern AI. If you want to understand context windows, cost, chunking, embeddings, retrieval quality, or why two models handle the same sentence differently, start here.
#
# ---
#
# ## Why This Phase Matters
#
# LLMs do not read words directly. They operate on **tokens**: subword units mapped to integer IDs. That design choice shapes latency, cost, multilingual behavior, prompt limits, and downstream model quality.
#
# This phase is foundational for later work in embeddings, vector search, RAG, fine-tuning, and inference optimization.
#
# ## How To Use This Phase Well
#
# - Start with intuition before implementation.
# - Compare how different tokenizers split the same text.
# - Pay attention to token count, vocabulary design, and special tokens.
# - Treat this phase as practical infrastructure knowledge, not just NLP theory.
#
# ## Notebooks in This Phase
#
# | Notebook | Topic |
# |----------|-------|
# | `01_tokenizers_quickstart.ipynb` | BPE, WordPiece, SentencePiece overview |
# | `02_tokenizers_training.ipynb` | Train your own tokenizer on custom data |
# | `03_advanced_training_methods.ipynb` | Unigram LM, tokenizer design decisions |
# | `06_pipeline_components.ipynb` | Hugging Face tokenizer pipeline internals |
# | `tiktoken_example.ipynb` | OpenAI tiktoken and GPT-style token counting |
# | `sentencepiece_example.ipynb` | SentencePiece for multilingual and custom pipelines |
# | `token_exploration.ipynb` | Visualize how different models tokenize text |
# | `token_exercises.ipynb` | Hands-on practice to check understanding |
#
# ## Prerequisites
#
# - Python basics (Phase 01)
# - Basic comfort reading notebooks and small code examples
#
# ## Key Concepts You'll Learn
#
# - **BPE** (Byte Pair Encoding) and why GPT-style models use it
# - **WordPiece** and **SentencePiece / Unigram** tokenization
# - **tiktoken** for API cost and context-window awareness
# - Why token count affects latency, pricing, and truncation
# - How tokenization choices affect multilingual and domain-specific models
#
# ## Recommended Order
#
# ```
# 03_tokenizers_quickstart.ipynb    <- Start here
# 12_tiktoken_example.ipynb            <- Do early if you use OpenAI-style APIs
# sentencepiece_example.ipynb
# 02_tokenizers_training.ipynb
# 03_advanced_training_methods.ipynb
# 06_pipeline_components.ipynb
# token_exploration.ipynb
# 13_token_exercises.ipynb             <- Finish with practice
# ```
#
# ## What Comes Next
#
# After this phase, move to embeddings and then vector databases. Those later phases make much more sense once you understand how text is segmented before it becomes vectors or model input.
