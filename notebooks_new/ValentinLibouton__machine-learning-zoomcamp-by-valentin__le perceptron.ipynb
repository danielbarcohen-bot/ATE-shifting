# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import make_blobs


# %matplotlib inline

# %%
X, y = make_blobs(n_samples=100, n_features=2, centers=2, random_state=0)
y = y.reshape(len(y), 1)

print('dimension de X:', X.shape)
print('dimension de y:', y.shape)

plt.scatter(X[:,0], X[:, 1], c=y, cmap='winter')
plt.show()
# Out:
# dimension de X: (100, 2)
# dimension de y: (100, 1)

# %%
def initialisation(X): 
    W = np.random.randn(X.shape[1], 1)
    b = np.random.randn(1)
    return (W, b)

# %%
def model(X, W, b):
    Z = X.dot(W) + b
    return Z

# %%
def activation(Z):
    A = 1 / (1 + np.exp(-Z))
    return A

# %%
# testons
W, b = initialisation(X)
A = activation(model(X, W, b))

A.shape
# Out:
# (100, 1)

# %%
A
# Out:
# array([[0.90519365],
#        [0.40779046],
#        [0.99598466],
#        [0.87724733],
#        [0.6976884 ],
#        [0.93564311],
#        [0.98772607],
#        [0.91832277],
#        [0.98516653],
#        [0.33931665],
#        [0.99180125],
#        [0.49024608],
#        [0.99731015],
#        [0.99009802],
#        [0.78987322],
#        [0.85428851],
#        [0.27207266],
#        [0.98359451],
#        [0.39639846],
#        [0.71769432],
#        [0.99413561],
#        [0.99070534],
#        [0.90377049],
#        [0.99660621],
#        [0.53410038],
#        [0.99423282],
#        [0.30187274],
#        [0.9990397 ],
#        [0.99396138],
#        [0.88697776],
#        [0.25293957],
#        [0.99347771],
#        [0.56649602],
#        [0.2548632 ],
#        [0.93508058],
#        [0.98910476],
#        [0.57036291],
#        [0.92600755],
#        [0.9582889 ],
#        [0.67537631],
#        [0.93579145],
#        [0.99875264],
#        [0.99908268],
#        [0.97761058],
#        [0.93806156],
#        [0.75938661],
#        [0.22917227],
#        [0.1805617 ],
#        [0.99374324],
#        [0.99792329],
#        [0.36277503],
#        [0.62906418],
#        [0.99927971],
#        [0.99623902],
#        [0.95073743],
#        [0.99429774],
#        [0.95523932],
#        [0.57105303],
#        [0.6926273 ],
#        [0.15296863],
#        [0.75480261],
#        [0.98926182],
#        [0.99724399],
#        [0.71162972],
#        [0.99854266],
#        [0.94078731],
#        [0.9778885 ],
#        [0.97181368],
#        [0.78024577],
#        [0.97696288],
#        [0.97201981],
#        [0.33107491],
#        [0.84132932],
#        [0.99235188],
#        [0.90925153],
#        [0.98358804],
#        [0.7487629 ],
#        [0.8272433 ],
#        [0.98214704],
#        [0.9944045 ],
#        [0.93730201],
#        [0.9840481 ],
#        [0.99686237],
#        [0.99230347],
#        [0.9544766 ],
#        [0.99357627],
#        [0.54975301],
#        [0.9981835 ],
#        [0.51140781],
#        [0.52350861],
#        [0.81053268],
#        [0.38853402],
#        [0.84151055],
#        [0.14227708],
#        [0.98908476],
#        [0.99464949],
#        [0.06642051],
#        [0.62596682],
#        [0.98510858],
#        [0.78324835]])

# %% [markdown]
# # Fonction Loss -- Log Loss
#
# $L = -{1\over m} \sum{y \times log{(A)} + (1-y) \times log{(1-A)}}$

# %%
def log_loss(A, y):
    return 1 / len(y) * np.sum(-y * np.log(A) - (1 - y) * np.log(1 - A))

# %%
# let's try it w
log_loss(A, y)
# Out:
# 1.9433463716360364

# %% [markdown]
# ## Gradients
#
# $$ \frac {\partial L }{\partial W}  = \frac {1}{m} X^T.(A - y)$$
# $$ \frac {\partial L }{\partial b}  = \frac {1}{m} (A - y)$$

# %%
def gradients(A, X, y):
    dW = 1 / len(y) * np.dot(X.T, A - y)
    db = 1 / len(y) * np.sum(A - y)
    return (dW, db)

# %%
X.T.shape
# Out:
# (2, 100)

# %%
y.shape
# Out:
# (100, 1)

# %%
dW, db = gradients(A, X, y)
dW.shape
# Out:
# (2, 1)

# %% [markdown]
# # Update of features and bias

# %%
def update(dW, db, W, b, learning_rate):
    W = W - learning_rate * dW
    b = b - learning_rate * db
    return (W, b)

# %%
def predict(X, W, b):
    A = model(X, W, b)
    # print(A)
    return A >= 0.5

# %%
from sklearn.metrics import accuracy_score

# %%
def neuron(X, y, learning_rate = 0.1, n_iter = 100):
    # initialisation W, b
    W, b = initialisation(X)

    Loss = []

    for i in range(n_iter):
        A = activation(model(X, W, b))
        Loss.append(log_loss(A, y))
        dW, db = gradients(A, X, y)
        W, b = update(dW, db, W, b, learning_rate)

    y_pred = predict(X, W, b)
    print(accuracy_score(y, y_pred))

    plt.plot(Loss)
    plt.show()

    return (W, b)

# %%
W, b = neuron(X, y)
# Out:
# 0.86

# %%
# Lets try a prediction on a new point

new_point = np.array([2,1])
plt.scatter(X[:,0], X[:, 1], c=y, cmap='winter')
plt.scatter(new_point[0], new_point[1], c='r')
plt.show()


predict(new_point, W, b)
# Out:
# array([ True])

# %%
fig, ax = plt.subplots(figsize=(9, 6))
ax.scatter(X[:,0], X[:, 1], c=y, cmap='summer')

x1 = np.linspace(-1, 4, 100)
x2 = ( - W[0] * x1 - b) / W[1]

ax.plot(x1, x2, c='orange', lw=3)

# %%
import plotly.graph_objects as go

fig = go.Figure(data=[go.Scatter3d( 
    x=X[:, 0].flatten(),
    y=X[:, 1].flatten(),
    z=y.flatten(),
    mode='markers',
    marker=dict(
        size=5,
        color=y.flatten(),                
        colorscale='YlGn',  
        opacity=0.8,
        reversescale=True
    )
)])

fig.update_layout(template= "plotly_dark", margin=dict(l=0, r=0, b=0, t=0))
fig.layout.scene.camera.projection.type = "orthographic"
fig.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\didie\Downloads\BXL-Bouman-2.22-master\BXL-Bouman-2.22-master\content\06.Deep_learning\01-Logistic_Regression\01-Your_first_neural_network\le perceptron.ipynb Cell 23 line 1
#      <a href='vscode-notebook-cell:/c%3A/Users/didie/Downloads/BXL-Bouman-2.22-master/BXL-Bouman-2.22-master/content/06.Deep_learning/01-Logistic_Regression/01-Your_first_neural_network/le%20perceptron.ipynb#X34sZmlsZQ%3D%3D?line=16'>17</a> fig.update_layout(template= "plotly_dark", margin=dict(l=0, r=0, b=0, t=0))
#      <a href='vscode-notebook-cell:/c%3A/Users/didie/Downloads/BXL-Bouman-2.22-master/BXL-Bouman-2.22-master/content/06.Deep_learning/01-Logistic_Regression/01-Your_first_neural_network/le%20perceptron.ipynb#X34sZmlsZQ%3D%3D?line=17'>18</a> fig.layout.scene.camera.projection.type = "orthographic"
# ---> <a href='vscode-notebook-cell:/c%3A/Users/didie/Downloads/BXL-Bouman-2.22-master/BXL-Bouman-2.22-master/content/06.Deep_learning/01-Logistic_Regression/01-Your_first_neural_network/le%20perceptron.ipynb#X34sZmlsZQ%3D%3D?line=18'>19</a> fig.show()
#
# File c:\Users\didie\anaconda3\envs\deepLenv\lib\site-packages\plotly\basedatatypes.py:3412, in BaseFigure.show(self, *args, **kwargs)
#    3379 """
#    3380 Show a figure using either the default renderer(s) or the renderer(s)
#    3381 specified by the renderer argument
#    (...)
#    3408 None
#    3409 """
#    3410 import plotly.io as pio
# -> 3412 return pio.show(self, *args, **kwargs)
#
# File c:\Users\didie\anaconda3\envs\deepLenv\lib\site-packages\plotly\io\_renderers.py:396, in show(fig, renderer, validate, **kwargs)
#     391         raise ValueError(
#     392             "Mime type rendering requires ipython but it is not installed"
#     393         )
#     395     if not nbformat or Version(nbformat.__version__) < Version("4.2.0"):
# --> 396         raise ValueError(
#     397             "Mime type rendering requires nbformat>=4.2.0 but it is not installed"
#     398         )
#     400     ipython_display.display(bundle, raw=True)
#     402 # external renderers
#
# ValueError: Mime type rendering requires nbformat>=4.2.0 but it is not installed
