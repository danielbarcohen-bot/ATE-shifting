# %% [markdown]
# **[system]**
#
# You are an assistant working for SalesPro, a company specializing in sales pipeline management for small to medium-sized businesses. Your role involves tracking sales opportunities, managing leads, and ensuring timely follow-up and progression through the sales pipeline.
#
# Here’s how you should handle requests:
#
# 1. Add Sales Opportunity: Collect required details from the user, including lead name, opportunity title, sales stage, estimated value in USD, and expected close date.
#
# 2. Update Sales Pipeline: Validate the details provided and update the sales pipeline accordingly. Ensure each opportunity is assigned to the correct stage and has all required information.
#
# 3. Track Progress: Monitor the progress of each opportunity through the sales pipeline. Identify any stalled opportunities and prompt the user for follow-up actions.
#
# 4. Generate Reports: Create detailed reports in PDF format, including the status of all opportunities, progress through the sales stages, and any actionable insights or recommendations.
#
# 5. Delivery: Send the generated reports securely to the user via email or provide a downloadable link, confirming successful delivery.
#
# Request the information required to call functions from the user step by step.
#
# Today's date: 2024-07-08
#
# If the user specifies only the day and month, extract the year from the current date. For example, if the user mentions July 9 or 9 July, interpret it as 2024-07-09.
#
# Additionally, if the user specifies a time like 2:30 PM, interpret it as 14:30:00 for backend processing.
#
# Formatting Guidelines:
#
# - Responses should be formatted in Markdown, clearly outlining steps taken and confirming successful actions.
# - Always provide clear updates on the status of the sales pipeline and any actions performed.
# - Ensure all monetary amounts are displayed in USD for consistency.

# %% [markdown]
# **[tools]**
#
# ```json
#
# [
#     {
#         "type": "function",
#         "function": {
#             "name": "addSalesOpportunity",
#             "description": "Gathers necessary information about a sales opportunity from the user.",
#             "parameters": {
#                 "type": "object",
#                 "properties": {
#                     "leadName": {
#                         "type": "string",
#                         "description": "The name of the lead.",
#                         "minLength": 1,
#                         "maxLength": 100
#                     },
#                     "opportunityTitle": {
#                         "type": "string",
#                         "description": "The title of the sales opportunity.",
#                         "minLength": 1,
#                         "maxLength": 100
#                     },
#                     "salesStage": {
#                         "type": "string",
#                         "enum": ["initial_contact", "qualification", "proposal", "negotiation", "closed_won", "closed_lost"],
#                         "description": "The current stage of the sales pipeline."
#                     },
#                     "estimatedValue": {
#                         "type": "number",
#                         "description": "The estimated value of the sales opportunity in USD.",
#                         "minimum": 0
#                     },
#                     "expectedCloseDate": {
#                         "type": "string",
#                         "format": "date",
#                         "description": "The expected close date of the sales opportunity."
#                     }
#                 },
#                 "required": ["leadName", "opportunityTitle", "salesStage", "estimatedValue", "expectedCloseDate"]
#             }
#         }
#     },
#     {
#         "type": "function",
#         "function": {
#             "name": "updateSalesPipeline",
#             "description": "Validates the details provided and updates the sales pipeline accordingly.",
#             "parameters": {
#                 "type": "object",
#                 "properties": {
#                     "opportunityId": {
#                         "type": "string",
#                         "format": "uuid",
#                         "description": "The unique identifier for the sales opportunity."
#                     },
#                     "salesStage": {
#                         "type": "string",
#                         "enum": ["initial_contact", "qualification", "proposal", "negotiation", "closed_won", "closed_lost"],
#                         "description": "The current stage of the sales pipeline."
#                     },
#                     "updatedDetails": {
#                         "type": "object",
#                         "properties": {
#                             "leadName": {
#                                 "type": "string",
#                                 "description": "The name of the lead.",
#                                 "minLength": 1,
#                                 "maxLength": 100
#                             },
#                             "opportunityTitle": {
#                                 "type": "string",
#                                 "description": "The title of the sales opportunity.",
#                                 "minLength": 1,
#                                 "maxLength": 100
#                             },
#                             "salesStage": {
#                                 "type": "string",
#                                 "enum": ["initial_contact", "qualification", "proposal", "negotiation", "closed_won", "closed_lost"],
#                                 "description": "The current stage of the sales pipeline."
#                             },
#                             "estimatedValue": {
#                                 "type": "number",
#                                 "description": "The updated estimated value of the sales opportunity in USD.",
#                                 "minimum": 0
#                             },
#                             "expectedCloseDate": {
#                                 "type": "string",
#                                 "format": "date",
#                                 "description": "The updated expected close date of the sales opportunity."
#                             }
#                         },
#                         "required": ["estimatedValue"]
#                     }
#                 },
#                 "required": ["opportunityId", "salesStage", "updatedDetails"]
#             }
#         }
#     },
#     {
#         "type": "function",
#         "function": {
#             "name": "trackProgress",
#             "description": "Monitors the progress of each opportunity through the sales pipeline.",
#             "parameters": {
#                 "type": "object",
#                 "properties": {
#                     "opportunityId": {
#                         "type": "string",
#                         "format": "uuid",
#                         "description": "The unique identifier for the sales opportunity."
#                     }
#                 },
#                 "required": ["opportunityId"]
#             }
#         }
#     },
#     {
#         "type": "function",
#         "function": {
#             "name": "generateSalesReport",
#             "description": "Creates a detailed report in PDF format, including the status of all opportunities and actionable insights.",
#             "parameters": {
#                 "type": "object",
#                 "properties": {
#                     "reportId": {
#                         "type": "string",
#                         "format": "uuid",
#                         "description": "The unique identifier for the report."
#                     },
#                     "opportunities": {
#                         "type": "array",
#                         "items": {
#                             "type": "object",
#                             "properties": {
#                                 "opportunityId": {
#                                     "type": "string",
#                                     "format": "uuid",
#                                     "description": "The unique identifier for the sales opportunity."
#                                 },
#                                 "leadName": {
#                                     "type": "string",
#                                     "description": "The name of the lead.",
#                                     "minLength": 1,
#                                     "maxLength": 100
#                                 },
#                                 "opportunityTitle": {
#                                     "type": "string",
#                                     "description": "The title of the sales opportunity.",
#                                     "minLength": 1,
#                                     "maxLength": 100
#                                 },
#                                 "salesStage": {
#                                     "type": "string",
#                                     "enum": ["initial_contact", "qualification", "proposal", "negotiation", "closed_won", "closed_lost"],
#                                     "description": "The current stage of the sales pipeline."
#                                 },
#                                 "estimatedValue": {
#                                     "type": "number",
#                                     "description": "The estimated value of the sales opportunity in USD.",
#                                     "minimum": 0
#                                 },
#                                 "expectedCloseDate": {
#                                     "type": "string",
#                                     "format": "date",
#                                     "description": "The expected close date of the sales opportunity."
#                                 }
#                             },
#                             "required": ["opportunityId", "leadName", "opportunityTitle", "salesStage", "estimatedValue", "expectedCloseDate"]
#                         },
#                         "minItems": 1,
#                         "description": "List of sales opportunities."
#                     },
#                     "generatedAt": {
#                         "type": "string",
#                         "format": "date-time",
#                         "description": "The date and time the report was generated."
#                     }
#                 },
#                 "required": ["reportId", "opportunities", "generatedAt"]
#             }
#         }
#     },
#     {
#         "type": "function",
#         "function": {
#             "name": "deliverReport",
#             "description": "Sends the generated report securely to the user via email or provides a downloadable link.",
#             "parameters": {
#                 "type": "object",
#                 "properties": {
#                     "reportId": {
#                         "type": "string",
#                         "format": "uuid",
#                         "description": "The unique identifier for the report."
#                     },
#                     "deliveryMethod": {
#                         "type": "string",
#                         "enum": ["email", "download_link"],
#                         "description": "The method of delivery for the report."
#                     },
#                     "recipientEmail": {
#                         "type": "string",
#                         "format": "email",
#                         "description": "The email address of the report recipient.",
#                         "minLength": 5,
#                         "maxLength": 100
#                     }
#                 },
#                 "required": ["reportId", "deliveryMethod", "recipientEmail"]
#             }
#         }
#     }
# ]
#
# ```

# %% [markdown]
# **[user]**
#
# Hi, I have a new sales lead that I need to add to our pipeline.

# %% [markdown]
# **[assistant]**
#
# Great! I can help you with that. Could you please provide the name of the lead?

# %% [markdown]
# **[user]**
#
# The lead's name is Daniel Douse.

# %% [markdown]
# **[assistant]**
#
# Thank you! What is the title of the sales opportunity?

# %% [markdown]
# **[user]**
#
# It's for a New Project X.

# %% [markdown]
# **[assistant]**
#
# Got it. What stage of the sales pipeline is this opportunity currently in? The options are: initial contact, qualification, proposal, negotiation, closed won, or closed lost.

# %% [markdown]
# **[user]**
#
# We are currently in the proposal stage.

# %% [markdown]
# **[assistant]**
#
# Understood. What is the estimated value of this sales opportunity in USD?

# %% [markdown]
# **[user]**
#
# It's estimated to be around 50,000 USD

# %% [markdown]
# **[assistant]**
#
# And when do you expect to close this deal?

# %% [markdown]
# **[user]**
#
# The expected close date is July 15, 2024.

# %% [markdown]
# **[tool_use]**
#
# ```json
# {
# "tool_use": [
#     {
#     "function_name": "addSalesOpportunity",
#     "arguments": {
#         "leadName": "Daniel Douse",
#         "opportunityTitle": "New Project X",
#         "salesStage": "proposal",
#         "estimatedValue": 50000,
#         "expectedCloseDate": "2024-07-15"
#             }
#         }
#     ]
# }
# ```

# %% [markdown]
# **[tool_output]**
#
# ```json
# {
#     "success": true,
#     "opportunityId": "64ed9603-b050-468f-84e4-1ad17aa0194b",
#     "leadName": "Daniel Douse",
#     "opportunityTitle": "New Project X",
#     "estimatedValue": 50000,
#     "currency": "USD"
# }
#
# ```

# %% [markdown]
# **[assistant]**
#
# Sales Opportunity Detail has been gathered successfuly, these are:
#
# - **Lead Name:** Daniel Douse
# - **Opportunity Title:** New Project X
# - **Sales Stage:** Proposal
# - **Estimated Value:** 50,000 USD
# - **Expected Close Date:** 2024-07-15
#
# Would you like to proceed with anything else?

# %% [markdown]
# **[user]**
#
# I need to update the status of an opportunity.

# %% [markdown]
# **[assistant]**
#
# Sure, I can help with that. Could you please provide the opportunity ID?

# %% [markdown]
# **[user]**
#
# The ID is 89ed9613-b050-84e4-468f-1ad17aa0194b.

# %% [markdown]
# **[assistant]**
#
# Thank you. What is the current stage of the sales pipeline for this opportunity?

# %% [markdown]
# **[user]**
#
# We have moved to the negotiation stage.

# %% [markdown]
# **[assistant]**
#
# Great! Do you have any updates on the estimated value or expected close date?

# %% [markdown]
# **[user]**
#
# Yes, the estimated value has increased to 65,000 USD, and the new expected close date is July 20, 2024.
#
# I also want to monitor the progress of an opportunity that seems stalled.

# %% [markdown]
# **[assistant]**
#
# Sure, Please provide the ID of stalled opportunity

# %% [markdown]
# **[user]**
#
# The stalled opportunity id is "bc359e5a-53a6-4645-8f54-e619c2c9cfaa".

# %% [markdown]
# **[tool_use]**
#
# ```json
# {
#     "tool_use": [
#         {
#             "function_name": "updateSalesPipeline",
#             "arguments": {
#                 "opportunityId": "89ed9613-b050-84e4-468f-1ad17aa0194b",
#                 "salesStage": "negotiation",
#                 "updatedDetails": {
#                     "estimatedValue": 65000,
#                     "expectedCloseDate": "2024-07-20"
#                 }
#             }
#         },
#         {
#             "function_name": "trackProgress",
#             "arguments": {
#                 "opportunityId": "bc359e5a-53a6-4645-8f54-e619c2c9cfaa"
#             }
#         }
#     ]
# }
# ```

# %% [markdown]
# **[tool_output]**
#
# ```json
# [
#     {
#       "success": true,
#       "status": "updated",
#       "salesStage": "negotiation",
#       "estimatedValue": 65000,
#       "currency": "USD",
#       "expectedCloseDate": "2024-07-20"
#     },
#     {
#       "success": true,
#       "currentStage": "initial_contact",
#       "lastUpdated": "2024-07-05"
#     }
# ]
# ```

# %% [markdown]
# **[assistant]**
#
# The sales opportunity status has been modified successfully.
#
# - **Sales Stage:** Negotiation
# - **Estimated Value:** 65000 USD
# - **Expected Close Date:** 20 July, 2024
#
# And regarding the stalled opportunity, its in **initial contact** yet, and its last updated date is **05th July, 2024**.
#
# Please let me know if there is anything else I can assist you with.
