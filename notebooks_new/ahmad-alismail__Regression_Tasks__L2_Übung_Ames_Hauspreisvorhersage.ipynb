# %% [markdown]
# # Übung: Ames Housing Dataset - Hauspreisvorhersage
#
#
# In dieser Übung werden Sie verschiedene Regressionstechniken auf den Ames Housing Dataset anwenden. Das Dataset enthält Informationen über 2.930 Wohnimmobilien in Ames, Iowa, von 2006 bis 2010.
#
# **Lernziele:**
# - Datenvorbereitung und -bereinigung durchführen
# - Lineare Regression, Ridge und Lasso Regression implementieren
# - Nichtlineare Modelle mit B-Splines erstellen
# - Modellbewertung und Vergleich durchführen
# - Residualanalyse interpretieren
#
# **Hinweise zur Bearbeitung:**
# - Lesen Sie jede Aufgabe sorgfältig durch
# - Nutzen Sie die bereitgestellten Hinweise
# - Kommentieren Sie Ihren Code
# - Interpretieren Sie die Ergebnisse

# %% [markdown]
# ## Aufgabe 1: Datenladung und erste Exploration
#
# **Aufgabe:** Laden Sie das Ames Housing Dataset und führen Sie eine erste Datenexploration durch.
#
# **Was Sie tun sollen:**
# 1. Importieren Sie alle notwendigen Bibliotheken
# 2. Laden Sie das Dataset aus 'data/AmesHousing.txt' (Tab-separiert)
# 3. Zeigen Sie die ersten 5 Zeilen an
# 4. Überprüfen Sie die Dimensionen des DataFrames
#
# **Hinweise:**
# - Verwenden Sie `pd.read_csv()` mit dem Parameter `sep='\t'` für Tab-separierte Dateien
# - Sie benötigen: pandas, numpy, plotly, sklearn, warnings
# - Das Dataset sollte 2.930 Zeilen und 80 Spalten haben

# %%
import pandas as pd
import numpy as np
import plotly.graph_objects as go
from plotly.subplots import make_subplots
import warnings
warnings.filterwarnings('ignore')
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.model_selection import train_test_split
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# Load the full dataset
df = pd.read_csv('data/AmesHousing.txt', sep='\t')

df.head()

# %%
# TODO: Dimensionen überprüfen

# %% [markdown]
# ## Aufgabe 2: Analyse fehlender Werte
#
# **Aufgabe:** Analysieren Sie die Datenqualität, insbesondere fehlende Werte.
#
# **Was Sie tun sollen:**
# 1. Zählen Sie fehlende Werte pro Spalte
# 2. Sortieren Sie die Ergebnisse absteigend
# 3. Identifizieren Sie die Zielvariable und prüfen Sie, ob sie fehlende Werte hat
#
# **Hinweise:**
# - Verwenden Sie `df.isnull().sum()` zum Zählen fehlender Werte
# - Die Zielvariable ist 'SalePrice'
# - Hohe Anzahl fehlender Werte bei Features wie 'Pool QC' ist normal (die meisten Häuser haben keinen Pool)

# %%
# Ihr Code hier:
# TODO: Fehlende Werte analysieren

# TODO: Zielvariable definieren und prüfen

# %% [markdown]
# ## Aufgabe 3: Datenvorbereitung - Features und Zielvariable trennen
#
# **Aufgabe:** Bereiten Sie die Daten für das Machine Learning vor, indem Sie Features von der Zielvariable trennen.
#
# **Was Sie tun sollen:**
# 1. Trennen Sie die Features von der Zielvariable 'SalePrice'
# 2. Konvertieren Sie die Zielvariable zu einem NumPy Array
# 3. Überprüfen Sie die Form der resultierenden Datenstrukturen
#
# **Hinweise:**
# - Verwenden Sie `df.drop(columns=[target])` um Features zu erhalten
# - Verwenden Sie `.values` um pandas Series zu NumPy Array zu konvertieren
# - Die Features sollten 79 Spalten haben (80 minus 1 Zielvariable)

# %%
# Ihr Code hier:
# TODO: Features und Zielvariable trennen

# TODO: Form überprüfen

# %% [markdown]
# ## Aufgabe 4: Umgang mit fehlenden Werten
#
# **Aufgabe:** Implementieren Sie eine systematische Strategie zum Umgang mit fehlenden Werten.
#
# **Was Sie tun sollen:**
# 1. Entfernen Sie Spalten mit mehr als 50% fehlenden Werten
# 2. Füllen Sie kategorische Variablen mit dem Modus oder 'Unknown'
# 3. Füllen Sie numerische Variablen mit dem Median
# 4. Entfernen Sie die 'PID' Spalte (falls vorhanden)
#
# **Hinweise:**
# - Verwenden Sie `dropna(thresh=threshold, axis=1)` für Spalten-Schwellenwert
# - Identifizieren Sie kategorische Spalten mit `select_dtypes(include=['object'])`
# - Verwenden Sie `fillna()` mit `.mode()[0]` oder `.median()`
# - Der Schwellenwert für 50% ist `len(features) * 0.5`

# %%
# Ihr Code hier:
# TODO: Spalten mit zu vielen fehlenden Werten entfernen

# TODO: Fehlende Werte auffüllen

# TODO: PID Spalte entfernen

# %% [markdown]
# ## Aufgabe 5: Kategorische Variablen kodieren
#
# **Aufgabe:** Konvertieren Sie kategorische Variablen in numerische Form für Machine Learning Algorithmen.
#
# **Was Sie tun sollen:**
# 1. Identifizieren Sie alle kategorischen Spalten
# 2. Verwenden Sie LabelEncoder für jede kategorische Spalte
# 3. Speichern Sie die Encoder für spätere Verwendung
# 4. Zeigen Sie die ersten 5 Zeilen der bereinigten Daten an
#
# **Hinweise:**
# - Importieren Sie `LabelEncoder` von sklearn.preprocessing
# - Verwenden Sie eine Schleife über alle kategorischen Spalten
# - Konvertieren Sie Spalten zu String mit `.astype(str)` vor dem Encoding
# - Speichern Sie Encoder in einem Dictionary für Rücktransformation

# %%
# Ihr Code hier:
# TODO: LabelEncoder importieren

# TODO: Kategorische Spalten identifizieren

# TODO: Label Encoding durchführen

# TODO: Ergebnis anzeigen

# %% [markdown]
# ## Aufgabe 6: Finale Datenvorbereitung
#
# **Aufgabe:** Konvertieren Sie die bereinigten Daten zu NumPy Arrays und entfernen Sie ungültige Zeilen.
#
# **Was Sie tun sollen:**
# 1. Konvertieren Sie das bereinigte DataFrame zu einem NumPy Array
# 2. Entfernen Sie Zeilen wo die Zielvariable fehlt
# 3. Stellen Sie sicher, dass X und y die gleiche Anzahl von Samples haben
# 4. Geben Sie die finale Datensatz-Form aus
#
# **Hinweise:**
# - Verwenden Sie `.values` für die Konvertierung zu NumPy
# - Verwenden Sie `~pd.isna(y)` um gültige Indizes zu finden
# - Überprüfen Sie, dass `X.shape[0] == len(y)`

# %%
# Ihr Code hier:
# TODO: Zu NumPy Arrays konvertieren

# TODO: Ungültige Zeilen entfernen

# TODO: Finale Form ausgeben

# %% [markdown]
# ## Aufgabe 7: Train/Test Split und Standardisierung
#
# **Aufgabe:** Teilen Sie die Daten in Trainings- und Testsets auf und standardisieren Sie sie.
#
# **Was Sie tun sollen:**
# 1. Teilen Sie die Daten in 70% Training und 30% Test auf
# 2. Erstellen Sie separate StandardScaler für Features und Zielvariable
# 3. Fitten Sie die Scaler nur auf Trainingsdaten
# 4. Transformieren Sie sowohl Trainings- als auch Testdaten
# 5. Geben Sie die Formen der standardisierten Datasets aus
#
# **Hinweise:**
# - Verwenden Sie `train_test_split` mit `test_size=0.3, random_state=123`
# - Importieren Sie `StandardScaler` von sklearn.preprocessing
# - Verwenden Sie `.reshape(-1, 1)` für 1D Arrays beim Scaling
# - Verwenden Sie `.flatten()` um zurück zu 1D Arrays zu konvertieren

# %%
# Ihr Code hier:
# TODO: Notwendige Importe

# TODO: Train/Test Split

# TODO: StandardScaler erstellen und anwenden

# TODO: Formen ausgeben

# %% [markdown]
# ## Aufgabe 8: Baseline-Modell - Lineare Regression
#
# **Aufgabe:** Implementieren Sie ein Baseline-Modell mit linearer Regression.
#
# **Was Sie tun sollen:**
# 1. Importieren Sie LinearRegression von sklearn
# 2. Trainieren Sie das Modell auf standardisierten Trainingsdaten
# 3. Machen Sie Vorhersagen für Trainings- und Testdaten
# 4. Transformieren Sie Vorhersagen zurück zur ursprünglichen Skala
# 5. Berechnen Sie R² Score und RMSE für beide Sets
# 6. Testen Sie das Modell an einem Beispielhaus
#
# **Hinweise:**
# - Verwenden Sie `r2_score` und `root_mean_squared_error` von sklearn.metrics
# - Verwenden Sie `sc_y.inverse_transform()` um Vorhersagen zurückzutransformieren
# - Ein gutes Modell sollte R² > 0.7 haben
# - Verwenden Sie ein spezifisches Beispiel (z.B. Index 4) zum Testen

# %%
# Ihr Code hier:
# TODO: Notwendige Importe

# TODO: Modell trainieren

# TODO: Vorhersagen machen

# TODO: Zurück zur ursprünglichen Skala transformieren

# TODO: Metriken berechnen

# TODO: Beispielvorhersage testen

# %% [markdown]
# ## Aufgabe 9: Ridge Regression mit Hyperparameter-Tuning
#
# **Aufgabe:** Implementieren Sie Ridge Regression mit L2-Regularisierung und finden Sie den optimalen Alpha-Wert.
#
# **Was Sie tun sollen:**
# 1. Testen Sie verschiedene Alpha-Werte: [0.01, 0.1, 1.0, 10.0, 100.0, 1000.0]
# 2. Verwenden Sie 5-fache Kreuzvalidierung für jedes Alpha
# 3. Finden Sie das beste Alpha basierend auf dem R² Score
# 4. Trainieren Sie das finale Modell mit dem besten Alpha
# 5. Evaluieren Sie die Performance auf Test- und Trainingsdaten
#
# **Hinweise:**
# - Importieren Sie `Ridge` und `cross_val_score` von sklearn
# - Verwenden Sie `cv=5, scoring='r2'` für Kreuzvalidierung
# - Speichern Sie das beste Alpha und den besten Score
# - Vergleichen Sie die Ergebnisse mit der linearen Regression

# %%
# Ihr Code hier:
# TODO: Notwendige Importe

# TODO: Alpha-Werte testen

# TODO: Bestes Alpha finden

# TODO: Finales Modell trainieren

# TODO: Performance evaluieren

# %% [markdown]
# ## Aufgabe 10: Ridge Regression von Grund auf implementieren
#
# **Aufgabe:** Implementieren Sie Ridge Regression von Grund auf, um das mathematische Verständnis zu vertiefen.
#
# **Was Sie tun sollen:**
# 1. Erstellen Sie eine Klasse `RidgeRegressionScratch`
# 2. Implementieren Sie die `fit` Methode mit der regularisierten Normal-Gleichung
# 3. Implementieren Sie `predict` und `score` Methoden
# 4. Testen Sie Ihre Implementierung gegen sklearn's Ridge
# 5. Vergleichen Sie die R² Scores
#
# **Hinweise:**
# - Die Ridge-Gleichung: w = (X^T X + αI)^(-1) X^T y
# - Regularisieren Sie nicht den Bias-Term (erste Zeile/Spalte der Identitätsmatrix)
# - Verwenden Sie `np.linalg.solve()` statt Matrixinversion
# - Verwenden Sie `np.column_stack()` um Bias-Spalte hinzuzufügen

# %%
# Ihr Code hier:
# TODO: RidgeRegressionScratch Klasse implementieren

# TODO: Mit sklearn vergleichen

# %% [markdown]
# ## Aufgabe 11: Lasso Regression für Feature-Selektion
#
# **Aufgabe:** Implementieren Sie Lasso Regression mit L1-Regularisierung für automatische Feature-Selektion.
#
# **Was Sie tun sollen:**
# 1. Testen Sie dieselben Alpha-Werte wie bei Ridge
# 2. Verwenden Sie Kreuzvalidierung um das beste Alpha zu finden
# 3. Trainieren Sie das finale Lasso-Modell
# 4. Analysieren Sie, wie viele Features ausgewählt wurden
# 5. Vergleichen Sie die Performance mit Ridge und linearer Regression
#
# **Hinweise:**
# - Importieren Sie `Lasso` von sklearn.linear_model
# - Setzen Sie `max_iter=2000` für Konvergenz
# - Verwenden Sie `np.sum(lasso.coef_ != 0)` um nicht-null Koeffizienten zu zählen
# - Lasso kann Koeffizienten auf exakt 0 setzen (automatische Feature-Selektion)

# %%
# Ihr Code hier:
# TODO: Lasso implementieren

# TODO: Feature-Selektion analysieren

# TODO: Performance vergleichen

# %% [markdown]
# ## Aufgabe 12: Nichtlineare Modellierung mit B-Splines
#
# **Aufgabe:** Implementieren Sie nichtlineare Modellierung mit B-Splines für wichtige kontinuierliche Features.
#
# **Was Sie tun sollen:**
# 1. Identifizieren Sie wichtige kontinuierliche Features: ['Gr Liv Area', 'Total Bsmt SF', 'Garage Area', 'Lot Area']
# 2. Testen Sie verschiedene Spline-Konfigurationen (Grad: 2,3,4 und Knoten: 3,5,7)
# 3. Verwenden Sie Kreuzvalidierung um die beste Konfiguration zu finden
# 4. Kombinieren Sie Spline-Features mit den verbleibenden Features
# 5. Trainieren Sie ein Ridge-Modell mit den Spline-Features
#
# **Hinweise:**
# - Importieren Sie `SplineTransformer` von sklearn.preprocessing
# - Finden Sie Feature-Indizes mit `feature_names.index(feature)`
# - Verwenden Sie `np.hstack()` um Spline- und verbleibende Features zu kombinieren
# - Setzen Sie `include_bias=False` im SplineTransformer

# %%
# Ihr Code hier:
# TODO: SplineTransformer importieren

# TODO: Wichtige Features identifizieren

# TODO: Spline-Konfigurationen testen

# TODO: Beste Konfiguration finden

# %% [markdown]
# ## Aufgabe 13: Finales Spline-Modell trainieren
#
# **Aufgabe:** Trainieren Sie das finale Spline-Modell mit der besten gefundenen Konfiguration.
#
# **Was Sie tun sollen:**
# 1. Erstellen Sie den finalen SplineTransformer mit den besten Parametern
# 2. Transformieren Sie Trainings- und Testdaten
# 3. Kombinieren Sie Spline-Features mit verbleibenden Features
# 4. Trainieren Sie ein Ridge-Modell mit den transformierten Daten
# 5. Berechnen Sie Performance-Metriken und vergleichen Sie mit vorherigen Modellen
# 6. Testen Sie das Modell an einem Beispielhaus
#
# **Hinweise:**
# - Verwenden Sie dieselbe Preprocessing-Pipeline wie beim Hyperparameter-Tuning
# - Transformieren Sie Vorhersagen zurück zur ursprünglichen Skala für Vergleiche
# - Das Spline-Modell sollte die beste Performance zeigen
# - Dokumentieren Sie die Anzahl der Features nach Spline-Transformation

# %%
# Ihr Code hier:
# TODO: Finales Spline-Modell trainieren

# TODO: Performance evaluieren

# TODO: Modellvergleich

# TODO: Beispielvorhersage

# %% [markdown]
# ## Aufgabe 14: Umfassende Residualanalyse
#
# **Aufgabe:** Erstellen Sie eine umfassende Residualanalyse für alle Modelle.
#
# **Was Sie tun sollen:**
# 1. Berechnen Sie Residuen für alle Modelle (Ridge, Lasso, Spline Ridge)
# 2. Erstellen Sie Predicted vs Actual Plots für jedes Modell
# 3. Erstellen Sie Residual vs Predicted Plots für jedes Modell
# 4. Berechnen Sie zusammenfassende Statistiken (R², RMSE, mittlere Residuen)
# 5. Interpretieren Sie die Ergebnisse bezüglich Modellqualität
#
# **Hinweise:**
# - Verwenden Sie plotly für interaktive Visualisierungen
# - Erstellen Sie Subplots mit `make_subplots(rows=2, cols=3)`
# - Verwenden Sie verschiedene Farben für Trainings- und Testdaten
# - Fügen Sie die perfekte Vorhersagelinie (y=x) und Nulllinie für Residuen hinzu
# - Analysieren Sie Patterns in den Residualplots

# %%
# Ihr Code hier:
# TODO: Plotly importieren

# TODO: Residuen berechnen

# TODO: Visualisierungen erstellen

# TODO: Zusammenfassende Statistiken

# TODO: Interpretation
