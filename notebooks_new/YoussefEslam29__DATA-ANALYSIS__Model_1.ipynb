# %% [markdown]
# # Type your Name and Registration Number Here:

# %%
'''
Name: 
Registration Number: 
'''

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Part A: Data Loading and Exploration

# %% [markdown]
# ## Question 1:
# ##  Load the 'fifa_eda.csv' dataset. Store it in a variable named **`df`**.

# %% [markdown]
# **💡Hints**\
# **pandas.read_csv():** Read a comma-separated values (csv) file into DataFrame.

# %%
df = pd.read_csv("fifa_eda.csv")

# %% [markdown]
# ## Question 2
# ## Print a Python list containing the column names of the dataframe.

# %% [markdown]
# **💡Hints**\
# **DataFrame.columns:** Returns column labels in the DataFrame.\
# **Series.tolist():** Converts a pandas Series to a regular Python list.

# %%
df.columns.tolist()
# Out:
# ['id',
#  'ID',
#  'Name',
#  'Age',
#  'Nationality',
#  'Overall',
#  'Potential',
#  'Club',
#  'Value',
#  'Wage',
#  'Preferred Foot',
#  'International Reputation',
#  'Skill Moves',
#  'Position',
#  'Contract Valid Until',
#  'Height',
#  'Weight',
#  'Release Clause']

# %% [markdown]
# ## Question 3:
# ## Inspect the dataset structure

# %% [markdown]
# **💡Hints**\
# **DataFrame.info():** Print a concise summary of a DataFrame.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 18 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   id                        1000 non-null   int64
#  1   ID                        1000 non-null   int64
#  2   Name                      800 non-null    object
#  3   Age                       1000 non-null   int64
#  4   Nationality               800 non-null    object
#  5   Overall                   1000 non-null   int64
#  6   Potential                 1000 non-null   int64
#  7   Club                      793 non-null    object
#  8   Value                     992 non-null    float64
#  9   Wage                      700 non-null    float64
#  10  Preferred Foot            800 non-null    object
#  11  International Reputation  1000 non-null   float64
#  12  Skill Moves               1000 non-null   float64
#  13  Position                  800 non-null    object
#  14  Contract Valid Until      795 non-null    object
#  15  Height                    1000 non-null   float64
#  16  Weight                    700 non-null    float64
#  17  Release Clause            1000 non-null   float64
# dtypes: float64(7), int64(5), object(6)
# memory usage: 140.8+ KB

# %% [markdown]
# ## Answer the following questions:
# ### a. What is the data type of Club in the dataset?
# ### b. How many features don't have null-values?

# %%
'''
Write your answers here
a.object 
b.17
'''

# %% [markdown]
# ## Question 4
# ## Display the dataframe with these columns only: "Name", "Age",  "Club", and "Release Clause".
# ## **Show only the first 12 rows of this dataframe.**

# %% [markdown]
# **💡Hints**\
# **DataFrame[[col1,col2]]:** Selects multiple columns (col1, col2, etc.) from the DataFrame and returns them as a new DataFrame.\
# **DataFrame.head():** Returns the first few rows of the DataFrame.

# %%
df[["Name","Age","Club","Release Clause"]].head(8)
# Out:
#                 Name  Age                 Club  Release Clause
# 0                NaN   31         FC Barcelona        226500.0
# 1  Cristiano Ronaldo   33             Juventus        127100.0
# 2          Neymar Jr   26  Paris Saint-Germain        228100.0
# 3             De Gea   27    Manchester United        138600.0
# 4       K. De Bruyne   27      Manchester City        196400.0
# 5          E. Hazard   27                  NaN        172100.0
# 6          L. Modrić   32          Real Madrid        137400.0
# 7          L. Suárez   31         FC Barcelona        164000.0

# %% [markdown]
# # Part B: Dataset Modification and Descriptive Analysis

# %% [markdown]
# ## Question 5:
# ##	Rename the new column "Release Clause" to "Clause".

# %% [markdown]
# **💡Hints**\
# **`DataFrame.rename(columns={'old_name': 'new_name'}, inplace= )`**: Renames one or more columns in the DataFrame.
# **`inplace=True`**: Applies the changes directly to the original DataFrame.
# **`inplace=False`**: Returns a new DataFrame with the changes, leaving the original unchanged.

# %%
df.rename(columns= {'Release Clause':'Clause'}, inplace= True)

# %%
df.describe()
# Out:
#                 id             ID          Age      Overall    Potential  \
# count  1000.000000    1000.000000  1000.000000  1000.000000  1000.000000
# mean    500.500000  193376.026000    27.374000    80.625000    82.507000
# std     288.819436   31251.621976     3.763015     3.038026     3.750469
# min       1.000000      41.000000    18.000000    77.000000    77.000000
# 25%     250.750000  182855.500000    25.000000    78.000000    80.000000
# 50%     500.500000  199197.500000    27.000000    80.000000    82.000000
# 75%     750.250000  211332.000000    30.000000    82.000000    85.000000
# max    1000.000000  244369.000000    40.000000    94.000000    95.000000
#
#                Value        Wage  International Reputation  Skill Moves  \
# count     992.000000  700.000000               1000.000000  1000.000000
# mean    18919.959677   65.077143                  2.143000     3.001000
# std     14493.247142   63.496678                  0.866777     1.038305
# min       600.000000    0.000000                  1.000000     1.000000
# 25%     10000.000000   26.000000                  2.000000     2.000000
# 50%     14500.000000   46.000000                  2.000000     3.000000
# 75%     22000.000000   82.250000                  3.000000     4.000000
# max    118500.000000  565.000000                  5.000000     5.000000
#
#             Height      Weight         Clause
# count  1000.000000    700.0000    1000.000000
# mean      5.971500   7976.6200   34854.053040
# std       0.225190  13256.9027   28758.597719
# min       5.333333    130.0000    1100.000000
# 25%       5.833333    163.0000   17900.000000
# 50%       6.000000    177.5000   27100.000000
# 75%       6.166667  16630.2500   42525.000000
# max       6.583333  46355.0000  228100.000000

# %% [markdown]
# ## Question 6:
# ##	Add a new column to your DataFrame '**Improvement**' that represents each person's Improvement using the equation:
# ###Improvement = Potential - Overall

# %% [markdown]
# **💡Hints**\
# **`DataFrame[['col_name']`**: Accesses the data in this column.

# %%
df['Improvment'] = df['Potential'] - df['Overall']

# %% [markdown]
# ## 7.	Generate descriptive statistics on the dataframe.

# %% [markdown]
# **`DataFrame.describe()`**: Generates summary statistics for numerical columns in the DataFrame.

# %%
df.describe()
# Out:
#                 id             ID          Age      Overall    Potential  \
# count  1000.000000    1000.000000  1000.000000  1000.000000  1000.000000
# mean    500.500000  193376.026000    27.374000    80.625000    82.507000
# std     288.819436   31251.621976     3.763015     3.038026     3.750469
# min       1.000000      41.000000    18.000000    77.000000    77.000000
# 25%     250.750000  182855.500000    25.000000    78.000000    80.000000
# 50%     500.500000  199197.500000    27.000000    80.000000    82.000000
# 75%     750.250000  211332.000000    30.000000    82.000000    85.000000
# max    1000.000000  244369.000000    40.000000    94.000000    95.000000
#
#                Value        Wage  International Reputation  Skill Moves  \
# count     992.000000  700.000000               1000.000000  1000.000000
# mean    18919.959677   65.077143                  2.143000     3.001000
# std     14493.247142   63.496678                  0.866777     1.038305
# min       600.000000    0.000000                  1.000000     1.000000
# 25%     10000.000000   26.000000                  2.000000     2.000000
# 50%     14500.000000   46.000000                  2.000000     3.000000
# 75%     22000.000000   82.250000                  3.000000     4.000000
# max    118500.000000  565.000000                  5.000000     5.000000
#
#             Height      Weight         Clause   Improvment
# count  1000.000000    700.0000    1000.000000  1000.000000
# mean      5.971500   7976.6200   34854.053040     1.882000
# std       0.225190  13256.9027   28758.597719     2.497662
# min       5.333333    130.0000    1100.000000     0.000000
# 25%       5.833333    163.0000   17900.000000     0.000000
# 50%       6.000000    177.5000   27100.000000     0.500000
# 75%       6.166667  16630.2500   42525.000000     3.000000
# max       6.583333  46355.0000  228100.000000    12.000000

# %% [markdown]
# ## Answer the following questions:
# ### a. What is the median of the "Clause" column?
# ### b. Why is count different among the columns?
# ### c. What is the standard deviation of the "Overall" column?

# %%
'''
Write your answers here
a.27100
b. because some of them has null valus that coudn't be counted
c.3.038026
'''

# %% [markdown]
# # Part C: Feature Analysis

# %% [markdown]
# ## 8.	Extract all numerical columns into a new dataframe called `numerical_df`. Then, calculate the skewness on those columns

# %% [markdown]
# **`DataFrame.select_dtypes(include=...)`**: Selects columns with specific data types based on the `include` parameter.
#
#   Valid options for `include`:
#   - `'number'`: Selects numerical columns (int, float).
#   - `'object'`: Selects columns with string or categorical data.
#   - `'bool'`: Selects boolean columns.
#   - `'datetime'`: Selects datetime columns.
#
# **`DataFrame.skew()`**: Calculates the skewness of the numerical columns.

# %%
numerical_df=df.select_dtypes(include= 'number')
numerical_df.skew()
# Out:
# id                          0.000000
# ID                         -2.594514
# Age                         0.188868
# Overall                     1.215016
# Potential                   0.581064
# Value                       2.522956
# Wage                        2.845206
# International Reputation    0.412916
# Skill Moves                -0.415971
# Height                     -0.039916
# Weight                      1.361880
# Clause                      2.468693
# Improvment                  1.210970
# dtype: float64

# %% [markdown]
# ## Answer the following question:
# ### Comment on the skewness of the "Clause" column. Is this feature left skewed or right skewed?

# %%
'''
Your answer goes here
because its positve its right skewed
'''

# %% [markdown]
# ## 9.	Plot the Box plots for each numerical column.

# %% [markdown]
# - **`plt.subplot()`**: creates a grid subplot in the format `subplot(rows, cols, position)`
# - **`plt.boxplot()`**: creates a boxplot to visualize the distribution of data.
#     - **`.dropna()`**: removes any missing values to avoid errors when plotting.
#     - **`patch_artist=True`**: fills the boxes with color instead of just outlines.

# %%
plt.figure(figsize=(15,10))
for i, col in enumerate(numerical_df.columns.tolist()):
    plt.subplot(3,3,i+1) 
    plt.boxplot(numerical_df[col].dropna(), patch_artist=True)
    plt.title(f'{col} Boxplot')
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[61], line 3
#       1 plt.figure(figsize=(15,10))
#       2 for i, col in enumerate(numerical_df.columns.tolist()):
# ----> 3     plt.subplot(3,3,i+1)
#       4     plt.boxplot(numerical_df[col].dropna(), patch_artist=True)
#       5     plt.title(f'{col} Boxplot')
#       6 plt.tight_layout()
#
# File ~\anaconda3\Lib\site-packages\matplotlib\pyplot.py:1534, in subplot(*args, **kwargs)
#    1531 fig = gcf()
#    1533 # First, search for an existing subplot with a matching spec.
# -> 1534 key = SubplotSpec._from_subplot_args(fig, args)
#    1536 for ax in fig.axes:
#    1537     # If we found an Axes at the position, we can reuse it if the user passed no
#    1538     # kwargs or if the Axes class and kwargs are identical.
#    1539     if (ax.get_subplotspec() == key
#    1540         and (kwargs == {}
#    1541              or (ax._projection_init
#    1542                  == fig._process_projection_requirements(**kwargs)))):
#
# File ~\anaconda3\Lib\site-packages\matplotlib\gridspec.py:589, in SubplotSpec._from_subplot_args(figure, args)
#     587 else:
#     588     if not isinstance(num, Integral) or num < 1 or num > rows*cols:
# --> 589         raise ValueError(
#     590             f"num must be an integer with 1 <= num <= {rows*cols}, "
#     591             f"not {num!r}"
#     592         )
#     593     i = j = num
#     594 return gs[i-1:j]
#
# ValueError: num must be an integer with 1 <= num <= 9, not 10

# %% [markdown]
# ###10. Show the frequency (count) of each value in all categorical columns, not just the column names.
# - dataframe[col].value_counts(): counts the frequency of each unique value inside the column

# %%
categorical_columns = df.columns.select_dtypes(include = 'object')
for col in categorical_columns:
    print()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[68], line 1
# ----> 1 categorical_columns = df.columns.select_dtypes(include = 'object')
#       2 for col in categorical_columns:
#       3     print()
#
# AttributeError: 'Index' object has no attribute 'select_dtypes'

# %% [markdown]
# ## 11.	Kurtosis
# ## - Perform kurtosis on the numerical columns.

# %% [markdown]
#  **`DataFrame.kurt()`**: Returns the kurtosis for each column of the DataFrame.

# %%
numerical_df.kurt()
# Out:
# id                          -1.200000
# ID                          11.445510
# Age                         -0.340244
# Overall                      1.496417
# Potential                   -0.243744
# Value                        8.643215
# Wage                        12.288806
# International Reputation    -0.209553
# Skill Moves                 -0.608228
# Height                      -0.497077
# Weight                       0.323517
# Clause                       8.582884
# Improvment                   0.499234
# dtype: float64

# %% [markdown]
# ## Answer the following question:
# ### Is the 'Wage' Column platykurtic, mesokurtic, or leptokurtic?

# %%
'''
Your answer here
leptokurtic becuse its greater than 3
'''

# %% [markdown]
# ## 12.	Compute the correlation matrix for the numerical columns , and display it.

# %% [markdown]
# **`DataFrame.corr()`**: Calculates the pairwise correlation coefficients between numerical columns in the DataFrame, showing how strongly the columns are related.
# - **`.dropna()`**: ensures that we don’t have NaN values affecting correlation calculations.

# %%
numerical_df = df.select_dtypes(include='number')
numerical_df.dropna().corr()
# Out:
#                                 id        ID       Age   Overall  Potential  \
# id                        1.000000  0.084700 -0.017212 -0.920568  -0.723041
# ID                        0.084700  1.000000 -0.742506 -0.184288   0.218956
# Age                      -0.017212 -0.742506  1.000000  0.119181  -0.490313
# Overall                  -0.920568 -0.184288  0.119181  1.000000   0.715206
# Potential                -0.723041  0.218956 -0.490313  0.715206   1.000000
# Value                    -0.711598  0.111314 -0.211692  0.855182   0.766197
# Wage                     -0.588444 -0.103219  0.031757  0.764521   0.562556
# International Reputation -0.523114 -0.490152  0.379126  0.640265   0.274502
# Skill Moves              -0.009209  0.118908 -0.195990  0.029068   0.087164
# Height                   -0.075133 -0.109511  0.111232  0.047325   0.010103
# Weight                    0.067863 -0.041616  0.097550 -0.051886  -0.084952
# Clause                   -0.682568  0.106638 -0.200027  0.821881   0.739405
# Improvment                0.033495  0.522257 -0.832052 -0.135927   0.595211
#
#                              Value      Wage  International Reputation  \
# id                       -0.711598 -0.588444                 -0.523114
# ID                        0.111314 -0.103219                 -0.490152
# Age                      -0.211692  0.031757                  0.379126
# Overall                   0.855182  0.764521                  0.640265
# Potential                 0.766197  0.562556                  0.274502
# Value                     1.000000  0.791817                  0.475095
# Wage                      0.791817  1.000000                  0.571506
# International Reputation  0.475095  0.571506                  1.000000
# Skill Moves               0.241764  0.157228                  0.057619
# Height                   -0.108781 -0.073779                  0.065496
# Weight                   -0.054821 -0.035824                 -0.037211
# Clause                    0.954626  0.764547                  0.430901
# Improvment                0.102857 -0.081570                 -0.347028
#
#                           Skill Moves    Height    Weight    Clause  \
# id                          -0.009209 -0.075133  0.067863 -0.682568
# ID                           0.118908 -0.109511 -0.041616  0.106638
# Age                         -0.195990  0.111232  0.097550 -0.200027
# Overall                      0.029068  0.047325 -0.051886  0.821881
# Potential                    0.087164  0.010103 -0.084952  0.739405
# Value                        0.241764 -0.108781 -0.054821  0.954626
# Wage                         0.157228 -0.073779 -0.035824  0.764547
# International Reputation     0.057619  0.065496 -0.037211  0.430901
# Skill Moves                  1.000000 -0.593247 -0.041135  0.218764
# Height                      -0.593247  1.000000  0.031201 -0.129436
# Weight                      -0.041135  0.031201  1.000000 -0.048128
# Clause                       0.218764 -0.129436 -0.048128  1.000000
# Improvment                   0.090135 -0.040091 -0.060764  0.103166
#
#                           Improvment
# id                          0.033495
# ID                          0.522257
# Age                        -0.832052
# Overall                    -0.135927
# Potential                   0.595211
# Value                       0.102857
# Wage                       -0.081570
# International Reputation   -0.347028
# Skill Moves                 0.090135
# Height                     -0.040091
# Weight                     -0.060764
# Clause                      0.103166
# Improvment                  1.000000

# %% [markdown]
# ## Answer the following question:
# ### comment on the correlation between between "Age" and "Clause"

# %%
'''
Your Answer Here
age:-0.017212
clause:-0.682568
corr = -0.200027
'''
# Out:
# '\nYour Answer Here\nage:-0.017212\nclause:-0.682568\n'

# %% [markdown]
# ## 13.	Plot the KDE plots of "Clause" and "Age" columns next to each other

# %% [markdown]
# - **`plt.subplot()`**: creates a grid subplot in the format `subplot(rows, cols, position)`
# - **`.plot()`**: generates diffrenet types of plots depending on the `kind` attribute.
#   - **`kind='kde'`**: Kernel Density Estimation plot that is a smoothed version of a histogram that estimates the probability density function of a variable.
# - **`plt.tight_layout()`**: automatically adjusts subplot spacing to prevent overlapping.
# - **`plt.show()`**: displays the final figure containing the density plots.

# %%
hist_columns["Age", "Clause"]

plt.figure(figsize=(15,10))
for i, col in enumerate(numerical_df.columns.tolist()):
    plt.subplot(3,3,i+1)
    numerical_df[col].plot(kind='kde')
    plt.title(f'{col} KDE')
   
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[67], line 1
# ----> 1 hist_columns["Age", "Clause"]
#       2
#       3 plt.figure(figsize=(15,10))
#       4 for i, col in enumerate(numerical_df.columns.tolist()):
#
# NameError: name 'hist_columns' is not defined

# %% [markdown]
# # Part D:Data Cleaning

# %% [markdown]
# ## 14.	Calculate the percentage of missing values for all numerical columns.

# %% [markdown]
# **`DataFrame.isnull():`** Detect missing values.\
# **`numpy.sum():`** Sum of array elements over a given axis.

# %%
missing_percentage = (numerical_df.isnull().sum() / len(numerical_df)) * 100
missing_percentage
# Out:
# id                           0.0
# ID                           0.0
# Age                          0.0
# Overall                      0.0
# Potential                    0.0
# Value                        0.8
# Wage                        30.0
# International Reputation     0.0
# Skill Moves                  0.0
# Height                       0.0
# Weight                      30.0
# Clause                       0.0
# Improvment                   0.0
# dtype: float64

# %% [markdown]
# ## Answer the following question:
# ###Identify the column(s) that have  missing values

# %%
'''
Your Answer Here
id                           0.0
ID                           0.0
Age                          0.0
Overall                      0.0
Potential                    0.0
International Reputation     0.0
Skill Moves                  0.0
Height                       0.0
Clause                       0.0
Improvment                   0.0
'''

# %% [markdown]
# ## 15.	Fill missing values:
# ## •	Use the mean and mode to fill missing values in numerical and categorical columns.

# %% [markdown]
# - **`fillna(desired_value)`**: Replaces **NaN** values in each column with the desired values.
# - **`df[numerical_columns_list].mean()`**: computes the median of each numerical column separately.

# %%
number_columns = numerical_df.columns
numerical_df[number_columns] = numerical_df[number_columns].fillna(numerical_df[number_columns].median())

# %% [markdown]
# ## 16.	Apply the Interquartile Range (IQR) method for outlier detection on numerical features: •	Print the count of outliers for each numerical column.

# %%
for col in numerical_df.columns.tolist():
  Q1 = df[col].quantile(0.25)
  Q3 = df[col].quantile(0.75)
  #Calculate IQR
  IQR =Q3-Q1
  #Calculate lower_bound
  lower_bound =Q1 - 1.5 * IQR
  #Calculate upper_bound
  upper_bound =Q3 + 1.5 * IQR
  outliers = df[(df[col] < lower_bound) | (df[col] >upper_bound )]
  print(f"Count of outliers in {col}: {outliers.shape[0]}")
# Out:
# Count of outliers in id: 0
# Count of outliers in ID: 39
# Count of outliers in Age: 3
# Count of outliers in Overall: 25
# Count of outliers in Potential: 8
# Count of outliers in Value: 74
# Count of outliers in Wage: 42
# Count of outliers in International Reputation: 6
# Count of outliers in Skill Moves: 0
# Count of outliers in Height: 0
# Count of outliers in Weight: 11
# Count of outliers in Clause: 64
# Count of outliers in Improvment: 34

# %% [markdown]
# # Part E:Data normalization

# %% [markdown]
# ## 17. Apply normalization or standardization to variables that require scaling for further analysis or modeling.

# %%
from sklearn.preprocessing import MinMaxScaler, StandardScaler

# %% [markdown]
# - **`fit_transform()`**: calculates mean & standard deviation of each numerical column, then applies Z-score normalization (Standardization).

# %%
df_minmax = df.copy()
df
# Out:
# id                           0.0
# ID                           0.0
# Age                          0.0
# Overall                      0.0
# Potential                    0.0
# Value                        0.8
# Wage                        30.0
# International Reputation     0.0
# Skill Moves                  0.0
# Height                       0.0
# Weight                      30.0
# Clause                       0.0
# Improvment                   0.0
# dtype: float64

# %% [markdown]
# ## Answer the following question:
# ### What Min Max normalization make in dataset?

# %%
'''
Your Answer Here
'''
