# %% [markdown]
# <a href="https://colab.research.google.com/github/cher16/FDSfE_ANjoku/blob/main/HW2/HW2_movies_exploratory.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Import the Pandas module to read in and wrangle the data

# %% [markdown]
# - Part I: Guided data exploration and cleaning
# - Part II: Finding interesting movies
#
# # PART I : Guided data exploration and cleaning

# %%
import pandas as pd
import missingno as msno
movies = pd.read_csv("https://github.com/fedhere/FDSfE_FBianco/blob/main/data/movies_metadata_kaggle.csv.zip?raw=true" , compression = "zip");

# %% [markdown]
# Find the raw link to the data in my GItHub repository in the folder `data`. The file name has changed since the class - I put the proper "zip" ending.

# %%
movies.shape
# Out:
# (45454, 25)

# %% [markdown]
# Calculate the shape of the dataframe: use the partial cell of code below to print it out

# %%
print("the movies dataframe has dimensions"+format(movies.shape) )
# Out:
# the movies dataframe has dimensions(45454, 25)

# %% [markdown]
# Display the top 5 lines of the dataframe

# %%
movies.head(5)
# Out:
#    adult                              belongs_to_collection      budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000.0
# 1  False                                                NaN  65000000.0
# 2  False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0.0
# 3  False                                                NaN  16000000.0
# 4  False  {'id': 96871, 'name': 'Father of the Bride Col...         0.0
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                     [{'id': 35, 'name': 'Comedy'}]
#
#                                homepage     id    imdb_id original_language  \
# 0  http://toystory.disney.com/toy-story    862  tt0114709                en
# 1                                   NaN   8844  tt0113497                en
# 2                                   NaN  15602  tt0113228                en
# 3                                   NaN  31357  tt0114885                en
# 4                                   NaN  11862  tt0113041                en
#
#                 original_title  \
# 0                    Toy Story
# 1                      Jumanji
# 2             Grumpier Old Men
# 3            Waiting to Exhale
# 4  Father of the Bride Part II
#
#                                             overview  ...      revenue  \
# 0  Led by Woody, Andy's toys live happily in his ...  ...  373554033.0
# 1  When siblings Judy and Peter discover an encha...  ...  262797249.0
# 2  A family wedding reignites the ancient feud be...  ...          0.0
# 3  Cheated on, mistreated and stepped on, the wom...  ...   81452156.0
# 4  Just when George Banks has recovered from his ...  ...   76578911.0
#
#   runtime                                   spoken_languages    status  \
# 0    81.0           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 1   104.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...  Released
# 2   101.0           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 3   127.0           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 4   106.0           [{'iso_639_1': 'en', 'name': 'English'}]  Released
#
#                                              tagline  \
# 0                                                NaN
# 1          Roll the dice and unleash the excitement!
# 2  Still Yelling. Still Fighting. Still Ready for...
# 3  Friends are the people who let you be yourself...
# 4  Just When His World Is Back To Normal... He's ...
#
#                          title  video vote_average vote_count   earnings
# 0                    Toy Story  False          7.7     5415.0  12.451801
# 1                      Jumanji  False          6.9     2413.0   4.043035
# 2             Grumpier Old Men  False          6.5       92.0        NaN
# 3            Waiting to Exhale  False          6.1       34.0   5.090760
# 4  Father of the Bride Part II  False          5.7      173.0        inf
#
# [5 rows x 25 columns]

# %% [markdown]
# Display the last five lines of the dataframe

# %%
movies.tail(5)
# Out:
#        adult belongs_to_collection  budget  \
# 45449  False                   NaN     0.0
# 45450  False                   NaN     0.0
# 45451  False                   NaN     0.0
# 45452  False                   NaN     0.0
# 45453  False                   NaN     0.0
#
#                                                   genres  \
# 45449  [{'id': 18, 'name': 'Drama'}, {'id': 10751, 'n...
# 45450                      [{'id': 18, 'name': 'Drama'}]
# 45451  [{'id': 28, 'name': 'Action'}, {'id': 18, 'nam...
# 45452                                                 []
# 45453                                                 []
#
#                                    homepage      id    imdb_id  \
# 45449  http://www.imdb.com/title/tt6209470/  439050  tt6209470
# 45450                                   NaN  111109  tt2028550
# 45451                                   NaN   67758  tt0303758
# 45452                                   NaN  227506  tt0008536
# 45453                                   NaN  461257  tt6980792
#
#       original_language       original_title  \
# 45449                fa              رگ خواب
# 45450                tl  Siglo ng Pagluluwal
# 45451                en             Betrayal
# 45452                en  Satana likuyushchiy
# 45453                en             Queerama
#
#                                                 overview  ...  revenue  \
# 45449        Rising and falling between a man and woman.  ...      0.0
# 45450  An artist struggles to finish his work while a...  ...      0.0
# 45451  When one of her hits goes wrong, a professiona...  ...      0.0
# 45452  In a small town live two brothers, one a minis...  ...      0.0
# 45453  50 years after decriminalisation of homosexual...  ...      0.0
#
#       runtime                          spoken_languages    status  \
# 45449    90.0    [{'iso_639_1': 'fa', 'name': 'فارسی'}]  Released
# 45450   360.0         [{'iso_639_1': 'tl', 'name': ''}]  Released
# 45451    90.0  [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 45452    87.0                                        []  Released
# 45453    75.0  [{'iso_639_1': 'en', 'name': 'English'}]  Released
#
#                                           tagline                title  video  \
# 45449  Rising and falling between a man and woman               Subdue  False
# 45450                                         NaN  Century of Birthing  False
# 45451                      A deadly game of wits.             Betrayal  False
# 45452                                         NaN     Satan Triumphant  False
# 45453                                         NaN             Queerama  False
#
#       vote_average vote_count earnings
# 45449          4.0        1.0      NaN
# 45450          9.0        3.0      NaN
# 45451          3.8        6.0      NaN
# 45452          0.0        0.0      NaN
# 45453          0.0        0.0      NaN
#
# [5 rows x 25 columns]

# %% [markdown]
# Complete the cell of code below: to save the name of the dataframe columns

# %%
columns = movies.columns
columns
# Out:
# Index(['adult', 'belongs_to_collection', 'budget', 'genres', 'homepage', 'id',
#        'imdb_id', 'original_language', 'original_title', 'overview',
#        'popularity', 'poster_path', 'production_companies',
#        'production_countries', 'release_date', 'revenue', 'runtime',
#        'spoken_languages', 'status', 'tagline', 'title', 'video',
#        'vote_average', 'vote_count', 'earnings'],
#       dtype='object')

# %% [markdown]
# Use the `describe` method of the dataframe to get a statitical description of the numerical columns within it

# %%
movies.describe()
# Out:
#              budget             id    popularity       revenue  vote_average  \
# count  4.545400e+04   45454.000000  45451.000000  4.545100e+04  45451.000000
# mean   4.225399e+06  108348.389075      2.921765  1.121157e+07      5.618543
# std    1.742576e+07  112445.975875      6.005910  6.433842e+07      1.924085
# min    0.000000e+00       2.000000      0.000000  0.000000e+00      0.000000
# 25%    0.000000e+00   26447.500000      0.385945  0.000000e+00      5.000000
# 50%    0.000000e+00   60004.000000      1.127613  0.000000e+00      6.000000
# 75%    0.000000e+00  157304.000000      3.679334  0.000000e+00      6.800000
# max    3.800000e+08  469172.000000    547.488298  2.787965e+09     10.000000
#
#          vote_count      earnings
# count  45451.000000  1.091600e+04
# mean     109.917538           inf
# std      491.356914           NaN
# min        0.000000  0.000000e+00
# 25%        3.000000  0.000000e+00
# 50%       10.000000  1.273533e+00
# 75%       34.000000  7.267308e+00
# max    14075.000000           inf

# %% [markdown]
# Answer the following question: why is the "count" value different for some of the columns?
#
# The 'count' value is different because of null values

# %% [markdown]
# # <mark> WFF </mark> Why do null values make the count values different?

# %%
movies.isnull().sum(axis=0)
# Out:
# adult                        0
# belongs_to_collection    40963
# budget                       0
# genres                       0
# homepage                 37677
# id                           0
# imdb_id                     17
# original_language           11
# original_title               0
# overview                   954
# popularity                   3
# poster_path                386
# production_companies         3
# production_countries         3
# release_date                86
# revenue                      3
# runtime                      0
# spoken_languages             3
# status                      84
# tagline                  25048
# title                        3
# video                        3
# vote_average                 3
# vote_count                   3
# earnings                 34538
# dtype: int64

# %% [markdown]
# How many missing values are in the `runtime` row?
#
# 0

# %% [markdown]
# Import the missingno python package and use it to visualize missing data with the function `matrix()` available in the missingno package. Describe the figure in a caption below. When you write your caption think of the "what" and the "why" - "what": describe first what the figure shows (what is on the x axis, what is on the y axis, what the colors represent etc) then describe "why" the figure is interesting and worth showing to your reader

# %%
import missingno as msno
msno.matrix(movies)
# make the figure here

# %% [markdown]
# *Figure* 1: The x axis displays the headings in the plot, while the y axis displays the columns in the plot. There are 45,454 rows of data. The white space is indicative of columns with empty cells; the columns with the most white space are 'belongs_to_collection', 'homepage', 'tagline', and 'earnings'.

# %% [markdown]
# Remove the columns of the dataframe that contain a large number of missing values and that are not numerical, such that they will not be needed to figure out which movie is the most popular

# %%
movies.drop(['belongs_to_collection', 'homepage', 'tagline', 'earnings'], axis=1, inplace= True)

# %%
movies.columns
# Out:
# Index(['adult', 'budget', 'genres', 'id', 'imdb_id', 'original_language',
#        'original_title', 'overview', 'popularity', 'poster_path',
#        'production_companies', 'production_countries', 'release_date',
#        'revenue', 'runtime', 'spoken_languages', 'status', 'title', 'video',
#        'vote_average', 'vote_count'],
#       dtype='object')

# %% [markdown]
# Inspect the dataframe and ensure that the columns you wanted to remove are gone (you can do that by remaking the plot above or printing the columns of the updated dataframe)

# %%
movies.dropna(subset=["popularity"],inplace =True)

# %%
movies.shape
# Out:
# (45451, 21)

# %% [markdown]
# This proves that the dataframes have been removed

# %% [markdown]
# # <mark> WFF </mark> How does this prove that the NaNs and the columns have been removed?

# %% [markdown]
# Remove the _rows_ of the dataframe where the value of popularity is missing (use the `dropna()` method). Then check that they are gone

# %%
movies.dropna(inplace=True);

# %%
movies.shape
# Out:
# (44040, 21)

# %% [markdown]
# # PART II : Finding interesting movies

# %% [markdown]
# Find the most popular movie and use the print statement below to present your findings.

# %%
movies = movies[movies["popularity"] == movies["popularity"].max()]
movies
# Out:
#        adult      budget                                             genres  \
# 30696  False  74000000.0  [{'id': 10751, 'name': 'Family'}, {'id': 16, '...
#
#            id    imdb_id original_language original_title  \
# 30696  211672  tt2293640                en        Minions
#
#                                                 overview  popularity  \
# 30696  Minions Stuart, Kevin and Bob are recruited by...  547.488298
#
#                            poster_path  ...  \
# 30696  /q0R4crx2SehcEEQEkYObktdeFy.jpg  ...
#
#                                     production_countries release_date  \
# 30696  [{'iso_3166_1': 'US', 'name': 'United States o...   2015-06-17
#
#             revenue  runtime                          spoken_languages  \
# 30696  1.156731e+09     91.0  [{'iso_639_1': 'en', 'name': 'English'}]
#
#          status    title  video vote_average  vote_count
# 30696  Released  Minions  False          6.4      4729.0
#
# [1 rows x 21 columns]

# %%
print("The most popular movie in this dataset is "+format(movies.original_title.values[0]))
# Out:
# The most popular movie in this dataset is Minions

# %% [markdown]
# Find the least popular movie (modify the last two cells of code apprioriately and print out the statement neatly with the print function as above)

# %%
leastpop = movies[movies["popularity"] == movies["popularity"].min()]
leastpop
# Out:
#        adult      budget                                             genres  \
# 30696  False  74000000.0  [{'id': 10751, 'name': 'Family'}, {'id': 16, '...
#
#            id    imdb_id original_language original_title  \
# 30696  211672  tt2293640                en        Minions
#
#                                                 overview  popularity  \
# 30696  Minions Stuart, Kevin and Bob are recruited by...  547.488298
#
#                            poster_path  ...  \
# 30696  /q0R4crx2SehcEEQEkYObktdeFy.jpg  ...
#
#                                     production_countries release_date  \
# 30696  [{'iso_3166_1': 'US', 'name': 'United States o...   2015-06-17
#
#             revenue  runtime                          spoken_languages  \
# 30696  1.156731e+09     91.0  [{'iso_639_1': 'en', 'name': 'English'}]
#
#          status    title  video vote_average  vote_count
# 30696  Released  Minions  False          6.4      4729.0
#
# [1 rows x 21 columns]

# %%
print("The least popular movie in this dataset is "+format(leastpop.original_title.values[0]))
# Out:
# The least popular movie in this dataset is Minions

# %% [markdown]
# Find the longest movie

# %%
longestruntime = movies[movies["runtime"] == movies["runtime"].max()]
longestruntime
# Out:
#        adult      budget                                             genres  \
# 30696  False  74000000.0  [{'id': 10751, 'name': 'Family'}, {'id': 16, '...
#
#            id    imdb_id original_language original_title  \
# 30696  211672  tt2293640                en        Minions
#
#                                                 overview  popularity  \
# 30696  Minions Stuart, Kevin and Bob are recruited by...  547.488298
#
#                            poster_path  ...  \
# 30696  /q0R4crx2SehcEEQEkYObktdeFy.jpg  ...
#
#                                     production_countries release_date  \
# 30696  [{'iso_3166_1': 'US', 'name': 'United States o...   2015-06-17
#
#             revenue  runtime                          spoken_languages  \
# 30696  1.156731e+09     91.0  [{'iso_639_1': 'en', 'name': 'English'}]
#
#          status    title  video vote_average  vote_count
# 30696  Released  Minions  False          6.4      4729.0
#
# [1 rows x 21 columns]

# %%
print("The movie with the longest runtime in this dataset is "+format(longestruntime.original_title.values[0]))
# Out:
# The movie with the longest runtime in this dataset is Minions

# %% [markdown]
# Find the movies with the highest revenue

# %%
highestrevenue = movies[movies["revenue"] == movies["revenue"].max()]
highestrevenue
# Out:
#        adult      budget                                             genres  \
# 30696  False  74000000.0  [{'id': 10751, 'name': 'Family'}, {'id': 16, '...
#
#            id    imdb_id original_language original_title  \
# 30696  211672  tt2293640                en        Minions
#
#                                                 overview  popularity  \
# 30696  Minions Stuart, Kevin and Bob are recruited by...  547.488298
#
#                            poster_path  ...  \
# 30696  /q0R4crx2SehcEEQEkYObktdeFy.jpg  ...
#
#                                     production_countries release_date  \
# 30696  [{'iso_3166_1': 'US', 'name': 'United States o...   2015-06-17
#
#             revenue  runtime                          spoken_languages  \
# 30696  1.156731e+09     91.0  [{'iso_639_1': 'en', 'name': 'English'}]
#
#          status    title  video vote_average  vote_count
# 30696  Released  Minions  False          6.4      4729.0
#
# [1 rows x 21 columns]

# %% [markdown]
# Find the movie with the highest _revenue per minute_.
#
# Hint: To do this first create a new column called `revenue_per_minute` by dividing the revenue by the runtime

# %%
movies['revenue']= movies['revenue'].astype('float')

# %%
movies['runtime']= movies['runtime'].astype('float')

# %%
movies['highestrevenuepermin']= movies.revenue/movies.runtime

# %%
movies.highestrevenuepermin.max()
# Out:
# 12711329.252747253

# %%
movies.highestrevenuepermin
# Out:
# 30696    1.271133e+07
# Name: highestrevenuepermin, dtype: float64

# %%
movies[movies['runtime']==movies.runtime.min()]
# Out:
#        adult      budget                                             genres  \
# 30696  False  74000000.0  [{'id': 10751, 'name': 'Family'}, {'id': 16, '...
#
#            id    imdb_id original_language original_title  \
# 30696  211672  tt2293640                en        Minions
#
#                                                 overview  popularity  \
# 30696  Minions Stuart, Kevin and Bob are recruited by...  547.488298
#
#                            poster_path  ... release_date       revenue  \
# 30696  /q0R4crx2SehcEEQEkYObktdeFy.jpg  ...   2015-06-17  1.156731e+09
#
#       runtime                          spoken_languages    status    title  \
# 30696    91.0  [{'iso_639_1': 'en', 'name': 'English'}]  Released  Minions
#
#        video vote_average vote_count  highestrevenuepermin
# 30696  False          6.4     4729.0          1.271133e+07
#
# [1 rows x 22 columns]

# %%
movies[movies['highestrevenuepermin']==movies.highestrevenuepermin.max()]
# Out:
#        adult      budget                                             genres  \
# 30696  False  74000000.0  [{'id': 10751, 'name': 'Family'}, {'id': 16, '...
#
#            id    imdb_id original_language original_title  \
# 30696  211672  tt2293640                en        Minions
#
#                                                 overview  popularity  \
# 30696  Minions Stuart, Kevin and Bob are recruited by...  547.488298
#
#                            poster_path  ... release_date       revenue  \
# 30696  /q0R4crx2SehcEEQEkYObktdeFy.jpg  ...   2015-06-17  1.156731e+09
#
#       runtime                          spoken_languages    status    title  \
# 30696    91.0  [{'iso_639_1': 'en', 'name': 'English'}]  Released  Minions
#
#        video vote_average vote_count  highestrevenuepermin
# 30696  False          6.4     4729.0          1.271133e+07
#
# [1 rows x 22 columns]

# %% [markdown]
# # <mark> WFF </mark> Minions is unfortunately not the answer to all of these questions, there is a mistake in your code that is leading you to print the same thing each time.
