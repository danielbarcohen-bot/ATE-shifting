# %%
import os
import sys
from pathlib import Path
import numpy as np
import pandas as pd
import librosa
from scipy.stats import entropy
from tqdm import tqdm
import soundfile as sf
from multiprocessing import Pool, cpu_count
from collections import defaultdict
import pyarrow as pa
import pyarrow.parquet as pq

# %%
# === Configuration ===
HOME = Path(os.environ["HOME"])
REPO_ROOT = HOME / "Uni-stuff/semester-2/applied_Ml/reef_zmsc"
MANIFEST = REPO_ROOT / "data/manifests/sample_50k_stratified.parquet"
OUTPUT_BASE = REPO_ROOT / "data/features/embeds_ecoacoustic_50k"

# %%
SAMPLE_RATE = 16000
N_FFT = 2048
HOP_LENGTH = 512
CLIP_LIMIT = None  # Set to None to process all 50K, or a number to limit
N_WORKERS = max(1, cpu_count() - 2)
BATCH_SIZE = 1000  # Write to disk every 1000 clips

# %%
def load_audio_clip(wav_path, start_s, end_s, sr=SAMPLE_RATE):
    """Load a specific time slice from a WAV file."""
    try:
        with sf.SoundFile(wav_path) as f:
            original_sr = f.samplerate
            start_frame = int(start_s * original_sr)
            duration_s = end_s - start_s
            frames_to_read = int(duration_s * original_sr)
            
            f.seek(start_frame)
            audio = f.read(frames_to_read)
            
            if len(audio.shape) > 1:
                audio = audio.mean(axis=1)
            
            if original_sr != sr:
                audio = librosa.resample(audio, orig_sr=original_sr, target_sr=sr)
            
            return audio.astype(np.float32)
    
    except Exception as e:
        duration_s = end_s - start_s
        return np.zeros(int(sr * duration_s), dtype=np.float32)

# %%
def extract_ecoacoustic_features(audio, sr):
    """
    Extract streamlined ecoacoustic indices (~15 features).
    Features are normalized to comparable scales for fusion with YAMNet.
    """
    # Compute spectrogram once
    S = np.abs(librosa.stft(audio, n_fft=N_FFT, hop_length=HOP_LENGTH))
    
    features = {}
    
    # === Spectral Features (6) - Normalize to [0, 1] ===
    centroid = librosa.feature.spectral_centroid(S=S, sr=sr, hop_length=HOP_LENGTH)
    bandwidth = librosa.feature.spectral_bandwidth(S=S, sr=sr, hop_length=HOP_LENGTH)
    rolloff = librosa.feature.spectral_rolloff(S=S, sr=sr, hop_length=HOP_LENGTH)
    flatness = librosa.feature.spectral_flatness(S=S, hop_length=HOP_LENGTH)
    contrast = librosa.feature.spectral_contrast(S=S, sr=sr, hop_length=HOP_LENGTH)
    
    # Normalize by Nyquist frequency (sr/2 = 8000 Hz for 16kHz audio)
    nyquist = sr / 2
    features['spectral_centroid_mean'] = float(np.mean(centroid) / nyquist)
    features['spectral_centroid_std'] = float(np.std(centroid) / nyquist)
    features['spectral_bandwidth_mean'] = float(np.mean(bandwidth) / nyquist)
    features['spectral_rolloff_mean'] = float(np.mean(rolloff) / nyquist)
    features['spectral_flatness_mean'] = float(np.mean(flatness))
    features['spectral_contrast_mean'] = float(np.mean(contrast) / 40.0)
    
    # === Acoustic Complexity Index (1) ===
    diffs = np.abs(np.diff(S, axis=1))
    aci_raw = np.sum(diffs) / (np.sum(S[:, :-1]) + 1e-10)
    features['aci'] = float(np.clip(aci_raw / 2.0, 0, 1))
    
    # === Entropy Features (2) ===
    mean_spectrum = np.mean(S, axis=1)
    mean_spectrum = mean_spectrum / (np.sum(mean_spectrum) + 1e-10)
    spectral_H = entropy(mean_spectrum + 1e-10)
    features['spectral_entropy'] = float(spectral_H / 8.0)
    
    envelope = np.abs(audio)
    envelope = envelope / (np.sum(envelope) + 1e-10)
    temporal_H = entropy(envelope + 1e-10)
    features['temporal_entropy'] = float(temporal_H / 15.0)
    
    # === Zero Crossing Rate (1) ===
    zcr = librosa.feature.zero_crossing_rate(audio, hop_length=HOP_LENGTH)
    features['zcr_mean'] = float(np.mean(zcr))
    
    # === Energy Features (3) ===
    rms = librosa.feature.rms(y=audio, hop_length=HOP_LENGTH).flatten()
    rms_mean = np.mean(rms)
    rms_max = np.max(rms)
    
    features['rms_mean'] = float(rms_mean)
    features['rms_std'] = float(np.std(rms))
    
    dynamic_range_raw = 20 * np.log10(rms_max / (rms_mean + 1e-10))
    features['dynamic_range_db'] = float(np.clip(dynamic_range_raw / 40.0, 0, 1))
    
    # === SNR Estimate (1) ===
    noise_level = np.percentile(rms, 10)
    signal_level = np.mean(rms)
    snr_raw = 20 * np.log10(signal_level / (noise_level + 1e-10))
    features['snr_db'] = float(np.clip(snr_raw / 40.0, 0, 1))
    
    # === Low/Mid/High Frequency Energy (3) ===
    freq_bins = librosa.fft_frequencies(sr=sr, n_fft=N_FFT)
    low_mask = freq_bins < 1000
    mid_mask = (freq_bins >= 1000) & (freq_bins < 3000)
    high_mask = freq_bins >= 3000
    
    total_energy = np.sum(S) + 1e-10
    features['low_freq_energy'] = float(np.sum(S[low_mask, :]) / total_energy)
    features['mid_freq_energy'] = float(np.sum(S[mid_mask, :]) / total_energy)
    features['high_freq_energy'] = float(np.sum(S[high_mask, :]) / total_energy)
    
    return features

# %%
def detect_logger_date(wav_path: str):
    """Extract logger ID and date from path - handles PAPCA and PAPCA_test."""
    try:
        parts = Path(wav_path).parts
        
        # Find any part that starts with "PAPCA"
        papca_idx = -1
        for idx, part in enumerate(parts):
            if part.startswith("PAPCA"):
                papca_idx = idx
                break
        
        if papca_idx >= 0 and papca_idx + 2 < len(parts):
            logger = parts[papca_idx + 1]
            date = parts[papca_idx + 2]
            
            if logger and date and logger.strip() and date.strip() and logger != "wav":
                return logger, date
        
    except Exception as e:
        pass
    
    return "unknown", "unknown"


def shard_path(out_root: Path, logger: str, date: str) -> Path:
    """Determines which Parquet shard to write this clip's features to."""
    logger = logger.strip() if logger else "unknown"
    date = date.strip() if date else "unknown"
    
    # Match YAMNet structure: OUT_ROOT/PAPCA/<logger>/<date>/features.parquet
    return out_root / "PAPCA" / logger / date / "features.parquet"


def process_clip(args):
    """Process a single clip from manifest."""
    idx, wav_path, start_s, end_s = args
    
    try:
        # Detect logger and date from path
        logger, date = detect_logger_date(wav_path)
        
        # Load audio
        audio = load_audio_clip(wav_path, start_s, end_s, SAMPLE_RATE)
        
        # Extract features
        features = extract_ecoacoustic_features(audio, SAMPLE_RATE)
        
        # Add metadata
        features['filepath'] = wav_path
        features['start_s'] = start_s
        features['end_s'] = end_s
        features['logger'] = logger
        features['date'] = date
        
        return features
    
    except Exception as e:
        print(f"✗ Error processing clip {idx}: {e}")
        return None


def save_batch(batch_data, output_base):
    """Save a batch of features grouped by logger/date using efficient append."""
    if not batch_data:
        return 0
    
    # Group by logger and date
    grouped = defaultdict(list)
    for features in batch_data:
        key = (features['logger'], features['date'])
        grouped[key].append(features)
    
    saved_count = 0
    for (logger, date), features_list in grouped.items():
        # Use shard_path function to get the correct path structure
        output_path = shard_path(output_base, logger, date)
        output_path.parent.mkdir(parents=True, exist_ok=True)
        
        # Convert to PyArrow Table
        new_table = pa.Table.from_pylist(features_list)
        
        # Append or create new file
        try:
            if output_path.exists():
                existing_table = pq.read_table(output_path)
                combined_table = pa.concat_tables([existing_table, new_table])
                pq.write_table(combined_table, output_path, compression="snappy")
            else:
                pq.write_table(new_table, output_path, compression="snappy")
            
            saved_count += len(features_list)
        except Exception as e:
            print(f"⚠️ Error saving to {output_path}: {e}")
    
    return saved_count

# %%
def main():
    print("=" * 70)
    print("ECOACOUSTIC FEATURES EXTRACTION - 50K STRATIFIED SAMPLE")
    print("=" * 70)
    
    # Load manifest
    print(f"\n📂 Loading manifest from: {MANIFEST}")
    df = pd.read_parquet(MANIFEST)
    print(f"   Total clips in manifest: {len(df):,}")
    
    # Determine filepath column
    PATH_COL = "filepath" if "filepath" in df.columns else "wav_path"
    assert PATH_COL in df.columns, f"Missing required column: {PATH_COL}"
    
    # Check for required columns
    required_cols = [PATH_COL, 'start_s']
    for col in required_cols:
        assert col in df.columns, f"Missing required column: {col}"
    
    # Handle end_s column (might not exist in stratified sample)
    if 'end_s' not in df.columns:
        print("   ℹ️  'end_s' column not found, computing from 'duration_s'")
        if 'duration_s' in df.columns:
            df['end_s'] = df['start_s'] + df['duration_s']
        else:
            print("   ⚠️  Assuming 10s clip duration")
            df['end_s'] = df['start_s'] + 10.0
    
    # Limit clips if specified
    if CLIP_LIMIT and len(df) > CLIP_LIMIT:
        print(f"   ⚠️  Limiting to {CLIP_LIMIT:,} clips for testing")
        df = df.sample(n=CLIP_LIMIT, random_state=42).reset_index(drop=True)
    
    print(f"\n📊 Processing {len(df):,} clips")
    print(f"   Batch size: {BATCH_SIZE} clips")
    print(f"   Workers: {N_WORKERS}")
    print(f"   Output: {OUTPUT_BASE.relative_to(REPO_ROOT)}")
    
    # Prepare data
    clip_data = [
        (idx, row[PATH_COL], row['start_s'], row['end_s'])
        for idx, row in df.iterrows()
    ]
    
    # Process in batches
    print(f"\n🔧 Extracting ecoacoustic features...")
    
    total_saved = 0
    batch_buffer = []
    
    with Pool(N_WORKERS) as pool:
        with tqdm(total=len(clip_data), desc="Processing clips", unit="clip") as pbar:
            for result in pool.imap(process_clip, clip_data, chunksize=20):
                if result is not None:
                    batch_buffer.append(result)
                
                # Save batch when buffer is full
                if len(batch_buffer) >= BATCH_SIZE:
                    saved = save_batch(batch_buffer, OUTPUT_BASE)
                    total_saved += saved
                    batch_buffer = []
                    pbar.set_postfix({'saved': total_saved})
                
                pbar.update(1)
            
            # Save remaining clips
            if batch_buffer:
                saved = save_batch(batch_buffer, OUTPUT_BASE)
                total_saved += saved
    
    print(f"\n✅ Successfully processed and saved {total_saved:,} clips")
    
    # Collect and display statistics
    print(f"\n📊 Collecting feature statistics...")
    
    all_features = []
    for parquet_file in OUTPUT_BASE.rglob("features.parquet"):
        df_features = pd.read_parquet(parquet_file)
        all_features.append(df_features)
    
    if all_features:
        combined = pd.concat(all_features, ignore_index=True)
        
        # Feature columns (exclude metadata)
        feature_cols = [c for c in combined.columns 
                       if c not in ['filepath', 'logger', 'date', 'start_s', 'end_s']]
        
        print(f"\n📐 Feature dimensions: {len(feature_cols)} features")
        print("\nFeature names:")
        for i, col in enumerate(feature_cols, 1):
            print(f"   {i:2d}. {col}")
        
        # Save statistics
        stats_path = OUTPUT_BASE / "feature_statistics.csv"
        stats = combined[feature_cols].describe()
        stats.to_csv(stats_path)
        print(f"\n💾 Statistics saved: {stats_path.relative_to(REPO_ROOT)}")
        
        # Show distribution by logger/date
        print(f"\n📦 Files created by logger/date:")
        grouped = combined.groupby(['logger', 'date']).size().reset_index(name='count')
        for _, row in grouped.iterrows():
            logger, date, count = row['logger'], row['date'], row['count']
            output_path = shard_path(OUTPUT_BASE, logger, date)
            rel_path = output_path.relative_to(REPO_ROOT)
            print(f"   ✓ {logger}/{date}: {count:>5} clips → {rel_path}")
        
        print(f"\n📈 Summary:")
        print(f"   Total clips processed: {len(combined):,}")
        print(f"   Unique loggers: {combined['logger'].nunique()}")
        print(f"   Unique dates: {combined['date'].nunique()}")
        print(f"   Features per clip: {len(feature_cols)}")
    
    print("\n" + "=" * 70)
    print("✅ ECOACOUSTIC EXTRACTION COMPLETE")
    print("=" * 70)


if __name__ == "__main__":
    main()
# Out:
# ======================================================================
# ECOACOUSTIC FEATURES EXTRACTION - 50K STRATIFIED SAMPLE
# ======================================================================
#
# 📂 Loading manifest from: /home/sparch/Uni-stuff/semester-2/applied_Ml/reef_zmsc/data/manifests/sample_50k_stratified.parquet
#    Total clips in manifest: 50,000
#    ℹ️  'end_s' column not found, computing from 'duration_s'
#
# 📊 Processing 50,000 clips
#    Batch size: 1000 clips
#    Workers: 18
#    Output: data/features/embeds_ecoacoustic_50k
#
# 🔧 Extracting ecoacoustic features...
# Processing clips: 100%|██████████| 50000/50000 [07:36<00:00, 109.49clip/s, saved=5e+4]
# ✅ Successfully processed and saved 50,000 clips
#
# 📊 Collecting feature statistics...
#
# 📐 Feature dimensions: 17 features
#
# Feature names:
#     1. spectral_centroid_mean
#     2. spectral_centroid_std
#     3. spectral_bandwidth_mean
#     4. spectral_rolloff_mean
#     5. spectral_flatness_mean
#     6. spectral_contrast_mean
#     7. aci
#     8. spectral_entropy
#     9. temporal_entropy
#    10. zcr_mean
#    11. rms_mean
#    12. rms_std
#    13. dynamic_range_db
#    14. snr_db
#    15. low_freq_energy
#    16. mid_freq_energy
#    17. high_freq_energy
#
# 💾 Statistics saved: data/features/embeds_ecoacoustic_50k/feature_statistics.csv
#
# 📦 Files created by logger/date:
#    ✓ 2802/20080226:    89 clips → data/features/embeds_ecoacoustic_50k/PAPCA/2802/20080226/features.parquet
#    ✓ 2802/20080227:    77 clips → data/features/embeds_ecoacoustic_50k/PAPCA/2802/20080227/features.parquet
#    ✓ 2802/20080228:   104 clips → data/features/embeds_ecoacoustic_50k/PAPCA/2802/20080228/features.parquet
#    ✓ 2802/20080229:   167 clips → data/features/embeds_ecoacoustic_50k/PAPCA/2802/20080229/features.parquet
#    ✓ 2802/20080301:   171 clips → data/features/embeds_ecoacoustic_50k/PAPCA/2802/20080301/features.parquet
#    ✓ 2802/20080302:   127 clips → data/features/embeds_ecoacoustic_50k/PAPCA/2802/20080302/features.parquet
#    ✓ 2802/20080303:   129 clips → data/features/embeds_ecoacoustic_50k/PAPCA/2802/20080303/features.parquet
#    ✓ 2802/20080304:   146 clips → data/features/embeds_ecoacoustic_50k/PAPCA/2802/20080304/features.parquet
#    ✓ 2802/20080305:   129 clips → data/features/embeds_ecoacoustic_50k/PAPCA/2802/20080305/features.parquet
#    ✓ 2802/20080306:   139 clips → data/features/embeds_ecoacoustic_50k/PAPCA/2802/20080306/features.parquet
#    ✓ 2802/20080307:   138 clips → data/features/embeds_ecoacoustic_50k/PAPCA/2802/20080307/features.parquet
#    ✓ 2802/20080308:   127 clips → data/features/embeds_ecoacoustic_50k/PAPCA/2802/20080308/features.parquet
#    ✓ 2802/20080309:   136 clips → data/features/embeds_ecoacoustic_50k/PAPCA/2802/20080309/features.parquet
#    ✓ 2802/20080310:   134 clips → data/features/embeds_ecoacoustic_50k/PAPCA/2802/20080310/features.parquet
#    ✓ 2802/20080311:   123 clips → data/features/embeds_ecoacoustic_50k/PAPCA/2802/20080311/features.parquet
#    ✓ 2802/20080312:   131 clips → data/features/embeds_ecoacoustic_50k/PAPCA/2802/20080312/features.parquet
#    ✓ 2802/20080313:   133 clips → data/features/embeds_ecoacoustic_50k/PAPCA/2802/20080313/features.parquet
#    ✓ 2802/20080314:   160 clips → data/features/embeds_ecoacoustic_50k/PAPCA/2802/20080314/features.parquet
#    ✓ 2802/20080315:   143 clips → data/features/embeds_ecoacoustic_50k/PAPCA/2802/20080315/features.parquet
#    ✓ 2802/20080316:   172 clips → data/features/embeds_ecoacoustic_50k/PAPCA/2802/20080316/features.parquet
#    ✓ 2802/20080317:   123 clips → data/features/embeds_ecoacoustic_50k/PAPCA/2802/20080317/features.parquet
#    ✓ 2802/20080318:   134 clips → data/features/embeds_ecoacoustic_50k/PAPCA/2802/20080318/features.parquet
#    ✓ 2802/20080319:   141 clips → data/features/embeds_ecoacoustic_50k/PAPCA/2802/20080319/features.parquet
#    ✓ 2802/20080320:   143 clips → data/features/embeds_ecoacoustic_50k/PAPCA/2802/20080320/features.parquet
#    ✓ 2802/20080321:   130 clips → data/features/embeds_ecoacoustic_50k/PAPCA/2802/20080321/features.parquet
#    ✓ 2802/20080322:   124 clips → data/features/embeds_ecoacoustic_50k/PAPCA/2802/20080322/features.parquet
#    ✓ 2802/20080323:   118 clips → data/features/embeds_ecoacoustic_50k/PAPCA/2802/20080323/features.parquet
#    ✓ 2802/20080324:   120 clips → data/features/embeds_ecoacoustic_50k/PAPCA/2802/20080324/features.parquet
#    ✓ 2802/20080325:   127 clips → data/features/embeds_ecoacoustic_50k/PAPCA/2802/20080325/features.parquet
#    ✓ 2802/20080326:   133 clips → data/features/embeds_ecoacoustic_50k/PAPCA/2802/20080326/features.parquet
#    ✓ 2802/20080327:   136 clips → data/features/embeds_ecoacoustic_50k/PAPCA/2802/20080327/features.parquet
#    ✓ 2802/20080328:   122 clips → data/features/embeds_ecoacoustic_50k/PAPCA/2802/20080328/features.parquet
#    ✓ 2802/20080329:   116 clips → data/features/embeds_ecoacoustic_50k/PAPCA/2802/20080329/features.parquet
#    ✓ 2802/20080330:   136 clips → data/features/embeds_ecoacoustic_50k/PAPCA/2802/20080330/features.parquet
#    ✓ 2802/20080331:   115 clips → data/features/embeds_ecoacoustic_50k/PAPCA/2802/20080331/features.parquet
#    ✓ 2802/20080401:   134 clips → data/features/embeds_ecoacoustic_50k/PAPCA/2802/20080401/features.parquet
#    ✓ 2802/20080402:   120 clips → data/features/embeds_ecoacoustic_50k/PAPCA/2802/20080402/features.parquet
#    ✓ 2802/20080403:   112 clips → data/features/embeds_ecoacoustic_50k/PAPCA/2802/20080403/features.parquet
#    ✓ 2802/20080404:   115 clips → data/features/embeds_ecoacoustic_50k/PAPCA/2802/20080404/features.parquet
#    ✓ 2802/20080405:   137 clips → data/features/embeds_ecoacoustic_50k/PAPCA/2802/20080405/features.parquet
#    ✓ 2802/20080406:   117 clips → data/features/embeds_ecoacoustic_50k/PAPCA/2802/20080406/features.parquet
#    ✓ 2802/20080407:   117 clips → data/features/embeds_ecoacoustic_50k/PAPCA/2802/20080407/features.parquet
#    ✓ 2802/20080408:   133 clips → data/features/embeds_ecoacoustic_50k/PAPCA/2802/20080408/features.parquet
#    ✓ 2802/20080409:   128 clips → data/features/embeds_ecoacoustic_50k/PAPCA/2802/20080409/features.parquet
#    ✓ 2802/20080410:   117 clips → data/features/embeds_ecoacoustic_50k/PAPCA/2802/20080410/features.parquet
#    ✓ 2802/20080411:   119 clips → data/features/embeds_ecoacoustic_50k/PAPCA/2802/20080411/features.parquet
#    ✓ 2802/20080412:     1 clips → data/features/embeds_ecoacoustic_50k/PAPCA/2802/20080412/features.parquet
#    ✓ 2802/20080419:    54 clips → data/features/embeds_ecoacoustic_50k/PAPCA/2802/20080419/features.parquet
#    ✓ 2802/20080420:   119 clips → data/features/embeds_ecoacoustic_50k/PAPCA/2802/20080420/features.parquet
#    ✓ 2802/20080421:     6 clips → data/features/embeds_ecoacoustic_50k/PAPCA/2802/20080421/features.parquet
#    ✓ 2802/20080811:    77 clips → data/features/embeds_ecoacoustic_50k/PAPCA/2802/20080811/features.parquet
#    ✓ 2802/20080812:   125 clips → data/features/embeds_ecoacoustic_50k/PAPCA/2802/20080812/features.parquet
#    ✓ 2802/20080813:   124 clips → data/features/embeds_ecoacoustic_50k/PAPCA/2802/20080813/features.parquet
#    ✓ 2802/20080814:   122 clips → data/features/embeds_ecoacoustic_50k/PAPCA/2802/20080814/features.parquet
#    ✓ 2802/20080815:   129 clips → data/features/embeds_ecoacoustic_50k/PAPCA/2802/20080815/features.parquet
#    ✓ 2802/20080816:   133 clips → data/features/embeds_ecoacoustic_50k/PAPCA/2802/20080816/features.parquet
#    ✓ 2802/20080817:   119 clips → data/features/embeds_ecoacoustic_50k/PAPCA/2802/20080817/features.parquet
#    ✓ 2802/20080818:   124 clips → data/features/embeds_ecoacoustic_50k/PAPCA/2802/20080818/features.parquet
#    ✓ 2802/20080819:   127 clips → data/features/embeds_ecoacoustic_50k/PAPCA/2802/20080819/features.parquet
#    ✓ 2802/20080820:   107 clips → data/features/embeds_ecoacoustic_50k/PAPCA/2802/20080820/features.parquet
#    ✓ 2802/20080821:   139 clips → data/features/embeds_ecoacoustic_50k/PAPCA/2802/20080821/features.parquet
#    ✓ 2802/20080822:   125 clips → data/features/embeds_ecoacoustic_50k/PAPCA/2802/20080822/features.parquet
#    ✓ 2802/20080823:   134 clips → data/features/embeds_ecoacoustic_50k/PAPCA/2802/20080823/features.parquet
#    ✓ 2802/20080824:   118 clips → data/features/embeds_ecoacoustic_50k/PAPCA/2802/20080824/features.parquet
#    ✓ 2802/20080825:   113 clips → data/features/embeds_ecoacoustic_50k/PAPCA/2802/20080825/features.parquet
#    ✓ 2802/20080826:   115 clips → data/features/embeds_ecoacoustic_50k/PAPCA/2802/20080826/features.parquet
#    ✓ 2802/20080827:   112 clips → data/features/embeds_ecoacoustic_50k/PAPCA/2802/20080827/features.parquet
#    ✓ 2802/20080828:   126 clips → data/features/embeds_ecoacoustic_50k/PAPCA/2802/20080828/features.parquet
#    ✓ 2802/20080829:    76 clips → data/features/embeds_ecoacoustic_50k/PAPCA/2802/20080829/features.parquet
#    ✓ 2823/20081229:    11 clips → data/features/embeds_ecoacoustic_50k/PAPCA/2823/20081229/features.parquet
#    ✓ 2823/20090214:    95 clips → data/features/embeds_ecoacoustic_50k/PAPCA/2823/20090214/features.parquet
#    ✓ 2823/20090215:    58 clips → data/features/embeds_ecoacoustic_50k/PAPCA/2823/20090215/features.parquet
#    ✓ 2823/20090216:   103 clips → data/features/embeds_ecoacoustic_50k/PAPCA/2823/20090216/features.parquet
#    ✓ 2823/20090224:    16 clips → data/features/embeds_ecoacoustic_50k/PAPCA/2823/20090224/features.parquet
#    ✓ 2823/20090225:   243 clips → data/features/embeds_ecoacoustic_50k/PAPCA/2823/20090225/features.parquet
#    ✓ 2823/20090226:   240 clips → data/features/embeds_ecoacoustic_50k/PAPCA/2823/20090226/features.parquet
#    ✓ 2823/20090227:   223 clips → data/features/embeds_ecoacoustic_50k/PAPCA/2823/20090227/features.parquet
#    ✓ 2823/20090228:   267 clips → data/features/embeds_ecoacoustic_50k/PAPCA/2823/20090228/features.parquet
#    ✓ 2823/20090301:   228 clips → data/features/embeds_ecoacoustic_50k/PAPCA/2823/20090301/features.parquet
#    ✓ 2823/20090302:   251 clips → data/features/embeds_ecoacoustic_50k/PAPCA/2823/20090302/features.parquet
#    ✓ 2823/20090303:   197 clips → data/features/embeds_ecoacoustic_50k/PAPCA/2823/20090303/features.parquet
#    ✓ 2823/20090304:   271 clips → data/features/embeds_ecoacoustic_50k/PAPCA/2823/20090304/features.parquet
#    ✓ 2823/20090305:   274 clips → data/features/embeds_ecoacoustic_50k/PAPCA/2823/20090305/features.parquet
#    ✓ 2823/20090306:   236 clips → data/features/embeds_ecoacoustic_50k/PAPCA/2823/20090306/features.parquet
#    ✓ 2823/20090307:   188 clips → data/features/embeds_ecoacoustic_50k/PAPCA/2823/20090307/features.parquet
#    ✓ 2823/20090308:   251 clips → data/features/embeds_ecoacoustic_50k/PAPCA/2823/20090308/features.parquet
#    ✓ 2823/20090309:   249 clips → data/features/embeds_ecoacoustic_50k/PAPCA/2823/20090309/features.parquet
#    ✓ 2823/20090310:   201 clips → data/features/embeds_ecoacoustic_50k/PAPCA/2823/20090310/features.parquet
#    ✓ 2823/20090311:   173 clips → data/features/embeds_ecoacoustic_50k/PAPCA/2823/20090311/features.parquet
#    ✓ 2823/20090312:   202 clips → data/features/embeds_ecoacoustic_50k/PAPCA/2823/20090312/features.parquet
#    ✓ 2823/20090313:   221 clips → data/features/embeds_ecoacoustic_50k/PAPCA/2823/20090313/features.parquet
#    ✓ 2823/20090314:   214 clips → data/features/embeds_ecoacoustic_50k/PAPCA/2823/20090314/features.parquet
#    ✓ 2823/20090315:   240 clips → data/features/embeds_ecoacoustic_50k/PAPCA/2823/20090315/features.parquet
#    ✓ 2823/20090316:   234 clips → data/features/embeds_ecoacoustic_50k/PAPCA/2823/20090316/features.parquet
#    ✓ 2823/20090317:   247 clips → data/features/embeds_ecoacoustic_50k/PAPCA/2823/20090317/features.parquet
#    ✓ 2823/20090318:   254 clips → data/features/embeds_ecoacoustic_50k/PAPCA/2823/20090318/features.parquet
#    ✓ 2823/20090319:   262 clips → data/features/embeds_ecoacoustic_50k/PAPCA/2823/20090319/features.parquet
#    ✓ 2823/20090320:   258 clips → data/features/embeds_ecoacoustic_50k/PAPCA/2823/20090320/features.parquet
#    ✓ 2823/20090321:   231 clips → data/features/embeds_ecoacoustic_50k/PAPCA/2823/20090321/features.parquet
#    ✓ 2823/20090322:   256 clips → data/features/embeds_ecoacoustic_50k/PAPCA/2823/20090322/features.parquet
#    ✓ 2823/20090323:   245 clips → data/features/embeds_ecoacoustic_50k/PAPCA/2823/20090323/features.parquet
#    ✓ 2823/20090324:   270 clips → data/features/embeds_ecoacoustic_50k/PAPCA/2823/20090324/features.parquet
#    ✓ 2823/20090325:   273 clips → data/features/embeds_ecoacoustic_50k/PAPCA/2823/20090325/features.parquet
#    ✓ 2823/20090326:   263 clips → data/features/embeds_ecoacoustic_50k/PAPCA/2823/20090326/features.parquet
#    ✓ 2823/20090327:   284 clips → data/features/embeds_ecoacoustic_50k/PAPCA/2823/20090327/features.parquet
#    ✓ 2823/20090328:   250 clips → data/features/embeds_ecoacoustic_50k/PAPCA/2823/20090328/features.parquet
#    ✓ 2823/20090329:   268 clips → data/features/embeds_ecoacoustic_50k/PAPCA/2823/20090329/features.parquet
#    ✓ 2823/20090330:   267 clips → data/features/embeds_ecoacoustic_50k/PAPCA/2823/20090330/features.parquet
#    ✓ 2823/20090331:   257 clips → data/features/embeds_ecoacoustic_50k/PAPCA/2823/20090331/features.parquet
#    ✓ 2823/20090401:   216 clips → data/features/embeds_ecoacoustic_50k/PAPCA/2823/20090401/features.parquet
#    ✓ 2823/20090402:   237 clips → data/features/embeds_ecoacoustic_50k/PAPCA/2823/20090402/features.parquet
#    ✓ 2823/20090403:   276 clips → data/features/embeds_ecoacoustic_50k/PAPCA/2823/20090403/features.parquet
#    ✓ 2823/20090404:   263 clips → data/features/embeds_ecoacoustic_50k/PAPCA/2823/20090404/features.parquet
#    ✓ 2823/20090405:   266 clips → data/features/embeds_ecoacoustic_50k/PAPCA/2823/20090405/features.parquet
#    ✓ 2823/20090406:   250 clips → data/features/embeds_ecoacoustic_50k/PAPCA/2823/20090406/features.parquet
#    ✓ 2823/20090407:   270 clips → data/features/embeds_ecoacoustic_50k/PAPCA/2823/20090407/features.parquet
#    ✓ 2823/20090408:   256 clips → data/features/embeds_ecoacoustic_50k/PAPCA/2823/20090408/features.parquet
#    ✓ 2823/20090409:   217 clips → data/features/embeds_ecoacoustic_50k/PAPCA/2823/20090409/features.parquet
#    ✓ 2823/20090410:   200 clips → data/features/embeds_ecoacoustic_50k/PAPCA/2823/20090410/features.parquet
#    ✓ 2823/20090411:   177 clips → data/features/embeds_ecoacoustic_50k/PAPCA/2823/20090411/features.parquet
#    ✓ 2823/20090412:   239 clips → data/features/embeds_ecoacoustic_50k/PAPCA/2823/20090412/features.parquet
#    ✓ 2823/20090413:   265 clips → data/features/embeds_ecoacoustic_50k/PAPCA/2823/20090413/features.parquet
#    ✓ 2823/20090414:   238 clips → data/features/embeds_ecoacoustic_50k/PAPCA/2823/20090414/features.parquet
#    ✓ 2823/20090415:   171 clips → data/features/embeds_ecoacoustic_50k/PAPCA/2823/20090415/features.parquet
#    ✓ 2823/20090416:   231 clips → data/features/embeds_ecoacoustic_50k/PAPCA/2823/20090416/features.parquet
#    ✓ 2823/20090417:   213 clips → data/features/embeds_ecoacoustic_50k/PAPCA/2823/20090417/features.parquet
#    ✓ 2823/20090418:   229 clips → data/features/embeds_ecoacoustic_50k/PAPCA/2823/20090418/features.parquet
#    ✓ 2823/20090419:   243 clips → data/features/embeds_ecoacoustic_50k/PAPCA/2823/20090419/features.parquet
#    ✓ 2823/20090420:   216 clips → data/features/embeds_ecoacoustic_50k/PAPCA/2823/20090420/features.parquet
#    ✓ 2823/20090421:   247 clips → data/features/embeds_ecoacoustic_50k/PAPCA/2823/20090421/features.parquet
#    ✓ 2823/20090422:   208 clips → data/features/embeds_ecoacoustic_50k/PAPCA/2823/20090422/features.parquet
#    ✓ 2823/20090423:   193 clips → data/features/embeds_ecoacoustic_50k/PAPCA/2823/20090423/features.parquet
#    ✓ 2823/20090424:   212 clips → data/features/embeds_ecoacoustic_50k/PAPCA/2823/20090424/features.parquet
#    ✓ 2823/20090425:   214 clips → data/features/embeds_ecoacoustic_50k/PAPCA/2823/20090425/features.parquet
#    ✓ 2823/20090426:   209 clips → data/features/embeds_ecoacoustic_50k/PAPCA/2823/20090426/features.parquet
#    ✓ 2823/20090427:   242 clips → data/features/embeds_ecoacoustic_50k/PAPCA/2823/20090427/features.parquet
#    ✓ 2823/20090428:   248 clips → data/features/embeds_ecoacoustic_50k/PAPCA/2823/20090428/features.parquet
#    ✓ 2823/20090429:   253 clips → data/features/embeds_ecoacoustic_50k/PAPCA/2823/20090429/features.parquet
#    ✓ 2823/20090430:   225 clips → data/features/embeds_ecoacoustic_50k/PAPCA/2823/20090430/features.parquet
#    ✓ 2823/20090501:   259 clips → data/features/embeds_ecoacoustic_50k/PAPCA/2823/20090501/features.parquet
#    ✓ 2823/20090503:    50 clips → data/features/embeds_ecoacoustic_50k/PAPCA/2823/20090503/features.parquet
#    ✓ 2823/20090504:   259 clips → data/features/embeds_ecoacoustic_50k/PAPCA/2823/20090504/features.parquet
#    ✓ 2823/20090505:   251 clips → data/features/embeds_ecoacoustic_50k/PAPCA/2823/20090505/features.parquet
#    ✓ 2823/20090506:   259 clips → data/features/embeds_ecoacoustic_50k/PAPCA/2823/20090506/features.parquet
#    ✓ 2823/20090507:   261 clips → data/features/embeds_ecoacoustic_50k/PAPCA/2823/20090507/features.parquet
#    ✓ 2823/20090508:   291 clips → data/features/embeds_ecoacoustic_50k/PAPCA/2823/20090508/features.parquet
#    ✓ 2823/20090509:   231 clips → data/features/embeds_ecoacoustic_50k/PAPCA/2823/20090509/features.parquet
#    ✓ 2823/20090510:   231 clips → data/features/embeds_ecoacoustic_50k/PAPCA/2823/20090510/features.parquet
#    ✓ 2823/20090511:   191 clips → data/features/embeds_ecoacoustic_50k/PAPCA/2823/20090511/features.parquet
#    ✓ 2823/20090512:   235 clips → data/features/embeds_ecoacoustic_50k/PAPCA/2823/20090512/features.parquet
#    ✓ 2823/20090513:   212 clips → data/features/embeds_ecoacoustic_50k/PAPCA/2823/20090513/features.parquet
#    ✓ 2823/20090514:   187 clips → data/features/embeds_ecoacoustic_50k/PAPCA/2823/20090514/features.parquet
#    ✓ 2823/20090515:   207 clips → data/features/embeds_ecoacoustic_50k/PAPCA/2823/20090515/features.parquet
#    ✓ 2823/20090516:   228 clips → data/features/embeds_ecoacoustic_50k/PAPCA/2823/20090516/features.parquet
#    ✓ 2823/20090517:   246 clips → data/features/embeds_ecoacoustic_50k/PAPCA/2823/20090517/features.parquet
#    ✓ 2823/20090518:   256 clips → data/features/embeds_ecoacoustic_50k/PAPCA/2823/20090518/features.parquet
#    ✓ 2823/20090519:   248 clips → data/features/embeds_ecoacoustic_50k/PAPCA/2823/20090519/features.parquet
#    ✓ 2823/20090520:   166 clips → data/features/embeds_ecoacoustic_50k/PAPCA/2823/20090520/features.parquet
#    ✓ 2823/20090521:   221 clips → data/features/embeds_ecoacoustic_50k/PAPCA/2823/20090521/features.parquet
#    ✓ 2823/20090522:   236 clips → data/features/embeds_ecoacoustic_50k/PAPCA/2823/20090522/features.parquet
#    ✓ 2823/20090523:   203 clips → data/features/embeds_ecoacoustic_50k/PAPCA/2823/20090523/features.parquet
#    ✓ 2823/20090524:   236 clips → data/features/embeds_ecoacoustic_50k/PAPCA/2823/20090524/features.parquet
#    ✓ 2823/20090525:   196 clips → data/features/embeds_ecoacoustic_50k/PAPCA/2823/20090525/features.parquet
#    ✓ 2823/20090526:   183 clips → data/features/embeds_ecoacoustic_50k/PAPCA/2823/20090526/features.parquet
#    ✓ 2823/20090527:   174 clips → data/features/embeds_ecoacoustic_50k/PAPCA/2823/20090527/features.parquet
#    ✓ 2823/20090528:   230 clips → data/features/embeds_ecoacoustic_50k/PAPCA/2823/20090528/features.parquet
#    ✓ 2823/20090529:   237 clips → data/features/embeds_ecoacoustic_50k/PAPCA/2823/20090529/features.parquet
#    ✓ 2823/20090530:   209 clips → data/features/embeds_ecoacoustic_50k/PAPCA/2823/20090530/features.parquet
#    ✓ 2823/20090531:   177 clips → data/features/embeds_ecoacoustic_50k/PAPCA/2823/20090531/features.parquet
#    ✓ 2823/20090601:   191 clips → data/features/embeds_ecoacoustic_50k/PAPCA/2823/20090601/features.parquet
#    ✓ 2823/20090602:   214 clips → data/features/embeds_ecoacoustic_50k/PAPCA/2823/20090602/features.parquet
#    ✓ 2823/20090603:   193 clips → data/features/embeds_ecoacoustic_50k/PAPCA/2823/20090603/features.parquet
#    ✓ 2823/20090604:   153 clips → data/features/embeds_ecoacoustic_50k/PAPCA/2823/20090604/features.parquet
#    ✓ 2823/20090605:   205 clips → data/features/embeds_ecoacoustic_50k/PAPCA/2823/20090605/features.parquet
#    ✓ 2823/20090606:   196 clips → data/features/embeds_ecoacoustic_50k/PAPCA/2823/20090606/features.parquet
#    ✓ 2823/20090607:   191 clips → data/features/embeds_ecoacoustic_50k/PAPCA/2823/20090607/features.parquet
#    ✓ 2823/20090608:   225 clips → data/features/embeds_ecoacoustic_50k/PAPCA/2823/20090608/features.parquet
#    ✓ 2823/20090609:   178 clips → data/features/embeds_ecoacoustic_50k/PAPCA/2823/20090609/features.parquet
#    ✓ 2823/20090610:   209 clips → data/features/embeds_ecoacoustic_50k/PAPCA/2823/20090610/features.parquet
#    ✓ 2823/20090611:   141 clips → data/features/embeds_ecoacoustic_50k/PAPCA/2823/20090611/features.parquet
#    ✓ 2823/20090612:   185 clips → data/features/embeds_ecoacoustic_50k/PAPCA/2823/20090612/features.parquet
#    ✓ 2823/20090613:   206 clips → data/features/embeds_ecoacoustic_50k/PAPCA/2823/20090613/features.parquet
#    ✓ 2823/20090614:   231 clips → data/features/embeds_ecoacoustic_50k/PAPCA/2823/20090614/features.parquet
#    ✓ 2823/20090615:   221 clips → data/features/embeds_ecoacoustic_50k/PAPCA/2823/20090615/features.parquet
#    ✓ 2823/20090616:   256 clips → data/features/embeds_ecoacoustic_50k/PAPCA/2823/20090616/features.parquet
#    ✓ 2823/20090617:   219 clips → data/features/embeds_ecoacoustic_50k/PAPCA/2823/20090617/features.parquet
#    ✓ 2823/20090618:   245 clips → data/features/embeds_ecoacoustic_50k/PAPCA/2823/20090618/features.parquet
#    ✓ 2823/20090619:   188 clips → data/features/embeds_ecoacoustic_50k/PAPCA/2823/20090619/features.parquet
#    ✓ 2823/20090620:   199 clips → data/features/embeds_ecoacoustic_50k/PAPCA/2823/20090620/features.parquet
#    ✓ 2823/20090621:   122 clips → data/features/embeds_ecoacoustic_50k/PAPCA/2823/20090621/features.parquet
#    ✓ 2823/20090622:   171 clips → data/features/embeds_ecoacoustic_50k/PAPCA/2823/20090622/features.parquet
#    ✓ 2823/20090623:   183 clips → data/features/embeds_ecoacoustic_50k/PAPCA/2823/20090623/features.parquet
#    ✓ 2823/20090624:   144 clips → data/features/embeds_ecoacoustic_50k/PAPCA/2823/20090624/features.parquet
#    ✓ 2823/20090625:   193 clips → data/features/embeds_ecoacoustic_50k/PAPCA/2823/20090625/features.parquet
#    ✓ 2823/20090626:   168 clips → data/features/embeds_ecoacoustic_50k/PAPCA/2823/20090626/features.parquet
#    ✓ 2823/20090627:   124 clips → data/features/embeds_ecoacoustic_50k/PAPCA/2823/20090627/features.parquet
#    ✓ 2823/20090628:   232 clips → data/features/embeds_ecoacoustic_50k/PAPCA/2823/20090628/features.parquet
#    ✓ 2823/20090629:   146 clips → data/features/embeds_ecoacoustic_50k/PAPCA/2823/20090629/features.parquet
#    ✓ 2823/20090630:   227 clips → data/features/embeds_ecoacoustic_50k/PAPCA/2823/20090630/features.parquet
#    ✓ 2823/20090701:   262 clips → data/features/embeds_ecoacoustic_50k/PAPCA/2823/20090701/features.parquet
#    ✓ 2823/20090702:   165 clips → data/features/embeds_ecoacoustic_50k/PAPCA/2823/20090702/features.parquet
#    ✓ 2823/20090703:   206 clips → data/features/embeds_ecoacoustic_50k/PAPCA/2823/20090703/features.parquet
#    ✓ 2823/20090704:   211 clips → data/features/embeds_ecoacoustic_50k/PAPCA/2823/20090704/features.parquet
#    ✓ 2823/20090705:   159 clips → data/features/embeds_ecoacoustic_50k/PAPCA/2823/20090705/features.parquet
#    ✓ 2823/20090706:   161 clips → data/features/embeds_ecoacoustic_50k/PAPCA/2823/20090706/features.parquet
#    ✓ 2823/20090707:   170 clips → data/features/embeds_ecoacoustic_50k/PAPCA/2823/20090707/features.parquet
#    ✓ 2823/20090708:   193 clips → data/features/embeds_ecoacoustic_50k/PAPCA/2823/20090708/features.parquet
#    ✓ 2823/20090709:   213 clips → data/features/embeds_ecoacoustic_50k/PAPCA/2823/20090709/features.parquet
#    ✓ 2823/20090710:   213 clips → data/features/embeds_ecoacoustic_50k/PAPCA/2823/20090710/features.parquet
#    ✓ 2823/20090711:    67 clips → data/features/embeds_ecoacoustic_50k/PAPCA/2823/20090711/features.parquet
#    ✓ 2823/20090712:   154 clips → data/features/embeds_ecoacoustic_50k/PAPCA/2823/20090712/features.parquet
#    ✓ 2823/20090713:   199 clips → data/features/embeds_ecoacoustic_50k/PAPCA/2823/20090713/features.parquet
#    ✓ 2823/20090714:   148 clips → data/features/embeds_ecoacoustic_50k/PAPCA/2823/20090714/features.parquet
#    ✓ 2823/20090715:   173 clips → data/features/embeds_ecoacoustic_50k/PAPCA/2823/20090715/features.parquet
#    ✓ 2823/20090716:   251 clips → data/features/embeds_ecoacoustic_50k/PAPCA/2823/20090716/features.parquet
#    ✓ 2823/20090717:   145 clips → data/features/embeds_ecoacoustic_50k/PAPCA/2823/20090717/features.parquet
#    ✓ 2823/20090718:   159 clips → data/features/embeds_ecoacoustic_50k/PAPCA/2823/20090718/features.parquet
#    ✓ 2823/20090719:   195 clips → data/features/embeds_ecoacoustic_50k/PAPCA/2823/20090719/features.parquet
#    ✓ 2823/20090720:   215 clips → data/features/embeds_ecoacoustic_50k/PAPCA/2823/20090720/features.parquet
#    ✓ 2823/20090721:   178 clips → data/features/embeds_ecoacoustic_50k/PAPCA/2823/20090721/features.parquet
#    ✓ 2823/20090722:   206 clips → data/features/embeds_ecoacoustic_50k/PAPCA/2823/20090722/features.parquet
#    ✓ 2823/20090723:   138 clips → data/features/embeds_ecoacoustic_50k/PAPCA/2823/20090723/features.parquet
#    ✓ 2823/20090724:   186 clips → data/features/embeds_ecoacoustic_50k/PAPCA/2823/20090724/features.parquet
#    ✓ 2823/20090725:   179 clips → data/features/embeds_ecoacoustic_50k/PAPCA/2823/20090725/features.parquet
#    ✓ 2823/20090726:   110 clips → data/features/embeds_ecoacoustic_50k/PAPCA/2823/20090726/features.parquet
#    ✓ 2823/20090827:    61 clips → data/features/embeds_ecoacoustic_50k/PAPCA/2823/20090827/features.parquet
#    ✓ 2823/20090828:   126 clips → data/features/embeds_ecoacoustic_50k/PAPCA/2823/20090828/features.parquet
#    ✓ 2823/20090829:   173 clips → data/features/embeds_ecoacoustic_50k/PAPCA/2823/20090829/features.parquet
#    ✓ 2823/20090830:   163 clips → data/features/embeds_ecoacoustic_50k/PAPCA/2823/20090830/features.parquet
#    ✓ 2823/20090831:   205 clips → data/features/embeds_ecoacoustic_50k/PAPCA/2823/20090831/features.parquet
#    ✓ 2823/20090901:   142 clips → data/features/embeds_ecoacoustic_50k/PAPCA/2823/20090901/features.parquet
#    ✓ 2823/20090902:   190 clips → data/features/embeds_ecoacoustic_50k/PAPCA/2823/20090902/features.parquet
#    ✓ 2823/20090903:   195 clips → data/features/embeds_ecoacoustic_50k/PAPCA/2823/20090903/features.parquet
#    ✓ 2823/20090904:   144 clips → data/features/embeds_ecoacoustic_50k/PAPCA/2823/20090904/features.parquet
#    ✓ 2823/20090905:   247 clips → data/features/embeds_ecoacoustic_50k/PAPCA/2823/20090905/features.parquet
#    ✓ 2823/20090906:   164 clips → data/features/embeds_ecoacoustic_50k/PAPCA/2823/20090906/features.parquet
#    ✓ 2823/20090907:   184 clips → data/features/embeds_ecoacoustic_50k/PAPCA/2823/20090907/features.parquet
#    ✓ 2823/20090908:   174 clips → data/features/embeds_ecoacoustic_50k/PAPCA/2823/20090908/features.parquet
#    ✓ 2823/20090909:   188 clips → data/features/embeds_ecoacoustic_50k/PAPCA/2823/20090909/features.parquet
#    ✓ 2823/20090910:   195 clips → data/features/embeds_ecoacoustic_50k/PAPCA/2823/20090910/features.parquet
#    ✓ 2823/20090911:   132 clips → data/features/embeds_ecoacoustic_50k/PAPCA/2823/20090911/features.parquet
#    ✓ 2823/20090912:   193 clips → data/features/embeds_ecoacoustic_50k/PAPCA/2823/20090912/features.parquet
#    ✓ 2823/20090913:   178 clips → data/features/embeds_ecoacoustic_50k/PAPCA/2823/20090913/features.parquet
#    ✓ 2823/20090914:   165 clips → data/features/embeds_ecoacoustic_50k/PAPCA/2823/20090914/features.parquet
#    ✓ 2823/20090915:   224 clips → data/features/embeds_ecoacoustic_50k/PAPCA/2823/20090915/features.parquet
#    ✓ 2823/20090916:   258 clips → data/features/embeds_ecoacoustic_50k/PAPCA/2823/20090916/features.parquet
#    ✓ 2823/20090917:   176 clips → data/features/embeds_ecoacoustic_50k/PAPCA/2823/20090917/features.parquet
#    ✓ 2823/20090918:   145 clips → data/features/embeds_ecoacoustic_50k/PAPCA/2823/20090918/features.parquet
#    ✓ 2823/20090919:   219 clips → data/features/embeds_ecoacoustic_50k/PAPCA/2823/20090919/features.parquet
#    ✓ 2823/20090920:   203 clips → data/features/embeds_ecoacoustic_50k/PAPCA/2823/20090920/features.parquet
#    ✓ 2823/20090921:   169 clips → data/features/embeds_ecoacoustic_50k/PAPCA/2823/20090921/features.parquet
#    ✓ 2823/20090922:   133 clips → data/features/embeds_ecoacoustic_50k/PAPCA/2823/20090922/features.parquet
#    ✓ 2823/20090923:   170 clips → data/features/embeds_ecoacoustic_50k/PAPCA/2823/20090923/features.parquet
#    ✓ 2823/20090924:   205 clips → data/features/embeds_ecoacoustic_50k/PAPCA/2823/20090924/features.parquet
#    ✓ 2823/20090925:   212 clips → data/features/embeds_ecoacoustic_50k/PAPCA/2823/20090925/features.parquet
#    ✓ 2823/20090926:   200 clips → data/features/embeds_ecoacoustic_50k/PAPCA/2823/20090926/features.parquet
#    ✓ 2823/20090927:   190 clips → data/features/embeds_ecoacoustic_50k/PAPCA/2823/20090927/features.parquet
#    ✓ 2823/20090928:   177 clips → data/features/embeds_ecoacoustic_50k/PAPCA/2823/20090928/features.parquet
#    ✓ 2823/20090929:   173 clips → data/features/embeds_ecoacoustic_50k/PAPCA/2823/20090929/features.parquet
#    ✓ 2823/20090930:   225 clips → data/features/embeds_ecoacoustic_50k/PAPCA/2823/20090930/features.parquet
#    ✓ 2823/20091001:   203 clips → data/features/embeds_ecoacoustic_50k/PAPCA/2823/20091001/features.parquet
#    ✓ 2823/20091002:   222 clips → data/features/embeds_ecoacoustic_50k/PAPCA/2823/20091002/features.parquet
#    ✓ 2823/20091003:   170 clips → data/features/embeds_ecoacoustic_50k/PAPCA/2823/20091003/features.parquet
#    ✓ 2823/20091004:   161 clips → data/features/embeds_ecoacoustic_50k/PAPCA/2823/20091004/features.parquet
#    ✓ 2823/20091005:   283 clips → data/features/embeds_ecoacoustic_50k/PAPCA/2823/20091005/features.parquet
#    ✓ 2823/20091006:   325 clips → data/features/embeds_ecoacoustic_50k/PAPCA/2823/20091006/features.parquet
#    ✓ 2823/20091007:   327 clips → data/features/embeds_ecoacoustic_50k/PAPCA/2823/20091007/features.parquet
#    ✓ 2823/20091008:   246 clips → data/features/embeds_ecoacoustic_50k/PAPCA/2823/20091008/features.parquet
#    ✓ 2823/20091009:   238 clips → data/features/embeds_ecoacoustic_50k/PAPCA/2823/20091009/features.parquet
#    ✓ 2823/20091010:   253 clips → data/features/embeds_ecoacoustic_50k/PAPCA/2823/20091010/features.parquet
#    ✓ 2823/20091011:   230 clips → data/features/embeds_ecoacoustic_50k/PAPCA/2823/20091011/features.parquet
#
# 📈 Summary:
#    Total clips processed: 50,000
#    Unique loggers: 2
#    Unique dates: 271
#    Features per clip: 17
#
# ======================================================================
# ✅ ECOACOUSTIC EXTRACTION COMPLETE
# ======================================================================
