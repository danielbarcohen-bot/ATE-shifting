# %%
import pandas as pd
import numpy as np
import gzip
import os
import datetime
import pandas as pd
import calendar
import numpy as np
import glob
import sys
import gc
import re
#import quantstats as qs
import time

import matplotlib.pyplot as plt

import nest_asyncio # install this package to avoid running in loop

import urllib
import pandas_ta as ta

import warnings

import requests

import hmac
import hashlib

import aiohttp
import asyncio

import logging
from datetime import timezone

import nest_asyncio

# Filter depreciation warnings from pandas regarding the append method
warnings.filterwarnings('ignore', category=FutureWarning, message=".*append.*")
pd.options.mode.chained_assignment = None

# Set pandas to display all digits for floating-point numbers
pd.options.display.float_format = '{:.8f}'.format

import os
from dotenv import load_dotenv

import warnings
warnings.simplefilter(action='ignore', category=pd.errors.PerformanceWarning)

# Ignore only FutureWarning
warnings.filterwarnings('ignore', category=FutureWarning)

# Ignore only RuntimeWarning
warnings.filterwarnings('ignore', category=RuntimeWarning)

import importlib


from Orats_options_fetch_functions import *

from faster_numba_strategy_functions import *

import strategy_functions

importlib.reload(strategy_functions)
from strategy_functions import *

# import Common_functions

# importlib.reload(strategy_functions)
# importlib.reload(Common_functions)

# from Common_functions import *
# coin_desk_api_key =  "e43c1fd991e660b9bf959645f0800bb7e76fb4a3537ab773cec62b2fad31af2d"
from datetime import time
from pathlib import Path
# Get the user's home directory dynamically
home_dir = r"C:\Data\Options_logs"
#====================================

strategy_name = "Spread_ROC_Arb"

# Create a folder for the strategy_name if it doesn't exist in home directory

strategy_folder = os.path.join(home_dir, strategy_name)
if not os.path.exists(strategy_folder):
    os.makedirs(strategy_folder)

# Create the full path to the output file. this file contains all the trades

output_all_trades_file = os.path.join(strategy_folder, f"All_trades_{strategy_name}.csv")
trade_html_file = os.path.join(strategy_folder, f"Trade_stats_{strategy_name}.html")

#=== location to store the trade dataframe for debug

base_folder_df = "strategy_dataframe"
df_folder = os.path.join(strategy_folder, base_folder_df)
if not os.path.exists(df_folder):
    os.makedirs(df_folder)
    print("\n Created strategy dataframe folder : " ,df_folder )

#----- symbol_wise_trades

trades_folder = "sym_wise_trades"
trades_strategy_folder = os.path.join(strategy_folder, trades_folder)

if not os.path.exists(trades_strategy_folder):
    print("\n Making folder for symbol wise trades of strategy" , trades_strategy_folder)
    os.makedirs(trades_strategy_folder)

logger = setup_logger("Spread_ROC_Arb", strategy_folder, log_file="strategy.log" , to_console=False)

# %%
import duckdb
import pandas as pd
import matplotlib.pyplot as plt

# Connect to an in-memory database
con = duckdb.connect()

# --- Your setup code (which is correct) ---
con.execute("INSTALL httpfs;")
con.execute("LOAD httpfs;")
con.execute("""
SET s3_endpoint='122.176.133.73:9000';
SET s3_use_ssl=false;
SET s3_access_key_id='minioadmin';
SET s3_secret_access_key='minioadmin';
""")
con.execute("SET s3_url_style='path';") 
con.execute("PRAGMA threads=8;")
con.execute("PRAGMA enable_object_cache;")

# --- THE MISSING STEP: Querying a file from S3 ---
# Replace with your actual S3 bucket and file path
# This can be a .parquet, .csv, or .json file
s3_file_path = 's3://duckdata/ORATS/Options/**/*.parquet'

try:
    # Execute a query on the S3 file and fetch the result as a Pandas DataFrame
    print(f"Querying data from: {s3_file_path}")
    df = con.execute(f"""
        SELECT *
        FROM '{s3_file_path}'
        LIMIT 2;
    """).df()

    print("\n✅ Query successful! First 5 rows of data:")
    print(df.head())

except Exception as e:
    print(f"\n❌ An error occurred during the query: {e}")

# finally:
#     # It's good practice to close the connection
#     con.close()
# Out:
# Querying data from: s3://duckdata/ORATS/Options/**/*.parquet
#
# ✅ Query successful! First 5 rows of data:
#       expiry       strike  dte  optionType                  ts         low  \
# 0 2024-01-26 421.00000000   25          -1 2024-01-02 17:13:00 17.18000000
# 1 2024-01-12 414.00000000   11          -1 2024-01-02 17:13:00 10.41500000
#
#          high        open       close     volume  ...      askSize  \
# 0 17.18000000 17.18000000 17.18000000 0.00000000  ...  50.00000000
# 1 10.41500000 10.41500000 10.41500000 0.00000000  ... 151.00000000
#
#      bidPrice    askPrice      bidIv      askIv         iv          oi  \
# 0 17.12000000 17.24000000 0.13785700 0.14511500 0.14148600 15.00000000
# 1 10.34000000 10.49000000 0.14267100 0.15199600 0.14733300 54.00000000
#
#     stockPrice        day ticker
# 0 404.00000000 2024-01-02    QQQ
# 1 404.00000000 2024-01-02    QQQ
#
# [2 rows x 21 columns]

# %%
ifol = r"C:\Data\Aggregate_Data\Options\USA\Raw_SPY_1min_2024_2025_ORATS_close.parquet"
#== read the RELIANCE data

com_df2 = pd.read_parquet(ifol)

if 'timestamp' in com_df2.columns:
    com_df2['timestamp'] = pd.to_datetime(com_df2['timestamp'])
    com_df2.set_index('timestamp', inplace=True)



com_df2 = com_df2[~com_df2.index.duplicated(keep='first')]


com_df2.dropna(how='all', inplace=True)

vix_df = pd.read_parquet(r"C:\Data\Aggregate_Data\VIX_1_min_2019_2025.parquet")
com_df2 = com_df2.join(vix_df)


final_symbols = com_df2.filter(like='close').columns.str.replace('_close', '')
print("Total symbols found after all filtering: ", len(final_symbols))

# Calculate the number of rows in the DataFrame

com_df2[[f"{symbol}_intraday_low" for symbol in final_symbols]] =com_df2[[f"{symbol}_close" for symbol in final_symbols]].apply(lambda x: intraday_low(com_df2, low_col=x.name,agg_func='min'))

com_df2[[f"{symbol}_intraday_high" for symbol in final_symbols]] =com_df2[[f"{symbol}_close" for symbol in final_symbols]].apply(lambda x: intraday_high(com_df2, high_col=x.name,agg_func='max'))

com_df2[[f"{symbol}_todayo" for symbol in final_symbols]] = com_df2[[f'{symbol}_close' for symbol in final_symbols]].resample('D').transform('first')

# com_df2[[f"{symbol}_daily_ROC" for symbol in final_symbols]] = com_df2[[f"{symbol}_close" for symbol in final_symbols]].pct_change(periods=50)

# com_df2[[f"{symbol}_ROC" for symbol in final_symbols]] = com_df2[[f"{symbol}_close" for symbol in final_symbols]].pct_change()

# com_df2[[f"{symbol}_ROC_4" for symbol in final_symbols]] = com_df2[[f"{symbol}_close" for symbol in final_symbols]].pct_change(periods=4)

com_df2[[f"{symbol}_prevdayl" for symbol in final_symbols]] = com_df2[[f"{symbol}_close" for symbol in final_symbols]].apply(lambda x: get_x_day_low_numba(com_df2, n=1, column=x.name))

com_df2[[f"{symbol}_prevdayh" for symbol in final_symbols]] = com_df2[[f"{symbol}_close" for symbol in final_symbols]].apply(lambda x: get_x_day_high_numba(com_df2, n=1, column=x.name))

com_df2[[f"{symbol}_secdayh" for symbol in final_symbols]] = com_df2[[f"{symbol}_close" for symbol in final_symbols]].apply(lambda x: get_x_day_high_numba(com_df2, n=2, column=x.name))


# This single call does it for the 20-day MA
ma_20d_df = calculate_daily_ma_vectorized(df=com_df2, symbols=final_symbols, periods=3 , agg_func='last' , col_suffix='close')

    # Join the new features back to the main DataFrame
com_df2 = pd.concat([com_df2, ma_20d_df] , axis=1 , join='outer')


com_df2[[f"{symbol}_ma" for symbol in final_symbols]] = com_df2[[f"{symbol}_close" for symbol in final_symbols]].rolling(2).mean()

com_df2[[f"{symbol}_ROC_30" for symbol in final_symbols]] = com_df2[[f"{symbol}_ma" for symbol in final_symbols]].pct_change(periods=30)


#com_df2[[f"{symbol}_ma_3d_low" for symbol in final_symbols]] = com_df2[[f"{symbol}_ma" for symbol in final_symbols]].values / com_df2[[f"{symbol}_3d_MA" for symbol in final_symbols]].values

com_df2[[f"{symbol}_prevdayc" for symbol in final_symbols]] = com_df2[[f"{symbol}_close" for symbol in final_symbols]].apply(lambda x: calculate_prev_day_close(com_df2, close_col=x.name, n_days=1))

com_df2[[f"{symbol}_secdayc" for symbol in final_symbols]] = com_df2[[f"{symbol}_close" for symbol in final_symbols]].apply(lambda x: calculate_prev_day_close(com_df2, close_col=x.name, n_days=2))


# #=== hourly volume
# com_df2[[f"{symbol}_vol_ma" for symbol in final_symbols]] = com_df2[[f"{symbol}_volume" for symbol in final_symbols]].rolling(4).mean()

# #==avg 3 day volume

# com_df2[[f"{symbol}_3d_vol_MA" for symbol in final_symbols]] = com_df2[[f"{symbol}_volume" for symbol in final_symbols]].apply(lambda x: daily_moving_average(com_df2, timeframe='1D', column=x.name, periods=3, agg_func='last'))

com_df2[[f"{symbol}_ma2_low" for symbol in final_symbols]] = com_df2[[f"{symbol}_close" for symbol in final_symbols]].rolling(5).mean()


com_df2[[f"{symbol}_3dlow" for symbol in final_symbols]] = com_df2[[f"{symbol}_ma2_low" for symbol in final_symbols]].apply(lambda x: get_x_day_low_numba(com_df2, n=3, column=x.name))

com_df2[[f"{symbol}_3dhigh" for symbol in final_symbols]] = com_df2[[f"{symbol}_ma2_low" for symbol in final_symbols]].apply(lambda x: get_x_day_high_numba(com_df2, n=3, column=x.name))



# 1. Get the lists of column names
high_3d_cols = [f"{symbol}_3dhigh" for symbol in final_symbols]
low_3d_cols = [f"{symbol}_3dlow" for symbol in final_symbols]

# 2. Perform the calculation on NumPy arrays
range_values = (com_df2[high_3d_cols].values / com_df2[low_3d_cols].values) - 1

# 3. Create a new DataFrame from the results
# This is the key step to avoid the error.
range_cols = [f"{symbol}_3d_rng" for symbol in final_symbols]
range_df = pd.DataFrame(range_values, index=com_df2.index, columns=range_cols)

# 4. Join the new DataFrame back to the main one
com_df2 = com_df2.join(range_df)



# # Calculate highest high of last 4 bars
# com_df2[[f"{symbol}_high_4bar" for symbol in final_symbols]] = com_df2[[f"{symbol}_close" for symbol in final_symbols]].rolling(10).max()

# # Calculate lowest low of last 4 bars
# com_df2[[f"{symbol}_low_4bar" for symbol in final_symbols]] = com_df2[[f"{symbol}_close" for symbol in final_symbols]].rolling(10).min()

# # 1. Get the lists of column names
# high_cols = [f"{symbol}_high_4bar" for symbol in final_symbols]
# low_cols = [f"{symbol}_low_4bar" for symbol in final_symbols]

# # 2. Perform the calculation on the NumPy arrays
# range_values = com_df2[high_cols].values - com_df2[low_cols].values

# # 3. Create a new DataFrame from the result (This is the key step)
# range_cols = [f"{symbol}_range_4bar" for symbol in final_symbols]
# range_df = pd.DataFrame(range_values, index=com_df2.index, columns=range_cols)

# # 4. Join the new DataFrame back to the main one
# com_df2 = com_df2.join(range_df)


# # Calculate mean range (average of the 4-bar ranges)
# com_df2[[f"{symbol}_mean_range_4bar" for symbol in final_symbols]] = com_df2[[f"{symbol}_range_4bar" for symbol in final_symbols]].rolling(12).mean()


# gc.collect()

# for symbol in final_symbols:

   
#     com_df2[f'{symbol}_iATR2'] = com_df2[f"{symbol}_ATR"].values / com_df2[f"{symbol}_close"].values


# 1. Define the column groups
close_cols = [f"{symbol}_close" for symbol in final_symbols]
low_3d_cols = [f"{symbol}_3dlow" for symbol in final_symbols]
high_3d_cols = [f"{symbol}_3dhigh" for symbol in final_symbols]

# 2. Perform the calculation in a more chained and memory-conscious way
# Using .to_numpy(dtype=np.float32) can cut memory usage by 50%
numerator = com_df2[close_cols].to_numpy(dtype=np.float32) - com_df2[low_3d_cols].to_numpy(dtype=np.float32)
denominator = com_df2[high_3d_cols].to_numpy(dtype=np.float32) - com_df2[low_3d_cols].to_numpy(dtype=np.float32)

# np.divide handles division by zero safely
percentile_values = np.divide(numerator, denominator, where=denominator != 0)

# 3. Create the new feature DataFrame
pctl_cols = [f"{symbol}_3d_Pctl" for symbol in final_symbols]
percentile_df = pd.DataFrame(percentile_values, index=com_df2.index, columns=pctl_cols)

# 4. Clip values and join back (same as your code)
percentile_df = percentile_df.clip(0, 1)
com_df2 = com_df2.join(percentile_df)

com_df2['decent'] = np.where((com_df2['SPY_todayo'] > com_df2['SPY_prevdayc'] * 0.985) & (com_df2['SPY_todayo'] > com_df2['SPY_prevdayc'] * 0.98), 1, 0)
com_df = com_df2[com_df2['decent']==1]
com_df = com_df[com_df.index.year>=2024]
# Out:
# Total symbols found after all filtering:  2
# Calculating 3-day MA for 2 symbols...

# %%
def fetch_bulk_option_data_call_put(con, ticker, end_date_str, n_days, strikes: List[float], expiries: List[str] , option_type: int = 0 ):
    
    """
    Fetches a range of minute-level data for MULTIPLE option contracts
    in a single, efficient query.

    Args:
        con: The database connection object.
        ticker (str): The stock ticker (e.g., 'SPY').
        end_date_str (str): The end date for the data fetch in 'YYYY-MM-DD' format.
        n_days (int): The number of business days to look back.
        strikes (List[float]): A list of strike prices to fetch.
        expiries (List[str]): A list of expiry dates in 'YYYY-MM-DD' format.
        option_type (int, optional): The type of option to fetch. 
                                     1 for Calls, -1 for Puts, 0 for Both. 
                                     Defaults to 0.
    
    Returns:
        pd.DataFrame: A DataFrame containing the requested option data, or an empty
                      DataFrame if no data is found or an error occurs.
    """

    # 1. Get the list of business days to query (same as before)
    nyse = mcal.get_calendar('NYSE')
    start_buffer = pd.to_datetime(end_date_str) - pd.Timedelta(days=n_days)
    schedule = nyse.schedule(start_date=start_buffer, end_date=end_date_str)
    business_day_list = [d.strftime('%Y-%m-%d') for d in schedule.index[-n_days:]]
    
    # 1. Validate the option_type parameter first
    if option_type not in [1, -1, 0]:
        print(f"❌ Bad input for option_type: '{option_type}'. Must be 1 (Call), -1 (Put), or 0 (Both).")
        return pd.DataFrame()


    # 2. Build the list of S3 paths (same as before)
    path_list = [
        f"'s3://duckdata/ORATS/Options/ticker={ticker}/day={d}/*.parquet'"
        for d in business_day_list ]
    
    # ▼▼▼ NEW QUERY LOGIC ▼▼▼
    # 3. Format the lists for the SQL 'IN' clause
    strikes_str = ",".join(map(str, strikes)) # For numbers: 470.0,471.0,472.0
    expiries_str = ",".join([f"'{e}'" for e in expiries]) # For strings: '2024-01-05','2024-01-08'
    
    # ▼▼▼ NEW LOGIC: DYNAMIC QUERY FILTER ▼▼▼
    # 2. Build the optionType filter string based on the parameter
    option_type_filter_str = ""
    if option_type == 1:
        option_type_filter_str = "AND optionType = 1"
    elif option_type == -1:
        option_type_filter_str = "AND optionType = -1"



    query = f"""
        SELECT ts, strike, expiry, close, bidPrice, askPrice, dte, optionType
        FROM read_parquet([{",".join(path_list)}])
        WHERE 
            CAST(strike AS FLOAT) IN ({strikes_str}) AND
            expiry IN ({expiries_str})
            {option_type_filter_str} 
        ORDER BY ts;
    """
    
    try:
        bulk_df = con.execute(query).df()
        
        if bulk_df.empty:
            return pd.DataFrame()
            
        # Perform timezone conversion and set index (same as before)
        bulk_df['ts'] = pd.to_datetime(bulk_df['ts'].dt.tz_localize('UTC').dt.tz_convert('America/New_York').dt.tz_localize(None))
        bulk_df.set_index('ts' , inplace=True)
        return bulk_df
        
    except Exception as e:
        print(f"An error occurred during bulk fetch: {e}")
        return pd.DataFrame()

# %%
# --- STRATEGY CONFIGURATION ---

# This defines the value of one strike step (e.g., for SPY, strikes are 1 point apart)
strike_interval = 1.0

# Example 1: 0DTE At-the-Money LONG STRADDLE
strategy_config = {
    'Leg1': {'action': 'SELL', 'option_type': -1, 'expiry_offset': 0, 'strike_offset': 1},  # Sell ATM Call
    }   # Buy 1DTE call

# 'Leg2': {'action': 'BUY', 'option_type': 1, 'expiry_offset': 1, 'strike_offset': 3

# %%
def log_and_close_trade(leg_name, exit_timestamp, exit_price, exit_reason, state_dicts, final_trade_log_list, option_multiplier=1):
    """
    Logs the details of a closed trade, calculates profit, and resets all state variables for that leg.
    """
    # Unpack the state dictionaries for easier access
    is_in_position, position_side, entry_price, qty, entry_timestamp, bar_count = \
        state_dicts['is_in_position'], state_dicts['position_side'], state_dicts['entry_price'], \
        state_dicts['qty'], state_dicts['entry_timestamp'], state_dicts['bar_count']

    # Check if the position actually exists before trying to close it
    if leg_name not in entry_price:
        print(f"⚠️  Warning: Trying to close non-existent position {leg_name}. Skipping.")
        return
    
    # Get the details of the position being closed
    side = position_side.get(leg_name)
    
    # Additional safety checks
    if side is None:
        print(f"⚠️  Warning: No position side found for {leg_name}. Skipping.")
        return
        
    if leg_name not in qty:
        print(f"⚠️  Warning: No quantity found for {leg_name}. Skipping.")
        return

    # Calculate profit
    profit = (exit_price - entry_price[leg_name]) * qty[leg_name] * side * option_multiplier

    # Create the trade log entry
    trade_details = {
        'name': leg_name,
        'Side': 'BUY' if side == 1 else 'SELL',
        'entry_date': entry_timestamp.get(leg_name, exit_timestamp),  # Use exit timestamp as fallback
        'entry_price': entry_price[leg_name],
        'qty': qty[leg_name],
        'exit_date': exit_timestamp,
        'exit_price': exit_price,
        'profit': profit,
        'bars_held': bar_count.get(leg_name, 0),
        'exit_reason': exit_reason
    }
    final_trade_log_list.append(trade_details)
    
    print(f"  -> {exit_reason} EXIT for {leg_name}. Profit: ${profit:.2f} and exit price is {exit_price:.2f}")

    # Reset all state variables for this leg (with safety checks)
    for dict_name, state_dict in state_dicts.items():
        if leg_name in state_dict:
            del state_dict[leg_name]
            #print(f"    Cleared {leg_name} from {dict_name}")

# %%
# ==============================================================================
# SCRIPT STARTS HERE
# ==============================================================================

import pandas_market_calendars as mcal
lookback_days = 1
nyse = mcal.get_calendar('NYSE')

# Initialize a list to hold all trade dictionaries.
final_trade_log_list = []
option_multiplier = 1

# --- Main Loop: Iterate Through Each Day ---
unique_days = com_df.index.normalize().unique()
print(f"🚀 Starting backtest for {len(unique_days)} unique days...")
for day in unique_days[1:]:
    day_str = day.strftime('%Y-%m-%d')
    print(f"\n--- Processing Day: {day_str} ---")
    daily_stop_loss_hit = False    
    try:
        # --- PHASE 1: PRE-FETCH DATA ---
        daily_underlying_df = com_df[com_df.index.date == day.date()]
        if daily_underlying_df.empty: 
            continue
            
        open_price = daily_underlying_df['SPY_close'].iloc[0]
        print(f"Fetching options across {open_price}")
                
        if pd.isna(open_price): 
            continue
        
        atm_strike_open = np.round(open_price)

        # ==============================================================================
        # --- PHASE 1: PRE-FETCH ALL POTENTIAL OPTION DATA FOR THE DAY ---
        # ==============================================================================
        
        strikes_to_fetch = set()
        expiries_to_fetch = set()
        legs_to_trade_info = {} # Store info to map data back to legs

        for leg_name, params in strategy_config.items():
            center_target_strike = atm_strike_open 
            # 1. Calculate the lower and upper price bounds
            lower_bound = center_target_strike * 0.9875
            upper_bound = center_target_strike * 1.005

            # 2. Round the bounds to the nearest valid strike
            rounded_lower = round_to_nearest(lower_bound, interval=strike_interval)
            rounded_upper = round_to_nearest(upper_bound, interval=strike_interval)

            # 3. Generate all strikes from the lower to upper bound, inclusive
            all_strikes_in_range = np.arange(rounded_lower, rounded_upper + strike_interval, strike_interval)
                    
            # 4. Add all of these strikes to your set for fetching
            strikes_to_fetch.update(all_strikes_in_range)

            # The schedule is fetched once
            schedule = nyse.schedule(start_date=day, end_date=day + pd.Timedelta(days=14))

            # 1. Get the primary expiry offset from your config
            primary_offset = params['expiry_offset']

            # 2. Get and add the primary target expiry date
            target_expiry_str = schedule.index[primary_offset].strftime('%Y-%m-%d')
            expiries_to_fetch.add(target_expiry_str)

            # 3. Calculate the offset for the next trading day
            next_day_offset = primary_offset + 1

            # 4. Safely get and add the next day's expiry date
            if next_day_offset < len(schedule.index):
                next_day_expiry_str = schedule.index[next_day_offset].strftime('%Y-%m-%d')
                expiries_to_fetch.add(next_day_expiry_str)
            else:
                print(f"  -> Added expiry: {target_expiry_str} (No further date in schedule)")
            
            # Store the central parameters for this leg
            legs_to_trade_info[leg_name] = {'strike': center_target_strike, 'expiry': target_expiry_str}

        # Make one single, efficient call to fetch all data
        bulk_data_df = fetch_bulk_option_data_call_put(
            con=con, ticker='SPY', end_date_str=day_str, n_days=lookback_days,
            strikes=list(strikes_to_fetch), expiries=list(expiries_to_fetch), option_type=1)

        if bulk_data_df.empty:
            print("Could not pre-fetch any option data for the day. Skipping.")
            continue

        grps = bulk_data_df.groupby(by=['strike', 'optionType', 'expiry'])
        total_legs = grps.ngroups 

        print("\n--- Phase 2: Preparing Master DataFrame ---")

        # 1. Create a list to hold the processed DataFrame for each option contract
        all_option_dfs = []

        # 2. Loop through each group (each unique option contract)
        for (strike, option_type, expiry), contract_df in grps:
            
            # 3. Create a unique, descriptive prefix for this specific contract
            type_char = 'C' if option_type == 1 else 'P'
            expiry_str = pd.to_datetime(expiry).strftime('%Y%m%d')
            prefix = f"{type_char}_{strike}_{expiry_str}_"
            
            # 4. Add the prefix to all columns of this contract's DataFrame
            prefixed_df = contract_df.add_prefix(prefix)
            
            # 5. Add the prepared DataFrame to our list
            all_option_dfs.append(prefixed_df)

        # 6. Concatenate all individual option DataFrames into one wide DataFrame
        if all_option_dfs:
            com_legs_df = pd.concat(all_option_dfs, axis=1, join='outer')

            print(f"✅ Successfully created master DataFrame with {len(com_legs_df.columns)} total columns.")
        else:
            print("❌ No valid option groups to process.")
            continue

        com_legs_df.replace(0, np.nan, inplace=True)
        com_legs_df.ffill(inplace=True)

        legs_to_process = [symbol for symbol in com_legs_df.filter(like='_close').columns.str.replace('_close', '').unique()
                          if symbol.startswith('C_') or symbol.startswith('P_')]

        #print(legs_to_process)

        # Apply rolling calculations
        com_legs_df[[f"{legs}_intraday_low" for legs in legs_to_process]] = com_legs_df[[f"{legs}_bidPrice" for legs in legs_to_process]].apply(lambda x: intraday_low(com_legs_df, low_col=x.name, agg_func='min'))

        com_legs_df[[f"{legs}_intraday_high" for legs in legs_to_process]] = com_legs_df[[f"{legs}_askPrice" for legs in legs_to_process]].apply(lambda x: intraday_high(com_legs_df, high_col=x.name, agg_func='max'))

        close_cols = [f'{leg}_close' for leg in legs_to_process]
        com_legs_df[[f'{leg}_ma10' for leg in legs_to_process]] = com_legs_df[close_cols].rolling(window=10).mean()

        # Calculate Today's Opening Price for each leg
        com_legs_df[[f'{leg}_todayo' for leg in legs_to_process]] = com_legs_df[[f'{leg}_close' for leg in legs_to_process]].resample('D').transform('first')

        com_legs_df[[f'{leg}_ROC_5' for leg in legs_to_process]] = com_legs_df[[f"{leg}_close" for leg in legs_to_process]].pct_change(periods=5)
        
        # 7. Join the wide option data with the underlying SPY data
        com_df3 = pd.concat([daily_underlying_df, com_legs_df], join='outer', axis=1)
                
        # 1. Calculate the rounded ATM strike for every row
        atm_strikes = round_to_nearest(com_df3['SPY_close'], interval=1)
        atm1_strikes = round_to_nearest(com_df3['SPY_close'], interval=1) + 1

        # 2. Build the corresponding leg name for every row
        com_df3['current_atm_leg'] = 'C_' + atm_strikes.astype(str) + '_' + day.strftime('%Y%m%d')        

        #=== logic for ROC ratio

        expiry_0dte = day.strftime('%Y%m%d')
        expiry_1dte = next_day_expiry_str.replace('-', '')
        
        # Build dynamic leg names for ATM+1 calls
        com_df3['atm1_0dte_call'] = 'C_' + atm1_strikes.astype(str) + '_' + expiry_0dte
        com_df3['atm1_1dte_call'] = 'C_' + atm1_strikes.astype(str) + '_' + expiry_1dte
        print(f"Expiry dates being used: 0DTE={expiry_0dte}, 1DTE={expiry_1dte}")

        

        # Extract ROC values for these specific legs
        com_df3['roc_0dte'] = com_df3.apply(
            lambda row: row.get(f"{row['atm1_0dte_call']}_ROC_5", np.nan) if pd.notna(row['atm1_0dte_call']) else np.nan, axis=1 )
        com_df3['roc_1dte'] = com_df3.apply(
            lambda row: row.get(f"{row['atm1_1dte_call']}_ROC_5", np.nan) if pd.notna(row['atm1_1dte_call']) else np.nan, axis=1)
        
        # Calculate the ROC ratio (handle division by zero)
        com_df3['roc_ratio'] = com_df3['roc_0dte'] / com_df3['roc_1dte'].replace(0, np.nan)
        
        # Calculate rolling max to identify when ratio is at highest
        lookback_window = 15  # Bars to look back
        com_df3['roc_ratio_rolling_max'] = com_df3['roc_ratio'].rolling(window=lookback_window).max()
        
        #print(com_df3[['atm1_0dte_call', 'atm1_1dte_call' , 'SPY_close' , 'roc_1dte' , 'roc_0dte' , 'roc_ratio' , 'roc_ratio_rolling_max']].head(2))

        # Create entry signal: ratio equals rolling max and above threshold
        com_df3['calendar_entry_signal'] = (
            (com_df3['roc_ratio'] >= com_df3['roc_ratio_rolling_max']*0.5) & 
            (com_df3['roc_ratio'] > 0.5) &  
            (com_df3['roc_0dte'] < 0.04) &  # ← ADD THIS: Ensure 0DTE is rising
            (com_df3['roc_1dte'] > 0.01) &  
            (pd.notna(com_df3['roc_ratio']))    )

        # --- STATE DICTIONARIES (Reset for each day) ---
        is_in_position = {}
        position_side = {}
        entry_price = {}
        entry_spy_price = {} 
        qty = {}
        entry_timestamp = {}
        has_been_hedged = {}
        hedge_for_leg = {}
        bar_count = {}
        net_premiums = {}

        #== Risk management parameters
        daily_trade_count = 0
        daily_max_trades = 2
        



        for i in range(len(com_df3)):
            
            timestamp = com_df3.index[i]
            row = com_df3.iloc[i]

            # --- CHECK DAILY LIMIT ---
            if daily_stop_loss_hit:
                continue


                    # Package all state dictionaries to pass to the helper function
            state_dictionaries = {
                'is_in_position': is_in_position, 'position_side': position_side, 'entry_price': entry_price,
                'qty': qty, 'entry_timestamp': entry_timestamp, 'bar_count': bar_count, 
                'entry_spy_price': entry_spy_price, 'has_been_hedged': has_been_hedged         }


            # Update bar counts for existing positions
            for leg_name in list(is_in_position.keys()):
                bar_count[leg_name] = bar_count.get(leg_name, 0) + 1

            # --- Part A: Check for NEW Short Entry ---
            is_short_open = -1 in position_side.values()
            is_calendar_open = len(hedge_for_leg) > 0


            calendar_entry_condition = (row['calendar_entry_signal'] and 
                not is_calendar_open and
                timestamp.time() > time(9, 45) and 
                timestamp.time() < time(13, 30) and
                daily_trade_count < daily_max_trades and
                pd.notna(row['roc_ratio']) and row['SPY_close']<row['SPY_prevdayc']*1.002 and row['SPY_close']>row['SPY_prevdayc']*0.996 )


            if calendar_entry_condition:
                print(f"Calendar Entry condition met at {timestamp} with ROC ratio {row['roc_ratio']:.2f}")

                atm1_strike = round_to_nearest(row['SPY_close'], 1) + 1
                
                # Build leg names for same strike, different expiries
                short_leg_0dte = f"C_{atm1_strike}_{expiry_0dte}"
                long_leg_1dte = f"C_{atm1_strike}_{expiry_1dte}"
                
                # Check if both legs have valid prices
                short_bid = row.get(f"{short_leg_0dte}_bidPrice", 0)
                short_ask = row.get(f"{short_leg_0dte}_askPrice", 0)
                long_ask = row.get(f"{long_leg_1dte}_askPrice", 0)
                long_bid = row.get(f"{long_leg_1dte}_bidPrice", 0)
                if (short_bid > 0.4 and long_ask > short_ask and 
                    long_ask > 0.5 and (long_ask - short_bid) < 2 and
                    pd.notna(short_bid) and pd.notna(long_ask)):
                    print(f"Price conditions met: Short Leg is: {short_leg_0dte} -price: {short_bid}, Long Leg is: {long_leg_1dte} -price: {long_ask}")

                    # Calculate quantities using hedge_ratio = 1
                    #spread_qty = int(100 * hedge_ratio)


                    is_in_position[short_leg_0dte] = True
                    position_side[short_leg_0dte] = -1
                    entry_price[short_leg_0dte] = row[f"{short_leg_0dte}_bidPrice"]
                    qty[short_leg_0dte] = 100
                    entry_timestamp[short_leg_0dte] = timestamp
                    bar_count[short_leg_0dte] = 0
                    
                    # Enter LONG 1DTE leg
                    is_in_position[long_leg_1dte] = True
                    position_side[long_leg_1dte] = 1
                    entry_price[long_leg_1dte] = long_ask
                    qty[long_leg_1dte] = 100
                    entry_timestamp[long_leg_1dte] = timestamp
                    bar_count[long_leg_1dte] = 0
                    
                    # Track the calendar spread
                    hedge_for_leg[short_leg_0dte] = long_leg_1dte
                    has_been_hedged[short_leg_0dte] = True

                     #Calculate net premium
                    short_premium = entry_price[short_leg_0dte] * qty[short_leg_0dte]
                    long_premium = entry_price[long_leg_1dte] * qty[long_leg_1dte]
                    net_debit = long_premium - short_premium
                    net_premiums[short_leg_0dte] = -net_debit  # Negative because we paid

                    daily_trade_count += 1

                    print(f"  -> CALENDAR SPREAD ENTRY at {timestamp.time()}")
                    print(f"     SHORT {short_leg_0dte} @ ${entry_price[short_leg_0dte]:.2f}")
                    print(f"     LONG  {long_leg_1dte} @ ${entry_price[long_leg_1dte]:.2f}")
                    print(f"     Net Debit: ${net_debit:.2f}")
                    print(f"     ROC Ratio: {row['roc_ratio']:.3f}")

        # --- ONLY EXIT: EOD Close All Positions ---
            # ==============================================================================
            
            # --- B: CHECK FOR EXITS IF A POSITION IS OPEN ---
            elif is_calendar_open:
                short_leg_name = list(hedge_for_leg.keys())[0]
                long_leg_name = hedge_for_leg[short_leg_name]
                
                # Increment bar count
                bar_count[short_leg_name] += 1
                bar_count[long_leg_name] += 1

                # Get current and entry prices
                long_leg_entry_price = entry_price.get(long_leg_name)
                short_leg_entry_price = entry_price.get(short_leg_name)
                current_long_price = row.get(f"{long_leg_name}_bidPrice")
                current_short_price = row.get(f"{short_leg_name}_askPrice")
                
                exit_reason = None

                # -- Exit 1: Take-Profit (Short leg decay) --
                if short_leg_entry_price and current_short_price is not None and timestamp.time() <= time(15, 1):
                    profit_target = 0.1 * short_leg_entry_price
                    if current_short_price <= profit_target and bar_count.get(short_leg_name, 0) > 3 :
                        exit_reason = 'TAKE-PROFIT'

                # -- Exit 2: Stop-Loss (Long leg value drop) --
                if not exit_reason and long_leg_entry_price and current_long_price is not None and timestamp.time() <= time(15, 1):
                    stop_loss_threshold = 0.45 * long_leg_entry_price
                    if current_long_price <= stop_loss_threshold:
                        exit_reason = 'STOP-LOSS'

                # -- Exit 3: End-of-Day --
                if not exit_reason and timestamp.time() >= time(15, 45):
                    exit_reason = 'EOD'

                # -- Execute Exit if any condition was met --
                if exit_reason:
                    print(f"    -> {exit_reason} TRIGGERED at {timestamp.time()}")
                    print(f"       SHORT {short_leg_name} Entry: ${short_leg_entry_price:.2f}, exit at: ${current_short_price:.2f}")
                    print(f"       LONG  {long_leg_name} Entry: ${long_leg_entry_price:.2f}, exit at: ${current_long_price:.2f}")
                    
                    log_and_close_trade(long_leg_name, timestamp, current_long_price, exit_reason, state_dictionaries, final_trade_log_list, option_multiplier)
                    log_and_close_trade(short_leg_name, timestamp, current_short_price, exit_reason, state_dictionaries, final_trade_log_list, option_multiplier)
                    
                    # Clean up all state and stop trading for the day
                    for d in [is_in_position, position_side, entry_price, qty, entry_timestamp, bar_count, hedge_for_leg, net_premiums]:
                        d.clear()
                    daily_exit_triggered = True  


    except Exception as e:
        print(f"  ❌ An error occurred on {day_str}: {e}")
        import traceback
        traceback.print_exc()

# --- Convert final log to DataFrame ---
if final_trade_log_list:
    local_trade_log2 = pd.DataFrame(final_trade_log_list)
    print(f"Trading completed. Total trades: {len(local_trade_log2)}")
else:
    print("No trades were made.")
# Out:
# 🚀 Starting backtest for 241 unique days...
#
# --- Processing Day: 2024-01-04 ---
# Fetching options across 468.44
#
# --- Phase 2: Preparing Master DataFrame ---
# ✅ Successfully created master DataFrame with 126 total columns.
# Expiry dates being used: 0DTE=20240104, 1DTE=20240105
#
# --- Processing Day: 2024-01-05 ---
# Fetching options across 468.15
#
# --- Phase 2: Preparing Master DataFrame ---
# ✅ Successfully created master DataFrame with 126 total columns.
# Expiry dates being used: 0DTE=20240105, 1DTE=20240108
# Calendar Entry condition met at 2024-01-05 12:47:00 with ROC ratio 3.14
#
# --- Processing Day: 2024-01-08 ---
# Fetching options across 468.64
#
# --- Phase 2: Preparing Master DataFrame ---
# ✅ Successfully created master DataFrame with 126 total columns.
# Expiry dates being used: 0DTE=20240108, 1DTE=20240109
#
# --- Processing Day: 2024-01-09 ---
# Fetching options across 472.0
#
# --- Phase 2: Preparing Master DataFrame ---
# ✅ Successfully created master DataFrame with 126 total columns.
# Expiry dates being used: 0DTE=20240109, 1DTE=20240110
#
# --- Processing Day: 2024-01-10 ---
# Fetching options across 474.35
#
# --- Phase 2: Preparing Master DataFrame ---
# ✅ Successfully created master DataFrame with 126 total columns.
# Expiry dates being used: 0DTE=20240110, 1DTE=20240111
#
# --- Processing Day: 2024-01-11 ---
# Fetching options across 477.93
#
# --- Phase 2: Preparing Master DataFrame ---
# ✅ Successfully created master DataFrame with 126 total columns.
# Expiry dates being used: 0DTE=20240111, 1DTE=20240112
#
# --- Processing Day: 2024-01-12 ---
# Fetching options across 477.91
#
# --- Phase 2: Preparing Master DataFrame ---
# ✅ Successfully created master DataFrame with 126 total columns.
# Expiry dates being used: 0DTE=20240112, 1DTE=20240116
#
# --- Processing Day: 2024-01-16 ---
# Fetching options across 475.37
#
# --- Phase 2: Preparing Master DataFrame ---
# ✅ Successfully created master DataFrame with 126 total columns.
# Expiry dates being used: 0DTE=20240116, 1DTE=20240117
#
# --- Processing Day: 2024-01-17 ---
# Fetching options across 471.78
#
# --- Phase 2: Preparing Master DataFrame ---
# ✅ Successfully created master DataFrame with 126 total columns.
# Expiry dates being used: 0DTE=20240117, 1DTE=20240118
#
# --- Processing Day: 2024-01-18 ---
# Fetching options across 474.0
#
# --- Phase 2: Preparing Master DataFrame ---
# ✅ Successfully created master DataFrame with 126 total columns.
# Expiry dates being used: 0DTE=20240118, 1DTE=20240119
#
# --- Processing Day: 2024-01-19 ---
# Fetching options across 477.44
#
# --- Phase 2: Preparing Master DataFrame ---
# ✅ Successfully created master DataFrame with 126 total columns.
# Expiry dates being used: 0DTE=20240119, 1DTE=20240122
# Calendar Entry condition met at 2024-01-19 09:50:00 with ROC ratio 1.72
# Price conditions met: Short Leg is: C_478.0_20240119 -price: 0.78, Long Leg is: C_478.0_20240122 -price: 1.33
#   -> CALENDAR SPREAD ENTRY at 09:50:00
#      SHORT C_478.0_20240119 @ $0.78
#      LONG  C_478.0_20240122 @ $1.33
#      Net Debit: $55.00
#      ROC Ratio: 1.715
#     -> EOD TRIGGERED at 15:45:00
#        SHORT C_478.0_20240119 Entry: $0.78, exit at: $4.01
#        LONG  C_478.0_20240122 Entry: $1.33, exit at: $4.23
#   -> EOD EXIT for C_478.0_20240122. Profit: $290.00 and exit price is 4.23
#   -> EOD EXIT for C_478.0_20240119. Profit: $-323.00 and exit price is 4.01
#
# --- Processing Day: 2024-01-22 ---
# Fetching options across 484.13
#
# --- Phase 2: Preparing Master DataFrame ---
# ✅ Successfully created master DataFrame with 126 total columns.
# Expiry dates being used: 0DTE=20240122, 1DTE=20240123
#
# --- Processing Day: 2024-01-23 ---
# Fetching options across 484.23
#
# --- Phase 2: Preparing Master DataFrame ---
# ✅ Successfully created master DataFrame with 126 total columns.
# Expiry dates being used: 0DTE=20240123, 1DTE=20240124
# Calendar Entry condition met at 2024-01-23 12:32:00 with ROC ratio 3.07
#
# --- Processing Day: 2024-01-24 ---
# Fetching options across 487.47
#
# --- Phase 2: Preparing Master DataFrame ---
# ✅ Successfully created master DataFrame with 126 total columns.
# Expiry dates being used: 0DTE=20240124, 1DTE=20240125
#
# --- Processing Day: 2024-01-25 ---
# Fetching options across 487.11
#
# --- Phase 2: Preparing Master DataFrame ---
# ✅ Successfully created master DataFrame with 126 total columns.
# Expiry dates being used: 0DTE=20240125, 1DTE=20240126
#
# --- Processing Day: 2024-01-26 ---
# Fetching options across 487.8
#
# --- Phase 2: Preparing Master DataFrame ---
# ✅ Successfully created master DataFrame with 126 total columns.
# Expiry dates being used: 0DTE=20240126, 1DTE=20240129
# Calendar Entry condition met at 2024-01-26 10:54:00 with ROC ratio 1.43
#
# --- Processing Day: 2024-01-29 ---
# Fetching options across 487.7
#
# --- Phase 2: Preparing Master DataFrame ---
# ✅ Successfully created master DataFrame with 126 total columns.
# Expiry dates being used: 0DTE=20240129, 1DTE=20240130
# Calendar Entry condition met at 2024-01-29 10:21:00 with ROC ratio 1.39
# Price conditions met: Short Leg is: C_489.0_20240129 -price: 0.41, Long Leg is: C_489.0_20240130 -price: 1.15
#   -> CALENDAR SPREAD ENTRY at 10:21:00
#      SHORT C_489.0_20240129 @ $0.41
#      LONG  C_489.0_20240130 @ $1.15
#      Net Debit: $74.00
#      ROC Ratio: 1.389
#     -> EOD TRIGGERED at 15:45:00
#        SHORT C_489.0_20240129 Entry: $0.41, exit at: $1.74
#        LONG  C_489.0_20240130 Entry: $1.15, exit at: $2.35
#   -> EOD EXIT for C_489.0_20240130. Profit: $120.00 and exit price is 2.35
#   -> EOD EXIT for C_489.0_20240129. Profit: $-133.00 and exit price is 1.74
#
# --- Processing Day: 2024-01-30 ---
# Fetching options across 490.89
#
# --- Phase 2: Preparing Master DataFrame ---
# ✅ Successfully created master DataFrame with 126 total columns.
# Expiry dates being used: 0DTE=20240130, 1DTE=20240131
# Calendar Entry condition met at 2024-01-30 10:51:00 with ROC ratio 1.47
# Price conditions met: Short Leg is: C_492.0_20240130 -price: 0.45, Long Leg is: C_492.0_20240131 -price: 1.33
#   -> CALENDAR SPREAD ENTRY at 10:51:00
#      SHORT C_492.0_20240130 @ $0.45
#      LONG  C_492.0_20240131 @ $1.33
#      Net Debit: $88.00
#      ROC Ratio: 1.466
#     -> EOD TRIGGERED at 15:45:00
#        SHORT C_492.0_20240130 Entry: $0.45, exit at: $0.31
#        LONG  C_492.0_20240131 Entry: $1.33, exit at: $1.52
#   -> EOD EXIT for C_492.0_20240131. Profit: $19.00 and exit price is 1.52
#   -> EOD EXIT for C_492.0_20240130. Profit: $14.00 and exit price is 0.31
#
# --- Processing Day: 2024-01-31 ---
# Fetching options across 488.7
#
# --- Phase 2: Preparing Master DataFrame ---
# ✅ Successfully created master DataFrame with 126 total columns.
# Expiry dates being used: 0DTE=20240131, 1DTE=20240201
#
# --- Processing Day: 2024-02-01 ---
# Fetching options across 485.15
#
# --- Phase 2: Preparing Master DataFrame ---
# ✅ Successfully created master DataFrame with 126 total columns.
# Expiry dates being used: 0DTE=20240201, 1DTE=20240202
#
# --- Processing Day: 2024-02-02 ---
# Fetching options across 489.85
#
# --- Phase 2: Preparing Master DataFrame ---
# ✅ Successfully created master DataFrame with 126 total columns.
# Expiry dates being used: 0DTE=20240202, 1DTE=20240205
#
# --- Processing Day: 2024-02-05 ---
# Fetching options across 493.25
#
# --- Phase 2: Preparing Master DataFrame ---
# ✅ Successfully created master DataFrame with 126 total columns.
# Expiry dates being used: 0DTE=20240205, 1DTE=20240206
# Calendar Entry condition met at 2024-02-05 09:50:00 with ROC ratio 1.27
# Price conditions met: Short Leg is: C_494.0_20240205 -price: 0.66, Long Leg is: C_494.0_20240206 -price: 1.26
#   -> CALENDAR SPREAD ENTRY at 09:50:00
#      SHORT C_494.0_20240205 @ $0.66
#      LONG  C_494.0_20240206 @ $1.26
#      Net Debit: $60.00
#      ROC Ratio: 1.266
#     -> STOP-LOSS TRIGGERED at 10:22:00
#        SHORT C_494.0_20240205 Entry: $0.66, exit at: $0.21
#        LONG  C_494.0_20240206 Entry: $1.26, exit at: $0.55
#   -> STOP-LOSS EXIT for C_494.0_20240206. Profit: $-71.00 and exit price is 0.55
#   -> STOP-LOSS EXIT for C_494.0_20240205. Profit: $45.00 and exit price is 0.21
#
# --- Processing Day: 2024-02-06 ---
# Fetching options across 493.98
#
# --- Phase 2: Preparing Master DataFrame ---
# ✅ Successfully created master DataFrame with 126 total columns.
# Expiry dates being used: 0DTE=20240206, 1DTE=20240207
# Calendar Entry condition met at 2024-02-06 10:48:00 with ROC ratio 1.21
# Calendar Entry condition met at 2024-02-06 12:02:00 with ROC ratio 1.43
# Calendar Entry condition met at 2024-02-06 12:11:00 with ROC ratio 1.30
# Price conditions met: Short Leg is: C_493.0_20240206 -price: 0.58, Long Leg is: C_493.0_20240207 -price: 1.27
#   -> CALENDAR SPREAD ENTRY at 12:11:00
#      SHORT C_493.0_20240206 @ $0.58
#      LONG  C_493.0_20240207 @ $1.27
#      Net Debit: $69.00
#      ROC Ratio: 1.300
#     -> EOD TRIGGERED at 15:45:00
#        SHORT C_493.0_20240206 Entry: $0.58, exit at: $0.30
#        LONG  C_493.0_20240207 Entry: $1.27, exit at: $1.22
#   -> EOD EXIT for C_493.0_20240207. Profit: $-5.00 and exit price is 1.22
#   -> EOD EXIT for C_493.0_20240206. Profit: $28.00 and exit price is 0.30
#
# --- Processing Day: 2024-02-07 ---
# Fetching options across 496.32
#
# --- Phase 2: Preparing Master DataFrame ---
# ✅ Successfully created master DataFrame with 126 total columns.
# Expiry dates being used: 0DTE=20240207, 1DTE=20240208
#
# --- Processing Day: 2024-02-08 ---
# Fetching options across 497.78
#
# --- Phase 2: Preparing Master DataFrame ---
# ✅ Successfully created master DataFrame with 126 total columns.
# Expiry dates being used: 0DTE=20240208, 1DTE=20240209
#
# --- Processing Day: 2024-02-09 ---
# Fetching options across 499.13
#
# --- Phase 2: Preparing Master DataFrame ---
# ✅ Successfully created master DataFrame with 126 total columns.
# Expiry dates being used: 0DTE=20240209, 1DTE=20240212
#
# --- Processing Day: 2024-02-12 ---
# Fetching options across 501.24
#
# --- Phase 2: Preparing Master DataFrame ---
# ✅ Successfully created master DataFrame with 140 total columns.
# Expiry dates being used: 0DTE=20240212, 1DTE=20240213
#
# --- Processing Day: 2024-02-13 ---
# Fetching options across 494.3
#
# --- Phase 2: Preparing Master DataFrame ---
# ✅ Successfully created master DataFrame with 126 total columns.
# Expiry dates being used: 0DTE=20240213, 1DTE=20240214
#
# --- Processing Day: 2024-02-14 ---
# Fetching options across 497.01
#
# --- Phase 2: Preparing Master DataFrame ---
# ✅ Successfully created master DataFrame with 126 total columns.
# Expiry dates being used: 0DTE=20240214, 1DTE=20240215
#
# --- Processing Day: 2024-02-15 ---
# Fetching options across 499.49
#
# --- Phase 2: Preparing Master DataFrame ---
# ✅ Successfully created master DataFrame with 126 total columns.
# Expiry dates being used: 0DTE=20240215, 1DTE=20240216
# Calendar Entry condition met at 2024-02-15 11:36:00 with ROC ratio 1.53
#
# --- Processing Day: 2024-02-16 ---
# Fetching options across 501.71
#
# --- Phase 2: Preparing Master DataFrame ---
# ✅ Successfully created master DataFrame with 140 total columns.
# Expiry dates being used: 0DTE=20240216, 1DTE=20240220
# Calendar Entry condition met at 2024-02-16 11:11:00 with ROC ratio 1.47
# Price conditions met: Short Leg is: C_502.0_20240216 -price: 0.62, Long Leg is: C_502.0_20240220 -price: 1.37
#   -> CALENDAR SPREAD ENTRY at 11:11:00
#      SHORT C_502.0_20240216 @ $0.62
#      LONG  C_502.0_20240220 @ $1.37
#      Net Debit: $75.00
#      ROC Ratio: 1.471
#     -> EOD TRIGGERED at 15:45:00
#        SHORT C_502.0_20240216 Entry: $0.62, exit at: $0.03
#        LONG  C_502.0_20240220 Entry: $1.37, exit at: $0.64
#   -> EOD EXIT for C_502.0_20240220. Profit: $-73.00 and exit price is 0.64
#   -> EOD EXIT for C_502.0_20240216. Profit: $59.00 and exit price is 0.03
#
# --- Processing Day: 2024-02-20 ---
# Fetching options across 497.88
#
# --- Phase 2: Preparing Master DataFrame ---
# ✅ Successfully created master DataFrame with 126 total columns.
# Expiry dates being used: 0DTE=20240220, 1DTE=20240221
#
# --- Processing Day: 2024-02-21 ---
# Fetching options across 495.45
#
# --- Phase 2: Preparing Master DataFrame ---
# ✅ Successfully created master DataFrame with 126 total columns.
# Expiry dates being used: 0DTE=20240221, 1DTE=20240222
# Calendar Entry condition met at 2024-02-21 12:17:00 with ROC ratio 2.11
# Price conditions met: Short Leg is: C_496.0_20240221 -price: 0.95, Long Leg is: C_496.0_20240222 -price: 2.0
#   -> CALENDAR SPREAD ENTRY at 12:17:00
#      SHORT C_496.0_20240221 @ $0.95
#      LONG  C_496.0_20240222 @ $2.00
#      Net Debit: $105.00
#      ROC Ratio: 2.112
#     -> EOD TRIGGERED at 15:45:00
#        SHORT C_496.0_20240221 Entry: $0.95, exit at: $1.18
#        LONG  C_496.0_20240222 Entry: $2.00, exit at: $2.46
#   -> EOD EXIT for C_496.0_20240222. Profit: $46.00 and exit price is 2.46
#   -> EOD EXIT for C_496.0_20240221. Profit: $-23.00 and exit price is 1.18
#
# --- Processing Day: 2024-02-22 ---
# Fetching options across 503.44
#
# --- Phase 2: Preparing Master DataFrame ---
# ✅ Successfully created master DataFrame with 140 total columns.
# Expiry dates being used: 0DTE=20240222, 1DTE=20240223
#
# --- Processing Day: 2024-02-23 ---
# Fetching options across 509.27
#
# --- Phase 2: Preparing Master DataFrame ---
# ✅ Successfully created master DataFrame with 126 total columns.
# Expiry dates being used: 0DTE=20240223, 1DTE=20240226
#
# --- Processing Day: 2024-02-26 ---
# Fetching options across 508.37
#
# --- Phase 2: Preparing Master DataFrame ---
# ✅ Successfully created master DataFrame with 133 total columns.
# Expiry dates being used: 0DTE=20240226, 1DTE=20240227
#
# --- Processing Day: 2024-02-27 ---
# Fetching options across 506.53
#
# --- Phase 2: Preparing Master DataFrame ---
# ✅ Successfully created master DataFrame with 140 total columns.
# Expiry dates being used: 0DTE=20240227, 1DTE=20240228
# Calendar Entry condition met at 2024-02-27 10:47:00 with ROC ratio 2.62
#
# --- Processing Day: 2024-02-28 ---
# Fetching options across 505.53
#
# --- Phase 2: Preparing Master DataFrame ---
# ✅ Successfully created master DataFrame with 140 total columns.
# Expiry dates being used: 0DTE=20240228, 1DTE=20240229
#
# --- Processing Day: 2024-02-29 ---
# Fetching options across 508.17
#
# --- Phase 2: Preparing Master DataFrame ---
# ✅ Successfully created master DataFrame with 140 total columns.
# Expiry dates being used: 0DTE=20240229, 1DTE=20240301
#
# --- Processing Day: 2024-03-01 ---
# Fetching options across 509.44
#
# --- Phase 2: Preparing Master DataFrame ---
# ✅ Successfully created master DataFrame with 140 total columns.
# Expiry dates being used: 0DTE=20240301, 1DTE=20240304
#
# --- Processing Day: 2024-03-04 ---
# Fetching options across 512.16
#
# --- Phase 2: Preparing Master DataFrame ---
# ✅ Successfully created master DataFrame with 140 total columns.
# Expiry dates being used: 0DTE=20240304, 1DTE=20240305
#
# --- Processing Day: 2024-03-05 ---
# Fetching options across 510.15
#
# --- Phase 2: Preparing Master DataFrame ---
# ✅ Successfully created master DataFrame with 140 total columns.
# Expiry dates being used: 0DTE=20240305, 1DTE=20240306
#
# --- Processing Day: 2024-03-06 ---
# Fetching options across 510.43
#
# --- Phase 2: Preparing Master DataFrame ---
# ✅ Successfully created master DataFrame with 140 total columns.
# Expiry dates being used: 0DTE=20240306, 1DTE=20240307
#
# --- Processing Day: 2024-03-07 ---
# Fetching options across 513.39
#
# --- Phase 2: Preparing Master DataFrame ---
# ✅ Successfully created master DataFrame with 140 total columns.
# Expiry dates being used: 0DTE=20240307, 1DTE=20240308
#
# --- Processing Day: 2024-03-08 ---
# Fetching options across 515.42
#
# --- Phase 2: Preparing Master DataFrame ---
# ✅ Successfully created master DataFrame with 140 total columns.
# Expiry dates being used: 0DTE=20240308, 1DTE=20240311
#
# --- Processing Day: 2024-03-11 ---
# Fetching options across 510.3
#
# --- Phase 2: Preparing Master DataFrame ---
# ✅ Successfully created master DataFrame with 140 total columns.
# Expiry dates being used: 0DTE=20240311, 1DTE=20240312
#
# --- Processing Day: 2024-03-12 ---
# Fetching options across 513.57
#
# --- Phase 2: Preparing Master DataFrame ---
# ✅ Successfully created master DataFrame with 140 total columns.
# Expiry dates being used: 0DTE=20240312, 1DTE=20240313
#
# --- Processing Day: 2024-03-13 ---
# Fetching options across 517.03
#
# --- Phase 2: Preparing Master DataFrame ---
# ✅ Successfully created master DataFrame with 140 total columns.
# Expiry dates being used: 0DTE=20240313, 1DTE=20240314
#
# --- Processing Day: 2024-03-14 ---
# Fetching options across 516.71
#
# --- Phase 2: Preparing Master DataFrame ---
# ✅ Successfully created master DataFrame with 140 total columns.
# Expiry dates being used: 0DTE=20240314, 1DTE=20240315
# Calendar Entry condition met at 2024-03-14 09:58:00 with ROC ratio 2.10
# Price conditions met: Short Leg is: C_515.0_20240314 -price: 1.06, Long Leg is: C_515.0_20240315 -price: 1.34
#   -> CALENDAR SPREAD ENTRY at 09:58:00
#      SHORT C_515.0_20240314 @ $1.06
#      LONG  C_515.0_20240315 @ $1.34
#      Net Debit: $28.00
#      ROC Ratio: 2.097
#     -> STOP-LOSS TRIGGERED at 13:32:00
#        SHORT C_515.0_20240314 Entry: $1.06, exit at: $0.16
#        LONG  C_515.0_20240315 Entry: $1.34, exit at: $0.59
#   -> STOP-LOSS EXIT for C_515.0_20240315. Profit: $-75.00 and exit price is 0.59
#   -> STOP-LOSS EXIT for C_515.0_20240314. Profit: $90.00 and exit price is 0.16
#
# --- Processing Day: 2024-03-15 ---
# Fetching options across 510.77
#
# --- Phase 2: Preparing Master DataFrame ---
# ✅ Successfully created master DataFrame with 140 total columns.
# Expiry dates being used: 0DTE=20240315, 1DTE=20240318
#
# --- Processing Day: 2024-03-18 ---
# Fetching options across 514.14
#
# --- Phase 2: Preparing Master DataFrame ---
# ✅ Successfully created master DataFrame with 140 total columns.
# Expiry dates being used: 0DTE=20240318, 1DTE=20240319
#
# --- Processing Day: 2024-03-19 ---
# Fetching options across 511.8
#
# --- Phase 2: Preparing Master DataFrame ---
# ✅ Successfully created master DataFrame with 140 total columns.
# Expiry dates being used: 0DTE=20240319, 1DTE=20240320
#
# --- Processing Day: 2024-03-20 ---
# Fetching options across 515.47
#
# --- Phase 2: Preparing Master DataFrame ---
# ✅ Successfully created master DataFrame with 140 total columns.
# Expiry dates being used: 0DTE=20240320, 1DTE=20240321
# Calendar Entry condition met at 2024-03-20 10:19:00 with ROC ratio 1.57
# Price conditions met: Short Leg is: C_517.0_20240320 -price: 1.21, Long Leg is: C_517.0_20240321 -price: 1.9
#   -> CALENDAR SPREAD ENTRY at 10:19:00
#      SHORT C_517.0_20240320 @ $1.21
#      LONG  C_517.0_20240321 @ $1.90
#      Net Debit: $69.00
#      ROC Ratio: 1.574
#     -> EOD TRIGGERED at 15:45:00
#        SHORT C_517.0_20240320 Entry: $1.21, exit at: $2.79
#        LONG  C_517.0_20240321 Entry: $1.90, exit at: $3.45
#   -> EOD EXIT for C_517.0_20240321. Profit: $155.00 and exit price is 3.45
#   -> EOD EXIT for C_517.0_20240320. Profit: $-158.00 and exit price is 2.79
#
# --- Processing Day: 2024-03-21 ---
# Fetching options across 523.12
#
# --- Phase 2: Preparing Master DataFrame ---
# ✅ Successfully created master DataFrame with 154 total columns.
# Expiry dates being used: 0DTE=20240321, 1DTE=20240322
#
# --- Processing Day: 2024-03-22 ---
# Fetching options across 522.11
#
# --- Phase 2: Preparing Master DataFrame ---
# ✅ Successfully created master DataFrame with 154 total columns.
# Expiry dates being used: 0DTE=20240322, 1DTE=20240325
# Calendar Entry condition met at 2024-03-22 10:01:00 with ROC ratio 1.21
# Price conditions met: Short Leg is: C_523.0_20240322 -price: 0.42, Long Leg is: C_523.0_20240325 -price: 1.03
#   -> CALENDAR SPREAD ENTRY at 10:01:00
#      SHORT C_523.0_20240322 @ $0.42
#      LONG  C_523.0_20240325 @ $1.03
#      Net Debit: $61.00
#      ROC Ratio: 1.211
#     -> EOD TRIGGERED at 15:45:00
#        SHORT C_523.0_20240322 Entry: $0.42, exit at: $0.02
#        LONG  C_523.0_20240325 Entry: $1.03, exit at: $0.63
#   -> EOD EXIT for C_523.0_20240325. Profit: $-40.00 and exit price is 0.63
#   -> EOD EXIT for C_523.0_20240322. Profit: $40.00 and exit price is 0.02
#
# --- Processing Day: 2024-03-25 ---
# Fetching options across 519.95
#
# --- Phase 2: Preparing Master DataFrame ---
# ✅ Successfully created master DataFrame with 140 total columns.
# Expiry dates being used: 0DTE=20240325, 1DTE=20240326
# Calendar Entry condition met at 2024-03-25 12:09:00 with ROC ratio 3.03
#
# --- Processing Day: 2024-03-26 ---
# Fetching options across 520.99
#
# --- Phase 2: Preparing Master DataFrame ---
# ✅ Successfully created master DataFrame with 154 total columns.
# Expiry dates being used: 0DTE=20240326, 1DTE=20240327
#
# --- Processing Day: 2024-03-27 ---
# Fetching options across 521.52
#
# --- Phase 2: Preparing Master DataFrame ---
# ✅ Successfully created master DataFrame with 154 total columns.
# Expiry dates being used: 0DTE=20240327, 1DTE=20240328
#
# --- Processing Day: 2024-03-28 ---
# Fetching options across 523.04
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# --- Phase 2: Preparing Master DataFrame ---
# ✅ Successfully created master DataFrame with 154 total columns.
# Expiry dates being used: 0DTE=20240328, 1DTE=20240401
#
# --- Processing Day: 2024-04-01 ---
# Fetching options across 523.63
#
# --- Phase 2: Preparing Master DataFrame ---
# ✅ Successfully created master DataFrame with 154 total columns.
# Expiry dates being used: 0DTE=20240401, 1DTE=20240402
# Calendar Entry condition met at 2024-04-01 10:58:00 with ROC ratio 2.34
# Price conditions met: Short Leg is: C_523.0_20240401 -price: 0.43, Long Leg is: C_523.0_20240402 -price: 1.01
#   -> CALENDAR SPREAD ENTRY at 10:58:00
#      SHORT C_523.0_20240401 @ $0.43
#      LONG  C_523.0_20240402 @ $1.01
#      Net Debit: $58.00
#      ROC Ratio: 2.341
#     -> EOD TRIGGERED at 15:45:00
#        SHORT C_523.0_20240401 Entry: $0.43, exit at: $0.05
#        LONG  C_523.0_20240402 Entry: $1.01, exit at: $0.73
#   -> EOD EXIT for C_523.0_20240402. Profit: $-28.00 and exit price is 0.73
#   -> EOD EXIT for C_523.0_20240401. Profit: $38.00 and exit price is 0.05
#
# --- Processing Day: 2024-04-02 ---
# Fetching options across 518.42
#
# --- Phase 2: Preparing Master DataFrame ---
# ✅ Successfully created master DataFrame with 140 total columns.
# Expiry dates being used: 0DTE=20240402, 1DTE=20240403
#
# --- Processing Day: 2024-04-03 ---
# Fetching options across 518.4
#
# --- Phase 2: Preparing Master DataFrame ---
# ✅ Successfully created master DataFrame with 140 total columns.
# Expiry dates being used: 0DTE=20240403, 1DTE=20240404
#
# --- Processing Day: 2024-04-04 ---
# Fetching options across 523.39
#
# --- Phase 2: Preparing Master DataFrame ---
# ✅ Successfully created master DataFrame with 154 total columns.
# Expiry dates being used: 0DTE=20240404, 1DTE=20240405
#
# --- Processing Day: 2024-04-05 ---
# Fetching options across 514.25
#
# --- Phase 2: Preparing Master DataFrame ---
# ✅ Successfully created master DataFrame with 126 total columns.
# Expiry dates being used: 0DTE=20240405, 1DTE=20240408
#
# --- Processing Day: 2024-04-08 ---
# Fetching options across 519.08
#
# --- Phase 2: Preparing Master DataFrame ---
# ✅ Successfully created master DataFrame with 140 total columns.
# Expiry dates being used: 0DTE=20240408, 1DTE=20240409
# Calendar Entry condition met at 2024-04-08 11:09:00 with ROC ratio 1.68
#
# --- Processing Day: 2024-04-09 ---
# Fetching options across 520.49
#
# --- Phase 2: Preparing Master DataFrame ---
# ✅ Successfully created master DataFrame with 140 total columns.
# Expiry dates being used: 0DTE=20240409, 1DTE=20240410
#
# --- Processing Day: 2024-04-10 ---
# Fetching options across 513.27
#
# --- Phase 2: Preparing Master DataFrame ---
# ✅ Successfully created master DataFrame with 140 total columns.
# Expiry dates being used: 0DTE=20240410, 1DTE=20240411
#
# --- Processing Day: 2024-04-11 ---
# Fetching options across 515.55
#
# --- Phase 2: Preparing Master DataFrame ---
# ✅ Successfully created master DataFrame with 140 total columns.
# Expiry dates being used: 0DTE=20240411, 1DTE=20240412
# Calendar Entry condition met at 2024-04-11 09:55:00 with ROC ratio 2.10
# Price conditions met: Short Leg is: C_516.0_20240411 -price: 0.86, Long Leg is: C_516.0_20240412 -price: 1.8
#   -> CALENDAR SPREAD ENTRY at 09:55:00
#      SHORT C_516.0_20240411 @ $0.86
#      LONG  C_516.0_20240412 @ $1.80
#      Net Debit: $94.00
#      ROC Ratio: 2.101
#     -> EOD TRIGGERED at 15:45:00
#        SHORT C_516.0_20240411 Entry: $0.86, exit at: $3.22
#        LONG  C_516.0_20240412 Entry: $1.80, exit at: $3.90
#   -> EOD EXIT for C_516.0_20240412. Profit: $210.00 and exit price is 3.90
#   -> EOD EXIT for C_516.0_20240411. Profit: $-236.00 and exit price is 3.22
#
# --- Processing Day: 2024-04-12 ---
# Fetching options across 514.55
#
# --- Phase 2: Preparing Master DataFrame ---
# ✅ Successfully created master DataFrame with 140 total columns.
# Expiry dates being used: 0DTE=20240412, 1DTE=20240415
#
# --- Processing Day: 2024-04-15 ---
# Fetching options across 514.7
#
# --- Phase 2: Preparing Master DataFrame ---
# ✅ Successfully created master DataFrame with 140 total columns.
# Expiry dates being used: 0DTE=20240415, 1DTE=20240416
# Calendar Entry condition met at 2024-04-15 11:26:00 with ROC ratio 2.02
# Price conditions met: Short Leg is: C_512.0_20240415 -price: 0.95, Long Leg is: C_512.0_20240416 -price: 2.17
#   -> CALENDAR SPREAD ENTRY at 11:26:00
#      SHORT C_512.0_20240415 @ $0.95
#      LONG  C_512.0_20240416 @ $2.17
#      Net Debit: $122.00
#      ROC Ratio: 2.021
#     -> STOP-LOSS TRIGGERED at 13:27:00
#        SHORT C_512.0_20240415 Entry: $0.95, exit at: $0.15
#        LONG  C_512.0_20240416 Entry: $2.17, exit at: $0.96
#   -> STOP-LOSS EXIT for C_512.0_20240416. Profit: $-121.00 and exit price is 0.96
#   -> STOP-LOSS EXIT for C_512.0_20240415. Profit: $80.00 and exit price is 0.15
#
# --- Processing Day: 2024-04-16 ---
# Fetching options across 504.69
#
# --- Phase 2: Preparing Master DataFrame ---
# ✅ Successfully created master DataFrame with 140 total columns.
# Expiry dates being used: 0DTE=20240416, 1DTE=20240417
# Calendar Entry condition met at 2024-04-16 11:03:00 with ROC ratio 1.19
# Price conditions met: Short Leg is: C_504.0_20240416 -price: 1.4, Long Leg is: C_504.0_20240417 -price: 2.42
#   -> CALENDAR SPREAD ENTRY at 11:03:00
#      SHORT C_504.0_20240416 @ $1.40
#      LONG  C_504.0_20240417 @ $2.42
#      Net Debit: $102.00
#      ROC Ratio: 1.194
#     -> EOD TRIGGERED at 15:45:00
#        SHORT C_504.0_20240416 Entry: $1.40, exit at: $0.75
#        LONG  C_504.0_20240417 Entry: $2.42, exit at: $2.44
#   -> EOD EXIT for C_504.0_20240417. Profit: $2.00 and exit price is 2.44
#   -> EOD EXIT for C_504.0_20240416. Profit: $65.00 and exit price is 0.75
#
# --- Processing Day: 2024-04-17 ---
# Fetching options across 505.66
#
# --- Phase 2: Preparing Master DataFrame ---
# ✅ Successfully created master DataFrame with 140 total columns.
# Expiry dates being used: 0DTE=20240417, 1DTE=20240418
# Calendar Entry condition met at 2024-04-17 11:51:00 with ROC ratio 1.83
# Price conditions met: Short Leg is: C_503.0_20240417 -price: 0.86, Long Leg is: C_503.0_20240418 -price: 1.89
#   -> CALENDAR SPREAD ENTRY at 11:51:00
#      SHORT C_503.0_20240417 @ $0.86
#      LONG  C_503.0_20240418 @ $1.89
#      Net Debit: $103.00
#      ROC Ratio: 1.829
#     -> EOD TRIGGERED at 15:45:00
#        SHORT C_503.0_20240417 Entry: $0.86, exit at: $0.07
#        LONG  C_503.0_20240418 Entry: $1.89, exit at: $1.41
#   -> EOD EXIT for C_503.0_20240418. Profit: $-48.00 and exit price is 1.41
#   -> EOD EXIT for C_503.0_20240417. Profit: $79.00 and exit price is 0.07
#
# --- Processing Day: 2024-04-18 ---
# Fetching options across 501.94
#
# --- Phase 2: Preparing Master DataFrame ---
# ✅ Successfully created master DataFrame with 140 total columns.
# Expiry dates being used: 0DTE=20240418, 1DTE=20240419
#
# --- Processing Day: 2024-04-19 ---
# Fetching options across 499.16
#
# --- Phase 2: Preparing Master DataFrame ---
# ✅ Successfully created master DataFrame with 126 total columns.
# Expiry dates being used: 0DTE=20240419, 1DTE=20240422
# Calendar Entry condition met at 2024-04-19 11:14:00 with ROC ratio 1.49
# Price conditions met: Short Leg is: C_500.0_20240419 -price: 0.84, Long Leg is: C_500.0_20240422 -price: 2.08
#   -> CALENDAR SPREAD ENTRY at 11:14:00
#      SHORT C_500.0_20240419 @ $0.84
#      LONG  C_500.0_20240422 @ $2.08
#      Net Debit: $124.00
#      ROC Ratio: 1.487
#     -> STOP-LOSS TRIGGERED at 12:30:00
#        SHORT C_500.0_20240419 Entry: $0.84, exit at: $0.15
#        LONG  C_500.0_20240422 Entry: $2.08, exit at: $0.91
#   -> STOP-LOSS EXIT for C_500.0_20240422. Profit: $-117.00 and exit price is 0.91
#   -> STOP-LOSS EXIT for C_500.0_20240419. Profit: $69.00 and exit price is 0.15
#
# --- Processing Day: 2024-04-22 ---
# Fetching options across 497.72
#
# --- Phase 2: Preparing Master DataFrame ---
# ✅ Successfully created master DataFrame with 126 total columns.
# Expiry dates being used: 0DTE=20240422, 1DTE=20240423
#
# --- Processing Day: 2024-04-23 ---
# Fetching options across 501.83
#
# --- Phase 2: Preparing Master DataFrame ---
# ✅ Successfully created master DataFrame with 140 total columns.
# Expiry dates being used: 0DTE=20240423, 1DTE=20240424
#
# --- Processing Day: 2024-04-24 ---
# Fetching options across 506.52
#
# --- Phase 2: Preparing Master DataFrame ---
# ✅ Successfully created master DataFrame with 140 total columns.
# Expiry dates being used: 0DTE=20240424, 1DTE=20240425
# Calendar Entry condition met at 2024-04-24 10:03:00 with ROC ratio 1.50
# Price conditions met: Short Leg is: C_507.0_20240424 -price: 1.03, Long Leg is: C_507.0_20240425 -price: 1.93
#   -> CALENDAR SPREAD ENTRY at 10:03:00
#      SHORT C_507.0_20240424 @ $1.03
#      LONG  C_507.0_20240425 @ $1.93
#      Net Debit: $90.00
#      ROC Ratio: 1.498
#     -> STOP-LOSS TRIGGERED at 12:00:00
#        SHORT C_507.0_20240424 Entry: $1.03, exit at: $0.21
#        LONG  C_507.0_20240425 Entry: $1.93, exit at: $0.86
#   -> STOP-LOSS EXIT for C_507.0_20240425. Profit: $-107.00 and exit price is 0.86
#   -> STOP-LOSS EXIT for C_507.0_20240424. Profit: $82.00 and exit price is 0.21
#
# --- Processing Day: 2024-04-25 ---
# Fetching options across 499.06
#
# --- Phase 2: Preparing Master DataFrame ---
# ✅ Successfully created master DataFrame with 126 total columns.
# Expiry dates being used: 0DTE=20240425, 1DTE=20240426
#
# --- Processing Day: 2024-04-26 ---
# Fetching options across 506.3
#
# --- Phase 2: Preparing Master DataFrame ---
# ✅ Successfully created master DataFrame with 140 total columns.
# Expiry dates being used: 0DTE=20240426, 1DTE=20240429
#
# --- Processing Day: 2024-04-29 ---
# Fetching options across 510.07
#
# --- Phase 2: Preparing Master DataFrame ---
# ✅ Successfully created master DataFrame with 140 total columns.
# Expiry dates being used: 0DTE=20240429, 1DTE=20240430
#
# --- Processing Day: 2024-04-30 ---
# Fetching options across 508.73
#
# --- Phase 2: Preparing Master DataFrame ---
# ✅ Successfully created master DataFrame with 140 total columns.
# Expiry dates being used: 0DTE=20240430, 1DTE=20240501
# Calendar Entry condition met at 2024-04-30 10:38:00 with ROC ratio 1.98
# Price conditions met: Short Leg is: C_509.0_20240430 -price: 0.92, Long Leg is: C_509.0_20240501 -price: 2.11
#   -> CALENDAR SPREAD ENTRY at 10:38:00
#      SHORT C_509.0_20240430 @ $0.92
#      LONG  C_509.0_20240501 @ $2.11
#      Net Debit: $119.00
#      ROC Ratio: 1.978
#     -> STOP-LOSS TRIGGERED at 14:29:00
#        SHORT C_509.0_20240430 Entry: $0.92, exit at: $0.10
#        LONG  C_509.0_20240501 Entry: $2.11, exit at: $0.93
#   -> STOP-LOSS EXIT for C_509.0_20240501. Profit: $-118.00 and exit price is 0.93
#   -> STOP-LOSS EXIT for C_509.0_20240430. Profit: $82.00 and exit price is 0.10
#
# --- Processing Day: 2024-05-01 ---
# Fetching options across 501.6
#
# --- Phase 2: Preparing Master DataFrame ---
# ✅ Successfully created master DataFrame with 140 total columns.
# Expiry dates being used: 0DTE=20240501, 1DTE=20240502
# Calendar Entry condition met at 2024-05-01 09:52:00 with ROC ratio 1.80
# Price conditions met: Short Leg is: C_502.0_20240501 -price: 1.67, Long Leg is: C_502.0_20240502 -price: 2.5
#   -> CALENDAR SPREAD ENTRY at 09:52:00
#      SHORT C_502.0_20240501 @ $1.67
#      LONG  C_502.0_20240502 @ $2.50
#      Net Debit: $83.00
#      ROC Ratio: 1.802
#     -> EOD TRIGGERED at 15:45:00
#        SHORT C_502.0_20240501 Entry: $1.67, exit at: $1.38
#        LONG  C_502.0_20240502 Entry: $2.50, exit at: $2.66
#   -> EOD EXIT for C_502.0_20240502. Profit: $16.00 and exit price is 2.66
#   -> EOD EXIT for C_502.0_20240501. Profit: $29.00 and exit price is 1.38
#
# --- Processing Day: 2024-05-02 ---
# Fetching options across 503.26
#
# --- Phase 2: Preparing Master DataFrame ---
# ✅ Successfully created master DataFrame with 140 total columns.
# Expiry dates being used: 0DTE=20240502, 1DTE=20240503
# Calendar Entry condition met at 2024-05-02 10:14:00 with ROC ratio 1.67
# Price conditions met: Short Leg is: C_502.0_20240502 -price: 1.2, Long Leg is: C_502.0_20240503 -price: 2.44
#   -> CALENDAR SPREAD ENTRY at 10:14:00
#      SHORT C_502.0_20240502 @ $1.20
#      LONG  C_502.0_20240503 @ $2.44
#      Net Debit: $124.00
#      ROC Ratio: 1.668
#     -> EOD TRIGGERED at 15:45:00
#        SHORT C_502.0_20240502 Entry: $1.20, exit at: $2.38
#        LONG  C_502.0_20240503 Entry: $2.44, exit at: $3.79
#   -> EOD EXIT for C_502.0_20240503. Profit: $135.00 and exit price is 3.79
#   -> EOD EXIT for C_502.0_20240502. Profit: $-118.00 and exit price is 2.38
#
# --- Processing Day: 2024-05-03 ---
# Fetching options across 511.25
#
# --- Phase 2: Preparing Master DataFrame ---
# ✅ Successfully created master DataFrame with 140 total columns.
# Expiry dates being used: 0DTE=20240503, 1DTE=20240506
#
# --- Processing Day: 2024-05-06 ---
# Fetching options across 513.5
#
# --- Phase 2: Preparing Master DataFrame ---
# ✅ Successfully created master DataFrame with 140 total columns.
# Expiry dates being used: 0DTE=20240506, 1DTE=20240507
#
# --- Processing Day: 2024-05-07 ---
# Fetching options across 517.38
#
# --- Phase 2: Preparing Master DataFrame ---
# ✅ Successfully created master DataFrame with 140 total columns.
# Expiry dates being used: 0DTE=20240507, 1DTE=20240508
#
# --- Processing Day: 2024-05-08 ---
# Fetching options across 515.54
#
# --- Phase 2: Preparing Master DataFrame ---
# ✅ Successfully created master DataFrame with 140 total columns.
# Expiry dates being used: 0DTE=20240508, 1DTE=20240509
# Calendar Entry condition met at 2024-05-08 10:32:00 with ROC ratio 1.46
# Calendar Entry condition met at 2024-05-08 10:33:00 with ROC ratio 3.03
# Calendar Entry condition met at 2024-05-08 11:50:00 with ROC ratio 3.63
#
# --- Processing Day: 2024-05-09 ---
# Fetching options across 517.51
#
# --- Phase 2: Preparing Master DataFrame ---
# ✅ Successfully created master DataFrame with 140 total columns.
# Expiry dates being used: 0DTE=20240509, 1DTE=20240510
#
# --- Processing Day: 2024-05-10 ---
# Fetching options across 521.43
#
# --- Phase 2: Preparing Master DataFrame ---
# ✅ Successfully created master DataFrame with 154 total columns.
# Expiry dates being used: 0DTE=20240510, 1DTE=20240513
# Calendar Entry condition met at 2024-05-10 10:51:00 with ROC ratio 1.25
# Calendar Entry condition met at 2024-05-10 11:05:00 with ROC ratio 2.10
# Price conditions met: Short Leg is: C_521.0_20240510 -price: 0.57, Long Leg is: C_521.0_20240513 -price: 1.19
#   -> CALENDAR SPREAD ENTRY at 11:05:00
#      SHORT C_521.0_20240510 @ $0.57
#      LONG  C_521.0_20240513 @ $1.19
#      Net Debit: $62.00
#      ROC Ratio: 2.099
#     -> EOD TRIGGERED at 15:45:00
#        SHORT C_521.0_20240510 Entry: $0.57, exit at: $0.28
#        LONG  C_521.0_20240513 Entry: $1.19, exit at: $1.08
#   -> EOD EXIT for C_521.0_20240513. Profit: $-11.00 and exit price is 1.08
#   -> EOD EXIT for C_521.0_20240510. Profit: $29.00 and exit price is 0.28
#
# --- Processing Day: 2024-05-13 ---
# Fetching options across 522.34
#
# --- Phase 2: Preparing Master DataFrame ---
# ✅ Successfully created master DataFrame with 154 total columns.
# Expiry dates being used: 0DTE=20240513, 1DTE=20240514
#
# --- Processing Day: 2024-05-14 ---
# Fetching options across 521.25
#
# --- Phase 2: Preparing Master DataFrame ---
# ✅ Successfully created master DataFrame with 154 total columns.
# Expiry dates being used: 0DTE=20240514, 1DTE=20240515
#
# --- Processing Day: 2024-05-15 ---
# Fetching options across 525.82
#
# --- Phase 2: Preparing Master DataFrame ---
# ✅ Successfully created master DataFrame with 154 total columns.
# Expiry dates being used: 0DTE=20240515, 1DTE=20240516
#
# --- Processing Day: 2024-05-16 ---
# Fetching options across 530.17
#
# --- Phase 2: Preparing Master DataFrame ---
# ✅ Successfully created master DataFrame with 154 total columns.
# Expiry dates being used: 0DTE=20240516, 1DTE=20240517
#
# --- Processing Day: 2024-05-17 ---
# Fetching options across 529.05
#
# --- Phase 2: Preparing Master DataFrame ---
# ✅ Successfully created master DataFrame with 154 total columns.
# Expiry dates being used: 0DTE=20240517, 1DTE=20240520
# Calendar Entry condition met at 2024-05-17 10:15:00 with ROC ratio 1.35
#
# --- Processing Day: 2024-05-20 ---
# Fetching options across 529.69
#
# --- Phase 2: Preparing Master DataFrame ---
# ✅ Successfully created master DataFrame with 154 total columns.
# Expiry dates being used: 0DTE=20240520, 1DTE=20240521
#
# --- Processing Day: 2024-05-21 ---
# Fetching options across 529.27
#
# --- Phase 2: Preparing Master DataFrame ---
# ✅ Successfully created master DataFrame with 154 total columns.
# Expiry dates being used: 0DTE=20240521, 1DTE=20240522
#
# --- Processing Day: 2024-05-22 ---
# Fetching options across 530.74
#
# --- Phase 2: Preparing Master DataFrame ---
# ✅ Successfully created master DataFrame with 154 total columns.
# Expiry dates being used: 0DTE=20240522, 1DTE=20240523
# Calendar Entry condition met at 2024-05-22 10:50:00 with ROC ratio 1.26
# Price conditions met: Short Leg is: C_532.0_20240522 -price: 1.03, Long Leg is: C_532.0_20240523 -price: 1.73
#   -> CALENDAR SPREAD ENTRY at 10:50:00
#      SHORT C_532.0_20240522 @ $1.03
#      LONG  C_532.0_20240523 @ $1.73
#      Net Debit: $70.00
#      ROC Ratio: 1.257
#     -> EOD TRIGGERED at 15:45:00
#        SHORT C_532.0_20240522 Entry: $1.03, exit at: $0.19
#        LONG  C_532.0_20240523 Entry: $1.73, exit at: $0.97
#   -> EOD EXIT for C_532.0_20240523. Profit: $-76.00 and exit price is 0.97
#   -> EOD EXIT for C_532.0_20240522. Profit: $84.00 and exit price is 0.19
#
# --- Processing Day: 2024-05-23 ---
# Fetching options across 532.69
#
# --- Phase 2: Preparing Master DataFrame ---
# ✅ Successfully created master DataFrame with 154 total columns.
# Expiry dates being used: 0DTE=20240523, 1DTE=20240524
#
# --- Processing Day: 2024-05-24 ---
# Fetching options across 527.58
#
# --- Phase 2: Preparing Master DataFrame ---
# ✅ Successfully created master DataFrame with 154 total columns.
# Expiry dates being used: 0DTE=20240524, 1DTE=20240528
#
# --- Processing Day: 2024-05-28 ---
# Fetching options across 530.17
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# --- Phase 2: Preparing Master DataFrame ---
# ✅ Successfully created master DataFrame with 154 total columns.
# Expiry dates being used: 0DTE=20240528, 1DTE=20240529
#
# --- Processing Day: 2024-05-29 ---
# Fetching options across 525.79
#
# --- Phase 2: Preparing Master DataFrame ---
# ✅ Successfully created master DataFrame with 154 total columns.
# Expiry dates being used: 0DTE=20240529, 1DTE=20240530
#
# --- Processing Day: 2024-05-30 ---
# Fetching options across 524.33
#
# --- Phase 2: Preparing Master DataFrame ---
# ✅ Successfully created master DataFrame with 154 total columns.
# Expiry dates being used: 0DTE=20240530, 1DTE=20240531
# Calendar Entry condition met at 2024-05-30 11:45:00 with ROC ratio 1.88
#
# --- Processing Day: 2024-05-31 ---
# Fetching options across 523.85
#
# --- Phase 2: Preparing Master DataFrame ---
# ✅ Successfully created master DataFrame with 154 total columns.
# Expiry dates being used: 0DTE=20240531, 1DTE=20240603
#
# --- Processing Day: 2024-06-03 ---
# Fetching options across 528.86
#
# --- Phase 2: Preparing Master DataFrame ---
# ✅ Successfully created master DataFrame with 154 total columns.
# Expiry dates being used: 0DTE=20240603, 1DTE=20240604
# Calendar Entry condition met at 2024-06-03 11:25:00 with ROC ratio 1.51
# Price conditions met: Short Leg is: C_527.0_20240603 -price: 0.7, Long Leg is: C_527.0_20240604 -price: 1.32
#   -> CALENDAR SPREAD ENTRY at 11:25:00
#      SHORT C_527.0_20240603 @ $0.70
#      LONG  C_527.0_20240604 @ $1.32
#      Net Debit: $62.00
#      ROC Ratio: 1.507
#     -> STOP-LOSS TRIGGERED at 12:54:00
#        SHORT C_527.0_20240603 Entry: $0.70, exit at: $0.14
#        LONG  C_527.0_20240604 Entry: $1.32, exit at: $0.56
#   -> STOP-LOSS EXIT for C_527.0_20240604. Profit: $-76.00 and exit price is 0.56
#   -> STOP-LOSS EXIT for C_527.0_20240603. Profit: $56.00 and exit price is 0.14
#
# --- Processing Day: 2024-06-04 ---
# Fetching options across 526.5
#
# --- Phase 2: Preparing Master DataFrame ---
# ✅ Successfully created master DataFrame with 154 total columns.
# Expiry dates being used: 0DTE=20240604, 1DTE=20240605
# Calendar Entry condition met at 2024-06-04 10:12:00 with ROC ratio 1.04
# Price conditions met: Short Leg is: C_527.0_20240604 -price: 0.95, Long Leg is: C_527.0_20240605 -price: 1.66
#   -> CALENDAR SPREAD ENTRY at 10:12:00
#      SHORT C_527.0_20240604 @ $0.95
#      LONG  C_527.0_20240605 @ $1.66
#      Net Debit: $71.00
#      ROC Ratio: 1.041
#     -> EOD TRIGGERED at 15:45:00
#        SHORT C_527.0_20240604 Entry: $0.95, exit at: $1.30
#        LONG  C_527.0_20240605 Entry: $1.66, exit at: $2.18
#   -> EOD EXIT for C_527.0_20240605. Profit: $52.00 and exit price is 2.18
#   -> EOD EXIT for C_527.0_20240604. Profit: $-35.00 and exit price is 1.30
#
# --- Processing Day: 2024-06-05 ---
# Fetching options across 530.64
#
# --- Phase 2: Preparing Master DataFrame ---
# ✅ Successfully created master DataFrame with 154 total columns.
# Expiry dates being used: 0DTE=20240605, 1DTE=20240606
# Calendar Entry condition met at 2024-06-05 10:14:00 with ROC ratio 1.29
# Price conditions met: Short Leg is: C_530.0_20240605 -price: 0.93, Long Leg is: C_530.0_20240606 -price: 1.51
#   -> CALENDAR SPREAD ENTRY at 10:14:00
#      SHORT C_530.0_20240605 @ $0.93
#      LONG  C_530.0_20240606 @ $1.51
#      Net Debit: $58.00
#      ROC Ratio: 1.294
#     -> EOD TRIGGERED at 15:45:00
#        SHORT C_530.0_20240605 Entry: $0.93, exit at: $3.90
#        LONG  C_530.0_20240606 Entry: $1.51, exit at: $4.20
#   -> EOD EXIT for C_530.0_20240606. Profit: $269.00 and exit price is 4.20
#   -> EOD EXIT for C_530.0_20240605. Profit: $-297.00 and exit price is 3.90
#
# --- Processing Day: 2024-06-06 ---
# Fetching options across 534.89
#
# --- Phase 2: Preparing Master DataFrame ---
# ✅ Successfully created master DataFrame with 154 total columns.
# Expiry dates being used: 0DTE=20240606, 1DTE=20240607
# Calendar Entry condition met at 2024-06-06 11:05:00 with ROC ratio 1.62
#
# --- Processing Day: 2024-06-07 ---
# Fetching options across 533.44
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# --- Phase 2: Preparing Master DataFrame ---
# ✅ Successfully created master DataFrame with 154 total columns.
# Expiry dates being used: 0DTE=20240607, 1DTE=20240610
# Calendar Entry condition met at 2024-06-07 10:25:00 with ROC ratio 1.07
# Price conditions met: Short Leg is: C_536.0_20240607 -price: 0.48, Long Leg is: C_536.0_20240610 -price: 1.04
#   -> CALENDAR SPREAD ENTRY at 10:25:00
#      SHORT C_536.0_20240607 @ $0.48
#      LONG  C_536.0_20240610 @ $1.04
#      Net Debit: $56.00
#      ROC Ratio: 1.068
#     -> EOD TRIGGERED at 15:45:00
#        SHORT C_536.0_20240607 Entry: $0.48, exit at: $0.05
#        LONG  C_536.0_20240610 Entry: $1.04, exit at: $0.64
#   -> EOD EXIT for C_536.0_20240610. Profit: $-40.00 and exit price is 0.64
#   -> EOD EXIT for C_536.0_20240607. Profit: $43.00 and exit price is 0.05
#
# --- Processing Day: 2024-06-10 ---
# Fetching options across 533.22
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# --- Phase 2: Preparing Master DataFrame ---
# ✅ Successfully created master DataFrame with 154 total columns.
# Expiry dates being used: 0DTE=20240610, 1DTE=20240611
# Calendar Entry condition met at 2024-06-10 10:26:00 with ROC ratio 2.70
# Calendar Entry condition met at 2024-06-10 10:29:00 with ROC ratio 1.36
# Calendar Entry condition met at 2024-06-10 10:35:00 with ROC ratio 2.74
# Calendar Entry condition met at 2024-06-10 10:38:00 with ROC ratio 2.65
# Calendar Entry condition met at 2024-06-10 10:40:00 with ROC ratio 2.67
# Calendar Entry condition met at 2024-06-10 13:20:00 with ROC ratio 1.30
#
# --- Processing Day: 2024-06-11 ---
# Fetching options across 533.74
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# --- Phase 2: Preparing Master DataFrame ---
# ✅ Successfully created master DataFrame with 154 total columns.
# Expiry dates being used: 0DTE=20240611, 1DTE=20240612
# Calendar Entry condition met at 2024-06-11 12:32:00 with ROC ratio 2.39
#
# --- Processing Day: 2024-06-12 ---
# Fetching options across 541.26
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# --- Phase 2: Preparing Master DataFrame ---
# ✅ Successfully created master DataFrame with 154 total columns.
# Expiry dates being used: 0DTE=20240612, 1DTE=20240613
#
# --- Processing Day: 2024-06-13 ---
# Fetching options across 542.9
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# --- Phase 2: Preparing Master DataFrame ---
# ✅ Successfully created master DataFrame with 154 total columns.
# Expiry dates being used: 0DTE=20240613, 1DTE=20240614
# Calendar Entry condition met at 2024-06-13 10:58:00 with ROC ratio 1.12
# Price conditions met: Short Leg is: C_542.0_20240613 -price: 0.54, Long Leg is: C_542.0_20240614 -price: 1.22
#   -> CALENDAR SPREAD ENTRY at 10:58:00
#      SHORT C_542.0_20240613 @ $0.54
#      LONG  C_542.0_20240614 @ $1.22
#      Net Debit: $68.00
#      ROC Ratio: 1.117
#     -> EOD TRIGGERED at 15:45:00
#        SHORT C_542.0_20240613 Entry: $0.54, exit at: $0.78
#        LONG  C_542.0_20240614 Entry: $1.22, exit at: $1.71
#   -> EOD EXIT for C_542.0_20240614. Profit: $49.00 and exit price is 1.71
#   -> EOD EXIT for C_542.0_20240613. Profit: $-24.00 and exit price is 0.78
#
# --- Processing Day: 2024-06-14 ---
# Fetching options across 540.86
#
# --- Phase 2: Preparing Master DataFrame ---
# ✅ Successfully created master DataFrame with 154 total columns.
# Expiry dates being used: 0DTE=20240614, 1DTE=20240617
# Calendar Entry condition met at 2024-06-14 09:50:00 with ROC ratio 2.27
# Price conditions met: Short Leg is: C_542.0_20240614 -price: 0.83, Long Leg is: C_542.0_20240617 -price: 1.41
#   -> CALENDAR SPREAD ENTRY at 09:50:00
#      SHORT C_542.0_20240614 @ $0.83
#      LONG  C_542.0_20240617 @ $1.41
#      Net Debit: $58.00
#      ROC Ratio: 2.266
#     -> EOD TRIGGERED at 15:45:00
#        SHORT C_542.0_20240614 Entry: $0.83, exit at: $0.33
#        LONG  C_542.0_20240617 Entry: $1.41, exit at: $1.24
#   -> EOD EXIT for C_542.0_20240617. Profit: $-17.00 and exit price is 1.24
#   -> EOD EXIT for C_542.0_20240614. Profit: $50.00 and exit price is 0.33
#
# --- Processing Day: 2024-06-17 ---
# Fetching options across 541.95
#
# --- Phase 2: Preparing Master DataFrame ---
# ✅ Successfully created master DataFrame with 154 total columns.
# Expiry dates being used: 0DTE=20240617, 1DTE=20240618
#
# --- Processing Day: 2024-06-18 ---
# Fetching options across 547.25
#
# --- Phase 2: Preparing Master DataFrame ---
# ✅ Successfully created master DataFrame with 147 total columns.
# Expiry dates being used: 0DTE=20240618, 1DTE=20240620
#
# --- Processing Day: 2024-06-20 ---
# Fetching options across 549.18
#
# --- Phase 2: Preparing Master DataFrame ---
# ✅ Successfully created master DataFrame with 154 total columns.
# Expiry dates being used: 0DTE=20240620, 1DTE=20240621
# Calendar Entry condition met at 2024-06-20 12:52:00 with ROC ratio 1.37
#
# --- Processing Day: 2024-06-21 ---
# Fetching options across 544.22
#
# --- Phase 2: Preparing Master DataFrame ---
# ✅ Successfully created master DataFrame with 154 total columns.
# Expiry dates being used: 0DTE=20240621, 1DTE=20240624
#
# --- Processing Day: 2024-06-24 ---
# Fetching options across 544.16
#
# --- Phase 2: Preparing Master DataFrame ---
# ✅ Successfully created master DataFrame with 154 total columns.
# Expiry dates being used: 0DTE=20240624, 1DTE=20240625
#
# --- Processing Day: 2024-06-25 ---
# Fetching options across 543.63
#
# --- Phase 2: Preparing Master DataFrame ---
# ✅ Successfully created master DataFrame with 154 total columns.
# Expiry dates being used: 0DTE=20240625, 1DTE=20240626
# Calendar Entry condition met at 2024-06-25 09:53:00 with ROC ratio 2.21
# Price conditions met: Short Leg is: C_545.0_20240625 -price: 0.45, Long Leg is: C_545.0_20240626 -price: 1.0
#   -> CALENDAR SPREAD ENTRY at 09:53:00
# ...
# Calendar Entry condition met at 2024-10-24 12:02:00 with ROC ratio 2.89
# Price conditions met: Short Leg is: C_579.0_20241024 -price: 0.57, Long Leg is: C_579.0_20241025 -price: 1.63
#   -> CALENDAR SPREAD ENTRY at 12:02:00
#      SHORT C_579.0_20241024 @ $0.57
#      LONG  C_579.0_20241025 @ $1.63
#      Net Debit: $106.00
#      ROC Ratio: 2.892
#     -> EOD TRIGGERED at 15:45:00
#        SHORT C_579.0_20241024 Entry: $0.57, exit at: $0.52
#        LONG  C_579.0_20241025 Entry: $1.63, exit at: $1.90
#   -> EOD EXIT for C_579.0_20241025. Profit: $27.00 and exit price is 1.90
#   -> EOD EXIT for C_579.0_20241024. Profit: $5.00 and exit price is 0.52
#
# --- Processing Day: 2024-10-25 ---
# Fetching options across 582.24
#
# --- Phase 2: Preparing Master DataFrame ---
# ✅ Successfully created master DataFrame with 154 total columns.
# Expiry dates being used: 0DTE=20241025, 1DTE=20241028
#
# --- Processing Day: 2024-10-28 ---
# Fetching options across 582.17
#
# --- Phase 2: Preparing Master DataFrame ---
# ✅ Successfully created master DataFrame with 154 total columns.
# Expiry dates being used: 0DTE=20241028, 1DTE=20241029
#
# --- Processing Day: 2024-10-29 ---
# Fetching options across 579.64
#
# --- Phase 2: Preparing Master DataFrame ---
# ✅ Successfully created master DataFrame with 154 total columns.
# Expiry dates being used: 0DTE=20241029, 1DTE=20241030
# Calendar Entry condition met at 2024-10-29 10:38:00 with ROC ratio 1.43
# Price conditions met: Short Leg is: C_582.0_20241029 -price: 0.8, Long Leg is: C_582.0_20241030 -price: 1.71
#   -> CALENDAR SPREAD ENTRY at 10:38:00
#      SHORT C_582.0_20241029 @ $0.80
#      LONG  C_582.0_20241030 @ $1.71
#      Net Debit: $91.00
#      ROC Ratio: 1.428
#     -> EOD TRIGGERED at 15:45:00
#        SHORT C_582.0_20241029 Entry: $0.80, exit at: $1.03
#        LONG  C_582.0_20241030 Entry: $1.71, exit at: $2.18
#   -> EOD EXIT for C_582.0_20241030. Profit: $47.00 and exit price is 2.18
#   -> EOD EXIT for C_582.0_20241029. Profit: $-23.00 and exit price is 1.03
#
# --- Processing Day: 2024-10-30 ---
# Fetching options across 581.27
#
# --- Phase 2: Preparing Master DataFrame ---
# ✅ Successfully created master DataFrame with 154 total columns.
# Expiry dates being used: 0DTE=20241030, 1DTE=20241031
#
# --- Processing Day: 2024-10-31 ---
# Fetching options across 575.2
#
# --- Phase 2: Preparing Master DataFrame ---
# ✅ Successfully created master DataFrame with 154 total columns.
# Expiry dates being used: 0DTE=20241031, 1DTE=20241101
#
# --- Processing Day: 2024-11-01 ---
# Fetching options across 571.37
#
# --- Phase 2: Preparing Master DataFrame ---
# ✅ Successfully created master DataFrame with 154 total columns.
# Expiry dates being used: 0DTE=20241101, 1DTE=20241104
#
# --- Processing Day: 2024-11-04 ---
# Fetching options across 571.31
#
# --- Phase 2: Preparing Master DataFrame ---
# ✅ Successfully created master DataFrame with 154 total columns.
# Expiry dates being used: 0DTE=20241104, 1DTE=20241105
# Calendar Entry condition met at 2024-11-04 09:56:00 with ROC ratio 1.15
# Price conditions met: Short Leg is: C_572.0_20241104 -price: 0.95, Long Leg is: C_572.0_20241105 -price: 1.93
#   -> CALENDAR SPREAD ENTRY at 09:56:00
#      SHORT C_572.0_20241104 @ $0.95
#      LONG  C_572.0_20241105 @ $1.93
#      Net Debit: $98.00
#      ROC Ratio: 1.152
#     -> STOP-LOSS TRIGGERED at 12:10:00
#        SHORT C_572.0_20241104 Entry: $0.95, exit at: $0.14
#        LONG  C_572.0_20241105 Entry: $1.93, exit at: $0.85
#   -> STOP-LOSS EXIT for C_572.0_20241105. Profit: $-108.00 and exit price is 0.85
#   -> STOP-LOSS EXIT for C_572.0_20241104. Profit: $81.00 and exit price is 0.14
#
# --- Processing Day: 2024-11-05 ---
# Fetching options across 571.11
#
# --- Phase 2: Preparing Master DataFrame ---
# ✅ Successfully created master DataFrame with 154 total columns.
# Expiry dates being used: 0DTE=20241105, 1DTE=20241106
#
# --- Processing Day: 2024-11-06 ---
# Fetching options across 588.26
#
# --- Phase 2: Preparing Master DataFrame ---
# ✅ Successfully created master DataFrame with 154 total columns.
# Expiry dates being used: 0DTE=20241106, 1DTE=20241107
#
# --- Processing Day: 2024-11-07 ---
# Fetching options across 593.27
#
# --- Phase 2: Preparing Master DataFrame ---
# ✅ Successfully created master DataFrame with 154 total columns.
# Expiry dates being used: 0DTE=20241107, 1DTE=20241108
#
# --- Processing Day: 2024-11-08 ---
# Fetching options across 596.51
#
# --- Phase 2: Preparing Master DataFrame ---
# ✅ Successfully created master DataFrame with 154 total columns.
# Expiry dates being used: 0DTE=20241108, 1DTE=20241111
#
# --- Processing Day: 2024-11-11 ---
# Fetching options across 600.03
#
# --- Phase 2: Preparing Master DataFrame ---
# ✅ Successfully created master DataFrame with 168 total columns.
# Expiry dates being used: 0DTE=20241111, 1DTE=20241112
#
# --- Processing Day: 2024-11-12 ---
# Fetching options across 598.93
#
# --- Phase 2: Preparing Master DataFrame ---
# ✅ Successfully created master DataFrame with 154 total columns.
# Expiry dates being used: 0DTE=20241112, 1DTE=20241113
# Calendar Entry condition met at 2024-11-12 10:50:00 with ROC ratio 1.99
#
# --- Processing Day: 2024-11-13 ---
# Fetching options across 597.31
#
# --- Phase 2: Preparing Master DataFrame ---
# ✅ Successfully created master DataFrame with 154 total columns.
# Expiry dates being used: 0DTE=20241113, 1DTE=20241114
# Calendar Entry condition met at 2024-11-13 10:25:00 with ROC ratio 1.13
# Price conditions met: Short Leg is: C_597.0_20241113 -price: 0.63, Long Leg is: C_597.0_20241114 -price: 1.44
#   -> CALENDAR SPREAD ENTRY at 10:25:00
#      SHORT C_597.0_20241113 @ $0.63
#      LONG  C_597.0_20241114 @ $1.44
#      Net Debit: $81.00
#      ROC Ratio: 1.134
#     -> EOD TRIGGERED at 15:45:00
#        SHORT C_597.0_20241113 Entry: $0.63, exit at: $1.21
#        LONG  C_597.0_20241114 Entry: $1.44, exit at: $2.08
#   -> EOD EXIT for C_597.0_20241114. Profit: $64.00 and exit price is 2.08
#   -> EOD EXIT for C_597.0_20241113. Profit: $-58.00 and exit price is 1.21
#
# --- Processing Day: 2024-11-14 ---
# Fetching options across 597.7
#
# --- Phase 2: Preparing Master DataFrame ---
# ✅ Successfully created master DataFrame with 154 total columns.
# Expiry dates being used: 0DTE=20241114, 1DTE=20241115
# Calendar Entry condition met at 2024-11-14 11:24:00 with ROC ratio 2.68
# Price conditions met: Short Leg is: C_597.0_20241114 -price: 0.55, Long Leg is: C_597.0_20241115 -price: 1.46
#   -> CALENDAR SPREAD ENTRY at 11:24:00
#      SHORT C_597.0_20241114 @ $0.55
#      LONG  C_597.0_20241115 @ $1.46
#      Net Debit: $91.00
#      ROC Ratio: 2.682
#     -> STOP-LOSS TRIGGERED at 13:58:00
#        SHORT C_597.0_20241114 Entry: $0.55, exit at: $0.06
#        LONG  C_597.0_20241115 Entry: $1.46, exit at: $0.65
#   -> STOP-LOSS EXIT for C_597.0_20241115. Profit: $-81.00 and exit price is 0.65
#   -> STOP-LOSS EXIT for C_597.0_20241114. Profit: $49.00 and exit price is 0.06
#
# --- Processing Day: 2024-11-15 ---
# Fetching options across 589.94
#
# --- Phase 2: Preparing Master DataFrame ---
# ✅ Successfully created master DataFrame with 154 total columns.
# Expiry dates being used: 0DTE=20241115, 1DTE=20241118
#
# --- Processing Day: 2024-11-18 ---
# Fetching options across 585.88
#
# --- Phase 2: Preparing Master DataFrame ---
# ✅ Successfully created master DataFrame with 154 total columns.
# Expiry dates being used: 0DTE=20241118, 1DTE=20241119
#
# --- Processing Day: 2024-11-19 ---
# Fetching options across 584.79
#
# --- Phase 2: Preparing Master DataFrame ---
# ✅ Successfully created master DataFrame with 154 total columns.
# Expiry dates being used: 0DTE=20241119, 1DTE=20241120
#
# --- Processing Day: 2024-11-20 ---
# Fetching options across 590.13
#
# --- Phase 2: Preparing Master DataFrame ---
# ✅ Successfully created master DataFrame with 154 total columns.
# Expiry dates being used: 0DTE=20241120, 1DTE=20241121
#
# --- Processing Day: 2024-11-21 ---
# Fetching options across 592.86
#
# --- Phase 2: Preparing Master DataFrame ---
# ✅ Successfully created master DataFrame with 154 total columns.
# Expiry dates being used: 0DTE=20241121, 1DTE=20241122
#
# --- Processing Day: 2024-11-22 ---
# Fetching options across 594.22
#
# --- Phase 2: Preparing Master DataFrame ---
# ✅ Successfully created master DataFrame with 154 total columns.
# Expiry dates being used: 0DTE=20241122, 1DTE=20241125
# Calendar Entry condition met at 2024-11-22 11:42:00 with ROC ratio 2.56
# Price conditions met: Short Leg is: C_595.0_20241122 -price: 0.67, Long Leg is: C_595.0_20241125 -price: 1.7
#   -> CALENDAR SPREAD ENTRY at 11:42:00
#      SHORT C_595.0_20241122 @ $0.67
#      LONG  C_595.0_20241125 @ $1.70
#      Net Debit: $103.00
#      ROC Ratio: 2.557
#     -> EOD TRIGGERED at 15:45:00
#        SHORT C_595.0_20241122 Entry: $0.67, exit at: $0.25
#        LONG  C_595.0_20241125 Entry: $1.70, exit at: $1.39
#   -> EOD EXIT for C_595.0_20241125. Profit: $-31.00 and exit price is 1.39
#   -> EOD EXIT for C_595.0_20241122. Profit: $42.00 and exit price is 0.25
#
# --- Processing Day: 2024-11-25 ---
# Fetching options across 599.01
#
# --- Phase 2: Preparing Master DataFrame ---
# ✅ Successfully created master DataFrame with 154 total columns.
# Expiry dates being used: 0DTE=20241125, 1DTE=20241126
#
# --- Processing Day: 2024-11-26 ---
# Fetching options across 598.8
#
# --- Phase 2: Preparing Master DataFrame ---
# ✅ Successfully created master DataFrame with 154 total columns.
# Expiry dates being used: 0DTE=20241126, 1DTE=20241127
#
# --- Processing Day: 2024-11-27 ---
# Fetching options across 600.28
#
# --- Phase 2: Preparing Master DataFrame ---
# ✅ Successfully created master DataFrame with 168 total columns.
# Expiry dates being used: 0DTE=20241127, 1DTE=20241129
# Calendar Entry condition met at 2024-11-27 09:50:00 with ROC ratio 1.20
# Price conditions met: Short Leg is: C_602.0_20241127 -price: 0.42, Long Leg is: C_602.0_20241129 -price: 1.03
#   -> CALENDAR SPREAD ENTRY at 09:50:00
#      SHORT C_602.0_20241127 @ $0.42
#      LONG  C_602.0_20241129 @ $1.03
#      Net Debit: $61.00
#      ROC Ratio: 1.205
#     -> STOP-LOSS TRIGGERED at 10:38:00
#        SHORT C_602.0_20241127 Entry: $0.42, exit at: $0.07
#        LONG  C_602.0_20241129 Entry: $1.03, exit at: $0.40
#   -> STOP-LOSS EXIT for C_602.0_20241129. Profit: $-63.00 and exit price is 0.40
#   -> STOP-LOSS EXIT for C_602.0_20241127. Profit: $35.00 and exit price is 0.07
#
# --- Processing Day: 2024-12-02 ---
# Fetching options across 603.29
#
# --- Phase 2: Preparing Master DataFrame ---
# ✅ Successfully created master DataFrame with 168 total columns.
# Expiry dates being used: 0DTE=20241202, 1DTE=20241203
#
# --- Processing Day: 2024-12-03 ---
# Fetching options across 603.41
#
# --- Phase 2: Preparing Master DataFrame ---
# ✅ Successfully created master DataFrame with 168 total columns.
# Expiry dates being used: 0DTE=20241203, 1DTE=20241204
#
# --- Processing Day: 2024-12-04 ---
# Fetching options across 605.67
#
# --- Phase 2: Preparing Master DataFrame ---
# ✅ Successfully created master DataFrame with 168 total columns.
# Expiry dates being used: 0DTE=20241204, 1DTE=20241205
#
# --- Processing Day: 2024-12-05 ---
# Fetching options across 607.78
#
# --- Phase 2: Preparing Master DataFrame ---
# ✅ Successfully created master DataFrame with 168 total columns.
# Expiry dates being used: 0DTE=20241205, 1DTE=20241206
#
# --- Processing Day: 2024-12-06 ---
# Fetching options across 607.74
#
# --- Phase 2: Preparing Master DataFrame ---
# ✅ Successfully created master DataFrame with 168 total columns.
# Expiry dates being used: 0DTE=20241206, 1DTE=20241209
#
# --- Processing Day: 2024-12-09 ---
# Fetching options across 607.48
#
# --- Phase 2: Preparing Master DataFrame ---
# ✅ Successfully created master DataFrame with 168 total columns.
# Expiry dates being used: 0DTE=20241209, 1DTE=20241210
#
# --- Processing Day: 2024-12-10 ---
# Fetching options across 604.94
#
# --- Phase 2: Preparing Master DataFrame ---
# ✅ Successfully created master DataFrame with 168 total columns.
# Expiry dates being used: 0DTE=20241210, 1DTE=20241211
#
# --- Processing Day: 2024-12-11 ---
# Fetching options across 605.65
#
# --- Phase 2: Preparing Master DataFrame ---
# ✅ Successfully created master DataFrame with 168 total columns.
# Expiry dates being used: 0DTE=20241211, 1DTE=20241212
#
# --- Processing Day: 2024-12-12 ---
# Fetching options across 606.54
#
# --- Phase 2: Preparing Master DataFrame ---
# ✅ Successfully created master DataFrame with 168 total columns.
# Expiry dates being used: 0DTE=20241212, 1DTE=20241213
# Calendar Entry condition met at 2024-12-12 09:49:00 with ROC ratio 2.53
#
# --- Processing Day: 2024-12-13 ---
# Fetching options across 606.35
#
# --- Phase 2: Preparing Master DataFrame ---
# ✅ Successfully created master DataFrame with 168 total columns.
# Expiry dates being used: 0DTE=20241213, 1DTE=20241216
#
# --- Processing Day: 2024-12-16 ---
# Fetching options across 606.35
#
# --- Phase 2: Preparing Master DataFrame ---
# ✅ Successfully created master DataFrame with 168 total columns.
# Expiry dates being used: 0DTE=20241216, 1DTE=20241217
#
# --- Processing Day: 2024-12-17 ---
# Fetching options across 603.83
#
# --- Phase 2: Preparing Master DataFrame ---
# ✅ Successfully created master DataFrame with 168 total columns.
# Expiry dates being used: 0DTE=20241217, 1DTE=20241218
#
# --- Processing Day: 2024-12-18 ---
# Fetching options across 604.08
# An error occurred during bulk fetch: HTTP Error: HTTP GET error reading 's3://duckdata/ORATS/Options/ticker=SPY/day=2024-12-18/duckdata/?encoding-type=url&list-type=2&prefix=ORATS%2FOptions%2Fticker%3DSPY%2Fday%3D2024-12-18%2F' in region 'us-east-1' (HTTP 403 Forbidden)
#
# Authentication Failure - this is usually caused by invalid or missing credentials.
# * Credentials are provided, but they did not work.
# * See https://duckdb.org/docs/stable/extensions/httpfs/s3api.html
# Could not pre-fetch any option data for the day. Skipping.
#
# --- Processing Day: 2024-12-19 ---
# Fetching options across 591.51
# An error occurred during bulk fetch: HTTP Error: HTTP GET error reading 's3://duckdata/ORATS/Options/ticker=SPY/day=2024-12-19/duckdata/?encoding-type=url&list-type=2&prefix=ORATS%2FOptions%2Fticker%3DSPY%2Fday%3D2024-12-19%2F' in region 'us-east-1' (HTTP 403 Forbidden)
#
# Authentication Failure - this is usually caused by invalid or missing credentials.
# * Credentials are provided, but they did not work.
# * See https://duckdb.org/docs/stable/extensions/httpfs/s3api.html
# Could not pre-fetch any option data for the day. Skipping.
#
# --- Processing Day: 2024-12-20 ---
# Fetching options across 581.16
# An error occurred during bulk fetch: HTTP Error: HTTP GET error reading 's3://duckdata/ORATS/Options/ticker=SPY/day=2024-12-20/duckdata/?encoding-type=url&list-type=2&prefix=ORATS%2FOptions%2Fticker%3DSPY%2Fday%3D2024-12-20%2F' in region 'us-east-1' (HTTP 403 Forbidden)
#
# Authentication Failure - this is usually caused by invalid or missing credentials.
# * Credentials are provided, but they did not work.
# * See https://duckdb.org/docs/stable/extensions/httpfs/s3api.html
# Could not pre-fetch any option data for the day. Skipping.
#
# --- Processing Day: 2024-12-23 ---
# Fetching options across 591.68
# An error occurred during bulk fetch: HTTP Error: HTTP GET error reading 's3://duckdata/ORATS/Options/ticker=SPY/day=2024-12-23/duckdata/?encoding-type=url&list-type=2&prefix=ORATS%2FOptions%2Fticker%3DSPY%2Fday%3D2024-12-23%2F' in region 'us-east-1' (HTTP 403 Forbidden)
#
# Authentication Failure - this is usually caused by invalid or missing credentials.
# * Credentials are provided, but they did not work.
# * See https://duckdb.org/docs/stable/extensions/httpfs/s3api.html
# Could not pre-fetch any option data for the day. Skipping.
#
# --- Processing Day: 2024-12-24 ---
# Fetching options across 595.66
# An error occurred during bulk fetch: HTTP Error: HTTP GET error reading 's3://duckdata/ORATS/Options/ticker=SPY/day=2024-12-24/duckdata/?encoding-type=url&list-type=2&prefix=ORATS%2FOptions%2Fticker%3DSPY%2Fday%3D2024-12-24%2F' in region 'us-east-1' (HTTP 403 Forbidden)
#
# Authentication Failure - this is usually caused by invalid or missing credentials.
# * Credentials are provided, but they did not work.
# * See https://duckdb.org/docs/stable/extensions/httpfs/s3api.html
# Could not pre-fetch any option data for the day. Skipping.
# Trading completed. Total trades: 134

# %%
daily_profits = local_trade_log2.groupby(local_trade_log2['entry_date'].dt.date)['profit'].sum()
print(daily_profits.mean())
negative_days = (daily_profits < 0).sum()
positive_days = (daily_profits > 0).sum()
total_days = daily_profits.count()

positive_pct = 100 * positive_days / total_days
negative_pct = 100 * negative_days / total_days

print(f"Positive days: {positive_days} ({positive_pct:.2f}%)")
print(f"Negative days: {negative_days} ({negative_pct:.2f}%)")
# Out:
# 4.94029850746269
# Positive days: 38 (56.72%)
# Negative days: 28 (41.79%)

# %%
local_trade_log2
# Out:
#                  name  Side          entry_date  entry_price  qty  \
# 0    C_478.0_20240122   BUY 2024-01-19 09:50:00   1.33000000  100
# 1    C_478.0_20240119  SELL 2024-01-19 09:50:00   0.78000000  100
# 2    C_489.0_20240130   BUY 2024-01-29 10:21:00   1.15000000  100
# 3    C_489.0_20240129  SELL 2024-01-29 10:21:00   0.41000000  100
# 4    C_492.0_20240131   BUY 2024-01-30 10:51:00   1.33000000  100
# ..                ...   ...                 ...          ...  ...
# 129  C_597.0_20241114  SELL 2024-11-14 11:24:00   0.55000000  100
# 130  C_595.0_20241125   BUY 2024-11-22 11:42:00   1.70000000  100
# 131  C_595.0_20241122  SELL 2024-11-22 11:42:00   0.67000000  100
# 132  C_602.0_20241129   BUY 2024-11-27 09:50:00   1.03000000  100
# 133  C_602.0_20241127  SELL 2024-11-27 09:50:00   0.42000000  100
#
#               exit_date  exit_price        profit  bars_held exit_reason
# 0   2024-01-19 15:45:00  4.23000000  290.00000000        710         EOD
# 1   2024-01-19 15:45:00  4.01000000 -323.00000000        710         EOD
# 2   2024-01-29 15:45:00  2.35000000  120.00000000        648         EOD
# 3   2024-01-29 15:45:00  1.74000000 -133.00000000        648         EOD
# 4   2024-01-30 15:45:00  1.52000000   19.00000000        588         EOD
# ..                  ...         ...           ...        ...         ...
# 129 2024-11-14 13:58:00  0.06000000   49.00000000        308   STOP-LOSS
# 130 2024-11-22 15:45:00  1.39000000  -31.00000000        486         EOD
# 131 2024-11-22 15:45:00  0.25000000   42.00000000        486         EOD
# 132 2024-11-27 10:38:00  0.40000000  -63.00000000         96   STOP-LOSS
# 133 2024-11-27 10:38:00  0.07000000   35.00000000         96   STOP-LOSS
#
# [134 rows x 10 columns]

# %%
daily_profits.min()
# Out:
# -63.00000000000003

# %%
daily_profits.cumsum().plot(figsize=(12, 6), title='Cumulative Daily Profits Over Time', grid=True)
# Out:
# <Axes: title={'center': 'Cumulative Daily Profits Over Time'}, xlabel='entry_date'>

# %%
com_df['SPY_close'].plot(figsize=(12, 6), title='SPY Close Price Over Time', grid=True)
# Out:
# <Axes: title={'center': 'SPY Close Price Over Time'}, xlabel='timestamp'>
