# %%
pip install yfinance
# Out:
# Collecting yfinance
#   Downloading yfinance-0.2.30-py2.py3-none-any.whl (65 kB)
#      ---------------------------------------- 65.4/65.4 kB 3.4 MB/s eta 0:00:00
# Collecting frozendict>=2.3.4
#   Downloading frozendict-2.3.8-cp39-cp39-win_amd64.whl (35 kB)
# Collecting html5lib>=1.1
#   Downloading html5lib-1.1-py2.py3-none-any.whl (112 kB)
#      -------------------------------------- 112.2/112.2 kB 2.2 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.16.5 in c:\users\aniru\anaconda\lib\site-packages (from yfinance) (1.24.3)
# Collecting requests>=2.31
#   Using cached requests-2.31.0-py3-none-any.whl (62 kB)
# Requirement already satisfied: pandas>=1.3.0 in c:\users\aniru\anaconda\lib\site-packages (from yfinance) (1.4.4)
# Collecting peewee>=3.16.2
#   Downloading peewee-3.16.3.tar.gz (928 kB)
#      -------------------------------------- 928.0/928.0 kB 2.9 MB/s eta 0:00:00
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Collecting pytz>=2022.5
#   Downloading pytz-2023.3.post1-py2.py3-none-any.whl (502 kB)
#      -------------------------------------- 502.5/502.5 kB 2.9 MB/s eta 0:00:00
# Requirement already satisfied: beautifulsoup4>=4.11.1 in c:\users\aniru\anaconda\lib\site-packages (from yfinance) (4.11.1)
# Requirement already satisfied: appdirs>=1.4.4 in c:\users\aniru\anaconda\lib\site-packages (from yfinance) (1.4.4)
# Requirement already satisfied: lxml>=4.9.1 in c:\users\aniru\anaconda\lib\site-packages (from yfinance) (4.9.1)
# Collecting multitasking>=0.0.7
#   Downloading multitasking-0.0.11-py3-none-any.whl (8.5 kB)
# Requirement already satisfied: soupsieve>1.2 in c:\users\aniru\anaconda\lib\site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.3.1)
# Requirement already satisfied: six>=1.9 in c:\users\aniru\anaconda\lib\site-packages (from html5lib>=1.1->yfinance) (1.16.0)
# Requirement already satisfied: webencodings in c:\users\aniru\anaconda\lib\site-packages (from html5lib>=1.1->yfinance) (0.5.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\aniru\anaconda\lib\site-packages (from pandas>=1.3.0->yfinance) (2.8.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\aniru\anaconda\lib\site-packages (from requests>=2.31->yfinance) (3.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\aniru\anaconda\lib\site-packages (from requests>=2.31->yfinance) (2.0.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\aniru\anaconda\lib\site-packages (from requests>=2.31->yfinance) (1.26.11)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\aniru\anaconda\lib\site-packages (from requests>=2.31->yfinance) (2022.9.14)
# Building wheels for collected packages: peewee
#   Building wheel for peewee (pyproject.toml): started
#   Building wheel for peewee (pyproject.toml): finished with status 'done'
#   Created wheel for peewee: filename=peewee-3.16.3-py3-none-any.whl size=135547 sha256=fa7ac2c9ed11948382e1743e4be1cc2569bba2ac86b5e197f0396f5a993990aa
#   Stored in directory: c:\users\aniru\appdata\local\pip\cache\wheels\46\c8\76\da8e4e28595d45fac70db742390350ab43211d5ae4b0eb376c
# Successfully built peewee
# Installing collected packages: pytz, peewee, multitasking, requests, html5lib, frozendict, yfinance
#   Attempting uninstall: pytz
#     Found existing installation: pytz 2022.1
#     Uninstalling pytz-2022.1:
#       Successfully uninstalled pytz-2022.1
#   Attempting uninstall: requests
#     Found existing installation: requests 2.28.1
#     Uninstalling requests-2.28.1:
#       Successfully uninstalled requests-2.28.1
# Successfully installed frozendict-2.3.8 html5lib-1.1 multitasking-0.0.11 peewee-3.16.3 pytz-2023.3.post1 requests-2.31.0 yfinance-0.2.30
# Note: you may need to restart the kernel to use updated packages.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# conda-repo-cli 1.0.20 requires clyent==1.2.1, but you have clyent 1.2.2 which is incompatible.
# conda-repo-cli 1.0.20 requires nbformat==5.4.0, but you have nbformat 5.5.0 which is incompatible.
# conda-repo-cli 1.0.20 requires requests==2.28.1, but you have requests 2.31.0 which is incompatible.

# %%
import yfinance as yf
import pandas as pd

class FinancialDataCollector:
    def __init__(self):
        self.start_date = "2021-01-01"
        self.end_date = "2021-12-31"

    def get_stock_data(self, symbol):
        try:
            data = yf.download(symbol, start=self.start_date, end=self.end_date)
            return data
        except Exception as e:
            print(f"Error fetching data for {symbol}: {str(e)}")
            return None

    def display_data(self, data):
        if data is not None:
            print(data)

def main():
    # Instantiate the FinancialDataCollector class
    data_collector = FinancialDataCollector()

    # List of stock symbols to retrieve data for (Microsoft and IBM in this case)
    symbols = ["MSFT", "IBM"]

    for symbol in symbols:
        print(f"Fetching data for {symbol} from {data_collector.start_date} to {data_collector.end_date}:")
        stock_data = data_collector.get_stock_data(symbol)
        data_collector.display_data(stock_data)
        print("\n" + "="*40 + "\n")

if __name__ == "__main__":
    main()
# Out:
# Fetching data for MSFT from 2021-01-01 to 2021-12-31:
# [*********************100%%**********************]  1 of 1 completed
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2021-01-04