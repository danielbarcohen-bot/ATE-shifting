# %% [markdown]
# # TP1
#
# Dans ce premier TP, vous allez découvrir la bibliothèque Pandas de Python. Ce premier Notebook vous permettra de vous famliariser avec les principales fonctions de pandas.
#
# Quelques ressources :
# - [site officiel de la bibliothèque pandas](http://pandas.pydata.org/)
# - [comment utiliser IPython/Jupyter notebook](https://youtu.be/IsXXlYVBt1M?t=5m17s)

# %%
import pandas as pd

# %% [markdown]
# ## Découverte des fonctions principales

# %% [markdown]
# 1. Téléchargez le fichier `imdb_sample.csv` puis chargez le dans une variable `df` via la fonction [read_csv](https://pandas.pydata.org/docs/reference/api/pandas.read_csv.html). Prenez le temps de lire la documentation de la fonction `read_csv` et de découvrir les différents arguments qui existent.

# %%
df = pd.read_csv("imdb_sample.csv")

# %% [markdown]
# 2. Utilisez la fonction [head](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.head.html) pour afficher les 10 premières lignes de votre jeu de données `df`.

# %%
df.head(10)
# Out:
#    star_rating                                          title content_rating  \
# 0          9.3                       The Shawshank Redemption              R
# 1          9.2                                  The Godfather              R
# 2          9.1                         The Godfather: Part II              R
# 3          9.0                                The Dark Knight          PG-13
# 4          8.9                                   Pulp Fiction              R
# 5          8.9                                   12 Angry Men      NOT RATED
# 6          8.9                 The Good, the Bad and the Ugly      NOT RATED
# 7          8.9  The Lord of the Rings: The Return of the King          PG-13
# 8          8.9                               Schindler's List              R
# 9          8.9                                     Fight Club              R
#
#        genre  duration                                        actors_list
# ...

# %% [markdown]
# 3. Utilisez la fonction [tail](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.tail.html) pour afficher les 5 dernières lignes de votre jeu de données `df`.

# %%
df.tail(5)
# Out:
#      star_rating                                            title  \
# 974          7.4                                          Tootsie
# 975          7.4                      Back to the Future Part III
# 976          7.4  Master and Commander: The Far Side of the World
# 977          7.4                                      Poltergeist
# 978          7.4                                      Wall Street
#
#     content_rating      genre  duration  \
# 974             PG     Comedy       116
# 975             PG  Adventure       118
# 976          PG-13     Action       138
# 977             PG     Horror       114
# 978              R      Crime       126
#
#                                            actors_list
# 974  [u'Dustin Hoffman', u'Jessica Lange', u'Teri G...
# 975  [u'Michael J. Fox', u'Christopher Lloyd', u'Ma...
# 976  [u'Russell Crowe', u'Paul Bettany', u'Billy Bo...
# 977  [u'JoBeth Williams', u"Heather O'Rourke", u'Cr...
# ...

# %% [markdown]
# 4. Quel est le nombre d'observations et de variables dans ce jeu de données (c'est-à-dire le nombre de lignes et colonnes). Vous pouvez utiliser l'attribut `shape`

# %%
print(f"ligne : {df.shape[0]}, col : {df.shape[1]}")
# Out:
# ligne : 979, col : 6

# %% [markdown]
# 5. Donnez la liste des colonnes qui composent votre jeu de données en utilisant l'attribut `columns`. Renseignez vous ensuite sur le type `Index` de pandas.

# %%
for column in df.columns:
    print(column)
# Out:
# note
# title
# content_rating
# genre
# duration
# note_over_20
# Index(['note', 'title', 'content_rating', 'genre', 'duration', 'note_over_20'], dtype='object')

# %% [markdown]
# 6. Renommez la colonne `star_rating` en `note` (allez voir la documentation de la fonction [rename](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.rename.html)).

# %%
df = df.rename(columns={"star_rating": "note"})

for column in df.columns:
    print(column)
# Out:
# note
# title
# content_rating
# genre
# duration
# actors_list

# %% [markdown]
# 7. La colonne `actors_list` ne nous servira pas pour ce TP. Utilisez la fonction [drop](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.drop.html) pour la supprimer.

# %%
df = df.drop(columns=['actors_list'])

for column in df.columns:
    print(column)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 df = df.drop(columns=['actors_list'])
#       3 for column in df.columns:
#       4     print(column)
#
# File ~/Library/Python/3.9/lib/python/site-packages/pandas/core/frame.py:5581, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5433 def drop(
#    5434     self,
#    5435     labels: IndexLabel | None = None,
#    (...)
#    5442     errors: IgnoreRaise = "raise",
#    5443 ) -> DataFrame | None:
#    5444     """
#    5445     Drop specified labels from rows or columns.
#    5446
#    (...)
#    5579             weight  1.0     0.8
#    5580     """
# -> 5581     return super().drop(
#    5582         labels=labels,
#    5583         axis=axis,
#    5584         index=index,
#    5585         columns=columns,
#    5586         level=level,
# ...

# %% [markdown]
# 8. Afficher le type de chaque variable/colonne en utilisant l'attribut `dtypes`. Comment interprétez vous le résultat ?

# %%
df.dtypes
# Out:
# note              float64
# title              object
# content_rating     object
# genre              object
# duration            int64
# dtype: object

# %% [markdown]
# ## Trier le jeu données
#
# 9. Affichez le jeu de données trié par note croissante (voir la fonction [sort_values](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.sort_values.html)).

# %%
df = df.sort_values(by='note', ascending=False)
df.head(10)
# Out:
#    note                                          title content_rating  \
# 0   9.3                       The Shawshank Redemption              R
# 1   9.2                                  The Godfather              R
# 2   9.1                         The Godfather: Part II              R
# 3   9.0                                The Dark Knight          PG-13
# 4   8.9                                   Pulp Fiction              R
# 5   8.9                                   12 Angry Men      NOT RATED
# 6   8.9                 The Good, the Bad and the Ugly      NOT RATED
# 7   8.9  The Lord of the Rings: The Return of the King          PG-13
# 8   8.9                               Schindler's List              R
# 9   8.9                                     Fight Club              R
#
#        genre  duration
# 0      Crime       142
# 1      Crime       175
# 2      Crime       200
# 3     Action       152
# 4      Crime       154
# 5      Drama        96
# 6    Western       161
# ...

# %% [markdown]
# 10. Affichez le jeu de données trié par note décroissante.

# %%
df = df.sort_values(by='note', ascending=False)
df.head(10)
# Out:
#    note                                          title content_rating  \
# 0   9.3                       The Shawshank Redemption              R
# 1   9.2                                  The Godfather              R
# 2   9.1                         The Godfather: Part II              R
# 3   9.0                                The Dark Knight          PG-13
# 4   8.9                                   Pulp Fiction              R
# 5   8.9                                   12 Angry Men      NOT RATED
# 6   8.9                 The Good, the Bad and the Ugly      NOT RATED
# 7   8.9  The Lord of the Rings: The Return of the King          PG-13
# 8   8.9                               Schindler's List              R
# 9   8.9                                     Fight Club              R
#
#        genre  duration
# 0      Crime       142
# 1      Crime       175
# 2      Crime       200
# 3     Action       152
# 4      Crime       154
# 5      Drama        96
# 6    Western       161
# ...

# %% [markdown]
# 11. Affichez le jeu de données trié par note croissante puis par durée croissante en cas d'égalité.

# %%
df = df.sort_values(by=['note', 'duration'], ascending=[False, False])
df.head(10)
# Out:
#    note                                          title content_rating  \
# 0   9.3                       The Shawshank Redemption              R
# 1   9.2                                  The Godfather              R
# 2   9.1                         The Godfather: Part II              R
# 3   9.0                                The Dark Knight          PG-13
# 7   8.9  The Lord of the Rings: The Return of the King          PG-13
# 8   8.9                               Schindler's List              R
# 6   8.9                 The Good, the Bad and the Ugly      NOT RATED
# 4   8.9                                   Pulp Fiction              R
# 9   8.9                                     Fight Club              R
# 5   8.9                                   12 Angry Men      NOT RATED
#
#        genre  duration
# 0      Crime       142
# 1      Crime       175
# 2      Crime       200
# 3     Action       152
# 7  Adventure       201
# 8  Biography       195
# 6    Western       161
# ...

# %% [markdown]
# ## Travailler avec les colonnes
#
# 12. Retournez le contenu de la colonne `title` (utilisez la notation à base de crochets).

# %%
df.head(10)['title']
# Out:
# 0                         The Shawshank Redemption
# 1                                    The Godfather
# 2                           The Godfather: Part II
# 3                                  The Dark Knight
# 7    The Lord of the Rings: The Return of the King
# 8                                 Schindler's List
# 6                   The Good, the Bad and the Ugly
# 4                                     Pulp Fiction
# 9                                       Fight Club
# 5                                     12 Angry Men
# Name: title, dtype: object

# %% [markdown]
# 13. Appliquez les fonctions `min`, `max`, `mean` sur la colonne `note` pour récupérer la note minimale, moyenne et maxime pour les films du jeu de données.

# %%
df['note'].min()
# Out:
# np.float64(7.4)

# %%
df['note'].max()
# Out:
# np.float64(9.3)

# %%
df['note'].mean()
# Out:
# np.float64(7.889785495403474)

# %% [markdown]
# 14. Créez votre propre fonction `min_max_mean` retournant la valeur minimale, maximale et moyenne d'une liste numérique.

# %%
def min_max_mean(arr: list) -> (float, float, float):
    return (arr.min(), arr.max(), arr.mean())

# %% [markdown]
# 15. Appliquez votre fonction sur la colonne `note` du jeu de données et comparez votre résultat à celui de la question 13.

# %%
print(min_max_mean(df['note']))
# Out:
# (np.float64(7.4), np.float64(9.3), np.float64(7.889785495403474))

# %% [markdown]
# 16. Créez une nouvelle colonne `note_over_20` qui correspond à la note passée à une échelle sur 20 (actuellement sur une échelle de 10). Puis affichez les 5 premières lignes du jeu de données.

# %%
def mult2(x):
    return 2*x

df['note_over_20'] = df['note']*2

df.head(10)
# Out:
#    note                                          title content_rating  \
# 0   9.3                       The Shawshank Redemption              R
# 1   9.2                                  The Godfather              R
# 2   9.1                         The Godfather: Part II              R
# 3   9.0                                The Dark Knight          PG-13
# 7   8.9  The Lord of the Rings: The Return of the King          PG-13
# 8   8.9                               Schindler's List              R
# 6   8.9                 The Good, the Bad and the Ugly      NOT RATED
# 4   8.9                                   Pulp Fiction              R
# 9   8.9                                     Fight Club              R
# 5   8.9                                   12 Angry Men      NOT RATED
#
#        genre  duration  note_over_20
# 0      Crime       142          18.6
# 1      Crime       175          18.4
# 2      Crime       200          18.2
# 3     Action       152          18.0
# ...

# %% [markdown]
# 17. Explorez la page de documentation de la fonction `value_counts` puis utiliser cette fonction sur la colonne `genre`. Faites une synthèse du résultat affiché.

# %%
df['genre'].value_counts()
# Out:
# genre
# Drama        278
# Comedy       156
# Action       136
# Crime        124
# Biography     77
# Adventure     75
# Animation     62
# Horror        29
# Mystery       16
# Western        9
# Sci-Fi         5
# Thriller       5
# Film-Noir      3
# Family         2
# History        1
# Fantasy        1
# Name: count, dtype: int64

# %% [markdown]
# 18. Ecrivez votre propre fonction `value_counts` permettant de compter le nombre d'éléments dans une liste.

# %%
def value_counts(arr: list)-> dict:
    for el in arr:

# %% [markdown]
# 19. Appliquez votre fonction `value_countz` sur la colonne `genre` et comparez votre résultat avec celui de la question 17.

# %%
value_counts(df['genre'])
# Out:
# genre
# Drama        278
# Comedy       156
# Action       136
# Crime        124
# Biography     77
# Adventure     75
# Animation     62
# Horror        29
# Mystery       16
# Western        9
# Sci-Fi         5
# Thriller       5
# Film-Noir      3
# Family         2
# History        1
# Fantasy        1
# Name: count, dtype: int64

# %% [markdown]
# 20. Utilisez la méthode `describe` pour afficher un certain nombre d'indications statistiques sur une variable numérique. Vous pouvez l'appliquer sur la colonne `note` par exemple.

# %%
df['note'].describe()
# Out:
# count    979.000000
# mean       7.889785
# std        0.336069
# min        7.400000
# 25%        7.600000
# 50%        7.800000
# 75%        8.100000
# max        9.300000
# Name: note, dtype: float64

# %% [markdown]
# ## Filtrer la donnée
#
# 21. Créer une liste `mask` ayant la même taille que le nombre de lignes dans le jeu données (question 4). Cette liste de booélens alternera les valeurs `True` et `False`

# %%
df['mask'] =

# %% [markdown]
# 22. Executez le bloc d'instruction suivant. Qu'observez-vous ?

# %%
df[mask].shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 df[mask].shape
#
# NameError: name 'mask' is not defined

# %% [markdown]
# 23. Mettez à jour la liste `mask` pour commencer par 3 fois `True` et mettre à `False` toutes les autres valeurs.

# %% [markdown]
# 24. Executez le bloc d'instruction suivant. Qu'observez-vous ?

# %%
df[mask]

# %% [markdown]
# 25. Créez un mask qui vaut `True` pour les films de plus de 2h30 et `False` sinon. Utilisez ensuite ce filtre pour afficher tous les films de plus de 2h30.

# %% [markdown]
# 26. Trouvez l'instruction en une seule ligne permettant de voir tous les films de genre `Crime`.

# %% [markdown]
# 27. Combien de films de genre `Crime` sont présents dans le jeu données ?

# %% [markdown]
# 28. Filtre multiconditions. En pandas, utilisez **`&`** et **`|`** pour respectivement réaliser des conjonctions (**`and`**) et disjonctions (**`or`**). L'utilisation de parenthèses est nécessaire pour encadrer chaque condition.
#
# Afficher la liste des films de genre `Crime` et de moins de 2h.

# %% [markdown]
# 29. Afficher la liste des films de genre Crime et Drama de plus de 3h.
