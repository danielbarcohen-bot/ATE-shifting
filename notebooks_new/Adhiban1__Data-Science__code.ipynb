# %%
import pandas as pd

# %%
df = pd.read_csv(r'12000 Data Science Jobs in India - Naukri.com\naukri_data_science_jobs_india.csv')
df.head()
# Out:
#                                             Job_Role            Company  \
# 0                              Senior Data Scientist                UPL
# 1                              Senior Data Scientist            Walmart
# 2  Applied Data Scientist / ML Senior Engineer (P...  SAP India Pvt.Ltd
# 3                                     Data Scientist                UPL
# 4                                     Data Scientist            Walmart
#
#                                   Location Job Experience  \
# 0  Bangalore/Bengaluru, Mumbai (All Areas)            3-6
# 1                      Bangalore/Bengaluru            5-9
# 2                      Bangalore/Bengaluru           5-10
# 3  Bangalore/Bengaluru, Mumbai (All Areas)            1-4
# 4                      Bangalore/Bengaluru            4-8
#
#                                   Skills/Description
# 0  python, MLT, statistical modeling, machine lea...
# 1  Data Science, Machine learning, Python, Azure,...
# ...

# %%
temp = []
for i in df['Skills/Description']:
    temp += i.split(', ')
temp = list(set(temp))
temp
# Out:
# ['Employee engagement',
#  'business Analysis',
#  'Bidding',
#  'Data Science',
#  'Data Warehousing',
#  'Spreadsheets',
#  'Design Patterns',
#  'Image Recognition',
#  'Loan Document',
#  'Telephony support',
#  'cpg',
#  'Apache Qpid',
#  'Business administration',
#  'advanced excel',
#  'Azure Data Lake Store',
#  'Capacity And Availability Management',
#  'Exploratory Testing',
#  'Grafana',
#  'SQL SQL Server',
#  'Visualization Consultant',
#  'root - cause analysis',
#  'Market research',
#  'Ecommerce',
#  'Dbase',
#  'Mba',
#  'pay per click',
#  'Green belt',
#  'Google data studio',
#  'process modeling',
#  'Scripting Languages',
#  'Qualtrics',
#  'Six Sigma Green Belt',
#  'Doctor',
#  'teradata sql',
#  'Six sigma green belt',
#  'STL',
#  'Time Series Analysis',
#  'Scrum Master',
#  'Tera data',
#  'Voice',
#  'Mortgage',
#  'Lambada',
#  'Bank Reconciliation',
#  'ADF',
#  'polls',
#  'Data Recovery',
#  'BE',
#  'Strong Communication Skills',
# ...

# %%
from rich.progress import track

# %%
d = []
for j in track(temp, 'Skill'):
    k = 0
    for i in df['Skills/Description']:
        if  f' {j},' in i:
            k += 1
    d.append([j, k])

df1 = pd.DataFrame(d, columns=['Skill', 'Count'])
# Out:
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>

# %%
df1 = df1.sort_values('Count', ascending=False)

# %%
df1.head()
# Out:
#            Skill  Count
# 2119      Python   2119
# 7351  management   1828
# 3021    analysis   1594
# 8037     science   1478
# 6668   IT Skills   1460

# %%
df1.to_csv('Skill-count.csv', index=False)

# %%
df1.shape
# Out:
# (9044, 2)

# %%
s = 'Skills keywords for Data Science job description:\n' + ', '.join(df1.Skill)
with open('Skills Keywords.txt', 'w') as f:
    f.write(s)

# %%
len(df.Job_Role.unique())
# Out:
# 6563

# %%
df.head()
# Out:
#                                             Job_Role            Company  \
# 0                              Senior Data Scientist                UPL
# 1                              Senior Data Scientist            Walmart
# 2  Applied Data Scientist / ML Senior Engineer (P...  SAP India Pvt.Ltd
# 3                                     Data Scientist                UPL
# 4                                     Data Scientist            Walmart
#
#                                   Location Job Experience  \
# 0  Bangalore/Bengaluru, Mumbai (All Areas)            3-6
# 1                      Bangalore/Bengaluru            5-9
# 2                      Bangalore/Bengaluru           5-10
# 3  Bangalore/Bengaluru, Mumbai (All Areas)            1-4
# 4                      Bangalore/Bengaluru            4-8
#
#                                   Skills/Description
# 0  python, MLT, statistical modeling, machine lea...
# 1  Data Science, Machine learning, Python, Azure,...
# ...

# %%
sheet = []
for i in track(df.Job_Role.unique()):
    a = df[df['Job_Role'] == i]
    temp = []
    for j in a['Skills/Description']:
        temp += j.split(', ')
    temp = list(set(temp))
    temp = ', '.join(temp)
    sheet.append([i, temp])
# Out:
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>

# %%
sheet[0]
# Out:
# ['Senior Data Scientist',
# ...

# %%
df2 = pd.DataFrame(sheet, columns=['Job', 'Skills/Keywords'])
df2.head()
# Out:
#                                                  Job  \
# 0                              Senior Data Scientist
# 1  Applied Data Scientist / ML Senior Engineer (P...
# 2                                     Data Scientist
# 3                           Principal Data Scientist
# 4                              Expert Data Scientist
#
#                                      Skills/Keywords
# 0  Venture capital, statistics, AWS, Tensor Flow,...
# 1  Python, Cloud, SAP, Testing, NLP, Product Mana...
# 2  management, quantitative analysis, Bidding, Da...
# 3  NLU, AWS, NumPy, Data Science, Display adverti...
# 4  MLT, Python, machine learning, team lead, Data...

# %%
df2.shape
# Out:
# (6563, 2)

# %%
df2.to_csv('Jobs_skills_or_keywords.csv', index=False)

# %%
import json

# %%
sheet = {}
for i in track(df.Job_Role.unique()):
    a = df[df['Job_Role'] == i]
    temp = []
    for j in a['Skills/Description']:
        temp += j.split(', ')
    temp = list(set(temp))
    sheet[i] = temp

with open('Jobs_skills_or_keywords.json', 'w') as f:
    json.dump(sheet, f, indent=4)
# Out:
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>

# %%
s = ''
for i,(j,k) in enumerate(sheet.items()):
    s += f'''{i+1}. {j}:
{', '.join(k)}

'''

with open('Jobs-Skills.txt', 'w') as f:
    f.write(s)

# %%
df.head()
# Out:
#                                             Job_Role            Company  \
# 0                              Senior Data Scientist                UPL
# 1                              Senior Data Scientist            Walmart
# 2  Applied Data Scientist / ML Senior Engineer (P...  SAP India Pvt.Ltd
# 3                                     Data Scientist                UPL
# 4                                     Data Scientist            Walmart
#
#                                   Location Job Experience  \
# 0  Bangalore/Bengaluru, Mumbai (All Areas)            3-6
# 1                      Bangalore/Bengaluru            5-9
# 2                      Bangalore/Bengaluru           5-10
# 3  Bangalore/Bengaluru, Mumbai (All Areas)            1-4
# 4                      Bangalore/Bengaluru            4-8
#
#                                   Skills/Description
# 0  python, MLT, statistical modeling, machine lea...
# 1  Data Science, Machine learning, Python, Azure,...
# ...

# %%
import re

# %%
re.findall('[A-Za-z]+', "Bangalore/Bengaluru, Mumbai (All Areas)")
# Out:
# ['Bangalore', 'Bengaluru', 'Mumbai', 'All', 'Areas']

# %%
temp = []
for i in df.Location.unique():
    if 'Bengaluru' in i:
        i = i.replace('Bengaluru', 'Bangalore')
    temp += re.findall('[A-Za-z]+', i)
temp1 = list(set(temp))
sheet1 = []
for i in temp1:
    k = 0
    for j in temp:
        if j == i:
            k += 1
    sheet1.append([i, k])
df3 = pd.DataFrame(sheet1, columns=['Location', 'Count']).sort_values('Count', ascending=False)
df3.head(10)
# Out:
#          Location  Count
# 231     Bangalore    686
# 268        Mumbai    290
# 179          Pune    252
# 183     Hyderabad    228
# 55   Secunderabad    208
# 324         Delhi    197
# 224       Chennai    196
# 272           NCR    141
# 185       Gurgaon    134
# 163      Gurugram    121

# %%
df3.to_csv('Location-count.csv', index=False)

# %%
temp = []
for i in df.Location.unique():
    temp += i.split(', ')
temp1 = list(set(temp))
sheet2 = []
for i in temp1:
    sheet2.append([i, temp.count(i)])
df4 = pd.DataFrame(sheet2, columns=['Locations', 'Count']).sort_values('Count', ascending=False)
df4.head()
# Out:
#                   Locations  Count
# 119     Bangalore/Bengaluru    291
# 152                    Pune    237
# 307  Hyderabad/Secunderabad    197
# 199                 Chennai    187
# 248                  Mumbai    149

# %%
df4.to_csv('Location-count(1).csv', index=False)

# %%
df.head()
# Out:
#                                             Job_Role            Company  \
# 0                              Senior Data Scientist                UPL
# 1                              Senior Data Scientist            Walmart
# 2  Applied Data Scientist / ML Senior Engineer (P...  SAP India Pvt.Ltd
# 3                                     Data Scientist                UPL
# 4                                     Data Scientist            Walmart
#
#                                   Location Job Experience  \
# 0  Bangalore/Bengaluru, Mumbai (All Areas)            3-6
# 1                      Bangalore/Bengaluru            5-9
# 2                      Bangalore/Bengaluru           5-10
# 3  Bangalore/Bengaluru, Mumbai (All Areas)            1-4
# 4                      Bangalore/Bengaluru            4-8
#
#                                   Skills/Description
# 0  python, MLT, statistical modeling, machine lea...
# 1  Data Science, Machine learning, Python, Azure,...
# ...

# %%
d1 = {}
for i in df4.Locations:
    temp = []
    for j in df.values:
        if f'{i},' in j[2] or f', {i}' in j[2]:
            temp.append(j[0])
    d1[i] = temp
with open('Location-jobs.json', 'w') as f:
    json.dump(d1, f, indent=4)

# %%
sheet3 = []
for i,j in d1.items():
    sheet3.append([i, len(j)])

df5 = pd.DataFrame(sheet3, columns=['Location', 'Number of Jobs']).sort_values('Number of Jobs', ascending=False)
df5.head()
# Out:
#                   Location  Number of Jobs
# 0      Bangalore/Bengaluru            1302
# 87               Bangalore            1225
# 1                     Pune             830
# 2   Hyderabad/Secunderabad             797
# 3                  Chennai             630

# %%
df5.to_csv('Location - Number of Jobs.csv', index=False)

# %%
df.head()
# Out:
#                                             Job_Role            Company  \
# 0                              Senior Data Scientist                UPL
# 1                              Senior Data Scientist            Walmart
# 2  Applied Data Scientist / ML Senior Engineer (P...  SAP India Pvt.Ltd
# 3                                     Data Scientist                UPL
# 4                                     Data Scientist            Walmart
#
#                                   Location Job Experience  \
# 0  Bangalore/Bengaluru, Mumbai (All Areas)            3-6
# 1                      Bangalore/Bengaluru            5-9
# 2                      Bangalore/Bengaluru           5-10
# 3  Bangalore/Bengaluru, Mumbai (All Areas)            1-4
# 4                      Bangalore/Bengaluru            4-8
#
#                                   Skills/Description
# 0  python, MLT, statistical modeling, machine lea...
# 1  Data Science, Machine learning, Python, Azure,...
# ...

# %%
temp3 = []
for i in df['Job Experience']:
    if re.findall('[A-Za-z]', i):
        temp3.append(False)
    else:
        temp3.append(True)
df6 = df[temp3]
df6.head()
# Out:
#                                             Job_Role            Company  \
# 0                              Senior Data Scientist                UPL
# 1                              Senior Data Scientist            Walmart
# 2  Applied Data Scientist / ML Senior Engineer (P...  SAP India Pvt.Ltd
# 3                                     Data Scientist                UPL
# 4                                     Data Scientist            Walmart
#
#                                   Location Job Experience  \
# 0  Bangalore/Bengaluru, Mumbai (All Areas)            3-6
# 1                      Bangalore/Bengaluru            5-9
# 2                      Bangalore/Bengaluru           5-10
# 3  Bangalore/Bengaluru, Mumbai (All Areas)            1-4
# 4                      Bangalore/Bengaluru            4-8
#
#                                   Skills/Description
# 0  python, MLT, statistical modeling, machine lea...
# 1  Data Science, Machine learning, Python, Azure,...
# ...

# %%
for i in df6['Job Experience'].unique():
    print(re.findall('[\d]+', i))
# Out:
# ['3', '6']
# ['5', '9']
# ['5', '10']
# ['1', '4']
# ['4', '8']
# ['7', '12']
# ['6', '9']
# ['10', '20']
# ['2', '7']
# ['2', '4']
# ['8', '12']
# ['5', '7']
# ['3', '5']
# ['1', '6']
# ['2', '3']
# ['4', '6']
# ['2', '6']
# ['5', '8']
# ['0', '3']
# ['7', '11']
# ['3', '7']
# ['8', '13']
# ['3', '8']
# ['6', '8']
# ['12', '16']
# ['2', '5']
# ['1', '2']
# ['4', '9']
# ['0', '1']
# ['10', '15']
# ['10', '12']
# ['7', '10']
# ['6', '11']
# ['1', '5']
# ['13', '20']
# ['4', '7']
# ['0', '4']
# ['8', '11']
# ['10', '18']
# ['10', '14']
# ['1', '3']
# ['3', '10']
# ['6', '10']
# ['12', '17']
# ['6', '12']
# ['9', '12']
# ['8', '10']
# ['5', '6']
# ['8', '14']
# ['6', '7']
# ['0', '2']
# ['0', '5']
# ['10', '17']
# ['15', '18']
# ['12', '15']
# ['7', '9']
# ['11', '15']
# ['3', '4']
# ['2', '8']
# ['3', '9']
# ['12', '18']
# ['4', '10']
# ['12', '22']
# ['15', '17']
# ['4', '5']
# ['9', '14']
# ['7', '8']
# ['5', '11']
# ['10', '13']
# ['4', '13']
# ['11', '21']
# ['7', '13']
# ...

# %%
sheet4 = []
for i in df6['Job Experience']:
    sheet4.append(re.findall('[\d]+', i))
df6[['Min Experience', 'Max Experience']] = pd.DataFrame(sheet4).astype(int)
df6.head()
# Out:
# C:\Users\ADHIBAN SIDDHARTH V\AppData\Local\Temp\ipykernel_6108\2642080316.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df6[['Min Experience', 'Max Experience']] = pd.DataFrame(sheet4).astype(int)
# C:\Users\ADHIBAN SIDDHARTH V\AppData\Local\Temp\ipykernel_6108\2642080316.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df6[['Min Experience', 'Max Experience']] = pd.DataFrame(sheet4).astype(int)
#                                             Job_Role            Company  \
# ...

# %%
df6 = df6.drop('Job Experience', axis=1)
df6.head()
# Out:
#                                             Job_Role            Company  \
# 0                              Senior Data Scientist                UPL
# 1                              Senior Data Scientist            Walmart
# 2  Applied Data Scientist / ML Senior Engineer (P...  SAP India Pvt.Ltd
# 3                                     Data Scientist                UPL
# 4                                     Data Scientist            Walmart
#
#                                   Location  \
# 0  Bangalore/Bengaluru, Mumbai (All Areas)
# 1                      Bangalore/Bengaluru
# 2                      Bangalore/Bengaluru
# 3  Bangalore/Bengaluru, Mumbai (All Areas)
# 4                      Bangalore/Bengaluru
#
#                                   Skills/Description  Min Experience  \
# 0  python, MLT, statistical modeling, machine lea...             3.0
# 1  Data Science, Machine learning, Python, Azure,...             5.0
# ...

# %%
df6.to_csv('cleaned_data.csv', index=False)

# %%
df6.shape
# Out:
# (11993, 6)

# %%
df7 = df6.loc[df6['Min Experience'] == 0]
df7.head()
# Out:
#                                               Job_Role  \
# 25    Junior Data Analyst/ Scientist- Fresher Position
# 50                  Freshers For Junior Data Scientist
# 120     Data Scientist - Experienced/fresher | Kolkata
# 127  Data Scientist/ Machine Learning, 2022 Passout...
# 184                                     Data Scientist
#
#                                              Company  \
# 25                              Sejal Consulting Hub
# 50       Aaum Research and Analytics Private Limited
# 120  SIBIA Analytics and Consulting Services Pvt Ltd
# 127                    Creative Hands HR Consultancy
# 184                  Foxberry Technologies Pvt. Ltd.
#
#                                               Location  \
# 25                                              Remote
# 50                                             Chennai
# 120                                            Kolkata
# 127  Hyderabad/Secunderabad, Pune, Ahmedabad, Chenn...
# ...

# %%
temp4 = []
for i in df7.Job_Role:
    i = i.lower()
    if 'data' in i or 'scien' in i:
        temp4.append(True)
    else:
        temp4.append(False)
df7 = df7[temp4]

# %%
df7.head()
# Out:
#                                               Job_Role  \
# 25    Junior Data Analyst/ Scientist- Fresher Position
# 50                  Freshers For Junior Data Scientist
# 120     Data Scientist - Experienced/fresher | Kolkata
# 127  Data Scientist/ Machine Learning, 2022 Passout...
# 184                                     Data Scientist
#
#                                              Company  \
# 25                              Sejal Consulting Hub
# 50       Aaum Research and Analytics Private Limited
# 120  SIBIA Analytics and Consulting Services Pvt Ltd
# 127                    Creative Hands HR Consultancy
# 184                  Foxberry Technologies Pvt. Ltd.
#
#                                               Location  \
# 25                                              Remote
# 50                                             Chennai
# 120                                            Kolkata
# 127  Hyderabad/Secunderabad, Pune, Ahmedabad, Chenn...
# ...

# %%
df7.shape
# Out:
# (199, 6)

# %%
df7.Location.unique()
# Out:
# array(['Remote', 'Chennai', 'Kolkata',
#        'Hyderabad/Secunderabad, Pune, Ahmedabad, Chennai, Bangalore/Bengaluru, Vadodara',
#        'Pune', 'Bangalore/Bengaluru', 'Pune(Kalyani Nagar)',
#        'Hyderabad/Secunderabad', 'Vadodara',
#        'Pune, Bangalore/Bengaluru, Mumbai (All Areas)', 'Mumbai',
#        'Hyderabad/Secunderabad, Bangalore/Bengaluru, Delhi / NCR',
#        'Pune(Baner)', 'Chennai, Bengaluru', 'Noida',
#        'Mumbai(Sector 30A Vashi)', 'Bengaluru', 'Hyderabad',
#        'Pune(Kharadi)', 'Gurgaon/Gurugram', 'Jaipur',
#        'Mumbai, Pune, Bangalore/Bengaluru',
#        'Kolkata, Mumbai, Hyderabad/Secunderabad, Pune, Chennai, Ahmedabad, Delhi / NCR, Bangalore/Bengaluru',
#        'Kolkata, Mumbai, Visakhapatnam, Hyderabad/Secunderabad, Pune, Chennai, Ahmedabad, Delhi / NCR, Bangalore/Bengaluru',
#        'Gurgaon/Gurugram, Gurgaon', 'Noida, Indore',
#        'Hyderabad/Secunderabad, Chennai, Bangalore/Bengaluru',
# ...

# %%
def search(*args):
    global df7
    k = 0
    for i in df7.Location:
        for j in args:
            if j in i.lower():
                k += 1
    return k

# %%
search('bangalore', 'chennai')
# Out:
# 99

# %%
temp5 = []
for i in df7.Location:
    i = i.lower()
    if 'bangalore' in i or 'chennai' in i:
        temp5.append(True)
    else:
        temp5.append(False)
df7 = df7[temp5]

# %%
df7.shape
# Out:
# (91, 6)

# %%
df7.head()
# Out:
#                                               Job_Role  \
# 50                  Freshers For Junior Data Scientist
# 127  Data Scientist/ Machine Learning, 2022 Passout...
# 207                                     Data Scientist
# 208                 Intern - Data Scientist/Programmer
# 311                                     data scientist
#
#                                          Company  \
# 50   Aaum Research and Analytics Private Limited
# 127                Creative Hands HR Consultancy
# 207                            Applied Materials
# 208                           The millionvisions
# 311                           Global Talent Pool
#
#                                               Location  \
# 50                                             Chennai
# 127  Hyderabad/Secunderabad, Pune, Ahmedabad, Chenn...
# 207                                Bangalore/Bengaluru
# 208                                Bangalore/Bengaluru
# ...

# %%
temp6 = []

for i in df7['Skills/Description'].unique():
    temp6 += i.split(', ')
temp7 = list(set(temp6))
sheet5 = []
for i in temp7:
    k = 0
    for j in df7['Skills/Description']:
        if i in j:
            k += 1
    sheet5.append([i, k])
df8 = pd.DataFrame(sheet5, columns=['Keywords', 'Count']).sort_values('Count', ascending=False)
df8.head()
# Out:
#       Keywords  Count
# 13         SQL     29
# 256     Python     29
# 315  IT Skills     25
# 373          R     21
# 14    Big Data     17

# %%
df8.shape
# Out:
# (374, 2)

# %%
df8.to_csv('Skills keywords in chennai and Bangalore.csv', index=False)

# %%
', '.join(df8.Keywords.tolist())
# Out:
# 'SQL, Python, IT Skills, R, Big Data, Java, management, Cloud, Management, Data Science, Computer science, communication, Unix, Analytical, Analytics, AWS, Data management, Spark, Coding, Data analysis, Excel, Machine Learning, data science, Azure, Healthcare, DevOps, Data Analysis, Business intelligence, Data Analyst, Troubleshooting, Agile, Artificial Intelligence, Consulting, spark, SAP, Operations, Data Management, Testing, Machine learning, Project Management, python, Oracle, VBA, analytical, Statistics, excel, Kafka, Data mining, pyspark, MongoDB, EMR, Teradata, Research, Apache, Data Analytics, Hive, Programming, Advanced Excel, CRO, Informatica, Performance tuning, Project management, NoSQL, Git, ETL, MapR, Research Analyst, big data, Commerce, No - SQL, Business process, C++, Data modeling, data cleansing, Data Engineer, Product Management, BI, S3, Scala, Monitoring, written communication, Interpersonal skills, Apache Spark, tableau, sql, Bigdata, data analysis, MySQL, Data 
# ...
