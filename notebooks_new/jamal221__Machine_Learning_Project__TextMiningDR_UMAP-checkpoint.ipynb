# %%
import pandas as pd

# %%
data = pd.read_csv('D:\project\dataset\CSV_Files\Persian_Text.csv')
data.head()
# Out:
#    NewsID                                              Title  \
# 0  843656  \nوزير علوم درجمع استادان نمونه: سن بازنشستگي ...
# 1  837144  \nگردهمايي دانش‌آموختگان موسسه آموزش عالي سوره...
# 2  436862  \nنتايج آزمون دوره‌هاي فراگير دانشگاه پيام‌نور...
# 3  227781  \nهمايش يكروزه آسيب شناسي مفهوم روابط عمومي در...
# 4  174187  \nوضعيت اقتصادي و ميزان تحصيلات والدين از مهمت...
#
#                                                 Body         Date       Time  \
# 0  \nوزير علوم در جمع استادان نمونه كشور گفت: از ...  \n138/5//09  \n0:9::18
# 1  \nبه گزارش سرويس صنفي آموزشي خبرگزاري دانشجويا...  \n138/5//09  \n1:4::11
# 2  \nنتايج آزمون دوره‌هاي فراگير مقاطع كارشناسي و...  \n138/3//07  \n1:0::03
# 3                                                 \n  \n138/2//02  \n1:3::42
# 4  \nمحمدتقي علوي يزدي، مجري اين طرح پژوهشي در اي...  \n138/1//08  \n1:1::49
#
#              Category  Category2
# 0           \nآموزشي-   \nآموزشي
# 1           \nآموزشي-   \nآموزشي
# 2           \nآموزشي-   \nآموزشي
# 3  \nاجتماعي-خانواده-  \nاجتماعي
# 4           \nآموزشي-   \nآموزشي

# %%
with open('stopwords.txt') as stopwords_file:
    stopwords = stopwords_file.readlines()
stopwords = [line.replace('\n', '') for line in stopwords]
stopwords
# Out:
# ['!',
#  '"',
#  '#',
#  '(',
#  ')',
#  '*',
#  ',',
#  '-',
#  '.',
#  '/',
#  ':',
#  '[',
#  ']',
#  'آ«',
#  'آ»',
#  'طŒ',
#  'ط›',
#  'طں',
#  'ط¢ط¨ط§ط¯',
#  'ط¢ط®',
#  'ط¢ط®ط±',
#  'ط¢ط®ط±ظ‡ط§',
#  'ط¢ط®ظ‡',
#  'ط¢ط¯ظ…ظ‡ط§ط³طھ',
#  'ط¢ط±ط§ظ…',
#  'ط¢ط±ط§ظ… ط¢ط±ط§ظ…',
#  'ط¢ط±ظ‡',
#  'ط¢ط±غŒ',
#  'ط¢ط²ط§ط¯ط§ظ†ظ‡',
#  'ط¢ط³ط§ظ†',
#  'ط¢ط³غŒط¨ ظ¾ط°غŒط±ظ†ط¯',
#  'ط¢ط´ظ†ط§غŒظ†ط¯',
#  'ط¢ط´ع©ط§ط±ط§',
#  'ط¢ظ‚ط§',
#  'ط¢ظ‚ط§غŒ',
#  'ط¢ظ‚ط§غŒط§ظ†',
#  'ط¢ظ…ط¯',
#  'ط¢ظ…ط¯ظ†',
#  'ط¢ظ…ط¯ظ‡',
#  'ط¢ظ…ط±ط§ظ†ظ‡',
#  'ط¢ظ†',
#  'ط¢ظ† ع¯ط§ظ‡',
#  'ط¢ظ†ط§ظ†',
#  'ط¢ظ†ط§ظ†غŒ',
#  'ط¢ظ†ط¬ط§',
#  'ط¢ظ†ط±ط§',
#  'ط¢ظ†ط·ظˆط±',
#  'ط¢ظ†ظ‚ط¯ط±',
#  'ط¢ظ†ظ‡ط§',
#  'ط¢ظ†ظ‡ط§ط³طھ',
#  'ط¢ظ†ع†ظ†ط§ظ†',
#  'ط¢ظ†ع†ظ†ط§ظ† ع©ظ‡',
#  'ط¢ظ†ع†ظ‡',
#  'ط¢ظ†ع©ظ‡',
#  'ط¢ظ†ع¯ط§ظ‡',
#  'ط¢ظ†â€Œظ‡ط§',
#  'ط¢ظ‡ط§ظ†',
#  'ط¢ظ‡ط§غŒ',
#  'ط¢ظˆط±',
#  'ط¢ظˆط±ط¯',
#  'ط¢ظˆط±ط¯ظ†',
#  'ط¢ظˆط±ط¯ظ‡',
#  'ط¢ظˆظ‡',
#  'ط¢غŒ',
#  'ط¢غŒط§',
#  'ط¢غŒط¯',
#  'ط¢غŒظ†ط¯',
#  'ط§',
#  'ط§طھظپط§ظ‚ط§',
#  'ط§ط«ط±ظگ',
#  'ط§ط¬ط±ط§ط³طھ',
#  'ط§ط\xadطھط±ط§ظ…ط§',
#  'ط§ط\xadطھظ…ط§ظ„ط§',
#  'ط§ط\xadغŒط§ظ†ط§ظ‹',
#  'ط§ط®غŒط±',
#  'ط§ط®غŒط±ط§ظ‹',
#  'ط§ط±غŒ',
#  'ط§ط²',
#  'ط§ط² ط¢ظ† ظ¾ط³',
#  'ط§ط² ط¬ظ…ظ„ظ‡',
#  'ط§ط²ط§غŒظ† ط±ظˆ',
#  'ط§ط²ط¬ظ…ظ„ظ‡',
#  'ط§ط²ط´',
#  'ط§ط³ط§ط³ط§',
#  'ط§ط³ط§ط³ط§ظ‹',
#  'ط§ط³طھ',
#  'ط§ط³طھظپط§ط¯',
#  'ط§ط³طھظپط§ط¯ظ‡',
#  'ط§ط³ظ„ط§ظ…غŒ ط§ظ†ط¯',
#  'ط§ط´',
#  'ط§ط´طھط¨ط§ظ‡ط§',
#  'ط§ط´ع©ط§ط±ط§',
#  'ط§طµظ„ط§',
#  'ط§طµظ„ط§ظ‹',
#  'ط§طµظˆظ„ط§',
#  'ط§طµظˆظ„ط§ظ‹',
#  'ط§ط¹ظ„ط§ظ…',
#  'ط§ط؛ظ„ط¨',
#  'ط§ظپط²ظˆط¯',
#  'ط§ظپط³ظˆط³',
#  'ط§ظ‚ظ„',
#  'ط§ظ‚ظ„غŒطھ',
#  'ط§ظ„ط§',
#  'ط§ظ„ط§ظ†',
#  'ط§ظ„ط¨طھظ‡',
#  'ط§ظ„ط¨طھظ‘ظ‡',
#  'ط§ظ„ظ‡غŒ',
#  'ط§ظ„غŒ',
#  'ط§ظ…',
#  'ط§ظ…ط§',
#  'ط§ظ…ط±ظˆط²',
#  'ط§ظ…ط±ظˆط²ظ‡',
#  'ط§ظ…ط³ط§ظ„',
#  'ط§ظ…ط´ط¨',
#  'ط§ظ…ظˆط±',
#  'ط§ظ…غŒط¯ظˆط§ط±ظ…',
#  'ط§ظ…غŒط¯ظˆط§ط±ظ†ط¯',
#  'ط§ظ…غŒط¯ظˆط§ط±غŒظ…',
#  'ط§ظ†',
#  'ط§ظ† ط´ط§ط£ط§ظ„ظ„ظ‡',
#  'ط§ظ†طھظ‡ط§',
#  'ط§ظ†ط¬ط§ظ…',
#  'ط§ظ†ط¯',
#  'ط§ظ†ط¯ع©غŒ',
#  'ط§ظ†ط´ط§ط§ظ„ظ„ظ‡',
#  'ط§ظ†طµط§ظپط§',
#  'ط§ظ†ط·ظˆط±',
#  'ط§ظ†ظ‚ط¯ط±',
#  'ط§ظ†ظ‡ط§',
#  'ط§ظ†ع†ظ†ط§ظ†',
#  'ط§ظ†ع©ظ‡',
#  'ط§ظ†ع¯ط§ط±',
#  'ط§ظˆ',
#  'ط§ظˆط³طھ',
#  'ط§ظˆظ„',
#  'ط§ظˆظ„ط§',
#  'ط§ظˆظ„ط§ظ‹',
#  'ط§ظˆظ„غŒظ†',
#  'ط§ظˆظ†',
#  'ط§ع©ط«ط±',
#  'ط§ع©ط«ط±ط§',
#  'ط§ع©ط«ط±ط§ظ‹',
#  'ط§ع©ط«ط±غŒطھ',
#  'ط§ع©ظ†ظˆظ†',
#  'ط§ع¯ط±',
#  'ط§ع¯ط± ع†ظ‡',
#  'ط§ع¯ط±ع†ظ‡',
#  'ط§ع¯ظ‡',
#  'ط§غŒ',
#  'ط§غŒط§',
#  'ط§غŒط¯',
#  'ط§غŒط´ط§ظ†',
#  'ط§غŒظ…',
#  'ط§غŒظ†',
#  'ط§غŒظ† ط¬ظˆط±غŒ',
#  'ط§غŒظ† ظ‚ط¯ط±',
#  'ط§غŒظ† ع¯ظˆظ†ظ‡',
#  'ط§غŒظ†ط§ظ†',
#  'ط§غŒظ†ط¬ط§',
#  'ط§غŒظ†ط¬ط§ط³طھ',
#  'ط§غŒظ†ط¯',
#  'ط§غŒظ†ط·ظˆط±',
#  'ط§غŒظ†ظ‚ط¯ط±',
#  'ط§غŒظ†ظ‡ط§',
#  'ط§غŒظ†ظ‡ط§ط³طھ',
#  'ط§غŒظ†ظˆ',
#  'ط§غŒظ†ع†ظ†غŒظ†',
#  'ط§غŒظ†ع©',
#  'ط§غŒظ†ع©ظ‡',
#  'ط§غŒظ†ع¯ظˆظ†ظ‡',
#  'ط¨ ',
#  'ط¨ط§',
#  'ط¨ط§ط§غŒظ† ط\xadط§ظ„',
#  'ط¨ط§ط§غŒظ† ظˆط¬ظˆط¯',
#  'ط¨ط§ط¯',
#  'ط¨ط§ط±',
#  'ط¨ط§ط±ط©',
#  'ط¨ط§ط±ظ‡',
#  'ط¨ط§ط±ظ‡ط§',
#  'ط¨ط§ط²',
#  'ط¨ط§ط² ظ‡ظ…',
#  'ط¨ط§ط²ظ‡ظ…',
#  'ط¨ط§ط²غŒ ع©ظ†ط§ظ†',
#  'ط¨ط§ط²غŒع¯ظˆط´ط§ظ†ظ‡',
#  'ط¨ط§ط´',
#  'ط¨ط§ط´ط¯',
#  'ط¨ط§ط´ظ…',
#  'ط¨ط§ط´ظ†ط¯',
#  'ط¨ط§ط´غŒ',
#  'ط¨ط§ط´غŒط¯',
#  'ط¨ط§ط´غŒظ…',
#  'ط¨ط§ظ„ط§',
#  'ط¨ط§ظ„ط§ط®ط±ظ‡',
#  'ط¨ط§ظ„ط§ط®طµ',
#  'ط¨ط§ظ„ط§ط³طھ',
#  'ط¨ط§ظ„ط§غŒ',
#  'ط¨ط§ظ„ط§غŒظگ',
#  'ط¨ط§ظ„ط·ط¨ط¹',
#  'ط¨ط§ظ„ط¹ع©ط³',
#  'ط¨ط§ظˆط¬ظˆط¯غŒ ع©ظ‡',
#  'ط¨ط§ظˆط±ظ†ط¯',
#  'ط¨ط§غŒط¯',
#  'ط¨طھط¯ط±غŒط¬',
#  'ط¨طھظˆط§ظ†',
#  'ط¨طھظˆط§ظ†ط¯',
#  'ط¨طھظˆط§ظ†غŒ',
#  'ط¨طھظˆط§ظ†غŒظ…',
#  'ط¨ط¬ط²',
#  'ط¨ط®ط´',
#  'ط¨ط®ط´ظ‡',
#  'ط¨ط®ط´غŒ',
#  'ط¨ط®طµظˆطµ',
#  'ط¨ط®ظˆط§ظ‡',
#  'ط¨ط®ظˆط§ظ‡ط¯',
#  'ط¨ط®ظˆط§ظ‡ظ…',
#  'ط¨ط®ظˆط§ظ‡ظ†ط¯',
#  'ط¨ط®ظˆط§ظ‡غŒ',
#  'ط¨ط®ظˆط§ظ‡غŒط¯',
#  'ط¨ط®ظˆط§ظ‡غŒظ…',
#  'ط¨ط®ظˆط¨غŒ',
#  'ط¨ط¯',
#  'ط¨ط¯ط§ظ†',
#  'ط¨ط¯ط§ظ†ط¬ط§',
#  'ط¨ط¯ط§ظ†ظ‡ط§',
#  'ط¨ط¯ظ‡غŒط¯',
#  'ط¨ط¯ظˆظ†',
#  'ط¨ط¯غŒظ†',
#  'ط¨ط¯غŒظ† طھط±طھغŒط¨',
#  'ط¨ط¯غŒظ†ط¬ط§',
#  'ط¨ط±',
#  'ط¨ط±ط¢ظ†ظ†ط¯',
#  'ط¨ط±ط§',
#  'ط¨ط±ط§ط¨ط±',
#  'ط¨ط±ط§ط¨ط±ظگ',
#  'ط¨ط±ط§ط\xadطھغŒ',
#  'ط¨ط±ط§ط³ط§ط³',
#  'ط¨ط±ط§ط³طھغŒ',
#  'ط¨ط±ط§غŒ',
#  'ط¨ط±ط§غŒطھ',
#  'ط¨ط±ط§غŒط´',
#  'ط¨ط±ط§غŒط´ط§ظ†',
#  'ط¨ط±ط§غŒظ…',
#  'ط¨ط±ط§غŒظ…ط§ظ†',
#  'ط¨ط±ط§غŒظگ',
#  'ط¨ط±ط®ظˆط±ط¯ط§ط±',
#  'ط¨ط±ط®ظˆط±ط¯ط§ط±ظ†ط¯',
#  'ط¨ط±ط®غŒ',
#  'ط¨ط±ط¯ط§ط±غŒ',
#  'ط¨ط±ط¹ع©ط³',
#  'ط¨ط±ظ†ط§ظ…ظ‡ ط³ط§ط²ظ‡ط§ط³طھ',
#  'ط¨ط±ظˆط²',
#  'ط¨ط±ظˆط´ظ†غŒ',
#  'ط¨ط²ط±ع¯',
#  'ط¨ط²ظˆط¯غŒ',
#  'ط¨ط³',
#  'ط¨ط³ط§',
#  'ط¨ط³ط§ط¯ع¯غŒ',
#  'ط¨ط³ط®طھغŒ',
#  'ط¨ط³ظˆغŒ',
#  'ط¨ط³غŒ',
#  'ط¨ط³غŒط§ط±',
#  'ط¨ط³غŒط§ط±غŒ',
#  'ط¨ط´ط¯طھ',
#  'ط¨ط·ظˆط±',
#  'ط¨ط·ظˆط±غŒ ع©ظ‡',
#  'ط¨ط¹ط¯',
#  'ط¨ط¹ط¯ ط§ط² ط§غŒظ† ع©ظ‡',
#  'ط¨ط¹ط¯ط§',
#  'ط¨ط¹ط¯ط§ط²ط¸ظ‡ط±',
#  'ط¨ط¹ط¯ط§ظ‹',
#  'ط¨ط¹ط¯ظ‡ط§',
#  'ط¨ط¹ط±غŒ',
#  'ط¨ط¹ط¶ط§',
#  'ط¨ط¹ط¶غŒ',
#  'ط¨ط¹ط¶غŒ ط´ط§ظ†',
#  'ط¨ط¹ط¶غŒظ‡ط§غŒط´ط§ظ†',
#  'ط¨ط¹ط¶غŒâ€Œظ‡ط§',
#  'ط¨ط¹ظ„ط§ظˆظ‡',
#  'ط¨ط¹غŒط¯',
#  'ط¨ظپظ‡ظ…غŒ ظ†ظپظ‡ظ…غŒ',
#  'ط¨ظ„ط§ظپط§طµظ„ظ‡',
#  'ط¨ظ„ظ‡',
#  'ط¨ظ„ع©ظ‡',
#  'ط¨ظ„غŒ',
#  'ط¨ظ…ط§ظ†ط¯',
#  'ط¨ظ†ط§ط¨ط±ط§غŒظ†',
#  'ط¨ظ†ط¯غŒ',
#  'ط¨ظ‡',
#  'ط¨ظ‡ ط¢ط³ط§ظ†غŒ',
#  'ط¨ظ‡ طھط§ط²ع¯غŒ',
#  'ط¨ظ‡ طھط¯ط±غŒط¬',
#  'ط¨ظ‡ طھظ…ط§ظ…غŒ',
#  'ط¨ظ‡ ط¬ط§غŒ',
#  'ط¨ظ‡ ط¬ط²',
#  'ط¨ظ‡ ط®ظˆط¨غŒ',
#  'ط¨ظ‡ ط¯ط±ط´طھغŒ',
#  'ط¨ظ‡ ط¯ظ„ط®ظˆط§ظ‡',
#  'ط¨ظ‡ ط±ط§ط³طھغŒ',
#  'ط¨ظ‡ ط±ط؛ظ…',
#  'ط¨ظ‡ ط±ظˆط´ظ†غŒ',
#  'ط¨ظ‡ ط²ظˆط¯غŒ',
#  'ط¨ظ‡ ط³ط§ط¯ع¯غŒ',
#  'ط¨ظ‡ ط³ط±ط¹طھ',
#  'ط¨ظ‡ ط´ط§ظ†',
#  'ط¨ظ‡ ط´ط¯طھ',
#  'ط¨ظ‡ ط·ظˆط± ع©ظ„غŒ',
#  'ط¨ظ‡ ط·ظˆط±غŒ ع©ظ‡',
#  'ط¨ظ‡ ط¹ظ„ط§ظˆظ‡',
#  'ط¨ظ‡ ظ‚ط¯ط±غŒ',
#  'ط¨ظ‡ ظ…ط±ط§طھط¨',
#  'ط¨ظ‡ ظ†ط§ع†ط§ط±',
#  'ط¨ظ‡ ظ‡ط±ط\xadط§ظ„',
#  'ط¨ظ‡ ظ‡غŒع† ظˆط¬ظ‡',
#  'ط¨ظ‡ ظˆط¶ظˆط\xad',
#  'ط¨ظ‡ ظˆغŒعکظ‡',
#  'ط¨ظ‡ ع©ط±ط§طھ',
#  'ط¨ظ‡ ع¯ط±ظ…غŒ',
#  'ط¨ظ‡طھ',
#  'ط¨ظ‡طھط±',
#  'ط¨ظ‡طھط±غŒظ†',
#  'ط¨ظ‡ط´',
#  'ط¨ظˆط¯',
#  'ط¨ظˆط¯ظ…',
#  'ط¨ظˆط¯ظ†',
#  'ط¨ظˆط¯ظ†ط¯',
#  'ط¨ظˆط¯ظ‡',
#  'ط¨ظˆط¯غŒ',
#  'ط¨ظˆط¯غŒط¯',
#  'ط¨ظˆط¯غŒظ…',
#  'ط¨ظˆغŒعکظ‡',
#  'ط¨ظ¾ط§',
#  'ط¨ع©ط§ط±',
#  'ط¨ع©ظ†',
#  'ط¨ع©ظ†ط¯',
#  'ط¨ع©ظ†ظ…',
#  'ط¨ع©ظ†ظ†ط¯',
#  'ط¨ع©ظ†غŒ',
#  'ط¨ع©ظ†غŒط¯',
#  'ط¨ع©ظ†غŒظ…',
#  'ط¨ع¯ط°ط§ط±غŒظ…',
#  'ط¨ع¯ظˆ',
#  'ط¨ع¯ظˆغŒط¯',
#  'ط¨ع¯ظˆغŒظ…',
#  'ط¨ع¯ظˆغŒظ†ط¯',
#  'ط¨ع¯ظˆغŒغŒ',
#  'ط¨ع¯ظˆغŒغŒط¯',
#  'ط¨ع¯ظˆغŒغŒظ…',
#  'ط¨ع¯غŒط±',
#  'ط¨ع¯غŒط±ط¯',
#  'ط¨ع¯غŒط±ظ…',
#  'ط¨ع¯غŒط±ظ†ط¯',
#  'ط¨ع¯غŒط±غŒ',
#  'ط¨ع¯غŒط±غŒط¯',
#  'ط¨ع¯غŒط±غŒظ…',
#  'ط¨غŒ',
#  'ط¨غŒ ط¢ظ†ع©ظ‡',
#  'ط¨غŒ ط§ط·ظ„ط§ط¹ظ†ط¯',
#  'ط¨غŒ طھط±ط¯غŒط¯',
#  'ط¨غŒ طھظپط§ظˆطھظ†ط¯',
#  'ط¨غŒ ظ†غŒط§ط²ظ…ظ†ط¯ط§ظ†ظ‡',
#  'ط¨غŒ ظ‡ط¯ظپ',
#  'ط¨غŒط§',
#  'ط¨غŒط§ط¨',
#  'ط¨غŒط§ط¨ط¯',
#  'ط¨غŒط§ط¨ظ…',
#  'ط¨غŒط§ط¨ظ†ط¯',
#  'ط¨غŒط§ط¨غŒ',
#  'ط¨غŒط§ط¨غŒط¯',
#  'ط¨غŒط§ط¨غŒظ…',
#  'ط¨غŒط§ظˆط±',
#  'ط¨غŒط§ظˆط±ط¯',
#  'ط¨غŒط§ظˆط±ظ…',
#  'ط¨غŒط§ظˆط±ظ†ط¯',
#  'ط¨غŒط§ظˆط±غŒ',
#  'ط¨غŒط§ظˆط±غŒط¯',
#  'ط¨غŒط§ظˆط±غŒظ…',
#  'ط¨غŒط§غŒط¯',
#  'ط¨غŒط§غŒظ…',
#  'ط¨غŒط§غŒظ†ط¯',
#  'ط¨غŒط§غŒغŒ',
#  'ط¨غŒط§غŒغŒط¯',
#  'ط¨غŒط§غŒغŒظ…',
#  'ط¨غŒط±ظˆظ†',
#  'ط¨غŒط±ظˆظ†ظگ',
#  'ط¨غŒط³طھ',
#  'ط¨غŒط´',
#  'ط¨غŒط´طھط±',
#  'ط¨غŒط´طھط±غŒ',
#  'ط¨غŒظ†',
#  'ط¨غŒع¯ظ…ط§ظ†',
#  'طھ',
#  'طھط§',
#  'طھط§ط²ظ‡',
#  'طھط§ظ†',
#  'طھط§ع©ظ†ظˆظ†',
#  'طھط\xadطھ',
#  'طھط\xadط±غŒظ… ظ‡ط§ط³طھ',
#  'طھط±',
#  'طھط± ط¨ط±ط§ط³ط§ط³',
#  'طھط±غŒظ„غŒط§ط±ط¯',
#  'طھط±غŒظ„غŒظˆظ†',
#  'طھط±غŒظ†',
#  'طھطµط±غŒط\xadط§ظ‹',
#  'طھط¹ط¯ط§ط¯غŒ',
#  'طھط¹ظ…ط¯ط§',
#  'طھظ‚ط±غŒط¨ط§',
#  'طھظ‚ط±غŒط¨ط§ظ‹',
#  'طھظ„ظˆغŒط\xadط§',
#  'طھظ„ظˆغŒط\xadط§ظ‹',
#  'طھظ…ط§ظ…',
#  'طھظ…ط§ظ… ظ‚ط¯',
#  'طھظ…ط§ظ…ط§',
#  'طھظ…ط§ظ…ط´ط§ظ†',
#  'طھظ…ط§ظ…غŒ',
#  'طھظ†ط¯ طھظ†ط¯',
#  'طھظ†ظ‡ط§',
#  'طھظˆ',
#  'طھظˆط¤ظ…ط§ظ‹',
#  'طھظˆط§ظ†',
#  'طھظˆط§ظ†ط¯',
#  'طھظˆط§ظ†ط³طھ',
#  'طھظˆط§ظ†ط³طھظ…',
#  'طھظˆط§ظ†ط³طھظ†',
#  'طھظˆط§ظ†ط³طھظ†ط¯',
#  'طھظˆط§ظ†ط³طھظ‡',
#  'طھظˆط§ظ†ط³طھغŒ',
#  'طھظˆط§ظ†ط³طھغŒظ…',
#  'طھظˆط§ظ†ظ…',
#  'طھظˆط§ظ†ظ†ط¯',
#  'طھظˆط§ظ†غŒ',
#  'طھظˆط§ظ†غŒط¯',
#  'طھظˆط§ظ†غŒظ…',
#  'طھظˆط³ط·',
#  'طھظˆظ„ظگ',
#  'طھظˆغŒ',
#  'طھظˆغŒظگ',
#  'طھع© طھع©',
#  'ط«',
#  'ط«ط§ظ„ط«ط§ظ‹',
#  'ط«ط§ظ†غŒط§',
#  'ط«ط§ظ†غŒط§ظ‹',
#  'ط¬',
#  'ط¬ط§',
#  'ط¬ط§غŒ',
#  'ط¬ط§غŒغŒ',
#  'ط¬ط¯ط§',
#  'ط¬ط¯ط§ظ‹',
#  'ط¬ط¯ط§ع¯ط§ظ†ظ‡',
#  'ط¬ط¯غŒط¯',
#  'ط¬ط¯غŒط¯ط§',
#  'ط¬ط±ظ…ط²ط§ط³طھ',
#  'ط¬ط±غŒط§ظ†',
#  'ط¬ط²',
#  'ط¬ظ„ظˆ',
#  'ط¬ظ„ظˆع¯غŒط±غŒ',
#  'ط¬ظ„ظˆغŒ',
#  'ط¬ظ„ظˆغŒظگ',
#  'ط¬ظ…ط¹ ط§ظ†ط¯',
#  'ط¬ظ…ط¹ط§',
#  'ط¬ظ…ط¹غŒ',
#  'ط¬ظ†ط§ط¨ط¹ط§ظ„غŒ',
#  'ط¬ظ†ط§ط\xad',
#  'ط¬ظ†ط³ ط§ظ†ط¯',
#  'ط¬ظ‡طھ',
#  'ط¬ظˆط±',
#  'ط\xad',
#  'ط\xadط§ط´غŒظ‡â€Œط§غŒ',
#  'ط\xadط§ط¶ط±',
#  'ط\xadط§ط¶ط±ظ…',
#  'ط\xadط§ظ„',
#  'ط\xadط§ظ„ط§',
#  'ط\xadط§ع©غŒط³طھ',
#  'ط\xadطھظ…ط§',
#  'ط\xadطھظ…ط§ظ‹',
#  'ط\xadطھغŒ',
#  'ط\xadط¯ط§ظ‚ظ„',
#  'ط\xadط¯ط§ع©ط«ط±',
#  'ط\xadط¯ظˆط¯',
#  'ط\xadط¯ظˆط¯ط§',
#  'ط\xadط¯ظˆط¯ظگ',
#  'ط\xadط³ط§ط¨ع¯ط±ط§ظ†ظ‡',
#  'ط\xadط¶ط±طھط¹ط§ظ„غŒ',
#  'ط\xadظ‚',
#  'ط\xadظ‚غŒط±ط§ظ†ظ‡',
#  'ط\xadظ‚غŒظ‚طھط§',
#  'ط\xadظˆظ„',
#  'ط\xadع©ظ…ط§ظ‹',
#  'ط®',
#  'ط®ط§ط±ط¬ظگ',
#  'ط®ط§ظ„طµط§ظ†ظ‡',
#  'ط®ط¨',
#  'ط®ط¯ط§ط\xadط§ظپط¸',
#  'ط®ط¯ط§ط³طھ',
#  'ط®ط¯ظ…ط§طھ',
#  'ط®ط³طھظ‡â€Œط§غŒ',
#  'ط®طµظˆطµط§',
#  'ط®طµظˆطµط§ظ‹',
#  'ط®ظ„ط§طµظ‡',
#  'ط®ظˆط§ط³طھ',
#  'ط®ظˆط§ط³طھظ…',
#  'ط®ظˆط§ط³طھظ†',
#  'ط®ظˆط§ط³طھظ†ط¯',
#  'ط®ظˆط§ط³طھظ‡',
#  'ط®ظˆط§ط³طھغŒ',
#  'ط®ظˆط§ط³طھغŒط¯',
#  'ط®ظˆط§ط³طھغŒظ…',
#  'ط®ظˆط§ظ‡',
#  'ط®ظˆط§ظ‡ط¯',
#  'ط®ظˆط§ظ‡ظ…',
#  'ط®ظˆط§ظ‡ظ†ط¯',
#  'ط®ظˆط§ظ‡غŒ',
#  'ط®ظˆط§ظ‡غŒط¯',
#  'ط®ظˆط§ظ‡غŒظ…',
#  'ط®ظˆط¨',
#  'ط®ظˆط¯',
#  'ط®ظˆط¯ ط¨ظ‡ ط®ظˆط¯',
#  'ط®ظˆط¯ط¨ظ‡ ط®ظˆط¯غŒ',
#  'ط®ظˆط¯طھ',
#  'ط®ظˆط¯طھط§ظ†',
#  'ط®ظˆط¯طھظˆ',
#  'ط®ظˆط¯ط´',
#  'ط®ظˆط¯ط´ط§ظ†',
#  'ط®ظˆط¯ظ…',
#  'ط®ظˆط¯ظ…ط§ظ†',
#  'ط®ظˆط¯ظ…ظˆ',
#  'ط®ظˆط´',
#  'ط®ظˆط´ط¨ط®طھط§ظ†ظ‡',
#  'ط®ظˆغŒط´',
#  'ط®ظˆغŒط´طھظ†',
#  'ط®ظˆغŒط´طھظ†ظ…',
#  'ط®غŒط§ظ‡',
#  'ط®غŒط±',
#  'ط®غŒط±ظ‡',
#  'ط®غŒظ„غŒ',
#  'ط¯',
#  'ط¯ط§',
#  'ط¯ط§ط§ظ…',
#  'ط¯ط§ط§ظ…ط§',
#  'ط¯ط§ط®ظ„',
#  'ط¯ط§ط¯',
#  'ط¯ط§ط¯ظ…',
#  'ط¯ط§ط¯ظ†',
#  'ط¯ط§ط¯ظ†ط¯',
#  'ط¯ط§ط¯ظ‡',
#  'ط¯ط§ط¯غŒ',
#  'ط¯ط§ط¯غŒط¯',
#  'ط¯ط§ط¯غŒظ…',
#  'ط¯ط§ط±',
#  'ط¯ط§ط±ط§ط³طھ',
#  'ط¯ط§ط±ط¯',
#  'ط¯ط§ط±ظ…',
#  'ط¯ط§ط±ظ†ط¯',
#  'ط¯ط§ط±غŒ',
#  'ط¯ط§ط±غŒط¯',
#  'ط¯ط§ط±غŒظ…',
#  'ط¯ط§ط´طھ',
#  'ط¯ط§ط´طھظ…',
#  'ط¯ط§ط´طھظ†',
#  'ط¯ط§ط´طھظ†ط¯',
#  'ط¯ط§ط´طھظ‡',
#  'ط¯ط§ط´طھغŒ',
#  'ط¯ط§ط´طھغŒط¯',
#  'ط¯ط§ط´طھغŒظ…',
#  'ط¯ط§ظ…ظ…',
#  'ط¯ط§ظ†ط³طھ',
#  'ط¯ط§ظ†ظ†ط¯',
#  'ط¯ط§غŒظ…',
#  'ط¯ط§غŒظ…ط§',
#  'ط¯ط±',
#  'ط¯ط± ط¨ط§ط±ظ‡',
#  'ط¯ط± ط¨ط§ط±ظ‡ظŒ',
#  'ط¯ط± ط«ط§ظ†غŒ',
#  'ط¯ط± ظ…ط¬ظ…ظˆط¹',
#  'ط¯ط± ظ†ظ‡ط§غŒطھ',
#  'ط¯ط± ظˆط§ظ‚ط¹',
#  'ط¯ط± ع©ظ„',
#  'ط¯ط± ع©ظ†ط§ط±',
#  'ط¯ط±ط§غŒظ† ظ…غŒط§ظ†',
#  'ط¯ط±ط¨ط§ط±ظ‡',
#  'ط¯ط±ط\xadط§ظ„غŒ ع©ظ‡',
#  'ط¯ط±ط\xadط§ظ„غŒع©ظ‡',
#  'ط¯ط±ط³طھ',
#  'ط¯ط±ط³طھ ظˆ ط\xadط³ط§ط¨غŒ',
#  'ط¯ط±ط³طھظ‡',
#  'ط¯ط±طµظˆط±طھغŒ ع©ظ‡',
#  'ط¯ط±ط¹غŒظ† ط\xadط§ظ„',
#  'ط¯ط±ظ…ط¬ظ…ظˆط¹',
#  'ط¯ط±ظˆط§ظ‚ط¹',
#  'ط¯ط±ظˆظ†',
#  'ط¯ط±غŒط؛',
#  'ط¯ط±غŒط؛ط§',
#  'ط¯ط±غŒظ†',
#  'ط¯ط³طھظ‡ ط¯ط³طھظ‡',
#  'ط¯ط´ظ…ظ†غŒظ…',
#  'ط¯ظ‚غŒظ‚ط§',
#  'ط¯ظ…',
#  'ط¯ظ†ط¨ط§ظ„ظگ',
#  'ط¯ظ‡',
#  'ط¯ظ‡ط¯',
#  'ط¯ظ‡ظ…',
#  'ط¯ظ‡ظ†ط¯',
#  'ط¯ظ‡غŒ',
#  'ط¯ظ‡غŒط¯',
#  'ط¯ظ‡غŒظ…',
#  'ط¯ظˆ',
#  'ط¯ظˆ ط±ظˆط²ظ‡',
#  'ط¯ظˆط¨ط§ط±ظ‡',
#  'ط¯ظˆظ…',
#  'ط¯غŒط¯ظ‡',
#  'ط¯غŒط±',
#  'ط¯غŒط±طھ',
#  'ط¯غŒط±ظ…',
#  'ط¯غŒط±ظˆط²',
#  'ط¯غŒط´ط¨',
#  'ط¯غŒظˆط§ظ†ظ‡â€Œط§غŒ',
#  'ط¯غŒظˆغŒ',
#  'ط¯غŒع¯ط±',
#  'ط¯غŒع¯ط±ط§ظ†',
#  'ط¯غŒع¯ط±غŒ',
#  'ط¯غŒع¯ظ‡',
#  'ط°',
#  'ط°ط§طھط§ظ‹',
#  'ط±',
#  'ط±ط§',
#  'ط±ط§ط¬ط¹ ط¨ظ‡',
#  'ط±ط§ط\xadطھ',
#  'ط±ط§ط³ط§',
#  'ط±ط§ط³طھ',
#  'ط±ط§ط³طھغŒ',
#  'ط±ط§ظ‡',
#  'ط±ط³ظ…ط§',
#  'ط±ط³غŒط¯',
#  'ط±ط³غŒط¯ظ‡',
#  'ط±ط´طھظ‡',
#  'ط±ظپطھ',
#  'ط±ظپطھط§ط±ظ‡ط§ط³طھ',
#  'ط±ظپطھظ‡',
#  'ط±ظ†ط¬ظ†ط¯',
#  'ط±ظ‡ع¯ط´ط§ط³طھ',
#  'ط±ظˆ',
#  'ط±ظˆط§ط³طھ',
#  'ط±ظˆط¨',
#  'ط±ظˆط¨ط±ظˆط³طھ',
#  'ط±ظˆط²',
#  'ط±ظˆط² ط¨ظ‡ ط±ظˆط²',
#  'ط±ظˆط²ط§ظ†ظ‡',
#  'ط±ظˆط²ظ‡ ط§غŒظ…',
#  'ط±ظˆط²ظ‡ ط³طھ',
#  'ط±ظˆط²ظ‡ ظ…',
#  'ط±ظˆط²ظ‡ط§غŒ',
#  'ط±ظˆط²ظ‡â€Œط§غŒ',
#  'ط±ظˆط´',
#  'ط±ظˆغŒ',
#  'ط±ظˆغŒط´',
#  'ط±ظˆغŒظگ',
#  'ط±غŒط²غŒ',
#  'ط²',
#  'ط²ط´طھع©ط§ط±ط§ظ†ظ†ط¯',
#  'ط²ظ…ط§ظ†',
#  'ط²ظ…ط§ظ†غŒ',
#  'ط²ظ…غŒظ†ظ‡',
#  'ط²ظ†ظ†ط¯',
#  'ط²ظ‡غŒ',
#  'ط²ظˆط¯',
#  'ط²ظˆط¯طھط±',
#  'ط²غŒط§ط¯',
#  'ط²غŒط§ط¯ظ‡',
#  'ط²غŒط±',
#  'ط²غŒط±ط§',
#  'ط²غŒط±ظگ',
#  'ط²غŒط±ع†ط´ظ…غŒ',
#  'ط³',
#  'ط³ط§ط¨ظ‚',
#  'ط³ط§ط®طھظ‡',
#  'ط³ط§ط¯ظ‡ ط§ظ†ط¯',
#  'ط³ط§ط²غŒ',
#  'ط³ط§ظ„ط§ظ†ظ‡',
#  'ط³ط§ظ„طھظ‡',
#  'ط³ط§ظ„ظ…â€Œطھط±',
#  'ط³ط§ظ„ظ‡ط§ط³طھ',
#  'ط³ط§ظ„غŒط§ظ†ظ‡',
#  'ط³ط§ع©ظ†ظ†ط¯',
#  'ط³ط§غŒط±',
#  'ط³ط®طھ',
#  'ط³ط®طھظ‡',
#  'ط³ط±',
#  'ط³ط±ط§ط³ط±',
#  'ط³ط±ط§ظ†ط¬ط§ظ…',
#  'ط³ط±ط§ظ¾ط§',
#  'ط³ط±غŒ',
#  'ط³ط±غŒط¹',
#  'ط³ط±غŒط¹ط§',
#  'ط³ط±غŒط¹ط§ظ‹',
#  'ط³ط±غŒظگ',
#  'ط³ط¹غŒ',
#  'ط³ظ…طھظگ',
#  'ط³ظ‡ ط¨ط§ط±ظ‡',
#  'ط³ظ‡ظˆط§ظ‹',
#  'ط³ظˆظ…',
#  'ط³ظˆغŒ',
#  'ط³ظˆغŒظگ',
#  'ط³ظ¾ط³',
#  'ط³غŒط§ظ‡ ع†ط§ظ„ظ‡ ظ‡ط§ط³طھ',
#  'ط³غŒط®',
#  'ط´',
#  'ط´ط§ظ†',
#  'ط´ط§ظ‡ط¯ظ†ط¯',
#  'ط´ط§ظ‡ط¯غŒظ…',
#  'ط´ط§غŒط¯',
#  'ط´ط¨ظ‡ط§ط³طھ',
#  'ط´ط®طµط§',
#  'ط´ط®طµط§ظ‹',
#  'ط´ط¯',
#  'ط´ط¯ظ…',
#  'ط´ط¯ظ†',
#  'ط´ط¯ظ†ط¯',
#  'ط´ط¯ظ‡',
#  'ط´ط¯غŒ',
#  'ط´ط¯غŒط¯',
#  'ط´ط¯غŒط¯ط§',
#  'ط´ط¯غŒط¯ط§ظ‹',
#  'ط´ط¯غŒظ…',
#  'ط´ط´',
#  'ط´ط´ ظ†ط¯ط§ط´طھظ‡',
#  'ط´ظ…ط§',
#  'ط´ظ…ط§ط±غŒ',
#  'ط´ظ…ط§ط³طھ',
#  'ط´ظ…ط§غŒظ†ط¯',
#  'ط´ظ†ط§ط³غŒ',
#  'ط´ظˆ',
#  'ط´ظˆط¯',
#  'ط´ظˆط±ط§ط³طھ',
#  'ط´ظˆظ‚ظ…',
#  'ط´ظˆظ…',
#  'ط´ظˆظ†ط¯',
#  'ط´ظˆظ†ط¯ظ‡',
#  'ط´ظˆغŒ',
#  'ط´ظˆغŒط¯',
#  'ط´ظˆغŒظ…',
#  'ط´غŒط±غŒظ†',
#  'ط´غŒط±غŒظ†ظ‡',
#  'ط´غŒع©',
#  'طµ',
#  'طµط¯',
#  'طµط¯ط¯ط±طµط¯',
#  'طµط±ظپط§',
#  'طµط±ظپط§ظ‹',
#  'طµط±غŒط\xadط§ظ‹',
#  'طµظ†ط¯ظˆظ‚ ظ‡ط§ط³طھ',
#  'طµظˆط±طھ',
#  'ط¶',
#  'ط¶ط¯ظگظ‘',
#  'ط¶ط¯ظ‘ظگ',
#  'ط¶ظ…ظ†',
#  'ط¶ظ…ظ†ط§ظ‹',
#  'ط·',
#  'ط·ط¨ط¹ط§',
#  'ط·ط¨ط¹ط§ظ‹',
#  'ط·ط¨ظ‚ظگ',
#  'ط·ط¨غŒط¹طھط§',
#  'ط·ط±ظپ',
#  'ط·ط±غŒظ‚',
#  'ط·ظ„ط¨ع©ط§ط±ط§ظ†ظ‡',
#  'ط·ظˆط±',
#  'ط·غŒ',
#  'ط¸',
#  'ط¸ط§ظ‡ط±ط§',
#  'ط¸ط§ظ‡ط±ط§ظ‹',
#  'ط¹',
#  'ط¹ط§ط¬ط²ط§ظ†ظ‡',
#  'ط¹ط§ظ‚ط¨طھ',
#  'ط¹ط¨ط§ط±طھظ†ط¯',
#  'ط¹ط¬ط¨',
#  'ط¹ط¬ظˆظ„ط§ظ†ظ‡',
#  'ط¹ط¯ظ…',
#  'ط¹ط±ظپط§ظ†غŒ',
#  'ط¹ظ‚ط¨',
#  'ط¹ظ‚ط¨ظگ',
#  'ط¹ظ„ط§ظˆظ‡ ط¨ط±',
#  'ط¹ظ„ط§ظˆظ‡ ط¨ط± ط¢ظ†',
#  'ط¹ظ„ط§ظˆظ‡ ط¨ط±ط¢ظ†',
#  'ط¹ظ„ظ†ط§ظ‹',
#  'ط¹ظ„ظ‘طھظگ',
#  'ط¹ظ„غŒ ط§ظ„ط¸ط§ظ‡ط±',
#  'ط¹ظ„غŒ ط±ط؛ظ…',
#  'ط¹ظ„غŒط±ط؛ظ…',
#  'ط¹ظ„غŒظ‡',
#  'ط¹ظ…ط¯ط§',
#  'ط¹ظ…ط¯ط§ظ‹',
#  'ط¹ظ…ط¯طھط§',
#  'ط¹ظ…ط¯طھط§ظ‹',
#  'ط¹ظ…ط¯ظ‡',
#  'ط¹ظ…ظ„',
#  'ط¹ظ…ظ„ط§',
#  'ط¹ظ…ظ„ط§ظ‹',
#  'ط¹ظ…ظ„غŒ ط§ظ†ط¯',
#  'ط¹ظ…ظˆظ…',
#  'ط¹ظ…ظˆظ…ط§',
#  'ط¹ظ…ظˆظ…ط§ظ‹',
#  'ط¹ظ†ظ‚ط±غŒط¨',
#  'ط¹ظ†ظˆط§ظ†',
#  'ط¹ظ†ظˆط§ظ†ظگ',
#  'ط¹غŒظ†ط§ظ‹',
#  'ط؛',
#  'ط؛ط§ظ„ط¨ط§',
#  'ط؛ط²ط§ظ„ط§ظ†',
#  'ط؛غŒط±',
#  'ط؛غŒط±ظ‚ط§ظ†ظˆظ†غŒ',
#  'ظپ',
#  'ظپط§ظ‚ط¯',
#  'ظپط¨ظ‡ط§',
#  'ظپط±',
#  'ظپط±ط¯ط§',
#  'ظپط¹ظ„ط§',
#  'ظپط¹ظ„ط§ظ‹',
#  'ظپظ‚ط·',
#  'ظپظ„ط§ظ†',
#  'ظپظ„ط°ط§',
#  'ظپظˆظ‚',
#  'ظپع©ط±',
#  'ظ‚',
#  'ظ‚ط§ط§ظ„ظ†ط¯',
#  'ظ‚ط§ط¨ظ„',
#  'ظ‚ط§ط·ط¨ظ‡',
#  'ظ‚ط§ط·ط¹ط§ظ†ظ‡',
#  'ظ‚ط§ط¹ط¯طھط§ظ‹',
#  'ظ‚ط§ظ†ظˆظ†ط§ظ‹',
#  'ظ‚ط¨ظ„',
#  'ظ‚ط¨ظ„ط§',
#  'ظ‚ط¨ظ„ط§ظ‹',
#  'ظ‚ط¨ظ„ظ†ط¯',
#  'ظ‚ط¯ط±',
#  'ظ‚ط¯ط±غŒ',
#  'ظ‚طµط¯ظگ',
#  'ظ‚ط¶ط§غŒط§ط³طھ',
#  'ظ‚ط·ط¹ط§',
#  'ظ‚ط·ط¹ط§ظ‹',
#  'ظ„',
#  'ظ„ط§ط§ظ‚ظ„',
#  'ظ„ط§ط¬ط±ظ…',
#  'ظ„ط¨',
#  'ظ„ط°ط§',
#  'ظ„ط²ظˆظ…ط§ظ‹',
#  'ظ„ط·ظپط§',
#  'ظ„ط·ظپط§ظ‹',
#  'ظ„غŒع©ظ†',
#  'ظ…',
#  'ظ…ط§',
#  'ظ…ط§ط¯ط§ظ…غŒ',
#  'ظ…ط§ط³طھ',
#  'ظ…ط§ظ…ط§ظ† ظ…ط§ظ…ط§ظ† ع¯ظˆغŒط§ظ†',
#  'ظ…ط§ظ†',
#  'ظ…ط§ظ†ظ†ط¯',
#  'ظ…ط§ظ†ظ†ط¯ظگ',
#  'ظ…ط¨ط§ط¯ط§',
#  'ظ…طھط¤ط³ظپط§ظ†ظ‡',
#  'ظ…طھط§ط³ظپط§ظ†ظ‡',
#  'ظ…طھط¹ط§ظ‚ط¨ط§',
#  'ظ…طھظپط§ظˆطھظ†ط¯',
#  'ظ…ط«ظ„',
#  'ظ…ط«ظ„ط§',
#  'ظ…ط«ظ„ظگ',
#  'ظ…ط¬ط§ظ†غŒ',
#  'ظ…ط¬ط¨ظˆط±ظ†ط¯',
#  'ظ…ط¬ط¯ط¯ط§',
#  'ظ…ط¬ط¯ط¯ط§ظ‹',
#  'ظ…ط¬ظ…ظˆط¹ط§',
#  'ظ…ط¬ظ…ظˆط¹ط§ظ‹',
#  'ظ…ط\xadطھط§ط¬ظ†ط¯',
#  'ظ…ط\xadع©ظ…',
#  'ظ…ط\xadع©ظ…â€Œطھط±',
#  'ظ…ط®ط§ظ„ظپظ†ط¯',
#  'ظ…ط®طھظ„ظپ',
#  'ظ…ط®طµظˆطµط§ظ‹',
#  'ظ…ط¯ط§ظ…',
#  'ظ…ط¯طھ',
#  'ظ…ط¯طھظ‡ط§ط³طھ',
#  'ظ…ط¯ظ‘طھغŒ',
#  'ظ…ط°ظ‡ط¨غŒ ط§ظ†ط¯',
#  'ظ…ط±ط§',
#  'ظ…ط±طھط¨',
#  'ظ…ط±ط¯ط§ظ†ظ‡',
#  'ظ…ط±ط¯ظ…',
#  'ظ…ط±ط¯ظ… ط§ظ†ط¯',
#  'ظ…ط±ط³غŒ',
#  'ظ…ط³طھط\xadط¶ط±غŒط¯',
#  'ظ…ط³طھظ‚غŒظ…ط§',
#  'ظ…ط³طھظ†ط¯',
#  'ظ…ط³ظ„ظ…ط§',
#  'ظ…ط´طھ',
#  'ظ…ط´طھط±ع©ط§ظ‹',
#  'ظ…ط´ط؛ظˆظ„ظ†ط¯',
#  'ظ…ط·ظ…ط§ظ†ط§',
#  'ظ…ط·ظ…ط§ظ†ظ…',
#  'ظ…ط·ظ…غŒظ†ط§',
#  'ظ…ط¹ ط§ظ„ط§ط³ظپ',
#  'ظ…ط¹ ط°ظ„ع©',
#  'ظ…ط¹طھظ‚ط¯ظ…',
#  'ظ…ط¹طھظ‚ط¯ظ†ط¯',
#  'ظ…ط¹طھظ‚ط¯غŒظ…',
#  'ظ…ط¹ط¯ظˆط¯',
#  'ظ…ط¹ط°ظˆط±غŒظ…',
#  'ظ…ط¹ظ„ظˆظ…ظ‡',
#  'ظ…ط¹ظ…ظˆظ„ط§',
#  'ظ…ط¹ظ…ظˆظ„ط§ظ‹',
#  'ظ…ط¹ظ…ظˆظ„غŒ',
#  'ظ…ط؛ط±ط¶ط§ظ†ظ‡',
#  'ظ…ظپغŒط¯ظ†ط¯',
#  'ظ…ظ‚ط§ط¨ظ„',
#  'ظ…ظ‚ط¯ط§ط±',
#  'ظ…ظ‚طµط±ظ†ط¯',
#  'ظ…ظ‚طµط±غŒ',
#  'ظ…ظ„غŒط§ط±ط¯',
#  'ظ…ظ„غŒظˆظ†',
#  'ظ…ظ…ع©ظ†',
#  'ظ…ظ…غŒط²غŒظ‡ط§ط³طھ',
#  'ظ…ظ†',
#  'ظ…ظ†طھظ‡غŒ',
#  'ظ…ظ†ط·ظ‚غŒ',
#  'ظ…ظ†غŒ',
#  'ظ…ظˆط§ط¬ظ‡ظ†ط¯',
#  'ظ…ظˆط§ط±ط¯',
#  'ظ…ظˆط¬ظˆط¯ظ†ط¯',
#  'ظ…ظˆط±ط¯',
#  'ظ…ظˆظ‚طھط§',
#  'ظ…ع©ط±ط±',
#  'ظ…ع©ط±ط±ط§ظ‹',
#  'ظ…ع¯ط±',
#  'ظ…ع¯ط± ط¢ظ† ع©ظ‡',
#  'ظ…ع¯ط± ط§غŒظ† ع©ظ‡',
#  'ظ…ع¯ظˆ',
#  'ظ…غŒ',
#  'ظ…غŒط§ظ†',
#  'ظ…غŒط²ط§ظ†',
#  'ظ…غŒظ„غŒط§ط±ط¯',
#  'ظ…غŒظ„غŒظˆظ†',
#  'ظ…غŒع©ظ†ط¯',
#  'ظ…غŒع©ظ†ظ…',
#  'ظ…غŒع©ظ†ظ†ط¯',
#  'ظ…غŒع©ظ†غŒ',
#  'ظ…غŒع©ظ†غŒط¯',
#  'ظ…غŒع©ظ†غŒظ…',
#  'ظ…غŒâ€Œطھظˆط§ظ†ط¯',
#  'ظ…غŒâ€Œط®ظˆط§ظ‡غŒظ…',
#  'ظ…غŒâ€Œط¯ط§ظ†ط¯',
#  'ظ…غŒâ€Œط±ط³ط¯',
#  'ظ…غŒâ€Œط±ظˆط¯',
#  'ظ…غŒâ€Œط´ظˆط¯',
#  'ظ…غŒâ€Œع©ظ†ظ…',
#  'ظ…غŒâ€Œع©ظ†ظ†ط¯',
#  'ظ…غŒâ€Œع©ظ†غŒظ…',
#  'ظ†',
#  'ظ†ط§ط§ظ…غŒط¯',
#  'ظ†ط§ط®ظˆط§ط³طھظ‡',
#  'ظ†ط§ط±ط§ط¶غŒ ط§ظ†ط¯',
#  'ظ†ط§ط´غŒ',
#  'ظ†ط§ظ…',
#  'ظ†ط§ع¯ط§ظ‡',
#  'ظ†ط§ع¯ط²غŒط±',
#  'ظ†ط§ع¯ظ‡ط§ظ†',
#  'ظ†ط§ع¯ظ‡ط§ظ†غŒ',
#  'ظ†ط¨ط§غŒط¯',
#  'ظ†ط¨ط´',
#  'ظ†ط¨ظˆط¯',
#  'ظ†ط®ط³طھ',
#  'ظ†ط®ط³طھغŒظ†',
#  'ظ†ط®ظˆط§ظ‡ط¯',
#  'ظ†ط®ظˆط§ظ‡ظ…',
#  'ظ†ط®ظˆط§ظ‡ظ†ط¯',
#  'ظ†ط®ظˆط§ظ‡غŒ',
#  'ظ†ط®ظˆط§ظ‡غŒط¯',
#  'ظ†ط®ظˆط§ظ‡غŒظ…',
#  'ظ†ط®ظˆط¯غŒ',
#  'ظ†ط¯ط§ط±ط¯',
#  'ظ†ط¯ط§ط±ظ…',
#  'ظ†ط¯ط§ط±ظ†ط¯',
#  'ظ†ط¯ط§ط±غŒ',
#  'ظ†ط¯ط§ط±غŒط¯',
#  'ظ†ط¯ط§ط±غŒظ…',
#  'ظ†ط¯ط§ط´طھ',
#  'ظ†ط¯ط§ط´طھظ…',
#  'ظ†ط¯ط§ط´طھظ†ط¯',
#  'ظ†ط¯ط§ط´طھظ‡',
#  'ظ†ط¯ط§ط´طھغŒ',
#  'ظ†ط¯ط§ط´طھغŒط¯',
#  'ظ†ط¯ط§ط´طھغŒظ…',
#  'ظ†ط²ط¯',
#  'ظ†ط²ط¯ظگ',
#  'ظ†ط²ط¯غŒع©',
#  'ظ†ط²ط¯غŒع©ظگ',
#  'ظ†ط³ط¨طھط§',
#  'ظ†ط´ط§ظ†',
#  'ظ†ط´ط¯ظ‡',
#  'ظ†ط¸غŒط±',
#  'ظ†ظپط±ظ†ط¯',
#  'ظ†ظ…ط§غŒط¯',
#  'ظ†ظ…ظˆط¯ظ‡',
#  'ظ†ظ…غŒ',
#  'ظ†ظ…غŒâ€Œط´ظˆط¯',
#  'ظ†ظ…غŒâ€Œع©ظ†ط¯',
#  ...]

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Administrator\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
nltk_stopwords = nltk.corpus.stopwords.words('english')
stopwords.extend(nltk_stopwords)
len(stopwords)
# Out:
# 1495

# %%
import hazm
stemmer = hazm.Stemmer()

# %%
stemmer.stem('کتاب‌ها')
# Out:
# 'کتاب'

# %%
from hazm import word_tokenize

# %%
dataset = pd.DataFrame(columns=('title_body', 'category'))
for index, row in data.iterrows():
    title_body = row['Title'] + ' ' + row['Body']
    title_body_tokenized = word_tokenize(title_body)
    title_body_tokenized_filtered = [w for w in title_body_tokenized if not w in stopwords]
    title_body_tokenized_filtered_stemmed = [stemmer.stem(w) for w in title_body_tokenized_filtered]
    dataset.loc[index] = {
        'title_body': ' '.join(title_body_tokenized_filtered_stemmed),
        'category': row['Category2'].replace('\n', '')
    }

# %%
dataset.head()

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
vectorizer = TfidfVectorizer()
vectorizer.fit(dataset['title_body'])

# %%
X = vectorizer.transform(dataset['title_body'])

# %%
X

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()
y = le.fit_transform(dataset['category'])

# %%
le.classes_

# %%
len(y)

# %%
import numpy as np
print(np.unique(dataset['category']))

# %%
np.shape(X)

# %%
np.shape(y)

# %%
import umap
from sklearn.manifold import TSNE
from matplotlib import pyplot as plt

# %%
tsne = TSNE(n_components=1000, perplexity=50 ,random_state=123)

# %%
tsne_result = tsne.fit(X)

# %%
X = tsne.transform(X)

# %%
np.shape(X)

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=123)

# %%
from sklearn import svm

# %%
svmc = svm.SVC()
svmc.fit(X_train, y_train)

# %%
svmc.score(X_test, y_test)
# It shows that is extremly awful

# %%
from sklearn.metrics import classification_report, confusion_matrix
y_pred = svmc.predict(X_test)
classification_report(y_test, y_pred)

# %%
print(classification_report(y_test, y_pred))

# %%
print(confusion_matrix(y_test, y_pred))
# Out:
# [[234  10   0   1   0   2   9   1   1   0   1]
#  [ 14 179  21   6   8   9   7  16   5   4   1]
#  [  3  26 200   0   4   5  12   3   1   2   0]
#  [  1   7   4 233   0   2   8   0   0   0   0]
#  [  0   4   1   0 219   9   1   2   3   1   0]
#  [  2   9  17   1   7 172   5   4  14   2   1]
#  [ 14   8   9  25   0   3 201   3   0   0   2]
#  [  2  12   5   1   4   5   5 199   1   4   4]
#  [  1   8   3   1   3  10   1   2 224   1   0]
#  [  0   6   2   1   1   2   0   2   1 237   0]
#  [  1   8   0   1   0   3   2   2   0   0 206]]
