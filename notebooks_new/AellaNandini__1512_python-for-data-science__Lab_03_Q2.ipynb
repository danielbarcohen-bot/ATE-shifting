# %% [markdown]
# <a href="https://colab.research.google.com/github/2303a51512/1512_python-for-data-science/blob/main/Lab_03_Q2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
np.random.seed(42)
image = np.random.randint(0, 256, size=(3, 3, 3), dtype=np.uint8)
print("Original RGB Image Array:\n", image)
# Out:
# Original RGB Image Array:
#  [[[102 220 225]
#   [ 95 179  61]
#   [234 203  92]]
#
#  [[  3  98 243]
#   [ 14 149 245]
#   [ 46 106 244]]
#
#  [[ 99 187  71]
#   [212 153 199]
#   [188 174  65]]]

# %%
red_channel = image[:, :, 0]
green_channel = image[:, :, 1]
blue_channel = image[:, :, 2]

print("\nRed Channel:\n", red_channel)
print("\nGreen Channel:\n", green_channel)
print("\nBlue Channel:\n", blue_channel)
# Out:
# Red Channel:
#  [[102  95 234]
#  [  3  14  46]
#  [ 99 212 188]]
#
# Green Channel:
#  [[220 179 203]
#  [ 98 149 106]
#  [187 153 174]]
#
# Blue Channel:
#  [[225  61  92]
#  [243 245 244]
#  [ 71 199  65]]

# %%
avg_red = np.mean(red_channel)
avg_green = np.mean(green_channel)
avg_blue = np.mean(blue_channel)

print("\nAverage Intensities - Red:", avg_red, "Green:", avg_green, "Blue:", avg_blue)
# Out:
# Average Intensities - Red: 110.33333333333333 Green: 163.22222222222223 Blue: 160.55555555555554

# %%
brightened_image = np.clip(image + 50, 0, 255)
print("\nBrightened Image Array:\n", brightened_image)
# Out:
# Brightened Image Array:
#  [[[152  14  19]
#   [145 229 111]
#   [ 28 253 142]]
#
#  [[ 53 148  37]
#   [ 64 199  39]
#   [ 96 156  38]]
#
#  [[149 237 121]
#   [  6 203 249]
#   [238 224 115]]]

# %%
fig, axs = plt.subplots(1, 2, figsize=(8, 4))
axs[0].imshow(image)
axs[0].set_title("Original Image")
axs[1].imshow(brightened_image)
axs[1].set_title("Brightened Image")
for ax in axs:
    ax.axis('off')
plt.tight_layout()
plt.show()
