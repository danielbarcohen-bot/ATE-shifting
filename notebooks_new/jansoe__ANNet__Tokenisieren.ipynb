# %% [markdown]
# <a href="https://colab.research.google.com/github/jansoe/ANNet/blob/main/Tokenisieren.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Transformers

# %%
# !pip install transformers -q

# %%
import transformers
import torch

# %% [markdown]
# ## Input : Tokens

# %%
#model_version = 'bert-base-uncased'
model_version = 'gpt2'
tokenizer = transformers.AutoTokenizer.from_pretrained(model_version)
# Out:
# config.json:   0%|          | 0.00/665 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]

# %%
tokenizer.tokenize('This is a test of the tokenizer')
# Out:
# ['This', 'Ġis', 'Ġa', 'Ġtest', 'Ġof', 'Ġthe', 'Ġtoken', 'izer']

# %%
tokens = tokenizer('This is a test of the tokenizer')['input_ids']
tokens
# Out:
# [1212, 318, 257, 1332, 286, 262, 11241, 7509]

# %%
[tokenizer.convert_ids_to_tokens(t) for t in tokens]
# Out:
# ['This', 'Ġis', 'Ġa', 'Ġtest', 'Ġof', 'Ġthe', 'Ġtoken', 'izer']

# %%
tokenizer.decode(tokens)
# Out:
# 'This is a test of the tokenizer'

# %%
tokenizer.tokenize('n0thing is corect')
# Out:
# ['n', '0', 'thing', 'Ġis', 'Ġcore', 'ct']

# %%
tokenizer.vocab
# Out:
# {'Ġdisgruntled': 48967,
#  'Ġmorphology': 46320,
#  'Ġstatements': 6299,
#  'Kar': 37753,
#  'language': 16129,
#  'VPN': 33883,
#  'HC': 16045,
#  'IONS': 11053,
#  'ĠOther': 3819,
#  'Ġpercentile': 37894,
#  'ĠStarCraft': 38460,
#  'ĠJohn': 1757,
#  'Ġdevise': 44668,
#  'ussia': 31269,
#  'Ġsleeves': 27409,
#  'Ġreceptive': 41062,
#  'ĠRadar': 38426,
#  'angling': 27499,
#  'ĠGoose': 46317,
#  'Cole': 46509,
#  'Ġdefeating': 21320,
#  'Ġsoftened': 41534,
#  'Ġschedules': 24025,
#  'Ġhall': 6899,
#  'Ġwheat': 17135,
#  'Ġath': 5782,
#  'Ġcandid': 2960,
#  'Ġsketch': 17548,
#  'Ġswitching': 15430,
#  'Ġ(Â£': 23068,
#  'ĠLean': 45661,
#  'ĠInstant': 24470,
#  'Ġlandfill': 47712,
#  'Ġdeclined': 7392,
#  'alogue': 30326,
#  'Ġdonors': 13334,
#  'Ġrecruiting': 16517,
#  'ĠEmail': 9570,
#  'Ġdocumentaries': 43014,
#  'ueller': 16466,
#  'Ġvinegar': 26600,
#  'ĠMMR': 41362,
#  'izont': 12071,
#  'hole': 13207,
#  'Lear': 14961,
#  'except': 16341,
#  'REAM': 32235,
#  '671': 46250,
#  'ĠPharmaceutical': 37175,
#  'ĠHardcore': 49691,
#  'Ġnarratives': 26274,
#  'ĠCanterbury': 43581,
#  'examination': 47779,
#  'ĠQuran': 30018,
#  'ĠEstablishment': 37132,
#  'ĠPier': 13762,
#  'ĠChair': 9369,
#  'Ġmisdemeanor': 22403,
#  'TB': 22737,
#  'tha': 12898,
#  '282': 32568,
#  'Ġsecure': 5713,
#  'ĠFra': 39313,
#  'finals': 32089,
#  'Ġnationalism': 24436,
#  'ĠAuthors': 46665,
#  'ĠMOR': 35208,
#  'ynamic': 28995,
#  'ucer': 48915,
#  'ĠSeaf': 49967,
#  'Ġninth': 19646,
#  'ĠLens': 30092,
#  'Tre': 31055,
#  'Ġheroes': 10281,
#  'aff': 2001,
#  'scope': 29982,
#  'ĠAffordable': 19258,
#  'ng': 782,
#  'Ġrare': 4071,
#  'Ġproletariat': 30444,
#  'ĠHawai': 10847,
#  'Ġdeviations': 47060,
#  'ĠstrutConnector': 50009,
#  'Ġyacht': 43207,
#  'tered': 4400,
#  'ing': 278,
#  'Ġask': 1265,
#  'ĠTrad': 8397,
#  'ĠMerkel': 18263,
#  'Ġdevice': 3335,
#  'ĠSecond': 5498,
#  'Ġnightly': 37862,
#  'Ġscheduled': 7530,
#  'Ġfoundation': 8489,
#  '.....': 12359,
#  'Ġaccidents': 17390,
#  'ĠIndian': 3942,
#  'Ġvalid': 4938,
#  'Ġfasting': 24845,
#  'ĠRs': 12820,
#  'alloc': 32332,
#  'Ġcommissioners': 33020,
#  'Ġdiversion': 34851,
#  'Ġdamning': 36706,
#  'ĠSatellite': 33530,
#  'ĠHarold': 23987,
#  'ĠNaj': 37135,
#  'ĠIllusion': 37697,
#  'Ġworship': 11892,
#  'kHz': 44191,
#  ']+': 48688,
#  'ĠCandle': 44973,
#  'Ġprecon': 49394,
#  'Paris': 40313,
#  'Ġprotection': 4800,
#  'resses': 16746,
#  'Ġseed': 9403,
#  'sofar': 38649,
#  'ĠEfficiency': 45728,
#  'ĠHughes': 19712,
#  'Ġwallet': 13008,
#  'ĠSwed': 7289,
#  'Ġfoc': 2133,
#  'Ġmedium': 7090,
#  '556': 37864,
#  'wark': 48542,
#  'empt': 1791,
#  'Ġcirculating': 24495,
#  'ĠTBD': 34343,
#  'days': 12545,
#  'anton': 23026,
#  'Attempt': 37177,
#  '035': 44215,
#  'Ġboulder': 46483,
#  'Ġleaked': 14109,
#  'Ġcleansing': 32784,
#  'Rest': 19452,
#  'Ġchanting': 31138,
#  'ĠOaks': 44781,
#  'hist': 10034,
#  'Ġhelpers': 49385,
#  'Ġskysc': 37885,
#  'ĠSam': 3409,
#  'Ġfem': 2796,
#  'mite': 32937,
#  'ause': 682,
#  'ĠCavs': 38943,
#  'Ġbumps': 34029,
#  'ĠResolution': 22406,
#  'ĠAFC': 27987,
#  'inventory': 24807,
#  'ĠBrooks': 17704,
#  'ĠHistoric': 30426,
#  'ĠLith': 19730,
#  'ĠConquer': 40963,
#  'REP': 35316,
#  'Builder': 32875,
#  'Ġfavor': 2661,
#  'Ġallegiance': 25696,
#  'ĠCoc': 18490,
#  'Ġhardened': 33034,
#  'ĠMist': 15078,
#  'Ġnegro': 47255,
#  'ĠChilean': 48014,
#  'ĠMeet': 21167,
#  '42': 3682,
#  'Ess': 29508,
#  'ĠMot': 6543,
#  'Ġrecognizable': 30264,
#  'Ġruns': 4539,
#  'Ġrockets': 20293,
#  'Ġgreat': 1049,
#  'Ġfaculty': 12829,
#  'Ġvulgar': 31016,
#  'ĠElite': 16158,
#  'itect': 5712,
#  'Ġweakened': 24135,
#  'Ġ324': 38595,
#  'Ġsuffice': 34302,
#  'ĠTransformers': 39185,
#  'felt': 31985,
#  'Pic': 39507,
#  'exempt': 42679,
#  'ĠMcH': 49634,
#  'ĠLafayette': 41388,
#  'âĢ¦': 1399,
#  'Ġyelling': 22187,
#  'ield': 1164,
#  'ĠMarine': 11000,
#  'ĠGall': 7096,
#  'Ġtrips': 13229,
#  'Block': 12235,
#  'Again': 15316,
#  'Ġdisg': 13757,
#  'Available': 10493,
#  'ipes': 18636,
#  'opers': 20618,
#  'Prop': 24331,
#  'Ġtransforming': 25449,
#  'Ġendanger': 35276,
#  'Ġdece': 12738,
#  'Ġprinces': 42676,
#  'haus': 30404,
#  'ĠCountry': 12946,
#  'ĠEnemy': 21785,
#  'Ġslic': 14369,
#  'benefit': 48649,
#  'ĠVigil': 39840,
#  'inst': 8625,
#  'Ġclan': 19065,
#  'ĠMU': 25108,
#  'Ġaffecting': 13891,
#  'Ġgeographic': 22987,
#  'ĠKeys': 26363,
#  'Ġmarkers': 19736,
#  'Ġ).': 6739,
#  'let': 1616,
#  'ĠBol': 10797,
#  'Ġdrug': 2563,
#  'burg': 7423,
#  'tein': 22006,
#  'Ġrebuke': 45830,
#  'EF': 25425,
#  '23': 1954,
#  'Ġfrogs': 37475,
#  'Ġearnest': 23176,
#  'Ġstaying': 10589,
#  'Ġshorthand': 45883,
#  'ĠFreddy': 45437,
#  'Ġlooms': 46234,
#  'ĠTreat': 11217,
#  'ĠRD': 31475,
#  'ĠGriffith': 30469,
#  'Ġhump': 49779,
#  'ĠHig': 11951,
#  'testers': 27205,
#  'FIN': 20032,
#  'ĠBundes': 33816,
#  'Ġsprinkle': 45799,
#  'Ġab': 450,
#  'Ġbinaries': 38640,
#  'Ġgoodies': 39863,
#  'Ġservicing': 43346,
#  'Sold': 33873,
#  'ism': 1042,
#  'Romney': 42184,
#  'Ġagility': 33546,
#  'Ġdemonstrations': 18721,
#  'ĠPep': 24226,
#  'Ġskeptical': 17988,
#  'ĠOPS': 40490,
#  'Ġcrowded': 18012,
#  'Ġnorth': 5093,
#  'ĠDirt': 49124,
#  'ĠSocrates': 41242,
#  'Ġneighborhood': 6232,
#  'ĠMEN': 41597,
#  'ĠMuscle': 43683,
#  'Ġbrainstorm': 48733,
#  'Sorry': 14385,
#  'ATING': 33881,
#  'Ġcritics': 9188,
#  'Ġflashlight': 38371,
#  'ĠPatients': 28021,
#  'ĠChu': 25459,
#  'Ġpi': 31028,
#  'ĠDip': 43945,
#  'Ġremarked': 24998,
#  'Ġbeing': 852,
#  'Ġglossy': 40551,
#  'bc': 15630,
#  'ãĥĥãĥĪ': 35799,
#  '/.': 11757,
#  'Safe': 31511,
#  'ĠÏ': 18074,
#  'replace': 33491,
#  'ovember': 3239,
#  'ĠEAR': 31834,
#  'Ġdaemon': 33386,
#  'Journal': 25296,
#  'ĠLu': 6026,
#  'Ġcrotch': 45885,
#  'ifled': 47157,
#  'akening': 18800,
#  'ĠObjects': 35832,
#  'were': 22474,
#  'Ġsew': 34249,
#  'volt': 37764,
#  'Ġceiling': 13387,
#  'Ġcases': 2663,
#  'Ġinterns': 47266,
#  'Ġirregularities': 48302,
#  'Ġmel': 7758,
#  'serving': 31293,
#  'Ġpaperback': 46771,
#  'hero': 11718,
#  'inqu': 18934,
#  'nant': 22057,
#  'ĠXML': 23735,
#  'ĠPercy': 38506,
#  'until': 28446,
#  'Ġnotor': 23305,
#  'Nin': 36091,
#  'Ġapple': 17180,
#  'fitted': 38631,
#  'Ġidle': 21696,
#  'enes': 18719,
#  'hound': 39047,
#  'Ġhonored': 21014,
#  'Ġorganizational': 26564,
#  'ĠComposite': 49355,
#  'Ġestim': 3959,
#  'Phys': 43215,
#  'itative': 12464,
#  'Ġsubsid': 7905,
#  'Ġcave': 11527,
#  'ĠProtective': 45004,
#  'Ġallegations': 7636,
#  'Ġkidney': 21919,
#  'ĠINFO': 24890,
#  'Ġnonexistent': 42601,
#  'Ġsizeable': 47225,
#  'Ġdecor': 11705,
#  'itations': 20597,
#  'ĠAppro': 20010,
#  'asp': 5126,
#  'lasses': 28958,
#  'lement': 1732,
#  'ĠChak': 46620,
#  'Ġpedd': 36145,
#  'ď': 203,
#  'ports': 3742,
#  'Ġrunning': 2491,
#  'ĠTrip': 18383,
#  'Ġenlarge': 27475,
#  'water': 7050,
#  'ĠSomali': 30886,
#  'Ġaspir': 18808,
#  'Soc': 37949,
#  'ak': 461,
#  'Ġtainted': 36912,
#  'ĠLeaving': 38068,
#  'ĠPledge': 45737,
#  'ĠTemp': 24189,
#  'bool': 30388,
#  'assuming': 32935,
#  'Ġwip': 14763,
#  'Ver': 13414,
#  'irmation': 36241,
#  'ĠUri': 46688,
#  'Ġvetoed': 49581,
#  'ĠSik': 32615,
#  'ĠHillary': 5073,
#  'Ġfont': 10369,
#  'ĠAttorney': 8123,
#  'Ap': 25189,
#  'Ġunilaterally': 44486,
#  'Ġsmaller': 4833,
#  'ĠDig': 7367,
#  'ĠGarcia': 18555,
#  'Ġsurreal': 28201,
#  'ĠFlan': 39016,
#  'ø': 180,
#  'ċ': 199,
#  'Ġpercentages': 28071,
#  'Ġdrastically': 22188,
#  'oubted': 15973,
#  '115': 15363,
#  'kish': 31501,
#  'Ġinvent': 8067,
#  'Ġlistened': 16399,
#  'Ġentails': 35445,
#  'Ġreservoir': 22115,
#  'gap': 43554,
#  'lex': 2588,
#  'Chinese': 23604,
#  '))': 4008,
#  'ĠNAT': 10149,
#  'Ġtracts': 42385,
#  'ĠURI': 43975,
#  'Ġattorney': 6136,
#  'prefix': 40290,
#  'Fuel': 42663,
#  'ĠElon': 32451,
#  'Ġblacks': 15102,
#  'ĠWRITE': 44423,
#  'Cele': 42741,
#  'Ġcompress': 27413,
#  'Ġunfolding': 34502,
#  'Ġbinds': 37354,
#  'Ġconduit': 44457,
#  'ĠPerry': 14105,
#  'Ġstorefront': 45527,
#  'jon': 46286,
#  'Ġliving': 2877,
#  '613': 47512,
#  'Ġpermission': 7170,
#  'Ġshoots': 20611,
#  'ĠIncome': 19003,
#  'Ġissuing': 19089,
#  'Ġpicture': 4286,
#  'IER': 38311,
#  'Ġqualifier': 39265,
#  'ĠDion': 29628,
#  'Ġbicycl': 48094,
#  'Ġfulfill': 14658,
#  'Ġarchaeological': 30971,
#  'ĠMelody': 38906,
#  'ĠDrama': 30647,
#  'Ġviewers': 10209,
#  'ĠSaving': 34689,
#  'Ohio': 31274,
#  'FUN': 42296,
#  'Ġworn': 12666,
#  'ĠAr': 943,
#  'iration': 15297,
#  'Ġwarrior': 16491,
#  'Ġimplicit': 16992,
#  'ĠProtest': 17801,
#  'Ġvolunteer': 13904,
#  'Ġblows': 20385,
#  'ĠThing': 21561,
#  'exper': 23100,
#  'ĠBRE': 29377,
#  'ĠRomance': 36555,
#  'CW': 43538,
#  'ĠGPA': 45283,
#  '------------------------------------------------': 47232,
#  'painted': 47351,
#  'Ġviewed': 9569,
#  'BILL': 39888,
#  'Ġinnate': 28690,
#  'ĠIT': 7283,
#  '458': 29334,
#  'Ġone': 530,
#  'Ġes': 1658,
#  'Ġalienated': 41258,
#  'ĠPopulation': 20133,
#  'detail': 49170,
#  'Ġfraught': 39730,
#  'STAT': 35744,
#  'Ġentering': 8218,
#  'Ġcircled': 48149,
#  'Ġskulls': 38556,
#  'Ġcoordinating': 35449,
#  '1968': 42246,
#  'mington': 39773,
#  '240': 16102,
#  'sing': 12215,
#  '730': 43916,
#  'ĠRecomm': 19237,
#  'Ġgreen': 4077,
#  'ulating': 8306,
#  'ĠPract': 13672,
#  'ĠWeak': 28788,
#  'Ġcontain': 3994,
#  'ky': 2584,
#  'econom': 13926,
#  'hill': 12639,
#  'ĠAnniversary': 21967,
#  'ĠStr': 4285,
#  'ourney': 5604,
#  'ĠRose': 8049,
#  'Ġdigest': 16274,
#  'Ġaccessing': 22534,
#  'taking': 26103,
#  'Ġfloated': 29742,
#  'Ġproducing': 9194,
#  'ãĤĮ': 39258,
#  'UCK': 16696,
#  'Ġ1984': 12844,
#  'bda': 43444,
#  'ĠBAT': 37421,
#  'ĠWhat': 1867,
#  'Ġarm': 3211,
#  'app': 1324,
#  'ĠStarter': 37460,
#  'ĠLena': 44131,
#  'Ġfateful': 46873,
#  'Champ': 48507,
#  'Ġfootball': 4346,
#  'ĠGuatemala': 32183,
#  'emphasis': 36663,
#  'Center': 23656,
#  'debug': 24442,
#  'ĠPope': 13258,
#  'Ġreferences': 10288,
#  'Ġpursuing': 15461,
#  'ears': 4127,
#  'Ġdive': 15647,
#  'ĠPant': 11427,
#  'ĠREUTERS': 15862,
#  '¿': 123,
#  'iker': 18320,
#  'Ġworm': 23849,
#  'Ġmedals': 28057,
#  'ĠInstr': 27901,
#  'Ġbreed': 15939,
#  'Ġmind': 2000,
#  'mber': 1916,
#  'Ġcomparisons': 17909,
#  'Ġessentially': 6986,
#  'esar': 18964,
#  'function': 8818,
#  'Inv': 19904,
#  'Ġswear': 21192,
#  'meter': 27231,
#  'ĠHomer': 28440,
#  'Ġcapac': 18457,
#  'rosso': 21074,
#  'uctor': 33029,
#  'Ġchildren': 1751,
#  'Wow': 22017,
#  'ĠRunning': 18162,
#  'ĠBed': 15585,
#  'Y': 56,
#  'Ġaccumulated': 22425,
#  'Ġvou': 25211,
#  'Ġd': 288,
#  'Ġsubmit': 9199,
#  'Ġstalking': 34683,
#  'Ġcharismatic': 34996,
#  'Ġsmear': 35180,
#  'Ġfro': 8400,
#  'Äĩ': 38325,
#  'ĠHemisphere': 42811,
#  'Ġfulfillment': 32402,
#  'ĠMen': 6065,
#  'Ġtextbooks': 31814,
#  'Advertisement': 4723,
#  'ĠCO': 7375,
#  'ĠKab': 28793,
#  'Ġslut': 33526,
#  'ĠChanging': 33680,
#  'Call': 14134,
#  'Ġabolished': 32424,
#  'Ġexpended': 37328,
#  'plugins': 37390,
#  'hub': 40140,
#  'vill': 41082,
#  'ĠNaw': 41179,
#  'cake': 30560,
#  'Folder': 41092,
#  'ensions': 5736,
#  'Ġcollaborating': 38152,
#  'Ġperiodically': 26034,
#  'Ġunsigned': 22165,
#  'Ġmockery': 42935,
#  'ĠSab': 9910,
#  'XM': 37643,
#  'ĠLionel': 44286,
#  'Ġcardio': 47926,
#  'Ġshenanigans': 48949,
#  'raised': 49309,
#  'ĠInventory': 35772,
#  'Ġ325': 29524,
#  'Ġmorphine': 43948,
#  'ĠLair': 15067,
#  'ĠEither': 15467,
#  'ĠWhole': 23431,
#  'ĠTill': 17888,
#  'ĠISI': 22048,
#  '644': 29173,
#  'lene': 29466,
#  'Ġatten': 31919,
#  'Ġ04': 8702,
#  'ĠSixth': 28980,
#  'thritis': 34043,
#  'ĠMorrow': 34693,
#  'Ġbranding': 24150,
#  'Sah': 32194,
#  'Ġsmashed': 23354,
#  'ĠReserved': 33876,
#  'ĠLambert': 36978,
#  'ĠUk': 5065,
#  'ĠSales': 17329,
#  'Ġpatri': 12650,
#  'different': 39799,
#  'QB': 40291,
#  'Kal': 41428,
#  'ĠBurning': 21460,
#  'facing': 29532,
#  '-+': 19529,
#  'ĠSamp': 42168,
#  'ĠForest': 9115,
#  'ĠARE': 15986,
#  'ĠNone': 6045,
#  'Basic': 26416,
#  'ĠYe': 11609,
#  'rend': 10920,
#  'z': 89,
#  'Ġinvaded': 26466,
#  'Ġexhaustive': 36049,
#  'ĠWebb': 25130,
#  'Ġgenius': 15632,
#  'ĠOst': 38919,
#  'ĠWah': 35893,
#  'Ġ414': 45900,
#  'ley': 1636,
#  'Additional': 17699,
#  'ĠWorm': 28505,
#  'ĠDG': 46133,
#  'ĠAless': 47319,
#  'NP': 22182,
#  'Ġpony': 26902,
#  'Ġguardians': 32769,
#  'Ġoutlet': 16615,
#  'olly': 5098,
#  'Ġconsumes': 37225,
#  'Ġ(+': 11502,
#  'Ġaliens': 16269,
#  'Ġacute': 14352,
#  'Farm': 48412,
#  'Ġstadiums': 37924,
#  'ĠCrossing': 31910,
#  'iece': 8535,
#  '027': 44698,
#  'Ġseafood': 31473,
#  'Ġsucks': 22523,
#  'Ġlegislature': 15928,
#  'eco': 47704,
#  'Ġshifts': 15381,
#  'Ġprohibiting': 30363,
#  'Ġflank': 30172,
#  'ĠSpan': 49101,
#  'Ġ2021': 33448,
#  'ampa': 13299,
#  'Ġconstituencies': 43742,
#  'Ġindictment': 19975,
#  'Ġexplanatory': 44742,
#  'Ġbundle': 18537,
#  'ĠGast': 31486,
#  'ĠConcepts': 50053,
#  'rier': 5277,
#  'Ġunmatched': 48621,
#  'ĠData': 6060,
#  '348': 28978,
#  'very': 548,
#  'Ġposit': 46436,
#  'ĠUSL': 44072,
#  'Ġorigins': 15587,
#  'IST': 8808,
#  'Ġyears': 812,
#  'ĠScroll': 17428,
#  'get': 1136,
#  'Ġpenetrate': 28302,
#  'Ġappe': 35787,
#  'dropping': 37554,
#  'secondary': 38238,
#  'Ġbil': 47027,
#  'ĠTick': 46093,
#  'sov': 47272,
#  'ĠCox': 18014,
#  'Ġprincipled': 48070,
#  'Ġmaster': 4958,
#  'His': 6653,
#  'Ġnick': 14428,
#  'country': 19315,
#  'eros': 27498,
#  'ĠAchilles': 39561,
#  'Ġcohorts': 40182,
#  'eller': 12368,
#  'Ġpredictably': 45741,
#  'Ġprincip': 26303,
#  'ĠRoyale': 49982,
#  'Ġadren': 26999,
#  'Ġinternal': 5387,
#  'Ġstirred': 33091,
#  'oler': 13625,
#  'ĠFollowing': 14207,
#  'Ġribbon': 29092,
#  'ĠStartup': 40472,
#  'ĠAlas': 45315,
#  'arr': 3258,
#  'liness': 26061,
#  'ccording': 2941,
#  'Ġinflammatory': 23760,
#  'OLOG': 33462,
#  'Ġdispose': 34291,
#  'light': 2971,
#  'Ġassorted': 46603,
#  'ĠWaiting': 39669,
#  'Ġperpendicular': 47190,
#  '=]': 48874,
#  'Ġguid': 10103,
#  'Ġrip': 18344,
#  'Ġannexation': 41329,
#  'Ġinterviewer': 39877,
#  'Ġprinciples': 7811,
#  'ĠDemon': 7814,
#  'Ġ115': 12279,
#  'integer': 41433,
#  'Ġbrilliant': 10457,
#  'Ġeth': 4555,
#  'ĠFrance': 4881,
#  'Address': 20231,
#  'ĠMonaco': 31630,
#  'Ġrarity': 32823,
#  'Ġaiding': 37221,
#  'Ġviolet': 45725,
#  'anks': 2283,
#  'ishing': 3929,
#  'ĠCT': 16356,
#  'ĠWhenever': 21326,
#  'Calling': 48593,
#  'Ġsince': 1201,
#  'tyard': 30308,
#  'Topic': 33221,
#  'ĠStellar': 39336,
#  'Advertisements': 14592,
#  'Ġregretted': 44652,
#  'encers': 42288,
#  'empl': 18856,
#  'Moon': 31640,
#  'Ġcomic': 9048,
#  'ĠMermaid': 45523,
#  'ĠRights': 6923,
#  'az': 1031,
#  'episode': 38668,
#  'ĠRoy': 9817,
#  'Ġbc': 47125,
#  'ENTS': 15365,
#  'ĠFlash': 9973,
#  'nih': 37373,
#  'Ġdrawing': 8263,
#  'ĠCosts': 36845,
#  'ĠRape': 35286,
#  'ly': 306,
#  'OVER': 41983,
#  'ĠALS': 27249,
#  'Ã¡s': 40138,
#  'Ġrefreshed': 47193,
#  'Ġspirituality': 39409,
#  'iculture': 47428,
#  'riger': 18096,
#  'Ret': 9781,
#  'Welcome': 14618,
#  '603': 35642,
#  'Ġcrisp': 23453,
#  'ĠHarm': 17925,
#  'Discover': 44596,
#  'Ġinsider': 25851,
#  'Ġshun': 32814,
#  'Ġpathways': 22963,
#  'Ġwage': 7699,
#  'ĠGord': 39592,
#  'Know': 23812,
#  'Ġconfused': 10416,
#  'ĠHampton': 36852,
#  'Ñı': 40623,
#  'Ġdoubtful': 31608,
#  'Ġinterruption': 41728,
#  'Ġreconcil': 40534,
#  'Ġangrily': 34425,
#  'Ġcreating': 4441,
#  'ĠSE': 7946,
#  'Ġdefendant': 11304,
#  'Ġstorytelling': 23689,
#  'Ġdeficient': 40043,
#  'ĠReplace': 40177,
#  'Ġelectron': 11538,
#  'ĠNazis': 19147,
#  'Ġdemocracies': 40416,
#  'meric': 946,
#  'ĠEduc': 7005,
#  'Ther': 35048,
#  'ĠUDP': 36428,
#  'Ġeducated': 15657,
#  'Ġvacated': 46346,
#  'Ġtheorem': 44728,
#  'Ġinterchange': 26478,
#  'ĠXV': 29922,
#  'Ġfolded': 24650,
#  'Ġfer': 11354,
#  'verning': 13974,
#  'ĠTalent': 29505,
#  'ĠEcc': 38308,
#  'irection': 4154,
#  'Mac': 14155,
#  'packing': 41291,
#  'afe': 8635,
#  'Mc': 9742,
#  'Ġbar': 2318,
#  'aries': 3166,
#  'Ġstagnant': 41391,
#  'Ns': 47503,
#  'ĠPaper': 14962,
#  'ĠSummit': 20014,
#  'Ġunpredict': 20378,
#  'osaurs': 22344,
#  'Ġcurrencies': 19247,
#  'vp': 36133,
#  'andering': 42454,
#  'Ġreactions': 12737,
#  'ĠAustria': 17322,
#  'Ġmisuse': 29169,
#  'Today': 8888,
#  'Davis': 36462,
#  'Tra': 15721,
#  'ĠAreas': 38662,
#  'angan': 37089,
#  'Ġpoliceman': 32166,
#  'Http': 43481,
#  'public': 11377,
#  'SO': 15821,
#  '714': 45722,
#  'ĠRET': 30826,
#  'Ġvict': 2210,
#  'Ġgraz': 32703,
#  'Yeah': 10995,
#  'des': 8906,
#  'Ġencouraged': 10085,
#  'ummer': 31647,
#  'adem': 36920,
#  'Ġvisit': 3187,
#  'Edge': 37021,
#  'Ġaest': 14606,
#  'Thom': 37582,
#  'ĠCasting': 39285,
#  'ĠMarlins': 38134,
#  'Directory': 43055,
#  'CHO': 44899,
#  'Ġstip': 22111,
#  'Ġlun': 14678,
#  'å': 161,
#  'arsh': 5406,
#  'egu': 15703,
#  '113': 16616,
#  'Ġaspire': 42926,
#  'ĠâĹı': 48049,
#  'ognitive': 46610,
#  'ĠColon': 14049,
#  'should': 21754,
#  'Years': 40630,
#  '(&': 39434,
#  'UM': 5883,
#  '213': 26427,
#  'Â©': 16224,
#  'pos': 1930,
#  'oked': 6545,
#  'Ġanimated': 15108,
#  'Ġspores': 47306,
#  'ĠMight': 24213,
#  'Ġarch': 3934,
#  'ussian': 31562,
#  'ĠClosing': 47055,
#  'elvet': 32667,
#  'Ġresearcher': 13453,
#  'VEN': 28290,
#  'ĠLah': 30693,
#  'ĠâĢĶ': 851,
#  'ĠGors': 34926,
#  'trump': 40954,
#  'ĠEuph': 47441,
#  'Ġuber': 48110,
#  'ĠGD': 27044,
#  'Stud': 13007,
#  'ĠLamp': 28607,
#  'Ġhood': 14263,
#  'ĠHanson': 35692,
#  'Ġawful': 12659,
#  'Ġfile': 2393,
#  'Ġtallest': 38760,
#  'Children': 26829,
#  'Ġcanonical': 40091,
#  'Ġgraphical': 27831,
#  'Ġ415': 40643,
#  'Otherwise': 48059,
#  'ĠGenocide': 48721,
#  'ĠEffect': 7896,
#  'Cast': 19248,
#  'Ġmartyr': 28009,
#  'ĠNort': 15209,
#  'Ġtherapists': 39395,
#  '!).': 19588,
#  'ĠLone': 23405,
#  'Ġprominently': 31015,
#  'Gordon': 47073,
#  'Ġmeticulous': 47628,
#  'Ġspecifics': 23514,
#  'ĠAware': 32828,
#  'Alt': 29161,
#  'Ġmos': 10867,
#  'Fortunately': 31276,
#  'Ġstewards': 38030,
#  'ĠYards': 42673,
#  'CON': 10943,
#  'TE': 9328,
#  'HAHAHAHA': 39021,
#  'Woman': 48081,
#  'lord': 10572,
#  'boat': 24482,
#  'Ba': 34458,
#  'Ġairs': 37112,
#  'Ġquer': 42517,
#  'sufficient': 46790,
#  'Ġunderstandably': 36250,
#  'Ġmascara': 48430,
#  'Ġcortisol': 41547,
#  '046': 45438,
#  'Ġbestselling': 47791,
#  'entially': 3746,
#  'Ġmillenn': 15755,
#  'ĠThey': 1119,
#  'Brazil': 39190,
#  'ĠPolicy': 7820,
#  '747': 48882,
#  'Ġpraised': 15342,
#  '1500': 33698,
#  'ĠHeader': 48900,
#  'ertodd': 36481,
#  'Ġabsorb': 17565,
#  'Ġhoused': 23707,
#  'ĠBrun': 15700,
#  'ĠRP': 25812,
#  'Ġshortstop': 40388,
#  'Ġ[*': 30138,
#  'ĠShy': 36838,
#  'Ġdeployments': 40854,
#  'IRO': 43708,
#  'Ġsem': 5026,
#  'Ġpaths': 13532,
#  'Ġpoll': 3278,
#  'pract': 29152,
#  'Palestinian': 35969,
#  'ĠBal': 8528,
#  'Ġsmoking': 9216,
#  'Ġfringe': 26821,
#  'ĠEmb': 13302,
#  'ĠOman': 41782,
#  'ĠTraps': 44110,
#  'ikuman': 42889,
#  'Ġcreated': 2727,
#  'ĠSixers': 46321,
#  'eem': 13761,
#  'gram': 4546,
#  'Ġcert': 5051,
#  'Ġrebel': 14034,
#  'ĠTheresa': 20251,
#  'ĠInfinity': 22385,
#  'lesi': 36027,
#  'ĠPresents': 47102,
#  'imil': 26641,
#  'ĠCK': 45233,
#  'ĠCreep': 41682,
#  'Ġgive': 1577,
#  'Ġpleasure': 9476,
#  'ĠPopular': 22623,
#  'ĠNPCs': 28167,
#  'Ġoperative': 28609,
#  'Ġpavement': 31726,
#  'ĠTasman': 29958,
#  'Ġ196': 28817,
#  'ĠParticipation': 34408,
#  'Ã¦': 21241,
#  'edar': 44226,
#  'Ġviability': 32141,
#  '¯': 107,
#  'Ġsurpassed': 30612,
#  '688': 34427,
#  'Ġgood': 922,
#  'Ġaph': 49812,
#  'ĠVikings': 16420,
#  '994': 42691,
#  'ĠAlf': 17136,
#  'Ġcomplaining': 18705,
#  'ĠGrand': 5675,
#  'even': 10197,
#  'ĠCube': 23315,
#  'mL': 32087,
#  'Ġcenturies': 10675,
#  're': 260,
#  'Ġ1906': 40538,
#  'bay': 24406,
#  'nesium': 27619,
#  'induced': 17223,
#  'ĠMartian': 32508,
#  'ĠStim': 41669,
#  'ĠSicily': 49301,
#  'Ġcorrid': 16080,
#  'Ġincrement': 18703,
#  'ĠSpeaker': 14931,
#  'stant': 18797,
#  'enza': 23674,
#  'Private': 29067,
#  'Ġdetach': 48224,
#  'Ġcustody': 10804,
#  'Ġavenues': 34265,
#  'ãĤ½': 47559,
#  'Ġcounty': 7968,
#  'Ġ1860': 37637,
#  'operated': 42767,
#  'Ġold': 1468,
#  'Ġsides': 5389,
#  'Ġformally': 15832,
#  'Ġwielded': 42459,
#  'ADE': 19266,
#  'ĠBry': 9092,
#  'Ġcustoms': 17112,
#  'ĠCynthia': 40897,
#  ...}

# %% [markdown]
# ### Test of different tokenizer
#
# Mögliche Modelle:
# * https://huggingface.co/models?pipeline_tag=text-classification&sort=downloads

# %% [markdown]
# Aufgabe: Suche ein deutsches Modell und vergleiche das Ergebnis der Tokenisierung
