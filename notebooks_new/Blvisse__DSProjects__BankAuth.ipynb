# %% [markdown]
# <a href="https://colab.research.google.com/github/Blvisse/DSProjects/blob/master/BankAuth.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from google.colab import files

# %%
files.upload()
# Out:
#      <input type="file" id="files-dcc63a38-a21f-4225-ad1e-01427d1a6526" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-dcc63a38-a21f-4225-ad1e-01427d1a6526">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving BankNote_Authentication.csv to BankNote_Authentication.csv
# {'BankNote_Authentication.csv': b'variance,skewness,curtosis,entropy,class\r\n3.6216,8.6661,-2.8073,-0.44699,0\r\n4.5459,8.1674,-2.4586,-1.4621,0\r\n3.866,-2.6383,1.9242,0.10645,0\r\n3.4566,9.5228,-4.0112,-3.5944,0\r\n0.32924,-4.4552,4.5718,-0.9888,0\r\n4.3684,9.6718,-3.9606,-3.1625,0\r\n3.5912,3.0129,0.72888,0.56421,0\r\n2.0922,-6.81,8.4636,-0.60216,0\r\n3.2032,5.7588,-0.75345,-0.61251,0\r\n1.5356,9.1772,-2.2718,-0.73535,0\r\n1.2247,8.7779,-2.2135,-0.80647,0\r\n3.9899,-2.7066,2.3946,0.86291,0\r\n1.8993,7.6625,0.15394,-3.1108,0\r\n-1.5768,10.843,2.5462,-2.9362,0\r\n3.404,8.7261,-2.9915,-0.57242,0\r\n4.6765,-3.3895,3.4896,1.4771,0\r\n2.6719,3.0646,0.37158,0.58619,0\r\n0.80355,2.8473,4.3439,0.6017,0\r\n1.4479,-4.8794,8.3428,-2.1086,0\r\n5.2423,11.0272,-4.353,-4.1013,0\r\n5.7867,7.8902,-2.6196,-0.48708,0\r\n0.3292,-4.4552,4.5718,-0.9888,0\r\n3.9362,10.1622,-3.8235,-4.0172,0\r\n0.93584,8.8855,-1.6831,-1.6599,0\r\n4.4338,9.887,-4.6795,-3.7483,0\r\n0.7057,-5.4981,8.3368,-2.8715,0\r\n1.1432,-3.7413,5.5777,-0.63578,0\r\n-0.38214,8.3909,2.1624,-3.7405,0\r\n6.5633,9.8187,-4.4113,-3.2258,0\r\n4.8906,-3.3584,3.4202,1.0905,0\r\n-0.24811,-0.17797,4.9068,0.15429,0\r\n1.4884,3.6274,3.308,0.48921,0\r\n4.2969,7.617,-2.3874,-0.96164,0\r\n-0.96511,9.4111,1.7305,-4.8629,0\r\n-1.6162,0.80908,8.1628,0.60817,0\r\n2.4391,6.4417,-0.80743,-0.69139,0\r\n2.6881,6.0195,-0.46641,-0.69268,0\r\n3.6289,0.81322,1.6277,0.77627,0\r\n4.5679,3.1929,-2.1055,0.29653,0\r\n3.4805,9.7008,-3.7541,-3.4379,0\r\n4.1711,8.722,-3.0224,-0.59699,0\r\n-0.2062,9.2207,-3.7044,-6.8103,0\r\n-0.0068919,9.2931,-0.41243,-1.9638,0\r\n0.96441,5.8395,2.3235,0.066365,0\r\n2.8561,6.9176,-0.79372,0.48403,0\r\n-0.7869,9.5663,-3.7867,-7.5034,0\r\n2.0843,6.6258,0.48382,-2.2134,0\r\n-0.7869,9.5663,-3.7867,-7.5034,0\r\n3.9102,6.065,-2.4534,-0.68234,0\r\n1.6349,3.286,2.8753,0.087054,0\r\n4.3239,-4.8835,3.4356,-0.5776,0\r\n5.262
# %%
data=pd.read_csv('BankNote_Authentication.csv')

# %%
data.head()
# Out:
#    variance  skewness  curtosis  entropy  class
# 0   3.62160    8.6661   -2.8073 -0.44699      0
# 1   4.54590    8.1674   -2.4586 -1.46210      0
# 2   3.86600   -2.6383    1.9242  0.10645      0
# 3   3.45660    9.5228   -4.0112 -3.59440      0
# 4   0.32924   -4.4552    4.5718 -0.98880      0

# %%
data.isnull().sum()
# Out:
# variance    0
# skewness    0
# curtosis    0
# entropy     0
# class       0
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1372 entries, 0 to 1371
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   variance  1372 non-null   float64
#  1   skewness  1372 non-null   float64
#  2   curtosis  1372 non-null   float64
#  3   entropy   1372 non-null   float64
#  4   class     1372 non-null   int64
# dtypes: float64(4), int64(1)
# memory usage: 53.7 KB

# %%
data.describe()
# Out:
#           variance     skewness     curtosis      entropy        class
# count  1372.000000  1372.000000  1372.000000  1372.000000  1372.000000
# mean      0.433735     1.922353     1.397627    -1.191657     0.444606
# std       2.842763     5.869047     4.310030     2.101013     0.497103
# min      -7.042100   -13.773100    -5.286100    -8.548200     0.000000
# 25%      -1.773000    -1.708200    -1.574975    -2.413450     0.000000
# 50%       0.496180     2.319650     0.616630    -0.586650     0.000000
# 75%       2.821475     6.814625     3.179250     0.394810     1.000000
# max       6.824800    12.951600    17.927400     2.449500     1.000000

# %%
import seaborn as sns
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
sns.heatmap(data.corr(),annot=True)

# %%
sns.scatterplot(data=data,x='variance',y='class')

# %%
sns.countplot(data=data,x='class')

# %%
sns.distplot(a=data['class'],kde=False)

# %%
sns.kdeplot(data=data['class'],shade=True)

# %%
X=data.iloc[:,:-1]
y=data.iloc[:,-1]

# %%
X
# Out:
#       variance  skewness  curtosis  entropy
# 0      3.62160   8.66610   -2.8073 -0.44699
# 1      4.54590   8.16740   -2.4586 -1.46210
# 2      3.86600  -2.63830    1.9242  0.10645
# 3      3.45660   9.52280   -4.0112 -3.59440
# 4      0.32924  -4.45520    4.5718 -0.98880
# ...        ...       ...       ...      ...
# 1367   0.40614   1.34920   -1.4501 -0.55949
# 1368  -1.38870  -4.87730    6.4774  0.34179
# 1369  -3.75030 -13.45860   17.5932 -2.77710
# 1370  -3.56370  -8.38270   12.3930 -1.28230
# 1371  -2.54190  -0.65804    2.6842  1.19520
#
# [1372 rows x 4 columns]

# %%
y
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 1367    1
# 1368    1
# 1369    1
# 1370    1
# 1371    1
# Name: class, Length: 1372, dtype: int64

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.3)

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
import lightgbm as lgb
import

# %%
from sklearn.model_selection import GridSearchCV

# %%
scaler=StandardScaler()

# %%
scaler.fit(X_train)
X_train=scaler.transform(X_train)
X_test=scaler.transform(X_test)

# %%
X_train
# Out:
# array([[-2.75859469e-03, -2.65345190e-01, -5.23948417e-01,
#          1.00867393e+00],
#        [ 4.54033168e-02,  5.86365657e-01, -7.47094534e-02,
#          3.19918558e-01],
#        [-6.01890383e-01, -5.26688075e-01,  2.06913924e-01,
#          9.14606661e-01],
#        ...,
#        [-4.58069217e-01, -2.87540866e-01, -3.33316324e-01,
#          3.53421832e-01],
#        [-2.41292875e+00,  1.29628473e+00, -3.22624900e-01,
#         -2.85067009e+00],
#        [-1.27381101e-01, -8.91137306e-01, -2.29066808e-03,
#          1.20584698e+00]])

# %%
RFC=RandomForestClassifier()
parameters={'n_estimators':[100,150,50,200],'random_state':[0,7,8,9,10]}
randomFC=GridSearchCV(RFC,param_grid=parameters,scoring='f1',cv=5)
randomFC.fit(X_train,y_train)
# Out:
# GridSearchCV(cv=5, error_score=nan,
#              estimator=RandomForestClassifier(bootstrap=True, ccp_alpha=0.0,
#                                               class_weight=None,
#                                               criterion='gini', max_depth=None,
#                                               max_features='auto',
#                                               max_leaf_nodes=None,
#                                               max_samples=None,
#                                               min_impurity_decrease=0.0,
#                                               min_impurity_split=None,
#                                               min_samples_leaf=1,
#                                               min_samples_split=2,
#                                               min_weight_fraction_leaf=0.0,
#                                               n_estimators=100, n_jobs=None,
#                                               oob_score=False,
#                                               random_state=None, verbose=0,
#                                               warm_start=False),
#              iid='deprecated', n_jobs=None,
#              param_grid={'n_estimators': [100, 150, 50, 200],
#                          'random_state': [0, 7, 8, 9, 10]},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring='f1', verbose=0)

# %%
print(randomFC.best_params_)
# Out:
# {'n_estimators': 100, 'random_state': 7}

# %%
print(randomFC.best_score_)
# Out:
# 0.993076638843138

# %%
lgbC=lgb.LGBMClassifier()
param_grid={'learning_rate':[0.1,0.001,1],
            'n_estimators':[50,100,150],
            'boosting_type':['gbdt','dart'],
            'num_leaves':[15,31,50]}
gridSearch=GridSearchCV(lgbC,param_grid=param_grid,scoring=['accuracy','f1'],refit='f1',verbose=100)
gridSearch.fit(X_train,y_train)
# Out:
# Fitting 5 folds for each of 54 candidates, totalling 270 fits
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV] boosting_type=gbdt, learning_rate=0.1, n_estimators=50, num_leaves=15
# [CV]  boosting_type=gbdt, learning_rate=0.1, n_estimators=50, num_leaves=15, accuracy=1.000, f1=1.000, total=   0.0s
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [CV] boosting_type=gbdt, learning_rate=0.1, n_estimators=50, num_leaves=15
# [CV]  boosting_type=gbdt, learning_rate=0.1, n_estimators=50, num_leaves=15, accuracy=0.990, f1=0.988, total=   0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.1s remaining:    0.0s
# [CV] boosting_type=gbdt, learning_rate=0.1, n_estimators=50, num_leaves=15
# [CV]  boosting_type=gbdt, learning_rate=0.1, n_estimators=50, num_leaves=15, accuracy=0.969, f1=0.965, total=   0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.1s remaining:    0.0s
# [CV] boosting_type=gbdt, learning_rate=0.1, n_estimators=50, num_leaves=15
# [CV]  boosting_type=gbdt, learning_rate=0.1, n_estimators=50, num_leaves=15, accuracy=0.995, f1=0.994, total=   0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.1s remaining:    0.0s
# [CV] boosting_type=gbdt, learning_rate=0.1, n_estimators=50, num_leaves=15
# [CV]  boosting_type=gbdt, learning_rate=0.1, n_estimators=50, num_leaves=15, accuracy=1.000, f1=1.000, total=   0.0s
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:    0.2s remaining:    0.0s
# [CV] boosting_type=gbdt, learning_rate=0.1, n_estimators=50, num_leaves=31
# [CV]  boosting_type=gbdt, learning_rate=0.1, n_estimators=50, num_leaves=31, accuracy=1.000, f1=1.000, total=   0.0s
# [Parallel(n_jobs=1)]: Done   6 out of   6 | elapsed:    0.2s remaining:    0.0s
# [CV] boosting_type=gbdt, learning_rate=0.1, n_estimators=50, num_leaves=31
# [CV]  boosting_type=gbdt, learning_rate=0.1, n_estimators=50, num_leaves=31, accuracy=0.995, f1=0.994, total=   0.0s
# [Parallel(n_jobs=1)]: Done   7 out of   7 | elapsed:    0.3s remaining:    0.0s
# [CV] boosting_type=gbdt, learning_rate=0.1, n_estimators=50, num_leaves=31
# [CV]  boosting_type=gbdt, learning_rate=0.1, n_estimators=50, num_leaves=31, accuracy=0.969, f1=0.965, total=   0.0s
# [Parallel(n_jobs=1)]: Done   8 out of   8 | elapsed:    0.3s remaining:    0.0s
# [CV] boosting_type=gbdt, learning_rate=0.1, n_estimators=50, num_leaves=31
# [CV]  boosting_type=gbdt, learning_rate=0.1, n_estimators=50, num_leaves=31, accuracy=0.995, f1=0.994, total=   0.0s
# [Parallel(n_jobs=1)]: Done   9 out of   9 | elapsed:    0.3s remaining:    0.0s
# [CV] boosting_type=gbdt, learning_rate=0.1, n_estimators=50, num_leaves=31
# [CV]  boosting_type=gbdt, learning_rate=0.1, n_estimators=50, num_leaves=31, accuracy=1.000, f1=1.000, total=   0.0s
# [Parallel(n_jobs=1)]: Done  10 out of  10 | elapsed:    0.4s remaining:    0.0s
# [CV] boosting_type=gbdt, learning_rate=0.1, n_estimators=50, num_leaves=50
# [CV]  boosting_type=gbdt, learning_rate=0.1, n_estimators=50, num_leaves=50, accuracy=1.000, f1=1.000, total=   0.0s
# [Parallel(n_jobs=1)]: Done  11 out of  11 | elapsed:    0.4s remaining:    0.0s
# [CV] boosting_type=gbdt, learning_rate=0.1, n_estimators=50, num_leaves=50
# [CV]  boosting_type=gbdt, learning_rate=0.1, n_estimators=50, num_leaves=50, accuracy=0.995, f1=0.994, total=   0.0s
# [Parallel(n_jobs=1)]: Done  12 out of  12 | elapsed:    0.5s remaining:    0.0s
# [CV] boosting_type=gbdt, learning_rate=0.1, n_estimators=50, num_leaves=50
# [CV]  boosting_type=gbdt, learning_rate=0.1, n_estimators=50, num_leaves=50, accuracy=0.969, f1=0.965, total=   0.0s
# [Parallel(n_jobs=1)]: Done  13 out of  13 | elapsed:    0.5s remaining:    0.0s
# [CV] boosting_type=gbdt, learning_rate=0.1, n_estimators=50, num_leaves=50
# [CV]  boosting_type=gbdt, learning_rate=0.1, n_estimators=50, num_leaves=50, accuracy=0.995, f1=0.994, total=   0.0s
# [Parallel(n_jobs=1)]: Done  14 out of  14 | elapsed:    0.6s remaining:    0.0s
# [CV] boosting_type=gbdt, learning_rate=0.1, n_estimators=50, num_leaves=50
# [CV]  boosting_type=gbdt, learning_rate=0.1, n_estimators=50, num_leaves=50, accuracy=1.000, f1=1.000, total=   0.0s
# [Parallel(n_jobs=1)]: Done  15 out of  15 | elapsed:    0.6s remaining:    0.0s
# [CV] boosting_type=gbdt, learning_rate=0.1, n_estimators=100, num_leaves=15
# [CV]  boosting_type=gbdt, learning_rate=0.1, n_estimators=100, num_leaves=15, accuracy=1.000, f1=1.000, total=   0.1s
# [Parallel(n_jobs=1)]: Done  16 out of  16 | elapsed:    0.7s remaining:    0.0s
# [CV] boosting_type=gbdt, learning_rate=0.1, n_estimators=100, num_leaves=15
# [CV]  boosting_type=gbdt, learning_rate=0.1, n_estimators=100, num_leaves=15, accuracy=0.990, f1=0.988, total=   0.0s
# [Parallel(n_jobs=1)]: Done  17 out of  17 | elapsed:    0.7s remaining:    0.0s
# [CV] boosting_type=gbdt, learning_rate=0.1, n_estimators=100, num_leaves=15
# [CV]  boosting_type=gbdt, learning_rate=0.1, n_estimators=100, num_leaves=15, accuracy=0.969, f1=0.965, total=   0.0s
# [Parallel(n_jobs=1)]: Done  18 out of  18 | elapsed:    0.8s remaining:    0.0s
# [CV] boosting_type=gbdt, learning_rate=0.1, n_estimators=100, num_leaves=15
# [CV]  boosting_type=gbdt, learning_rate=0.1, n_estimators=100, num_leaves=15, accuracy=0.984, f1=0.982, total=   0.0s
# [Parallel(n_jobs=1)]: Done  19 out of  19 | elapsed:    0.8s remaining:    0.0s
# [CV] boosting_type=gbdt, learning_rate=0.1, n_estimators=100, num_leaves=15
# [CV]  boosting_type=gbdt, learning_rate=0.1, n_estimators=100, num_leaves=15, accuracy=1.000, f1=1.000, total=   0.0s
# [Parallel(n_jobs=1)]: Done  20 out of  20 | elapsed:    0.8s remaining:    0.0s
# [CV] boosting_type=gbdt, learning_rate=0.1, n_estimators=100, num_leaves=31
# [CV]  boosting_type=gbdt, learning_rate=0.1, n_estimators=100, num_leaves=31, accuracy=1.000, f1=1.000, total=   0.1s
# [Parallel(n_jobs=1)]: Done  21 out of  21 | elapsed:    0.9s remaining:    0.0s
# [CV] boosting_type=gbdt, learning_rate=0.1, n_estimators=100, num_leaves=31
# [CV]  boosting_type=gbdt, learning_rate=0.1, n_estimators=100, num_leaves=31, accuracy=0.990, f1=0.988, total=   0.1s
# [Parallel(n_jobs=1)]: Done  22 out of  22 | elapsed:    1.0s remaining:    0.0s
# [CV] boosting_type=gbdt, learning_rate=0.1, n_estimators=100, num_leaves=31
# [CV]  boosting_type=gbdt, learning_rate=0.1, n_estimators=100, num_leaves=31, accuracy=0.969, f1=0.965, total=   0.1s
# [Parallel(n_jobs=1)]: Done  23 out of  23 | elapsed:    1.1s remaining:    0.0s
# [CV] boosting_type=gbdt, learning_rate=0.1, n_estimators=100, num_leaves=31
# [CV]  boosting_type=gbdt, learning_rate=0.1, n_estimators=100, num_leaves=31, accuracy=0.995, f1=0.994, total=   0.1s
# [Parallel(n_jobs=1)]: Done  24 out of  24 | elapsed:    1.2s remaining:    0.0s
# [CV] boosting_type=gbdt, learning_rate=0.1, n_estimators=100, num_leaves=31
# [CV]  boosting_type=gbdt, learning_rate=0.1, n_estimators=100, num_leaves=31, accuracy=1.000, f1=1.000, total=   0.1s
# [Parallel(n_jobs=1)]: Done  25 out of  25 | elapsed:    1.2s remaining:    0.0s
# [CV] boosting_type=gbdt, learning_rate=0.1, n_estimators=100, num_leaves=50
# [CV]  boosting_type=gbdt, learning_rate=0.1, n_estimators=100, num_leaves=50, accuracy=1.000, f1=1.000, total=   0.1s
# [Parallel(n_jobs=1)]: Done  26 out of  26 | elapsed:    1.3s remaining:    0.0s
# [CV] boosting_type=gbdt, learning_rate=0.1, n_estimators=100, num_leaves=50
# [CV]  boosting_type=gbdt, learning_rate=0.1, n_estimators=100, num_leaves=50, accuracy=0.990, f1=0.988, total=   0.1s
# [Parallel(n_jobs=1)]: Done  27 out of  27 | elapsed:    1.4s remaining:    0.0s
# [CV] boosting_type=gbdt, learning_rate=0.1, n_estimators=100, num_leaves=50
# [CV]  boosting_type=gbdt, learning_rate=0.1, n_estimators=100, num_leaves=50, accuracy=0.969, f1=0.965, total=   0.1s
# [Parallel(n_jobs=1)]: Done  28 out of  28 | elapsed:    1.5s remaining:    0.0s
# [CV] boosting_type=gbdt, learning_rate=0.1, n_estimators=100, num_leaves=50
# [CV]  boosting_type=gbdt, learning_rate=0.1, n_estimators=100, num_leaves=50, accuracy=0.995, f1=0.994, total=   0.1s
# [Parallel(n_jobs=1)]: Done  29 out of  29 | elapsed:    1.5s remaining:    0.0s
# [CV] boosting_type=gbdt, learning_rate=0.1, n_estimators=100, num_leaves=50
# [CV]  boosting_type=gbdt, learning_rate=0.1, n_estimators=100, num_leaves=50, accuracy=1.000, f1=1.000, total=   0.1s
# [Parallel(n_jobs=1)]: Done  30 out of  30 | elapsed:    1.6s remaining:    0.0s
# [CV] boosting_type=gbdt, learning_rate=0.1, n_estimators=150, num_leaves=15
# [CV]  boosting_type=gbdt, learning_rate=0.1, n_estimators=150, num_leaves=15, accuracy=1.000, f1=1.000, total=   0.1s
# [Parallel(n_jobs=1)]: Done  31 out of  31 | elapsed:    1.7s remaining:    0.0s
# [CV] boosting_type=gbdt, learning_rate=0.1, n_estimators=150, num_leaves=15
# [CV]  boosting_type=gbdt, learning_rate=0.1, n_estimators=150, num_leaves=15, accuracy=0.990, f1=0.988, total=   0.1s
# [Parallel(n_jobs=1)]: Done  32 out of  32 | elapsed:    1.7s remaining:    0.0s
# [CV] boosting_type=gbdt, learning_rate=0.1, n_estimators=150, num_leaves=15
# [CV]  boosting_type=gbdt, learning_rate=0.1, n_estimators=150, num_leaves=15, accuracy=0.974, f1=0.970, total=   0.1s
# [Parallel(n_jobs=1)]: Done  33 out of  33 | elapsed:    1.8s remaining:    0.0s
# [CV] boosting_type=gbdt, learning_rate=0.1, n_estimators=150, num_leaves=15
# [CV]  boosting_type=gbdt, learning_rate=0.1, n_estimators=150, num_leaves=15, accuracy=0.990, f1=0.988, total=   0.1s
# [Parallel(n_jobs=1)]: Done  34 out of  34 | elapsed:    1.9s remaining:    0.0s
# [CV] boosting_type=gbdt, learning_rate=0.1, n_estimators=150, num_leaves=15
# [CV]  boosting_type=gbdt, learning_rate=0.1, n_estimators=150, num_leaves=15, accuracy=1.000, f1=1.000, total=   0.1s
# [Parallel(n_jobs=1)]: Done  35 out of  35 | elapsed:    1.9s remaining:    0.0s
# [CV] boosting_type=gbdt, learning_rate=0.1, n_estimators=150, num_leaves=31
# [CV]  boosting_type=gbdt, learning_rate=0.1, n_estimators=150, num_leaves=31, accuracy=1.000, f1=1.000, total=   0.1s
# [Parallel(n_jobs=1)]: Done  36 out of  36 | elapsed:    2.0s remaining:    0.0s
# [CV] boosting_type=gbdt, learning_rate=0.1, n_estimators=150, num_leaves=31
# [CV]  boosting_type=gbdt, learning_rate=0.1, n_estimators=150, num_leaves=31, accuracy=0.990, f1=0.988, total=   0.1s
# [Parallel(n_jobs=1)]: Done  37 out of  37 | elapsed:    2.2s remaining:    0.0s
# [CV] boosting_type=gbdt, learning_rate=0.1, n_estimators=150, num_leaves=31
# [CV]  boosting_type=gbdt, learning_rate=0.1, n_estimators=150, num_leaves=31, accuracy=0.974, f1=0.970, total=   0.1s
# [Parallel(n_jobs=1)]: Done  38 out of  38 | elapsed:    2.2s remaining:    0.0s
# [CV] boosting_type=gbdt, learning_rate=0.1, n_estimators=150, num_leaves=31
# [CV]  boosting_type=gbdt, learning_rate=0.1, n_estimators=150, num_leaves=31, accuracy=0.990, f1=0.988, total=   0.1s
# [Parallel(n_jobs=1)]: Done  39 out of  39 | elapsed:    2.3s remaining:    0.0s
# [CV] boosting_type=gbdt, learning_rate=0.1, n_estimators=150, num_leaves=31
# [CV]  boosting_type=gbdt, learning_rate=0.1, n_estimators=150, num_leaves=31, accuracy=1.000, f1=1.000, total=   0.1s
# [Parallel(n_jobs=1)]: Done  40 out of  40 | elapsed:    2.4s remaining:    0.0s
# [CV] boosting_type=gbdt, learning_rate=0.1, n_estimators=150, num_leaves=50
# [CV]  boosting_type=gbdt, learning_rate=0.1, n_estimators=150, num_leaves=50, accuracy=1.000, f1=1.000, total=   0.1s
# [Parallel(n_jobs=1)]: Done  41 out of  41 | elapsed:    2.5s remaining:    0.0s
# [CV] boosting_type=gbdt, learning_rate=0.1, n_estimators=150, num_leaves=50
# [CV]  boosting_type=gbdt, learning_rate=0.1, n_estimators=150, num_leaves=50, accuracy=0.990, f1=0.988, total=   0.1s
# [Parallel(n_jobs=1)]: Done  42 out of  42 | elapsed:    2.6s remaining:    0.0s
# [CV] boosting_type=gbdt, learning_rate=0.1, n_estimators=150, num_leaves=50
# [CV]  boosting_type=gbdt, learning_rate=0.1, n_estimators=150, num_leaves=50, accuracy=0.974, f1=0.970, total=   0.1s
# [Parallel(n_jobs=1)]: Done  43 out of  43 | elapsed:    2.7s remaining:    0.0s
# [CV] boosting_type=gbdt, learning_rate=0.1, n_estimators=150, num_leaves=50
# [CV]  boosting_type=gbdt, learning_rate=0.1, n_estimators=150, num_leaves=50, accuracy=0.990, f1=0.988, total=   0.1s
# [Parallel(n_jobs=1)]: Done  44 out of  44 | elapsed:    2.8s remaining:    0.0s
# [CV] boosting_type=gbdt, learning_rate=0.1, n_estimators=150, num_leaves=50
# [CV]  boosting_type=gbdt, learning_rate=0.1, n_estimators=150, num_leaves=50, accuracy=1.000, f1=1.000, total=   0.1s
# [Parallel(n_jobs=1)]: Done  45 out of  45 | elapsed:    2.9s remaining:    0.0s
# [CV] boosting_type=gbdt, learning_rate=0.001, n_estimators=50, num_leaves=15
# [CV]  boosting_type=gbdt, learning_rate=0.001, n_estimators=50, num_leaves=15, accuracy=0.552, f1=0.000, total=   0.0s
# [Parallel(n_jobs=1)]: Done  46 out of  46 | elapsed:    2.9s remaining:    0.0s
# [CV] boosting_type=gbdt, learning_rate=0.001, n_estimators=50, num_leaves=15
# [CV]  boosting_type=gbdt, learning_rate=0.001, n_estimators=50, num_leaves=15, accuracy=0.552, f1=0.000, total=   0.0s
# [Parallel(n_jobs=1)]: Done  47 out of  47 | elapsed:    3.0s remaining:    0.0s
# [CV] boosting_type=gbdt, learning_rate=0.001, n_estimators=50, num_leaves=15
# [CV]  boosting_type=gbdt, learning_rate=0.001, n_estimators=50, num_leaves=15, accuracy=0.552, f1=0.000, total=   0.0s
# [Parallel(n_jobs=1)]: Done  48 out of  48 | elapsed:    3.0s remaining:    0.0s
# [CV] boosting_type=gbdt, learning_rate=0.001, n_estimators=50, num_leaves=15
# [CV]  boosting_type=gbdt, learning_rate=0.001, n_estimators=50, num_leaves=15, accuracy=0.557, f1=0.000, total=   0.0s
# [Parallel(n_jobs=1)]: Done  49 out of  49 | elapsed:    3.0s remaining:    0.0s
# [CV] boosting_type=gbdt, learning_rate=0.001, n_estimators=50, num_leaves=15
# [CV]  boosting_type=gbdt, learning_rate=0.001, n_estimators=50, num_leaves=15, accuracy=0.557, f1=0.000, total=   0.0s
# [Parallel(n_jobs=1)]: Done  50 out of  50 | elapsed:    3.1s remaining:    0.0s
# [CV] boosting_type=gbdt, learning_rate=0.001, n_estimators=50, num_leaves=31
# [CV]  boosting_type=gbdt, learning_rate=0.001, n_estimators=50, num_leaves=31, accuracy=0.552, f1=0.000, total=   0.0s
# [Parallel(n_jobs=1)]: Done  51 out of  51 | elapsed:    3.1s remaining:    0.0s
# [CV] boosting_type=gbdt, learning_rate=0.001, n_estimators=50, num_leaves=31
# [CV]  boosting_type=gbdt, learning_rate=0.001, n_estimators=50, num_leaves=31, accuracy=0.552, f1=0.000, total=   0.0s
# [Parallel(n_jobs=1)]: Done  52 out of  52 | elapsed:    3.1s remaining:    0.0s
# [CV] boosting_type=gbdt, learning_rate=0.001, n_estimators=50, num_leaves=31
# [CV]  boosting_type=gbdt, learning_rate=0.001, n_estimators=50, num_leaves=31, accuracy=0.552, f1=0.000, total=   0.0s
# [Parallel(n_jobs=1)]: Done  53 out of  53 | elapsed:    3.2s remaining:    0.0s
# [CV] boosting_type=gbdt, learning_rate=0.001, n_estimators=50, num_leaves=31
# [CV]  boosting_type=gbdt, learning_rate=0.001, n_estimators=50, num_leaves=31, accuracy=0.557, f1=0.000, total=   0.0s
# [Parallel(n_jobs=1)]: Done  54 out of  54 | elapsed:    3.2s remaining:    0.0s
# [CV] boosting_type=gbdt, learning_rate=0.001, n_estimators=50, num_leaves=31
# [CV]  boosting_type=gbdt, learning_rate=0.001, n_estimators=50, num_leaves=31, accuracy=0.557, f1=0.000, total=   0.0s
# [Parallel(n_jobs=1)]: Done  55 out of  55 | elapsed:    3.2s remaining:    0.0s
# [CV] boosting_type=gbdt, learning_rate=0.001, n_estimators=50, num_leaves=50
# [CV]  boosting_type=gbdt, learning_rate=0.001, n_estimators=50, num_leaves=50, accuracy=0.552, f1=0.000, total=   0.0s
# [Parallel(n_jobs=1)]: Done  56 out of  56 | elapsed:    3.3s remaining:    0.0s
# [CV] boosting_type=gbdt, learning_rate=0.001, n_estimators=50, num_leaves=50
# [CV]  boosting_type=gbdt, learning_rate=0.001, n_estimators=50, num_leaves=50, accuracy=0.552, f1=0.000, total=   0.0s
# [Parallel(n_jobs=1)]: Done  57 out of  57 | elapsed:    3.3s remaining:    0.0s
# [CV] boosting_type=gbdt, learning_rate=0.001, n_estimators=50, num_leaves=50
# [CV]  boosting_type=gbdt, learning_rate=0.001, n_estimators=50, num_leaves=50, accuracy=0.552, f1=0.000, total=   0.0s
# [Parallel(n_jobs=1)]: Done  58 out of  58 | elapsed:    3.3s remaining:    0.0s
# [CV] boosting_type=gbdt, learning_rate=0.001, n_estimators=50, num_leaves=50
# [CV]  boosting_type=gbdt, learning_rate=0.001, n_estimators=50, num_leaves=50, accuracy=0.557, f1=0.000, total=   0.0s
# [Parallel(n_jobs=1)]: Done  59 out of  59 | elapsed:    3.4s remaining:    0.0s
# [CV] boosting_type=gbdt, learning_rate=0.001, n_estimators=50, num_leaves=50
# [CV]  boosting_type=gbdt, learning_rate=0.001, n_estimators=50, num_leaves=50, accuracy=0.557, f1=0.000, total=   0.0s
# [Parallel(n_jobs=1)]: Done  60 out of  60 | elapsed:    3.4s remaining:    0.0s
# [CV] boosting_type=gbdt, learning_rate=0.001, n_estimators=100, num_leaves=15
# [CV]  boosting_type=gbdt, learning_rate=0.001, n_estimators=100, num_leaves=15, accuracy=0.552, f1=0.000, total=   0.1s
# [Parallel(n_jobs=1)]: Done  61 out of  61 | elapsed:    3.5s remaining:    0.0s
# [CV] boosting_type=gbdt, learning_rate=0.001, n_estimators=100, num_leaves=15
# [CV]  boosting_type=gbdt, learning_rate=0.001, n_estimators=100, num_leaves=15, accuracy=0.552, f1=0.000, total=   0.0s
# [Parallel(n_jobs=1)]: Done  62 out of  62 | elapsed:    3.5s remaining:    0.0s
# [CV] boosting_type=gbdt, learning_rate=0.001, n_estimators=100, num_leaves=15
# [CV]  boosting_type=gbdt, learning_rate=0.001, n_estimators=100, num_leaves=15, accuracy=0.552, f1=0.000, total=   0.0s
# [Parallel(n_jobs=1)]: Done  63 out of  63 | elapsed:    3.6s remaining:    0.0s
# [CV] boosting_type=gbdt, learning_rate=0.001, n_estimators=100, num_leaves=15
# [CV]  boosting_type=gbdt, learning_rate=0.001, n_estimators=100, num_leaves=15, accuracy=0.557, f1=0.000, total=   0.0s
# [Parallel(n_jobs=1)]: Done  64 out of  64 | elapsed:    3.6s remaining:    0.0s
# [CV] boosting_type=gbdt, learning_rate=0.001, n_estimators=100, num_leaves=15
# [CV]  boosting_type=gbdt, learning_rate=0.001, n_estimators=100, num_leaves=15, accuracy=0.557, f1=0.000, total=   0.0s
# [Parallel(n_jobs=1)]: Done  65 out of  65 | elapsed:    3.7s remaining:    0.0s
# [CV] boosting_type=gbdt, learning_rate=0.001, n_estimators=100, num_leaves=31
# [CV]  boosting_type=gbdt, learning_rate=0.001, n_estimators=100, num_leaves=31, accuracy=0.552, f1=0.000, total=   0.1s
# [Parallel(n_jobs=1)]: Done  66 out of  66 | elapsed:    3.7s remaining:    0.0s
# [CV] boosting_type=gbdt, learning_rate=0.001, n_estimators=100, num_leaves=31
# [CV]  boosting_type=gbdt, learning_rate=0.001, n_estimators=100, num_leaves=31, accuracy=0.552, f1=0.000, total=   0.1s
# [Parallel(n_jobs=1)]: Done  67 out of  67 | elapsed:    3.8s remaining:    0.0s
# [CV] boosting_type=gbdt, learning_rate=0.001, n_estimators=100, num_leaves=31
# [CV]  boosting_type=gbdt, learning_rate=0.001, n_estimators=100, num_leaves=31, accuracy=0.552, f1=0.000, total=   0.1s
# [Parallel(n_jobs=1)]: Done  68 out of  68 | elapsed:    3.9s remaining:    0.0s
# [CV] boosting_type=gbdt, learning_rate=0.001, n_estimators=100, num_leaves=31
# [CV]  boosting_type=gbdt, learning_rate=0.001, n_estimators=100, num_leaves=31, accuracy=0.557, f1=0.000, total=   0.1s
# [Parallel(n_jobs=1)]: Done  69 out of  69 | elapsed:    3.9s remaining:    0.0s
# [CV] boosting_type=gbdt, learning_rate=0.001, n_estimators=100, num_leaves=31
# [CV]  boosting_type=gbdt, learning_rate=0.001, n_estimators=100, num_leaves=31, accuracy=0.557, f1=0.000, total=   0.1s
# [Parallel(n_jobs=1)]: Done  70 out of  70 | elapsed:    4.0s remaining:    0.0s
# [CV] boosting_type=gbdt, learning_rate=0.001, n_estimators=100, num_leaves=50
# [CV]  boosting_type=gbdt, learning_rate=0.001, n_estimators=100, num_leaves=50, accuracy=0.552, f1=0.000, total=   0.1s
# [Parallel(n_jobs=1)]: Done  71 out of  71 | elapsed:    4.0s remaining:    0.0s
# [CV] boosting_type=gbdt, learning_rate=0.001, n_estimators=100, num_leaves=50
# [CV]  boosting_type=gbdt, learning_rate=0.001, n_estimators=100, num_leaves=50, accuracy=0.552, f1=0.000, total=   0.1s
# [Parallel(n_jobs=1)]: Done  72 out of  72 | elapsed:    4.1s remaining:    0.0s
# [CV] boosting_type=gbdt, learning_rate=0.001, n_estimators=100, num_leaves=50
# [CV]  boosting_type=gbdt, learning_rate=0.001, n_estimators=100, num_leaves=50, accuracy=0.552, f1=0.000, total=   0.1s
# [Parallel(n_jobs=1)]: Done  73 out of  73 | elapsed:    4.2s remaining:    0.0s
# [CV] boosting_type=gbdt, learning_rate=0.001, n_estimators=100, num_leaves=50
# [CV]  boosting_type=gbdt, learning_rate=0.001, n_estimators=100, num_leaves=50, accuracy=0.557, f1=0.000, total=   0.1s
# [Parallel(n_jobs=1)]: Done  74 out of  74 | elapsed:    4.2s remaining:    0.0s
# [CV] boosting_type=gbdt, learning_rate=0.001, n_estimators=100, num_leaves=50
# [CV]  boosting_type=gbdt, learning_rate=0.001, n_estimators=100, num_leaves=50, accuracy=0.557, f1=0.000, total=   0.1s
# [Parallel(n_jobs=1)]: Done  75 out of  75 | elapsed:    4.3s remaining:    0.0s
# [CV] boosting_type=gbdt, learning_rate=0.001, n_estimators=150, num_leaves=15
# [CV]  boosting_type=gbdt, learning_rate=0.001, n_estimators=150, num_leaves=15, accuracy=0.911, f1=0.894, total=   0.1s
# [Parallel(n_jobs=1)]: Done  76 out of  76 | elapsed:    4.4s remaining:    0.0s
# [CV] boosting_type=gbdt, learning_rate=0.001, n_estimators=150, num_leaves=15
# [CV]  boosting_type=gbdt, learning_rate=0.001, n_estimators=150, num_leaves=15, accuracy=0.901, f1=0.877, total=   0.1s
# [Parallel(n_jobs=1)]: Done  77 out of  77 | elapsed:    4.4s remaining:    0.0s
# [CV] boosting_type=gbdt, learning_rate=0.001, n_estimators=150, num_leaves=15
# [CV]  boosting_type=gbdt, learning_rate=0.001, n_estimators=150, num_leaves=15, accuracy=0.865, f1=0.827, total=   0.1s
# [Parallel(n_jobs=1)]: Done  78 out of  78 | elapsed:    4.5s remaining:    0.0s
# [CV] boosting_type=gbdt, learning_rate=0.001, n_estimators=150, num_leaves=15
# [CV]  boosting_type=gbdt, learning_rate=0.001, n_estimators=150, num_leaves=15, accuracy=0.917, f1=0.899, total=   0.1s
# [Parallel(n_jobs=1)]: Done  79 out of  79 | elapsed:    4.6s remaining:    0.0s
# [CV] boosting_type=gbdt, learning_rate=0.001, n_estimators=150, num_leaves=15
# [CV]  boosting_type=gbdt, learning_rate=0.001, n_estimators=150, num_leaves=15, accuracy=0.943, f1=0.932, total=   0.1s
# [Parallel(n_jobs=1)]: Done  80 out of  80 | elapsed:    4.7s remaining:    0.0s
# [CV] boosting_type=gbdt, learning_rate=0.001, n_estimators=150, num_leaves=31
# [CV]  boosting_type=gbdt, learning_rate=0.001, n_estimators=150, num_leaves=31, accuracy=0.911, f1=0.894, total=   0.1s
# [Parallel(n_jobs=1)]: Done  81 out of  81 | elapsed:    4.8s remaining:    0.0s
# [CV] boosting_type=gbdt, learning_rate=0.001, n_estimators=150, num_leaves=31
# [CV]  boosting_type=gbdt, learning_rate=0.001, n_estimators=150, num_leaves=31, accuracy=0.901, f1=0.877, total=   0.1s
# [Parallel(n_jobs=1)]: Done  82 out of  82 | elapsed:    4.9s remaining:    0.0s
# [CV] boosting_type=gbdt, learning_rate=0.001, n_estimators=150, num_leaves=31
# [CV]  boosting_type=gbdt, learning_rate=0.001, n_estimators=150, num_leaves=31, accuracy=0.865, f1=0.827, total=   0.1s
# [Parallel(n_jobs=1)]: Done  83 out of  83 | elapsed:    4.9s remaining:    0.0s
# [CV] boosting_type=gbdt, learning_rate=0.001, n_estimators=150, num_leaves=31
# [CV]  boosting_type=gbdt, learning_rate=0.001, n_estimators=150, num_leaves=31, accuracy=0.927, f1=0.910, total=   0.1s
# [Parallel(n_jobs=1)]: Done  84 out of  84 | elapsed:    5.0s remaining:    0.0s
# [CV] boosting_type=gbdt, learning_rate=0.001, n_estimators=150, num_leaves=31
# [CV]  boosting_type=gbdt, learning_rate=0.001, n_estimators=150, num_leaves=31, accuracy=0.943, f1=0.932, total=   0.1s
# [Parallel(n_jobs=1)]: Done  85 out of  85 | elapsed:    5.1s remaining:    0.0s
# [CV] boosting_type=gbdt, learning_rate=0.001, n_estimators=150, num_leaves=50
# [CV]  boosting_type=gbdt, learning_rate=0.001, n_estimators=150, num_leaves=50, accuracy=0.911, f1=0.894, total=   0.1s
# [Parallel(n_jobs=1)]: Done  86 out of  86 | elapsed:    5.2s remaining:    0.0s
# [CV] boosting_type=gbdt, learning_rate=0.001, n_estimators=150, num_leaves=50
# [CV]  boosting_type=gbdt, learning_rate=0.001, n_estimators=150, num_leaves=50, accuracy=0.901, f1=0.877, total=   0.1s
# [Parallel(n_jobs=1)]: Done  87 out of  87 | elapsed:    5.3s remaining:    0.0s
# [CV] boosting_type=gbdt, learning_rate=0.001, n_estimators=150, num_leaves=50
# [CV]  boosting_type=gbdt, learning_rate=0.001, n_estimators=150, num_leaves=50, accuracy=0.865, f1=0.827, total=   0.1s
# [Parallel(n_jobs=1)]: Done  88 out of  88 | elapsed:    5.4s remaining:    0.0s
# [CV] boosting_type=gbdt, learning_rate=0.001, n_estimators=150, num_leaves=50
# [CV]  boosting_type=gbdt, learning_rate=0.001, n_estimators=150, num_leaves=50, accuracy=0.927, f1=0.910, total=   0.1s
# [Parallel(n_jobs=1)]: Done  89 out of  89 | elapsed:    5.5s remaining:    0.0s
# [CV] boosting_type=gbdt, learning_rate=0.001, n_estimators=150, num_leaves=50
# [CV]  boosting_type=gbdt, learning_rate=0.001, n_estimators=150, num_leaves=50, accuracy=0.943, f1=0.932, total=   0.1s
# [Parallel(n_jobs=1)]: Done  90 out of  90 | elapsed:    5.6s remaining:    0.0s
# [CV] boosting_type=gbdt, learning_rate=1, n_estimators=50, num_leaves=15
# [CV]  boosting_type=gbdt, learning_rate=1, n_estimators=50, num_leaves=15, accuracy=1.000, f1=1.000, total=   0.0s
# [Parallel(n_jobs=1)]: Done  91 out of  91 | elapsed:    5.6s remaining:    0.0s
# [CV] boosting_type=gbdt, learning_rate=1, n_estimators=50, num_leaves=15
# [CV]  boosting_type=gbdt, learning_rate=1, n_estimators=50, num_leaves=15, accuracy=0.990, f1=0.988, total=   0.0s
# [Parallel(n_jobs=1)]: Done  92 out of  92 | elapsed:    5.6s remaining:    0.0s
# [CV] boosting_type=gbdt, learning_rate=1, n_estimators=50, num_leaves=15
# [CV]  boosting_type=gbdt, learning_rate=1, n_estimators=50, num_leaves=15, accuracy=0.974, f1=0.970, total=   0.0s
# [Parallel(n_jobs=1)]: Done  93 out of  93 | elapsed:    5.6s remaining:    0.0s
# [CV] boosting_type=gbdt, learning_rate=1, n_estimators=50, num_leaves=15
# [CV]  boosting_type=gbdt, learning_rate=1, n_estimators=50, num_leaves=15, accuracy=1.000, f1=1.000, total=   0.0s
# [Parallel(n_jobs=1)]: Done  94 out of  94 | elapsed:    5.6s remaining:    0.0s
# [CV] boosting_type=gbdt, learning_rate=1, n_estimators=50, num_leaves=15
# [CV]  boosting_type=gbdt, learning_rate=1, n_estimators=50, num_leaves=15, accuracy=1.000, f1=1.000, total=   0.0s
# [Parallel(n_jobs=1)]: Done  95 out of  95 | elapsed:    5.7s remaining:    0.0s
# [CV] boosting_type=gbdt, learning_rate=1, n_estimators=50, num_leaves=31
# [CV]  boosting_type=gbdt, learning_rate=1, n_estimators=50, num_leaves=31, accuracy=1.000, f1=1.000, total=   0.0s
# [Parallel(n_jobs=1)]: Done  96 out of  96 | elapsed:    5.7s remaining:    0.0s
# [CV] boosting_type=gbdt, learning_rate=1, n_estimators=50, num_leaves=31
# [CV]  boosting_type=gbdt, learning_rate=1, n_estimators=50, num_leaves=31, accuracy=0.990, f1=0.988, total=   0.0s
# [Parallel(n_jobs=1)]: Done  97 out of  97 | elapsed:    5.7s remaining:    0.0s
# [CV] boosting_type=gbdt, learning_rate=1, n_estimators=50, num_leaves=31
# [CV]  boosting_type=gbdt, learning_rate=1, n_estimators=50, num_leaves=31, accuracy=0.969, f1=0.965, total=   0.0s
# [Parallel(n_jobs=1)]: Done  98 out of  98 | elapsed:    5.7s remaining:    0.0s
# [CV] boosting_type=gbdt, learning_rate=1, n_estimators=50, num_leaves=31
# [CV]  boosting_type=gbdt, learning_rate=1, n_estimators=50, num_leaves=31, accuracy=0.995, f1=0.994, total=   0.0s
# [Parallel(n_jobs=1)]: Done  99 out of  99 | elapsed:    5.7s remaining:    0.0s
# [CV] boosting_type=gbdt, learning_rate=1, n_estimators=50, num_leaves=31
# [CV]  boosting_type=gbdt, learning_rate=1, n_estimators=50, num_leaves=31, accuracy=1.000, f1=1.000, total=   0.0s
# [CV] boosting_type=gbdt, learning_rate=1, n_estimators=50, num_leaves=50
# [CV]  boosting_type=gbdt, learning_rate=1, n_estimators=50, num_leaves=50, accuracy=1.000, f1=1.000, total=   0.0s
# [CV] boosting_type=gbdt, learning_rate=1, n_estimators=50, num_leaves=50
# [CV]  boosting_type=gbdt, learning_rate=1, n_estimators=50, num_leaves=50, accuracy=0.990, f1=0.988, total=   0.0s
# [CV] boosting_type=gbdt, learning_rate=1, n_estimators=50, num_leaves=50
# [CV]  boosting_type=gbdt, learning_rate=1, n_estimators=50, num_leaves=50, accuracy=0.969, f1=0.965, total=   0.0s
# [CV] boosting_type=gbdt, learning_rate=1, n_estimators=50, num_leaves=50
# [CV]  boosting_type=gbdt, learning_rate=1, n_estimators=50, num_leaves=50, accuracy=0.995, f1=0.994, total=   0.0s
# [CV] boosting_type=gbdt, learning_rate=1, n_estimators=50, num_leaves=50
# [CV]  boosting_type=gbdt, learning_rate=1, n_estimators=50, num_leaves=50, accuracy=1.000, f1=1.000, total=   0.0s
# [CV] boosting_type=gbdt, learning_rate=1, n_estimators=100, num_leaves=15
# [CV]  boosting_type=gbdt, learning_rate=1, n_estimators=100, num_leaves=15, accuracy=1.000, f1=1.000, total=   0.0s
# [CV] boosting_type=gbdt, learning_rate=1, n_estimators=100, num_leaves=15
# [CV]  boosting_type=gbdt, learning_rate=1, n_estimators=100, num_leaves=15, accuracy=0.990, f1=0.988, total=   0.0s
# [CV] boosting_type=gbdt, learning_rate=1, n_estimators=100, num_leaves=15
# [CV]  boosting_type=gbdt, learning_rate=1, n_estimators=100, num_leaves=15, accuracy=0.974, f1=0.970, total=   0.0s
# [CV] boosting_type=gbdt, learning_rate=1, n_estimators=100, num_leaves=15
# [CV]  boosting_type=gbdt, learning_rate=1, n_estimators=100, num_leaves=15, accuracy=1.000, f1=1.000, total=   0.0s
# [CV] boosting_type=gbdt, learning_rate=1, n_estimators=100, num_leaves=15
# [CV]  boosting_type=gbdt, learning_rate=1, n_estimators=100, num_leaves=15, accuracy=1.000, f1=1.000, total=   0.0s
# [CV] boosting_type=gbdt, learning_rate=1, n_estimators=100, num_leaves=31
# [CV]  boosting_type=gbdt, learning_rate=1, n_estimators=100, num_leaves=31, accuracy=1.000, f1=1.000, total=   0.0s
# [CV] boosting_type=gbdt, learning_rate=1, n_estimators=100, num_leaves=31
# [CV]  boosting_type=gbdt, learning_rate=1, n_estimators=100, num_leaves=31, accuracy=0.990, f1=0.988, total=   0.0s
# [CV] boosting_type=gbdt, learning_rate=1, n_estimators=100, num_leaves=31
# [CV]  boosting_type=gbdt, learning_rate=1, n_estimators=100, num_leaves=31, accuracy=0.969, f1=0.965, total=   0.0s
# [CV] boosting_type=gbdt, learning_rate=1, n_estimators=100, num_leaves=31
# [CV]  boosting_type=gbdt, learning_rate=1, n_estimators=100, num_leaves=31, accuracy=0.995, f1=0.994, total=   0.0s
# [CV] boosting_type=gbdt, learning_rate=1, n_estimators=100, num_leaves=31
# [CV]  boosting_type=gbdt, learning_rate=1, n_estimators=100, num_leaves=31, accuracy=1.000, f1=1.000, total=   0.0s
# [CV] boosting_type=gbdt, learning_rate=1, n_estimators=100, num_leaves=50
# [CV]  boosting_type=gbdt, learning_rate=1, n_estimators=100, num_leaves=50, accuracy=1.000, f1=1.000, total=   0.0s
# [CV] boosting_type=gbdt, learning_rate=1, n_estimators=100, num_leaves=50
# [CV]  boosting_type=gbdt, learning_rate=1, n_estimators=100, num_leaves=50, accuracy=0.990, f1=0.988, total=   0.0s
# [CV] boosting_type=gbdt, learning_rate=1, n_estimators=100, num_leaves=50
# [CV]  boosting_type=gbdt, learning_rate=1, n_estimators=100, num_leaves=50, accuracy=0.969, f1=0.965, total=   0.0s
# [CV] boosting_type=gbdt, learning_rate=1, n_estimators=100, num_leaves=50
# [CV]  boosting_type=gbdt, learning_rate=1, n_estimators=100, num_leaves=50, accuracy=0.995, f1=0.994, total=   0.0s
# [CV] boosting_type=gbdt, learning_rate=1, n_estimators=100, num_leaves=50
# [CV]  boosting_type=gbdt, learning_rate=1, n_estimators=100, num_leaves=50, accuracy=1.000, f1=1.000, total=   0.0s
# [CV] boosting_type=gbdt, learning_rate=1, n_estimators=150, num_leaves=15
# [CV]  boosting_type=gbdt, learning_rate=1, n_estimators=150, num_leaves=15, accuracy=1.000, f1=1.000, total=   0.0s
# [CV] boosting_type=gbdt, learning_rate=1, n_estimators=150, num_leaves=15
# [CV]  boosting_type=gbdt, learning_rate=1, n_estimators=150, num_leaves=15, accuracy=0.990, f1=0.988, total=   0.0s
# [CV] boosting_type=gbdt, learning_rate=1, n_estimators=150, num_leaves=15
# [CV]  boosting_type=gbdt, learning_rate=1, n_estimators=150, num_leaves=15, accuracy=0.974, f1=0.970, total=   0.0s
# [CV] boosting_type=gbdt, learning_rate=1, n_estimators=150, num_leaves=15
# [CV]  boosting_type=gbdt, learning_rate=1, n_estimators=150, num_leaves=15, accuracy=0.995, f1=0.994, total=   0.0s
# [CV] boosting_type=gbdt, learning_rate=1, n_estimators=150, num_leaves=15
# [CV]  boosting_type=gbdt, learning_rate=1, n_estimators=150, num_leaves=15, accuracy=1.000, f1=1.000, total=   0.0s
# [CV] boosting_type=gbdt, learning_rate=1, n_estimators=150, num_leaves=31
# [CV]  boosting_type=gbdt, learning_rate=1, n_estimators=150, num_leaves=31, accuracy=1.000, f1=1.000, total=   0.0s
# [CV] boosting_type=gbdt, learning_rate=1, n_estimators=150, num_leaves=31
# [CV]  boosting_type=gbdt, learning_rate=1, n_estimators=150, num_leaves=31, accuracy=0.990, f1=0.988, total=   0.0s
# [CV] boosting_type=gbdt, learning_rate=1, n_estimators=150, num_leaves=31
# [CV]  boosting_type=gbdt, learning_rate=1, n_estimators=150, num_leaves=31, accuracy=0.969, f1=0.965, total=   0.0s
# [CV] boosting_type=gbdt, learning_rate=1, n_estimators=150, num_leaves=31
# [CV]  boosting_type=gbdt, learning_rate=1, n_estimators=150, num_leaves=31, accuracy=0.995, f1=0.994, total=   0.0s
# [CV] boosting_type=gbdt, learning_rate=1, n_estimators=150, num_leaves=31
# [CV]  boosting_type=gbdt, learning_rate=1, n_estimators=150, num_leaves=31, accuracy=1.000, f1=1.000, total=   0.0s
# [CV] boosting_type=gbdt, learning_rate=1, n_estimators=150, num_leaves=50
# [CV]  boosting_type=gbdt, learning_rate=1, n_estimators=150, num_leaves=50, accuracy=1.000, f1=1.000, total=   0.0s
# [CV] boosting_type=gbdt, learning_rate=1, n_estimators=150, num_leaves=50
# [CV]  boosting_type=gbdt, learning_rate=1, n_estimators=150, num_leaves=50, accuracy=0.990, f1=0.988, total=   0.0s
# [CV] boosting_type=gbdt, learning_rate=1, n_estimators=150, num_leaves=50
# [CV]  boosting_type=gbdt, learning_rate=1, n_estimators=150, num_leaves=50, accuracy=0.969, f1=0.965, total=   0.0s
# [CV] boosting_type=gbdt, learning_rate=1, n_estimators=150, num_leaves=50
# [CV]  boosting_type=gbdt, learning_rate=1, n_estimators=150, num_leaves=50, accuracy=0.995, f1=0.994, total=   0.0s
# [CV] boosting_type=gbdt, learning_rate=1, n_estimators=150, num_leaves=50
# [CV]  boosting_type=gbdt, learning_rate=1, n_estimators=150, num_leaves=50, accuracy=1.000, f1=1.000, total=   0.0s
# [CV] boosting_type=dart, learning_rate=0.1, n_estimators=50, num_leaves=15
# [CV]  boosting_type=dart, learning_rate=0.1, n_estimators=50, num_leaves=15, accuracy=1.000, f1=1.000, total=   0.0s
# [CV] boosting_type=dart, learning_rate=0.1, n_estimators=50, num_leaves=15
# [CV]  boosting_type=dart, learning_rate=0.1, n_estimators=50, num_leaves=15, accuracy=0.984, f1=0.982, total=   0.0s
# [CV] boosting_type=dart, learning_rate=0.1, n_estimators=50, num_leaves=15
# [CV]  boosting_type=dart, learning_rate=0.1, n_estimators=50, num_leaves=15, accuracy=0.969, f1=0.965, total=   0.0s
# [CV] boosting_type=dart, learning_rate=0.1, n_estimators=50, num_leaves=15
# [CV]  boosting_type=dart, learning_rate=0.1, n_estimators=50, num_leaves=15, accuracy=0.995, f1=0.994, total=   0.0s
# [CV] boosting_type=dart, learning_rate=0.1, n_estimators=50, num_leaves=15
# [CV]  boosting_type=dart, learning_rate=0.1, n_estimators=50, num_leaves=15, accuracy=0.995, f1=0.994, total=   0.0s
# [CV] boosting_type=dart, learning_rate=0.1, n_estimators=50, num_leaves=31
# [CV]  boosting_type=dart, learning_rate=0.1, n_estimators=50, num_leaves=31, accuracy=0.995, f1=0.994, total=   0.0s
# [CV] boosting_type=dart, learning_rate=0.1, n_estimators=50, num_leaves=31
# [CV]  boosting_type=dart, learning_rate=0.1, n_estimators=50, num_leaves=31, accuracy=0.984, f1=0.982, total=   0.0s
# [CV] boosting_type=dart, learning_rate=0.1, n_estimators=50, num_leaves=31
# [CV]  boosting_type=dart, learning_rate=0.1, n_estimators=50, num_leaves
total=   0.0s
# [CV] boosting_type=dart, learning_rate=1, n_estimators=50, num_leaves=15
# [CV]  boosting_type=dart, learning_rate=1, n_estimators=50, num_leaves=15, accuracy=0.990, f1=0.988, total=   0.0s
# [CV] boosting_type=dart, learning_rate=1, n_estimators=50, num_leaves=15
# [CV]  boosting_type=dart, learning_rate=1, n_estimators=50, num_leaves=15, accuracy=0.995, f1=0.994, total=   0.0s
# [CV] boosting_type=dart, learning_rate=1, n_estimators=50, num_leaves=15
# [CV]  boosting_type=dart, learning_rate=1, n_estimators=50, num_leaves=15, accuracy=1.000, f1=1.000, total=   0.0s
# [CV] boosting_type=dart, learning_rate=1, n_estimators=50, num_leaves=31
# [CV]  boosting_type=dart, learning_rate=1, n_estimators=50, num_leaves=31, accuracy=1.000, f1=1.000, total=   0.0s
# [CV] boosting_type=dart, learning_rate=1, n_estimators=50, num_leaves=31
# [CV]  boosting_type=dart, learning_rate=1, n_estimators=50, num_leaves=31, accuracy=0.990, f1=0.988, total=   0.0s
# [CV] boosting_type=dart, learning_rate=1, n_estimators=50, num_leaves=31
# [CV]  boosting_type=dart, learning_rate=1, n_estimators=50, num_leaves=31, accuracy=0.969, f1=0.965, total=   0.0s
# [CV] boosting_type=dart, learning_rate=1, n_estimators=50, num_leaves=31
# [CV]  boosting_type=dart, learning_rate=1, n_estimators=50, num_leaves=31, accuracy=0.995, f1=0.994, total=   0.0s
# [CV] boosting_type=dart, learning_rate=1, n_estimators=50, num_leaves=31
# [CV]  boosting_type=dart, learning_rate=1, n_estimators=50, num_leaves=31, accuracy=1.000, f1=1.000, total=   0.0s
# [CV] boosting_type=dart, learning_rate=1, n_estimators=50, num_leaves=50
# [CV]  boosting_type=dart, learning_rate=1, n_estimators=50, num_leaves=50, accuracy=1.000, f1=1.000, total=   0.0s
# [CV] boosting_type=dart, learning_rate=1, n_estimators=50, num_leaves=50
# [CV]  boosting_type=dart, learning_rate=1, n_estimators=50, num_leaves=50, accuracy=0.990, f1=0.988, total=   0.0s
# [CV] boosting_type=dart, learning_rate=1, n_estimators=50, num_leaves=50
# [CV]  boosting_type=dart, learning_rate=1, n_estimators=50, num_leaves=50, accuracy=0.969, f1=0.965, total=   0.0s
# [CV] boosting_type=dart, learning_rate=1, n_estimators=50, num_leaves=50
# [CV]  boosting_type=dart, learning_rate=1, n_estimators=50, num_leaves=50, accuracy=0.995, f1=0.994, total=   0.0s
# [CV] boosting_type=dart, learning_rate=1, n_estimators=50, num_leaves=50
# [CV]  boosting_type=dart, learning_rate=1, n_estimators=50, num_leaves=50, accuracy=1.000, f1=1.000, total=   0.0s
# [CV] boosting_type=dart, learning_rate=1, n_estimators=100, num_leaves=15
# [CV]  boosting_type=dart, learning_rate=1, n_estimators=100, num_leaves=15, accuracy=1.000, f1=1.000, total=   0.0s
# [CV] boosting_type=dart, learning_rate=1, n_estimators=100, num_leaves=15
# [CV]  boosting_type=dart, learning_rate=1, n_estimators=100, num_leaves=15, accuracy=0.990, f1=0.988, total=   0.0s
# [CV] boosting_type=dart, learning_rate=1, n_estimators=100, num_leaves=15
# [CV]  boosting_type=dart, learning_rate=1, n_estimators=100, num_leaves=15, accuracy=0.990, f1=0.988, total=   0.0s
# [CV] boosting_type=dart, learning_rate=1, n_estimators=100, num_leaves=15
# [CV]  boosting_type=dart, learning_rate=1, n_estimators=100, num_leaves=15, accuracy=0.995, f1=0.994, total=   0.0s
# [CV] boosting_type=dart, learning_rate=1, n_estimators=100, num_leaves=15
# [CV]  boosting_type=dart, learning_rate=1, n_estimators=100, num_leaves=15, accuracy=1.000, f1=1.000, total=   0.0s
# [CV] boosting_type=dart, learning_rate=1, n_estimators=100, num_leaves=31
# [CV]  boosting_type=dart, learning_rate=1, n_estimators=100, num_leaves=31, accuracy=1.000, f1=1.000, total=   0.0s
# [CV] boosting_type=dart, learning_rate=1, n_estimators=100, num_leaves=31
# [CV]  boosting_type=dart, learning_rate=1, n_estimators=100, num_leaves=31, accuracy=0.990, f1=0.988, total=   0.1s
# [CV] boosting_type=dart, learning_rate=1, n_estimators=100, num_leaves=31
# [CV]  boosting_type=dart, learning_rate=1, n_estimators=100, num_leaves=31, accuracy=0.990, f1=0.988, total=   0.1s
# [CV] boosting_type=dart, learning_rate=1, n_estimators=100, num_leaves=31
# [CV]  boosting_type=dart, learning_rate=1, n_estimators=100, num_leaves=31, accuracy=0.995, f1=0.994, total=   0.1s
# [CV] boosting_type=dart, learning_rate=1, n_estimators=100, num_leaves=31
# [CV]  boosting_type=dart, learning_rate=1, n_estimators=100, num_leaves=31, accuracy=1.000, f1=1.000, total=   0.0s
# [CV] boosting_type=dart, learning_rate=1, n_estimators=100, num_leaves=50
# [CV]  boosting_type=dart, learning_rate=1, n_estimators=100, num_leaves=50, accuracy=1.000, f1=1.000, total=   0.0s
# [CV] boosting_type=dart, learning_rate=1, n_estimators=100, num_leaves=50
# [CV]  boosting_type=dart, learning_rate=1, n_estimators=100, num_leaves=50, accuracy=0.990, f1=0.988, total=   0.0s
# [CV] boosting_type=dart, learning_rate=1, n_estimators=100, num_leaves=50
# [CV]  boosting_type=dart, learning_rate=1, n_estimators=100, num_leaves=50, accuracy=0.990, f1=0.988, total=   0.0s
# [CV] boosting_type=dart, learning_rate=1, n_estimators=100, num_leaves=50
# [CV]  boosting_type=dart, learning_rate=1, n_estimators=100, num_leaves=50, accuracy=0.995, f1=0.994, total=   0.0s
# [CV] boosting_type=dart, learning_rate=1, n_estimators=100, num_leaves=50
# [CV]  boosting_type=dart, learning_rate=1, n_estimators=100, num_leaves=50, accuracy=1.000, f1=1.000, total=   0.0s
# [CV] boosting_type=dart, learning_rate=1, n_estimators=150, num_leaves=15
# [CV]  boosting_type=dart, learning_rate=1, n_estimators=150, num_leaves=15, accuracy=1.000, f1=1.000, total=   0.1s
# [CV] boosting_type=dart, learning_rate=1, n_estimators=150, num_leaves=15
# [CV]  boosting_type=dart, learning_rate=1, n_estimators=150, num_leaves=15, accuracy=0.990, f1=0.988, total=   0.1s
# [CV] boosting_type=dart, learning_rate=1, n_estimators=150, num_leaves=15
# [CV]  boosting_type=dart, learning_rate=1, n_estimators=150, num_leaves=15, accuracy=0.990, f1=0.988, total=   0.1s
# [CV] boosting_type=dart, learning_rate=1, n_estimators=150, num_leaves=15
# [CV]  boosting_type=dart, learning_rate=1, n_estimators=150, num_leaves=15, accuracy=0.995, f1=0.994, total=   0.1s
# [CV] boosting_type=dart, learning_rate=1, n_estimators=150, num_leaves=15
# [CV]  boosting_type=dart, learning_rate=1, n_estimators=150, num_leaves=15, accuracy=1.000, f1=1.000, total=   0.1s
# [CV] boosting_type=dart, learning_rate=1, n_estimators=150, num_leaves=31
# [CV]  boosting_type=dart, learning_rate=1, n_estimators=150, num_leaves=31, accuracy=1.000, f1=1.000, total=   0.1s
# [CV] boosting_type=dart, learning_rate=1, n_estimators=150, num_leaves=31
# [CV]  boosting_type=dart, learning_rate=1, n_estimators=150, num_leaves=31, accuracy=0.990, f1=0.988, total=   0.1s
# [CV] boosting_type=dart, learning_rate=1, n_estimators=150, num_leaves=31
# [CV]  boosting_type=dart, learning_rate=1, n_estimators=150, num_leaves=31, accuracy=0.990, f1=0.988, total=   0.1s
# [CV] boosting_type=dart, learning_rate=1, n_estimators=150, num_leaves=31
# [CV]  boosting_type=dart, learning_rate=1, n_estimators=150, num_leaves=31, accuracy=0.995, f1=0.994, total=   0.1s
# [CV] boosting_type=dart, learning_rate=1, n_estimators=150, num_leaves=31
# [CV]  boosting_type=dart, learning_rate=1, n_estimators=150, num_leaves=31, accuracy=1.000, f1=1.000, total=   0.1s
# [CV] boosting_type=dart, learning_rate=1, n_estimators=150, num_leaves=50
# [CV]  boosting_type=dart, learning_rate=1, n_estimators=150, num_leaves=50, accuracy=1.000, f1=1.000, total=   0.1s
# [CV] boosting_type=dart, learning_rate=1, n_estimators=150, num_leaves=50
# [CV]  boosting_type=dart, learning_rate=1, n_estimators=150, num_leaves=50, accuracy=0.990, f1=0.988, total=   0.1s
# [CV] boosting_type=dart, learning_rate=1, n_estimators=150, num_leaves=50
# [CV]  boosting_type=dart, learning_rate=1, n_estimators=150, num_leaves=50, accuracy=0.990, f1=0.988, total=   0.1s
# [CV] boosting_type=dart, learning_rate=1, n_estimators=150, num_leaves=50
# [CV]  boosting_type=dart, learning_rate=1, n_estimators=150, num_leaves=50, accuracy=0.995, f1=0.994, total=   0.1s
# [CV] boosting_type=dart, learning_rate=1, n_estimators=150, num_leaves=50
# [CV]  boosting_type=dart, learning_rate=1, n_estimators=150, num_leaves=50, accuracy=1.000, f1=1.000, total=   0.1s
# [Parallel(n_jobs=1)]: Done 270 out of 270 | elapsed:   16.8s finished
# GridSearchCV(cv=None, error_score=nan,
#              estimator=LGBMClassifier(boosting_type='gbdt', class_weight=None,
#                                       colsample_bytree=1.0,
#                                       importance_type='split',
#                                       learning_rate=0.1, max_depth=-1,
#                                       min_child_samples=20,
#                                       min_child_weight=0.001,
#                                       min_split_gain=0.0, n_estimators=100,
#                                       n_jobs=-1, num_leaves=31, objective=None,
#                                       random_state=None, reg_alpha=0.0,
#                                       reg_lambda=0.0, silent=True,
#                                       subsample=1.0, subsample_for_bin=200000,
#                                       subsample_freq=0),
#              iid='deprecated', n_jobs=None,
#              param_grid={'boosting_type': ['gbdt', 'dart'],
#                          'learning_rate': [0.1, 0.001, 1],
#                          'n_estimators': [50, 100, 150],
#                          'num_leaves': [15, 31, 50]},
#              pre_dispatch='2*n_jobs', refit='f1', return_train_score=False,
#              scoring=['accuracy', 'f1'], verbose=100)

# %%
print(gridSearch.best_params_)
# Out:
# {'boosting_type': 'dart', 'learning_rate': 1, 'n_estimators': 50, 'num_leaves': 15}

# %%
print(gridSearch.best_score_)
# Out:
# 0.9941792465660274

# %%
from  joblib import dump,load

# %%
dump(gridSearch.best_params_,'gridSearch.joblib')
# Out:
# ['gridSearch.joblib']

# %%
gridSearch=load('gridSearch.joblib')

# %%
gridSearch
# Out:
# {'boosting_type': 'dart',
#  'learning_rate': 1,
#  'n_estimators': 50,
#  'num_leaves': 15}

# %%
lgbm=lgb.LGBMClassifier(boosting_type='dart',learning_rate=1,n_estimators=50,num_leaves=15)

# %%
lgbm.fit(X_train,y_train)
# Out:
# LGBMClassifier(boosting_type='dart', class_weight=None, colsample_bytree=1.0,
#                importance_type='split', learning_rate=1, max_depth=-1,
#                min_child_samples=20, min_child_weight=0.001, min_split_gain=0.0,
#                n_estimators=50, n_jobs=-1, num_leaves=15, objective=None,
#                random_state=None, reg_alpha=0.0, reg_lambda=0.0, silent=True,
#                subsample=1.0, subsample_for_bin=200000, subsample_freq=0)

# %%
predictions=lgbm.predict(X_test)

# %%
from sklearn.metrics import f1_score
from sklearn.metrics import accuracy_score

# %%
f1_score(y_test,predictions)
# Out:
# 0.9972602739726028

# %%
accuracy_score(y_test,predictions)
# Out:
# 0.9975728155339806

# %%
import pickle
pickle_out=open('LGBMClasifier.pkl','wb')
pickle.dump(lgbm,pickle_out)
pickle_out.close()

# %%
 lgbm.predict([[2,3,4,1]])
# Out:
# array([0])
