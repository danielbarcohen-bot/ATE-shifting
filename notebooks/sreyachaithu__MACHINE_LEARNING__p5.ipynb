# %%
#1
import pandas as pd
import matplotlib.pyplot as plt
df=pd.read_csv('tvmarketing.csv')
df
# Out:
#         TV  Sales
# 0    230.1   22.1
# 1     44.5   10.4
# 2     17.2    9.3
# 3    151.5   18.5
# 4    180.8   12.9
# ..     ...    ...
# 195   38.2    7.6
# 196   94.2    9.7
# 197  177.0   12.8
# 198  283.6   25.5
# 199  232.1   13.4
#
# [200 rows x 2 columns]

# %%
#2
df.head()
# Out:
#       TV  Sales
# 0  230.1   22.1
# 1   44.5   10.4
# 2   17.2    9.3
# 3  151.5   18.5
# 4  180.8   12.9

# %%
#3
df.shape[0]
df.shape[1]
# Out:
# 2

# %%
df.shape
# Out:
# (200, 2)

# %%
#4
df.describe()
# Out:
#                TV       Sales
# count  200.000000  200.000000
# mean   147.042500   14.022500
# std     85.854236    5.217457
# min      0.700000    1.600000
# 25%     74.375000   10.375000
# 50%    149.750000   12.900000
# 75%    218.825000   17.400000
# max    296.400000   27.000000

# %%
#5
x=df['TV']
y=df['Sales']
plt.scatter(x,y)
plt.show()

# %%
#6
import seaborn as sns
x=df['TV']
y=df['Sales']
sns.scatterplot(x=x,y=y)
# Out:
# <Axes: xlabel='TV', ylabel='Sales'>

# %%
import pandas as pd
df=pd.read_csv('tvmarketing.csv')
df
X=df['TV']
y=df['Sales']
print(X,y)
# Out:
# 0      230.1
# 1       44.5
# 2       17.2
# 3      151.5
# 4      180.8
#        ...
# 195     38.2
# 196     94.2
# 197    177.0
# 198    283.6
# 199    232.1
# Name: TV, Length: 200, dtype: float64 0      22.1
# 1      10.4
# 2       9.3
# 3      18.5
# 4      12.9
#        ...
# 195     7.6
# 196     9.7
# 197    12.8
# 198    25.5
# 199    13.4
# Name: Sales, Length: 200, dtype: float64

# %%
#7
from sklearn.model_selection import train_test_split
X_train, X_test,y_train, y_test=train_test_split(X,y,test_size=0.3)

# %%
#8
X_test.shape,X_train.shape
# Out:
# ((60,), (140,))

# %%
X_test.shape,y_test.shape
# Out:
# ((60,), (60,))

# %%
#9
import numpy as np

# %%
x_mean = X_train.mean()
y_mean = y_train.mean()
numerator = np.sum((X_train - x_mean) * (y_train - y_mean))
denominator = np.sum((X_train - x_mean)**2)
slope = numerator / denominator
intercept = y_mean - slope * x_mean
print(slope, intercept)
# Out:
# 0.048581469501021844 6.952844032960692

# %%
#10
y_prediction=(slope)+(intercept)*(X_test)
y_prediction
# Out:
# 116     967.884471
# 81     1667.340581
# 185    1425.381608
# 145     975.532599
# 44      174.564967
# 31      785.024673
# 156     652.920636
# 187    1328.737076
# 3      1053.404452
# 96     1373.930562
# 198    1971.875149
# 13      677.950875
# 108      91.130838
# 115     522.207168
# 98     2014.287498
# 167    1437.896727
# 197    1230.701975
# 190     274.685921
# 47     1668.035865
# 91      198.899921
# 150    1951.711902
# 155      28.555242
# 92     1513.682727
# 65      479.794820
# 180    1088.863957
# 56       50.804343
# 153    1191.070764
# 90      933.815535
# 97     1285.629443
# 159     915.738141
# 23     1587.382874
# 188    1988.561975
# 102    1948.235480
# 68     1650.653755
# 89      763.470856
# 113    1457.364691
# 184    1764.680397
# 131    1843.942819
# 121     130.762049
# 14     1419.124049
# 110    1570.000764
# 41     1230.701975
# 163    1136.838581
# 74     1483.785498
# 125     606.336581
# 2       119.637499
# 20     1518.549718
# 88      613.984710
# 48     1579.734746
# 123     855.943682
# 11     1492.824195
# 52     1504.644030
# 106     173.869682
# 95     1135.448012
# 79      806.578489
# 147    1690.980250
# 83      475.623113
# 151     841.342709
# 161     595.907315
# 50     1389.226819
# Name: TV, dtype: float64

# %%
#11&12
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
model=LinearRegression()
a=X_train.values.reshape(-1,1)
b=X_test.values.reshape(-1,1)
model.fit(a,y_train)
print(model.intercept_)
print(model.coef_)
# Out:
# 6.952844032960692
# [0.04858147]

# %%
a.shape
# Out:
# (140, 1)

# %%
#13
y_predict=model.predict(a)
y_predict
# Out:
# array([ 9.29932901, 20.76455581, 17.41729256, 14.99793538, 15.45945934,
#        20.24959224, 10.20294434, 17.32498777,  9.11471943,  7.59411943,
#         8.48316032, 19.02048106, 14.10889449, 10.24666767, 14.22549002,
#        12.80691111, 19.14193473, 17.8350932 , 11.67496287,  8.80865617,
#        16.79059161, 10.75191495, 18.52495007, 10.6644683 , 13.32187468,
#         9.97946958,  9.74627853, 17.65534176, 15.1339635 , 15.33314752,
#         8.10908301, 11.60209066, 17.18895966, 10.65961016, 18.10229128,
#         7.3317795 , 11.6263814 ,  8.28883444, 11.83042357, 13.89513602,
#         7.36092838, 10.6644683 , 10.38269578, 16.62541461,  8.19652965,
#        18.2286031 , 10.5818798 , 11.52921846, 16.08130215, 20.39533664,
#        11.31060185, 13.56964018, 17.00435007, 17.66505806,  7.52124723,
#        13.65222868, 14.23034816, 10.31468172, 12.03446574, 18.13144017,
#        20.92487466, 16.44566317,  9.68312262,  6.98685106, 20.40505294,
#        21.07547722, 12.64659226, 17.75736285, 15.93555774, 12.33081271,
#        17.56789512,  7.82245234, 16.61569832, 18.61725486, 16.07644401,
#        10.51872389,  9.12443572, 17.48530662, 17.75736285, 18.02941908,
#        19.91923824, 18.61725486, 19.64718201, 18.57838968,  8.25482742,
#        21.35239159,  9.04670537, 13.81740567, 15.05623315,  7.78844531,
#        11.94216095, 16.10559289, 21.21636348, 17.1938178 ,  7.37550282,
#        10.84907789,  9.84829962, 11.34460888,  8.79893987, 16.65942164,
#        12.28708938, 10.61102869, 15.73637372, 13.05953475, 12.79233667,
#         7.77387087, 15.82382036, 18.69498521,  7.37064467, 10.16407917,
#        13.23928619,  9.55195265, 14.94449577, 16.55254241,  7.89532454,
#         7.90504084,  8.74550026, 16.36307468, 10.62074498, 19.36055134,
#        13.52105871, 15.48860822, 19.72491236, 15.22141014, 21.18235645,
#        20.62366955, 19.71519607,  7.21518397, 17.63105103, 19.03991364,
#        12.17049386, 18.34519863, 18.48608489, 13.72024273, 16.33878394,
#         9.04184722, 13.72995903,  7.86131751,  9.38191751, 19.85608233])

# %%
#14&15
plt.scatter(a,y_train)
plt.plot(a,model.predict(a),color="red")

# %%
df=pd.read_csv('tvmarketing.csv')
df
# Out:
#         TV  Sales
# 0    230.1   22.1
# 1     44.5   10.4
# 2     17.2    9.3
# 3    151.5   18.5
# 4    180.8   12.9
# ..     ...    ...
# 195   38.2    7.6
# 196   94.2    9.7
# 197  177.0   12.8
# 198  283.6   25.5
# 199  232.1   13.4
#
# [200 rows x 2 columns]

# %%
y_predict = slope * X_test + intercept

# %%
#16
from sklearn.metrics import mean_squared_error, r2_score

mse = mean_squared_error(y_test, y_predict)
r2 = r2_score(y_test, y_predict)

print("Mean Squared Error:", mse)
print("R^2 Score:", r2)
# Out:
# Mean Squared Error: 10.919212882879322
# R^2 Score: 0.5533765395302461

# %%
#17
num=np.sum((y_test-y_predict)**2)
den=np.sum((y_test-y_mean)**2) 
r_score=1-(num/den)
r_score
# Out:
# 0.5564723281348657

# %%
num=np.sum((y_test-y_predict)**2)
den=np.sum((y_test-y_mean)**2)
r_square=1-(num/den)
r_square
# Out:
# 0.5564723281348657
