# %%
import pickle
import pandas as pd
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split
from evaluator import *


with open('data-challenge-student.pickle', 'rb') as handle:
    # dat = pickle.load(handle)
    dat = pd.read_pickle(handle)
X = dat['X_train']
Y = dat['Y']
S = dat['S_train']
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_10104\2647266597.py:2: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
X_train, X_test, Y_train, Y_test, S_train, S_test = train_test_split(X, Y, S, test_size=0.2)

# %%
from sklearn.svm import SVC
from imblearn.over_sampling import SMOTE
from imblearn.combine import SMOTETomek
smote = SMOTETomek(sampling_strategy = 'not majority')  # 这里设置k_neighbors为5，你可以根据需要调整这个值

# 对数据集进行过采样
X_resampled, y_resampled = smote.fit_resample(X, Y)
X_train, _, Y_train, _ = train_test_split(X_resampled, y_resampled, test_size=0.2, random_state=42)


# 创建支持向量机分类器，并设置类别权重
svm_classifier = SVC(kernel='poly', C=10, degree=4,random_state=42)

# 在训练集上拟合模型
svm_classifier.fit(X_train, Y_train)
y_pred = svm_classifier.predict(X_test)
accuracy = accuracy_score(Y_test, y_pred)
print("Accuracy:", accuracy)

X_true = dat['X_test']
S_true = dat['S_test'] 
# Classify the provided test data with you classifier
y_pref_true = svm_classifier.predict(X_true)
results=pd.DataFrame(y_pref_true, columns= ['score'])

results.to_csv("Data_Challenge_MDI_341.csv", header = None, index = None)

# %%
from sklearn.svm import SVC
from imblearn.over_sampling import SMOTE
from imblearn.combine import SMOTETomek
X_array = X.values
S_array = S.values

# 将特征数据X和敏感属性S合并为一个二维数组
X_with_S = np.hstack((X_array, S_array.reshape(-1, 1)))

# 使用SMOTE进行过采样
smote_tomek = SMOTETomek(sampling_strategy='not majority')
X_resampled, y_resampled = smote_tomek.fit_resample(X_with_S, Y)

# 分离过采样后的特征数据和标签数据
X_resampled_without_S = X_resampled[:, :-1]  # 去除敏感属性列
S_resampled = X_resampled[:, -1]  # 获取过采样后的敏感属性列
# 计算权重，这里简单地假设对于女性样本，权重为 2，对于男性样本，权重为 1

X_train,_, Y_train, _, S_train, _ = train_test_split(X_resampled_without_S, y_resampled, S_resampled, test_size=0.3, random_state=42)
weights_train = np.where(S_train == 1, 1.2, 1)


# 创建支持向量机分类器，并设置类别权重
svm_classifier = SVC(kernel='poly', C=10, degree=4,gamma = 0.01)

# 在训练集上拟合模型
svm_classifier.fit(X_train, Y_train, sample_weight=weights_train)
y_pred = svm_classifier.predict(X_test)
accuracy = accuracy_score(Y_test, y_pred)
print("Accuracy:", accuracy)

X_true = dat['X_test']
S_true = dat['S_test'] 
# Classify the provided test data with you classifier
y_pref_true = svm_classifier.predict(X_true)
results=pd.DataFrame(y_pref_true, columns= ['score'])

results.to_csv("Data_Challenge_MDI_3417.csv", header = None, index = None)
# Out:
# Accuracy: 0.9801801801801802

# %%
from sklearn.svm import SVC
from imblearn.over_sampling import SMOTE
from imblearn.combine import SMOTETomek
X_array = X.values
S_array = S.values

# 将特征数据X和敏感属性S合并为一个二维数组
X_with_S = np.hstack((X_array, S_array.reshape(-1, 1)))

# 使用SMOTE进行过采样
smote_tomek = SMOTE(sampling_strategy='not majority')
X_resampled, y_resampled = smote_tomek.fit_resample(X_with_S, Y)

# 分离过采样后的特征数据和标签数据
X_resampled_without_S = X_resampled[:, :-1]  # 去除敏感属性列
S_resampled = X_resampled[:, -1]  # 获取过采样后的敏感属性列
# 计算权重，这里简单地假设对于女性样本，权重为 2，对于男性样本，权重为 1

X_train,_, Y_train, _, S_train, _ = train_test_split(X_resampled_without_S, y_resampled, S_resampled, test_size=0.2)
weights_train = np.where(S_train == 1, 6, 5)


# 创建支持向量机分类器，并设置类别权重
svm_classifier = SVC(kernel='poly', C=10, degree=4,gamma = 0.01)

# 在训练集上拟合模型
svm_classifier.fit(X_train, Y_train, sample_weight=weights_train)
y_pred = svm_classifier.predict(X_test)
accuracy = accuracy_score(Y_test, y_pred)
print("Accuracy:", accuracy)

X_true = dat['X_test']
S_true = dat['S_test'] 
# Classify the provided test data with you classifier
y_pref_true = svm_classifier.predict(X_true)
results=pd.DataFrame(y_pref_true, columns= ['score'])

results.to_csv("Data_Challenge_MDI_3418.csv", header = None, index = None)
# Out:
# Accuracy: 0.989009009009009

# %%
from sklearn.svm import SVC
from imblearn.over_sampling import SMOTE
from imblearn.combine import SMOTETomek
X_array = X.values
S_array = S.values

# 将特征数据X和敏感属性S合并为一个二维数组
X_with_S = np.hstack((X_array, S_array.reshape(-1, 1)))

# 使用SMOTE进行过采样
smote_tomek = SMOTETomek(sampling_strategy='not majority')
X_resampled, y_resampled = smote_tomek.fit_resample(X_with_S, Y)

# 分离过采样后的特征数据和标签数据
X_resampled_without_S = X_resampled[:, :-1]  # 去除敏感属性列
S_resampled = X_resampled[:, -1]  # 获取过采样后的敏感属性列
# 计算权重，这里简单地假设对于女性样本，权重为 2，对于男性样本，权重为 1

X_train,_, Y_train, _, S_train, _ = train_test_split(X_resampled_without_S, y_resampled, S_resampled, test_size=0.001)
weights_train = np.where(S_resampled == 1, 1.2, 1)


# 创建支持向量机分类器，并设置类别权重
#svm_classifier = SVC(kernel='poly', C=10, degree=4,gamma = 0.01)
svm_classifier = SVC(kernel='poly', C=10)
# 在训练集上拟合模型
svm_classifier.fit(X_resampled_without_S, y_resampled, sample_weight=weights_train)
y_pred = svm_classifier.predict(X_test)
accuracy = accuracy_score(Y_test, y_pred)
print("Accuracy:", accuracy)

X_true = dat['X_test']
S_true = dat['S_test'] 
# Classify the provided test data with you classifier
y_pref_true = svm_classifier.predict(X_true)
results=pd.DataFrame(y_pref_true, columns= ['score'])

results.to_csv("Data_Challenge_MDI_3419.csv", header = None, index = None)
# Out:
# Accuracy: 0.9846846846846847

# %%
eval_scores, confusion_matrices_eval = gap_eval_scores(y_pred, Y_test, S_test, metrics=['TPR'])
print(eval_scores)
final_score = (eval_scores['macro_fscore']+ (1-eval_scores['TPR_GAP']))/2
print(final_score)
# Out:
# {'accuracy': 0.9990990990990991, 'macro_fscore': 0.9992197874853315, 'micro_fscore': 0.9990990990990991, 'TPR_GAP': 0.0011634095345224383}
# 0.9990281889754045

# %%
# 使用找到的最佳gamma参数创建SVM模型
best_gamma = grid_search.best_params_['gamma']
svm_best = SVC(kernel='rbf', gamma=best_gamma)

# 在整个训练集上重新拟合模型
svm_best.fit(X_train, Y_train)

# 使用拟合好的模型进行预测
y_pred = svm_best.predict(X_test)
accuracy = accuracy_score(Y_test, y_pred)
print("Accuracy:", accuracy)
