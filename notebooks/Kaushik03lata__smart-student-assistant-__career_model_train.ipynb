# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MultiLabelBinarizer
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
import joblib

# %%
# Updated data section for career_model_train.py

data = {
    'skills': [
        ['python', 'machine learning', 'data analysis'],
        ['python', 'flask', 'sql'],
        ['html', 'css', 'javascript'],
        ['aws', 'cloud computing', 'linux'],
        ['java', 'spring', 'hibernate'],
        ['python', 'pandas', 'matplotlib'],
        ['sql', 'excel', 'power bi'],
        ['javascript', 'react', 'css'],
        ['c++', 'oop', 'data structures'],
        ['networking', 'linux', 'firewall'],
        ['python', 'django', 'postgresql'],
        ['python', 'data science', 'nlp'],
        ['html', 'bootstrap', 'jquery'],
        ['aws', 'terraform', 'devops'],
        ['java', 'android', 'xml'],
        ['r', 'statistics', 'data visualization'],
        ['sql', 'etl', 'tableau'],
        ['javascript', 'vue', 'sass'],
        ['c#', '.net', 'sql'],
        ['networking', 'ccna', 'routing'],
        ['python', 'fastapi', 'api development'],
        ['python', 'tensorflow', 'deep learning'],
        ['html', 'javascript', 'figma'],
        ['aws', 'docker', 'kubernetes'],
        ['java', 'junit', 'maven'],
        ['python', 'numpy', 'scikit-learn'],
        ['sql', 'powerbi', 'data modeling'],
        ['javascript', 'nodejs', 'express'],
        ['c++', 'algorithms', 'competitive programming'],
        ['networking', 'vpn', 'security'],
        ['python', 'sqlalchemy', 'rest api'],
        ['python', 'cv2', 'image processing'],
        ['html', 'css', 'responsive design'],
        ['aws', 'lambda', 'serverless'],
        ['java', 'jsp', 'servlets'],
        ['python', 'seaborn', 'eda'],
        ['sql', 'ssis', 'data warehouse'],
        ['javascript', 'typescript', 'nextjs'],
        ['c', 'microcontrollers', 'embedded systems'],
        ['linux', 'cybersecurity', 'pen testing'],
        ['python', 'bokeh', 'dashboard'],
        ['r', 'shiny', 'data reporting'],
        ['html', 'css', 'tailwind'],
        ['aws', 'cloudformation', 'monitoring'],
        ['java', 'struts', 'mvc'],
        ['python', 'keras', 'neural networks'],
        ['sql', 'snowflake', 'analytics'],
        ['javascript', 'jquery', 'ajax'],
        ['c#', 'asp.net', 'mvc'],
        ['networking', 'dns', 'tcp/ip'],
        ['python', 'dash', 'plotly']
    ],
    'career': [
        'Data Scientist',
        'Backend Developer',
        'Frontend Developer',
        'Cloud Engineer',
        'Java Developer',
        'Data Analyst',
        'Business Analyst',
        'Frontend Developer',
        'Software Engineer',
        'Network Engineer',
        'Backend Developer',
        'NLP Engineer',
        'Frontend Developer',
        'DevOps Engineer',
        'Mobile App Developer',
        'Data Analyst',
        'BI Developer',
        'Frontend Developer',
        'Full Stack Developer',
        'Network Engineer',
        'API Developer',
        'AI Engineer',
        'UI/UX Developer',
        'DevOps Engineer',
        'Java Developer',
        'ML Engineer',
        'Power BI Analyst',
        'Backend Developer',
        'Software Engineer',
        'Cybersecurity Analyst',
        'API Developer',
        'Computer Vision Engineer',
        'Web Developer',
        'Cloud Developer',
        'Java Web Developer',
        'Data Analyst',
        'Data Engineer',
        'Full Stack Developer',
        'Embedded Systems Engineer',
        'Cybersecurity Analyst',
        'Data Dashboard Developer',
        'R Shiny Developer',
        'UI Developer',
        'Cloud Architect',
        'Enterprise Java Developer',
        'Deep Learning Engineer',
        'Data Engineer',
        'Frontend Developer',
        '.NET Developer',
        'Network Admin',
        'Dashboard Developer'
    ]
}

# %%
# Convert to DataFrame
df = pd.DataFrame(data)

# %%
# Use MultiLabelBinarizer to convert skills list into one-hot encoding
mlb = MultiLabelBinarizer()
X = mlb.fit_transform(df['skills'])

# Target variable
Y = df['career']

# %%
# train full data 
X_train, Y_train = X,Y
model = RandomForestClassifier(n_estimators=100, random_state=42)
model.fit(X_train, Y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %%
# Save model and mlb to disk
joblib.dump(model, 'career_model.pkl')
# Out:
# ['career_model.pkl']

# %%
joblib.dump(mlb, 'mlb.pkl')
# Out:
# ['mlb.pkl']
