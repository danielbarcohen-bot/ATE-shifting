# %% [markdown]
# #### Experimentation playground for translating Feature Engineering INTO SQL for `gold layer`

# %% [markdown]
# in the silver and gold could we implement zero copy integration by passing same dataframe from the cleaning to that.
# or is the featuren engienering and join overhead more than that.

# %%
import duckdb
import config

# %%
con = duckdb.connect('../duckdb/master_db.duckdb')
con.execute('INSTALL delta; LOAD delta')

# %% [markdown]
# - create a table weekly_sales for original data

# %%
con.sql(f"""
    CREATE TABLE IF NOT EXISTS weekly_sales AS 
    SELECT 
        *
    FROM delta_scan('{config.SILVER_SALES_PATH}') s
    LEFT JOIN delta_scan('{config.SILVER_FEATURES_PATH}') f
        ON s.store = f.store AND s.date = f.date
    LEFT JOIN delta_scan('{config.SILVER_STORES_PATH}') st
        ON s.store = st.store
    """
)

# %%
con.sql('SELECT COUNT(*) FROM weekly_sales LIMIT 5')
# Out:
# ┌──────────────┐
# │ count_star() │
# │    int64     │
# ├──────────────┤
# │       421570 │
# └──────────────┘

# %% [markdown]
# - create the continous scaffold from previous eda's

# %%
sql = """
    CREATE OR REPLACE TABLE scaffold_sales AS 
    WITH calender AS 
    -- Generate Continous weekly Dates
    (SELECT 
         * 
    FROM GENERATE_SERIES(
        (SELECT MIN(date) FROM weekly_sales),
        (SELECT MAX(date) FROM weekly_sales),
        INTERVAL 7 DAYS
    ) AS t(date)),

    -- Get unique store dept combinations
    unique_stores AS 
    (SELECT 
        DISTINCT store,
        dept
     FROM weekly_sales),

     -- Cross join to create the continous timeline
    scaffold AS (
    SELECT 
        u.store, u.dept, c.date
    FROM unique_stores u
    CROSS JOIN calender c ),

    merged_data AS (
    SELECT
        *
    FROM scaffold s
    LEFT JOIN weekly_sales AS sales 
        ON s.store = sales.store AND s.dept = sales.dept AND s.date = sales.date)
        
    SELECT * FROM merged_data;

"""

con.sql(sql)

# %%
con.sql(
    """
    SELECT COUNT(*) FROM scaffold_sales LIMIT 5
    """
)
# Out:
# ┌──────────────┐
# │ count_star() │
# │    int64     │
# ├──────────────┤
# │       476333 │
# └──────────────┘

# %% [markdown]
# - Logic for creating other features

# %%
con.sql(
    """
    CREATE OR REPLACE TABLE features AS  
    SELECT 
        store,
        dept,
        date,
        LN(weekly_sales + 1) AS sales_log,
        SIN(2 * PI() * WEEK(date)/52) AS sin_week,
        COS(2 * PI() * WEEK(date)/52) AS cos_week,
        LAG(LN(weekly_sales + 1), 1) OVER w_momentum AS lag_1,
        LAG(LN(weekly_sales + 1), 5) OVER w_momentum AS lag_5
    FROM scaffold_sales
    WINDOW w_momentum AS (PARTITION BY store, dept ORDER BY date);
    """

)

# %%
con.sql("""SELECT * FROM features""")
# Out:
# ┌───────┬───────┬─────────────────────┬────────────────────┬─────────────────────┬─────────────────────────┬────────────────────┬────────────────────┐
# │ store │ dept  │        date         │     sales_log      │      sin_week       │        cos_week         │       lag_1        │       lag_5        │
# │ int32 │ int32 │      timestamp      │       double       │       double        │         double          │       double       │       double       │
# ├───────┼───────┼─────────────────────┼────────────────────┼─────────────────────┼─────────────────────────┼────────────────────┼────────────────────┤
# │    39 │    41 │ 2010-08-06 00:00:00 │  6.309700072603219 │ -0.5680647467311556 │     -0.8229838658936565 │ 6.5638555265321274 │  5.522580291130163 │
# │    39 │    41 │ 2010-08-13 00:00:00 │  7.622169700043039 │  -0.663122658240795 │     -0.7485107481711013 │  6.309700072603219 │  6.363924253602162 │
# │    39 │    41 │ 2010-08-20 00:00:00 │  7.214607425769474 │ -0.7485107481711011 │     -0.6631226582407952 │  7.622169700043039 │  6.303479411324824 │
# │    39 │    41 │ 2010-08-27 00:00:00 │ 7.3296775552923945 │ -0.8229838658936564 │     -0.5680647467311559 │  7.214607425769474 │  6.249743555190446 │
# │    39 │    41 │ 2010-09-03 00:00:00 │  7.932634909672732 │ -0.8854560256532096 │     -0.4647231720437691 │ 7.3296775552923945 │ 6.5638555265321274 │
# │    39 │    41 │ 2010-09-10 00:00:00 │  7.457897765125078 │ -0.9350162426854147 │     -0.3546048870425359 │  7.932634909672732 │  6.309700072603219 │
# │    39 │    41 │ 2010-09-17 00:00:00 │  7.690743163541872 │  -0.970941817426052 │    -0.23931566428755774 │  7.457897765125078 │  7.622169700043039 │
# │    39 │    41 │ 2010-09-24 00:00:00 │ 7.8900996336474725 │  -0.992708874098054 │    -0.12053668025532357 │  7.690743163541872 │  7.214607425769474 │
# │    39 │    41 │ 2010-10-01 00:00:00 │  7.988502262533002 │                -1.0 │ -1.8369701987210297e-16 │ 7.8900996336474725 │ 7.3296775552923945 │
# │    39 │    41 │ 2010-10-08 00:00:00 │  7.908019444632471 │  -0.992708874098054 │      0.1205366802553232 │  7.988502262533002 │  7.932634909672732 │
# │     · │     · │          ·          │           ·        │           ·         │               ·         │          ·         │          ·         │
# │     · │     · │          ·          │           ·        │           ·         │               ·         │          ·         │          ·         │
# │     · │     · │          ·          │           ·        │           ·         │               ·         │          ·         │          ·         │
# │     3 │    13 │ 2011-09-02 00:00:00 │   9.42257503716988 │ -0.8854560256532096 │     -0.4647231720437691 │  9.329384833922012 │  9.227135540221163 │
# │     3 │    13 │ 2011-09-09 00:00:00 │  9.247146634225796 │ -0.9350162426854147 │     -0.3546048870425359 │   9.42257503716988 │  9.357216081835839 │
# │     3 │    13 │ 2011-09-16 00:00:00 │  9.343849764358701 │  -0.970941817426052 │    -0.23931566428755774 │  9.247146634225796 │  9.261845893841889 │
# │     3 │    13 │ 2011-09-23 00:00:00 │  9.299700155964912 │  -0.992708874098054 │    -0.12053668025532357 │  9.343849764358701 │  9.288749438291712 │
# │     3 │    13 │ 2011-09-30 00:00:00 │  9.287367151692225 │                -1.0 │ -1.8369701987210297e-16 │  9.299700155964912 │  9.329384833922012 │
# │     3 │    13 │ 2011-10-07 00:00:00 │  9.319183117627471 │  -0.992708874098054 │      0.1205366802553232 │  9.287367151692225 │   9.42257503716988 │
# │     3 │    13 │ 2011-10-14 00:00:00 │  9.308691378323136 │ -0.9709418174260521 │     0.23931566428755738 │  9.319183117627471 │  9.247146634225796 │
# │     3 │    13 │ 2011-10-21 00:00:00 │  9.248970526168458 │ -0.9350162426854148 │     0.35460488704253557 │  9.308691378323136 │  9.343849764358701 │
# │     3 │    13 │ 2011-10-28 00:00:00 │   9.18275949235539 │ -0.8854560256532101 │       0.464723172043768 │  9.248970526168458 │  9.299700155964912 │
# │     3 │    13 │ 2011-11-04 00:00:00 │  9.369913466760373 │  -0.822983865893657 │      0.5680647467311548 │   9.18275949235539 │  9.287367151692225 │
# └───────┴───────┴─────────────────────┴────────────────────┴─────────────────────┴─────────────────────────┴────────────────────┴────────────────────┘
#   ? rows (>9999 rows, 20 shown)                                                                                                            8 columns
