# %%
import hashlib
from PIL import Image
import imagehash
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense
from tensorflow.keras.preprocessing.image import img_to_array, load_img
from sklearn.preprocessing import LabelBinarizer
from sklearn.model_selection import train_test_split
from sklearn.metrics.pairwise import cosine_similarity
import joblib
import os

# %%
def _parse_function(proto):
    # Define the feature description dictionary
    keys_to_features = {
        'image/height': tf.io.FixedLenFeature([], tf.int64),
        'image/width': tf.io.FixedLenFeature([], tf.int64),
        'image/filename': tf.io.FixedLenFeature([], tf.string),
        'image/source_id': tf.io.FixedLenFeature([], tf.string),
        'image/encoded': tf.io.FixedLenFeature([], tf.string),
        'image/object/class/label': tf.io.FixedLenFeature([], tf.int64),
    }
    
    parsed_features = tf.io.parse_single_example(proto, keys_to_features)
    image = tf.image.decode_jpeg(parsed_features['image/encoded'])  # Use decode_jpeg or decode_png
    image = tf.image.resize(image, [150, 150])
    image = tf.cast(image, tf.float32) / 255.0
    
    label = parsed_features['image/object/class/label']
    return image, label

# %%
raw_dataset = tf.data.TFRecordDataset('path_to_tfrecord_file')
for raw_record in raw_dataset.take(1):
    print(raw_record.numpy())
# Out:
# ---------------------------------------------------------------------------
# NotFoundError                             Traceback (most recent call last)
# Cell In[33], line 2
#       1 raw_dataset = tf.data.TFRecordDataset('path_to_tfrecord_file')
# ----> 2 for raw_record in raw_dataset.take(1):
#       3     print(raw_record.numpy())
#
# File e:\Anaconda\envs\py310\lib\site-packages\tensorflow\python\data\ops\iterator_ops.py:766, in OwnedIterator.__next__(self)
#     764 def __next__(self):
#     765   try:
# --> 766     return self._next_internal()
#     767   except errors.OutOfRangeError:
#     768     raise StopIteration
#
# File e:\Anaconda\envs\py310\lib\site-packages\tensorflow\python\data\ops\iterator_ops.py:749, in OwnedIterator._next_internal(self)
#     746 # TODO(b/77291417): This runs in sync mode as iterators use an error status
#     747 # to communicate that there is no more data to iterate over.
#     748 with context.execution_mode(context.SYNC):
# --> 749   ret = gen_dataset_ops.iterator_get_next(
#     750       self._iterator_resource,
#     751       output_types=self._flat_output_types,
#     752       output_shapes=self._flat_output_shapes)
#     754   try:
#     755     # Fast path for the case `self._structure` is not a nested structure.
#     756     return self._element_spec._from_compatible_tensor_list(ret)  # pylint: disable=protected-access
#
# File e:\Anaconda\envs\py310\lib\site-packages\tensorflow\python\ops\gen_dataset_ops.py:3016, in iterator_get_next(iterator, output_types, output_shapes, name)
#    3014   return _result
#    3015 except _core._NotOkStatusException as e:
# -> 3016   _ops.raise_from_not_ok_status(e, name)
#    3017 except _core._FallbackException:
#    3018   pass
#
# File e:\Anaconda\envs\py310\lib\site-packages\tensorflow\python\framework\ops.py:7209, in raise_from_not_ok_status(e, name)
#    7207 def raise_from_not_ok_status(e, name):
#    7208   e.message += (" name: " + name if name is not None else "")
# -> 7209   raise core._status_to_exception(e) from None
#
# NotFoundError: {{function_node __wrapped__IteratorGetNext_output_types_1_device_/job:localhost/replica:0/task:0/device:CPU:0}} NewRandomAccessFile failed to Create/Open: path_to_tfrecord_file : The system cannot find the file specified.
# ; No such file or directory [Op:IteratorGetNext]
