# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder
import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader
import torch.nn.functional as F
import matplotlib.pyplot as plt
#from rff.layers import GaussianEncoding #pip install random-fourier-features-pytorch
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, f1_score, recall_score, confusion_matrix
from sklearn.preprocessing import StandardScaler
import seaborn as sns


import sys
import importlib
sys.path.append('../../helpers/')
import helper
sys.path.append('../../model/')
from ourModel import Classifier, train, test

# %%
# Run regardless if you do or do not have GPU so all tensors are moved to right location later on
if torch.cuda.is_available():
    device_in_use = torch.device("cuda")
    print("GPU is available and being used")
else:
    device_in_use = torch.device("cpu")
    print("GPU is not available, using CPU instead")
# Out:
# GPU is available and being used

# %% [markdown]
# # Prepare Dataset

# %%
importlib.reload(helper)
path_to_data = '../../datasets/ddos/01-12/'
samples_per_file = 10
df = helper.get_ddos_data_cleaned(path = path_to_data, num_rows = samples_per_file)
df.rename(columns={'Label':'Attack Type'}, inplace=True)
df.rename(columns={' Protocol':'Protocol'}, inplace=True)
#removes 0 in protocol rows this should not be done if not classifying on protocol
df = df[df['Protocol'] != 0]

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 105 entries, 0 to 9
# Data columns (total 68 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Protocol                      105 non-null    int64
#  1    Flow Duration                105 non-null    int64
#  2    Total Fwd Packets            105 non-null    int64
#  3    Total Backward Packets       105 non-null    int64
#  4   Total Length of Fwd Packets   105 non-null    float64
#  5    Total Length of Bwd Packets  105 non-null    float64
#  6    Fwd Packet Length Max        105 non-null    float64
#  7    Fwd Packet Length Min        105 non-null    float64
#  8    Fwd Packet Length Mean       105 non-null    float64
#  9    Fwd Packet Length Std        105 non-null    float64
#  10  Bwd Packet Length Max         105 non-null    float64
#  11   Bwd Packet Length Min        105 non-null    float64
#  12   Bwd Packet Length Mean       105 non-null    float64
#  13   Bwd Packet Length Std        105 non-null    float64
#  14  Flow Bytes/s                  105 non-null    float64
#  15   Flow Packets/s               105 non-null    float64
#  16   Flow IAT Mean                105 non-null    float64
#  17   Flow IAT Std                 105 non-null    float64
#  18   Flow IAT Max                 105 non-null    float64
#  19   Flow IAT Min                 105 non-null    float64
#  20  Fwd IAT Total                 105 non-null    float64
#  21   Fwd IAT Mean                 105 non-null    float64
#  22   Fwd IAT Std                  105 non-null    float64
#  23   Fwd IAT Max                  105 non-null    float64
#  24   Fwd IAT Min                  105 non-null    float64
#  25  Bwd IAT Total                 105 non-null    float64
#  26   Bwd IAT Mean                 105 non-null    float64
#  27   Bwd IAT Std                  105 non-null    float64
#  28   Bwd IAT Max                  105 non-null    float64
#  29   Bwd IAT Min                  105 non-null    float64
#  30  Fwd PSH Flags                 105 non-null    int64
#  31   Fwd Header Length            105 non-null    int64
#  32   Bwd Header Length            105 non-null    int64
#  33  Fwd Packets/s                 105 non-null    float64
#  34   Bwd Packets/s                105 non-null    float64
#  35   Min Packet Length            105 non-null    float64
#  36   Max Packet Length            105 non-null    float64
#  37   Packet Length Mean           105 non-null    float64
#  38   Packet Length Std            105 non-null    float64
#  39   Packet Length Variance       105 non-null    float64
#  40   SYN Flag Count               105 non-null    int64
#  41   RST Flag Count               105 non-null    int64
#  42   ACK Flag Count               105 non-null    int64
#  43   URG Flag Count               105 non-null    int64
#  44   CWE Flag Count               105 non-null    int64
#  45   Down/Up Ratio                105 non-null    float64
#  46   Average Packet Size          105 non-null    float64
#  47   Avg Fwd Segment Size         105 non-null    float64
#  48   Avg Bwd Segment Size         105 non-null    float64
#  49   Fwd Header Length.1          105 non-null    int64
#  50  Subflow Fwd Packets           105 non-null    int64
#  51   Subflow Fwd Bytes            105 non-null    int64
#  52   Subflow Bwd Packets          105 non-null    int64
#  53   Subflow Bwd Bytes            105 non-null    int64
#  54  Init_Win_bytes_forward        105 non-null    int64
#  55   Init_Win_bytes_backward      105 non-null    int64
#  56   act_data_pkt_fwd             105 non-null    int64
#  57   min_seg_size_forward         105 non-null    int64
#  58  Active Mean                   105 non-null    float64
#  59   Active Std                   105 non-null    float64
#  60   Active Max                   105 non-null    float64
#  61   Active Min                   105 non-null    float64
#  62  Idle Mean                     105 non-null    float64
#  63   Idle Std                     105 non-null    float64
#  64   Idle Max                     105 non-null    float64
#  65   Idle Min                     105 non-null    float64
#  66   Inbound                      105 non-null    int64
#  67  Attack Type                   105 non-null    object
# dtypes: float64(45), int64(22), object(1)
# memory usage: 56.6+ KB

# %% [markdown]
# ### Understanding ddos dataset & CIC flowmeter
# Protocol: 17-UDP 6-TCP 0-Other/Unknown
# Flow Duration: measured in microseconds

# %%
targets = [
    'Attack Type',
      'Protocol'
]

# print(df.shape)
# print(df.dtypes.value_counts())
# for x in targets:
#     print(df[x].value_counts())

# %%
# encode the labels of the targets and create decoding dict
label_encoders = []
encoded_to_labels = []
for x in range(len(targets)):
    label_encoders.append(LabelEncoder())
    df[targets[x]] = label_encoders[x].fit_transform(df[targets[x]])
    encoded_to_labels.append({encoded: label for label, encoded in zip(label_encoders[x].classes_, label_encoders[x].transform(label_encoders[x].classes_))})

# %%
print(encoded_to_labels)
# Out:
# [{0: 'BENIGN', 1: 'DNS', 2: 'LDAP', 3: 'MSSQL', 4: 'NTP', 5: 'NetBIOS', 6: 'SNMP', 7: 'SSDP', 8: 'Syn', 9: 'TFTP', 10: 'UDP', 11: 'UDP-lag'}, {0: 6, 1: 17}]

# %% [markdown]
# # Beyond here you dont have to mess with the dataframe anymore.

# %% [markdown]
# ### Structure data for pytorch and split into training and testing splits

# %%
# dataset wrapper for the dataframe. Just a way to structure the data that pytorch likes and needs to then wrap with dataloader.

class DatasetWrapper(Dataset):
    def __init__(self, df : pd.DataFrame, target : str):
        self.n = df.shape[0]
        
        self.y = df[target].astype(np.int64).values

        self.scalar = StandardScaler()
        self.x = self.scalar.fit_transform(df.drop(columns=targets)).astype(np.float32)

    def __len__(self):
        return self.n
    
    def __getitem__(self, index):
        return self.x[index], self.y[index]
    
exp_dataset = DatasetWrapper(df, target=targets) # UPDATE for your experiments

# Split training and testing samples
train_size = int(0.8*len(exp_dataset)) # Use a different ratio if you want
test_size = len(exp_dataset) - train_size
train_dataset, test_dataset = torch.utils.data.random_split(exp_dataset, [train_size, test_size])

print(f"Train length: {len(train_dataset)}, Test length: {len(test_dataset)}") # See the ratios

batch_size = 256 #Hyperparameter that you should try messing with depending on the size of your dataset. The smaller it is, the more stochastic and chaotic the training gets.

# Wrapping with dataloader so that its easy to extract batches from the train and test subsets
train_dataloader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True) 
test_dataloader = DataLoader(test_dataset, batch_size=batch_size, shuffle=True)
# Out:
# Train length: 84, Test length: 21

# %% [markdown]
# ## Model instantiation

# %%
num_features =  len(train_dataset[0][0])
num_targets =   len(train_dataset[0][1])
classes_per_target = [len(df[t].unique()) for t in targets ]

print(f"Features: {num_features}")
print(f"Targets: {num_targets}")
print(f"Classes per Target: {classes_per_target}")
# Out:
# Features: 66
# Targets: 2
# Classes per Target: [12, 2]

# %%
#Updated with f1
model = Classifier(n_features=num_features, 
                                   pre_norm_on=True, 
                                   rff_on=True, 
                                   forward_expansion=1, 
                                   mlp_scale_classification=2, 
                                   targets_classes=classes_per_target
                                   ).to(device_in_use) # Instantiate the model

# %% [markdown]
# ## Loss functions

# %%
loss_functions = []
#This loop could easily be adapted to us BinaryCrossEntropy for binary class and Cross for multi class
for x in targets:
    loss_functions.append(nn.CrossEntropyLoss())

optimizer = torch.optim.Adam(params=model.parameters(), lr = 0.001) # Maybe try messing around with optimizers. try other torch optimizers with different configurations.

# %% [markdown]
# ## Train Test Loop

# %%
epochs = 40 #Set the number of epochs

# %%
train_losses = []
test_losses = []
train_accuracies = [[] for _ in range(num_targets)]
test_accuracies =  [[] for _ in range(num_targets)]

for t in range(epochs):
  train_loss, train_accuracy= train(train_dataloader, model, loss_functions, optimizer, device_in_use=device_in_use)
  test_loss, test_accuracy, all_predictions, all_targets, f1 = test(test_dataloader, model, loss_functions, device_in_use=device_in_use)

  #Losses
  train_losses.append(train_loss)
  test_losses.append(test_loss)
  #Accuracies
  for i in range(num_targets):
    train_accuracies[i].append(train_accuracy[i])
    test_accuracies[i].append(test_accuracy[i])
 
  # Formatting for easier reading
  epoch_str = f"Epoch [{t+1:2}/{epochs}]"

  train_metrics = f"Train: Loss {train_loss:.2f}"
  for target, Acc in zip(targets, train_accuracy):
    train_metrics += f", {target} Accuracy: {Acc:.2f}"
  
  test_metrics = f"Test: Loss {format_metric(test_loss)}, Attack Type Accuracy {format_metric(test_accuracy[0])}, Attack F1 {format_metric(f1[0])}"
  for target, Acc, fone in zip(targets, test_accuracy, f1):
    test_metrics += f", {target} Accuracy: {Acc:.2f}, {target} F1: {fone:.2f}"

  print(f"{epoch_str:15} | {train_metrics} | {test_metrics}")
# Out:
# Epoch [ 1/40]   | Train: Loss 1.64, Attack Type Accuracy: 0.10, Protocol Accuracy: 0.25 | Test: Loss 1.61, Attack Type Accuracy 0.05, Attack F1 0.00, Attack Type Accuracy: 0.05, Attack Type F1: 0.00, Protocol Accuracy: 0.57, Protocol F1: 0.56
# Epoch [ 2/40]   | Train: Loss 1.62, Attack Type Accuracy: 0.10, Protocol Accuracy: 0.32 | Test: Loss 1.60, Attack Type Accuracy 0.05, Attack F1 0.00, Attack Type Accuracy: 0.05, Attack Type F1: 0.00, Protocol Accuracy: 0.62, Protocol F1: 0.47
# Epoch [ 3/40]   | Train: Loss 1.60, Attack Type Accuracy: 0.10, Protocol Accuracy: 0.75 | Test: Loss 1.60, Attack Type Accuracy 0.05, Attack F1 0.00, Attack Type Accuracy: 0.05, Attack Type F1: 0.00, Protocol Accuracy: 0.62, Protocol F1: 0.47
# Epoch [ 4/40]   | Train: Loss 1.58, Attack Type Accuracy: 0.10, Protocol Accuracy: 0.75 | Test: Loss 1.59, Attack Type Accuracy 0.05, Attack F1 0.00, Attack Type Accuracy: 0.05, Attack Type F1: 0.00, Protocol Accuracy: 0.62, Protocol F1: 0.47
# Epoch [ 5/40]   | Train: Loss 1.56, Attack Type Accuracy: 0.10, Protocol Accuracy: 0.75 | Test: Loss 1.59, Attack Type Accuracy 0.05, Attack F1 0.00, Attack Type Accuracy: 0.05, Attack Type F1: 0.00, Protocol Accuracy: 0.62, Protocol F1: 0.47
# Epoch [ 6/40]   | Train: Loss 1.55, Attack Type Accuracy: 0.10, Protocol Accuracy: 0.75 | Test: Loss 1.59, Attack Type Accuracy 0.05, Attack F1 0.00, Attack Type Accuracy: 0.05, Attack Type F1: 0.00, Protocol Accuracy: 0.62, Protocol F1: 0.47
# Epoch [ 7/40]   | Train: Loss 1.54, Attack Type Accuracy: 0.10, Protocol Accuracy: 0.75 | Test: Loss 1.59, Attack Type Accuracy 0.05, Attack F1 0.00, Attack Type Accuracy: 0.05, Attack Type F1: 0.00, Protocol Accuracy: 0.62, Protocol F1: 0.47
# Epoch [ 8/40]   | Train: Loss 1.53, Attack Type Accuracy: 0.10, Protocol Accuracy: 0.75 | Test: Loss 1.59, Attack Type Accuracy 0.05, Attack F1 0.00, Attack Type Accuracy: 0.05, Attack Type F1: 0.00, Protocol Accuracy: 0.62, Protocol F1: 0.47
# Epoch [ 9/40]   | Train: Loss 1.52, Attack Type Accuracy: 0.10, Protocol Accuracy: 0.75 | Test: Loss 1.59, Attack Type Accuracy 0.05, Attack F1 0.00, Attack Type Accuracy: 0.05, Attack Type F1: 0.00, Protocol Accuracy: 0.62, Protocol F1: 0.47
# Epoch [10/40]   | Train: Loss 1.52, Attack Type Accuracy: 0.10, Protocol Accuracy: 0.75 | Test: Loss 1.60, Attack Type Accuracy 0.05, Attack F1 0.00, Attack Type Accuracy: 0.05, Attack Type F1: 0.00, Protocol Accuracy: 0.62, Protocol F1: 0.47
# Epoch [11/40]   | Train: Loss 1.51, Attack Type Accuracy: 0.10, Protocol Accuracy: 0.75 | Test: Loss 1.60, Attack Type Accuracy 0.05, Attack F1 0.00, Attack Type Accuracy: 0.05, Attack Type F1: 0.00, Protocol Accuracy: 0.62, Protocol F1: 0.47
# Epoch [12/40]   | Train: Loss 1.51, Attack Type Accuracy: 0.08, Protocol Accuracy: 0.75 | Test: Loss 1.60, Attack Type Accuracy 0.05, Attack F1 0.00, Attack Type Accuracy: 0.05, Attack Type F1: 0.00, Protocol Accuracy: 0.62, Protocol F1: 0.47
# Epoch [13/40]   | Train: Loss 1.50, Attack Type Accuracy: 0.10, Protocol Accuracy: 0.75 | Test: Loss 1.60, Attack Type Accuracy 0.05, Attack F1 0.00, Attack Type Accuracy: 0.05, Attack Type F1: 0.00, Protocol Accuracy: 0.62, Protocol F1: 0.47
# Epoch [14/40]   | Train: Loss 1.50, Attack Type Accuracy: 0.10, Protocol Accuracy: 0.75 | Test: Loss 1.60, Attack Type Accuracy 0.05, Attack F1 0.00, Attack Type Accuracy: 0.05, Attack Type F1: 0.00, Protocol Accuracy: 0.62, Protocol F1: 0.47
# Epoch [15/40]   | Train: Loss 1.50, Attack Type Accuracy: 0.10, Protocol Accuracy: 0.75 | Test: Loss 1.60, Attack Type Accuracy 0.05, Attack F1 0.00, Attack Type Accuracy: 0.05, Attack Type F1: 0.00, Protocol Accuracy: 0.62, Protocol F1: 0.47
# Epoch [16/40]   | Train: Loss 1.49, Attack Type Accuracy: 0.10, Protocol Accuracy: 0.75 | Test: Loss 1.60, Attack Type Accuracy 0.05, Attack F1 0.00, Attack Type Accuracy: 0.05, Attack Type F1: 0.00, Protocol Accuracy: 0.62, Protocol F1: 0.47
# Epoch [17/40]   | Train: Loss 1.49, Attack Type Accuracy: 0.10, Protocol Accuracy: 0.75 | Test: Loss 1.60, Attack Type Accuracy 0.05, Attack F1 0.00, Attack Type Accuracy: 0.05, Attack Type F1: 0.00, Protocol Accuracy: 0.62, Protocol F1: 0.47
# Epoch [18/40]   | Train: Loss 1.49, Attack Type Accuracy: 0.10, Protocol Accuracy: 0.75 | Test: Loss 1.59, Attack Type Accuracy 0.05, Attack F1 0.00, Attack Type Accuracy: 0.05, Attack Type F1: 0.00, Protocol Accuracy: 0.62, Protocol F1: 0.47
# Epoch [19/40]   | Train: Loss 1.48, Attack Type Accuracy: 0.10, Protocol Accuracy: 0.75 | Test: Loss 1.59, Attack Type Accuracy 0.05, Attack F1 0.00, Attack Type Accuracy: 0.05, Attack Type F1: 0.00, Protocol Accuracy: 0.62, Protocol F1: 0.47
# Epoch [20/40]   | Train: Loss 1.48, Attack Type Accuracy: 0.10, Protocol Accuracy: 0.75 | Test: Loss 1.59, Attack Type Accuracy 0.05, Attack F1 0.01, Attack Type Accuracy: 0.05, Attack Type F1: 0.01, Protocol Accuracy: 0.62, Protocol F1: 0.47
# Epoch [21/40]   | Train: Loss 1.47, Attack Type Accuracy: 0.10, Protocol Accuracy: 0.75 | Test: Loss 1.58, Attack Type Accuracy 0.05, Attack F1 0.01, Attack Type Accuracy: 0.05, Attack Type F1: 0.01, Protocol Accuracy: 0.62, Protocol F1: 0.47
# Epoch [22/40]   | Train: Loss 1.47, Attack Type Accuracy: 0.10, Protocol Accuracy: 0.75 | Test: Loss 1.58, Attack Type Accuracy 0.05, Attack F1 0.01, Attack Type Accuracy: 0.05, Attack Type F1: 0.01, Protocol Accuracy: 0.62, Protocol F1: 0.47
# Epoch [23/40]   | Train: Loss 1.46, Attack Type Accuracy: 0.10, Protocol Accuracy: 0.75 | Test: Loss 1.57, Attack Type Accuracy 0.05, Attack F1 0.01, Attack Type Accuracy: 0.05, Attack Type F1: 0.01, Protocol Accuracy: 0.62, Protocol F1: 0.47
# Epoch [24/40]   | Train: Loss 1.46, Attack Type Accuracy: 0.10, Protocol Accuracy: 0.75 | Test: Loss 1.57, Attack Type Accuracy 0.05, Attack F1 0.01, Attack Type Accuracy: 0.05, Attack Type F1: 0.01, Protocol Accuracy: 0.62, Protocol F1: 0.47
# Epoch [25/40]   | Train: Loss 1.45, Attack Type Accuracy: 0.10, Protocol Accuracy: 0.75 | Test: Loss 1.56, Attack Type Accuracy 0.05, Attack F1 0.01, Attack Type Accuracy: 0.05, Attack Type F1: 0.01, Protocol Accuracy: 0.62, Protocol F1: 0.47
# Epoch [26/40]   | Train: Loss 1.44, Attack Type Accuracy: 0.10, Protocol Accuracy: 0.75 | Test: Loss 1.55, Attack Type Accuracy 0.05, Attack F1 0.01, Attack Type Accuracy: 0.05, Attack Type F1: 0.01, Protocol Accuracy: 0.62, Protocol F1: 0.47
# Epoch [27/40]   | Train: Loss 1.44, Attack Type Accuracy: 0.10, Protocol Accuracy: 0.75 | Test: Loss 1.55, Attack Type Accuracy 0.05, Attack F1 0.01, Attack Type Accuracy: 0.05, Attack Type F1: 0.01, Protocol Accuracy: 0.62, Protocol F1: 0.47
# Epoch [28/40]   | Train: Loss 1.43, Attack Type Accuracy: 0.10, Protocol Accuracy: 0.75 | Test: Loss 1.54, Attack Type Accuracy 0.05, Attack F1 0.01, Attack Type Accuracy: 0.05, Attack Type F1: 0.01, Protocol Accuracy: 0.62, Protocol F1: 0.47
# Epoch [29/40]   | Train: Loss 1.42, Attack Type Accuracy: 0.10, Protocol Accuracy: 0.75 | Test: Loss 1.53, Attack Type Accuracy 0.05, Attack F1 0.01, Attack Type Accuracy: 0.05, Attack Type F1: 0.01, Protocol Accuracy: 0.62, Protocol F1: 0.47
# Epoch [30/40]   | Train: Loss 1.41, Attack Type Accuracy: 0.10, Protocol Accuracy: 0.75 | Test: Loss 1.52, Attack Type Accuracy 0.05, Attack F1 0.01, Attack Type Accuracy: 0.05, Attack Type F1: 0.01, Protocol Accuracy: 0.62, Protocol F1: 0.47
# Epoch [31/40]   | Train: Loss 1.40, Attack Type Accuracy: 0.10, Protocol Accuracy: 0.75 | Test: Loss 1.51, Attack Type Accuracy 0.10, Attack F1 0.04, Attack Type Accuracy: 0.10, Attack Type F1: 0.04, Protocol Accuracy: 0.62, Protocol F1: 0.47
# Epoch [32/40]   | Train: Loss 1.39, Attack Type Accuracy: 0.18, Protocol Accuracy: 0.75 | Test: Loss 1.49, Attack Type Accuracy 0.19, Attack F1 0.15, Attack Type Accuracy: 0.19, Attack Type F1: 0.15, Protocol Accuracy: 0.62, Protocol F1: 0.47
# Epoch [33/40]   | Train: Loss 1.38, Attack Type Accuracy: 0.25, Protocol Accuracy: 0.75 | Test: Loss 1.48, Attack Type Accuracy 0.19, Attack F1 0.15, Attack Type Accuracy: 0.19, Attack Type F1: 0.15, Protocol Accuracy: 0.62, Protocol F1: 0.47
# Epoch [34/40]   | Train: Loss 1.36, Attack Type Accuracy: 0.25, Protocol Accuracy: 0.75 | Test: Loss 1.47, Attack Type Accuracy 0.24, Attack F1 0.16, Attack Type Accuracy: 0.24, Attack Type F1: 0.16, Protocol Accuracy: 0.62, Protocol F1: 0.47
# Epoch [35/40]   | Train: Loss 1.35, Attack Type Accuracy: 0.27, Protocol Accuracy: 0.75 | Test: Loss 1.45, Attack Type Accuracy 0.29, Attack F1 0.18, Attack Type Accuracy: 0.29, Attack Type F1: 0.18, Protocol Accuracy: 0.62, Protocol F1: 0.47
# Epoch [36/40]   | Train: Loss 1.33, Attack Type Accuracy: 0.30, Protocol Accuracy: 0.75 | Test: Loss 1.44, Attack Type Accuracy 0.29, Attack F1 0.17, Attack Type Accuracy: 0.29, Attack Type F1: 0.17, Protocol Accuracy: 0.62, Protocol F1: 0.47
# Epoch [37/40]   | Train: Loss 1.32, Attack Type Accuracy: 0.30, Protocol Accuracy: 0.75 | Test: Loss 1.42, Attack Type Accuracy 0.29, Attack F1 0.18, Attack Type Accuracy: 0.29, Attack Type F1: 0.18, Protocol Accuracy: 0.62, Protocol F1: 0.47
# Epoch [38/40]   | Train: Loss 1.30, Attack Type Accuracy: 0.29, Protocol Accuracy: 0.75 | Test: Loss 1.40, Attack Type Accuracy 0.24, Attack F1 0.16, Attack Type Accuracy: 0.24, Attack Type F1: 0.16, Protocol Accuracy: 0.62, Protocol F1: 0.47
# Epoch [39/40]   | Train: Loss 1.28, Attack Type Accuracy: 0.31, Protocol Accuracy: 0.77 | Test: Loss 1.37, Attack Type Accuracy 0.19, Attack F1 0.13, Attack Type Accuracy: 0.19, Attack Type F1: 0.13, Protocol Accuracy: 0.71, Protocol F1: 0.66
# Epoch [40/40]   | Train: Loss 1.26, Attack Type Accuracy: 0.31, Protocol Accuracy: 0.88 | Test: Loss 1.35, Attack Type Accuracy 0.19, Attack F1 0.13, Attack Type Accuracy: 0.19, Attack Type F1: 0.13, Protocol Accuracy: 0.76, Protocol F1: 0.73

# %%
plot_num = 1
# Plotting the loss curves
plt.figure(figsize=(15, 5))
plt.subplot(1, 3, plot_num)
plt.plot(range(1, epochs+1), train_losses, label='Train Loss')
plt.plot(range(1, epochs+1), [l for l in test_losses], label='Test Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training and Test Loss Curve')
plt.legend()
plot_num+=1

for i in range(num_targets):
    plt.subplot(1, 3, plot_num)
    plt.plot(range(1, epochs+1), train_accuracies[i], label='Train Accuracy')
    plt.plot(range(1, epochs+1), test_accuracies[i], label='Test Accuracy')
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    plt.title(f'Training and Test Accuracy Curve for {targets[i]}')
    plt.legend()
    plot_num+=1


plt.tight_layout()
plt.tight_layout()
plt.show()

# %%
# actual_labels = [encoded_to_labels[i] for i in sorted(list(set(all_targets[i] + all_predictions[i])))]
# conf_matrix_1 = confusion_matrix(all_targets[i], all_predictions[i])
# plt.figure(figsize=(8, 6))
# sns.heatmap(conf_matrix_1, annot=True, fmt="d", cmap="Blues", cbar=False,
#             xticklabels=actual_labels, yticklabels=actual_labels)
# plt.xlabel('Predicted')
# plt.ylabel('Actual')
# plt.title(f'Confusion Matrix for {targets[0]}')
# plt.show()
