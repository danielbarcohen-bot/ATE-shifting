# %%
import gym
import torch
import torch.nn as nn
import torch.nn.functional as F
env = gym.envs.make("MountainCarContinuous-v0")

# %%
class ActorCriticModel(nn.Module):
    def __init__(self, n_input, n_output, n_hidden):
        super(ActorCriticModel,self).__init__()
        self.fc = nn.Linear(n_input, n_hidden)
        self.mu = nn.Linear(n_hidden, n_output)
        self.sigma = nn.Linear(n_hidden, n_output)
        self.value = nn.Linear(n_hidden, 1)
        self.distribution = torch.distributions.Normal

    def forward(self, x):
        x = F.relu(self.fc(x))
        mu = 2* torch.tanh(self.mu(x))
        sigma = F.softplus(self.sigma(x)) + 1e-5
        dist = self.distribution(mu.view(1,).data,sigma.view(1,).data)
        value = self.value(x)

        return dist, value

# %%
class PolicyNetwork():
    def __init__(self, n_state, n_action, n_hidden=50, lr = 0.001):
        self.model = ActorCriticModel(n_state, n_action, n_hidden)
        self.optimizer = torch.optim.Adam(
            self.model.parameters(),lr
        )

    def predict(self, s):
        self.model.training = False
        return self.model(torch.Tensor(s))
    
    def update(self,returns,  log_probs, state_values):
        loss = 0 
        for log_prob, value, Gt in zip (log_probs,state_values, returns):
            advantage = Gt - value.item()
            policy_loss = -log_prob * advantage
           # print("value ",value)
           # print("log prob " ,log_prob)
            #print("Gt " ,Gt)

            value_loss = F.smooth_l1_loss(value,torch.tensor([Gt]))
            loss += policy_loss  + value_loss
        self.optimizer.zero_grad()
        loss.backward()
        self.optimizer.step()


    
    def get_action(self,s):
        dist , state_value = self.predict(s)
        action = dist.sample().numpy()
        log_prob = dist.log_prob(torch.tensor(action[0]))
        return action , log_prob, state_value

# %%
import sklearn.preprocessing 
import numpy as np
state_space_samples = np.array(
    [env.observation_space.sample() for x in range(10000)]
)

scaler = sklearn.preprocessing.StandardScaler()
scaler.fit(state_space_samples)
# Out:
# StandardScaler()

# %%
def scale_state(state):
    scaled = scaler.transform([state])
    return scaled[0]

# %%
def actor_critic(env, estimator, n_episode , gamma = 1.0):
    for episode in range(n_episode):
        log_probs = []
        rewards = []
        state_values = []
        is_done = False
        state,_ = env.reset()
        #print(state)
        print("begin")
        i =0 
        while True:
            state = scale_state(state)
            action , log_prob, state_value = estimator.get_action(state)
            
            action = action.clip(env.action_space.low[0], env.action_space.high[0])
            #i += 1
            #print("count : ",i)
            next_state, reward , terminated , truncated , _ = env.step(action)
            #print(reward)
            #print(terminated)
            
            if terminated or truncated:
                #reward = reward + 100
                is_done = True
            
            total_reward_episode[episode] += reward
            #print(reward)
            log_probs.append(log_prob)
            state_values.append(state_value)
            rewards.append(reward)
            if is_done:
                
                returns = []
                Gt = 0
                pw = 0
                for reward in rewards[::-1]:
                    Gt += gamma **pw *reward
                    pw += 1
                    returns.append(Gt)

                returns = returns[::-1]
                returns = torch.tensor(returns)
                returns = (returns - returns.mean())/(returns.std() + 1e-9)
               # print("log and state vals", len(log_probs),len(state_values))
                estimator.update(
                    returns, log_probs, state_values
                )
                print('Episode: {}, total reward : {}'.format(episode, total_reward_episode[episode]))
                break 

            state = next_state

# %%
n_state = env.observation_space.shape[0]
n_action = 1
n_hidden = 150
lr = 0.0003
policy_net = PolicyNetwork(n_state,n_action, n_hidden, lr)
gamma = 0.9

# %%
n_episode  = 200
total_reward_episode = [0] * n_episode
actor_critic(env, policy_net, n_episode, gamma)
# Out:
# begin
# /home/prayash/.local/lib/python3.11/site-packages/gym/utils/passive_env_checker.py:233: DeprecationWarning: `np.bool8` is a deprecated alias for `np.bool_`.  (Deprecated NumPy 1.24)
#   if not isinstance(terminated, (bool, np.bool8)):
#
# begin
# Episode: 137, total reward : 81.60091780046872
# begin
# Episode: 138, total reward : 72.91491380859463
# begin
# Episode: 139, total reward : 65.17028950484709
# begin
# Episode: 140, total reward : 86.69698157317
# begin
# Episode: 141, total reward : 85.54658472764602
# begin
# Episode: 142, total reward : 87.5298067599585
# begin
# Episode: 143, total reward : 73.42122226187519
# begin
# Episode: 144, total reward : 86.30757995401629
# begin
# Episode: 145, total reward : 81.97061697803818
# begin
# Episode: 146, total reward : 75.30084620463344
# begin
# Episode: 147, total reward : 73.95130266195014
# begin
# Episode: 148, total reward : 71.74966970707804
# begin
# Episode: 149, total reward : 82.86514502971295
# begin
# Episode: 150, total reward : 77.10412441526464
# begin
# Episode: 151, total reward : 72.84541234863798
# begin
# Episode: 152, total reward : 84.94561502635133
# begin
# Episode: 153, total reward : 82.15538778200208
# begin
# Episode: 154, total reward : 84.9034493407276
# begin
# Episode: 155, total reward : 72.87134827184818
# begin
# Episode: 156, total reward : 82.85513953960943
# begin
# Episode: 157, total reward : 82.60325859125845
# begin
# Episode: 158, total reward : 79.64226410993962
# begin
# Episode: 159, total reward : 73.3584399755226
# begin
# Episode: 160, total reward : 75.4353891187188
# begin
# Episode: 161, total reward : 76.06094790839528
# begin
# Episode: 162, total reward : 76.38782520941307
# begin
# Episode: 163, total reward : 79.32699767354893
# begin
# Episode: 164, total reward : 75.08294556562566
# begin
# Episode: 165, total reward : 78.79420137682786
# begin
# Episode: 166, total reward : 78.24649470464323
# begin
# Episode: 167, total reward : 58.22026479954508
# begin
# Episode: 168, total reward : 85.75634167661373
# begin
# Episode: 169, total reward : 71.71270201766822
# begin
# Episode: 170, total reward : 84.38249530820563
# begin
# Episode: 171, total reward : 82.1968029767888
# begin
# Episode: 172, total reward : 82.38314949423444
# begin
# Episode: 173, total reward : 80.87399773624404
# begin
# Episode: 174, total reward : 63.3636588008715
# begin
# Episode: 175, total reward : 81.56163661304393
# begin
# Episode: 176, total reward : 73.96686601222615
# begin
# Episode: 177, total reward : 76.24959624000394
# begin
# Episode: 178, total reward : 80.7907799885817
# begin
# Episode: 179, total reward : 85.61093276043975
# begin
# Episode: 180, total reward : 80.1345182533843
# begin
# Episode: 181, total reward : 82.20169969304585
# begin
# Episode: 182, total reward : 72.15459321020847
# begin
# Episode: 183, total reward : 77.14297882333703
# begin
# Episode: 184, total reward : 79.64276703782377
# begin
# Episode: 185, total reward : 80.36047908342758
# begin
# Episode: 186, total reward : 72.10062327791482
# begin
# Episode: 187, total reward : 83.38388843196057
# begin
# Episode: 188, total reward : 69.28684079631141
# begin
# Episode: 189, total reward : 73.38799707490432
# begin
# Episode: 190, total reward : 78.42195530215471
# begin
# Episode: 191, total reward : 82.35185056986955
# begin
# Episode: 192, total reward : 83.16224714166972
# begin
# Episode: 193, total reward : 73.0736908059611
# begin
# Episode: 194, total reward : 67.63892861684639
# begin
# Episode: 195, total reward : 70.66904929186174
# begin
# Episode: 196, total reward : 82.9184418684666
# begin
# Episode: 197, total reward : 83.45577543611347
# begin
# Episode: 198, total reward : 88.52336098692948
# begin
# Episode: 199, total reward : 78.33498804631314

# %%
import matplotlib.pyplot as plt
plt.plot(range(100, n_episode), total_reward_episode[100:])
plt.title('Episode reward over time')
plt.xlabel('Episode')
plt.ylabel('Total reward')
plt.show()
