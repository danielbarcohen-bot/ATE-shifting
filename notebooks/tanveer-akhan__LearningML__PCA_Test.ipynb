# %%
import pandas as pd
import numpy as np
from sklearn import decomposition
import tensorflow as tf
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler

# %%
iris_df = sns.load_dataset('iris')
y = iris_df['species']
y = pd.get_dummies(y)
iris_df = iris_df.drop(['species'], axis = 1)

# %%
print(iris_df.head(2))
print(y.head(2))
# Out:
#    sepal_length  sepal_width  petal_length  petal_width
# 0           5.1          3.5           1.4          0.2
# 1           4.9          3.0           1.4          0.2
#    setosa  versicolor  virginica
# 0    True       False      False
# 1    True       False      False

# %%
sns.scatterplot(iris_df).set(title = "IRIS")
plt.show()

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components = 4)
pca.fit(iris_df)
# Out:
# PCA(n_components=4)

# %%
print(pca.explained_variance_ratio_)
compressed_data = pca.fit_transform(iris_df)
# Out:
# [0.92461872 0.05306648 0.01710261 0.00521218]

# %%
var = pca.explained_variance_ratio_
ax = sns.barplot(data = var).set(title = "Scree Plot", ylabel = "Variance")
plt.show()

# %%
#gg = pca.inverse_transform(compressed_data)
sns.scatterplot(compressed_data)
# Out:
# <Axes: >

# %%
pca.fit(compressed_data)
pca.explained_variance_ratio_
# Out:
# array([0.94572232, 0.05427768])
