# %%
import pandas
import requests

# %%
adopce = pandas.read_csv("adopce-zvirat.csv", sep = ';')
adopce.head(5)
# Out:
#    id             nazev_cz                     nazev_en    trida_cz  cena  \
# 0   7          Šváb syčivý  Madagascar giant cockroach   Bezobratlí  1000
# 1   8  Pakobylka okřídlená     Pink-winged stick insect  Bezobratlí  1000
# 2  16                Tayra                        Tayra       Savci  5000
# 3  35        Kajmanka supí    Alligator snapping turtle       Plazi  2000
# 4  37      Želva žlutočelá       Indochinese box turtle       Plazi  1000
#
#    k_prohlidce
# 0            1
# 1            1
# 2            1
# 3            1
# 4            1

# %% [markdown]
# kolik máme řádků umím více způsoby, kolik sloupců samostatně neumím

# %%
# řádky i sloupce
adopce.shape
# Out:
# (513, 6)

# %%
adopce.shape[0]
# nebo
len(adopce)
# Out:
# 513

# %%
# počet sloupců můžu dostat
adopce.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 513 entries, 0 to 512
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id           513 non-null    int64
#  1   nazev_cz     513 non-null    object
#  2   nazev_en     513 non-null    object
#  3   trida_cz     513 non-null    object
#  4   cena         513 non-null    int64
#  5   k_prohlidce  513 non-null    int64
# dtypes: int64(3), object(3)
# memory usage: 24.2+ KB

# %%
# jak se jmenuji sloupce?
adopce.columns
# Out:
# Index(['id', 'nazev_cz', 'nazev_en', 'trida_cz', 'cena', 'k_prohlidce'], dtype='object')

# %%
# název zvířete s indexem 34 v češtině i angličtině.
vybrany_radek = adopce[['nazev_cz', 'nazev_en']]
vybrany_radek.iloc[32]
# Out:
# nazev_cz     Zejozob africký
# nazev_en    African openbill
# Name: 32, dtype: object

# %%
# načti znova s indexem nazev_cz
adopce2 = pandas.read_csv("adopce-zvirat.csv", sep = ';', index_col='nazev_cz')
adopce2.head(7)
# Out:
#                             id                     nazev_en    trida_cz  cena  \
# nazev_cz
# Šváb syčivý                  7  Madagascar giant cockroach   Bezobratlí  1000
# Pakobylka okřídlená          8     Pink-winged stick insect  Bezobratlí  1000
# Tayra                       16                        Tayra       Savci  5000
# Kajmanka supí               35    Alligator snapping turtle       Plazi  2000
# Želva žlutočelá             37       Indochinese box turtle       Plazi  1000
# Želva stepní (= čtyřprstá)  38             Russian tortoise       Plazi  1500
# Želva sloní                 39           Galapagos tortoise       Plazi  5000
#
#                             k_prohlidce
# nazev_cz
# Šváb syčivý                           1
# Pakobylka okřídlená                   1
# Tayra                                 1
# Kajmanka supí                         1
# Želva žlutočelá                       1
# Želva stepní (= čtyřprstá)            1
# ...

# %%
# ověřte, že je index unikátní
adopce2.index.is_unique
# Out:
# True

# %%
# seřadit podle nového indexu - seřadím adopci2, adopce zůstane, jak byla
adopce2 = adopce2.sort_index()
adopce2[500:]
# Out:
#                                              id  \
# nazev_cz
# Želva plochohřbetá                          987
# Želva skalní                                 41
# Želva sloní                                  39
# Želva stepní (= čtyřprstá)                   38
# Želva texaská (= Berlandierova)            1096
# Želva tlustohrdlá                           772
# Želva tuniská                              1160
# Želva zubatá                                771
# Želva černavá                               673
# Želva žlutočelá                              37
# Žirafa severní núbijská (= Rothschildova)   396
# Žluna větší                                1069
# Žluva hajní                                1190
#
#                                                                  nazev_en  \
# nazev_cz
# Želva plochohřbetá                            Malayan flat-shelled turtle
# Želva skalní                                             Pancake tortoise
# ...

# %%
# Vyhledej řádek indexovaný názvem "Outloň váhavý"
adopce2.loc['Outloň váhavý']
# Out:
# id                          749
# nazev_en       Sunda slow loris
# trida_cz                  Savci
# cena                       2000
# k_prohlidce                   1
# Name: Outloň váhavý, dtype: object

# %%
# Vyhledej záznamy mezi "Želva Smithova" a "Želva žlutočelá".
adopce2.loc['Želva Smithova':'Želva žlutočelá']
# Out:
#                                    id                        nazev_en  \
# nazev_cz
# Želva Smithova                   1117               Brown roof turtle
# Želva amboinská                   479              Malayan box turtle
# Želva annámská                    478          Vietnamese pond turtle
# Želva bahenní                    1115            European pond turtle
# Želva dlaždicovitá               1338              Impressed tortoise
# Želva egyptská                    980               Egyptian tortoise
# Želva hvězdnatá                  1412
# Želva korunkatá                  1112            Crowned river turtle
# Želva kubánská                    830          North Antillean slider
# Želva obrovská                     40          Aldabra giant tortoise
# Želva ostnitá                    1255                    Spiny turtle
# Želva pardálí                     763                Leopard tortoise
# Želva plochohřbetá                987     Malayan flat-shelled turtle
# ...
