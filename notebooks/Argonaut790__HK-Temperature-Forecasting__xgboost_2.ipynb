# %%
from utils.DataPreprocessing import dataloader
from loguru import logger
import os

path = os.path.dirname(os.path.dirname(os.getcwd()))
print(path)
lag = 20
n_steps_out = 1
data = dataloader(path=path, lag=lag)
# Out:
# 2024-04-18 07:29:35.139 | INFO     | utils.DataPreprocessing:load_csv:129 - shape: (11_103, 3)
# ┌───────────┬─────────────┬────────────┐
# │ AVG_TEMP  ┆ AVG_TEMP_DC ┆ date       │
# │ ---       ┆ ---         ┆ ---        │
# │ f32       ┆ str         ┆ date       │
# ╞═══════════╪═════════════╪════════════╡
# │ 29.299999 ┆ C           ┆ 1992-07-01 │
# │ 29.200001 ┆ C           ┆ 1992-07-02 │
# │ 29.6      ┆ C           ┆ 1992-07-03 │
# │ 29.299999 ┆ C           ┆ 1992-07-04 │
# │ 29.299999 ┆ C           ┆ 1992-07-05 │
# │ …         ┆ …           ┆ …          │
# │ 22.200001 ┆ C           ┆ 2022-11-26 │
# │ 22.4      ┆ C           ┆ 2022-11-27 │
# │ 25.4      ┆ C           ┆ 2022-11-28 │
# │ 25.1      ┆ C           ┆ 2022-11-29 │
# │ 22.1      ┆ C           ┆ 2022-11-30 │
# └───────────┴─────────────┴────────────┘
# 2024-04-18 07:29:35.140 | INFO     | utils.DataPreprocessing:load_csv:131 - shape: (1, 3)
# ┌──────────┬─────────────┬──────┐
# │ AVG_TEMP ┆ AVG_TEMP_DC ┆ date │
# │ ---      ┆ ---         ┆ ---  │
# │ u32      ┆ u32         ┆ u32  │
# ╞══════════╪═════════════╪══════╡
# │ 0        ┆ 0           ┆ 0    │
# └──────────┴─────────────┴──────┘
# 2024-04-18 07:29:35.150 | INFO     | utils.DataPreprocessing:load_csv:129 - shape: (11_110, 3)
# ┌───────────┬────────┬────────────┐
# │ GSR       ┆ GSR_DC ┆ date       │
# │ ---       ┆ ---    ┆ ---        │
# │ f32       ┆ str    ┆ date       │
# ╞═══════════╪════════╪════════════╡
# │ 20.1      ┆ C      ┆ 1992-07-01 │
# │ 17.76     ┆ C      ┆ 1992-07-02 │
# │ 19.799999 ┆ C      ┆ 1992-07-03 │
# │ 9.19      ┆ C      ┆ 1992-07-04 │
# │ 14.14     ┆ C      ┆ 1992-07-05 │
# │ …         ┆ …      ┆ …          │
# │ 4.27      ┆ C      ┆ 2022-11-26 │
# │ 3.66      ┆ C      ┆ 2022-11-27 │
# │ 11.34     ┆ C      ┆ 2022-11-28 │
# │ 17.049999 ┆ C      ┆ 2022-11-29 │
# │ 7.06      ┆ C      ┆ 2022-11-30 │
# └───────────┴────────┴────────────┘
# 2024-04-18 07:29:35.152 | INFO     | utils.DataPreprocessing:load_csv:131 - shape: (1, 3)
# ┌─────┬────────┬──────┐
# │ GSR ┆ GSR_DC ┆ date │
# │ --- ┆ ---    ┆ ---  │
# │ u32 ┆ u32    ┆ u32  │
# ╞═════╪════════╪══════╡
# │ 0   ┆ 0      ┆ 0    │
# └─────┴────────┴──────┘
# 2024-04-18 07:29:35.160 | INFO     | utils.DataPreprocessing:load_csv:129 - shape: (11_101, 3)
# ┌──────┬───────┬────────────┐
# │ RH   ┆ RH_DC ┆ date       │
# │ ---  ┆ ---   ┆ ---        │
# │ f32  ┆ str   ┆ date       │
# ╞══════╪═══════╪════════════╡
# │ 80.0 ┆ C     ┆ 1992-07-01 │
# │ 81.0 ┆ C     ┆ 1992-07-02 │
# │ 79.0 ┆ C     ┆ 1992-07-03 │
# │ 82.0 ┆ C     ┆ 1992-07-04 │
# │ 81.0 ┆ C     ┆ 1992-07-05 │
# │ …    ┆ …     ┆ …          │
# │ 89.0 ┆ C     ┆ 2022-11-26 │
# │ 92.0 ┆ C     ┆ 2022-11-27 │
# │ 88.0 ┆ C     ┆ 2022-11-28 │
# │ 86.0 ┆ C     ┆ 2022-11-29 │
# │ 83.0 ┆ C     ┆ 2022-11-30 │
# └──────┴───────┴────────────┘
# 2024-04-18 07:29:35.161 | INFO     | utils.DataPreprocessing:load_csv:131 - shape: (1, 3)
# ┌─────┬───────┬──────┐
# │ RH  ┆ RH_DC ┆ date │
# │ --- ┆ ---   ┆ ---  │
# │ u32 ┆ u32   ┆ u32  │
# ╞═════╪═══════╪══════╡
# │ 0   ┆ 0     ┆ 0    │
# └─────┴───────┴──────┘
# 2024-04-18 07:29:35.169 | INFO     | utils.DataPreprocessing:load_csv:129 - shape: (11_110, 3)
# ┌──────┬────────┬────────────┐
# │ SUN  ┆ SUN_DC ┆ date       │
# │ ---  ┆ ---    ┆ ---        │
# │ f32  ┆ str    ┆ date       │
# ╞══════╪════════╪════════════╡
# │ 10.7 ┆ C      ┆ 1992-07-01 │
# │ 8.4  ┆ C      ┆ 1992-07-02 │
# │ 8.6  ┆ C      ┆ 1992-07-03 │
# │ 1.4  ┆ C      ┆ 1992-07-04 │
# │ 1.5  ┆ C      ┆ 1992-07-05 │
# │ …    ┆ …      ┆ …          │
# │ 0.2  ┆ C      ┆ 2022-11-26 │
# │ 0.0  ┆ C      ┆ 2022-11-27 │
# │ 4.2  ┆ C      ┆ 2022-11-28 │
# │ 8.9  ┆ C      ┆ 2022-11-29 │
# │ 2.6  ┆ C      ┆ 2022-11-30 │
# └──────┴────────┴────────────┘
# 2024-04-18 07:29:35.170 | INFO     | utils.DataPreprocessing:load_csv:131 - shape: (1, 3)
# ┌─────┬────────┬──────┐
# │ SUN ┆ SUN_DC ┆ date │
# │ --- ┆ ---    ┆ ---  │
# │ u32 ┆ u32    ┆ u32  │
# ╞═════╪════════╪══════╡
# │ 0   ┆ 0      ┆ 0    │
# └─────┴────────┴──────┘
# 2024-04-18 07:29:35.178 | INFO     | utils.DataPreprocessing:load_csv:129 - shape: (11_261, 3)
# ┌─────┬───────┬────────────┐
# │ RF  ┆ RF_DC ┆ date       │
# │ --- ┆ ---   ┆ ---        │
# │ f32 ┆ str   ┆ date       │
# ╞═════╪═══════╪════════════╡
# │ 0.0 ┆ C     ┆ 1992-07-01 │
# │ 1.7 ┆ C     ┆ 1992-07-02 │
# │ 0.0 ┆ C     ┆ 1992-07-03 │
# │ 1.8 ┆ C     ┆ 1992-07-04 │
# │ 1.0 ┆ C     ┆ 1992-07-05 │
# │ …   ┆ …     ┆ …          │
# │ 0.0 ┆ C     ┆ 2023-04-26 │
# │ 0.0 ┆ C     ┆ 2023-04-27 │
# │ 1.2 ┆ C     ┆ 2023-04-28 │
# │ 0.0 ┆ C     ┆ 2023-04-29 │
# │ 0.0 ┆ C     ┆ 2023-04-30 │
# └─────┴───────┴────────────┘
# 2024-04-18 07:29:35.180 | INFO     | utils.DataPreprocessing:load_csv:131 - shape: (1, 3)
# ┌─────┬───────┬──────┐
# │ RF  ┆ RF_DC ┆ date │
# │ --- ┆ ---   ┆ ---  │
# │ u32 ┆ u32   ┆ u32  │
# ╞═════╪═══════╪══════╡
# │ 11  ┆ 11    ┆ 0    │
# └─────┴───────┴──────┘
# 2024-04-18 07:29:35.188 | INFO     | utils.DataPreprocessing:load_csv:129 - shape: (8_642, 3)
# ┌─────┬───────┬────────────┐
# │ UV  ┆ UV_DC ┆ date       │
# │ --- ┆ ---   ┆ ---        │
# │ f32 ┆ str   ┆ date       │
# ╞═════╪═══════╪════════════╡
# │ 7.0 ┆ C     ┆ 1999-08-01 │
# │ 3.0 ┆ C     ┆ 1999-08-02 │
# │ 3.0 ┆ C     ┆ 1999-08-03 │
# │ 3.0 ┆ C     ┆ 1999-08-04 │
# │ 4.0 ┆ C     ┆ 1999-08-05 │
# │ …   ┆ …     ┆ …          │
# │ 0.3 ┆ C     ┆ 2023-03-27 │
# │ 0.5 ┆ C     ┆ 2023-03-28 │
# │ 2.0 ┆ C     ┆ 2023-03-29 │
# │ 0.9 ┆ C     ┆ 2023-03-30 │
# │ 0.6 ┆ C     ┆ 2023-03-31 │
# └─────┴───────┴────────────┘
# 2024-04-18 07:29:35.189 | INFO     | utils.DataPreprocessing:load_csv:131 - shape: (1, 3)
# ┌─────┬───────┬──────┐
# │ UV  ┆ UV_DC ┆ date │
# │ --- ┆ ---   ┆ ---  │
# │ u32 ┆ u32   ┆ u32  │
# ╞═════╪═══════╪══════╡
# │ 11  ┆ 11    ┆ 0    │
# └─────┴───────┴──────┘
# 2024-04-18 07:29:35.198 | INFO     | utils.DataPreprocessing:load_csv:129 - shape: (11_261, 3)
# ┌──────┬─────────┬────────────┐
# │ WSPD ┆ WSPD_DC ┆ date       │
# │ ---  ┆ ---     ┆ ---        │
# │ f32  ┆ str     ┆ date       │
# ╞══════╪═════════╪════════════╡
# │ 6.4  ┆ #       ┆ 1992-07-01 │
# │ 7.4  ┆ #       ┆ 1992-07-02 │
# │ 8.5  ┆ C       ┆ 1992-07-03 │
# │ 11.0 ┆ C       ┆ 1992-07-04 │
# │ 14.5 ┆ C       ┆ 1992-07-05 │
# │ …    ┆ …       ┆ …          │
# │ 8.8  ┆ C       ┆ 2023-04-26 │
# │ 13.3 ┆ C       ┆ 2023-04-27 │
# │ 12.3 ┆ C       ┆ 2023-04-28 │
# │ 6.5  ┆ C       ┆ 2023-04-29 │
# │ 8.4  ┆ C       ┆ 2023-04-30 │
# └──────┴─────────┴────────────┘
# 2024-04-18 07:29:35.200 | INFO     | utils.DataPreprocessing:load_csv:131 - shape: (1, 3)
# ┌──────┬─────────┬──────┐
# │ WSPD ┆ WSPD_DC ┆ date │
# │ ---  ┆ ---     ┆ ---  │
# │ u32  ┆ u32     ┆ u32  │
# ╞══════╪═════════╪══════╡
# │ 21   ┆ 21      ┆ 0    │
# └──────┴─────────┴──────┘
# 2024-04-18 07:29:35.233 | INFO     | utils.DataPreprocessing:feature_engineering:262 - RF
# 2024-04-18 07:29:35.234 | DEBUG    | utils.DataPreprocessing:remove_outliers:168 - shape: (5, 3)
# ┌─────┬───────┬────────────┐
# │ RF  ┆ RF_DC ┆ date       │
# │ --- ┆ ---   ┆ ---        │
# │ f32 ┆ str   ┆ date       │
# ╞═════╪═══════╪════════════╡
# │ 0.0 ┆ C     ┆ 1992-07-01 │
# │ 1.7 ┆ C     ┆ 1992-07-02 │
# │ 0.0 ┆ C     ┆ 1992-07-03 │
# │ 1.8 ┆ C     ┆ 1992-07-04 │
# │ 1.0 ┆ C     ┆ 1992-07-05 │
# └─────┴───────┴────────────┘
# 2024-04-18 07:29:35.238 | INFO     | utils.DataPreprocessing:feature_engineering:265 - WSPD
# 2024-04-18 07:29:35.239 | DEBUG    | utils.DataPreprocessing:remove_outliers:168 - shape: (5, 3)
# ┌──────┬─────────┬────────────┐
# │ WSPD ┆ WSPD_DC ┆ date       │
# │ ---  ┆ ---     ┆ ---        │
# │ f32  ┆ str     ┆ date       │
# ╞══════╪═════════╪════════════╡
# │ 6.4  ┆ #       ┆ 1992-07-01 │
# │ 7.4  ┆ #       ┆ 1992-07-02 │
# │ 8.5  ┆ C       ┆ 1992-07-03 │
# │ 11.0 ┆ C       ┆ 1992-07-04 │
# │ 14.5 ┆ C       ┆ 1992-07-05 │
# └──────┴─────────┴────────────┘
# 2024-04-18 07:29:35.242 | SUCCESS  | utils.DataPreprocessing:feature_engineering:270 - Removed 76 outliers from RF
# 2024-04-18 07:29:35.243 | SUCCESS  | utils.DataPreprocessing:feature_engineering:271 - Removed 56 outliers from WSPD
# 2024-04-18 07:29:35.274 | ERROR    | utils.DataPreprocessing:feature_engineering:285 - shape: (8_523, 8)
# ┌───────────┬─────────────────────┬───────────┬──────┬──────┬─────┬──────┬──────┐
# │ AVG_TEMP  ┆ date                ┆ GSR       ┆ SUN  ┆ RH   ┆ UV  ┆ RF   ┆ WSPD │
# │ ---       ┆ ---                 ┆ ---       ┆ ---  ┆ ---  ┆ --- ┆ ---  ┆ ---  │
# │ f32       ┆ datetime[μs]        ┆ f32       ┆ f32  ┆ f32  ┆ f32 ┆ f32  ┆ f32  │
# ╞═══════════╪═════════════════════╪═══════════╪══════╪══════╪═════╪══════╪══════╡
# │ 29.200001 ┆ 1999-08-01 00:00:00 ┆ 25.1      ┆ 11.6 ┆ 79.0 ┆ 7.0 ┆ 0.5  ┆ 8.6  │
# │ 29.1      ┆ 1999-08-02 00:00:00 ┆ 15.13     ┆ 7.0  ┆ 82.0 ┆ 3.0 ┆ 30.5 ┆ 4.1  │
# │ 29.0      ┆ 1999-08-03 00:00:00 ┆ 11.85     ┆ 2.4  ┆ 83.0 ┆ 3.0 ┆ 0.0  ┆ 5.3  │
# │ 27.5      ┆ 1999-08-04 00:00:00 ┆ 10.67     ┆ 2.3  ┆ 87.0 ┆ 3.0 ┆ 35.0 ┆ 9.1  │
# │ 27.9      ┆ 1999-08-05 00:00:00 ┆ 15.18     ┆ 6.0  ┆ 82.0 ┆ 4.0 ┆ 55.0 ┆ 7.8  │
# │ …         ┆ …                   ┆ …         ┆ …    ┆ …    ┆ …   ┆ …    ┆ …    │
# │ 22.200001 ┆ 2022-11-26 00:00:00 ┆ 4.27      ┆ 0.2  ┆ 89.0 ┆ 0.9 ┆ 0.6  ┆ 7.2  │
# │ 22.4      ┆ 2022-11-27 00:00:00 ┆ 3.66      ┆ 0.0  ┆ 92.0 ┆ 0.8 ┆ 0.8  ┆ 13.9 │
# │ 25.4      ┆ 2022-11-28 00:00:00 ┆ 11.34     ┆ 4.2  ┆ 88.0 ┆ 2.0 ┆ 0.7  ┆ 7.8  │
# │ 25.1      ┆ 2022-11-29 00:00:00 ┆ 17.049999 ┆ 8.9  ┆ 86.0 ┆ 3.0 ┆ 0.0  ┆ 8.0  │
# │ 22.1      ┆ 2022-11-30 00:00:00 ┆ 7.06      ┆ 2.6  ┆ 83.0 ┆ 1.0 ┆ 0.0  ┆ 8.5  │
# └───────────┴─────────────────────┴───────────┴──────┴──────┴─────┴──────┴──────┘
# 2024-04-18 07:29:35.281 | INFO     | utils.DataPreprocessing:feature_engineering:295 - shape: (8_523, 16)
# ┌───────────┬───────────────┬───────────┬──────┬───┬────────────┬────────────┬───────────┬─────────┐
# │ AVG_TEMP  ┆ date          ┆ GSR       ┆ SUN  ┆ … ┆ dayofmonth ┆ weekofyear ┆ dayofyear ┆ quarter │
# │ ---       ┆ ---           ┆ ---       ┆ ---  ┆   ┆ ---        ┆ ---        ┆ ---       ┆ ---     │
# │ f32       ┆ datetime[μs]  ┆ f32       ┆ f32  ┆   ┆ i8         ┆ i8         ┆ i16       ┆ i8      │
# ╞═══════════╪═══════════════╪═══════════╪══════╪═══╪════════════╪════════════╪═══════════╪═════════╡
# │ 29.200001 ┆ 1999-08-01    ┆ 25.1      ┆ 11.6 ┆ … ┆ 1          ┆ 30         ┆ 213       ┆ 3       │
# │           ┆ 00:00:00      ┆           ┆      ┆   ┆            ┆            ┆           ┆         │
# │ 29.1      ┆ 1999-08-02    ┆ 15.13     ┆ 7.0  ┆ … ┆ 2          ┆ 31         ┆ 214       ┆ 3       │
# │           ┆ 00:00:00      ┆           ┆      ┆   ┆            ┆            ┆           ┆         │
# │ 29.0      ┆ 1999-08-03    ┆ 11.85     ┆ 2.4  ┆ … ┆ 3          ┆ 31         ┆ 215       ┆ 3       │
# │           ┆ 00:00:00      ┆           ┆      ┆   ┆            ┆            ┆           ┆         │
# │ 27.5      ┆ 1999-08-04    ┆ 10.67     ┆ 2.3  ┆ … ┆ 4          ┆ 31         ┆ 216       ┆ 3       │
# │           ┆ 00:00:00      ┆           ┆      ┆   ┆            ┆            ┆           ┆         │
# │ 27.9      ┆ 1999-08-05    ┆ 15.18     ┆ 6.0  ┆ … ┆ 5          ┆ 31         ┆ 217       ┆ 3       │
# │           ┆ 00:00:00      ┆           ┆      ┆   ┆            ┆            ┆           ┆         │
# │ …         ┆ …             ┆ …         ┆ …    ┆ … ┆ …          ┆ …          ┆ …         ┆ …       │
# │ 22.200001 ┆ 2022-11-26    ┆ 4.27      ┆ 0.2  ┆ … ┆ 26         ┆ 47         ┆ 330       ┆ 4       │
# │           ┆ 00:00:00      ┆           ┆      ┆   ┆            ┆            ┆           ┆         │
# │ 22.4      ┆ 2022-11-27    ┆ 3.66      ┆ 0.0  ┆ … ┆ 27         ┆ 47         ┆ 331       ┆ 4       │
# │           ┆ 00:00:00      ┆           ┆      ┆   ┆            ┆            ┆           ┆         │
# │ 25.4      ┆ 2022-11-28    ┆ 11.34     ┆ 4.2  ┆ … ┆ 28         ┆ 48         ┆ 332       ┆ 4       │
# │           ┆ 00:00:00      ┆           ┆      ┆   ┆            ┆            ┆           ┆         │
# │ 25.1      ┆ 2022-11-29    ┆ 17.049999 ┆ 8.9  ┆ … ┆ 29         ┆ 48         ┆ 333       ┆ 4       │
# │           ┆ 00:00:00      ┆           ┆      ┆   ┆            ┆            ┆           ┆         │
# │ 22.1      ┆ 2022-11-30    ┆ 7.06      ┆ 2.6  ┆ … ┆ 30         ┆ 48         ┆ 334       ┆ 4       │
# │           ┆ 00:00:00      ┆           ┆      ┆   ┆            ┆            ┆           ┆         │
# └───────────┴───────────────┴───────────┴──────┴───┴────────────┴────────────┴───────────┴─────────┘
# 2024-04-18 07:29:35.282 | INFO     | utils.DataPreprocessing:feature_engineering:296 - shape: (1, 16)
# ┌──────────┬──────┬─────┬─────┬───┬────────────┬────────────┬───────────┬─────────┐
# │ AVG_TEMP ┆ date ┆ GSR ┆ SUN ┆ … ┆ dayofmonth ┆ weekofyear ┆ dayofyear ┆ quarter │
# │ ---      ┆ ---  ┆ --- ┆ --- ┆   ┆ ---        ┆ ---        ┆ ---       ┆ ---     │
# │ u32      ┆ u32  ┆ u32 ┆ u32 ┆   ┆ u32        ┆ u32        ┆ u32       ┆ u32     │
# ╞══════════╪══════╪═════╪═════╪═══╪════════════╪════════════╪═══════════╪═════════╡
# │ 0        ┆ 0    ┆ 0   ┆ 0   ┆ … ┆ 0          ┆ 0          ┆ 0         ┆ 0       │
# └──────────┴──────┴─────┴─────┴───┴────────────┴────────────┴───────────┴─────────┘
# 2024-04-18 07:29:35.291 | INFO     | utils.DataPreprocessing:feature_engineering:308 - shape: (8_503, 36)
# ┌───────────┬────────────┬───────────┬─────┬───┬────────────┬────────────┬────────────┬────────────┐
# │ AVG_TEMP  ┆ date       ┆ GSR       ┆ SUN ┆ … ┆ AVG_TEMP_t ┆ AVG_TEMP_t ┆ AVG_TEMP_t ┆ AVG_TEMP_t │
# │ ---       ┆ ---        ┆ ---       ┆ --- ┆   ┆ -4         ┆ -3         ┆ -2         ┆ -1         │
# │ f32       ┆ datetime[μ ┆ f32       ┆ f32 ┆   ┆ ---        ┆ ---        ┆ ---        ┆ ---        │
# │           ┆ s]         ┆           ┆     ┆   ┆ f32        ┆ f32        ┆ f32        ┆ f32        │
# ╞═══════════╪════════════╪═══════════╪═════╪═══╪════════════╪════════════╪════════════╪════════════╡
# │ 29.299999 ┆ 1999-08-21 ┆ 16.440001 ┆ 6.9 ┆ … ┆ 28.799999  ┆ 29.0       ┆ 29.299999  ┆ 30.299999  │
# │           ┆ 00:00:00   ┆           ┆     ┆   ┆            ┆            ┆            ┆            │
# │ 25.9      ┆ 1999-08-22 ┆ 1.93      ┆ 0.0 ┆ … ┆ 29.0       ┆ 29.299999  ┆ 30.299999  ┆ 29.299999  │
# │           ┆ 00:00:00   ┆           ┆     ┆   ┆            ┆            ┆            ┆            │
# │ 24.1      ┆ 1999-08-23 ┆ 3.04      ┆ 0.0 ┆ … ┆ 29.299999  ┆ 30.299999  ┆ 29.299999  ┆ 25.9       │
# │           ┆ 00:00:00   ┆           ┆     ┆   ┆            ┆            ┆            ┆            │
# │ 24.9      ┆ 1999-08-24 ┆ 4.34      ┆ 0.0 ┆ … ┆ 30.299999  ┆ 29.299999  ┆ 25.9       ┆ 24.1       │
# │           ┆ 00:00:00   ┆           ┆     ┆   ┆            ┆            ┆            ┆            │
# │ 25.0      ┆ 1999-08-25 ┆ 2.04      ┆ 0.0 ┆ … ┆ 29.299999  ┆ 25.9       ┆ 24.1       ┆ 24.9       │
# │           ┆ 00:00:00   ┆           ┆     ┆   ┆            ┆            ┆            ┆            │
# │ …         ┆ …          ┆ …         ┆ …   ┆ … ┆ …          ┆ …          ┆ …          ┆ …          │
# │ 22.200001 ┆ 2022-11-26 ┆ 4.27      ┆ 0.2 ┆ … ┆ 22.9       ┆ 22.799999  ┆ 21.299999  ┆ 21.799999  │
# │           ┆ 00:00:00   ┆           ┆     ┆   ┆            ┆            ┆            ┆            │
# │ 22.4      ┆ 2022-11-27 ┆ 3.66      ┆ 0.0 ┆ … ┆ 22.799999  ┆ 21.299999  ┆ 21.799999  ┆ 22.200001  │
# │           ┆ 00:00:00   ┆           ┆     ┆   ┆            ┆            ┆            ┆            │
# │ 25.4      ┆ 2022-11-28 ┆ 11.34     ┆ 4.2 ┆ … ┆ 21.299999  ┆ 21.799999  ┆ 22.200001  ┆ 22.4       │
# │           ┆ 00:00:00   ┆           ┆     ┆   ┆            ┆            ┆            ┆            │
# │ 25.1      ┆ 2022-11-29 ┆ 17.049999 ┆ 8.9 ┆ … ┆ 21.799999  ┆ 22.200001  ┆ 22.4       ┆ 25.4       │
# │           ┆ 00:00:00   ┆           ┆     ┆   ┆            ┆            ┆            ┆            │
# │ 22.1      ┆ 2022-11-30 ┆ 7.06      ┆ 2.6 ┆ … ┆ 22.200001  ┆ 22.4       ┆ 25.4       ┆ 25.1       │
# │           ┆ 00:00:00   ┆           ┆     ┆   ┆            ┆            ┆            ┆            │
# └───────────┴────────────┴───────────┴─────┴───┴────────────┴────────────┴────────────┴────────────┘
# /home/argonaut/programming/Global-Solar-Radiation-in-King-s-Park

# %%
logger.success(data.X_train)
logger.success(data.y_train)
logger.success(data.X_test)
logger.success(data.y_test)
# Out:
# 2024-04-18 07:29:35.304 | SUCCESS  | __main__:<module>:1 - shape: (6_802, 34)
# ┌───────────┬──────┬──────┬─────┬───┬──────────────┬──────────────┬──────────────┬──────────────┐
# │ GSR       ┆ SUN  ┆ RH   ┆ UV  ┆ … ┆ AVG_TEMP_t-4 ┆ AVG_TEMP_t-3 ┆ AVG_TEMP_t-2 ┆ AVG_TEMP_t-1 │
# │ ---       ┆ ---  ┆ ---  ┆ --- ┆   ┆ ---          ┆ ---          ┆ ---          ┆ ---          │
# │ f32       ┆ f32  ┆ f32  ┆ f32 ┆   ┆ f32          ┆ f32          ┆ f32          ┆ f32          │
# ╞═══════════╪══════╪══════╪═════╪═══╪══════════════╪══════════════╪══════════════╪══════════════╡
# │ 16.440001 ┆ 6.9  ┆ 75.0 ┆ 4.0 ┆ … ┆ 28.799999    ┆ 29.0         ┆ 29.299999    ┆ 30.299999    │
# │ 1.93      ┆ 0.0  ┆ 79.0 ┆ 0.6 ┆ … ┆ 29.0         ┆ 29.299999    ┆ 30.299999    ┆ 29.299999    │
# │ 3.04      ┆ 0.0  ┆ 92.0 ┆ 1.0 ┆ … ┆ 29.299999    ┆ 30.299999    ┆ 29.299999    ┆ 25.9         │
# │ 4.34      ┆ 0.0  ┆ 91.0 ┆ 1.0 ┆ … ┆ 30.299999    ┆ 29.299999    ┆ 25.9         ┆ 24.1         │
# │ 2.04      ┆ 0.0  ┆ 93.0 ┆ 0.5 ┆ … ┆ 29.299999    ┆ 25.9         ┆ 24.1         ┆ 24.9         │
# │ …         ┆ …    ┆ …    ┆ …   ┆ … ┆ …            ┆ …            ┆ …            ┆ …            │
# │ 24.91     ┆ 10.6 ┆ 63.0 ┆ 5.0 ┆ … ┆ 22.4         ┆ 22.0         ┆ 22.200001    ┆ 22.799999    │
# │ 22.33     ┆ 9.7  ┆ 72.0 ┆ 4.0 ┆ … ┆ 22.0         ┆ 22.200001    ┆ 22.799999    ┆ 22.799999    │
# │ 21.41     ┆ 10.4 ┆ 71.0 ┆ 4.0 ┆ … ┆ 22.200001    ┆ 22.799999    ┆ 22.799999    ┆ 22.9         │
# │ 24.17     ┆ 10.8 ┆ 74.0 ┆ 4.0 ┆ … ┆ 22.799999    ┆ 22.799999    ┆ 22.9         ┆ 23.5         │
# │ 23.389999 ┆ 10.5 ┆ 78.0 ┆ 4.0 ┆ … ┆ 22.799999    ┆ 22.9         ┆ 23.5         ┆ 24.0         │
# └───────────┴──────┴──────┴─────┴───┴──────────────┴──────────────┴──────────────┴──────────────┘
# 2024-04-18 07:29:35.307 | SUCCESS  | __main__:<module>:2 - shape: (6_802,)
# Series: 'AVG_TEMP' [f32]
# [
# 	29.299999
# 	25.9
# 	24.1
# 	24.9
# 	25.0
# 	…
# 	22.799999
# 	22.9
# 	23.5
# 	24.0
# 	24.200001
# ]
# 2024-04-18 07:29:35.308 | SUCCESS  | __main__:<module>:3 - shape: (1_701, 34)
# ┌───────────┬──────┬──────┬─────┬───┬──────────────┬──────────────┬──────────────┬──────────────┐
# │ GSR       ┆ SUN  ┆ RH   ┆ UV  ┆ … ┆ AVG_TEMP_t-4 ┆ AVG_TEMP_t-3 ┆ AVG_TEMP_t-2 ┆ AVG_TEMP_t-1 │
# │ ---       ┆ ---  ┆ ---  ┆ --- ┆   ┆ ---          ┆ ---          ┆ ---          ┆ ---          │
# │ f32       ┆ f32  ┆ f32  ┆ f32 ┆   ┆ f32          ┆ f32          ┆ f32          ┆ f32          │
# ╞═══════════╪══════╪══════╪═════╪═══╪══════════════╪══════════════╪══════════════╪══════════════╡
# │ 19.129999 ┆ 8.8  ┆ 78.0 ┆ 4.0 ┆ … ┆ 22.9         ┆ 23.5         ┆ 24.0         ┆ 24.200001    │
# │ 9.87      ┆ 4.2  ┆ 68.0 ┆ 2.0 ┆ … ┆ 23.5         ┆ 24.0         ┆ 24.200001    ┆ 24.0         │
# │ 7.23      ┆ 0.5  ┆ 39.0 ┆ 1.0 ┆ … ┆ 24.0         ┆ 24.200001    ┆ 24.0         ┆ 21.6         │
# │ 25.969999 ┆ 11.1 ┆ 48.0 ┆ 4.0 ┆ … ┆ 24.200001    ┆ 24.0         ┆ 21.6         ┆ 17.200001    │
# │ 24.16     ┆ 10.7 ┆ 75.0 ┆ 4.0 ┆ … ┆ 24.0         ┆ 21.6         ┆ 17.200001    ┆ 19.4         │
# │ …         ┆ …    ┆ …    ┆ …   ┆ … ┆ …            ┆ …            ┆ …            ┆ …            │
# │ 4.27      ┆ 0.2  ┆ 89.0 ┆ 0.9 ┆ … ┆ 22.9         ┆ 22.799999    ┆ 21.299999    ┆ 21.799999    │
# │ 3.66      ┆ 0.0  ┆ 92.0 ┆ 0.8 ┆ … ┆ 22.799999    ┆ 21.299999    ┆ 21.799999    ┆ 22.200001    │
# │ 11.34     ┆ 4.2  ┆ 88.0 ┆ 2.0 ┆ … ┆ 21.299999    ┆ 21.799999    ┆ 22.200001    ┆ 22.4         │
# │ 17.049999 ┆ 8.9  ┆ 86.0 ┆ 3.0 ┆ … ┆ 21.799999    ┆ 22.200001    ┆ 22.4         ┆ 25.4         │
# │ 7.06      ┆ 2.6  ┆ 83.0 ┆ 1.0 ┆ … ┆ 22.200001    ┆ 22.4         ┆ 25.4         ┆ 25.1         │
# └───────────┴──────┴──────┴─────┴───┴──────────────┴──────────────┴──────────────┴──────────────┘
# 2024-04-18 07:29:35.310 | SUCCESS  | __main__:<module>:4 - shape: (1_701,)
# Series: 'AVG_TEMP' [f32]
# [
# 	24.0
# 	21.6
# 	17.200001
# 	19.4
# 	21.4
# 	…
# 	22.200001
# 	22.4
# 	25.4
# 	25.1
# 	22.1
# ]

# %%
import xgboost as xgb
from sklearn.model_selection import GridSearchCV

reg = xgb.XGBRegressor(base_score=0.5, 
                       booster='gbtree',    
                     # n_estimators=1000,
                     # early_stopping_rounds=50,
                     objective='reg:squarederror',
                     # max_depth=3,
                     # learning_rate=0.01, 
                     tree_method = "hist", 
                     device = "cuda")

# set up our search grid
param_grid = {"max_depth": list(range(3, 5, 1)), # 4
              "n_estimators": list(range(700, 1000, 100)), # 900
              "learning_rate": [0.015, 0.02, 0.025], # 0.02
              "min_child_weight": [5, 7, 9], # 5
              }

# search = GridSearchCV(reg, param_grid, cv=5, verbose=100).fit(x_train, y_train)

# print("The best hyperparameters are ",search.best_params_)

# %%
# reg:xgb.XGBRegressor=xgb.XGBRegressor(learning_rate = search.best_params_["learning_rate"],
#                                    n_estimators = search.best_params_["n_estimators"],
#                                    max_depth = search.best_params_["max_depth"],
#                                    early_stopping_rounds=50,
#                                    objective='reg:squarederror',
#                                    base_score=0.5, 
#                                    booster='gbtree',)

reg:xgb.XGBRegressor=xgb.XGBRegressor(learning_rate = 0.02,
                                        n_estimators = 900,
                                        max_depth = 4,
                                        early_stopping_rounds=50,
                                        objective='reg:squarederror',
                                        base_score=0.5, 
                                        min_child_weight = 5,
                                        booster='gbtree',
                                        tree_method = "hist", 
                                        device = "cuda")

# %%
# from skforecast.ForecasterAutoreg import ForecasterAutoreg
# import pandas as pd
# lag = 3
# forecaster = ForecasterAutoreg(regressor=reg, 
#                                      lags=lag)

# print(data.y_train.to_pandas())
# forecaster.fit(y=data.y_train.to_pandas())

# predictions = forecaster.predict(steps=5)

# %%
reg.fit(data.X_train, data.y_train,
        eval_set=[(data.X_train, data.y_train), (data.X_test, data.y_test)],
        verbose=100)
# Out:
# [0]	validation_0-rmse:22.73881	validation_1-rmse:23.75217
# [100]	validation_0-rmse:3.25331	validation_1-rmse:3.47294
# [200]	validation_0-rmse:1.06090	validation_1-rmse:1.13738
# [300]	validation_0-rmse:0.91108	validation_1-rmse:0.96623
# [400]	validation_0-rmse:0.87120	validation_1-rmse:0.94151
# [500]	validation_0-rmse:0.84164	validation_1-rmse:0.93046
# [600]	validation_0-rmse:0.81913	validation_1-rmse:0.92574
# [700]	validation_0-rmse:0.80000	validation_1-rmse:0.92323
# [800]	validation_0-rmse:0.78216	validation_1-rmse:0.92199
# [807]	validation_0-rmse:0.78080	validation_1-rmse:0.92175
# XGBRegressor(base_score=0.5, booster='gbtree', callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device='cuda', early_stopping_rounds=50,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=0.02, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=4, max_leaves=None,
#              min_child_weight=5, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=900, n_jobs=None,
#              num_parallel_tree=None, random_state=None, ...)

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import r2_score
# plot the loss
results = reg.evals_result()
epochs = len(results['validation_0']['rmse'])
x_axis = range(0, epochs)
fig, ax = plt.subplots(figsize=(15, 5))
ax.plot(x_axis, results['validation_0']['rmse'], label='Train')
ax.plot(x_axis, results['validation_1']['rmse'], label='Test')
ax.legend()
plt.ylabel('RMSE')
plt.title('XGBoost RMSE')
plt.savefig('loss.png')

# %%
# Predict the values
y_train_pred = reg.predict(data.X_train)
y_test_pred = reg.predict(data.X_test)

# Calculate R^2 scores
r2_train = r2_score(data.y_train, y_train_pred)
r2_test = r2_score(data.y_test, y_test_pred)

# # Plot R^2 scores
# plt.figure(figsize=(10, 6))
# plt.bar(['Train', 'Test'], [r2_train, r2_test])
# plt.title('R^2 Scores for Train and Test Sets')
# plt.ylabel('R^2 Score')
# plt.show()

# %%
# cal the r2 score, mse, mae
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
import numpy as np

# r2_score_train = r2_score(data.y_train, y_train_pred)
r2_score_test = r2_score(data.y_test, y_test_pred)
mse_test = mean_squared_error(data.y_test, y_test_pred)
mae_test = mean_absolute_error(data.y_test, y_test_pred)

logger.success(f"R2 score for test set: {r2_score_test}")
logger.success(f"MSE for test set: {mse_test}")
logger.success(f"MAE for test set: {mae_test}")
# Out:
# 2024-04-18 07:29:40.839 | SUCCESS  | __main__:<module>:10 - R2 score for test set: 0.9614749123093667
# 2024-04-18 07:29:40.840 | SUCCESS  | __main__:<module>:11 - MSE for test set: 0.8494701385498047
# 2024-04-18 07:29:40.842 | SUCCESS  | __main__:<module>:12 - MAE for test set: 0.6671268343925476

# %%
from polars import DataFrame
import seaborn as sns

def plot_predictions(testing_dates, y_test, prediction):
    fig, ax = plt.subplots(
        figsize=(15, 5),
    )
    df_test = DataFrame(
        {"date": testing_dates, "actual": y_test, "prediction": prediction}
    )
    date_col = "date"
    data_col = df_test.columns[1]  # Assuming the first column is 'date'
    plot_data = df_test[[date_col, data_col]]
    sns.scatterplot(x=date_col, y=data_col, data=plot_data)

    data_col = df_test.columns[2]
    plot_data = df_test[[date_col, data_col]]
    sns.scatterplot(x=date_col, y=data_col, data=plot_data)
    plt.title("XGBoost")
    plt.title(f"n_past = {lag:}, n_future = {n_steps_out}", loc="right", fontsize=13)
    plt.title(f"r2_score = {r2_score_test:.4}, mse = {mse_test:.4}, mae = {mae_test:.4}", loc="left", fontsize=14)
    plt.legend(["Actual", "Prediction"])
    plt.savefig("xgboost.png")
  
plot_predictions(data.date_test, data.y_test, y_test_pred)
# plot_predictions(x_test.index[-10:], y_test[-10:], y_test_pred[-10:])
