# %%
import pandas as pd 
import numpy as np

# %%
df = pd.read_csv('Data/original.csv')
df
# Out:
#       StudentID  CGPA  Internships  Projects  Workshops/Certifications  \
# 0             1   7.5            1         1                         1
# 1             2   8.9            0         3                         2
# 2             3   7.3            1         2                         2
# 3             4   7.5            1         1                         2
# 4             5   8.3            1         2                         2
# ...         ...   ...          ...       ...                       ...
# 9995       9996   7.5            1         1                         2
# 9996       9997   7.4            0         1                         0
# 9997       9998   8.4            1         3                         0
# 9998       9999   8.9            0         3                         2
# 9999      10000   8.4            0         1                         1
#
#       AptitudeTestScore  SoftSkillsRating ExtracurricularActivities  \
# ...

# %%
df = df.drop(columns=['StudentID'])

# %%
df.isnull().any()
# Out:
# CGPA                         False
# Internships                  False
# Projects                     False
# Workshops/Certifications     False
# AptitudeTestScore            False
# SoftSkillsRating             False
# ExtracurricularActivities    False
# PlacementTraining            False
# SSC_Marks                    False
# HSC_Marks                    False
# PlacementStatus              False
# dtype: bool

# %%
from sklearn.preprocessing import OneHotEncoder
ohe1 = OneHotEncoder(sparse_output=False,drop='if_binary')
ohe2 = OneHotEncoder(sparse_output=False,drop='if_binary')

# %%
X = df.drop(columns=['PlacementStatus'])
y = df['PlacementStatus']

# %%
from sklearn.compose import ColumnTransformer
ct = ColumnTransformer([('ohe1',ohe1,[6]),
                        ('ohe2',ohe2,[7])],
                        remainder='passthrough')
ct.fit(X)
X = ct.transform(X)

# %%
X[1]
# Out:
# array([ 1. ,  1. ,  8.9,  0. ,  3. ,  2. , 90. ,  4. , 78. , 82. ])

# %%
pd.DataFrame(X).to_csv("Data/X.csv",index=False)
y.to_csv("Data/y.csv",index=False)

# %%
import pickle

# %%
with open('models/ct.pkl','wb') as file:
    pickle.dump(ct,file)
