# %%
#Import of libraries and data preprocessing.
# !python3 -m pip install scikit-learn tensorflow numpy pandas matplotlib keras

import tensorflow as tf
from keras.models import Model
from keras.layers import Dropout, Dense, BatchNormalization
from keras.models import Sequential
from keras.utils import to_categorical
import warnings
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import accuracy_score, classification_report
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
warnings.filterwarnings("ignore")

df = pd.read_csv("../../assets/risk_profiles.csv")
df.drop(["total_score"], axis=1, inplace=True)

m_data = np.array(df)

X = np.zeros((2000, 5))
Y = [0] * 2000
for i in range(2000):
    X[i] = m_data[i, :5] #this syntax for numPy shows [row, col]
    Y[i] = m_data[i, 5]

label_convert = LabelEncoder()
fitted_Y = label_convert.fit(Y)
converted_Y = label_convert.transform(Y)  

print("Class index mapping:")
for idx, label in enumerate(label_convert.classes_):
    print(f"{idx} → {label}")
    
Y = to_categorical(converted_Y).astype(float)
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: scikit-learn in /Users/davidahn/Library/Python/3.9/lib/python/site-packages (1.6.1)
# Requirement already satisfied: tensorflow in /Users/davidahn/Library/Python/3.9/lib/python/site-packages (2.20.0)
# Requirement already satisfied: numpy in /Users/davidahn/Library/Python/3.9/lib/python/site-packages (2.0.1)
# Requirement already satisfied: pandas in /Users/davidahn/Library/Python/3.9/lib/python/site-packages (2.3.3)
# Requirement already satisfied: matplotlib in /Users/davidahn/Library/Python/3.9/lib/python/site-packages (3.9.4)
# Requirement already satisfied: keras in /Users/davidahn/Library/Python/3.9/lib/python/site-packages (3.10.0)
# Requirement already satisfied: scipy>=1.6.0 in /Users/davidahn/Library/Python/3.9/lib/python/site-packages (from scikit-learn) (1.13.1)
# Requirement already satisfied: joblib>=1.2.0 in /Users/davidahn/Library/Python/3.9/lib/python/site-packages (from scikit-learn) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /Users/davidahn/Library/Python/3.9/lib/python/site-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: absl-py>=1.0.0 in /Users/davidahn/Library/Python/3.9/lib/python/site-packages (from tensorflow) (2.3.1)
# Requirement already satisfied: astunparse>=1.6.0 in /Users/davidahn/Library/Python/3.9/lib/python/site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /Users/davidahn/Library/Python/3.9/lib/python/site-packages (from tensorflow) (25.12.19)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /Users/davidahn/Library/Python/3.9/lib/python/site-packages (from tensorflow) (0.7.0)
# Requirement already satisfied: google_pasta>=0.1.1 in /Users/davidahn/Library/Python/3.9/lib/python/site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /Users/davidahn/Library/Python/3.9/lib/python/site-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt_einsum>=2.3.2 in /Users/davidahn/Library/Python/3.9/lib/python/site-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in /Users/davidahn/Library/Python/3.9/lib/python/site-packages (from tensorflow) (24.2)
# Requirement already satisfied: protobuf>=5.28.0 in /Users/davidahn/Library/Python/3.9/lib/python/site-packages (from tensorflow) (6.33.4)
# Requirement already satisfied: requests<3,>=2.21.0 in /Users/davidahn/Library/Python/3.9/lib/python/site-packages (from tensorflow) (2.32.5)
# Requirement already satisfied: setuptools in /Library/Python/3.9/site-packages (from tensorflow) (80.9.0)
# Requirement already satisfied: six>=1.12.0 in /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/site-packages (from tensorflow) (1.15.0)
# Requirement already satisfied: termcolor>=1.1.0 in /Users/davidahn/Library/Python/3.9/lib/python/site-packages (from tensorflow) (3.1.0)
# Requirement already satisfied: typing_extensions>=3.6.6 in /Users/davidahn/Library/Python/3.9/lib/python/site-packages (from tensorflow) (4.15.0)
# Requirement already satisfied: wrapt>=1.11.0 in /Users/davidahn/Library/Python/3.9/lib/python/site-packages (from tensorflow) (2.0.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /Users/davidahn/Library/Python/3.9/lib/python/site-packages (from tensorflow) (1.76.0)
# Requirement already satisfied: tensorboard~=2.20.0 in /Users/davidahn/Library/Python/3.9/lib/python/site-packages (from tensorflow) (2.20.0)
# Requirement already satisfied: h5py>=3.11.0 in /Users/davidahn/Library/Python/3.9/lib/python/site-packages (from tensorflow) (3.14.0)
# Requirement already satisfied: ml_dtypes<1.0.0,>=0.5.1 in /Users/davidahn/Library/Python/3.9/lib/python/site-packages (from tensorflow) (0.5.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/davidahn/Library/Python/3.9/lib/python/site-packages (from requests<3,>=2.21.0->tensorflow) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/davidahn/Library/Python/3.9/lib/python/site-packages (from requests<3,>=2.21.0->tensorflow) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/davidahn/Library/Python/3.9/lib/python/site-packages (from requests<3,>=2.21.0->tensorflow) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/davidahn/Library/Python/3.9/lib/python/site-packages (from requests<3,>=2.21.0->tensorflow) (2026.1.4)
# Requirement already satisfied: markdown>=2.6.8 in /Users/davidahn/Library/Python/3.9/lib/python/site-packages (from tensorboard~=2.20.0->tensorflow) (3.9)
# Requirement already satisfied: pillow in /Users/davidahn/Library/Python/3.9/lib/python/site-packages (from tensorboard~=2.20.0->tensorflow) (11.3.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /Users/davidahn/Library/Python/3.9/lib/python/site-packages (from tensorboard~=2.20.0->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /Users/davidahn/Library/Python/3.9/lib/python/site-packages (from tensorboard~=2.20.0->tensorflow) (3.1.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/davidahn/Library/Python/3.9/lib/python/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/davidahn/Library/Python/3.9/lib/python/site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /Users/davidahn/Library/Python/3.9/lib/python/site-packages (from pandas) (2025.3)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/davidahn/Library/Python/3.9/lib/python/site-packages (from matplotlib) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /Users/davidahn/Library/Python/3.9/lib/python/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/davidahn/Library/Python/3.9/lib/python/site-packages (from matplotlib) (4.60.2)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/davidahn/Library/Python/3.9/lib/python/site-packages (from matplotlib) (1.4.7)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/davidahn/Library/Python/3.9/lib/python/site-packages (from matplotlib) (3.3.1)
# Requirement already satisfied: importlib-resources>=3.2.0 in /Users/davidahn/Library/Python/3.9/lib/python/site-packages (from matplotlib) (6.5.2)
# Requirement already satisfied: rich in /Users/davidahn/Library/Python/3.9/lib/python/site-packages (from keras) (14.2.0)
# Requirement already satisfied: namex in /Users/davidahn/Library/Python/3.9/lib/python/site-packages (from keras) (0.1.0)
# Requirement already satisfied: optree in /Users/davidahn/Library/Python/3.9/lib/python/site-packages (from keras) (0.18.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /Library/Python/3.9/site-packages (from astunparse>=1.6.0->tensorflow) (0.45.1)
# Requirement already satisfied: zipp>=3.1.0 in /Users/davidahn/Library/Python/3.9/lib/python/site-packages (from importlib-resources>=3.2.0->matplotlib) (3.23.0)
# Requirement already satisfied: importlib-metadata>=4.4 in /Users/davidahn/Library/Python/3.9/lib/python/site-packages (from markdown>=2.6.8->tensorboard~=2.20.0->tensorflow) (8.7.1)
# Requirement already satisfied: markupsafe>=2.1.1 in /Users/davidahn/Library/Python/3.9/lib/python/site-packages (from werkzeug>=1.0.1->tensorboard~=2.20.0->tensorflow) (3.0.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Users/davidahn/Library/Python/3.9/lib/python/site-packages (from rich->keras) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/davidahn/Library/Python/3.9/lib/python/site-packages (from rich->keras) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /Users/davidahn/Library/Python/3.9/lib/python/site-packages (from markdown-it-py>=2.2.0->rich->keras) (0.1.2)
# Class index mapping:
# 0 → Aggressive
# 1 → Conservative
# 2 → Moderate

# %%
#Custom Model
scaler = StandardScaler()
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=None)

scaler.fit(X_train)
X_train_scaled = scaler.transform(X_train)
X_test_scaled = scaler.transform(X_test)

custom_model = Sequential()
custom_model.add(Dense(32, activation='relu', input_dim = 5))
custom_model.add(BatchNormalization())
custom_model.add(Dropout(0.2))
custom_model.add(Dense(64, activation='relu'))
custom_model.add(BatchNormalization())
custom_model.add(Dropout(0.2))
custom_model.add(Dense(32, activation='relu'))
custom_model.add(Dense(3, activation='softmax')) 

custom_model.compile(optimizer='adam',loss='categorical_crossentropy', metrics=['accuracy'])
record = custom_model.fit(X_train_scaled, Y_train, epochs=100, batch_size=20, validation_data=(X_test_scaled, Y_test))

fig, loss_ax = plt.subplots()

acc_ax = loss_ax.twinx()

loss_ax.plot(record.history['loss'], 'y', label='train loss')
loss_ax.plot(record.history['val_loss'], 'r', label='val loss')

acc_ax.plot(record.history['accuracy'], 'b', label='train acc')
acc_ax.plot(record.history['val_accuracy'], 'g', label='val acc')

loss_ax.set_xlabel('epoch')
loss_ax.set_ylabel('loss')
acc_ax.set_ylabel('accuracy')

loss_ax.legend(loc='upper left')
acc_ax.legend(loc='lower left')

plt.show()

# Predictions
custom_pred = np.argmax(custom_model.predict(X_test_scaled), axis=1)

# True labels
custom_labeled_result = np.argmax(Y_test, axis=1)

accuracy = accuracy_score(custom_labeled_result, custom_pred)
print(f"accuracy = {accuracy * 100:.2f}%")

print(classification_report(custom_labeled_result, custom_pred, target_names=label_convert.classes_))
# Out:
# Epoch 1/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.5011 - loss: 1.0440 - val_accuracy: 0.8100 - val_loss: 0.7190
# Epoch 2/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 737us/step - accuracy: 0.8086 - loss: 0.4691 - val_accuracy: 0.8375 - val_loss: 0.4834
# Epoch 3/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 821us/step - accuracy: 0.8392 - loss: 0.3877 - val_accuracy: 0.8925 - val_loss: 0.3314
# Epoch 4/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 947us/step - accuracy: 0.8429 - loss: 0.3418 - val_accuracy: 0.9225 - val_loss: 0.2319
# Epoch 5/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 831us/step - accuracy: 0
100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 723us/step - accuracy: 0.9816 - loss: 0.0518 - val_accuracy: 0.9800 - val_loss: 0.0354
# Epoch 70/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 738us/step - accuracy: 0.9776 - loss: 0.0813 - val_accuracy: 1.0000 - val_loss: 0.0136
# Epoch 71/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 714us/step - accuracy: 0.9807 - loss: 0.0493 - val_accuracy: 0.9975 - val_loss: 0.0110
# Epoch 72/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 716us/step - accuracy: 0.9776 - loss: 0.0578 - val_accuracy: 0.9975 - val_loss: 0.0108
# Epoch 73/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 712us/step - accuracy: 0.9803 - loss: 0.0606 - val_accuracy: 0.9975 - val_loss: 0.0122
# Epoch 74/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 714us/step - accuracy: 0.9793 - loss: 0.0664 - val_accuracy: 0.9950 - val_loss: 0.0166
# Epoch 75/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 723us/step - accuracy: 0.9820 - loss: 0.0520 - val_accuracy: 1.0000 - val_loss: 0.0179
# Epoch 76/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 713us/step - accuracy: 0.9770 - loss: 0.0725 - val_accuracy: 0.9975 - val_loss: 0.0171
# Epoch 77/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 714us/step - accuracy: 0.9758 - loss: 0.0655 - val_accuracy: 0.9950 - val_loss: 0.0182
# Epoch 78/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 722us/step - accuracy: 0.9792 - loss: 0.0598 - val_accuracy: 0.9950 - val_loss: 0.0130
# Epoch 79/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 719us/step - accuracy: 0.9802 - loss: 0.0603 - val_accuracy: 0.9950 - val_loss: 0.0175
# Epoch 80/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 713us/step - accuracy: 0.9837 - loss: 0.0451 - val_accuracy: 0.9975 - val_loss: 0.0114
# Epoch 81/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 724us/step - accuracy: 0.9784 - loss: 0.0525 - val_accuracy: 1.0000 - val_loss: 0.0093
# Epoch 82/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 712us/step - accuracy: 0.9912 - loss: 0.0441 - val_accuracy: 1.0000 - val_loss: 0.0081
# Epoch 83/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 716us/step - accuracy: 0.9900 - loss: 0.0440 - val_accuracy: 0.9950 - val_loss: 0.0104
# Epoch 84/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 712us/step - accuracy: 0.9876 - loss: 0.0405 - val_accuracy: 0.9950 - val_loss: 0.0165
# Epoch 85/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 723us/step - accuracy: 0.9795 - loss: 0.0576 - val_accuracy: 1.0000 - val_loss: 0.0064
# Epoch 86/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 718us/step - accuracy: 0.9845 - loss: 0.0381 - val_accuracy: 1.0000 - val_loss: 0.0077
# Epoch 87/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 718us/step - accuracy: 0.9867 - loss: 0.0365 - val_accuracy: 0.9900 - val_loss: 0.0199
# Epoch 88/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 718us/step - accuracy: 0.9771 - loss: 0.0675 - val_accuracy: 1.0000 - val_loss: 0.0086
# Epoch 89/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 757us/step - accuracy: 0.9765 - loss: 0.0715 - val_accuracy: 0.9950 - val_loss: 0.0147
# Epoch 90/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 717us/step - accuracy: 0.9781 - loss: 0.0555 - val_accuracy: 1.0000 - val_loss: 0.0081
# Epoch 91/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 718us/step - accuracy: 0.9851 - loss: 0.0455 - val_accuracy: 1.0000 - val_loss: 0.0091
# Epoch 92/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 716us/step - accuracy: 0.9840 - loss: 0.0489 - val_accuracy: 1.0000 - val_loss: 0.0068
# Epoch 93/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 718us/step - accuracy: 0.9870 - loss: 0.0366 - val_accuracy: 0.9975 - val_loss: 0.0098
# Epoch 94/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 718us/step - accuracy: 0.9792 - loss: 0.0614 - val_accuracy: 1.0000 - val_loss: 0.0062
# Epoch 95/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 719us/step - accuracy: 0.9835 - loss: 0.0409 - val_accuracy: 1.0000 - val_loss: 0.0059
# Epoch 96/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 712us/step - accuracy: 0.9800 - loss: 0.0716 - val_accuracy: 0.9975 - val_loss: 0.0120
# Epoch 97/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 716us/step - accuracy: 0.9882 - loss: 0.0329 - val_accuracy: 0.9975 - val_loss: 0.0092
# Epoch 98/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 717us/step - accuracy: 0.9806 - loss: 0.0566 - val_accuracy: 0.9975 - val_loss: 0.0092
# Epoch 99/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 707us/step - accuracy: 0.9809 - loss: 0.0462 - val_accuracy: 0.9975 - val_loss: 0.0095
# Epoch 100/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 725us/step - accuracy: 0.9739 - loss: 0.0582 - val_accuracy: 0.9975 - val_loss: 0.0116
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# accuracy = 99.75%
#               precision    recall  f1-score   support
#
#   Aggressive       1.00      0.99      1.00       128
# Conservative       1.00      1.00      1.00       113
#     Moderate       0.99      1.00      1.00       159
#
#     accuracy                           1.00       400
#    macro avg       1.00      1.00      1.00       400
# weighted avg       1.00      1.00      1.00       400

# %%
import joblib

custom_model.save("nnmodel.h5")
joblib.dump(scaler, "nnscaler.pkl")
joblib.dump(label_convert, "nnencoder.pkl")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# ['nnencoder.pkl']
