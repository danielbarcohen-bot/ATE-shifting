# %% [markdown]
# Exercise 1
#
# Fit a 10-nearest neighbors model to predict the SalePrice of an 1800 square foot, 3 bedroom, 2 bathroom home.
#
# A DataFrame consisting of this "test data" is provided for you.
#
# X_test = pd.DataFrame([
#
#    {"Gr Liv Area": 1800,
#
#     "Bedroom AbvGr": 3,
#
#     "Full Bath": 2}
#
# ])
#
# X_test

# %%
# all the import statements
import os
import pandas as pd
import kagglehub
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsRegressor
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split
from sklearn import datasets
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.datasets import make_classification

# Kaggle
path = kagglehub.dataset_download("shashanknecrothapa/ames-housing-dataset")

csv_path = os.path.join(path, "AmesHousing.csv")
df = pd.read_csv(csv_path)

# determine input and output
X = df[["Gr Liv Area", "Bedroom AbvGr", "Full Bath"]]
y = df["SalePrice"]

# split into training nd testing from the lecture
X_train, X_val, y_train, y_val = train_test_split( X, y, test_size=0.2
)

# create the scalar
scaler = StandardScaler()

#⃣ Fit the scaler only on training data, then transform
scaler.fit(X_train)
X_train_scaled = scaler.transform(X_train)

#  Transform
X_val_scaled = scaler.transform(X_val)

#  train
model = KNeighborsRegressor(n_neighbors=10)
model.fit(X_train_scaled, y_train)


# from the exercise
X_test = pd.DataFrame([
    {
        "Gr Liv Area": 1800,
        "Bedroom AbvGr": 3,
        "Full Bath": 2
    }
])



#  Predict the SalePrice for this house
prediction = model.predict(X_test_scaled)[0]

print(
    f"Exercise 1: "
    f"${prediction:,.2f}"
)
# Out:
# Exercise 1: $229,750.00

# %% [markdown]
# Exercise 2
#
# Fit a 10 -nearest neighbors model to predict the Sale Price of a home in each neighborhood of Ames. That is, the categorical variable Neighborhood should be the only input feature to your model.
#
# A DataFrame consisting of this "test data" is provided for you.
#
# Can you explain intuitively what the 𝑘-nearest neighbors model is doing? For example, what is the prediction for the Bluestem ("Blueste") neighborhood?
#
# X_test = pd.DataFrame({
#
#    "Neighborhood": df["Neighborhood"].unique()
#
# })
#
# X_test

# %%
from sklearn.preprocessing import OneHotEncoder

# neighborhood is categorical
X = df[["Neighborhood"]]
y = df["SalePrice"]

# Split into training and validation
X_train, X_val, y_train, y_val = train_test_split(
    X, y, test_size=0.2
)

# needed for categorigal values
encoder = OneHotEncoder( handle_unknown="ignore")

X_train_encoded = encoder.fit_transform(X_train)

X_val_encoded = encoder.transform(X_val)

# train the model
model = KNeighborsRegressor(n_neighbors=10)
model.fit(X_train_encoded, y_train)

# from the exercise
X_test = pd.DataFrame({
    "Neighborhood": df["Neighborhood"].unique()
})

X_test_encoded = encoder.transform(X_test)

predictions = model.predict(X_test_encoded)

print("\nExercise 2:")
for neigh, pred in zip(X_test["Neighborhood"], predictions):
    print(f"{neigh}: ${pred:,.2f}")
# Out:
# Exercise 2:
# NAmes: $166,350.00
# Gilbert: $199,881.40
# StoneBr: $282,991.80
# NWAmes: $195,580.50
# Somerst: $219,222.40
# BrDale: $106,200.00
# NPkVill: $140,550.00
# NridgHt: $302,842.30
# Blmngtn: $175,286.10
# NoRidge: $286,850.00
# SawyerW: $176,198.30
# Sawyer: $150,415.00
# Greens: $169,290.00
# BrkSide: $128,460.00
# OldTown: $115,240.00
# IDOTRR: $113,480.00
# ClearCr: $204,043.20
# SWISU: $129,088.40
# Edwards: $132,805.00
# CollgCr: $208,826.00
# Crawfor: $211,563.50
# Blueste: $143,590.00
# Mitchel: $147,200.00
# Timber: $255,919.20
# MeadowV: $91,559.00
# Veenker: $225,300.00
# GrnHill: $197,220.00
# Landmrk: $173,030.00

# %% [markdown]
# ### How it works is it takes a point and matches it to the closest 10 neighbors. then it averages their prices.

# %% [markdown]
# Exercise 3
#
# Fit a 10-nearest neighbors model to predict the Sale Price of a 1800 square foot, 3 bedroom, 2 bathroom two-story home (House Style) in the Veenker neighborhood (Neighborhood) of Ames.
#
# How does this compare with the predictions from the models you fit in Exercises 1 and 2?

# %%
# neighborhood is categorical
X = df[["Neighborhood"]]
y = df["SalePrice"]

# Split into training and validation
X_train, X_val, y_train, y_val = train_test_split(
    X, y, test_size=0.2
)
