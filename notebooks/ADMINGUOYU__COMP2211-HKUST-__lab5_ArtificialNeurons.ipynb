# %% [markdown]
# # **COMP 2211 Exploring Artificial Intelligence** #
# ## Lab 5 Artificial Neuron ##
#
# ![perceptron.png](data:image/png;base64,...)

# %% [markdown]
# ## Before We Begin ##
#
# This lab is for you to understand the artificial neuron. In this lab, we will learn how to implement the artificial neuron model from scratch. In the second part, we will apply the artificial neuron model to different datasets.

# %% [markdown]
# # 1. The artificial neuron model
#
# In this section, we mainly define the training process of an artificial neuron model. To accomplish that, we need to do the following:
#
# >1. Set initial weights and the bias for the artificial neuron.
# >2. Predict the label with input variables, weight and bias.
# >3. Update the weights and bias according to the 'distance' between the predicted label and the true label.
# >4. Repeat steps __2__ and __3__ to complete the training.
#
# You need to fill the TODOs to implement the ArtificialNeuron class, which can be reused for different datasets.
#
# There are 3 functions in the model: `__init__`, `fit` and `predict`.<br>
# >The `__init__` will help create the artificial neuron model and initialize the variables.<br>
# >The `fit` will help train the artificial neuron model by updating variables in the class with a given dataset.<br>
# >The `predict` function will help calculate the value based on input and class variables and then return the class label.

# %% [markdown]
# ## Task 1.1
#
# Initialize the __weights_and_bias__ inside the `fit` function.
#
# __weights_and_bias__ represents all trainable variables, including "weight", and “bias”. Therefore, the vector length of __weights_and_bias__ should be: <br>
# >1 + the number of features.
#
# Putting all trainable parameters into one variable is useful when we want to pass, manage, and update them, especially closely related parameters (bias and weight will be used and updated simultaneously).

# %% [markdown]
# ## Task 1.2
#
# Implement the training function `fit`, which will take __X__ and __Y__ as input to update __weights_and_bias__ for our artificial neuron model.
#
# The __weights_and_bias__ should be updated according to the value of the data samples in __X__ and the difference between predictions and the true labels:
#
# >1. Predict the label with input features and __weights_and_bias__
# >2. Update __weights_and_bias__ according to the "distance" between the predicted label and true label
# >3. Repeat processes __1__ and __2__ to complete the training
#
# Meanwhile, record the number of mismatches in each epoch so that we can visualize the training process later.
# You can do this by checking the error terms __delta__ for each data sample and putting the count of non-zero ones in each epoch into the error list __errors__.
# > For example, if there are 5 mismatchings (__delta__ != 0) in the first epoch, we append __5__ to the __errors__.
#
# As mentioned in the review notebook, there are different rules for stopping the training process. Use the following rule to stop before __max_epoch__ is reached:
# * Stop when the $accuracy$ is high enough. Similar to the above, we can calculate the accuracy level after each epoch. If the accuracy exceeds a certain threshold, stop the training process.
#
# Specifically, we set the number as __0.98__, and reuse the number of mismatches in each epoch recorded above to calculate the accuracy.
# >For example, if there are 5 mismatchings (__delta__ != 0) in the first epoch, and there are __n__ data samples in X. Then the accuracy for the first epoch should be $1-\frac{5}{n}$.

# %% [markdown]
# ## Task 1.3
#
# Implement the prediction function `predict`, which takes __X__ as input to calculate and return the predictions.
# To do so, you should consider how artificial neuron uses weights and the bias to predict the labels.
#
# Utilize the __.dot()__ or __.matmul()__ function to meet the following requirements:
#
# - The prediction function can take __X__ in both matrix (#samples > 1) and vector (#samples = 1) form.
# - Return the prediction in an integer-type array when #samples > 1, or just as an integer (i.e., 0 or 1) when #samples = 1.
# - Do not use any loops.
#
# If __X__ is a matrix (2-D array):
# \begin{bmatrix}
#     x_{11} & x_{12} & x_{13} & \dots  & x_{1n} \\
#     x_{21} & x_{22} & x_{23} & \dots  & x_{2n} \\
#     \vdots & \vdots & \vdots & \ddots & \vdots \\
#     x_{d1} & x_{d2} & x_{d3} & \dots  & x_{dn}
# \end{bmatrix}
#
# and __weights_and_bias__ is
# \begin{bmatrix}
#     \theta \\
#     w_{1}\\
#     w_{2}\\
#     \vdots \\
#     w_{n}
# \end{bmatrix}
#
# Then, the calculation of the prediction in matrix form will be like this:
#
# $$\begin{bmatrix}
#     x_{11} & x_{12} & x_{13} & \dots  & x_{1n} \\
#     x_{21} & x_{22} & x_{23} & \dots  & x_{2n} \\
#     \vdots & \vdots & \vdots & \ddots & \vdots \\
#     x_{d1} & x_{d2} & x_{d3} & \dots  & x_{dn}
# \end{bmatrix}\cdot
# \begin{bmatrix}
#     w_{1}\\
#     w_{2}\\
#     \vdots \\
#     w_{n}
# \end{bmatrix}+
# \begin{bmatrix}
#     \theta\\
#     \theta\\
#     \vdots \\
#     \theta
# \end{bmatrix}
# =\begin{bmatrix}
#     Y_{1}\\
#     Y_{2}\\
#     \vdots \\
#     Y_{d}
# \end{bmatrix}$$
#
# If the __X__ is a vector (1-D array):
# \begin{bmatrix}
#     x_{11} & x_{12} & x_{13} & \dots  & x_{1n} \\
# \end{bmatrix}
#
# and __weights_and_bias__ is
# \begin{bmatrix}
#     \theta \\
#     w_{1}\\
#     w_{2}\\
#     \vdots \\
#     w_{n}
# \end{bmatrix}
#
# Then, the calculation of the prediction in vector form will be like this:
#
# $$\begin{bmatrix}
#     x_{11} & x_{12} & x_{13} & \dots  & x_{1n} \\
# \end{bmatrix} \cdot
# \begin{bmatrix}
#     w_{1}\\
#     w_{2}\\
#     \vdots \\
#     w_{n}
# \end{bmatrix}+ \theta
# =Y_{1}$$
#
# Try to use NumPy operations to construct the function.

# %%
import numpy as np


class ArtificialNeuron(object):
    def __init__(self, lr=0.01, epoch=10, in_weight=0.0):
        self.lr = lr  # learning rate
        self.epoch = epoch  # the max epoch of training
        self.in_weight = in_weight  # the initial value of weights_and_bias

    def fit(self, X, Y):
        # Fit the training data
        # X: Training vectors, X.shape = [#samples, #features]
        # Y: Target values, Y.shape = [#samples]

        # TODO:
        # - create a NumPy array to store the weights and bias
        # - initialze the weights and bias with a same value according to self.in_weight
        self.weights_and_bias = np.zeros(shape = (X.shape[-1] + 1, )) + self.in_weight

        # create the list that records the number of misclassifications in each epoch
        self.errors = []

        # TODO:
        # - update self.weights_and_bias according to the features and the difference between the predictions and the true labels
        # - record the number of misclassifications in each epoch
        # - stop when the prediction accuracy is at least 0.98 (or the number of epochs reach self.epoch)
        # note: you may use self.predict here which will be implemented in task 1.3
        i = 0
        while i <= self.epoch:
            # YOUR CODE HERE

            # get forward pass first (logits)
            logits = ((np.dot(X, self.weights_and_bias[ 1 :  , np.newaxis ])) + self.weights_and_bias[0])
            logits = np.squeeze(a = logits)
            predict = (logits > 0).astype(dtype = np.int8)

            # calculate distance (predict & label)
            difference = Y - predict
            if (i > 0):
                # append error
                self.errors.append(np.sum(a = (difference != 0)))
                # calculate accuracy
                accuracy = np.sum(a = (difference == 0.0)) / difference.shape[0]
                # early stop / stop
                if (accuracy >= 0.98 or i >= self.epoch):
                    break

            # calculate derivative
            distance = np.pow(predict - Y, 2)
            d_predict = -2 * difference
            d_bias = np.sum(a = d_predict)
            d_weight = np.dot(X.T, d_predict)

            # update params
            self.weights_and_bias[0] -= d_bias * self.lr
            self.weights_and_bias[ 1 :  ] -= d_weight * self.lr

            i += 1

    def predict(self, X) -> np.ndarray:
        # Predict the labels
        # X: Test vectors, X.shape = [#samples, #features]

        # TODO:
        # predict the labels based on the features and self.weights_and_bias
        logits = ((np.dot(X, self.weights_and_bias[ 1 :  , np.newaxis ])) + self.weights_and_bias[0])
        logits = np.squeeze(a = logits)
        prediction = (logits > 0).astype(dtype = np.int8)

        return prediction

# %% [markdown]
# # 2. Prepare the dataset
#
# After preparing the model, it is time to test it on various datasets. The datasets we will use in this lab are the __Sonar__ dataset and the __Iris__ dataset:
#
# - The __Sonar__ dataset describes the information collected from a sonar system. The features represent the strength of the signal from different angles, while the prediction variables (the letter __R__ or __M__) indicate the type of object (__rocks__ or __metal__). This is a binary classification problem that we can solve using our model.
#
# - The __Iris__ dataset describes the information about 3 kinds of iris plants. The dataset contains 3 classes of 50 instances each. The features are sepal length, sepal width, petal length and petal width, while the prediction variables (the labels) indicate the type of iris plant. We will take 2 classes (__Iris-setosa__ and __Iris-versicolor__) of this dataset to formulate a binary classification problem.

# %% [markdown]
# Run the following code to load the sonar dataset.

# %%
import pandas as pd
dataset1 = pd.read_csv('http://archive.ics.uci.edu/ml/machine-learning-databases/undocumented/connectionist-bench/sonar/sonar.all-data', index_col=False, header=None)
dataset1
# Out:
#          0       1       2       3       4       5       6       7       8   \
# 0    0.0200  0.0371  0.0428  0.0207  0.0954  0.0986  0.1539  0.1601  0.3109
# 1    0.0453  0.0523  0.0843  0.0689  0.1183  0.2583  0.2156  0.3481  0.3337
# 2    0.0262  0.0582  0.1099  0.1083  0.0974  0.2280  0.2431  0.3771  0.5598
# 3    0.0100  0.0171  0.0623  0.0205  0.0205  0.0368  0.1098  0.1276  0.0598
# 4    0.0762  0.0666  0.0481  0.0394  0.0590  0.0649  0.1209  0.2467  0.3564
# ..      ...     ...     ...     ...     ...     ...     ...     ...     ...
# 203  0.0187  0.0346  0.0168  0.0177  0.0393  0.1630  0.2028  0.1694  0.2328
# 204  0.0323  0.0101  0.0298  0.0564  0.0760  0.0958  0.0990  0.1018  0.1030
# 205  0.0522  0.0437  0.0180  0.0292  0.0351  0.1171  0.1257  0.1178  0.1258
# 206  0.0303  0.0353  0.0490  0.0608  0.0167  0.1354  0.1465  0.1123  0.1945
# 207  0.0260  0.0363  0.0136  0.0272  0.0214  0.0338  0.0655  0.1400  0.1843
#
# ...

# %% [markdown]
# Run the following code to load the iris dataset.

# %%
import pandas as pd
dataset2 = pd.read_csv('https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data', header=None)
dataset2 = dataset2[:100]  # take two classes
dataset2
# Out:
#       0    1    2    3                4
# 0   5.1  3.5  1.4  0.2      Iris-setosa
# 1   4.9  3.0  1.4  0.2      Iris-setosa
# 2   4.7  3.2  1.3  0.2      Iris-setosa
# 3   4.6  3.1  1.5  0.2      Iris-setosa
# 4   5.0  3.6  1.4  0.2      Iris-setosa
# ..  ...  ...  ...  ...              ...
# 95  5.7  3.0  4.2  1.2  Iris-versicolor
# 96  5.7  2.9  4.2  1.3  Iris-versicolor
# 97  6.2  2.9  4.3  1.3  Iris-versicolor
# 98  5.1  2.5  3.0  1.1  Iris-versicolor
# 99  5.7  2.8  4.1  1.3  Iris-versicolor
#
# [100 rows x 5 columns]

# %% [markdown]
# ## Vector representation transformation
# As we can see, the data inputs are in __float__ format, while the labels are in __string__ format. To use them to build a model, we need to transform labels into numbers.
#
# The label transformation here involves the __LabelEncoder__ we used in Lab 3.
#
# Run the following code to perform the transformation.

# %%
from sklearn.preprocessing import LabelEncoder
encoder = LabelEncoder()

for k in dataset1.keys():
    if type(dataset1[k][0]) == str:
        dataset1[k] = encoder.fit_transform(dataset1[k])

# %%
for k in dataset2.keys():
    if(type(dataset2[k][0]) == str):
        dataset2[k] = encoder.fit_transform(dataset2[k])

# %% [markdown]
# Now you can check the numeric data.
# Compare it with the original dataset to identify differences (hint: look at the last column).

# %%
dataset1
# Out:
#          0       1       2       3       4       5       6       7       8   \
# 0    0.0200  0.0371  0.0428  0.0207  0.0954  0.0986  0.1539  0.1601  0.3109
# 1    0.0453  0.0523  0.0843  0.0689  0.1183  0.2583  0.2156  0.3481  0.3337
# 2    0.0262  0.0582  0.1099  0.1083  0.0974  0.2280  0.2431  0.3771  0.5598
# 3    0.0100  0.0171  0.0623  0.0205  0.0205  0.0368  0.1098  0.1276  0.0598
# 4    0.0762  0.0666  0.0481  0.0394  0.0590  0.0649  0.1209  0.2467  0.3564
# ..      ...     ...     ...     ...     ...     ...     ...     ...     ...
# 203  0.0187  0.0346  0.0168  0.0177  0.0393  0.1630  0.2028  0.1694  0.2328
# 204  0.0323  0.0101  0.0298  0.0564  0.0760  0.0958  0.0990  0.1018  0.1030
# 205  0.0522  0.0437  0.0180  0.0292  0.0351  0.1171  0.1257  0.1178  0.1258
# 206  0.0303  0.0353  0.0490  0.0608  0.0167  0.1354  0.1465  0.1123  0.1945
# 207  0.0260  0.0363  0.0136  0.0272  0.0214  0.0338  0.0655  0.1400  0.1843
#
# ...

# %%
dataset2
# Out:
#       0    1    2    3  4
# 0   5.1  3.5  1.4  0.2  0
# 1   4.9  3.0  1.4  0.2  0
# 2   4.7  3.2  1.3  0.2  0
# 3   4.6  3.1  1.5  0.2  0
# 4   5.0  3.6  1.4  0.2  0
# ..  ...  ...  ...  ... ..
# 95  5.7  3.0  4.2  1.2  1
# 96  5.7  2.9  4.2  1.3  1
# 97  6.2  2.9  4.3  1.3  1
# 98  5.1  2.5  3.0  1.1  1
# 99  5.7  2.8  4.1  1.3  1
#
# [100 rows x 5 columns]

# %% [markdown]
# # 3. Fit perceptron model for different datasets
#
# In this section, we will apply our perceptron model to the dataset mentioned and examine the performance.

# %% [markdown]
# ## Task 3.1: Split the train set and test set
#
# First, the data are split along the second axis into features __X__ and labels __Y__.
#
# Second, you need to split __X__ and __Y__ along the first axis into a training set and a test set (__75%__ for training to __25%__ for testing in the Sonar dataset; __70%__ for training to __30%__ for testing in the Iris dataset). You can do this by using the `train_test_split` function from sklearn to split the dataset into training and test sets. Please use the number __3__ for the __random_state__ parameter of `train_test_split`.

# %%
from sklearn.model_selection import train_test_split
np_dataset1=dataset1.to_numpy()

X1 = np_dataset1[:, :-1]
Y1 = np_dataset1[:, -1]

# TODO:
X1_train, X1_test, Y1_train, Y1_test = train_test_split(X1, Y1, 
                                                        test_size = 0.25, 
                                                        random_state = 42)

# %%
np_dataset2=dataset2.to_numpy()

X2 = np_dataset2[:, :-1]
Y2 = np_dataset2[:, -1]

# TODO:
X2_train, X2_test, Y2_train, Y2_test = train_test_split(X2, Y2, 
                                                        test_size = 0.3, 
                                                        random_state = 42)

# %% [markdown]
# ## Visualize the datasets
# We can plot the iris dataset via two-dimensional scatter for better understanding.

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(8,6))
plt.scatter(X2[:50, 0], X2[:50, 1], color='red', marker='o', label='setosa')
plt.scatter(X2[50:100, 0], X2[50:100, 1], color='blue', marker='x', label='versicolor')
plt.xlabel('petal length')
plt.ylabel('sepal length')
plt.legend(loc='upper left')
plt.show()

# %% [markdown]
# However, it is hard to plot the sonar dataset in two-dimensional scatter as it contains 60 categories.

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(8,6))
plt.scatter(X1[:97, 0], X1[:97, 1], color='red', marker='o', label='R')
plt.scatter(X1[97:, 0], X1[97:, 1], color='blue', marker='x', label='M')
plt.legend(loc='upper left')
plt.show()

# %% [markdown]
# ## Task 3.2: Fit the models
# Initialize and train our perceptron model on the Sonar dataset and the Iris data subset.
#
# To perform initialization and training, you can create an object from the perceptron class and call the `fit` function to train the model.
#
# For the Sonar dataset, set the learning rate and epochs to 0.01 and 500, and initialize all variables in __weights_and_bias__ to 0.
#
# You can also try other combinations of hyperparameters (such as learning rate and epochs).
# Different hyperparameter combinations may produce varying outcomes.

# %%
# TODO:
sonar_artificialneuron = ArtificialNeuron(in_weight = 0.0, epoch = 500)
sonar_artificialneuron.fit(X1_train, Y1_train)

# %% [markdown]
# Plot the misclassification error for each epoch to check if the algorithm converged and found a decision boundary that separates the two sonar classes.

# %%
plt.figure(figsize=(8,6))
plt.plot(range(1, len(sonar_artificialneuron.errors) + 1), sonar_artificialneuron.errors, marker='o')
plt.xlabel('Epochs in sonar')
plt.ylabel('Number of misclassifications')
plt.show()

# %% [markdown]
# For the Iris dataset, set the learning rate and epochs as 0.01 and 20, and initialize all variables in __weights_and_bias__ as 0.

# %%
# TODO:
iris_artificialneuron = ArtificialNeuron(in_weight = 0.0, epoch = 500)
iris_artificialneuron.fit(X2_train, Y2_train)

# %% [markdown]
# Plot the misclassification error for each epoch to determine if the algorithm converged and found a decision boundary that separates the two Iris flower classes.

# %%
plt.figure(figsize=(8,6))
plt.plot(range(1, len(iris_artificialneuron.errors) + 1), iris_artificialneuron.errors, marker='o')
plt.xlabel('Epochs in iris')
plt.ylabel('Number of misclassifications')
plt.show()

# %% [markdown]
# ## Prediction and evaluate the performance
#
# Finally, we can evaluate the model on the test set.

# %%
prediction = sonar_artificialneuron.predict(X1_test)

# %%
prediction2 = iris_artificialneuron.predict(X2_test)

# %% [markdown]
# Following is the accuracy metric provided by sklearn.

# %%
from sklearn import metrics
print("accuracy for sonar_artificialneurona: ", metrics.accuracy_score(Y1_test, prediction))
print("accuracy for iris_artificialneuron: ", metrics.accuracy_score(Y2_test, prediction2))
# Out:
# accuracy for sonar_artificialneurona:  0.8076923076923077
# accuracy for iris_artificialneuron:  1.0

# %% [markdown]
# Let us use another metric to evaluate the performance: The __F1__ score.
#
# The __F1__ score is a balanced measure that takes into account both precision and recall.

# %%
print("F1 for sonar_artificialneuron: ", metrics.f1_score(Y1_test, prediction))
print("F1 for iris_artificialneuron: ", metrics.f1_score(Y2_test, prediction2))
# Out:
# F1 for sonar_artificialneuron:  0.7222222222222222
# F1 for iris_artificialneuron:  1.0

# %% [markdown]
# # Perceptron in sklearn
# You can change the __in_weight__, __lr__, __epoch__, etc., and run the training process again.
#
# With different parameter settings, you may obtain varying accuracy scores.
#
# Since we do not need to submit this lab, the accuracy score of the perceptron model implemented by sklearn is included here as a reference.

# %%
from sklearn.linear_model import Perceptron

input = X1_train
output = Y1_train
weights = {0:0.1, 1:0.5}
model = Perceptron(class_weight=weights, eta0=0.1)
model.fit(input, output)
prediction2 = model.predict(X1_test)

# %%
print(metrics.accuracy_score(Y1_test, prediction2))
# Out:
# 0.6153846153846154
