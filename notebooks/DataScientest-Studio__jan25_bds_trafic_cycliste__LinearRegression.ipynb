#  47  Nom du site de comptage_81 boulevard Mortier                           1204344 non-null  int64
#  48  Nom du site de comptage_87 avenue de Flandre                           1204344 non-null  int64
#  49  Nom du site de comptage_89 boulevard de Magenta                        1204344 non-null  int64
#  50  Nom du site de comptage_9 boulevard Jourdan                            1204344 non-null  int64
#  51  Nom du site de comptage_90 Rue De Sèvres                               1204344 non-null  int64
#  52  Nom du site de comptage_97 avenue Denfert Rochereau                    1204344 non-null  int64
#  53  Nom du site de comptage_98 boulevard Poniatowski                       1204344 non-null  int64
#  54  Nom du site de comptage_Face 104 rue d'Aubervilliers                   1204344 non-null  int64
#  55  Nom du site de comptage_Face au 16 avenue de la  Porte des Ternes      1204344 non-null  int64
#  56  Nom du site de comptage_Face au 25 quai de l'Oise                      1204344 non-null  int64
#  57  Nom du site de comptage_Face au 4 avenue de la porte de Bagnolet       1204344 non-null  int64
#  58  Nom du site de comptage_Face au 40 quai D'Issy                         1204344 non-null  int64
#  59  Nom du site de comptage_Face au 48 quai de la marne                    1204344 non-null  int64
#  60  Nom du site de comptage_Face au 49 boulevard du Général Martial Valin  1204344 non-null  int64
#  61  Nom du site de comptage_Face au 70 quai de Bercy                       1204344 non-null  int64
#  62  Nom du site de comptage_Face au 8 avenue de la porte de Charenton      1204344 non-null  int64
#  63  Nom du site de comptage_Pont Charles De Gaulle                         1204344 non-null  int64
#  64  Nom du site de comptage_Pont National                                  1204344 non-null  int64
#  65  Nom du site de comptage_Pont de Bercy                                  1204344 non-null  int64
#  66  Nom du site de comptage_Pont de la Concorde                            1204344 non-null  int64
#  67  Nom du site de comptage_Pont des Invalides                             1204344 non-null  int64
#  68  Nom du site de comptage_Pont du Garigliano                             1204344 non-null  int64
#  69  Nom du site de comptage_Quai d'Orsay                                   1204344 non-null  int64
#  70  Nom du site de comptage_Quai des Tuileries                             1204344 non-null  int64
#  71  Nom du site de comptage_Totem 64 Rue de Rivoli                         1204344 non-null  int64
#  72  Nom du site de comptage_Totem 73 boulevard de Sébastopol               1204344 non-null  int64
#  73  Nom du site de comptage_Totem 85 quai d'Austerlitz                     1204344 non-null  int64
#  74  Nom du site de comptage_Totem Cours la Reine                           1204344 non-null  int64
#  75  Nom du site de comptage_Voie Georges Pompidou                          1204344 non-null  int64
# dtypes: int64(76)
# memory usage: 707.5 MB

# %%
## Processing variables catégorielles

# %%
y = df["Comptage horaire"]
X = df.drop(columns=["Comptage horaire"])

col_norm = ["Jour", "Mois", "Année", "Heure", "Jour_semaine", "Jour férié", "Vacances scolaires"]
encoder = preprocessing.OneHotEncoder(sparse_output=False, dtype=int) 

array = encoder.fit_transform(X[col_norm])

encoded_df_clean = pd.DataFrame(array, columns=encoder.get_feature_names_out(col_norm))

encoded_df_clean.index = X.index

X_clean = pd.concat([X.drop(columns=col_norm), encoded_df_clean], axis=1)

# %%
X_clean.head()
# Out:
#          Nom du site de comptage_10 avenue de la Grande Armée  ...  Vacances scolaires_1
# 57773                                                    0     ...                     0
# 1092998                                                  0     ...                     1
# 1171485                                                  0     ...                     0
# 57487                                                    0     ...                     0
# 57812                                                    0     ...                     0
#
# [5 rows x 149 columns]

# %%
## Séparation données d'entrainement et de test

# %%
X_train, X_test, y_train, y_test = train_test_split(X_clean, y, test_size=0.2, random_state=42)

# %%
## Entrainement du modèle

# %%
clf = LinearRegression()
clf.fit(X_train, y_train)
print("train score", clf.score(X_train, y_train))
print("test score", clf.score(X_test, y_test))
# Out:
# train score 0.5939158529774999
# test score 0.5900886613201042

# %%
from sklearn.metrics import root_mean_squared_error

# %%
y_pred = clf.predict(X_test)
print(root_mean_squared_error(y_test, y_pred))
# Out:
# 102.21355356947552
