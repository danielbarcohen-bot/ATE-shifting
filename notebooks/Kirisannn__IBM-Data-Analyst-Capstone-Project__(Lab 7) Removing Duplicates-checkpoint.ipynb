# %% [markdown]
# <p style="text-align:center">
#     <a href="https://skills.network" target="_blank">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="200" alt="Skills Network Logo"  />
#     </a>
# </p>

# %% [markdown]
# # **Removing Duplicates**

# %% [markdown]
# Estimated time needed: **45 to 60** minutes

# %% [markdown]
# ## Introduction

# %% [markdown]
# In this lab, you will focus on data wrangling, an important step in preparing data for analysis. Data wrangling involves cleaning and organizing data to make it suitable for analysis. One key task in this process is removing duplicate entries, which are repeated entries that can distort analysis and lead to inaccurate conclusions.

# %% [markdown]
# ## Objectives

# %% [markdown]
# In this lab you will perform the following:

# %% [markdown]
# 1. Identify duplicate rows  in the dataset.
# 2. Use suitable techniques to remove duplicate rows and verify the removal.
# 3. Summarize how to handle missing values appropriately.
# 4. Use ConvertedCompYearly to normalize compensation data.

# %% [markdown]
# ### Install the Required Libraries

# %% [raw]
# !pip install pandas

# %% [markdown]
# ### Step 1: Import Required Libraries

# %% [raw]
# !pip install tqdm

# %%
# Import necessary libraries
import pandas as pd
import numpy as np

# For downloading
import requests
from tqdm.notebook import tqdm
from urllib.parse import urlparse

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# %% [markdown]
# ### Step 2: Load the Dataset into a DataFrame

# %% [markdown]
# #### **Read Data**

# %% [markdown]
# If you are using JupyterLite, use the code below to download the dataset into your environment. If you are using a local environment, you can use the direct URL with <code>pd.read_csv()</code>.

# %% [raw]
# from pyodide.http import pyfetch
#
# async def download(url, filename):
#     response = await pyfetch(url)
#     if response.status == 200:
#         with open(filename, "wb") as f:
#             f.write(await response.bytes())
#
# # Define the file path for the data
# file_path = "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/n01PQ9pSmiRX6520flujwQ/survey-data.csv"
#
# # Download the dataset
# await download(file_path, "survey_data.csv")
# file_name = "survey_data.csv"

# %% [markdown]
# **Load the data into a pandas dataframe:**

# %% [raw]
# df = pd.read_csv(file_name)

# %% [markdown]
# **Note: If you are working on a local Jupyter environment, you can use the URL directly in the <code>pandas.read_csv()</code>  function as shown below:**

# %% [markdown]
# ##### df = pd.read_csv("https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/n01PQ9pSmiRX6520flujwQ/survey-data.csv")

# %%
dataset_url = "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/VYPrOu0Vs3I0hKLLjiPGrA/survey-data-with-duplicate.csv"
data_name = urlparse(dataset_url).path.strip('/').split('/')[-1]

# %% [raw]
# # Download if necessary
# r = requests.get(dataset_url, stream=True)
# total_size = int(r.headers.get('content-length', 0))  # in bytes
# chunk_size = 1024  # 1 KB
#
# with open(data_name, 'wb') as file, tqdm(
#     desc=f"Downloading {data_name}",
#     total=total_size,
#     unit='B',
#     unit_scale=True,
#     unit_divisor=1024,
# ) as bar:
#     for chunk in r.iter_content(chunk_size=chunk_size):
#         if chunk:  # filter out keep-alive chunks
#             file.write(chunk)
#             bar.update(len(chunk))

# %%
# Read data and display
df = pd.read_csv(data_name)
df.head(n=3)
# Out:
#    ResponseId                      MainBranch                 Age  \
# 0           1  I am a developer by profession  Under 18 years old
# 1           2  I am a developer by profession     35-44 years old
# 2           3  I am a developer by profession     45-54 years old
#
#             Employment RemoteWork   Check  \
# 0  Employed, full-time     Remote  Apples
# 1  Employed, full-time     Remote  Apples
# 2  Employed, full-time     Remote  Apples
#
#                                     CodingActivities  \
# 0                                              Hobby
# 1  Hobby;Contribute to open-source projects;Other...
# 2  Hobby;Contribute to open-source projects;Other...
#
#                                            EdLevel  \
# 0                        Primary/elementary school
# 1     Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 2  Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
#
#                                            LearnCode  \
# ...

# %% [markdown]
# ### Step 3: Identifying Duplicate Rows

# %% [markdown]
# **Task 1: Identify Duplicate Rows**
#   1. Count the number of duplicate rows in the dataset.
#   2. Display the first few duplicate rows to understand their structure.

# %%
dups=df[df.duplicated(keep=False)]
print(dups.shape[0])
dups.head()
# Out:
# 40
#    ResponseId                      MainBranch                 Age  \
# 0           1  I am a developer by profession  Under 18 years old
# 1           2  I am a developer by profession     35-44 years old
# 2           3  I am a developer by profession     45-54 years old
# 3           4           I am learning to code     18-24 years old
# 4           5  I am a developer by profession     18-24 years old
#
#             Employment RemoteWork   Check  \
# 0  Employed, full-time     Remote  Apples
# 1  Employed, full-time     Remote  Apples
# 2  Employed, full-time     Remote  Apples
# 3   Student, full-time        NaN  Apples
# 4   Student, full-time        NaN  Apples
#
#                                     CodingActivities  \
# 0                                              Hobby
# 1  Hobby;Contribute to open-source projects;Other...
# 2  Hobby;Contribute to open-source projects;Other...
# 3                                                NaN
# ...

# %% [markdown]
# ### Step 4: Removing Duplicate Rows

# %% [markdown]
# **Task 2: Remove Duplicates**
#    1. Remove duplicate rows from the dataset using the drop_duplicates() function.
# 2. Verify the removal by counting the number of duplicate rows after removal .

# %%
df.duplicated(keep=False).value_counts()
# Out:
# False    65417
# True        40
# Name: count, dtype: int64

# %%
df_clean = df.drop_duplicates(keep='first')
if (df.shape[0] - df_clean.shape[0] == dups.shape[0] / 2):
    df = df_clean
    print("Successfully removed duplicates")
# Out:
# Successfully removed duplicates

# %% [markdown]
# ### Step 5: Handling Missing Values

# %% [markdown]
# **Task 3: Identify and Handle Missing Values**
#    1. Identify missing values for all columns in the dataset.
#    2. Choose a column with significant missing values (e.g., EdLevel) and impute with the most frequent value.

# %%
# 1. Identifying missing values
missing=df.isna()

# %%
missing_stats=missing.sum().sort_values(ascending=False).to_frame(name='count')
missing_stats['Missing (%)'] = (missing_stats['count'] / len(df) * 100).round(3)
missing_stats
# Out:
#                                 count  Missing (%)
# AINextMuch less integrated      64289       98.246
# AINextLess integrated           63082       96.401
# AINextNo change                 52939       80.901
# AINextMuch more integrated      51999       79.464
# EmbeddedAdmired                 48704       74.429
# EmbeddedWantToWorkWith          47837       73.104
# EmbeddedHaveWorkedWith          43223       66.053
# ConvertedCompYearly             42002       64.187
# AIToolNot interested in Using   41023       62.691
# AINextMore integrated           41009       62.669
# Knowledge_9                     37802       57.769
# Frequency_3                     37727       57.654
# Knowledge_8                     37679       57.581
# ProfessionalTech                37673       57.571
# Knowledge_7                     37659       57.550
# Knowledge_6                     37573       57.419
# Knowledge_5                     37557       57.394
# ...

# %%
print(f"EdLevel missing percentage: {missing_stats.loc['EdLevel', 'Missing (%)']}%")
# Out:
# EdLevel missing percentage: 7.111%

# %%
print(f"ConvertedCompYearly missing percentage: {missing_stats.loc['ConvertedCompYearly', 'Missing (%)']}%")
# Out:
# ConvertedCompYearly missing percentage: 64.187%

# %%
# Define function to impute columns according to data type
def impute_column(col):
    if col.dtype == 'O': # Object data type
        return col.fillna(col.mode()[0]) # Fill missing with first mode
    else: # Numeric data types
        return col.fillna(col.median())

# %%
# Impute only EdLevel (categorical)
df['EdLevel'] = impute_column(df['EdLevel'])

# %%
# Checking successful imputation of columns via lack of missing values
print(f"EdLevel number of missing values: {df['EdLevel'].isna().sum()}")
# Out:
# EdLevel number of missing values: 0

# %% [markdown]
# ### Step 6: Normalizing Compensation Data

# %% [markdown]
# **Task 4: Normalize Compensation Data Using ConvertedCompYearly**
#    1. Use the ConvertedCompYearly column for compensation analysis as the normalized annual compensation is already provided.
#    2. Check for missing values in ConvertedCompYearly and handle them if necessary.

# %%
scaled = df.copy()

# %%
# Min-Max Scaling
scaled['ConvertedCompYearly'] = (scaled['ConvertedCompYearly'] - scaled['ConvertedCompYearly'].min()) / (scaled['ConvertedCompYearly'].max() - scaled['ConvertedCompYearly'].min())

# %%
# Impute only ConvertedCompYearly (numeric)
scaled['ConvertedCompYearly'] = impute_column(scaled['ConvertedCompYearly'])
print(f"ConvertedCompYearly number of missing values: {scaled['ConvertedCompYearly'].isna().sum()}")
# Out:
# ConvertedCompYearly number of missing values: 0

# %% [markdown]
# ### Step 7: Summary and Next Steps

# %% [markdown]
# **In this lab, you focused on identifying and removing duplicate rows.**
#
# - You handled missing values by imputing the most frequent value in a chosen column.
#
# - You used ConvertedCompYearly for compensation normalization and handled missing values.
#
# - For further analysis, consider exploring other columns or visualizing the cleaned dataset.

# %% [markdown]
# <!--
# ## Change Log
#
# |Date (YYYY-MM-DD)|Version|Changed By|Change Description|
# |-|-|-|-|
# |2024-11-05|1.2|Madhusudhan Moole|Updated lab|
# |2024-09-24|1.1|Madhusudhan Moole|Updated lab|
# |2024-09-23|1.0|Raghul Ramesh|Created lab|
#
# --!>

# %% [markdown]
# ## <h3 align="center"> © IBM Corporation. All rights reserved. <h3/>
