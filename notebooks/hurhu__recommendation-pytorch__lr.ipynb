# %%
import numpy as np
import math
from sklearn import datasets
from collections import Counter
from sklearn.model_selection import train_test_split
infinity = float(-2 ** 31)

# %% [markdown]
# ## python实现逻辑回归

# %%
def sigmoid_train(Xb, W):
    #训练阶段 用当前的权重W预测样本Xb的每个样本的概率
    params = - Xb.dot(W)
    r = np.zeros(params.shape[0]) #生成维度为样本数的一维数组
    for i in range(len(r)):
        r[i] = 1 / (1 + math.exp(params[i]))
    return r
def sigmoid_predict(Xb, W):
    #预测阶段 用当前W预测Xb的每个样本的标签，概率值大于等于0.5标签为1 否则标签为0
    params = -Xb.dot(W)
    r = np.zeros(params.shape[0])
    for i in range(len(r)):
        r[i] = 1 / (1 + math.exp(params[i]))
        if r[i] >= 0.5:
            r[i] = 1
        else:
            r[i] = 0
    return r
def sigmoid(Xi, W):
    #计算某个样本在权重W下的概率
    params = -np.sum(Xi * W)
    r = 1 / (1 + math.exp(params))
    return r

class LinearLogsiticRegression(object):
    W = None
    m = 0
    #训练
    #alpha：学习率,accuracy时训练停止条件
    def fit(self, X, y, alpha=0.01, accuracy=0.00001):
        #插入第一列为1(即偏置项b)，构成Xb矩阵
        self.W = np.full(X.shape[1]+1, 0.5)#用0.5初始化权重向量W
        self.m = X.shape[0] #样本数量
        a = np.full((self.m,1),1) #生成一列偏置项
        Xb = np.column_stack((a,X))
        dimension = X.shape[1] + 1 #输入数据的特征个数+偏置项
        #梯度下降迭代
        count = 1
        while True:
            oldJ = self.costFunc(Xb, y)
            #根据上面的公式更新权重
            error = sigmoid_train(Xb, self.W) - y
            for j in range(dimension):
                self.W[j] -= alpha * np.sum(error * Xb[:,j]) / self.m
            newJ = self.costFunc(Xb, y)
            if newJ == oldJ or math.fabs(newJ - oldJ) < accuracy:
                print('代价函数迭代到最小值，退出!')
                print('收敛到:', newJ)
                break
            print('迭代第', count, '次')
            print('代价函数上一次的差:', (oldJ - newJ))
            count += 1
            
    ##计算损失函数
    def costFunc(self, Xb, y):
        sums = 0.0
        for i in range(self.m):
            yPre = sigmoid(Xb[i,:], self.W)
            if yPre == 1 or yPre == 0:
                return infinity
            sums += y[i] * math.log(yPre) + (1 - y[i]) * math.log(1 - yPre)
        return -1 * sums / self.m
    #预测
    def predict(self, X):
        a = np.full((len(X),1), 1)
        Xb = np.column_stack((a,X))
        return sigmoid_predict(Xb, self.W)
    #用准确率衡量预测结果的好坏
    def score(self, X_test, y_test):
        y_predict = self.predict(X_test)
        re = (y_test==y_predict)
        re1 = Counter(re)
        acc = re1[True] / (re1[True] + re1[False])
        return acc

# %%
iris = datasets.load_iris()
X = iris['data']
y = iris['target']
X = X[y!=2]
y = y[y!=2]
X_train, X_test, y_train, y_test = train_test_split(X, y)

myLogistic = LinearLogsiticRegression()
myLogistic.fit(X_train, y_train)
y_predict = myLogistic.predict(X_test)

print('权重值:', myLogistic.W)
print('测试集准确度:', myLogistic.score(X_test, y_test))
# Out:
# 迭代第 1 次
# 代价函数上一次的差: 0.10318127256093002
# 迭代第 2 次
# 代价函数上一次的差: 0.10295861917071703
# 迭代第 3 次
# 代价函数上一次的差: 0.10268621319883442
# 迭代第 4 次
# 代价函数上一次的差: 0.1023532130341609
# 迭代第 5 次
# 代价函数上一次的差: 0.10194657832381271
# 迭代第 6 次
# 代价函数上一次的差: 0.10145071155655971
# 迭代第 7 次
# 代价函数上一次的差: 0.10084708727119329
# 迭代第 8 次
# 代价函数上一次的差: 0.10011389615388211
# 迭代第 9 次
# 代价函数上一次的差: 0.09922574800536643
# 迭代第 10 次
# 代价函数上一次的差: 0.09815349976526178
# 迭代第 11 次
# 代价函数上一次的差: 0.0968643022514839
# 迭代第 12 次
# 代价函数上一次的差: 0.09532198992146412
# 迭代第 13 次
# 代价函数上一次的差: 0.09348796647265001
# 迭代第 14 次
# 代价函数上一次的差: 0.09132275535161072
# 迭代第 15 次
# 代价函数上一次的差: 0.08878837220192715
# 迭代第 16 次
# 代价函数上一次的差: 0.08585161474211023
# 迭代第 17 次
# 代价函数上一次的差: 0.08248823281840445
# 迭代第 18 次
# 代价函数上一次的差: 0.07868772586235306
# 迭代第 19 次
# 代价函数上一次的差: 0.07445823180572275
# 迭代第 20 次
# 代价函数上一次的差: 0.06983067943483046
# 迭代第 21 次
# 代价函数上一次的差: 0.06486118238245808
# 迭代第 22 次
# 代价函数上一次的差: 0.05963068917041614
# 迭代第 23 次
# 代价函数上一次的差: 0.05424126657760331
# 迭代第 24 次
# 代价函数上一次的差: 0.04880906868816204
# 迭代第 25 次
# 代价函数上一次的差: 0.043454862457037
# 迭代第 26 次
# 代价函数上一次的差: 0.038293659441824945
# 迭代第 27 次
# 代价函数上一次的差: 0.03342527166102971
# 迭代第 28 次
# 代价函数上一次的差: 0.028927353211201323
# 迭代第 29 次
# 代价函数上一次的差: 0.024851815432346935
# 迭代第 30 次
# 代价函数上一次的差: 0.021224678818873355
# 迭代第 31 次
# 代价函数上一次的差: 0.018048733910930537
# 迭代第 32 次
# 代价函数上一次的差: 0.01530800156779677
# 迭代第 33 次
# 代价函数上一次的差: 0.012972933351663163
# 迭代第 34 次
# 代价函数上一次的差: 0.01100548424011355
# 迭代第 35 次
# 代价函数上一次的差: 0.009363490830156418
# 迭代第 36 次
# 代价函数上一次的差: 0.008004086799894283
# 迭代第 37 次
# 代价函数上一次的差: 0.006886118889648796
# 迭代第 38 次
# 代价函数上一次的差: 0.005971671475255014
# 迭代第 39 次
# 代价函数上一次的差: 0.0052268757086884055
# 迭代第 40 次
# 代价函数上一次的差: 0.004622192384091062
# 迭代第 41 次
# 代价函数上一次的差: 0.004132339008115327
# 迭代第 42 次
# 代价函数上一次的差: 0.0037359988662246657
# 迭代第 43 次
# 代价函数上一次的差: 0.0034154147261759027
# 迭代第 44 次
# 代价函数上一次的差: 0.0031559383846589406
# 迭代第 45 次
# 代价函数上一次的差: 0.0029455820020490298
# 迭代第 46 次
# 代价函数上一次的差: 0.002774598353245006
# 迭代第 47 次
# 代价函数上一次的差: 0.0026351039501477658
# 迭代第 48 次
# 代价函数上一次的差: 0.002520750293984686
# 迭代第 49 次
# 代价函数上一次的差: 0.002426443130029099
# 迭代第 50 次
# 代价函数上一次的差: 0.0023481065124400513
# 迭代第 51 次
# 代价函数上一次的差: 0.002282486971011466
# 迭代第 52 次
# 代价函数上一次的差: 0.002226992538753747
# 迭代第 53 次
# 代价函数上一次的差: 0.0021795614541940678
# 迭代第 54 次
# 代价函数上一次的差: 0.0021385557299097857
# 迭代第 55 次
# 代价函数上一次的差: 0.0021026753085295335
# 迭代第 56 次
# 代价函数上一次的差: 0.002070889104302309
# 迭代第 57 次
# 代价函数上一次的差: 0.002042379791465765
# 迭代第 58 次
# 代价函数上一次的差: 0.0020164997178708233
# 迭代第 59 次
# 代价函数上一次的差: 0.0019927357793275147
# 迭代第 60 次
# 代价函数上一次的差: 0.001970681483389858
# 迭代第 61 次
# 代价函数上一次的差: 0.0019500147633158549
# 迭代第 62 次
# 代价函数上一次的差: 0.0019304803792759007
# 迭代第 63 次
# 代价函数上一次的差: 0.0019118759714421008
# 迭代第 64 次
# 代价函数上一次的差: 0.0018940410153632237
# 迭代第 65 次
# 代价函数上一次的差: 0.0018768480807022647
# 迭代第 66 次
# 代价函数上一次的差: 0.001860195915972196
# 迭代第 67 次
# 代价函数上一次的差: 0.0018440039795429297
# 迭代第 68 次
# 代价函数上一次的差: 0.00182820811534401
# 迭代第 69 次
# 代价函数上一次的差: 0.001812757134080023
# 迭代第 70 次
# 代价函数上一次的差: 0.0017976101104560382
# 迭代第 71 次
# 代价函数上一次的差: 0.0017827342464005747
# 迭代第 72 次
# 代价函数上一次的差: 0.0017681031816079162
# 迭代第 73 次
# 代价函数上一次的差: 0.0017536956575836538
# 迭代第 74 次
# 代价函数上一次的差: 0.0017394944610116259
# 迭代第 75 次
# 代价函数上一次的差: 0.001725485587877329
# 迭代第 76 次
# 代价函数上一次的差: 0.0017116575820249058
# 迭代第 77 次
# 代价函数上一次的差: 0.001698001011610606
# 迭代第 78 次
# 代价函数上一次的差: 0.0016845080545561109
# 迭代第 79 次
# 代价函数上一次的差: 0.0016711721701921922
# 迭代第 80 次
# 代价函数上一次的差: 0.0016579878390730607
# 迭代第 81 次
# 代价函数上一次的差: 0.0016449503567194101
# 迭代第 82 次
# 代价函数上一次的差: 0.0016320556700404887
# 迭代第 83 次
# 代价函数上一次的差: 0.0016193002475437535
# 迭代第 84 次
# 代价函数上一次的差: 0.0016066809762971257
# 迭代第 85 次
# 代价函数上一次的差: 0.0015941950800886229
# 迭代第 86 次
# 代价函数上一次的差: 0.0015818400543864963
# 迭代第 87 次
# 代价函数上一次的差: 0.001569613614611387
# 迭代第 88 次
# 代价函数上一次的差: 0.001557513654980025
# 迭代第 89 次
# 代价函数上一次的差: 0.0015455382157252284
# 迭代第 90 次
# 代价函数上一次的差: 0.0015336854569752423
# 迭代第 91 次
# 代价函数上一次的差: 0.0015219536379156295
# 迭代第 92 次
# 代价函数上一次的差: 0.001510341100154633
# 迭代第 93 次
# 代价函数上一次的差: 0.0014988462544250347
# 迭代第 94 次
# 代价函数上一次的差: 0.0014874675699446116
# 迭代第 95 次
# 代价函数上一次的差: 0.0014762035658902328
# 迭代第 96 次
# 代价函数上一次的差: 0.0014650528045548894
# 迭代第 97 次
# 代价函数上一次的差: 0.0014540138858459284
# 迭代第 98 次
# 代价函数上一次的差: 0.0014430854428534867
# 迭代第 99 次
# 代价函数上一次的差: 0.0014322661382732416
# 迭代第 100 次
# 代价函数上一次的差: 0.0014215546615040098
# 迭代第 101 次
# 代价函数上一次的差: 0.001410949726298294
# 迭代第 102 次
# 代价函数上一次的差: 0.0014004500688399868
# 迭代第 103 次
# 代价函数上一次的差: 0.0013900544461724063
# 迭代第 104 次
# 代价函数上一次的差: 0.0013797616349050523
# 迭代第 105 次
# 代价函数上一次的差: 0.0013695704301422973
# 迭代第 106 次
# 代价函数上一次的差: 0.0013594796445926538
# 迭代第 107 次
# 代价函数上一次的差: 0.0013494881078179866
# 迭代第 108 次
# 代价函数上一次的差: 0.0013395946656007407
# 迭代第 109 次
# 代价函数上一次的差: 0.0013297981794051505
# 迭代第 110 次
# 代价函数上一次的差: 0.0013200975259073933
# 迭代第 111 次
# 代价函数上一次的差: 0.001310491596593355
# 迭代第 112 次
# 代价函数上一次的差: 0.0013009792973994183
# 迭代第 113 次
# 代价函数上一次的差: 0.0012915595483947717
# 迭代第 114 次
# 代价函数上一次的差: 0.0012822312834959715
# 迭代第 115 次
# 代价函数上一次的差: 0.0012729934502070939
# 迭代第 116 次
# 代价函数上一次的差: 0.001263845009379816
# 迭代第 117 次
# 代价函数上一次的差: 0.001254784934994091
# 迭代第 118 次
# 代价函数上一次的差: 0.0012458122139485384
# 迭代第 119 次
# 代价函数上一次的差: 0.0012369258458670984
# 迭代第 120 次
# 代价函数上一次的差: 0.0012281248429124592
# 迭代第 121 次
# 代价函数上一次的差: 0.0012194082296077546
# 迭代第 122 次
# 代价函数上一次的差: 0.001210775042667922
# 迭代第 123 次
# 代价函数上一次的差: 0.0012022243308323355
# 迭代第 124 次
# 代价函数上一次的差: 0.001193755154706877
# 迭代第 125 次
# 代价函数上一次的差: 0.0011853665866073393
# 迭代第 126 次
# 代价函数上一次的差: 0.0011770577104072144
# 迭代第 127 次
# 代价函数上一次的差: 0.0011688276213893123
# 迭代第 128 次
# 代价函数上一次的差: 0.0011606754260999885
# 迭代第 129 次
# 代价函数上一次的差: 0.001152600242205537
# 迭代第 130 次
# 代价函数上一次的差: 0.0011446011983513027
# 迭代第 131 次
# 代价函数上一次的差: 0.0011366774340238472
# 迭代第 132 次
# 代价函数上一次的差: 0.001128828099413004
# 迭代第 133 次
# 代价函数上一次的差: 0.0011210523552779295
# 迭代第 134 次
# 代价函数上一次的差: 0.0011133493728128219
# 迭代第 135 次
# 代价函数上一次的差: 0.0011057183335179688
# 迭代第 136 次
# 代价函数上一次的差: 0.001098158429067353
# 迭代第 137 次
# 代价函数上一次的差: 0.0010906688611829196
# 迭代第 138 次
# 代价函数上一次的差: 0.001083248841505291
# 迭代第 139 次
# 代价函数上一次的差: 0.0010758975914713642
# 迭代第 140 次
# 代价函数上一次的差: 0.0010686143421886896
# 迭代第 141 次
# 代价函数上一次的差: 0.0010613983343142341
# 迭代第 142 次
# 代价函数上一次的差: 0.0010542488179325904
# 迭代第 143 次
# 代价函数上一次的差: 0.001047165052437904
# 迭代第 144 次
# 代价函数上一次的差: 0.0010401463064134142
# 迭代第 145 次
# 代价函数上一次的差: 0.001033191857518212
# 迭代第 146 次
# 代价函数上一次的差: 0.0010263009923670574
# 迭代第 147 次
# 代价函数上一次的差: 0.0010194730064206903
# 迭代第 148 次
# 代价函数上一次的差: 0.0010127072038708107
# 迭代第 149 次
# 代价函数上一次的差: 0.0010060028975278912
# 迭代第 150 次
# 代价函数上一次的差: 0.0009993594087127633
# 迭代第 151 次
# 代价函数上一次的差: 0.000992776067145984
# 迭代第 152 次
# 代价函数上一次的差: 0.0009862522108413097
# 迭代第 153 次
# 代价函数上一次的差: 0.000979787185998282
# 迭代第 154 次
# 代价函数上一次的差: 0.0009733803468975344
# 迭代第 155 次
# 代价函数上一次的差: 0.0009670310557968187
# 迭代第 156 次
# 代价函数上一次的差: 0.0009607386828275888
# 迭代第 157 次
# 代价函数上一次的差: 0.0009545026058942474
# 迭代第 158 次
# 代价函数上一次的差: 0.0009483222105742262
# 迭代第 159 次
# 代价函数上一次的差: 0.0009421968900161226
# 迭代第 160 次
# 代价函数上一次的差: 0.0009361260448459974
# 迭代第 161 次
# 代价函数上一次的差: 0.00093010908306701
# 迭代第 162 次
# 代价函数上一次的差: 0.0009241454199652721
# 迭代第 163 次
# 代价函数上一次的差: 0.0009182344780159224
# 迭代第 164 次
# 代价函数上一次的差: 0.0009123756867895905
# 迭代第 165 次
# 代价函数上一次的差: 0.0009065684828582499
# 迭代第 166 次
# 代价函数上一次的差: 0.000900812309707788
# 迭代第 167 次
# 代价函数上一次的差: 0.0008951066176456912
# 迭代第 168 次
# 代价函数上一次的差: 0.0008894508637127263
# 迭代第 169 次
# 代价函数上一次的差: 0.0008838445115958438
# 迭代第 170 次
# 代价函数上一次的差: 0.0008782870315413582
# 迭代第 171 次
# 代价函数上一次的差: 0.0008727779002692393
# 迭代第 172 次
# 代价函数上一次的差: 0.0008673166008897337
# 迭代第 173 次
# 代价函数上一次的差: 0.0008619026228181559
# 迭代第 174 次
# 代价函数上一次的差: 0.000856535461694341
# 迭代第 175 次
# 代价函数上一次的差: 0.0008512146193021541
# 迭代第 176 次
# 代价函数上一次的差: 0.0008459396034861122
# 迭代第 177 次
# 代价函数上一次的差: 0.0008407099280757224
# 迭代第 178 次
# 代价函数上一次的差: 0.0008355251128053243
# 迭代第 179 次
# 代价函数上一次的差: 0.000830384683237928
# 迭代第 180 次
# 代价函数上一次的差: 0.0008252881706882764
# 迭代第 181 次
# 代价函数上一次的差: 0.0008202351121485152
# 迭代第 182 次
# 代价函数上一次的差: 0.0008152250502142522
# 迭代第 183 次
# 代价函数上一次的差: 0.0008102575330098394
# 迭代第 184 次
# 代价函数上一次的差: 0.0008053321141179015
# 迭代第 185 次
# 代价函数上一次的差: 0.0008004483525069772
# 迭代第 186 次
# 代价函数上一次的差: 0.0007956058124617971
# 迭代第 187 次
# 代价函数上一次的差: 0.0007908040635128677
# 迭代第 188 次
# 代价函数上一次的差: 0.0007860426803699971
# 迭代第 189 次
# 代价函数上一次的差: 0.0007813212428515459
# 迭代第 190 次
# 代价函数上一次的差: 0.00077663933582095
# 迭代第 191 次
# 代价函数上一次的差: 0.0007719965491185254
# 迭代第 192 次
# 代价函数上一次的差: 0.0007673924774980745
# 迭代第 193 次
# 代价函数上一次的差: 0.0007628267205610495
# 迭代第 194 次
# 代价函数上一次的差: 0.0007582988826954906
# 迭代第 195 次
# 代价函数上一次的差: 0.0007538085730117716
# 迭代第 196 次
# 代价函数上一次的差: 0.0007493554052817875
# 迭代第 197 次
# 代价函数上一次的差: 0.0007449389978778642
# 迭代第 198 次
# 代价函数上一次的差: 0.0007405589737137785
# 迭代第 199 次
# 代价函数上一次的差: 0.0007362149601836399
# 迭代第 200 次
# 代价函数上一次的差: 0.0007319065891062404
# 迭代第 201 次
# 代价函数上一次的差: 0.0007276334966646036
# 迭代第 202 次
# 代价函数上一次的差: 0.0007233953233511115
# 迭代第 203 次
# 代价函数上一次的差: 0.0007191917139113546
# 迭代第 204 次
# 代价函数上一次的差: 0.0007150223172877612
# 迭代第 205 次
# 代价函数上一次的差: 0.0007108867865656121
# 迭代第 206 次
# 代价函数上一次的差: 0.0007067847789199166
# 迭代第 207 次
# 代价函数上一次的差: 0.0007027159555611784
# 迭代第 208 次
# 代价函数上一次的差: 0.0006986799816840472
# 迭代第 209 次
# 代价函数上一次的差: 0.0006946765264147503
# 迭代第 210 次
# 代价函数上一次的差: 0.0006907052627604382
# 迭代第 211 次
# 代价函数上一次的差: 0.0006867658675595578
# 迭代第 212 次
# 代价函数上一次的差: 0.0006828580214316704
# 迭代第 213 次
# 代价函数上一次的差: 0.0006789814087277968
# 迭代第 214 次
# 代价函数上一次的差: 0.0006751357174842043
# 迭代第 215 次
# 代价函数上一次的差: 0.0006713206393722249
# 迭代第 216 次
# 代价函数上一次的差: 0.0006675358696538736
# 迭代第 217 次
# 代价函数上一次的差: 0.0006637811071331101
# 迭代第 218 次
# 代价函数上一次的差: 0.0006600560541123734
# 迭代第 219 次
# 代价函数上一次的差: 0.0006563604163453973
# 迭代第 220 次
# 代价函数上一次的差: 0.0006526939029948553
# 迭代第 221 次
# 代价函数上一次的差: 0.0006490562265863697
# 迭代第 222 次
# 代价函数上一次的差: 0.0006454471029672115
# 迭代第 223 次
# 代价函数上一次的差: 0.0006418662512622519
# 迭代第 224 次
# 代价函数上一次的差: 0.0006383133938324681
# 迭代第 225 次
# 代价函数上一次的差: 0.0006347882562334484
# 迭代第 226 次
# 代价函数上一次的差: 0.0006312905671739533
# 迭代第 227 次
# 代价函数上一次的差: 0.0006278200584762805
# 迭代第 228 次
# 代价函数上一次的差: 0.0006243764650354922
# 迭代第 229 次
# 代价函数上一次的差: 0.0006209595247811672
# 迭代第 230 次
# 代价函数上一次的差: 0.0006175689786380167
# 迭代第 231 次
# 代价函数上一次的差: 0.0006142045704871368
# 迭代第 232 次
# 代价函数上一次的差: 0.0006108660471293159
# 迭代第 233 次
# 代价函数上一次的差: 0.0006075531582474258
# 迭代第 234 次
# 代价函数上一次的差: 0.0006042656563695348
# 迭代第 235 次
# 代价函数上一次的差: 0.0006010032968325474
# 迭代第 236 次
# 代价函数上一次的差: 0.0005977658377471218
# 迭代第 237 次
# 代价函数上一次的差: 0.0005945530399621701
# 迭代第 238 次
# 代价函数上一次的差: 0.0005913646670297201
# 迭代第 239 次
# 代价函数上一次的差: 0.0005882004851707756
# 迭代第 240 次
# 代价函数上一次的差: 0.0005850602632428148
# 迭代第 241 次
# 代价函数上一次的差: 0.000581943772703708
# 迭代第 242 次
# 代价函数上一次的差: 0.0005788507875817139
# 迭代第 243 次
# 代价函数上一次的差: 0.0005757810844411182
# 迭代第 244 次
# 代价函数上一次的差: 0.0005727344423508973
# 迭代第 245 次
# 代价函数上一次的差: 0.0005697106428534382
# 迭代第 246 次
# 代价函数上一次的差: 0.0005667094699331465
# 迭代第 247 次
# 代价函数上一次的差: 0.0005637307099846944
# 迭代第 248 次
# 代价函数上一次的差: 0.0005607741517848208
# 迭代第 249 次
# 代价函数上一次的差: 0.0005578395864609398
# 迭代第 250 次
# 代价函数上一次的差: 0.0005549268074614977
# 迭代第 251 次
# 代价函数上一次的差: 0.0005520356105282176
# 迭代第 252 次
# 代价函数上一次的差: 0.0005491657936658179
# 迭代第 253 次
# 代价函数上一次的差: 0.0005463171571151171
# 迭代第 254 次
# 代价函数上一次的差: 0.0005434895033241682
# 迭代第 255 次
# 代价函数上一次的差: 0.0005406826369206141
# 迭代第 256 次
# 代价函数上一次的差: 0.0005378963646861246
# 迭代第 257 次
# 代价函数上一次的差: 0.0005351304955268921
# 迭代第 258 次
# 代价函数上一次的差: 0.0005323848404498455
# 迭代第 259 次
# 代价函数上一次的差: 0.0005296592125347832
# 迭代第 260 次
# 代价函数上一次的差: 0.0005269534269095599
# 迭代第 261 次
# 代价函数上一次的差: 0.0005242673007243293
# 迭代第 262 次
# 代价函数上一次的差: 0.000521600653126647
# 迭代第 263 次
# 代价函数上一次的差: 0.0005189533052364081
# 迭代第 264 次
# 代价函数上一次的差: 0.0005163250801223096
# 迭代第 265 次
# 代价函数上一次的差: 0.0005137158027768707
# 迭代第 266 次
# 代价函数上一次的差: 0.0005111253000931459
# 迭代第 267 次
# 代价函数上一次的差: 0.0005085534008414383
# 迭代第 268 次
# 代价函数上一次的差: 0.0005059999356457345
# 迭代第 269 次
# 代价函数上一次的差: 0.0005034647369620282
# 迭代第 270 次
# 代价函数上一次的差: 0.0005009476390542
# 迭代第 271 次
# 代价函数上一次的差: 0.0004984484779729792
# 迭代第 272 次
# 代价函数上一次的差: 0.000495967091534294
# 迭代第 273 次
# 代价函数上一次的差: 0.0004935033192965677
# 迭代第 274 次
# 代价函数上一次的差: 0.0004910570025404015
# 迭代第 275 次
# 代价函数上一次的差: 0.000488627984247425
# 迭代第 276 次
# 代价函数上一次的差: 0.00048621610907884083
# 迭代第 277 次
# 代价函数上一次的差: 0.00048382122335619004
# 迭代第 278 次
# 代价函数上一次的差: 0.000481443175039592
# 迭代第 279 次
# 代价函数上一次的差: 0.0004790818137101749
# 迭代第 280 次
# 代价函数上一次的差: 0.00047673699054753826
# 迭代第 281 次
# 代价函数上一次的差: 0.0004744085583125446
# 迭代第 282 次
# 代价函数上一次的差: 0.00047209637132766824
# 迭代第 283 次
# 代价函数上一次的差: 0.000469800285457872
# 迭代第 284 次
# 代价函数上一次的差: 0.0004675201580913724
# 迭代第 285 次
# 代价函数上一次的差: 0.000465255848122903
# 迭代第 286 次
# 代价函数上一次的差: 0.00046300721593453553
# 迭代第 287 次
# 代价函数上一次的差: 0.00046077412337708346
# 迭代第 288 次
# 代价函数上一次的差: 0.0004585564337544479
# 迭代第 289 次
# 代价函数上一次的差: 0.00045635401180413315
# 迭代第 290 次
# 代价函数上一次的差: 0.0004541667236814262
# 迭代第 291 次
# 代价函数上一次的差: 0.0004519944369417994
# 迭代第 292 次
# 代价函数上一次的差: 0.0004498370205245905
# 迭代第 293 次
# 代价函数上一次的差: 0.00044769434473584946
# 迭代第 294 次
# 代价函数上一次的差: 0.0004455662812326844
# 迭代第 295 次
# 代价函数上一次的差: 0.00044345270300708006
# 迭代第 296 次
# 代价函数上一次的差: 0.0004413534843696332
# 迭代第 297 次
# 代价函数上一次的差: 0.00043926850093389813
# 迭代第 298 次
# 代价函数上一次的差: 0.0004371976296021485
# 迭代第 299 次
# 代价函数上一次的差: 0.0004351407485478076
# 迭代第 300 次
# 代价函数上一次的差: 0.00043309773720265343
# 迭代第 301 次
# 代价函数上一次的差: 0.0004310684762411643
# 迭代第 302 次
# 代价函数上一次的差: 0.0004290528475645594
# 迭代第 303 次
# 代价函数上一次的差: 0.0004270507342888641
# 迭代第 304 次
# 代价函数上一次的差: 0.0004250620207285061
# 迭代第 305 次
# 代价函数上一次的差: 0.000423086592383104
# 迭代第 306 次
# 代价函数上一次的差: 0.00042112433592320087
# 迭代第 307 次
# 代价函数上一次的差: 0.0004191751391773024
# 迭代第 308 次
# 代价函数上一次的差: 0.00041723889111733303
# 迭代第 309 次
# 代价函数上一次的差: 0.00041531548184575717
# 迭代第 310 次
# 代价函数上一次的差: 0.00041340480258231227
# 迭代第 311 次
# 代价函数上一次的差: 0.00041150674565090806
# 迭代第 312 次
# 代价函数上一次的差: 0.0004096212044671643
# 迭代第 313 次
# 代价函数上一次的差: 0.00040774807352500497
# 迭代第 314 次
# 代价函数上一次的差: 0.00040588724838444556
# 迭代第 315 次
# 代价函数上一次的差: 0.00040403862565971393
# 迭代第 316 次
# 代价函数上一次的差: 0.0004022021030061773
# 迭代第 317 次
# 代价函数上一次的差: 0.0004003775791084907
# 迭代第 318 次
# 代价函数上一次的差: 0.0003985649536698277
# 迭代第 319 次
# 代价函数上一次的差: 0.0003967641273982525
# 迭代第 320 次
# 代价函数上一次的差: 0.0003949750019966447
# 迭代第 321 次
# 代价函数上一次的差: 0.00039319748015009814
# 迭代第 322 次
# 代价函数上一次的差: 0.0003914314655158735
# 迭代第 323 次
# 代价函数上一次的差: 0.00038967686271143553
# 迭代第 324 次
# 代价函数上一次的差: 0.00038793357730318445
# 迭代第 325 次
# 代价函数上一次的差: 0.000386201515796325
# 迭代第 326 次
# 代价函数上一次的差: 0.0003844805856236533
# 迭代第 327 次
# 代价函数上一次的差: 0.0003827706951350651
# 迭代第 328 次
# 代价函数上一次的差: 0.00038107175358745304
# 迭代第 329 次
# 代价函数上一次的差: 0.00037938367113329874
# 迭代第 330 次
# 代价函数上一次的差: 0.0003777063588123186
# 迭代第 331 次
# 代价函数上一次的差: 0.00037603972853894607
# 迭代第 332 次
# 代价函数上一次的差: 0.000374383693095115
# 迭代第 333 次
# 代价函数上一次的差: 0.00037273816611779753
# 迭代第 334 次
# 代价函数上一次的差: 0.0003711030620918432
# 迭代第 335 次
# 代价函数上一次的差: 0.0003694782963378218
# 迭代第 336 次
# 代价函数上一次的差: 0.0003678637850052513
# 迭代第 337 次
# 代价函数上一次的差: 0.0003662594450604961
# 迭代第 338 次
# 代价函数上一次的差: 0.00036466519428041133
# 迭代第 339 次
# 代价函数上一次的差: 0.00036308095124096273
# 迭代第 340 次
# 代价函数上一次的差: 0.00036150663530884475
# 迭代第 341 次
# 代价函数上一次的差: 0.0003599421666338476
# 迭代第 342 次
# 代价函数上一次的差: 0.00035838746613819916
# 迭代第 343 次
# 代价函数上一次的差: 0.00035684245550968163
# 迭代第 344 次
# 代价函数上一次的差: 0.0003553070571910011
# 迭代第 345 次
# 代价函数上一次的差: 0.00035378119437406985
# 迭代第 346 次
# 代价函数上一次的差: 0.00035226479098929286
# 迭代第 347 次
# 代价函数上一次的差: 0.00035075777169837896
# 迭代第 348 次
# 代价函数上一次的差: 0.00034926006188618075
# 迭代第 349 次
# 代价函数上一次的差: 0.00034777158765286753
# 迭代第 350 次
# 代价函数上一次的差: 0.00034629227580521005
# 迭代第 351 次
# 代价函数上一次的差: 0.00034482205384966935
# 迭代第 352 次
# 代价函数上一次的差: 0.0003433608499842644
# 迭代第 353 次
# 代价函数上一次的差: 0.00034190859309080057
# 迭代第 354 次
# 代价函数上一次的差: 0.0003404652127275698
# 迭代第 355 次
# 代价函数上一次的差: 0.0003390306391218012
# 迭代第 356 次
# 代价函数上一次的差: 0.0003376048031623058
# 迭代第 357 次
# 代价函数上一次的差: 0.00033618763639273186
# 迭代第 358 次
# 代价函数上一次的差: 0.000334779071002822
# 迭代第 359 次
# 代价函数上一次的差: 0.00033337903982369466
# 迭代第 360 次
# 代价函数上一次的差: 0.0003319874763189068
# 迭代第 361 次
# 代价函数上一次的差: 0.0003306043145780424
# 迭代第 362 次
# 代价函数上一次的差: 0.00032922948931066176
# 迭代第 363 次
# 代价函数上一次的差: 0.0003278629358385299
# 迭代第 364 次
# 代价函数上一次的差: 0.00032650459008951027
# 迭代第 365 次
# 代价函数上一次的差: 0.0003251543885907371
# 迭代第 366 次
# 代价函数上一次的差: 0.0003238122684625089
# 迭代第 367 次
# 代价函数上一次的差: 0.00032247816741146074
# 迭代第 368 次
# 代价函数上一次的差: 0.0003211520237246246
# 迭代第 369 次
# 代价函数上一次的差: 0.000319833776262074
# 迭代第 370 次
# 代价函数上一次的差: 0.00031852336445287177
# 迭代第 371 次
# 代价函数上一次的差: 0.00031722072828660464
# 迭代第 372 次
# 代价函数上一次的差: 0.00031592580830880346
# 迭代第 373 次
# 代价函数上一次的差: 0.00031463854561472604
# 迭代第 374 次
# 代价函数上一次的差: 0.00031335888184333416
# 迭代第 375 次
# 代价函数上一次的差: 0.0003120867591706322
# 迭代第 376 次
# 代价函数上一次的差: 0.00031082212030611456
# 迭代第 377 次
# 代价函数上一次的差: 0.000309564908484522
# 迭代第 378 次
# 代价函数上一次的差: 0.00030831506746206716
# 迭代第 379 次
# 代价函数上一次的差: 0.00030707254151027263
# 迭代第 380 次
# 代价函数上一次的差: 0.00030583727540978156
# 迭代第 381 次
# 代价函数上一次的差: 0.0003046092144463053
# 迭代第 382 次
# 代价函数上一次的差: 0.00030338830440462816
# 迭代第 383 次
# 代价函数上一次的差: 0.00030217449156266785
# 迭代第 384 次
# 代价函数上一次的差: 0.0003009677226871177
# 迭代第 385 次
# 代价函数上一次的差: 0.00029976794502856174
# 迭代第 386 次
# 代价函数上一次的差: 0.00029857510631506323
# 迭代第 387 次
# 代价函数上一次的差: 0.000297389154748251
# 迭代第 388 次
# 代价函数上一次的差: 0.0002962100389982958
# 迭代第 389 次
# 代价函数上一次的差: 0.0002950377081980815
# 迭代第 390 次
# 代价函数上一次的差: 0.000293872111939375
# 迭代第 391 次
# 代价函数上一次的差: 0.00029271320026785785
# 迭代第 392 次
# 代价函数上一次的差: 0.0002915609236771588
# 迭代第 393 次
# 代价函数上一次的差: 0.0002904152331063836
# 迭代第 394 次
# 代价函数上一次的差: 0.00028927607993312066
# 迭代第 395 次
# 代价函数上一次的差: 0.0002881434159708318
# 迭代第 396 次
# 代价函数上一次的差: 0.0002870171934627741
# 迭代第 397 次
# 代价函数上一次的差: 0.00028589736507872443
# 迭代第 398 次
# 代价函数上一次的差: 0.0002847838839098449
# 迭代第 399 次
# 代价函数上一次的差: 0.0002836767034645471
# 迭代第 400 次
# 代价函数上一次的差: 0.0002825757776638571
# 迭代第 401 次
# 代价函数上一次的差: 0.00028148106083797364
# 迭代第 402 次
# 代价函数上一次的差: 0.00028039250772129987
# 迭代第 403 次
# 代价函数上一次的差: 0.0002793100734481413
# 迭代第 404 次
# 代价函数上一次的差: 0.00027823371354929183
# 迭代第 405 次
# 代价函数上一次的差: 0.0002771633839475651
# 迭代第 406 次
# 代价函数上一次的差: 0.0002760990409540198
# 迭代第 407 次
# 代价函数上一次的差: 0.0002750406412631301
# 迭代第 408 次
# 代价函数上一次的差: 0.0002739881419498713
# 迭代第 409 次
# 代价函数上一次的差: 0.00027294150046586196
# 迭代第 410 次
# 代价函数上一次的差: 0.00027190067463417344
# 迭代第 411 次
# 代价函数上一次的差: 0.00027086562264730385
# 迭代第 412 次
# 代价函数上一次的差: 0.00026983630306226525
# 迭代第 413 次
# 代价函数上一次的差: 0.0002688126747973085
# 迭代第 414 次
# 代价函数上一次的差: 0.00026779469712776005
# 迭代第 415 次
# 代价函数上一次的差: 0.00026678232968335713
# 迭代第 416 次
# 代价函数上一次的差: 0.00026577553244375163
# 迭代第 417 次
# 代价函数上一次的差: 0.0002647742657355401
# 迭代第 418 次
# 代价函数上一次的差: 0.0002637784902279616
# 迭代第 419 次
# 代价函数上一次的差: 0.00026278816693084406
# 迭代第 420 次
# 代价函数上一次的差: 0.0002618032571897466
# 迭代第 421 次
# 代价函数上一次的差: 0.0002608237226832122
# 迭代第 422 次
# 代价函数上一次的差: 0.0002598495254198252
# 迭代第 423 次
# 代价函数上一次的差: 0.0002588806277339928
# 迭代第 424 次
# 代价函数上一次的差: 0.0002579169922831692
# 迭代第 425 次
# 代价函数上一次的差: 0.0002569585820448306
# 迭代第 426 次
# 代价函数上一次的差: 0.000256005360313033
# 迭代第 427 次
# 代价函数上一次的差: 0.00025505729069499883
# 迭代第 428 次
# 代价函数上一次的差: 0.00025411433710872955
# 迭代第 429 次
# 代价函数上一次的差: 0.0002531764637789813
# 迭代第 430 次
# 代价函数上一次的差: 0.00025224363523471127
# 迭代第 431 次
# 代价函数上一次的差: 0.00025131581630657984
# 迭代第 432 次
# 代价函数上一次的差: 0.0002503929721228426
# 迭代第 433 次
# 代价函数上一次的差: 0.0002494750681069635
# 迭代第 434 次
# 代价函数上一次的差: 0.00024856206997517227
# 迭代第 435 次
# 代价函数上一次的差: 0.00024765394373271743
# 迭代第 436 次
# 代价函数上一次的差: 0.0002467506556714516
# 迭代第 437 次
# 代价函数上一次的差: 0.0002458521723671392
# 迭代第 438 次
# 代价函数上一次的差: 0.00024495846067645877
# 迭代第 439 次
# 代价函数上一次的差: 0.0002440694877340055
# 迭代第 440 次
# 代价函数上一次的差: 0.00024318522095026496
# 迭代第 441 次
# 代价函数上一次的差: 0.00024230562800800493
# 迭代第 442 次
# 代价函数上一次的差: 0.00024143067686055453
# 迭代第 443 次
# 代价函数上一次的差: 0.00024056033572836255
# 迭代第 444 次
# 代价函数上一次的差: 0.0002396945730970823
# 迭代第 445 次
# 代价函数上一次的差: 0.00023883335771388015
# 迭代第 446 次
# 代价函数上一次的差: 0.0002379766585869636
# 迭代第 447 次
# 代价函数上一次的差: 0.00023712444498028007
# 迭代第 448 次
# 代价函数上一次的差: 0.0002362766864132948
# 迭代第 449 次
# 代价函数上一次的差: 0.0002354333526577157
# 迭代第 450 次
# 代价函数上一次的差: 0.0002345944137347733
# 迭代第 451 次
# 代价函数上一次的差: 0.00023375983991327787
# 迭代第 452 次
# 代价函数上一次的差: 0.00023292960170673283
# 迭代第 453 次
# 代价函数上一次的差: 0.0002321036698716139
# 迭代第 454 次
# 代价函数上一次的差: 0.0002312820154044548
# 迭代第 455 次
# 代价函数上一次的差: 0.00023046460954001535
# 迭代第 456 次
# 代价函数上一次的差: 0.00022965142374845038
# 迭代第 457 次
# 代价函数上一次的差: 0.00022884242973369995
# 迭代第 458 次
# 代价函数上一次的差: 0.0002280375994303807
# 迭代第 459 次
# 代价函数上一次的差: 0.0002272369050027867
# 迭代第 460 次
# 代价函数上一次的差: 0.00022644031884155869
# 迭代第 461 次
# 代价函数上一次的差: 0.00022564781356215757
# 迭代第 462 次
# 代价函数上一次的差: 0.00022485936200211665
# 迭代第 463 次
# 代价函数上一次的差: 0.00022407493722048644
# 迭代第 464 次
# 代价函数上一次的差: 0.00022329451249317178
# 迭代第 465 次
# 代价函数上一次的差: 0.0002225180613132649
# 迭代第 466 次
# 代价函数上一次的差: 0.00022174555738796453
# 迭代第 467 次
# 代价函数上一次的差: 0.00022097697463591137
# 迭代第 468 次
# 代价函数上一次的差: 0.0002202122871869383
# 迭代第 469 次
# 代价函数上一次的差: 0.00021945146937824012
# 迭代第 470 次
# 代价函数上一次的差: 0.00021869449575351307
# 迭代第 471 次
# 代价函数上一次的差: 0.00021794134106079
# 迭代第 472 次
# 代价函数上一次的差: 0.0002171919802502753
# 迭代第 473 次
# 代价函数上一次的差: 0.00021644638847247155
# 迭代第 474 次
# 代价函数上一次的差: 0.00021570454107708303
# 迭代第 475 次
# 代价函数上一次的差: 0.0002149664136098517
# 迭代第 476 次
# 代价函数上一次的差: 0.00021423198181164116
# 迭代第 477 次
# 代价函数上一次的差: 0.00021350122161636897
# 迭代第 478 次
# 代价函数上一次的差: 0.0002127741091491192
# 迭代第 479 次
# 代价函数上一次的差: 0.00021205062072464365
# 迭代第 480 次
# 代价函数上一次的差: 0.0002113307328451136
# 迭代第 481 次
# 代价函数上一次的差: 0.00021061442219887094
# 迭代第 482 次
# 代价函数上一次的差: 0.00020990166565866553
# 迭代第 483 次
# 代价函数上一次的差: 0.0002091924402789075
# 迭代第 484 次
# 代价函数上一次的差: 0.00020848672329608353
# 迭代第 485 次
# 代价函数上一次的差: 0.00020778449212507932
# 迭代第 486 次
# 代价函数上一次的差: 0.00020708572435819417
# 迭代第 487 次
# 代价函数上一次的差: 0.00020639039776422508
# 迭代第 488 次
# 代价函数上一次的差: 0.0002056984902856357
# 迭代第 489 次
# 代价函数上一次的差: 0.00020500998003790405
# 迭代第 490 次
# 代价函数上一次的差: 0.00020432484530741313
# 迭代第 491 次
# 代价函数上一次的差: 0.00020364306455010472
# 迭代第 492 次
# 代价函数上一次的差: 0.000202964616389939
# 迭代第 493 次
# 代价函数上一次的差: 0.0002022894796170488
# 迭代第 494 次
# 代价函数上一次的差: 0.00020161763318687909
# 迭代第 495 次
# 代价函数上一次的差: 0.00020094905621777237
# 迭代第 496 次
# 代价函数上一次的差: 0.00020028372799037186
# 迭代第 497 次
# 代价函数上一次的差: 0.00019962162794577576
# 迭代第 498 次
# 代价函数上一次的差: 0.00019896273568342782
# 迭代第 499 次
# 代价函数上一次的差: 0.00019830703096122837
# 迭代第 500 次
# 代价函数上一次的差: 0.00019765449369248123
# 迭代第 501 次
# 代价函数上一次的差: 0.00019700510394550508
# 迭代第 502 次
# 代价函数上一次的差: 0.00019635884194180164
# 迭代第 503 次
# 代价函数上一次的差: 0.00019571568805488992
# 迭代第 504 次
# 代价函数上一次的差: 0.00019507562280847435
# 迭代第 505 次
# 代价函数上一次的差: 0.00019443862687618108
# 迭代第 506 次
# 代价函数上一次的差: 0.00019380468107853266
# 迭代第 507 次
# 代价函数上一次的差: 0.00019317376638326722
# 迭代第 508 次
# 代价函数上一次的差: 0.00019254586390321515
# 迭代第 509 次
# 代价函数上一次的差: 0.00019192095489477257
# 迭代第 510 次
# 代价函数上一次的差: 0.0001912990207573323
# 迭代第 511 次
# 代价函数上一次的差: 0.00019068004303136876
# 迭代第 512 次
# 代价函数上一次的差: 0.0001900640033975498
# 迭代第 513 次
# 代价函数上一次的差: 0.00018945088367544605
# 迭代第 514 次
# 代价函数上一次的差: 0.00018884066582183778
# 迭代第 515 次
# 代价函数上一次的差: 0.00018823333193057623
# 迭代第 516 次
# 代价函数上一次的差: 0.0001876288642299051
# 迭代第 517 次
# 代价函数上一次的差: 0.00018702724508261326
# 迭代第 518 次
# 代价函数上一次的差: 0.00018642845698386978
# 迭代第 519 次
# 代价函数上一次的差: 0.00018583248256062723
# 迭代第 520 次
# 代价函数上一次的差: 0.00018523930457037263
# 迭代第 521 次
# 代价函数上一次的差: 0.00018464890589971195
# 迭代第 522 次
# 代价函数上一次的差: 0.00018406126956325985
# 迭代第 523 次
# 代价函数上一次的差: 0.00018347637870301525
# 迭代第 524 次
# 代价函数上一次的差: 0.00018289421658680693
# 迭代第 525 次
# 代价函数上一次的差: 0.0001823147666068642
# 迭代第 526 次
# 代价函数上一次的差: 0.00018173801227960862
# 迭代第 527 次
# 代价函数上一次的差: 0.00018116393724391944
# 迭代第 528 次
# 代价函数上一次的差: 0.00018059252526002323
# 迭代第 529 次
# 代价函数上一次的差: 0.00018002376020880007
# 迭代第 530 次
# 代价函数上一次的差: 0.00017945762609079818
# 迭代第 531 次
# 代价函数上一次的差: 0.00017889410702449926
# 迭代第 532 次
# 代价函数上一次的差: 0.00017833318724616576
# 迭代第 533 次
# 代价函数上一次的差: 0.00017777485110799518
# 迭代第 534 次
# 代价函数上一次的差: 0.00017721908307795353
# 迭代第 535 次
# 代价函数上一次的差: 0.00017666586773797122
# 迭代第 536 次
# 代价函数上一次的差: 0.0001761151897837071
# 迭代第 537 次
# 代价函数上一次的差: 0.00017556703402273055
# 迭代第 538 次
# 代价函数上一次的差: 0.00017502138537436873
# 迭代第 539 次
# 代价函数上一次的差: 0.00017447822886824949
# 迭代第 540 次
# 代价函数上一次的差: 0.00017393754964341313
# 迭代第 541 次
# 代价函数上一次的差: 0.00017339933294782672
# 迭代第 542 次
# 代价函数上一次的差: 0.00017286356413637183
# 迭代第 543 次
# 代价函数上一次的差: 0.00017233022867114978
# 迭代第 544 次
# 代价函数上一次的差: 0.0001717993121200384
# 迭代第 545 次
# 代价函数上一次的差: 0.00017127080015545693
# 迭代第 546 次
# 代价函数上一次的差: 0.00017074467855408837
# 迭代第 547 次
# 代价函数上一次的差: 0.0001702209331954363
# 迭代第 548 次
# 代价函数上一次的差: 0.0001696995500616305
# 迭代第 549 次
# 代价函数上一次的差: 0.0001691805152355258
# 迭代第 550 次
# 代价函数上一次的差: 0.00016866381490107663
# 迭代第 551 次
# 代价函数上一次的差: 0.00016814943534133875
# 迭代第 552 次
# 代价函数上一次的差: 0.00016763736293844145
# 迭代第 553 次
# 代价函数上一次的差: 0.0001671275841722969
# 迭代第 554 次
# 代价函数上一次的差: 0.00016662008562022546
# 迭代第 555 次
# 代价函数上一次的差: 0.00016611485395524872
# 迭代第 556 次
# 代价函数上一次的差: 0.0001656118759464642
# 迭代第 557 次
# 代价函数上一次的差: 0.00016511113845718572
# 迭代第 558 次
# 代价函数上一次的差: 0.00016461262844509605
# 迭代第 559 次
# 代价函数上一次的差: 0.00016411633296027628
# 迭代第 560 次
# 代价函数上一次的差: 0.00016362223914564988
# 迭代第 561 次
# 代价函数上一次的差: 0.00016313033423549783
# 迭代第 562 次
# 代价函数上一次的差: 0.00016264060555479243
# 迭代第 563 次
# 代价函数上一次的差: 0.00016215304051861446
# 迭代第 564 次
# 代价函数上一次的差: 0.00016166762663118173
# 迭代第 565 次
# 代价函数上一次的差: 0.00016118435148525234
# 迭代第 566 次
# 代价函数上一次的差: 0.00016070320276133365
# 迭代第 567 次
# 代价函数上一次的差: 0.00016022416822703
# 迭代第 568 次
# 代价函数上一次的差: 0.00015974723573602967
# 迭代第 569 次
# 代价函数上一次的差: 0.00015927239322804931
# 迭代第 570 次
# 代价函数上一次的差: 0.00015879962872707154
# 迭代第 571 次
# 代价函数上一次的差: 0.0001583289303418861
# 迭代第 572 次
# 代价函数上一次的差: 0.00015786028626416093
# 迭代第 573 次
# 代价函数上一次的差: 0.0001573936847689139
# 迭代第 574 次
# 代价函数上一次的差: 0.0001569291142127366
# 迭代第 575 次
# 代价函数上一次的差: 0.00015646656303408557
# 迭代第 576 次
# 代价函数上一次的差: 0.00015600601975192252
# 迭代第 577 次
# 代价函数上一次的差: 0.00015554747296525617
# 迭代第 578 次
# 代价函数上一次的差: 0.0001550909113527399
# 迭代第 579 次
# 代价函数上一次的差: 0.0001546363236717696
# 迭代第 580 次
# 代价函数上一次的差: 0.00015418369875754012
# 迭代第 581 次
# 代价函数上一次的差: 0.00015373302552307289
# 迭代第 582 次
# 代价函数上一次的差: 0.00015328429295835555
# 迭代第 583 次
# 代价函数上一次的差: 0.00015283749012924563
# 迭代第 584 次
# 代价函数上一次的差: 0.000152392606177415
# 迭代第 585 次
# 代价函数上一次的差: 0.00015194963031937847
# 迭代第 586 次
# 代价函数上一次的差: 0.00015150855184628553
# 迭代第 587 次
# 代价函数上一次的差: 0.00015106936012289351
# 迭代第 588 次
# 代价函数上一次的差: 0.00015063204458705404
# 迭代第 589 次
# 代价函数上一次的差: 0.00015019659474943547
# 迭代第 590 次
# 代价函数上一次的差: 0.00014976300019248212
# 迭代第 591 次
# 代价函数上一次的差: 0.0001493312505701644
# 迭代第 592 次
# 代价函数上一次的差: 0.00014890133560743757
# 迭代第 593 次
# 代价函数上一次的差: 0.00014847324509890958
# 迭代第 594 次
# 代价函数上一次的差: 0.0001480469689098124
# 迭代第 595 次
# 代价函数上一次的差: 0.0001476224969736012
# 迭代第 596 次
# 代价函数上一次的差: 0.00014719981929307846
# 迭代第 597 次
# 代价函数上一次的差: 0.00014677892593849273
# 迭代第 598 次
# 代价函数上一次的差: 0.00014635980704792717
# 迭代第 599 次
# 代价函数上一次的差: 0.00014594245282623097
# 迭代第 600 次
# 代价函数上一次的差: 0.00014552685354471406
# 迭代第 601 次
# 代价函数上一次的差: 0.00014511299954061974
# 迭代第 602 次
# 代价函数上一次的差: 0.00014470088121644464
# 迭代第 603 次
# 代价函数上一次的差: 0.00014429048903939756
# 迭代第 604 次
# 代价函数上一次的差: 0.00014388181354146878
# 迭代第 605 次
# 代价函数上一次的差: 0.0001434748453178203
# 迭代第 606 次
# 代价函数上一次的差: 0.00014306957502735473
# 迭代第 607 次
# 代价函数上一次的差: 0.00014266599339161912
# 迭代第 608 次
# 代价函数上一次的差: 0.00014226409119437455
# 迭代第 609 次
# 代价函数上一次的差: 0.00014186385928129097
# 迭代第 610 次
# 代价函数上一次的差: 0.00014146528855950302
# 迭代第 611 次
# 代价函数上一次的差: 0.0001410683699962778
# 迭代第 612 次
# 代价函数上一次的差: 0.00014067309462027777
# 迭代第 613 次
# 代价函数上一次的差: 0.0001402794535191043
# 迭代第 614 次
# 代价函数上一次的差: 0.00013988743784031088
# 迭代第 615 次
# 代价函数上一次的差: 0.0001394970387900707
# 迭代第 616 次
# 代价函数上一次的差: 0.0001391082476332739
# 迭代第 617 次
# 代价函数上一次的差: 0.00013872105569258386
# 迭代第 618 次
# 代价函数上一次的差: 0.00013833545434852046
# 迭代第 619 次
# 代价函数上一次的差: 0.00013795143503819718
# 迭代第 620 次
# 代价函数上一次的差: 0.00013756898925587624
# 迭代第 621 次
# 代价函数上一次的差: 0.0001371881085519555
# 迭代第 622 次
# 代价函数上一次的差: 0.00013680878453227463
# 迭代第 623 次
# 代价函数上一次的差: 0.00013643100885840642
# 迭代第 624 次
# 代价函数上一次的差: 0.00013605477324657445
# 迭代第 625 次
# 代价函数上一次的差: 0.00013568006946759747
# 迭代第 626 次
# 代价函数上一次的差: 0.00013530688934647317
# 迭代第 627 次
# 代价函数上一次的差: 0.00013493522476139275
# 迭代第 628 次
# 代价函数上一次的差: 0.00013456506764440712
# 迭代第 629 次
# 代价函数上一次的差: 0.0001341964099798032
# 迭代第 630 次
# 代价函数上一次的差: 0.0001338292438045896
# 迭代第 631 次
# 代价函数上一次的差: 0.0001334635612077889
# 迭代第 632 次
# 代价函数上一次的差: 0.0001330993543298964
# 迭代第 633 次
# 代价函数上一次的差: 0.00013273661536251924
# 迭代第 634 次
# 代价函数上一次的差: 0.00013237533654825162
# 迭代第 635 次
# 代价函数上一次的差: 0.00013201551018025837
# 迭代第 636 次
# 代价函数上一次的差: 0.00013165712860127576
# 迭代第 637 次
# 代价函数上一次的差: 0.00013130018420387524
# 迭代第 638 次
# 代价函数上一次的差: 0.00013094466943028293
# 迭代第 639 次
# 代价函数上一次的差: 0.0001305905767710197
# 迭代第 640 次
# 代价函数上一次的差: 0.00013023789876542846
# 迭代第 641 次
# 代价函数上一次的差: 0.00012988662800110518
# 迭代第 642 次
# 代价函数上一次的差: 0.00012953675711291357
# 迭代第 643 次
# 代价函数上一次的差: 0.00012918827878388717
# 迭代第 644 次
# 代价函数上一次的差: 0.00012884118574361947
# 迭代第 645 次
# 代价函数上一次的差: 0.00012849547076825008
# 迭代第 646 次
# 代价函数上一次的差: 0.00012815112668081163
# 迭代第 647 次
# 代价函数上一次的差: 0.00012780814634982818
# 迭代第 648 次
# 代价函数上一次的差: 0.0001274665226896482
# 迭代第 649 次
# 代价函数上一次的差: 0.0001271262486601532
# 迭代第 650 次
# 代价函数上一次的差: 0.00012678731726563364
# 迭代第 651 次
# 代价函数上一次的差: 0.00012644972155560763
# 迭代第 652 次
# 代价函数上一次的差: 0.00012611345462330836
# 迭代第 653 次
# 代价函数上一次的差: 0.00012577850960644732
# 迭代第 654 次
# 代价函数上一次的差: 0.00012544487968588203
# 迭代第 655 次
# 代价函数上一次的差: 0.0001251125580860879
# 迭代第 656 次
# 代价函数上一次的差: 0.00012478153807432557
# 迭代第 657 次
# 代价函数上一次的差: 0.00012445181296033558
# 迭代第 658 次
# 代价函数上一次的差: 0.00012412337609685187
# 迭代第 659 次
# 代价函数上一次的差: 0.0001237962208778809
# 迭代第 660 次
# 代价函数上一次的差: 0.00012347034073935392
# 迭代第 661 次
# 代价函数上一次的差: 0.0001231457291586413
# 迭代第 662 次
# 代价函数上一次的差: 0.00012282237965435816
# 迭代第 663 次
# 代价函数上一次的差: 0.00012250028578542072
# 迭代第 664 次
# 代价函数上一次的差: 0.0001221794411516708
# 迭代第 665 次
# 代价函数上一次的差: 0.00012185983939283496
# 迭代第 666 次
# 代价函数上一次的差: 0.00012154147418853845
# 迭代第 667 次
# 代价函数上一次的差: 0.00012122433925819409
# 迭代第 668 次
# 代价函数上一次的差: 0.00012090842836025295
# 迭代第 669 次
# 代价函数上一次的差: 0.00012059373529214878
# 迭代第 670 次
# 代价函数上一次的差: 0.00012028025389011765
# 迭代第 671 次
# 代价函数上一次的差: 0.00011996797802885095
# 迭代第 672 次
# 代价函数上一次的差: 0.00011965690162099585
# 迭代第 673 次
# 代价函数上一次的差: 0.00011934701861726627
# 迭代第 674 次
# 代价函数上一次的差: 0.00011903832300565187
# 迭代第 675 次
# 代价函数上一次的差: 0.00011873080881180664
# 迭代第 676 次
# 代价函数上一次的差: 0.00011842447009809132
# 迭代第 677 次
# 代价函数上一次的差: 0.00011811930096378154
# 迭代第 678 次
# 代价函数上一次的差: 0.000117815295544485
# 迭代第 679 次
# 代价函数上一次的差: 0.00011751244801237737
# 迭代第 680 次
# 代价函数上一次的差: 0.00011721075257496716
# 迭代第 681 次
# 代价函数上一次的差: 0.00011691020347612269
# 迭代第 682 次
# 代价函数上一次的差: 0.00011661079499460103
# 迭代第 683 次
# 代价函数上一次的差: 0.00011631252144478355
# 迭代第 684 次
# 代价函数上一次的差: 0.00011601537717551014
# 迭代第 685 次
# 代价函数上一次的差: 0.00011571935657071764
# 迭代第 686 次
# 代价函数上一次的差: 0.00011542445404835733
# 迭代第 687 次
# 代价函数上一次的差: 0.00011513066406071415
# 迭代第 688 次
# 代价函数上一次的差: 0.00011483798109422627
# 迭代第 689 次
# 代价函数上一次的差: 0.0001145463996684859
# 迭代第 690 次
# 代价函数上一次的差: 0.00011425591433691928
# 迭代第 691 次
# 代价函数上一次的差: 0.00011396651968598182
# 迭代第 692 次
# 代价函数上一次的差: 0.00011367821033508863
# 迭代第 693 次
# 代价函数上一次的差: 0.0001133909809362954
# 迭代第 694 次
# 代价函数上一次的差: 0.00011310482617425677
# 迭代第 695 次
# 代价函数上一次的差: 0.00011281974076583767
# 迭代第 696 次
# 代价函数上一次的差: 0.00011253571945973873
# 迭代第 697 次
# 代价函数上一次的差: 0.0001122527570366072
# 迭代第 698 次
# 代价函数上一次的差: 0.00011197084830867621
# 迭代第 699 次
# 代价函数上一次的差: 0.0001116899881193345
# 迭代第 700 次
# 代价函数上一次的差: 0.00011141017134320974
# 迭代第 701 次
# 代价函数上一次的差: 0.00011113139288573826
# 迭代第 702 次
# 代价函数上一次的差: 0.00011085364768292916
# 迭代第 703 次
# 代价函数上一次的差: 0.00011057693070146146
# 迭代第 704 次
# 代价函数上一次的差: 0.00011030123693807348
# 迭代第 705 次
# 代价函数上一次的差: 0.00011002656141938238
# 迭代第 706 次
# 代价函数上一次的差: 0.0001097528992022867
# 迭代第 707 次
# 代价函数上一次的差: 0.00010948024537250911
# 迭代第 708 次
# 代价函数上一次的差: 0.00010920859504599811
# 迭代第 709 次
# 代价函数上一次的差: 0.00010893794336699902
# 迭代第 710 次
# 代价函数上一次的差: 0.00010866828550958052
# 迭代第 711 次
# 代价函数上一次的差: 0.00010839961667589992
# 迭代第 712 次
# 代价函数上一次的差: 0.00010813193209685545
# 迭代第 713 次
# 代价函数上一次的差: 0.00010786522703196133
# 迭代第 714 次
# 代价函数上一次的差: 0.00010759949676852898
# 迭代第 715 次
# 代价函数上一次的差: 0.00010733473662191684
# 迭代第 716 次
# 代价函数上一次的差: 0.00010707094193532218
# 迭代第 717 次
# 代价函数上一次的差: 0.000106808108079684
# 迭代第 718 次
# 代价函数上一次的差: 0.00010654623045272538
# 迭代第 719 次
# 代价函数上一次的差: 0.0001062853044799944
# 迭代第 720 次
# 代价函数上一次的差: 0.00010602532561354572
# 迭代第 721 次
# 代价函数上一次的差: 0.00010576628933256504
# 迭代第 722 次
# 代价函数上一次的差: 0.0001055081911427308
# 迭代第 723 次
# 代价函数上一次的差: 0.00010525102657603369
# 迭代第 724 次
# 代价函数上一次的差: 0.00010499479119079058
# 迭代第 725 次
# 代价函数上一次的差: 0.00010473948057160287
# 迭代第 726 次
# 代价函数上一次的差: 0.00010448509032839892
# 迭代第 727 次
# 代价函数上一次的差: 0.00010423161609748877
# 迭代第 728 次
# 代价函数上一次的差: 0.00010397905354014858
# 迭代第 729 次
# 代价函数上一次的差: 0.00010372739834330069
# 迭代第 730 次
# 代价函数上一次的差: 0.00010347664621888908
# 迭代第 731 次
# 代价函数上一次的差: 0.000103226792903921
# 迭代第 732 次
# 代价函数上一次的差: 0.00010297783416021722
# 迭代第 733 次
# 代价函数上一次的差: 0.00010272976577432869
# 迭代第 734 次
# 代价函数上一次的差: 0.00010248258355698148
# 迭代第 735 次
# 代价函数上一次的差: 0.00010223628334365964
# 迭代第 736 次
# 代价函数上一次的差: 0.00010199086099371701
# 迭代第 737 次
# 代价函数上一次的差: 0.00010174631239047438
# 迭代第 738 次
# 代价函数上一次的差: 0.00010150263344112231
# 迭代第 739 次
# 代价函数上一次的差: 0.00010125982007654077
# 迭代第 740 次
# 代价函数上一次的差: 0.00010101786825107706
# 迭代第 741 次
# 代价函数上一次的差: 0.00010077677394250417
# 迭代第 742 次
# 代价函数上一次的差: 0.00010053653315142408
# 迭代第 743 次
# 代价函数上一次的差: 0.00010029714190186445
# 迭代第 744 次
# 代价函数上一次的差: 0.00010005859624045987
# 迭代第 745 次
# 代价函数上一次的差: 9.982089223664614e-05
# 迭代第 746 次
# 代价函数上一次的差: 9.958402598232718e-05
# 迭代第 747 次
# 代价函数上一次的差: 9.93479935918612e-05
# 迭代第 748 次
# 代价函数上一次的差: 9.911279120188021e-05
# 迭代第 749 次
# 代价函数上一次的差: 9.887841497090155e-05
# 迭代第 750 次
# 代价函数上一次的差: 9.864486107973025e-05
# 迭代第 751 次
# 代价函数上一次的差: 9.841212573052927e-05
# 迭代第 752 次
# 代价函数上一次的差: 9.818020514762438e-05
# 迭代第 753 次
# 代价函数上一次的差: 9.79490955761303e-05
# 迭代第 754 次
# 代价函数上一次的差: 9.771879328338007e-05
# 迭代第 755 次
# 代价函数上一次的差: 9.74892945572875e-05
# 迭代第 756 次
# 代价函数上一次的差: 9.726059570686063e-05
# 迭代第 757 次
# 代价函数上一次的差: 9.70326930623544e-05
# 迭代第 758 次
# 代价函数上一次的差: 9.680558297453512e-05
# 迭代第 759 次
# 代价函数上一次的差: 9.657926181505516e-05
# 迭代第 760 次
# 代价函数上一次的差: 9.635372597570357e-05
# 迭代第 761 次
# 代价函数上一次的差: 9.612897186911384e-05
# 迭代第 762 次
# 代价函数上一次的差: 9.590499592758428e-05
# 迭代第 763 次
# 代价函数上一次的差: 9.568179460411885e-05
# 迭代第 764 次
# 代价函数上一次的差: 9.54593643712337e-05
# 迭代第 765 次
# 代价函数上一次的差: 9.523770172142898e-05
# 迭代第 766 次
# 代价函数上一次的差: 9.501680316689742e-05
# 迭代第 767 次
# 代价函数上一次的差: 9.479666523938557e-05
# 迭代第 768 次
# 代价函数上一次的差: 9.4577284490166e-05
# 迭代第 769 次
# 代价函数上一次的差: 9.435865748956551e-05
# 迭代第 770 次
# 代价函数上一次的差: 9.414078082749244e-05
# 迭代第 771 次
# 代价函数上一次的差: 9.392365111246526e-05
# 迭代第 772 次
# 代价函数上一次的差: 9.370726497215376e-05
# 迭代第 773 次
# 代价函数上一次的差: 9.349161905314318e-05
# 迭代第 774 次
# 代价函数上一次的差: 9.32767100204901e-05
# 迭代第 775 次
# 代价函数上一次的差: 9.306253455781954e-05
# 迭代第 776 次
# 代价函数上一次的差: 9.284908936715852e-05
# 迭代第 777 次
# 代价函数上一次的差: 9.263637116914414e-05
# 迭代第 778 次
# 代价函数上一次的差: 9.242437670226034e-05
# 迭代第 779 次
# 代价函数上一次的差: 9.221310272307381e-05
# 迭代第 780 次
# 代价函数上一次的差: 9.200254600640057e-05
# 迭代第 781 次
# 代价函数上一次的差: 9.179270334445933e-05
# 迭代第 782 次
# 代价函数上一次的差: 9.158357154766261e-05
# 迭代第 783 次
# 代价函数上一次的差: 9.137514744347874e-05
# 迭代第 784 次
# 代价函数上一次的差: 9.116742787748655e-05
# 迭代第 785 次
# 代价函数上一次的差: 9.096040971197372e-05
# 迭代第 786 次
# 代价函数上一次的差: 9.075408982694988e-05
# 迭代第 787 次
# 代价函数上一次的差: 9.054846511946657e-05
# 迭代第 788 次
# 代价函数上一次的差: 9.034353250361726e-05
# 迭代第 789 次
# 代价函数上一次的差: 9.013928891003775e-05
# 迭代第 790 次
# 代价函数上一次的差: 8.993573128691923e-05
# 迭代第 791 次
# 代价函数上一次的差: 8.973285659841235e-05
# 迭代第 792 次
# 代价函数上一次的差: 8.953066182576519e-05
# 迭代第 793 次
# 代价函数上一次的差: 8.932914396639346e-05
# 迭代第 794 次
# 代价函数上一次的差: 8.91283000343801e-05
# 迭代第 795 次
# 代价函数上一次的差: 8.8928127059823e-05
# 迭代第 796 次
# 代价函数上一次的差: 8.872862208900156e-05
# 迭代第 797 次
# 代价函数上一次的差: 8.852978218455709e-05
# 迭代第 798 次
# 代价函数上一次的差: 8.833160442477117e-05
# 迭代第 799 次
# 代价函数上一次的差: 8.813408590378768e-05
# 迭代第 800 次
# 代价函数上一次的差: 8.793722373175161e-05
# 迭代第 801 次
# 代价函数上一次的差: 8.774101503429554e-05
# 迭代第 802 次
# 代价函数上一次的差: 8.754545695253968e-05
# 迭代第 803 次
# 代价函数上一次的差: 8.735054664314734e-05
# 迭代第 804 次
# 代价函数上一次的差: 8.715628127825559e-05
# 迭代第 805 次
# 代价函数上一次的差: 8.696265804496173e-05
# 迭代第 806 次
# 代价函数上一次的差: 8.676967414576742e-05
# 迭代第 807 次
# 代价函数上一次的差: 8.657732679820396e-05
# 迭代第 808 次
# 代价函数上一次的差: 8.638561323458249e-05
# 迭代第 809 次
# 代价函数上一次的差: 8.61945307023132e-05
# 迭代第 810 次
# 代价函数上一次的差: 8.600407646340569e-05
# 迭代第 811 次
# 代价函数上一次的差: 8.581424779482982e-05
# 迭代第 812 次
# 代价函数上一次的差: 8.562504198755816e-05
# 迭代第 813 次
# 代价函数上一次的差: 8.543645634788433e-05
# 迭代第 814 次
# 代价函数上一次的差: 8.524848819572994e-05
# 迭代第 815 次
# 代价函数上一次的差: 8.50611348657132e-05
# 迭代第 816 次
# 代价函数上一次的差: 8.487439370674643e-05
# 迭代第 817 次
# 代价函数上一次的差: 8.468826208157809e-05
# 迭代第 818 次
# 代价函数上一次的差: 8.450273736725078e-05
# 迭代第 819 次
# 代价函数上一次的差: 8.431781695461549e-05
# 迭代第 820 次
# 代价函数上一次的差: 8.413349824849814e-05
# 迭代第 821 次
# 代价函数上一次的差: 8.394977866731101e-05
# 迭代第 822 次
# 代价函数上一次的差: 8.376665564344132e-05
# 迭代第 823 次
# 代价函数上一次的差: 8.358412662252956e-05
# 迭代第 824 次
# 代价函数上一次的差: 8.34021890641079e-05
# 迭代第 825 次
# 代价函数上一次的差: 8.322084044082301e-05
# 迭代第 826 次
# 代价函数上一次的差: 8.304007823894954e-05
# 迭代第 827 次
# 代价函数上一次的差: 8.285989995764076e-05
# 迭代第 828 次
# 代价函数上一次的差: 8.268030310967789e-05
# 迭代第 829 次
# 代价函数上一次的差: 8.250128522063749e-05
# 迭代第 830 次
# 代价函数上一次的差: 8.232284382925226e-05
# 迭代第 831 次
# 代价函数上一次的差: 8.214497648716124e-05
# 迭代第 832 次
# 代价函数上一次的差: 8.196768075881267e-05
# 迭代第 833 次
# 代价函数上一次的差: 8.179095422135296e-05
# 迭代第 834 次
# 代价函数上一次的差: 8.161479446498754e-05
# 迭代第 835 次
# 代价函数上一次的差: 8.143919909199548e-05
# 迭代第 836 次
# 代价函数上一次的差: 8.126416571768713e-05
# 迭代第 837 次
# 代价函数上一次的差: 8.1089691969502e-05
# 迭代第 838 次
# 代价函数上一次的差: 8.091577548755002e-05
# 迭代第 839 次
# 代价函数上一次的差: 8.074241392379278e-05
# 迭代第 840 次
# 代价函数上一次的差: 8.056960494315368e-05
# 迭代第 841 次
# 代价函数上一次的差: 8.039734622181105e-05
# 迭代第 842 次
# 代价函数上一次的差: 8.022563544869687e-05
# 迭代第 843 次
# 代价函数上一次的差: 8.005447032459478e-05
# 迭代第 844 次
# 代价函数上一次的差: 7.988384856198738e-05
# 迭代第 845 次
# 代价函数上一次的差: 7.97137678855836e-05
# 迭代第 846 次
# 代价函数上一次的差: 7.954422603148603e-05
# 迭代第 847 次
# 代价函数上一次的差: 7.937522074778769e-05
# 迭代第 848 次
# 代价函数上一次的差: 7.920674979410014e-05
# 迭代第 849 次
# 代价函数上一次的差: 7.903881094172005e-05
# 迭代第 850 次
# 代价函数上一次的差: 7.887140197325448e-05
# 迭代第 851 次
# 代价函数上一次的差: 7.870452068280132e-05
# 迭代第 852 次
# 代价函数上一次的差: 7.853816487606025e-05
# 迭代第 853 次
# 代价函数上一次的差: 7.837233236958341e-05
# 迭代第 854 次
# 代价函数上一次的差: 7.820702099148313e-05
# 迭代第 855 次
# 代价函数上一次的差: 7.804222858094623e-05
# 迭代第 856 次
# 代价函数上一次的差: 7.787795298806743e-05
# 迭代第 857 次
# 代价函数上一次的差: 7.771419207418251e-05
# 迭代第 858 次
# 代价函数上一次的差: 7.755094371154903e-05
# 迭代第 859 次
# 代价函数上一次的差: 7.738820578305494e-05
# 迭代第 860 次
# 代价函数上一次的差: 7.722597618274596e-05
# 迭代第 861 次
# 代价函数上一次的差: 7.70642528152149e-05
# 迭代第 862 次
# 代价函数上一次的差: 7.690303359582373e-05
# 迭代第 863 次
# 代价函数上一次的差: 7.674231645037055e-05
# 迭代第 864 次
# 代价函数上一次的差: 7.658209931549198e-05
# 迭代第 865 次
# 代价函数上一次的差: 7.642238013813585e-05
# 迭代第 866 次
# 代价函数上一次的差: 7.626315687572771e-05
# 迭代第 867 次
# 代价函数上一次的差: 7.610442749600432e-05
# 迭代第 868 次
# 代价函数上一次的差: 7.594618997715241e-05
# 迭代第 869 次
# 代价函数上一次的差: 7.578844230728132e-05
# 迭代第 870 次
# 代价函数上一次的差: 7.56311824851863e-05
# 迭代第 871 次
# 代价函数上一次的差: 7.547440851915499e-05
# 迭代第 872 次
# 代价函数上一次的差: 7.531811842817482e-05
# 迭代第 873 次
# 代价函数上一次的差: 7.516231024078113e-05
# 迭代第 874 次
# 代价函数上一次的差: 7.500698199558453e-05
# 迭代第 875 次
# 代价函数上一次的差: 7.485213174107663e-05
# 迭代第 876 次
# 代价函数上一次的差: 7.469775753547736e-05
# 迭代第 877 次
# 代价函数上一次的差: 7.454385744704028e-05
# 迭代第 878 次
# 代价函数上一次的差: 7.439042955346975e-05
# 迭代第 879 次
# 代价函数上一次的差: 7.423747194197639e-05
# 迭代第 880 次
# 代价函数上一次的差: 7.408498270981834e-05
# 迭代第 881 次
# 代价函数上一次的差: 7.393295996344085e-05
# 迭代第 882 次
# 代价函数上一次的差: 7.378140181873993e-05
# 迭代第 883 次
# 代价函数上一次的差: 7.36303064012983e-05
# 迭代第 884 次
# 代价函数上一次的差: 7.347967184563597e-05
# 迭代第 885 次
# 代价函数上一次的差: 7.332949629612617e-05
# 迭代第 886 次
# 代价函数上一次的差: 7.317977790589902e-05
# 迭代第 887 次
# 代价函数上一次的差: 7.303051483749379e-05
# 迭代第 888 次
# 代价函数上一次的差: 7.288170526255355e-05
# 迭代第 889 次
# 代价函数上一次的差: 7.27333473619779e-05
# 迭代第 890 次
# 代价函数上一次的差: 7.258543932538164e-05
# 迭代第 891 次
# 代价函数上一次的差: 7.24379793516361e-05
# 迭代第 892 次
# 代价函数上一次的差: 7.229096564820292e-05
# 迭代第 893 次
# 代价函数上一次的差: 7.214439643192516e-05
# 迭代第 894 次
# 代价函数上一次的差: 7.199826992801417e-05
# 迭代第 895 次
# 代价函数上一次的差: 7.185258437063247e-05
# 迭代第 896 次
# 代价函数上一次的差: 7.170733800265783e-05
# 迭代第 897 次
# 代价函数上一次的差: 7.15625290756694e-05
# 迭代第 898 次
# 代价函数上一次的差: 7.14181558496979e-05
# 迭代第 899 次
# 代价函数上一次的差: 7.127421659353095e-05
# 迭代第 900 次
# 代价函数上一次的差: 7.11307095844077e-05
# 迭代第 901 次
# 代价函数上一次的差: 7.098763310800504e-05
# 迭代第 902 次
# 代价函数上一次的差: 7.084498545846529e-05
# 迭代第 903 次
# 代价函数上一次的差: 7.070276493813255e-05
# 迭代第 904 次
# 代价函数上一次的差: 7.056096985794125e-05
# 迭代第 905 次
# 代价函数上一次的差: 7.041959853694435e-05
# 迭代第 906 次
# 代价函数上一次的差: 7.02786493023827e-05
# 迭代第 907 次
# 代价函数上一次的差: 7.013812048968504e-05
# 迭代第 908 次
# 代价函数上一次的差: 6.999801044249576e-05
# 迭代第 909 次
# 代价函数上一次的差: 6.985831751245286e-05
# 迭代第 910 次
# 代价函数上一次的差: 6.971904005924345e-05
# 迭代第 911 次
# 代价函数上一次的差: 6.958017645058989e-05
# 迭代第 912 次
# 代价函数上一次的差: 6.944172506215263e-05
# 迭代第 913 次
# 代价函数上一次的差: 6.930368427736366e-05
# 迭代第 914 次
# 代价函数上一次的差: 6.916605248752372e-05
# 迭代第 915 次
# 代价函数上一次的差: 6.902882809202426e-05
# 迭代第 916 次
# 代价函数上一次的差: 6.889200949755647e-05
# 迭代第 917 次
# 代价函数上一次的差: 6.875559511887452e-05
# 迭代第 918 次
# 代价函数上一次的差: 6.861958337830987e-05
# 迭代第 919 次
# 代价函数上一次的差: 6.848397270574347e-05
# 迭代第 920 次
# 代价函数上一次的差: 6.834876153871683e-05
# 迭代第 921 次
# 代价函数上一次的差: 6.821394832216832e-05
# 迭代第 922 次
# 代价函数上一次的差: 6.807953150886337e-05
# 迭代第 923 次
# 代价函数上一次的差: 6.794550955858958e-05
# 迭代第 924 次
# 代价函数上一次的差: 6.781188093887835e-05
# 迭代第 925 次
# 代价函数上一次的差: 6.76786441244498e-05
# 迭代第 926 次
# 代价函数上一次的差: 6.754579759736534e-05
# 迭代第 927 次
# 代价函数上一次的差: 6.741333984705555e-05
# 迭代第 928 次
# 代价函数上一次的差: 6.728126937018131e-05
# 迭代第 929 次
# 代价函数上一次的差: 6.714958467039789e-05
# 迭代第 930 次
# 代价函数上一次的差: 6.701828425884071e-05
# 迭代第 931 次
# 代价函数上一次的差: 6.688736665347306e-05
# 迭代第 932 次
# 代价函数上一次的差: 6.67568303796412e-05
# 迭代第 933 次
# 代价函数上一次的差: 6.662667396932498e-05
# 迭代第 934 次
# 代价函数上一次的差: 6.649689596191499e-05
# 迭代第 935 次
# 代价函数上一次的差: 6.636749490349092e-05
# 迭代第 936 次
# 代价函数上一次的差: 6.623846934711297e-05
# 迭代第 937 次
# 代价函数上一次的差: 6.610981785284964e-05
# 迭代第 938 次
# 代价函数上一次的差: 6.59815389872781e-05
# 迭代第 939 次
# 代价函数上一次的差: 6.585363132435851e-05
# 迭代第 940 次
# 代价函数上一次的差: 6.572609344397684e-05
# 迭代第 941 次
# 代价函数上一次的差: 6.559892393366573e-05
# 迭代第 942 次
# 代价函数上一次的差: 6.547212138685587e-05
# 迭代第 943 次
# 代价函数上一次的差: 6.534568440427768e-05
# 迭代第 944 次
# 代价函数上一次的差: 6.521961159272616e-05
# 迭代第 945 次
# 代价函数上一次的差: 6.509390156589356e-05
# 迭代第 946 次
# 代价函数上一次的差: 6.496855294396697e-05
# 迭代第 947 次
# 代价函数上一次的差: 6.484356435353111e-05
# 迭代第 948 次
# 代价函数上一次的差: 6.471893442774879e-05
# 迭代第 949 次
# 代价函数上一次的差: 6.459466180612494e-05
# 迭代第 950 次
# 代价函数上一次的差: 6.44707451346177e-05
# 迭代第 951 次
# 代价函数上一次的差: 6.434718306551346e-05
# 迭代第 952 次
# 代价函数上一次的差: 6.422397425742687e-05
# 迭代第 953 次
# 代价函数上一次的差: 6.410111737525925e-05
# 迭代第 954 次
# 代价函数上一次的差: 6.397861109011527e-05
# 迭代第 955 次
# 代价函数上一次的差: 6.385645407949725e-05
# 迭代第 956 次
# 代价函数上一次的差: 6.37346450267362e-05
# 迭代第 957 次
# 代价函数上一次的差: 6.361318262176896e-05
# 迭代第 958 次
# 代价函数上一次的差: 6.349206556019449e-05
# 迭代第 959 次
# 代价函数上一次的差: 6.337129254410656e-05
# 迭代第 960 次
# 代价函数上一次的差: 6.325086228117782e-05
# 迭代第 961 次
# 代价函数上一次的差: 6.313077348554796e-05
# 迭代第 962 次
# 代价函数上一次的差: 6.301102487717147e-05
# 迭代第 963 次
# 代价函数上一次的差: 6.2891615181776e-05
# 迭代第 964 次
# 代价函数上一次的差: 6.277254313112601e-05
# 迭代第 965 次
# 代价函数上一次的差: 6.26538074631755e-05
# 迭代第 966 次
# 代价函数上一次的差: 6.25354069210271e-05
# 迭代第 967 次
# 代价函数上一次的差: 6.241734025433376e-05
# 迭代第 968 次
# 代价函数上一次的差: 6.229960621800812e-05
# 迭代第 969 次
# 代价函数上一次的差: 6.2182203572958e-05
# 迭代第 970 次
# 代价函数上一次的差: 6.206513108593381e-05
# 迭代第 971 次
# 代价函数上一次的差: 6.194838752883458e-05
# 迭代第 972 次
# 代价函数上一次的差: 6.183197167999865e-05
# 迭代第 973 次
# 代价函数上一次的差: 6.171588232276037e-05
# 迭代第 974 次
# 代价函数上一次的差: 6.160011824619949e-05
# 迭代第 975 次
# 代价函数上一次的差: 6.148467824523829e-05
# 迭代第 976 次
# 代价函数上一次的差: 6.136956111998937e-05
# 迭代第 977 次
# 代价函数上一次的差: 6.125476567628296e-05
# 迭代第 978 次
# 代价函数上一次的差: 6.114029072515348e-05
# 迭代第 979 次
# 代价函数上一次的差: 6.1026135083588895e-05
# 迭代第 980 次
# 代价函数上一次的差: 6.091229757339278e-05
# 迭代第 981 次
# 代价函数上一次的差: 6.0798777022294526e-05
# 迭代第 982 次
# 代价函数上一次的差: 6.068557226281135e-05
# 迭代第 983 次
# 代价函数上一次的差: 6.057268213334466e-05
# 迭代第 984 次
# 代价函数上一次的差: 6.04601054772641e-05
# 迭代第 985 次
# 代价函数上一次的差: 6.0347841143310044e-05
# 迭代第 986 次
# 代价函数上一次的差: 6.023588798539925e-05
# 迭代第 987 次
# 代价函数上一次的差: 6.0124244862708176e-05
# 迭代第 988 次
# 代价函数上一次的差: 6.001291063972847e-05
# 迭代第 989 次
# 代价函数上一次的差: 5.990188418579512e-05
# 迭代第 990 次
# 代价函数上一次的差: 5.9791164375558314e-05
# 迭代第 991 次
# 代价函数上一次的差: 5.968075008896956e-05
# 迭代第 992 次
# 代价函数上一次的差: 5.957064021068492e-05
# 迭代第 993 次
# 代价函数上一次的差: 5.946083363048138e-05
# 迭代第 994 次
# 代价函数上一次的差: 5.9351329243423345e-05
# 迭代第 995 次
# 代价函数上一次的差: 5.9242125949307556e-05
# 迭代第 996 次
# 代价函数上一次的差: 5.913322265284349e-05
# 迭代第 997 次
# 代价函数上一次的差: 5.902461826408356e-05
# 迭代第 998 次
# 代价函数上一次的差: 5.891631169747946e-05
# 迭代第 999 次
# 代价函数上一次的差: 5.880830187264541e-05
# 迭代第 1000 次
# 代价函数上一次的差: 5.8700587714094477e-05
# 迭代第 1001 次
# 代价函数上一次的差: 5.859316815104432e-05
# 迭代第 1002 次
# 代价函数上一次的差: 5.848604211751429e-05
# 迭代第 1003 次
# 代价函数上一次的差: 5.837920855239487e-05
# 迭代第 1004 次
# 代价函数上一次的差: 5.827266639930884e-05
# 迭代第 1005 次
# 代价函数上一次的差: 5.8166414606555805e-05
# 迭代第 1006 次
# 代价函数上一次的差: 5.8060452127237094e-05
# 迭代第 1007 次
# 代价函数上一次的差: 5.795477791900594e-05
# 迭代第 1008 次
# 代价函数上一次的差: 5.784939094433117e-05
# 迭代第 1009 次
# 代价函数上一次的差: 5.774429017006699e-05
# 迭代第 1010 次
# 代价函数上一次的差: 5.763947456793872e-05
# 迭代第 1011 次
# 代价函数上一次的差: 5.753494311414031e-05
# 迭代第 1012 次
# 代价函数上一次的差: 5.743069478947316e-05
# 迭代第 1013 次
# 代价函数上一次的差: 5.7326728579096264e-05
# 迭代第 1014 次
# 代价函数上一次的差: 5.7223043472803825e-05
# 迭代第 1015 次
# 代价函数上一次的差: 5.71196384650946e-05
# 迭代第 1016 次
# 代价函数上一次的差: 5.701651255442253e-05
# 迭代第 1017 次
# 代价函数上一次的差: 5.6913664744182024e-05
# 迭代第 1018 次
# 代价函数上一次的差: 5.681109404170881e-05
# 迭代第 1019 次
# 代价函数上一次的差: 5.67087994594595e-05
# 迭代第 1020 次
# 代价函数上一次的差: 5.6606780013207514e-05
# 迭代第 1021 次
# 代价函数上一次的差: 5.6505034724124714e-05
# 迭代第 1022 次
# 代价函数上一次的差: 5.6403562616949565e-05
# 迭代第 1023 次
# 代价函数上一次的差: 5.63023627211251e-05
# 迭代第 1024 次
# 代价函数上一次的差: 5.6201434070174416e-05
# 迭代第 1025 次
# 代价函数上一次的差: 5.6100775702047634e-05
# 迭代第 1026 次
# 代价函数上一次的差: 5.600038665874718e-05
# 迭代第 1027 次
# 代价函数上一次的差: 5.5900265986674746e-05
# 迭代第 1028 次
# 代价函数上一次的差: 5.580041273606229e-05
# 迭代第 1029 次
# 代价函数上一次的差: 5.5700825961846334e-05
# 迭代第 1030 次
# 代价函数上一次的差: 5.560150472275205e-05
# 迭代第 1031 次
# 代价函数上一次的差: 5.550244808147364e-05
# 迭代第 1032 次
# 代价函数上一次的差: 5.5403655105382144e-05
# 迭代第 1033 次
# 代价函数上一次的差: 5.5305124865248634e-05
# 迭代第 1034 次
# 代价函数上一次的差: 5.520685643647938e-05
# 迭代第 1035 次
# 代价函数上一次的差: 5.510884889807499e-05
# 迭代第 1036 次
# 代价函数上一次的差: 5.501110133337983e-05
# 迭代第 1037 次
# 代价函数上一次的差: 5.491361282952689e-05
# 迭代第 1038 次
# 代价函数上一次的差: 5.4816382477757e-05
# 迭代第 1039 次
# 代价函数上一次的差: 5.4719409373099603e-05
# 迭代第 1040 次
# 代价函数上一次的差: 5.462269261477526e-05
# 迭代第 1041 次
# 代价函数上一次的差: 5.4526231305571105e-05
# 迭代第 1042 次
# 代价函数上一次的差: 5.443002455256252e-05
# 迭代第 1043 次
# 代价函数上一次的差: 5.433407146637759e-05
# 迭代第 1044 次
# 代价函数上一次的差: 5.423837116164121e-05
# 迭代第 1045 次
# 代价函数上一次的差: 5.414292275675303e-05
# 迭代第 1046 次
# 代价函数上一次的差: 5.4047725374081756e-05
# 迭代第 1047 次
# 代价函数上一次的差: 5.3952778139562674e-05
# 迭代第 1048 次
# 代价函数上一次的差: 5.38580801829891e-05
# 迭代第 1049 次
# 代价函数上一次的差: 5.376363063804013e-05
# 迭代第 1050 次
# 代价函数上一次的差: 5.366942864194757e-05
# 迭代第 1051 次
# 代价函数上一次的差: 5.3575473335704116e-05
# 迭代第 1052 次
# 代价函数上一次的差: 5.348176386417436e-05
# 迭代第 1053 次
# 代价函数上一次的差: 5.338829937554662e-05
# 迭代第 1054 次
# 代价函数上一次的差: 5.329507902208236e-05
# 迭代第 1055 次
# 代价函数上一次的差: 5.3202101959352877e-05
# 迭代第 1056 次
# 代价函数上一次的差: 5.310936734669036e-05
# 迭代第 1057 次
# 代价函数上一次的差: 5.3016874347104614e-05
# 迭代第 1058 次
# 代价函数上一次的差: 5.2924622126991616e-05
# 迭代第 1059 次
# 代价函数上一次的差: 5.28326098565568e-05
# 迭代第 1060 次
# 代价函数上一次的差: 5.274083670927382e-05
# 迭代第 1061 次
# 代价函数上一次的差: 5.264930186248823e-05
# 迭代第 1062 次
# 代价函数上一次的差: 5.255800449665421e-05
# 迭代第 1063 次
# 代价函数上一次的差: 5.2466943796028453e-05
# 迭代第 1064 次
# 代价函数上一次的差: 5.2376118948448125e-05
# 迭代第 1065 次
# 代价函数上一次的差: 5.2285529144636966e-05
# 迭代第 1066 次
# 代价函数上一次的差: 5.219517357944736e-05
# 迭代第 1067 次
# 代价函数上一次的差: 5.2105051450701545e-05
# 迭代第 1068 次
# 代价函数上一次的差: 5.201516195982303e-05
# 迭代第 1069 次
# 代价函数上一次的差: 5.192550431155213e-05
# 迭代第 1070 次
# 代价函数上一次的差: 5.18360777140639e-05
# 迭代第 1071 次
# 代价函数上一次的差: 5.174688137882938e-05
# 迭代第 1072 次
# 代价函数上一次的差: 5.165791452065027e-05
# 迭代第 1073 次
# 代价函数上一次的差: 5.156917635774222e-05
# 迭代第 1074 次
# 代价函数上一次的差: 5.148066611151275e-05
# 迭代第 1075 次
# 代价函数上一次的差: 5.139238300671395e-05
# 迭代第 1076 次
# 代价函数上一次的差: 5.1304326271442435e-05
# 迭代第 1077 次
# 代价函数上一次的差: 5.121649513683407e-05
# 迭代第 1078 次
# 代价函数上一次的差: 5.112888883756356e-05
# 迭代第 1079 次
# 代价函数上一次的差: 5.1041506611261556e-05
# 迭代第 1080 次
# 代价函数上一次的差: 5.095434769889634e-05
# 迭代第 1081 次
# 代价函数上一次的差: 5.08674113446142e-05
# 迭代第 1082 次
# 代价函数上一次的差: 5.078069679574637e-05
# 迭代第 1083 次
# 代价函数上一次的差: 5.069420330267721e-05
# 迭代第 1084 次
# 代价函数上一次的差: 5.060793011915643e-05
# 迭代第 1085 次
# 代价函数上一次的差: 5.0521876501778695e-05
# 迭代第 1086 次
# 代价函数上一次的差: 5.0436041710483215e-05
# 迭代第 1087 次
# 代价函数上一次的差: 5.0350425008234556e-05
# 迭代第 1088 次
# 代价函数上一次的差: 5.026502566098795e-05
# 迭代第 1089 次
# 代价函数上一次的差: 5.017984293793215e-05
# 迭代第 1090 次
# 代价函数上一次的差: 5.009487611105923e-05
# 迭代第 1091 次
# 代价函数上一次的差: 5.001012445574049e-05
# 迭代第 1092 次
# 代价函数上一次的差: 4.992558725004648e-05
# 迭代第 1093 次
# 代价函数上一次的差: 4.9841263775211864e-05
# 迭代第 1094 次
# 代价函数上一次的差: 4.975715331537178e-05
# 迭代第 1095 次
# 代价函数上一次的差: 4.967325515789489e-05
# 迭代第 1096 次
# 代价函数上一次的差: 4.958956859268254e-05
# 迭代第 1097 次
# 代价函数上一次的差: 4.950609291288349e-05
# 迭代第 1098 次
# 代价函数上一次的差: 4.942282741465104e-05
# 迭代第 1099 次
# 代价函数上一次的差: 4.933977139667117e-05
# 迭代第 1100 次
# 代价函数上一次的差: 4.9256924160918925e-05
# 迭代第 1101 次
# 代价函数上一次的差: 4.9174285012061614e-05
# 迭代第 1102 次
# 代价函数上一次的差: 4.909185325775722e-05
# 迭代第 1103 次
# 代价函数上一次的差: 4.900962820833521e-05
# 迭代第 1104 次
# 代价函数上一次的差: 4.892760917721284e-05
# 迭代第 1105 次
# 代价函数上一次的差: 4.884579548035395e-05
# 迭代第 1106 次
# 代价函数上一次的差: 4.87641864369559e-05
# 迭代第 1107 次
# 代价函数上一次的差: 4.8682781368540595e-05
# 迭代第 1108 次
# 代价函数上一次的差: 4.860157959967609e-05
# 迭代第 1109 次
# 代价函数上一次的差: 4.8520580457858675e-05
# 迭代第 1110 次
# 代价函数上一次的差: 4.843978327287446e-05
# 迭代第 1111 次
# 代价函数上一次的差: 4.835918737777778e-05
# 迭代第 1112 次
# 代价函数上一次的差: 4.827879210811403e-05
# ...
# 迭代第 2203 次
# 代价函数上一次的差: 1.3295846611860451e-05
# 迭代第 2204 次
# 代价函数上一次的差: 1.3284317513705124e-05
# 迭代第 2205 次
# 代价函数上一次的差: 1.3272803508650177e-05
# 迭代第 2206 次
# 代价函数上一次的差: 1.3261304570383325e-05
# 迭代第 2207 次
# 代价函数上一次的差: 1.3249820672515955e-05
# 迭代第 2208 次
# 代价函数上一次的差: 1.3238351788777414e-05
# 迭代第 2209 次
# 代价函数上一次的差: 1.3226897893098277e-05
# 迭代第 2210 次
# 代价函数上一次的差: 1.321545895922871e-05
# 迭代第 2211 次
# 代价函数上一次的差: 1.3204034961182554e-05
# 迭代第 2212 次
# 代价函数上一次的差: 1.3192625872848751e-05
# 迭代第 2213 次
# 代价函数上一次的差: 1.3181231668386861e-05
# 迭代第 2214 次
# 代价函数上一次的差: 1.3169852321782971e-05
# 迭代第 2215 次
# 代价函数上一次的差: 1.3158487807231334e-05
# 迭代第 2216 次
# 代价函数上一次的差: 1.314713809894702e-05
# 迭代第 2217 次
# 代价函数上一次的差: 1.31358031711451e-05
# 迭代第 2218 次
# 代价函数上一次的差: 1.3124482998276565e-05
# 迭代第 2219 次
# 代价函数上一次的差: 1.311317755454261e-05
# 迭代第 2220 次
# 代价函数上一次的差: 1.3101886814533004e-05
# 迭代第 2221 次
# 代价函数上一次的差: 1.3090610752559961e-05
# 迭代第 2222 次
# 代价函数上一次的差: 1.307934934335897e-05
# 迭代第 2223 次
# 代价函数上一次的差: 1.3068102561360206e-05
# 迭代第 2224 次
# 代价函数上一次的差: 1.3056870381292218e-05
# 迭代第 2225 次
# 代价函数上一次的差: 1.3045652777918249e-05
# 迭代第 2226 次
# 代价函数上一次的差: 1.3034449725904396e-05
# 迭代第 2227 次
# 代价函数上一次的差: 1.3023261200048597e-05
# 迭代第 2228 次
# 代价函数上一次的差: 1.3012087175329201e-05
# 迭代第 2229 次
# 代价函数上一次的差: 1.3000927626599657e-05
# 迭代第 2230 次
# 代价函数上一次的差: 1.2989782528824434e-05
# 迭代第 2231 次
# 代价函数上一次的差: 1.2978651857085965e-05
# 迭代第 2232 次
# 代价函数上一次的差: 1.2967535586459744e-05
# 迭代第 2233 次
# 代价函数上一次的差: 1.2956433692049019e-05
# 迭代第 2234 次
# 代价函数上一次的差: 1.2945346149061121e-05
# 迭代第 2235 次
# 代价函数上一次的差: 1.2934272932793589e-05
# 迭代第 2236 次
# 代价函数上一次的差: 1.292321401848845e-05
# 迭代第 2237 次
# 代价函数上一次的差: 1.2912169381491811e-05
# 迭代第 2238 次
# 代价函数上一次的差: 1.2901138997260808e-05
# 迭代第 2239 次
# 代价函数上一次的差: 1.289012284126645e-05
# 迭代第 2240 次
# 代价函数上一次的差: 1.2879120888917295e-05
# 迭代第 2241 次
# 代价函数上一次的差: 1.2868133115878644e-05
# 迭代第 2242 次
# 代价函数上一次的差: 1.2857159497732529e-05
# 迭代第 2243 次
# 代价函数上一次的差: 1.2846200010165065e-05
# 迭代第 2244 次
# 代价函数上一次的差: 1.283525462886237e-05
# 迭代第 2245 次
# 代价函数上一次的差: 1.2824323329628518e-05
# 迭代第 2246 次
# 代价函数上一次的差: 1.2813406088295343e-05
# 迭代第 2247 次
# 代价函数上一次的差: 1.2802502880701616e-05
# 迭代第 2248 次
# 代价函数上一次的差: 1.2791613682824887e-05
# 迭代第 2249 次
# 代价函数上一次的差: 1.2780738470587194e-05
# 迭代第 2250 次
# 代价函数上一次的差: 1.276987722012915e-05
# 迭代第 2251 次
# 代价函数上一次的差: 1.275902990739708e-05
# 迭代第 2252 次
# 代价函数上一次的差: 1.274819650862527e-05
# 迭代第 2253 次
# 代价函数上一次的差: 1.2737376999950867e-05
# 迭代第 2254 次
# 代价函数上一次的差: 1.2726571357618566e-05
# 迭代第 2255 次
# 代价函数上一次的差: 1.271577955795633e-05
# 迭代第 2256 次
# 代价函数上一次的差: 1.2705001577240083e-05
# 迭代第 2257 次
# 代价函数上一次的差: 1.2694237391856766e-05
# 迭代第 2258 次
# 代价函数上一次的差: 1.2683486978370268e-05
# 迭代第 2259 次
# 代价函数上一次的差: 1.2672750313112019e-05
# 迭代第 2260 次
# 代价函数上一次的差: 1.2662027372663254e-05
# 迭代第 2261 次
# 代价函数上一次的差: 1.2651318133674594e-05
# 迭代第 2262 次
# 代价函数上一次的差: 1.2640622572786253e-05
# 迭代第 2263 次
# 代价函数上一次的差: 1.2629940666551709e-05
# 迭代第 2264 次
# 代价函数上一次的差: 1.2619272391885261e-05
# 迭代第 2265 次
# 代价函数上一次的差: 1.2608617725416715e-05
# 迭代第 2266 次
# 代价函数上一次的差: 1.259797664412629e-05
# 迭代第 2267 次
# 代价函数上一次的差: 1.2587349124817265e-05
# 迭代第 2268 次
# 代价函数上一次的差: 1.2576735144497614e-05
# 迭代第 2269 次
# 代价函数上一次的差: 1.2566134679977553e-05
# 迭代第 2270 次
# 代价函数上一次的差: 1.2555547708525266e-05
# 迭代第 2271 次
# 代价函数上一次的差: 1.2544974207061993e-05
# 迭代第 2272 次
# 代价函数上一次的差: 1.2534414152789997e-05
# 迭代第 2273 次
# 代价函数上一次的差: 1.2523867522824805e-05
# 迭代第 2274 次
# 代价函数上一次的差: 1.2513334294483175e-05
# 迭代第 2275 次
# 代价函数上一次的差: 1.2502814444936144e-05
# 迭代第 2276 次
# 代价函数上一次的差: 1.2492307951618431e-05
# 迭代第 2277 次
# 代价函数上一次的差: 1.2481814791801688e-05
# 迭代第 2278 次
# 代价函数上一次的差: 1.2471334943014306e-05
# 迭代第 2279 次
# 代价函数上一次的差: 1.2460868382611207e-05
# 迭代第 2280 次
# 代价函数上一次的差: 1.2450415088148536e-05
# 迭代第 2281 次
# 代价函数上一次的差: 1.243997503726571e-05
# 迭代第 2282 次
# 代价函数上一次的差: 1.2429548207456426e-05
# 迭代第 2283 次
# 代价函数上一次的差: 1.2419134576457241e-05
# 迭代第 2284 次
# 代价函数上一次的差: 1.2408734121893694e-05
# 迭代第 2285 次
# 代价函数上一次的差: 1.2398346821620304e-05
# 迭代第 2286 次
# 代价函数上一次的差: 1.2387972653366691e-05
# 迭代第 2287 次
# 代价函数上一次的差: 1.2377611595008192e-05
# 迭代第 2288 次
# 代价函数上一次的差: 1.2367263624402797e-05
# 迭代第 2289 次
# 代价函数上一次的差: 1.2356928719536864e-05
# 迭代第 2290 次
# 代价函数上一次的差: 1.2346606858296139e-05
# 迭代第 2291 次
# 代价函数上一次的差: 1.2336298018882086e-05
# 迭代第 2292 次
# 代价函数上一次的差: 1.2326002179242901e-05
# 迭代第 2293 次
# 代价函数上一次的差: 1.2315719317524537e-05
# 迭代第 2294 次
# 代价函数上一次的差: 1.2305449411886826e-05
# 迭代第 2295 次
# 代价函数上一次的差: 1.2295192440600622e-05
# 迭代第 2296 次
# 代价函数上一次的差: 1.2284948381877797e-05
# 迭代第 2297 次
# 代价函数上一次的差: 1.2274717214051656e-05
# 迭代第 2298 次
# 代价函数上一次的差: 1.2264498915445093e-05
# 迭代第 2299 次
# 代价函数上一次的差: 1.2254293464439986e-05
# 迭代第 2300 次
# 代价函数上一次的差: 1.2244100839636785e-05
# 迭代第 2301 次
# 代价函数上一次的差: 1.2233921019243893e-05
# 迭代第 2302 次
# 代价函数上一次的差: 1.222375398206299e-05
# 迭代第 2303 次
# 代价函数上一次的差: 1.2213599706517586e-05
# 迭代第 2304 次
# 代价函数上一次的差: 1.2203458171260173e-05
# 迭代第 2305 次
# 代价函数上一次的差: 1.219332935497447e-05
# 迭代第 2306 次
# 代价函数上一次的差: 1.218321323642399e-05
# 迭代第 2307 次
# 代价函数上一次的差: 1.2173109794209186e-05
# 迭代第 2308 次
# 代价函数上一次的差: 1.2163019007346842e-05
# 迭代第 2309 次
# 代价函数上一次的差: 1.21529408545068e-05
# 迭代第 2310 次
# 代价函数上一次的差: 1.2142875314632984e-05
# 迭代第 2311 次
# 代价函数上一次的差: 1.2132822366710955e-05
# 迭代第 2312 次
# 代价函数上一次的差: 1.2122781989625658e-05
# 迭代第 2313 次
# 代价函数上一次的差: 1.2112754162487555e-05
# 迭代第 2314 次
# 代价函数上一次的差: 1.210273886430649e-05
# 迭代第 2315 次
# 代价函数上一次的差: 1.2092736074192922e-05
# 迭代第 2316 次
# 代价函数上一次的差: 1.2082745771371806e-05
# 迭代第 2317 次
# 代价函数上一次的差: 1.2072767934898088e-05
# 迭代第 2318 次
# 代价函数上一次的差: 1.2062802544149376e-05
# 迭代第 2319 次
# 代价函数上一次的差: 1.2052849578340213e-05
# 迭代第 2320 次
# 代价函数上一次的差: 1.2042909016796166e-05
# 迭代第 2321 次
# 代价函数上一次的差: 1.203298083889831e-05
# 迭代第 2322 次
# 代价函数上一次的差: 1.2023065024062418e-05
# 迭代第 2323 次
# 代价函数上一次的差: 1.2013161551752832e-05
# 迭代第 2324 次
# 代价函数上一次的差: 1.2003270401440835e-05
# 迭代第 2325 次
# 代价函数上一次的差: 1.1993391552635874e-05
# 迭代第 2326 次
# 代价函数上一次的差: 1.1983524985020866e-05
# 迭代第 2327 次
# 代价函数上一次的差: 1.1973670678108728e-05
# 迭代第 2328 次
# 代价函数上一次的差: 1.1963828611637889e-05
# 迭代第 2329 次
# 代价函数上一次的差: 1.1953998765253104e-05
# 迭代第 2330 次
# 代价函数上一次的差: 1.1944181118814234e-05
# 迭代第 2331 次
# 代价函数上一次的差: 1.1934375651997259e-05
# 迭代第 2332 次
# 代价函数上一次的差: 1.1924582344679385e-05
# 迭代第 2333 次
# 代价函数上一次的差: 1.19148011767517e-05
# 迭代第 2334 次
# 代价函数上一次的差: 1.1905032128108756e-05
# 迭代第 2335 次
# 代价函数上一次的差: 1.189527517870409e-05
# 迭代第 2336 次
# 代价函数上一次的差: 1.1885530308581443e-05
# 迭代第 2337 次
# 代价函数上一次的差: 1.1875797497722107e-05
# 迭代第 2338 次
# 代价函数上一次的差: 1.186607672630513e-05
# 迭代第 2339 次
# 代价函数上一次的差: 1.1856367974284049e-05
# 迭代第 2340 次
# 代价函数上一次的差: 1.1846671222007915e-05
# 迭代第 2341 次
# 代价函数上一次的差: 1.1836986449575981e-05
# 迭代第 2342 次
# 代价函数上一次的差: 1.1827313637260972e-05
# 迭代第 2343 次
# 代价函数上一次的差: 1.1817652765339082e-05
# 迭代第 2344 次
# 代价函数上一次的差: 1.1808003814155893e-05
# 迭代第 2345 次
# 代价函数上一次的差: 1.179836676410903e-05
# 迭代第 2346 次
# 代价函数上一次的差: 1.178874159547122e-05
# 迭代第 2347 次
# 代价函数上一次的差: 1.1779128288893354e-05
# 迭代第 2348 次
# 代价函数上一次的差: 1.1769526824689791e-05
# 迭代第 2349 次
# 代价函数上一次的差: 1.1759937183514896e-05
# 迭代第 2350 次
# 代价函数上一次的差: 1.175035934584609e-05
# 迭代第 2351 次
# 代价函数上一次的差: 1.1740793292327328e-05
# 迭代第 2352 次
# 代价函数上一次的差: 1.1731239003612975e-05
# 迭代第 2353 次
# 代价函数上一次的差: 1.1721696460402498e-05
# 迭代第 2354 次
# 代价函数上一次的差: 1.1712165643364136e-05
# 迭代第 2355 次
# 代价函数上一次的差: 1.1702646533367361e-05
# 迭代第 2356 次
# 代价函数上一次的差: 1.1693139111132456e-05
# 迭代第 2357 次
# 代价函数上一次的差: 1.1683643357535828e-05
# 迭代第 2358 次
# 代价函数上一次的差: 1.1674159253450417e-05
# 迭代第 2359 次
# 代价函数上一次的差: 1.1664686779839367e-05
# 迭代第 2360 次
# 代价函数上一次的差: 1.1655225917589496e-05
# 迭代第 2361 次
# 代价函数上一次的差: 1.1645776647747214e-05
# 迭代第 2362 次
# 代价函数上一次的差: 1.1636338951424852e-05
# 迭代第 2363 次
# 代价函数上一次的差: 1.1626912809599432e-05
# 迭代第 2364 次
# 代价函数上一次的差: 1.1617498203407572e-05
# 迭代第 2365 次
# 代价函数上一次的差: 1.1608095114027522e-05
# 迭代第 2366 次
# 代价函数上一次的差: 1.159870352265488e-05
# 迭代第 2367 次
# 代价函数上一次的差: 1.1589323410519936e-05
# 迭代第 2368 次
# 代价函数上一次的差: 1.1579954758901556e-05
# 迭代第 2369 次
# 代价函数上一次的差: 1.157059754909942e-05
# 迭代第 2370 次
# 代价函数上一次的差: 1.1561251762468722e-05
# 迭代第 2371 次
# 代价函数上一次的差: 1.1551917380361182e-05
# 迭代第 2372 次
# 代价函数上一次的差: 1.154259438421526e-05
# 迭代第 2373 次
# 代价函数上一次的差: 1.1533282755608193e-05
# 迭代第 2374 次
# 代价函数上一次的差: 1.152398247585354e-05
# 迭代第 2375 次
# 代价函数上一次的差: 1.151469352656323e-05
# 迭代第 2376 次
# 代价函数上一次的差: 1.150541588938736e-05
# 迭代第 2377 次
# 代价函数上一次的差: 1.1496149545830309e-05
# 迭代第 2378 次
# 代价函数上一次的差: 1.1486894477618498e-05
# 迭代第 2379 次
# 代价函数上一次的差: 1.1477650666377737e-05
# 迭代第 2380 次
# 代价函数上一次的差: 1.1468418093858734e-05
# 迭代第 2381 次
# 代价函数上一次的差: 1.1459196741836486e-05
# 迭代第 2382 次
# 代价函数上一次的差: 1.1449986592075578e-05
# 迭代第 2383 次
# 代价函数上一次的差: 1.1440787626479376e-05
# 迭代第 2384 次
# 代价函数上一次的差: 1.1431599826808997e-05
# 迭代第 2385 次
# 代价函数上一次的差: 1.1422423175092705e-05
# 迭代第 2386 次
# 代价函数上一次的差: 1.1413257653185294e-05
# 迭代第 2387 次
# 代价函数上一次的差: 1.140410324309074e-05
# 迭代第 2388 次
# 代价函数上一次的差: 1.139495992684772e-05
# 迭代第 2389 次
# 代价函数上一次的差: 1.138582768651572e-05
# 迭代第 2390 次
# 代价函数上一次的差: 1.1376706504133416e-05
# 迭代第 2391 次
# 代价函数上一次的差: 1.1367596361892135e-05
# 迭代第 2392 次
# 代价函数上一次的差: 1.1358497241913817e-05
# 迭代第 2393 次
# 代价函数上一次的差: 1.1349409126410609e-05
# 迭代第 2394 次
# 代价函数上一次的差: 1.1340331997653635e-05
# 迭代第 2395 次
# 代价函数上一次的差: 1.1331265837792592e-05
# 迭代第 2396 次
# 代价函数上一次的差: 1.1322210629296364e-05
# 迭代第 2397 次
# 代价函数上一次的差: 1.1313166354345872e-05
# 迭代第 2398 次
# 代价函数上一次的差: 1.1304132995486327e-05
# 迭代第 2399 次
# 代价函数上一次的差: 1.129511053496457e-05
# 迭代第 2400 次
# 代价函数上一次的差: 1.1286098955398671e-05
# 迭代第 2401 次
# 代价函数上一次的差: 1.1277098239073635e-05
# 迭代第 2402 次
# 代价函数上一次的差: 1.1268108368694268e-05
# 迭代第 2403 次
# 代价函数上一次的差: 1.1259129326663536e-05
# 迭代第 2404 次
# 代价函数上一次的差: 1.125016109571747e-05
# 迭代第 2405 次
# 代价函数上一次的差: 1.124120365835965e-05
# 迭代第 2406 次
# 代价函数上一次的差: 1.1232256997350393e-05
# 迭代第 2407 次
# 代价函数上一次的差: 1.1223321095266137e-05
# 迭代第 2408 次
# 代价函数上一次的差: 1.1214395934936588e-05
# 迭代第 2409 次
# 代价函数上一次的差: 1.1205481499056147e-05
# 迭代第 2410 次
# 代价函数上一次的差: 1.1196577770430233e-05
# 迭代第 2411 次
# 代价函数上一次的差: 1.1187684731957942e-05
# 迭代第 2412 次
# 代价函数上一次的差: 1.1178802366472451e-05
# 迭代第 2413 次
# 代价函数上一次的差: 1.1169930656793059e-05
# 迭代第 2414 次
# 代价函数上一次的差: 1.1161069585999273e-05
# 迭代第 2415 次
# 代价函数上一次的差: 1.1152219136896513e-05
# 迭代第 2416 次
# 代价函数上一次的差: 1.1143379292654493e-05
# 迭代第 2417 次
# 代价函数上一次的差: 1.113455003622435e-05
# 迭代第 2418 次
# 代价函数上一次的差: 1.1125731350609264e-05
# 迭代第 2419 次
# 代价函数上一次的差: 1.1116923219062214e-05
# 迭代第 2420 次
# 代价函数上一次的差: 1.1108125624621074e-05
# 迭代第 2421 次
# 代价函数上一次的差: 1.1099338550518006e-05
# 迭代第 2422 次
# 代价函数上一次的差: 1.1090561979860275e-05
# 迭代第 2423 次
# 代价函数上一次的差: 1.108179589595984e-05
# 迭代第 2424 次
# 代价函数上一次的差: 1.1073040282159885e-05
# 迭代第 2425 次
# 代价函数上一次的差: 1.1064295121609308e-05
# 迭代第 2426 次
# 代价函数上一次的差: 1.1055560397772723e-05
# 迭代第 2427 次
# 代价函数上一次的差: 1.1046836093934337e-05
# 迭代第 2428 次
# 代价函数上一次的差: 1.1038122193603866e-05
# 迭代第 2429 次
# 代价函数上一次的差: 1.102941868005164e-05
# 迭代第 2430 次
# 代价函数上一次的差: 1.1020725536964315e-05
# 迭代第 2431 次
# 代价函数上一次的差: 1.1012042747674672e-05
# 迭代第 2432 次
# 代价函数上一次的差: 1.100337029579651e-05
# 迭代第 2433 次
# 代价函数上一次的差: 1.0994708164888123e-05
# 迭代第 2434 次
# 代价函数上一次的差: 1.0986056338552902e-05
# 迭代第 2435 次
# 代价函数上一次的差: 1.0977414800390772e-05
# 迭代第 2436 次
# 代价函数上一次的差: 1.0968783534136967e-05
# 迭代第 2437 次
# 代价函数上一次的差: 1.0960162523426104e-05
# 迭代第 2438 次
# 代价函数上一次的差: 1.0951551752055866e-05
# 迭代第 2439 次
# 代价函数上一次的差: 1.0942951203685158e-05
# 迭代第 2440 次
# 代价函数上一次的差: 1.093436086225738e-05
# 迭代第 2441 次
# 代价函数上一次的差: 1.0925780711469602e-05
# 迭代第 2442 次
# 代价函数上一次的差: 1.0917210735251343e-05
# 迭代第 2443 次
# 代价函数上一次的差: 1.0908650917452328e-05
# 迭代第 2444 次
# 代价函数上一次的差: 1.0900101242057592e-05
# 迭代第 2445 次
# 代价函数上一次的差: 1.0891561692996654e-05
# 迭代第 2446 次
# 代价函数上一次的差: 1.0883032254209446e-05
# 迭代第 2447 次
# 代价函数上一次的差: 1.0874512909771206e-05
# 迭代第 2448 次
# 代价函数上一次的差: 1.08660036437086e-05
# 迭代第 2449 次
# 代价函数上一次的差: 1.0857504440117682e-05
# 迭代第 2450 次
# 代价函数上一次的差: 1.0849015283125735e-05
# 迭代第 2451 次
# 代价函数上一次的差: 1.0840536156825342e-05
# 迭代第 2452 次
# 代价函数上一次的差: 1.0832067045475624e-05
# 迭代第 2453 次
# 代价函数上一次的差: 1.0823607933137941e-05
# 迭代第 2454 次
# 代价函数上一次的差: 1.0815158804283048e-05
# 迭代第 2455 次
# 代价函数上一次的差: 1.0806719642930673e-05
# 迭代第 2456 次
# 代价函数上一次的差: 1.0798290433555041e-05
# 迭代第 2457 次
# 代价函数上一次的差: 1.078987116042568e-05
# 迭代第 2458 次
# 代价函数上一次的差: 1.0781461807860687e-05
# 迭代第 2459 次
# 代价函数上一次的差: 1.0773062360386332e-05
# 迭代第 2460 次
# 代价函数上一次的差: 1.0764672802261732e-05
# 迭代第 2461 次
# 代价函数上一次的差: 1.0756293118072136e-05
# 迭代第 2462 次
# 代价函数上一次的差: 1.0747923292215439e-05
# 迭代第 2463 次
# 代价函数上一次的差: 1.0739563309263012e-05
# 迭代第 2464 次
# 代价函数上一次的差: 1.073121315374112e-05
# 迭代第 2465 次
# 代价函数上一次的差: 1.0722872810255829e-05
# 迭代第 2466 次
# 代价函数上一次的差: 1.0714542263326465e-05
# 迭代第 2467 次
# 代价函数上一次的差: 1.0706221497659707e-05
# 迭代第 2468 次
# 代价函数上一次的差: 1.0697910497934476e-05
# 迭代第 2469 次
# 代价函数上一次的差: 1.068960924879847e-05
# 迭代第 2470 次
# 代价函数上一次的差: 1.0681317734996532e-05
# 迭代第 2471 次
# 代价函数上一次的差: 1.0673035941325543e-05
# 迭代第 2472 次
# 代价函数上一次的差: 1.0664763852509529e-05
# 迭代第 2473 次
# 代价函数上一次的差: 1.0656501453390477e-05
# 迭代第 2474 次
# 代价函数上一次的差: 1.0648248728841597e-05
# 迭代第 2475 次
# 代价函数上一次的差: 1.0640005663694468e-05
# 迭代第 2476 次
# 代价函数上一次的差: 1.0631772242877813e-05
# 迭代第 2477 次
# 代价函数上一次的差: 1.062354845127872e-05
# 迭代第 2478 次
# 代价函数上一次的差: 1.0615334273947341e-05
# 迭代第 2479 次
# 代价函数上一次的差: 1.0607129695826278e-05
# 迭代第 2480 次
# 代价函数上一次的差: 1.0598934701941398e-05
# 迭代第 2481 次
# 代价函数上一次的差: 1.0590749277335915e-05
# 迭代第 2482 次
# 代价函数上一次的差: 1.0582573407146717e-05
# 迭代第 2483 次
# 代价函数上一次的差: 1.0574407076361508e-05
# 迭代第 2484 次
# 代价函数上一次的差: 1.0566250270249017e-05
# 迭代第 2485 次
# 代价函数上一次的差: 1.0558102973873273e-05
# 迭代第 2486 次
# 代价函数上一次的差: 1.05499651725377e-05
# 迭代第 2487 次
# 代价函数上一次的差: 1.0541836851361841e-05
# 迭代第 2488 次
# 代价函数上一次的差: 1.0533717995708097e-05
# 迭代第 2489 次
# 代价函数上一次的差: 1.0525608590737645e-05
# 迭代第 2490 次
# 代价函数上一次的差: 1.051750862185799e-05
# 迭代第 2491 次
# 代价函数上一次的差: 1.0509418074362148e-05
# 迭代第 2492 次
# 代价函数上一次的差: 1.0501336933661093e-05
# 迭代第 2493 次
# 代价函数上一次的差: 1.0493265185079065e-05
# 迭代第 2494 次
# 代价函数上一次的差: 1.048520281408602e-05
# 迭代第 2495 次
# 代价函数上一次的差: 1.0477149806162322e-05
# 迭代第 2496 次
# 代价函数上一次的差: 1.0469106146743234e-05
# 迭代第 2497 次
# 代价函数上一次的差: 1.0461071821333406e-05
# 迭代第 2498 次
# 代价函数上一次的差: 1.045304681555545e-05
# 迭代第 2499 次
# 代价函数上一次的差: 1.0445031114851566e-05
# 迭代第 2500 次
# 代价函数上一次的差: 1.0437024704861714e-05
# 迭代第 2501 次
# 代价函数上一次的差: 1.0429027571267485e-05
# 迭代第 2502 次
# 代价函数上一次的差: 1.0421039699656798e-05
# 迭代第 2503 次
# 代价函数上一次的差: 1.0413061075718183e-05
# 迭代第 2504 次
# 代价函数上一次的差: 1.040509168515058e-05
# 迭代第 2505 次
# 代价函数上一次的差: 1.0397131513718849e-05
# 迭代第 2506 次
# 代价函数上一次的差: 1.0389180547108051e-05
# 迭代第 2507 次
# 代价函数上一次的差: 1.0381238771232232e-05
# 迭代第 2508 次
# 代价函数上一次的差: 1.0373306171759106e-05
# 迭代第 2509 次
# 代价函数上一次的差: 1.0365382734627004e-05
# 迭代第 2510 次
# 代价函数上一次的差: 1.0357468445701401e-05
# 迭代第 2511 次
# 代价函数上一次的差: 1.0349563290781849e-05
# 迭代第 2512 次
# 代价函数上一次的差: 1.0341667255983622e-05
# 迭代第 2513 次
# 代价函数上一次的差: 1.0333780327040354e-05
# 迭代第 2514 次
# 代价函数上一次的差: 1.0325902490070787e-05
# 迭代第 2515 次
# 代价函数上一次的差: 1.0318033731061826e-05
# 迭代第 2516 次
# 代价函数上一次的差: 1.031017403596568e-05
# 迭代第 2517 次
# 代价函数上一次的差: 1.0302323390956603e-05
# 迭代第 2518 次
# 代价函数上一次的差: 1.0294481782024967e-05
# 迭代第 2519 次
# 代价函数上一次的差: 1.0286649195296454e-05
# 迭代第 2520 次
# 代价函数上一次的差: 1.0278825617011239e-05
# 迭代第 2521 次
# 代价函数上一次的差: 1.0271011033208266e-05
# 迭代第 2522 次
# 代价函数上一次的差: 1.026320543012077e-05
# 迭代第 2523 次
# 代价函数上一次的差: 1.0255408793971577e-05
# 迭代第 2524 次
# 代价函数上一次的差: 1.0247621111035554e-05
# 迭代第 2525 次
# 代价函数上一次的差: 1.0239842367507773e-05
# 迭代第 2526 次
# 代价函数上一次的差: 1.0232072549812288e-05
# 迭代第 2527 次
# 代价函数上一次的差: 1.0224311644102535e-05
# 迭代第 2528 次
# 代价函数上一次的差: 1.0216559636913591e-05
# 迭代第 2529 次
# 代价函数上一次的差: 1.020881651442665e-05
# 迭代第 2530 次
# 代价函数上一次的差: 1.0201082263221889e-05
# 迭代第 2531 次
# 代价函数上一次的差: 1.0193356869643566e-05
# 迭代第 2532 次
# 代价函数上一次的差: 1.0185640320112266e-05
# 迭代第 2533 次
# 代价函数上一次的差: 1.017793260118735e-05
# 迭代第 2534 次
# 代价函数上一次的差: 1.0170233699327569e-05
# 迭代第 2535 次
# 代价函数上一次的差: 1.0162543601015955e-05
# 迭代第 2536 次
# 代价函数上一次的差: 1.0154862292961059e-05
# 迭代第 2537 次
# 代价函数上一次的差: 1.014718976160775e-05
# 迭代第 2538 次
# 代价函数上一次的差: 1.013952599359172e-05
# 迭代第 2539 次
# 代价函数上一次的差: 1.0131870975583351e-05
# 迭代第 2540 次
# 代价函数上一次的差: 1.0124224694228745e-05
# 迭代第 2541 次
# 代价函数上一次的差: 1.0116587136201755e-05
# 迭代第 2542 次
# 代价函数上一次的差: 1.0108958288193581e-05
# 迭代第 2543 次
# 代价函数上一次的差: 1.0101338136992571e-05
# 迭代第 2544 次
# 代价函数上一次的差: 1.0093726669338499e-05
# 迭代第 2545 次
# 代价函数上一次的差: 1.008612387195032e-05
# 迭代第 2546 次
# 代价函数上一次的差: 1.007852973174822e-05
# 迭代第 2547 次
# 代价函数上一次的差: 1.0070944235517076e-05
# 迭代第 2548 次
# 代价函数上一次的差: 1.0063367370083398e-05
# 迭代第 2549 次
# 代价函数上一次的差: 1.0055799122409004e-05
# 迭代第 2550 次
# 代价函数上一次的差: 1.004823947933775e-05
# 迭代第 2551 次
# 代价函数上一次的差: 1.0040688427855743e-05
# 迭代第 2552 次
# 代价函数上一次的差: 1.0033145954890105e-05
# 迭代第 2553 次
# 代价函数上一次的差: 1.0025612047409593e-05
# 迭代第 2554 次
# 代价函数上一次的差: 1.0018086692476641e-05
# 迭代第 2555 次
# 代价函数上一次的差: 1.0010569877108577e-05
# 迭代第 2556 次
# 代价函数上一次的差: 1.0003061588322731e-05
# 代价函数迭代到最小值，退出!
# 收敛到: 0.027753074927386438
# 权重值: [ 0.14940936 -0.59087557 -1.25547434  2.18740719  1.25935037]
# 测试集准确度: 1.0

# %% [markdown]
# ## sklearn中的逻辑回归

# %%
from sklearn.linear_model import LogisticRegression
lr = LogisticRegression()
lr.fit(X_train, y_train)
print('权重值:', lr.coef_)
print('偏置项:', lr.intercept_)
print('准确度:', lr.score(X_test, y_test))
# Out:
# 权重值: [[ 0.36672199 -0.87147115  2.19851905  0.90008508]]
# 偏置项: [-5.91064795]
# 准确度: 1.0
