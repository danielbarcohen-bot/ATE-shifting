# %% [markdown]
# MACHINE LEARNING

# %%
import pandas as pd
df=pd.read_csv('encoded.csv')
del df['Unnamed: 0']
df
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /Users/atharvt14/Desktop/untitled folder/MachineLearning/ML1.ipynb Cell 2 in <cell line: 2>()
#       <a href='vscode-notebook-cell:/Users/atharvt14/Desktop/untitled%20folder/MachineLearning/ML1.ipynb#W1sZmlsZQ%3D%3D?line=0'>1</a> import pandas as pd
# ----> <a href='vscode-notebook-cell:/Users/atharvt14/Desktop/untitled%20folder/MachineLearning/ML1.ipynb#W1sZmlsZQ%3D%3D?line=1'>2</a> df=pd.read_csv('encoded.csv')
#       <a href='vscode-notebook-cell:/Users/atharvt14/Desktop/untitled%20folder/MachineLearning/ML1.ipynb#W1sZmlsZQ%3D%3D?line=2'>3</a> del df['Unnamed: 0']
#       <a href='vscode-notebook-cell:/Users/atharvt14/Desktop/untitled%20folder/MachineLearning/ML1.ipynb#W1sZmlsZQ%3D%3D?line=3'>4</a> df
#
# ...

# %%
import numpy as np
from sklearn.ensemble import RandomForestClassifier,RandomForestRegressor
from sklearn.ensemble import RandomForestClassifier,RandomForestRegressor
from sklearn.tree import DecisionTreeClassifier,DecisionTreeRegressor
from sklearn.neighbors import KNeighborsClassifier,KNeighborsRegressor
from sklearn.svm import SVR,SVC
from catboost import CatBoostRegressor,CatBoostClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score,accuracy_score

# %% [markdown]
# Random forest classifier and regressor

# %%
x1=df['Sequence'].values
y1=df['Subpopulation'].values

x_train1, x_test1, y_train1, y_test1 = train_test_split(x1, y1, test_size=0.25, random_state=48)
x_train1 = x_train1.reshape(-1, 1)
x_test1 = x_test1.reshape(-1, 1)

subpoprf = RandomForestClassifier()

subpoprf.fit(x_train1, y_train1)
y_pred1 = subpoprf.predict(x_test1)
subpopac=accuracy_score(y_test1,y_pred1)
subpopac
# Out:
# 0.8421052631578947

# %%
x2 = df['Sequence'].values
y2 = df['PlantHeight'].values

x_train2, x_test2, y_train2, y_test2 = train_test_split(x2, y2, test_size=0.25)
x_test2 = x_test2.reshape(-1, 1)
x_train2 = x_train2.reshape(-1, 1)

plhrf = RandomForestRegressor()

plhrf.fit(x_train2, y_train2)
y_pred2 = plhrf.predict(x_test2)
heightacc=r2_score(y_test2,y_pred2)
heightacc
# Out:
# 0.8775652703541618

# %%
x3 = df['Sequence'].values
y3 = df['Yield'].values

x_train3, x_test3, y_train3, y_test3 = train_test_split(x2, y2, test_size=0.25)
x_test3 = x_test3.reshape(-1, 1)
x_train3 = x_train3.reshape(-1, 1)

plhrf = RandomForestRegressor()

plhrf.fit(x_train3, y_train3)
y_pred3 = plhrf.predict(x_test3)
ylac=r2_score(y_test3,y_pred3)
ylac
# Out:
# 0.8348652612696486

# %% [markdown]
# DECISION TREES REGRESSOR AND CLASSIFIER

# %%
x1=df['Sequence'].values
y1=df['Subpopulation'].values

x_train1, x_test1, y_train1, y_test1 = train_test_split(x1, y1, test_size=0.2, random_state=42)
x_train1 = x_train1.reshape(-1, 1)
x_test1 = x_test1.reshape(-1, 1)

subpoprf = DecisionTreeClassifier() # Corrected class name

subpoprf.fit(x_train1, y_train1)
y_pred1 = subpoprf.predict(x_test1)
subpopac=accuracy_score(y_test1,y_pred1)
subpopac
# Out:
# 0.8773584905660378

# %%
x2 = df['Sequence'].values
y2 = df['PlantHeight'].values

x_train2, x_test2, y_train2, y_test2 = train_test_split(x2, y2, test_size=0.25)
x_test2 = x_test2.reshape(-1, 1)
x_train2 = x_train2.reshape(-1, 1)

plhrf = DecisionTreeRegressor()

plhrf.fit(x_train2, y_train2)
y_pred2 = plhrf.predict(x_test2)
hc=r2_score(y_test2,y_pred2)
hc
# Out:
# 0.7918055425531778

# %%
x3 = df['Sequence'].values
y3 = df['Yield'].values

x_train3, x_test3, y_train3, y_test3 = train_test_split(x3, y3, test_size=0.25)
x_test3 = x_test3.reshape(-1, 1)
x_train3 = x_train3.reshape(-1, 1)

yld = DecisionTreeRegressor()

yld.fit(x_train3, y_train3)
y_pred3 = yld.predict(x_test3)
y_pred3
heightacc=r2_score(y_test3,y_pred3)
heightacc
# Out:
# 0.5003057837485994

# %% [markdown]
# KNN

# %%
x1=df['Sequence'].values
y1=df['Subpopulation'].values

x_train1, x_test1, y_train1, y_test1 = train_test_split(x1, y1, test_size=0.2, random_state=42)
x_train1 = x_train1.reshape(-1, 1)
x_test1 = x_test1.reshape(-1, 1)

subpoprf = KNeighborsClassifier() # Corrected class name

subpoprf.fit(x_train1, y_train1)
y_pred1 = subpoprf.predict(x_test1)
subpopac=accuracy_score(y_test1,y_pred1)
subpopac
# Out:
# 0.9150943396226415

# %%
x2 = df['Sequence'].values
y2 = df['PlantHeight'].values

x_train2, x_test2, y_train2, y_test2 = train_test_split(x2, y2, test_size=0.25)
x_test2 = x_test2.reshape(-1, 1)
x_train2 = x_train2.reshape(-1, 1)

plhrf = KNeighborsRegressor()

plhrf.fit(x_train2, y_train2)
y_pred2 = plhrf.predict(x_test2)
heightacc=r2_score(y_test2,y_pred2)
heightacc
# Out:
# 0.9383519642198593

# %%
x3 = df['Sequence'].values
y3 = df['Yield'].values

x_train3, x_test3, y_train3, y_test3 = train_test_split(x3, y3, test_size=0.25)
x_test3 = x_test3.reshape(-1, 1)
x_train3 = x_train3.reshape(-1, 1)

yld = DecisionTreeRegressor()

yld.fit(x_train3, y_train3)
y_pred3 = yld.predict(x_test3)
hc=r2_score(y_test3,y_pred3)
hc
# Out:
# 0.5361289190364894

# %% [markdown]
# SUPPORT VECTOR REGRESSOR and CLASSIFIER

# %%
x1=df['Sequence'].values
y1=df['Subpopulation'].values

x_train1, x_test1, y_train1, y_test1 = train_test_split(x1, y1, test_size=0.2, random_state=42)
x_train1 = x_train1.reshape(-1, 1)
x_test1 = x_test1.reshape(-1, 1)

subpoprf = SVC() # Corrected class name

subpoprf.fit(x_train1, y_train1)
y_pred1 = subpoprf.predict(x_test1)
subpopac=accuracy_score(y_test1,y_pred1)
subpopac
# Out:
# 0.330188679245283

# %%
x2 = df['Sequence'].values
y2 = df['PlantHeight'].values

x_train2, x_test2, y_train2, y_test2 = train_test_split(x2, y2, test_size=0.25)
x_test2 = x_test2.reshape(-1, 1)
x_train2 = x_train2.reshape(-1, 1)

plhrf = SVR()

plhrf.fit(x_train2, y_train2)
y_pred2 = plhrf.predict(x_test2)
heightacc=r2_score(y_test2,y_pred2)
heightacc
# Out:
# 0.13026215393606844

# %%
x3 = df['Sequence'].values
y3 = df['Yield'].values

x_train3, x_test3, y_train3, y_test3 = train_test_split(x3, y3, test_size=0.25)
x_test3 = x_test3.reshape(-1, 1)
x_train3 = x_train3.reshape(-1, 1)

yld = SVR()

yld.fit(x_train3, y_train3)
y_pred3 = yld.predict(x_test3)
hc=r2_score(y_test3,y_pred3)
hc
# Out:
# -0.12930647360216918

# %% [markdown]
# CATBOOST REGRESSION AND CLASSIFICATION

# %%
x1=df['Sequence'].values
y1=df['Subpopulation'].values

x_train1, x_test1, y_train1, y_test1 = train_test_split(x1, y1, test_size=0.2, random_state=42)
x_train1 = x_train1.reshape(-1, 1)
x_test1 = x_test1.reshape(-1, 1)

subpoprf = CatBoostClassifier() # Corrected class name

subpoprf.fit(x_train1, y_train1)
y_pred1 = subpoprf.predict(x_test1)
subpopac=accuracy_score(y_test1,y_pred1)
subpopac
# Out:
# Learning rate set to 0.07573
# 0:	learn: 2.1227543	total: 57.4ms	remaining: 57.3s
# 1:	learn: 1.9580873	total: 58.1ms	remaining: 29s
# 2:	learn: 1.8368882	total: 58.9ms	remaining: 19.6s
# 3:	learn: 1.7432514	total: 59.7ms	remaining: 14.9s
# 4:	learn: 1.6622053	total: 60.4ms	remaining: 12s
# 5:	learn: 1.5845379	total: 61ms	remaining: 10.1s
# 6:	learn: 1.5219738	total: 61.7ms	remaining: 8.75s
# 7:	learn: 1.4747436	total: 62.3ms	remaining: 7.73s
# 8:	learn: 1.4269309	total: 62.9ms	remaining: 6.93s
# 9:	learn: 1.3827199	total: 63.5ms	remaining: 6.28s
# 10:	learn: 1.3397320	total: 64.1ms	remaining: 5.76s
# 11:	learn: 1.3005758	total: 64.7ms	remaining: 5.33s
# 12:	learn: 1.2646699	total: 65.5ms	remaining: 4.97s
# 13:	learn: 1.2457168	total: 66ms	remaining: 4.65s
# 14:	learn: 1.2148535	total: 66.6ms	remaining: 4.37s
# 15:	learn: 1.1824671	total: 67.2ms	remaining: 4.13s
# 16:	learn: 1.1595582	total: 67.9ms	remaining: 3.92s
# 17:	learn: 1.1331469	total: 68.5ms	remaining: 3.74s
# ...

# %%
x2 = df['Sequence'].values
y2 = df['PlantHeight'].values

x_train2, x_test2, y_train2, y_test2 = train_test_split(x2, y2, test_size=0.25)
x_test2 = x_test2.reshape(-1, 1)
x_train2 = x_train2.reshape(-1, 1)

plhrf = CatBoostRegressor()

plhrf.fit(x_train2, y_train2)
y_pred2 = plhrf.predict(x_test2)
heightacc=r2_score(y_test2,y_pred2)
heightacc
# Out:
# Learning rate set to 0.035368
# 0:	learn: 25.6006958	total: 393us	remaining: 393ms
# 1:	learn: 25.1133715	total: 583us	remaining: 291ms
# 2:	learn: 24.5481626	total: 877us	remaining: 292ms
# 3:	learn: 24.0996291	total: 1.1ms	remaining: 275ms
# 4:	learn: 23.6150085	total: 1.33ms	remaining: 265ms
# 5:	learn: 23.2176746	total: 1.53ms	remaining: 254ms
# 6:	learn: 22.8314674	total: 1.66ms	remaining: 236ms
# 7:	learn: 22.4395743	total: 1.91ms	remaining: 237ms
# 8:	learn: 22.1135556	total: 2.07ms	remaining: 228ms
# 9:	learn: 21.7184319	total: 2.3ms	remaining: 227ms
# 10:	learn: 21.4395960	total: 2.49ms	remaining: 224ms
# 11:	learn: 21.0735586	total: 2.7ms	remaining: 223ms
# 12:	learn: 20.7749639	total: 2.91ms	remaining: 221ms
# 13:	learn: 20.4218395	total: 3.17ms	remaining: 223ms
# 14:	learn: 20.1568255	total: 3.33ms	remaining: 219ms
# 15:	learn: 19.9455747	total: 3.48ms	remaining: 214ms
# 16:	learn: 19.7020944	total: 3.58ms	remaining: 207ms
# ...

# %%
x3 = df['Sequence'].values
y3 = df['Yield'].values

x_train3, x_test3, y_train3, y_test3 = train_test_split(x3, y3, test_size=0.25)
x_test3 = x_test3.reshape(-1, 1)
x_train3 = x_train3.reshape(-1, 1)

yld = CatBoostRegressor()

yld.fit(x_train3, y_train3)
y_pred3 = yld.predict(x_test3)
hc=r2_score(y_test3,y_pred3)
hc
# Out:
# Learning rate set to 0.035368
# 0:	learn: 6.8875792	total: 409us	remaining: 409ms
# 1:	learn: 6.8239658	total: 617us	remaining: 308ms
# 2:	learn: 6.7644917	total: 816us	remaining: 272ms
# 3:	learn: 6.7158549	total: 1ms	remaining: 249ms
# 4:	learn: 6.6552317	total: 1.15ms	remaining: 228ms
# 5:	learn: 6.6052049	total: 1.42ms	remaining: 236ms
# 6:	learn: 6.5336156	total: 1.59ms	remaining: 226ms
# 7:	learn: 6.4933699	total: 1.78ms	remaining: 221ms
# 8:	learn: 6.4248155	total: 2.03ms	remaining: 223ms
# 9:	learn: 6.3916700	total: 2.22ms	remaining: 220ms
# 10:	learn: 6.3646721	total: 2.44ms	remaining: 220ms
# 11:	learn: 6.3226342	total: 2.64ms	remaining: 217ms
# 12:	learn: 6.2724540	total: 2.89ms	remaining: 220ms
# 13:	learn: 6.2323215	total: 3.05ms	remaining: 215ms
# 14:	learn: 6.1850673	total: 3.25ms	remaining: 213ms
# 15:	learn: 6.1373117	total: 3.5ms	remaining: 215ms
# 16:	learn: 6.0987297	total: 3.75ms	remaining: 217ms
# 17:	learn: 6.0680035	total: 3.93ms	remaining: 215ms
# ...

# %% [markdown]
# RANDOM FOREST GIVES HIGHEST ACCURACY SCORE AND KNN GIVES HIGHEST ACCURACY SCORES
# hence we choose those two models
