# %% [markdown]
# Alunos:
#
# Eduardo Durante Godinho 2101327
#
# Eduardo Golin 2142562
#
# Matheus Bueno Faria 2052423

# %%
# Analisando Diabetes através da Base Iris

import pandas
import matplotlib.pyplot as plt
from sklearn.tree import DecisionTreeClassifier
from sklearn import tree
from sklearn.model_selection import train_test_split
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory
#Base Iris
# carrega a base de dados iris
dados = pandas.read_csv('/kaggle/input/review/diabetes.csv')
dados

colunas = dados.columns.drop('Glucose')

X = dados[colunas].values
y = dados['Insulin'].values
# le = LabelEncoder()
# y = le.fit_transform(dados['Name'])

X_treino, X_teste, y_treino, y_teste = train_test_split(X, 
                            y, train_size=0.7, test_size=0.3)

clf = DecisionTreeClassifier(criterion="entropy")
# treina o classificador
clf.fit(X_treino, y_treino)

y_pred = clf.predict(X_teste)

#Print Text Representation
#Exporting Decision Tree to the text representation can be useful when working on applications whitout user interface or when we want to log information about the model into the text file. You can check details about export_text in the sklearn
text_representation = tree.export_text(clf)
print(text_representation)

#Cria uam lista com features e class names
fn=['sepal length (cm)','sepal width (cm)',
    'petal length (cm)','petal width (cm)']
cn=['setosa', 'versicolor', 'virginica']



plt.show()

# %%
# Diabetes utilizando a base Play Tennis

import pandas as pd
import numpy as np

df = pd.read_csv('/kaggle/input/review/diabetes.csv')

df

def entropia(feature):
    
    probs = feature.value_counts(normalize=True)
    impureza = -1 * np.sum(np.log2(probs) * probs)
        
    return(round(impureza, 3))

print('Entropia atributo classe:', entropia(df['Glucose']))

df['Glucose'].value_counts()

def ganho_informacao(df, target, descriptive_feature):
    
    print('Atributo classe:', target)
    print('Atributo avaliado:', descriptive_feature)
           
    target_entropy = entropia(df[target])

    entropy_list = list()
    weight_list = list()
    
    for nivel in df[descriptive_feature].unique():
        df_feature_level = df[df[descriptive_feature] == nivel]
        entropy_level = entropia(df_feature_level[target])
        entropy_list.append(round(entropy_level, 3))
        weight_level = len(df_feature_level) / len(df)
        weight_list.append(round(weight_level, 3))

    print('Entropia das ramificações:', entropy_list)    

    entropia_atual = np.sum(np.array(entropy_list) * np.array(weight_list))
    print('Impureza atual:', entropia_atual)
    
    information_gain = target_entropy - entropia_atual
    print('Ganho de informação:', information_gain)
    
    print('====================')

    return(information_gain)

for feature in df.drop(columns='Glucose').columns:
    feature_info_gain = ganho_informacao(df, 'Glucose', feature)

# %%
#Acoustic Features usando a Base Iris

import pandas
import matplotlib.pyplot as plt
from sklearn.tree import DecisionTreeClassifier
from sklearn import tree
from sklearn.model_selection import train_test_split
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory
#Base Iris
# carrega a base de dados iris
dados = pandas.read_csv('/kaggle/input/turkish-music-emotion-dataset/Acoustic Features.csv')
dados

colunas = dados.columns.drop('Class')

X = dados[colunas].values
y = dados['Class'].values
# le = LabelEncoder()
# y = le.fit_transform(dados['Name'])

X_treino, X_teste, y_treino, y_teste = train_test_split(X, 
                            y, train_size=0.7, test_size=0.3)

clf = DecisionTreeClassifier(criterion="entropy")
# treina o classificador
clf.fit(X_treino, y_treino)

y_pred = clf.predict(X_teste)

#Print Text Representation
#Exporting Decision Tree to the text representation can be useful when working on applications whitout user interface or when we want to log information about the model into the text file. You can check details about export_text in the sklearn
text_representation = tree.export_text(clf)
print(text_representation)

#Cria uam lista com features e class names
fn=['sepal length (cm)','sepal width (cm)',
    'petal length (cm)','petal width (cm)']
cn=['setosa', 'versicolor', 'virginica']



plt.show()

# %%
#Acoustic Features usando a Base Play Tennis

import pandas as pd
import numpy as np

df = pd.read_csv('/kaggle/input/turkish-music-emotion-dataset/Acoustic Features.csv')

df

def entropia(feature):
    
    probs = feature.value_counts(normalize=True)
    impureza = -1 * np.sum(np.log2(probs) * probs)
        
    return(round(impureza, 3))

print('Entropia atributo classe:', entropia(df['Class']))

df['Class'].value_counts()

def ganho_informacao(df, target, descriptive_feature):
    
    print('Atributo classe:', target)
    print('Atributo avaliado:', descriptive_feature)
           
    target_entropy = entropia(df[target])

    entropy_list = list()
    weight_list = list()
    
    for nivel in df[descriptive_feature].unique():
        df_feature_level = df[df[descriptive_feature] == nivel]
        entropy_level = entropia(df_feature_level[target])
        entropy_list.append(round(entropy_level, 3))
        weight_level = len(df_feature_level) / len(df)
        weight_list.append(round(weight_level, 3))

    print('Entropia das ramificações:', entropy_list)    

    entropia_atual = np.sum(np.array(entropy_list) * np.array(weight_list))
    print('Impureza atual:', entropia_atual)
    
    information_gain = target_entropy - entropia_atual
    print('Ganho de informação:', information_gain)
    
    print('====================')

    return(information_gain)

for feature in df.drop(columns='Class').columns:
    feature_info_gain = ganho_informacao(df, 'Class', feature)
