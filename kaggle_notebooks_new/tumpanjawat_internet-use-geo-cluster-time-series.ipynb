# %% [markdown]
# <div style="padding: 35px;color:white;margin:10;font-size:200%;text-align:center;display:fill;border-radius:10px;overflow:hidden;background-image: url(https://w0.peakpx.com/wallpaper/957/661/HD-wallpaper-white-marble-white-stone-texture-marble-stone-background-white-stone.jpg)"><b><span style='color:black'>Getting Started </span></b> </div>
#
# <br>
#
# This analysis focuses on **visualizing the geographical distribution** of various internet usage metrics, such as the percentage of internet users, the number of internet users, mobile subscriptions, and fixed broadband subscriptions. The metrics are studied at the regional level across the following regions: `East Asia and Pacific`, `Europe and Central Asia`, `European Union`, `atin America and Caribbean`, `Middle East and North Africa`, `North America`, `South Asia`, and `Sub-Saharan Africa`.
#
# The aim is to create a series of choropleth maps - **geographical maps** where areas are shaded or patterned in relation to the data variable being displayed on the map, in this case, internet usage data. The analysis is conducted for the year 2020 to reflect the most recent trends in global internet usage.
#
# In addition to shedding light on the internet usage landscape, this analysis can serve as a valuable tool for policy-makers, researchers, and businesses to understand regional internet usage patterns and drive decision-making processes.
#
# <br>
#
# ![](https://images.pexels.com/photos/67112/pexels-photo-67112.jpeg?auto=compress&cs=tinysrgb&w=1260&h=750&dpr=1)
#
# <br>
#
# ### <b><span style='color:#526D82'>|</span> Domain Knowledge</b>
#
# <br>
#
# 1. **`Entity`** - This column represents either the name of a country or a larger geographical region. Regions group together countries with geographical proximity or shared characteristics, which allows for broader, more generalized comparisons and analyses. The regional classification can be particularly useful when assessing digital divide, internet penetration, or development trends on a more macroscopic scale.
#
# 2. **`Code`** - This field contains the ISO 3166-1 alpha-3 country codes, which are internationally recognized codes assigned to each country. When the code has the value 'Region', it indicates that the row provides data for a broader geographical or socio-political region, as opposed to a single country. Utilizing standardized country codes ensures consistency, especially when merging or comparing datasets from different sources.
#
# 3. **`Year`** - The dataset spans from 1980 to 2020, providing a four-decade view of the global evolution of internet usage and cellular subscriptions. This longitudinal data can help us identify patterns and trends over time, as well as to estimate future trends.
#
# 4. **`Cellular Subscription`** - This metric signifies the number of mobile phone subscriptions per 100 people within a given country or region. If the number exceeds 100, this implies that on average, individuals have more than one mobile subscription - a scenario common in many developed and developing countries. This statistic is a useful indicator of mobile connectivity and infrastructure, and indirectly, of the potential for mobile internet access.
#
# 5. **`Internet Users(%)`** - This data represents the percentage of the population in a country or region that uses the internet. This key metric is a primary indicator of digital divide, and it can provide insights into societal digital literacy, the reach of digital services, and the impact of government policies promoting digital access.
#
# 6. **`No. of Internet Users`** - This value stands for the absolute number of people who use the internet in a given country or region. While the percentage of internet users provides a relative measure, the absolute number of users can provide a sense of the scale or market size for digital services or e-commerce in a specific region or country.
#
# 7. **`Broadband Subscription`** - The number of fixed broadband subscriptions per 100 people reflects the prevalence of high-speed, stable internet connections in a region or country. Fixed broadband connections, typically via DSL, fiber, or cable, often provide faster and more reliable service than mobile internet connections. This metric is a crucial indicator of the infrastructure available for services like high-quality video streaming, online gaming, and other data-intensive applications.
#
# <br>
#
# ✔️ **By understanding these data elements in detail, we can extract valuable insights about global digital connectivity, access to digital services, the evolution of digital technology, and the potential for digital growth in different parts of the world.**
#
# # <span style="color:#E888BB; font-size: 1%;">0 | INTRODUCTION</span>
# <div style="padding: 30px;color:white;margin:10;font-size:170%;text-align:left;display:fill;border-radius:10px;overflow:hidden;background-image: url(https://images.pexels.com/photos/532173/pexels-photo-532173.jpeg?auto=compress&cs=tinysrgb&w=1260&h=750&dpr=1)"><b><span style='color:white'>0 | INTRODUCTION </span></b> </div>
#
# <br>
#
# ### <b>I <span style='color:#526D82'>|</span> Preface</b>
#
# <br>
#
# In this analysis, we delve into the fascinating world of **<span style='color:#526D82'>internet usage and its progression from the year 1980 to 2020</span>**. Our primary focus lies in scrutinizing the trends, comparisons, and growth trajectories within different geographical clusters and income groups.
#
# Our dataset holds a wealth of information that spans across nations and regions, offering a bird's eye view of the internet's evolution in different parts of the world. However, to truly appreciate the granularity and complexity of this data, it becomes imperative to dissect it into more targeted subsets.
#
# 1. **Regional Data** : The first level of our analysis branches the data based on the 'Region' column, separating out individual regions from the collective data. This segmentation provides a nuanced understanding of regional differences, developmental contrasts, and allows us to focus on the digital landscape within these specific geographical bounds. By dissecting the data in this manner, we can develop region-specific insights and identify unique trends and patterns.
#
# 2. **Income Group Data**: The second dimension we explore is the income group. We extract this information from the 'Entity' column in the 'Region' section of the data. This categorization segregates countries into various income groups like low-income, lower-middle-income, upper-middle-income, and high-income countries. Analyzing data through the lens of income groups enables us to understand the correlation between a country's wealth and its access to and use of internet services. This segmentation can reveal striking disparities in internet usage, accessibility, and technological development based on the income group.
#
# 3. **Global Data**: Finally, we isolate data representing the world as a whole. This global snapshot gives us an overarching perspective of the internet's growth trajectory and the progression of digital connectivity worldwide. It allows us to evaluate global trends and generate high-level insights about internet usage, cellular subscription, and broadband subscription rates on a global scale.
#
# <br>
#
# <div style="border-radius:10px;border:#526D82 solid;padding: 15px;background-color:#ffffff00;font-size:100%;text-align:left">
#    📝Through this multifaceted examination, our analysis promises a comprehensive and rich understanding of the progression of internet usage across time, geography, and income divisions. This preface serves as a roadmap to the ensuing journey, where numbers weave stories of digital evolution, revealing insights that are as profound as they are impactful.
#    </div>
#
# <br>
#
# ### <b>II <span style='color:#526D82'>|</span> Import libraries</b>

# %%
import warnings
warnings.filterwarnings('ignore')

import numpy as np
import pandas as pd 
import plotly.express as px
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

# %% [markdown]
# ### <b>III <span style='color:#526D82'>|</span> Input the data</b>

# %%
data = pd.read_csv('/kaggle/input/internet-users/Final.csv')

# %%
data.head(10)

# %% [markdown]
# # <span style="color:#E888BB; font-size: 1%;">1 | DATA CLEANSING AND DATA PREP</span>
# <div style="padding: 35px;color:white;margin:10;font-size:170%;text-align:left;display:fill;border-radius:10px;overflow:hidden;background-image: url(https://images.pexels.com/photos/532173/pexels-photo-532173.jpeg?auto=compress&cs=tinysrgb&w=1260&h=750&dpr=1)"><b><span style='color:black'>1 | DATA CLEANSING AND DATA PREP </span></b> </div>
#
# ## <div style="padding: 20px;color:white;margin:10;font-size:90%;text-align:left;display:fill;border-radius:10px;overflow:hidden;background-image: url(https://w0.peakpx.com/wallpaper/957/661/HD-wallpaper-white-marble-white-stone-texture-marble-stone-background-white-stone.jpg)"><b><span style='color:black'> 1. Data Quality</span></b> </div>
#
# ### <b>I <span style='color:#526D82'>|</span> Uniqueness</b>

# %%
# Loop through each column and count the number of distinct values
for column in data.columns:
    num_distinct_values = len(data[column].unique())
    print(f"{column}: {num_distinct_values} distinct values")

# %%
# Handle duplicates
duplicate_rows_data = data[data.duplicated()]
print("number of duplicate rows: ", duplicate_rows_data.shape)

# %%
data = data.drop('Unnamed: 0', axis=1)

# %% [markdown]
# ### <b>II <span style='color:#16C2D5'>|</span> Completeness </b>

# %%
#check missing ratio
data_na = (data.isnull().sum() / len(data)) * 100
data_na = data_na.drop(data_na[data_na == 0].index).sort_values(ascending=False)[:30]
missing_data = pd.DataFrame({'Missing Ratio' :data_na})
missing_data.head(20)

# %% [markdown]
# ### <b>III <span style='color:#526D82'>|</span> Consistency </b>

# %%
# Print the unique values in the "Code" column
unique_value = data['Code'].unique()
print(unique_value)

# %%
#Create a new dataframe
df = data.copy()

#Separate World and Region from the data set
world_df = df[df['Code'].str.contains('OWID_WRL')].copy()
region_df = df[df['Code'].str.contains('Region')].copy()

# Change 'OWID_KOS' to 'KOS' in the 'Code' column
df['Code'] = df['Code'].replace('OWID_KOS', 'KOS')

# Drop rows with 'OWID_WRL' and 'Region' values in the 'Code' column
df = df[~df['Code'].isin(['OWID_WRL', 'Region'])].copy()

# %%
# Print the unique values in the "Code" column
unique_value = df['Code'].unique()
print(unique_value)

# %%
# Print the unique values in the "Entity" column
unique_value = region_df['Entity'].unique()
print(unique_value)

# %%
# Specify the values we want to separate from the 'Entity' column
desired_values = ['High income', 'Low and middle income', 'Low income', 'Lower middle income', 'Middle income', 'Upper middle income']
# Create a new dataframe for the desired values
income_df = region_df[region_df['Entity'].isin(desired_values)].copy()
# Drop the rows containing the desired values from the 'Entity' column
region_df = region_df[~region_df['Entity'].isin(desired_values)].copy()

# %%
# Print the unique values in the "Entity" column
unique_value = income_df['Entity'].unique()
print(unique_value)

# %%
# Print the unique values in the "Entity" column
unique_value = region_df['Entity'].unique()
print(unique_value)

# %% [markdown]
# # <span style="color:#E888BB; font-size: 1%;">2 | EXPLORATORY DATA ANALYSIS</span>
# <div style="padding: 30px;color:white;margin:10;font-size:170%;text-align:left;display:fill;border-radius:10px;overflow:hidden;background-image: url(https://images.pexels.com/photos/532173/pexels-photo-532173.jpeg?auto=compress&cs=tinysrgb&w=1260&h=750&dpr=1)"><b><span style='color:white'>2 | EXPLORATORY DATA ANALYSIS </span></b> </div>
#
# <br>
#
# ## <div style="padding: 20px;color:white;margin:10;font-size:90%;text-align:left;display:fill;border-radius:10px;overflow:hidden;background-image: url(https://w0.peakpx.com/wallpaper/957/661/HD-wallpaper-white-marble-white-stone-texture-marble-stone-background-white-stone.jpg)"><b><span style='color:black'> 1. World trend</span></b> </div>

# %%
# Line plot of Internet Users over the years for the specific region
plt.figure(figsize=(12, 6))
sns.lineplot(x='Year', y='Internet Users(%)', data=world_df)
plt.title('Internet Users over the Years')
plt.show()

# Line plot of Cellular Subscription over the years for the specific region
plt.figure(figsize=(12, 6))
sns.lineplot(x='Year', y='Cellular Subscription', data=world_df)
plt.title('Cellular Subscription over the Years')
plt.show()

# Line plot of Broadband Subscription over the years for the specific region
plt.figure(figsize=(12, 6))
sns.lineplot(x='Year', y='Broadband Subscription', data=world_df)
plt.title('Broadband Subscription over the Years')
plt.show()

# %% [markdown]
# ## <div style="padding: 20px;color:white;margin:10;font-size:90%;text-align:left;display:fill;border-radius:10px;overflow:hidden;background-image: url(https://w0.peakpx.com/wallpaper/957/661/HD-wallpaper-white-marble-white-stone-texture-marble-stone-background-white-stone.jpg)"><b><span style='color:black'> 2. Region trend</span></b> </div>

# %%
# Line plot of Internet Users over the years for the specific region
plt.figure(figsize=(12, 6))
sns.lineplot(x='Year', y='Internet Users(%)', hue='Entity', data=region_df)
plt.title('Internet Users over the Years by Region')
plt.show()

# Line plot of Cellular Subscription over the years for the specific region
plt.figure(figsize=(12, 6))
sns.lineplot(x='Year', y='Cellular Subscription', hue='Entity', data=region_df)
plt.title('Cellular Subscription over the Years by Region')
plt.show()

# Line plot of Broadband Subscription over the years for the specific region
plt.figure(figsize=(12, 6))
sns.lineplot(x='Year', y='Broadband Subscription', hue='Entity', data=region_df)
plt.title('Broadband Subscription over the Years by Region')
plt.show()

# %% [markdown]
# ## <div style="padding: 20px;color:white;margin:10;font-size:90%;text-align:left;display:fill;border-radius:10px;overflow:hidden;background-image: url(https://w0.peakpx.com/wallpaper/957/661/HD-wallpaper-white-marble-white-stone-texture-marble-stone-background-white-stone.jpg)"><b><span style='color:black'> 3. Income and internet adoption</span></b> </div>

# %%
# Line plot of Internet Users over the years
plt.figure(figsize=(12, 6))
sns.lineplot(x='Year', y='Internet Users(%)', hue='Entity', data=income_df)
plt.title('Internet Users over the Years by Income')
plt.show()

# Line plot of Cellular Subscription over the years
plt.figure(figsize=(12, 6))
sns.lineplot(x='Year', y='Cellular Subscription', hue='Entity', data=income_df)
plt.title('Cellular Subscription over the Years by Income')
plt.show()

# Line plot of Broadband Subscription over the years
plt.figure(figsize=(12, 6))
sns.lineplot(x='Year', y='Broadband Subscription', hue='Entity', data=income_df)
plt.title('Broadband Subscription over the Years by Income')
plt.show()

# %% [markdown]
# # <span style="color:#E888BB; font-size: 1%;">3 | GEOSPATIAL ANALYSIS</span>
# <div style="padding: 30px;color:white;margin:10;font-size:150%;text-align:left;display:fill;border-radius:10px;overflow:hidden;background-image: url(https://images.pexels.com/photos/532173/pexels-photo-532173.jpeg?auto=compress&cs=tinysrgb&w=1260&h=750&dpr=1)"><b><span style='color:white'>3 | GEOSPATIAL ANALYSIS </span></b> </div>

# %%
df_2020 = df[df['Year'] == 2020]

# %%
fig = px.choropleth(df_2020, 
                    locations='Code', 
                    color='No. of Internet Users', 
                    hover_name='Entity', 
                    color_continuous_scale='RdBu',
                    range_color=(0, 200000000),  # Set the color range from 0 to 200 million
                    )

fig.update_layout(
    title_text='Number of Internet Users in 2020',
    coloraxis_colorbar=dict(
        title='No. of Internet Users',
        dtick=20000000,  # Adjust the colorbar tick interval as per your preference
        tickformat='.0s',  # Format the tick labels in a readable way
    )
)

fig.show()

# %%
fig = px.choropleth(df_2020, locations='Code', 
                    color='Internet Users(%)', 
                    hover_name='Entity', 
                    color_continuous_scale='RdBu')

fig.update_layout(title_text = 'Internet Users (%) in 2020')
fig.show()

# %%
fig = px.choropleth(df_2020, 
                    locations='Code', 
                    color='Cellular Subscription', 
                    hover_name='Entity', 
                    color_continuous_scale='RdBu',
                    range_color=(0, 100)  # Set the color range from 0 to 100
                    )

fig.update_layout(
    title_text='Cellular Subscriptions per 100 people in 2020',
    coloraxis_colorbar=dict(
        title='Cellular Subscription',
        dtick=10  # Adjust the colorbar tick interval as per your preference
    )
)

fig.show()

# %%
fig = px.choropleth(df_2020, locations='Code', 
                    color='Broadband Subscription', 
                    hover_name='Entity', 
                    color_continuous_scale='RdBu')

fig.update_layout(title_text = 'Fixed Broadband Subscriptions per 100 people in 2020')
fig.show()

# %% [markdown]
# # <span style="color:#E888BB; font-size: 1%;">4 | CLUSTERING</span>
# <div style="padding: 35px;color:white;margin:10;font-size:170%;text-align:left;display:fill;border-radius:10px;overflow:hidden;background-image: url(https://images.pexels.com/photos/532173/pexels-photo-532173.jpeg?auto=compress&cs=tinysrgb&w=1260&h=750&dpr=1)"><b><span style='color:black'>4 | CLUSTERING </span></b> </div>
#
# ## <div style="padding: 20px;color:white;margin:10;font-size:90%;text-align:left;display:fill;border-radius:10px;overflow:hidden;background-image: url(https://w0.peakpx.com/wallpaper/957/661/HD-wallpaper-white-marble-white-stone-texture-marble-stone-background-white-stone.jpg)"><b><span style='color:black'> 1. Separate the years column to decade to make comparison</span></b> </div>

# %%
# Create a new column for the decade
df['Decade'] = (df['Year'] // 10) * 10

# Separate the dataframe into different periods
df_80s = df[df['Decade'] == 1980]
df_90s = df[df['Decade'] == 1990]
df_2000s = df[df['Decade'] == 2000]
df_2010s = df[df['Decade'] == 2010]
df_2020s = df[df['Decade'] == 2020]

# %% [markdown]
# ## <div style="padding: 20px;color:white;margin:10;font-size:90%;text-align:left;display:fill;border-radius:10px;overflow:hidden;background-image: url(https://w0.peakpx.com/wallpaper/957/661/HD-wallpaper-white-marble-white-stone-texture-marble-stone-background-white-stone.jpg)"><b><span style='color:black'> 2. Apply t-SNE and K-means clustering </span></b> </div>
#
# ### <b>I <span style='color:#526D82'>|</span> create a function</b>

# %%
def cluster_data(df_decade, decade_name):
    # Handle missing values
    df_decade.fillna(df_decade.mean(), inplace=True)

    # Define the features for clustering
    features = ['Cellular Subscription', 'Internet Users(%)', 'No. of Internet Users', 'Broadband Subscription']

    # Standardize the features
    scaler = StandardScaler()
    df_decade_scaled = df_decade.copy()
    df_decade_scaled[features] = scaler.fit_transform(df_decade[features])

    # Perform PCA for dimensionality reduction
    pca = PCA(n_components=2)
    principal_components = pca.fit_transform(df_decade_scaled[features])
    df_decade_pca = pd.DataFrame(data = principal_components, columns = ['Principal Component 1', 'Principal Component 2'])

    # Perform KMeans clustering
    kmeans = KMeans(n_clusters=3)
    clusters = kmeans.fit_predict(df_decade_pca)
    df_decade_pca['Cluster'] = clusters
    df_decade_pca['Entity'] = df_decade['Entity'].values

    # Visualize the clusters using Plotly
    fig = px.scatter(df_decade_pca, x='Principal Component 1', y='Principal Component 2', color='Cluster', 
                     hover_data=['Entity'], title=f'Clusters for {decade_name}')
    fig.show()

# %% [markdown]
# ### <b>II <span style='color:#526D82'>|</span> apply the function to each decade</b>

# %%
# Apply function to each decade
cluster_data(df_80s, '1980s')
cluster_data(df_90s, '1990s')
cluster_data(df_2000s, '2000s')
cluster_data(df_2010s, '2010s')
cluster_data(df_2020s, '2020s')

# %%
#------------------------------------
#To be continue ..... Times serie Analysis
#------------------------------------

# %% [markdown]
# # <span style="color:#E888BB; font-size: 1%;">4 | TIME SERIES ANALYSIS</span>
# <div style="padding: 30px;color:white;margin:10;font-size:170%;text-align:left;display:fill;border-radius:10px;overflow:hidden;background-image: url(https://images.pexels.com/photos/532173/pexels-photo-532173.jpeg?auto=compress&cs=tinysrgb&w=1260&h=750&dpr=1)"><b><span style='color:white'>4 | TIME SERIES ANALYSIS </span></b> </div>
#
# <br>
#
# ## <div style="padding: 20px;color:white;margin:10;font-size:90%;text-align:left;display:fill;border-radius:10px;overflow:hidden;background-image: url(https://w0.peakpx.com/wallpaper/957/661/HD-wallpaper-white-marble-white-stone-texture-marble-stone-background-white-stone.jpg)"><b><span style='color:black'> Intro</span></b> </div>
#
# The main objective of this study is to forecast the global internet user penetration rate using time series analysis. We employ **<mark style="background-color:#16C2D5;color:white;border-radius:5px;opacity:1.0">SARIMAX (Seasonal AutoRegressive Integrated Moving Average with eXogenous regressors)</mark>** model, a widely used model for time series forecasting.

# %%
from statsmodels.tsa.seasonal import seasonal_decompose
import matplotlib.pyplot as plt
from statsmodels.tsa.statespace.sarimax import SARIMAX
from pandas.tseries.offsets import DateOffset

# %%
#Create a new dataframe
df = data.copy()

#Separate World and Region from the data set
world_df = df[df['Code'].str.contains('OWID_WRL')].copy()

# %%
# Remove rows with values from 1980 to 1989 in the "Year" column
world_df = world_df[~world_df['Year'].between(1980, 1989)]

# Reset the index of the DataFrame
world_df.reset_index(drop=True, inplace=True)

# %%
# Convert the 'Year' column to datetime format
world_df['Year'] = pd.to_datetime(world_df['Year'], format='%Y')
print(world_df.dtypes)

# %% [markdown]
# ## <div style="padding: 20px;color:white;margin:10;font-size:90%;text-align:left;display:fill;border-radius:10px;overflow:hidden;background-image: url(https://w0.peakpx.com/wallpaper/957/661/HD-wallpaper-white-marble-white-stone-texture-marble-stone-background-white-stone.jpg)"><b><span style='color:black'> 2. Data Description</span></b> </div>
#
# The dataset represents the global internet user penetration rate, expressed as a percentage. The data includes a single series with yearly observations.

# %%
# Plot the time series data
plt.figure(figsize=(12, 6))
sns.lineplot(data=world_df, x='Year', y='Internet Users(%)')
plt.title('Internet Users(%) over Time')
plt.xlabel('Year')
plt.ylabel('Internet Users(%)')
plt.show()

# %%
# Set the Year as the index
world_df.set_index('Year', inplace=True)

# Convert the index to a PeriodIndex with yearly frequency
world_df.index = pd.PeriodIndex(world_df.index, freq='A-DEC')

# Convert the index to datetime format for plotting
world_df.index = world_df.index.to_timestamp()

# %% [markdown]
# ## <div style="padding: 20px;color:white;margin:10;font-size:90%;text-align:left;display:fill;border-radius:10px;overflow:hidden;background-image: url(https://w0.peakpx.com/wallpaper/957/661/HD-wallpaper-white-marble-white-stone-texture-marble-stone-background-white-stone.jpg)"><b><span style='color:black'> 3. Methodology</span></b> </div>
#
# The dataset represents the global internet user penetration rate, expressed as a percentage. The data includes a single series with yearly observations.

# %%
# Decompose the time series
decomposition = seasonal_decompose(world_df['Internet Users(%)'], period=1)

# Plot the trend, seasonal, and residual components
decomposition.plot()
plt.show()

# %% [markdown]
# ## <div style="padding: 20px;color:white;margin:10;font-size:90%;text-align:left;display:fill;border-radius:10px;overflow:hidden;background-image: url(https://w0.peakpx.com/wallpaper/957/661/HD-wallpaper-white-marble-white-stone-texture-marble-stone-background-white-stone.jpg)"><b><span style='color:black'> 4. Model</span></b> </div>
#
# We have used the **<mark style="background-color:#16C2D5;color:white;border-radius:5px;opacity:1.0">SARIMAX</mark>** model, which is a generalization of **<mark style="background-color:#16C2D5;color:white;border-radius:5px;opacity:1.0">ARIMA</mark>**. **<mark style="background-color:#16C2D5;color:white;border-radius:5px;opacity:1.0">SARIMAX</mark>** models are denoted SARIMAX(p,d,q)(P,D,Q)m, where:
#
# * p, d, q are the non-seasonal parameters,
#
# * P, D, Q are the seasonal parameters, and
#
# * m is the number of periods per season.
#
# In our case, since we have no seasonality, the seasonal parameters were not utilized.

# %%
# Fit a SARIMAX model
model = SARIMAX(world_df['Internet Users(%)'], order=(1, 1, 1))
results = model.fit(disp=-1)

# Generate forecast for the next 5 years
future_years = [world_df.index[-1] + DateOffset(years=x) for x in range(1, 6)]
future_years_df = pd.DataFrame(index=future_years, columns=world_df.columns)
future_df = pd.concat([world_df, future_years_df])

# Predict for the next 5 years
future_df['forecast'] = results.predict(start = len(world_df), end = len(world_df) + 5, dynamic= True)

# Plot the original data, the fitted values, and the forecast
plt.figure(figsize=(12, 6))
plt.plot(future_df['Internet Users(%)'], label='Original')
plt.plot(future_df['forecast'], label='Forecast')
plt.legend(loc='best')
plt.show()

# %% [markdown]
# ## <div style="padding: 20px;color:white;margin:10;font-size:90%;text-align:left;display:fill;border-radius:10px;overflow:hidden;background-image: url(https://w0.peakpx.com/wallpaper/957/661/HD-wallpaper-white-marble-white-stone-texture-marble-stone-background-white-stone.jpg)"><b><span style='color:black'> 5. Results</span></b> </div>
#
# The model fit the data reasonably well and provided a forecast for the future global internet user penetration rates. **The prediction of the model for the next 5 years was displayed in a chart alongside the original data.**
#
#
#
# ## <div style="padding: 20px;color:white;margin:10;font-size:90%;text-align:left;display:fill;border-radius:10px;overflow:hidden;background-image: url(https://w0.peakpx.com/wallpaper/957/661/HD-wallpaper-white-marble-white-stone-texture-marble-stone-background-white-stone.jpg)"><b><span style='color:black'> 6. Conclusion</span></b> </div>
#
# The global internet user penetration rate appears to have a consistent upward trend over the years. The forecast suggests that this trend will continue in the future.
#
# <br>
#
# > However, it is worth noting that the forecast is based purely on past trends and does not take into account any potential socio-economic, technological, or political factors that could significantly influence future internet usage rates.
#
# <br>
#
# ***
#
# <br>
#
# <div style="text-align: center;">
#    <span style="font-size: 4.5em; font-weight: bold; font-family: Arial;">THANK YOU!</span>
# </div>
#
# <div style="text-align: center;">
#     <span style="font-size: 5em;">✔️</span>
# </div>
#
# <br>
#
# <div style="text-align: center;">
#    <span style="font-size: 1.4em; font-weight: bold; font-family: Arial; max-width:1200px; display: inline-block;">
#        If you discovered this notebook to be useful or enjoyable, I'd greatly appreciate any upvotes! Your support motivates me to regularly update and improve it. :-)
#    </span>
# </div>
#
# <br>
#
# <br>
#
#
#
#
# <div style="text-align: center;">
#    <span style="font-size: 1.6em; font-weight: bold;font-family: Arial;"><a href="https://www.kaggle.com/tumpanjawat/code">@pannmie</a></span>
# </div>
