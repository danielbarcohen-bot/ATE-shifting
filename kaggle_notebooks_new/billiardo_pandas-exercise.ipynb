# %% [markdown]
# # Pandas Exercise
#
# Latihan ini dirancang sebagai pengantar untuk memahami penggunaan dasar pandas dalam analisis data. Anda akan berinteraksi dengan data mengenai mahasiswa, termasuk informasi seperti ID, Nama, Gender, Nilai, Tanggal Ujian, Mata pelajaran, serta nilai UAS dan UTS. Dalam latihan ini, Anda akan belajar bagaimana membaca data, menghitung statistik sederhana, melakukan seleksi, dan mendapatkan wawasan awal tentang dataset. Latihan ini dirancang untuk memberi Anda pengalaman praktis dalam menggunakan pandas dan membangun dasar yang kuat untuk analisis data lebih lanjut.

# %% [markdown]
# **Instructions**
# Bersihkan data terlebih dahulu dengan mengganti tipe data dan mempersingkat gender dengan alias.

# %%
# Cleansing Data
...

# %% [markdown]
# ### 1. Berapa jumlah data dalam dataset?

# %% [markdown]
# ### 2. Berapa rata-rata nilai akhir (rata-rata Nilai) dari seluruh mahasiswa?

# %% [markdown]
# ### 3. Apakah ada mahasiswa perempuan yang mendapatkan nilai UAS lebih dari 80?

# %% [markdown]
# ### 4. Berapa jumlah mahasiswa laki-laki yang mengambil mata pelajaran Kimia?

# %% [markdown]
# ### 5. Siapa mahasiswa dengan nilai tertinggi?

# %% [markdown]
# ### 6. Berapa persentase mahasiswa perempuan dalam dataset?

# %% [markdown]
# ### 7. Mata pelajaran apa yang memiliki rata-rata nilai UTS tertinggi?

# %% [markdown]
# ### 8. Berapa jumlah mahasiswa yang mendapatkan nilai lebih dari 90 dalam setiap mata pelajaran?

# %% [markdown]
# ### 9. Berapa banyak mahasiswa yang ujian pada tanggal 15?

# %% [markdown]
# ### 10. Berapa jumlah rata-rata nilai UAS mahasiswa perempuan?

# %% [markdown]
# ### 11. Berapa banyak mahasiswa yang mendapatkan nilai UAS di atas 80?

# %% [markdown]
# ### 12. Tampilkan 3 mahasiswa dengan nilai UTS terendah beserta nama dan nilai UTS-nya?

# %% [markdown]
# ### 13. Berapa jumlah mahasiswa yang lulus (nilai >= 60) pada masing-masing mata pelajaran?

# %% [markdown]
# ### 14. Berapa rentang tanggal ujian pada dataset ini?

# %% [markdown]
# ### 15. Ada berapa mahasiswa yang mendapatkan nilai sempurna (95) pada ujian UAS?
