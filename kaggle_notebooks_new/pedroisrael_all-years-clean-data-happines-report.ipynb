# %% [markdown]
# *** For those of you who just want to do the analysis and not the cleansing:
# I bring you here a clean table with all years.***
#
#
# *** The table is in the "Data" section and the rest is just my explanation of how I made it, but you can trust it. ***

# %% [markdown]
# For the very few of you who want to know the process. Here I listed all the steps:
#
#
#
# Clean Data=
# I chose to clean the tables in excel + power query because they are small (excel can process them). And I consider its much simpler this way, they had a lot of problems which is easier to detect viewing them with these tools.
#
# Steps:
# all tables in 1 document
# look for differences between tables.
#
# table 2015=
# modify column names = shorter
#
# 2016=
# copy names from 2015
# st error from 2015 missing, I change 2015 and send this column last.
# 2 new columns in 2016 send them to the back
# reorder columns
# Now both tables with same column names and same order. With the difference that: depending on the table, some columns are completely empty
#
# 2017=
# copy names from 2016
# Column “Region” = Reorder 2015,2016 = send this column last
# reorder columns
#
# 2018=
# copy names from 2017
# reorder columns
#
# 2019=
# copy names from 2018
# reorder columns
#
#
# add column = “Year” for each table
# union tables
