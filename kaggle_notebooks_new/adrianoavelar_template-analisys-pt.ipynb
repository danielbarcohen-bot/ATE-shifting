# %% [markdown]
# <img src="http://www.mgroupholdingsinc.com/wp-content/uploads/2015/03/1900x400.jpg" width=1900px height=400px />

# %% [markdown]
# # Título do Kernel
#
# <h3>Descrição do Kernel:</h3>
# > Qual o objetivo do Kernel. Quais Técnicas/Modelos ele utiliza.

# %% [markdown]
# # Tabela de Conteúdo:
#
# **1. [Definição do Problema](#id1)** <br>
# **2. [Coleta e Obtenção dos Dados](#id2)** <br>
# **3. [Carregando e Verificando os dados](#id3)** <br>
# **4. [Pré-Processamento dos Dados](#id4)** <br>
# **5. [Criação do Modelo](#id5)** <br>
# **6. [Visualização e Análise dos Resultados](#id6)** <br>
# **7. [Conclusão](#id7)** <br>
# **8. [Referências](#ref)** <br>

# %% [markdown]
# <a id="id1"></a>
# # **1. Definição do Problema:**
# > Nesta seção, descreva o problema a ser abordado.<br>

# %% [markdown]
# <a id="id2"></a>
# # **2. Coleta e Obtenção dos Dados:**
# > Nesta seção, você deve descrever como a coleta dos dados foi conduzida. Qual metodologia foi usada. Formulários, perquisa boca a boca, telefone, os dados foram obtidos de terceiros etc..

# %% [markdown]
# <a id="id3"></a>
# # **3. Carregando e Verificando os dados:**
# > Nesta seção, inicia-se a codificação do problema e o primeiro passo é carregar os dados e fazer uma análise prévia das colunas da base.
# <br>Dica: `pandas.read_csv("nomeDaBase.csv", index_col='id')`

# %% [markdown]
# <h3>3.1 Cabeçalhos da base</h3>
# > Aqui imprima as 5 primeiras linhas da base<br>
# Dica: `base.head()`

# %% [markdown]
# <h3>3.2 Dicionário dos Dados</h3>
# > Caso seja necessário, coloque o dicionário dos dados da base, ou seja, o significado de cada coluna.

# %% [markdown]
# <a id="id4"></a>
# # **4. Pré-Processamento dos Dados:**
# Nesta seção, os dados serão tratados, limpos e preparados para o modelo.

# %% [markdown]
# <h3>4.1 Verificando a correlação entre as variáveis numéricas</h3>

# %% [markdown]
# > Nessa fase, você decidirá quais dados serão mantidos, quais serão corrigidos e quais são mais importantes para sua análise

# %% [markdown]
# <h3>4.2 Verificando os dados categóricos.</h3>
# > Verificar a variabilidade dos dados...<br>
# plotar gráficos de histogram, countplot e usar o value_counts para descobrir a variabilidade dos dados.

# %% [markdown]
# <h3>4.3 Verificando Valores Inconsistêntes </h3>
# > Verificar valores muito altos e ou muito baixos (outliers)

# %% [markdown]
# <h3>4.4 Verificando Valores Nulos </h3>
# > Verificar valores nulos (NaN) e/ou faltosos (Vazios)<br>
# Dica: `base.isnull().sum().sort_values(ascending=False)`

# %% [markdown]
# <h3>4.5 Transformar Dados Categóricos em Dados Numéricos</h3>
# > Após todos as análises e correções feitas anteriormente nos dados é necessário transformar os dados categóricos em dados numéricos. <br>
# Dica.: Usando o `pandas.get_dummies()`

# %% [markdown]
# <h3>4.6 Separar os dados de treinamento e teste</h3>
# A última parte do preprocessamento é separar os dados de treinamento e teste. Se a modelagem foi feita utilizando validação cruzada essa separação não é necessária.

# %% [markdown]
# <a id="id5"></a>
# # **5. Criação do Modelo:**
# > Nesta seção, o modelo será criado e treinado. Ainda não haverá teste, deixe os testes para a seção de análise.

# %% [markdown]
# <a id="id6"></a>
# # **6. Visualização e Análise dos Resultados:**
# > Esta seção é exclusiva para validar o modelo criado usando a base de testes. No final da seção, é preciso colocar a precisão atingida pelo modelo.

# %% [markdown]
# <a id="id7"></a>
# # **7. Conclusão:**
# > Nesta seção, você colocará a conclusão que você chegou sobre seu trabalho. Se esse kernel for de competição, aqui também é criado o arquivo de submissão final.

# %% [markdown]
# <a id="ref"></a>
# # **8. Referências:**
# > Coloque aqui toda e qualquer referência utilizada para a construção deste Kernel.

# %% [markdown]
# > **Nota**: Este Kernel é utilizado como template de WorkFlow para resolução de problemas.<br>
# Feito por [@AdrianoAvelar](https://www.kaggle.com/adrianoavelar)<br>
# Clone e Codifique.
