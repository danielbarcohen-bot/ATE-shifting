# %% [markdown]
# # Tutorial de Pandas en Python

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import pandas 
import numpy as np

# Set up code checking
from learntools.core import binder
binder.bind(globals())
from tutorial_basico_pandas_modulo import *


# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) 
# will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# Any results you write to the current directory are saved as output.

# %% [markdown]
# ## Leer un archivo de Excel
#
# Puedes leer desde un archivo de Excel usando el método read_excel() de pandas.
#
# El siguiente ejemplo muestra cómo leer de una hoja de Excel y, para ello,  usaremos una hoja de Excel con el siguiente contenido:
#
#
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Para leer un archivo de Excel,  pasaremos el nombre del archivo de Excel ('pandasExcel.xlsx') y el número de hoja del que necesitamos leer los datos ('Sheet1') al método read_excel(). El resultado es un objeto llamado DataFrame.
#
# El DataFrame es una estructura de 2 dimensiones etiquetada donde podemos almacenar datos de diferentes tipos. DataFrame es similar a una tabla SQL o una hoja de cálculo de Excel.

# %%
df_excel = ___
df_excel

# %%
step1.check()

# %%
step1.solution()

# %% [markdown]
# ## Importar archivo CSV
#
# Para leer un archivo CSV, puedes usar el método read_csv() de pandas. También podemos usar el método read_csv() de pandas para leer desde un archivo de texto.
#
# Para hacerlo usaremos el fihero "Book1.csv" con el siguiente contenido:
#
# ![image.png](attachment:image.png)

# %%
df_book = ___
df_book

# %%
step2.check()

# %%
step2.solution()

# %% [markdown]
# ## Seleccionar columnas
#
# En este ejemplo, usaremos un fichero CSV llamado “Empleado”. Usando el método read_csv() de pandas  recuperaremos todos los datos de la tabla contenida.
#
# Supongamos que tenemos tres columnas en la tabla “Empleado” de esta manera:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Seleccionar una columna de una tabla accediendo al DataFrame. Considera el  ejemplo de mostrar el contenido de la columna 'Name'.

# %%
df_csv = pandas.read_csv('/kaggle/input/basic-pandas-dataset/Employee.csv', delimiter=';')
df_csv

# %%
df_col = ___
df_col

# %%
step3.check()

# %%
step3.solution()

# %% [markdown]
# ## Seleccionar filas por valor
#
# Primero, crearemos un DataFrame desde el cual seleccionaremos filas. En este código, crearemos un DataFrame con tres columnas y tres filas usando el método DataFrame() de pandas.
#
# Para crear el DataFrame, considera los datos incluidos en la tabla “Empleado”.

# %% [markdown]
# DataFrame.loc[] es un método que se puede usar para acceder a filas o columnas mediante valores o etiquetas. En el código a escribir, se buscará la fila donde el nombre es igual a "Jason".

# %%
df_csv = pandas.read_csv('/kaggle/input/basic-pandas-dataset/Employee.csv', delimiter=';')
df_csv

# %%
df_loc = ___
df_loc

# %%
step4.check()

# %%
step4.solution()

# %% [markdown]
# ## Seleccionar fila por índice
#
# Para seleccionar una fila por su índice, podemos usar el operador de segmentación (:) o el método df.loc[].

# %% [markdown]
# Como ya hemos visto, para a acceder a una fila podemos usar df.loc[]. Ahora, podemos hacer lo mismo usando el operador de segmentación (:).

# %%
df_csv = pandas.read_csv('/kaggle/input/basic-pandas-dataset/Employee.csv', delimiter=';')
df_csv

# %%
df_row = ___
df_row

# %%
step5.check()

# %%
step5.solution()

# %% [markdown]
# ## Aplicar una función a columnas y filas
#
# Para aplicar una función en una columna o fila, puedes usar el método apply() de DataFrame.
#
# Creamos un DataFrame y agregamos valores de tipo entero en las filas.

# %%
data = {'A': [2, 1, 3], 'B': [18, 20, 22], 'C': [54, 12, 12]}
 
df_data = pandas.DataFrame(data)
df_data

# %% [markdown]
# Entonces, para aplicar una función (por ejemplo, la raíz cuadrada) a los valores, necesitamos importar primero el módulo numpy para usar la función sqrt.

# %%
df_sqrt = ___
df_sqrt

# %%
step6.check()

# %%
step6.solution()

# %% [markdown]
# Para aplicar una función (por ejemplo, la raíz cuadrada) a una columna especifica, puedes especificar la columna deseada.

# %%
data = {'A': [2, 1, 3], 'B': [18, 20, 22], 'C': [54, 12, 12]}
 
df_data = pandas.DataFrame(data)
df_data

# %%
df_sqrt_col = ___
df_sqrt_col

# %%
step7.check()

# %%
step7.solution()

# %% [markdown]
# ## Ordenar valores y ordenar por columna
#
# Para ordenar los valores en un DataFrame, utiliza el método sort_values() del DataFrame. Este método  tiene un atributo “by” que es necesario.
#
# Ahora para ordenar los valores podemos usar el DataFrame con valores enteros y usar la columna 'A' para hacerlo.

# %%
data = {'A': [2, 1, 3], 'B': [18, 20, 22], 'C': [54, 12, 12]}
 
df_data = pandas.DataFrame(data)
df_data

# %%
df_sort = ___
df_sort

# %%
step8.check()

# %%
step8.solution()

# %% [markdown]
# También podemos ordenar por varias columnas, por ejemplo, por las columnas 'C' y 'B'.

# %%
data = {'A': [2, 1, 3], 'B': [18, 20, 22], 'C': [54, 12, 12]}
 
df_data = pandas.DataFrame(data)
df_data

# %%
df_sort_cols = ___
df_sort_cols

# %%
step9.check()

# %%
step9.solution()

# %% [markdown]
# También podemos ordenar los valores incluidos en la tabla "Empleado"  y usar la columna 'Salary' para hacerlo.

# %%
df_csv = pandas.read_csv('/kaggle/input/basic-pandas-dataset/Employee.csv', delimiter=';')
df_csv

# %%
df_sort_salary = ___
df_sort_salary

# %%
step10.check()

# %%
step10.solution()

# %% [markdown]
# Si desea ordenar en orden descendente, establece el atributo ascending de sort_values a False.

# %%
df_csv = pandas.read_csv('/kaggle/input/basic-pandas-dataset/Employee.csv', delimiter=';')
df_csv

# %%
df_no_asc = ___
df_no_asc

# %%
step11.check()

# %%
step11.solution()

# %% [markdown]
# ## Eliminar duplicados
#
# Para eliminar filas duplicadas de un DataFrame, usa el método drop_duplicates() del DataFrame.
#
# Aquí debemos usar un DataFrame con alguna fila duplicada.  Para verificar si hay filas duplicadas en el DataFrame, usa el método duplicated() del DataFrame.
#
# Aquí puedes ver que los datos de "Jason" esta dos veces.

# %%
data = {
    'Name': ['James', 'Jason', 'Rogers', 'Jason'], 
    'Age': [18, 20, 22, 20], 
    'Job': ['Assistant', 'Manager', 'Clerk', 'Manager']
}
 
df_tmp = pandas.DataFrame(data)

df_tmp

# %%
df_dupl = ___
df_dupl

# %%
step12.check()

# %%
step12.solution()

# %%
df_drop_dupl = ___
df_drop_dupl

# %%
step13.check()

# %%
step13.solution()

# %% [markdown]
# ## Eliminar duplicados por columna
#
# A veces, tenemos datos en los que los valores de las columnas son los mismos y deseamos eliminarlos. Podemos eliminar una fila por columna al pasar el nombre de la columna que debemos eliminar.
#
# Ahora podemos usar el DataFrame de valores de tipo entero en las filas donde se puede ver que el valor 12 esta dos veces en la columna "A".

# %%
data = {'A': [2, 1, 3], 'B': [18, 20, 22], 'C': [54, 12, 12]}
 
df_data = pandas.DataFrame(data)
df_data

# %%
df_dupl_data = df_data.duplicated()
df_dupl_data

# %%
df_drop_dupl_data = ___
df_drop_dupl_data

# %%
step14.check()

# %%
step14.solution()

# %% [markdown]
# ## Elimnar una columna
#
# Para eliminar una columna o fila completa, podemos usar el método drop() del DataFrame especificando el nombre de la columna o fila.
#
# En este caso vamos a eliminar  la columna llamada “Job” para el DataFrame con la tabla "Empleado".
#
# El argumento del eje es necesario aquí. Si el valor del eje es 1 significa que queremos eliminar columnas y si el valor del eje es 0 significa que la fila se eliminará.

# %%
df_csv = pandas.read_csv('/kaggle/input/basic-pandas-dataset/Employee.csv', delimiter=';')
df_csv

# %%
df_drop_col = ___
df_drop_col

# %%
step15.check()

# %%
step15.solution()

# %% [markdown]
# ## Eliminar filas
#
# Podemos usar el método drop() para eliminar una fila al pasar el índice de la fila.
#
#  Eliminar una fila con el índice 0 en el DataFrame con la tabla "Empleado".

# %%
df_csv = pandas.read_csv('/kaggle/input/basic-pandas-dataset/Employee.csv', delimiter=';')
df_csv

# %%
df_drop = ___
df_drop

# %%
step16.check()

# %%
step16.solution()

# %% [markdown]
# Ahora vamos a crear un DataFrame donde los índices son los nombres. Entonces,  podemos eliminar una fila con un cierto valor. En este caso,  queremos eliminar la fila donde el nombre es "Rogers".

# %%
data = {
    'Name': ['James', 'Jason', 'Rogers'], 
    'Age': [18, 20, 22], 
    'Job': ['Assistant', 'Manager', 'Clerk']
}
 
df_names = pandas.DataFrame(data, index = ['James', 'Jason', 'Rogers'])
df_names

# %%
df_drop_name = ___
df_drop_name

# %%
step17.check()

# %%
step17.solution()

# %% [markdown]
# También podemos eliminar un rango de filas. Lo que queremos es eliminar las filas del índice 0 a 1 con lo que solo quedará una fila ya que nuestro DataFrame se compone de 3 filas.

# %%
data = {
    'Name': ['James', 'Jason', 'Rogers'], 
    'Age': [18, 20, 22], 
    'Job': ['Assistant', 'Manager', 'Clerk']
}
 
df_names = pandas.DataFrame(data, index = ['James', 'Jason', 'Rogers'])
df_names

# %%
df_rows = ___
df_rows

# %%
step18.check()

# %%
step18.solution()

# %% [markdown]
# Si deseamos eliminar la última fila del DataFrame y no sabemos cuál es el número total de filas, podemos utilizar la indexación negativa.
#
# Es decir, el índice -1 borra la última fila y, similarmente, el indice -2 borrará las últimas 2 filas y así sucesivamente.

# %%
data = {
    'Name': ['James', 'Jason', 'Rogers'], 
    'Age': [18, 20, 22], 
    'Job': ['Assistant', 'Manager', 'Clerk']
}
 
df_names = pandas.DataFrame(data, index = ['James', 'Jason', 'Rogers'])
df_names

# %%
df_last_row = ___
df_last_row

# %%
step19.check()

# %%
step19.solution()
