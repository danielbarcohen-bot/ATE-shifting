# %% [markdown]
# ![iş bankası.jpg](attachment:172e8fd7-97d6-4a97-b59e-509ecccce6b8.jpg)

# %% [markdown]
# <div style="background-color: #ffe0b2; padding: 10px 20px; border: 1px solid #ff9800; border-radius: 10px; text-align: center; margin: 20px 0;">
#     <h2 style="color: #000000; font-weight: bold;">🚀 İş Problemi 🚀</h2>
# </div>

# %% [markdown]
# <div style="background-color: #e0f7fa; padding: 30px; border: 1px solid #0097a7; border-radius: 15px;">
#
# <h2 style="color: #000000; font-weight: bold; border-bottom: 3px solid #0097a7;">🎉 Genç Yeteneklere Özel Machine Learning Challenge 🎉</h2>
#
# <h3 style="color: #000000; font-weight: bold;">📱 Overview 📱</h3>
# <p>
# Hayatımızın vazgeçilmez bir parçası olan akıllı telefonlar ve mobil uygulamalar gündelik işlerimizi son derece kolay hale getirebilmektedir. Ancak tüm kullanıcılara hitap etmesi için tasarlanan bu uygulamalar, kullanıcı deneyiminin kişiselleştirilmesi konusunda yetersiz kalabilmektedir.
# </p>
# <p>
# Tüm kullanıcılar aynı mobil uygulama üzerinden işlemlerini gerçekleştiriyor olsa da, her bir kullanıcının öncelikli olarak kullandığı belli başlı menüler bulunmaktadır. Bu menülerin kişiselleştirilmiş ve müşteri ihtiyaçlarını karşılayacak şekilde kullanıcıya önerilmesi, hem zaman kazandıracak hem de kişiye özel bir arayüz ile kullanıcı deneyimini önemli ölçüde artıracaktır. Tavsiye mekanizmaları ve makine öğrenmesi yardımıyla bu konuda iyileştirmeler yapılabilecektir.
# </p>
# <p>
# <b>Sizden beklenen</b>, bir mobil uygulamanın kullanım verileriyle bir yapay zeka modeli geliştirerek her bir kullanıcıya o uygulamada en çok ihtiyaç duyacağı menüyü önermenizdir.Veri setinde hedef olarak, her bir kullanıcının geçmiş kullanımında tercih ettiği menüleri binary olarak belirten 9 tane menü yer almaktadır. Bu 9 menüden hangi 3 tanesinin kullanıcı arayüzüne ekleneceğini tahminlemeniz gerekmektedir.
# </p>
# <p style="color: #ff6f00; font-weight: bold;">
# 🛡️ Bir tavsiye mekanizması geliştirmeniz beklenen bu problemde yaratıcı çözümlerinizi bekliyoruz! 🛡️
# </p>
#
# <h3 style="color: #000000; font-weight: bold;">📊 Evaluation 📊</h3>
# <p>
# Metrik kriteri olarak <b>Jaccard Score</b> belirlenmiştir. Her bir menünün önerilip önerilmeyeceğini gösteren 9 adet binary değerden oluşan tahminleriniz bu metrik ile kıyaslanacaktır. Yarışma tamamlandığında Private Leaderboard'da toplamda en iyi tahmin skoruna önce ulaşan yarışmacı final sunumu yapmaya hak kazanacaktır.
# </p>
# <p>
# <b>Örnek çıktı:</b>
# <ul>
#   <li>Müşteri A -> 000101010 (Müşteri A’ya 4., 6., ve 8. Menüler önerilmesi tahminlenmiştir.)</li>
#   <li>Müşteri B -> 100000011 (Müşteri A’ya 1., 8., ve 9. Menüler önerilmesi tahminlenmiştir.)</li>
# </ul>
# <b><i>*Tahminlerin yalnızca 3 adet menüyü içermesi gerekmektedir.</i></b>
# </p>
#
# </div>

# %% [markdown]
# <div style="background-color: #ffe0b2; padding: 10px 20px; border: 1px solid #ff9800; border-radius: 10px; text-align: center; margin: 20px 0;">
#     <h2 style="color: #000000; font-weight: bold;">📖 Veri Seti Hikayesi 📖</h2>
# </div>

# %% [markdown]
# <div style="background-color: #f3e5f5; padding: 30px; border: 1px solid #9c27b0; border-radius: 15px;">
#
# <h2 style="color: #6a1b9a; font-weight: bold; border-bottom: 3px solid #9c27b0;">📊 Veri Seti Bilgileri 📊</h2>
#
# <h3 style="color: #4a148c; font-weight: bold;">Dosyalar:</h3>
# <ul>
#     <li><b>train_final.parquet</b> - Eğitim veri seti.</li>
#     <li><b>test_final.parquet</b> - Test veri seti.</li>
#     <li><b>submission_sample_final.parquet</b> - Doğru formatı gösteren örnek cevap dosyası.</li>
# </ul>
#
# <h3 style="color: #4a148c; font-weight: bold;">Veri Zaman Aralığı:</h3>
# <ul>
#     <li><b>Train Veri Seti:</b> 2022 yılının Ekim, Kasım ve Aralık aylarına ait veriler.</li>
#     <li><b>Test Veri Seti:</b> 2023 yılının Ocak ayına ait veriler.</li>
# </ul>
#
# <h3 style="color: #4a148c; font-weight: bold;">Sütunlar:</h3>
# <ul>
#     <li><b>ID:</b> Maskelenmiş müşteri ID'si.</li>
#     <li><b>MONTH:</b> İşlemin yapıldığı ay.</li>
#     <li><b>N_SECONDS_[*]:</b> Menülerde geçirilen süre (target sıralaması ile).</li>
#     <li><b>CARRIER:</b> İşlemin yapıldığı telefon hattı.</li>
#     <li><b>DEVICEBRAND:</b> İşlemin yapıldığı cihaz markası.</li>
#     <li><b>FEATURE_[*]:</b> Müşteriye özgü maskelenmiş öznitelikler.</li>
#     <li><b>TARGET:</b> Müşterinin belirli bir ayda en çok vakit geçirdiği 3 menü için 0-1 değerlerinden oluşan tanımlayıcı değer.</li>
# </ul>
#
# </div>

# %% [markdown]
# <div style="background-color: #ffe0b2; padding: 10px 20px; border: 1px solid #ff9800; border-radius: 10px; text-align: center; margin: 20px 0;">
#     <h2 style="color: #000000; font-weight: bold;">🧭 Yol Haritası 🧭</h2>
# </div>

# %% [markdown]
# <div style="background-color: #ffebee; padding: 20px 40px; border: 1px solid #f44336; border-radius: 15px;">
#
# <h2 style="color: #b71c1c; font-weight: bold; border-bottom: 3px solid #f44336; padding-bottom: 10px;">🧭 Yol Haritası 🧭</h2>
#
# <ol style="font-weight: bold; color: #000000;">
#     <li>📚 Gerekli Kütüphanelerin Yüklenmesi</li>
#     <li>📐 Satır Sütun Ayarlarının Yapılması</li>
#     <li>🔍 Veri Setlerinin Yüklenmesi</li>
#     <li>🔎 Keşifçi Veri Analizinin Yapılması</li>
#     <li>📊 Kategorik ve Nümerik Değişkenlerin Tespiti</li>
#     <li>🔖 Kategorik Değişken Analizi</li>
#     <li>📈 Nümerik Değişken Analizi</li>
#     <li>🎯 Hedef Değişkene Göre Kategorik Değişken Analizi</li>
#     <li>📉 Hedef Değişkene Göre Nümerik Değişken Analizi</li>
#     <li>🧲 Kolerasyon Analizi</li>
#     <li>🎲 Bağımlı (Hedef) Değişkenin Dağılımları</li>
#     <li>❓ Eksik Değer Analizi</li>
#     <li>⚠️ Aykırı Değer Analizi</li>
#     <li>🛠️ Özellik Çıkarım İşlemleri</li>
#     <li>🔄 Encoding İşlemleri</li>
#     <li>📏 Standartlaştırma İşlemleri</li>
#     <li>🤖 Modelleme İşlemleri</li>
# </ol>
#
# </div>

# %% [markdown]
# <div style="background-color: #ffe0b2; padding: 10px 20px; border: 1px solid #ff9800; border-radius: 10px; text-align: center; margin: 20px 0;">
#     <h2 style="color: #000000; font-weight: bold;">🚀 Çözüm Stratejisi ve Yaklaşım 🚀</h2>
# </div>

# %% [markdown]
# <div style="background-color: #f3e5f5; padding: 20px 40px; border: 1px solid #aa00ff; border-radius: 15px;">
#
# <h2 style="color: #7b1fa2; font-weight: bold; border-bottom: 3px solid #aa00ff; padding-bottom: 10px;">🚀 Çözüm Stratejisi ve Yaklaşım 🚀</h2>
#
# <p style="font-weight: bold; color: #000000;">
# Mobil uygulama kullanıcıları için en alakalı menü önerilerini sağlamak amacıyla bir makine öğrenimi yaklaşımı benimsedik. Bu süreçte, LightGBM sınıflandırıcısını tercih ettik. LightGBM, yüksek performanslı ve hızlı bir gradyan artırma algoritmasıdır. Özellikle büyük veri setleriyle çalışırken etkilidir ve diğer algoritmalara kıyasla daha yüksek Jaccard Skoru elde etmemizi sağlar.
# </p>
#
# <h3 style="color: #8e24aa; font-weight: bold;">Eğitim Veri Seti Üzerinde İşlemler:</h3>
#
# <ul>
#     <li>İlk olarak, hedef değişken olan menülerin sütunu virgülle ayrılarak listeye dönüştürüldü ve MultiLabelBinarizer kullanılarak binarize edildi.</li>
#     <li>Carrier ve Devicebrand sütunları için en yaygın kategorileri koruyarak diğerlerini "Other" olarak etiketledik ve bu kategorik sütunları LabelEncoder ile numerik değerlere dönüştürdük.</li>
#     <li>Sonraki adımda, veri setini eğitim ve doğrulama setlerine ayırdık.</li>
#     <li>Etiket frekanslarına dayanarak sınıf dengesizliklerini gidermek için sınıf ağırlıkları hesaplandı.</li>
#     <li>LightGBM sınıflandırıcısı kullanılarak her menü için bağımsız sınıflandırma modelleri eğitildi. Eğitilen bu modellerle doğrulama seti üzerinden tahminlerde bulunuldu ve bu tahminlerin performansı Jaccard Skoru ile değerlendirildi.</li>
# </ul>
#
# <h3 style="color: #8e24aa; font-weight: bold;">Test Veri Seti Üzerinde İşlemler:</h3>
#
# <ul>
#     <li>Test veri setinde de aynı kategorik sütun dönüşümleri gerçekleştirildi.</li>
#     <li>Daha sonra, eğitilen LightGBM modeli OneVsRestClassifier ile sarılarak çoklu sınıflandırma için uygundur hale getirildi ve bu model eğitim veri seti üzerinde eğitildi.</li>
#     <li>Test seti üzerinden olasılık tahminleri yapıldı. Bu tahminler arasından her bir kullanıcı için en yüksek 3 olasılığa sahip menüler seçildi ve bu menüler için öneri tahminleri oluşturuldu.</li>
#     <li>Sonuçlar, kullanıcıların ID'leriyle birlikte bir veri çerçevesine kaydedildi ve bu veri çerçevesi CSV dosyası olarak kaydedildi.</li>
# </ul>
#
# <p style="color: #7b1fa2; font-weight: bold;">
# Bu stratejik yaklaşımın, mobil uygulama kullanıcıları için daha kişiselleştirilmiş bir deneyim sağlamada etkili olacağını umuyoruz.
# </p>
#
# </div>

# %% [markdown]
# <div style="background-color: #ffe0b2; padding: 10px 20px; border-radius: 15px; margin-bottom: 20px;">
#     <h3 style="color: #000000; font-weight: bold;">1. 📚 Gerekli Kütüphanelerin Yüklenmesi</h3>
# </div>

# %%
import warnings
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import missingno as msno
import joblib
import graphviz
import plotly.graph_objects as go
from scipy import stats
from datetime import date

# Scikit-Learn utilities and models
from sklearn.model_selection import train_test_split, GridSearchCV, cross_validate, RandomizedSearchCV, validation_curve
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier, VotingClassifier
from sklearn.multioutput import MultiOutputClassifier
from sklearn.metrics import jaccard_score, accuracy_score, precision_score, recall_score, f1_score, roc_auc_score, classification_report
from sklearn.feature_selection import SelectKBest, chi2, mutual_info_classif
from sklearn.preprocessing import LabelBinarizer, StandardScaler, MinMaxScaler, LabelEncoder, RobustScaler, OneHotEncoder
from sklearn.multiclass import OneVsRestClassifier
from sklearn.tree import DecisionTreeClassifier, export_graphviz, export_text
from sklearn.neighbors import KNeighborsClassifier, LocalOutlierFactor
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import MultiLabelBinarizer

# Gradient Boosting Classifiers
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier
from catboost import CatBoostClassifier

# Set warnings to ignore
warnings.simplefilter(action="ignore")

# %% [markdown]
# <div style="background-color: #ffe0b2; padding: 10px 20px; border-radius: 15px; margin-bottom: 20px;">
#     <h3 style="color: #000000; font-weight: bold;">2. 📐 Satır Sütun Ayarlarının Yapılması</h3>
# </div>

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.width', 1000)
pd.set_option('display.max_rows', None)
pd.set_option('display.float_format', lambda x: '%.3f' % x)

# %% [markdown]
# <div style="background-color: #ffe0b2; padding: 10px 20px; border-radius: 15px; margin-bottom: 20px;">
#     <h3 style="color: #000000; font-weight: bold;">3. 🔍 Veri Setlerinin Yüklenmesi</h3>
# </div>

# %%
# Submission Verisini Yükle
submission_data = pd.read_parquet('/kaggle/input/turkiye-is-bankasi-ml-challenge-5/submission_sample_final.parquet', engine='pyarrow')

# %%
submission_data.head()

# %%
# Test Verisini Yükle
test_data = pd.read_parquet('/kaggle/input/turkiye-is-bankasi-ml-challenge-5/test_final.parquet', engine='pyarrow')

# %%
test_data.head()

# %%
# Train verisini Yükle
train_data = pd.read_parquet('/kaggle/input/turkiye-is-bankasi-ml-challenge-5/train_final.parquet', engine='pyarrow')

# %%
train_data.head()

# %% [markdown]
# <div style="background-color: #ffe0b2; padding: 10px 20px; border-radius: 15px; margin-bottom: 20px;">
#     <h3 style="color: #000000; font-weight: bold;">4. 🔎 Keşifçi Veri Analizinin Yapılması</h3>
# </div>

# %%
def check_df(dataframe, head=5):
    print('##################### Shape #####################')
    print(dataframe.shape)
    print('##################### Types #####################')
    print(dataframe.dtypes)
    print('##################### Head #####################')
    print(dataframe.head(head))
    print('##################### Tail #####################')
    print(dataframe.tail(head))
    print('##################### NA #####################')
    print(dataframe.isnull().sum())
    print('##################### Quantiles #####################')
    print(dataframe.describe([0, 0.05, 0.50, 0.95, 0.99, 1]).T)

# %%
check_df(train_data)

# %% [markdown]
# <div style="background-color: #00CED1; padding: 10px 20px; border-radius: 15px; margin-bottom: 20px;">
#     <h3 style="color: #000000; font-weight: bold;">1. Bölüm: 🚂 Eğitim Verisi Üzerinde Ön İşleme Adımları ve Modelleme</h3>
# </div>

# %% [markdown]
# <div style="background-color: #ffe0b2; padding: 10px 20px; border-radius: 15px; margin-bottom: 20px;">
#     <h3 style="color: #000000; font-weight: bold;">5. 📊 Kategorik ve Nümerik Değişkenlerin Tespiti</h3>
# </div>

# %%
def grab_col_names(dataframe, cat_th=10, car_th=20):
    """

    Returns the names of categorical, numeric and categorical but cardinal variables in the data set.
    Note Categorical variables include categorical variables with numeric appearance.

    Parameters
    ------
        dataframe: dataframe
                Variable names of the dataframe to be taken
        cat_th: int, optional
                class threshold for numeric but categorical variables
        car_th: int, optinal
                class threshold for categorical but cardinal variables

    Returns
    ------
        cat_cols: list
                Categorical variable list
        num_cols: list
                Numeric variable list
        cat_but_car: list
                List of cardinal variables with categorical appearance

    Examples
    ------
        import seaborn as sns
        df = sns.load_dataset("iris")
        print(grab_col_names(df))


    Notes
    ------
        cat_cols + num_cols + cat_but_car = total number of variables
        num_but_cat is inside cat_cols.
        The sum of the 3 return lists equals the total number of variables: cat_cols + num_cols + cat_but_car = number of variables

    """

    # cat_cols, cat_but_car
    cat_cols = [col for col in dataframe.columns if dataframe[col].dtypes == "O"] 

    num_but_cat = [col for col in dataframe.columns if dataframe[col].nunique() < cat_th and
                   dataframe[col].dtypes != "O"]

    cat_but_car = [col for col in dataframe.columns if dataframe[col].nunique() > car_th and
                   dataframe[col].dtypes == "O"]

    cat_cols = cat_cols + num_but_cat

    cat_cols = [col for col in cat_cols if col not in cat_but_car] 

    num_cols = [col for col in dataframe.columns if dataframe[col].dtypes != "O"] 

    num_cols = [col for col in num_cols if col not in num_but_cat] 
    
    print(f"Observations: {dataframe.shape[0]}") 
    print(f"Variables: {dataframe.shape[1]}") 
    print(f'cat_cols: {len(cat_cols)}') 
    print(f'num_cols: {len(num_cols)}') 
    print(f'cat_but_car: {len(cat_but_car)}') 
    print(f'num_but_cat: {len(num_but_cat)}') 


    return cat_cols, num_cols, cat_but_car, num_but_cat

# %%
cat_cols, num_cols, cat_but_car,  num_but_cat = grab_col_names(train_data)

# %%
cat_cols

# %%
num_cols

# %%
cat_but_car

# %%
num_but_cat

# %% [markdown]
# <div style="background-color: #f3e5f5; padding: 15px; border: 1px solid #7b1fa2; border-radius: 15px; margin-bottom: 20px;">
#     <h4 style="color: #6a1b9a; font-weight: bold;">📌 Bilgi Notu-1:</h4>
#     <p style="color: #4a148c; font-weight: bold;">Bundan sonraki analizlerde hatalı analizler yapmamak için bazı değişkenlerde tip dönüşümleri ve hedef değişkenimizde bazı işlemler yapmamız gerekecek.</p>
# </div>

# %%
cat_cols = ['carrier', 'devicebrand']

# %%
cat_cols

# %%
num_cols

# %%
num_cols = num_cols + ['month']

# %%
num_cols

# %%
cat_but_car = ['id']

# %%
cat_but_car

# %%
num_but_cat =[]

# %%
num_but_cat

# %% [markdown]
# <div style="background-color: #f3e5f5; padding: 15px; border: 1px solid #7b1fa2; border-radius: 15px; margin-bottom: 20px;">
#     <h4 style="color: #6a1b9a; font-weight: bold;">📌 Bilgi Notu-2:</h4>
#     <p style="color: #4a148c; font-weight: bold;"> Değişken tipleri ile ilgili bazı gerekli değişiklikleri yaptık. Sırada Hedef(target) değişkeni ile ilgili gerekli dönüşümlerin yapılması işlemi vardır.</p>
# </div>

# %%
from sklearn.preprocessing import MultiLabelBinarizer

# 'target' sütununu virgülle ayır ve listeye çevir
train_data['target'] = train_data['target'].str.split(', ')

# MultiLabelBinarizer ile 'target' sütununu binarize edin
mlb = MultiLabelBinarizer()
target_binarized = mlb.fit_transform(train_data['target'])

# Binarize edilmiş target değerlerini DataFrame'e çevir ve sütun isimlerini ayarla
target_df = pd.DataFrame(target_binarized, columns=mlb.classes_)

# Binarize edilmiş target değerlerini göster
target_df.head()

# %%
# 'target' sütununu train_data veri setinden kaldır
train_data = train_data.drop(columns=['target'])

# %%
train_data.head()

# %% [markdown]
# <div style="background-color: #ffe0b2; padding: 10px 20px; border-radius: 15px; margin-bottom: 20px;">
#     <h3 style="color: #000000; font-weight: bold;">6. 🔖 Kategorik Değişken Analizi</h3>
# </div>

# %%
def cat_summary(dataframe, col_name, plot=False):
    # En çok sayıda olan 10 sınıfı ve oranları
    top_10 = dataframe[col_name].value_counts().head(10)
    top_10_ratio = 100 * top_10 / len(dataframe)
    
    # Diğer sınıfların toplam sayısı ve oranı
    other_count = dataframe[col_name].value_counts()[10:].sum()
    other_ratio = 100 * other_count / len(dataframe)
    
    # Sonuçları DataFrame olarak birleştirme
    result = pd.concat([top_10, top_10_ratio], axis=1, keys=[col_name, 'Ratio (%)'])
    # **`append()` fonksiyonunu `concat()` fonksiyonuyla değiştiriyoruz.**
    result = pd.concat([result, pd.Series({col_name: other_count, 'Ratio (%)': other_ratio}, name='Other')], axis=0)
    
    print(result)
    print('##########################################')
    
    if plot:
        # **Grafik boyutlarını ayarlıyoruz.**
        fig, ax = plt.subplots(figsize=(10, 6))
        sns.countplot(x=dataframe[col_name], data=dataframe, order=result.index, ax=ax)
        ax.set_xticklabels(ax.get_xticklabels(), rotation=45)
        plt.show(block=True)

# %%
for col in cat_cols:
    cat_summary(train_data, col, plot=True)

# %% [markdown]
# <div style="background-color: #ffe0b2; padding: 10px 20px; border-radius: 15px; margin-bottom: 20px;">
#     <h3 style="color: #000000; font-weight: bold;">7. 📈 Nümerik Değişken Analizi</h3>
# </div>

# %%
def num_summary_horizontal_boxplot(dataframe, numerical_col, plot=False):
    quantiles = [0.05, 0.10, 0.20, 0.30, 0.40, 0.50, 0.60, 0.70, 0.80, 0.90, 0.95, 0.99]
    print(dataframe[numerical_col].describe(quantiles).T)

    if plot:
        # Grafik boyutunu ayarlıyoruz.
        plt.figure(figsize=(15, 6))
        
        # İlk grafik: distplot
        plt.subplot(1, 2, 1)
        sns.distplot(dataframe[numerical_col], bins=20)
        plt.title(f"Distribution of {numerical_col}")
        
        # İkinci grafik: boxplot with horizontal orientation
        plt.subplot(1, 2, 2)
        sns.boxplot(x=dataframe[numerical_col], orient="h")
        plt.title(f"Boxplot of {numerical_col}")
        
        plt.tight_layout()
        plt.show(block=True)

# İlk 5 numerik sütun için örnek olarak num_summary_horizontal_boxplot fonksiyonunu çalıştıralım
for col in num_cols[:5]:  # buradaki rakamı değiştirerek istediğiniz kadar özelliği inceleyebilriz.
    num_summary_horizontal_boxplot(train_data, col, plot=True)

# %% [markdown]
# <div style="background-color: #ffe0b2; padding: 10px 20px; border-radius: 15px; margin-bottom: 20px;">
#     <h3 style="color: #000000; font-weight: bold;">8. 🎯 Hedef Değişkene Göre Kategorik Değişken Analizi</h3>
# </div>

# %%
# Seaborn'un stilini "darkgrid" olarak ayarlayalım
sns.set_style("darkgrid")

# Bu analiz için hedef değişkenler ile train veri setini birleştirelim
merged_data = pd.concat([train_data, target_df], axis=1)

def target_summary_with_beautified_output(dataframe, target_df, categorical_col, plot=False):
    # En yüksek frekansta olan ilk 20 sınıfı seç
    top_20_cats = dataframe[categorical_col].value_counts().head(20).index
    
    # DataFrame'de bu sınıflar dışındakileri 'Other' olarak değiştir
    dataframe_copy = dataframe.copy()
    dataframe_copy[categorical_col] = np.where(dataframe_copy[categorical_col].isin(top_20_cats), 
                                               dataframe_copy[categorical_col], 
                                               'Other')
    
    # Hedef değişkenlerin her biri için ayrı ayrı bu işlemi yapacağız
    for target_col in target_df.columns:
        print(f"\033[1mAnalysis for Target: {target_col}\033[0m")
        print("----------------------------------")
        result = dataframe_copy.groupby(categorical_col)[target_col].mean().reset_index()
        display(result.style.background_gradient(cmap="Blues"))
        print("\n\n")
        
        if plot:
            plt.figure(figsize=(16, 6))
            sns.barplot(x=categorical_col, y=target_col, data=dataframe_copy, ci=None, palette="coolwarm")
            plt.title(f"Mean of {target_col} by {categorical_col}", fontsize=16)
            plt.xticks(rotation=45, fontsize=12)
            plt.yticks(fontsize=12)
            plt.xlabel(categorical_col, fontsize=14)
            plt.ylabel(f"Mean of {target_col}", fontsize=14)
            plt.tight_layout()
            plt.show(block=True)

# 'carrier' ve 'devicebrand' kategorik sütunları için bu fonksiyonu çalıştıralım
for col in cat_cols:
    target_summary_with_beautified_output(merged_data, target_df, col, plot=True)

# %% [markdown]
# <div style="background-color: #ffe0b2; padding: 10px 20px; border-radius: 15px; margin-bottom: 20px;">
#     <h3 style="color: #000000; font-weight: bold;">9. 📉 Hedef Değişkene Göre Nümerik Değişken Analizi</h3>
# </div>

# %%
def target_summary_with_num_custom(dataframe, numerical_cols=None, target_cols=None, plot=False):
    # Eğer nümerik değişkenler belirtilmemişse, ilk 5 nümerik değişkeni al
    if numerical_cols is None:
        numerical_cols = num_cols[:5]
    
    # Eğer hedef değişkenler belirtilmemişse, ilk 5 hedef değişkeni al
    if target_cols is None:
        target_cols = target_df.columns[:5]

    for target_col in target_cols:
        for num_col in numerical_cols:
            print(f"\033[1mAnalysis for Target: {target_col} with Numerical: {num_col}\033[0m")
            print("----------------------------------")
            
            if plot:
                plt.figure(figsize=(10, 6))
                sns.boxplot(x=dataframe[target_col], y=num_col, data=dataframe)
                plt.title(f"Distribution of {num_col} by {target_col}", fontsize=16)
                plt.xlabel(target_col, fontsize=14)
                plt.ylabel(num_col, fontsize=14)
                plt.tight_layout()
                plt.show(block=True)
            print("\n\n")

# Örnek olarak ilk 3 nümerik değişken ve ilk 3 hedef değişken için fonksiyonu çalıştıralım
target_summary_with_num_custom(merged_data, numerical_cols=num_cols[:3], target_cols=target_df.columns[:3], plot=True)

# %% [markdown]
# <div style="background-color: #ffe0b2; padding: 10px 20px; border-radius: 15px; margin-bottom: 20px;">
#     <h3 style="color: #000000; font-weight: bold;">10. 🧲 Kolerasyon Analizi</h3>
# </div>

# %% [markdown]
# <div style="background-color: #e8f5e9; padding: 10px; border-left: 5px solid #388e3c; border-radius: 5px; margin-bottom: 20px;">
#     <h4 style="color: #2e7d32; font-weight: bold;">🔗 1. Değişkenler Arası Korelasyon Analizi</h4>
# </div>

# %%
# Yüksek Korelasyonlu Özellikleri Filtreleme
threshold = 0.3

correlation_matrix = merged_data[num_cols].corr()

# Korelasyon değerlerinin mutlak değerlerine göre filtreleme
high_correlations = correlation_matrix[correlation_matrix.abs() > threshold].stack().reset_index()
high_correlations = high_correlations[high_correlations['level_0'] != high_correlations['level_1']]

# Yüksek korelasyonlu özelliklerin benzersiz kombinasyonlarını elde etme
high_correlations['ordered-cols'] = high_correlations.apply(lambda x: '-'.join(sorted([x['level_0'], x['level_1']])), axis=1)
high_correlations = high_correlations.drop_duplicates(['ordered-cols'])
high_correlations.drop('ordered-cols', axis=1, inplace=True)

# Korelasyon matrisini bu özellikler için oluşturma
filtered_corr_matrix = merged_data[high_correlations['level_0'].unique()].corr()

# Korelasyon matrisini gösterme
plt.figure(figsize=(20, 15))
sns.heatmap(filtered_corr_matrix, annot=True, cmap='coolwarm', fmt=".2f", linewidths=0.5)
plt.title("High Correlation Between Features")
plt.show(block=True)

# %% [markdown]
# <div style="background-color: #e8f5e9; padding: 10px; border-left: 5px solid #388e3c; border-radius: 5px; margin-bottom: 20px;">
#     <h4 style="color: #2e7d32; font-weight: bold;">🔗 Değişkenlerin, Hedef Değişkenler(menüler) ile Korelasyon Analizi</h4>
# </div>

# %%
correlation_with_target = merged_data[num_cols + target_df.columns.tolist()].corr()

# Sadece hedef değişkenlerle olan korelasyonları alalım
correlation_with_target = correlation_with_target[target_df.columns.tolist()].loc[num_cols]

# Korelasyonları gösterelim
plt.figure(figsize=(15, 15))
sns.heatmap(correlation_with_target, annot=True, cmap='coolwarm', fmt=".2f", linewidths=0.5)
plt.title("Correlation Between Features and Targets")
plt.show()

# %% [markdown]
# <div style="background-color: #ffe0b2; padding: 10px 20px; border-radius: 15px; margin-bottom: 20px;">
#     <h3 style="color: #000000; font-weight: bold;">11. 🎲 Bağımlı (Hedef) Değişkenin Dağılımları</h3>
# </div>

# %%
# Menülerin görünme sıklıklarını görselleştirelim
menu_freq = target_df.sum().sort_values(ascending=False)

plt.figure(figsize=(10, 6))
plt.bar(menu_freq.index, menu_freq.values, color='skyblue')
plt.xlabel('Menüler')
plt.ylabel('Görünme Sayısı')
plt.title('Menülerin Görünme Sıklıkları')
plt.xticks(rotation=45)
plt.show(block=True)

# %% [markdown]
# <div style="background-color: #ffe0b2; padding: 10px 20px; border-radius: 15px; margin-bottom: 20px;">
#     <h3 style="color: #000000; font-weight: bold;">12. ❓ Eksik Değer Analizi</h3>
# </div>

# %%
train_data.isnull().sum()

# %% [markdown]
# <div style="background-color: #ffe0b2; padding: 10px 20px; border-radius: 15px; margin-bottom: 20px;">
#     <h3 style="color: #000000; font-weight: bold;">14. 🛠️ Özellik Çıkarım İşlemleri</h3>
# </div>

# %%
# 'n_seconds_1', 'n_seconds_2' ve 'n_seconds_3' sütunlarının ortalamasını alarak yeni bir 'average_usage_time' sütunu oluşturun
train_data['average_usage_time'] = train_data[['n_seconds_1', 'n_seconds_2', 'n_seconds_3']].mean(axis=1)

# %%
# Önemli özellikleri seç
important_features = ['feature_29', 'feature_10', 'feature_31', 'feature_0', 'feature_26', 
                      'feature_11', 'feature_21', 'feature_18', 'feature_25', 'feature_16','feature_8', 'feature_44', 'feature_34', 'feature_20']

# Her satır için önemli özelliklerin ortalamasını hesapla ve yeni bir özellik oluştur
train_data['onemli_ozellikler_ortalamasi'] = train_data[important_features].mean(axis=1)

# Seçilen özellik çiftlerinin çarpımı üzerinden etkileşim özellikleri oluştur
epsilon = 1e-5

train_data['feature_29_ve_31_carpim'] = train_data['feature_29'] * train_data['feature_31']
train_data['feature_10_ve_31_carpim'] = train_data['feature_10'] * train_data['feature_31']
train_data['feature_10_31_ratio'] = train_data['feature_10'] / (train_data['feature_31'] + epsilon)
train_data["feature_9_20_21"]= train_data['feature_9'] * train_data['feature_20']*train_data['feature_21']
train_data["feature_8_11"]= train_data['feature_8'] * train_data['feature_11']

# %%
train_data.head()

# %%
cat_cols, num_cols, cat_but_car,  num_but_cat = grab_col_names(train_data)

# %% [markdown]
# <div style="background-color: #ffe0b2; padding: 10px 20px; border-radius: 15px; margin-bottom: 20px;">
#     <h3 style="color: #000000; font-weight: bold;">13. ⚠️ Aykırı Değer Analizi</h3>
# </div>

# %%
def outlier_thresholds(dataframe, col_name, q1=0.14, q3=0.86):
    quartile1 = dataframe[col_name].quantile(q1)
    quartile3 = dataframe[col_name].quantile(q3)
    interquantile_range = quartile3 - quartile1
    up_limit = quartile3 + 1.5 * interquantile_range
    low_limit = quartile1 - 1.5 * interquantile_range
    return low_limit, up_limit

# %%
def check_outlier(dataframe, col_name):
    low_limit, up_limit = outlier_thresholds(dataframe, col_name)
    if dataframe[(dataframe[col_name] > up_limit) | (dataframe[col_name] < low_limit)].any(axis=None):
        return True
    else:
        return False

# %%
def replace_with_thresholds(dataframe, variable):
    low_limit, up_limit = outlier_thresholds(dataframe, variable)
    dataframe.loc[(dataframe[variable] < low_limit), variable] = low_limit
    dataframe.loc[(dataframe[variable] > up_limit), variable] = up_limit

# %%
for col in num_cols:
    print(col, check_outlier(train_data, col))

# %%
for col in num_cols:
    if check_outlier(train_data, col):
        replace_with_thresholds(train_data, col)

# %%
for col in num_cols:
    print(col, check_outlier(train_data, col))

# %% [markdown]
# <div style="background-color: #ffe0b2; padding: 10px 20px; border-radius: 15px; margin-bottom: 20px;">
#     <h3 style="color: #000000; font-weight: bold;">15. 🔄 Encoding İşlemleri</h3>
# </div>

# %%
from sklearn.preprocessing import LabelEncoder

top_n = 15  

# 'carrier' için en sık rastlanan N kategoriyi seçip diğerlerini "Other" olarak kodlama
top_carriers = train_data["carrier"].value_counts().head(top_n).index.tolist()
train_data["carrier_encoded"] = train_data["carrier"].apply(lambda x: x if x in top_carriers else "Other")

# Label encoding uygulama
label_encoder_carrier = LabelEncoder()
train_data["carrier_encoded"] = label_encoder_carrier.fit_transform(train_data["carrier_encoded"])

# 'devicebrand' için en sık rastlanan N kategoriyi seçip diğerlerini "Other" olarak kodlama
top_devicebrand = train_data["devicebrand"].value_counts().head(20).index.tolist()
train_data["devicebrand_encoded"] = train_data["devicebrand"].apply(lambda x: x if x in top_devicebrand else "Other")

# Label encoding uygulama
label_encoder_devicebrand = LabelEncoder()
train_data["devicebrand_encoded"] = label_encoder_devicebrand.fit_transform(train_data["devicebrand_encoded"])

# %%
num_cols = num_cols + ["devicebrand_encoded","carrier_encoded"]

# %%
droplist =["carrier", "devicebrand"]

# %%
train_data.drop(droplist, axis=1, inplace=True)

# %%
train_data.head()

# %% [markdown]
# <div style="background-color: #ffe0b2; padding: 10px 20px; border-radius: 15px; margin-bottom: 20px;">
#     <h3 style="color: #000000; font-weight: bold;">16. 📏 Standartlaştırma İşlemleri</h3>
# </div>

# %%
scaler = RobustScaler()

# %%
num_cols

# %%
train_data[num_cols] = scaler.fit_transform(train_data[num_cols])

# %%
train_data.head()

# %% [markdown]
# <div style="background-color: #ffe0b2; padding: 10px 20px; border-radius: 15px; margin-bottom: 20px;">
#     <h3 style="color: #000000; font-weight: bold;">17. 🤖 Modelleme İşlemleri</h3>
# </div>

# %% [markdown]
# <div style="background-color: #f3e5f5; padding: 15px; border: 1px solid #7b1fa2; border-radius: 15px; margin-bottom: 20px;">
#     <h4 style="color: #4a148c; font-weight: bold;">📌 Bilgi Notu-2:</h4>
#     <p style="font-weight: bold;">
#         Bu modelde, çok-etiketli bir sınıflandırma problemiyle karşı karşıya olduğumuz için her bir menü (etiket) için ayrı bir model eğitmeyi seçtik. Bu yaklaşım, her etiketin bağımsız bir sınıflandırma problemi olarak ele alınmasına olanak tanır ve bu sayede problemi basit hale getirir.
#     </p>
#     <ul style="font-weight: bold;">
#         <li>Öncelikle, veriyi eğitim ve doğrulama setlerine ayırdık.</li>
#         <li>Sınıf ağırlıklarını hesapladık. Bu, dengesiz sınıf dağılımlarını dengelemek için kullanılır.</li>
#         <li>Her etiket için ayrı ayrı LightGBM modeli eğittik. LightGBM, yüksek performanslı bir gradyan boosting modeli olduğu için tercih ettik.</li>
#         <li>Eğitilmiş her bir modeli kullanarak doğrulama seti üzerinde tahminlerde bulunduk.</li>
#         <li>Tahmin sonuçlarını birleştirerek çok-etiketli tahmin sonuçları elde ettik.</li>
#         <li>Son olarak, Jaccard skoru kullanarak modelin performansını değerlendirdik.</li>
#     </ul>
#     <p style="font-weight: bold;">Bu yaklaşımın avantajı, her bir etiket için özelleştirilmiş model eğitme esnekliğine sahip olmamızdır.</p>
# </div>

# %%
from sklearn.model_selection import train_test_split

# Özellikler ve hedef değişkenlerini ayarla
X = train_data.drop(columns=['id'])
y = target_df

# Veri setini eğitim ve doğrulama setlerine ayır
X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.1, random_state=42)

# %%
from lightgbm import LGBMClassifier
import numpy as np
from sklearn.metrics import jaccard_score

# Etiket sayısını al
num_labels = y_train.shape[1]

# y_train ve y_val'i numpy dizisine çevir
y_train_array = y_train.to_numpy()
y_val_array = y_val.to_numpy()

# Sınıf ağırlıklarını hesapla
label_freq = y_train.sum(axis=0)
class_weights = len(y_train) / (num_labels * label_freq)

params={
}
params['boosting_type']='dart'
params['learning_rate']=.5
params['min_data_in_leaf']=300
params['feature_fraction']=0.6
params['bagging_freq']=3
params['bagging_fraction']=0.6
params['num_leaves']=50
params['max_depth']=2
params['is_unbalanced']=True
params['lambda_l1']=1
params['random_state']=1009
params['n_estimators']=600

# Her etiket için bir model eğit
models = []
for label_index in range(num_labels):
    lgbm_model = LGBMClassifier(random_state=42, n_estimators=600, learning_rate=0.05,  n_jobs=-1, class_weight={0: class_weights[label_index], 1: 1})
    lgbm_model.fit(X_train, y_train_array[:, label_index])
    models.append(lgbm_model)

# Her model ile tahmin yap ve sonuçları birleştir
y_val_pred = np.zeros_like(y_val_array)
y_val_pred_proba = np.zeros_like(y_val_array, dtype=float)

zero_proba_counts = []

for label_index, model in enumerate(models):
    y_val_pred[:, label_index] = model.predict(X_val)
    y_val_pred_proba[:, label_index] = model.predict_proba(X_val)[:, 1]  # Pozitif sınıfın olasılıklarını al
    
    # Sıfır olasılıklı tahminleri kontrol et
    zero_proba_count = np.sum(y_val_pred_proba[:, label_index] == 0)
    zero_proba_counts.append(zero_proba_count)
    print(f'Label {label_index + 1} için sıfır olasılıklı tahminlerin sayısı: {zero_proba_count}')

# Jaccard score hesapla
score = jaccard_score(y_val_array, y_val_pred, average='samples')
print(f'Jaccard Score: {score}')

# %% [markdown]
# <div style="background-color: #ffe0b2; padding: 10px 20px; border-radius: 15px; margin-bottom: 20px;">
#     <h3 style="color: #000000; font-weight: bold;">18. 🤖 Özellik Önem Derecesi</h3>
# </div>

# %% [markdown]
# <div style="background-color: #f3e5f5; padding: 20px; border: 1px solid #7b1fa2; border-radius: 15px; margin-bottom: 20px;">
#     <h4 style="color: #4a148c; font-weight: bold;">📌 Bilgi Notu-3:</h4>
#     <p style="font-weight: bold;">
#         Bu bölüm, çok-etiketli sınıflandırma problemi için her bir LightGBM modelinin özellik önemlerini analiz etmek amacıyla oluşturduk. Özelliklerin modelin tahminlerini oluştururken ne kadar etkili olduğunu belirlemek ve özellik önemlerini tabular bir biçimde sıralı olarak görmek istedik. Her bir modelin özellik önemlerini toplayarak genel bir görünüm elde ettik. Toplam özellik önemlerini model sayısına bölerek ortalama bir önem elde ettik.
#     </p>
# </div>

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# Her model için özellik önemlerini topla
total_feature_importances = np.zeros_like(models[0].feature_importances_)

for model in models:
    total_feature_importances += model.feature_importances_

# Ortalama özellik önemlerini hesapla
average_feature_importances = total_feature_importances / num_labels

# Özellik isimleriyle eşleştir
features = X_train.columns

# Özellik önemlerini büyükten küçüğe sırala
sorted_idx = average_feature_importances.argsort()

# En önemli özellikleri ve önemlerini görselleştir
plt.figure(figsize=(10, 12))
plt.barh(range(len(sorted_idx)), average_feature_importances[sorted_idx], align="center")
plt.yticks(range(len(sorted_idx)), features[sorted_idx])
plt.xlabel("Feature Importance")
plt.title("Average Feature Importance in LightGBM Classifiers")
plt.show(block=True)

# %%
# Özellik önemlerini ve özellik isimlerini bir DataFrame'e çevir
feature_importances_df = pd.DataFrame({
    'Feature': features,
    'Importance': average_feature_importances
})

# Özellik önemlerini büyükten küçüğe sırala
feature_importances_df = feature_importances_df.sort_values(by='Importance', ascending=False)

# Sıralı özellik önemlerini yazdır
print(feature_importances_df)

# %% [markdown]
# <div style="background-color: #f3e5f5; padding: 20px; border: 1px solid #7b1fa2; border-radius: 15px; margin-bottom: 20px;">
#     <h4 style="color: #4a148c; font-weight: bold;">📌 Bilgi Notu-4:</h4>
#     <p style="font-weight: bold;">
#         Bu bölümde incelemek istediğimiz her hanngi menü bazında özellik önem derecesini görebiliyoruz.
#     </p>
# </div>

# %%
for label_index in [2, 4, 6]:  # İncelenmek istenen etiketlerin indekslerini yazıyoruz.
    features = X_train.columns
    feature_importances = models[label_index].feature_importances_

    # Özellik isimleriyle eşleştir
    feature_importances_df = pd.DataFrame({
        'Feature': features,
        'Importance': feature_importances
    })

    # Özellik önemlerini büyükten küçüğe sırala
    feature_importances_df = feature_importances_df.sort_values(by='Importance', ascending=False)

    # Sıralı özellik önemlerini yazdır
    print(f"\nFeature importances for label {label_index}:")
    print(feature_importances_df)

# %% [markdown]
# <div style="background-color: #00CED1; padding: 10px 20px; border-radius: 15px; margin-bottom: 20px;">
#     <h3 style="color: #000000; font-weight: bold;">2. Bölüm: 🚂 Test Verisi Üzerinde Özellik Mühendisliği Adımları ve Tahminleme</h3>
# </div>

# %% [markdown]
# <div style="background-color: #f3e5f5; padding: 15px; border: 1px solid #7b1fa2; border-radius: 15px; margin-bottom: 20px;">
#     <h4 style="color: #4a148c; font-weight: bold;">📌 Bilgi Notu-5:</h4>
#     <p style="font-weight: bold;">Bu bölümde, train veri seti üzerinde yaptığımız özellik mühendisliği işlemlerinin aynısını test_data üzerinde de gerçekleştiriyoruz. Çünkü test_data üzerinde tahminler yaparken uyumsuzlukla karşılaşmamak, model performansının doğru bir şekilde değerlendirilmesi ve veri sızıntısının önüne geçmek için bu adımları test_data üzerinde de gerçekleştirmemiz gerekiyor. Daha sonra tahminleme adımına geçeceğiz.</p>
# </div>

# %% [markdown]
# <div style="background-color: #ffe0b2; padding: 10px 20px; border-radius: 15px; margin-bottom: 20px;">
#     <h3 style="color: #000000; font-weight: bold;">19. 🛠️ Özellik Mühendisliği ve Çıkarımı İşlemleri</h3>
# </div>

# %%
# 1. 'n_seconds_1', 'n_seconds_2' ve 'n_seconds_3' sütunlarının ortalamasını alarak
# yeni bir 'average_usage_time' sütunu oluşturun
test_data['average_usage_time'] = test_data[['n_seconds_1', 'n_seconds_2', 'n_seconds_3']].mean(axis=1)

# %%
# Önemli özellikleri seç
important_features = ['feature_29', 'feature_10', 'feature_31', 'feature_0', 'feature_26', 
                      'feature_11', 'feature_21', 'feature_18', 'feature_25', 'feature_16','feature_8', 'feature_44', 'feature_34', 'feature_20']

# Her satır için önemli özelliklerin ortalamasını hesapla ve yeni bir özellik oluştur
test_data['onemli_ozellikler_ortalamasi'] = test_data[important_features].mean(axis=1)

# Seçilen özellik çiftlerinin çarpımı üzerinden etkileşim özellikleri oluştur
epsilon = 1e-5
# train_data["feature_29v2"]=train_data["feature_29"]**2/(train_data["n_seconds_3"])
test_data['feature_29_ve_31_carpim'] = test_data['feature_29'] * test_data['feature_31']
test_data['feature_10_ve_31_carpim'] = test_data['feature_10'] * test_data['feature_31']
test_data['feature_10_31_ratio'] = test_data['feature_10'] / (test_data['feature_31'] + epsilon)
test_data["feature_9_20_21"]= test_data['feature_9'] * test_data['feature_20']*test_data['feature_21']
test_data["feature_8_11"]= test_data['feature_8'] * test_data['feature_11']


# Yeni özelliklerle güncellenen train_data'nın ilk birkaç satırını göster
test_data[['onemli_ozellikler_ortalamasi', 'feature_29_ve_31_carpim', 'feature_10_ve_31_carpim']].head()

# %% [markdown]
# <div style="background-color: #ffe0b2; padding: 10px 20px; border-radius: 15px; margin-bottom: 20px;">
#     <h3 style="color: #000000; font-weight: bold;">20. ⚠️ Aykırı Değer Analizi</h3>
# </div>

# %%
test_data.head()

# %%
features_to_remove = ['devicebrand_encoded', 'carrier_encoded']

# %%
num_cols = [feature for feature in num_cols if feature not in features_to_remove]

# %%
num_cols

# %%
# Sürekli değişkenlerde aykırı değerleri tespit edip, bu değerleri sınırlarla değiştirelim
for col in num_cols:
    if check_outlier(test_data, col):
        replace_with_thresholds(test_data, col)

# %%
test_data.head()

# %% [markdown]
# <div style="background-color: #ffe0b2; padding: 10px 20px; border-radius: 15px; margin-bottom: 20px;">
#     <h3 style="color: #000000; font-weight: bold;">21. 🔄 Encoding İşlemleri</h3>
# </div>

# %%
from sklearn.preprocessing import LabelEncoder

top_n = 15  

# 'carrier' için en sık rastlanan N kategoriyi seçip diğerlerini "Other" olarak kodlama
top_carriers = test_data["carrier"].value_counts().head(top_n).index.tolist()
test_data["carrier_encoded"] = test_data["carrier"].apply(lambda x: x if x in top_carriers else "Other")

# Label encoding uygulama
label_encoder_carrier = LabelEncoder()
test_data["carrier_encoded"] = label_encoder_carrier.fit_transform(test_data["carrier_encoded"])

# 'devicebrand' için en sık rastlanan N kategoriyi seçip diğerlerini "Other" olarak kodlama
top_devicebrand = test_data["devicebrand"].value_counts().head(20).index.tolist()
test_data["devicebrand_encoded"] = test_data["devicebrand"].apply(lambda x: x if x in top_devicebrand else "Other")

# Label encoding uygulama
label_encoder_devicebrand = LabelEncoder()
test_data["devicebrand_encoded"] = label_encoder_devicebrand.fit_transform(test_data["devicebrand_encoded"])

# %%
droplist =["carrier", "devicebrand"]

# %%
test_data.drop(droplist, axis=1, inplace=True)

# %%
test_data.head()

# %% [markdown]
# <div style="background-color: #ffe0b2; padding: 10px 20px; border-radius: 15px; margin-bottom: 20px;">
#     <h3 style="color: #000000; font-weight: bold;">22. 📏 Standartlaştırma İşlemleri</h3>
# </div>

# %%
num_cols

# %%
num_cols=num_cols+["devicebrand_encoded","carrier_encoded"]

# %%
num_cols

# %%
# Sürekli değişkenleri ölçeklendirelim (RobustScaler kullanarak)
test_data[num_cols] = scaler.transform(test_data[num_cols])

# %%
# Ön işleme ve özellik mühendisliği sonrası test setinin ilk beş satırını gösterelim
test_data.head()

# %%
test_data.isnull().sum()

# %% [markdown]
# <div style="background-color: #ffe0b2; padding: 10px 20px; border-radius: 15px; margin-bottom: 20px;">
#     <h3 style="color: #000000; font-weight: bold;">23. 🔮 Test Verisi Üzerinden Tahminleme İşlemleri</h3>
# </div>

# %%
from sklearn.multiclass import OneVsRestClassifier

test_ids = test_data['id']
test_data = test_data.drop(columns=['id'])

# %%
# OneVsRestClassifier kullanarak modeli eğit
ovr_classifier = OneVsRestClassifier(lgbm_model)
ovr_classifier.fit(X_train, y_train)

# %%
# Test seti üzerinden olasılık tahminleri yap
y_test_proba = ovr_classifier.predict_proba(test_data)

# %%
y_test_proba

# %% [markdown]
# <div style="background-color: #ffe0b2; padding: 10px 20px; border-radius: 15px; margin-bottom: 20px;">
#     <h3 style="color: #000000; font-weight: bold;">24. 💾 Submission Dosyasının Oluşturulması</h3>
# </div>

# %%
# Her kullanıcı için en yüksek 3 olasılığa sahip menüleri seç
top_3_menus_ovr = np.argsort(-y_test_proba)[:, :3]

# %%
top_3_menus_ovr

# %%
# İkili tahminleri oluştur
num_samples, num_classes = y_test_proba.shape
y_test_pred_ovr = np.zeros((num_samples, num_classes), dtype=int)
for i, indices in enumerate(top_3_menus_ovr):
    y_test_pred_ovr[i, indices] = 1

# %%
y_test_pred_ovr

# %%
# İkili tahminleri stringe dönüştür
y_test_pred_str_ovr = [''.join(map(str, row)) for row in y_test_pred_ovr]

# %%
# Sonuçları veri çerçevesine dönüştür
submission_df_ovr = pd.DataFrame({'id': test_ids, 'target': y_test_pred_str_ovr})

# %%
# Veri çerçevesini CSV dosyasına kaydet
submission_df_ovr.to_csv('submission_lightgbm.csv', index=False)

# %%
submission_df_ovr.head()
