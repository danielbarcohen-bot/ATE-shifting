# %% [markdown]
# > ## Sorry it's in Japanese.
# > 当Notebookは社内勉強会の資料として作成しました。
#
# <img src='https://storage.googleapis.com/kaggle-avatars/images/2080166-kg.png' height='256' width='256' align='left'/><br clear="left">

# %% [markdown]
# # 目次
#
# 1. [はじめに](#h1)
# 1. [Kaggleの使い方、用語説明](#h2)
# 1. [Titanicコンペに参加しよう](#h3)
# 1. [機械学習の流れを確認](#h4)
# 1. [生存者予測の精度を上げてみよう](#h5)
# 1. [さいごに](#h6)

# %% [markdown]
# <a id="h1"></a> <br>
# # [1．はじめに](#h1)

# %% [markdown]
# ## 1-1. 本日の目標
#
# - 機械学習の流れを体験する
# - 『自分でもプログラムが書けそう』と感じてもらう

# %% [markdown]
# ## 1-2. 本日の予定
#
# ### 😄 やること
#
# - Pythonの基本（少しだけ）
# - Kaggleの使い方、用語説明
# - 分類問題（Titanicコンペに参加）
# - 機械学習の流れを確認
# - 予測精度を上げてみる
#
# ### 😓 やらないこと
#
# - Pythonライブラリの詳細（※使用頻度の高いものだけ例示します）
# - 回帰問題
# - 教師なし学習
# - ディープラーニング
#
# <font color="blue">もちろんわからない点は質問頂ければ都度説明します！</font>

# %% [markdown]
# ## 1-3. Pythonの基本

# %% [markdown]
# ### 変数
#
# 宣言、型指定なしで使えます

# %%
a = 1
b = '2'
c = a + 3
d = b + '4'

# %%
print(a, b, c, d)

# %% [markdown]
# ### リスト

# %%
x = [1, 2, 4, 8, 16]
y = [i for i in range(3, 9)]  # リスト内包表記

print('x:', x)
print('y:', y)

# %%
x[:3]

# %%
y[2:4]

# %% [markdown]
# ### 連想配列

# %%
m = {'code':1000, 'name':'hoge'}
print(m)

# %%
print('コード:', m['code'])
print('名称:', m['name'])

# %% [markdown]
# ### for文

# %%
n = 0
for i in range(5):
    n += i
    
    print('+' + str(i), '=', n)
    
print('---')

# %% [markdown]
# ### if文

# %%
for i in range(5):
    
    if (i % 2) == 0:
        print(i)

# %% [markdown]
# ## 主に使用するライブラリ
#
# - NumPy - 数値計算を効率的に行うための拡張モジュール。
# - Pandas - データ解析を支援する機能を提供するライブラリ。
# - matplotlib -  グラフ描画のライブラリ。Pandasオブジェクトのグラフ描画メソッドで利用している。
# - Seaborn - matplotlib のラッパー。matplotlib をそのまま使うと面倒なグラフが簡単に描ける。
# - scikit-learn - オープンソース機械学習ライブラリ。

# %% [markdown]
# ## 1-4. Kaggleとは
#
# - 世界中のデータサイエンス・機械学習に携わる人が参加するコミュニティーサイトです。
# - サイト上にコーディング環境があり、Python/R言語でのデータ分析および機械学習が行えます。
# - 企業や政府などの組織がコンペを開催しており、高い分析モデルに賞金が与えられるコンペもあります。

# %% [markdown]
# <a id="h2"></a> <br>
# # [2．Kaggleの使い方、用語説明](#h2)

# %% [markdown]
# ## さわってみよう
# [![kaggle](https://www.kaggle.com/static/images/site-logo.png)](https://www.kaggle.com/)

# %% [markdown]
# ## 用語（Kaggle）
#
# - Competition … コンペ。コンペに参加する場合、コンペに紐づくNotebookを作成します。
#     補足）
#     分類／回帰予測のモデルを作成し、その精度を競います。
#     コンペは期間限定で開催されます。
#     コンペのページに概要、評価の方法、賞金について、などの記載があります。
#     今回参加するタイタニック生存者予測はチュートリアルの位置づけです。
#
# - Dataset … 色々なデータが公開されています。自分でデータをuploadしてDatasetを作成することができます。
# - Notebook … ソースファイルみたいなもの。昔(2019/07以前)はKernelと呼ばれていました。
# - New Notebook … 新規に作成する場合JupyterNotebook形式の’Notebook'か、1ファイル形式の'Script'かを選びます。
# - Leaderboard … スコアのランキング。参加者が特定のデータに過学習するのを防ぐため、非公開スコアと公開スコアがあります。モデルが過学習している場合、モデルを訓練したデータ以外のデータには適合しません。これは、類似の別のサンプルでは、モデルの精度が低くなることを意味します。
# - Public Leaderboard … テストデータの予測 (サブミットしたデータ)の50%が公開スコアに割り当てられます。
# - Private Leaderboard … 残り50%の予測は非公開スコアに割り当てられます。参加者は非公開スコアをコンペが終わるまで、見ることができません。非公開スコアは、コンペの勝者を決定するために使用されます。なお、Getting started competitionsでは、非公開スコアは公開されません。

# %% [markdown]
# ### private sharing 禁止
#
# チーム外でコードやデータを個人的に共有することは許可されていません。
# フォーラムのすべての参加者が利用できるようになっている場合、コードを共有してもかまいません。

# %% [markdown]
# ## 用語（データ分析、機械学習）
#
# - 分類／回帰 - 対象のデータが属するクラスを予測するときは分類、値を予測するときは回帰となります。
# - EDA (Exploratory Data Analysis) - 探索的データ解析。EDAと書いてあるNotebookを見ると、コンペの概要をつかむことができます。
# - 過学習 - 統計学や機械学習において、訓練データに対して学習されているが、未知データ（テストデータ）に対しては適合できていない状態を指します。これは汎化能力の不足に起因します。
# - 汎化性能 - ある訓練データをもとにつくったモデルが、他のデータ（＝未知データ）に対して同じような予測精度を示すかどうか、というモデルの性能のこと。
# - アンサンブル学習 - 単独では精度の高くない弱学習器（決定木など）を多数用いることで高い精度を出す手法。
# - ヒストグラム - 縦軸に度数、横軸に階級をとった統計グラフ。

# %% [markdown]
# <a id="h3"></a> <br>
# # [3．Titanicコンペに参加](#h3)

# %% [markdown]
# ## 3-1. 概要を確認
#
# [Titanic: Machine Learning from Disaster](https://www.kaggle.com/c/titanic)
#
# - コンペ概要
# - 評価方法、提出ファイル形式
# - データファイル
# - サブミット回数制限

# %% [markdown]
# ## 3-2. Notebookを作成
#
# - 通常はコンペティションからTitanicコンペを選び、Notebookから「New Notebook」を選択します。
# - コンペ参加時には、そのコンペのルールを承諾する必要があります。
# - 今回はテンプレートを作成しましたので、そのNotebookをコピーして作成します。
#
# [Let's start!!](https://www.kaggle.com/plasticgrammer/titanic-predict-survivors)

# %% [markdown]
# ## 3-3. Notebookの操作について
#
# ### これだけは覚えて
#
# - Shift+Enterでセルの内容を実行
# - print文を書かなくとも、セル内の最終行の結果が出力される
# - 現在セルの上まで実行（Run Before）、全て実行（Run All） がある
# - 上のセルに戻って、コード追加/セル追加して実行できるけど、後で順番に実行する際に予期しないエラーになるかも

# %% [markdown]
# <a id="h4"></a> <br>
# # [4．機械学習の流れを確認](#h4)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## 4-1. データ読込

# %%
# pandasのread_csv関数でデータを読み込み、DataFrame型として変数に保持させます。
train = pd.read_csv('../input/titanic/train.csv')
test = pd.read_csv('../input/titanic/test.csv')

# %% [markdown]
# ## 4-2. データ分析
#
# データサイエンスにおいては一般的に、データの特性をつかみ、仮説と検証を繰り返すことでモデルを改善していくというプロセスが取られます。
# まずは、データの基本的な情報を確認することから始めましょう。

# %% [markdown]
# ### データ項目
#
# [Data Dictionary](https://www.kaggle.com/c/titanic/data)
#
# - PassengerId: 乗客のID
# - Survived: 生存(1)、死亡(0)
# - Pclass: 乗客の階級
# - Name: 乗客の名前
# - Sex: 性別
# - Age: 年齢
# - SibSp: タイタニック号に乗っていた兄弟、姉妹、義兄弟、義姉妹、夫、妻の数（自分を除く）
# - Parch: タイタニック号に乗っていた母親、父親、息子、娘の数
# - Ticket: チケットナンバー
# - Fare: 乗船料金
# - Cabin: キャビン番号
# - Embarked: 乗船場
#
# 補足）機械学習では分析対象の項目のことを、特徴量(feature)と呼びます

# %% [markdown]
# ### よく使うコード

# %%
# 先頭n件
train.head(5)

# %%
# 行数・列数を取得
train.shape

# %%
# 行数取得
# train.shape[0] と同じ
print(len(train))

# 列数取得
# train.shape[1] と同じ
print(len(train.columns))

# %%
# 指定カラムのみ（Seriesとして取得）
pid = train['PassengerId']

print(type(pid))
pid.head(5)

# %%
# 指定カラムのみ(DataFrameとして取得)
sub_df = train[['Survived','Pclass','Sex','Age']]

print(type(sub_df))
sub_df.head(5)

# %%
# 指定カラムのみ(DataFrameとして取得)
sub_df = train[['PassengerId']]

print(type(sub_df))
sub_df.head(5)

# %%
# 有効値の数、型情報
train.info()

# %%
# 欠損値の数
train.isna().sum()

# %%
# 統計量表示
train.describe()

# %%
# 統計量を個別に取得
train['Fare'].min(), train['Fare'].max(), train['Fare'].mean(), train['Fare'].median()

# %%
# 統計量を個別に取得（最頻値）
train['Pclass'].mode()

# %%
# 値リスト
train['Pclass'].unique()

# %%
# 値と件数
train['Pclass'].value_counts()

# %%
# 条件指定のフィルタリング
train[train['Survived'] == 1].head()

# %%
# ヒストグラム … 縦軸に度数、横軸に階級をとった統計グラフ。分布状況の確認に使用。
train['Age'].hist(bins=20) # bins:棒の数

# %%
train[train['Survived'] == 0]['Age'].hist(bins=20, alpha=0.3, color='red')
train[train['Survived'] == 1]['Age'].hist(bins=20, alpha=0.3, color='blue')

# %%
# 複数プロットしたい場合、plt.subplots(行数,列数) で取得したax行列を使用する
fig, ax = plt.subplots(1, 2, figsize=(12,4))

# ヒストグラム（範囲内での頻度）
train['Pclass'].hist(ax=ax[0])

# カテゴリ単位の棒グラフ
train['Pclass'].value_counts().plot.bar(ax=ax[1])

# %%
# 同上
# plt.figure(figsize=(表示横サイズ,表示縦サイズ))
# plt.subplot(行数, 列数, 何番目のプロットか)

plt.figure(figsize=(12,4))

plt.subplot(1, 2, 1)
train['Pclass'].hist()

plt.subplot(1, 2, 2)
train['Pclass'].value_counts().plot.bar()

# %%
# クロス集計
pd.crosstab(train['Survived'], train['Pclass'])

# %%
fig, ax = plt.subplots(1, 2, figsize=(12,4))

# クロス集計結果の棒グラフ化
pd.crosstab(train['Pclass'], train['Survived']).plot.bar(ax=ax[0])
pd.crosstab(train['Survived'], train['Pclass']).plot.bar(ax=ax[1])

# %%
# Seabornを使った 件数の棒グラフ化（hue:集計列名）
sns.countplot(x='Pclass', hue='Survived', data=train)

# %%
# 散布図
plt.scatter(train['Age'], train['Fare'], s=6)

# %% [markdown]
# 他にもたくさんの可視化方法があります。
# どのような分析をしたいかによって、可視化の方法を選びましょう。

# %% [markdown]
# ### Tips

# %%
# %%time

# セルの先頭に"%%time"で、実行時間表示

a = [n for n in range(10^10)]

# %%
_='''

複数行コメント（※実際は複数行の文字列）
読み捨て用変数（とりあえず_）に値を設定することで、最終行をコメントとしても出力には表示されない

'''

# %% [markdown]
# ## 4-3. 前処理
#
# <font color="red">重要：（基本的に）文字列をそのまま渡して学習することはできません。事前に数値へ変更しましょう！</font>

# %% [markdown]
# ### カテゴリ変数の変換（One-Hotエンコーディング）

# %%
# 単純に数値変換しても、そこには大小関係は必要ないので、1つだけ1でそれ以外は0のベクトル（行列）に変換
#train = pd.get_dummies(train, columns=['Embarked'])
pd.get_dummies(train, columns=['Embarked']).head(5)

# %% [markdown]
# ### カテゴリ変数の変換（数値への置換）

# %%
# train['Sex'] = 下記いずれかのコード
train['Sex'].map({'male':0, 'female':1})[:10]

# %%
pd.factorize(train['Sex'])[0][:10]

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
le.fit_transform(train['Sex'])[:10]

# %% [markdown]
# ### 欠損値の補完

# %%
# train['Age'] = train['Age'].fillna(0) # <-- 下記inplace=Trueはこれと同じになる
train['Age'].fillna(0, inplace=True)
test['Age'].fillna(0, inplace=True)

# %% [markdown]
# ### 各特徴量の正規化（標準化）
#
# 回帰の学習においてベクトル空間の誤差を小さくする際、0〜1のように狭い範囲でばらついている特徴量と
# -30000〜800000のように広い範囲でばらついている特徴量が混在していると、学習に悪影響が出てしまいます。
# 各特徴量からの影響度を揃えるために行うのが、正規化（標準化）です。

# %%
# 代表的な方法として、
# 各変数を平均0、標準偏差1に揃える方法（sklearn.preprocessing.StandardScaler）と、
# 各変数を最小値0、最大値1に揃える方法（sklearn.preprocessing.MinMaxScaler）が存在します。

print(train['Age'][:10])

from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
sc.fit_transform(train[['Age']])[:10] # 2次元配列のin,out

# %% [markdown]
# ### 特徴量選択

# %%
# 不要な列の削除
drop_columns = ['PassengerId','Name','SibSp','Parch','Ticket','Fare','Cabin','Embarked']
#train.drop(drop_columns, axis=1, inplace=True)
train.drop(drop_columns, axis=1).head(5)

# %% [markdown]
# ## 4-4. モデル作成、学習、予測

# %%
# 予測に使用する列名
cols = ['Pclass','Age']

# 学習用
X_train = train[cols]
y_train = train['Survived']

# 予測用
X_test = test[cols]

# %%
from sklearn.linear_model import LogisticRegression

# モデル作成（ロジスティック回帰）
model = LogisticRegression(solver='liblinear', random_state=42)

# 学習
model.fit(X_train, y_train)
# 予測
y_test = model.predict(X_test)

pd.Series(y_test).value_counts()

# %%
from sklearn.ensemble import RandomForestClassifier

# モデル作成（ランダムフォレスト）
model = RandomForestClassifier(n_estimators=100, max_depth=3, random_state=42)

# 学習
model.fit(X_train, y_train)
# 予測
y_test = model.predict(X_test)

pd.Series(y_test).value_counts()

# %% [markdown]
# ### random_stateパラメータについて
#
# - 乱数を使用するクラスには、このパラメータがあります。
# - 学習器を作成する際に、重みの初期値やデータをランダムに選ぶために乱数を使用します。
# - random_stateが同じだと、全く同じ乱数値（の組）が用いられるので、同じ結果を得ることができます。

# %% [markdown]
# ## 4-5. 評価
# - Commit … Notebookへの変更が新規バージョンでコミットされ、別セッションにてNotebookが実行されます
# - Submit … 出力したSubmitファイルを選び "Submit to Competition"

# %% [markdown]
# <a id="h5"></a> <br>
# # [5. 生存者予測の精度を上げてみよう](#h5)

# %% [markdown]
# ## 5-1. 精度の検証について
#
# １日にサブミットできる回数に制限があるため（タイタニックは10回）、手元で精度を確認できる仕組みが必要です。
# 手元でスコアが確認できるようになれば、 自分の気の済むだけ試行錯誤を繰り返し、
# 良いスコアを得た場合に提出するような運用が可能です。
# ※実世界でも未知のデータに対応する必要があるので、この仕組みは必要！
#
# [Cross Validationはなぜ重要なのか【kaggle Advent Calendar 3日目】](https://upura.hatenablog.com/entry/2018/12/04/205200)

# %% [markdown]
# ### ホールドアウト検証
#
# - 妥当性検証のためのデータセットを、trainのデータセットから分割することで作成します。

# %%
from sklearn.model_selection import train_test_split

# X_trainとY_trainをtrainとvalidに分割
train_x, valid_x, train_y, valid_y = train_test_split(X_train, y_train, test_size=0.2, random_state=0)

# %% [markdown]
# ### 交差検証（Cross Validation、CV）
#
# - 交差検証では、複数回にわたって異なるようにデータセットを分割し、それぞれでホールドアウト検証を実行します。
# - その平均のスコアを確認することで、1回のホールドアウト検証で生じうる偏りに対する懸念を弱めることができます。

# %%
from sklearn.model_selection import KFold

folds = KFold(n_splits=3)

for fold_, (trn_, val_) in enumerate(folds.split(X_train, y_train)):
    trn_x, trn_y = X_train.iloc[trn_], y_train.iloc[trn_]
    val_x, val_y = X_train.iloc[val_], y_train.iloc[val_]
    
    # （省略）trn_x, trn_y を使って学習、val_x, val_y を使って検証

# %% [markdown]
# ## 5-2. まずやってみること
#
# - 使っていない特徴量を含めてみよう（まずは変換が簡単なものから）
# - 欠損値に補完すべき適切な値を考えてみよう

# %% [markdown]
# ## 5-3. 自分で進められる人は
#
# - 他の特徴量についても可視化してみよう
# - 一人旅かどうかが生存率に影響しているらしいよ（SibSp＋Parch≦1）
# - 名前やチケット番号から情報を抜き出せないか考えてみよう
# - KFoldクラスを使用して、交差検証をしてみよう
# - 別の人が作成したNotebookを見て、良いアイデアを取り込んでみよう

# %% [markdown]
# <a id="h6"></a> <br>
# # [6. さいごに](#h6)

# %% [markdown]
# 個人的感想ですが、機械学習は、ライブラリの使い方から始まり、統計や数学など、幅広い知識を求められている気がします。
# その全てを基礎から学ぼうとすると大変なので、統計や数学については「必要を感じるまで学ばない」ことをオススメします。
# Kaggleでコンペ入賞を目指すぐらいのモチベーションになるまでは、逆に「どこまで勉強せずにやれるか」ぐらいに考えた方がいいと思います。
#
# [もらえる経験値を最大化する「正しい努力」のまとめ](https://teruyastar.hatenablog.com/entry/20140110/1389461028)
#
# 以下、機械学習を学んでいきたいと思った人向けに、今後の指針を示しておきます。

# %% [markdown]
# ## 6-1. 次に参加すべきコンペ
#
# - 回帰問題：
# [住宅価格予測 - House Prices: Advanced Regression Techniques](https://www.kaggle.com/c/house-prices-advanced-regression-techniques)
#
# - ディープラーニング：
# [手書き数字認識 - Digit Recognizer](https://www.kaggle.com/c/digit-recognizer)

# %% [markdown]
# ## 6-2. 参考／学習サイト
#
# - [Kaggleに登録したら次にやること ～ これだけやれば十分闘える！Titanicの先へ行く入門 10 Kernel ～](https://qiita.com/upura/items/3c10ff6fed4e7c3d70f0)
# - [実践データサイエンス─サンプルコードと図表で学ぶ、前処理・モデル評価・パラメータチューニング](https://employment.en-japan.com/engineerhub/entry/2019/09/10/103000)
# - [Kaggle Learn](https://www.kaggle.com/learn/overview)

# %% [markdown]
# ## 6-3. オススメの本
#
# - [第2版]Python 機械学習プログラミング 達人データサイエンティストによる理論と実践
# - ゼロから作るDeepLearning
# - Kaggleで勝つデータ分析の技術 （※2019-10-09発売）

# %% [markdown]
# Survive the world of machine learning!
#
# 最後にアンケートにご協力ください。
#
# <a href="https://forms.gle/678irxLG5R6wAKcA6">
# <img src='https://upload.wikimedia.org/wikipedia/commons/thumb/f/f9/Reuterdahl_-_Sinking_of_the_Titanic.jpg/759px-Reuterdahl_-_Sinking_of_the_Titanic.jpg' height='512' width='512' align='left'/>
# </a>
