# %%
# This Python 3 environment comes with many helpful analytics libraries installed - what's a library? you'll find out!
# Here's a few helpful packages we'll be loading

import numpy as np # for linear algebra
import pandas as pd # for data processing, CSV file I/O (e.g. pd.read_csv) - we'll learn more about CSV files in a bit

# %% [markdown]
# # Instructions
# What do the emojis mean?
#
# 🔎 - Read and understand. \
# ❓ - What do you think? \
# 🖱️ - Have a go!
#
# There are 3 levels of difficulty:
#
# 🟢 Beginners
#
# 🟡 Intermediate
#
# 🔴 Advanced    users
#
# Please attempt each task before using looking at the [hints and answers](https://www.kaggle.com/code/insightprogramme/shopping-trends-hints-answers).

# %% [markdown]
# # Introduction & Setup (all levels)

# %% [markdown]
# 🔎 The 'read.csv' function seen below grabs a CSV file from a Google Drive that contains the data we'll be using.
#
# 🔎 A CSV file is a way of structuring data in rows and columns,
# similar to a spreadsheet.
#
# Fun Fact: CSV stands for **C**omma, **S**eparated, **V**alues!
#
# 🔎 We'll be importing the **Pandas** library to perform our data manipulation and analysis. A 'library' in the context of programming is a collection of pre-written code that we can use to perform specific tasks, in our case some data science tasks.
#
# 🖱️Run the cell below by clicking the 'play' button to the left of it, so that the notebook can download the data from the Google Drive and the code from Pandas.

# %%
DF = pd.read_csv("/kaggle/input/customer-purchase-data/shopping_data.csv")

# %% [markdown]
# 🔎 The method 'head(*n*)' seen in the cell below shows the first *n* rows of a dataset (you can swap 'n' for '10' here). We can use this throughout our work to check what effect our code is having on the data.
#
# 🖱️Run the cell to see the data in action!

# %%
DF.head(10)

# %% [markdown]
# ❓ You may see that there are a few inconsistencies in the data that need to be fixed. Data cleansing always comes first before any kind of analysis, otherwise our calculations won't produce anything we can use. Let's get to work!

# %% [markdown]
# # 🟢 Beginner Tasks

# %% [markdown]
# ## Cleansing

# %% [markdown]
# 🔎 The 'replace' function below allows us to replace values in an entire dataframe or column, using a *dictionary*, aka a structure that holds a collection of data as a set of unordered pairs.

# %%
gender_mapping = {'F': 'Female', 'M': 'Male'} #this is a dictionary
DF["Gender"] = DF["Gender"].replace(gender_mapping) #this line replaces the 'Gender' labels that were inconsistent in the table we just made, with matching labels that we can see in the line above

# %% [markdown]
# 🖱️ Replace nothing with the number 0 in the column **Previous Purchases**.

# %%
# Your code goes here

# %% [markdown]
# ## Categorising
#
# Let's make a new column **Age Category** to store the age ranges.
#
# 🔎 We're going to compare each value to a lower and upper boundary, and *if* the 'age' falls inbetween them, we return a name for the range - that's an **if** statement!
#
# 🔎 **elif** is the code for an 'else if' statement, where you can ask the computer to check for multiple things, <u> IF the first if statement is not fulfilled.</u> For example here we're checking the age category by category, by asking elif after elif statement, and waiting for one to be true.

# %%
# Function to categorise age
def categorise_age(age):
    if age <= 12:
        ageRange = 'Kids'
    elif 13 <= age <= 17:
        ageRange = 'Teens'
    elif 18 <= age <= 25:
        ageRange = '18-25'
    elif 26 <= age <= 35:
        ageRange = '26-35'
    elif 36 <= age <= 50:
        ageRange = '36-50'
    else:
        ageRange = '51+'
    return ageRange

# %% [markdown]
# 🖱️ 2. One of the bounds (either upper or lower) isn't needed here. Which one is it and why?

# %%
# Your code goes here

# %% [markdown]
# 🔎 We can perform calculations on the whole row using the in-built tools from Pandas
#
# To do so, we need to treat the whole column as one variable, and Pandas can handle the rest.

# %%
discount_percentage = 1 - DF["Discount value"] / 100 #remember that 'DF' refers to our dataset
DF['Total Cost'] = DF['Purchase Amount (USD)'] * discount_percentage

# %% [markdown]
# ## Calculations

# %% [markdown]
# 🔎 We can filter within the dataframe by comparing an entire column to one variable. Pandas returns indexes (numbers) of those rows where the condition we asked for were met.

# %%
No_prev_purchases = DF["Previous Purchases"] == 0 #this finds all instances where value of the 'Previous Purchases' column is "0"
Promo_used = DF["Promo Code Used"] == "Yes" #this finds all instances where value in the 'Promo Code Used' column is "Yes"

# %% [markdown]
# 🔎 Using the binary operation **AND** ('&') we can compare booleans values. A 'boolean' value is binary, and can only be TRUE or FALSE.
#
# Here, the output will contain a series of boolean values showing where there were no previous purchases and the promocode was used.

# %%
DF_first_time_discount = DF[No_prev_purchases & Promo_used] 
# translated this means "we only want to give a first-time discount to people who haven't used the code before,
# and haven't bought anything from the shop before"

# %%
DF.head() #remember this from earlier?

# %% [markdown]
# 🖱️ 3. Find all instances in the dataframe where a customer bought a Shirt using a Credit Card *and* didn't use any Promo Codes.

# %%
# Your code goes here

# %% [markdown]
# ## Plotting
# 🔎 To plot values we are going to use Pandas' built-in plotting tools. Visualising data can make it so much easier for clients, colleagues, and stakeholders to interpret.
#
# In the code below we are showing the top 5 most expensive items and their respective reviews. Let's run the code and take a look:

# %%
top_5 = DF.sort_values(by = "Purchase Amount (USD)", ascending=False).head(5) #this sorts the data
top_5.plot.bar(x = "Item Purchased", y = "Review Rating") #and this plots it

# %% [markdown]
# 🖱️4. We want to see what is the most frequently used payment method using a bar chart. Use the method '.value_counts()' to see the data and display it.

# %%
#Your code goes here

# %% [markdown]
# ## 🟡 Intermediate Tasks

# %% [markdown]
# ## Cleansing

# %% [markdown]
# 🔎 The 'replace' function allows us to replace values in the entire dataframe/column, using a *key-value pair*, aka. a dictionary. This is explained more in the beginner section.

# %%
gender_mapping = {'F': 'Female', 'M': 'Male'}
DF["Gender"] = DF["Gender"].replace(gender_mapping)

# %% [markdown]
# 🖱️ 1. Replace the NaN (**N**ot **a** **N**umber) values in the whole dataset with an appropriate variable for the column.

# %%
# Your code goes here

# %% [markdown]
# ## Categorising
#
# Let's make a new column **Age Category** to store the age ranges.
#
# 🔎 We're going to compare each value to a lower and upper boundary, and if 'age' falls in between them, we return a name for the range.
#
# 🔎 **elif** = else if

# %%
# Function to categorise age
def categorise_age(age):
    if age <= 12:
        ageRange = 'Kids'
    elif 13 <= age <= 17:
        ageRange = 'Teens'
    elif 18 <= age <= 25:
        ageRange = '18-25'
    elif 26 <= age <= 35:
        ageRange = '26-35'
    elif 36 <= age <= 50:
        ageRange = '36-50'
    else:
        ageRange = '51+'
    return ageRange

# %% [markdown]
# 🖱️ 2. Can you identify the parts of the code that are unnecessary or redundant?

# %%
# Your code goes here

# %% [markdown]
# ## Calculations

# %% [markdown]
# 🔎 We can filter within the dataframe by comparing an entire to column to a variable. Pandas returns the indexes of those rows where the condition(s) we asked for were met.

# %%
No_prev_purchases = DF["Previous Purchases"] == 0 #finds all instances where value Previous Purchases column is 0 
Promo_used = DF["Promo Code Used"] == "Yes" # finds all instances where value in Promo Code Used is Yes

# %% [markdown]
# 🔎 Using the binary operation **AND** (&) we can compare booleans in both pandas series. Check out the beginner section for more about booleans.
#
# Here, the output will contain a series of boolean values showing where there were no previous purchases and the promocode was used.

# %%
t_time_discount = DF[No_prev_purchases & Promo_used]

# %%
DF.head() #remember this from earlier?

# %% [markdown]
# 🖱️ 3. Due to an inflation of 6%, the business has decided to increase the price of their products. Calculate a new cost of an item and update the total cost.

# %%
# Your code goes here

# %% [markdown]
# ## Plotting
# 🔎 To plot values we are going to use Pandas' built-in plotting tools. Visualising data can make it so much easier for clients, colleagues, and stakeholders to interpret.
#
# In the code below we are showing the top 5 most expensive items and their respective reviews. Let's run the code and take a look:

# %%
top_5 = DF.sort_values(by = "Purchase Amount (USD)", ascending=False).head(5) #this sorts the data
top_5.plot.bar(x = "Item Purchased", y = "Review Rating") #and this plots it

# %% [markdown]
# 🔎 Pie charts are useful tool to see the percentage a category takes up from a total

# %%
clothes_category = DF["Size"].value_counts()
clothes_category.plot.pie(title = "Proportion of sizes", ylabel = "Proportion")

# %% [markdown]
# 🖱️ 4. Create a pie chart for category of clothing. Make sure to give it an appropriate title and display percentage to 1 d.p. too!

# %%
# Your code goes here

# %% [markdown]
# ## 🔴 Advanced Tasks

# %% [markdown]
# ## Cleansing

# %% [markdown]
# ❓ 1. Explore the values in every column. Should all columns be present in the dataset, or can some be removed?

# %%
# Your code goes here

# %% [markdown]
# ## Categorising
#
# Let's make a new column **Age Category** to store the age ranges.

# %%
# Function to categorise age
def categorise_age(age):
    if age <= 12:
        ageRange = 'Kids'
    elif 13 <= age <= 17:
        ageRange = 'Teens'
    elif 18 <= age <= 25:
        ageRange = '18-25'
    elif 26 <= age <= 35:
        ageRange = '26-35'
    elif 36 <= age <= 50:
        ageRange = '36-50'
    else:
        ageRange = '51+'
    return ageRange

# %% [markdown]
# 🔎  You don't need to use the python in-built tools as Pandas is usually faster more user-friendly

# %%
DF['Age Category'] = DF['Age'].apply(categorise_age)

# %% [markdown]
# 🖱️ 2.  Make a **Star** category, which is calculated as the **Review Rating** number rounded down to the nearest whole number.

# %%
# Your code goes here

# %% [markdown]
# ## Calculations

# %% [markdown]
# 🔎 We can filter within the dataframe by comparing an entire to column to a variable. Pandas returns indexes of those rows where the condition we asked for was met.

# %%
No_prev_purchases = DF["Previous Purchases"] == 0 #finds all instances where value Previos Purchases column is 0 
Promo_used = DF["Promo Code Used"] == "Yes" # finds all instances where value in Promo Code Used is Yes

# %% [markdown]
# 🔎 Here, the output will contain a series of boolean values (True/False) showing where there were no previous purchases and the promocode was used.

# %%
DF_first_time_discount = DF[No_prev_purchases & Promo_used]

# %%
DF.head()

# %% [markdown]
# 🖱️ 3. Our target audience are women aged 18-35 and men aged 25-40. Display our target audience.

# %%
# Your code goes here

# %% [markdown]
# ## Plotting
# 🔎 To plot values we are going to use Pandas' built-in plotting tools. Visualising data can make it so much easier for clients, colleagues, and stakeholders to interpret.
#
# In the code below we are showing the top 5 most expensive items and their respective reviews:

# %%
top_5 = DF.sort_values(by = "Purchase Amount (USD)", ascending=False).head(5)
top_5.plot.bar(x = "Item Purchased", y = "Review Rating")

# %% [markdown]
# 🔎 To see summary statistics, we can perform an aggregate function on columns that we need.
#
# Let's look at some statistics for **Purchase amount** and **Review Rating** for all purchases in the state of Kentucky and Virginia

# %%
Ken_or_Virg = DF["Location"].isin(["Kentucky","Virginia"]) # we can use Pandas methods to make our program more readable

DF[Ken_or_Virg].aggregate(
    {"Purchase Amount (USD)": ["mean", "min", "max"],
     "Review Rating": ["mean", "min", "max"]}
)

# %% [markdown]
# 🖱️ 4. Try performing the same aggregation on every category and its size

# %%
# Your code goes here
