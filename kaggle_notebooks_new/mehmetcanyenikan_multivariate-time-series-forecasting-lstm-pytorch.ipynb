# %% [markdown]
# # **Hello Kaggler, in my previous work, I made a prediction only on Close price using the LSTM network. Now I want to predict Close price using all other information. The other work and this work will be transformed into an explanatory content for myself over time. Development will continue until each step is clearly understood. Note: I also plan to share the references I used while doing these.**

# %%
import numpy
import pandas

# %%
df = pandas.read_csv('/kaggle/input/bitcoin-historical-data/bitstampUSD_1-min_data_2012-01-01_to_2021-03-31.csv')
df.head()

# %%
data_interpolated = df.interpolate()
data_interpolated.head()
