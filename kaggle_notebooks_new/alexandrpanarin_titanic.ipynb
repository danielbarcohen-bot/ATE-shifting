# %% [markdown]
# ## Импортируем необходимые библиотеки

# %%
import pandas 
import numpy as np
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# ## Загружаем данные

# %%
train = pandas.read_csv('../input/titanic/train.csv')
test = pandas.read_csv('../input/titanic/test.csv')

train

# %% [markdown]
# ## Подготавливаем данные
#
# Разделяем выборку на признаки и метки, а также меняем признак пол на 1 или 0

# %%
train_y = train['Survived']
train_X = train.filter(['Sex', 'Pclass', 'SibSp'])
train_X['Sex'] = train_X['Sex'].replace('male', 0)
train_X['Sex'] = train_X['Sex'].replace('female', 1)

test_X = test.filter(['Sex', 'Pclass', 'SibSp'])
test_X['Sex'] = test_X['Sex'].replace('male', 0)
test_X['Sex'] = test_X['Sex'].replace('female', 1)

# %% [markdown]
# ## Нормализуем данные

# %%
scaler = StandardScaler()
train_X = scaler.fit_transform(train_X)
test_X = scaler.fit_transform(test_X)

# %% [markdown]
# ## Используем метод логистической регрессии
#
# Логистическая регрессия применяется для прогнозирования вероятности возникновения некоторого события по значениям множества признаков.

# %%
lr = LogisticRegression()
lr.fit(train_X, train_y)
res = lr.predict(test_X)

# %% [markdown]
# ## Создание submission.csv

# %%
pandas.DataFrame({
    "PassengerId": test.PassengerId.values,
    "Survived": res.astype(int)
    }).to_csv('submission.csv', index=False, header=True)
