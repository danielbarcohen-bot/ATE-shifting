# %% [markdown]
# Вступаем в соревнование https://www.kaggle.com/competitions/m5-forecasting-accuracy/overview , скачиваем данные, можем скачать с помощью kaggle api. Нам нужен только файл `sales_train_evaluation.csv`

# %%
#!kaggle competitions download -c m5-forecasting-accuracy

# %%
import pandas

data=pandas.read_csv('../input/trickyleaky/sales_train_evaluation.csv')
print(data)

# %% [markdown]
# Нам осталось выбрать нужные столбцы)

# %%
l=1914
r=1941
d=pandas.DataFrame(data.id)
for i in range(l,r+1):
    d.loc[:,f'd_{i}']=data.loc[:,f'd_{i}']

# %%
d.to_csv('tricky_leaky_submission.csv', index=False)
