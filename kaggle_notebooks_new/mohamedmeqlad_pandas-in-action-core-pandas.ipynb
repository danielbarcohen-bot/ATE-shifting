# %%
# hello in this series of notebooks I will try my best to summarize the "pandas in Actoin"
# one of the best books that discuss pandas
# hope that you find this notebook useful 
# don't forget to upvote and leave a comment

# %% [markdown]
# ![image.png](attachment:4f8efe47-e137-492d-a388-fde790b84dde.png)

# %% [markdown]
# "Pandas in Action" is a comprehensive guidebook that offers hands-on examples and practical techniques to master data manipulation and analysis with the popular Python library, pandas. Whether you are a beginner or an experienced data analyst, this book provides step-by-step instructions and real-world use cases to effectively utilize pandas for cleaning, reshaping, and analyzing large datasets. With this book, you will learn how to leverage pandas' powerful functionalities, such as data cleansing, merging, grouping, and pivoting, to tackle everyday data challenges. From data exploration and visualization to machine learning and time series analysis, "Pandas in Action" equips you with the skills needed to become proficient in data analysis using pandas, making it an
# essential resource for any aspiring data scientist or data professional.
#
# the book is divided to three parts
#
# Part 1: Introduction to pandas and its key features
# - Overview of pandas as an open-source data manipulation and analysis library for Python.
# - Explanation of the core data structures in pandas: Series and DataFrame.
# - Introduction to the key features and benefits of using pandas for data analysis tasks.
#
# Part 2: Working with Series and DataFrame
# - Detailed explanation of creating and manipulating Series objects, which are one-dimensional labeled arrays.
# - In-depth exploration of DataFrame objects, which are two-dimensional labeled data structures.
# - Understanding how to load data from various sources, such as CSV files or databases, into pandas.
#
# Part 3: Data exploration and basic analysis
# - Introduction to basic data exploration and analysis using pandas functions and methods.
# - Overview of indexing and selecting data within a DataFrame.
# - Explanation of basic data cleaning and preprocessing techniques using pandas.

# %% [markdown]
# ### in this note book I will discuss the first cahpter Introducing pandas

# %% [markdown]
# -Pandas is comparable to Microsoft’s Excel spreadsheet software and Google’s in browser Sheets application. In all three technologies, a user interacts with tables consisting of rows and columns of data. A row represents a record or, equivalently, one
# collection of values for the columns.
# Transformations are applied to coax the data into the desired state.
#
# -What makes pandas unique is the balance it strikes between processing power and
# user productivity. By relying on lower-level languages such as C for many of its calculations, the library can efficiently transform million-row data sets in milliseconds. At the
# same time, it maintains a simple and intuitive set of commands. It is easy to accomplish a lot with a little code in pandas.
#
# -notice the coming code

# %%
import pandas as pd
df=pd.read_csv("/kaggle/input/world-population-dataset/world_population.csv")
df.head()

# %% [markdown]
# -Pandas works seamlessly with numbers, text, dates, times, missing data, and more. We’ll explore its incredible versatilit
#
# -Pandas requires a different mindset from a graphical spreadsheet app such as Excel.
# Programming is inherently more verbal than it is visual. We communicate with the
# computer through commands, not clicks. Because it makes fewer assumptions about
# what you’re trying to accomplish, a programming language tends to be more unforgiving.
#
# -When you’re fiddling with functions such as SUMIF and
# VLOOKUP in Excel, you’re already thinking like a programmer. The process is the
# same: identify the correct function to use and then supply the right inputs in the
# proper order. Pandas requires an identical set of skills; the difference is that we’re
# communicating with the computer in a more verbose language.
#
# -The best way to grasp the power of pandas is to see it in action. Let’s take a quick tour
# of the library by analyzing a data set of the 1000 highest-grossing movies of all time. I hope you are pleasantly surprised by how intuitive the syntax of pandas can be, even if
# you are new to programming
# (notice the coming code )

# %%
movies = pd.read_csv("/kaggle/input/top-1000-highest-grossing-movies/Highest Holywood Grossing Movies.csv")
movies.head()

# %% [markdown]
# -The first row lists the five columns in the data set: Rank, Title, Studio, Gross, and Year.
# The second row holds the first record or, equivalently, the data for the first movie. The
# film has a Rank of 1, a Title of "Avengers: Endgame", a Studio of "Buena Vista", a
# Gross of "$2,796.30", and a Year of 2019
#
# -A function in pandas is equivalent to a function in
# Excel. It’s a command that we issue, either to the library or an entity within it. In this
# scenario, we’ll use the read_csv function to import the movies.csv
#
# -Pandas imports the CSV file’s contents into an object called a DataFrame. Think of
# an object as a container for storing data. Different objects are optimized for different
# types of data, and we interact with them in different ways. Pandas uses one type of
# object (the DataFrame) to store multicolumn data sets and another type of object
# (the Series) to store single-column data sets. A DataFrame is comparable to a multicolumn table in Excel.
#  To avoid cluttering the screen, pandas displays only the first five and last five rows
# of the DataFrame. A row of ellipses ( . . . ) marks where the data gap occurs.
#  This DataFrame consists of five columns (Rank, Title, Studio, Gross, Year) and an
# index. The index is the range of ascending numbers on the left side of the DataFrame. Index labels serve as identifiers for rows of data. We can set any column as the
# index of the DataFrame. When we do not explicitly tell pandas which column to use,
# the library generates a numeric index starting from 0.
#  What column is a good candidate for the index? It’s one whose values can act as a
# primary identifier or point of reference for each row. Among our five columns, Rank
# and Title are the two best options. Let’s swap the autogenerated numeric index with
# the values from the Title column. We can do so directly during the CSV import

# %%
df=pd.read_csv("/kaggle/input/top-1000-highest-grossing-movies/Highest Holywood Grossing Movies.csv",index_col='Title')
df.head()

# %% [markdown]
# -We can look at the DataFrame from a variety of angles. We can extract a few rows
# from the beginning:

# %%
movies.head(4)

# %% [markdown]
# Or we can peek at the end of the data set instead:

# %%
movies.tail(5)

# %% [markdown]
# -We can find out how many rows the DataFrame has:

# %%
len(movies)

# %% [markdown]
# -We can ask pandas for the number of rows and columns in the DataFrame

# %%
movies.shape

# %% [markdown]
# -We can inquire about the total number of cells:

# %%
movies.size

# %% [markdown]
# -We can ask for the data types of the four columns. In the following output, int64
# denotes an integer column, and object denotes a text column:

# %%
movies.dtypes

# %% [markdown]
# -We can extract a row from the data set by its numeric order in line, also called its index
# position. In most programming languages, the index starts counting at 0. Thus, if we
# wanted to pull out the 500th movie in the data set, we would target index position 499:

# %%
movies.iloc[499]

# %% [markdown]
# -notice that Pandas returns a new object here called a Series, a one-dimensional labeled array of
# values. Think of it as a single column of data with an identifier for each row. Notice
# that the Series’ index labels (Rank, Studio, Gross, and Year) are the four columns
# from the movies DataFrame. Pandas has altered the presentation of the original
# row’s values.
#
# -We can also use an index label to access a DataFrame row. As a reminder, our
# DataFrame index holds the films’ titles. Let’s extract the row values for everyone’s
#  The next example extracts a row by its index label
# rather than its numeric position:

# %%
df.loc['Sonic the Hedgehog'] #we use df not movies because title is the index column in df

# %% [markdown]
# -We can also sort the index, which is helpful if we want to see the movies in alphabetical order:

# %%
df.sort_index().head()

# %% [markdown]
# -The operations we’ve performed so far return new DataFrame objects. Pandas has not
# altered the original movies DataFrame from the CSV file. The nondestructive nature
# of these operations is beneficial; it actively encourages experimentation. We can
# always confirm that a result is correct before making it permanent.
#
# -What if we wanted to find out which movie studio had the greatest number of highest-grossing films? To solve this problem, we’ll
# need to count the number of times each studio appears in the Studio column.
#  We can extract a single column of data from a DataFrame as a Series. Notice
# that pandas preserves the DataFrame’s index, the movie titles, in the Series:

# %%
movies['Distributor'] #notice the length

# %% [markdown]
# -If a Series has a large number of rows, pandas truncates the data set to show only the
# first five and the last five rows.
#  Now that we’ve isolated the Studio column, we can count each unique value’s
# number of occurrences. Let’s limit our results to the top 10 studios:

# %%
movies["Distributor"].value_counts().head(10)

# %% [markdown]
# -Filtering a column by one or more criteria
# You’ll often want to extract a subset of rows based on one or more criteria. Excel
# offers the Filter tool for this exact purpose.
#  What if we wanted to find only the films released by Universal Studios? We can
# accomplish this task with one line of code in pandas:

# %%
 movies[movies["Distributor"] == "Universal Pictures"]

# %% [markdown]
# -We can assign the filtering condition to a variable to provide context for readers:

# %%
released_by_universal = movies[movies["Distributor"] == "Universal Pictures"]
released_by_universal.head()

# %% [markdown]
# -We can also filter DataFrame rows by multiple criteria. The next example targets all
# movies released by Universal Studios and released in 2015:

# %%
 released_by_universal = movies["Distributor"] == "Universal Pictures"
 released_in_2015 = movies["Year"] == 2015
 m_v = movies[released_by_universal & released_in_2015]
m_v.head()

# %% [markdown]
# -lets find the number of movies that achieve the two conditions

# %%
len(m_v)

# %% [markdown]
# -Pandas provides additional ways to filter a DataFrame. We can target column values
# less than or greater than a specific value, for example. Here, we target movies released

# %%
after_2020 = movies['Year'] > 2020
movies[after_2020]

# %% [markdown]
# -next we will  gain more knowledge about Grouping data in pandas

# %%
studios = movies.groupby('Distributor')

# %% [markdown]
# -we have group the movies to slices of data ( groups ) by Distributor column using the -groupby- function
#
# -We can ask pandas to count the number of films per studio:

# %%
studios['Title'].count()

# %% [markdown]
# ### summary of the first cahpter
#  Pandas is a data analysis library built on top of the Python programming language.
#
#  Pandas excels at performing complex operations on large data sets with a terse
# syntax.
#
#  Competitors to pandas include the graphical spreadsheet application Excel, the
# statistical programming language R, and the SAS software suite.
#
#  Programming requires a different skill set than working with Excel or Sheets.
#
#  Pandas can import a variety of file formats. A popular format is CSV, which separates rows with line breaks and row values with commas.
#
# Summary 21
#  The DataFrame is the primary data structure in pandas. It is effectively a table
#
# of data with multiple columns.
#  The Series is a one-dimensional labeled array. Think of it as a single column
# of data.
#
#  We can access a row in a Series or DataFrame by its row number or index
# label.
#
#  We can sort a DataFrame by values across one or more columns.
#
#  We can use logical conditions to extract subsets of data from a DataFrame.
#
#  We bucket DataFrame rows based on a column’s values. We can also perform
# aggregate operations such as sums on the resulting groups.
