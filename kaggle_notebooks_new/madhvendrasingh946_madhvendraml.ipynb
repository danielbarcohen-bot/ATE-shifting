# %%
# welcome to numpy tutorial

# %%
import numpy as np

# %%
myarr=np.array([3,6,32,7])

# %%
myarr

# %%
myarr[2]=333333333

# %%
myarr

# %%
myarr.shape

# %%
myarr.dtype

# %%
arr2d=np.array([[2,3,4,5,4],[10,11,12,1,3]])

# %%
 arr2d

# %%
a=np.arange(25).reshape(5,5)

# %%
a

# %%
a[:,1:4:2]

# %%
a[1:4:2,0:3:2]

# %%
a[4,:]

# %%
a

# %%
a=np.array([-1,-3,1,4,-6,9,3])
a<0

# %%
mask=a<0

# %%
negative=a<0

# %%
a[negative]

# %%
a[negative]=0

# %%
positive=a>0

# %%
a[positive]

# %%
a[positive]=1

# %%
a

# %%
a=np.arange(25).reshape(5,5)

# %%
a

# %%
a[[0,2,3,3],[2,3,1,4]]

# %%
a[a%3==0]

# %%
 a%3==0

# %%
a[a%3==0]

# %%
div3=a%3==0

# %%
ndiv3=a%3!=0

# %%
a[div3]=1

# %%
a[ndiv3]=0

# %%
a

# %%
b=np.ones((5))

# %%
b

# %%
b.reshape(1,5)

# %%
a=np.array([-1,2,5,5])

# %%
 a==a.max()

# %%
np.where(a==a.max())

# %%
np.where(a>0)

# %%
np.where(a%2==0)

# %%
import matplotlib
import matplotlib.pyplot as plt

# %%
print(matplotlib.get_backend())

# %%
matplotlib.use('nbagg')

# %%
print(matplotlib.get_backend())

# %%
fig=plt.figure(facecolor=(1,0,0,.1))

# %%
plt.show()

# %%
fig=plt.figure(figsize=plt.figaspect(2.0),facecolor=(1,1,0))

# %%
plt.show()

# %%
fig=plt.figure(figsize=plt.figaspect(1.0))

# %%
ax=fig.add_subplot(1,1,1)
ax.set(xlim=[0.5,4.5],ylim=[-2,8],title='AN EXAMPLE AXIS',
        ylabel='y axis',xlabel='x axis')
plt.show()

# %%
fig=plt.figure(figsize=plt.figaspect(1.0))

# %%
ax=fig.add_subplot(111)
ax.plot([1,2,3,4],[10,20,25,30],color='lightblue',linewidth=3)
ax.scatter([0.3,3.8,1.2,2.5],[11,25,9,26],c=[1,2,3,5],marker='^')
ax.set_xlim(0.5,4.5)

plt.show()

# %%
 fig.ax=plt.subplots(nrows=2, ncols=2)
plt.show()

# %%
import numpy as np

# %%
x=np.linspace(0,10,100)
y1,y2,y3=np.cos(x),np.cos(x+1),np.cos(x+2)

# %%
fig.ax=plt.subplots(nrows=3,ncols=1)
ax[0,0].set(title='Signal 1')
ax[1,0].set(title='Signal 2')
ax[2,0].set(title='Signal 3')
for a in ax.flat:
    a.set(xticks=[],yticks=[])
    plt.show()

# %%
import numpy as np
import matplotlib

import matplotlib.pyplot as plt

# %%
matplotlib.use('nbagg')

# %%
fig=plt.figure(figsize=plt.figaspect(1.0))

# %%
ax=fig.add_subplot(111)
ax.plot([1,2,3,4],[10,20,25,30],color='lightblue',linewidth=3)
ax.scatter([0.3,3.8,1.2,2.5],[11,25,9,26],c=[1,2,3,5],marker='^')
ax.set_xlim(0.5,4.5)

plt.show()

# %%
 x=np.linspace(0,10,100)
y1,y2,y3=np.cos(x),np.cos(x+1),np.cos(x+2)

# %%
names=['signal1 ','signal2','signal3']

# %%
fig,axes=plt.subplots(nrows=3)
for ax,y,name in zip(axes,[y1,y2,y3],names):
    ax.plot(x,y,color='black')
    ax.set(xticks=[],yticks=[],title=name)
plt.show()

# %%
 np.random.seed(1)
x=np.arange(5)
y= np.random.randn(5)
fig, ax=plt.subplots(ncols=2,figsize=plt.figaspect(1/2))
vbars=ax[0].bar(x,y,align='center')
hbar=ax[1].barh(x,y,align='center')
 for bar,height in zip(vbars,y):
    if height<0:
     bar.set(facecolor='salmon')

    ax[0].axhline(0,color='grey',linewidth=2)
ax[1].axvline(0,color='grey',linewidth=2) 

plt.show()

# %%
import numpy as np
np.random.seed(1)

y_raw=np.random.randn(1000).cumsum()+15
x_raw=np.linspace(0,24, y_raw.size)
    
x_pos=x_raw.reshape(-1,100).min(axis=1)
y_avg=y_raw.reshape(-1,100).min(axis=1)
y_err=y_raw.reshape(-1,100).ptp(axis=1)
bar_width=x_pos[1]-x_pos[0]
    
x_pred=np.linspace(0,30)
y_max_pred=y_avg[0]+y_err[0]+2.3*x_pred
y_min_pred=y_avg[0]+y_err[0]+1.2*x_pred

# %%
fig, ax=plt.subplots()
ax.plot(x_raw,y_raw,color='salmon')
ax.bar(x_pos,y_avg,color="lightblue",width=bar_width,yerr=y_err)
ax.fill_between(x_pred,y_max_pred,y_min_pred,color="wheat")
plt.show()

# %%
 data1=np.random.random((10,10))
data2 =2*np.random.random((10,10))
data3=3*np.random.random((10,10))

fig, ax=plt.subplots(ncols=3,figsize=plt.figaspect(0.5))
fig.tight_layout()
cax=fig.add_axes([0.25,0.1,0.55,0.03])


for ax ,data in zip(ax,[data1,data2,data3]):
    im =ax.imshow(data ,vmin=0,vmax=3)
    fig.colorbar(im,cax=cax,orientation= 'horizontal')
plt.show()

# %%
t=np.arange(0.0,5.0,0.2)
plt.plot(t,t,'r',t,t**2,'c',t,t**3,'black')
plt.show()

# %%
t=np.arange(0.0,5.0,0.2)
plt.plot(t,t,'^',t,t**2,'8m',t,t**3,'sg')
plt.show()

# %%
t=np.arange(0.0,5.0,0.2)
plt.plot(t,t,'-',t,t**2,'--',t,t**3,'-.',t,-t,':')
plt.show()

# %%
t=np.arange(0.0,5.0,0.1)
a=np.exp(-t)*np.cos(2*np.pi*t)
plt.plot(t,a,'r:d',mec='g',mfc='y' )
plt.show()

# %%
import matplotlib as mpl
from matplotlib.rcsetup import cycler
mpl.rc('axes',prop_cycle=cycler('color','rgc')+
                        cycler('lw',[1,4,6])+
                         cycler('linestyle',['-','-.',':']))

t=np.arange(0.0,5.0,0.2)
plt.plot(t,t)
plt.plot(t,t**2)
plt.plot(t,t**3)
plt.show()

# %%
fig, (ax1,ax2)=plt.subplots(ncols=2,figsize=plt.figaspect(0.5))
ax1.plot([-10,-5,0,5,10,15],[-1.2,2,3.5,-0.3,-4,1])
ax2.scatter([-10,-5,0,5,10,15],[-1.2,2,3.5,-0.3,-4,1])
ax1.margins(x=0.0,y=0.1)
ax2.margins(0.05)
plt.show()

# %%
fig, ax=plt.subplots(figsize=plt.figaspect(1.0))
t=np.linspace(0,2*np.pi,150)
x1,y1=np.cos(t),np.sin(t)
x2,y2=2*x1,2*y1
colors=['darkred','darkgreen']
ax.plot(x1,y1,color=colors[0],label='inner',linewidth=3)
ax.plot(x2,y2,color=colors[1],label='outer',linewidth=3)
ax.legend()

ax.axis("equal")
plt.show()

# %%
import pandas

# %%
pandas.__version__

# %%
  pandas.read_csv('./scipy-2019-pandas-master/data/gapminder.tsv', sep='\t')

# %%
df=pandas.read_csv('./scipy-2019-pandas-master/data/gapminder.tsv', sep='\t')

# %%
df

# %%
import pandas as pd

# %%
df= pd.read_csv('./scipy-2019-pandas-master/data/gapminder.tsv', sep='\t')

# %%
# from pandas import* # dont do this

# %%
type(df)

# %%
df.shape

# %%
df.info()

# %%
df.head()

# %%
df.tail()

# %%
df.columns

# %%
df.index

# %%
df.values

# %%
df.values[[0]]

# %%
df.dtypes

# %%
country=df['country']

# %%
country

# %%
#above is a not a dataframe object its more of a list or series as shown below.

# %%
type(country)

# %%
country=df[['country']]

# %%
country

# %%
# above shown is a dataframe not a list

# %%
type(country)

# %%
df_dropp=df.drop(['continent','country'], axis='columns',)

# %%
df.head()

# %%
df.loc[0]

# %%
df.loc[[0,1]]

# %%
df.iloc[[0,1,-1]]

# %%
subset = df.loc[:,['year','pop']]

# %%
subset

# %%
subset = df.iloc[:,[2,4]]

# %%
subset

# %%
df.loc[df['country']=='United States']

# %%
df.loc[(df['country']=='United States')& (df['year']== 1982)]

# %%
df.groupby(['year'])['lifeExp'].mean()

# %%
# an agg function = that function that takes multiple values and returns a value
# like mean=as it takes multiple value and give a average of data
import numpy as np
df.groupby(['year'])['lifeExp'].agg(np.std)

# %%
df.groupby(['year','continent'])[['lifeExp','gdpPercap']].agg(np.mean).reset_index()

# %%
 ## TIDY DATA

# %%
import pandas as pd
import numpy as np

# %%
pew=pd.read_csv('./scipy-2019-pandas-master/data/pew.csv')

# %%
pew.head()

# %%
pew.melt(id_vars='religion')

# %%
pew_tidy=pew.melt(id_vars='religion',var_name='income',value_name='count')

# %%
pew_tidy.head()

# %%
billboard=pd.read_csv('./scipy-2019-pandas-master/data/billboard.csv')

# %%
billboard

# %%
billboard.head()

# %%
billboard_tidy=billboard.melt(id_vars=['year','artist','track','time','date.entered'],var_name='weeks',value_name='rank')

# %%
billboard_tidy

# %%
billboard.melt(id_vars=['year','artist','track','time','date.entered'],
      var_name='weeks',
      value_name='rank').groupby('artist')['rank'].mean().reset_index()

# %%
ebola=pd.read_csv('./scipy-2019-pandas-master/data/country_timeseries.csv')

# %%
ebola.head()

# %%
ebola_long=ebola.melt(id_vars=['Date','Day'],
                     var_name='cd_country',
                     value_name='count')

# %%
ebola_long

# %%
'hello_world'.split('_')

# %%
ebola_long['cd_country'].str.split('_')

# %%
ebola_long['cd_country'].str.split('_')

# %%
ebola_split=ebola_long['cd_country'].str.split('_',expand=True)

# %%
ebola_split

# %%
ebola_long['test']=1

# %%
ebola_long

# %%
ebola_long[['status','country']]= ebola_split

# %%
ebola_long

# %%
weather=pd.read_csv('./scipy-2019-pandas-master/data/weather.csv')

# %%
weather.head()

# %%
weather_long=weather.melt(id_vars=['id','year','month','element'],
                         var_name='day',
                         value_name='temp')

# %%
weather_long

# %%
weather_long.pivot_table(index=['id','year','month','day'],
                        columns='element',
                        values='temp').reset_index()

# %%
10_000_000_000_000

# %%
[1,2,3]

# %%
# function in padnas
import pandas as pd
import numpy as np

# %%
def avg_2(x,y):
    return(x+y)/2

# %%
df=pd.DataFrame({
    'a':[10,20,30,40],
    'b':[20,30,40,50]
})

# %%
df

# %%
# broadcasting
df['a']**2

# %%
def my_sqrt(x):
    return x**2

# %%
#function calling
df['a'].apply(my_sqrt)

# %%
def my_exp(x,e):
    return x**e

# %%
#every part of function is using it


df['a'].apply(my_exp,e=4)

# %%
def print_me(x):
    print(x)

# %%
#happens columnwise
df.apply(print_me)

# %%
def avg_3(x,y,z):
    return (x+y+z)/3

# %%
# here y=1 and z=2 is important as it gives an erroe as we donot give the value 
# of y and z and x takes the value of the element in the column 
df.apply(avg_3,y=1,z=2)

# %%
import numpy as np

# %%
def avg_3_apply(col):
    return np.mean(col)

# %%
df.apply(avg_3_apply)

# %%
def avg_3_(col):
    x=col[0]
    y=col[1]
   
    return (x+y)/2

# %%
df.apply(avg_3_)

# %%
#by changing the axis we do operation columnwise rather than rowise
df.apply(avg_3_,axis='columns')

# %%
df

# %%
def avg_2_mod(x,y):
    if(x==20):
        return np.NaN  
    else:
        return(x+y)/2

# %%
avg_2_mod(df['a'],df['b'])

# %%
avg_2_mode_vec=np.vectorize(avg_2_mod)

# %%
avg_2_mode_vec(df['a'],df['b'])

# %%
@np.vectorize
def avg_2_mod(x,y):
    if(x==20):
        return np.NaN  
    else:
        return(x+y)/2

# %%
# the above function is the same as the one done in 125

# %%
avg_2_mode_vec=np.vectorize(avg_2_mod)

# %%
avg_2_mode_vec(df['a'],df['b'])

# %%
avg_2_mod(df['a'],df['b'])

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
tips=sns.load_dataset('tips')

# %%
tips

# %%
tips.tip.plot(kind='hist')

# %%
cts=tips.smoker.value_counts()

# %%
cts

# %%
cts.plot(kind='bar')

# %%
sns.countplot(x='smoker',data=tips)

# %%
sns.distplot(tips.total_bill)

# %%
sns.lmplot(x='total_bill',y='tip',data= tips )

# %%
sns.lmplot(x='total_bill',y='tip',data= tips ,hue='sex')

# %%
sns.lmplot(x='total_bill',y='tip',data= tips ,hue='sex',fit_reg=False)

# %%
sns.lmplot(x='total_bill',y='tip',data= tips ,hue='sex',fit_reg=False,col='smoker',row='day')

# %%
facet = sns.FacetGrid(tips,col='time',row='smoker',hue='sex')

# %%
facet = sns.FacetGrid(tips,col='time',row='smoker',hue='sex')
facet.map(plt.scatter,'total_bill','tip')

# %%
fig, (ax)=plt.subplots(1,1)
ax.scatter(tips.tip,tips.total_bill)

# %%
fig, (ax1,ax2)=plt.subplots(1,2)
ax1.scatter(tips.tip,tips.total_bill)
ax2.hist(tips.total_bill)

# %%
dis=sns.distplot(tips.tip)

# %%
fig,(ax1,ax2)=plt.subplots(1,2)
sns.distplot(tips.tip,ax=ax1)
sns.regplot(x='total_bill',y='tip',data=tips,ax=ax2)

# %%
from sklearn import linear_model

# %%
tips=sns.load_dataset('tips')

# %%
tips.head()

# %%
lr=linear_model.LinearRegression()

# %%
lr.fit(X=tips[['total_bill','size']],y=tips['tip'])

# %%
lr.coef_

# %%
lr.intercept_

# %%
# dummy encoding
#one-hot encoding

# %%
tips_dummy=pd.get_dummies(tips,drop_first=True)
tips_dummy.head()

# %%
lr.fit(X=tips_dummy.iloc[:,2:],y=tips_dummy['tip'])

# %%
lr.coef_
