# %% [markdown]
# <div style="border-radius:10px;
#             border : #015a2c solid;
#             background-color:#D7D9DB;
#            font-size:110%;
#            letter-spacing:0.5px;
#             text-align: center">
#
# <center><h1 style="padding: 25px 0px; color:#015a4c; font-weight: bold; font-family: Cursive">
# Structured Query Language, or SQL  <br><br>💡💡💡💡💡 <br><br> Learning BigQuery commands To use BigQuery  </h1></center>
# <center><h3 style="padding-bottom: 25px; color:#025b2c; font-weight: bold; font-style:italic; font-family: Cursive">
# Using the tutorial at kaggle as the practice part and an Article in zealoq.com for the theoretical part
#     </h3></center>
#
# </div>

# %% [markdown]
# > # SQL for Data Engineering. A Roadmap for Success
#
#    **========================================================================**
#
# > ### **First: Let's understand the importance of SQL for Data Engineering**
#
# .
#
# **Did you know SQL is the top skill listed in 73.4% of data engineer job postings on Indeed?**
#
#
# SQL is the most commonly-used language in data science. Despite the buzz surrounding NoSQL, Hadoop, and other big data technologies, SQL remains the most dominant language for data operations among all tech companies.
#
#
#
# .
#
#
# ![sql](https://user-images.githubusercontent.com/36210723/226332488-d8da50e0-21df-45d0-ae99-f2ec5c20b553.png)
#
#
#
# .
#
#
# > ## Why Learn SQL for Data Engineering?
#
# ===========================================
#
# **1.** Learning SQL can help data engineers work more effectively with data analysts and data scientists as they share a common language for querying and analysing data.
#
#
# **2.** SQL skills are highly transferable as they can be applied to wide range of databases and data management tools, making it a valuable data engineering skill for people working in a variety of industries and business contexts.
#
#
# **3.** Knowing SQL helps data engineers optimize data infrastructures for better performance and efficiency and also develop more effective data models and data warehousing solutions.
#
# .
#
#
#
# > ## What SQL data engineers DO?
#
# ===========================================
#
# .
#
# **1.** Data engineers can extract data from a table in a relational database using SQL queries like the "SELECT" statement with the "FROM" and "WHERE" clauses. Engineers can also use the "LOAD DATA INFILE" command to extract data from flat files like CSV or TXT. Additionally, SQL enables data engineers to perform data transformation tasks like data cleaning or aggregation from various data sources and loading data into data warehouses or other storage systems using simple SQL queries.
#
# **2.** Data engineers primarily need SQL for creating data integration scripts and executing analytical queries that transform and utilize data for business insights. Data engineers use SQL to modify any database and table structure and extract subsets of the data from the database for various business analytics use cases.
#
# **3.** Your SQL skills as a data engineer are crucial for data modeling and analytics tasks. Making data accessible for querying is a common task for data engineers.
#
#
# .
#
# > ## SQL for Data Engineering - Basics
#
# ===========================================
#
# **The following categories can be used to classify SQL data types broadly ,Arithmetic, Bitwise, Comparison, Compound, Logical, and String.**
#
# .
#
# **1.** Numeric data types (INT, TINYINT, BIGINT, FLOAT, REAL, etc.)
#
# **2.** Date and Time data types (DATE, TIME, DATETIME, etc.)
#
# **3.** Character and String data types (CHAR, VARCHAR, TEXT, etc.)
#
# **4.** Unicode character string data types (NCHAR, NVARCHAR, NTEXT, etc.)
#
# **5.** Binary data types (BINARY, VARBINARY, etc.)
#
# **6.** Miscellaneous data types (CLOB, BLOB, XML, CURSOR, TABLE, etc.)
#
# .
#
#
# > ## SQL for Data Engineering - Advanced concepts
#
# ===========================================
#
# .
#
#
# **1.** Joins (INNER JOIN, LEFT JOIN, RIGHT JOIN, FULL JOIN)
#
# **2.** Subqueries
#
# **3.** Stored Procs and Views
#
# **4.** Aggregation and Grouping functions
#
# **5.** Window Functions (RANK, DENSE_RANK)
#
# **6.** PIVOT and UNPIVOT
#
#
#
# .
#
#
#
# > ## SQL for Data Engineering Pipelines:
#
# ===========================================
#
#
# **There are two major aspects of data engineering pipelines- ETL and Big Data.**
#
#
# .
#
# **1.** ETL
#
# SQL is the most commonly used for ETL purposes. Adopting a hybrid approach by combining the best of both worlds – SQL and ETL is the need of the hour. The market's current ETL solutions come with a SQL action that users can employ to execute any SQL queries (DDLs, Stored Procedures, Index Creations, etc.).
#
#
# **2.** SQL in Big Data
#
# SQL is not just limited to data warehousing and traditional relational database management systems (RDBMS). To analyze big data and create data lakes and data warehouses, SQL-on-Hadoop engines run on top of distributed file systems. The SQL-on-Hadoop platform combines the Hadoop data architecture with traditional SQL-style structured data querying to create a specific analytical application tool. SQL is essential for effectively adopting loosely structured and structured data in Hadoop as it has become increasingly popular for enterprise data architecture.
#
#
#
#
# .
#
#
#
# > ## SQL for Data Engineering - The best Practises
#
# ===========================================
#
# .
#
# **1.** Optimizing SQL Query Performance.
#
# **2.** Well-written SQL Unit Tests.
#
# **3.** Git-based SQL Version Control.
#
# **4.** use SQL Indexes.
#
# **5.** Database Security
#
# .
#
# > **Hope this guide "helpful" , it is from good topic for author : [ Ajay K](https://zealoq.com/feed/view/deck/124/sql-for-data-engineering-a-roadmap-for-success?utm_campaign=copy_link&utm_user=6766&user=ajay-k-6766&utm_share_root=unknown&utm_source=zealoq)**
#
#
# .
#
# [For more pratice ceck this topic](https://www.linkedin.com/posts/ajay026_dataanalytics-like-share-ugcPost-7042377120173498368-dRqa/?utm_source=share&utm_medium=member_android)

# %% [markdown]
# > ## I am Studying many `SQL useful resources ` for data analysts, Here are some of them.
#
#
#
# .
#
#  ![SQL for data analysts](https://user-images.githubusercontent.com/36210723/196912866-876148b9-e6d6-4226-920a-301cc5d071fd.png)
#
#
#
# .
#
# > **If you want to learn SQL, here are free (+ paid) resources👇. Also, you can use these contents to face SQL interviews 🔥**
#
#
# .
#
#
# 𝟭. 𝗦𝗤𝗟 𝗕𝗼𝗹𝘁
# 👉 https://sqlbolt.com/
#
# From SELECT * to GROUP BY, SQL Bolt contains lessons and interactive exercises to help you grasp the essentials in SQL. With no SQL Experience, you can get the basics of SQL in just one week.
#
# 𝟮. 𝗦𝘁𝗮𝗻𝗳𝗼𝗿𝗱 𝗗𝗕 & 𝗦𝗤𝗟 𝗰𝗼𝘂𝗿𝘀𝗲
# 👉 https://lnkd.in/gFEc8ngA
#
# If you want a detailed explanation of SQL queries with a mixture of easy and hard SQL problems, I highly recommend you check out this course.
#
# 𝟯. 𝗧𝗲𝗰𝗵𝗧𝗙𝗤 𝗬𝗼𝘂𝗧𝘂𝗯𝗲 𝗖𝗵𝗮𝗻𝗻𝗲𝗹
# 👉 https://lnkd.in/gjm4JZ9D
#
# I have seen a number of YouTubers focused on SQL and DBs, and I’d have to say I love Thoufiq’s explanation style. He covers a broad sweep of knowledge in SQL with an easy-to-follow explanation style.
#
# 𝟰. 𝗦𝗤𝗟-𝗣𝗿𝗮𝗰𝘁𝗶𝗰𝗲
# 👉 https://lnkd.in/gg3RsFnQ
#
# Here’s another free resource on learning SQL. It’s has a simple browser IDE that will allow you to learn the basics and play around with SQL.
#
# 𝟱. 𝗗𝗮𝘁𝗮𝗜𝗻𝘁𝗲𝗿𝘃𝗶𝗲𝘄 𝗦𝗤𝗟 𝗣𝗮𝗱
# 👉 https://lnkd.in/gAmR4eQM
#
# Here’s a SQL Pad designed for SQL interview prep. It has 100 FAANG-style curated and solved questions.
#
#
# .

# %% [markdown]
# > ## **This notebook is an exercise in the [SQL](https://www.kaggle.com/learn/intro-to-sql) course.  You can reference the tutorial at [this link](https://www.kaggle.com/dansbecker/getting-started-with-sql-and-bigquery).**
#
# ---

# %% [markdown]
# ## The Introduction for the exercise ideas in `Kaggle`
#
#
# ==================================================
#
#
# **Structured Query Language, or SQL**, is the programming language used with databases, and it is an important skill for any data scientist. In this course, you'll build your SQL skills using BigQuery, a web service that lets you apply SQL to huge datasets.
#
# [In the lesson](https://www.kaggle.com/code/dansbecker/getting-started-with-sql-and-bigquery/tutorial), you'll learn the basics of accessing and examining BigQuery datasets. After you have a handle on these basics, we'll come back to build your SQL skills.
#
# Your first BigQuery commands
# To use BigQuery, we'll import the Python package below:

# %% [markdown]
# ## Getting Started With SQL and BigQuery
#
# =========================================
#
# The first test of your new data exploration skills uses data describing crime in the city of Chicago.
#
# Before you get started, run the following cell. It sets up the automated feedback system to review your answers.

# %%
# IN THE FIRST Set up feedack system
from learntools.core import binder
binder.bind(globals())
from learntools.sql.ex1 import *
print("Setup Complete")

# %% [markdown]
# ### Now , let's Use the next code cell to fetch the dataset.

# %%
from google.cloud import bigquery

# Create a "Client" object
client = bigquery.Client()

# Construct a reference to the "chicago_crime" dataset
dataset_ref = client.dataset("chicago_crime", project="bigquery-public-data")

# API request - fetch the dataset
dataset = client.get_dataset(dataset_ref)

# %% [markdown]
# # Exercises
#
# ### 1) Count tables in the dataset
#
# How many tables are in the Chicago Crime dataset?

# %%
# Write the code you need here to figure out the answer
# List all the tables in the "chicago_crime" dataset
tables = list(client.list_tables(dataset))

# Print number of tables in the dataset
print(len(tables))

num_tables = 1

# %%
# num_tables = ____  # Store the answer as num_tables and then run this cell

# Check your answer
q_1.check()

# List all the tables in the "chicago_crime" dataset
tables = list(client.list_tables(dataset))

# Print number of tables in the dataset
print(len(tables))

num_tables = 1

# %% [markdown]
# For a hint or the solution, uncomment the appropriate line below.

# %% [markdown]
# ### 2) Explore the table schema
#
# How many columns in the `crime` table have `TIMESTAMP` data?

# %%
# Write the code to figure out the answer

# %%
#num_timestamp_fields = ____ # Put your answer here


# Construct a reference to the "crime" table
table_ref = dataset_ref.table("crime")

# API request - fetch the table
table = client.get_table(table_ref)

# Print information on all the columns in the "crime" table in the "chicago_crime" dataset
print(table.schema)

num_timestamp_fields = 2

# Check your answer
q_2.check()

# %% [markdown]
# For a hint or the solution, uncomment the appropriate line below.

# %% [markdown]
# ### 3) Create a crime map
#
# If you wanted to create a map with a dot at the location of each crime, what are the names of the two fields you likely need to pull out of the `crime` table to plot the crimes on a map?

# %%
# Write the code here to explore the data so you can find the answer

# %%
fields_for_plotting = ['latitude', 'longitude'] # Put your answers here
# Check your answer
q_3.check()

# %% [markdown]
# Thinking about the question above, there are a few columns that appear to have geographic data. Look at a few values (with the `list_rows()` command) to see if you can determine their relationship.  Two columns will still be hard to interpret. But it should be obvious how the `location` column relates to `latitude` and `longitude`.

# %% [markdown]
# # Keep going
# You've looked at the schema, but you haven't yet done anything exciting with the data itself. Things get more interesting when you get to the data, so keep going to **[write your first SQL query](https://www.kaggle.com/dansbecker/select-from-where).**

# %%
# Scratch space for your code

print ("Done and understand the concept ")

# %% [markdown]
# ![2022-05-26_083337.png](attachment:21fb2bf7-31a1-441f-83be-db0bb8a2cc33.png)

# %% [markdown]
# > ### Done and understand this  concept

# %% [markdown]
# > # Suggestion : for other resource
#
# ==========================================

# %% [markdown]
#  **In the below image I found a good explanation for learning ` what SQL and NoSQL ` as accurate quick abbreviations 😊 it is clear, and easy, to use.**
#
#
#
#
#  > **I find it useful, so I share it with you as `Guide`  in one simple image  for  `SQL and NoSQL ` 😃**
#
#
# .
#
#
# ![1656686253429](https://user-images.githubusercontent.com/36210723/176996523-f4693dd7-537e-4543-8299-c1af2d0b55c9.jpg)
#
#
#
#
#
#  **[I read this article from : The Ravit Show ](https://www.linkedin.com/company/theravitshow/)**
#
#
# > **Wish you all have useful learning 😊**

# %% [markdown]
# > ## To know more information, please follow my [GitHub repository Self Education for Data Analyst ](https://github.com/Self-Education-for-Business-analyst)
