# %% [markdown]
# # Part 1: Data Exploration
# ### Working in Kaggle Kernels
# You will be coding in a Python notebook environment within Kaggle Kernels. This allows you to easily see instructions, your code and its output in one place.  A few tips:
#
# 1) The notebook is composed of "cells."  You can set a cell to either contain **Code** for commands in Python, or **Markdown** for additional description. Execute the code in the current cell using the play button on the left of the cell, or with the keyboard shortcut Control-Enter.
#
# 2) Add a new cell by clicking on a cell, and then using the arrow buttons in the top right of the cell. The arrows indicate whether the new cell goes above or below your current location.
#
# 3) You can save your work at any time by clicking the blue **Commit & Run** button at the top right of your notebook screen. This will also run the code in all the cells in your notebook. To see the outputs of your notebook, wait for the code to finish running and then check the **View Snapshot** button on the right hand side.
#
# 4) You can include comments in your Code cells by using the `#` symbol.
#
# 5) You can also run code in the Console at the bottom of the screen. The Environment Variables tab allows you to check the variables currently available.
#
# ### Your Data
#
# You will write code to build a model predicting house prices in the US state of Iowa. The Iowa data is pre-loaded in your coding notebook.
#
# The left sidebar shows your data.  By clicking on Google Codelab House Price Prediction, you will see a list of the data fields. The data file we will use is **train.csv**.
#
# ### Using `pandas` to Get Familiar With Your Data
#
# The first thing you'll want to do is familiarize yourself with the data.  You'll use the `pandas` library for this.  `pandas` is a common tool that data scientists use for exploring and manipulating data.  Most people abbreviate pandas in their code as `pd`.  To import `pandas`, run the code in the cell below.

# %%
import pandas as pd

# %% [markdown]
# The most important part of the `pandas` library is the DataFrame.  A DataFrame holds the type of data you might think of as a table. This is similar to a sheet in Excel, or a table in a SQL database.
#
# The example will use data at the file path `../input/train.csv`.  Load the data into `pandas` by running the following cell.

# %%
# save filepath to variable for easier access
file_path = '../input/train.csv'
# read the data and store data in DataFrame titled data
data = pd.read_csv(file_path)

# %% [markdown]
# ### Printing a Data Summary
# In the cell below run `data.describe()` to print a summary of the data.

# %%
# print a data summary here

# %% [markdown]
# ### Interpreting the Data Summary
# The results show 8 numbers for each column in your original dataset.
#
# The first number, the **count**,  shows how many rows have non-missing values.  Missing values arise for many reasons. For example, the size of the 2nd bedroom wouldn't be collected when surveying a 1 bedroom house. We'll come back to the topic of missing data.
#
# The second value is the **mean**, which is the average.  Under that, **std** is the standard deviation, which measures how numerically spread out the values are.
#
# To interpret the **min**, **25%**, **50%**, **75%** and **max** values, imagine sorting each column from lowest to highest value.  The first (smallest) value is the **min**.  If you go half way through the list, you'll find the **50%** value, also known as the median.  The **25%** and **75%** values are defined similarly, and the **max** is the largest number.
#
# There are a lot of fields in this data.  You'll also see some columns filled with `...`.  That indicates that we had too many columns of data to print, so the middle ones were omitted from printing.
#
# If we are interested in predicting house sale prices, we'll be particularly interested in the `SalePrice` column. The mean price can tell us what a typical house might sell for.
#
# In the cell below write down the mean sale price, rounded to the nearest $1,000.

# %%
# The mean sale price is:

# %% [markdown]
# The min and max of a particular column can give us an idea of whether the column includes any outliers. Outliers are data points which are highly atypical or possibly indicate poor data quality, and may need to be treated differently in subsequent analysis.
#
# In the cell below write down the year the oldest house was built, as an integer.

# %%
# The year the oldest house was built is:

# %% [markdown]
# ### Plotting Histograms
#
# We would like to plot a histogram to show how frequently houses of different values are sold. This gives us a sense of whether the data is skewed (ie. concentrated more on one side of the mean than the other). Possibly, predicting the values of houses at the cheap and expensive ends of the market will present different challenges.
#
# To help get set up to plot a histogram, run the following code to import the `matplotlib.pyplot` library, which is often abbreviated to `plt`.

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# You can select a column from a DataFrame using an expression like `data.SalePrice`, which will select the `SalePrice` column.
#
# Run the following code to generate a histogram of sales prices using the `hist` function, where the prices are grouped into 50 "bins". Using `;` at the end of the line makes sure just the histogram is printed, without any other information.
#
# The X axis shows sale prices and the Y axis shows the number of house sales in a particular price group.

# %%
plt.hist(data.SalePrice, bins=50);

# %% [markdown]
# Understanding how the data of a particular column is distributed can be useful for assessing how to effectively use the column in a prediction problem. For example, some continuous variables might be better represented as categorical variables if the data falls into clear clusters.
#
# Plot a histogram with 50 bins for the `YearBuilt` column. Do you notice any difference in the shape of the histogram compared to the histogram of `SalePrice`?

# %%
# plot a histogram of the YearBuilt column here

# %% [markdown]
# # Part 2: Building a Machine Learning Model
#
# ### Choosing the Prediction Target
#
# Machine learning models allows us to make predictions from data. To get started, let's choose which column we want to predict. This column is called the **prediction target**. There is a convention that the prediction target is referred to as **y**. Run the following code to set **y** to be the sale prices of the houses in the data.

# %%
y = data.SalePrice

# %% [markdown]
# ### Choosing Predictors
# Next we select the predictors. Sometimes, you will want to use all of the variables except the target. It's possible to model with non-numeric variables, but we'll start with a narrower set of numeric variables.  As a reminder, numeric variables take on number values whereas categorical variables have non-number values such as strings.
#
# Pick out a few numeric variables (at least 5) that you think might be predictive, and put them in a list called `predictors`. For example, `predictors = ['LotArea', 'OverallQual', 'OverallCond', 'YearBuilt', 'YrSold']`.

# %%
# create a list of numeric variables called predictors

# %% [markdown]
# Select these predictors into a DataFrame called **X** using `X = data[predictors]`.

# %%
# create a DataFrame called X containing the predictors here

# %% [markdown]
# ### Building Your Model
#
# You will use the `scikit-learn` library to create your models.  When coding, this library is written as `sklearn`, as you will see in the sample code. Scikit-learn is easily the most popular library for modeling the types of data typically stored in DataFrames.
#
# The steps to building and using a model are:
# * **Define:** What type of model will it be?  A decision tree?  Some other type of model? Some other parameters of the model type are specified too.
# * **Fit:** Capture patterns from provided data. This is the heart of modeling.
# * **Predict:** Just what it sounds like
# * **Evaluate**: Determine how accurate the model's predictions are.
#
# Here is the example for defining and fitting the model.

# %% [markdown]
# We're going to fit a decision tree model. To read more about decision trees check out this [explanation](https://www.kaggle.com/dansbecker/how-models-work). Run the following code to get started.

# %%
from sklearn.tree import DecisionTreeRegressor
model = DecisionTreeRegressor()

# %% [markdown]
# To fit the model to your data run `model.fit(X, y);` in the cell below. The `;` means that no output is printed.

# %%
# fit your decision tree model here

# %% [markdown]
# The output describes some parameters about the type of model you've built. Don't worry about it for now.
#
# Make predictions with your model using the command `predictions = model.predict(X)` in the cell below.

# %%
# make predictions with your model here

# %% [markdown]
# Compare the model's predictions with the true sale prices for the first few houses by running the following command in the cell below.
# ```python
# X.assign(Prediction = predictions).assign(Y = y).head()
# ```

# %%
# compare the model's predictions with the true sale prices of the first few houses here

# %% [markdown]
# ### Model Evaluation
# You've built a model. But how good is it?
#
# There are many metrics for summarising model quality, but we'll use one called [Mean Absolute Error](https://en.wikipedia.org/wiki/Mean_absolute_error). Let's break down this metric starting with the last word, **error**. The error for each house is:
#
# *error = actual − prediction*
#
# So, if a house cost \$150,000 and you predicted it would cost \$100,000, the error is \$50,000. We take the **absolute** value so that each error is a positive number. We then take the **mean** of those absolute errors. This is our measure of model quality.
#
# Our objective is to minimise the error. If our predictions are perfect, our error would be zero.
#
# To import a Python implementation of Mean Absolute Error, run the code in the cell below.

# %%
from sklearn.metrics import mean_absolute_error

# %% [markdown]
# To compute the mean absolute error of your predictions, run the command `mean_absolute_error(y, predictions)` in the cell below.

# %%
# compute the mean absolute error of your predictions here

# %% [markdown]
# ### The Problem with "In-Sample" Scores
#
# The measure we just computed can be called an "in-sample" score. We used a single set of houses (called a data sample) for both building the model and for calculating its Mean Absolute Error. This is bad.
#
# Imagine that, in the large real estate market, door color is unrelated to home price. However, in the sample of data you used to build the model, it may be that all homes with green doors were very expensive. The model's job is to find patterns that predict home prices, so it will see this pattern, and it will always predict high prices for homes with green doors.
#
# Since this pattern was originally derived from the training data, the model will appear accurate in the training data. But this pattern likely won't hold when the model sees new data, and the model would be very inaccurate (and cost us lots of money) when we applied it to our real estate business.

# %% [markdown]
# ### Using Validation Data
#
# Models' practical value come from making predictions on new data, so we should measure performance on data that wasn't used to build the model. The most straightforward way to do this is to exclude some data from the model-building process, and then use those to test the model's accuracy on data it hasn't seen before. This data is called **validation data**.
#
# We want to divide the houses into training and validation data, fit a model on the training data, make predictions with the model on the validation data, and compute the mean absolute error of the predictions. To complete these steps, copy the following code and run it in the cell below.
#
# ```python
# from sklearn.model_selection import train_test_split
# val_model = DecisionTreeRegressor()
# train_X, val_X, train_y, val_y = train_test_split(X, y, random_state = 0)
# val_model.fit(train_X, train_y)
# val_predictions = val_model.predict(val_X)
# mean_absolute_error(val_y, val_predictions)```

# %%
# compute the mean absolute error on the validation data here

# %% [markdown]
# How does the validation data error compare to your previous "In-Sample" estimate?

# %% [markdown]
# # Part 3: Submit and Refine Your Model
#
# ### Kaggle Competition
# In the final part of this Codelab, you should use your model to make predictions for **test** data where you do not have access to the actual sale prices. You will submit these predictions to a Kaggle Competition set up for Codelab participants. Kaggle computes the Mean Absolute Error of participant predictions over the test data sale prices, and displays these on the [Competition Leaderboard](https://www.kaggle.com/c/google-codelab-house-price-prediction/leaderboard).

# %% [markdown]
# ### Making Test Set Predictions
# For our test set predictions, use your original model fit using all of the training data. To use your model to make predictions for the test data, copy the following code and run it in the cell below.
#
# ```python
# test = pd.read_csv('../input/test.csv')
# test_X = test[predictors]
# test_predictions = model.predict(test_X)```

# %%
# make predictions for the test data here

# %% [markdown]
# ### Preparing a Submission File
# We make submissions in CSV files.  Your submissions usually have two columns: an ID column and a prediction column.
#
# We will create a DataFrame with this data, and then use the dataframe's `to_csv` method to write our submission file.  Explicitly include the argument `index=False` to prevent pandas from adding another column in our csv file.
#
# To prepare your submission file, copy the following code and run it in the cell below.
#
# ```python
# submission = pd.DataFrame({'Id': test.Id, 'SalePrice': test_predictions})
# submission.to_csv('submission.csv', index=False)```

# %%
# prepare your submission file here

# %% [markdown]
# ### Making a Submission
# Hit the blue **Commit & Run** button at the top right of your notebook screen.  It will take some time for your kernel to run.  When it has finished click on the **View Snapshot** button on the right.
#
# The navigation bar at the top of the screen will have a tab for **Output**.  This only shows up if you have written an output file (like we did in the **Prepare Submission File** step).
#
# ---
# ![Imgur](https://i.imgur.com/hV9O90I.png)
#
# Click on the Output button.  This will bring you to a screen with an option to **Submit to Competition**.  Hit that and you will see how your model performed on the competition leaderboard.
#
# Next, go to the [Team tab](https://www.kaggle.com/c/google-codelab-house-price-prediction/team) and ensure your name is of the format *Your Name (Your University Name)*. For example,  *Jane Smith (University of Adelaide)*.

# %% [markdown]
# ### Refining Your Model
#
# After making your submission, you have completed the basics of the Codelab - congrats!  You've come a long way.  But you will see from the Competition Leaderboard that there is still a lot of room for improvement.
#
# To refine your model, navigate back to the [Kernels tab](https://www.kaggle.com/c/google-codelab-house-price-prediction/kernels) of the competition. Go ahead and experiment further.
#
# For example, you could:
#
# - change the columns you selected to be `predictors`
# - use a decision tree with [different parameters](http://scikit-learn.org/stable/modules/generated/sklearn.tree.DecisionTreeRegressor.html#sklearn.tree.DecisionTreeRegressor), such as
#   - `max_depth`: determines the number of levels in the decision tree
#   - `criterion`: determines how decision tree splits are conducted (e.g. use 'mae' instead of the default 'mse')
# - Use a different kind of model from [scikit-learn](http://scikit-learn.org/stable/supervised_learning.html#supervised-learning), such as
#   - [linear regression](http://scikit-learn.org/stable/modules/linear_model.html#ordinary-least-squares)
#   - [k-nearest neighbours](http://scikit-learn.org/stable/modules/neighbors.html#nearest-neighbors-regression)
# - Try out Google's open source deep learning library [TensorFlow](https://www.tensorflow.org/get_started/get_started_for_beginners).
#
#
#
# The [Tutorials section](https://www.kaggle.com/c/google-codelab-house-price-prediction#tutorials) of this competition contains plenty of examples specific to this competition. A great set of resources to help you with machine learning more generally can be found at [Kaggle's Learn Page](https://www.kaggle.com/learn).
