# %% [markdown]
# **Load Data**

# %%
from keras.models import Sequential
from keras.layers import Dense 
from keras.models import model_from_json
import numpy
import os
import pandas 

# fix random seed for reproducibility
seed = 7
numpy.random.seed(seed)


data = pandas.read_csv('../input/pima-indians-diabetes-database/diabetes.csv')
array = data.values
X = array[:,0:8]
Y = array[:,8]

data.head(5)
# Out:
#    Pregnancies  Glucose   ...     Age  Outcome
# 0            6      148   ...      50        1
# 1            1       85   ...      31        0
# 2            8      183   ...      32        1
# 3            1       89   ...      21        0
# 4            0      137   ...      33        1
#
# [5 rows x 9 columns]

# %% [markdown]
# **Load Saved Model Architecture and Weights**

# %%
#load json and create model
json_file = open('../input/runmila-diabetes-prediction/diabetes_model.json', 'r')
loaded_model_json = json_file.read()
json_file.close()
loaded_model = model_from_json(loaded_model_json)

#load weights into new model
loaded_model.load_weights("../input/runmila-diabetes-prediction/diabetes_model.h5")

loaded_model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 15)                135
# _________________________________________________________________
# dense_2 (Dense)              (None, 8)                 128
# _________________________________________________________________
# dense_3 (Dense)              (None, 3)                 27
# _________________________________________________________________
# dense_4 (Dense)              (None, 1)                 4
# =================================================================
# Total params: 294
# Trainable params: 294
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# **Use Trained Model to Make Predictions and Estimations**

# %%
# Calculate Predictions
predictions = loaded_model.predict(X)


# round predictions
rounded = [round(x[0],1) for x in predictions]

#Not Rounded For Non-Linear Outputs as Probability
print(rounded)
# Out:
# [0.7, 0.1, 0.7, 0.0, 0.7, 0.4, 0.1, 0.7, 0.7, 0.3, 0.3, 0.7, 0.5, 0.7, 0.7, 0.4, 0.5, 0.6, 0.2, 0.2, 0.4, 0.3, 0.7, 0.6, 0.6, 0.3, 0.7, 0.0, 0.2, 0.6, 0.2, 0.6, 0.0, 0.0, 0.6, 0.4, 0.7, 0.6, 0.2, 0.6, 0.7, 0.7, 0.2, 0.7, 0.7, 0.7, 0.7, 0.1, 0.6, 0.2, 0.0, 0.1, 0.1, 0.7, 0.7, 0.0, 0.7, 0.3, 0.7, 0.2, 0.0, 0.7, 0.0, 0.4, 0.7, 0.2, 0.2, 0.6, 0.0, 0.2, 0.1, 0.4, 0.7, 0.0, 0.1, 0.0, 0.1, 0.3, 0.7, 0.1, 0.6, 0.0, 0.1, 0.0, 0.7, 0.2, 0.7, 0.1, 0.5, 0.1, 0.1, 0.2, 0.1, 0.5, 0.3, 0.6, 0.1, 0.0, 0.1, 0.5, 0.7, 0.4, 0.0, 0.0, 0.3, 0.3, 0.0, 0.4, 0.1, 0.0, 0.5, 0.7, 0.0, 0.1, 0.7, 0.7, 0.7, 0.3, 0.2, 0.0, 0.5, 0.6, 0.1, 0.3, 0.2, 0.2, 0.3, 0.1, 0.2, 0.5, 0.7, 0.7, 0.7, 0.3, 0.0, 0.2, 0.0, 0.1, 0.3, 0.5, 0.6, 0.3, 0.1, 0.6, 0.5, 0.0, 0.1, 0.3, 0.6, 0.0, 0.5, 0.5, 0.7, 0.6, 0.7, 0.7, 0.1, 0.2, 0.0, 0.7, 0.5, 0.2, 0.2, 0.1, 0.3, 0.3, 0.7, 0.7, 0.6, 0.0, 0.4, 0.3, 0.4, 0.1, 0.0, 0.7, 0.1, 0.3, 0.7, 0.7, 0.1, 0.1, 0.0, 0.1,