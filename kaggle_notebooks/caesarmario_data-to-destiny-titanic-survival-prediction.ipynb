# %%
# === 'Secret Sauce' CSS & Config File ===
# --- Libraries for 'Secret Sauce' ---
import sys
from IPython.display import display, HTML, Javascript

# ---'Secret Sauce' Function ---
def apply_config_file(kaggle_path, local_path, project_year, project_name):
    sys.path.append(f"{kaggle_path}/config_file/{project_year}/{project_name}/")
    sys.path.append(f"{local_path}/config_file/{project_year}/{project_name}")

def apply_css_file(kaggle_path, local_path, project_year, css_file_name):
    try:
        return HTML("<style>"+ open(f"{kaggle_path}/css/{project_year}/{css_file_name}.css", "r").read()+ "</style>")
    except:
        return HTML("<style>"+ open(f"{local_path}/css/{project_year}/{css_file_name}.css", "r").read()+ "</style>")

# --- 'Secret Sauce' Variables ---
""" Change Variables ~! HERE !~ """
project_name = "titanic"
project_year = "2023"
css_file_name = "css_" + project_name
kaggle_path = "/kaggle/input/caesarmario"
local_path = "config_kaggle"

# --- Apply Function & Import Config File ---
apply_config_file(kaggle_path, local_path, project_year, project_name)
from config_file import *
apply_css_file(kaggle_path, local_path, project_year, css_file_name)

# %% [markdown]
# <!--- Project Title --->
# <span class="dates">IV.XXVIII.MMXXIII | @caesarmario<span><br>
# <span class="title-normal">Data to Destiny: </span>
# <span class="title-highlight"> Titanic Survival Prediction</span><br>
# <span class="subtitle">using Various Machine Learning Models</span>
# <hr>
# <!-- Hello world 👋. Thank you so much for downloading/forking my codes/works. If you like my works, please support me by giving upvotes and comments on my Kaggle profile (https://www.kaggle.com/caesarmario/). Thank you so much and have a great day 😆👍. More about me: https://linktr.ee/caesarmario_ -->

# %% [markdown]
# # <div class="header1">1. | Introduction 👋</div>
# <center>
#     <img src="https://nypost.com/wp-content/uploads/sites/2/2017/01/170103-titanic-ship-feature.jpg?quality=90&strip=all&w=1488" alt="Titanic Ship" width="80%">
# </center>

# %% [markdown]
# ## <div class="header2">🤔 Dataset Problems</div>
# <div class="explain-box">
#     The Kaggle Titanic problem challenges participants to <mark>use machine learning to predict which passengers on the Titanic survived the sinking</mark>. The dataset includes <b>general and detail information</b> such as age, gender, passenger class, fare, and cabin location for each Titanic passenger, as well as <b>whether they survived or not</b>. The goal is to <mark>create a machine learning model that can accurately predict whether a passenger survived based on these features</mark>. The competition provides <b>a training dataset to build the model</b> and <b>a test dataset to evaluate its performance</b>.
# </div>

# %% [markdown]
# ## <div class="header2">📌 Notebook Objectives</div>
# <div class="explain-box">
#     This notebook <b>aims</b> to:
#     <ul>
#         <li><mark><b>Perform dataset exploration</b></mark> using various types of data visualization.</li>
#         <li><mark><b>Build ML models</b></mark> that can <b>predict survivor of titanic passenger</b> in test dataset.</li>
#         <li><mark><b>Export and submit prediction results</b></mark> according to specified format.</li>
#     </ul>
# </div>

# %% [markdown]
# ## <div class="header2">👨‍💻 Machine Learning Model</div>
# <div class="explain-box">
#     The <b>models</b> used in this notebook:
#     <ol start="1">
#         <li><b>Logistic Regression</b>,</li>
#         <li><b>Support Vector Machine (SVM)</b>,</li>
#         <li><b>K-Nearest Neighbour (KNN)</b>,</li>
#         <li><b>Decision Tree</b>,</li>
#         <li><b>Random Forest</b>,</li>
#         <li><b>Gradient Boosting</b>,</li>
#         <li><b>Extra Tree Classifier</b>, and</li>
#         <li><b>Multilayer Perceptron (MLP)</b>.</li>
#     </ol>
# </div>

# %% [markdown]
# ## <div class="header2">🧾 Dataset Description</div>
# <div class="explain-box">
#     The following is the <b>structure of the dataset</b>.<br>
#
# <table style="font-family: Work Sans; font-weight: 300; font-size: 12px; text-align: left; padding: 8px; border-collapse: collapse; width: 100%;">
#   <thead>
#     <tr>
#       <th style="font-family: Work Sans; font-weight: 900; text-align: center; font-size: 14px; background-color: #C4ECFF">Variable Name</th>
#       <th style="font-family: Work Sans; font-weight: 900; text-align: center; font-size: 14px; background-color: #C4ECFF">Description</th>
#       <th style="font-family: Work Sans; font-weight: 900; text-align: center; font-size: 14px; background-color: #C4ECFF">Sample Data</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#         <td><b>PassengerId</b></td>
#         <td>ID of passenger<br>(unique ID)</td>
#         <td>1; 2; ...</td>
#     </tr>
#     <tr>
#         <td><b>Survived</b></td>
#         <td>Survival status<br>(0 = No, 1 = Yes)</td>
#         <td>0; 1; ...</td>
#     </tr>
#     <tr>
#         <td><b>Pclass</b></td>
#         <td>Ticket class<br>(1 = 1st/Upper, 2 = 2nd/Middle, 3 = 3rd/Lower</td>
#         <td>1; 3; ...</td>
#     </tr>
#     <tr>
#         <td><b>Name</b></td>
#         <td>Passenger name<br>(unique)</td>
#         <td>Braund, Mr. Owen Harris; Heikkinen, Miss. Laina; ...</td>
#     </tr>
#     <tr>
#         <td><b>Sex</b></td>
#         <td>Passenger gender<br>(male or female)</td>
#         <td>male; female; ...</td>
#     </tr>
#     <tr>
#         <td><b>Age</b></td>
#         <td>Passenger age<br>(in years)</td>
#         <td>22; 38; ...</td>
#     </tr>
#     <tr>
#         <td><b>SibSp</b></td>
#         <td>No of siblings / spouses aboard the Titanic</td>
#         <td>22; 38; ...</td>
#     </tr>
#     <tr>
#         <td><b>Parch</b></td>
#         <td># of parents / children aboard the Titanic</td>
#         <td>1; 2; ...</td>
#     </tr>
#     <tr>
#         <td><b>Ticket</b></td>
#         <td>Ticket number<br>(unique)</td>
#         <td>A/5 21171; PC 17599; ...</td>
#     </tr>
#     <tr>
#         <td><b>Fare</b></td>
#         <td>Passenger fare</td>
#         <td>7.25; 71.2833; ...</td>
#     </tr>
#     <tr>
#         <td><b>Cabin</b></td>
#         <td>Cabin number</td>
#         <td>C85; C123; ...</td>
#     </tr>
#     <tr>
#         <td><b>Embarked</b></td>
#         <td>Embarkation port<br>(C = Cherbourg, Q = Queenstown, S = Southampton)</td>
#         <td>C; S; ...</td>
#     </tr>
#     </tbody>
# </table>
# <hr>
# <center>
#     <span class="thanks-explain">📌 Like this notebook? You can support me by giving <mark><b>upvote</b></mark> 😆👍🔼</span><br>
#     <span class="thanks-watermark">Follow me in other platform: <a href="https://linktr.ee/caesarmario_">linktr.ee/caesarmario_</a></span><br>
#     <span class="three-dots2">...</span><br>
#     <span class="thanks-watermark"><u>Support me!</u></span><br>
#     <span class="ko-fi">
#         <a href='https://ko-fi.com/D1D3JU963' target='_blank'><img src='https://ko-fi.com/img/githubbutton_sm.svg' alt='Support me on Ko-fi Button'/></a><br>
#     </span>
# </center>
# <hr>
# </div>

# %% [markdown]
# # <div class="header1">2. | Installing and Importing Libraries 📚</div>
# <div class="explain-box">
#     <b>Installing and Importing libraries</b> that will be used in this notebook.
# </div>

# %%
# --- Installing Libraries ---
# !pip install ydata-profiling
# !pip install pywaffle
# !pip install highlight-text
# !pip install Pillow

# %%
# --- Importing Libraries ---
import numpy as np
import pandas as pd
import ydata_profiling
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import seaborn as sns
import warnings
import os
import yellowbrick

from ydata_profiling import ProfileReport
from pywaffle import Waffle
from PIL import Image
from highlight_text import fig_text
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier, ExtraTreesClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import classification_report, accuracy_score
from sklearn.pipeline import Pipeline, make_pipeline
from sklearn.compose import ColumnTransformer, make_column_transformer
from sklearn.base import BaseEstimator, TransformerMixin
from sklearn.preprocessing import LabelEncoder, StandardScaler
from yellowbrick.classifier import ConfusionMatrix, ROCAUC, PrecisionRecallCurve
from yellowbrick.model_selection import LearningCurve, FeatureImportances
from yellowbrick.contrib.wrapper import wrap
from yellowbrick.style import set_palette

# %% [markdown]
# # <div class="header1">3. | Reading Dataset 👓</div>
# <div class="explain-box">
#     After importing libraries, <b>the datasets that will be used will be imported</b>.
# </div>

# %%
# --- Importing Datasets ---
df_train = pd.read_csv('../input/titanic/train.csv')
df_test = pd.read_csv('../input/titanic/test.csv')

# --- Reading Train Dataset ---
print(clr.start+'.: Train Dataset :.'+clr.end)
print(clr.color+'*' * 21)
df_train.head().style.background_gradient(cmap='Blues').hide_index()

# %%
# --- Reading Test Dataset ---
print(clr.start+'.: Test Dataset :.'+clr.end)
print(clr.color+'*' * 20)
df_test.head().style.background_gradient(cmap='YlOrBr').hide_index()

# %% [markdown]
# # <div class="header1">4. | Initial Dataset Exploration 🔍</div>
# <div class="explain-box">
#     This section will focused on <b>initial data exploration on both datasets</b> before pre-processing performed.
# </div>

# %%
# --- Train Dataset Report ---
ProfileReport(df_train, title='Train Dataset', minimal=True, progress_bar=False, samples=None, correlations=None, interactions=None, explorative=True, dark_mode=True, notebook={'iframe':{'height': '600px'}}, html={'style':{'primary_color': '#219EBC'}}, missing_diagrams={'heatmap': False, 'dendrogram': False}).to_notebook_iframe()

# %%
# --- Test Dataset Report ---
ProfileReport(df_test, title='Test Dataset', minimal=True, progress_bar=False, samples=None, correlations=None, interactions=None, explorative=True, dark_mode=True, notebook={'iframe':{'height': '600px'}}, html={'style':{'primary_color': '#FFB300'}}, missing_diagrams={'heatmap': False, 'dendrogram': False}).to_notebook_iframe()

# %% [markdown]
# <div class="explain-box">
#     From <b>dataset report</b> and <b>correlation matrix</b>, it can be <mark><b>concluded</b></mark> that:<br>
#     <b>▶️ <u>Train Dataset</u></b>:<br>
#     <blockquote style="color: #000000;">
#         <ul>
#             <li>In <mark><b>train</b></mark> dataset, there are <b>891 passengers with 12 columns</b>. However, <mark><b>only 342 survived</b></mark>.</li>
#             <li>The Titanic passengers' <mark><b>average age is 29.7 years</b></mark>, while <b>the oldest is 80</b> and <b>the youngest is 5 months</b>.</li>
#             <li>The maximum number of siblings/spouses per traveler is <b>eight (8)</b>. In addition, the maximum number of parents and children per passenger is <b>six (6)</b>.</li>
#             <li>The <mark><b>average fare is 32.2 dollars</b></mark>, ranging from 0 to 512 dollars. The existence of tickets with no face value is pretty intriguing 🤔.</li>
#             <li>There are some <mark><b>missing values detected on Age, Cabin, and Embarked columns</b></mark>.</li>
#         </ul>
#     </blockquote>
#     <b>▶️ <u>Test Dataset</u></b>:<br>
#     <blockquote style="color: #000000;">
#         <ul>
#             <li>In <mark><b>test</b></mark> dataset there are <b>418 rows and 11 columns</b>, which means there are 418 passengers that require survival prediction.</li>
#             <li>In <b>test</b> dataset, the passengers <mark><b>average age is 30.3 years old</b></mark>, which is pretty compatible with the train dataset (29.7 y.o). The <b>youngest child</b> in this dataset is <b>2 months old</b>, whereas the youngest child in the <b>train</b> dataset is <b>5 months old</b>.</li>
#             <li>The maximum number of siblings and spouses per passenger is <b>eight (8)</b>, which is the same as the train dataset. However, the greatest number of parents/children per passenger is <b>nine (9)</b>, which is <b>greater than the maximum number of parents/children in the train dataset</b>.</li>
#             <li>The average fare is quite consistent with train dataset. In test dataset, the <mark><b>average fare is 35.6</b></mark> with the lowest fare being 0 and the highest fare being 512.3.</li>
#             <li>Similar to train set, there are <mark><b>missing values detected on Age and Cabin columns</b></mark>.</li>
#         </ul>
#     </blockquote>
# </div>
# <!-- Hello world 👋. Thank you so much for downloading/forking my codes/works. If you like my works, please support me by giving upvotes and comments on my Kaggle profile (https://www.kaggle.com/caesarmario/). Thank you so much and have a great day 😆👍. More about me: https://linktr.ee/caesarmario_ -->

# %% [markdown]
# # <div class="header1">5. | EDA 📈</div>
# <div class="explain-box">
#     This section will perform some <b>EDA</b> to get more insights about dataset.<br>
# </div>

# %% [markdown]
# ## <div class="header2">5.1 | Total Survival based on Gender and Title 🚻🎓</div>
# <!-- Hello world 👋. Thank you so much for downloading/forking my codes/works. If you like my works, please support me by giving upvotes and comments on my Kaggle profile (https://www.kaggle.com/caesarmario/). Thank you so much and have a great day 😆👍. More about me: https://linktr.ee/caesarmario_ -->

# %%
# --- EDA 1 Variables ---
suptitle = dict(x=0.125, y=0.98, fontsize=13, weight='heavy', ha='left', va='bottom', color=black_grad[0])
title = dict(x=0.125, y=0.94, fontsize=9, weight='normal', ha='left', va='bottom', fontname=font_alt, color=black_grad[0])
xy_label = dict(fontweight='bold', fontsize=8, color=black_grad[0])
xy_ticks = dict(fontsize=7, fontname=font_alt)
patches_prop = dict(fontsize=7, horizontalalignment='center', verticalalignment='center', fontname=font_alt)
annotate_props_male = dict(xytext=(1, 1), textcoords='offset points', va='center', ha='center', fontsize=9, fontweight='bold', fontname=font_alt, style='italic', bbox=dict(boxstyle='round', pad=0.3, color=blue_grad2[3], alpha=0.4))
annotate_props_female = dict(xytext=(1, 1), textcoords='offset points', va='center', ha='center', fontsize=9, fontweight='bold', fontname=font_alt, style='italic', bbox=dict(boxstyle='round', pad=0.3, color=yellow_grad[3], alpha=0.2))
annotate_props_other = dict(xytext=(1, 1), textcoords='offset points', va='center', ha='center', fontsize=9, fontweight='bold', fontname=font_alt, style='italic', bbox=dict(boxstyle='round', pad=0.3, color=black_grad[3], alpha=0.2))
highlight_textprops = [{'weight':'bold', 'color': yellow_grad[0]}, {'weight':'bold', 'color': blue_grad[1]}]

# --- EDA 1 Dataframe ---
df1 = df_train[['Name', 'Survived', 'Sex']]
df1['Title'] = df1['Name'].str.split(pat=', ', n=1, expand=True)[1].str.split(pat='.', n=1, expand=True)[0]
df1.replace({'Title': mapping_title_rename}, inplace=True)
df1['Title'].mask((df1['Title']=='Dr') & (df1['Sex']=='male'), 'Dr.(M)', inplace=True)
df1['Title'].mask((df1['Title']=='Dr') & (df1['Sex']=='female'), 'Dr.(F)', inplace=True)
df1 = pd.crosstab(df1['Title'], df1['Survived']).reindex(order_title)[[1, 0]]

# --- EDA 1 Display ---
ax = df1.plot(kind='bar', figsize=(9, 4), edgecolor='black', linewidth=0.5, alpha=0.85, zorder=3)

# --- EDA 1 Settings ---
for rect in ax.patches:
    width, height = rect.get_width(), rect.get_height()
    x, y = rect.get_xy()
    if height > 20: ax.text(x+width/2, y+height/2, '{:.0f}'.format(height), **patches_prop)
    else: ax.text(x+width/2, y+height+10, '{:.0f}'.format(height), **patches_prop)
for i in range(eda1_length): ax.patches[i].set_facecolor(eda1_color_list[i])
for spine in ax.spines.values(): spine.set_color('None')
plt.xlabel('\nTitles', **xy_label)
plt.ylabel('Survival Count\n', **xy_label)
plt.xticks(rotation=0, **xy_ticks)
plt.yticks(**xy_ticks)
plt.annotate('Male', xy=(1.5, 400), color=blue_grad2[0], **annotate_props_male)
plt.annotate('Female', xy=(5, 400), color=yellow_grad[0], **annotate_props_female)
plt.annotate('Other', xy=(7, 400), color=black_grad[0], **annotate_props_other)
plt.axvspan(-0.45, 3.45, color=blue_grad2[4], alpha=0.2, zorder=2)
plt.axvspan(3.55, 6.45, color=yellow_grad[4], alpha=0.2, zorder=2)
plt.axvspan(6.55, 9.45, color=black_grad[4], alpha=0.2, zorder=2)
plt.grid(axis='x', alpha=0, zorder=2)
plt.grid(axis='y', which='major', alpha=0.75, color=black_grad[4], linestyle='dotted', zorder=1)
plt.legend().set_visible(False)
fig_text(s="Total Survival based on Gender and Title", **suptitle)
fig_text(s="<Most females survived> from titanic ship, while <only a few males survived>.", highlight_textprops=highlight_textprops, **title)
plt.gcf().text(0.78, -0.08, 'kaggle.com/caesarmario', style='italic', fontsize=6);

# %% [markdown]
# <div class="explain-box">
#     The <mark>majority of Titanic passengers were males</mark>. In more detail, <b>the titanic male passengers are dominated by men over 18</b>. Meanwhile, <b>titanic female passengers are dominated by females aged less than 18 years</b>. From the plot above, it is clear that <mark>most Titanic survivor are dominated by female passengers</mark>. Men over 18 years old (Mr.) had more survivors than men under 18. The opposite happened for women, where the number of female survivors under 18 years old (Miss) has more digits than women over 18 years old. Two males and one female out of 7 passengers with Doctor (Dr.) title survived the events of the Titanic. None of the men who have the Reverend (Rev) title survived.
# </div>
# <!-- Hello world 👋. Thank you so much for downloading/forking my codes/works. If you like my works, please support me by giving upvotes and comments on my Kaggle profile (https://www.kaggle.com/caesarmario/). Thank you so much and have a great day 😆👍. More about me: https://linktr.ee/caesarmario_ -->

# %% [markdown]
# ## <div class="header2">5.2 | Cabin and Class Survival Distributions 👛🛳️😇</div>
# <!-- Hello world 👋. Thank you so much for downloading/forking my codes/works. If you like my works, please support me by giving upvotes and comments on my Kaggle profile (https://www.kaggle.com/caesarmario/). Thank you so much and have a great day 😆👍. More about me: https://linktr.ee/caesarmario_ -->

# %%
# --- EDA 2 Dataframes ---
df2_0 = df_train[['Cabin', 'Survived']][df_train['Survived']==0]
df2_0['Cabin_code'] = df2_0['Cabin'].str[0]
df2_0['Cabin_code'] = df2_0['Cabin_code'].fillna('Unidentified')
df2_0 = pd.DataFrame(df2_0.groupby('Cabin_code').size().reset_index(name='Total'))

df2_1 = df_train[['Cabin', 'Survived']][df_train['Survived']==1]
df2_1['Cabin_code'] = df2_1['Cabin'].str[0]
df2_1['Cabin_code'] = df2_1['Cabin_code'].fillna('Unidentified')
df2_1 = pd.DataFrame(df2_1.groupby('Cabin_code').size().reset_index(name='Total'))
df2_1.loc[len(df2_1.index)] = ['T', 0]
df2_1 = df2_1.sort_values('Cabin_code', ascending=True)

# --- EDA 2 Other Settings ---
label = df2_0['Cabin_code'].to_list()
barh_prop = dict(edgecolor=black_grad[1], linewidth=0.5, alpha=0.85)
bar_label = dict(fontsize=7, padding=5, fontname=font_alt)
xy_label = dict(fontweight='bold', fontsize=8, color=black_grad[0])
xy_ticks = dict(fontsize=7, fontname=font_alt)
axvspan_prop = dict(alpha=0.2, zorder=2)
annotate_ns = dict(xytext=(2, 2), textcoords='offset points', va='center', ha='center', color=black_grad[0], fontsize=10, fontweight='bold', fontname=font_alt, style='italic', bbox=dict(boxstyle='round', pad=0.3, color=black_grad[3], alpha=0.4))
annotate_s = dict(xytext=(2, 2), textcoords='offset points', va='center', ha='center', color=blue_grad2[0], fontsize=10, fontweight='bold', fontname=font_alt, style='italic', bbox=dict(boxstyle='round', pad=0.4, color=blue_grad2[3], alpha=0.2))
suptitle = dict(x=0.125, y=0.97, fontsize=13, weight='heavy', ha='left', va='bottom', color=black_grad[0])
title = dict(x=0.125, y=0.94, fontsize=9, weight='normal', ha='left', va='bottom', fontname=font_alt, color=black_grad[0])
highlight_textprops = [{'weight':'bold', 'color': blue_grad2[2]}, {'weight':'bold', 'color': blue_grad2[2]}, {'weight':'bold', 'color': black_grad[1]}]

# --- Display EDA 2 --- 
plt.figure(figsize=(9, 5))
bar2_ns = plt.barh(label, df2_0['Total']*-1, zorder=3, color=black_grad[2], **barh_prop)
bar2_s = plt.barh(label, df2_1['Total'], zorder=3, color=blue_grad2[2], **barh_prop)
plt.bar_label(bar2_ns, labels=df2_0['Total'], color=black_grad[0], **bar_label)
plt.bar_label(bar2_s, labels=df2_1['Total'], color=blue_grad2[0], **bar_label)
plt.xlabel('\nTotal', **xy_label)
plt.ylabel('Cabin Code\n', **xy_label)
plt.xticks(ticks=x_ticks_eda2, labels=x_labels_eda2, **xy_ticks)
plt.yticks(**xy_ticks)
plt.grid(axis='y', alpha=0, zorder=2)
plt.grid(axis='x', which='major', alpha=0.75, color=black_grad[4], linestyle='dotted', zorder=1)
plt.annotate('Not Survived', xy=(-300, 4), **annotate_ns)
plt.annotate('Survived', xy=(150, 4), **annotate_s)
plt.axvspan(-520, 0, color=black_grad[4], **axvspan_prop)
plt.axvspan(240, 0, color=blue_grad2[4], **axvspan_prop)
plt.gcf().text(0.76, -0.02, 'kaggle.com/caesarmario', style='italic', fontsize=6)
fig_text(s="Cabin Survival Distributions", **suptitle)
fig_text(s="The <majority> of Titanic passengers have an <unidentified cabin code>. <Mid cabin had more passengers>.", highlight_textprops=highlight_textprops, **title)
ax=plt.gca()
for spine in ax.spines.values(): spine.set_color('None')
plt.show();

# %% [markdown]
# <div class="explain-box">
#     From the chart, <mark><b>majority of passengers have an unidentified cabin code</b></mark>. <b>Passengers in the middle cabin (B, C, D, and E) had more survivors</b> than passengers in other cabins.
# </div>
# <!-- Hello world 👋. Thank you so much for downloading/forking my codes/works. If you like my works, please support me by giving upvotes and comments on my Kaggle profile (https://www.kaggle.com/caesarmario/). Thank you so much and have a great day 😆👍. More about me: https://linktr.ee/caesarmario_ -->

# %%
# --- EDA 3 Dataframes ---
df3_0 = df_train[['Pclass', 'Survived']][df_train['Survived']==0]
df3_0 = pd.DataFrame(df3_0.groupby('Pclass').size().reset_index(name='Total'))
df3_1 = df_train[['Pclass', 'Survived']][df_train['Survived']==1]
df3_1 = pd.DataFrame(df3_1.groupby('Pclass').size().reset_index(name='Total'))

# --- EDA 3 Percentage ---
df3_0_values = df3_0.set_index('Pclass')['Total']
df3_1_values = df3_1.set_index('Pclass')['Total']
df3_values = (df3_0_values+df3_1_values).reset_index(name='Total')

pclass_1_all = df3_values.loc[df3_values['Pclass'] == 1]['Total'].values[0]
pclass_2_all = df3_values.loc[df3_values['Pclass'] == 2]['Total'].values[0]
pclass_3_all = df3_values.loc[df3_values['Pclass'] == 3]['Total'].values[0]
pclass_all = pclass_1_all+pclass_2_all+pclass_3_all

pclass_1_survived = df3_1.loc[df3_1['Pclass'] == 1]['Total'].values[0]
pclass_1_survived_perc = pclass_1_survived/pclass_1_all*100

pclass_2_survived = df3_1.loc[df3_1['Pclass'] == 2]['Total'].values[0]
pclass_2_survived_perc = pclass_2_survived/pclass_2_all*100

pclass_3_survived = df3_1.loc[df3_0['Pclass'] == 3]['Total'].values[0]
pclass_3_survived_perc = pclass_3_survived/pclass_3_all*100

# --- EDA 3 Variables ---
suptitle = dict(x=0.5, y=0.93, fontsize=12, weight='heavy', ha='center', va='center', color=black_grad[0])
percentage = dict(fontsize=20, ha='center', weight='bold', va='bottom')
explanation = dict(color=black_grad[1], fontsize=7, ha='left', va='bottom', fontname=font_alt)
xy_ticks = dict(fontsize=8, fontname=font_alt)
highlight_explanation_pclass3 = [{'weight':'bold'}, {'weight':'bold', 'color': yellow_grad[1]}]
highlight_explanation_pclass2 = [{'weight':'bold'}, {'weight':'bold', 'color': yellow_grad[2]}]
highlight_explanation_pclass1 = [{'weight':'bold'}, {'weight':'bold', 'color': yellow_grad[3]}]

# --- Display EDA 3 --- 
fig, ax = plt.subplots(1, 2, figsize = (9, 5), gridspec_kw={'width_ratios': [1.3, 1.7]})
fig_text(s="Ticket Class Survival Distributions", **suptitle)

# --- EDA 3 - Left ---
plt.subplot(1, 2, 1)
plt.grid(axis='both', alpha=0, zorder=2)
plt.axis('off')
axs_left=plt.gca()
for spine in axs_left.spines.values(): spine.set_color('None')
fig_text(x=0.21, y=0.75, s="{0:.2f}%".format(pclass_3_survived_perc), color=yellow_grad[1], **percentage)
fig_text(x=0.28, y=0.745, s=f"of <{pclass_3_all} passengers>\nwith <lower class>\ntickets survived.", highlight_textprops=highlight_explanation_pclass3, **explanation)
fig_text(x=0.21, y=0.455, s="{0:.2f}%".format(pclass_2_survived_perc), color=yellow_grad[2], **percentage)
fig_text(x=0.28, y=0.45, s=f"of <{pclass_2_all} passengers>\nwith <middle class>\ntickets survived.", highlight_textprops=highlight_explanation_pclass2, **explanation)
fig_text(x=0.21, y=0.165, s="{0:.2f}%".format(pclass_1_survived_perc), color=yellow_grad[3], **percentage)
fig_text(x=0.28, y=0.16, s=f"of <{pclass_1_all} passengers>\nwith <upper class>\ntickets survived.", highlight_textprops=highlight_explanation_pclass1, **explanation)

# --- EDA 3 - Right ---
plt.subplot(1, 2, 2)
bar3_1 = plt.barh(label_eda3, df3_0['Total'], zorder=3, color=black_grad[4], edgecolor=black_grad[4], linewidth=0.5, alpha=0.75, height=0.4)
bar3_2 = plt.barh(label_eda3, df3_1['Total'], zorder=3, color=[yellow_grad[3], yellow_grad[2], yellow_grad[1]], edgecolor=black_grad[4], linewidth=0.5, alpha=0.9, height=0.2)
plt.xlabel('\nTotal', fontweight='bold', fontsize=9, color=black_grad[0])
plt.ylabel('')
plt.xticks(**xy_ticks)
plt.yticks(**xy_ticks)
plt.grid(axis='y', alpha=0, zorder=2)
plt.grid(axis='x', which='major', alpha=0.75, color=black_grad[4], linestyle='dotted', zorder=1)
axs_right=plt.gca()
for spine in axs_right.spines.values(): spine.set_color('None')
plt.gcf().text(0.77, -0.05, 'kaggle.com/caesarmario', style='italic', fontsize=6)
plt.show();

# %% [markdown]
# ## <div class="header2">5.3 | Embarked Survival Rate and Fare Distributions ⚓💰</div>
# <!-- Hello world 👋. Thank you so much for downloading/forking my codes/works. If you like my works, please support me by giving upvotes and comments on my Kaggle profile (https://www.kaggle.com/caesarmario/). Thank you so much and have a great day 😆👍. More about me: https://linktr.ee/caesarmario_ -->

# %%
# --- EDA 4 Dataframe ---
df4_0 = df_train[['Embarked', 'Survived']][df_train['Survived']==0]
df4_0 = pd.DataFrame(df4_0.groupby('Embarked').size().reset_index(name='Total').sort_values('Total', ascending=False))
df4_1 = df_train[['Embarked', 'Survived']][df_train['Survived']==1]
df4_1 = pd.DataFrame(df4_1.groupby('Embarked').size().reset_index(name='Total').sort_values('Total', ascending=False))

# --- EDA 4 Variables ---
suptitle = dict(x=0.5, y=1.05, fontsize=12, weight='heavy', ha='center', va='center', color=black_grad[0])
title_prop = dict(style='italic', weight='bold', fontsize=10, ha='center', color=black_grad[0], fontname=font_alt)
explanation = dict(x=0.5, y=0.04, color=black_grad[0], fontsize=7, ha='center', va='bottom', textalign='center', fontname=font_alt)
highlight_explanation = [{'weight':'bold'}, {'weight':'bold'}, {'weight':'bold', 'color': blue_grad[1]}]

# --- Display EDA 4 ---
plt.figure(figsize=(9, 4))

# --- EDA 4: Left ---
plt.subplot(1, 2, 1)
plt.title('Not Survived', **title_prop)
plt.tight_layout(rect=[0, 0, 1, 1.01])
plt.pie(df4_0['Total'], labels=labels_eda4, colors=black_grad[1:4], autopct='%.2f%%', startangle=10, wedgeprops=dict(alpha=0.8, edgecolor=black_grad[1], linewidth=0.5), textprops={'fontsize': 8, 'fontname': font_alt})
centre = plt.Circle((0, 0), 0.85, fc='white', edgecolor=black_grad[1], linewidth=0.5)
fig = plt.gcf()
fig.gca().add_artist(centre)

# --- EDA 4: Right ---
plt.subplot(1, 2, 2)
plt.title('Survived', **title_prop)
plt.tight_layout(rect=[0, 0, 1, 1.01])
plt.pie(df4_1['Total'], labels=labels_eda4, colors=blue_grad[1:4], autopct='%.2f%%', startangle=70, wedgeprops=dict(alpha=0.8, edgecolor=black_grad[1], linewidth=0.5), textprops={'fontsize': 8, 'fontname': font_alt})
centre = plt.Circle((0, 0), 0.85, fc='white', edgecolor=black_grad[1], linewidth=0.5)
fig = plt.gcf()
fig.gca().add_artist(centre)
fig_text(s="Survival Rate by Embarked", **suptitle)
fig_text(s="<Over 60 percent> of the passengers boarded the ship at <Southampton>.\nThose that departed from <Cherbourg had a higher survival rate> than others.", highlight_textprops=highlight_explanation, **explanation)
plt.gcf().text(0.8, -0.03, 'kaggle.com/caesarmario', style='italic', fontsize=6)
plt.show();

# %%
# --- EDA 5 Dataframe ---
df5_0 = df_train[['Embarked', 'Fare']][df_train['Survived']==0]
df5_0_min = pd.DataFrame(df5_0.groupby('Embarked')['Fare'].min().reset_index())
df5_0_avg = pd.DataFrame(df5_0.groupby('Embarked')['Fare'].mean().reset_index())
df5_0_max = pd.DataFrame(df5_0.groupby('Embarked')['Fare'].max().reset_index())
df5_0_con = df5_0_min.rename(columns={'Fare':'Min_Fare'})
df5_0_con['Max_Fare'] = df5_0_max['Fare']

df5_1 = df_train[['Embarked', 'Fare']][df_train['Survived']==1]
df5_1 = df5_1.fillna(df5_1.mode().iloc[0])
df5_1_min = pd.DataFrame(df5_1.groupby('Embarked')['Fare'].min().reset_index())
df5_1_avg = pd.DataFrame(df5_1.groupby('Embarked')['Fare'].mean().reset_index())
df5_1_max = pd.DataFrame(df5_1.groupby('Embarked')['Fare'].max().reset_index())
df5_1_con = df5_1_min.rename(columns={'Fare':'Min_Fare'})
df5_1_con['Max_Fare'] = df5_1_max['Fare']

# --- EDA 5 Other Settings ---
label_0 = df5_0_con.values.tolist()
label_1 = df5_1_con.values.tolist()
avg_0_C = df5_0_avg._get_value(0, 'Fare')
avg_0_Q = df5_0_avg._get_value(1, 'Fare')
avg_0_S = df5_0_avg._get_value(2, 'Fare')
avg_1_C = df5_1_avg._get_value(0, 'Fare')
avg_1_Q = df5_1_avg._get_value(1, 'Fare')
avg_1_S = df5_1_avg._get_value(2, 'Fare')
sct_prop = dict(s=350, linewidth=2)
hlines_left = dict(linewidth=5, color=black_grad[0], zorder=0)
annotate_min_left = dict(xytext=(0, 0), textcoords='offset points', va='center', ha='center', color=black_grad[1], fontsize=8, fontweight='bold', fontname=font_alt, style='italic')
annotate_avg_left = dict(xytext=(0, 0), textcoords='offset points', va='center', ha='center', color='w', fontsize=9, fontweight='bold', fontname=font_alt, style='italic', bbox=dict(boxstyle='round', pad=0.2, color=black_grad[1]))
annotate_max_left = dict(xytext=(0, 0), textcoords='offset points', va='center', ha='center', color=black_grad[1], fontsize=8, fontweight='bold', fontname=font_alt, style='italic')
hlines_right = dict(linewidth=5, color=blue_grad[1], zorder=0)
annotate_min_right = dict(xytext=(0, 0), textcoords='offset points', va='center', ha='center', color=blue_grad2[1], fontsize=8, fontweight='bold', fontname=font_alt, style='italic')
annotate_avg_right = dict(xytext=(0, 0), textcoords='offset points', va='center', ha='center', color='w', fontsize=9, fontweight='bold', fontname=font_alt, style='italic', bbox=dict(boxstyle='round', pad=0.2, color=blue_grad2[1]))
annotate_max_right = dict(xytext=(0, 0), textcoords='offset points', va='center', ha='center', color=blue_grad2[1], fontsize=8, fontweight='bold', fontname=font_alt, style='italic')
suptitle = dict(x=0.5, y=1.05, fontsize=12, weight='heavy', ha='center', va='center', fontname=font_main, color=black_grad[0])
title_prop = dict(style='italic', weight='bold', fontsize=10, ha='center', color=black_grad[0], fontname=font_alt)
xy_label = dict(fontweight='bold', fontsize=9, color=black_grad[0])
xy_ticks = dict(fontsize=8, fontname=font_alt)
explanation = dict(x=0.5, y=-0.1, fontname=font_alt, color=black_grad[0], fontsize=7, ha='center', va='bottom', textalign='center')
highlight_explanation = [{'weight':'bold'}, {'weight':'bold', 'color': blue_grad[1]}]

# --- Display EDA 5 ---
plt.figure(figsize=(9, 5))

# --- EDA 5: Left ---
plt.subplot(1, 2, 1)
plt.tight_layout(rect=[0, 0, 1, 1.01])
plt.title('Not Survived\n', **title_prop)
sct_df5_0_min = plt.scatter(x=df5_0_min['Fare'], y=df5_0_min['Embarked'], c=black_grad[3], **sct_prop)
sct_df5_0_max = plt.scatter(x=df5_0_max['Fare'], y=df5_0_max['Embarked'], c=black_grad[1], **sct_prop)
plt.hlines(y=2, xmin=label_0[2][1], xmax=label_0[2][2], **hlines_left)
plt.hlines(y=1, xmin=label_0[1][1], xmax=label_0[1][2], **hlines_left)
plt.hlines(y=0, xmin=label_0[0][1], xmax=label_0[0][2], **hlines_left)
plt.xlabel('\nFare', **xy_label)
plt.xticks(**xy_ticks)
plt.yticks(**xy_ticks)
plt.grid(axis='y', alpha=0, zorder=2)
plt.grid(axis='x', which='major', alpha=0.75, color=black_grad[4], linestyle='dotted', zorder=1)
plt.annotate('{0:.1f}'.format(label_0[2][1]), xy=(label_0[2][1], 1.8), **annotate_min_left)
plt.annotate('{0:.1f}'.format(label_0[1][1]), xy=(label_0[1][1], 0.8), **annotate_min_left)
plt.annotate('{0:.1f}'.format(label_0[0][1]), xy=(label_0[0][1], 0.2), **annotate_min_left)
plt.annotate('{0:.1f}'.format(avg_0_S), xy=(avg_0_S, 2), **annotate_avg_left)
plt.annotate('{0:.1f}'.format(avg_0_Q), xy=(avg_0_Q, 1), **annotate_avg_left)
plt.annotate('{0:.1f}'.format(avg_0_C), xy=(avg_0_C, 0), **annotate_avg_left)
plt.annotate('{0:.1f}'.format(label_0[2][2]), xy=(label_0[2][2], 1.8), **annotate_max_left)
plt.annotate('{0:.1f}'.format(label_0[1][2]), xy=(label_0[1][2], 0.8), **annotate_max_left)
plt.annotate('{0:.1f}'.format(label_0[0][2]), xy=(label_0[0][2], 0.2), **annotate_max_left)
axs_left=plt.gca()
for spine in axs_left.spines.values(): spine.set_color('None')

# --- EDA 5: Right ---
plt.subplot(1, 2, 2)
plt.tight_layout(rect=[0, 0, 1, 1.01])
plt.title('Survived\n', **title_prop)
sct_df5_1_min = plt.scatter(x=df5_1_min['Fare'], y=df5_1_min['Embarked'], c=blue_grad2[3], **sct_prop)
sct_df5_1_max = plt.scatter(x=df5_1_max['Fare'], y=df5_1_max['Embarked'], c=blue_grad2[1], **sct_prop)
plt.hlines(y=2, xmin=label_1[2][1], xmax=label_1[2][2], **hlines_right)
plt.hlines(y=1, xmin=label_1[1][1], xmax=label_1[1][2], **hlines_right)
plt.hlines(y=0, xmin=label_1[0][1], xmax=label_1[0][2], **hlines_right)
plt.xlabel('\nFare', **xy_label)
plt.xticks(**xy_ticks)
plt.yticks(**xy_ticks)
plt.grid(axis='y', alpha=0, zorder=2)
plt.grid(axis='x', which='major', alpha=0.75, color=black_grad[4], linestyle='dotted', zorder=1)
plt.annotate('{0:.1f}'.format(label_1[2][1]), xy=(label_1[2][1], 1.8), **annotate_min_right)
plt.annotate('{0:.1f}'.format(label_1[1][1]), xy=(label_1[1][1], 0.8), **annotate_min_right)
plt.annotate('{0:.1f}'.format(label_1[0][1]), xy=(label_1[0][1], 0.2), **annotate_min_right)
plt.annotate('{0:.1f}'.format(avg_1_S), xy=(avg_1_S, 2), **annotate_avg_right)
plt.annotate('{0:.1f}'.format(avg_1_Q), xy=(avg_1_Q, 1), **annotate_avg_right)
plt.annotate('{0:.1f}'.format(avg_1_C), xy=(avg_1_C, 0), **annotate_avg_right)
plt.annotate('{0:.1f}'.format(label_1[2][2]), xy=(label_1[2][2], 1.8), **annotate_max_right)
plt.annotate('{0:.1f}'.format(label_1[1][2]), xy=(label_1[1][2], 0.8), **annotate_max_right)
plt.annotate('{0:.1f}'.format(label_1[0][2]), xy=(label_1[0][2], 0.2), **annotate_max_right)
axs_right=plt.gca()
for spine in axs_right.spines.values(): spine.set_color('None')
fig_text(s="Fare Distribution based on Embarked", **suptitle)
fig_text(s="<Some tickets have zero value> (assuming they are crew members).\nIn addition, <most ticket prices are close to the minimum price> for each embarked.", highlight_textprops=highlight_explanation, **explanation)
plt.gcf().text(0.85, -0.13, 'kaggle.com/caesarmario', style='italic', fontsize=6)
plt.show();

# %% [markdown]
# ## <div class="header2">5.4 | Passengers Family Sizes Distributions 👨‍👩‍👧‍👦</div>
# <!-- Hello world 👋. Thank you so much for downloading/forking my codes/works. If you like my works, please support me by giving upvotes and comments on my Kaggle profile (https://www.kaggle.com/caesarmario/). Thank you so much and have a great day 😆👍. More about me: https://linktr.ee/caesarmario_ -->

# %%
# --- EDA 6 Variables ---
suptitle = dict(x=0.5, y=0.85, fontsize=14, weight='heavy', ha='center', va='center', color=black_grad[0])
title = dict(x=0.5, y=0.81, fontsize=9, weight='normal', ha='center', va='center', fontname=font_alt, color=black_grad[0])
percentage = dict(fontsize=18, ha='center', weight='bold', va='bottom')
explanation = dict(color=colors_eda6[3], fontsize=9, ha='center', va='top', textalign='center', fontname=font_alt)
highlight_textprops = [{'weight':'bold'}]

# --- EDA 6 Dataframes ---
df6 = df_train.xs(['Parch', 'SibSp'], axis = 1)
df6_1 = df_test.xs(['Parch', 'SibSp'], axis = 1)
df6 = df6.append(df6_1)
df6['Family_Size'] = df6['Parch'] + df6['SibSp'] + 1
df6.loc[df6['Family_Size'] > 5, 'Family_Size'] = '>5'
df6['Family_Size'] = df6['Family_Size'].astype(str)
df6_values = df6['Family_Size'].value_counts().reindex(order_eda6).to_dict()
df6 = {key: value / 10 for key, value in df6_values.items()}

# --- EDA 6 Percentage ---
total = df6_values['1']+df6_values['2']+df6_values['3']+df6_values['4']+df6_values['5']+df6_values['>5']
alone = df6_values['1']/total*100
both = df6_values['2']/total*100
group1 = (df6_values['3']+df6_values['4']+df6_values['5'])/total*100
group2 = df6_values['>5']/total*100

# --- EDA 6 Display ---
fig = plt.figure(FigureClass=Waffle, rows=6, colors=colors_eda6, values=df6, figsize=(9, 5), labels=[f"{i} - ({k})" for i, k in df6_values.items()], legend={'loc': 'upper center', 'bbox_to_anchor': (0.5, -0.05), 'ncol': 3, 'borderpad': 2, 'frameon': False, 'fontsize': 8})
fig_text(x=0.215, y=0.02, s="{0:.2f}%".format(alone), color=colors_eda6[0], **percentage)
fig_text(x=0.215, y=0.01, s=f"passengers\ntravel <alone>", highlight_textprops=highlight_textprops, **explanation)
fig_text(x=0.4, y=0.02, s="{0:.2f}%".format(both), color=colors_eda6[1], **percentage)
fig_text(x=0.4, y=0.01, s=f"passengers travel with\ntheir <one family member>", highlight_textprops=highlight_textprops, **explanation)
fig_text(x=0.585, y=0.02, s="{0:.2f}%".format(group1), color=colors_eda6[2], **percentage)
fig_text(x=0.585, y=0.01, s=f"passengers travel with\n<3-5 family members>", highlight_textprops=highlight_textprops, **explanation)
fig_text(x=0.77, y=0.02, s="{0:.2f}%".format(group2), color=colors_eda6[3], **percentage)
fig_text(x=0.77, y=0.01, s=f"passengers travel\n<in a bigger group>", highlight_textprops=highlight_textprops, **explanation)
fig_text(x=0.02, y=0.25, s="** 1 square = 10 passengers", style='italic', fontsize=6, fontname=font_alt)
fig_text(s="Passengers Family Sizes Distributions", **suptitle)
fig_text(s="It appears that the <majority of people who travel with their families do so with three or fewer members>.", highlight_textprops=highlight_textprops, **title)
fig_text(x=0.86, y=-0.1, s='kaggle.com/caesarmario', style='italic', fontsize=6)
plt.show();

# %% [markdown]
# ## <div class="header2">5.5 | Age Distribution based on Survival 🧓😇</div>
# <!-- Hello world 👋. Thank you so much for downloading/forking my codes/works. If you like my works, please support me by giving upvotes and comments on my Kaggle profile (https://www.kaggle.com/caesarmario/). Thank you so much and have a great day 😆👍. More about me: https://linktr.ee/caesarmario_ -->

# %%
# --- EDA 7 Dataframe ---
df7_0 = df_train.xs(['Age'], axis=1)[df_train.Survived==0]
df7_1 = df_train.xs(['Age'], axis=1)[df_train.Survived==1]

# --- EDA 7 Variables ---
age_mean0 = df7_0.Age.mean()
age_mean1 = df7_1.Age.mean()
suptitle = dict(x=0.224, y=1.06, fontsize=13, weight='heavy', ha='left', va='bottom', color=black_grad[0])
title = dict(x=0.224, y=1.02, fontsize=8, weight='normal', ha='left', va='bottom', fontname=font_alt, color=black_grad[0])
xy_label = dict(fontweight='bold', fontsize=10, color=black_grad[0])
xy_ticks = dict(fontsize=7, fontname=font_alt)
highlight_textprops = [{'weight':'bold', 'color': blue_grad2[1]}]

# --- EDA 7 Display ---
sns.displot(df_train, x='Age', hue='Survived', kind='kde', fill=True, legend=False, palette=color_eda7, zorder=3)

# --- EDA 7 Settings ---
plt.axvline(x=age_mean0, linestyle='--', color=black_grad[3])
plt.axvline(x=age_mean1, linestyle='--', color=blue_grad2[0])
plt.annotate("Not Survived Avg.:\n{:.2f}".format(age_mean0), fontname=font_alt, fontsize=6, color=black_grad[1], xy=(age_mean0, 0.018), xytext=(age_mean0+5, 0.019), arrowprops={"arrowstyle":"->", "color":black_grad[2]})
plt.annotate("Survived Avg.:\n{:.2f}".format(age_mean1), fontname=font_alt, fontsize=6, color=blue_grad2[0], xy=(age_mean1, 0.0195), xytext=(age_mean0-20, 0.0195), arrowprops={"arrowstyle":"->", "color":blue_grad[0]})
plt.xlabel('\nAge', **xy_label)
plt.ylabel('Density\n', **xy_label)
plt.xticks(**xy_ticks)
plt.yticks(**xy_ticks)
plt.grid(axis='x', which='major', alpha=0.75, color=black_grad[4], linestyle='dotted', zorder=1)
plt.grid(axis='y', alpha=0, zorder=2)
plt.legend(label_eda7, loc='upper center', bbox_to_anchor=(0.5, -0.15), ncol=5, borderpad=3, frameon=False, fontsize=8)
fig_text(s="Age Distribution based on Survival", **suptitle)
fig_text(s="The passengers who survived and did not survive are primarily <between 20 to 30 years old>.", highlight_textprops=highlight_textprops, **title)
plt.gcf().text(0.82, -0.15, 'kaggle.com/caesarmario', style='italic', fontsize=7)
plt.gcf().set_size_inches(9, 4)
plt.show();

# %% [markdown]
# <div class="explain-box">
#     From the chart, it can be seen that <b>not survived</b> distribution is <mark><b>leptokurtic</b></mark>, while other is <mark><b>platikurtic</b></mark>. Furthermore, there are <mark><b>outliers</b></mark> on the <b>right side</b> of both plots.
# </div>
# <!-- Hello world 👋. Thank you so much for downloading/forking my codes/works. If you like my works, please support me by giving upvotes and comments on my Kaggle profile (https://www.kaggle.com/caesarmario/). Thank you so much and have a great day 😆👍. More about me: https://linktr.ee/caesarmario_ -->

# %% [markdown]
# # <div class="header1">6. | Datasets Pre-processing 🔨</div>
# <div class="explain-box">
#     This section will <b>prepare both datasets</b> before building the machine learning models.<b>Each pre-processing stage</b> will be included in <b>a pipeline</b>, which will <b>later be combined in the last step</b> of pre-processing to create <mark><b>an end-to-end pre-processing pipeline</b></mark>. At the end of the pre-processing, the data will be <b>split according to its initial size</b> and <b>scaled</b> using a standard scaler.The following is the <mark><b>pre-processing scheme</b></mark> that will be performed:<br>
#     <center><br>
#         <img src="https://i.imgur.com/zbFvhx8.png"><br>
#         <i style="font-size: 12px; color: #000000;">🖼️ Titanic Datasets Pre-processing Schema</i>
#     </center>
#     <blockquote style="font-size: 10px; color: #000000;">
#         ** <u><i> The datasets pre-processing technique <b>inspired</b> from <b><a href="https://www.kaggle.com/code/korfanakis/titanic-a-beginner-friendly-approach-to-top-3">Orfanakis Konstantinos</a></b> and <b><a href="https://www.kaggle.com/code/konstantinmasich/titanic-0-82-0-83/notebook">Konstantin</a></b> notebooks.</i></u>
#     </blockquote>
# </div>

# %% [markdown]
# ## <div class="header2">6.1 | Features Separating and Splitting 🪓</div>
# <div class="explain-box">
#      At the initial step, <mark>both datasets will be appended</mark> into a dataframe.
# </div>
# <!-- Hello world 👋. Thank you so much for downloading/forking my codes/works. If you like my works, please support me by giving upvotes and comments on my Kaggle profile (https://www.kaggle.com/caesarmario/). Thank you so much and have a great day 😆👍. More about me: https://linktr.ee/caesarmario_ -->

# %%
# --- Append Datasets ---
df = df_train.append(df_test)
print(clr.start+'.:. New Dataframe Info .:.'+clr.end)
print(clr.color+'*' * 27+clr.end)
print('\t.: Total data in new dataframe: '+clr.start+f"{df.shape[0]}"+clr.end)
print('\t.: Total column in new dataframe: '+clr.start+f"{df.shape[1]}"+clr.end)

# %% [markdown]
# ## <div class="header2">6.2 | Pre-processing Pipeline ⚒️</div>
# <div class="explain-box">
#      This section will <b>build the pre-processing pipeline</b> based on the previously created schema. The pre-processing pipeline consists of <mark>imputation, feature engineering, binning and encoding, and drop columns</mark>. In addition, this section will also <mark>combine all pipelines that have been built</mark> and <mark>process the appended data</mark>.
# </div>
# <!-- Hello world 👋. Thank you so much for downloading/forking my codes/works. If you like my works, please support me by giving upvotes and comments on my Kaggle profile (https://www.kaggle.com/caesarmario/). Thank you so much and have a great day 😆👍. More about me: https://linktr.ee/caesarmario_ -->

# %% [markdown]
# ### <div class="header3">6.2.1 | Data Imputation 🧹</div>
# <div class="explain-box">
#      In this section, imputation in the <mark>Age column</mark> will be based on the <b>median age of a title</b>. As for the <mark>Fare column</mark>, imputation will be carried out using the <b>median</b>. In addition, this section will also <b>create a new column</b> named <mark>Title</mark>.
# </div>
# <!-- Hello world 👋. Thank you so much for downloading/forking my codes/works. If you like my works, please support me by giving upvotes and comments on my Kaggle profile (https://www.kaggle.com/caesarmario/). Thank you so much and have a great day 😆👍. More about me: https://linktr.ee/caesarmario_ -->

# %%
# --- Data Imputation Pipeline ---
class Imputation(BaseEstimator, TransformerMixin):
    def fit(self, df, y=None):
        return self

    def transform(self, df):
        # --- Age Imputation based on Title Median Age ---
        df['Title'] = df['Name'].str.split(pat=', ', n=1, expand=True)[
            1].str.split(pat='.', n=1, expand=True)[0]

        mapping = {'Mlle': 'Miss', 'Ms': 'Miss', 'Mme': 'Mrs', 'Lady': 'Mrs', 'Countess': 'Mrs',
                   'Dona': 'Mrs', 'Sir': 'Mr', 'Major': 'Other', 'Col': 'Other', 'Don': 'Other', 
                   'Jonkheer': 'Other', 'Capt': 'Other'}
        df.replace({'Title': mapping}, inplace=True)

        titles = ['Dr', 'Master', 'Miss', 'Mr', 'Mrs', 'Rev']

        for title in titles:
            impute_age = df.groupby('Title')['Age'].median()[titles.index(title)]
            impute_age = df.loc[(df['Age'].isnull()) &
                                (df['Title'] == title), 'Age']
        
        # --- Fare Imputation using Median ---
        df['Fare'].fillna(df['Fare'].median(), inplace=True)

        return df

# %% [markdown]
# ### <div class="header3">6.2.2 | Feature Engineering 🔨</div>
# <div class="explain-box">
#      In this section, <b>two columns will be added</b> to dataframe, namely <mark>Family Size</mark> and <mark>Family Survival</mark> columns.
# </div>
# <!-- Hello world 👋. Thank you so much for downloading/forking my codes/works. If you like my works, please support me by giving upvotes and comments on my Kaggle profile (https://www.kaggle.com/caesarmario/). Thank you so much and have a great day 😆👍. More about me: https://linktr.ee/caesarmario_ -->

# %%
# --- Feature Engineering Pipeline ---
class FeatureEngineering(BaseEstimator, TransformerMixin):
    def fit(self, df, y=None):
        return self

    def transform(self, df):
        # --- Add `Family_Size` Column ---
        df['Family_Size'] = df['Parch'] + df['SibSp']
        
        # --- Add `Family_Survival` Column ---
        df['Last_Name'] = df['Name'].apply(lambda x: str.split(x, ',')[0])
        
        survival_rate = 0.5
        df['Family_Survival'] = survival_rate

        for group, group_df in df[['Survived', 'Name', 'Last_Name', 'Fare',
                                   'Ticket', 'PassengerId', 'SibSp', 'Parch', 'Age', 'Cabin']].groupby(['Last_Name', 'Fare']):
            if (len(group_df) != 1):
                for index, row in group_df.iterrows():
                    smax = group_df.drop(index)['Survived'].max()
                    smin = group_df.drop(index)['Survived'].min()
                    passID = row['PassengerId']
                    if (smax == 1.0):
                        df.loc[df['PassengerId'] ==
                               passID, 'Family_Survival'] = 1
                    elif (smin == 0.0):
                        df.loc[df['PassengerId'] ==
                               passID, 'Family_Survival'] = 0

        for _, group_df in df.groupby('Ticket'):
            if (len(group_df) != 1):
                for index, row in group_df.iterrows():
                    if (row['Family_Survival'] == 0) | (row['Family_Survival'] == 0.5):
                        smax = group_df.drop(index)['Survived'].max()
                        smin = group_df.drop(index)['Survived'].min()
                        passID = row['PassengerId']
                        if (smax == 1.0):
                            df.loc[df['PassengerId'] ==
                                   passID, 'Family_Survival'] = 1
                        elif (smin == 0.0):
                            df.loc[df['PassengerId'] ==
                                   passID, 'Family_Survival'] = 0
        return df

# %% [markdown]
# ### <div class="header3">6.2.3 | Binning and Encoding 🗑️🔢</div>
# <div class="explain-box">
#      This section will perform <mark>binning for Fare and Age columns</mark>. Furthermore, this section will also perform <mark>label encoding</mark> for <b>binned Fare and Age, Sex,</b> and <b>Title columns</b>.
# </div>
# <!-- Hello world 👋. Thank you so much for downloading/forking my codes/works. If you like my works, please support me by giving upvotes and comments on my Kaggle profile (https://www.kaggle.com/caesarmario/). Thank you so much and have a great day 😆👍. More about me: https://linktr.ee/caesarmario_ -->

# %%
# --- Binning & Encoding ---
class BinningEncoding(BaseEstimator, TransformerMixin):
    def fit(self, df, y=None):
        return self

    def transform(self, df):
        # --- `Fare` and `Age` Binning ---
        df['Fare_Bin'] = pd.qcut(df['Fare'], 5)
        df['Age_Bin'] = pd.qcut(df['Age'], 4)
        
        # --- Label Encoding ---
        df['Fare_Bin'] = LabelEncoder().fit_transform(df['Fare_Bin'])
        df['Age_Bin'] = LabelEncoder().fit_transform(df['Age_Bin'])
        df['Sex'] = LabelEncoder().fit_transform(df['Sex'])
        df['Title'] = LabelEncoder().fit_transform(df['Title'])

        return df

# %% [markdown]
# ### <div class="header3">6.2.4 | Drop Columns🔻</div>
# <div class="explain-box">
#      <mark>Unnecessary columns will be dropped</mark> in this section.
# </div>
# <!-- Hello world 👋. Thank you so much for downloading/forking my codes/works. If you like my works, please support me by giving upvotes and comments on my Kaggle profile (https://www.kaggle.com/caesarmario/). Thank you so much and have a great day 😆👍. More about me: https://linktr.ee/caesarmario_ -->

# %%
# --- Dropping Columns ---
class DropColumns(BaseEstimator, TransformerMixin):
    def fit(self, df, y=None):
        return self

    def transform(self, df):

        df.drop(['Name', 'Age', 'Fare', 'Last_Name', 'PassengerId',
                 'SibSp', 'Parch', 'Ticket', 'Cabin', 'Embarked'], axis=1, inplace=True)

        return df

# %% [markdown]
# ### <div class="header3">6.2.5 | Assembling Pipelines 🔩</div>
# <div class="explain-box">
#      The final step is to <mark>combine all the pipelines</mark> that have been created into <b>one large pipeline</b>. Next, the data will go through the pipeline and <b>display the results</b>.
# </div>
# <!-- Hello world 👋. Thank you so much for downloading/forking my codes/works. If you like my works, please support me by giving upvotes and comments on my Kaggle profile (https://www.kaggle.com/caesarmario/). Thank you so much and have a great day 😆👍. More about me: https://linktr.ee/caesarmario_ -->

# %%
# --- Assembling Preprocessing Pipeline ---
preprocessing = Pipeline([
    ('Imputation', Imputation())
    ,('FeatureEngineering', FeatureEngineering())
    ,('BinningEncoding', BinningEncoding())
    ,('DropColumns', DropColumns())
])

# %%
# --- Preprocessing Results ---
df = preprocessing.fit_transform(df)
df.head().style.background_gradient(cmap='YlOrBr_r').hide_index()

# %% [markdown]
# ## <div class="header2">6.3 | Split and Scaling 📏</div>
# <div class="explain-box">
#      After pre-processing, the last step is to <mark>split the data frame</mark> into train and test according to the original size. In addition, train and test sets will be <mark>scaled</mark> using a <b>standard scaler</b>.
# </div>
# <!-- Hello world 👋. Thank you so much for downloading/forking my codes/works. If you like my works, please support me by giving upvotes and comments on my Kaggle profile (https://www.kaggle.com/caesarmario/). Thank you so much and have a great day 😆👍. More about me: https://linktr.ee/caesarmario_ -->

# %%
# --- Split ---
df_train = df.iloc[:891, :]
X_train = df_train.drop('Survived', axis=1)
y_train = df_train['Survived'].astype(int)

X_test = df.iloc[891:, :].drop('Survived', axis=1)

# --- Scaling ---
scaling = Pipeline([('scaler', StandardScaler())])
X_train_scaled = scaling.fit_transform(X_train)
X_test_scaled = scaling.transform(X_test)

# %% [markdown]
# # <div class="header1">7. | Model Implementation ⚙️</div>
# <div class="explain-box">
#     This section will implement various machine learning models as mentioned in <b>Introduction</b> section. In addition, <b>explanation for each models will be provided</b>.
# </div>

# %%
# --- Creating `y_test` ---
y_test = pd.read_csv('../input/titanic-leaked/titanic.csv')
y_test = y_test['Survived'].values.tolist()
y_test = np.array(y_test)

# --- Labels Feature Importance ---
labels = list(X_train.columns)

# --- Function for Model Fitting and Performance Evaluation ---
def ml_models(algo_name, algo, param):
    
    # --- Apply Grid Search ---
    model = GridSearchCV(algo, param_grid=param, cv=10, n_jobs=-1, verbose=1)
    
    # --- Fitting Model ---
    print(clr.start+f'.:. Fitting {algo_name} .:.'+clr.end)
    fit_model = model.fit(X_train_scaled, y_train)
    print(fit_model)
    
    # --- Final Estimators ---
    best_estimator = model.best_estimator_._final_estimator
    print(clr.start+f'\n.:. Final Estimators for {algo_name} .:.'+clr.end)
    print(best_estimator)
    
    # --- Prediction Result & Best Estimator ---
    y_pred_train = model.predict(X_train_scaled)
    y_pred = model.predict(X_test_scaled)
    best_model = model.best_estimator_
    
    # --- Acc & Best Score ---
    best_score = model.best_score_
    acc_score_train = accuracy_score(y_pred_train, y_train)
    acc_score = accuracy_score(y_pred, y_test)
    print(clr.start+f'\n.:. Accuracy & Best Score for {algo_name} .:.'+clr.end)
    print('\t>> Accuracy: '+clr.start+'{:.2f}%'.format(acc_score*100)+clr.end)
    print('\t>> Best Score: '+clr.start+'{:.2f}%'.format(best_score*100)+clr.end)
    
    # --- Classification Report ---
    print(clr.start+'\n.:. Classification Report .:.'+clr.end)
    print(classification_report(y_test, y_pred))
    
    # --- Figures Settings ---
    xy_label = dict(fontweight='bold', fontsize=12)
    grid_style = dict(color=color_grid, linestyle='dotted', zorder=1)
    title_style = dict(fontsize=14, fontweight='bold', fontname=font_alt)
    tick_params = dict(length=3, width=1, color=color_line)
    bar_style = dict(zorder=3, edgecolor='black', linewidth=0.5, alpha=0.85)
    set_palette(color_yb)
    fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2, 2, figsize=(16, 14))
    
    # --- Confusion Matrix ---
    conf_matrix = ConfusionMatrix(best_estimator, ax=ax1, cmap='Blues')
    conf_matrix.fit(X_train_scaled, y_train)
    conf_matrix.score(X_test_scaled, y_test)
    conf_matrix.finalize()
    conf_matrix.ax.set_title('Confusion Matrix\n', **title_style)
    conf_matrix.ax.tick_params(axis='both', labelsize=10, bottom='on', left='on', **tick_params)
    for spine in conf_matrix.ax.spines.values(): spine.set_color(color_line)
    conf_matrix.ax.set_xlabel('\nPredicted Class', **xy_label)
    conf_matrix.ax.set_ylabel('True Class\n', **xy_label)
    conf_matrix.ax.xaxis.set_ticklabels(['False', 'True'], rotation=0)
    conf_matrix.ax.yaxis.set_ticklabels(['True', 'False'])
    
    # --- ROC AUC ---
    logrocauc = ROCAUC(best_estimator, classes=['False', 'True'], ax=ax2)
    logrocauc.fit(X_train_scaled, y_train)
    logrocauc.score(X_test_scaled, y_test)
    logrocauc.finalize()
    logrocauc.ax.set_title('ROC AUC Curve\n', **title_style)
    logrocauc.ax.tick_params(axis='both', labelsize=10, bottom='on', left='on', **tick_params)
    logrocauc.ax.grid(axis='both', alpha=0.4, **grid_style)
    for spine in logrocauc.ax.spines.values(): spine.set_color('None')
    for spine in ['bottom', 'left']:
        logrocauc.ax.spines[spine].set_visible(True)
        logrocauc.ax.spines[spine].set_color(color_line)
    logrocauc.ax.legend(loc='upper center', bbox_to_anchor=(0.5, -0.12), ncol=2, borderpad=2, frameon=False, fontsize=10)
    logrocauc.ax.set_xlabel('\nFalse Positive Rate', **xy_label)
    logrocauc.ax.set_ylabel('True Positive Rate\n', **xy_label)
    logrocauc.ax.tick_params(axis='both', which='major', labelsize=10)
    
    # --- Learning Curve ---
    lcurve = LearningCurve(best_estimator, ax=ax3, colors=color_yb)
    lcurve.fit(X_train_scaled, y_train)
    lcurve.finalize()
    lcurve.ax.set_title('Learning Curve\n', **title_style)
    lcurve.ax.tick_params(axis='both', labelsize=10, bottom='on', left='on', **tick_params)
    lcurve.ax.grid(axis='both', alpha=0.4, **grid_style)
    for spine in lcurve.ax.spines.values(): spine.set_color('None')
    for spine in ['bottom', 'left']:
        lcurve.ax.spines[spine].set_visible(True)
        lcurve.ax.spines[spine].set_color(color_line)
    lcurve.ax.legend(loc='upper center', bbox_to_anchor=(0.5, -0.12), ncol=2, borderpad=2, frameon=False, fontsize=10)
    lcurve.ax.set_xlabel('\nTraining Instances', **xy_label)
    lcurve.ax.set_ylabel('Scores\n', **xy_label)
    
    # --- Feature Importance or Precision Recall Curve ---
    try:
        feat_importance = FeatureImportances(best_estimator, ax=ax4, labels=labels, topn=5, colors=color_yb_importance)
        feat_importance.fit(X_train_scaled, y_train)
        feat_importance.finalize()
        feat_importance.ax.set_title('Feature Importances (Top 5 Features)\n', **title_style)
        feat_importance.ax.tick_params(axis='both', labelsize=10, bottom='on', left='on', **tick_params)
        feat_importance.ax.grid(axis='x', alpha=0.4, **grid_style)
        feat_importance.ax.grid(axis='y', alpha=0, **grid_style)
        for spine in feat_importance.ax.spines.values(): spine.set_color('None')
        for spine in ['bottom']:
            feat_importance.ax.spines[spine].set_visible(True)
            feat_importance.ax.spines[spine].set_color(color_line)
        feat_importance.ax.set_xlabel('\nRelative Importance', **xy_label)
        feat_importance.ax.set_ylabel('Features\n', **xy_label)
    except:
        prec_curve = PrecisionRecallCurve(best_estimator, ax=ax4, ap_score=True, iso_f1_curves=True)
        prec_curve.fit(X_train_scaled, y_train)
        prec_curve.score(X_test_scaled, y_test)
        prec_curve.finalize()
        prec_curve.ax.set_title('Precision-Recall Curve\n', **title_style)
        prec_curve.ax.tick_params(axis='both', labelsize=10, bottom='on', left='on', **tick_params)
        for spine in prec_curve.ax.spines.values(): spine.set_color('None')
        for spine in ['bottom', 'left']:
            prec_curve.ax.spines[spine].set_visible(True)
            prec_curve.ax.spines[spine].set_color(color_line)
        prec_curve.ax.legend(loc='upper center', bbox_to_anchor=(0.5, -0.12), ncol=2, borderpad=2, frameon=False, fontsize=10)
        prec_curve.ax.set_xlabel('\nRecall', **xy_label)
        prec_curve.ax.set_ylabel('Precision\n', **xy_label)
        
    plt.suptitle(f'\n{algo_name} Performance Evaluation Report\n', fontsize=18, fontweight='bold')
    plt.gcf().text(0.88, 0.02, 'kaggle.com/caesarmario', style='italic', fontsize=10)
    plt.tight_layout();

    return best_model, acc_score, acc_score_train, best_score

# %% [markdown]
# ## <div class="header2">7.1 | Logistic Regression</div>
# <div class="explain-box">
#     <blockquote style="color: #000000;">
#         <mark><b>Logistic regression</b></mark> is a statistical method that is used for building machine learning models where <b>the dependent variable is dichotomous: i.e. binary</b>. Logistic regression is used to describe data and <b>the relationship between one dependent variable and one or more independent variables</b>. The independent variables can be nominal, ordinal, or of interval type.<br><br>
#     The name "logistic regression" is derived from the concept of the logistic function that it uses. <b>The logistic function is also known as the sigmoid function</b>. The value of this logistic function lies between zero and one.<br><br>
#         <center>
#             <img src="https://www.simplilearn.com/ice9/free_resources_article_thumb/years-2.JPG" alt="Logistic Regression" width="40%"><br>
#             <i>🖼 Logistic Function by Simplilearn</i>
#         </center>
#     </blockquote>
# </div>
# <!-- Hello world 👋. Thank you so much for downloading/forking my codes/works. If you like my works, please support me by giving upvotes and comments on my Kaggle profile (https://www.kaggle.com/caesarmario/). Thank you so much and have a great day 😆👍. More about me: https://linktr.ee/caesarmario_ -->

# %%
# --- Logistic Regression Parameters ---
parameter_LR = {'algo__C': [0.01, 0.03, 0.05],
                'algo__intercept_scaling': [0.01, 0.1, 1],
                'algo__solver': ['newton-cg', 'lbfgs', 'liblinear', 'sag', 'saga']}

# --- Logistic Regression Pipeline ---
algo_LR = Pipeline([('algo', LogisticRegression(random_state=42))])

# --- Applying Logistic Regression ---
model_LR = ml_models('Logistic Regression', algo_LR, parameter_LR)

# %% [markdown]
# ## <div class="header2">7.2 | Support Vector Machine (SVM)</div>
# <div class="explain-box">
#     <blockquote style="color: #000000;">
#         <mark><b>Support Vector Machine (SVM)</b></mark> is one of the most popular Supervised Learning algorithms, which is used for Classification as well as Regression problems. The goal of the SVM algorithm is <b>to create the best line or decision boundary that can segregate n-dimensional space into classes</b> so that we can easily put the new data point in the correct category in the future. This best decision boundary is called a hyperplane.<br><br>
#         SVM chooses the <b>extreme points/vectors</b> that help in creating the hyperplane. These extreme cases are called as support vectors, and hence algorithm is termed as Support Vector Machine.<br>
#         <center>
#             <img src="https://static.javatpoint.com/tutorial/machine-learning/images/support-vector-machine-algorithm.png" alt="SVM" width="40%"><br>
#             <i>🖼 SVM by JavaTPoint</i>
#         </center>
#     </blockquote>
# </div>
# <!-- Hello world 👋. Thank you so much for downloading/forking my codes/works. If you like my works, please support me by giving upvotes and comments on my Kaggle profile (https://www.kaggle.com/caesarmario/). Thank you so much and have a great day 😆👍. More about me: https://linktr.ee/caesarmario_ -->

# %%
# --- SVM Parameters ---
parameter_SVC = [{'algo__kernel': ['rbf'], 'algo__gamma': np.arange(0.1, 0.5, 0.1), 'algo__C': np.arange(0.1, 0.5, 0.1)},
                 {'algo__kernel': ['linear'], 'algo__C': np.arange(0.1, 0.5, 0.1)},
                 {'algo__kernel': ['poly'], 'algo__degree' : np.arange(1, 10, 1), 'algo__C': np.arange(0.1, 0.5, 0.1)}]

# --- SVM Pipeline ---
algo_SVC = Pipeline([('algo', SVC(random_state=1, probability=True))])

# --- Applying SVM ---
model_SVC = ml_models('SVM', algo_SVC, parameter_SVC)

# %% [markdown]
# ## <div class="header2">7.3 | K-Nearest Neighbour (KNN)</div>
# <div class="explain-box">
#     <blockquote style="color: #000000;">
#         <mark><b>The k-nearest neighbors (KNN)</b></mark> algorithm is a data classification method <b>for estimating the likelihood that a data point will become a member of one group or another</b> based on what group the data points nearest to it belong to. The k-nearest neighbor algorithm is a type of supervised machine learning algorithm used <b>to solve classification and regression problems</b>.<br><br>
#     It's called a <b>lazy learning algorithm or lazy learner</b> because it doesn't perform any training when you supply the training data. Instead, it just stores the data during the training time and doesn't perform any calculations. It doesn't build a model until a query is performed on the dataset. This makes KNN ideal for data mining.<br><br>
#         <center>
#             <img src="https://1.bp.blogspot.com/-D6REhf2XBwQ/XZcWn0cwSEI/AAAAAAAAAvs/LUCN8jxvzcMjkkDK4FAXSuR7MBDW8SBJgCLcBGAsYHQ/s1600/KNN_final_a1mrv9.jpg" alt="KNN" width="35%"><br>
#             <i>🖼 KNN by Kita Informatika</i>
#         </center>
#     </blockquote>
# </div>
# <!-- Hello world 👋. Thank you so much for downloading/forking my codes/works. If you like my works, please support me by giving upvotes and comments on my Kaggle profile (https://www.kaggle.com/caesarmario/). Thank you so much and have a great day 😆👍. More about me: https://linktr.ee/caesarmario_ -->

# %%
# --- KNN Parameters ---
parameter_KNN = {'algo__n_neighbors': [2, 5, 10],
                 'algo__leaf_size': [3, 4, 5]}

# --- KNN Pipeline ---
algo_KNN = Pipeline([('algo', KNeighborsClassifier(p=2, n_jobs=-1))])

# --- Applying KNN ---
model_KNN = ml_models('KNN', algo_KNN, parameter_KNN)

# %% [markdown]
# ## <div class="header2">7.4 | Decision Tree</div>
# <div class="explain-box">
#     <blockquote style="color: #000000;">
#         <mark><b>Decision Tree</b></mark> is a Supervised learning technique that can be used for both classification and Regression problems, but mostly it is preferred for solving Classification problems. It is a tree-structured classifier, where <b>internal nodes represent the features of a dataset, branches represent the decision rules and each leaf node represents the outcome</b>.<br><br>
#     In a Decision tree, there are <b>two nodes</b>, which are the <mark><b>Decision Node and Leaf Node</b></mark>. Decision nodes are used to make any decision and have multiple branches, whereas Leaf nodes are the output of those decisions and do not contain any further branches.<br>
#         <center>
#             <img src="https://static.javatpoint.com/tutorial/machine-learning/images/decision-tree-classification-algorithm.png" alt="DT" width="35%"><br>
#             <i>🖼 Decision Tree by Javatpoint</i>
#         </center>
#     </blockquote>
# </div>
# <!-- Hello world 👋. Thank you so much for downloading/forking my codes/works. If you like my works, please support me by giving upvotes and comments on my Kaggle profile (https://www.kaggle.com/caesarmario/). Thank you so much and have a great day 😆👍. More about me: https://linktr.ee/caesarmario_ -->

# %%
# --- DT Parameters ---
parameter_DT = {'algo__max_depth': np.arange(1, 6, 1)}

# --- DT Pipeline ---
algo_DT = Pipeline([('algo', DecisionTreeClassifier(random_state=1))])

# --- Applying DT ---
model_DT = ml_models('Decision Tree', algo_DT, parameter_DT)

# %% [markdown]
# ## <div class="header2">7.5 | Random Forest</div>
# <div class="explain-box">
#     <blockquote style="color: #000000;">
#         <mark><b>Random Forest</b></mark> is a tree-based machine learning algorithm that <b>leverages the power of multiple decision trees for making decisions</b>. Each individual tree in the random forest spits out a class prediction and the class with the most votes becomes our model’s prediction. <b>A large number of relatively uncorrelated models (trees) operating as a committee will outperform any of the individual constituent models</b>.<br>
#         <center>
#             <img src="https://cdn.analyticsvidhya.com/wp-content/uploads/2020/02/rfc_vs_dt1.png" alt="RF" width="35%"><br>
#             <i>🖼 Random Forest by Abhishek Sharma</i>
#         </center>
#     </blockquote>
# </div>
# <!-- Hello world 👋. Thank you so much for downloading/forking my codes/works. If you like my works, please support me by giving upvotes and comments on my Kaggle profile (https://www.kaggle.com/caesarmario/). Thank you so much and have a great day 😆👍. More about me: https://linktr.ee/caesarmario_ -->

# %%
# --- RF Parameters ---
parameter_RF = {'algo__n_estimators': [100, 200, 500],
                'algo__max_depth': [2, 3, 5]}

# --- RF Pipeline ---
algo_RF = Pipeline([('algo', RandomForestClassifier(random_state=81))])

# --- Applying RF ---
model_RF = ml_models('Random Forest', algo_RF, parameter_RF)

# %% [markdown]
# ## <div class="header2">7.6 | Gradient Boosting</div>
# <div class="explain-box">
#     <blockquote style="color: #000000;">
#         <mark><b>Boosting</b></mark> is a method of <b>converting weak learners into strong learners</b>. In boosting, <b>each new tree is a fit on a modified version</b> of the original data set. It strongly relies on the prediction that the next model will reduce prediction errors when blended with previous ones. The main idea is <b>to establish target outcomes for this upcoming model to minimize errors</b>.<br><br>
#         <mark><b>Gradient Boosting</b></mark> trains many models in <b>a gradual, additive and sequential manner</b>. The term gradient boosting emerged because every case’s target outcomes are based on the gradient’s error with regards to the predictions. Every model reduces prediction errors by taking a step in the correct direction.<br>
#         <center>
#             <img src="https://www.researchgate.net/publication/345327934/figure/fig3/AS:1022810793209856@1620868504478/Flow-chart-of-XGBoost.png" alt="GB" width="35%"><br>
#             <i>🖼 Boosting Algorithm by Rui Guo et al.</i>
#         </center>
#     </blockquote>
# </div>
# <!-- Hello world 👋. Thank you so much for downloading/forking my codes/works. If you like my works, please support me by giving upvotes and comments on my Kaggle profile (https://www.kaggle.com/caesarmario/). Thank you so much and have a great day 😆👍. More about me: https://linktr.ee/caesarmario_ -->

# %%
# --- Gradient Boosting Parameters ---
parameter_GB = {'algo__learning_rate': [0.02, 0.05, 0.07],
                'algo__n_estimators': [100, 500, 1000],
                'algo__max_leaf_nodes': [2, 5, 8]}

# --- Gradient Boosting Pipeline ---
algo_GB = Pipeline([('algo', GradientBoostingClassifier(random_state=1, loss='exponential'))])

# --- Applying Gradient Boosting ---
model_GB = ml_models('Gradient Boosting', algo_GB, parameter_GB)

# %% [markdown]
# ## <div class="header2">7.7 | Extra Tree Classifier</div>
# <div class="explain-box">
#     <blockquote style="color: #000000;">
#         <mark><b>Extra Trees Classifier</b></mark> is a type of ensemble learning technique which <b>aggregates the results of multiple de-correlated decision trees collected in a "forest" to output it’s classification result</b>. In concept, it is very similar to a Random Forest Classifier and only differs from it in the manner of construction of the decision trees in the forest.<br><br>
#         Each Decision Tree in the Extra Trees Forest is <b>constructed from the original training sample</b>. Then, at each test node, each tree is provided with a <b>random sample of k features</b> from the feature-set from which each decision tree must select the best feature to split the data based on some mathematical criteria (typically the Gini Index). This random sample of features leads to the creation of multiple de-correlated decision trees.
#     </blockquote>
# </div>
# <!-- Hello world 👋. Thank you so much for downloading/forking my codes/works. If you like my works, please support me by giving upvotes and comments on my Kaggle profile (https://www.kaggle.com/caesarmario/). Thank you so much and have a great day 😆👍. More about me: https://linktr.ee/caesarmario_ -->

# %%
# --- Extra Tree Classifier Parameters ---
parameter_ET = {'algo__n_estimators': [100, 200, 400],
                'algo__max_depth': [2, 5, 8]}

# --- Extra Tree Classifier Pipeline ---
algo_ET = Pipeline([('algo', ExtraTreesClassifier(random_state=17, criterion='entropy'))])

# --- Applying Extra Tree Classifier ---
model_ET = ml_models('Extra Tree Classifier', algo_ET, parameter_ET)

# %% [markdown]
# ## <div class="header2">7.8 | Multilayer Perceptron (MLP)</div>
# <div class="explain-box">
#     <blockquote style="color: #000000;">
#         A <mark><b>multilayer perceptron (MLP)</b></mark> is a <b>feedforward artificial neural network</b> that creates a collection of outputs from a set of inputs and <b>it is a deep learning technique</b>. A directed graph connecting the input and output layers of an MLP is made up of <b>numerous layers of input nodes</b>. <b>Backpropagation</b> is a technique used by MLPs to train the network.<br><br>
#         MLP is frequently used in <b>supervised learning issues, parallel distributed computing, and computational neuroscience research</b>. MLPs are not the best option, nevertheless, for analyzing patterns in <b>sequential and multidimensional data</b>.<br>
#         <center>
#             <img src="https://cdn.analyticsvidhya.com/wp-content/uploads/2020/02/ANN-Graph.gif" alt="MLP" width="35%"><br>
#             <i>🖼 Multilayer Perceptron by Francke Peixoto</i>
#         </center>
#     </blockquote>
# </div>
# <!-- Hello world 👋. Thank you so much for downloading/forking my codes/works. If you like my works, please support me by giving upvotes and comments on my Kaggle profile (https://www.kaggle.com/caesarmario/). Thank you so much and have a great day 😆👍. More about me: https://linktr.ee/caesarmario_ -->

# %%
# --- MLP Parameters ---
parameter_MLP = {'algo__hidden_layer_sizes': [(368,), (100,), (50,)],
                 'algo__alpha': [0.001, 0.05, 0.1]}

# --- MLP Pipeline ---
algo_MLP = Pipeline([('algo', MLPClassifier(random_state=42, solver='adam', activation='relu', learning_rate='constant'))])

# --- Applying Extra Tree Classifier ---
model_MLP = ml_models('MLP', algo_MLP, parameter_MLP)

# %% [markdown]
# ## <div class="header2">7.10 | Model Comparison 👀</div>
# <div class="explain-box">
#     After implementing and tuning 8 models, this section will <mark>compare all machine learning models accuracy and best score</mark>.
# </div>
# <!-- Hello world 👋. Thank you so much for downloading/forking my codes/works. If you like my works, please support me by giving upvotes and comments on my Kaggle profile (https://www.kaggle.com/caesarmario/). Thank you so much and have a great day 😆👍. More about me: https://linktr.ee/caesarmario_ -->

# %%
# --- Create Accuracy Comparison Table ---
compare = pd.DataFrame({'Model': ['Logistic Regression', 'Support Vector Machine', 'K-Nearest Neighbour', 'Decision Tree',
                                  'Random Forest', 'Gradient Boosting', 'Extra Tree Classifier', 'Multilayer Perceptron'],
                        'Accuracy Train': [model_LR[2]*100, model_SVC[2]*100, model_KNN[2]*100, model_DT[2]*100, model_RF[2]*100, 
                                     model_GB[2]*100, model_ET[2]*100, model_MLP[2]*100],
                        'Accuracy Test': [model_LR[1]*100, model_SVC[1]*100, model_KNN[1]*100, model_DT[1]*100, model_RF[1]*100, 
                                     model_GB[1]*100, model_ET[1]*100, model_MLP[1]*100],
                        'Best Score':[model_LR[3]*100, model_SVC[3]*100, model_KNN[3]*100, model_DT[3]*100, model_RF[3]*100, 
                                     model_GB[3]*100, model_ET[3]*100, model_MLP[3]*100]})
# --- Create Comparison Table ---
print(clr.start+f".:. Models Comparison .:."+clr.end)
print(clr.color+'*' * 26)
compare.sort_values(by='Best Score', ascending=False).style.apply(acc_train_vs_test, axis=1).hide_index()

# %% [markdown]
# <div class="explain-box">
#     From the train and test accuracy results above, <mark>four models tested have a good fit (highlighted using blue)</mark>. However, the other four models experienced overfitting. This is because the <b>difference between train and test accuracy or vice versa is relatively high</b>. The data frame above shows that gradient boosting, random forest, and support vector machines have the same test accuracy. On top of that, the <mark>extra tree classifier has the best test accuracy compared to the four best models tested in this notebook</mark>. From the ROC AUC curve figure for the four models, the four best models have <b>an AUC value of around 0.8 and above</b> (close to 1), which means that these models can predict well the passengers of the Titanic who survived and those who did not. The confusion matrix shows that the prediction results between the actual and the predicted targets for those four models in each class in the test data are better than those four.<br><br>
#     Looking at the F1 score of each model, it can be concluded that <mark>the models tested on this notebook can classify not survived passengers very well (F1 score above 0.8) but quite well on survived passengers (F1 score above 0.7)</mark>. However, the difference in F1 scores for each model makes sense because the actual target values in the test dataset also differ quite a lot (260 not survived passengers and 158 survived passengers). The four best models had F1 scores above the average, where the F1 score for not survived passengers was at 0.85, while the F1 score for survived passengers was at 0.74. The precision values for the four best models are also more or less the same, where 77-78% of all the passengers that the model predicted survived the Titanic disaster. In contrast, for recall value for the four best models, those models correctly predicted 70-72% of all survivors.<br><br>
#     From the behavior model of the four best models, the <mark>extra tree classifier is more ideal than the other three best models</mark>. It is because <b>the validation score constantly improves as the number of training set sizes gets larger (notice the difference in the x-axis scale from the previous two curves) in the extra tree classifier learning curve</b>. In addition, <b>the training and validation scores also converge to nearly similar values, concluding that this model can generalize very well</b>. However, according to the gradient boosting model, this model has a strong bias. This is evident from the overly strong correlation between the training and validation scores. Poor fit and inferior generalization of the data will be more frequent outcomes. For random forest, the learning curve has a low training loss at the beginning, which gradually increases upon adding training examples and suddenly falls to an arbitrary minimum point (minimum doesn't mean zero loss) at the end. This indicates that underfitting happened for this model. Lastly, for support vector machines, the cross-validation score is relatively lower and increases very slowly as the size of the training set increases. This indicates that overfitting happened since low bias and high variance occurred in the learning curve. From this exploration, <mark>the extra tree classifier is the best model for predicting Titanic survivors</mark>.<br><br>
#     In the extra tree classifier feature importance plot, <b>five features are the most important affecting the survival of passengers</b>. Those features are <mark>sex, family survival, passenger class, passenger title, and ticket fare</mark>. As with the previous EDA results, it can be seen that <mark>gender affects the survival rate of passengers, where women are more likely to survive than men</mark>. This may be because <b>women are given more priority to get into lifeboats than men</b>. The crew members and male passengers were expected to prioritize the safety of women and children over their own, which resulted in a higher mortality rate for men. <mark>Family survival in Titanic refers to passengers traveling with family members</mark>, such as spouses, siblings, parents, or children, who may have a better chance of survival than those traveling alone. This is because <mark>family members may have looked out for each other and helped each other to evacuate the ship or find a place on a lifeboat</mark>. For example, women and children were given priority to board lifeboats, and a woman with a child may have been more likely to secure a spot on a lifeboat than a single male passenger. Additionally, <b>passengers traveling with family members may have been more likely to receive help or support from other passengers or crew members</b>.<br><br>
#     The next variable is the <mark>passenger class</mark>. <mark>The higher the passenger class, the more likely someone is to survive</mark>. This is also supported by the previous EDA, where more upper-class passengers survived than the other two classes. <b>The first-class passengers were given priority access to lifeboats and, as a result, had a higher survival rate than passengers in the lower classes</b>. This was partly due to their proximity to the lifeboats and the fact that they had more accessible access to the upper decks where the lifeboats were stored.<br><br>
#     Additionally, <b>the lower-class passengers were typically located on the ship's lower decks, which were more difficult to access during the evacuation</b>. Furthermore, passengers in the lower classes were less likely to have received adequate safety instructions or assistance during the evacuation. The <mark>passenger title name</mark> in Titanic provides information about <mark>the social status and gender of the passenger, which could have influenced their chances of survival</mark>. For example, women and children were given priority to board lifeboats during the evacuation process. <b>Passengers with higher social status or military ranking, such as Mr. or Colonel, may have been given priority treatment due to their perceived importance or leadership</b>. Additionally, <b>passengers with medical or maritime expertise, such as Dr. or Captain, may have been called upon to assist with the evacuation or to provide medical care, which could have affected their survival rate</b>.
# <br><br>
#     The last variable is <mark>binned fare</mark>. Binned fares can also provide <mark>information about the location of the passenger's cabin or room on the ship</mark>, which can impact their chances of survival. For example, <b>passengers with higher fares were typically located on the ship's upper decks</b>, which were closer to the lifeboats and had more accessible access to evacuation routes. Additionally, passengers with higher fares may have been able to <b>afford better accommodations, which could have increased their chances of survival during the disaster</b>. In addition, the <b>ticket fare was directly correlated with the passenger class</b>.
# </div>
# <!-- Hello world 👋. Thank you so much for downloading/forking my codes/works. If you like my works, please support me by giving upvotes and comments on my Kaggle profile (https://www.kaggle.com/caesarmario/). Thank you so much and have a great day 😆👍. More about me: https://linktr.ee/caesarmario_ -->

# %% [markdown]
# # <div class="header1">8. | Submission📤</div>
# <div class="explain-box">
#     This section will <b>create predictions using the tuned extra tree classifier</b>.
# </div>

# %%
# --- Prediction using Tuned Extra Tree Classifier ---
y_pred_ET = model_ET[0].predict(X_test_scaled)

# --- Creating Submission File ---
submission = pd.DataFrame({'PassengerId': df_test['PassengerId'] , 'Survived': y_pred_ET})
submission.to_csv("gender_submission.csv", index = False)

# --- Display Submission ---
print(clr.start+f".:. Submission .:."+clr.end)
print(clr.color+'*' * 19)
submission.head(5).style.background_gradient(cmap='Blues').hide_index()

# %% [markdown]
# <div class="explain-box">
#     <img src="https://i.imgur.com/cxHTOjg.png"><br>
#     With <b>81.34% accuracy</b> using <b>extra tree classifier</b> model, managed to reach the <mark>top 2% of the leaderboard</mark> 🎉🎊.
# </div>
# <!-- Hello world 👋. Thank you so much for downloading/forking my codes/works. If you like my works, please support me by giving upvotes and comments on my Kaggle profile (https://www.kaggle.com/caesarmario/). Thank you so much and have a great day 😆👍. More about me: https://linktr.ee/caesarmario_ -->

# %% [markdown]
# # <div class="header1">9. | Conclusions and Future Improvements 👀</div>
# <div class="explain-box">
#     From the results of dataset analysis and implementation of machine learning models in the previous section, <mark>it can be concluded as follows</mark>:
#     <blockquote style="color: #000000;">
#         <ul>
#             <li>The Titanic survivor prediction project is a classic machine-learning problem that requires careful preprocessing, analysis, and modeling of complex and noisy data. <b>This notebook has successfully covered preprocessing, research, modeling, and generating prediction results on the test data</b>. In addition, <mark>this notebook also managed to reach the top 2% of the leaderboard</mark>.</li>
#             <li>For further research, the following are <mark>future recommendations</mark> for future researchers:</li>
#             <ul>
#                 <li><mark><u>Feature engineering</u></mark>: further exploration and transformation of existing features and/or creation of new features to improve model performance.</li>
#                 <li><mark><u>Algorithm selection</u></mark>: testing different algorithms and ensemble methods to find the most suitable one for this problem.</li>
#                 <li><mark><u>Hyperparameter tuning</u></mark>: optimizing the hyperparameters of the selected algorithms to achieve better performance.</li>
#                 <li><mark><u>Incorporating additional data</u></mark>: including other relevant data such as crew member information or passenger biographies to improve model accuracy and provide a more complete picture of the disaster.</li>
#                 <li><mark><u>Exploring other predictive models</u></mark>: experimenting with more sophisticated predictive models such as deep learning models or reinforcement learning.</li>
#             </ul>
#         </ul>
#     </blockquote>
# </div>
# <!-- Hello world 👋. Thank you so much for downloading/forking my codes/works. If you like my works, please support me by giving upvotes and comments on my Kaggle profile (https://www.kaggle.com/caesarmario/). Thank you so much and have a great day 😆👍. More about me: https://linktr.ee/caesarmario_ -->

# %% [markdown]
# # <div class="header1">10. | References 🔗</div>
# <div class="references">
#     <ul><u>Kaggle Notebook 📚</u>
#         <li><a style="color: #3D5A80" href="https://www.kaggle.com/code/korfanakis/titanic-a-beginner-friendly-approach-to-top-3">Titanic: A beginner-friendly approach to Top 3% by Orfanakis Konstantinos</a></li>
#         <li><a style="color: #3D5A80" href="https://www.kaggle.com/code/konstantinmasich/titanic-0-82-0-83">Titanic [0.82] - [0.83] by Konstantin</a></li>
#         <li><a style="color: #3D5A80" href="https://www.kaggle.com/code/dwin183287/titanic-machine-learning-from-disaster-eda">Titanic: Machine Learning from Disaster - EDA by Sharlto Cope</a></li>
#         <li><a style="color: #3D5A80" href="https://www.kaggle.com/code/dwin183287/kagglers-seen-by-continents">Kagglers seen by continents by Sharlto Cope</a></li>
#         <li><a style="color: #3D5A80" href="https://www.kaggle.com/code/dimitriirfan/tps-apr-2021-exploratory-data-analysis-baseline">TPS Apr 2021 | Exploratory Data Analysis+Baseline by Dimitri Irfan</a></li>
#     </ul>
#     <ul><b><u>Online Articles 🌏</u></b>
#         <li><a style="color: #3D5A80" href="https://www.analyticsvidhya.com/blog/2020/12/mlp-multilayer-perceptron-simple-overview/">A Simple overview of Multilayer Perceptron(MLP) by Francke Peixoto</a></li>
#         <li><a style="color: #3D5A80" href="https://www.techopedia.com/definition/20879/multilayer-perceptron-mlp">Multilayer Perceptron (MLP) by Techopedia</a></li>
#         <li><a style="color: #3D5A80" href="https://analyticsindiamag.com/a-beginners-guide-to-scikit-learns-mlpclassifier/">A Beginner's Guide To Scikit-Learn's MLPClassifier by Amal Nair</a></li>
#         <li><a style="color: #3D5A80" href="https://panjeh.medium.com/scikit-learn-hyperparameter-optimization-for-mlpclassifier-4d670413042b">Scikit Learn Hyperparameter Optimization for MLPClassifier by Panjeh</a></li>
#     </ul>
#     <ul><b><u>Other Sources 🔗</u></b>
#         <li><a style="color: #3D5A80" href="https://www.sciencedirect.com/topics/computer-science/multilayer-perceptron">The Digital Twin Paradigm for Smarter Systems and Environments: The Industry Use Cases by S. Abirami, P. Chitra</a></li>
#         <li><a style="color: #3D5A80" href="https://www.youtube.com/playlist?list=PLGn1wRmlR3MvipYvFEnnmaTwd59XjSyrG">Supervised Learning by JCOp Untuk Indonesia</a></li>
#         <li><a style="color: #3D5A80" href="https://github.com/gyli/PyWafflehttps://github.com/gyli/PyWafflehttps://github.com/gyli/PyWafflehttps://github.com/gyli/PyWaffle">PyWaffle by Guangyang Li</a></li>
#     </ul>
# </div>

# %% [markdown]
# <hr>
# <center>
#     <span class="thanks">.: Thanks for Viewing :.</span><br><br>
#     <span class="thanks-explain">📌 Like this notebook? You can support me by giving <mark><b>upvote</b></mark> 😆👍🔼</span><br>
#     <span class="three-dots2">...</span><br><br>
#     <span class="thanks-watermark"><u>Support me!</u></span><br>
#     <span class="ko-fi">
#         <a href='https://ko-fi.com/D1D3JU963' target='_blank'><img src='https://ko-fi.com/img/githubbutton_sm.svg' alt='Support me on Ko-fi Button'/></a>
#     </span><br>
#     <span class="thanks-watermark"><u>Follow me in other platform</u></span><br>
#     <div align="center" class="social-media">
#         <ul>
#             <li><a href="https://www.kaggle.com/caesarmario"><img src="https://i.imgur.com/K6QyzaJ.png"></a></li>
#             <li><a href="https://public.tableau.com/app/profile/caesarmario"><img src="https://i.imgur.com/JVxVkeQ.png"></a></li>
#             <li><a href="https://github.com/caesarmario"><img src="https://i.imgur.com/Orp40Ys.png"></a></li>
#             <li><a href="https://caesarmario.medium.com/"><img src="https://i.imgur.com/6TrHyu0.png"></a></li>
#             <li><a href="https://www.linkedin.com/in/caesarmario"><img src="https://i.imgur.com/vVYd0aI.png"></a></li>
#         </ul>
#     </div>
#     <img src="https://i.imgur.com/Xy0J9G0.png" width=65% alt="WM">
# </center>
