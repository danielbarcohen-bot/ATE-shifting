# %% [markdown]
# ## Fala Senhoras e Senhores!
#
#
#  ### Esse notebook é exclusivamente para scraping da cotação diária do dolar na API do Bacen.
#
# ### Qualquer dúvida é só me chamar!
# ### Email: marcus.rodrigues4003@gmail.com
# ### Whatsapp: (11) 94937-0306
#
# ### Atenciosamente Marcus Vinicius!
#
# <img src="https://media.giphy.com/media/mCdhhsCLGluNi/giphy.gif">
#
# Link para montar uma request na API do Bacen: https://olinda.bcb.gov.br/olinda/servico/PTAX/versao/v1/aplicacao#!/recursos/CotacaoDolarPeriodo#...
#
# Link dos dados abertos do Bacen: https://dadosabertos.bcb.gov.br

# %%
import pandas
import requests
from datetime import date
import io

# %% [markdown]
# ### Request na API do Bacen:
#
# A documentação de acesso a API está disponível nos dados abertos do bacen!

# %%
today=date.today()
today=today.strftime("%m-%d-%Y")
req=requests.get(f"https://olinda.bcb.gov.br/olinda/servico/PTAX/versao/v1/odata/CotacaoDolarPeriodo(dataInicial=@dataInicial,dataFinalCotacao=@dataFinalCotacao)?@dataInicial='01-01-1980'&@dataFinalCotacao='{today}'&$format=text/csv&$select=cotacaoCompra,cotacaoVenda,dataHoraCotacao")

# %% [markdown]
# ### Tratamento das informações obtidas. Observe que eu utilizo o seguinte código para converter as informações da requisição:
# > df=pandas.read_csv(io.StringIO(req.content.decode('utf-8')))
# ### Visto que a request nos retorna um texto!

# %%
print("O request tem o retorno: ",req.status_code)
if req.status_code==200:
   df=pandas.read_csv(io.StringIO(req.content.decode('utf-8')))
   print("Salvando informação!")
   df.rename(columns = {'cotacaoCompra' : 'Cotacao Compra', 'cotacaoVenda' : 'Cotacao Venda','dataHoraCotacao' : 'Data e hora da Cotacao'}, inplace = True)
   df.to_csv("Cotação Atualizada Dolar_Real.csv", sep=";",index=False, encoding='utf-8', mode="w", decimal=',')

else:
  print("Não é possível atualizar dolar Diário")

# %%
import pandas as pd
from datetime import date
from urllib.request import urlretrieve
url="http://api.bcb.gov.br/dados/serie/bcdata.sgs.11/dados?formato=csv"
urlretrieve(url, "TAXA SELIC.csv")
