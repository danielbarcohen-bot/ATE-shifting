# %% [markdown]
# <!-- # <span style="color:#FFFFFF; font-size: 0%;">1 | Introduction</span>
# <div style="border-radius: 0px; background-color: #112241; text-align:center;">
#     <h4 style="color: white; padding: 1.5rem; font-size: 19px"><b>1 | INTRODUCTION</b></h4>
# </div>
# <!-- <br> -->
#
# <div style="display: flex; flex-direction: row; align-items: center;">
#     <div style="flex : 0; margin-top: 10px;">
#         <img src="https://wallpaperaccess.com/full/2355536.jpg" alt="Image" style="max-width: 400px; max-height540px;" />
#     </div>
#     <div style="flex: 1; margin-left: 26px; margin-top: 7px">
#         <h1><b>Data Alchemy: Decoding Iris Insights 🔍✨</b></h1>
#
# Hi, I am <h3><b>Saman Fatima</b></h3> Welcome! This concise notebook navigates through the Iris dataset, offering insightful exploratory data analysis, handling null values and outliers, and implementing effective machine learning techniques. Designed with beginners in mind.
# <br>
# <blockquote> your upvote serves as motivation! 👍🚀
#     </div>
# </div>

# %% [markdown]
# ## **Table of Contents**
#
# 1. [About The Author](#1-about-the-author)
# 2. [About The Data](#2-about-the-data)
#    - [About the Columns](#about-the-columns)
#    - [Empowering Solutions](#empowering-solutions)
#    - [Let's Begin !!!](#lets-begin-)
# 3. [Overview of Data](#overview-of-data)
# 4. [Dealing With Outliers](#dealing-with-outliers)
# 5. [Getting Data without Outliers and Merging with Actual Data](#getting-data-without-outliers-and-merging-with-actual-data)
# 6. [Checking Unique and Inconsistencies in the Data](#checking-unique-and-inconsistencies-in-the-data)
# 7. [Changing Data Type](#changing-data-type)
# 8. [Choosing the Right Model](#choosing-the-right-model)
# 9. [Saving and Predicting The Model](#saving-and-predicting-the-model)
# 10. [Conclusion](#Conclusion)

# %% [markdown]
# ## **Stay Connected for More Insights 🌐🔗**
#
# [Facebook](https://www.facebook.com/saman.fatima.50364592/)
#
# [Email](samanfatimgmail.cm)
#
# [Github](https://github.com/SamanFatima7)
#
# [kaggle](https://www.kaggle.com/samanfatima7)
#
# [Linkedin](https://www.linkedin.com/in/saman-fatima-datascience/)
#
# [Twitter](https://twitter.com/SamanFatima9106)

# %% [markdown]
# # **2. About The Data**
#
# - To get the Iris dataset in Python, you can use the Seaborn library's load_dataset function.
#
# - > pip install seaborn
# - > import seaborn as sns
# - > iris_data = sns.load_dataset('iris')

# %% [markdown]
# #### ***About the Columns***

# %% [markdown]
# 1. **Sepal Length (cm):**
#    - *Description:* Length of the iris flower's sepal (the outermost whorl of a flower).
#
# 2. **Sepal Width (cm):**
#    - *Description:* Width of the iris flower's sepal.
#
# 3. **Petal Length (cm):**
#    - *Description:* Length of the iris flower's petal (the innermost whorl of a flower).
#
# 4. **Petal Width (cm):**
#    - *Description:* Width of the iris flower's petal.
#
# 5. **Species:**
#    - *Description:* The class of the iris flower, indicating its species.
#    - *Values:* Setosa, Versicolor, Virginica.

# %% [markdown]
# `Empowering Solutions` : ***Simplifying Iris Categorization through Innovative ML Models***
#
# We will built a machine learning model that classifies Iris flowers by analyzing their sepal length, sepal width, petal length, and petal width. This model accurately predicts the Iris flower type, simplifying the categorization process in various applications.

# %% [markdown]
# > #### **Let's Begin !!!**

# %%
# Loading Important Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split, GridSearchCV, cross_val_score
from sklearn.preprocessing import LabelEncoder, StandardScaler, MinMaxScaler
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier, AdaBoostClassifier
from xgboost import XGBClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from sklearn.neighbors import KNeighborsClassifier
from sklearn.pipeline import Pipeline

# %%
data = pd.read_csv("../input/iris-flower-dataset/IRIS.csv")

# %%
# data = pd.read_csv('/Kaggle/input/iris-flower-dataset/IRIS.csv')

# %%
# Loading the dataset
# data = sns.load_dataset('Iris')

# %% [markdown]
# ---
# # ***Overview of Data***
# ---

# %%
# Checking the rows and columns
data.shape
# Out:
# (150, 5)

# %%
# Checking Null/Non Null and Data types of Columns
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
# Taking a quick look on the data 
data.head(5)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
# Checking the null values with their sum 
data.isnull().sum()
# Out:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# species         0
# dtype: int64

# %%
# Checking columns names
data.columns
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')

# %% [markdown]
# ---
# # ***Dealing With Outliers***
# ---

# %%
# We are using Z score method for checking and removing outliers
# We are just checking one column for better understanding of z-score method
mean = np.mean(data['sepal_width'])
std = np.std(data['sepal_width'])

# Step 1: Calculate the Z-Score
data['width-Z-Score'] = (data['sepal_width'] - mean) / std
data.head(5)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species  \
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa
#
#    width-Z-Score
# 0       1.032057
# 1      -0.124958
# 2       0.337848
# 3       0.106445
# 4       1.263460

# %%
print(f"Here are the outliers based on the z-score threshold, 3:\n {data[data['width-Z-Score'] > 3]}")
# Out:
# Here are the outliers based on the z-score threshold, 3:
#      sepal_length  sepal_width  petal_length  petal_width      species  \
# 15           5.7          4.4           1.5          0.4  Iris-setosa
#
#     width-Z-Score
# 15       3.114684

# %%
# Now we will check all the outliers in these 4 columns
data_1 = data[['sepal_length','sepal_width','petal_length','petal_width']]

# Creating a new dataframe 
data_1 = pd.DataFrame(data_1)

# Calculate mean and standard deviation for all columns
means = data_1.mean()
stds = data_1.std()

# Calculate Z-scores for all columns
z_scores = (data - means) / stds

# Set a threshold for Z-score to identify outliers
threshold = 3  # You can adjust this threshold based on your preference

# Identify rows where any column has an outlier
outliers = (z_scores.abs() > threshold).any(axis=1)

# Display rows with outliers
print("Rows with outliers:")
print(data_1[outliers])
# Out:
# Rows with outliers:
#     sepal_length  sepal_width  petal_length  petal_width
# 15           5.7          4.4           1.5          0.4

# %%
df_no_outliers = data_1[~outliers]

# Display the DataFrame without outliers
print("DataFrame without outliers:")
print(df_no_outliers.head(5))
# Out:
# DataFrame without outliers:
#    sepal_length  sepal_width  petal_length  petal_width
# 0           5.1          3.5           1.4          0.2
# 1           4.9          3.0           1.4          0.2
# 2           4.7          3.2           1.3          0.2
# 3           4.6          3.1           1.5          0.2
# 4           5.0          3.6           1.4          0.2

# %% [markdown]
# ---
# ## ***Getting Data without outliers and merging with actual data***
# ---

# %%
# Merging the data without outliers on the index basis
merged_df = pd.merge(df_no_outliers, data, left_index=True, right_index=True)
merged_df.head(5)
# Out:
#    sepal_length_x  sepal_width_x  petal_length_x  petal_width_x  \
# 0             5.1            3.5             1.4            0.2
# 1             4.9            3.0             1.4            0.2
# 2             4.7            3.2             1.3            0.2
# 3             4.6            3.1             1.5            0.2
# 4             5.0            3.6             1.4            0.2
#
#    sepal_length_y  sepal_width_y  petal_length_y  petal_width_y      species  \
# 0             5.1            3.5             1.4            0.2  Iris-setosa
# 1             4.9            3.0             1.4            0.2  Iris-setosa
# 2             4.7            3.2             1.3            0.2  Iris-setosa
# 3             4.6            3.1             1.5            0.2  Iris-setosa
# 4             5.0            3.6             1.4            0.2  Iris-setosa
#
#    width-Z-Score
# 0       1.032057
# 1      -0.124958
# 2       0.337848
# 3       0.106445
# 4       1.263460

# %%
# Now we will remove Duplicate Columns 
merged_df = merged_df[['sepal_length_x','sepal_width_x','petal_length_x','petal_width_x','species']]

# %%
# Removing _x and replacing it in first 4 columns to make column easy to read
merged_df.columns = merged_df.columns.str.replace('_x', '')

# %%
# Creating a dataframe without any outliers 
df = merged_df.copy()

# %%
# Finnaly we have the data without Outliers 
df.head(5)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %% [markdown]
# ---
# # ***Checking Unique and Inconsistencies in the Data***
# ---

# %%
# Checking Nan and All unique values so that if there is inconsistency in the data we will figure it out 
unique_summary = df.apply(lambda col: col.unique())
print(unique_summary)
# Out:
# sepal_length    [5.1, 4.9, 4.7, 4.6, 5.0, 5.4, 4.4, 4.8, 4.3, ...
# sepal_width     [3.5, 3.0, 3.2, 3.1, 3.6, 3.9, 3.4, 2.9, 3.7, ...
# petal_length    [1.4, 1.3, 1.5, 1.7, 1.6, 1.1, 1.2, 1.0, 1.9, ...
# petal_width     [0.2, 0.4, 0.3, 0.1, 0.5, 0.6, 1.4, 1.5, 1.3, ...
# species            [Iris-setosa, Iris-versicolor, Iris-virginica]
# dtype: object

# %% [markdown]
# ---
# ### ***Changing Data Type***
# ---

# %%
df['species'].dtype
# Out:
# dtype('O')

# %%
# Changing the Data type of species from Object to Category
df['species'] = df['species'].astype('category')
df['species'].dtype
# Out:
# CategoricalDtype(categories=['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], ordered=False)

# %% [markdown]
# ---
# # ***Choosing the right model***
# ---

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split, KFold, RepeatedKFold, GridSearchCV, RandomizedSearchCV
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler, MinMaxScaler, RobustScaler, OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from sklearn.svm import SVR

def evaluate_regression_model(y_true, y_pred):
    return {
        'MAE': mean_absolute_error(y_true, y_pred),
        'MSE': mean_squared_error(y_true, y_pred),
        'RMSE': np.sqrt(mean_squared_error(y_true, y_pred)),
        'R-squared': r2_score(y_true, y_pred)
    }

def automated_regression_task(X, y, split_method='train_test_split', search_method='grid', scaling_method='standard', test_size=0.2, random_state=42, n_splits=5, n_repeats=3):
    models = {
        'Linear Regression': LinearRegression(),
        'Decision Tree': DecisionTreeRegressor(),
        'Random Forest': RandomForestRegressor(),
        'Gradient Boosting': GradientBoostingRegressor(),
        'SVR': SVR()
    }

    param_grids = {
        'Random Forest': {
            'model__n_estimators': [50, 100, 200],
            'model__max_depth': [None, 10, 20, 30]
        },
        'Gradient Boosting': {
            'model__n_estimators': [50, 100, 200],
            'model__max_depth': [None, 10, 20, 30],
            'model__learning_rate': [0.01, 0.1, 0.2]
        },
        'SVR': {
            'model__C': [0.1, 1, 10],
            'model__epsilon': [0.1, 0.2, 0.3],
            'model__kernel': ['linear', 'rbf']
        },
        'Linear Regression': {},
        'Decision Tree': {
            'model__max_depth': [None, 10, 20, 30]
        }
    }

    def split_data(X, y, split_method, test_size, random_state, n_splits, n_repeats):
        if split_method == 'train_test_split':
            return train_test_split(X, y, test_size=test_size, random_state=random_state)
        elif split_method == 'k_fold':
            kf = KFold(n_splits=n_splits, shuffle=True, random_state=random_state)
            return [(X.iloc[train_index], X.iloc[test_index], y.iloc[train_index], y.iloc[test_index]) for train_index, test_index in kf.split(X)]
        elif split_method == 'repeated_k_fold':
            rkf = RepeatedKFold(n_splits=n_splits, n_repeats=n_repeats, random_state=random_state)
            return [(X.iloc[train_index], X.iloc[test_index], y.iloc[train_index], y.iloc[test_index]) for train_index, test_index in rkf.split(X)]

    def perform_search(pipeline, param_grid, search_method, X_train, y_train):
        if search_method == 'grid':
            search = GridSearchCV(pipeline, param_grid, cv=5, scoring='neg_mean_squared_error', n_jobs=-1)
        elif search_method == 'random':
            search = RandomizedSearchCV(pipeline, param_grid, cv=5, scoring='neg_mean_squared_error', n_jobs=-1, n_iter=50)
        search.fit(X_train, y_train)
        return search.best_estimator_, search.best_params_

    if scaling_method == 'standard':
        scaler = StandardScaler()
    elif scaling_method == 'minmax':
        scaler = MinMaxScaler()
    elif scaling_method == 'robust':
        scaler = RobustScaler()
    else:
        scaler = StandardScaler()  # Default scaler

    # Ensure the target variable is numeric
    y = pd.to_numeric(y, errors='coerce')
    if y.isnull().any():
        raise ValueError("The target variable contains non-numeric values that could not be converted.")

    # Encode categorical features in X
    categorical_features = X.select_dtypes(include=['object']).columns
    numeric_features = X.select_dtypes(exclude=['object']).columns

    preprocessor = ColumnTransformer(
        transformers=[
            ('num', scaler, numeric_features),
            ('cat', OneHotEncoder(), categorical_features)
        ]
    )

    results = []

    for model_name, model in models.items():
        pipeline = Pipeline([
            ('preprocessor', preprocessor),
            ('model', model)
        ])
        param_grid = param_grids[model_name]

        if split_method == 'train_test_split':
            X_train, X_test, y_train, y_test = split_data(X, y, split_method, test_size, random_state, n_splits, n_repeats)
            best_model, best_params = perform_search(pipeline, param_grid, search_method, X_train, y_train)
            y_pred = best_model.predict(X_test)
            evaluation_results = evaluate_regression_model(y_test, y_pred)
            results.append({'Model': model_name, 'Best Parameters': best_params, 'Evaluation Results': evaluation_results})
            print(f"Model: {model_name}")
            print(f"Best Parameters: {best_params}")
            print("Evaluation Results:", evaluation_results)

        else:
            for X_train, X_test, y_train, y_test in split_data(X, y, split_method, test_size, random_state, n_splits, n_repeats):
                best_model, best_params = perform_search(pipeline, param_grid, search_method, X_train, y_train)
                y_pred = best_model.predict(X_test)
                evaluation_results = evaluate_regression_model(y_test, y_pred)
                results.append({'Model': model_name, 'Best Parameters': best_params, 'Evaluation Results': evaluation_results})
                print(f"Model: {model_name}")
                print(f"Best Parameters: {best_params}")
                print("Evaluation Results:", evaluation_results)

    return results

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split, KFold, RepeatedKFold, GridSearchCV, RandomizedSearchCV
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler, MinMaxScaler, RobustScaler
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from sklearn.svm import SVR

def evaluate_regression_model(y_true, y_pred):
    return {
        'MAE': mean_absolute_error(y_true, y_pred),
        'MSE': mean_squared_error(y_true, y_pred),
        'RMSE': np.sqrt(mean_squared_error(y_true, y_pred)),
        'R-squared': r2_score(y_true, y_pred)
    }

def automated_regression_task(X, y, split_method='train_test_split', search_method='grid', scaling_method='standard', test_size=0.2, random_state=42, n_splits=5, n_repeats=3):
    models = {
        'Linear Regression': LinearRegression(),
        'Decision Tree': DecisionTreeRegressor(),
        'Random Forest': RandomForestRegressor(),
        'Gradient Boosting': GradientBoostingRegressor(),
        'SVR': SVR()
    }

    param_grids = {
        'Random Forest': {
            'model__n_estimators': [50, 100, 200],
            'model__max_depth': [None, 10, 20, 30]
        },
        'Gradient Boosting': {
            'model__n_estimators': [50, 100, 200],
            'model__max_depth': [None, 10, 20, 30],
            'model__learning_rate': [0.01, 0.1, 0.2]
        },
        'SVR': {
            'model__C': [0.1, 1, 10],
            'model__epsilon': [0.1, 0.2, 0.3],
            'model__kernel': ['linear', 'rbf']
        },
        'Linear Regression': {},
        'Decision Tree': {
            'model__max_depth': [None, 10, 20, 30]
        }
    }

    def split_data(X, y, split_method, test_size, random_state, n_splits, n_repeats):
        if split_method == 'train_test_split':
            return train_test_split(X, y, test_size=test_size, random_state=random_state)
        elif split_method == 'k_fold':
            kf = KFold(n_splits=n_splits, shuffle=True, random_state=random_state)
            return [(X.iloc[train_index], X.iloc[test_index], y.iloc[train_index], y.iloc[test_index]) for train_index, test_index in kf.split(X)]
        elif split_method == 'repeated_k_fold':
            rkf = RepeatedKFold(n_splits=n_splits, n_repeats=n_repeats, random_state=random_state)
            return [(X.iloc[train_index], X.iloc[test_index], y.iloc[train_index], y.iloc[test_index]) for train_index, test_index in rkf.split(X)]

    def perform_search(pipeline, param_grid, search_method, X_train, y_train):
        if search_method == 'grid':
            search = GridSearchCV(pipeline, param_grid, cv=5, scoring='neg_mean_squared_error', n_jobs=-1)
        elif search_method == 'random':
            search = RandomizedSearchCV(pipeline, param_grid, cv=5, scoring='neg_mean_squared_error', n_jobs=-1, n_iter=50)
        search.fit(X_train, y_train)
        return search.best_estimator_, search.best_params_

    if scaling_method == 'standard':
        scaler = StandardScaler()
    elif scaling_method == 'minmax':
        scaler = MinMaxScaler()
    elif scaling_method == 'robust':
        scaler = RobustScaler()
    else:
        scaler = StandardScaler()  # Default scaler

    results = []

    for model_name, model in models.items():
        pipeline = Pipeline([
            ('scaler', scaler),
            ('model', model)
        ])
        param_grid = param_grids[model_name]

        if split_method == 'train_test_split':
            X_train, X_test, y_train, y_test = split_data(X, y, split_method, test_size, random_state, n_splits, n_repeats)
            best_model, best_params = perform_search(pipeline, param_grid, search_method, X_train, y_train)
            y_pred = best_model.predict(X_test)
            evaluation_results = evaluate_regression_model(y_test, y_pred)
            results.append({'Model': model_name, 'Best Parameters': best_params, 'Evaluation Results': evaluation_results})
            print(f"Model: {model_name}")
            print(f"Best Parameters: {best_params}")
            print("Evaluation Results:", evaluation_results)

        else:
            for X_train, X_test, y_train, y_test in split_data(X, y, split_method, test_size, random_state, n_splits, n_repeats):
                best_model, best_params = perform_search(pipeline, param_grid, search_method, X_train, y_train)
                y_pred = best_model.predict(X_test)
                evaluation_results = evaluate_regression_model(y_test, y_pred)
                results.append({'Model': model_name, 'Best Parameters': best_params, 'Evaluation Results': evaluation_results})
                print(f"Model: {model_name}")
                print(f"Best Parameters: {best_params}")
                print("Evaluation Results:", evaluation_results)

    return results

# Example usage
# Assuming df_tr is your DataFrame
X = data[['sepal_length', 'sepal_width', 'petal_length', 'petal_width']]
y = data['species']
results = automated_regression_task(X, y, split_method='k_fold', search_method='grid', scaling_method='minmax', n_splits=5)
print(results)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[23], line 112
#     110 X = data[['sepal_length', 'sepal_width', 'petal_length', 'petal_width']]
#     111 y = data['species']
# --> 112 results = automated_regression_task(X, y, split_method='k_fold', search_method='grid', scaling_method='minmax', n_splits=5)
#     113 print(results)
#
# Cell In[23], line 98, in automated_regression_task(X, y, split_method, search_method, scaling_method, test_size, random_state, n_splits, n_repeats)
#      96 else:
#      97     for X_train, X_test, y_train, y_test in split_data(X, y, split_method, test_size, random_state, n_splits, n_repeats):
# ---> 98         best_model, best_params = perform_search(pipeline, param_grid, search_method, X_train, y_train)
#      99         y_pred = best_model.predict(X_test)
# ...

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split, KFold, RepeatedKFold, GridSearchCV, RandomizedSearchCV
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler, MinMaxScaler, RobustScaler
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from sklearn.svm import SVR

def evaluate_regression_model(y_true, y_pred):
    return {
        'MAE': mean_absolute_error(y_true, y_pred),
        'MSE': mean_squared_error(y_true, y_pred),
        'RMSE': np.sqrt(mean_squared_error(y_true, y_pred)),
        'R-squared': r2_score(y_true, y_pred)
    }

def automated_regression_task(X, y, split_method='train_test_split', search_method='grid', scaling_method='standard', test_size=0.2, random_state=42, n_splits=5, n_repeats=3):
    models = {
        'Linear Regression': LinearRegression(),
        'Decision Tree': DecisionTreeRegressor(),
        'Random Forest': RandomForestRegressor(),
        'Gradient Boosting': GradientBoostingRegressor(),
        'SVR': SVR()
    }

    param_grid = {
        'model': [RandomForestRegressor(), GradientBoostingRegressor(), SVR(), LinearRegression(), DecisionTreeRegressor()],
        'model__n_estimators': [50, 100, 200],
        'model__max_depth': [None, 10, 20, 30]
    }

    def split_data(X, y, split_method, test_size, random_state, n_splits, n_repeats):
        if split_method == 'train_test_split':
            return train_test_split(X, y, test_size=test_size, random_state=random_state)
        elif split_method == 'k_fold':
            kf = KFold(n_splits=n_splits, shuffle=True, random_state=random_state)
            return [(X.iloc[train_index], X.iloc[test_index], y.iloc[train_index], y.iloc[test_index]) for train_index, test_index in kf.split(X)]
        elif split_method == 'repeated_k_fold':
            rkf = RepeatedKFold(n_splits=n_splits, n_repeats=n_repeats, random_state=random_state)
            return [(X.iloc[train_index], X.iloc[test_index], y.iloc[train_index], y.iloc[test_index]) for train_index, test_index in rkf.split(X)]

    def perform_search(pipeline, param_grid, search_method, X_train, y_train):
        if search_method == 'grid':
            search = GridSearchCV(pipeline, param_grid, cv=5, scoring='neg_mean_squared_error', n_jobs=-1)
        elif search_method == 'random':
            search = RandomizedSearchCV(pipeline, param_grid, cv=5, scoring='neg_mean_squared_error', n_jobs=-1, n_iter=50)
        search.fit(X_train, y_train)
        return search.best_estimator_, search.best_params_

    if scaling_method == 'standard':
        scaler = StandardScaler()
    elif scaling_method == 'minmax':
        scaler = MinMaxScaler()
    elif scaling_method == 'robust':
        scaler = RobustScaler()
    else:
        scaler = StandardScaler()  # Default scaler

    pipeline = Pipeline([
        ('scaler', scaler),
        ('model', RandomForestRegressor())
    ])

    results = []

    if split_method == 'train_test_split':
        X_train, X_test, y_train, y_test = split_data(X, y, split_method, test_size, random_state, n_splits, n_repeats)
        best_model, best_params = perform_search(pipeline, param_grid, search_method, X_train, y_train)
        y_pred = best_model.predict(X_test)
        evaluation_results = evaluate_regression_model(y_test, y_pred)
        results.append({'Best Parameters': best_params, 'Evaluation Results': evaluation_results})
        print(f"Best Parameters: {best_params}")
        print("Evaluation Results:", evaluation_results)

    else:
        for X_train, X_test, y_train, y_test in split_data(X, y, split_method, test_size, random_state, n_splits, n_repeats):
            best_model, best_prams = perform_search(pipeline, param_grid, search_method, X_train, y_train)
            y_pred = best_model.predict(X_test)
            evaluation_results = evaluate_regression_model(y_test, y_pred)
            results.append({'Best Parameters': best_params, 'Evaluation Results': evaluation_results})
            print(f"Best Parameters: {best_params}")
            print("Evaluation Results:", evaluation_results)

    return results

# Example usage
# Assuming df_tr is your DataFrame
X = data[['sepal_length', 'sepal_width', 'petal_length', 'petal_width']]
y = data['species']
results = automated_regression_task(X, y, split_method='k_fold', search_method='random', scaling_method='minmax', n_splits=5)
print(results)

# %%
# Load a data and defining X  Features and y Labels)
X = data[['sepal_length', 'sepal_width', 'petal_length', 'petal_width']]
y = data['species']

# Testing Different Models and selecting one on the basis of Accuracy Score 
models = {
    'LogisticRegression': (LogisticRegression(), {'C': [0.1, 1, 10]}),
    'KNeighborsClassifier': (KNeighborsClassifier(), {'n_neighbors': range(1, 21)}),
    'DecisionTreeClassifier': (DecisionTreeClassifier(random_state=42), {'max_depth': [None, 5, 10]}),
    'RandomForestClassifier': (RandomForestClassifier(random_state=42), {'n_estimators': [10, 50, 100], 'max_depth': [None, 5, 10, 15]}),
}

model_results = {}

# Apply feature scaling within the cross-validation loop
for name, (model, params) in models.items():
    # Create a pipeline with a StandardScaler and the model
    pipeline = Pipeline([
        ('scaler', StandardScaler()),
        ('model', GridSearchCV(model, params, cv=5, scoring='accuracy', n_jobs=-1))
    ])
    
    # Use cross_val_score for cross-validation 
    cv_scores = cross_val_score(pipeline, X, y, cv=5, scoring='accuracy')
    mean_cv_accuracy = cv_scores.mean()
    
    pipeline.fit(X, y)
    best_model = pipeline.named_steps['model'].best_estimator_
    
    model_results[name] = {'Cross-Validation Accuracy': mean_cv_accuracy}
    
    print(f"\nModel: {name}")
    print(f"Cross-Validation Mean Accuracy: {mean_cv_accuracy:.2f}")
    print(f"Best Parameters: {best_model.get_params()}")

best_model_name = max(model_results, key=lambda model: model_results[model]['Cross-Validation Accuracy'])

print(f"\nBest Model: {best_model_name} with Metrics: {model_results[best_model_name]}")

# %% [markdown]
# > ### ***According to the results `Best Model` is `LogisticRegression` with  `Accuracy: 0.9733333333333334`***

# %% [markdown]
# ---
# # ***Saving and Predicting The Model***
# ---

# %%
# Saving the model
import pickle
save_path = r'C:\Users\Mr.J10\Desktop\Full_Model\Iris_model_02.pkl'
with open(save_path, 'wb') as file:
    pickle.dump(best_model, file)

# %%
# Loading the model
import pickle
save_path = r'C:\Users\Mr.J10\Desktop\Full_Model\Iris_model_02.pkl'
model_load = pickle.load(open(save_path, 'rb'))

# %%
# Predicting the model
model_load.predict([[4.6,3.1,1.5,0.2]])

# %% [markdown]
# ---
# # ***Conclusion***
# ---

# %% [markdown]
# > In a nutshell, our smart computer program is really good at figuring out what kind of Iris flower it is. It looks at things like how long and wide the petals and sepals are. This helps a lot in sorting out the flowers quickly and correctly. It's like a helpful tool that makes it easier to know which Iris flower is which, and it can be used in different situations where we need to tell them apart.
