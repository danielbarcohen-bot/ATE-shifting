# %%
# === "Secret Sauce" CSS & Config File ===
# --- Libraries for "Secret Sauce" ---
import sys
from IPython.display import display, HTML, Javascript

# ---"Secret Sauce" Function ---
def apply_config_file(kaggle_path, local_path, project_year, project_name):
    sys.path.append(f"{kaggle_path}/config_file/{project_year}/{project_name}/")
    sys.path.append(f"{local_path}/config_file/{project_year}/{project_name}")

def apply_css_file(kaggle_path, local_path, project_year, css_file_name):
    try:
        return HTML("<style>"+ open(f"{kaggle_path}/css/{project_year}/{css_file_name}.css", "r").read()+ "</style>")
    except:
        return HTML("<style>"+ open(f"{local_path}/css/{project_year}/{css_file_name}.css", "r").read()+ "</style>")

# --- "Secret Sauce" Variables ---
""" Change Variables ~! HERE !~ """
project_name = "bigmartsales"
project_year = "2024"
css_file_name = "css_" + project_name
kaggle_path = "/kaggle/input/caesarmario"
local_path = "config_kaggle"

# --- Apply Function & Import Config File ---
apply_config_file(kaggle_path, local_path, project_year, project_name)
from config_file import *
apply_css_file(kaggle_path, local_path, project_year, css_file_name)

# %% [markdown]
# <!--- Project Title --->
# <span class="dates">II.XXVIII.MMXXIV | @caesarmario</span><br>
# <span class="title-normal">Python Magic: </span>
# <span class="title-highlight"> Big Mart Sales Data Transformed</span><br>
# <span class="subtitle">Data Pre-processing, EDA & Feature Engineering on Big Mart Sales Dataset</span>
# <hr>
# <!-- Hello world 👋. Thank you so much for downloading/forking my codes/works. If you like my works, please support me by giving upvotes and comments on my Kaggle profile (https://www.kaggle.com/caesarmario/). Thank you so much and have a great day 😆👍. More about me: https://linktr.ee/caesarmario_ -->

# %% [markdown]
# # <div class="header1">1. | Introduction 👋</div>
# <center>
#     <img src="https://images.unsplash.com/photo-1588421024623-940056140e58?ixlib=rb-1.2.1&ixid=MnwxMjA3fDB8MHxwaG90by1wYWdlfHx8fGVufDB8fHx8&auto=format&fit=crop&w=1169&q=80" alt="Mart" width="80%">
# </center>

# %% [markdown]
# ## <div class="header2">🤔 Dataset Problems</div>
# <div class="explain-box">
#     BigMart's data scientists collected sales data for <b>1559 commodities across 10 locations in various cities during 2013</b>. Additionally, specific characteristics of each product and retailer were identified. This notebook will undertake <mark>data pre-processing and feature engineering to ensure the dataset is ready for use by the machine learning model</mark>. Additionally, this notebook will <mark>involve initial data exploration, EDA, and some hypothesis testing</mark>. These steps <b>ensure a thorough understanding of the data and its nuances before applying it to the machine-learning model</b>.
# </div>

# %% [markdown]
# ## <div class="header2">📌 Notebook Objectives</div>
# <div class="explain-box">
#     This notebook <b>aims</b> to:
#     <ul>
#         <li>Perform <mark>initial data exploration</mark>.</li>
#         <li>Perform <mark> data pre-processing using Pandas and its related libraries</mark>.</li>
#         <li>Perform <mark> EDA and hypothesis testing (statistical and non-statistical)</mark> in cleaned dataset.</li>
#         <li>Perform <mark> feature engineering (one-hot encoding, label encoding, and binning)</mark>.</li>
#     </ul>
# </div>

# %% [markdown]
# ## <div class="header2">🧾 Dataset Description</div>
# <div class="explain-box">
#     The following is the <b>structure of the dataset</b>.<br>
# <table style="font-family: Inconsolata; font-weight: 300; font-size: 12px; text-align: left; padding: 8px; border-collapse: collapse; width: 100%;">
#     <thead>
#         <tr>
#             <th style="font-family: Inconsolata; font-weight: 900; text-align: center; font-size: 14px; background-color: #C4ECFF">Variable Name</th>
#             <th style="font-family: Inconsolata; font-weight: 900; text-align: center; font-size: 14px; background-color: #C4ECFF">Description</th>
#             <th style="font-family: Inconsolata; font-weight: 900; text-align: center; font-size: 14px; background-color: #C4ECFF">Sample Data</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <td><b>Item_Identifier</b></td>
#             <td>Product ID</td>
#             <td>FDA15; DRC01; ...</td>
#         </tr>
#         <tr>
#             <td><b>Item_Weight</b></td>
#             <td>Weight of product</td>
#             <td>9.3; 5.92, ...</td>
#         </tr>
#         <tr>
#             <td><b>Item_Fat_Content</b></td>
#             <td>Content of product (low fat or regular)</td>
#             <td>Low Fat; Regular; ...</td>
#         </tr>
#         <tr>
#             <td><b>Item_Visibility</b></td>
#             <td>The percentage of all products in the store that are assigned to a specific product in the total display area</td>
#             <td>0.016047301; 0.016760075; ......</td>
#         </tr>
#         <tr>
#             <td><b>Item_Type</b></td>
#             <td>Category of product</td>
#             <td>Dairy; Soft Drinks; ...</td>
#         </tr>
#         <tr>
#             <td><b>Item_MRP</b></td>
#             <td>Maximum retail price of a product</td>
#             <td>249.8092; 141.618; ...</td>
#         </tr>
#         <tr>
#             <td><b>Outlet_Identifier</b></td>
#             <td>Store ID</td>
#             <td>OUT049; OUT010; ...</td>
#         </tr>
#         <tr>
#             <td><b>Outlet_Establishment_Year</b></td>
#             <td>Year the store established</td>
#             <td>2009; 1998; ...</td>
#         </tr>
#         <tr>
#             <td><b>Outlet_Size</b></td>
#             <td>Size of the store</td>
#             <td>Medium; High; ...</td>
#         </tr>
#         <tr>
#             <td><b>Outlet_Location_Type</b></td>
#             <td>The type of city where the store is located</td>
#             <td>Tier 1; Tier 3; ...</td>
#         </tr>
#         <tr>
#             <td><b>Outlet_Type</b></td>
#             <td>Type of the store</td>
#             <td>Supermarket Type1; Grocery Store; ...</td>
#         </tr>
#         <tr>
#             <td><b>Item_Outlet_Sales</b></td>
#             <td>Sales of product</td>
#             <td>3735.138; 2097.27; ...</td>
#         </tr>
#     </tbody>
# </table>
# <hr>
# <center>
#     <span class="thanks-explain">📌 Like this notebook? You can support me by giving <mark><b>upvote</b></mark> 😆👍🔼</span><br>
#     <span class="thanks-watermark">Follow me in other platform: <a href="https://linktr.ee/caesarmario_">linktr.ee/caesarmario_</a></span><br>
#     <span class="three-dots2">...</span><br>
#     <span class="thanks-watermark"><u>Support me!</u></span><br>
#     <span class="ko-fi">
#         <a href='https://ko-fi.com/D1D3JU963' target='_blank'><img src='https://ko-fi.com/img/githubbutton_sm.svg' alt='Support me on Ko-fi Button'/></a><br>
#     </span>
# </center>
# <hr>
# </div>

# %% [markdown]
# # <div class="header1">2. | Installing and Importing Libraries 📚</div>
# <div class="explain-box">
#     <b>Installing and Importing libraries</b> that will be used in this notebook.
# </div>

# %%
# --- Installing Libraries ---
# !pip install ydata-profiling
# !pip install pywaffle
# !pip install highlight-text

# --- Importing Libraries ---
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.ticker as mtick
import seaborn as sns
import math

from datetime import datetime
from matplotlib.colors import LinearSegmentedColormap, NoNorm
from ydata_profiling import ProfileReport
from highlight_text import fig_text, ax_text

# %% [markdown]
# # <div class="header1">3. | Reading Dataset 👓</div>
# <div class="explain-box">
#     After importing libraries, <b>the dataset that will be used will be imported</b>.
# </div>

# %%
# --- Importing Dataset ---
df = pd.read_csv("/kaggle/input/big-mart-sales/train_v9rqX0R.csv")

# --- Reading Train Dataset ---
print(clr.start+".: Imported Dataset :."+clr.end)
print(clr.color+"*" * 23)
df.head().style.background_gradient(cmap="Blues").hide()

# %% [markdown]
# # <div class="header1">4. | Initial Dataset Exploration 🔍</div>
# <div class="explain-box">
#     This section will focused on <b>initial data exploration on the dataset</b> with <u>Pandas Profiling</u> before pre-processing performed.
# </div>

# %%
# --- Dataset Report ---
ProfileReport(df, title="Big Mart Sales Dataset Report", minimal=True
              , progress_bar=False, samples=None, correlations=None, interactions=None, explorative=True, dark_mode=True
              , notebook={"iframe":{"height": "700px"}}
              , html={"style":{"primary_color": color_line}}
              , missing_diagrams={"heatmap": False, "dendrogram": False}).to_notebook_iframe()

# %% [markdown]
# <div class="explain-box">
#     From the <b>dataset report</b>, it can be <mark><b>concluded</b></mark> that:<br>
#     <b>🔠 <u>Categorical Variables</u></b>:<br>
#     <blockquote style="color: #000000;">
#         <ul>
#             <li>There are <mark>missing values detected in "Outlet_Size"</mark> column.</li>
#             <li>There are <b>1559 unique item IDs</b> in the dataset. Also, <mark>each item ID starts with the same specific character (Ex: "DR", "FD", or "NC") followed by numbers</mark> at the end of ID.</li>
#             <li>In the "Item_Fat_Content" column, <mark>most of the products are categorized as "Low Fat" products</mark>. In addition, <b>there are inconsistent values, which means that some values have the same meaning but in different forms</b>. For example, "LF" and "low fat" for Low Fat" and "reg" for Regular.</li>
#             <li>In the "Item_Type" column, <mark>there are 16 item types available, with "Fruits and vegetables" becoming the item type with the highest number</mark>.</li>
#             <li>There are <mark>ten outlets</mark> in the "Outler_Identifier" column, with <b>almost all the outlets having the same number of outlets except "OUT10" and "OUT19"</b>, which have the least number of outlets.</li>
#             <li>There are <b>3 types of outlet sizes in the "Outler_Size" column</b> which are <mark>small, medium, and high size</mark>. <mark>"Medium" size becomes the outlet size with the most number while the smallest number outlet size is "High" size</mark>.</li>
#             <li>In the "Outlet_Location_Type" column, <mark>there are 3 levels of outlet location: tier 1, tier 2, and tier 3</mark>. <mark>Tier 3 becomes the outlet location with the most number while the smallest number of outlet locations is Tier 1</mark>.</li>
#             <li>There are <b>4 outlet types in the "Outlet_Type" column</b>, namely <mark>grocery store, supermarket type 1, supermarket type 2, and supermarket type 3</mark>. <mark>Supermarket type 1 becomes the outlet type with the most number while the smallest number outlet type is supermarket type 2</mark>.</li>
#         </ul>
#     </blockquote>
#     <b>🔢 <u>Continuous Variables</u></b>:<br>
#     <blockquote style="color: #000000;">
#         <li>There are <mark>missing values detected in the "Item_Weight"</mark> column.</li>
#         <li><mark>"Item_Weight", "Item_MRP", and "Outlet_Establishment_Year" distributions are normal</mark> (no outliers detected in these columns). These are also proven from the skewness value, in which the skewness is less than 0.5.</li>
#         <li>However, for the <mark>"Item_Visibility" and "Item_Outlet_Sales" distributions, the distribution is right-skewed distributions</mark> (have a long right tail, and the mean position is on the right side of the data). In addition, these columns' <b>skewness value is more than 1</b>. These outliers will be pre-processed in the next section.</li>
#         <blockquote>
#             <span style="font-size: 11px;">📌 If skewness is <b>less than -1 or greater than 1</b>, the distribution is <mark>highly skewed</mark>. If skewness is <b>between -1 and -0.5 or between 0.5 and 1</b>, the distribution is <mark>moderately skewed</mark>. If skewness is <b>between -0.5 and 0.5</b>, the distribution is <mark>approximately symmetric</mark>.
#             </span>
#         </blockquote>
#         <li>Looking at the kurtosis value, <mark>all continuous variables are platikurtic</mark> since the kurtosis values are less than 3</li>
#         <blockquote>
#             <span style="font-size: 11px;">📌 <mark>Kurtosis</mark> values used to show <mark>tailedness of a column</mark>. The value of normal distribution (mesokurtotic) should be equal to 3. If the kurtosis value is more than 3, it is called leptokurtic. Meanwhile, if the kurtosis value is less than 3, then it is called platikurtic.
#             </span>
#         </blockquote>
# </div>
# <!-- Hello world 👋. Thank you so much for downloading/forking my codes/works. If you like my works, please support me by giving upvotes and comments on my Kaggle profile (https://www.kaggle.com/caesarmario/). Thank you so much and have a great day 😆👍. More about me: https://linktr.ee/caesarmario_ -->

# %% [markdown]
# # <div class="header1">5. | Data Preprocessing ⚙️</div>
# <div class="explain-box">
#     This section <b>will perform data pre-processing to ensure high-quality data</b> by cleaning dirty data, imputing missing values, and handling outliers.
# </div>

# %% [markdown]
# ## <div class="header2">5.1 | Handling Dirty Data🧹</div>
# <div class="explain-box">
#     In previous section, it is already mentioned that there are <b>some inconsistent values detected in "Item_Fat_Content" column</b>. In this section, <mark>those inconsistent values will be transformed into one value</mark>, which has the same meaning/interpretation.
# </div>
# <!-- Hello world 👋. Thank you so much for downloading/forking my codes/works. If you like my works, please support me by giving upvotes and comments on my Kaggle profile (https://www.kaggle.com/caesarmario/). Thank you so much and have a great day 😆👍. More about me: https://linktr.ee/caesarmario_ -->

# %%
# --- Handling Incosistent Values ---
df['Item_Fat_Content'] = df['Item_Fat_Content'] \
                            .replace(['LF', 'low fat'], 'Low Fat') \
                            .replace('reg', 'Regular')

# %%
# --- DataFrame ---
df_dirty = pd.DataFrame(df["Item_Fat_Content"].value_counts()).reset_index()

# --- Variables ---
item_fat_type = ["Low Fat", "Regular"]
cnt_label = dict(fontsize=8, horizontalalignment='center', verticalalignment='center')
xy_label = dict(fontweight='bold', fontsize=8)
x_ticks = list(np.arange(0, 6000, 1000))
tick_params = dict(length=3, width=1, color=color_line)
suptitle = dict(x=0.125, y=0.97, fontsize=13, weight='heavy', ha='left', va='bottom', fontname=font_main)
title = dict(x=0.125, y=0.93, fontsize=8, weight='normal', ha='left', va='bottom', fontname=font_alt)
highlight_textprops = [{'weight':'bold', 'color': colors[1]}]

# --- Dirty Data Bar Chart ---
fig, ax = plt.subplots(figsize=(7, 4))
ax = sns.countplot(y='Item_Fat_Content', data=df
                   , palette=[colors[1], black_palette[4]]
                   , edgecolor="black"
                   , alpha=0.85)
for rect in ax.patches:
    width, height = rect.get_width(), rect.get_height()
    x, y = rect.get_xy()
    ax.text(x+width/2, y+height/2, '{:.0f}'.format(width), **cnt_label)
ax.set_yticklabels(item_fat_type, fontsize=7, fontname=font_alt)
plt.xticks(fontsize=7, ticks=x_ticks, fontname=font_alt)
plt.ylabel('Item Fat Content\n', **xy_label)
plt.xlabel('')
plt.grid(axis='y', alpha=0, zorder=2)
plt.grid(axis='x', which='major', alpha=0.3, color=color_grid, linestyle='dotted', zorder=1)
plt.tick_params(bottom='on', **tick_params)
ax=plt.gca()
for spine in ax.spines.values(): spine.set_color('None')
ax.spines['bottom'].set_visible(True)
ax.spines['bottom'].set_color(color_line)
fig_text(s='Item Fat Content Distribution after Cleaning', **suptitle)
fig_text(s="After cleaning the dirty data, <low fat products still have the largest distribution>.", highlight_textprops=highlight_textprops, **title)
plt.gcf().text(0.74, -0.04, 'kaggle.com/caesarmario', style='italic', fontsize=6)
plt.show();

# %% [markdown]
# ## <div class="header2">5.2 | Handling Missing Values ❓</div>
# <div class="explain-box">
#     In the previous section, it is already mentioned that there are <b>some missing values detected in two columns, namely "Outlet_Size" and "Item_Weight" columns</b>. In this section, <mark>those missing values will be handled by imputing it for both columns</mark>.
# </div>
# <!-- Hello world 👋. Thank you so much for downloading/forking my codes/works. If you like my works, please support me by giving upvotes and comments on my Kaggle profile (https://www.kaggle.com/caesarmario/). Thank you so much and have a great day 😆👍. More about me: https://linktr.ee/caesarmario_ -->

# %% [markdown]
# ### <div class="header3">5.2.1 | Outlet_Size</div>
# <div class="explain-box">
#     Before carrying out the imputation process, <b>an analysis will be carried out first</b> to make sure the imputation values are correct, avoid biased results, and provide a high-quality dataset. Based on the previous section analysis, <b>medium-sized outlets have the highest number</b> in distribution. <mark>However, imputation with a medium value will make the dataset biased since the medium size will dominate the outer outlet size</mark>. Due to this reason, the first step is to <mark>group outlet types and outlet sizes, and then calculate the total available outlets in the dataset</mark>.
# </div>
# <!-- Hello world 👋. Thank you so much for downloading/forking my codes/works. If you like my works, please support me by giving upvotes and comments on my Kaggle profile (https://www.kaggle.com/caesarmario/). Thank you so much and have a great day 😆👍. More about me: https://linktr.ee/caesarmario_ -->

# %%
# --- Calculate Total Outlets by Grouping "Outlet_Type" and "Outlet_Size" ---
df.groupby(['Outlet_Type', 'Outlet_Size'], dropna=False)['Item_Identifier'] \
            .nunique() \
            .reset_index() \
            .sort_values(by=['Outlet_Size'], ascending=False) \
            .style.background_gradient(cmap='GnBu').hide()

# %% [markdown]
# <div class="explain-box">
#     From the table above, <mark>the small outlet size belongs to the grocery store and mostly to supermarket type 1</mark>. For this case, the <mark>grocery store will be imputed using small value</mark> (last value replacement method), and <mark>supermarket type 1 outlet will be imputed based on the mode of supermarket type 1 outlet size numbers, which is small</mark>.
# </div>
# <!-- Hello world 👋. Thank you so much for downloading/forking my codes/works. If you like my works, please support me by giving upvotes and comments on my Kaggle profile (https://www.kaggle.com/caesarmario/). Thank you so much and have a great day 😆👍. More about me: https://linktr.ee/caesarmario_ -->

# %%
# --- Performing Imputation ---
df['Outlet_Size'] = df['Outlet_Size'].replace(np.nan, 'Small')

# %%
# --- DataFrame After Imputation ---
df.groupby(['Outlet_Type', 'Outlet_Size'], dropna=False)['Item_Identifier'] \
            .nunique() \
            .reset_index() \
            .sort_values(by=['Outlet_Size'], ascending=False) \
            .style.background_gradient(cmap='Blues').hide()

# %% [markdown]
# <div class="explain-box">
#     The data frame above shows that <mark>all the missing values have been imputed</mark> based on the analysis mentioned previously.
# </div>
# <!-- Hello world 👋. Thank you so much for downloading/forking my codes/works. If you like my works, please support me by giving upvotes and comments on my Kaggle profile (https://www.kaggle.com/caesarmario/). Thank you so much and have a great day 😆👍. More about me: https://linktr.ee/caesarmario_ -->

# %% [markdown]
# ### <div class="header3">5.2.2 | Item_Weight</div>
# <div class="explain-box">
#     Similar to the "Outlet_Size" column, <b>an analysis will be carried out first</b> before doing imputation. This is because <b>imputation using mode/mean could make the processed dataset biased and provide not high-quality dataset</b>. The first step is to <mark>separate the item ID and item weight column, and then sort it based on the item ID</mark>.
# </div>
# <!-- Hello world 👋. Thank you so much for downloading/forking my codes/works. If you like my works, please support me by giving upvotes and comments on my Kaggle profile (https://www.kaggle.com/caesarmario/). Thank you so much and have a great day 😆👍. More about me: https://linktr.ee/caesarmario_ -->

# %%
# --- Sorted "Item_Identifier" and "Item_Weight" Columns ---
df[['Item_Identifier', 'Item_Weight']].drop_duplicates() \
                                        .sort_values(by=['Item_Identifier']) \
                                        .head(13) \
                                        .style.background_gradient(cmap='PuBu').hide()

# %% [markdown]
# <div class="explain-box">
#     From the table above, it can be seen that <mark>there are several "Item_Identifiers" that already have "Item_Weight" values and not (null)</mark>. <mark>These null "Item_Weight" values will be imputed based on the previous "Item_Weight" values of each "Item_Identifiers"</mark> to provide a high-quality dataset (last value replacement method).
# </div>
# <!-- Hello world 👋. Thank you so much for downloading/forking my codes/works. If you like my works, please support me by giving upvotes and comments on my Kaggle profile (https://www.kaggle.com/caesarmario/). Thank you so much and have a great day 😆👍. More about me: https://linktr.ee/caesarmario_ -->

# %%
# --- Filling Missing Values based on "Item_Weight" column using 'ffill' & 'bfill' ---
df['Item_Weight'] = df.groupby('Item_Identifier')['Item_Weight'].fillna(method='ffill')
df['Item_Weight'] = df.groupby('Item_Identifier')['Item_Weight'].fillna(method='bfill')

# %%
# --- "Item_Identifier" and "Item_Weight" Columns After Imputation ---
df[['Item_Identifier', 'Item_Weight']].drop_duplicates() \
                                        .sort_values(by=['Item_Identifier']) \
                                        .head(13) \
                                        .style.background_gradient(cmap='GnBu').hide()

# %% [markdown]
# <div class="explain-box">
#     As can be seen, <mark>the missing values have been successfully imputed</mark>. The next step is to <b>perform another check if there are still missing values present in the dataset</b>.
# </div>
# <!-- Hello world 👋. Thank you so much for downloading/forking my codes/works. If you like my works, please support me by giving upvotes and comments on my Kaggle profile (https://www.kaggle.com/caesarmario/). Thank you so much and have a great day 😆👍. More about me: https://linktr.ee/caesarmario_ -->

# %%
# --- Checking Another Missing Values ---
print(clr.start+".: Imported Dataset :."+clr.end)
print(clr.color+"*" * 23)
df[['Item_Identifier', 'Item_Weight']].drop_duplicates() \
                                        .sort_values(by=['Item_Identifier']) \
                                        .loc[df['Item_Weight'].isna()] \
                                        .style.background_gradient(cmap='PuBu').hide()

# %% [markdown]
# <div class="explain-box">
#     After doing another check, there are still missing values in the "Item_Weight" column due to <mark>these item IDs not having previous item weight values</mark>. To tackle this issue, <mark>these missing values will be imputed with the "Item_Weight" column mean value</mark>.
# </div>
# <!-- Hello world 👋. Thank you so much for downloading/forking my codes/works. If you like my works, please support me by giving upvotes and comments on my Kaggle profile (https://www.kaggle.com/caesarmario/). Thank you so much and have a great day 😆👍. More about me: https://linktr.ee/caesarmario_ -->

# %%
# --- Imputation for the Remaining Missing Values using Mean ---
df['Item_Weight']=df['Item_Weight'].fillna(df['Item_Weight'].mean())

# %% [markdown]
# ### <div class="header3">5.2.3 | After Handling Missing Values</div>
# <div class="explain-box">
#     After handling the missing values, <mark>the below figure will show that all the missing values have been successfully imputed</mark>.
# </div>
# <!-- Hello world 👋. Thank you so much for downloading/forking my codes/works. If you like my works, please support me by giving upvotes and comments on my Kaggle profile (https://www.kaggle.com/caesarmario/). Thank you so much and have a great day 😆👍. More about me: https://linktr.ee/caesarmario_ -->

# %%
# --- No Missing Values DataFrame ---
df_missing = pd.DataFrame(df.notna().sum()).reset_index()

# --- Variables ---
y_ticks = [str(perc) + "%" for perc in np.arange(0, 120, 20)]
xy_label = dict(fontweight='bold', fontsize=8)
cnt_label = dict(fontsize=8, horizontalalignment='center', verticalalignment='center', fontname=font_alt)
tick_params = dict(length=3, width=1, color=color_line)
suptitle = dict(x=0.125, y=0.97, fontsize=13, weight='heavy', ha='left', va='bottom', fontname=font_main)
title = dict(x=0.125, y=0.93, fontsize=8, weight='normal', ha='left', va='bottom', fontname=font_alt)
highlight_textprops = [{'weight':'bold', 'color': colors[1]}, {'weight':'bold', 'color': colors[1]}]

# --- Missing Values Bar Chart ---
fig, ax = plt.subplots(figsize=(10, 4))
ax = sns.countplot(x='index', data=df_missing
                   , palette=[colors[1] for idx, col in enumerate(df_missing["index"])]
                   , edgecolor="black"
                   , alpha=0.85)
for rect in ax.patches:
    width, height = rect.get_width(), rect.get_height()
    x, y = rect.get_xy()
    ax.text(x+width/2, y+height/2, '{:.0f}%'.format(height*100), **cnt_label)
ax.set_yticklabels(y_ticks, fontsize=7, fontname=font_alt)
plt.xticks(fontsize=7, rotation=30, ha="right", fontname=font_alt)
plt.ylabel('')
plt.xlabel('\nColumn', **xy_label)
plt.grid(axis='x', alpha=0, zorder=2)
plt.grid(axis='y', which='major', alpha=0.3, color=color_grid, linestyle='dotted', zorder=1)
plt.tick_params(bottom='on', **tick_params)
ax=plt.gca()
for spine in ax.spines.values(): spine.set_color('None')
ax.spines['bottom'].set_visible(True)
ax.spines['bottom'].set_color(color_line)
fig_text(s='Missing Values in After Imputation', **suptitle)
fig_text(s="The <missing values> are <no longer available> in the dataset.", highlight_textprops=highlight_textprops, **title)
plt.gcf().text(0.8, -0.18, 'kaggle.com/caesarmario', style='italic', fontsize=6)
plt.show();

# %% [markdown]
# ## <div class="header2">5.3 | Handling Outliers 🔧</div>
# <div class="explain-box">
#     As mentioned in the previous section, <b>"Item_Visibility" and "Item_Outlet_Sales" have outliers in their distribution</b>. This section will focus on <mark>transforming those columns to eliminate the outliers using log and square root transformation</mark>. After the transformation is done, <mark>the results of the techniques will be compared first</mark> before being applied to the real dataset.
# </div>
# <!-- Hello world 👋. Thank you so much for downloading/forking my codes/works. If you like my works, please support me by giving upvotes and comments on my Kaggle profile (https://www.kaggle.com/caesarmario/). Thank you so much and have a great day 😆👍. More about me: https://linktr.ee/caesarmario_ -->

# %%
# --- Creating Transformation DataFrame ---
df_transform = df[['Item_Visibility', 'Item_Outlet_Sales']].copy()

# --- Log Transformation ---
df_transform['Item_Visibility_log'] = np.log(df_transform['Item_Visibility'])
df_transform['Item_Outlet_Sales_log'] = np.log(df_transform['Item_Outlet_Sales'])

# --- Using Square Root Transformation
df_transform['Item_Visibility_sqrt'] = np.sqrt(df_transform['Item_Visibility'])
df_transform['Item_Outlet_Sales_sqrt'] = np.sqrt(df_transform['Item_Outlet_Sales'])

# %%
# --- DataFrame ---
df_transform_skew = pd.DataFrame(df_transform.skew(axis=0, skipna=True)).T
df_transform_kurt = pd.DataFrame(df_transform.kurt(axis=0, skipna=True)).T

# --- Variables ---
ax_num_iv, ax_num_os = 0, 0
tick_params = dict(length=3, width=1, color=color_line)
suptitle = dict(x=0.5, y=0.94, fontsize=20, weight='heavy', ha='center', va='bottom', fontname=font_main)
title = dict(x=0.5, y=0.93, fontsize=15, weight='normal', ha='center', va='bottom', fontname=font_alt)
highlight_textprops = [{'weight':'bold', 'color': colors[1]}, {'weight':'bold'}, {'weight':'bold'}]

# --- Functions ---
def distribution_plot(ax, col_name):
    skew_value = df_transform_skew.iloc[0][col_name]
    kurt_value = df_transform_kurt.iloc[0][col_name]

    ax.xaxis.set_label_position('top')
    ax.set_title(f"\n{col_name}", fontsize=13, fontweight='bold')
    ax.set_xlabel('Skewness Value: {:.4f}\nKurtosis Value: {:.4f}'.format(skew_value, kurt_value), fontsize=10, fontname=font_alt)
    ax.set_ylabel('')
    ax.grid(axis='y', alpha=0, zorder=2)
    ax.grid(axis='x', which='major', alpha=0.3, color=color_grid, linestyle='dotted', zorder=1)
    for spine in ax.spines.values(): spine.set_color('None')
    ax.spines['bottom'].set_visible(True)
    ax.spines['bottom'].set_color(color_line)
    ax.tick_params(bottom='on', **tick_params)
    
# --- Plot Size ---
fig, ax = plt.subplots(3, 2, figsize=(19, 21))
for col, axes in zip(list(df_transform.columns), ax.flatten()):
    if col.find("Item_Visibility") == 0:
        eda_transform = sns.histplot(data=df_transform, x=col, kde=True, ax=axes, color=colors[3])
        distribution_plot(axes, col)
        ax_num_iv += 1
    else:
        eda_transform = sns.histplot(data=df_transform, x=col, kde=True, ax=axes, color=colors[-2])
        distribution_plot(axes, col)
        ax_num_os += 1
fig_text(s='Transformation Comparison', **suptitle)
fig_text(s='<Distribution Comparison after Transformation> on <"Item_Visibility"> and <"Item_Outlet_Sales">', highlight_textprops=highlight_textprops, **title)
plt.gcf().text(0.78, 0.07, 'kaggle.com/caesarmario', style='italic', fontsize=12)
fig.tight_layout()
plt.show();

# %% [markdown]
# <div class="explain-box">
#     Based on histograms, skewness, and kurtosis values shown above, <mark>square root transformation is better than log transformation</mark> since <b>the histogram distributions of square root transformation are closer to normal distribution</b> even though outliers are still detected in both columns. In addition, the <b>skewness value showed that square root transformation can reduce skewness value effectively</b>. The next step will <b>apply square root transformation</b> for both columns in a real dataset.
# </div>
# <!-- Hello world 👋. Thank you so much for downloading/forking my codes/works. If you like my works, please support me by giving upvotes and comments on my Kaggle profile (https://www.kaggle.com/caesarmario/). Thank you so much and have a great day 😆👍. More about me: https://linktr.ee/caesarmario_ -->

# %%
# --- Apply Square Root Transformation on Real Dataset ---
df['Item_Visibility_sqrt'] = np.sqrt(df['Item_Visibility'])
df['Item_Outlet_Sales_sqrt'] = np.sqrt(df['Item_Outlet_Sales'])

# --- Drop Original Columns ---
df = df.drop(columns=['Item_Visibility', 'Item_Outlet_Sales'])

# %% [markdown]
# # <div class="header1">6. | EDA 📊</div>
# <div class="explain-box">
#     This section <mark>will perform some EDA</mark> to get more insights about dataset and <mark>explore variables relationship</mark> in the dataset using different various plots/charts.
# </div>

# %% [markdown]
# ## <div class="header2">6.1 | Correlation Map</div>
# <!-- Hello world 👋. Thank you so much for downloading/forking my codes/works. If you like my works, please support me by giving upvotes and comments on my Kaggle profile (https://www.kaggle.com/caesarmario/). Thank you so much and have a great day 😆👍. More about me: https://linktr.ee/caesarmario_ -->

# %%
# --- EDA 1 Variables ---
suptitle = dict(x=0.21, y=0.94, fontsize=13, weight='heavy', ha='left', va='bottom', fontname=font_main)
title = dict(x=0.21, y=0.92, fontsize=8, weight='normal', ha='left', va='bottom', fontname=font_alt)
xy_label = dict(size=6, fontname=font_alt)
highlight_textprops = [{'weight':'bold', 'color': colors[0]}]

# --- EDA 1 DataFrame ---
df_corr = df.select_dtypes(exclude=['object'])

# --- Display EDA 1 ---
fig, ax = plt.subplots(figsize=(7, 6))
sns.heatmap(df_corr.corr(), annot=True, cmap="Blues", linewidths=0.7, cbar=False, annot_kws={"size": 7}, rasterized=True)

# --- EDA 1 Settings ---
yticks, ylabels = plt.yticks()
xticks, xlabels = plt.xticks()
ax.set_xticklabels(xlabels, rotation=0, **xy_label)
ax.set_yticklabels(ylabels, **xy_label)
ax.grid(False)
fig_text(s='Numerical Variables Correlation Map', **suptitle)
fig_text(s='Item maximum retail price has <significant correlations> with item outlet sales.', highlight_textprops=highlight_textprops, **title)
plt.tight_layout(rect=[0, 0.04, 1, 1.01])
plt.gcf().text(0.84, 0.03, 'kaggle.com/caesarmario', style='italic', fontsize=5)
plt.show();

# %% [markdown]
# ## <div class="header2">6.2 | Item Fat Content based on Item Type</div>
# <!-- Hello world 👋. Thank you so much for downloading/forking my codes/works. If you like my works, please support me by giving upvotes and comments on my Kaggle profile (https://www.kaggle.com/caesarmario/). Thank you so much and have a great day 😆👍. More about me: https://linktr.ee/caesarmario_ -->

# %%
# --- EDA 2 DataFrames ---
dfreg = df.loc[df['Item_Fat_Content'] == 'Regular']
dfreg = dfreg[['Item_Type', 'Item_Identifier']]
dfreg = dfreg.groupby(['Item_Type'], dropna=False)['Item_Identifier'].nunique().reset_index().sort_values(by=['Item_Identifier'], ascending=False)

dflf = df.loc[df['Item_Fat_Content'] == 'Low Fat']
dflf = dflf[['Item_Type', 'Item_Identifier']]
dflf = dflf.groupby(['Item_Type'], dropna=False)['Item_Identifier'].nunique().reset_index().sort_values(by=['Item_Identifier'], ascending=False)

# --- EDA 2 Variables ---
suptitle = dict(x=0.5, y=1.05, fontsize=12, weight='heavy', ha='center', va='center', color=black_palette[0])
title_prop = dict(style='italic', weight='bold', fontsize=8, ha='center', color=black_palette[0], fontname=font_alt)
exp_text = dict(x=0.5, y=0, fontsize=6, weight='normal', ha='center', va='center', textalign='center', fontname=font_alt)
highlight_explanation = [{'weight':'bold', 'color': colors[1]}, {'weight':'bold'}, {'weight':'bold', 'color': colors[1]}
                        , {'weight':'bold'}, {'weight':'bold', 'color': colors[1]}, {'weight':'bold', 'color': colors[1]}
                        , {'weight':'bold', 'color': colors[1]}, {'weight':'bold', 'color': colors[1]}
                        , {'weight':'bold', 'color': colors[1]}, {'weight':'bold'}, {'weight':'bold', 'color': colors[1]}]

# --- Display EDA 2 ---
plt.figure(figsize=(9, 4))

# --- EDA 2: Left ---
plt.subplot(1, 2, 1)
plt.text(0, 0, 'Low Fat Item Type', **title_prop)
plt.tight_layout(rect=[0, 0, 1, 1.01])
plt.pie(dflf['Item_Identifier'], labels=dflf['Item_Type']
        , colors=sns.color_palette('GnBu'), autopct='%.2f%%'
        , startangle=5, wedgeprops=dict(alpha=0.8, edgecolor=black_palette[1], linewidth=0.5)
        , textprops={'fontsize': 6, 'fontname': font_alt})
centre = plt.Circle((0, 0), 0.8, fc='white', edgecolor=black_palette[1], linewidth=0.5)
fig = plt.gcf()
fig.gca().add_artist(centre)

# --- EDA 2: Right ---
plt.subplot(1, 2, 2)
plt.text(0, 0, 'Regular Item Type', **title_prop)
plt.tight_layout(rect=[0, 0, 1, 1.01])
plt.pie(dfreg['Item_Identifier'], labels=dfreg['Item_Type']
        , colors=sns.color_palette('PuBu'), autopct='%.2f%%'
        , startangle=10, wedgeprops=dict(alpha=0.8, edgecolor=black_palette[1], linewidth=0.5)
        , textprops={'fontsize': 6, 'fontname': font_alt})
centre = plt.Circle((0, 0), 0.8, fc='white', edgecolor=black_palette[1], linewidth=0.5)
fig = plt.gcf()
fig.gca().add_artist(centre)
fig_text(s="Item Fat Content Distribution based on Item Type", **suptitle)
fig_text(s="""The <household item> becomes the item type with the <most number in the low-fat category> with a percentage of <16.87%>. However, the item type with the
<smallest number in the low-fat item type> category is the <seafood items> with a percentage of <0.6%>.


In addition, <fruits and vegetables are the most in the regular category>, with a percentage of <18.33%>, while <seafood> is the item with the 
<smallest number in the regular category>, with a percentage of <0.73%>."""
         , highlight_textprops=highlight_explanation, **exp_text)
plt.gcf().text(0.85, -0.16, 'kaggle.com/caesarmario', style='italic', fontsize=6)
plt.show();

# %% [markdown]
# ## <div class="header2">6.3 | Outlet Location Type based on Outlet Type</div>
# <!-- Hello world 👋. Thank you so much for downloading/forking my codes/works. If you like my works, please support me by giving upvotes and comments on my Kaggle profile (https://www.kaggle.com/caesarmario/). Thank you so much and have a great day 😆👍. More about me: https://linktr.ee/caesarmario_ -->

# %%
# --- EDA 3 DataFrame ---
df_eda3 = pd.crosstab(df["Outlet_Type"], df["Outlet_Location_Type"])

# --- EDA 3 Variables ---
patches_prop = dict(fontsize=7, horizontalalignment='center', verticalalignment='center', fontname=font_alt)
xy_ticks = dict(fontsize=7, fontname=font_alt)
suptitle = dict(x=0.12, y=1.07, fontsize=12, weight='heavy', ha='left', va='bottom', color=black_palette[0])
title = dict(x=0.12, y=1, fontsize=7, weight='normal', ha='left', va='bottom', fontname=font_alt, color=black_palette[0])
highlight_textprops = [{'weight':'bold', 'color': colors[1]}, {'weight':'bold'}]

# --- EDA 3 Display ---
ax = df_eda3.plot(kind='bar', figsize=(9, 4), edgecolor='black', linewidth=0.5, alpha=0.85, zorder=3)

# ---  EDA 3 Settings ---
for rect in ax.patches:
    width, height = rect.get_width(), rect.get_height()
    x, y = rect.get_xy()
    if height > 500: ax.text(x+width/2, y+height/2, '{:.0f}'.format(height), **patches_prop)
    else: ax.text(x+width/2, y+height+50, '{:.0f}'.format(height), **patches_prop)
for i in range(eda3_length): ax.patches[i].set_facecolor(eda3_color_list[i])
for spine in ax.spines.values(): spine.set_color('None')
plt.xlabel('')
plt.ylabel('')
plt.xticks(rotation=0, **xy_ticks)
plt.yticks(**xy_ticks)
plt.grid(axis='x', alpha=0, zorder=2)
plt.grid(axis='y', which='major', alpha=0.75, color=black_palette[4], linestyle='dotted', zorder=1)
plt.tick_params(bottom='on', **tick_params)
ax=plt.gca()
for spine in ax.spines.values(): spine.set_color('None')
ax.spines['bottom'].set_visible(True)
ax.spines['bottom'].set_color(color_line)
plt.legend(loc='upper center', bbox_to_anchor=(0.5, 1.12), ncol=3, borderpad=1, frameon=False, fontsize=6)
fig_text(s="Outlet Location Type based on Outlet Type", **suptitle)
fig_text(s="""<Supermarket type 1 only owned tier 1 locations>. Both <supermarket type 2 and 3 only owned tier 3 locations>, while supermarket type 1
owned every tier locations.""", highlight_textprops=highlight_textprops, **title)
plt.gcf().text(0.77, -0.05, 'kaggle.com/caesarmario', style='italic', fontsize=6)
plt.show();

# %% [markdown]
# ## <div class="header2">6.4 | Outlet Identifier based on Outlet Size</div>
# <!-- Hello world 👋. Thank you so much for downloading/forking my codes/works. If you like my works, please support me by giving upvotes and comments on my Kaggle profile (https://www.kaggle.com/caesarmario/). Thank you so much and have a great day 😆👍. More about me: https://linktr.ee/caesarmario_ -->

# %%
# --- EDA 4 DataFrame ---
df_eda4 = pd.crosstab(df["Outlet_Size"], df["Outlet_Identifier"])

# --- EDA 4 Variables ---
labels = list(df["Outlet_Identifier"].sort_values(ascending=True).unique())
xy_ticks = dict(fontsize=7, fontname=font_alt)
patches_prop = dict(rotation=45, fontsize=5.5, horizontalalignment='center', verticalalignment='center', fontname=font_alt)
suptitle = dict(x=0.12, y=1.09, fontsize=12, weight='heavy', ha='left', va='bottom', color=black_palette[0])
title = dict(x=0.12, y=1, fontsize=7, weight='normal', ha='left', va='bottom', fontname=font_alt, color=black_palette[0])
highlight_textprops = [{'weight':'bold', 'color': colors[1]}, {'weight':'bold'}]

# --- EDA 4 Display ---
ax = df_eda4.plot(kind='bar', figsize=(8, 3), edgecolor='black', linewidth=0.5, alpha=0.85, zorder=3, color=eda4_color_list)

# ---  EDA 4 Settings ---
for rect in ax.patches:
    width, height = rect.get_width(), rect.get_height()
    x, y = rect.get_xy()
    ax.text(x+width/2, y+height+40, '{:.0f}'.format(height), **patches_prop)
for spine in ax.spines.values(): spine.set_color('None')
plt.xlabel('')
plt.ylabel('')
plt.xticks(rotation=0, **xy_ticks)
plt.yticks(**xy_ticks)
plt.grid(axis='x', alpha=0, zorder=2)
plt.grid(axis='y', which='major', alpha=0.75, color=black_palette[4], linestyle='dotted', zorder=1)
plt.legend(labels, loc='upper center', bbox_to_anchor=(0.5, -0.1), ncol=5, borderpad=1, frameon=False, fontsize=6)
plt.tick_params(bottom='on', **tick_params)
ax=plt.gca()
for spine in ax.spines.values(): spine.set_color('None')
ax.spines['bottom'].set_visible(True)
ax.spines['bottom'].set_color(color_line)
fig_text(s="Outlet Identifier based on Outlet Size", **suptitle)
fig_text(s="""<The number of outlet identifiers distribution in each outlet size is approximately the same>, around 900 outlets
<except outlet IDs "OUT10" and "OUT19">, which only have 500 outlets."""
         , highlight_textprops=highlight_textprops, **title)
plt.gcf().text(0.77, -0.14, 'kaggle.com/caesarmario', style='italic', fontsize=6)
plt.show();

# %% [markdown]
# ## <div class="header2">6.5 | Item Outlet Sales Distribution (<i>sqrt</i>) based on Outlet Type and Identifier</div>
# <!-- Hello world 👋. Thank you so much for downloading/forking my codes/works. If you like my works, please support me by giving upvotes and comments on my Kaggle profile (https://www.kaggle.com/caesarmario/). Thank you so much and have a great day 😆👍. More about me: https://linktr.ee/caesarmario_ -->

# %%
# --- EDA 5 Variables ---
xy_label = dict(fontweight='bold', fontsize=12)
xy_ticks = dict(fontsize=11, fontname=font_alt)
suptitle = dict(x=0.125, y=1.01, fontsize=22, weight='heavy', ha='left', va='bottom', fontname=font_main)
title = dict(x=0.125, y=0.98, fontsize=14, weight='normal', ha='left', va='bottom', fontname=font_alt)
highlight_textprops = [{'weight':'bold', 'color': colors[2]}, {'weight':'bold', 'color': colors[2]}]

# --- Display EDA 5 ---
fig, ax = plt.subplots(figsize=(17, 8))
ax = sns.boxplot(data=df, x='Outlet_Identifier', y='Item_Outlet_Sales_sqrt', hue='Outlet_Type', boxprops=dict(alpha=0.9), linewidth=1.5
                 , palette=eda5_color_list)
plt.xticks(**xy_ticks)
plt.yticks(**xy_ticks)
plt.ylabel('Item Outlet Sales\n', **xy_label)
plt.xlabel('')
plt.grid(axis='x', alpha=0, zorder=2)
plt.grid(axis='y', which='major', alpha=0.3, color=color_grid, linestyle='dotted', zorder=1)
plt.tick_params(bottom='on', **tick_params)
ax=plt.gca()
for spine in ax.spines.values(): spine.set_color('None')
ax.spines['bottom'].set_visible(True)
ax.spines['bottom'].set_color(color_line)
plt.legend(loc='upper center', bbox_to_anchor=(0.5, 1.1), ncol=5, borderpad=1, frameon=False, fontsize=11)
fig_text(s='Item Outlet Sales Distribution based on Outlet Type and Identifier', **suptitle)
fig_text(s="The <higher the outlet type>, the <more items/expensive> are purchased at that outlet."
         , highlight_textprops=highlight_textprops, **title)
plt.gcf().text(0.78, -0.045, 'kaggle.com/caesarmario', style='italic', fontsize=10)
plt.show();

# %% [markdown]
# ## <div class="header2">6.6 | Item Category Distribution based on Item Fat Content</div>
# <!-- Hello world 👋. Thank you so much for downloading/forking my codes/works. If you like my works, please support me by giving upvotes and comments on my Kaggle profile (https://www.kaggle.com/caesarmario/). Thank you so much and have a great day 😆👍. More about me: https://linktr.ee/caesarmario_ -->

# %%
# --- EDA 6 DataFrames ---
df_eda6 = df[["Item_Identifier", "Item_Fat_Content"]]
df_eda6["Item_Category"] = df_eda6["Item_Identifier"].astype(str).str[:2].replace(['FD', 'DR', 'NC'],['Food', 'Drink', 'Non-Consumable'])

df_eda6_lf = df_eda6[df_eda6['Item_Fat_Content']=="Low Fat"]
df_eda6_lf = pd.DataFrame(df_eda6_lf.groupby('Item_Category').size().reset_index(name='Total'))

df_eda6_rg = df_eda6[df_eda6['Item_Fat_Content']=="Regular"]
df_eda6_rg = pd.DataFrame(df_eda6_rg.groupby('Item_Category').size().reset_index(name='Total'))
df_eda6_rg.loc[2] = ['Non-Consumable', 0]

# --- EDA 6 Variables ---
label = df_eda6_lf["Item_Category"].to_list()
barh_prop = dict(edgecolor=black_palette[1], linewidth=0.5, alpha=0.85)
bar_label = dict(fontsize=7, padding=5, fontname=font_alt)
xy_ticks = dict(fontsize=7, fontname=font_alt)
axvspan_prop = dict(alpha=0.15, zorder=2)
annotate_lf = dict(xytext=(2, 2), textcoords='offset points', va='center', ha='center', color=colors[1]
                   , fontsize=10, fontweight='bold', fontname=font_alt, style='italic'
                   , bbox=dict(boxstyle='round', pad=0.3, color=colors[1], alpha=0.2))
annotate_rg = dict(xytext=(2, 2), textcoords='offset points', va='center', ha='center', color=colors[8]
                   , fontsize=10, fontweight='bold', fontname=font_alt, style='italic'
                   , bbox=dict(boxstyle='round', pad=0.4, color=colors[8], alpha=0.2))
suptitle = dict(x=0.16, y=0.97, fontsize=12, weight='heavy', ha='left', va='bottom', color=black_palette[0])
title = dict(x=0.16, y=0.94, fontsize=8, weight='normal', ha='left', va='bottom', fontname=font_alt, color=black_palette[0])
highlight_textprops = [{'weight':'bold', 'color': colors[1]}
                       , {'weight':'bold', 'color': colors[1]}
                       , {'weight':'bold'}]

# --- Display EDA 6 ---
plt.figure(figsize=(9, 5))
bar6_lf = plt.barh(label, df_eda6_lf['Total']*-1, zorder=3, color=colors[1], **barh_prop)
bar6_rg = plt.barh(label, df_eda6_rg['Total'], zorder=3, color=colors[7], **barh_prop)
plt.bar_label(bar6_lf, labels=df_eda6_lf['Total'], **bar_label)
plt.bar_label(bar6_rg, labels=df_eda6_rg['Total'], **bar_label)
plt.xticks(ticks=x_ticks_eda6, labels=x_labels_eda6, **xy_ticks)
plt.yticks(**xy_ticks)
plt.grid(axis='y', alpha=0, zorder=2)
plt.grid(axis='x', which='major', alpha=0.75, color=black_palette[4], linestyle='dotted', zorder=1)
plt.annotate('Low Fat', xy=(math.ceil(df_eda6_lf["Total"].max()/-2)-1200, 2), **annotate_lf)
plt.annotate('Regular', xy=(math.ceil(df_eda6_rg["Total"].max()/2)+450, 2), **annotate_rg)
plt.axvspan(math.ceil(df_eda6_lf["Total"].max()/100) * -125, 0, color=colors[1], **axvspan_prop)
plt.axvspan(math.ceil(df_eda6_rg["Total"].max()/100) * 120, 0, color=colors[8], **axvspan_prop)
plt.gcf().text(0.75, -0.02, 'kaggle.com/caesarmario', style='italic', fontsize=6)
fig_text(s="Item Category Distribution based on Item Fat Content", **suptitle)
fig_text(s="<Food> is the category item with the <largest number>. <All non-consumable items are low fat>."
         , highlight_textprops=highlight_textprops, **title)
ax=plt.gca()
for spine in ax.spines.values(): spine.set_color('None')
plt.show();

# %% [markdown]
# ## <div class="header2">6.7 | Outlet Type Percentage based on Item Type</div>
# <!-- Hello world 👋. Thank you so much for downloading/forking my codes/works. If you like my works, please support me by giving upvotes and comments on my Kaggle profile (https://www.kaggle.com/caesarmario/). Thank you so much and have a great day 😆👍. More about me: https://linktr.ee/caesarmario_ -->

# %%
# --- EDA 7 DataFrames ---
df_eda7 = df[["Item_Type", "Outlet_Type"]]
df_eda7 = df_eda7.groupby(["Item_Type", "Outlet_Type"]).size().reset_index(name="Total")
df_eda7['Percentage'] = round(100* df_eda7['Total'] / df_eda7.groupby(['Item_Type'])['Total'].transform('sum'), 2)
df_eda7 = df_eda7.pivot_table('Percentage', 'Item_Type', 'Outlet_Type').sort_values("Item_Type", ascending=False)

# --- EDA 7 Variables ---
xy_ticks = dict(fontsize=7, fontname=font_alt)
suptitle = dict(x=0.125, y=0.97, fontsize=12, weight='heavy', ha='left', va='bottom', fontname=font_main)
title = dict(x=0.125, y=0.95, fontsize=8, weight='normal', ha='left', va='bottom', fontname=font_alt)
highlight_textprops = [{'weight':'bold', 'color': colors[2]}, {'weight':'bold', 'color': colors[2]}]

# --- Display EDA 7 ---
ax = df_eda7.plot(kind='barh', stacked=True, figsize=(8, 8), edgecolor='black'
                  , color=eda7_color_list
                  , linewidth=0.5, alpha=0.85
                  , zorder=3)
for rect in ax.patches:
    width, height = rect.get_width(), rect.get_height()
    x, y = rect.get_xy()
    if width > 5:
        ax.text(x+width/2, y+height/2, '{:.1f}%'.format(width), fontsize=6, horizontalalignment='center', verticalalignment='center')
plt.xlabel('')
plt.ylabel('')
plt.xticks(**xy_ticks)
plt.yticks(**xy_ticks)
plt.grid(axis='y', alpha=0, zorder=2)
plt.grid(axis='x', which='major', alpha=0.3, color=color_grid, linestyle='dotted', zorder=1)
plt.legend(loc='upper center', bbox_to_anchor=(0.5, 1.08), ncol=4, borderpad=1, frameon=False, fontsize=6)
plt.gca().xaxis.set_major_formatter(mtick.PercentFormatter())
plt.tick_params(bottom='on', **tick_params)
for spine in ax.spines.values(): spine.set_color('None')
for spine in ['bottom']:
    ax.spines[spine].set_visible(True)
    ax.spines[spine].set_color(color_line)
fig_text(s='Outlet Type Percentage based on Item Type', **suptitle)
fig_text(s="The <majority percentage> of item types are in <supermarket type 1, followed by grocery store>."
         , highlight_textprops=highlight_textprops, **title)
plt.gcf().text(0.76, 0.04, 'kaggle.com/caesarmario', style='italic', fontsize=6)
plt.show();

# %% [markdown]
# # <div class="header1">7. | Hypothesis Tests 🧪</div>
# <div class="explain-box">
#      This section will perform <mark>hypothesis testing</mark> on the pre-processed/cleaned dataset.
# </div>

# %% [markdown]
# ## <div class="header2">7.1 | Hypothesis 1</div>
# <div class="explain-box">
#     <blockquote style="color: #000000;">
#         <ul>
#             <li><b>H<sub>0</sub></b>: There is <mark><b>no heteroscedasticity</b></mark> between "Item_MRP" and "Item_Weight".</li>
#             <li><b>H<sub>1</sub></b>: There is <mark><b>heteroscedasticity</b></mark> between "Item_MRP" and "Item_Weight". </li>
#         </ul>
#     </blockquote>
# </div>
# <!-- Hello world 👋. Thank you so much for downloading/forking my codes/works. If you like my works, please support me by giving upvotes and comments on my Kaggle profile (https://www.kaggle.com/caesarmario/). Thank you so much and have a great day 😆👍. More about me: https://linktr.ee/caesarmario_ -->

# %%
# --- Variables H1 ---
item_fat_list = list(df["Item_Fat_Content"].unique())
xy_label = dict(fontweight='bold', fontsize=10)
xy_ticks = dict(fontsize=8, fontname=font_alt)
scatter_style = dict(s=45, linewidth=0.65, edgecolor=scatter_color_edge, alpha=0.8)
grid_style = dict(alpha=0.3, color=color_grid, linestyle='dotted', zorder=1)
suptitle = dict(x=0.125, y=0.97, fontsize=16, weight='heavy', ha='left', va='bottom', color=black_palette[0])
title = dict(x=0.125, y=0.94, fontsize=10, weight='normal', ha='left', va='bottom', fontname=font_alt, color=black_palette[0])
highlight_textprops = [{'weight':'bold', 'color': colors[1]}]
sub_axes = [None] * 2

# --- Display H1 ---
fig, ax = plt.subplots(figsize=(10, 7))
for idx, item_fat in enumerate(item_fat_list):
    ax.scatter(data=df[['Item_Weight', 'Item_MRP']].loc[df['Item_Fat_Content'] == item_fat]
               , x='Item_Weight', y='Item_MRP', color=h1_color_list[idx], **scatter_style)
    ax.set_xlabel('\nItem Weight', **xy_label)
    ax.set_ylabel('Item Max. Retail Price\n', **xy_label)
    ax.grid(axis='y', which='major', **grid_style)
    ax.grid(axis='x', which='major', **grid_style)
    for spine in ax.spines.values(): spine.set_color('None')
    for spine in ['bottom', 'left']:
        ax.spines[spine].set_visible(True)
        ax.spines[spine].set_color(color_line)
    plt.tick_params(bottom='on', left='on', **tick_params)
    plt.xticks(**xy_ticks)
    plt.yticks(**xy_ticks)
plt.legend(item_fat_list, loc='upper center', bbox_to_anchor=(0.5, 1.07), ncol=5, borderpad=1, frameon=False, fontsize=7)
fig_text(s='Hypothesis 1 - Heteroscedasticity Test', **suptitle)
fig_text(s="""There is <no specific pattern> for irregular points spread above and below the 0 axes on the Y-axis."""
         , highlight_textprops=highlight_textprops, **title)
plt.gcf().text(0.77, 0, 'kaggle.com/caesarmario', style='italic', fontsize=7)
plt.show();

# %% [markdown]
# <div class="explain-box">
#     <blockquote style="font-size: 16px; color: #000000;">
#         ▶ Conclusion: <b>H<sub>0</sub> accepted</b>
#     </blockquote>
# </div>
# <!-- Hello world 👋. Thank you so much for downloading/forking my codes/works. If you like my works, please support me by giving upvotes and comments on my Kaggle profile (https://www.kaggle.com/caesarmario/). Thank you so much and have a great day 😆👍. More about me: https://linktr.ee/caesarmario_ -->

# %% [markdown]
# ## <div class="header2">7.2 | Hypothesis 2</div>
# <div class="explain-box">
#     <blockquote style="color: #000000;">
#         <ul>
#             <li><b>H<sub>0</sub></b>: Tier 3 <mark><b>does not have the most numbers</b></mark> in "High" size outlets.</li>
#             <li><b>H<sub>1</sub></b>: Tier 3 <mark><b>has the most numbers</b></mark> in "High" size outlets. </li>
#         </ul>
#     </blockquote>
# </div>
# <!-- Hello world 👋. Thank you so much for downloading/forking my codes/works. If you like my works, please support me by giving upvotes and comments on my Kaggle profile (https://www.kaggle.com/caesarmario/). Thank you so much and have a great day 😆👍. More about me: https://linktr.ee/caesarmario_ -->

# %%
# --- DataFrame H2 ---
df_h2 = pd.crosstab(df["Outlet_Size"], df["Outlet_Location_Type"])

# --- Variables H2 ---
patches_prop = dict(fontsize=7, horizontalalignment='center', verticalalignment='center', fontname=font_alt)
xy_ticks = dict(fontsize=7, fontname=font_alt)
suptitle = dict(x=0.12, y=1.03, fontsize=12, weight='heavy', ha='left', va='bottom', color=black_palette[0])
title = dict(x=0.12, y=1, fontsize=7, weight='normal', ha='left', va='bottom', fontname=font_alt, color=black_palette[0])
highlight_textprops = [{'weight':'bold', 'color': colors[1]}]

# --- Display H2 ---
ax = df_h2.plot(kind='bar', figsize=(9, 4), edgecolor='black', linewidth=0.5, alpha=0.85, zorder=3, color=h2_color_list)

# --- Settings H2 ---
for rect in ax.patches:
    width, height = rect.get_width(), rect.get_height()
    x, y = rect.get_xy()
    if height > 500: ax.text(x+width/2, y+height/2, '{:.0f}'.format(height), **patches_prop)
    else: ax.text(x+width/2, y+height+50, '{:.0f}'.format(height), **patches_prop)
for spine in ax.spines.values(): spine.set_color('None')
plt.xlabel('')
plt.ylabel('')
plt.xticks(rotation=0, **xy_ticks)
plt.yticks(**xy_ticks)
plt.grid(axis='x', alpha=0, zorder=2)
plt.grid(axis='y', which='major', alpha=0.75, color=black_palette[4], linestyle='dotted', zorder=1)
plt.legend(loc='upper center', bbox_to_anchor=(0.5, 1.12), ncol=3, borderpad=1, frameon=False, fontsize=6)
plt.tick_params(bottom='on', **tick_params)
ax=plt.gca()
for spine in ax.spines.values(): spine.set_color('None')
ax.spines['bottom'].set_visible(True)
ax.spines['bottom'].set_color(color_line)
fig_text(s="Hypothesis 2 - High-size Outlets Number in Tier 3", **suptitle)
fig_text(s="""<Tier 3 has the most numbers in medium-size outlets>, followed by high-size outlets.""", highlight_textprops=highlight_textprops, **title)
plt.gcf().text(0.77, -0.03, 'kaggle.com/caesarmario', style='italic', fontsize=6)
plt.show();

# %% [markdown]
# <div class="explain-box">
#     <blockquote style="font-size: 16px; color: #000000;">
#         ▶ Conclusion: <b>H<sub>0</sub> accepted</b>
#     </blockquote>
# </div>
# <!-- Hello world 👋. Thank you so much for downloading/forking my codes/works. If you like my works, please support me by giving upvotes and comments on my Kaggle profile (https://www.kaggle.com/caesarmario/). Thank you so much and have a great day 😆👍. More about me: https://linktr.ee/caesarmario_ -->

# %% [markdown]
# ## <div class="header2">7.3 | Hypothesis 3</div>
# <div class="explain-box">
#     <blockquote style="color: #000000;">
#         <ul>
#             <li><b>H<sub>0</sub></b>: There was <mark><b>a decrease in the number of outlets</b></mark> from 1985 to 1998.</li>
#             <li><b>H<sub>1</sub></b>: There was <mark><b>an increase in the number of outlets</b></mark> from 1985 to 1998. </li>
#         </ul>
#     </blockquote>
# </div>
# <!-- Hello world 👋. Thank you so much for downloading/forking my codes/works. If you like my works, please support me by giving upvotes and comments on my Kaggle profile (https://www.kaggle.com/caesarmario/). Thank you so much and have a great day 😆👍. More about me: https://linktr.ee/caesarmario_ -->

# %%
# --- DataFrame H3 ---
df_h3 = df["Outlet_Establishment_Year"].value_counts()
df_h3 = pd.DataFrame(df_h3).reset_index().sort_values("Outlet_Establishment_Year")

# --- Variables H3 ---
patches_prop = dict(fontsize=7, horizontalalignment='center', verticalalignment='center', fontname=font_alt)
xy_ticks = dict(fontsize=6, fontname=font_alt)
suptitle = dict(x=0.13, y=0.96, fontsize=12, weight='heavy', ha='left', va='bottom', color=black_palette[0])
title = dict(x=0.13, y=0.93, fontsize=7, weight='normal', ha='left', va='bottom', fontname=font_alt, color=black_palette[0])
highlight_textprops = [{'weight':'bold', 'color': colors[5]}]

# --- Display H3 ---
ax = df_h3.plot(x="Outlet_Establishment_Year", y="count", kind='bar', figsize=(9, 4), legend=None
                , edgecolor='black', linewidth=0.5, alpha=0.85, zorder=3, color=h3_color_list)

# --- Settings H3 ---
for rect in ax.patches:
    width, height = rect.get_width(), rect.get_height()
    x, y = rect.get_xy()
    if height > 500: ax.text(x+width/2, y+height/2, '{:.0f}'.format(height), **patches_prop)
    else: ax.text(x+width/2, y+height+50, '{:.0f}'.format(height), **patches_prop)
for spine in ax.spines.values(): spine.set_color('None')
plt.xlabel('')
plt.ylabel('')
plt.xticks(rotation=0, **xy_ticks)
plt.yticks(**xy_ticks)
plt.grid(axis='x', alpha=0, zorder=2)
plt.grid(axis='y', which='major', alpha=0.75, color=black_palette[4], linestyle='dotted', zorder=1)
plt.tick_params(bottom='on', **tick_params)
ax=plt.gca()
for spine in ax.spines.values(): spine.set_color('None')
ax.spines['bottom'].set_visible(True)
ax.spines['bottom'].set_color(color_line)
fig_text(s="Hypothesis 3 - Outlet Numbers between 1985 to 1998", **suptitle)
fig_text(s="""There was a <decrease> in the number of outlets in the year 1985 to 1998.""", highlight_textprops=highlight_textprops, **title)
plt.gcf().text(0.77, -0.06, 'kaggle.com/caesarmario', style='italic', fontsize=6)
plt.show();

# %% [markdown]
# # <div class="header1">8. | Feature Engineering 🪚</div>
# <div class="explain-box">
#      This section will perform <b>feature engineering</b> including <mark>one-hot encoding, label encoding, and binning</mark>.
# </div>

# %% [markdown]
# ## <div class="header2">8.1 | New Columns</div>
# <!-- Hello world 👋. Thank you so much for downloading/forking my codes/works. If you like my works, please support me by giving upvotes and comments on my Kaggle profile (https://www.kaggle.com/caesarmario/). Thank you so much and have a great day 😆👍. More about me: https://linktr.ee/caesarmario_ -->

# %% [markdown]
# ### <div class="header3">8.1.1 | Item_Category</div>
# <div class="explain-box">
#     A new column called <mark>"Item_Category"</mark> will be created <b>based on the first 2 letters in the "Item_Identifier" column</b>. <b>FD</b> will be classified <b>as food products</b>, <b>DR as drink products</b>, and <b>NC as non-consumable</b>.
# </div>
# <!-- Hello world 👋. Thank you so much for downloading/forking my codes/works. If you like my works, please support me by giving upvotes and comments on my Kaggle profile (https://www.kaggle.com/caesarmario/). Thank you so much and have a great day 😆👍. More about me: https://linktr.ee/caesarmario_ -->

# %%
# --- Creating 'Item_Category' Column ---
df['Item_Category'] = df['Item_Identifier'].astype(str).str[:2]
df['Item_Category'] = df['Item_Category'].replace(['FD', 'DR', 'NC'],['Food', 'Drink', 'Non-Consumable'])

# --- Showing Dataset ---
print(clr.start+".: New 'Item_Category' Column :."+clr.end)
print(clr.color+"*" * 33)
df.head().style.set_properties(**highlight_dict1, subset=['Item_Category']).hide()

# %% [markdown]
# ### <div class="header3">8.1.2 | Age_Outlet</div>
# <div class="explain-box">
#     Next, <mark>"Age_Outlet"</mark> will be created based on the <b>substraction of 2022 with the year in "Outlet_Establishment_Year" column</b>.
# </div>
# <!-- Hello world 👋. Thank you so much for downloading/forking my codes/works. If you like my works, please support me by giving upvotes and comments on my Kaggle profile (https://www.kaggle.com/caesarmario/). Thank you so much and have a great day 😆👍. More about me: https://linktr.ee/caesarmario_ -->

# %%
# --- Creating 'Age_Outlet' Column ---
df['Age_Outlet'] = datetime.now().year-df['Outlet_Establishment_Year']

# --- Showing Dataset ---
print(clr.start+".: New 'Age_Outlet' Column :."+clr.end)
print(clr.color+"*" * 30)
df.head().style.set_properties(**highlight_dict2, subset=['Age_Outlet']).hide()

# %% [markdown]
# ## <div class="header2">8.2 | Binning</div>
# <div class="explain-box">
#     Binning method will be performed on <b>"Age_Outlet"</b> to create <mark><b>"Outlet_Category"</b></mark> column.
# </div>
# <!-- Hello world 👋. Thank you so much for downloading/forking my codes/works. If you like my works, please support me by giving upvotes and comments on my Kaggle profile (https://www.kaggle.com/caesarmario/). Thank you so much and have a great day 😆👍. More about me: https://linktr.ee/caesarmario_ -->

# %%
# --- Binning in 'Outlet_Category' ---
bin = [1, 10, 20, 100]
outlet_cat = ['New Outlet', 'Moderate Outlet', 'Old Outlet']
df['Outlet_Category'] = pd.cut(df['Age_Outlet'], bins=bin, labels=outlet_cat)

# --- Showing Dataset ---
print(clr.start+".: New 'Outlet_Category' Column :."+clr.end)
print(clr.color+"*" * 35)
df.head().style.set_properties(**highlight_dict3, subset=['Outlet_Category']).hide()

# %% [markdown]
# ## <div class="header2">8.3 | Label Encoding</div>
# <div class="explain-box">
#     This section will perform <mark>label encoding</mark> for <b>"Item_Fat_Content"</b> column.
# </div>
# <!-- Hello world 👋. Thank you so much for downloading/forking my codes/works. If you like my works, please support me by giving upvotes and comments on my Kaggle profile (https://www.kaggle.com/caesarmario/). Thank you so much and have a great day 😆👍. More about me: https://linktr.ee/caesarmario_ -->

# %%
# --- Label Encoding on 'Item_Fat_Content' ---
df['Item_Fat_Content_Encoding'] = df['Item_Fat_Content'].replace(['Low Fat', 'Regular'], ['0', '1'])

# --- Showing Dataset ---
print(clr.start+".: New 'Item_Fat_Content_Encoding' Column :."+clr.end)
print(clr.color+"*" * 45)
df.head().style.set_properties(**highlight_dict1, subset=['Item_Fat_Content_Encoding']).hide()

# %% [markdown]
# ## <div class="header2">8.4 | One-Hot Encoding</div>
# <div class="explain-box">
#     <mark>One-hot encoding</mark> will be performed for <b>"Item_Category", "Outlet_Category", "Outlet_Size", and "Outlet_Location_Type"</b>.
# </div>
# <!-- Hello world 👋. Thank you so much for downloading/forking my codes/works. If you like my works, please support me by giving upvotes and comments on my Kaggle profile (https://www.kaggle.com/caesarmario/). Thank you so much and have a great day 😆👍. More about me: https://linktr.ee/caesarmario_ -->

# %%
# --- Perform One-Hot Encoding ---
onehot_cols = ['Item_Category', 'Outlet_Category', 'Outlet_Size', 'Outlet_Location_Type', 'Outlet_Type']
df = pd.get_dummies(data=df, columns=onehot_cols, drop_first=True)

# --- Showing Dataset ---
print(clr.start+".: Perform 'One-Hot Encoding' :."+clr.end)
print(clr.color+"*" * 33)
df.head().style.set_properties(**highlight_dict2, subset=onehot_cols_list).hide()

# %% [markdown]
# ## <div class="header2">8.5 | Dropping Unnecessary Variables</div>
# <div class="explain-box">
#     The <mark>variables that unnecessary will be deleted</mark>. In addition, this section will also <mark>show the final data frame after going through the feature engineering stage</mark>.
# </div>
# <!-- Hello world 👋. Thank you so much for downloading/forking my codes/works. If you like my works, please support me by giving upvotes and comments on my Kaggle profile (https://www.kaggle.com/caesarmario/). Thank you so much and have a great day 😆👍. More about me: https://linktr.ee/caesarmario_ -->

# %%
# --- Drop Unnecessary Variables ---
df = df.drop(columns = ['Item_Fat_Content', 'Outlet_Establishment_Year'])

# --- Final DataFrame ---
print(clr.start+".: Showing Final DataFrame :."+clr.end)
print(clr.color+"*" * 30)
df.head().style.background_gradient(cmap='GnBu').hide()

# %% [markdown]
# # <div class="header1">9. | Final Step 👀</div>
# <div class="explain-box">
#      In this final section, <mark>the new dataset metadata will be shown</mark>. In addition, the new data frame (cleaned) will be <mark>exported</mark> as <code>.csv</code> file. Below is the new data frame metadata from the processing results in the previous section.
# </div>
# <!-- Hello world 👋. Thank you so much for downloading/forking my codes/works. If you like my works, please support me by giving upvotes and comments on my Kaggle profile (https://www.kaggle.com/caesarmario/). Thank you so much and have a great day 😆👍. More about me: https://linktr.ee/caesarmario_ -->

# %% [markdown]
# <table
#   style="font-family: Inconsolata; font-weight: 300; font-size: 12px; text-align: left; padding: 8px; border-collapse: collapse; width: 100%;">
#   <thead>
#     <tr>
#       <th
#         style="font-family: Inconsolata; font-weight: 900; text-align: center; font-size: 14px; background-color: #C4ECFF">
#         Variable Name</th>
#       <th
#         style="font-family: Inconsolata; font-weight: 900; text-align: center; font-size: 14px; background-color: #C4ECFF">
#         Data Type</th>
#       <th
#         style="font-family: Inconsolata; font-weight: 900; text-align: center; font-size: 14px; background-color: #C4ECFF">
#         Description</th>
#       <th
#         style="font-family: Inconsolata; font-weight: 900; text-align: center; font-size: 14px; background-color: #C4ECFF">
#         Sample Data</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td style="font-weight: bold">Item_Identifier</td>
#       <td>Char</td>
#       <td>ProductID</td>
#       <td>FDA15, DRC01, FDN15, …</td>
#     </tr>
#     <tr>
#       <td style="font-weight: bold">Item_Weight</td>
#       <td>Num</td>
#       <td>The product's weight</td>
#       <td>9.3, 5.92, 17.5, …</td>
#     </tr>
#     <tr>
#       <td style="font-weight: bold">Item_Type</td>
#       <td>Char</td>
#       <td>Category of product<br>(Soft Drinks, Dairy, Hard Drinks, Canned, Frozen Foods, <br> Fruits and Vegetables,
#         Snack Foods, Baking Goods, Starchy Foods, Meat, <br> Seafood, Breakfast, Breads, Health and Hygiene,
#         Household, Others)</td>
#       <td>Dairy, Soft Drinks, Meat, …</td>
#     </tr>
#     <tr>
#       <td style="font-weight: bold">Item_MRP</td>
#       <td>Num</td>
#       <td>Maximum Retail Price of a product</td>
#       <td>249.8092, 48.2692, 141.618, …</td>
#     </tr>
#     <tr>
#       <td style="font-weight: bold">Outlet_Identifier</td>
#       <td>Char</td>
#       <td>Outlet ID</td>
#       <td>OUT049,OUT018, OUT049, …</td>
#     </tr>
#     <tr style="background-color: #E0FBFF; font-weight: bold">
#       <td>Item_Visibility_sqrt</td>
#       <td>Num</td>
#       <td>The percentage of a store's overall display area <br> that is dedicated to a single product (Square Root).
#       </td>
#       <td>0.126678, 0.138846, 0.129461, …</td>
#     </tr>
#     <tr style="background-color: #E0FBFF; font-weight: bold">
#       <td>Item_Outlet_Sales_sqrt</td>
#       <td>Num</td>
#       <td>Sales of product (Square Root)</td>
#       <td>61.115775, 21.057607, 45.795961, …</td>
#     </tr>
#     <tr style="background-color: #E0FBFF; font-weight: bold">
#       <td>Age_Outlet</td>
#       <td>Num</td>
#       <td>Age of an outlet</td>
#       <td>23, 13, 35, …</td>
#     </tr>
#     <tr style="background-color: #E0FBFF; font-weight: bold">
#       <td>Item_Fat_Content_Encoding</td>
#       <td>Num</td>
#       <td>Types of Product Content<br><br>0 = Low Fat<br>1 = Regular</td>
#       <td>0, 1, 0, …</td>
#     </tr>
#     <tr style="background-color: #E0FBFF; font-weight: bold">
#       <td>Item_Category_Food</td>
#       <td>Num</td>
#       <td>Encoded Item_Category<br><br>0 ≠ Food<br>1 = Food</td>
#       <td>1, 0, 1, …</td>
#     </tr>
#     <tr style="background-color: #E0FBFF; font-weight: bold">
#       <td>Item_Category_Non-Consumable</td>
#       <td>Num</td>
#       <td>Encoded Item_Category<br><br>0 ≠ Non-Consumable<br>1 = Non-Consumable</td>
#       <td>0, 0, 0, …</td>
#     </tr>
#     <tr style="background-color: #E0FBFF; font-weight: bold">
#       <td>Outlet_Category_Moderate Outlet</td>
#       <td>Num</td>
#       <td>Encoded Outlet_Category<br><br>0 ≠ Moderate Outlet<br>1= Moderate Outlet</td>
#       <td>0, 1, 0, …</td>
#     </tr>
#     <tr style="background-color: #E0FBFF; font-weight: bold">
#       <td>Outlet_Category_Old Outlet</td>
#       <td>Num</b></td>
#       <td>Encoded Outlet_Category<br><br>0 ≠ Old Outlet<br>1 = Old Outlet</td>
#       <td>1, 0, 1, …</td>
#     </tr>
#     <tr style="background-color: #E0FBFF; font-weight: bold">
#       <td>Outlet_Size_Medium</td>
#       <td>Num</td>
#       <td>Encoded Outlet_Size<br><br>0 ≠ Medium<br>1 = Medium</td>
#       <td>1, 1, 1, …</td>
#     </tr>
#     <tr style="background-color: #E0FBFF; font-weight: bold">
#       <td>Outlet_Size_Small</td>
#       <td>Num</td>
#       <td>Encoded Outlet_Size<br><br>0 ≠ Small<br>1 = Small</td>
#       <td>0, 0, 0, …</td>
#     </tr>
#     <tr style="background-color: #E0FBFF; font-weight: bold">
#       <td>Outlet_Location_Type_Tier_2</td>
#       <td>Num</td>
#       <td>Encoded Outlet_Location_Type<br><br>0 ≠ Tier 2<br>1 = Tier 2</td>
#       <td>0, 0, 0, …</td>
#     </tr>
#     <tr style="background-color: #E0FBFF; font-weight: bold">
#       <td>Outlet_Location_Type_Tier_3</td>
#       <td>Num</td>
#       <td>Encoded Outlet_Location_Type<br><br>0 ≠ Tier 3<br>1 = Tier 3</td>
#       <td>0, 1, 0, …</td>
#     </tr>
#     <tr style="background-color: #E0FBFF; font-weight: bold">
#       <td>Outlet_Type_Supermarket_Type1</td>
#       <td>Num</td>
#       <td>Encoded Outlet_Type<br><br>0 ≠ Supermarket Type1<br>1 = Supermarket Type1</td>
#       <td>1, 0, 1, …</td>
#     </tr>
#     <tr style="background-color: #E0FBFF; font-weight: bold">
#       <td>Outlet_Type_Supermarket_Type2</td>
#       <td>Num</td>
#       <td>Encoded Outlet_Type<br><br>0 ≠ Supermarket Type2<br>1 = Supermarket Type2</td>
#       <td>0, 1, 0, …</td>
#     </tr>
#     <tr style="background-color: #E0FBFF; font-weight: bold">
#       <td>Outlet_Type_Supermarket_Type3</td>
#       <td>Num</td>
#       <td>Encoded Outlet_Type<br><br>0 ≠ Supermarket Type3<br>1 = Supermarket Type3</td>
#       <td>0, 0, 0, …</td>
#     </tr>
#   </tbody>
# </table>
# <!-- Hello world 👋. Thank you so much for downloading/forking my codes/works. If you like my works, please support me by giving upvotes and comments on my Kaggle profile (https://www.kaggle.com/caesarmario/). Thank you so much and have a great day 😆👍. More about me: https://linktr.ee/caesarmario_ -->

# %% [markdown]
# <div class="explain-box">
#     The final step will <mark>export the cleaned dataset in a new file</mark> (<code>.csv</code> file).
# </div>
# <!-- Hello world 👋. Thank you so much for downloading/forking my codes/works. If you like my works, please support me by giving upvotes and comments on my Kaggle profile (https://www.kaggle.com/caesarmario/). Thank you so much and have a great day 😆👍. More about me: https://linktr.ee/caesarmario_ -->

# %%
# --- Export Cleaned Dataframe into `.csv` File ---
df.to_csv('processed/train_v9rqX0R_caesarmario.csv', index=False, sep=',', encoding='utf-8')

# %% [markdown]
# <hr>
# <center>
#     <span class="thanks">.: Thanks for Viewing :.</span><br><br>
#     <span class="thanks-explain">📌 Like this notebook? You can support me by giving <mark><b>upvote</b></mark> 😆👍🔼</span><br>
#     <span class="three-dots2">...</span><br><br>
#     <span class="thanks-explain">Similar project on <b><u>GitHub</u></b>:</span><br><br>
#     <span class="promotion">▸▸ Data Processing using <b>SAS Studio</b> <a href="https://github.com/caesarmario/big-mart-sales-preprocessing-SAS-studio">here</a> ◂◂</span><br><br>
#     <span class="thanks-watermark"><u>Support me!</u></span><br>
#     <span class="ko-fi">
#         <a href='https://ko-fi.com/D1D3JU963' target='_blank'><img src='https://ko-fi.com/img/githubbutton_sm.svg' alt='Support me on Ko-fi Button'/></a>
#     </span><br>
#     <span class="thanks-watermark"><u>Follow me in other platform</u></span><br>
#     <div align="center" class="social-media">
#         <ul>
#             <li><a href="https://www.kaggle.com/caesarmario"><img src="https://i.imgur.com/K6QyzaJ.png"></a></li>
#             <li><a href="https://public.tableau.com/app/profile/caesarmario"><img src="https://i.imgur.com/JVxVkeQ.png"></a></li>
#             <li><a href="https://github.com/caesarmario"><img src="https://i.imgur.com/Orp40Ys.png"></a></li>
#             <li><a href="https://caesarmario.medium.com/"><img src="https://i.imgur.com/6TrHyu0.png"></a></li>
#             <li><a href="https://www.linkedin.com/in/caesarmario"><img src="https://i.imgur.com/vVYd0aI.png"></a></li>
#         </ul>
#     </div>
#     <img src="https://i.imgur.com/iuaulzI.png" width=65% alt="WM">
# </center>
