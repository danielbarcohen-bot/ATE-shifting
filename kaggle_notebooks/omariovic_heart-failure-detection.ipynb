# %%
import pandas
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.decomposition import PCA
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestClassifier, VotingClassifier, BaggingClassifier, AdaBoostClassifier, GradientBoostingClassifier
from sklearn.metrics import *

# %%
dataset = pandas.read_csv('/kaggle/input/heart-failure-prediction/heart.csv')
dataset

# %%
dic = dataset[['HeartDisease', 'Sex']].groupby('Sex').mean()
dic.plot(kind = 'bar', color = 'crimson')
plt.show()

# %%
dic = dataset[['ChestPainType', 'HeartDisease']].groupby('ChestPainType').mean().sort_values(by = 'HeartDisease')
dic.plot(kind = 'bar', color = 'gold')
plt.show()

# %%
dic = dataset[['FastingBS', 'HeartDisease']].groupby('FastingBS').mean().sort_values(by = 'HeartDisease')
dic.plot(kind = 'bar', color = 'violet')
plt.show()

# %%
dic = dataset[['RestingECG', 'HeartDisease']].groupby('RestingECG').mean().sort_values(by = 'HeartDisease')
dic.plot(kind = 'bar', color = 'black')
plt.show()

# %%
dic = dataset[['ExerciseAngina', 'HeartDisease']].groupby('ExerciseAngina').mean().sort_values(by = 'HeartDisease')
dic.plot(kind = 'bar', color = 'green')
plt.show()

# %%
dic = dataset[['ST_Slope', 'HeartDisease']].groupby('ST_Slope').mean().sort_values(by = 'HeartDisease')
dic.plot(kind = 'bar', color = 'blue')
plt.show()

# %%
dataset['Sex'] = dataset['Sex'].map({'F': 0, 'M': 1})
dataset['ChestPainType'] = dataset['ChestPainType'].map({'ATA': 0, 'NAP': 1, 'TA': 2, 'ASY': 3})
dataset['RestingECG'] = dataset['RestingECG'].map({'Normal': 0, 'LVH': 1, 'ST': 2}) 
dataset['ExerciseAngina'] = dataset['ExerciseAngina'].map({'N': 0, 'Y': 1})
dataset['ST_Slope'] = dataset['ST_Slope'].map({'Up': 0, 'Down': 1, 'Flat': 2})

# %%
dataset

# %%
corr_matrix = dataset.corr()
def absolute(x):
    return np.abs(x)
plt.figure(figsize = (10, 6))
sns.heatmap(corr_matrix, annot = True, cmap = 'Blues')
plt.show()

# %%
data = dataset.drop(['HeartDisease'], axis = 1).copy()
target = dataset['HeartDisease'].copy()

# %%
data = StandardScaler().fit_transform(data)

# %%
X_train, X_test, y_train, y_test = train_test_split(data, target, test_size = 0.25, random_state = 289)

# %%
model = BaggingClassifier(LogisticRegression(solver = 'liblinear'), n_estimators = 100)
model.fit(X_train, y_train)

# %%
y_pred = model.predict(X_test)
print(classification_report(y_pred, y_test))
