# %% [markdown]
#  <img src="https://www.cs.hs-rm.de/~ulges/pics/banner_statistik2.jpg" width="100%">
#
# # Autopreise vorhersagen
# Wir verwenden in diesme Notebook multiple lineare Regression (wie in der Vorlesung vorgestellt), um die Preise von Autos vorherzusagen.

# %% [markdown]
# ## 1. Daten einlesen
# Wir laden - wie schon im letzten Notebook - die Daten aus der Datei cars.csv ein.

# %%
import pandas

cars = pandas.read_csv('/kaggle/input/carscsv/cars.csv')
columns = cars.columns
for i,col in enumerate(columns):
    print('%.2d : %s' %(i,col))
    
data = cars.values.astype('float')

# %% [markdown]
#  <img src="https://www.cs.hs-rm.de/~ulges/pics/magician.png" width="100%">
#
#
# ## 2. Hyperebene fitten
# Führen Sie nun multiple lineare Regression zur Preisvorhersage durch:
# * Der **Spaltenvektor y** soll vorhergesagt werden. Er besteht aus den Preisen aller Autos.
# * Die **Matrix X** besteht aus *allen anderen* Merkmalen, sowie einer zusätzlichen Spalte in der sich nur *Einsen* befinden.
# Lösen Sie dann (wie in der Vorlesung) das **Lineare Gleichungssystem**
# $$
# \underbrace{X^T \cdot X}_A \cdot \mathbf{w} = \underbrace{X^T \cdot \mathbf{y}}_\mathbf{b}
# $$
# und geben den Ergebnisvektor $\mathbf{w}$ zurück. Dies sind die Parameter der gefundenen Hyperebene.

# %%
import numpy as np


def fit_plane_to_data(data):

    # Spaltenvektor y
    y = None # FIXME

    # Matrix X
    X = None # FIXME

    # Erstelle und löse das Gleichungssystem
    # FIXME
    w = None
    
    return w


w = fit_plane_to_data(data)

# %% [markdown]
# # 4. Anwendung des Modells
# Benutzen Sie das Modell nun, um den Preis von Autos vorherzusagen. Schreiben Sie hierzu die Methode predict() unten. Diese erhält...
# * alle Eingabemerkmale für ein Auto, d.h. eine Zeile unserer data-Matrix mit Ausnahme des Preises.
# * Den Gewichtsvektor $\mathbf{w}$.
#
# predict() bildet nun die gewichtete Summe und gibt somit eine Vorhersage für den Preis des gegebenen Autos zurück.

# %%
def predict(car, w):
    return None # FIXME


''' Vorhersage für das erste Auto '''
# Eingabedaten: Das erste Auto, alle Merkmale bis auf den Preis.
first_car = data[0,1:]
# Der echte Preis des Autos...
price = data[0,0]
# ... und der vorhergesagte Preis.
predicted_price = predict(car, w)

print('Real price = ', data[0,0])
print('Predicted price = ', predicted_price)

# %% [markdown]
# # 3. Testen
# Führen Sie die Preisprognose nun für die ersten 20 Autos durch und vergleichen Sie Ihre Vorhersagen mit den echten Preisen. Wie würden Sie die Prognosen bewerten, und was fällt Ihnen auf?

# %%
# FIXME
