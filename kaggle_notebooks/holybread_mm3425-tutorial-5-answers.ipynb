# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
# Use pandas.read_csv() to create a dataframe named em_df from the dataset at 
# URL: /kaggle/input/global-fossil-co2-emissions-by-country-2002-2022/GCB2022v27_MtCO2_flat.csv

em_df = pd.read_csv('/kaggle/input/global-fossil-co2-emissions-by-country-2002-2022/GCB2022v27_MtCO2_flat.csv')
em_df

# %% [markdown]
# ## Exercise 1 Create a Histogram

# %%
# Use pandas.DataFrame.dropna() to remove rows containing missing values in em_df
em_df = em_df.dropna()

# Select all Carbon Emission records for all countries at 2021
em_2021_df = em_df.loc[(em_df['Year'] == 2021),]

# Create a non-cumulative histogram for the Carbon Emission per Capita records at 2021
# (the column named Per Capita in em_2021_df) with 10 bins

# Replace this line with your code
em_2021_df.hist(column=['Per Capita'], cumulative=False, bins=10)

# %% [markdown]
# ## Exercise 2 Obtain a Summary of Descriptive Statistics

# %%
# Create a summary of descriptive statistics for the Carbon Emission per Capita records at 2021
# (the column named Per Capita in em_2021_df)

# Replace this line with your code
em_2021_df['Per Capita'].describe()

# %% [markdown]
# ## Exercise 3 Calculate z-Scores

# %%
em_2021_df['Per Capita']

# %%
# Import the stats library from the scipy package
from scipy import stats

# Caculate the z-Scores for the Carbon Emission per Capita records at 2021
# (the column named Per Capita in em_2021_df)

# Replace this line with your code
stats.zscore(em_2021_df['Per Capita'])

# %% [markdown]
# ## Exercise 4 Identify Outliers through the Box Plot

# %%
# Import the seaborn and matplotlib.pyplot packages for data viasualization
import seaborn as sns
import matplotlib.pyplot as plt

# Set the size of the plot
plt.figure(figsize=(6,8))

# Use seaborn.boxplot() to create a box plot for the Carbon Emission per Capita records at 2021
# (the column named Per Capita in em_2021_df)

# Replace this line with your code
sns.boxplot(data=em_2021_df, y='Per Capita', orient='v')

# %%
# Use the conditional index to examine the outliers highlighted in the box plot

# Replace this line with your code
em_2021_df.loc[(em_2021_df['Per Capita'] > 14),]

# %% [markdown]
# ## [Optional] Exercise 5 Create Multiple Box Plots

# %%
# Use pandas.DataFrame.loc[] to create a dataframe named em_period_df for records 
# of the Carbon Emission per Capita since 2000 for China and the Global

# Hint: Use pandas.Series.isin() to select rows that contains China or the Global in the Country column

# Replace this line with your code
em_period_df = em_df.loc[(em_df['Year'] >= 2000) & (em_df['Country'].isin(['China', 'Global'])),]

# Use seaborn.boxplot() to create two box plots side-by-side in the same figure for 
# the Carbon Emission per Capita (Per Capita) since 2000 for China and the Global

# Replace this line with your code
sns.boxplot(data=em_period_df, x='Country', y='Per Capita', orient='v')

# %% [markdown]
# ## [Optional] Implication 1
# What is the implication can you draw from comparing the two box plots of the Carbon Emission per Capita?
#
# **Exemplary Answer:**
# > **The size of the Carbon Emission per Capita in China surpassed the world average during the period from 2000 to 2021.**

# %% [markdown]
# ## Exercise 6 Create a Scatter Plot

# %%
# Use pandas.DataFrame.loc[] to create a dataframe named em_full_df for all records 
# of the Carbon Emission per Capita for China and the Global

# Replace this line with your code
em_full_df = em_df.loc[(em_df['Country'].isin(['China', 'Global'])),]

# Use seaborn.scatterplot() to create a scatter plot to visualize the annual change of the Carbon Emission per Capita 
# for China and the World
# Set the Year column as the x-axis and the Per Capita column as the y-axis

# Hint: Set hue='Country' to plot data points for China and the Global in different colors

# Replace this line with your code
sns.scatterplot(data=em_full_df, x='Year', y='Per Capita', hue='Country')

# %% [markdown]
# ## Exercise 7 Create a Covariance Matrix

# %%
# Use pandas.DataFrame.loc[] to create a dataframe named em_cov_df for all records 
# of the Carbon Emission per Capita since 2000

# Replace this line with your code
em_cov_df = em_df.loc[(em_df['Year'] >= 2000),]

# Use pandas.DataFrame.cov() to create a covariance matrix for the followng columns of em_cov_df:
# ['Year', 'Total', 'Coal', 'Oil', 'Gas', 'Cement', 'Flaring', 'Other', 'Per Capita']

# Replace this line with your code
em_cov_df.loc[:,['Year', 'Total', 'Coal', 'Oil', 'Gas', 'Cement', 'Flaring', 'Other', 'Per Capita']].cov()

# %% [markdown]
# ## Exercise 8 Create a Correlation Matrix

# %%
# Use pandas.DataFrame.corr() to create a correlation matrix for the followng columns of em_cov_df:
# ['Year', 'Total', 'Coal', 'Oil', 'Gas', 'Cement', 'Flaring', 'Other', 'Per Capita']
# Assign the correlation matrix to a newly created variable corr_matrix

# Replace this line with your code
corr_matrix = em_cov_df.loc[:,['Year', 'Total', 'Coal', 'Oil', 'Gas', 'Cement', 'Flaring', 'Other', 'Per Capita']].corr()

corr_matrix

# %%
# Set the size of the plot
plt.figure(figsize=(9,6))

# Visualize the correlational matrix
sns.heatmap(corr_matrix, cmap="YlGnBu", annot=True)

# %% [markdown]
# ## Exercise 9 Calculate Correlational Coefficients with p-Values

# %%
# Use stats.pearsonr() to calculate the correlation coefficient between 
# the Carbon Emisssion from Coal and that from Cement in em_cov_df and its p-Value

# Replace this line with your code
stats.pearsonr(em_cov_df['Coal'], em_cov_df['Cement'])

# %% [markdown]
# ## Implication 2
#
# What is the implication that you may draw from the correlation between the Carbon Emission from Goals and Cements?
#
# **Exemplary Answer:**
# > **The positive association means that using goal in steel production leaves a major carbon footprint and steels are used together with cements in real-estate development.**

# %% [markdown]
# ## [Optional] Exercise 10 Calculate Correlational Coefficients for Carbon Emission per Capita Records

# %%
# Use stats.pearsonr() to calculate the correlation coefficient between 
# the Year and the Carbon Emission per Capita in em_cov_df and its p-Value

# Replace this line with your code
stats.pearsonr(em_cov_df['Year'], em_cov_df['Per Capita'])

# %%
# Use seaborn.scatterplot() to create a scatter plot to visualize the relationship between 
# the Year and the Carbon Emission per Capita
# Set the Year column as the x-axis and the Per Capita column as the y-axis

# Replace this line with your code
sns.scatterplot(data=em_cov_df, x='Year', y='Per Capita')

# %% [markdown]
# ## [Optional] Implication 3
#
# What is the implication that you may draw from the correlation between the Year and the Carbon Emission per Capita?
#
# **Exemplary Answer:**
# > **The negative association means that overall, the carbon emission per capita around the globe is in decline since 2000.**
